# %% [markdown]
# ##### ⚠️Deprecated Qiskit module detected.
# We've detected that you've opened a notebook that uses "qiskit.tools" module and/or "cnot()" gate that have been deprecated in Qiskit v1.
#
# A few changes to your notebook are needed so that it continues to work in this hosted environment:
# - Remove all imports of `qiskit.tools` module.
# - Remove all usages of `job_monitor()` method. You can simply use `job.result()` method to monitor job completion and get job result.
# - Replace all usages of `cnot()` gates with `cx()`.
#
# For more information on deprecated Qiskit APIs, please refer to [Qiskit 1.0 feature changes](https://docs.quantum.ibm.com/api/migration-guides/qiskit-1.0-features#qiskit-10-feature-changes)

# %%
from azure.quantum import Workspace
workspace = Workspace (
   resource_id = "/subscriptions/3df80297-0ee4-4237-9d4d-bf9353dc986d/resourceGroups/AzureQuantum/providers/Microsoft.Quantum/Workspaces/QResourceEstimation",
   location = "eastus"
)

from azure.quantum.qiskit import AzureQuantumProvider
from qiskit import QuantumCircuit, transpile
from qiskit.circuit.library import RGQFTMultiplier
from qiskit import *

# %%
def get_transpiled_circ(benchmark, backend):
    basis_gates = backend.configuration().basis_gates
    circ = transpile(benchmark, basis_gates=basis_gates, optimization_level=0)

    # print some statistics
    print(f"[INFO]   qubit count: {circ.num_qubits}")
    print("[INFO]   gate counts")
    for gate, count in circ.count_ops().items():
        print(f"[INFO]   - {gate}: {count}")

    return circ

# %%
provider = AzureQuantumProvider(
            resource_id = "/subscriptions/3df80297-0ee4-4237-9d4d-bf9353dc986d/resourceGroups/AzureQuantum/providers/Microsoft.Quantum/Workspaces/QResourceEstimation",
            location = "eastus")
backend = provider.get_backend('microsoft.estimator')
# Out:
# /tmp/ipykernel_12368/3233661341.py:1: DeprecationWarning: Consider passing "workspace" argument explicitly.
#                  The ability to initialize AzureQuantumProvider with arguments "resource_id", "location" is going to be deprecated in future versions.
#   provider = AzureQuantumProvider(

# %% [markdown]
# ## All Benchmarks (in QASM)

# %% [markdown]
# ## Estimation

# %%
benchmarks = {}

benchmarks['shor-15'] = '''
// Benchmark was created by MQT Bench on 2023-06-29
// For more information about MQT Bench, please visit https://www.cda.cit.tum.de/mqtbench/
// MQT Bench version: v1.0.0
// Qiskit version: {'qiskit-terra': '0.24.1', 'qiskit-aer': '0.12.0', 'qiskit-ignis': None, 'qiskit-ibmq-provider': '0.20.2', 'qiskit': '0.43.1', 'qiskit-nature': '0.6.2', 'qiskit-finance': '0.3.4', 'qiskit-optimization': '0.5.0', 'qiskit-machine-learning': '0.6.1'}

OPENQASM 2.0;
include "qelib1.inc";
qreg q[18];
creg meas[18];
h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
x q[8];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[8],q[12];
cx q[8],q[0];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[8],q[13];
cp(0.0) q[0],q[12];
cx q[8],q[0];
u2(0,0) q[12];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(pi/2) q[8],q[14];
cp(0.0) q[0],q[13];
cx q[8],q[0];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[0],q[14];
cx q[8],q[0];
cp(pi/4) q[8],q[15];
cp(pi/2) q[0],q[14];
cx q[8],q[0];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[0],q[15];
cx q[8],q[0];
cp(pi/8) q[8],q[16];
cp(pi/4) q[0],q[15];
cx q[8],q[0];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[0],q[16];
cx q[8],q[0];
cp(pi/8) q[0],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[8],q[12];
cx q[8],q[0];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[8],q[13];
cp(0.0) q[0],q[12];
cx q[8],q[0];
h q[12];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[8],q[14];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[8],q[15];
cp(-pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[8],q[16];
cp(-pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[0],q[16];
cx q[8],q[0];
cp(-pi/8) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[8],q[12];
cx q[8],q[0];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[8],q[13];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[9],q[12];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(pi/2) q[8],q[14];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[0],q[14];
cx q[8],q[0];
cp(pi/4) q[8],q[15];
cp(pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[0],q[15];
cx q[8],q[0];
cp(pi/8) q[8],q[16];
cp(pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[0],q[16];
cx q[8],q[0];
cp(pi/8) q[0],q[16];
cx q[9],q[0];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(0.0) q[9],q[13];
cp(0.0) q[0],q[12];
cx q[9],q[0];
u2(0,0) q[12];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[9],q[14];
cp(0.0) q[0],q[13];
cx q[9],q[0];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(pi/2) q[9],q[15];
cp(0.0) q[0],q[14];
cx q[9],q[0];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[0],q[15];
cx q[9],q[0];
cp(pi/4) q[9],q[16];
cp(pi/2) q[0],q[15];
cx q[9],q[0];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[0],q[16];
cx q[9],q[0];
cp(pi/4) q[0],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[0];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(0.0) q[9],q[13];
cp(0.0) q[0],q[12];
cx q[9],q[0];
h q[12];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[9],q[14];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-pi/2) q[9],q[15];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[0],q[15];
cx q[9],q[0];
cp(-pi/4) q[9],q[16];
cp(-pi/2) q[0],q[15];
cx q[9],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[0],q[16];
cx q[9],q[0];
cp(-pi/4) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[0];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(0.0) q[9],q[13];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(pi/2) q[10],q[12];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[9],q[14];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(pi/2) q[9],q[15];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-pi/2) q[0],q[15];
cx q[9],q[0];
cp(pi/4) q[9],q[16];
cp(pi/2) q[0],q[15];
cx q[9],q[0];
cp(-pi/4) q[0],q[16];
cx q[9],q[0];
cp(pi/4) q[0],q[16];
cx q[10],q[0];
cp(-pi/2) q[0],q[12];
cx q[10],q[0];
cp(pi/4) q[10],q[13];
cp(pi/2) q[0],q[12];
cx q[10],q[0];
u2(0,0) q[12];
cp(-pi/4) q[0],q[13];
cx q[10],q[0];
cp(pi/8) q[10],q[14];
cp(pi/4) q[0],q[13];
cx q[10],q[0];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[0],q[14];
cx q[10],q[0];
cp(pi/16) q[10],q[15];
cp(pi/8) q[0],q[14];
cx q[10],q[0];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[0],q[15];
cx q[10],q[0];
cp(pi/32) q[10],q[16];
cp(pi/16) q[0],q[15];
cx q[10],q[0];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[0],q[16];
cx q[10],q[0];
cp(pi/32) q[0],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[10],q[12];
cx q[10],q[0];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[0],q[12];
cx q[10],q[0];
cp(-pi/4) q[10],q[13];
cp(-pi/2) q[0],q[12];
cx q[10],q[0];
h q[12];
cp(pi/4) q[0],q[13];
cx q[10],q[0];
cp(-pi/8) q[10],q[14];
cp(-pi/4) q[0],q[13];
cx q[10],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[0],q[14];
cx q[10],q[0];
cp(-pi/16) q[10],q[15];
cp(-pi/8) q[0],q[14];
cx q[10],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[0],q[15];
cx q[10],q[0];
cp(-pi/32) q[10],q[16];
cp(-pi/16) q[0],q[15];
cx q[10],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[0],q[16];
cx q[10],q[0];
cp(-pi/32) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[10],q[12];
cx q[10],q[0];
cp(-pi/2) q[0],q[12];
cx q[10],q[0];
cp(pi/4) q[10],q[13];
cp(pi/2) q[0],q[12];
cx q[10],q[0];
cp(0.0) q[11],q[12];
cp(-pi/4) q[0],q[13];
cx q[10],q[0];
cp(pi/8) q[10],q[14];
cp(pi/4) q[0],q[13];
cx q[10],q[0];
cp(-pi/8) q[0],q[14];
cx q[10],q[0];
cp(pi/16) q[10],q[15];
cp(pi/8) q[0],q[14];
cx q[10],q[0];
cp(-pi/16) q[0],q[15];
cx q[10],q[0];
cp(pi/32) q[10],q[16];
cp(pi/16) q[0],q[15];
cx q[10],q[0];
cp(-pi/32) q[0],q[16];
cx q[10],q[0];
cp(pi/32) q[0],q[16];
cx q[11],q[0];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(pi/2) q[11],q[13];
cp(0.0) q[0],q[12];
cx q[11],q[0];
u2(0,0) q[12];
cp(-pi/2) q[0],q[13];
cx q[11],q[0];
cp(pi/4) q[11],q[14];
cp(pi/2) q[0],q[13];
cx q[11],q[0];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[0],q[14];
cx q[11],q[0];
cp(pi/8) q[11],q[15];
cp(pi/4) q[0],q[14];
cx q[11],q[0];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[0],q[15];
cx q[11],q[0];
cp(pi/16) q[11],q[16];
cp(pi/8) q[0],q[15];
cx q[11],q[0];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[0],q[16];
cx q[11],q[0];
cp(pi/16) q[0],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[0];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(-pi/2) q[11],q[13];
cp(0.0) q[0],q[12];
cx q[11],q[0];
h q[12];
cp(pi/2) q[0],q[13];
cx q[11],q[0];
cp(-pi/4) q[11],q[14];
cp(-pi/2) q[0],q[13];
cx q[11],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[0],q[14];
cx q[11],q[0];
cp(-pi/8) q[11],q[15];
cp(-pi/4) q[0],q[14];
cx q[11],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[0],q[15];
cx q[11],q[0];
cp(-pi/16) q[11],q[16];
cp(-pi/8) q[0],q[15];
cx q[11],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[0],q[16];
cx q[11],q[0];
cp(-pi/16) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[0];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(pi/2) q[11],q[13];
cp(0.0) q[0],q[12];
cx q[11],q[0];
h q[12];
cp(-pi/2) q[0],q[13];
cx q[11],q[0];
cp(pi/4) q[11],q[14];
cp(pi/2) q[0],q[13];
cx q[11],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[0],q[14];
cx q[11],q[0];
cp(pi/8) q[11],q[15];
cp(pi/4) q[0],q[14];
cx q[11],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[0],q[15];
cx q[11],q[0];
cp(pi/16) q[11],q[16];
cp(pi/8) q[0],q[15];
cx q[11],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[0],q[16];
cx q[11],q[0];
cp(pi/16) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[0],q[8],q[12];
cswap q[0],q[9],q[13];
cswap q[0],q[10],q[14];
cswap q[0],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[0];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(-pi/2) q[11],q[13];
cp(0.0) q[0],q[12];
cx q[11],q[0];
h q[12];
cp(pi/2) q[0],q[13];
cx q[11],q[0];
cp(-pi/4) q[11],q[14];
cp(-pi/2) q[0],q[13];
cx q[11],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[0],q[14];
cx q[11],q[0];
cp(-pi/8) q[11],q[15];
cp(-pi/4) q[0],q[14];
cx q[11],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[0],q[15];
cx q[11],q[0];
cp(-pi/16) q[11],q[16];
cp(-pi/8) q[0],q[15];
cx q[11],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[0],q[16];
cx q[11],q[0];
cp(-pi/16) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[0];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(pi/2) q[11],q[13];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[0],q[13];
cx q[11],q[0];
cp(pi/4) q[11],q[14];
cp(pi/2) q[0],q[13];
cx q[11],q[0];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[0],q[14];
cx q[11],q[0];
cp(pi/8) q[11],q[15];
cp(pi/4) q[0],q[14];
cx q[11],q[0];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[0],q[15];
cx q[11],q[0];
cp(pi/16) q[11],q[16];
cp(pi/8) q[0],q[15];
cx q[11],q[0];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[0],q[16];
cx q[11],q[0];
cp(pi/16) q[0],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[0];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[0],q[12];
cx q[11],q[0];
cp(-pi/2) q[11],q[13];
cp(0.0) q[0],q[12];
cp(-pi/2) q[10],q[12];
cx q[11],q[0];
cp(pi/2) q[0],q[13];
cx q[11],q[0];
cp(-pi/4) q[11],q[14];
cp(-pi/2) q[0],q[13];
cx q[11],q[0];
cp(pi/4) q[0],q[14];
cx q[11],q[0];
cp(-pi/8) q[11],q[15];
cp(-pi/4) q[0],q[14];
cx q[11],q[0];
cp(pi/8) q[0],q[15];
cx q[11],q[0];
cp(-pi/16) q[11],q[16];
cp(-pi/8) q[0],q[15];
cx q[11],q[0];
cp(pi/16) q[0],q[16];
cx q[11],q[0];
cp(-pi/16) q[0],q[16];
cx q[10],q[0];
cp(pi/2) q[0],q[12];
cx q[10],q[0];
cp(-pi/4) q[10],q[13];
cp(-pi/2) q[0],q[12];
cx q[10],q[0];
h q[12];
cp(pi/4) q[0],q[13];
cx q[10],q[0];
cp(-pi/8) q[10],q[14];
cp(-pi/4) q[0],q[13];
cx q[10],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[0],q[14];
cx q[10],q[0];
cp(-pi/16) q[10],q[15];
cp(-pi/8) q[0],q[14];
cx q[10],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[0],q[15];
cx q[10],q[0];
cp(-pi/32) q[10],q[16];
cp(-pi/16) q[0],q[15];
cx q[10],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[0],q[16];
cx q[10],q[0];
cp(-pi/32) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[10],q[12];
cx q[10],q[0];
cp(-pi/2) q[0],q[12];
cx q[10],q[0];
cp(pi/4) q[10],q[13];
cp(pi/2) q[0],q[12];
cx q[10],q[0];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[0],q[13];
cx q[10],q[0];
cp(pi/8) q[10],q[14];
cp(pi/4) q[0],q[13];
cx q[10],q[0];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[0],q[14];
cx q[10],q[0];
cp(pi/16) q[10],q[15];
cp(pi/8) q[0],q[14];
cx q[10],q[0];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[0],q[15];
cx q[10],q[0];
cp(pi/32) q[10],q[16];
cp(pi/16) q[0],q[15];
cx q[10],q[0];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[0],q[16];
cx q[10],q[0];
cp(pi/32) q[0],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[10],q[12];
cx q[10],q[0];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[0],q[12];
cx q[10],q[0];
cp(-pi/4) q[10],q[13];
cp(-pi/2) q[0],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[0];
cp(pi/4) q[0],q[13];
cx q[10],q[0];
cp(-pi/8) q[10],q[14];
cp(-pi/4) q[0],q[13];
cx q[10],q[0];
cp(pi/8) q[0],q[14];
cx q[10],q[0];
cp(-pi/16) q[10],q[15];
cp(-pi/8) q[0],q[14];
cx q[10],q[0];
cp(pi/16) q[0],q[15];
cx q[10],q[0];
cp(-pi/32) q[10],q[16];
cp(-pi/16) q[0],q[15];
cx q[10],q[0];
cp(pi/32) q[0],q[16];
cx q[10],q[0];
cp(-pi/32) q[0],q[16];
cx q[9],q[0];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(0.0) q[9],q[13];
cp(0.0) q[0],q[12];
cx q[9],q[0];
h q[12];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[9],q[14];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-pi/2) q[9],q[15];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[0],q[15];
cx q[9],q[0];
cp(-pi/4) q[9],q[16];
cp(-pi/2) q[0],q[15];
cx q[9],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[0],q[16];
cx q[9],q[0];
cp(-pi/4) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[0];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(0.0) q[9],q[13];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[9],q[14];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(pi/2) q[9],q[15];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[0],q[15];
cx q[9],q[0];
cp(pi/4) q[9],q[16];
cp(pi/2) q[0],q[15];
cx q[9],q[0];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[0],q[16];
cx q[9],q[0];
cp(pi/4) q[0],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[0];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[0],q[12];
cx q[9],q[0];
cp(0.0) q[9],q[13];
cp(0.0) q[0],q[12];
cp(0.0) q[8],q[12];
cx q[9],q[0];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[9],q[14];
cp(0.0) q[0],q[13];
cx q[9],q[0];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(-pi/2) q[9],q[15];
cp(0.0) q[0],q[14];
cx q[9],q[0];
cp(pi/2) q[0],q[15];
cx q[9],q[0];
cp(-pi/4) q[9],q[16];
cp(-pi/2) q[0],q[15];
cx q[9],q[0];
cp(pi/4) q[0],q[16];
cx q[9],q[0];
cp(-pi/4) q[0],q[16];
cx q[8],q[0];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[8],q[13];
cp(0.0) q[0],q[12];
cx q[8],q[0];
h q[12];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[8],q[14];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[8],q[15];
cp(-pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[8],q[16];
cp(-pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[0],q[16];
cx q[8],q[0];
cp(-pi/8) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[8],q[12];
cx q[8],q[0];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[8],q[13];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(pi/2) q[8],q[14];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[0],q[14];
cx q[8],q[0];
cp(pi/4) q[8],q[15];
cp(pi/2) q[0],q[14];
cx q[8],q[0];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[0],q[15];
cx q[8],q[0];
cp(pi/8) q[8],q[16];
cp(pi/4) q[0],q[15];
cx q[8],q[0];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[0],q[16];
cx q[8],q[0];
cp(pi/8) q[0],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[8],q[12];
cx q[8],q[0];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[0],q[12];
cx q[8],q[0];
cp(0.0) q[8],q[13];
cp(0.0) q[0],q[12];
cx q[8],q[0];
h q[12];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[8],q[14];
cp(0.0) q[0],q[13];
cx q[8],q[0];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[8],q[15];
cp(-pi/2) q[0],q[14];
cx q[8],q[0];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[8],q[16];
cp(-pi/4) q[0],q[15];
cx q[8],q[0];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[0],q[16];
cx q[8],q[0];
cp(-pi/8) q[0],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[1];
cp(-pi/2) q[1],q[12];
cx q[8],q[1];
cp(pi/4) q[8],q[13];
cp(pi/2) q[1],q[12];
cx q[8],q[1];
u2(0,0) q[12];
cp(-pi/4) q[1],q[13];
cx q[8],q[1];
cp(pi/8) q[8],q[14];
cp(pi/4) q[1],q[13];
cx q[8],q[1];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[1],q[14];
cx q[8],q[1];
cp(pi/16) q[8],q[15];
cp(pi/8) q[1],q[14];
cx q[8],q[1];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[1],q[15];
cx q[8],q[1];
cp(pi/32) q[8],q[16];
cp(pi/16) q[1],q[15];
cx q[8],q[1];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[1],q[16];
cx q[8],q[1];
cp(pi/32) q[1],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[1];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[1],q[12];
cx q[8],q[1];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[1],q[12];
cx q[8],q[1];
h q[12];
cp(pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[1],q[16];
cx q[8],q[1];
cp(-pi/32) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[1];
cp(-pi/2) q[1],q[12];
cx q[8],q[1];
cp(pi/4) q[8],q[13];
cp(pi/2) q[1],q[12];
cx q[8],q[1];
cp(0.0) q[9],q[12];
cp(-pi/4) q[1],q[13];
cx q[8],q[1];
cp(pi/8) q[8],q[14];
cp(pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/8) q[1],q[14];
cx q[8],q[1];
cp(pi/16) q[8],q[15];
cp(pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/16) q[1],q[15];
cx q[8],q[1];
cp(pi/32) q[8],q[16];
cp(pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/32) q[1],q[16];
cx q[8],q[1];
cp(pi/32) q[1],q[16];
cx q[9],q[1];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(pi/2) q[9],q[13];
cp(0.0) q[1],q[12];
cx q[9],q[1];
u2(0,0) q[12];
cp(-pi/2) q[1],q[13];
cx q[9],q[1];
cp(pi/4) q[9],q[14];
cp(pi/2) q[1],q[13];
cx q[9],q[1];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[1],q[14];
cx q[9],q[1];
cp(pi/8) q[9],q[15];
cp(pi/4) q[1],q[14];
cx q[9],q[1];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[1],q[15];
cx q[9],q[1];
cp(pi/16) q[9],q[16];
cp(pi/8) q[1],q[15];
cx q[9],q[1];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[1],q[16];
cx q[9],q[1];
cp(pi/16) q[1],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[1];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(-pi/2) q[9],q[13];
cp(0.0) q[1],q[12];
cx q[9],q[1];
h q[12];
cp(pi/2) q[1],q[13];
cx q[9],q[1];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[1],q[13];
cx q[9],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[1],q[14];
cx q[9],q[1];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[1],q[14];
cx q[9],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[1],q[15];
cx q[9],q[1];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[1],q[15];
cx q[9],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[1],q[16];
cx q[9],q[1];
cp(-pi/16) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[1];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(pi/2) q[9],q[13];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(0.0) q[10],q[12];
cp(-pi/2) q[1],q[13];
cx q[9],q[1];
cp(pi/4) q[9],q[14];
cp(pi/2) q[1],q[13];
cx q[9],q[1];
cp(-pi/4) q[1],q[14];
cx q[9],q[1];
cp(pi/8) q[9],q[15];
cp(pi/4) q[1],q[14];
cx q[9],q[1];
cp(-pi/8) q[1],q[15];
cx q[9],q[1];
cp(pi/16) q[9],q[16];
cp(pi/8) q[1],q[15];
cx q[9],q[1];
cp(-pi/16) q[1],q[16];
cx q[9],q[1];
cp(pi/16) q[1],q[16];
cx q[10],q[1];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[10],q[13];
cp(0.0) q[1],q[12];
cx q[10],q[1];
u2(0,0) q[12];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(pi/2) q[10],q[14];
cp(0.0) q[1],q[13];
cx q[10],q[1];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[1],q[14];
cx q[10],q[1];
cp(pi/4) q[10],q[15];
cp(pi/2) q[1],q[14];
cx q[10],q[1];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[1],q[15];
cx q[10],q[1];
cp(pi/8) q[10],q[16];
cp(pi/4) q[1],q[15];
cx q[10],q[1];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[1],q[16];
cx q[10],q[1];
cp(pi/8) q[1],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[1];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[10],q[13];
cp(0.0) q[1],q[12];
cx q[10],q[1];
h q[12];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-pi/2) q[10],q[14];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[1],q[14];
cx q[10],q[1];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[1],q[14];
cx q[10],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[1],q[15];
cx q[10],q[1];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[1],q[15];
cx q[10],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[1],q[16];
cx q[10],q[1];
cp(-pi/8) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[1];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[10],q[13];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[11],q[12];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(pi/2) q[10],q[14];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-pi/2) q[1],q[14];
cx q[10],q[1];
cp(pi/4) q[10],q[15];
cp(pi/2) q[1],q[14];
cx q[10],q[1];
cp(-pi/4) q[1],q[15];
cx q[10],q[1];
cp(pi/8) q[10],q[16];
cp(pi/4) q[1],q[15];
cx q[10],q[1];
cp(-pi/8) q[1],q[16];
cx q[10],q[1];
cp(pi/8) q[1],q[16];
cx q[11],q[1];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(0.0) q[11],q[13];
cp(0.0) q[1],q[12];
cx q[11],q[1];
u2(0,0) q[12];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[11],q[14];
cp(0.0) q[1],q[13];
cx q[11],q[1];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(pi/2) q[11],q[15];
cp(0.0) q[1],q[14];
cx q[11],q[1];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[1],q[15];
cx q[11],q[1];
cp(pi/4) q[11],q[16];
cp(pi/2) q[1],q[15];
cx q[11],q[1];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[1],q[16];
cx q[11],q[1];
cp(pi/4) q[1],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[1];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(0.0) q[11],q[13];
cp(0.0) q[1],q[12];
cx q[11],q[1];
h q[12];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[11],q[14];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-pi/2) q[11],q[15];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[1],q[15];
cx q[11],q[1];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[1],q[15];
cx q[11],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[1],q[16];
cx q[11],q[1];
cp(-pi/4) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[1];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(0.0) q[11],q[13];
cp(0.0) q[1],q[12];
cx q[11],q[1];
h q[12];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[11],q[14];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(pi/2) q[11],q[15];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[1],q[15];
cx q[11],q[1];
cp(pi/4) q[11],q[16];
cp(pi/2) q[1],q[15];
cx q[11],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[1],q[16];
cx q[11],q[1];
cp(pi/4) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[1],q[8],q[12];
cswap q[1],q[9],q[13];
cswap q[1],q[10],q[14];
cswap q[1],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[1];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(0.0) q[11],q[13];
cp(0.0) q[1],q[12];
cx q[11],q[1];
h q[12];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[11],q[14];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-pi/2) q[11],q[15];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[1],q[15];
cx q[11],q[1];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[1],q[15];
cx q[11],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[1],q[16];
cx q[11],q[1];
cp(-pi/4) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[1];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(0.0) q[11],q[13];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[11],q[14];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(pi/2) q[11],q[15];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[1],q[15];
cx q[11],q[1];
cp(pi/4) q[11],q[16];
cp(pi/2) q[1],q[15];
cx q[11],q[1];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[1],q[16];
cx q[11],q[1];
cp(pi/4) q[1],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[1];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[1],q[12];
cx q[11],q[1];
cp(0.0) q[11],q[13];
cp(0.0) q[1],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[1];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[11],q[14];
cp(0.0) q[1],q[13];
cx q[11],q[1];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(-pi/2) q[11],q[15];
cp(0.0) q[1],q[14];
cx q[11],q[1];
cp(pi/2) q[1],q[15];
cx q[11],q[1];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[1],q[15];
cx q[11],q[1];
cp(pi/4) q[1],q[16];
cx q[11],q[1];
cp(-pi/4) q[1],q[16];
cx q[10],q[1];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[10],q[13];
cp(0.0) q[1],q[12];
cx q[10],q[1];
h q[12];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-pi/2) q[10],q[14];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[1],q[14];
cx q[10],q[1];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[1],q[14];
cx q[10],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[1],q[15];
cx q[10],q[1];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[1],q[15];
cx q[10],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[1],q[16];
cx q[10],q[1];
cp(-pi/8) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[1];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[10],q[13];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(pi/2) q[10],q[14];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[1],q[14];
cx q[10],q[1];
cp(pi/4) q[10],q[15];
cp(pi/2) q[1],q[14];
cx q[10],q[1];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[1],q[15];
cx q[10],q[1];
cp(pi/8) q[10],q[16];
cp(pi/4) q[1],q[15];
cx q[10],q[1];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[1],q[16];
cx q[10],q[1];
cp(pi/8) q[1],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[1];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[1],q[12];
cx q[10],q[1];
cp(0.0) q[10],q[13];
cp(0.0) q[1],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[1];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(-pi/2) q[10],q[14];
cp(0.0) q[1],q[13];
cx q[10],q[1];
cp(pi/2) q[1],q[14];
cx q[10],q[1];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[1],q[14];
cx q[10],q[1];
cp(pi/4) q[1],q[15];
cx q[10],q[1];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[1],q[15];
cx q[10],q[1];
cp(pi/8) q[1],q[16];
cx q[10],q[1];
cp(-pi/8) q[1],q[16];
cx q[9],q[1];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(-pi/2) q[9],q[13];
cp(0.0) q[1],q[12];
cx q[9],q[1];
h q[12];
cp(pi/2) q[1],q[13];
cx q[9],q[1];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[1],q[13];
cx q[9],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[1],q[14];
cx q[9],q[1];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[1],q[14];
cx q[9],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[1],q[15];
cx q[9],q[1];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[1],q[15];
cx q[9],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[1],q[16];
cx q[9],q[1];
cp(-pi/16) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[1];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(pi/2) q[9],q[13];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[1],q[13];
cx q[9],q[1];
cp(pi/4) q[9],q[14];
cp(pi/2) q[1],q[13];
cx q[9],q[1];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[1],q[14];
cx q[9],q[1];
cp(pi/8) q[9],q[15];
cp(pi/4) q[1],q[14];
cx q[9],q[1];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[1],q[15];
cx q[9],q[1];
cp(pi/16) q[9],q[16];
cp(pi/8) q[1],q[15];
cx q[9],q[1];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[1],q[16];
cx q[9],q[1];
cp(pi/16) q[1],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[1];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[1],q[12];
cx q[9],q[1];
cp(-pi/2) q[9],q[13];
cp(0.0) q[1],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[1];
cp(pi/2) q[1],q[13];
cx q[9],q[1];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[1],q[13];
cx q[9],q[1];
cp(pi/4) q[1],q[14];
cx q[9],q[1];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[1],q[14];
cx q[9],q[1];
cp(pi/8) q[1],q[15];
cx q[9],q[1];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[1],q[15];
cx q[9],q[1];
cp(pi/16) q[1],q[16];
cx q[9],q[1];
cp(-pi/16) q[1],q[16];
cx q[8],q[1];
cp(pi/2) q[1],q[12];
cx q[8],q[1];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[1],q[12];
cx q[8],q[1];
h q[12];
cp(pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[1],q[16];
cx q[8],q[1];
cp(-pi/32) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[1];
cp(-pi/2) q[1],q[12];
cx q[8],q[1];
cp(pi/4) q[8],q[13];
cp(pi/2) q[1],q[12];
cx q[8],q[1];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[1],q[13];
cx q[8],q[1];
cp(pi/8) q[8],q[14];
cp(pi/4) q[1],q[13];
cx q[8],q[1];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[1],q[14];
cx q[8],q[1];
cp(pi/16) q[8],q[15];
cp(pi/8) q[1],q[14];
cx q[8],q[1];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[1],q[15];
cx q[8],q[1];
cp(pi/32) q[8],q[16];
cp(pi/16) q[1],q[15];
cx q[8],q[1];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[1],q[16];
cx q[8],q[1];
cp(pi/32) q[1],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[1];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[1],q[12];
cx q[8],q[1];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[1],q[12];
cx q[8],q[1];
h q[12];
cp(pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[1],q[13];
cx q[8],q[1];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[1],q[14];
cx q[8],q[1];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[1],q[15];
cx q[8],q[1];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[1],q[16];
cx q[8],q[1];
cp(-pi/32) q[1],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[2];
cp(-pi/2) q[2],q[12];
cx q[8],q[2];
cp(pi/4) q[8],q[13];
cp(pi/2) q[2],q[12];
cx q[8],q[2];
u2(0,0) q[12];
cp(-pi/4) q[2],q[13];
cx q[8],q[2];
cp(pi/8) q[8],q[14];
cp(pi/4) q[2],q[13];
cx q[8],q[2];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[2],q[14];
cx q[8],q[2];
cp(pi/16) q[8],q[15];
cp(pi/8) q[2],q[14];
cx q[8],q[2];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[2],q[15];
cx q[8],q[2];
cp(pi/32) q[8],q[16];
cp(pi/16) q[2],q[15];
cx q[8],q[2];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[2],q[16];
cx q[8],q[2];
cp(pi/32) q[2],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[2];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[2],q[12];
cx q[8],q[2];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[2],q[12];
cx q[8],q[2];
h q[12];
cp(pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[2],q[16];
cx q[8],q[2];
cp(-pi/32) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[2];
cp(-pi/2) q[2],q[12];
cx q[8],q[2];
cp(pi/4) q[8],q[13];
cp(pi/2) q[2],q[12];
cx q[8],q[2];
cp(0.0) q[9],q[12];
cp(-pi/4) q[2],q[13];
cx q[8],q[2];
cp(pi/8) q[8],q[14];
cp(pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/8) q[2],q[14];
cx q[8],q[2];
cp(pi/16) q[8],q[15];
cp(pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/16) q[2],q[15];
cx q[8],q[2];
cp(pi/32) q[8],q[16];
cp(pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/32) q[2],q[16];
cx q[8],q[2];
cp(pi/32) q[2],q[16];
cx q[9],q[2];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(pi/2) q[9],q[13];
cp(0.0) q[2],q[12];
cx q[9],q[2];
u2(0,0) q[12];
cp(-pi/2) q[2],q[13];
cx q[9],q[2];
cp(pi/4) q[9],q[14];
cp(pi/2) q[2],q[13];
cx q[9],q[2];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[2],q[14];
cx q[9],q[2];
cp(pi/8) q[9],q[15];
cp(pi/4) q[2],q[14];
cx q[9],q[2];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[2],q[15];
cx q[9],q[2];
cp(pi/16) q[9],q[16];
cp(pi/8) q[2],q[15];
cx q[9],q[2];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[2],q[16];
cx q[9],q[2];
cp(pi/16) q[2],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[2];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(-pi/2) q[9],q[13];
cp(0.0) q[2],q[12];
cx q[9],q[2];
h q[12];
cp(pi/2) q[2],q[13];
cx q[9],q[2];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[2],q[13];
cx q[9],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[2],q[14];
cx q[9],q[2];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[2],q[14];
cx q[9],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[2],q[15];
cx q[9],q[2];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[2],q[15];
cx q[9],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[2],q[16];
cx q[9],q[2];
cp(-pi/16) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[2];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(pi/2) q[9],q[13];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(0.0) q[10],q[12];
cp(-pi/2) q[2],q[13];
cx q[9],q[2];
cp(pi/4) q[9],q[14];
cp(pi/2) q[2],q[13];
cx q[9],q[2];
cp(-pi/4) q[2],q[14];
cx q[9],q[2];
cp(pi/8) q[9],q[15];
cp(pi/4) q[2],q[14];
cx q[9],q[2];
cp(-pi/8) q[2],q[15];
cx q[9],q[2];
cp(pi/16) q[9],q[16];
cp(pi/8) q[2],q[15];
cx q[9],q[2];
cp(-pi/16) q[2],q[16];
cx q[9],q[2];
cp(pi/16) q[2],q[16];
cx q[10],q[2];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[10],q[13];
cp(0.0) q[2],q[12];
cx q[10],q[2];
u2(0,0) q[12];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(pi/2) q[10],q[14];
cp(0.0) q[2],q[13];
cx q[10],q[2];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[2],q[14];
cx q[10],q[2];
cp(pi/4) q[10],q[15];
cp(pi/2) q[2],q[14];
cx q[10],q[2];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[2],q[15];
cx q[10],q[2];
cp(pi/8) q[10],q[16];
cp(pi/4) q[2],q[15];
cx q[10],q[2];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[2],q[16];
cx q[10],q[2];
cp(pi/8) q[2],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[2];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[10],q[13];
cp(0.0) q[2],q[12];
cx q[10],q[2];
h q[12];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-pi/2) q[10],q[14];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[2],q[14];
cx q[10],q[2];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[2],q[14];
cx q[10],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[2],q[15];
cx q[10],q[2];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[2],q[15];
cx q[10],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[2],q[16];
cx q[10],q[2];
cp(-pi/8) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[2];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[10],q[13];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[11],q[12];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(pi/2) q[10],q[14];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-pi/2) q[2],q[14];
cx q[10],q[2];
cp(pi/4) q[10],q[15];
cp(pi/2) q[2],q[14];
cx q[10],q[2];
cp(-pi/4) q[2],q[15];
cx q[10],q[2];
cp(pi/8) q[10],q[16];
cp(pi/4) q[2],q[15];
cx q[10],q[2];
cp(-pi/8) q[2],q[16];
cx q[10],q[2];
cp(pi/8) q[2],q[16];
cx q[11],q[2];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(0.0) q[11],q[13];
cp(0.0) q[2],q[12];
cx q[11],q[2];
u2(0,0) q[12];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[11],q[14];
cp(0.0) q[2],q[13];
cx q[11],q[2];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(pi/2) q[11],q[15];
cp(0.0) q[2],q[14];
cx q[11],q[2];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[2],q[15];
cx q[11],q[2];
cp(pi/4) q[11],q[16];
cp(pi/2) q[2],q[15];
cx q[11],q[2];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[2],q[16];
cx q[11],q[2];
cp(pi/4) q[2],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[2];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(0.0) q[11],q[13];
cp(0.0) q[2],q[12];
cx q[11],q[2];
h q[12];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[11],q[14];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-pi/2) q[11],q[15];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[2],q[15];
cx q[11],q[2];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[2],q[15];
cx q[11],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[2],q[16];
cx q[11],q[2];
cp(-pi/4) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[2];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(0.0) q[11],q[13];
cp(0.0) q[2],q[12];
cx q[11],q[2];
h q[12];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[11],q[14];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(pi/2) q[11],q[15];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[2],q[15];
cx q[11],q[2];
cp(pi/4) q[11],q[16];
cp(pi/2) q[2],q[15];
cx q[11],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[2],q[16];
cx q[11],q[2];
cp(pi/4) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[2],q[8],q[12];
cswap q[2],q[9],q[13];
cswap q[2],q[10],q[14];
cswap q[2],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[2];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(0.0) q[11],q[13];
cp(0.0) q[2],q[12];
cx q[11],q[2];
h q[12];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[11],q[14];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-pi/2) q[11],q[15];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[2],q[15];
cx q[11],q[2];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[2],q[15];
cx q[11],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[2],q[16];
cx q[11],q[2];
cp(-pi/4) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[2];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(0.0) q[11],q[13];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[11],q[14];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(pi/2) q[11],q[15];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[2],q[15];
cx q[11],q[2];
cp(pi/4) q[11],q[16];
cp(pi/2) q[2],q[15];
cx q[11],q[2];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[2],q[16];
cx q[11],q[2];
cp(pi/4) q[2],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[2];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[2],q[12];
cx q[11],q[2];
cp(0.0) q[11],q[13];
cp(0.0) q[2],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[2];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[11],q[14];
cp(0.0) q[2],q[13];
cx q[11],q[2];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(-pi/2) q[11],q[15];
cp(0.0) q[2],q[14];
cx q[11],q[2];
cp(pi/2) q[2],q[15];
cx q[11],q[2];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[2],q[15];
cx q[11],q[2];
cp(pi/4) q[2],q[16];
cx q[11],q[2];
cp(-pi/4) q[2],q[16];
cx q[10],q[2];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[10],q[13];
cp(0.0) q[2],q[12];
cx q[10],q[2];
h q[12];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-pi/2) q[10],q[14];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[2],q[14];
cx q[10],q[2];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[2],q[14];
cx q[10],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[2],q[15];
cx q[10],q[2];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[2],q[15];
cx q[10],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[2],q[16];
cx q[10],q[2];
cp(-pi/8) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[2];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[10],q[13];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(pi/2) q[10],q[14];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[2],q[14];
cx q[10],q[2];
cp(pi/4) q[10],q[15];
cp(pi/2) q[2],q[14];
cx q[10],q[2];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[2],q[15];
cx q[10],q[2];
cp(pi/8) q[10],q[16];
cp(pi/4) q[2],q[15];
cx q[10],q[2];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[2],q[16];
cx q[10],q[2];
cp(pi/8) q[2],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[2];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[2],q[12];
cx q[10],q[2];
cp(0.0) q[10],q[13];
cp(0.0) q[2],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[2];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(-pi/2) q[10],q[14];
cp(0.0) q[2],q[13];
cx q[10],q[2];
cp(pi/2) q[2],q[14];
cx q[10],q[2];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[2],q[14];
cx q[10],q[2];
cp(pi/4) q[2],q[15];
cx q[10],q[2];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[2],q[15];
cx q[10],q[2];
cp(pi/8) q[2],q[16];
cx q[10],q[2];
cp(-pi/8) q[2],q[16];
cx q[9],q[2];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(-pi/2) q[9],q[13];
cp(0.0) q[2],q[12];
cx q[9],q[2];
h q[12];
cp(pi/2) q[2],q[13];
cx q[9],q[2];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[2],q[13];
cx q[9],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[2],q[14];
cx q[9],q[2];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[2],q[14];
cx q[9],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[2],q[15];
cx q[9],q[2];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[2],q[15];
cx q[9],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[2],q[16];
cx q[9],q[2];
cp(-pi/16) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[2];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(pi/2) q[9],q[13];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[2],q[13];
cx q[9],q[2];
cp(pi/4) q[9],q[14];
cp(pi/2) q[2],q[13];
cx q[9],q[2];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[2],q[14];
cx q[9],q[2];
cp(pi/8) q[9],q[15];
cp(pi/4) q[2],q[14];
cx q[9],q[2];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[2],q[15];
cx q[9],q[2];
cp(pi/16) q[9],q[16];
cp(pi/8) q[2],q[15];
cx q[9],q[2];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[2],q[16];
cx q[9],q[2];
cp(pi/16) q[2],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[2];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[2],q[12];
cx q[9],q[2];
cp(-pi/2) q[9],q[13];
cp(0.0) q[2],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[2];
cp(pi/2) q[2],q[13];
cx q[9],q[2];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[2],q[13];
cx q[9],q[2];
cp(pi/4) q[2],q[14];
cx q[9],q[2];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[2],q[14];
cx q[9],q[2];
cp(pi/8) q[2],q[15];
cx q[9],q[2];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[2],q[15];
cx q[9],q[2];
cp(pi/16) q[2],q[16];
cx q[9],q[2];
cp(-pi/16) q[2],q[16];
cx q[8],q[2];
cp(pi/2) q[2],q[12];
cx q[8],q[2];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[2],q[12];
cx q[8],q[2];
h q[12];
cp(pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[2],q[16];
cx q[8],q[2];
cp(-pi/32) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[2];
cp(-pi/2) q[2],q[12];
cx q[8],q[2];
cp(pi/4) q[8],q[13];
cp(pi/2) q[2],q[12];
cx q[8],q[2];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[2],q[13];
cx q[8],q[2];
cp(pi/8) q[8],q[14];
cp(pi/4) q[2],q[13];
cx q[8],q[2];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[2],q[14];
cx q[8],q[2];
cp(pi/16) q[8],q[15];
cp(pi/8) q[2],q[14];
cx q[8],q[2];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[2],q[15];
cx q[8],q[2];
cp(pi/32) q[8],q[16];
cp(pi/16) q[2],q[15];
cx q[8],q[2];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[2],q[16];
cx q[8],q[2];
cp(pi/32) q[2],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[2];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[2],q[12];
cx q[8],q[2];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[2],q[12];
cx q[8],q[2];
h q[12];
cp(pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[2],q[13];
cx q[8],q[2];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[2],q[14];
cx q[8],q[2];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[2],q[15];
cx q[8],q[2];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[2],q[16];
cx q[8],q[2];
cp(-pi/32) q[2],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[3];
cp(-pi/2) q[3],q[12];
cx q[8],q[3];
cp(pi/4) q[8],q[13];
cp(pi/2) q[3],q[12];
cx q[8],q[3];
u2(0,0) q[12];
cp(-pi/4) q[3],q[13];
cx q[8],q[3];
cp(pi/8) q[8],q[14];
cp(pi/4) q[3],q[13];
cx q[8],q[3];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[3],q[14];
cx q[8],q[3];
cp(pi/16) q[8],q[15];
cp(pi/8) q[3],q[14];
cx q[8],q[3];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[3],q[15];
cx q[8],q[3];
cp(pi/32) q[8],q[16];
cp(pi/16) q[3],q[15];
cx q[8],q[3];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[3],q[16];
cx q[8],q[3];
cp(pi/32) q[3],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[3];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[3],q[12];
cx q[8],q[3];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[3],q[12];
cx q[8],q[3];
h q[12];
cp(pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[3],q[16];
cx q[8],q[3];
cp(-pi/32) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[3];
cp(-pi/2) q[3],q[12];
cx q[8],q[3];
cp(pi/4) q[8],q[13];
cp(pi/2) q[3],q[12];
cx q[8],q[3];
cp(0.0) q[9],q[12];
cp(-pi/4) q[3],q[13];
cx q[8],q[3];
cp(pi/8) q[8],q[14];
cp(pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/8) q[3],q[14];
cx q[8],q[3];
cp(pi/16) q[8],q[15];
cp(pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/16) q[3],q[15];
cx q[8],q[3];
cp(pi/32) q[8],q[16];
cp(pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/32) q[3],q[16];
cx q[8],q[3];
cp(pi/32) q[3],q[16];
cx q[9],q[3];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(pi/2) q[9],q[13];
cp(0.0) q[3],q[12];
cx q[9],q[3];
u2(0,0) q[12];
cp(-pi/2) q[3],q[13];
cx q[9],q[3];
cp(pi/4) q[9],q[14];
cp(pi/2) q[3],q[13];
cx q[9],q[3];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[3],q[14];
cx q[9],q[3];
cp(pi/8) q[9],q[15];
cp(pi/4) q[3],q[14];
cx q[9],q[3];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[3],q[15];
cx q[9],q[3];
cp(pi/16) q[9],q[16];
cp(pi/8) q[3],q[15];
cx q[9],q[3];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[3],q[16];
cx q[9],q[3];
cp(pi/16) q[3],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[3];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(-pi/2) q[9],q[13];
cp(0.0) q[3],q[12];
cx q[9],q[3];
h q[12];
cp(pi/2) q[3],q[13];
cx q[9],q[3];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[3],q[13];
cx q[9],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[3],q[14];
cx q[9],q[3];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[3],q[14];
cx q[9],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[3],q[15];
cx q[9],q[3];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[3],q[15];
cx q[9],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[3],q[16];
cx q[9],q[3];
cp(-pi/16) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[3];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(pi/2) q[9],q[13];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(0.0) q[10],q[12];
cp(-pi/2) q[3],q[13];
cx q[9],q[3];
cp(pi/4) q[9],q[14];
cp(pi/2) q[3],q[13];
cx q[9],q[3];
cp(-pi/4) q[3],q[14];
cx q[9],q[3];
cp(pi/8) q[9],q[15];
cp(pi/4) q[3],q[14];
cx q[9],q[3];
cp(-pi/8) q[3],q[15];
cx q[9],q[3];
cp(pi/16) q[9],q[16];
cp(pi/8) q[3],q[15];
cx q[9],q[3];
cp(-pi/16) q[3],q[16];
cx q[9],q[3];
cp(pi/16) q[3],q[16];
cx q[10],q[3];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[10],q[13];
cp(0.0) q[3],q[12];
cx q[10],q[3];
u2(0,0) q[12];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(pi/2) q[10],q[14];
cp(0.0) q[3],q[13];
cx q[10],q[3];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[3],q[14];
cx q[10],q[3];
cp(pi/4) q[10],q[15];
cp(pi/2) q[3],q[14];
cx q[10],q[3];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[3],q[15];
cx q[10],q[3];
cp(pi/8) q[10],q[16];
cp(pi/4) q[3],q[15];
cx q[10],q[3];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[3],q[16];
cx q[10],q[3];
cp(pi/8) q[3],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[3];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[10],q[13];
cp(0.0) q[3],q[12];
cx q[10],q[3];
h q[12];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-pi/2) q[10],q[14];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[3],q[14];
cx q[10],q[3];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[3],q[14];
cx q[10],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[3],q[15];
cx q[10],q[3];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[3],q[15];
cx q[10],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[3],q[16];
cx q[10],q[3];
cp(-pi/8) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[3];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[10],q[13];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[11],q[12];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(pi/2) q[10],q[14];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-pi/2) q[3],q[14];
cx q[10],q[3];
cp(pi/4) q[10],q[15];
cp(pi/2) q[3],q[14];
cx q[10],q[3];
cp(-pi/4) q[3],q[15];
cx q[10],q[3];
cp(pi/8) q[10],q[16];
cp(pi/4) q[3],q[15];
cx q[10],q[3];
cp(-pi/8) q[3],q[16];
cx q[10],q[3];
cp(pi/8) q[3],q[16];
cx q[11],q[3];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(0.0) q[11],q[13];
cp(0.0) q[3],q[12];
cx q[11],q[3];
u2(0,0) q[12];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[11],q[14];
cp(0.0) q[3],q[13];
cx q[11],q[3];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(pi/2) q[11],q[15];
cp(0.0) q[3],q[14];
cx q[11],q[3];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[3],q[15];
cx q[11],q[3];
cp(pi/4) q[11],q[16];
cp(pi/2) q[3],q[15];
cx q[11],q[3];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[3],q[16];
cx q[11],q[3];
cp(pi/4) q[3],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[3];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(0.0) q[11],q[13];
cp(0.0) q[3],q[12];
cx q[11],q[3];
h q[12];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[11],q[14];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-pi/2) q[11],q[15];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[3],q[15];
cx q[11],q[3];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[3],q[15];
cx q[11],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[3],q[16];
cx q[11],q[3];
cp(-pi/4) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[3];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(0.0) q[11],q[13];
cp(0.0) q[3],q[12];
cx q[11],q[3];
h q[12];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[11],q[14];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(pi/2) q[11],q[15];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[3],q[15];
cx q[11],q[3];
cp(pi/4) q[11],q[16];
cp(pi/2) q[3],q[15];
cx q[11],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[3],q[16];
cx q[11],q[3];
cp(pi/4) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[3],q[8],q[12];
cswap q[3],q[9],q[13];
cswap q[3],q[10],q[14];
cswap q[3],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[3];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(0.0) q[11],q[13];
cp(0.0) q[3],q[12];
cx q[11],q[3];
h q[12];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[11],q[14];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-pi/2) q[11],q[15];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[3],q[15];
cx q[11],q[3];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[3],q[15];
cx q[11],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[3],q[16];
cx q[11],q[3];
cp(-pi/4) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[3];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(0.0) q[11],q[13];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[11],q[14];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(pi/2) q[11],q[15];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[3],q[15];
cx q[11],q[3];
cp(pi/4) q[11],q[16];
cp(pi/2) q[3],q[15];
cx q[11],q[3];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[3],q[16];
cx q[11],q[3];
cp(pi/4) q[3],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[3];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[3],q[12];
cx q[11],q[3];
cp(0.0) q[11],q[13];
cp(0.0) q[3],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[3];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[11],q[14];
cp(0.0) q[3],q[13];
cx q[11],q[3];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(-pi/2) q[11],q[15];
cp(0.0) q[3],q[14];
cx q[11],q[3];
cp(pi/2) q[3],q[15];
cx q[11],q[3];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[3],q[15];
cx q[11],q[3];
cp(pi/4) q[3],q[16];
cx q[11],q[3];
cp(-pi/4) q[3],q[16];
cx q[10],q[3];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[10],q[13];
cp(0.0) q[3],q[12];
cx q[10],q[3];
h q[12];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-pi/2) q[10],q[14];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[3],q[14];
cx q[10],q[3];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[3],q[14];
cx q[10],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[3],q[15];
cx q[10],q[3];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[3],q[15];
cx q[10],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[3],q[16];
cx q[10],q[3];
cp(-pi/8) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[3];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[10],q[13];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(pi/2) q[10],q[14];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[3],q[14];
cx q[10],q[3];
cp(pi/4) q[10],q[15];
cp(pi/2) q[3],q[14];
cx q[10],q[3];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[3],q[15];
cx q[10],q[3];
cp(pi/8) q[10],q[16];
cp(pi/4) q[3],q[15];
cx q[10],q[3];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[3],q[16];
cx q[10],q[3];
cp(pi/8) q[3],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[3];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[3],q[12];
cx q[10],q[3];
cp(0.0) q[10],q[13];
cp(0.0) q[3],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[3];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(-pi/2) q[10],q[14];
cp(0.0) q[3],q[13];
cx q[10],q[3];
cp(pi/2) q[3],q[14];
cx q[10],q[3];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[3],q[14];
cx q[10],q[3];
cp(pi/4) q[3],q[15];
cx q[10],q[3];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[3],q[15];
cx q[10],q[3];
cp(pi/8) q[3],q[16];
cx q[10],q[3];
cp(-pi/8) q[3],q[16];
cx q[9],q[3];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(-pi/2) q[9],q[13];
cp(0.0) q[3],q[12];
cx q[9],q[3];
h q[12];
cp(pi/2) q[3],q[13];
cx q[9],q[3];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[3],q[13];
cx q[9],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[3],q[14];
cx q[9],q[3];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[3],q[14];
cx q[9],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[3],q[15];
cx q[9],q[3];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[3],q[15];
cx q[9],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[3],q[16];
cx q[9],q[3];
cp(-pi/16) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[3];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(pi/2) q[9],q[13];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[3],q[13];
cx q[9],q[3];
cp(pi/4) q[9],q[14];
cp(pi/2) q[3],q[13];
cx q[9],q[3];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[3],q[14];
cx q[9],q[3];
cp(pi/8) q[9],q[15];
cp(pi/4) q[3],q[14];
cx q[9],q[3];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[3],q[15];
cx q[9],q[3];
cp(pi/16) q[9],q[16];
cp(pi/8) q[3],q[15];
cx q[9],q[3];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[3],q[16];
cx q[9],q[3];
cp(pi/16) q[3],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[3];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[3],q[12];
cx q[9],q[3];
cp(-pi/2) q[9],q[13];
cp(0.0) q[3],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[3];
cp(pi/2) q[3],q[13];
cx q[9],q[3];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[3],q[13];
cx q[9],q[3];
cp(pi/4) q[3],q[14];
cx q[9],q[3];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[3],q[14];
cx q[9],q[3];
cp(pi/8) q[3],q[15];
cx q[9],q[3];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[3],q[15];
cx q[9],q[3];
cp(pi/16) q[3],q[16];
cx q[9],q[3];
cp(-pi/16) q[3],q[16];
cx q[8],q[3];
cp(pi/2) q[3],q[12];
cx q[8],q[3];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[3],q[12];
cx q[8],q[3];
h q[12];
cp(pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[3],q[16];
cx q[8],q[3];
cp(-pi/32) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[3];
cp(-pi/2) q[3],q[12];
cx q[8],q[3];
cp(pi/4) q[8],q[13];
cp(pi/2) q[3],q[12];
cx q[8],q[3];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[3],q[13];
cx q[8],q[3];
cp(pi/8) q[8],q[14];
cp(pi/4) q[3],q[13];
cx q[8],q[3];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[3],q[14];
cx q[8],q[3];
cp(pi/16) q[8],q[15];
cp(pi/8) q[3],q[14];
cx q[8],q[3];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[3],q[15];
cx q[8],q[3];
cp(pi/32) q[8],q[16];
cp(pi/16) q[3],q[15];
cx q[8],q[3];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[3],q[16];
cx q[8],q[3];
cp(pi/32) q[3],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[3];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[3],q[12];
cx q[8],q[3];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[3],q[12];
cx q[8],q[3];
h q[12];
cp(pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[3],q[13];
cx q[8],q[3];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[3],q[14];
cx q[8],q[3];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[3],q[15];
cx q[8],q[3];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[3],q[16];
cx q[8],q[3];
cp(-pi/32) q[3],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[4];
cp(-pi/2) q[4],q[12];
cx q[8],q[4];
cp(pi/4) q[8],q[13];
cp(pi/2) q[4],q[12];
cx q[8],q[4];
u2(0,0) q[12];
cp(-pi/4) q[4],q[13];
cx q[8],q[4];
cp(pi/8) q[8],q[14];
cp(pi/4) q[4],q[13];
cx q[8],q[4];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[4],q[14];
cx q[8],q[4];
cp(pi/16) q[8],q[15];
cp(pi/8) q[4],q[14];
cx q[8],q[4];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[4],q[15];
cx q[8],q[4];
cp(pi/32) q[8],q[16];
cp(pi/16) q[4],q[15];
cx q[8],q[4];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[4],q[16];
cx q[8],q[4];
cp(pi/32) q[4],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[4];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[4],q[12];
cx q[8],q[4];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[4],q[12];
cx q[8],q[4];
h q[12];
cp(pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[4],q[16];
cx q[8],q[4];
cp(-pi/32) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[4];
cp(-pi/2) q[4],q[12];
cx q[8],q[4];
cp(pi/4) q[8],q[13];
cp(pi/2) q[4],q[12];
cx q[8],q[4];
cp(0.0) q[9],q[12];
cp(-pi/4) q[4],q[13];
cx q[8],q[4];
cp(pi/8) q[8],q[14];
cp(pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/8) q[4],q[14];
cx q[8],q[4];
cp(pi/16) q[8],q[15];
cp(pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/16) q[4],q[15];
cx q[8],q[4];
cp(pi/32) q[8],q[16];
cp(pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/32) q[4],q[16];
cx q[8],q[4];
cp(pi/32) q[4],q[16];
cx q[9],q[4];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(pi/2) q[9],q[13];
cp(0.0) q[4],q[12];
cx q[9],q[4];
u2(0,0) q[12];
cp(-pi/2) q[4],q[13];
cx q[9],q[4];
cp(pi/4) q[9],q[14];
cp(pi/2) q[4],q[13];
cx q[9],q[4];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[4],q[14];
cx q[9],q[4];
cp(pi/8) q[9],q[15];
cp(pi/4) q[4],q[14];
cx q[9],q[4];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[4],q[15];
cx q[9],q[4];
cp(pi/16) q[9],q[16];
cp(pi/8) q[4],q[15];
cx q[9],q[4];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[4],q[16];
cx q[9],q[4];
cp(pi/16) q[4],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[4];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(-pi/2) q[9],q[13];
cp(0.0) q[4],q[12];
cx q[9],q[4];
h q[12];
cp(pi/2) q[4],q[13];
cx q[9],q[4];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[4],q[13];
cx q[9],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[4],q[14];
cx q[9],q[4];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[4],q[14];
cx q[9],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[4],q[15];
cx q[9],q[4];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[4],q[15];
cx q[9],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[4],q[16];
cx q[9],q[4];
cp(-pi/16) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[4];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(pi/2) q[9],q[13];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(0.0) q[10],q[12];
cp(-pi/2) q[4],q[13];
cx q[9],q[4];
cp(pi/4) q[9],q[14];
cp(pi/2) q[4],q[13];
cx q[9],q[4];
cp(-pi/4) q[4],q[14];
cx q[9],q[4];
cp(pi/8) q[9],q[15];
cp(pi/4) q[4],q[14];
cx q[9],q[4];
cp(-pi/8) q[4],q[15];
cx q[9],q[4];
cp(pi/16) q[9],q[16];
cp(pi/8) q[4],q[15];
cx q[9],q[4];
cp(-pi/16) q[4],q[16];
cx q[9],q[4];
cp(pi/16) q[4],q[16];
cx q[10],q[4];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[10],q[13];
cp(0.0) q[4],q[12];
cx q[10],q[4];
u2(0,0) q[12];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(pi/2) q[10],q[14];
cp(0.0) q[4],q[13];
cx q[10],q[4];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[4],q[14];
cx q[10],q[4];
cp(pi/4) q[10],q[15];
cp(pi/2) q[4],q[14];
cx q[10],q[4];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[4],q[15];
cx q[10],q[4];
cp(pi/8) q[10],q[16];
cp(pi/4) q[4],q[15];
cx q[10],q[4];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[4],q[16];
cx q[10],q[4];
cp(pi/8) q[4],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[4];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[10],q[13];
cp(0.0) q[4],q[12];
cx q[10],q[4];
h q[12];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-pi/2) q[10],q[14];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[4],q[14];
cx q[10],q[4];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[4],q[14];
cx q[10],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[4],q[15];
cx q[10],q[4];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[4],q[15];
cx q[10],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[4],q[16];
cx q[10],q[4];
cp(-pi/8) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[4];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[10],q[13];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[11],q[12];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(pi/2) q[10],q[14];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-pi/2) q[4],q[14];
cx q[10],q[4];
cp(pi/4) q[10],q[15];
cp(pi/2) q[4],q[14];
cx q[10],q[4];
cp(-pi/4) q[4],q[15];
cx q[10],q[4];
cp(pi/8) q[10],q[16];
cp(pi/4) q[4],q[15];
cx q[10],q[4];
cp(-pi/8) q[4],q[16];
cx q[10],q[4];
cp(pi/8) q[4],q[16];
cx q[11],q[4];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(0.0) q[11],q[13];
cp(0.0) q[4],q[12];
cx q[11],q[4];
u2(0,0) q[12];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[11],q[14];
cp(0.0) q[4],q[13];
cx q[11],q[4];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(pi/2) q[11],q[15];
cp(0.0) q[4],q[14];
cx q[11],q[4];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[4],q[15];
cx q[11],q[4];
cp(pi/4) q[11],q[16];
cp(pi/2) q[4],q[15];
cx q[11],q[4];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[4],q[16];
cx q[11],q[4];
cp(pi/4) q[4],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[4];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(0.0) q[11],q[13];
cp(0.0) q[4],q[12];
cx q[11],q[4];
h q[12];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[11],q[14];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-pi/2) q[11],q[15];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[4],q[15];
cx q[11],q[4];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[4],q[15];
cx q[11],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[4],q[16];
cx q[11],q[4];
cp(-pi/4) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[4];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(0.0) q[11],q[13];
cp(0.0) q[4],q[12];
cx q[11],q[4];
h q[12];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[11],q[14];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(pi/2) q[11],q[15];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[4],q[15];
cx q[11],q[4];
cp(pi/4) q[11],q[16];
cp(pi/2) q[4],q[15];
cx q[11],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[4],q[16];
cx q[11],q[4];
cp(pi/4) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[4],q[8],q[12];
cswap q[4],q[9],q[13];
cswap q[4],q[10],q[14];
cswap q[4],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[4];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(0.0) q[11],q[13];
cp(0.0) q[4],q[12];
cx q[11],q[4];
h q[12];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[11],q[14];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-pi/2) q[11],q[15];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[4],q[15];
cx q[11],q[4];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[4],q[15];
cx q[11],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[4],q[16];
cx q[11],q[4];
cp(-pi/4) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[4];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(0.0) q[11],q[13];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[11],q[14];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(pi/2) q[11],q[15];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[4],q[15];
cx q[11],q[4];
cp(pi/4) q[11],q[16];
cp(pi/2) q[4],q[15];
cx q[11],q[4];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[4],q[16];
cx q[11],q[4];
cp(pi/4) q[4],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[4];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[4],q[12];
cx q[11],q[4];
cp(0.0) q[11],q[13];
cp(0.0) q[4],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[4];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[11],q[14];
cp(0.0) q[4],q[13];
cx q[11],q[4];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(-pi/2) q[11],q[15];
cp(0.0) q[4],q[14];
cx q[11],q[4];
cp(pi/2) q[4],q[15];
cx q[11],q[4];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[4],q[15];
cx q[11],q[4];
cp(pi/4) q[4],q[16];
cx q[11],q[4];
cp(-pi/4) q[4],q[16];
cx q[10],q[4];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[10],q[13];
cp(0.0) q[4],q[12];
cx q[10],q[4];
h q[12];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-pi/2) q[10],q[14];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[4],q[14];
cx q[10],q[4];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[4],q[14];
cx q[10],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[4],q[15];
cx q[10],q[4];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[4],q[15];
cx q[10],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[4],q[16];
cx q[10],q[4];
cp(-pi/8) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[4];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[10],q[13];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(pi/2) q[10],q[14];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[4],q[14];
cx q[10],q[4];
cp(pi/4) q[10],q[15];
cp(pi/2) q[4],q[14];
cx q[10],q[4];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[4],q[15];
cx q[10],q[4];
cp(pi/8) q[10],q[16];
cp(pi/4) q[4],q[15];
cx q[10],q[4];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[4],q[16];
cx q[10],q[4];
cp(pi/8) q[4],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[4];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[4],q[12];
cx q[10],q[4];
cp(0.0) q[10],q[13];
cp(0.0) q[4],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[4];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(-pi/2) q[10],q[14];
cp(0.0) q[4],q[13];
cx q[10],q[4];
cp(pi/2) q[4],q[14];
cx q[10],q[4];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[4],q[14];
cx q[10],q[4];
cp(pi/4) q[4],q[15];
cx q[10],q[4];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[4],q[15];
cx q[10],q[4];
cp(pi/8) q[4],q[16];
cx q[10],q[4];
cp(-pi/8) q[4],q[16];
cx q[9],q[4];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(-pi/2) q[9],q[13];
cp(0.0) q[4],q[12];
cx q[9],q[4];
h q[12];
cp(pi/2) q[4],q[13];
cx q[9],q[4];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[4],q[13];
cx q[9],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[4],q[14];
cx q[9],q[4];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[4],q[14];
cx q[9],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[4],q[15];
cx q[9],q[4];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[4],q[15];
cx q[9],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[4],q[16];
cx q[9],q[4];
cp(-pi/16) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[4];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(pi/2) q[9],q[13];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[4],q[13];
cx q[9],q[4];
cp(pi/4) q[9],q[14];
cp(pi/2) q[4],q[13];
cx q[9],q[4];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[4],q[14];
cx q[9],q[4];
cp(pi/8) q[9],q[15];
cp(pi/4) q[4],q[14];
cx q[9],q[4];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[4],q[15];
cx q[9],q[4];
cp(pi/16) q[9],q[16];
cp(pi/8) q[4],q[15];
cx q[9],q[4];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[4],q[16];
cx q[9],q[4];
cp(pi/16) q[4],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[4];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[4],q[12];
cx q[9],q[4];
cp(-pi/2) q[9],q[13];
cp(0.0) q[4],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[4];
cp(pi/2) q[4],q[13];
cx q[9],q[4];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[4],q[13];
cx q[9],q[4];
cp(pi/4) q[4],q[14];
cx q[9],q[4];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[4],q[14];
cx q[9],q[4];
cp(pi/8) q[4],q[15];
cx q[9],q[4];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[4],q[15];
cx q[9],q[4];
cp(pi/16) q[4],q[16];
cx q[9],q[4];
cp(-pi/16) q[4],q[16];
cx q[8],q[4];
cp(pi/2) q[4],q[12];
cx q[8],q[4];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[4],q[12];
cx q[8],q[4];
h q[12];
cp(pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[4],q[16];
cx q[8],q[4];
cp(-pi/32) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[4];
cp(-pi/2) q[4],q[12];
cx q[8],q[4];
cp(pi/4) q[8],q[13];
cp(pi/2) q[4],q[12];
cx q[8],q[4];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[4],q[13];
cx q[8],q[4];
cp(pi/8) q[8],q[14];
cp(pi/4) q[4],q[13];
cx q[8],q[4];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[4],q[14];
cx q[8],q[4];
cp(pi/16) q[8],q[15];
cp(pi/8) q[4],q[14];
cx q[8],q[4];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[4],q[15];
cx q[8],q[4];
cp(pi/32) q[8],q[16];
cp(pi/16) q[4],q[15];
cx q[8],q[4];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[4],q[16];
cx q[8],q[4];
cp(pi/32) q[4],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[4];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[4],q[12];
cx q[8],q[4];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[4],q[12];
cx q[8],q[4];
h q[12];
cp(pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[4],q[13];
cx q[8],q[4];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[4],q[14];
cx q[8],q[4];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[4],q[15];
cx q[8],q[4];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[4],q[16];
cx q[8],q[4];
cp(-pi/32) q[4],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[5];
swap q[3],q[4];
cp(-pi/2) q[5],q[12];
cx q[8],q[5];
cp(pi/4) q[8],q[13];
cp(pi/2) q[5],q[12];
cx q[8],q[5];
u2(0,0) q[12];
cp(-pi/4) q[5],q[13];
cx q[8],q[5];
cp(pi/8) q[8],q[14];
cp(pi/4) q[5],q[13];
cx q[8],q[5];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[5],q[14];
cx q[8],q[5];
cp(pi/16) q[8],q[15];
cp(pi/8) q[5],q[14];
cx q[8],q[5];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[5],q[15];
cx q[8],q[5];
cp(pi/32) q[8],q[16];
cp(pi/16) q[5],q[15];
cx q[8],q[5];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[5],q[16];
cx q[8],q[5];
cp(pi/32) q[5],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[5];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[5],q[12];
cx q[8],q[5];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[5],q[12];
cx q[8],q[5];
h q[12];
cp(pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[5],q[16];
cx q[8],q[5];
cp(-pi/32) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[5];
cp(-pi/2) q[5],q[12];
cx q[8],q[5];
cp(pi/4) q[8],q[13];
cp(pi/2) q[5],q[12];
cx q[8],q[5];
cp(0.0) q[9],q[12];
cp(-pi/4) q[5],q[13];
cx q[8],q[5];
cp(pi/8) q[8],q[14];
cp(pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/8) q[5],q[14];
cx q[8],q[5];
cp(pi/16) q[8],q[15];
cp(pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/16) q[5],q[15];
cx q[8],q[5];
cp(pi/32) q[8],q[16];
cp(pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/32) q[5],q[16];
cx q[8],q[5];
cp(pi/32) q[5],q[16];
cx q[9],q[5];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(pi/2) q[9],q[13];
cp(0.0) q[5],q[12];
cx q[9],q[5];
u2(0,0) q[12];
cp(-pi/2) q[5],q[13];
cx q[9],q[5];
cp(pi/4) q[9],q[14];
cp(pi/2) q[5],q[13];
cx q[9],q[5];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[5],q[14];
cx q[9],q[5];
cp(pi/8) q[9],q[15];
cp(pi/4) q[5],q[14];
cx q[9],q[5];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[5],q[15];
cx q[9],q[5];
cp(pi/16) q[9],q[16];
cp(pi/8) q[5],q[15];
cx q[9],q[5];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[5],q[16];
cx q[9],q[5];
cp(pi/16) q[5],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[5];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(-pi/2) q[9],q[13];
cp(0.0) q[5],q[12];
cx q[9],q[5];
h q[12];
cp(pi/2) q[5],q[13];
cx q[9],q[5];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[5],q[13];
cx q[9],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[5],q[14];
cx q[9],q[5];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[5],q[14];
cx q[9],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[5],q[15];
cx q[9],q[5];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[5],q[15];
cx q[9],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[5],q[16];
cx q[9],q[5];
cp(-pi/16) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[5];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(pi/2) q[9],q[13];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(0.0) q[10],q[12];
cp(-pi/2) q[5],q[13];
cx q[9],q[5];
cp(pi/4) q[9],q[14];
cp(pi/2) q[5],q[13];
cx q[9],q[5];
cp(-pi/4) q[5],q[14];
cx q[9],q[5];
cp(pi/8) q[9],q[15];
cp(pi/4) q[5],q[14];
cx q[9],q[5];
cp(-pi/8) q[5],q[15];
cx q[9],q[5];
cp(pi/16) q[9],q[16];
cp(pi/8) q[5],q[15];
cx q[9],q[5];
cp(-pi/16) q[5],q[16];
cx q[9],q[5];
cp(pi/16) q[5],q[16];
cx q[10],q[5];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[10],q[13];
cp(0.0) q[5],q[12];
cx q[10],q[5];
u2(0,0) q[12];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(pi/2) q[10],q[14];
cp(0.0) q[5],q[13];
cx q[10],q[5];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[5],q[14];
cx q[10],q[5];
cp(pi/4) q[10],q[15];
cp(pi/2) q[5],q[14];
cx q[10],q[5];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[5],q[15];
cx q[10],q[5];
cp(pi/8) q[10],q[16];
cp(pi/4) q[5],q[15];
cx q[10],q[5];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[5],q[16];
cx q[10],q[5];
cp(pi/8) q[5],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[5];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[10],q[13];
cp(0.0) q[5],q[12];
cx q[10],q[5];
h q[12];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-pi/2) q[10],q[14];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[5],q[14];
cx q[10],q[5];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[5],q[14];
cx q[10],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[5],q[15];
cx q[10],q[5];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[5],q[15];
cx q[10],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[5],q[16];
cx q[10],q[5];
cp(-pi/8) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[5];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[10],q[13];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[11],q[12];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(pi/2) q[10],q[14];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-pi/2) q[5],q[14];
cx q[10],q[5];
cp(pi/4) q[10],q[15];
cp(pi/2) q[5],q[14];
cx q[10],q[5];
cp(-pi/4) q[5],q[15];
cx q[10],q[5];
cp(pi/8) q[10],q[16];
cp(pi/4) q[5],q[15];
cx q[10],q[5];
cp(-pi/8) q[5],q[16];
cx q[10],q[5];
cp(pi/8) q[5],q[16];
cx q[11],q[5];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(0.0) q[11],q[13];
cp(0.0) q[5],q[12];
cx q[11],q[5];
u2(0,0) q[12];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[11],q[14];
cp(0.0) q[5],q[13];
cx q[11],q[5];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(pi/2) q[11],q[15];
cp(0.0) q[5],q[14];
cx q[11],q[5];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[5],q[15];
cx q[11],q[5];
cp(pi/4) q[11],q[16];
cp(pi/2) q[5],q[15];
cx q[11],q[5];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[5],q[16];
cx q[11],q[5];
cp(pi/4) q[5],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[5];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(0.0) q[11],q[13];
cp(0.0) q[5],q[12];
cx q[11],q[5];
h q[12];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[11],q[14];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-pi/2) q[11],q[15];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[5],q[15];
cx q[11],q[5];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[5],q[15];
cx q[11],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[5],q[16];
cx q[11],q[5];
cp(-pi/4) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[5];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(0.0) q[11],q[13];
cp(0.0) q[5],q[12];
cx q[11],q[5];
h q[12];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[11],q[14];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(pi/2) q[11],q[15];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[5],q[15];
cx q[11],q[5];
cp(pi/4) q[11],q[16];
cp(pi/2) q[5],q[15];
cx q[11],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[5],q[16];
cx q[11],q[5];
cp(pi/4) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[5],q[8],q[12];
cswap q[5],q[9],q[13];
cswap q[5],q[10],q[14];
cswap q[5],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[5];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(0.0) q[11],q[13];
cp(0.0) q[5],q[12];
cx q[11],q[5];
h q[12];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[11],q[14];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-pi/2) q[11],q[15];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[5],q[15];
cx q[11],q[5];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[5],q[15];
cx q[11],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[5],q[16];
cx q[11],q[5];
cp(-pi/4) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[5];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(0.0) q[11],q[13];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[11],q[14];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(pi/2) q[11],q[15];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[5],q[15];
cx q[11],q[5];
cp(pi/4) q[11],q[16];
cp(pi/2) q[5],q[15];
cx q[11],q[5];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[5],q[16];
cx q[11],q[5];
cp(pi/4) q[5],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[5];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[5],q[12];
cx q[11],q[5];
cp(0.0) q[11],q[13];
cp(0.0) q[5],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[5];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[11],q[14];
cp(0.0) q[5],q[13];
cx q[11],q[5];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(-pi/2) q[11],q[15];
cp(0.0) q[5],q[14];
cx q[11],q[5];
cp(pi/2) q[5],q[15];
cx q[11],q[5];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[5],q[15];
cx q[11],q[5];
cp(pi/4) q[5],q[16];
cx q[11],q[5];
cp(-pi/4) q[5],q[16];
cx q[10],q[5];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[10],q[13];
cp(0.0) q[5],q[12];
cx q[10],q[5];
h q[12];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-pi/2) q[10],q[14];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[5],q[14];
cx q[10],q[5];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[5],q[14];
cx q[10],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[5],q[15];
cx q[10],q[5];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[5],q[15];
cx q[10],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[5],q[16];
cx q[10],q[5];
cp(-pi/8) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[5];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[10],q[13];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(pi/2) q[10],q[14];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[5],q[14];
cx q[10],q[5];
cp(pi/4) q[10],q[15];
cp(pi/2) q[5],q[14];
cx q[10],q[5];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[5],q[15];
cx q[10],q[5];
cp(pi/8) q[10],q[16];
cp(pi/4) q[5],q[15];
cx q[10],q[5];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[5],q[16];
cx q[10],q[5];
cp(pi/8) q[5],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[5];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[5],q[12];
cx q[10],q[5];
cp(0.0) q[10],q[13];
cp(0.0) q[5],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[5];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(-pi/2) q[10],q[14];
cp(0.0) q[5],q[13];
cx q[10],q[5];
cp(pi/2) q[5],q[14];
cx q[10],q[5];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[5],q[14];
cx q[10],q[5];
cp(pi/4) q[5],q[15];
cx q[10],q[5];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[5],q[15];
cx q[10],q[5];
cp(pi/8) q[5],q[16];
cx q[10],q[5];
cp(-pi/8) q[5],q[16];
cx q[9],q[5];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(-pi/2) q[9],q[13];
cp(0.0) q[5],q[12];
cx q[9],q[5];
h q[12];
cp(pi/2) q[5],q[13];
cx q[9],q[5];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[5],q[13];
cx q[9],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[5],q[14];
cx q[9],q[5];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[5],q[14];
cx q[9],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[5],q[15];
cx q[9],q[5];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[5],q[15];
cx q[9],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[5],q[16];
cx q[9],q[5];
cp(-pi/16) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[5];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(pi/2) q[9],q[13];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[5],q[13];
cx q[9],q[5];
cp(pi/4) q[9],q[14];
cp(pi/2) q[5],q[13];
cx q[9],q[5];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[5],q[14];
cx q[9],q[5];
cp(pi/8) q[9],q[15];
cp(pi/4) q[5],q[14];
cx q[9],q[5];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[5],q[15];
cx q[9],q[5];
cp(pi/16) q[9],q[16];
cp(pi/8) q[5],q[15];
cx q[9],q[5];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[5],q[16];
cx q[9],q[5];
cp(pi/16) q[5],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[5];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[5],q[12];
cx q[9],q[5];
cp(-pi/2) q[9],q[13];
cp(0.0) q[5],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[5];
cp(pi/2) q[5],q[13];
cx q[9],q[5];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[5],q[13];
cx q[9],q[5];
cp(pi/4) q[5],q[14];
cx q[9],q[5];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[5],q[14];
cx q[9],q[5];
cp(pi/8) q[5],q[15];
cx q[9],q[5];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[5],q[15];
cx q[9],q[5];
cp(pi/16) q[5],q[16];
cx q[9],q[5];
cp(-pi/16) q[5],q[16];
cx q[8],q[5];
cp(pi/2) q[5],q[12];
cx q[8],q[5];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[5],q[12];
cx q[8],q[5];
h q[12];
cp(pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[5],q[16];
cx q[8],q[5];
cp(-pi/32) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[5];
cp(-pi/2) q[5],q[12];
cx q[8],q[5];
cp(pi/4) q[8],q[13];
cp(pi/2) q[5],q[12];
cx q[8],q[5];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[5],q[13];
cx q[8],q[5];
cp(pi/8) q[8],q[14];
cp(pi/4) q[5],q[13];
cx q[8],q[5];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[5],q[14];
cx q[8],q[5];
cp(pi/16) q[8],q[15];
cp(pi/8) q[5],q[14];
cx q[8],q[5];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[5],q[15];
cx q[8],q[5];
cp(pi/32) q[8],q[16];
cp(pi/16) q[5],q[15];
cx q[8],q[5];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[5],q[16];
cx q[8],q[5];
cp(pi/32) q[5],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[5];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[5],q[12];
cx q[8],q[5];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[5],q[12];
cx q[8],q[5];
h q[12];
cp(pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[5],q[13];
cx q[8],q[5];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[5],q[14];
cx q[8],q[5];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[5],q[15];
cx q[8],q[5];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[5],q[16];
cx q[8],q[5];
cp(-pi/32) q[5],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[6];
swap q[2],q[5];
cp(-pi/2) q[6],q[12];
cx q[8],q[6];
cp(pi/4) q[8],q[13];
cp(pi/2) q[6],q[12];
cx q[8],q[6];
u2(0,0) q[12];
cp(-pi/4) q[6],q[13];
cx q[8],q[6];
cp(pi/8) q[8],q[14];
cp(pi/4) q[6],q[13];
cx q[8],q[6];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[6],q[14];
cx q[8],q[6];
cp(pi/16) q[8],q[15];
cp(pi/8) q[6],q[14];
cx q[8],q[6];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[6],q[15];
cx q[8],q[6];
cp(pi/32) q[8],q[16];
cp(pi/16) q[6],q[15];
cx q[8],q[6];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[6],q[16];
cx q[8],q[6];
cp(pi/32) q[6],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[6];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[6],q[12];
cx q[8],q[6];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[6],q[12];
cx q[8],q[6];
h q[12];
cp(pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[6],q[16];
cx q[8],q[6];
cp(-pi/32) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[6];
cp(-pi/2) q[6],q[12];
cx q[8],q[6];
cp(pi/4) q[8],q[13];
cp(pi/2) q[6],q[12];
cx q[8],q[6];
cp(0.0) q[9],q[12];
cp(-pi/4) q[6],q[13];
cx q[8],q[6];
cp(pi/8) q[8],q[14];
cp(pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/8) q[6],q[14];
cx q[8],q[6];
cp(pi/16) q[8],q[15];
cp(pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/16) q[6],q[15];
cx q[8],q[6];
cp(pi/32) q[8],q[16];
cp(pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/32) q[6],q[16];
cx q[8],q[6];
cp(pi/32) q[6],q[16];
cx q[9],q[6];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(pi/2) q[9],q[13];
cp(0.0) q[6],q[12];
cx q[9],q[6];
u2(0,0) q[12];
cp(-pi/2) q[6],q[13];
cx q[9],q[6];
cp(pi/4) q[9],q[14];
cp(pi/2) q[6],q[13];
cx q[9],q[6];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[6],q[14];
cx q[9],q[6];
cp(pi/8) q[9],q[15];
cp(pi/4) q[6],q[14];
cx q[9],q[6];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[6],q[15];
cx q[9],q[6];
cp(pi/16) q[9],q[16];
cp(pi/8) q[6],q[15];
cx q[9],q[6];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[6],q[16];
cx q[9],q[6];
cp(pi/16) q[6],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[6];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(-pi/2) q[9],q[13];
cp(0.0) q[6],q[12];
cx q[9],q[6];
h q[12];
cp(pi/2) q[6],q[13];
cx q[9],q[6];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[6],q[13];
cx q[9],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[6],q[14];
cx q[9],q[6];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[6],q[14];
cx q[9],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[6],q[15];
cx q[9],q[6];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[6],q[15];
cx q[9],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[6],q[16];
cx q[9],q[6];
cp(-pi/16) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[6];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(pi/2) q[9],q[13];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(0.0) q[10],q[12];
cp(-pi/2) q[6],q[13];
cx q[9],q[6];
cp(pi/4) q[9],q[14];
cp(pi/2) q[6],q[13];
cx q[9],q[6];
cp(-pi/4) q[6],q[14];
cx q[9],q[6];
cp(pi/8) q[9],q[15];
cp(pi/4) q[6],q[14];
cx q[9],q[6];
cp(-pi/8) q[6],q[15];
cx q[9],q[6];
cp(pi/16) q[9],q[16];
cp(pi/8) q[6],q[15];
cx q[9],q[6];
cp(-pi/16) q[6],q[16];
cx q[9],q[6];
cp(pi/16) q[6],q[16];
cx q[10],q[6];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[10],q[13];
cp(0.0) q[6],q[12];
cx q[10],q[6];
u2(0,0) q[12];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(pi/2) q[10],q[14];
cp(0.0) q[6],q[13];
cx q[10],q[6];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[6],q[14];
cx q[10],q[6];
cp(pi/4) q[10],q[15];
cp(pi/2) q[6],q[14];
cx q[10],q[6];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[6],q[15];
cx q[10],q[6];
cp(pi/8) q[10],q[16];
cp(pi/4) q[6],q[15];
cx q[10],q[6];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[6],q[16];
cx q[10],q[6];
cp(pi/8) q[6],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[6];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[10],q[13];
cp(0.0) q[6],q[12];
cx q[10],q[6];
h q[12];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-pi/2) q[10],q[14];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[6],q[14];
cx q[10],q[6];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[6],q[14];
cx q[10],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[6],q[15];
cx q[10],q[6];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[6],q[15];
cx q[10],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[6],q[16];
cx q[10],q[6];
cp(-pi/8) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[6];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[10],q[13];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[11],q[12];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(pi/2) q[10],q[14];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-pi/2) q[6],q[14];
cx q[10],q[6];
cp(pi/4) q[10],q[15];
cp(pi/2) q[6],q[14];
cx q[10],q[6];
cp(-pi/4) q[6],q[15];
cx q[10],q[6];
cp(pi/8) q[10],q[16];
cp(pi/4) q[6],q[15];
cx q[10],q[6];
cp(-pi/8) q[6],q[16];
cx q[10],q[6];
cp(pi/8) q[6],q[16];
cx q[11],q[6];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(0.0) q[11],q[13];
cp(0.0) q[6],q[12];
cx q[11],q[6];
u2(0,0) q[12];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[11],q[14];
cp(0.0) q[6],q[13];
cx q[11],q[6];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(pi/2) q[11],q[15];
cp(0.0) q[6],q[14];
cx q[11],q[6];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[6],q[15];
cx q[11],q[6];
cp(pi/4) q[11],q[16];
cp(pi/2) q[6],q[15];
cx q[11],q[6];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[6],q[16];
cx q[11],q[6];
cp(pi/4) q[6],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[6];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(0.0) q[11],q[13];
cp(0.0) q[6],q[12];
cx q[11],q[6];
h q[12];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[11],q[14];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-pi/2) q[11],q[15];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[6],q[15];
cx q[11],q[6];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[6],q[15];
cx q[11],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[6],q[16];
cx q[11],q[6];
cp(-pi/4) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[6];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(0.0) q[11],q[13];
cp(0.0) q[6],q[12];
cx q[11],q[6];
h q[12];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[11],q[14];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(pi/2) q[11],q[15];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[6],q[15];
cx q[11],q[6];
cp(pi/4) q[11],q[16];
cp(pi/2) q[6],q[15];
cx q[11],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[6],q[16];
cx q[11],q[6];
cp(pi/4) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[6],q[8],q[12];
cswap q[6],q[9],q[13];
cswap q[6],q[10],q[14];
cswap q[6],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[6];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(0.0) q[11],q[13];
cp(0.0) q[6],q[12];
cx q[11],q[6];
h q[12];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[11],q[14];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-pi/2) q[11],q[15];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[6],q[15];
cx q[11],q[6];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[6],q[15];
cx q[11],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[6],q[16];
cx q[11],q[6];
cp(-pi/4) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[6];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(0.0) q[11],q[13];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[11],q[14];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(pi/2) q[11],q[15];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[6],q[15];
cx q[11],q[6];
cp(pi/4) q[11],q[16];
cp(pi/2) q[6],q[15];
cx q[11],q[6];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[6],q[16];
cx q[11],q[6];
cp(pi/4) q[6],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[6];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[6],q[12];
cx q[11],q[6];
cp(0.0) q[11],q[13];
cp(0.0) q[6],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[6];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[11],q[14];
cp(0.0) q[6],q[13];
cx q[11],q[6];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(-pi/2) q[11],q[15];
cp(0.0) q[6],q[14];
cx q[11],q[6];
cp(pi/2) q[6],q[15];
cx q[11],q[6];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[6],q[15];
cx q[11],q[6];
cp(pi/4) q[6],q[16];
cx q[11],q[6];
cp(-pi/4) q[6],q[16];
cx q[10],q[6];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[10],q[13];
cp(0.0) q[6],q[12];
cx q[10],q[6];
h q[12];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-pi/2) q[10],q[14];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[6],q[14];
cx q[10],q[6];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[6],q[14];
cx q[10],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[6],q[15];
cx q[10],q[6];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[6],q[15];
cx q[10],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[6],q[16];
cx q[10],q[6];
cp(-pi/8) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[6];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[10],q[13];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(pi/2) q[10],q[14];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[6],q[14];
cx q[10],q[6];
cp(pi/4) q[10],q[15];
cp(pi/2) q[6],q[14];
cx q[10],q[6];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[6],q[15];
cx q[10],q[6];
cp(pi/8) q[10],q[16];
cp(pi/4) q[6],q[15];
cx q[10],q[6];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[6],q[16];
cx q[10],q[6];
cp(pi/8) q[6],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[6];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[6],q[12];
cx q[10],q[6];
cp(0.0) q[10],q[13];
cp(0.0) q[6],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[6];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(-pi/2) q[10],q[14];
cp(0.0) q[6],q[13];
cx q[10],q[6];
cp(pi/2) q[6],q[14];
cx q[10],q[6];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[6],q[14];
cx q[10],q[6];
cp(pi/4) q[6],q[15];
cx q[10],q[6];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[6],q[15];
cx q[10],q[6];
cp(pi/8) q[6],q[16];
cx q[10],q[6];
cp(-pi/8) q[6],q[16];
cx q[9],q[6];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(-pi/2) q[9],q[13];
cp(0.0) q[6],q[12];
cx q[9],q[6];
h q[12];
cp(pi/2) q[6],q[13];
cx q[9],q[6];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[6],q[13];
cx q[9],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[6],q[14];
cx q[9],q[6];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[6],q[14];
cx q[9],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[6],q[15];
cx q[9],q[6];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[6],q[15];
cx q[9],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[6],q[16];
cx q[9],q[6];
cp(-pi/16) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[6];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(pi/2) q[9],q[13];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[6],q[13];
cx q[9],q[6];
cp(pi/4) q[9],q[14];
cp(pi/2) q[6],q[13];
cx q[9],q[6];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[6],q[14];
cx q[9],q[6];
cp(pi/8) q[9],q[15];
cp(pi/4) q[6],q[14];
cx q[9],q[6];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[6],q[15];
cx q[9],q[6];
cp(pi/16) q[9],q[16];
cp(pi/8) q[6],q[15];
cx q[9],q[6];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[6],q[16];
cx q[9],q[6];
cp(pi/16) q[6],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[6];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[6],q[12];
cx q[9],q[6];
cp(-pi/2) q[9],q[13];
cp(0.0) q[6],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[6];
cp(pi/2) q[6],q[13];
cx q[9],q[6];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[6],q[13];
cx q[9],q[6];
cp(pi/4) q[6],q[14];
cx q[9],q[6];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[6],q[14];
cx q[9],q[6];
cp(pi/8) q[6],q[15];
cx q[9],q[6];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[6],q[15];
cx q[9],q[6];
cp(pi/16) q[6],q[16];
cx q[9],q[6];
cp(-pi/16) q[6],q[16];
cx q[8],q[6];
cp(pi/2) q[6],q[12];
cx q[8],q[6];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[6],q[12];
cx q[8],q[6];
h q[12];
cp(pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[6],q[16];
cx q[8],q[6];
cp(-pi/32) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[6];
cp(-pi/2) q[6],q[12];
cx q[8],q[6];
cp(pi/4) q[8],q[13];
cp(pi/2) q[6],q[12];
cx q[8],q[6];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[6],q[13];
cx q[8],q[6];
cp(pi/8) q[8],q[14];
cp(pi/4) q[6],q[13];
cx q[8],q[6];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[6],q[14];
cx q[8],q[6];
cp(pi/16) q[8],q[15];
cp(pi/8) q[6],q[14];
cx q[8],q[6];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[6],q[15];
cx q[8],q[6];
cp(pi/32) q[8],q[16];
cp(pi/16) q[6],q[15];
cx q[8],q[6];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[6],q[16];
cx q[8],q[6];
cp(pi/32) q[6],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[6];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[6],q[12];
cx q[8],q[6];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[6],q[12];
cx q[8],q[6];
h q[12];
cp(pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[6],q[13];
cx q[8],q[6];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[6],q[14];
cx q[8],q[6];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[6],q[15];
cx q[8],q[6];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[6],q[16];
cx q[8],q[6];
cp(-pi/32) q[6],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[7];
swap q[1],q[6];
cp(-pi/2) q[7],q[12];
cx q[8],q[7];
cp(pi/4) q[8],q[13];
cp(pi/2) q[7],q[12];
cx q[8],q[7];
u2(0,0) q[12];
cp(-pi/4) q[7],q[13];
cx q[8],q[7];
cp(pi/8) q[8],q[14];
cp(pi/4) q[7],q[13];
cx q[8],q[7];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[7],q[14];
cx q[8],q[7];
cp(pi/16) q[8],q[15];
cp(pi/8) q[7],q[14];
cx q[8],q[7];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[7],q[15];
cx q[8],q[7];
cp(pi/32) q[8],q[16];
cp(pi/16) q[7],q[15];
cx q[8],q[7];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[7],q[16];
cx q[8],q[7];
cp(pi/32) q[7],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[7];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(pi/2) q[7],q[12];
cx q[8],q[7];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[7],q[12];
cx q[8],q[7];
h q[12];
cp(pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[7],q[16];
cx q[8],q[7];
cp(-pi/32) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[7];
cp(-pi/2) q[7],q[12];
cx q[8],q[7];
cp(pi/4) q[8],q[13];
cp(pi/2) q[7],q[12];
cx q[8],q[7];
cp(0.0) q[9],q[12];
cp(-pi/4) q[7],q[13];
cx q[8],q[7];
cp(pi/8) q[8],q[14];
cp(pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/8) q[7],q[14];
cx q[8],q[7];
cp(pi/16) q[8],q[15];
cp(pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/16) q[7],q[15];
cx q[8],q[7];
cp(pi/32) q[8],q[16];
cp(pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/32) q[7],q[16];
cx q[8],q[7];
cp(pi/32) q[7],q[16];
cx q[9],q[7];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(pi/2) q[9],q[13];
cp(0.0) q[7],q[12];
cx q[9],q[7];
u2(0,0) q[12];
cp(-pi/2) q[7],q[13];
cx q[9],q[7];
cp(pi/4) q[9],q[14];
cp(pi/2) q[7],q[13];
cx q[9],q[7];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[7],q[14];
cx q[9],q[7];
cp(pi/8) q[9],q[15];
cp(pi/4) q[7],q[14];
cx q[9],q[7];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[7],q[15];
cx q[9],q[7];
cp(pi/16) q[9],q[16];
cp(pi/8) q[7],q[15];
cx q[9],q[7];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[7],q[16];
cx q[9],q[7];
cp(pi/16) q[7],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[9],q[12];
cx q[9],q[7];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(-pi/2) q[9],q[13];
cp(0.0) q[7],q[12];
cx q[9],q[7];
h q[12];
cp(pi/2) q[7],q[13];
cx q[9],q[7];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[7],q[13];
cx q[9],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[7],q[14];
cx q[9],q[7];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[7],q[14];
cx q[9],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[7],q[15];
cx q[9],q[7];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[7],q[15];
cx q[9],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[7],q[16];
cx q[9],q[7];
cp(-pi/16) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[7];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(pi/2) q[9],q[13];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(0.0) q[10],q[12];
cp(-pi/2) q[7],q[13];
cx q[9],q[7];
cp(pi/4) q[9],q[14];
cp(pi/2) q[7],q[13];
cx q[9],q[7];
cp(-pi/4) q[7],q[14];
cx q[9],q[7];
cp(pi/8) q[9],q[15];
cp(pi/4) q[7],q[14];
cx q[9],q[7];
cp(-pi/8) q[7],q[15];
cx q[9],q[7];
cp(pi/16) q[9],q[16];
cp(pi/8) q[7],q[15];
cx q[9],q[7];
cp(-pi/16) q[7],q[16];
cx q[9],q[7];
cp(pi/16) q[7],q[16];
cx q[10],q[7];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[10],q[13];
cp(0.0) q[7],q[12];
cx q[10],q[7];
u2(0,0) q[12];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(pi/2) q[10],q[14];
cp(0.0) q[7],q[13];
cx q[10],q[7];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[7],q[14];
cx q[10],q[7];
cp(pi/4) q[10],q[15];
cp(pi/2) q[7],q[14];
cx q[10],q[7];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[7],q[15];
cx q[10],q[7];
cp(pi/8) q[10],q[16];
cp(pi/4) q[7],q[15];
cx q[10],q[7];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[7],q[16];
cx q[10],q[7];
cp(pi/8) q[7],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[10],q[12];
cx q[10],q[7];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[10],q[13];
cp(0.0) q[7],q[12];
cx q[10],q[7];
h q[12];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-pi/2) q[10],q[14];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[7],q[14];
cx q[10],q[7];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[7],q[14];
cx q[10],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[7],q[15];
cx q[10],q[7];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[7],q[15];
cx q[10],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[7],q[16];
cx q[10],q[7];
cp(-pi/8) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[7];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[10],q[13];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[11],q[12];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(pi/2) q[10],q[14];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-pi/2) q[7],q[14];
cx q[10],q[7];
cp(pi/4) q[10],q[15];
cp(pi/2) q[7],q[14];
cx q[10],q[7];
cp(-pi/4) q[7],q[15];
cx q[10],q[7];
cp(pi/8) q[10],q[16];
cp(pi/4) q[7],q[15];
cx q[10],q[7];
cp(-pi/8) q[7],q[16];
cx q[10],q[7];
cp(pi/8) q[7],q[16];
cx q[11],q[7];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(0.0) q[11],q[13];
cp(0.0) q[7],q[12];
cx q[11],q[7];
u2(0,0) q[12];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[11],q[14];
cp(0.0) q[7],q[13];
cx q[11],q[7];
p(-3*pi/2) q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(pi/2) q[11],q[15];
cp(0.0) q[7],q[14];
cx q[11],q[7];
p(-7*pi/4) q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[7],q[15];
cx q[11],q[7];
cp(pi/4) q[11],q[16];
cp(pi/2) q[7],q[15];
cx q[11],q[7];
p(-15*pi/8) q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[7],q[16];
cx q[11],q[7];
cp(pi/4) q[7],q[16];
p(-15*pi/16) q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi) q[17],q[12];
cp(0.0) q[11],q[12];
cx q[11],q[7];
cp(3*pi/2) q[17],q[13];
cp(7*pi/4) q[17],q[14];
cp(15*pi/8) q[17],q[15];
cp(15*pi/16) q[17],q[16];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(0.0) q[11],q[13];
cp(0.0) q[7],q[12];
cx q[11],q[7];
h q[12];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[11],q[14];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-pi/2) q[11],q[15];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[7],q[15];
cx q[11],q[7];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[7],q[15];
cx q[11],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[7],q[16];
cx q[11],q[7];
cp(-pi/4) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[7];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(0.0) q[11],q[13];
cp(0.0) q[7],q[12];
cx q[11],q[7];
h q[12];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[11],q[14];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(pi/2) q[11],q[15];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[7],q[15];
cx q[11],q[7];
cp(pi/4) q[11],q[16];
cp(pi/2) q[7],q[15];
cx q[11],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[7],q[16];
cx q[11],q[7];
cp(pi/4) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
cswap q[7],q[8],q[12];
cswap q[7],q[9],q[13];
cswap q[7],q[10],q[14];
cswap q[7],q[11],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[7];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(0.0) q[11],q[13];
cp(0.0) q[7],q[12];
cx q[11],q[7];
h q[12];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[11],q[14];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-pi/2) q[11],q[15];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/2) q[7],q[15];
cx q[11],q[7];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[7],q[15];
cx q[11],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/4) q[7],q[16];
cx q[11],q[7];
cp(-pi/4) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[11],q[12];
cx q[11],q[7];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(0.0) q[11],q[13];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[11],q[14];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(pi/2) q[11],q[15];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/2) q[7],q[15];
cx q[11],q[7];
cp(pi/4) q[11],q[16];
cp(pi/2) q[7],q[15];
cx q[11],q[7];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/4) q[7],q[16];
cx q[11],q[7];
cp(pi/4) q[7],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[11],q[12];
cx q[11],q[7];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[7],q[12];
cx q[11],q[7];
cp(0.0) q[11],q[13];
cp(0.0) q[7],q[12];
cp(0.0) q[10],q[12];
cx q[11],q[7];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[11],q[14];
cp(0.0) q[7],q[13];
cx q[11],q[7];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(-pi/2) q[11],q[15];
cp(0.0) q[7],q[14];
cx q[11],q[7];
cp(pi/2) q[7],q[15];
cx q[11],q[7];
cp(-pi/4) q[11],q[16];
cp(-pi/2) q[7],q[15];
cx q[11],q[7];
cp(pi/4) q[7],q[16];
cx q[11],q[7];
cp(-pi/4) q[7],q[16];
cx q[10],q[7];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[10],q[13];
cp(0.0) q[7],q[12];
cx q[10],q[7];
h q[12];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-pi/2) q[10],q[14];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/2) q[7],q[14];
cx q[10],q[7];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[7],q[14];
cx q[10],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/4) q[7],q[15];
cx q[10],q[7];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[7],q[15];
cx q[10],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/8) q[7],q[16];
cx q[10],q[7];
cp(-pi/8) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[10],q[12];
cx q[10],q[7];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[10],q[13];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(-pi) q[17],q[12];
h q[12];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(pi/2) q[10],q[14];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/2) q[7],q[14];
cx q[10],q[7];
cp(pi/4) q[10],q[15];
cp(pi/2) q[7],q[14];
cx q[10],q[7];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/4) q[7],q[15];
cx q[10],q[7];
cp(pi/8) q[10],q[16];
cp(pi/4) q[7],q[15];
cx q[10],q[7];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/8) q[7],q[16];
cx q[10],q[7];
cp(pi/8) q[7],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[10],q[12];
cx q[10],q[7];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[7],q[12];
cx q[10],q[7];
cp(0.0) q[10],q[13];
cp(0.0) q[7],q[12];
cp(0.0) q[9],q[12];
cx q[10],q[7];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(-pi/2) q[10],q[14];
cp(0.0) q[7],q[13];
cx q[10],q[7];
cp(pi/2) q[7],q[14];
cx q[10],q[7];
cp(-pi/4) q[10],q[15];
cp(-pi/2) q[7],q[14];
cx q[10],q[7];
cp(pi/4) q[7],q[15];
cx q[10],q[7];
cp(-pi/8) q[10],q[16];
cp(-pi/4) q[7],q[15];
cx q[10],q[7];
cp(pi/8) q[7],q[16];
cx q[10],q[7];
cp(-pi/8) q[7],q[16];
cx q[9],q[7];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(-pi/2) q[9],q[13];
cp(0.0) q[7],q[12];
cx q[9],q[7];
h q[12];
cp(pi/2) q[7],q[13];
cx q[9],q[7];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[7],q[13];
cx q[9],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/4) q[7],q[14];
cx q[9],q[7];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[7],q[14];
cx q[9],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/8) q[7],q[15];
cx q[9],q[7];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[7],q[15];
cx q[9],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/16) q[7],q[16];
cx q[9],q[7];
cp(-pi/16) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0.0) q[9],q[12];
cx q[9],q[7];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(pi/2) q[9],q[13];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/2) q[7],q[13];
cx q[9],q[7];
cp(pi/4) q[9],q[14];
cp(pi/2) q[7],q[13];
cx q[9],q[7];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/4) q[7],q[14];
cx q[9],q[7];
cp(pi/8) q[9],q[15];
cp(pi/4) q[7],q[14];
cx q[9],q[7];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/8) q[7],q[15];
cx q[9],q[7];
cp(pi/16) q[9],q[16];
cp(pi/8) q[7],q[15];
cx q[9],q[7];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/16) q[7],q[16];
cx q[9],q[7];
cp(pi/16) q[7],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(0.0) q[9],q[12];
cx q[9],q[7];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(0.0) q[7],q[12];
cx q[9],q[7];
cp(-pi/2) q[9],q[13];
cp(0.0) q[7],q[12];
cp(-pi/2) q[8],q[12];
cx q[9],q[7];
cp(pi/2) q[7],q[13];
cx q[9],q[7];
cp(-pi/4) q[9],q[14];
cp(-pi/2) q[7],q[13];
cx q[9],q[7];
cp(pi/4) q[7],q[14];
cx q[9],q[7];
cp(-pi/8) q[9],q[15];
cp(-pi/4) q[7],q[14];
cx q[9],q[7];
cp(pi/8) q[7],q[15];
cx q[9],q[7];
cp(-pi/16) q[9],q[16];
cp(-pi/8) q[7],q[15];
cx q[9],q[7];
cp(pi/16) q[7],q[16];
cx q[9],q[7];
cp(-pi/16) q[7],q[16];
cx q[8],q[7];
cp(pi/2) q[7],q[12];
cx q[8],q[7];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[7],q[12];
cx q[8],q[7];
h q[12];
cp(pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[7],q[16];
cx q[8],q[7];
cp(-pi/32) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
u2(0,0) q[16];
cx q[16],q[17];
u2(-pi,-pi) q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(pi/2) q[8],q[12];
cx q[8],q[7];
cp(-pi/2) q[7],q[12];
cx q[8],q[7];
cp(pi/4) q[8],q[13];
cp(pi/2) q[7],q[12];
cx q[8],q[7];
cp(-pi) q[17],q[12];
h q[12];
cp(-pi/4) q[7],q[13];
cx q[8],q[7];
cp(pi/8) q[8],q[14];
cp(pi/4) q[7],q[13];
cx q[8],q[7];
cp(-3*pi/2) q[17],q[13];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/8) q[7],q[14];
cx q[8],q[7];
cp(pi/16) q[8],q[15];
cp(pi/8) q[7],q[14];
cx q[8],q[7];
cp(-7*pi/4) q[17],q[14];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/16) q[7],q[15];
cx q[8],q[7];
cp(pi/32) q[8],q[16];
cp(pi/16) q[7],q[15];
cx q[8],q[7];
cp(-15*pi/8) q[17],q[15];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/32) q[7],q[16];
cx q[8],q[7];
cp(pi/32) q[7],q[16];
cp(-15*pi/16) q[17],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cx q[16],q[17];
h q[16];
cp(pi/2) q[16],q[15];
h q[15];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
u2(-pi,-pi) q[12];
cp(-pi/2) q[8],q[12];
cx q[8],q[7];
p(3*pi/2) q[13];
p(7*pi/4) q[14];
p(15*pi/8) q[15];
p(15*pi/16) q[16];
cp(pi/2) q[7],q[12];
cx q[8],q[7];
cp(-pi/4) q[8],q[13];
cp(-pi/2) q[7],q[12];
cx q[8],q[7];
h q[12];
cp(pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/8) q[8],q[14];
cp(-pi/4) q[7],q[13];
cx q[8],q[7];
cp(-pi/2) q[13],q[12];
h q[13];
cp(pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/16) q[8],q[15];
cp(-pi/8) q[7],q[14];
cx q[8],q[7];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/32) q[8],q[16];
cp(-pi/16) q[7],q[15];
cx q[8],q[7];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(pi/32) q[7],q[16];
cx q[8],q[7];
cp(-pi/32) q[7],q[16];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
swap q[0],q[7];
h q[0];
cp(-pi/2) q[1],q[0];
h q[1];
cp(-pi/4) q[2],q[0];
cp(-pi/2) q[2],q[1];
h q[2];
cp(-pi/8) q[3],q[0];
cp(-pi/4) q[3],q[1];
cp(-pi/2) q[3],q[2];
h q[3];
cp(-pi/16) q[4],q[0];
cp(-pi/8) q[4],q[1];
cp(-pi/4) q[4],q[2];
cp(-pi/2) q[4],q[3];
h q[4];
cp(-pi/32) q[5],q[0];
cp(-pi/16) q[5],q[1];
cp(-pi/8) q[5],q[2];
cp(-pi/4) q[5],q[3];
cp(-pi/2) q[5],q[4];
h q[5];
cp(-pi/64) q[6],q[0];
cp(-pi/32) q[6],q[1];
cp(-pi/16) q[6],q[2];
cp(-pi/8) q[6],q[3];
cp(-pi/4) q[6],q[4];
cp(-pi/2) q[6],q[5];
h q[6];
cp(-pi/128) q[7],q[0];
cp(-pi/64) q[7],q[1];
cp(-pi/32) q[7],q[2];
cp(-pi/16) q[7],q[3];
cp(-pi/8) q[7],q[4];
cp(-pi/4) q[7],q[5];
cp(-pi/2) q[7],q[6];
h q[7];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];

'''

benchmarks['ising-66'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q[66];
creg c[66];
creg meas[66];
h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
h q[8];
h q[9];
h q[10];
h q[11];
h q[12];
h q[13];
h q[14];
h q[15];
h q[16];
h q[17];
h q[18];
h q[19];
h q[20];
h q[21];
h q[22];
h q[23];
h q[24];
h q[25];
h q[26];
h q[27];
h q[28];
h q[29];
h q[30];
h q[31];
h q[32];
h q[33];
h q[34];
h q[35];
h q[36];
h q[37];
h q[38];
h q[39];
h q[40];
h q[41];
h q[42];
h q[43];
h q[44];
h q[45];
h q[46];
h q[47];
h q[48];
h q[49];
h q[50];
h q[51];
h q[52];
h q[53];
h q[54];
h q[55];
h q[56];
h q[57];
h q[58];
h q[59];
h q[60];
h q[61];
h q[62];
h q[63];
h q[64];
h q[65];
rz(1.6845551) q[0];
rz(-1.6845551) q[1];
rz(-1.6845551) q[1];
cx q[0],q[1];
rz(1.6845551) q[1];
cx q[0],q[1];
rz(-1.2572348) q[2];
rz(1.2572348) q[3];
rz(1.2572348) q[3];
cx q[2],q[3];
rz(-1.2572348) q[3];
cx q[2],q[3];
rz(1.2928823) q[4];
rz(-1.2928823) q[5];
rz(-1.2928823) q[5];
cx q[4],q[5];
rz(1.2928823) q[5];
cx q[4],q[5];
rz(-1.5703962) q[6];
rz(1.5703962) q[7];
rz(1.5703962) q[7];
cx q[6],q[7];
rz(-1.5703962) q[7];
cx q[6],q[7];
rz(-1.0388736) q[8];
rz(1.0388736) q[9];
rz(1.0388736) q[9];
cx q[8],q[9];
rz(-1.0388736) q[9];
cx q[8],q[9];
rz(1.3780137) q[10];
rz(-1.3780137) q[11];
rz(-1.3780137) q[11];
cx q[10],q[11];
rz(1.3780137) q[11];
cx q[10],q[11];
rz(-0.0070144794) q[12];
rz(0.0070144794) q[13];
rz(0.0070144794) q[13];
cx q[12],q[13];
rz(-0.0070144794) q[13];
cx q[12],q[13];
rz(-1.3439775) q[14];
rz(1.3439775) q[15];
rz(1.3439775) q[15];
cx q[14],q[15];
rz(-1.3439775) q[15];
cx q[14],q[15];
rz(1.7769919) q[16];
rz(-1.7769919) q[17];
rz(-1.7769919) q[17];
cx q[16],q[17];
rz(1.7769919) q[17];
cx q[16],q[17];
rz(-1.532035) q[18];
rz(1.532035) q[19];
rz(1.532035) q[19];
cx q[18],q[19];
rz(-1.532035) q[19];
cx q[18],q[19];
rz(-1.4790855) q[20];
rz(1.4790855) q[21];
rz(1.4790855) q[21];
cx q[20],q[21];
rz(-1.4790855) q[21];
cx q[20],q[21];
rz(1.6621023) q[22];
rz(-1.6621023) q[23];
rz(-1.6621023) q[23];
cx q[22],q[23];
rz(1.6621023) q[23];
cx q[22],q[23];
rz(-1.346359) q[24];
rz(1.346359) q[25];
rz(1.346359) q[25];
cx q[24],q[25];
rz(-1.346359) q[25];
cx q[24],q[25];
rz(1.2437046) q[26];
rz(-1.2437046) q[27];
rz(-1.2437046) q[27];
cx q[26],q[27];
rz(1.2437046) q[27];
cx q[26],q[27];
rz(-1.4035615) q[28];
rz(1.4035615) q[29];
rz(1.4035615) q[29];
cx q[28],q[29];
rz(-1.4035615) q[29];
cx q[28],q[29];
rz(-0.94399531) q[30];
rz(0.94399531) q[31];
rz(0.94399531) q[31];
cx q[30],q[31];
rz(-0.94399531) q[31];
cx q[30],q[31];
rz(-0.10547849) q[32];
rz(0.10547849) q[33];
rz(0.10547849) q[33];
cx q[32],q[33];
rz(-0.10547849) q[33];
cx q[32],q[33];
rz(-0.32112909) q[34];
rz(0.32112909) q[35];
rz(0.32112909) q[35];
cx q[34],q[35];
rz(-0.32112909) q[35];
cx q[34],q[35];
rz(1.2551978) q[36];
rz(-1.2551978) q[37];
rz(-1.2551978) q[37];
cx q[36],q[37];
rz(1.2551978) q[37];
cx q[36],q[37];
rz(0.83274755) q[38];
rz(-0.83274755) q[39];
rz(-0.83274755) q[39];
cx q[38],q[39];
rz(0.83274755) q[39];
cx q[38],q[39];
rz(-0.51687854) q[40];
rz(0.51687854) q[41];
rz(0.51687854) q[41];
cx q[40],q[41];
rz(-0.51687854) q[41];
cx q[40],q[41];
rz(-1.6689561) q[42];
rz(1.6689561) q[43];
rz(1.6689561) q[43];
cx q[42],q[43];
rz(-1.6689561) q[43];
cx q[42],q[43];
rz(-0.87783496) q[44];
rz(0.87783496) q[45];
rz(0.87783496) q[45];
cx q[44],q[45];
rz(-0.87783496) q[45];
cx q[44],q[45];
rz(1.7917125) q[46];
rz(-1.7917125) q[47];
rz(-1.7917125) q[47];
cx q[46],q[47];
rz(1.7917125) q[47];
cx q[46],q[47];
rz(0.85318811) q[48];
rz(-0.85318811) q[49];
rz(-0.85318811) q[49];
cx q[48],q[49];
rz(0.85318811) q[49];
cx q[48],q[49];
rz(1.1007048) q[50];
rz(-1.1007048) q[51];
rz(-1.1007048) q[51];
cx q[50],q[51];
rz(1.1007048) q[51];
cx q[50],q[51];
rz(1.2374139) q[52];
rz(-1.2374139) q[53];
rz(-1.2374139) q[53];
cx q[52],q[53];
rz(1.2374139) q[53];
cx q[52],q[53];
rz(0.86900691) q[54];
rz(-0.86900691) q[55];
rz(-0.86900691) q[55];
cx q[54],q[55];
rz(0.86900691) q[55];
cx q[54],q[55];
rz(-0.075544295) q[56];
rz(0.075544295) q[57];
rz(0.075544295) q[57];
cx q[56],q[57];
rz(-0.075544295) q[57];
cx q[56],q[57];
rz(1.9666965) q[58];
rz(-1.9666965) q[59];
rz(-1.9666965) q[59];
cx q[58],q[59];
rz(1.9666965) q[59];
cx q[58],q[59];
rz(-0.8932567) q[60];
rz(0.8932567) q[61];
rz(0.8932567) q[61];
cx q[60],q[61];
rz(-0.8932567) q[61];
cx q[60],q[61];
rz(1.0753497) q[62];
rz(-1.0753497) q[63];
rz(-1.0753497) q[63];
cx q[62],q[63];
rz(1.0753497) q[63];
cx q[62],q[63];
rz(-0.23544851) q[64];
rz(0.23544851) q[65];
rz(0.23544851) q[65];
cx q[64],q[65];
rz(-0.23544851) q[65];
cx q[64],q[65];
rz(-0.27302102) q[1];
rz(0.27302102) q[2];
rz(0.27302102) q[2];
cx q[1],q[2];
rz(-0.27302102) q[2];
cx q[1],q[2];
rz(0.93575124) q[3];
rz(-0.93575124) q[4];
rz(-0.93575124) q[4];
cx q[3],q[4];
rz(0.93575124) q[4];
cx q[3],q[4];
rz(-0.79244696) q[5];
rz(0.79244696) q[6];
rz(0.79244696) q[6];
cx q[5],q[6];
rz(-0.79244696) q[6];
cx q[5],q[6];
rz(-0.45987014) q[7];
rz(0.45987014) q[8];
rz(0.45987014) q[8];
cx q[7],q[8];
rz(-0.45987014) q[8];
cx q[7],q[8];
rz(-0.66887293) q[9];
rz(0.66887293) q[10];
rz(0.66887293) q[10];
cx q[9],q[10];
rz(-0.66887293) q[10];
cx q[9],q[10];
rz(0.26174741) q[11];
rz(-0.26174741) q[12];
rz(-0.26174741) q[12];
cx q[11],q[12];
rz(0.26174741) q[12];
cx q[11],q[12];
rz(-0.95258407) q[13];
rz(0.95258407) q[14];
rz(0.95258407) q[14];
cx q[13],q[14];
rz(-0.95258407) q[14];
cx q[13],q[14];
rz(0.90853417) q[15];
rz(-0.90853417) q[16];
rz(-0.90853417) q[16];
cx q[15],q[16];
rz(0.90853417) q[16];
cx q[15],q[16];
rz(-1.998859) q[17];
rz(1.998859) q[18];
rz(1.998859) q[18];
cx q[17],q[18];
rz(-1.998859) q[18];
cx q[17],q[18];
rz(1.7129122) q[19];
rz(-1.7129122) q[20];
rz(-1.7129122) q[20];
cx q[19],q[20];
rz(1.7129122) q[20];
cx q[19],q[20];
rz(1.713981) q[21];
rz(-1.713981) q[22];
rz(-1.713981) q[22];
cx q[21],q[22];
rz(1.713981) q[22];
cx q[21],q[22];
rz(1.9973678) q[23];
rz(-1.9973678) q[24];
rz(-1.9973678) q[24];
cx q[23],q[24];
rz(1.9973678) q[24];
cx q[23],q[24];
rz(1.2910342) q[25];
rz(-1.2910342) q[26];
rz(-1.2910342) q[26];
cx q[25],q[26];
rz(1.2910342) q[26];
cx q[25],q[26];
rz(1.4634312) q[27];
rz(-1.4634312) q[28];
rz(-1.4634312) q[28];
cx q[27],q[28];
rz(1.4634312) q[28];
cx q[27],q[28];
rz(0.65619548) q[29];
rz(-0.65619548) q[30];
rz(-0.65619548) q[30];
cx q[29],q[30];
rz(0.65619548) q[30];
cx q[29],q[30];
rz(1.1369534) q[31];
rz(-1.1369534) q[32];
rz(-1.1369534) q[32];
cx q[31],q[32];
rz(1.1369534) q[32];
cx q[31],q[32];
rz(-0.3166508) q[33];
rz(0.3166508) q[34];
rz(0.3166508) q[34];
cx q[33],q[34];
rz(-0.3166508) q[34];
cx q[33],q[34];
rz(1.6679692) q[35];
rz(-1.6679692) q[36];
rz(-1.6679692) q[36];
cx q[35],q[36];
rz(1.6679692) q[36];
cx q[35],q[36];
rz(0.94889695) q[37];
rz(-0.94889695) q[38];
rz(-0.94889695) q[38];
cx q[37],q[38];
rz(0.94889695) q[38];
cx q[37],q[38];
rz(1.3389506) q[39];
rz(-1.3389506) q[40];
rz(-1.3389506) q[40];
cx q[39],q[40];
rz(1.3389506) q[40];
cx q[39],q[40];
rz(0.42250814) q[41];
rz(-0.42250814) q[42];
rz(-0.42250814) q[42];
cx q[41],q[42];
rz(0.42250814) q[42];
cx q[41],q[42];
rz(-0.16700096) q[43];
rz(0.16700096) q[44];
rz(0.16700096) q[44];
cx q[43],q[44];
rz(-0.16700096) q[44];
cx q[43],q[44];
rz(1.3028807) q[45];
rz(-1.3028807) q[46];
rz(-1.3028807) q[46];
cx q[45],q[46];
rz(1.3028807) q[46];
cx q[45],q[46];
rz(-1.8720307) q[47];
rz(1.8720307) q[48];
rz(1.8720307) q[48];
cx q[47],q[48];
rz(-1.8720307) q[48];
cx q[47],q[48];
rz(-1.1861875) q[49];
rz(1.1861875) q[50];
rz(1.1861875) q[50];
cx q[49],q[50];
rz(-1.1861875) q[50];
cx q[49],q[50];
rz(-0.11663793) q[51];
rz(0.11663793) q[52];
rz(0.11663793) q[52];
cx q[51],q[52];
rz(-0.11663793) q[52];
cx q[51],q[52];
rz(1.7434165) q[53];
rz(-1.7434165) q[54];
rz(-1.7434165) q[54];
cx q[53],q[54];
rz(1.7434165) q[54];
cx q[53],q[54];
rz(1.9586679) q[55];
rz(-1.9586679) q[56];
rz(-1.9586679) q[56];
cx q[55],q[56];
rz(1.9586679) q[56];
cx q[55],q[56];
rz(-0.91863643) q[57];
rz(0.91863643) q[58];
rz(0.91863643) q[58];
cx q[57],q[58];
rz(-0.91863643) q[58];
cx q[57],q[58];
rz(-1.378703) q[59];
rz(1.378703) q[60];
rz(1.378703) q[60];
cx q[59],q[60];
rz(-1.378703) q[60];
cx q[59],q[60];
rz(1.2285706) q[61];
rz(-1.2285706) q[62];
rz(-1.2285706) q[62];
cx q[61],q[62];
rz(1.2285706) q[62];
cx q[61],q[62];
rz(0.28670827) q[63];
rz(-0.28670827) q[64];
rz(-0.28670827) q[64];
cx q[63],q[64];
rz(0.28670827) q[64];
cx q[63],q[64];
h q[0];
rz(0) q[0];
h q[0];
rz(0) q[0];
h q[1];
rz(0) q[1];
h q[1];
rz(0) q[1];
h q[2];
rz(0) q[2];
h q[2];
rz(0) q[2];
h q[3];
rz(0) q[3];
h q[3];
rz(0) q[3];
h q[4];
rz(0) q[4];
h q[4];
rz(0) q[4];
h q[5];
rz(0) q[5];
h q[5];
rz(0) q[5];
h q[6];
rz(0) q[6];
h q[6];
rz(0) q[6];
h q[7];
rz(0) q[7];
h q[7];
rz(0) q[7];
h q[8];
rz(0) q[8];
h q[8];
rz(0) q[8];
h q[9];
rz(0) q[9];
h q[9];
rz(0) q[9];
h q[10];
rz(0) q[10];
h q[10];
rz(0) q[10];
h q[11];
rz(0) q[11];
h q[11];
rz(0) q[11];
h q[12];
rz(0) q[12];
h q[12];
rz(0) q[12];
h q[13];
rz(0) q[13];
h q[13];
rz(0) q[13];
h q[14];
rz(0) q[14];
h q[14];
rz(0) q[14];
h q[15];
rz(0) q[15];
h q[15];
rz(0) q[15];
h q[16];
rz(0) q[16];
h q[16];
rz(0) q[16];
h q[17];
rz(0) q[17];
h q[17];
rz(0) q[17];
h q[18];
rz(0) q[18];
h q[18];
rz(0) q[18];
h q[19];
rz(0) q[19];
h q[19];
rz(0) q[19];
h q[20];
rz(0) q[20];
h q[20];
rz(0) q[20];
h q[21];
rz(0) q[21];
h q[21];
rz(0) q[21];
h q[22];
rz(0) q[22];
h q[22];
rz(0) q[22];
h q[23];
rz(0) q[23];
h q[23];
rz(0) q[23];
h q[24];
rz(0) q[24];
h q[24];
rz(0) q[24];
h q[25];
rz(0) q[25];
h q[25];
rz(0) q[25];
h q[26];
rz(0) q[26];
h q[26];
rz(0) q[26];
h q[27];
rz(0) q[27];
h q[27];
rz(0) q[27];
h q[28];
rz(0) q[28];
h q[28];
rz(0) q[28];
h q[29];
rz(0) q[29];
h q[29];
rz(0) q[29];
h q[30];
rz(0) q[30];
h q[30];
rz(0) q[30];
h q[31];
rz(0) q[31];
h q[31];
rz(0) q[31];
h q[32];
rz(0) q[32];
h q[32];
rz(0) q[32];
h q[33];
rz(0) q[33];
h q[33];
rz(0) q[33];
h q[34];
rz(0) q[34];
h q[34];
rz(0) q[34];
h q[35];
rz(0) q[35];
h q[35];
rz(0) q[35];
h q[36];
rz(0) q[36];
h q[36];
rz(0) q[36];
h q[37];
rz(0) q[37];
h q[37];
rz(0) q[37];
h q[38];
rz(0) q[38];
h q[38];
rz(0) q[38];
h q[39];
rz(0) q[39];
h q[39];
rz(0) q[39];
h q[40];
rz(0) q[40];
h q[40];
rz(0) q[40];
h q[41];
rz(0) q[41];
h q[41];
rz(0) q[41];
h q[42];
rz(0) q[42];
h q[42];
rz(0) q[42];
h q[43];
rz(0) q[43];
h q[43];
rz(0) q[43];
h q[44];
rz(0) q[44];
h q[44];
rz(0) q[44];
h q[45];
rz(0) q[45];
h q[45];
rz(0) q[45];
h q[46];
rz(0) q[46];
h q[46];
rz(0) q[46];
h q[47];
rz(0) q[47];
h q[47];
rz(0) q[47];
h q[48];
rz(0) q[48];
h q[48];
rz(0) q[48];
h q[49];
rz(0) q[49];
h q[49];
rz(0) q[49];
h q[50];
rz(0) q[50];
h q[50];
rz(0) q[50];
h q[51];
rz(0) q[51];
h q[51];
rz(0) q[51];
h q[52];
rz(0) q[52];
h q[52];
rz(0) q[52];
h q[53];
rz(0) q[53];
h q[53];
rz(0) q[53];
h q[54];
rz(0) q[54];
h q[54];
rz(0) q[54];
h q[55];
rz(0) q[55];
h q[55];
rz(0) q[55];
h q[56];
rz(0) q[56];
h q[56];
rz(0) q[56];
h q[57];
rz(0) q[57];
h q[57];
rz(0) q[57];
h q[58];
rz(0) q[58];
h q[58];
rz(0) q[58];
h q[59];
rz(0) q[59];
h q[59];
rz(0) q[59];
h q[60];
rz(0) q[60];
h q[60];
rz(0) q[60];
h q[61];
rz(0) q[61];
h q[61];
rz(0) q[61];
h q[62];
rz(0) q[62];
h q[62];
rz(0) q[62];
h q[63];
rz(0) q[63];
h q[63];
rz(0) q[63];
h q[64];
rz(0) q[64];
h q[64];
rz(0) q[64];
h q[65];
rz(0) q[65];
h q[65];
rz(0) q[65];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];

'''

benchmarks['wstate-60'] = '''
// Benchmark was created by MQT Bench on 2023-06-29
// For more information about MQT Bench, please visit https://www.cda.cit.tum.de/mqtbench/
// MQT Bench version: v1.0.0
// Qiskit version: {'qiskit-terra': '0.24.1', 'qiskit-aer': '0.12.0', 'qiskit-ignis': None, 'qiskit-ibmq-provider': '0.20.2', 'qiskit': '0.43.1', 'qiskit-nature': '0.6.2', 'qiskit-finance': '0.3.4', 'qiskit-optimization': '0.5.0', 'qiskit-machine-learning': '0.6.1'}

OPENQASM 2.0;
include "qelib1.inc";
qreg q[60];
creg meas[60];
ry(-pi/4) q[0];
ry(-0.9553166181245093) q[1];
ry(-pi/3) q[2];
ry(-1.1071487177940904) q[3];
ry(-1.1502619915109316) q[4];
ry(-1.183199640139716) q[5];
ry(-1.2094292028881888) q[6];
ry(-1.2309594173407747) q[7];
ry(-1.2490457723982544) q[8];
ry(-1.2645189576252271) q[9];
ry(-1.277953555066321) q[10];
ry(-1.2897614252920828) q[11];
ry(-1.3002465638163236) q[12];
ry(-1.3096389158918722) q[13];
ry(-1.318116071652818) q[14];
ry(-1.3258176636680323) q[15];
ry(-1.3328552019646882) q[16];
ry(-1.3393189628247182) q[17];
ry(-1.3452829208967654) q[18];
ry(-1.3508083493994372) q[19];
ry(-1.3559464937191843) q[20];
ry(-1.3607405877236576) q[21];
ry(-1.3652273956337226) q[22];
ry(-1.3694384060045657) q[23];
ry(-1.3734007669450157) q[24];
ry(-1.37713802635057) q[25];
ry(-1.38067072344843) q[26];
ry(-1.384016865713303) q[27];
ry(-1.387192316515978) q[28];
ry(-1.3902111126041985) q[29];
ry(-1.3930857259497849) q[30];
ry(-1.3958272811292076) q[31];
ry(-1.3984457368955736) q[32];
ry(-1.400950038711223) q[33];
ry(-1.4033482475752073) q[34];
ry(-1.4056476493802696) q[35];
ry(-1.4078548481843771) q[36];
ry(-1.409975846120432) q[37];
ry(-1.412016112149136) q[38];
ry(-1.4139806414504958) q[39];
ry(-1.4158740069240832) q[40];
ry(-1.417700404008042) q[41];
ry(-1.419463689817681) q[42];
ry(-1.4211674174353792) q[43];
ry(-1.4228148660461128) q[44];
ry(-1.4244090675006476) q[45];
ry(-1.4259528297963369) q[46];
ry(-1.4274487578895312) q[47];
ry(-1.4288992721907325) q[48];
ry(-1.4303066250413763) q[49];
ry(-1.431672915427498) q[50];
ry(-1.4330001021490115) q[51];
ry(-1.4342900156325915) q[52];
ry(-1.435544368550241) q[53];
ry(-1.4367647653836775) q[54];
ry(-1.4379527110560313) q[55];
ry(-1.4391096187364805) q[56];
ry(-1.4402368169098754) q[57];
ry(-1.441335555791786) q[58];
x q[59];
cz q[59],q[58];
ry(1.441335555791786) q[58];
cz q[58],q[57];
ry(1.4402368169098754) q[57];
cz q[57],q[56];
ry(1.4391096187364805) q[56];
cz q[56],q[55];
ry(1.4379527110560313) q[55];
cz q[55],q[54];
ry(1.4367647653836775) q[54];
cz q[54],q[53];
ry(1.435544368550241) q[53];
cz q[53],q[52];
ry(1.4342900156325915) q[52];
cz q[52],q[51];
ry(1.4330001021490115) q[51];
cz q[51],q[50];
ry(1.431672915427498) q[50];
cz q[50],q[49];
ry(1.4303066250413763) q[49];
cz q[49],q[48];
ry(1.4288992721907325) q[48];
cz q[48],q[47];
ry(1.4274487578895312) q[47];
cz q[47],q[46];
ry(1.4259528297963369) q[46];
cz q[46],q[45];
ry(1.4244090675006476) q[45];
cz q[45],q[44];
ry(1.4228148660461128) q[44];
cz q[44],q[43];
ry(1.4211674174353792) q[43];
cz q[43],q[42];
ry(1.419463689817681) q[42];
cz q[42],q[41];
ry(1.417700404008042) q[41];
cz q[41],q[40];
ry(1.4158740069240832) q[40];
cz q[40],q[39];
ry(1.4139806414504958) q[39];
cz q[39],q[38];
ry(1.412016112149136) q[38];
cz q[38],q[37];
ry(1.409975846120432) q[37];
cz q[37],q[36];
ry(1.4078548481843771) q[36];
cz q[36],q[35];
ry(1.4056476493802696) q[35];
cz q[35],q[34];
ry(1.4033482475752073) q[34];
cz q[34],q[33];
ry(1.400950038711223) q[33];
cz q[33],q[32];
ry(1.3984457368955736) q[32];
cz q[32],q[31];
ry(1.3958272811292076) q[31];
cz q[31],q[30];
ry(1.3930857259497849) q[30];
cz q[30],q[29];
ry(1.3902111126041985) q[29];
cz q[29],q[28];
ry(1.387192316515978) q[28];
cz q[28],q[27];
ry(1.384016865713303) q[27];
cz q[27],q[26];
ry(1.38067072344843) q[26];
cz q[26],q[25];
ry(1.37713802635057) q[25];
cz q[25],q[24];
ry(1.3734007669450157) q[24];
cz q[24],q[23];
ry(1.3694384060045657) q[23];
cz q[23],q[22];
ry(1.3652273956337226) q[22];
cz q[22],q[21];
ry(1.3607405877236576) q[21];
cz q[21],q[20];
ry(1.3559464937191843) q[20];
cz q[20],q[19];
ry(1.3508083493994372) q[19];
cz q[19],q[18];
ry(1.3452829208967654) q[18];
cz q[18],q[17];
ry(1.3393189628247182) q[17];
cz q[17],q[16];
ry(1.3328552019646882) q[16];
cz q[16],q[15];
ry(1.3258176636680323) q[15];
cz q[15],q[14];
ry(1.318116071652818) q[14];
cz q[14],q[13];
ry(1.3096389158918722) q[13];
cz q[13],q[12];
ry(1.3002465638163236) q[12];
cz q[12],q[11];
ry(1.2897614252920828) q[11];
cz q[11],q[10];
ry(1.277953555066321) q[10];
cz q[10],q[9];
cx q[58],q[59];
cx q[57],q[58];
cx q[56],q[57];
cx q[55],q[56];
cx q[54],q[55];
cx q[53],q[54];
cx q[52],q[53];
cx q[51],q[52];
cx q[50],q[51];
cx q[49],q[50];
cx q[48],q[49];
cx q[47],q[48];
cx q[46],q[47];
cx q[45],q[46];
cx q[44],q[45];
cx q[43],q[44];
cx q[42],q[43];
cx q[41],q[42];
cx q[40],q[41];
cx q[39],q[40];
cx q[38],q[39];
cx q[37],q[38];
cx q[36],q[37];
cx q[35],q[36];
cx q[34],q[35];
cx q[33],q[34];
cx q[32],q[33];
cx q[31],q[32];
cx q[30],q[31];
cx q[29],q[30];
cx q[28],q[29];
cx q[27],q[28];
cx q[26],q[27];
cx q[25],q[26];
cx q[24],q[25];
cx q[23],q[24];
cx q[22],q[23];
cx q[21],q[22];
cx q[20],q[21];
cx q[19],q[20];
cx q[18],q[19];
cx q[17],q[18];
cx q[16],q[17];
cx q[15],q[16];
cx q[14],q[15];
cx q[13],q[14];
cx q[12],q[13];
cx q[11],q[12];
cx q[10],q[11];
ry(1.2645189576252271) q[9];
cz q[9],q[8];
ry(1.2490457723982544) q[8];
cz q[8],q[7];
ry(1.2309594173407747) q[7];
cz q[7],q[6];
ry(1.2094292028881888) q[6];
cz q[6],q[5];
ry(1.183199640139716) q[5];
cz q[5],q[4];
ry(1.1502619915109316) q[4];
cz q[4],q[3];
ry(1.1071487177940904) q[3];
cz q[3],q[2];
ry(pi/3) q[2];
cz q[2],q[1];
ry(0.9553166181245093) q[1];
cz q[1],q[0];
ry(pi/4) q[0];
cx q[9],q[10];
cx q[8],q[9];
cx q[7],q[8];
cx q[6],q[7];
cx q[5],q[6];
cx q[4],q[5];
cx q[3],q[4];
cx q[2],q[3];
cx q[1],q[2];
cx q[0],q[1];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];

'''

benchmarks['multiplier-45'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q0[45];
creg c0[9];
x q0[40];
x q0[37];
x q0[30];
x q0[29];
x q0[28];
ccx q0[36],q0[27],q0[1];
ccx q0[36],q0[28],q0[4];
ccx q0[36],q0[29],q0[7];
ccx q0[36],q0[30],q0[10];
ccx q0[36],q0[31],q0[13];
ccx q0[36],q0[32],q0[16];
ccx q0[36],q0[33],q0[19];
ccx q0[36],q0[34],q0[22];
ccx q0[36],q0[35],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[36],q0[27],q0[1];
ccx q0[36],q0[28],q0[4];
ccx q0[36],q0[29],q0[7];
ccx q0[36],q0[30],q0[10];
ccx q0[36],q0[31],q0[13];
ccx q0[36],q0[32],q0[16];
ccx q0[36],q0[33],q0[19];
ccx q0[36],q0[34],q0[22];
ccx q0[36],q0[35],q0[25];
ccx q0[37],q0[27],q0[4];
ccx q0[37],q0[28],q0[7];
ccx q0[37],q0[29],q0[10];
ccx q0[37],q0[30],q0[13];
ccx q0[37],q0[31],q0[16];
ccx q0[37],q0[32],q0[19];
ccx q0[37],q0[33],q0[22];
ccx q0[37],q0[34],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[37],q0[27],q0[4];
ccx q0[37],q0[28],q0[7];
ccx q0[37],q0[29],q0[10];
ccx q0[37],q0[30],q0[13];
ccx q0[37],q0[31],q0[16];
ccx q0[37],q0[32],q0[19];
ccx q0[37],q0[33],q0[22];
ccx q0[37],q0[34],q0[25];
ccx q0[38],q0[27],q0[7];
ccx q0[38],q0[28],q0[10];
ccx q0[38],q0[29],q0[13];
ccx q0[38],q0[30],q0[16];
ccx q0[38],q0[31],q0[19];
ccx q0[38],q0[32],q0[22];
ccx q0[38],q0[33],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[38],q0[27],q0[7];
ccx q0[38],q0[28],q0[10];
ccx q0[38],q0[29],q0[13];
ccx q0[38],q0[30],q0[16];
ccx q0[38],q0[31],q0[19];
ccx q0[38],q0[32],q0[22];
ccx q0[38],q0[33],q0[25];
ccx q0[39],q0[27],q0[10];
ccx q0[39],q0[28],q0[13];
ccx q0[39],q0[29],q0[16];
ccx q0[39],q0[30],q0[19];
ccx q0[39],q0[31],q0[22];
ccx q0[39],q0[32],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[39],q0[27],q0[10];
ccx q0[39],q0[28],q0[13];
ccx q0[39],q0[29],q0[16];
ccx q0[39],q0[30],q0[19];
ccx q0[39],q0[31],q0[22];
ccx q0[39],q0[32],q0[25];
ccx q0[40],q0[27],q0[13];
ccx q0[40],q0[28],q0[16];
ccx q0[40],q0[29],q0[19];
ccx q0[40],q0[30],q0[22];
ccx q0[40],q0[31],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[40],q0[27],q0[13];
ccx q0[40],q0[28],q0[16];
ccx q0[40],q0[29],q0[19];
ccx q0[40],q0[30],q0[22];
ccx q0[40],q0[31],q0[25];
ccx q0[41],q0[27],q0[16];
ccx q0[41],q0[28],q0[19];
ccx q0[41],q0[29],q0[22];
ccx q0[41],q0[30],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[41],q0[27],q0[16];
ccx q0[41],q0[28],q0[19];
ccx q0[41],q0[29],q0[22];
ccx q0[41],q0[30],q0[25];
ccx q0[42],q0[27],q0[19];
ccx q0[42],q0[28],q0[22];
ccx q0[42],q0[29],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[42],q0[27],q0[19];
ccx q0[42],q0[28],q0[22];
ccx q0[42],q0[29],q0[25];
ccx q0[43],q0[27],q0[22];
ccx q0[43],q0[28],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[43],q0[27],q0[22];
ccx q0[43],q0[28],q0[25];
ccx q0[44],q0[27],q0[25];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[44],q0[27],q0[25];
measure q0[2] -> c0[0];
measure q0[5] -> c0[1];
measure q0[8] -> c0[2];
measure q0[11] -> c0[3];
measure q0[14] -> c0[4];
measure q0[17] -> c0[5];
measure q0[20] -> c0[6];
measure q0[23] -> c0[7];
measure q0[26] -> c0[8];
'''

benchmarks['qft-160'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q[160];
creg c[160];
creg meas[160];
h q[0];
u1(pi/4) q[1];
cx q[1],q[0];
u1(-pi/4) q[0];
cx q[1],q[0];
u1(pi/4) q[0];
h q[1];
u1(pi/8) q[2];
cx q[2],q[0];
u1(-pi/8) q[0];
cx q[2],q[0];
u1(pi/8) q[0];
u1(pi/4) q[2];
cx q[2],q[1];
u1(-pi/4) q[1];
cx q[2],q[1];
u1(pi/4) q[1];
h q[2];
u1(pi/16) q[3];
cx q[3],q[0];
u1(-pi/16) q[0];
cx q[3],q[0];
u1(pi/16) q[0];
u1(pi/8) q[3];
cx q[3],q[1];
u1(-pi/8) q[1];
cx q[3],q[1];
u1(pi/8) q[1];
u1(pi/4) q[3];
cx q[3],q[2];
u1(-pi/4) q[2];
cx q[3],q[2];
u1(pi/4) q[2];
h q[3];
u1(pi/32) q[4];
cx q[4],q[0];
u1(-pi/32) q[0];
cx q[4],q[0];
u1(pi/32) q[0];
u1(pi/16) q[4];
cx q[4],q[1];
u1(-pi/16) q[1];
cx q[4],q[1];
u1(pi/16) q[1];
u1(pi/8) q[4];
cx q[4],q[2];
u1(-pi/8) q[2];
cx q[4],q[2];
u1(pi/8) q[2];
u1(pi/4) q[4];
cx q[4],q[3];
u1(-pi/4) q[3];
cx q[4],q[3];
u1(pi/4) q[3];
h q[4];
u1(pi/64) q[5];
cx q[5],q[0];
u1(-pi/64) q[0];
cx q[5],q[0];
u1(pi/64) q[0];
u1(pi/32) q[5];
cx q[5],q[1];
u1(-pi/32) q[1];
cx q[5],q[1];
u1(pi/32) q[1];
u1(pi/16) q[5];
cx q[5],q[2];
u1(-pi/16) q[2];
cx q[5],q[2];
u1(pi/16) q[2];
u1(pi/8) q[5];
cx q[5],q[3];
u1(-pi/8) q[3];
cx q[5],q[3];
u1(pi/8) q[3];
u1(pi/4) q[5];
cx q[5],q[4];
u1(-pi/4) q[4];
cx q[5],q[4];
u1(pi/4) q[4];
h q[5];
u1(pi/128) q[6];
cx q[6],q[0];
u1(-pi/128) q[0];
cx q[6],q[0];
u1(pi/128) q[0];
u1(pi/64) q[6];
cx q[6],q[1];
u1(-pi/64) q[1];
cx q[6],q[1];
u1(pi/64) q[1];
u1(pi/32) q[6];
cx q[6],q[2];
u1(-pi/32) q[2];
cx q[6],q[2];
u1(pi/32) q[2];
u1(pi/16) q[6];
cx q[6],q[3];
u1(-pi/16) q[3];
cx q[6],q[3];
u1(pi/16) q[3];
u1(pi/8) q[6];
cx q[6],q[4];
u1(-pi/8) q[4];
cx q[6],q[4];
u1(pi/8) q[4];
u1(pi/4) q[6];
cx q[6],q[5];
u1(-pi/4) q[5];
cx q[6],q[5];
u1(pi/4) q[5];
h q[6];
u1(pi/256) q[7];
cx q[7],q[0];
u1(-pi/256) q[0];
cx q[7],q[0];
u1(pi/256) q[0];
u1(pi/128) q[7];
cx q[7],q[1];
u1(-pi/128) q[1];
cx q[7],q[1];
u1(pi/128) q[1];
u1(pi/64) q[7];
cx q[7],q[2];
u1(-pi/64) q[2];
cx q[7],q[2];
u1(pi/64) q[2];
u1(pi/32) q[7];
cx q[7],q[3];
u1(-pi/32) q[3];
cx q[7],q[3];
u1(pi/32) q[3];
u1(pi/16) q[7];
cx q[7],q[4];
u1(-pi/16) q[4];
cx q[7],q[4];
u1(pi/16) q[4];
u1(pi/8) q[7];
cx q[7],q[5];
u1(-pi/8) q[5];
cx q[7],q[5];
u1(pi/8) q[5];
u1(pi/4) q[7];
cx q[7],q[6];
u1(-pi/4) q[6];
cx q[7],q[6];
u1(pi/4) q[6];
h q[7];
u1(pi/512) q[8];
cx q[8],q[0];
u1(-pi/512) q[0];
cx q[8],q[0];
u1(pi/512) q[0];
u1(pi/256) q[8];
cx q[8],q[1];
u1(-pi/256) q[1];
cx q[8],q[1];
u1(pi/256) q[1];
u1(pi/128) q[8];
cx q[8],q[2];
u1(-pi/128) q[2];
cx q[8],q[2];
u1(pi/128) q[2];
u1(pi/64) q[8];
cx q[8],q[3];
u1(-pi/64) q[3];
cx q[8],q[3];
u1(pi/64) q[3];
u1(pi/32) q[8];
cx q[8],q[4];
u1(-pi/32) q[4];
cx q[8],q[4];
u1(pi/32) q[4];
u1(pi/16) q[8];
cx q[8],q[5];
u1(-pi/16) q[5];
cx q[8],q[5];
u1(pi/16) q[5];
u1(pi/8) q[8];
cx q[8],q[6];
u1(-pi/8) q[6];
cx q[8],q[6];
u1(pi/8) q[6];
u1(pi/4) q[8];
cx q[8],q[7];
u1(-pi/4) q[7];
cx q[8],q[7];
u1(pi/4) q[7];
h q[8];
u1(pi/1024) q[9];
cx q[9],q[0];
u1(-pi/1024) q[0];
cx q[9],q[0];
u1(pi/1024) q[0];
u1(pi/512) q[9];
cx q[9],q[1];
u1(-pi/512) q[1];
cx q[9],q[1];
u1(pi/512) q[1];
u1(pi/256) q[9];
cx q[9],q[2];
u1(-pi/256) q[2];
cx q[9],q[2];
u1(pi/256) q[2];
u1(pi/128) q[9];
cx q[9],q[3];
u1(-pi/128) q[3];
cx q[9],q[3];
u1(pi/128) q[3];
u1(pi/64) q[9];
cx q[9],q[4];
u1(-pi/64) q[4];
cx q[9],q[4];
u1(pi/64) q[4];
u1(pi/32) q[9];
cx q[9],q[5];
u1(-pi/32) q[5];
cx q[9],q[5];
u1(pi/32) q[5];
u1(pi/16) q[9];
cx q[9],q[6];
u1(-pi/16) q[6];
cx q[9],q[6];
u1(pi/16) q[6];
u1(pi/8) q[9];
cx q[9],q[7];
u1(-pi/8) q[7];
cx q[9],q[7];
u1(pi/8) q[7];
u1(pi/4) q[9];
cx q[9],q[8];
u1(-pi/4) q[8];
cx q[9],q[8];
u1(pi/4) q[8];
h q[9];
u1(pi/2048) q[10];
cx q[10],q[0];
u1(-pi/2048) q[0];
cx q[10],q[0];
u1(pi/2048) q[0];
u1(pi/1024) q[10];
cx q[10],q[1];
u1(-pi/1024) q[1];
cx q[10],q[1];
u1(pi/1024) q[1];
u1(pi/512) q[10];
cx q[10],q[2];
u1(-pi/512) q[2];
cx q[10],q[2];
u1(pi/512) q[2];
u1(pi/256) q[10];
cx q[10],q[3];
u1(-pi/256) q[3];
cx q[10],q[3];
u1(pi/256) q[3];
u1(pi/128) q[10];
cx q[10],q[4];
u1(-pi/128) q[4];
cx q[10],q[4];
u1(pi/128) q[4];
u1(pi/64) q[10];
cx q[10],q[5];
u1(-pi/64) q[5];
cx q[10],q[5];
u1(pi/64) q[5];
u1(pi/32) q[10];
cx q[10],q[6];
u1(-pi/32) q[6];
cx q[10],q[6];
u1(pi/32) q[6];
u1(pi/16) q[10];
cx q[10],q[7];
u1(-pi/16) q[7];
cx q[10],q[7];
u1(pi/16) q[7];
u1(pi/8) q[10];
cx q[10],q[8];
u1(-pi/8) q[8];
cx q[10],q[8];
u1(pi/8) q[8];
u1(pi/4) q[10];
cx q[10],q[9];
u1(-pi/4) q[9];
cx q[10],q[9];
u1(pi/4) q[9];
h q[10];
u1(pi/4096) q[11];
cx q[11],q[0];
u1(-pi/4096) q[0];
cx q[11],q[0];
u1(pi/4096) q[0];
u1(pi/2048) q[11];
cx q[11],q[1];
u1(-pi/2048) q[1];
cx q[11],q[1];
u1(pi/2048) q[1];
u1(pi/1024) q[11];
cx q[11],q[2];
u1(-pi/1024) q[2];
cx q[11],q[2];
u1(pi/1024) q[2];
u1(pi/512) q[11];
cx q[11],q[3];
u1(-pi/512) q[3];
cx q[11],q[3];
u1(pi/512) q[3];
u1(pi/256) q[11];
cx q[11],q[4];
u1(-pi/256) q[4];
cx q[11],q[4];
u1(pi/256) q[4];
u1(pi/128) q[11];
cx q[11],q[5];
u1(-pi/128) q[5];
cx q[11],q[5];
u1(pi/128) q[5];
u1(pi/64) q[11];
cx q[11],q[6];
u1(-pi/64) q[6];
cx q[11],q[6];
u1(pi/64) q[6];
u1(pi/32) q[11];
cx q[11],q[7];
u1(-pi/32) q[7];
cx q[11],q[7];
u1(pi/32) q[7];
u1(pi/16) q[11];
cx q[11],q[8];
u1(-pi/16) q[8];
cx q[11],q[8];
u1(pi/16) q[8];
u1(pi/8) q[11];
cx q[11],q[9];
u1(-pi/8) q[9];
cx q[11],q[9];
u1(pi/8) q[9];
u1(pi/4) q[11];
cx q[11],q[10];
u1(-pi/4) q[10];
cx q[11],q[10];
u1(pi/4) q[10];
h q[11];
u1(pi/8192) q[12];
cx q[12],q[0];
u1(-pi/8192) q[0];
cx q[12],q[0];
u1(pi/8192) q[0];
u1(pi/4096) q[12];
cx q[12],q[1];
u1(-pi/4096) q[1];
cx q[12],q[1];
u1(pi/4096) q[1];
u1(pi/2048) q[12];
cx q[12],q[2];
u1(-pi/2048) q[2];
cx q[12],q[2];
u1(pi/2048) q[2];
u1(pi/1024) q[12];
cx q[12],q[3];
u1(-pi/1024) q[3];
cx q[12],q[3];
u1(pi/1024) q[3];
u1(pi/512) q[12];
cx q[12],q[4];
u1(-pi/512) q[4];
cx q[12],q[4];
u1(pi/512) q[4];
u1(pi/256) q[12];
cx q[12],q[5];
u1(-pi/256) q[5];
cx q[12],q[5];
u1(pi/256) q[5];
u1(pi/128) q[12];
cx q[12],q[6];
u1(-pi/128) q[6];
cx q[12],q[6];
u1(pi/128) q[6];
u1(pi/64) q[12];
cx q[12],q[7];
u1(-pi/64) q[7];
cx q[12],q[7];
u1(pi/64) q[7];
u1(pi/32) q[12];
cx q[12],q[8];
u1(-pi/32) q[8];
cx q[12],q[8];
u1(pi/32) q[8];
u1(pi/16) q[12];
cx q[12],q[9];
u1(-pi/16) q[9];
cx q[12],q[9];
u1(pi/16) q[9];
u1(pi/8) q[12];
cx q[12],q[10];
u1(-pi/8) q[10];
cx q[12],q[10];
u1(pi/8) q[10];
u1(pi/4) q[12];
cx q[12],q[11];
u1(-pi/4) q[11];
cx q[12],q[11];
u1(pi/4) q[11];
h q[12];
u1(pi/16384) q[13];
cx q[13],q[0];
u1(-pi/16384) q[0];
cx q[13],q[0];
u1(pi/16384) q[0];
u1(pi/8192) q[13];
cx q[13],q[1];
u1(-pi/8192) q[1];
cx q[13],q[1];
u1(pi/8192) q[1];
u1(pi/4096) q[13];
cx q[13],q[2];
u1(-pi/4096) q[2];
cx q[13],q[2];
u1(pi/4096) q[2];
u1(pi/2048) q[13];
cx q[13],q[3];
u1(-pi/2048) q[3];
cx q[13],q[3];
u1(pi/2048) q[3];
u1(pi/1024) q[13];
cx q[13],q[4];
u1(-pi/1024) q[4];
cx q[13],q[4];
u1(pi/1024) q[4];
u1(pi/512) q[13];
cx q[13],q[5];
u1(-pi/512) q[5];
cx q[13],q[5];
u1(pi/512) q[5];
u1(pi/256) q[13];
cx q[13],q[6];
u1(-pi/256) q[6];
cx q[13],q[6];
u1(pi/256) q[6];
u1(pi/128) q[13];
cx q[13],q[7];
u1(-pi/128) q[7];
cx q[13],q[7];
u1(pi/128) q[7];
u1(pi/64) q[13];
cx q[13],q[8];
u1(-pi/64) q[8];
cx q[13],q[8];
u1(pi/64) q[8];
u1(pi/32) q[13];
cx q[13],q[9];
u1(-pi/32) q[9];
cx q[13],q[9];
u1(pi/32) q[9];
u1(pi/16) q[13];
cx q[13],q[10];
u1(-pi/16) q[10];
cx q[13],q[10];
u1(pi/16) q[10];
u1(pi/8) q[13];
cx q[13],q[11];
u1(-pi/8) q[11];
cx q[13],q[11];
u1(pi/8) q[11];
u1(pi/4) q[13];
cx q[13],q[12];
u1(-pi/4) q[12];
cx q[13],q[12];
u1(pi/4) q[12];
h q[13];
u1(pi/32768) q[14];
cx q[14],q[0];
u1(-pi/32768) q[0];
cx q[14],q[0];
u1(pi/32768) q[0];
u1(pi/16384) q[14];
cx q[14],q[1];
u1(-pi/16384) q[1];
cx q[14],q[1];
u1(pi/16384) q[1];
u1(pi/8192) q[14];
cx q[14],q[2];
u1(-pi/8192) q[2];
cx q[14],q[2];
u1(pi/8192) q[2];
u1(pi/4096) q[14];
cx q[14],q[3];
u1(-pi/4096) q[3];
cx q[14],q[3];
u1(pi/4096) q[3];
u1(pi/2048) q[14];
cx q[14],q[4];
u1(-pi/2048) q[4];
cx q[14],q[4];
u1(pi/2048) q[4];
u1(pi/1024) q[14];
cx q[14],q[5];
u1(-pi/1024) q[5];
cx q[14],q[5];
u1(pi/1024) q[5];
u1(pi/512) q[14];
cx q[14],q[6];
u1(-pi/512) q[6];
cx q[14],q[6];
u1(pi/512) q[6];
u1(pi/256) q[14];
cx q[14],q[7];
u1(-pi/256) q[7];
cx q[14],q[7];
u1(pi/256) q[7];
u1(pi/128) q[14];
cx q[14],q[8];
u1(-pi/128) q[8];
cx q[14],q[8];
u1(pi/128) q[8];
u1(pi/64) q[14];
cx q[14],q[9];
u1(-pi/64) q[9];
cx q[14],q[9];
u1(pi/64) q[9];
u1(pi/32) q[14];
cx q[14],q[10];
u1(-pi/32) q[10];
cx q[14],q[10];
u1(pi/32) q[10];
u1(pi/16) q[14];
cx q[14],q[11];
u1(-pi/16) q[11];
cx q[14],q[11];
u1(pi/16) q[11];
u1(pi/8) q[14];
cx q[14],q[12];
u1(-pi/8) q[12];
cx q[14],q[12];
u1(pi/8) q[12];
u1(pi/4) q[14];
cx q[14],q[13];
u1(-pi/4) q[13];
cx q[14],q[13];
u1(pi/4) q[13];
h q[14];
u1(pi/65536) q[15];
cx q[15],q[0];
u1(-pi/65536) q[0];
cx q[15],q[0];
u1(pi/65536) q[0];
u1(pi/32768) q[15];
cx q[15],q[1];
u1(-pi/32768) q[1];
cx q[15],q[1];
u1(pi/32768) q[1];
u1(pi/16384) q[15];
cx q[15],q[2];
u1(-pi/16384) q[2];
cx q[15],q[2];
u1(pi/16384) q[2];
u1(pi/8192) q[15];
cx q[15],q[3];
u1(-pi/8192) q[3];
cx q[15],q[3];
u1(pi/8192) q[3];
u1(pi/4096) q[15];
cx q[15],q[4];
u1(-pi/4096) q[4];
cx q[15],q[4];
u1(pi/4096) q[4];
u1(pi/2048) q[15];
cx q[15],q[5];
u1(-pi/2048) q[5];
cx q[15],q[5];
u1(pi/2048) q[5];
u1(pi/1024) q[15];
cx q[15],q[6];
u1(-pi/1024) q[6];
cx q[15],q[6];
u1(pi/1024) q[6];
u1(pi/512) q[15];
cx q[15],q[7];
u1(-pi/512) q[7];
cx q[15],q[7];
u1(pi/512) q[7];
u1(pi/256) q[15];
cx q[15],q[8];
u1(-pi/256) q[8];
cx q[15],q[8];
u1(pi/256) q[8];
u1(pi/128) q[15];
cx q[15],q[9];
u1(-pi/128) q[9];
cx q[15],q[9];
u1(pi/128) q[9];
u1(pi/64) q[15];
cx q[15],q[10];
u1(-pi/64) q[10];
cx q[15],q[10];
u1(pi/64) q[10];
u1(pi/32) q[15];
cx q[15],q[11];
u1(-pi/32) q[11];
cx q[15],q[11];
u1(pi/32) q[11];
u1(pi/16) q[15];
cx q[15],q[12];
u1(-pi/16) q[12];
cx q[15],q[12];
u1(pi/16) q[12];
u1(pi/8) q[15];
cx q[15],q[13];
u1(-pi/8) q[13];
cx q[15],q[13];
u1(pi/8) q[13];
u1(pi/4) q[15];
cx q[15],q[14];
u1(-pi/4) q[14];
cx q[15],q[14];
u1(pi/4) q[14];
h q[15];
u1(pi/131072) q[16];
cx q[16],q[0];
u1(-pi/131072) q[0];
cx q[16],q[0];
u1(pi/131072) q[0];
u1(pi/65536) q[16];
cx q[16],q[1];
u1(-pi/65536) q[1];
cx q[16],q[1];
u1(pi/65536) q[1];
u1(pi/32768) q[16];
cx q[16],q[2];
u1(-pi/32768) q[2];
cx q[16],q[2];
u1(pi/32768) q[2];
u1(pi/16384) q[16];
cx q[16],q[3];
u1(-pi/16384) q[3];
cx q[16],q[3];
u1(pi/16384) q[3];
u1(pi/8192) q[16];
cx q[16],q[4];
u1(-pi/8192) q[4];
cx q[16],q[4];
u1(pi/8192) q[4];
u1(pi/4096) q[16];
cx q[16],q[5];
u1(-pi/4096) q[5];
cx q[16],q[5];
u1(pi/4096) q[5];
u1(pi/2048) q[16];
cx q[16],q[6];
u1(-pi/2048) q[6];
cx q[16],q[6];
u1(pi/2048) q[6];
u1(pi/1024) q[16];
cx q[16],q[7];
u1(-pi/1024) q[7];
cx q[16],q[7];
u1(pi/1024) q[7];
u1(pi/512) q[16];
cx q[16],q[8];
u1(-pi/512) q[8];
cx q[16],q[8];
u1(pi/512) q[8];
u1(pi/256) q[16];
cx q[16],q[9];
u1(-pi/256) q[9];
cx q[16],q[9];
u1(pi/256) q[9];
u1(pi/128) q[16];
cx q[16],q[10];
u1(-pi/128) q[10];
cx q[16],q[10];
u1(pi/128) q[10];
u1(pi/64) q[16];
cx q[16],q[11];
u1(-pi/64) q[11];
cx q[16],q[11];
u1(pi/64) q[11];
u1(pi/32) q[16];
cx q[16],q[12];
u1(-pi/32) q[12];
cx q[16],q[12];
u1(pi/32) q[12];
u1(pi/16) q[16];
cx q[16],q[13];
u1(-pi/16) q[13];
cx q[16],q[13];
u1(pi/16) q[13];
u1(pi/8) q[16];
cx q[16],q[14];
u1(-pi/8) q[14];
cx q[16],q[14];
u1(pi/8) q[14];
u1(pi/4) q[16];
cx q[16],q[15];
u1(-pi/4) q[15];
cx q[16],q[15];
u1(pi/4) q[15];
h q[16];
u1(pi/262144) q[17];
cx q[17],q[0];
u1(-pi/262144) q[0];
cx q[17],q[0];
u1(pi/262144) q[0];
u1(pi/131072) q[17];
cx q[17],q[1];
u1(-pi/131072) q[1];
cx q[17],q[1];
u1(pi/131072) q[1];
u1(pi/65536) q[17];
cx q[17],q[2];
u1(-pi/65536) q[2];
cx q[17],q[2];
u1(pi/65536) q[2];
u1(pi/32768) q[17];
cx q[17],q[3];
u1(-pi/32768) q[3];
cx q[17],q[3];
u1(pi/32768) q[3];
u1(pi/16384) q[17];
cx q[17],q[4];
u1(-pi/16384) q[4];
cx q[17],q[4];
u1(pi/16384) q[4];
u1(pi/8192) q[17];
cx q[17],q[5];
u1(-pi/8192) q[5];
cx q[17],q[5];
u1(pi/8192) q[5];
u1(pi/4096) q[17];
cx q[17],q[6];
u1(-pi/4096) q[6];
cx q[17],q[6];
u1(pi/4096) q[6];
u1(pi/2048) q[17];
cx q[17],q[7];
u1(-pi/2048) q[7];
cx q[17],q[7];
u1(pi/2048) q[7];
u1(pi/1024) q[17];
cx q[17],q[8];
u1(-pi/1024) q[8];
cx q[17],q[8];
u1(pi/1024) q[8];
u1(pi/512) q[17];
cx q[17],q[9];
u1(-pi/512) q[9];
cx q[17],q[9];
u1(pi/512) q[9];
u1(pi/256) q[17];
cx q[17],q[10];
u1(-pi/256) q[10];
cx q[17],q[10];
u1(pi/256) q[10];
u1(pi/128) q[17];
cx q[17],q[11];
u1(-pi/128) q[11];
cx q[17],q[11];
u1(pi/128) q[11];
u1(pi/64) q[17];
cx q[17],q[12];
u1(-pi/64) q[12];
cx q[17],q[12];
u1(pi/64) q[12];
u1(pi/32) q[17];
cx q[17],q[13];
u1(-pi/32) q[13];
cx q[17],q[13];
u1(pi/32) q[13];
u1(pi/16) q[17];
cx q[17],q[14];
u1(-pi/16) q[14];
cx q[17],q[14];
u1(pi/16) q[14];
u1(pi/8) q[17];
cx q[17],q[15];
u1(-pi/8) q[15];
cx q[17],q[15];
u1(pi/8) q[15];
u1(pi/4) q[17];
cx q[17],q[16];
u1(-pi/4) q[16];
cx q[17],q[16];
u1(pi/4) q[16];
h q[17];
u1(pi/524288) q[18];
cx q[18],q[0];
u1(-pi/524288) q[0];
cx q[18],q[0];
u1(pi/524288) q[0];
u1(pi/262144) q[18];
cx q[18],q[1];
u1(-pi/262144) q[1];
cx q[18],q[1];
u1(pi/262144) q[1];
u1(pi/131072) q[18];
cx q[18],q[2];
u1(-pi/131072) q[2];
cx q[18],q[2];
u1(pi/131072) q[2];
u1(pi/65536) q[18];
cx q[18],q[3];
u1(-pi/65536) q[3];
cx q[18],q[3];
u1(pi/65536) q[3];
u1(pi/32768) q[18];
cx q[18],q[4];
u1(-pi/32768) q[4];
cx q[18],q[4];
u1(pi/32768) q[4];
u1(pi/16384) q[18];
cx q[18],q[5];
u1(-pi/16384) q[5];
cx q[18],q[5];
u1(pi/16384) q[5];
u1(pi/8192) q[18];
cx q[18],q[6];
u1(-pi/8192) q[6];
cx q[18],q[6];
u1(pi/8192) q[6];
u1(pi/4096) q[18];
cx q[18],q[7];
u1(-pi/4096) q[7];
cx q[18],q[7];
u1(pi/4096) q[7];
u1(pi/2048) q[18];
cx q[18],q[8];
u1(-pi/2048) q[8];
cx q[18],q[8];
u1(pi/2048) q[8];
u1(pi/1024) q[18];
cx q[18],q[9];
u1(-pi/1024) q[9];
cx q[18],q[9];
u1(pi/1024) q[9];
u1(pi/512) q[18];
cx q[18],q[10];
u1(-pi/512) q[10];
cx q[18],q[10];
u1(pi/512) q[10];
u1(pi/256) q[18];
cx q[18],q[11];
u1(-pi/256) q[11];
cx q[18],q[11];
u1(pi/256) q[11];
u1(pi/128) q[18];
cx q[18],q[12];
u1(-pi/128) q[12];
cx q[18],q[12];
u1(pi/128) q[12];
u1(pi/64) q[18];
cx q[18],q[13];
u1(-pi/64) q[13];
cx q[18],q[13];
u1(pi/64) q[13];
u1(pi/32) q[18];
cx q[18],q[14];
u1(-pi/32) q[14];
cx q[18],q[14];
u1(pi/32) q[14];
u1(pi/16) q[18];
cx q[18],q[15];
u1(-pi/16) q[15];
cx q[18],q[15];
u1(pi/16) q[15];
u1(pi/8) q[18];
cx q[18],q[16];
u1(-pi/8) q[16];
cx q[18],q[16];
u1(pi/8) q[16];
u1(pi/4) q[18];
cx q[18],q[17];
u1(-pi/4) q[17];
cx q[18],q[17];
u1(pi/4) q[17];
h q[18];
u1(pi/1048576) q[19];
cx q[19],q[0];
u1(-pi/1048576) q[0];
cx q[19],q[0];
u1(pi/1048576) q[0];
u1(pi/524288) q[19];
cx q[19],q[1];
u1(-pi/524288) q[1];
cx q[19],q[1];
u1(pi/524288) q[1];
u1(pi/262144) q[19];
cx q[19],q[2];
u1(-pi/262144) q[2];
cx q[19],q[2];
u1(pi/262144) q[2];
u1(pi/131072) q[19];
cx q[19],q[3];
u1(-pi/131072) q[3];
cx q[19],q[3];
u1(pi/131072) q[3];
u1(pi/65536) q[19];
cx q[19],q[4];
u1(-pi/65536) q[4];
cx q[19],q[4];
u1(pi/65536) q[4];
u1(pi/32768) q[19];
cx q[19],q[5];
u1(-pi/32768) q[5];
cx q[19],q[5];
u1(pi/32768) q[5];
u1(pi/16384) q[19];
cx q[19],q[6];
u1(-pi/16384) q[6];
cx q[19],q[6];
u1(pi/16384) q[6];
u1(pi/8192) q[19];
cx q[19],q[7];
u1(-pi/8192) q[7];
cx q[19],q[7];
u1(pi/8192) q[7];
u1(pi/4096) q[19];
cx q[19],q[8];
u1(-pi/4096) q[8];
cx q[19],q[8];
u1(pi/4096) q[8];
u1(pi/2048) q[19];
cx q[19],q[9];
u1(-pi/2048) q[9];
cx q[19],q[9];
u1(pi/2048) q[9];
u1(pi/1024) q[19];
cx q[19],q[10];
u1(-pi/1024) q[10];
cx q[19],q[10];
u1(pi/1024) q[10];
u1(pi/512) q[19];
cx q[19],q[11];
u1(-pi/512) q[11];
cx q[19],q[11];
u1(pi/512) q[11];
u1(pi/256) q[19];
cx q[19],q[12];
u1(-pi/256) q[12];
cx q[19],q[12];
u1(pi/256) q[12];
u1(pi/128) q[19];
cx q[19],q[13];
u1(-pi/128) q[13];
cx q[19],q[13];
u1(pi/128) q[13];
u1(pi/64) q[19];
cx q[19],q[14];
u1(-pi/64) q[14];
cx q[19],q[14];
u1(pi/64) q[14];
u1(pi/32) q[19];
cx q[19],q[15];
u1(-pi/32) q[15];
cx q[19],q[15];
u1(pi/32) q[15];
u1(pi/16) q[19];
cx q[19],q[16];
u1(-pi/16) q[16];
cx q[19],q[16];
u1(pi/16) q[16];
u1(pi/8) q[19];
cx q[19],q[17];
u1(-pi/8) q[17];
cx q[19],q[17];
u1(pi/8) q[17];
u1(pi/4) q[19];
cx q[19],q[18];
u1(-pi/4) q[18];
cx q[19],q[18];
u1(pi/4) q[18];
h q[19];
u1(pi/2097152) q[20];
cx q[20],q[0];
u1(-pi/2097152) q[0];
cx q[20],q[0];
u1(pi/2097152) q[0];
u1(pi/1048576) q[20];
cx q[20],q[1];
u1(-pi/1048576) q[1];
cx q[20],q[1];
u1(pi/1048576) q[1];
u1(pi/524288) q[20];
cx q[20],q[2];
u1(-pi/524288) q[2];
cx q[20],q[2];
u1(pi/524288) q[2];
u1(pi/262144) q[20];
cx q[20],q[3];
u1(-pi/262144) q[3];
cx q[20],q[3];
u1(pi/262144) q[3];
u1(pi/131072) q[20];
cx q[20],q[4];
u1(-pi/131072) q[4];
cx q[20],q[4];
u1(pi/131072) q[4];
u1(pi/65536) q[20];
cx q[20],q[5];
u1(-pi/65536) q[5];
cx q[20],q[5];
u1(pi/65536) q[5];
u1(pi/32768) q[20];
cx q[20],q[6];
u1(-pi/32768) q[6];
cx q[20],q[6];
u1(pi/32768) q[6];
u1(pi/16384) q[20];
cx q[20],q[7];
u1(-pi/16384) q[7];
cx q[20],q[7];
u1(pi/16384) q[7];
u1(pi/8192) q[20];
cx q[20],q[8];
u1(-pi/8192) q[8];
cx q[20],q[8];
u1(pi/8192) q[8];
u1(pi/4096) q[20];
cx q[20],q[9];
u1(-pi/4096) q[9];
cx q[20],q[9];
u1(pi/4096) q[9];
u1(pi/2048) q[20];
cx q[20],q[10];
u1(-pi/2048) q[10];
cx q[20],q[10];
u1(pi/2048) q[10];
u1(pi/1024) q[20];
cx q[20],q[11];
u1(-pi/1024) q[11];
cx q[20],q[11];
u1(pi/1024) q[11];
u1(pi/512) q[20];
cx q[20],q[12];
u1(-pi/512) q[12];
cx q[20],q[12];
u1(pi/512) q[12];
u1(pi/256) q[20];
cx q[20],q[13];
u1(-pi/256) q[13];
cx q[20],q[13];
u1(pi/256) q[13];
u1(pi/128) q[20];
cx q[20],q[14];
u1(-pi/128) q[14];
cx q[20],q[14];
u1(pi/128) q[14];
u1(pi/64) q[20];
cx q[20],q[15];
u1(-pi/64) q[15];
cx q[20],q[15];
u1(pi/64) q[15];
u1(pi/32) q[20];
cx q[20],q[16];
u1(-pi/32) q[16];
cx q[20],q[16];
u1(pi/32) q[16];
u1(pi/16) q[20];
cx q[20],q[17];
u1(-pi/16) q[17];
cx q[20],q[17];
u1(pi/16) q[17];
u1(pi/8) q[20];
cx q[20],q[18];
u1(-pi/8) q[18];
cx q[20],q[18];
u1(pi/8) q[18];
u1(pi/4) q[20];
cx q[20],q[19];
u1(-pi/4) q[19];
cx q[20],q[19];
u1(pi/4) q[19];
h q[20];
u1(pi/4194304) q[21];
cx q[21],q[0];
u1(-pi/4194304) q[0];
cx q[21],q[0];
u1(pi/4194304) q[0];
u1(pi/2097152) q[21];
cx q[21],q[1];
u1(-pi/2097152) q[1];
cx q[21],q[1];
u1(pi/2097152) q[1];
u1(pi/1048576) q[21];
cx q[21],q[2];
u1(-pi/1048576) q[2];
cx q[21],q[2];
u1(pi/1048576) q[2];
u1(pi/524288) q[21];
cx q[21],q[3];
u1(-pi/524288) q[3];
cx q[21],q[3];
u1(pi/524288) q[3];
u1(pi/262144) q[21];
cx q[21],q[4];
u1(-pi/262144) q[4];
cx q[21],q[4];
u1(pi/262144) q[4];
u1(pi/131072) q[21];
cx q[21],q[5];
u1(-pi/131072) q[5];
cx q[21],q[5];
u1(pi/131072) q[5];
u1(pi/65536) q[21];
cx q[21],q[6];
u1(-pi/65536) q[6];
cx q[21],q[6];
u1(pi/65536) q[6];
u1(pi/32768) q[21];
cx q[21],q[7];
u1(-pi/32768) q[7];
cx q[21],q[7];
u1(pi/32768) q[7];
u1(pi/16384) q[21];
cx q[21],q[8];
u1(-pi/16384) q[8];
cx q[21],q[8];
u1(pi/16384) q[8];
u1(pi/8192) q[21];
cx q[21],q[9];
u1(-pi/8192) q[9];
cx q[21],q[9];
u1(pi/8192) q[9];
u1(pi/4096) q[21];
cx q[21],q[10];
u1(-pi/4096) q[10];
cx q[21],q[10];
u1(pi/4096) q[10];
u1(pi/2048) q[21];
cx q[21],q[11];
u1(-pi/2048) q[11];
cx q[21],q[11];
u1(pi/2048) q[11];
u1(pi/1024) q[21];
cx q[21],q[12];
u1(-pi/1024) q[12];
cx q[21],q[12];
u1(pi/1024) q[12];
u1(pi/512) q[21];
cx q[21],q[13];
u1(-pi/512) q[13];
cx q[21],q[13];
u1(pi/512) q[13];
u1(pi/256) q[21];
cx q[21],q[14];
u1(-pi/256) q[14];
cx q[21],q[14];
u1(pi/256) q[14];
u1(pi/128) q[21];
cx q[21],q[15];
u1(-pi/128) q[15];
cx q[21],q[15];
u1(pi/128) q[15];
u1(pi/64) q[21];
cx q[21],q[16];
u1(-pi/64) q[16];
cx q[21],q[16];
u1(pi/64) q[16];
u1(pi/32) q[21];
cx q[21],q[17];
u1(-pi/32) q[17];
cx q[21],q[17];
u1(pi/32) q[17];
u1(pi/16) q[21];
cx q[21],q[18];
u1(-pi/16) q[18];
cx q[21],q[18];
u1(pi/16) q[18];
u1(pi/8) q[21];
cx q[21],q[19];
u1(-pi/8) q[19];
cx q[21],q[19];
u1(pi/8) q[19];
u1(pi/4) q[21];
cx q[21],q[20];
u1(-pi/4) q[20];
cx q[21],q[20];
u1(pi/4) q[20];
h q[21];
u1(pi/8388608) q[22];
cx q[22],q[0];
u1(-pi/8388608) q[0];
cx q[22],q[0];
u1(pi/8388608) q[0];
u1(pi/4194304) q[22];
cx q[22],q[1];
u1(-pi/4194304) q[1];
cx q[22],q[1];
u1(pi/4194304) q[1];
u1(pi/2097152) q[22];
cx q[22],q[2];
u1(-pi/2097152) q[2];
cx q[22],q[2];
u1(pi/2097152) q[2];
u1(pi/1048576) q[22];
cx q[22],q[3];
u1(-pi/1048576) q[3];
cx q[22],q[3];
u1(pi/1048576) q[3];
u1(pi/524288) q[22];
cx q[22],q[4];
u1(-pi/524288) q[4];
cx q[22],q[4];
u1(pi/524288) q[4];
u1(pi/262144) q[22];
cx q[22],q[5];
u1(-pi/262144) q[5];
cx q[22],q[5];
u1(pi/262144) q[5];
u1(pi/131072) q[22];
cx q[22],q[6];
u1(-pi/131072) q[6];
cx q[22],q[6];
u1(pi/131072) q[6];
u1(pi/65536) q[22];
cx q[22],q[7];
u1(-pi/65536) q[7];
cx q[22],q[7];
u1(pi/65536) q[7];
u1(pi/32768) q[22];
cx q[22],q[8];
u1(-pi/32768) q[8];
cx q[22],q[8];
u1(pi/32768) q[8];
u1(pi/16384) q[22];
cx q[22],q[9];
u1(-pi/16384) q[9];
cx q[22],q[9];
u1(pi/16384) q[9];
u1(pi/8192) q[22];
cx q[22],q[10];
u1(-pi/8192) q[10];
cx q[22],q[10];
u1(pi/8192) q[10];
u1(pi/4096) q[22];
cx q[22],q[11];
u1(-pi/4096) q[11];
cx q[22],q[11];
u1(pi/4096) q[11];
u1(pi/2048) q[22];
cx q[22],q[12];
u1(-pi/2048) q[12];
cx q[22],q[12];
u1(pi/2048) q[12];
u1(pi/1024) q[22];
cx q[22],q[13];
u1(-pi/1024) q[13];
cx q[22],q[13];
u1(pi/1024) q[13];
u1(pi/512) q[22];
cx q[22],q[14];
u1(-pi/512) q[14];
cx q[22],q[14];
u1(pi/512) q[14];
u1(pi/256) q[22];
cx q[22],q[15];
u1(-pi/256) q[15];
cx q[22],q[15];
u1(pi/256) q[15];
u1(pi/128) q[22];
cx q[22],q[16];
u1(-pi/128) q[16];
cx q[22],q[16];
u1(pi/128) q[16];
u1(pi/64) q[22];
cx q[22],q[17];
u1(-pi/64) q[17];
cx q[22],q[17];
u1(pi/64) q[17];
u1(pi/32) q[22];
cx q[22],q[18];
u1(-pi/32) q[18];
cx q[22],q[18];
u1(pi/32) q[18];
u1(pi/16) q[22];
cx q[22],q[19];
u1(-pi/16) q[19];
cx q[22],q[19];
u1(pi/16) q[19];
u1(pi/8) q[22];
cx q[22],q[20];
u1(-pi/8) q[20];
cx q[22],q[20];
u1(pi/8) q[20];
u1(pi/4) q[22];
cx q[22],q[21];
u1(-pi/4) q[21];
cx q[22],q[21];
u1(pi/4) q[21];
h q[22];
u1(pi/16777216) q[23];
cx q[23],q[0];
u1(-pi/16777216) q[0];
cx q[23],q[0];
u1(pi/16777216) q[0];
u1(pi/8388608) q[23];
cx q[23],q[1];
u1(-pi/8388608) q[1];
cx q[23],q[1];
u1(pi/8388608) q[1];
u1(pi/4194304) q[23];
cx q[23],q[2];
u1(-pi/4194304) q[2];
cx q[23],q[2];
u1(pi/4194304) q[2];
u1(pi/2097152) q[23];
cx q[23],q[3];
u1(-pi/2097152) q[3];
cx q[23],q[3];
u1(pi/2097152) q[3];
u1(pi/1048576) q[23];
cx q[23],q[4];
u1(-pi/1048576) q[4];
cx q[23],q[4];
u1(pi/1048576) q[4];
u1(pi/524288) q[23];
cx q[23],q[5];
u1(-pi/524288) q[5];
cx q[23],q[5];
u1(pi/524288) q[5];
u1(pi/262144) q[23];
cx q[23],q[6];
u1(-pi/262144) q[6];
cx q[23],q[6];
u1(pi/262144) q[6];
u1(pi/131072) q[23];
cx q[23],q[7];
u1(-pi/131072) q[7];
cx q[23],q[7];
u1(pi/131072) q[7];
u1(pi/65536) q[23];
cx q[23],q[8];
u1(-pi/65536) q[8];
cx q[23],q[8];
u1(pi/65536) q[8];
u1(pi/32768) q[23];
cx q[23],q[9];
u1(-pi/32768) q[9];
cx q[23],q[9];
u1(pi/32768) q[9];
u1(pi/16384) q[23];
cx q[23],q[10];
u1(-pi/16384) q[10];
cx q[23],q[10];
u1(pi/16384) q[10];
u1(pi/8192) q[23];
cx q[23],q[11];
u1(-pi/8192) q[11];
cx q[23],q[11];
u1(pi/8192) q[11];
u1(pi/4096) q[23];
cx q[23],q[12];
u1(-pi/4096) q[12];
cx q[23],q[12];
u1(pi/4096) q[12];
u1(pi/2048) q[23];
cx q[23],q[13];
u1(-pi/2048) q[13];
cx q[23],q[13];
u1(pi/2048) q[13];
u1(pi/1024) q[23];
cx q[23],q[14];
u1(-pi/1024) q[14];
cx q[23],q[14];
u1(pi/1024) q[14];
u1(pi/512) q[23];
cx q[23],q[15];
u1(-pi/512) q[15];
cx q[23],q[15];
u1(pi/512) q[15];
u1(pi/256) q[23];
cx q[23],q[16];
u1(-pi/256) q[16];
cx q[23],q[16];
u1(pi/256) q[16];
u1(pi/128) q[23];
cx q[23],q[17];
u1(-pi/128) q[17];
cx q[23],q[17];
u1(pi/128) q[17];
u1(pi/64) q[23];
cx q[23],q[18];
u1(-pi/64) q[18];
cx q[23],q[18];
u1(pi/64) q[18];
u1(pi/32) q[23];
cx q[23],q[19];
u1(-pi/32) q[19];
cx q[23],q[19];
u1(pi/32) q[19];
u1(pi/16) q[23];
cx q[23],q[20];
u1(-pi/16) q[20];
cx q[23],q[20];
u1(pi/16) q[20];
u1(pi/8) q[23];
cx q[23],q[21];
u1(-pi/8) q[21];
cx q[23],q[21];
u1(pi/8) q[21];
u1(pi/4) q[23];
cx q[23],q[22];
u1(-pi/4) q[22];
cx q[23],q[22];
u1(pi/4) q[22];
h q[23];
u1(pi/33554432) q[24];
cx q[24],q[0];
u1(-pi/33554432) q[0];
cx q[24],q[0];
u1(pi/33554432) q[0];
u1(pi/16777216) q[24];
cx q[24],q[1];
u1(-pi/16777216) q[1];
cx q[24],q[1];
u1(pi/16777216) q[1];
u1(pi/8388608) q[24];
cx q[24],q[2];
u1(-pi/8388608) q[2];
cx q[24],q[2];
u1(pi/8388608) q[2];
u1(pi/4194304) q[24];
cx q[24],q[3];
u1(-pi/4194304) q[3];
cx q[24],q[3];
u1(pi/4194304) q[3];
u1(pi/2097152) q[24];
cx q[24],q[4];
u1(-pi/2097152) q[4];
cx q[24],q[4];
u1(pi/2097152) q[4];
u1(pi/1048576) q[24];
cx q[24],q[5];
u1(-pi/1048576) q[5];
cx q[24],q[5];
u1(pi/1048576) q[5];
u1(pi/524288) q[24];
cx q[24],q[6];
u1(-pi/524288) q[6];
cx q[24],q[6];
u1(pi/524288) q[6];
u1(pi/262144) q[24];
cx q[24],q[7];
u1(-pi/262144) q[7];
cx q[24],q[7];
u1(pi/262144) q[7];
u1(pi/131072) q[24];
cx q[24],q[8];
u1(-pi/131072) q[8];
cx q[24],q[8];
u1(pi/131072) q[8];
u1(pi/65536) q[24];
cx q[24],q[9];
u1(-pi/65536) q[9];
cx q[24],q[9];
u1(pi/65536) q[9];
u1(pi/32768) q[24];
cx q[24],q[10];
u1(-pi/32768) q[10];
cx q[24],q[10];
u1(pi/32768) q[10];
u1(pi/16384) q[24];
cx q[24],q[11];
u1(-pi/16384) q[11];
cx q[24],q[11];
u1(pi/16384) q[11];
u1(pi/8192) q[24];
cx q[24],q[12];
u1(-pi/8192) q[12];
cx q[24],q[12];
u1(pi/8192) q[12];
u1(pi/4096) q[24];
cx q[24],q[13];
u1(-pi/4096) q[13];
cx q[24],q[13];
u1(pi/4096) q[13];
u1(pi/2048) q[24];
cx q[24],q[14];
u1(-pi/2048) q[14];
cx q[24],q[14];
u1(pi/2048) q[14];
u1(pi/1024) q[24];
cx q[24],q[15];
u1(-pi/1024) q[15];
cx q[24],q[15];
u1(pi/1024) q[15];
u1(pi/512) q[24];
cx q[24],q[16];
u1(-pi/512) q[16];
cx q[24],q[16];
u1(pi/512) q[16];
u1(pi/256) q[24];
cx q[24],q[17];
u1(-pi/256) q[17];
cx q[24],q[17];
u1(pi/256) q[17];
u1(pi/128) q[24];
cx q[24],q[18];
u1(-pi/128) q[18];
cx q[24],q[18];
u1(pi/128) q[18];
u1(pi/64) q[24];
cx q[24],q[19];
u1(-pi/64) q[19];
cx q[24],q[19];
u1(pi/64) q[19];
u1(pi/32) q[24];
cx q[24],q[20];
u1(-pi/32) q[20];
cx q[24],q[20];
u1(pi/32) q[20];
u1(pi/16) q[24];
cx q[24],q[21];
u1(-pi/16) q[21];
cx q[24],q[21];
u1(pi/16) q[21];
u1(pi/8) q[24];
cx q[24],q[22];
u1(-pi/8) q[22];
cx q[24],q[22];
u1(pi/8) q[22];
u1(pi/4) q[24];
cx q[24],q[23];
u1(-pi/4) q[23];
cx q[24],q[23];
u1(pi/4) q[23];
h q[24];
u1(pi/67108864) q[25];
cx q[25],q[0];
u1(-pi/67108864) q[0];
cx q[25],q[0];
u1(pi/67108864) q[0];
u1(pi/33554432) q[25];
cx q[25],q[1];
u1(-pi/33554432) q[1];
cx q[25],q[1];
u1(pi/33554432) q[1];
u1(pi/16777216) q[25];
cx q[25],q[2];
u1(-pi/16777216) q[2];
cx q[25],q[2];
u1(pi/16777216) q[2];
u1(pi/8388608) q[25];
cx q[25],q[3];
u1(-pi/8388608) q[3];
cx q[25],q[3];
u1(pi/8388608) q[3];
u1(pi/4194304) q[25];
cx q[25],q[4];
u1(-pi/4194304) q[4];
cx q[25],q[4];
u1(pi/4194304) q[4];
u1(pi/2097152) q[25];
cx q[25],q[5];
u1(-pi/2097152) q[5];
cx q[25],q[5];
u1(pi/2097152) q[5];
u1(pi/1048576) q[25];
cx q[25],q[6];
u1(-pi/1048576) q[6];
cx q[25],q[6];
u1(pi/1048576) q[6];
u1(pi/524288) q[25];
cx q[25],q[7];
u1(-pi/524288) q[7];
cx q[25],q[7];
u1(pi/524288) q[7];
u1(pi/262144) q[25];
cx q[25],q[8];
u1(-pi/262144) q[8];
cx q[25],q[8];
u1(pi/262144) q[8];
u1(pi/131072) q[25];
cx q[25],q[9];
u1(-pi/131072) q[9];
cx q[25],q[9];
u1(pi/131072) q[9];
u1(pi/65536) q[25];
cx q[25],q[10];
u1(-pi/65536) q[10];
cx q[25],q[10];
u1(pi/65536) q[10];
u1(pi/32768) q[25];
cx q[25],q[11];
u1(-pi/32768) q[11];
cx q[25],q[11];
u1(pi/32768) q[11];
u1(pi/16384) q[25];
cx q[25],q[12];
u1(-pi/16384) q[12];
cx q[25],q[12];
u1(pi/16384) q[12];
u1(pi/8192) q[25];
cx q[25],q[13];
u1(-pi/8192) q[13];
cx q[25],q[13];
u1(pi/8192) q[13];
u1(pi/4096) q[25];
cx q[25],q[14];
u1(-pi/4096) q[14];
cx q[25],q[14];
u1(pi/4096) q[14];
u1(pi/2048) q[25];
cx q[25],q[15];
u1(-pi/2048) q[15];
cx q[25],q[15];
u1(pi/2048) q[15];
u1(pi/1024) q[25];
cx q[25],q[16];
u1(-pi/1024) q[16];
cx q[25],q[16];
u1(pi/1024) q[16];
u1(pi/512) q[25];
cx q[25],q[17];
u1(-pi/512) q[17];
cx q[25],q[17];
u1(pi/512) q[17];
u1(pi/256) q[25];
cx q[25],q[18];
u1(-pi/256) q[18];
cx q[25],q[18];
u1(pi/256) q[18];
u1(pi/128) q[25];
cx q[25],q[19];
u1(-pi/128) q[19];
cx q[25],q[19];
u1(pi/128) q[19];
u1(pi/64) q[25];
cx q[25],q[20];
u1(-pi/64) q[20];
cx q[25],q[20];
u1(pi/64) q[20];
u1(pi/32) q[25];
cx q[25],q[21];
u1(-pi/32) q[21];
cx q[25],q[21];
u1(pi/32) q[21];
u1(pi/16) q[25];
cx q[25],q[22];
u1(-pi/16) q[22];
cx q[25],q[22];
u1(pi/16) q[22];
u1(pi/8) q[25];
cx q[25],q[23];
u1(-pi/8) q[23];
cx q[25],q[23];
u1(pi/8) q[23];
u1(pi/4) q[25];
cx q[25],q[24];
u1(-pi/4) q[24];
cx q[25],q[24];
u1(pi/4) q[24];
h q[25];
u1(pi/134217728) q[26];
cx q[26],q[0];
u1(-pi/134217728) q[0];
cx q[26],q[0];
u1(pi/134217728) q[0];
u1(pi/67108864) q[26];
cx q[26],q[1];
u1(-pi/67108864) q[1];
cx q[26],q[1];
u1(pi/67108864) q[1];
u1(pi/33554432) q[26];
cx q[26],q[2];
u1(-pi/33554432) q[2];
cx q[26],q[2];
u1(pi/33554432) q[2];
u1(pi/16777216) q[26];
cx q[26],q[3];
u1(-pi/16777216) q[3];
cx q[26],q[3];
u1(pi/16777216) q[3];
u1(pi/8388608) q[26];
cx q[26],q[4];
u1(-pi/8388608) q[4];
cx q[26],q[4];
u1(pi/8388608) q[4];
u1(pi/4194304) q[26];
cx q[26],q[5];
u1(-pi/4194304) q[5];
cx q[26],q[5];
u1(pi/4194304) q[5];
u1(pi/2097152) q[26];
cx q[26],q[6];
u1(-pi/2097152) q[6];
cx q[26],q[6];
u1(pi/2097152) q[6];
u1(pi/1048576) q[26];
cx q[26],q[7];
u1(-pi/1048576) q[7];
cx q[26],q[7];
u1(pi/1048576) q[7];
u1(pi/524288) q[26];
cx q[26],q[8];
u1(-pi/524288) q[8];
cx q[26],q[8];
u1(pi/524288) q[8];
u1(pi/262144) q[26];
cx q[26],q[9];
u1(-pi/262144) q[9];
cx q[26],q[9];
u1(pi/262144) q[9];
u1(pi/131072) q[26];
cx q[26],q[10];
u1(-pi/131072) q[10];
cx q[26],q[10];
u1(pi/131072) q[10];
u1(pi/65536) q[26];
cx q[26],q[11];
u1(-pi/65536) q[11];
cx q[26],q[11];
u1(pi/65536) q[11];
u1(pi/32768) q[26];
cx q[26],q[12];
u1(-pi/32768) q[12];
cx q[26],q[12];
u1(pi/32768) q[12];
u1(pi/16384) q[26];
cx q[26],q[13];
u1(-pi/16384) q[13];
cx q[26],q[13];
u1(pi/16384) q[13];
u1(pi/8192) q[26];
cx q[26],q[14];
u1(-pi/8192) q[14];
cx q[26],q[14];
u1(pi/8192) q[14];
u1(pi/4096) q[26];
cx q[26],q[15];
u1(-pi/4096) q[15];
cx q[26],q[15];
u1(pi/4096) q[15];
u1(pi/2048) q[26];
cx q[26],q[16];
u1(-pi/2048) q[16];
cx q[26],q[16];
u1(pi/2048) q[16];
u1(pi/1024) q[26];
cx q[26],q[17];
u1(-pi/1024) q[17];
cx q[26],q[17];
u1(pi/1024) q[17];
u1(pi/512) q[26];
cx q[26],q[18];
u1(-pi/512) q[18];
cx q[26],q[18];
u1(pi/512) q[18];
u1(pi/256) q[26];
cx q[26],q[19];
u1(-pi/256) q[19];
cx q[26],q[19];
u1(pi/256) q[19];
u1(pi/128) q[26];
cx q[26],q[20];
u1(-pi/128) q[20];
cx q[26],q[20];
u1(pi/128) q[20];
u1(pi/64) q[26];
cx q[26],q[21];
u1(-pi/64) q[21];
cx q[26],q[21];
u1(pi/64) q[21];
u1(pi/32) q[26];
cx q[26],q[22];
u1(-pi/32) q[22];
cx q[26],q[22];
u1(pi/32) q[22];
u1(pi/16) q[26];
cx q[26],q[23];
u1(-pi/16) q[23];
cx q[26],q[23];
u1(pi/16) q[23];
u1(pi/8) q[26];
cx q[26],q[24];
u1(-pi/8) q[24];
cx q[26],q[24];
u1(pi/8) q[24];
u1(pi/4) q[26];
cx q[26],q[25];
u1(-pi/4) q[25];
cx q[26],q[25];
u1(pi/4) q[25];
h q[26];
u1(pi/268435456) q[27];
cx q[27],q[0];
u1(-pi/268435456) q[0];
cx q[27],q[0];
u1(pi/268435456) q[0];
u1(pi/134217728) q[27];
cx q[27],q[1];
u1(-pi/134217728) q[1];
cx q[27],q[1];
u1(pi/134217728) q[1];
u1(pi/67108864) q[27];
cx q[27],q[2];
u1(-pi/67108864) q[2];
cx q[27],q[2];
u1(pi/67108864) q[2];
u1(pi/33554432) q[27];
cx q[27],q[3];
u1(-pi/33554432) q[3];
cx q[27],q[3];
u1(pi/33554432) q[3];
u1(pi/16777216) q[27];
cx q[27],q[4];
u1(-pi/16777216) q[4];
cx q[27],q[4];
u1(pi/16777216) q[4];
u1(pi/8388608) q[27];
cx q[27],q[5];
u1(-pi/8388608) q[5];
cx q[27],q[5];
u1(pi/8388608) q[5];
u1(pi/4194304) q[27];
cx q[27],q[6];
u1(-pi/4194304) q[6];
cx q[27],q[6];
u1(pi/4194304) q[6];
u1(pi/2097152) q[27];
cx q[27],q[7];
u1(-pi/2097152) q[7];
cx q[27],q[7];
u1(pi/2097152) q[7];
u1(pi/1048576) q[27];
cx q[27],q[8];
u1(-pi/1048576) q[8];
cx q[27],q[8];
u1(pi/1048576) q[8];
u1(pi/524288) q[27];
cx q[27],q[9];
u1(-pi/524288) q[9];
cx q[27],q[9];
u1(pi/524288) q[9];
u1(pi/262144) q[27];
cx q[27],q[10];
u1(-pi/262144) q[10];
cx q[27],q[10];
u1(pi/262144) q[10];
u1(pi/131072) q[27];
cx q[27],q[11];
u1(-pi/131072) q[11];
cx q[27],q[11];
u1(pi/131072) q[11];
u1(pi/65536) q[27];
cx q[27],q[12];
u1(-pi/65536) q[12];
cx q[27],q[12];
u1(pi/65536) q[12];
u1(pi/32768) q[27];
cx q[27],q[13];
u1(-pi/32768) q[13];
cx q[27],q[13];
u1(pi/32768) q[13];
u1(pi/16384) q[27];
cx q[27],q[14];
u1(-pi/16384) q[14];
cx q[27],q[14];
u1(pi/16384) q[14];
u1(pi/8192) q[27];
cx q[27],q[15];
u1(-pi/8192) q[15];
cx q[27],q[15];
u1(pi/8192) q[15];
u1(pi/4096) q[27];
cx q[27],q[16];
u1(-pi/4096) q[16];
cx q[27],q[16];
u1(pi/4096) q[16];
u1(pi/2048) q[27];
cx q[27],q[17];
u1(-pi/2048) q[17];
cx q[27],q[17];
u1(pi/2048) q[17];
u1(pi/1024) q[27];
cx q[27],q[18];
u1(-pi/1024) q[18];
cx q[27],q[18];
u1(pi/1024) q[18];
u1(pi/512) q[27];
cx q[27],q[19];
u1(-pi/512) q[19];
cx q[27],q[19];
u1(pi/512) q[19];
u1(pi/256) q[27];
cx q[27],q[20];
u1(-pi/256) q[20];
cx q[27],q[20];
u1(pi/256) q[20];
u1(pi/128) q[27];
cx q[27],q[21];
u1(-pi/128) q[21];
cx q[27],q[21];
u1(pi/128) q[21];
u1(pi/64) q[27];
cx q[27],q[22];
u1(-pi/64) q[22];
cx q[27],q[22];
u1(pi/64) q[22];
u1(pi/32) q[27];
cx q[27],q[23];
u1(-pi/32) q[23];
cx q[27],q[23];
u1(pi/32) q[23];
u1(pi/16) q[27];
cx q[27],q[24];
u1(-pi/16) q[24];
cx q[27],q[24];
u1(pi/16) q[24];
u1(pi/8) q[27];
cx q[27],q[25];
u1(-pi/8) q[25];
cx q[27],q[25];
u1(pi/8) q[25];
u1(pi/4) q[27];
cx q[27],q[26];
u1(-pi/4) q[26];
cx q[27],q[26];
u1(pi/4) q[26];
h q[27];
u1(pi/536870912) q[28];
cx q[28],q[0];
u1(-pi/536870912) q[0];
cx q[28],q[0];
u1(pi/536870912) q[0];
u1(pi/268435456) q[28];
cx q[28],q[1];
u1(-pi/268435456) q[1];
cx q[28],q[1];
u1(pi/268435456) q[1];
u1(pi/134217728) q[28];
cx q[28],q[2];
u1(-pi/134217728) q[2];
cx q[28],q[2];
u1(pi/134217728) q[2];
u1(pi/67108864) q[28];
cx q[28],q[3];
u1(-pi/67108864) q[3];
cx q[28],q[3];
u1(pi/67108864) q[3];
u1(pi/33554432) q[28];
cx q[28],q[4];
u1(-pi/33554432) q[4];
cx q[28],q[4];
u1(pi/33554432) q[4];
u1(pi/16777216) q[28];
cx q[28],q[5];
u1(-pi/16777216) q[5];
cx q[28],q[5];
u1(pi/16777216) q[5];
u1(pi/8388608) q[28];
cx q[28],q[6];
u1(-pi/8388608) q[6];
cx q[28],q[6];
u1(pi/8388608) q[6];
u1(pi/4194304) q[28];
cx q[28],q[7];
u1(-pi/4194304) q[7];
cx q[28],q[7];
u1(pi/4194304) q[7];
u1(pi/2097152) q[28];
cx q[28],q[8];
u1(-pi/2097152) q[8];
cx q[28],q[8];
u1(pi/2097152) q[8];
u1(pi/1048576) q[28];
cx q[28],q[9];
u1(-pi/1048576) q[9];
cx q[28],q[9];
u1(pi/1048576) q[9];
u1(pi/524288) q[28];
cx q[28],q[10];
u1(-pi/524288) q[10];
cx q[28],q[10];
u1(pi/524288) q[10];
u1(pi/262144) q[28];
cx q[28],q[11];
u1(-pi/262144) q[11];
cx q[28],q[11];
u1(pi/262144) q[11];
u1(pi/131072) q[28];
cx q[28],q[12];
u1(-pi/131072) q[12];
cx q[28],q[12];
u1(pi/131072) q[12];
u1(pi/65536) q[28];
cx q[28],q[13];
u1(-pi/65536) q[13];
cx q[28],q[13];
u1(pi/65536) q[13];
u1(pi/32768) q[28];
cx q[28],q[14];
u1(-pi/32768) q[14];
cx q[28],q[14];
u1(pi/32768) q[14];
u1(pi/16384) q[28];
cx q[28],q[15];
u1(-pi/16384) q[15];
cx q[28],q[15];
u1(pi/16384) q[15];
u1(pi/8192) q[28];
cx q[28],q[16];
u1(-pi/8192) q[16];
cx q[28],q[16];
u1(pi/8192) q[16];
u1(pi/4096) q[28];
cx q[28],q[17];
u1(-pi/4096) q[17];
cx q[28],q[17];
u1(pi/4096) q[17];
u1(pi/2048) q[28];
cx q[28],q[18];
u1(-pi/2048) q[18];
cx q[28],q[18];
u1(pi/2048) q[18];
u1(pi/1024) q[28];
cx q[28],q[19];
u1(-pi/1024) q[19];
cx q[28],q[19];
u1(pi/1024) q[19];
u1(pi/512) q[28];
cx q[28],q[20];
u1(-pi/512) q[20];
cx q[28],q[20];
u1(pi/512) q[20];
u1(pi/256) q[28];
cx q[28],q[21];
u1(-pi/256) q[21];
cx q[28],q[21];
u1(pi/256) q[21];
u1(pi/128) q[28];
cx q[28],q[22];
u1(-pi/128) q[22];
cx q[28],q[22];
u1(pi/128) q[22];
u1(pi/64) q[28];
cx q[28],q[23];
u1(-pi/64) q[23];
cx q[28],q[23];
u1(pi/64) q[23];
u1(pi/32) q[28];
cx q[28],q[24];
u1(-pi/32) q[24];
cx q[28],q[24];
u1(pi/32) q[24];
u1(pi/16) q[28];
cx q[28],q[25];
u1(-pi/16) q[25];
cx q[28],q[25];
u1(pi/16) q[25];
u1(pi/8) q[28];
cx q[28],q[26];
u1(-pi/8) q[26];
cx q[28],q[26];
u1(pi/8) q[26];
u1(pi/4) q[28];
cx q[28],q[27];
u1(-pi/4) q[27];
cx q[28],q[27];
u1(pi/4) q[27];
h q[28];
u1(pi/1073741824) q[29];
cx q[29],q[0];
u1(-pi/1073741824) q[0];
cx q[29],q[0];
u1(pi/1073741824) q[0];
u1(pi/536870912) q[29];
cx q[29],q[1];
u1(-pi/536870912) q[1];
cx q[29],q[1];
u1(pi/536870912) q[1];
u1(pi/268435456) q[29];
cx q[29],q[2];
u1(-pi/268435456) q[2];
cx q[29],q[2];
u1(pi/268435456) q[2];
u1(pi/134217728) q[29];
cx q[29],q[3];
u1(-pi/134217728) q[3];
cx q[29],q[3];
u1(pi/134217728) q[3];
u1(pi/67108864) q[29];
cx q[29],q[4];
u1(-pi/67108864) q[4];
cx q[29],q[4];
u1(pi/67108864) q[4];
u1(pi/33554432) q[29];
cx q[29],q[5];
u1(-pi/33554432) q[5];
cx q[29],q[5];
u1(pi/33554432) q[5];
u1(pi/16777216) q[29];
cx q[29],q[6];
u1(-pi/16777216) q[6];
cx q[29],q[6];
u1(pi/16777216) q[6];
u1(pi/8388608) q[29];
cx q[29],q[7];
u1(-pi/8388608) q[7];
cx q[29],q[7];
u1(pi/8388608) q[7];
u1(pi/4194304) q[29];
cx q[29],q[8];
u1(-pi/4194304) q[8];
cx q[29],q[8];
u1(pi/4194304) q[8];
u1(pi/2097152) q[29];
cx q[29],q[9];
u1(-pi/2097152) q[9];
cx q[29],q[9];
u1(pi/2097152) q[9];
u1(pi/1048576) q[29];
cx q[29],q[10];
u1(-pi/1048576) q[10];
cx q[29],q[10];
u1(pi/1048576) q[10];
u1(pi/524288) q[29];
cx q[29],q[11];
u1(-pi/524288) q[11];
cx q[29],q[11];
u1(pi/524288) q[11];
u1(pi/262144) q[29];
cx q[29],q[12];
u1(-pi/262144) q[12];
cx q[29],q[12];
u1(pi/262144) q[12];
u1(pi/131072) q[29];
cx q[29],q[13];
u1(-pi/131072) q[13];
cx q[29],q[13];
u1(pi/131072) q[13];
u1(pi/65536) q[29];
cx q[29],q[14];
u1(-pi/65536) q[14];
cx q[29],q[14];
u1(pi/65536) q[14];
u1(pi/32768) q[29];
cx q[29],q[15];
u1(-pi/32768) q[15];
cx q[29],q[15];
u1(pi/32768) q[15];
u1(pi/16384) q[29];
cx q[29],q[16];
u1(-pi/16384) q[16];
cx q[29],q[16];
u1(pi/16384) q[16];
u1(pi/8192) q[29];
cx q[29],q[17];
u1(-pi/8192) q[17];
cx q[29],q[17];
u1(pi/8192) q[17];
u1(pi/4096) q[29];
cx q[29],q[18];
u1(-pi/4096) q[18];
cx q[29],q[18];
u1(pi/4096) q[18];
u1(pi/2048) q[29];
cx q[29],q[19];
u1(-pi/2048) q[19];
cx q[29],q[19];
u1(pi/2048) q[19];
u1(pi/1024) q[29];
cx q[29],q[20];
u1(-pi/1024) q[20];
cx q[29],q[20];
u1(pi/1024) q[20];
u1(pi/512) q[29];
cx q[29],q[21];
u1(-pi/512) q[21];
cx q[29],q[21];
u1(pi/512) q[21];
u1(pi/256) q[29];
cx q[29],q[22];
u1(-pi/256) q[22];
cx q[29],q[22];
u1(pi/256) q[22];
u1(pi/128) q[29];
cx q[29],q[23];
u1(-pi/128) q[23];
cx q[29],q[23];
u1(pi/128) q[23];
u1(pi/64) q[29];
cx q[29],q[24];
u1(-pi/64) q[24];
cx q[29],q[24];
u1(pi/64) q[24];
u1(pi/32) q[29];
cx q[29],q[25];
u1(-pi/32) q[25];
cx q[29],q[25];
u1(pi/32) q[25];
u1(pi/16) q[29];
cx q[29],q[26];
u1(-pi/16) q[26];
cx q[29],q[26];
u1(pi/16) q[26];
u1(pi/8) q[29];
cx q[29],q[27];
u1(-pi/8) q[27];
cx q[29],q[27];
u1(pi/8) q[27];
u1(pi/4) q[29];
cx q[29],q[28];
u1(-pi/4) q[28];
cx q[29],q[28];
u1(pi/4) q[28];
h q[29];
u1(pi/2147483648) q[30];
cx q[30],q[0];
u1(-pi/2147483648) q[0];
cx q[30],q[0];
u1(pi/2147483648) q[0];
u1(pi/1073741824) q[30];
cx q[30],q[1];
u1(-pi/1073741824) q[1];
cx q[30],q[1];
u1(pi/1073741824) q[1];
u1(pi/536870912) q[30];
cx q[30],q[2];
u1(-pi/536870912) q[2];
cx q[30],q[2];
u1(pi/536870912) q[2];
u1(pi/268435456) q[30];
cx q[30],q[3];
u1(-pi/268435456) q[3];
cx q[30],q[3];
u1(pi/268435456) q[3];
u1(pi/134217728) q[30];
cx q[30],q[4];
u1(-pi/134217728) q[4];
cx q[30],q[4];
u1(pi/134217728) q[4];
u1(pi/67108864) q[30];
cx q[30],q[5];
u1(-pi/67108864) q[5];
cx q[30],q[5];
u1(pi/67108864) q[5];
u1(pi/33554432) q[30];
cx q[30],q[6];
u1(-pi/33554432) q[6];
cx q[30],q[6];
u1(pi/33554432) q[6];
u1(pi/16777216) q[30];
cx q[30],q[7];
u1(-pi/16777216) q[7];
cx q[30],q[7];
u1(pi/16777216) q[7];
u1(pi/8388608) q[30];
cx q[30],q[8];
u1(-pi/8388608) q[8];
cx q[30],q[8];
u1(pi/8388608) q[8];
u1(pi/4194304) q[30];
cx q[30],q[9];
u1(-pi/4194304) q[9];
cx q[30],q[9];
u1(pi/4194304) q[9];
u1(pi/2097152) q[30];
cx q[30],q[10];
u1(-pi/2097152) q[10];
cx q[30],q[10];
u1(pi/2097152) q[10];
u1(pi/1048576) q[30];
cx q[30],q[11];
u1(-pi/1048576) q[11];
cx q[30],q[11];
u1(pi/1048576) q[11];
u1(pi/524288) q[30];
cx q[30],q[12];
u1(-pi/524288) q[12];
cx q[30],q[12];
u1(pi/524288) q[12];
u1(pi/262144) q[30];
cx q[30],q[13];
u1(-pi/262144) q[13];
cx q[30],q[13];
u1(pi/262144) q[13];
u1(pi/131072) q[30];
cx q[30],q[14];
u1(-pi/131072) q[14];
cx q[30],q[14];
u1(pi/131072) q[14];
u1(pi/65536) q[30];
cx q[30],q[15];
u1(-pi/65536) q[15];
cx q[30],q[15];
u1(pi/65536) q[15];
u1(pi/32768) q[30];
cx q[30],q[16];
u1(-pi/32768) q[16];
cx q[30],q[16];
u1(pi/32768) q[16];
u1(pi/16384) q[30];
cx q[30],q[17];
u1(-pi/16384) q[17];
cx q[30],q[17];
u1(pi/16384) q[17];
u1(pi/8192) q[30];
cx q[30],q[18];
u1(-pi/8192) q[18];
cx q[30],q[18];
u1(pi/8192) q[18];
u1(pi/4096) q[30];
cx q[30],q[19];
u1(-pi/4096) q[19];
cx q[30],q[19];
u1(pi/4096) q[19];
u1(pi/2048) q[30];
cx q[30],q[20];
u1(-pi/2048) q[20];
cx q[30],q[20];
u1(pi/2048) q[20];
u1(pi/1024) q[30];
cx q[30],q[21];
u1(-pi/1024) q[21];
cx q[30],q[21];
u1(pi/1024) q[21];
u1(pi/512) q[30];
cx q[30],q[22];
u1(-pi/512) q[22];
cx q[30],q[22];
u1(pi/512) q[22];
u1(pi/256) q[30];
cx q[30],q[23];
u1(-pi/256) q[23];
cx q[30],q[23];
u1(pi/256) q[23];
u1(pi/128) q[30];
cx q[30],q[24];
u1(-pi/128) q[24];
cx q[30],q[24];
u1(pi/128) q[24];
u1(pi/64) q[30];
cx q[30],q[25];
u1(-pi/64) q[25];
cx q[30],q[25];
u1(pi/64) q[25];
u1(pi/32) q[30];
cx q[30],q[26];
u1(-pi/32) q[26];
cx q[30],q[26];
u1(pi/32) q[26];
u1(pi/16) q[30];
cx q[30],q[27];
u1(-pi/16) q[27];
cx q[30],q[27];
u1(pi/16) q[27];
u1(pi/8) q[30];
cx q[30],q[28];
u1(-pi/8) q[28];
cx q[30],q[28];
u1(pi/8) q[28];
u1(pi/4) q[30];
cx q[30],q[29];
u1(-pi/4) q[29];
cx q[30],q[29];
u1(pi/4) q[29];
h q[30];
u1(pi/4294967296) q[31];
cx q[31],q[0];
u1(-pi/4294967296) q[0];
cx q[31],q[0];
u1(pi/4294967296) q[0];
u1(pi/2147483648) q[31];
cx q[31],q[1];
u1(-pi/2147483648) q[1];
cx q[31],q[1];
u1(pi/2147483648) q[1];
u1(pi/1073741824) q[31];
cx q[31],q[2];
u1(-pi/1073741824) q[2];
cx q[31],q[2];
u1(pi/1073741824) q[2];
u1(pi/536870912) q[31];
cx q[31],q[3];
u1(-pi/536870912) q[3];
cx q[31],q[3];
u1(pi/536870912) q[3];
u1(pi/268435456) q[31];
cx q[31],q[4];
u1(-pi/268435456) q[4];
cx q[31],q[4];
u1(pi/268435456) q[4];
u1(pi/134217728) q[31];
cx q[31],q[5];
u1(-pi/134217728) q[5];
cx q[31],q[5];
u1(pi/134217728) q[5];
u1(pi/67108864) q[31];
cx q[31],q[6];
u1(-pi/67108864) q[6];
cx q[31],q[6];
u1(pi/67108864) q[6];
u1(pi/33554432) q[31];
cx q[31],q[7];
u1(-pi/33554432) q[7];
cx q[31],q[7];
u1(pi/33554432) q[7];
u1(pi/16777216) q[31];
cx q[31],q[8];
u1(-pi/16777216) q[8];
cx q[31],q[8];
u1(pi/16777216) q[8];
u1(pi/8388608) q[31];
cx q[31],q[9];
u1(-pi/8388608) q[9];
cx q[31],q[9];
u1(pi/8388608) q[9];
u1(pi/4194304) q[31];
cx q[31],q[10];
u1(-pi/4194304) q[10];
cx q[31],q[10];
u1(pi/4194304) q[10];
u1(pi/2097152) q[31];
cx q[31],q[11];
u1(-pi/2097152) q[11];
cx q[31],q[11];
u1(pi/2097152) q[11];
u1(pi/1048576) q[31];
cx q[31],q[12];
u1(-pi/1048576) q[12];
cx q[31],q[12];
u1(pi/1048576) q[12];
u1(pi/524288) q[31];
cx q[31],q[13];
u1(-pi/524288) q[13];
cx q[31],q[13];
u1(pi/524288) q[13];
u1(pi/262144) q[31];
cx q[31],q[14];
u1(-pi/262144) q[14];
cx q[31],q[14];
u1(pi/262144) q[14];
u1(pi/131072) q[31];
cx q[31],q[15];
u1(-pi/131072) q[15];
cx q[31],q[15];
u1(pi/131072) q[15];
u1(pi/65536) q[31];
cx q[31],q[16];
u1(-pi/65536) q[16];
cx q[31],q[16];
u1(pi/65536) q[16];
u1(pi/32768) q[31];
cx q[31],q[17];
u1(-pi/32768) q[17];
cx q[31],q[17];
u1(pi/32768) q[17];
u1(pi/16384) q[31];
cx q[31],q[18];
u1(-pi/16384) q[18];
cx q[31],q[18];
u1(pi/16384) q[18];
u1(pi/8192) q[31];
cx q[31],q[19];
u1(-pi/8192) q[19];
cx q[31],q[19];
u1(pi/8192) q[19];
u1(pi/4096) q[31];
cx q[31],q[20];
u1(-pi/4096) q[20];
cx q[31],q[20];
u1(pi/4096) q[20];
u1(pi/2048) q[31];
cx q[31],q[21];
u1(-pi/2048) q[21];
cx q[31],q[21];
u1(pi/2048) q[21];
u1(pi/1024) q[31];
cx q[31],q[22];
u1(-pi/1024) q[22];
cx q[31],q[22];
u1(pi/1024) q[22];
u1(pi/512) q[31];
cx q[31],q[23];
u1(-pi/512) q[23];
cx q[31],q[23];
u1(pi/512) q[23];
u1(pi/256) q[31];
cx q[31],q[24];
u1(-pi/256) q[24];
cx q[31],q[24];
u1(pi/256) q[24];
u1(pi/128) q[31];
cx q[31],q[25];
u1(-pi/128) q[25];
cx q[31],q[25];
u1(pi/128) q[25];
u1(pi/64) q[31];
cx q[31],q[26];
u1(-pi/64) q[26];
cx q[31],q[26];
u1(pi/64) q[26];
u1(pi/32) q[31];
cx q[31],q[27];
u1(-pi/32) q[27];
cx q[31],q[27];
u1(pi/32) q[27];
u1(pi/16) q[31];
cx q[31],q[28];
u1(-pi/16) q[28];
cx q[31],q[28];
u1(pi/16) q[28];
u1(pi/8) q[31];
cx q[31],q[29];
u1(-pi/8) q[29];
cx q[31],q[29];
u1(pi/8) q[29];
u1(pi/4) q[31];
cx q[31],q[30];
u1(-pi/4) q[30];
cx q[31],q[30];
u1(pi/4) q[30];
h q[31];
u1(pi/8589934592) q[32];
cx q[32],q[0];
u1(-pi/8589934592) q[0];
cx q[32],q[0];
u1(pi/8589934592) q[0];
u1(pi/4294967296) q[32];
cx q[32],q[1];
u1(-pi/4294967296) q[1];
cx q[32],q[1];
u1(pi/4294967296) q[1];
u1(pi/2147483648) q[32];
cx q[32],q[2];
u1(-pi/2147483648) q[2];
cx q[32],q[2];
u1(pi/2147483648) q[2];
u1(pi/1073741824) q[32];
cx q[32],q[3];
u1(-pi/1073741824) q[3];
cx q[32],q[3];
u1(pi/1073741824) q[3];
u1(pi/536870912) q[32];
cx q[32],q[4];
u1(-pi/536870912) q[4];
cx q[32],q[4];
u1(pi/536870912) q[4];
u1(pi/268435456) q[32];
cx q[32],q[5];
u1(-pi/268435456) q[5];
cx q[32],q[5];
u1(pi/268435456) q[5];
u1(pi/134217728) q[32];
cx q[32],q[6];
u1(-pi/134217728) q[6];
cx q[32],q[6];
u1(pi/134217728) q[6];
u1(pi/67108864) q[32];
cx q[32],q[7];
u1(-pi/67108864) q[7];
cx q[32],q[7];
u1(pi/67108864) q[7];
u1(pi/33554432) q[32];
cx q[32],q[8];
u1(-pi/33554432) q[8];
cx q[32],q[8];
u1(pi/33554432) q[8];
u1(pi/16777216) q[32];
cx q[32],q[9];
u1(-pi/16777216) q[9];
cx q[32],q[9];
u1(pi/16777216) q[9];
u1(pi/8388608) q[32];
cx q[32],q[10];
u1(-pi/8388608) q[10];
cx q[32],q[10];
u1(pi/8388608) q[10];
u1(pi/4194304) q[32];
cx q[32],q[11];
u1(-pi/4194304) q[11];
cx q[32],q[11];
u1(pi/4194304) q[11];
u1(pi/2097152) q[32];
cx q[32],q[12];
u1(-pi/2097152) q[12];
cx q[32],q[12];
u1(pi/2097152) q[12];
u1(pi/1048576) q[32];
cx q[32],q[13];
u1(-pi/1048576) q[13];
cx q[32],q[13];
u1(pi/1048576) q[13];
u1(pi/524288) q[32];
cx q[32],q[14];
u1(-pi/524288) q[14];
cx q[32],q[14];
u1(pi/524288) q[14];
u1(pi/262144) q[32];
cx q[32],q[15];
u1(-pi/262144) q[15];
cx q[32],q[15];
u1(pi/262144) q[15];
u1(pi/131072) q[32];
cx q[32],q[16];
u1(-pi/131072) q[16];
cx q[32],q[16];
u1(pi/131072) q[16];
u1(pi/65536) q[32];
cx q[32],q[17];
u1(-pi/65536) q[17];
cx q[32],q[17];
u1(pi/65536) q[17];
u1(pi/32768) q[32];
cx q[32],q[18];
u1(-pi/32768) q[18];
cx q[32],q[18];
u1(pi/32768) q[18];
u1(pi/16384) q[32];
cx q[32],q[19];
u1(-pi/16384) q[19];
cx q[32],q[19];
u1(pi/16384) q[19];
u1(pi/8192) q[32];
cx q[32],q[20];
u1(-pi/8192) q[20];
cx q[32],q[20];
u1(pi/8192) q[20];
u1(pi/4096) q[32];
cx q[32],q[21];
u1(-pi/4096) q[21];
cx q[32],q[21];
u1(pi/4096) q[21];
u1(pi/2048) q[32];
cx q[32],q[22];
u1(-pi/2048) q[22];
cx q[32],q[22];
u1(pi/2048) q[22];
u1(pi/1024) q[32];
cx q[32],q[23];
u1(-pi/1024) q[23];
cx q[32],q[23];
u1(pi/1024) q[23];
u1(pi/512) q[32];
cx q[32],q[24];
u1(-pi/512) q[24];
cx q[32],q[24];
u1(pi/512) q[24];
u1(pi/256) q[32];
cx q[32],q[25];
u1(-pi/256) q[25];
cx q[32],q[25];
u1(pi/256) q[25];
u1(pi/128) q[32];
cx q[32],q[26];
u1(-pi/128) q[26];
cx q[32],q[26];
u1(pi/128) q[26];
u1(pi/64) q[32];
cx q[32],q[27];
u1(-pi/64) q[27];
cx q[32],q[27];
u1(pi/64) q[27];
u1(pi/32) q[32];
cx q[32],q[28];
u1(-pi/32) q[28];
cx q[32],q[28];
u1(pi/32) q[28];
u1(pi/16) q[32];
cx q[32],q[29];
u1(-pi/16) q[29];
cx q[32],q[29];
u1(pi/16) q[29];
u1(pi/8) q[32];
cx q[32],q[30];
u1(-pi/8) q[30];
cx q[32],q[30];
u1(pi/8) q[30];
u1(pi/4) q[32];
cx q[32],q[31];
u1(-pi/4) q[31];
cx q[32],q[31];
u1(pi/4) q[31];
h q[32];
u1(pi/17179869184) q[33];
cx q[33],q[0];
u1(-pi/17179869184) q[0];
cx q[33],q[0];
u1(pi/17179869184) q[0];
u1(pi/8589934592) q[33];
cx q[33],q[1];
u1(-pi/8589934592) q[1];
cx q[33],q[1];
u1(pi/8589934592) q[1];
u1(pi/4294967296) q[33];
cx q[33],q[2];
u1(-pi/4294967296) q[2];
cx q[33],q[2];
u1(pi/4294967296) q[2];
u1(pi/2147483648) q[33];
cx q[33],q[3];
u1(-pi/2147483648) q[3];
cx q[33],q[3];
u1(pi/2147483648) q[3];
u1(pi/1073741824) q[33];
cx q[33],q[4];
u1(-pi/1073741824) q[4];
cx q[33],q[4];
u1(pi/1073741824) q[4];
u1(pi/536870912) q[33];
cx q[33],q[5];
u1(-pi/536870912) q[5];
cx q[33],q[5];
u1(pi/536870912) q[5];
u1(pi/268435456) q[33];
cx q[33],q[6];
u1(-pi/268435456) q[6];
cx q[33],q[6];
u1(pi/268435456) q[6];
u1(pi/134217728) q[33];
cx q[33],q[7];
u1(-pi/134217728) q[7];
cx q[33],q[7];
u1(pi/134217728) q[7];
u1(pi/67108864) q[33];
cx q[33],q[8];
u1(-pi/67108864) q[8];
cx q[33],q[8];
u1(pi/67108864) q[8];
u1(pi/33554432) q[33];
cx q[33],q[9];
u1(-pi/33554432) q[9];
cx q[33],q[9];
u1(pi/33554432) q[9];
u1(pi/16777216) q[33];
cx q[33],q[10];
u1(-pi/16777216) q[10];
cx q[33],q[10];
u1(pi/16777216) q[10];
u1(pi/8388608) q[33];
cx q[33],q[11];
u1(-pi/8388608) q[11];
cx q[33],q[11];
u1(pi/8388608) q[11];
u1(pi/4194304) q[33];
cx q[33],q[12];
u1(-pi/4194304) q[12];
cx q[33],q[12];
u1(pi/4194304) q[12];
u1(pi/2097152) q[33];
cx q[33],q[13];
u1(-pi/2097152) q[13];
cx q[33],q[13];
u1(pi/2097152) q[13];
u1(pi/1048576) q[33];
cx q[33],q[14];
u1(-pi/1048576) q[14];
cx q[33],q[14];
u1(pi/1048576) q[14];
u1(pi/524288) q[33];
cx q[33],q[15];
u1(-pi/524288) q[15];
cx q[33],q[15];
u1(pi/524288) q[15];
u1(pi/262144) q[33];
cx q[33],q[16];
u1(-pi/262144) q[16];
cx q[33],q[16];
u1(pi/262144) q[16];
u1(pi/131072) q[33];
cx q[33],q[17];
u1(-pi/131072) q[17];
cx q[33],q[17];
u1(pi/131072) q[17];
u1(pi/65536) q[33];
cx q[33],q[18];
u1(-pi/65536) q[18];
cx q[33],q[18];
u1(pi/65536) q[18];
u1(pi/32768) q[33];
cx q[33],q[19];
u1(-pi/32768) q[19];
cx q[33],q[19];
u1(pi/32768) q[19];
u1(pi/16384) q[33];
cx q[33],q[20];
u1(-pi/16384) q[20];
cx q[33],q[20];
u1(pi/16384) q[20];
u1(pi/8192) q[33];
cx q[33],q[21];
u1(-pi/8192) q[21];
cx q[33],q[21];
u1(pi/8192) q[21];
u1(pi/4096) q[33];
cx q[33],q[22];
u1(-pi/4096) q[22];
cx q[33],q[22];
u1(pi/4096) q[22];
u1(pi/2048) q[33];
cx q[33],q[23];
u1(-pi/2048) q[23];
cx q[33],q[23];
u1(pi/2048) q[23];
u1(pi/1024) q[33];
cx q[33],q[24];
u1(-pi/1024) q[24];
cx q[33],q[24];
u1(pi/1024) q[24];
u1(pi/512) q[33];
cx q[33],q[25];
u1(-pi/512) q[25];
cx q[33],q[25];
u1(pi/512) q[25];
u1(pi/256) q[33];
cx q[33],q[26];
u1(-pi/256) q[26];
cx q[33],q[26];
u1(pi/256) q[26];
u1(pi/128) q[33];
cx q[33],q[27];
u1(-pi/128) q[27];
cx q[33],q[27];
u1(pi/128) q[27];
u1(pi/64) q[33];
cx q[33],q[28];
u1(-pi/64) q[28];
cx q[33],q[28];
u1(pi/64) q[28];
u1(pi/32) q[33];
cx q[33],q[29];
u1(-pi/32) q[29];
cx q[33],q[29];
u1(pi/32) q[29];
u1(pi/16) q[33];
cx q[33],q[30];
u1(-pi/16) q[30];
cx q[33],q[30];
u1(pi/16) q[30];
u1(pi/8) q[33];
cx q[33],q[31];
u1(-pi/8) q[31];
cx q[33],q[31];
u1(pi/8) q[31];
u1(pi/4) q[33];
cx q[33],q[32];
u1(-pi/4) q[32];
cx q[33],q[32];
u1(pi/4) q[32];
h q[33];
u1(pi/34359738368) q[34];
cx q[34],q[0];
u1(-pi/34359738368) q[0];
cx q[34],q[0];
u1(pi/34359738368) q[0];
u1(pi/17179869184) q[34];
cx q[34],q[1];
u1(-pi/17179869184) q[1];
cx q[34],q[1];
u1(pi/17179869184) q[1];
u1(pi/8589934592) q[34];
cx q[34],q[2];
u1(-pi/8589934592) q[2];
cx q[34],q[2];
u1(pi/8589934592) q[2];
u1(pi/4294967296) q[34];
cx q[34],q[3];
u1(-pi/4294967296) q[3];
cx q[34],q[3];
u1(pi/4294967296) q[3];
u1(pi/2147483648) q[34];
cx q[34],q[4];
u1(-pi/2147483648) q[4];
cx q[34],q[4];
u1(pi/2147483648) q[4];
u1(pi/1073741824) q[34];
cx q[34],q[5];
u1(-pi/1073741824) q[5];
cx q[34],q[5];
u1(pi/1073741824) q[5];
u1(pi/536870912) q[34];
cx q[34],q[6];
u1(-pi/536870912) q[6];
cx q[34],q[6];
u1(pi/536870912) q[6];
u1(pi/268435456) q[34];
cx q[34],q[7];
u1(-pi/268435456) q[7];
cx q[34],q[7];
u1(pi/268435456) q[7];
u1(pi/134217728) q[34];
cx q[34],q[8];
u1(-pi/134217728) q[8];
cx q[34],q[8];
u1(pi/134217728) q[8];
u1(pi/67108864) q[34];
cx q[34],q[9];
u1(-pi/67108864) q[9];
cx q[34],q[9];
u1(pi/67108864) q[9];
u1(pi/33554432) q[34];
cx q[34],q[10];
u1(-pi/33554432) q[10];
cx q[34],q[10];
u1(pi/33554432) q[10];
u1(pi/16777216) q[34];
cx q[34],q[11];
u1(-pi/16777216) q[11];
cx q[34],q[11];
u1(pi/16777216) q[11];
u1(pi/8388608) q[34];
cx q[34],q[12];
u1(-pi/8388608) q[12];
cx q[34],q[12];
u1(pi/8388608) q[12];
u1(pi/4194304) q[34];
cx q[34],q[13];
u1(-pi/4194304) q[13];
cx q[34],q[13];
u1(pi/4194304) q[13];
u1(pi/2097152) q[34];
cx q[34],q[14];
u1(-pi/2097152) q[14];
cx q[34],q[14];
u1(pi/2097152) q[14];
u1(pi/1048576) q[34];
cx q[34],q[15];
u1(-pi/1048576) q[15];
cx q[34],q[15];
u1(pi/1048576) q[15];
u1(pi/524288) q[34];
cx q[34],q[16];
u1(-pi/524288) q[16];
cx q[34],q[16];
u1(pi/524288) q[16];
u1(pi/262144) q[34];
cx q[34],q[17];
u1(-pi/262144) q[17];
cx q[34],q[17];
u1(pi/262144) q[17];
u1(pi/131072) q[34];
cx q[34],q[18];
u1(-pi/131072) q[18];
cx q[34],q[18];
u1(pi/131072) q[18];
u1(pi/65536) q[34];
cx q[34],q[19];
u1(-pi/65536) q[19];
cx q[34],q[19];
u1(pi/65536) q[19];
u1(pi/32768) q[34];
cx q[34],q[20];
u1(-pi/32768) q[20];
cx q[34],q[20];
u1(pi/32768) q[20];
u1(pi/16384) q[34];
cx q[34],q[21];
u1(-pi/16384) q[21];
cx q[34],q[21];
u1(pi/16384) q[21];
u1(pi/8192) q[34];
cx q[34],q[22];
u1(-pi/8192) q[22];
cx q[34],q[22];
u1(pi/8192) q[22];
u1(pi/4096) q[34];
cx q[34],q[23];
u1(-pi/4096) q[23];
cx q[34],q[23];
u1(pi/4096) q[23];
u1(pi/2048) q[34];
cx q[34],q[24];
u1(-pi/2048) q[24];
cx q[34],q[24];
u1(pi/2048) q[24];
u1(pi/1024) q[34];
cx q[34],q[25];
u1(-pi/1024) q[25];
cx q[34],q[25];
u1(pi/1024) q[25];
u1(pi/512) q[34];
cx q[34],q[26];
u1(-pi/512) q[26];
cx q[34],q[26];
u1(pi/512) q[26];
u1(pi/256) q[34];
cx q[34],q[27];
u1(-pi/256) q[27];
cx q[34],q[27];
u1(pi/256) q[27];
u1(pi/128) q[34];
cx q[34],q[28];
u1(-pi/128) q[28];
cx q[34],q[28];
u1(pi/128) q[28];
u1(pi/64) q[34];
cx q[34],q[29];
u1(-pi/64) q[29];
cx q[34],q[29];
u1(pi/64) q[29];
u1(pi/32) q[34];
cx q[34],q[30];
u1(-pi/32) q[30];
cx q[34],q[30];
u1(pi/32) q[30];
u1(pi/16) q[34];
cx q[34],q[31];
u1(-pi/16) q[31];
cx q[34],q[31];
u1(pi/16) q[31];
u1(pi/8) q[34];
cx q[34],q[32];
u1(-pi/8) q[32];
cx q[34],q[32];
u1(pi/8) q[32];
u1(pi/4) q[34];
cx q[34],q[33];
u1(-pi/4) q[33];
cx q[34],q[33];
u1(pi/4) q[33];
h q[34];
u1(pi/68719476736) q[35];
cx q[35],q[0];
u1(-pi/68719476736) q[0];
cx q[35],q[0];
u1(pi/68719476736) q[0];
u1(pi/34359738368) q[35];
cx q[35],q[1];
u1(-pi/34359738368) q[1];
cx q[35],q[1];
u1(pi/34359738368) q[1];
u1(pi/17179869184) q[35];
cx q[35],q[2];
u1(-pi/17179869184) q[2];
cx q[35],q[2];
u1(pi/17179869184) q[2];
u1(pi/8589934592) q[35];
cx q[35],q[3];
u1(-pi/8589934592) q[3];
cx q[35],q[3];
u1(pi/8589934592) q[3];
u1(pi/4294967296) q[35];
cx q[35],q[4];
u1(-pi/4294967296) q[4];
cx q[35],q[4];
u1(pi/4294967296) q[4];
u1(pi/2147483648) q[35];
cx q[35],q[5];
u1(-pi/2147483648) q[5];
cx q[35],q[5];
u1(pi/2147483648) q[5];
u1(pi/1073741824) q[35];
cx q[35],q[6];
u1(-pi/1073741824) q[6];
cx q[35],q[6];
u1(pi/1073741824) q[6];
u1(pi/536870912) q[35];
cx q[35],q[7];
u1(-pi/536870912) q[7];
cx q[35],q[7];
u1(pi/536870912) q[7];
u1(pi/268435456) q[35];
cx q[35],q[8];
u1(-pi/268435456) q[8];
cx q[35],q[8];
u1(pi/268435456) q[8];
u1(pi/134217728) q[35];
cx q[35],q[9];
u1(-pi/134217728) q[9];
cx q[35],q[9];
u1(pi/134217728) q[9];
u1(pi/67108864) q[35];
cx q[35],q[10];
u1(-pi/67108864) q[10];
cx q[35],q[10];
u1(pi/67108864) q[10];
u1(pi/33554432) q[35];
cx q[35],q[11];
u1(-pi/33554432) q[11];
cx q[35],q[11];
u1(pi/33554432) q[11];
u1(pi/16777216) q[35];
cx q[35],q[12];
u1(-pi/16777216) q[12];
cx q[35],q[12];
u1(pi/16777216) q[12];
u1(pi/8388608) q[35];
cx q[35],q[13];
u1(-pi/8388608) q[13];
cx q[35],q[13];
u1(pi/8388608) q[13];
u1(pi/4194304) q[35];
cx q[35],q[14];
u1(-pi/4194304) q[14];
cx q[35],q[14];
u1(pi/4194304) q[14];
u1(pi/2097152) q[35];
cx q[35],q[15];
u1(-pi/2097152) q[15];
cx q[35],q[15];
u1(pi/2097152) q[15];
u1(pi/1048576) q[35];
cx q[35],q[16];
u1(-pi/1048576) q[16];
cx q[35],q[16];
u1(pi/1048576) q[16];
u1(pi/524288) q[35];
cx q[35],q[17];
u1(-pi/524288) q[17];
cx q[35],q[17];
u1(pi/524288) q[17];
u1(pi/262144) q[35];
cx q[35],q[18];
u1(-pi/262144) q[18];
cx q[35],q[18];
u1(pi/262144) q[18];
u1(pi/131072) q[35];
cx q[35],q[19];
u1(-pi/131072) q[19];
cx q[35],q[19];
u1(pi/131072) q[19];
u1(pi/65536) q[35];
cx q[35],q[20];
u1(-pi/65536) q[20];
cx q[35],q[20];
u1(pi/65536) q[20];
u1(pi/32768) q[35];
cx q[35],q[21];
u1(-pi/32768) q[21];
cx q[35],q[21];
u1(pi/32768) q[21];
u1(pi/16384) q[35];
cx q[35],q[22];
u1(-pi/16384) q[22];
cx q[35],q[22];
u1(pi/16384) q[22];
u1(pi/8192) q[35];
cx q[35],q[23];
u1(-pi/8192) q[23];
cx q[35],q[23];
u1(pi/8192) q[23];
u1(pi/4096) q[35];
cx q[35],q[24];
u1(-pi/4096) q[24];
cx q[35],q[24];
u1(pi/4096) q[24];
u1(pi/2048) q[35];
cx q[35],q[25];
u1(-pi/2048) q[25];
cx q[35],q[25];
u1(pi/2048) q[25];
u1(pi/1024) q[35];
cx q[35],q[26];
u1(-pi/1024) q[26];
cx q[35],q[26];
u1(pi/1024) q[26];
u1(pi/512) q[35];
cx q[35],q[27];
u1(-pi/512) q[27];
cx q[35],q[27];
u1(pi/512) q[27];
u1(pi/256) q[35];
cx q[35],q[28];
u1(-pi/256) q[28];
cx q[35],q[28];
u1(pi/256) q[28];
u1(pi/128) q[35];
cx q[35],q[29];
u1(-pi/128) q[29];
cx q[35],q[29];
u1(pi/128) q[29];
u1(pi/64) q[35];
cx q[35],q[30];
u1(-pi/64) q[30];
cx q[35],q[30];
u1(pi/64) q[30];
u1(pi/32) q[35];
cx q[35],q[31];
u1(-pi/32) q[31];
cx q[35],q[31];
u1(pi/32) q[31];
u1(pi/16) q[35];
cx q[35],q[32];
u1(-pi/16) q[32];
cx q[35],q[32];
u1(pi/16) q[32];
u1(pi/8) q[35];
cx q[35],q[33];
u1(-pi/8) q[33];
cx q[35],q[33];
u1(pi/8) q[33];
u1(pi/4) q[35];
cx q[35],q[34];
u1(-pi/4) q[34];
cx q[35],q[34];
u1(pi/4) q[34];
h q[35];
u1(pi/137438953472) q[36];
cx q[36],q[0];
u1(-pi/137438953472) q[0];
cx q[36],q[0];
u1(pi/137438953472) q[0];
u1(pi/68719476736) q[36];
cx q[36],q[1];
u1(-pi/68719476736) q[1];
cx q[36],q[1];
u1(pi/68719476736) q[1];
u1(pi/34359738368) q[36];
cx q[36],q[2];
u1(-pi/34359738368) q[2];
cx q[36],q[2];
u1(pi/34359738368) q[2];
u1(pi/17179869184) q[36];
cx q[36],q[3];
u1(-pi/17179869184) q[3];
cx q[36],q[3];
u1(pi/17179869184) q[3];
u1(pi/8589934592) q[36];
cx q[36],q[4];
u1(-pi/8589934592) q[4];
cx q[36],q[4];
u1(pi/8589934592) q[4];
u1(pi/4294967296) q[36];
cx q[36],q[5];
u1(-pi/4294967296) q[5];
cx q[36],q[5];
u1(pi/4294967296) q[5];
u1(pi/2147483648) q[36];
cx q[36],q[6];
u1(-pi/2147483648) q[6];
cx q[36],q[6];
u1(pi/2147483648) q[6];
u1(pi/1073741824) q[36];
cx q[36],q[7];
u1(-pi/1073741824) q[7];
cx q[36],q[7];
u1(pi/1073741824) q[7];
u1(pi/536870912) q[36];
cx q[36],q[8];
u1(-pi/536870912) q[8];
cx q[36],q[8];
u1(pi/536870912) q[8];
u1(pi/268435456) q[36];
cx q[36],q[9];
u1(-pi/268435456) q[9];
cx q[36],q[9];
u1(pi/268435456) q[9];
u1(pi/134217728) q[36];
cx q[36],q[10];
u1(-pi/134217728) q[10];
cx q[36],q[10];
u1(pi/134217728) q[10];
u1(pi/67108864) q[36];
cx q[36],q[11];
u1(-pi/67108864) q[11];
cx q[36],q[11];
u1(pi/67108864) q[11];
u1(pi/33554432) q[36];
cx q[36],q[12];
u1(-pi/33554432) q[12];
cx q[36],q[12];
u1(pi/33554432) q[12];
u1(pi/16777216) q[36];
cx q[36],q[13];
u1(-pi/16777216) q[13];
cx q[36],q[13];
u1(pi/16777216) q[13];
u1(pi/8388608) q[36];
cx q[36],q[14];
u1(-pi/8388608) q[14];
cx q[36],q[14];
u1(pi/8388608) q[14];
u1(pi/4194304) q[36];
cx q[36],q[15];
u1(-pi/4194304) q[15];
cx q[36],q[15];
u1(pi/4194304) q[15];
u1(pi/2097152) q[36];
cx q[36],q[16];
u1(-pi/2097152) q[16];
cx q[36],q[16];
u1(pi/2097152) q[16];
u1(pi/1048576) q[36];
cx q[36],q[17];
u1(-pi/1048576) q[17];
cx q[36],q[17];
u1(pi/1048576) q[17];
u1(pi/524288) q[36];
cx q[36],q[18];
u1(-pi/524288) q[18];
cx q[36],q[18];
u1(pi/524288) q[18];
u1(pi/262144) q[36];
cx q[36],q[19];
u1(-pi/262144) q[19];
cx q[36],q[19];
u1(pi/262144) q[19];
u1(pi/131072) q[36];
cx q[36],q[20];
u1(-pi/131072) q[20];
cx q[36],q[20];
u1(pi/131072) q[20];
u1(pi/65536) q[36];
cx q[36],q[21];
u1(-pi/65536) q[21];
cx q[36],q[21];
u1(pi/65536) q[21];
u1(pi/32768) q[36];
cx q[36],q[22];
u1(-pi/32768) q[22];
cx q[36],q[22];
u1(pi/32768) q[22];
u1(pi/16384) q[36];
cx q[36],q[23];
u1(-pi/16384) q[23];
cx q[36],q[23];
u1(pi/16384) q[23];
u1(pi/8192) q[36];
cx q[36],q[24];
u1(-pi/8192) q[24];
cx q[36],q[24];
u1(pi/8192) q[24];
u1(pi/4096) q[36];
cx q[36],q[25];
u1(-pi/4096) q[25];
cx q[36],q[25];
u1(pi/4096) q[25];
u1(pi/2048) q[36];
cx q[36],q[26];
u1(-pi/2048) q[26];
cx q[36],q[26];
u1(pi/2048) q[26];
u1(pi/1024) q[36];
cx q[36],q[27];
u1(-pi/1024) q[27];
cx q[36],q[27];
u1(pi/1024) q[27];
u1(pi/512) q[36];
cx q[36],q[28];
u1(-pi/512) q[28];
cx q[36],q[28];
u1(pi/512) q[28];
u1(pi/256) q[36];
cx q[36],q[29];
u1(-pi/256) q[29];
cx q[36],q[29];
u1(pi/256) q[29];
u1(pi/128) q[36];
cx q[36],q[30];
u1(-pi/128) q[30];
cx q[36],q[30];
u1(pi/128) q[30];
u1(pi/64) q[36];
cx q[36],q[31];
u1(-pi/64) q[31];
cx q[36],q[31];
u1(pi/64) q[31];
u1(pi/32) q[36];
cx q[36],q[32];
u1(-pi/32) q[32];
cx q[36],q[32];
u1(pi/32) q[32];
u1(pi/16) q[36];
cx q[36],q[33];
u1(-pi/16) q[33];
cx q[36],q[33];
u1(pi/16) q[33];
u1(pi/8) q[36];
cx q[36],q[34];
u1(-pi/8) q[34];
cx q[36],q[34];
u1(pi/8) q[34];
u1(pi/4) q[36];
cx q[36],q[35];
u1(-pi/4) q[35];
cx q[36],q[35];
u1(pi/4) q[35];
h q[36];
u1(pi/274877906944) q[37];
cx q[37],q[0];
u1(-pi/274877906944) q[0];
cx q[37],q[0];
u1(pi/274877906944) q[0];
u1(pi/137438953472) q[37];
cx q[37],q[1];
u1(-pi/137438953472) q[1];
cx q[37],q[1];
u1(pi/137438953472) q[1];
u1(pi/68719476736) q[37];
cx q[37],q[2];
u1(-pi/68719476736) q[2];
cx q[37],q[2];
u1(pi/68719476736) q[2];
u1(pi/34359738368) q[37];
cx q[37],q[3];
u1(-pi/34359738368) q[3];
cx q[37],q[3];
u1(pi/34359738368) q[3];
u1(pi/17179869184) q[37];
cx q[37],q[4];
u1(-pi/17179869184) q[4];
cx q[37],q[4];
u1(pi/17179869184) q[4];
u1(pi/8589934592) q[37];
cx q[37],q[5];
u1(-pi/8589934592) q[5];
cx q[37],q[5];
u1(pi/8589934592) q[5];
u1(pi/4294967296) q[37];
cx q[37],q[6];
u1(-pi/4294967296) q[6];
cx q[37],q[6];
u1(pi/4294967296) q[6];
u1(pi/2147483648) q[37];
cx q[37],q[7];
u1(-pi/2147483648) q[7];
cx q[37],q[7];
u1(pi/2147483648) q[7];
u1(pi/1073741824) q[37];
cx q[37],q[8];
u1(-pi/1073741824) q[8];
cx q[37],q[8];
u1(pi/1073741824) q[8];
u1(pi/536870912) q[37];
cx q[37],q[9];
u1(-pi/536870912) q[9];
cx q[37],q[9];
u1(pi/536870912) q[9];
u1(pi/268435456) q[37];
cx q[37],q[10];
u1(-pi/268435456) q[10];
cx q[37],q[10];
u1(pi/268435456) q[10];
u1(pi/134217728) q[37];
cx q[37],q[11];
u1(-pi/134217728) q[11];
cx q[37],q[11];
u1(pi/134217728) q[11];
u1(pi/67108864) q[37];
cx q[37],q[12];
u1(-pi/67108864) q[12];
cx q[37],q[12];
u1(pi/67108864) q[12];
u1(pi/33554432) q[37];
cx q[37],q[13];
u1(-pi/33554432) q[13];
cx q[37],q[13];
u1(pi/33554432) q[13];
u1(pi/16777216) q[37];
cx q[37],q[14];
u1(-pi/16777216) q[14];
cx q[37],q[14];
u1(pi/16777216) q[14];
u1(pi/8388608) q[37];
cx q[37],q[15];
u1(-pi/8388608) q[15];
cx q[37],q[15];
u1(pi/8388608) q[15];
u1(pi/4194304) q[37];
cx q[37],q[16];
u1(-pi/4194304) q[16];
cx q[37],q[16];
u1(pi/4194304) q[16];
u1(pi/2097152) q[37];
cx q[37],q[17];
u1(-pi/2097152) q[17];
cx q[37],q[17];
u1(pi/2097152) q[17];
u1(pi/1048576) q[37];
cx q[37],q[18];
u1(-pi/1048576) q[18];
cx q[37],q[18];
u1(pi/1048576) q[18];
u1(pi/524288) q[37];
cx q[37],q[19];
u1(-pi/524288) q[19];
cx q[37],q[19];
u1(pi/524288) q[19];
u1(pi/262144) q[37];
cx q[37],q[20];
u1(-pi/262144) q[20];
cx q[37],q[20];
u1(pi/262144) q[20];
u1(pi/131072) q[37];
cx q[37],q[21];
u1(-pi/131072) q[21];
cx q[37],q[21];
u1(pi/131072) q[21];
u1(pi/65536) q[37];
cx q[37],q[22];
u1(-pi/65536) q[22];
cx q[37],q[22];
u1(pi/65536) q[22];
u1(pi/32768) q[37];
cx q[37],q[23];
u1(-pi/32768) q[23];
cx q[37],q[23];
u1(pi/32768) q[23];
u1(pi/16384) q[37];
cx q[37],q[24];
u1(-pi/16384) q[24];
cx q[37],q[24];
u1(pi/16384) q[24];
u1(pi/8192) q[37];
cx q[37],q[25];
u1(-pi/8192) q[25];
cx q[37],q[25];
u1(pi/8192) q[25];
u1(pi/4096) q[37];
cx q[37],q[26];
u1(-pi/4096) q[26];
cx q[37],q[26];
u1(pi/4096) q[26];
u1(pi/2048) q[37];
cx q[37],q[27];
u1(-pi/2048) q[27];
cx q[37],q[27];
u1(pi/2048) q[27];
u1(pi/1024) q[37];
cx q[37],q[28];
u1(-pi/1024) q[28];
cx q[37],q[28];
u1(pi/1024) q[28];
u1(pi/512) q[37];
cx q[37],q[29];
u1(-pi/512) q[29];
cx q[37],q[29];
u1(pi/512) q[29];
u1(pi/256) q[37];
cx q[37],q[30];
u1(-pi/256) q[30];
cx q[37],q[30];
u1(pi/256) q[30];
u1(pi/128) q[37];
cx q[37],q[31];
u1(-pi/128) q[31];
cx q[37],q[31];
u1(pi/128) q[31];
u1(pi/64) q[37];
cx q[37],q[32];
u1(-pi/64) q[32];
cx q[37],q[32];
u1(pi/64) q[32];
u1(pi/32) q[37];
cx q[37],q[33];
u1(-pi/32) q[33];
cx q[37],q[33];
u1(pi/32) q[33];
u1(pi/16) q[37];
cx q[37],q[34];
u1(-pi/16) q[34];
cx q[37],q[34];
u1(pi/16) q[34];
u1(pi/8) q[37];
cx q[37],q[35];
u1(-pi/8) q[35];
cx q[37],q[35];
u1(pi/8) q[35];
u1(pi/4) q[37];
cx q[37],q[36];
u1(-pi/4) q[36];
cx q[37],q[36];
u1(pi/4) q[36];
h q[37];
u1(pi/549755813888) q[38];
cx q[38],q[0];
u1(-pi/549755813888) q[0];
cx q[38],q[0];
u1(pi/549755813888) q[0];
u1(pi/274877906944) q[38];
cx q[38],q[1];
u1(-pi/274877906944) q[1];
cx q[38],q[1];
u1(pi/274877906944) q[1];
u1(pi/137438953472) q[38];
cx q[38],q[2];
u1(-pi/137438953472) q[2];
cx q[38],q[2];
u1(pi/137438953472) q[2];
u1(pi/68719476736) q[38];
cx q[38],q[3];
u1(-pi/68719476736) q[3];
cx q[38],q[3];
u1(pi/68719476736) q[3];
u1(pi/34359738368) q[38];
cx q[38],q[4];
u1(-pi/34359738368) q[4];
cx q[38],q[4];
u1(pi/34359738368) q[4];
u1(pi/17179869184) q[38];
cx q[38],q[5];
u1(-pi/17179869184) q[5];
cx q[38],q[5];
u1(pi/17179869184) q[5];
u1(pi/8589934592) q[38];
cx q[38],q[6];
u1(-pi/8589934592) q[6];
cx q[38],q[6];
u1(pi/8589934592) q[6];
u1(pi/4294967296) q[38];
cx q[38],q[7];
u1(-pi/4294967296) q[7];
cx q[38],q[7];
u1(pi/4294967296) q[7];
u1(pi/2147483648) q[38];
cx q[38],q[8];
u1(-pi/2147483648) q[8];
cx q[38],q[8];
u1(pi/2147483648) q[8];
u1(pi/1073741824) q[38];
cx q[38],q[9];
u1(-pi/1073741824) q[9];
cx q[38],q[9];
u1(pi/1073741824) q[9];
u1(pi/536870912) q[38];
cx q[38],q[10];
u1(-pi/536870912) q[10];
cx q[38],q[10];
u1(pi/536870912) q[10];
u1(pi/268435456) q[38];
cx q[38],q[11];
u1(-pi/268435456) q[11];
cx q[38],q[11];
u1(pi/268435456) q[11];
u1(pi/134217728) q[38];
cx q[38],q[12];
u1(-pi/134217728) q[12];
cx q[38],q[12];
u1(pi/134217728) q[12];
u1(pi/67108864) q[38];
cx q[38],q[13];
u1(-pi/67108864) q[13];
cx q[38],q[13];
u1(pi/67108864) q[13];
u1(pi/33554432) q[38];
cx q[38],q[14];
u1(-pi/33554432) q[14];
cx q[38],q[14];
u1(pi/33554432) q[14];
u1(pi/16777216) q[38];
cx q[38],q[15];
u1(-pi/16777216) q[15];
cx q[38],q[15];
u1(pi/16777216) q[15];
u1(pi/8388608) q[38];
cx q[38],q[16];
u1(-pi/8388608) q[16];
cx q[38],q[16];
u1(pi/8388608) q[16];
u1(pi/4194304) q[38];
cx q[38],q[17];
u1(-pi/4194304) q[17];
cx q[38],q[17];
u1(pi/4194304) q[17];
u1(pi/2097152) q[38];
cx q[38],q[18];
u1(-pi/2097152) q[18];
cx q[38],q[18];
u1(pi/2097152) q[18];
u1(pi/1048576) q[38];
cx q[38],q[19];
u1(-pi/1048576) q[19];
cx q[38],q[19];
u1(pi/1048576) q[19];
u1(pi/524288) q[38];
cx q[38],q[20];
u1(-pi/524288) q[20];
cx q[38],q[20];
u1(pi/524288) q[20];
u1(pi/262144) q[38];
cx q[38],q[21];
u1(-pi/262144) q[21];
cx q[38],q[21];
u1(pi/262144) q[21];
u1(pi/131072) q[38];
cx q[38],q[22];
u1(-pi/131072) q[22];
cx q[38],q[22];
u1(pi/131072) q[22];
u1(pi/65536) q[38];
cx q[38],q[23];
u1(-pi/65536) q[23];
cx q[38],q[23];
u1(pi/65536) q[23];
u1(pi/32768) q[38];
cx q[38],q[24];
u1(-pi/32768) q[24];
cx q[38],q[24];
u1(pi/32768) q[24];
u1(pi/16384) q[38];
cx q[38],q[25];
u1(-pi/16384) q[25];
cx q[38],q[25];
u1(pi/16384) q[25];
u1(pi/8192) q[38];
cx q[38],q[26];
u1(-pi/8192) q[26];
cx q[38],q[26];
u1(pi/8192) q[26];
u1(pi/4096) q[38];
cx q[38],q[27];
u1(-pi/4096) q[27];
cx q[38],q[27];
u1(pi/4096) q[27];
u1(pi/2048) q[38];
cx q[38],q[28];
u1(-pi/2048) q[28];
cx q[38],q[28];
u1(pi/2048) q[28];
u1(pi/1024) q[38];
cx q[38],q[29];
u1(-pi/1024) q[29];
cx q[38],q[29];
u1(pi/1024) q[29];
u1(pi/512) q[38];
cx q[38],q[30];
u1(-pi/512) q[30];
cx q[38],q[30];
u1(pi/512) q[30];
u1(pi/256) q[38];
cx q[38],q[31];
u1(-pi/256) q[31];
cx q[38],q[31];
u1(pi/256) q[31];
u1(pi/128) q[38];
cx q[38],q[32];
u1(-pi/128) q[32];
cx q[38],q[32];
u1(pi/128) q[32];
u1(pi/64) q[38];
cx q[38],q[33];
u1(-pi/64) q[33];
cx q[38],q[33];
u1(pi/64) q[33];
u1(pi/32) q[38];
cx q[38],q[34];
u1(-pi/32) q[34];
cx q[38],q[34];
u1(pi/32) q[34];
u1(pi/16) q[38];
cx q[38],q[35];
u1(-pi/16) q[35];
cx q[38],q[35];
u1(pi/16) q[35];
u1(pi/8) q[38];
cx q[38],q[36];
u1(-pi/8) q[36];
cx q[38],q[36];
u1(pi/8) q[36];
u1(pi/4) q[38];
cx q[38],q[37];
u1(-pi/4) q[37];
cx q[38],q[37];
u1(pi/4) q[37];
h q[38];
u1(pi/1099511627776) q[39];
cx q[39],q[0];
u1(-pi/1099511627776) q[0];
cx q[39],q[0];
u1(pi/1099511627776) q[0];
u1(pi/549755813888) q[39];
cx q[39],q[1];
u1(-pi/549755813888) q[1];
cx q[39],q[1];
u1(pi/549755813888) q[1];
u1(pi/274877906944) q[39];
cx q[39],q[2];
u1(-pi/274877906944) q[2];
cx q[39],q[2];
u1(pi/274877906944) q[2];
u1(pi/137438953472) q[39];
cx q[39],q[3];
u1(-pi/137438953472) q[3];
cx q[39],q[3];
u1(pi/137438953472) q[3];
u1(pi/68719476736) q[39];
cx q[39],q[4];
u1(-pi/68719476736) q[4];
cx q[39],q[4];
u1(pi/68719476736) q[4];
u1(pi/34359738368) q[39];
cx q[39],q[5];
u1(-pi/34359738368) q[5];
cx q[39],q[5];
u1(pi/34359738368) q[5];
u1(pi/17179869184) q[39];
cx q[39],q[6];
u1(-pi/17179869184) q[6];
cx q[39],q[6];
u1(pi/17179869184) q[6];
u1(pi/8589934592) q[39];
cx q[39],q[7];
u1(-pi/8589934592) q[7];
cx q[39],q[7];
u1(pi/8589934592) q[7];
u1(pi/4294967296) q[39];
cx q[39],q[8];
u1(-pi/4294967296) q[8];
cx q[39],q[8];
u1(pi/4294967296) q[8];
u1(pi/2147483648) q[39];
cx q[39],q[9];
u1(-pi/2147483648) q[9];
cx q[39],q[9];
u1(pi/2147483648) q[9];
u1(pi/1073741824) q[39];
cx q[39],q[10];
u1(-pi/1073741824) q[10];
cx q[39],q[10];
u1(pi/1073741824) q[10];
u1(pi/536870912) q[39];
cx q[39],q[11];
u1(-pi/536870912) q[11];
cx q[39],q[11];
u1(pi/536870912) q[11];
u1(pi/268435456) q[39];
cx q[39],q[12];
u1(-pi/268435456) q[12];
cx q[39],q[12];
u1(pi/268435456) q[12];
u1(pi/134217728) q[39];
cx q[39],q[13];
u1(-pi/134217728) q[13];
cx q[39],q[13];
u1(pi/134217728) q[13];
u1(pi/67108864) q[39];
cx q[39],q[14];
u1(-pi/67108864) q[14];
cx q[39],q[14];
u1(pi/67108864) q[14];
u1(pi/33554432) q[39];
cx q[39],q[15];
u1(-pi/33554432) q[15];
cx q[39],q[15];
u1(pi/33554432) q[15];
u1(pi/16777216) q[39];
cx q[39],q[16];
u1(-pi/16777216) q[16];
cx q[39],q[16];
u1(pi/16777216) q[16];
u1(pi/8388608) q[39];
cx q[39],q[17];
u1(-pi/8388608) q[17];
cx q[39],q[17];
u1(pi/8388608) q[17];
u1(pi/4194304) q[39];
cx q[39],q[18];
u1(-pi/4194304) q[18];
cx q[39],q[18];
u1(pi/4194304) q[18];
u1(pi/2097152) q[39];
cx q[39],q[19];
u1(-pi/2097152) q[19];
cx q[39],q[19];
u1(pi/2097152) q[19];
u1(pi/1048576) q[39];
cx q[39],q[20];
u1(-pi/1048576) q[20];
cx q[39],q[20];
u1(pi/1048576) q[20];
u1(pi/524288) q[39];
cx q[39],q[21];
u1(-pi/524288) q[21];
cx q[39],q[21];
u1(pi/524288) q[21];
u1(pi/262144) q[39];
cx q[39],q[22];
u1(-pi/262144) q[22];
cx q[39],q[22];
u1(pi/262144) q[22];
u1(pi/131072) q[39];
cx q[39],q[23];
u1(-pi/131072) q[23];
cx q[39],q[23];
u1(pi/131072) q[23];
u1(pi/65536) q[39];
cx q[39],q[24];
u1(-pi/65536) q[24];
cx q[39],q[24];
u1(pi/65536) q[24];
u1(pi/32768) q[39];
cx q[39],q[25];
u1(-pi/32768) q[25];
cx q[39],q[25];
u1(pi/32768) q[25];
u1(pi/16384) q[39];
cx q[39],q[26];
u1(-pi/16384) q[26];
cx q[39],q[26];
u1(pi/16384) q[26];
u1(pi/8192) q[39];
cx q[39],q[27];
u1(-pi/8192) q[27];
cx q[39],q[27];
u1(pi/8192) q[27];
u1(pi/4096) q[39];
cx q[39],q[28];
u1(-pi/4096) q[28];
cx q[39],q[28];
u1(pi/4096) q[28];
u1(pi/2048) q[39];
cx q[39],q[29];
u1(-pi/2048) q[29];
cx q[39],q[29];
u1(pi/2048) q[29];
u1(pi/1024) q[39];
cx q[39],q[30];
u1(-pi/1024) q[30];
cx q[39],q[30];
u1(pi/1024) q[30];
u1(pi/512) q[39];
cx q[39],q[31];
u1(-pi/512) q[31];
cx q[39],q[31];
u1(pi/512) q[31];
u1(pi/256) q[39];
cx q[39],q[32];
u1(-pi/256) q[32];
cx q[39],q[32];
u1(pi/256) q[32];
u1(pi/128) q[39];
cx q[39],q[33];
u1(-pi/128) q[33];
cx q[39],q[33];
u1(pi/128) q[33];
u1(pi/64) q[39];
cx q[39],q[34];
u1(-pi/64) q[34];
cx q[39],q[34];
u1(pi/64) q[34];
u1(pi/32) q[39];
cx q[39],q[35];
u1(-pi/32) q[35];
cx q[39],q[35];
u1(pi/32) q[35];
u1(pi/16) q[39];
cx q[39],q[36];
u1(-pi/16) q[36];
cx q[39],q[36];
u1(pi/16) q[36];
u1(pi/8) q[39];
cx q[39],q[37];
u1(-pi/8) q[37];
cx q[39],q[37];
u1(pi/8) q[37];
u1(pi/4) q[39];
cx q[39],q[38];
u1(-pi/4) q[38];
cx q[39],q[38];
u1(pi/4) q[38];
h q[39];
u1(pi/2199023255552) q[40];
cx q[40],q[0];
u1(-pi/2199023255552) q[0];
cx q[40],q[0];
u1(pi/2199023255552) q[0];
u1(pi/1099511627776) q[40];
cx q[40],q[1];
u1(-pi/1099511627776) q[1];
cx q[40],q[1];
u1(pi/1099511627776) q[1];
u1(pi/549755813888) q[40];
cx q[40],q[2];
u1(-pi/549755813888) q[2];
cx q[40],q[2];
u1(pi/549755813888) q[2];
u1(pi/274877906944) q[40];
cx q[40],q[3];
u1(-pi/274877906944) q[3];
cx q[40],q[3];
u1(pi/274877906944) q[3];
u1(pi/137438953472) q[40];
cx q[40],q[4];
u1(-pi/137438953472) q[4];
cx q[40],q[4];
u1(pi/137438953472) q[4];
u1(pi/68719476736) q[40];
cx q[40],q[5];
u1(-pi/68719476736) q[5];
cx q[40],q[5];
u1(pi/68719476736) q[5];
u1(pi/34359738368) q[40];
cx q[40],q[6];
u1(-pi/34359738368) q[6];
cx q[40],q[6];
u1(pi/34359738368) q[6];
u1(pi/17179869184) q[40];
cx q[40],q[7];
u1(-pi/17179869184) q[7];
cx q[40],q[7];
u1(pi/17179869184) q[7];
u1(pi/8589934592) q[40];
cx q[40],q[8];
u1(-pi/8589934592) q[8];
cx q[40],q[8];
u1(pi/8589934592) q[8];
u1(pi/4294967296) q[40];
cx q[40],q[9];
u1(-pi/4294967296) q[9];
cx q[40],q[9];
u1(pi/4294967296) q[9];
u1(pi/2147483648) q[40];
cx q[40],q[10];
u1(-pi/2147483648) q[10];
cx q[40],q[10];
u1(pi/2147483648) q[10];
u1(pi/1073741824) q[40];
cx q[40],q[11];
u1(-pi/1073741824) q[11];
cx q[40],q[11];
u1(pi/1073741824) q[11];
u1(pi/536870912) q[40];
cx q[40],q[12];
u1(-pi/536870912) q[12];
cx q[40],q[12];
u1(pi/536870912) q[12];
u1(pi/268435456) q[40];
cx q[40],q[13];
u1(-pi/268435456) q[13];
cx q[40],q[13];
u1(pi/268435456) q[13];
u1(pi/134217728) q[40];
cx q[40],q[14];
u1(-pi/134217728) q[14];
cx q[40],q[14];
u1(pi/134217728) q[14];
u1(pi/67108864) q[40];
cx q[40],q[15];
u1(-pi/67108864) q[15];
cx q[40],q[15];
u1(pi/67108864) q[15];
u1(pi/33554432) q[40];
cx q[40],q[16];
u1(-pi/33554432) q[16];
cx q[40],q[16];
u1(pi/33554432) q[16];
u1(pi/16777216) q[40];
cx q[40],q[17];
u1(-pi/16777216) q[17];
cx q[40],q[17];
u1(pi/16777216) q[17];
u1(pi/8388608) q[40];
cx q[40],q[18];
u1(-pi/8388608) q[18];
cx q[40],q[18];
u1(pi/8388608) q[18];
u1(pi/4194304) q[40];
cx q[40],q[19];
u1(-pi/4194304) q[19];
cx q[40],q[19];
u1(pi/4194304) q[19];
u1(pi/2097152) q[40];
cx q[40],q[20];
u1(-pi/2097152) q[20];
cx q[40],q[20];
u1(pi/2097152) q[20];
u1(pi/1048576) q[40];
cx q[40],q[21];
u1(-pi/1048576) q[21];
cx q[40],q[21];
u1(pi/1048576) q[21];
u1(pi/524288) q[40];
cx q[40],q[22];
u1(-pi/524288) q[22];
cx q[40],q[22];
u1(pi/524288) q[22];
u1(pi/262144) q[40];
cx q[40],q[23];
u1(-pi/262144) q[23];
cx q[40],q[23];
u1(pi/262144) q[23];
u1(pi/131072) q[40];
cx q[40],q[24];
u1(-pi/131072) q[24];
cx q[40],q[24];
u1(pi/131072) q[24];
u1(pi/65536) q[40];
cx q[40],q[25];
u1(-pi/65536) q[25];
cx q[40],q[25];
u1(pi/65536) q[25];
u1(pi/32768) q[40];
cx q[40],q[26];
u1(-pi/32768) q[26];
cx q[40],q[26];
u1(pi/32768) q[26];
u1(pi/16384) q[40];
cx q[40],q[27];
u1(-pi/16384) q[27];
cx q[40],q[27];
u1(pi/16384) q[27];
u1(pi/8192) q[40];
cx q[40],q[28];
u1(-pi/8192) q[28];
cx q[40],q[28];
u1(pi/8192) q[28];
u1(pi/4096) q[40];
cx q[40],q[29];
u1(-pi/4096) q[29];
cx q[40],q[29];
u1(pi/4096) q[29];
u1(pi/2048) q[40];
cx q[40],q[30];
u1(-pi/2048) q[30];
cx q[40],q[30];
u1(pi/2048) q[30];
u1(pi/1024) q[40];
cx q[40],q[31];
u1(-pi/1024) q[31];
cx q[40],q[31];
u1(pi/1024) q[31];
u1(pi/512) q[40];
cx q[40],q[32];
u1(-pi/512) q[32];
cx q[40],q[32];
u1(pi/512) q[32];
u1(pi/256) q[40];
cx q[40],q[33];
u1(-pi/256) q[33];
cx q[40],q[33];
u1(pi/256) q[33];
u1(pi/128) q[40];
cx q[40],q[34];
u1(-pi/128) q[34];
cx q[40],q[34];
u1(pi/128) q[34];
u1(pi/64) q[40];
cx q[40],q[35];
u1(-pi/64) q[35];
cx q[40],q[35];
u1(pi/64) q[35];
u1(pi/32) q[40];
cx q[40],q[36];
u1(-pi/32) q[36];
cx q[40],q[36];
u1(pi/32) q[36];
u1(pi/16) q[40];
cx q[40],q[37];
u1(-pi/16) q[37];
cx q[40],q[37];
u1(pi/16) q[37];
u1(pi/8) q[40];
cx q[40],q[38];
u1(-pi/8) q[38];
cx q[40],q[38];
u1(pi/8) q[38];
u1(pi/4) q[40];
cx q[40],q[39];
u1(-pi/4) q[39];
cx q[40],q[39];
u1(pi/4) q[39];
h q[40];
u1(pi/4398046511104) q[41];
cx q[41],q[0];
u1(-pi/4398046511104) q[0];
cx q[41],q[0];
u1(pi/4398046511104) q[0];
u1(pi/2199023255552) q[41];
cx q[41],q[1];
u1(-pi/2199023255552) q[1];
cx q[41],q[1];
u1(pi/2199023255552) q[1];
u1(pi/1099511627776) q[41];
cx q[41],q[2];
u1(-pi/1099511627776) q[2];
cx q[41],q[2];
u1(pi/1099511627776) q[2];
u1(pi/549755813888) q[41];
cx q[41],q[3];
u1(-pi/549755813888) q[3];
cx q[41],q[3];
u1(pi/549755813888) q[3];
u1(pi/274877906944) q[41];
cx q[41],q[4];
u1(-pi/274877906944) q[4];
cx q[41],q[4];
u1(pi/274877906944) q[4];
u1(pi/137438953472) q[41];
cx q[41],q[5];
u1(-pi/137438953472) q[5];
cx q[41],q[5];
u1(pi/137438953472) q[5];
u1(pi/68719476736) q[41];
cx q[41],q[6];
u1(-pi/68719476736) q[6];
cx q[41],q[6];
u1(pi/68719476736) q[6];
u1(pi/34359738368) q[41];
cx q[41],q[7];
u1(-pi/34359738368) q[7];
cx q[41],q[7];
u1(pi/34359738368) q[7];
u1(pi/17179869184) q[41];
cx q[41],q[8];
u1(-pi/17179869184) q[8];
cx q[41],q[8];
u1(pi/17179869184) q[8];
u1(pi/8589934592) q[41];
cx q[41],q[9];
u1(-pi/8589934592) q[9];
cx q[41],q[9];
u1(pi/8589934592) q[9];
u1(pi/4294967296) q[41];
cx q[41],q[10];
u1(-pi/4294967296) q[10];
cx q[41],q[10];
u1(pi/4294967296) q[10];
u1(pi/2147483648) q[41];
cx q[41],q[11];
u1(-pi/2147483648) q[11];
cx q[41],q[11];
u1(pi/2147483648) q[11];
u1(pi/1073741824) q[41];
cx q[41],q[12];
u1(-pi/1073741824) q[12];
cx q[41],q[12];
u1(pi/1073741824) q[12];
u1(pi/536870912) q[41];
cx q[41],q[13];
u1(-pi/536870912) q[13];
cx q[41],q[13];
u1(pi/536870912) q[13];
u1(pi/268435456) q[41];
cx q[41],q[14];
u1(-pi/268435456) q[14];
cx q[41],q[14];
u1(pi/268435456) q[14];
u1(pi/134217728) q[41];
cx q[41],q[15];
u1(-pi/134217728) q[15];
cx q[41],q[15];
u1(pi/134217728) q[15];
u1(pi/67108864) q[41];
cx q[41],q[16];
u1(-pi/67108864) q[16];
cx q[41],q[16];
u1(pi/67108864) q[16];
u1(pi/33554432) q[41];
cx q[41],q[17];
u1(-pi/33554432) q[17];
cx q[41],q[17];
u1(pi/33554432) q[17];
u1(pi/16777216) q[41];
cx q[41],q[18];
u1(-pi/16777216) q[18];
cx q[41],q[18];
u1(pi/16777216) q[18];
u1(pi/8388608) q[41];
cx q[41],q[19];
u1(-pi/8388608) q[19];
cx q[41],q[19];
u1(pi/8388608) q[19];
u1(pi/4194304) q[41];
cx q[41],q[20];
u1(-pi/4194304) q[20];
cx q[41],q[20];
u1(pi/4194304) q[20];
u1(pi/2097152) q[41];
cx q[41],q[21];
u1(-pi/2097152) q[21];
cx q[41],q[21];
u1(pi/2097152) q[21];
u1(pi/1048576) q[41];
cx q[41],q[22];
u1(-pi/1048576) q[22];
cx q[41],q[22];
u1(pi/1048576) q[22];
u1(pi/524288) q[41];
cx q[41],q[23];
u1(-pi/524288) q[23];
cx q[41],q[23];
u1(pi/524288) q[23];
u1(pi/262144) q[41];
cx q[41],q[24];
u1(-pi/262144) q[24];
cx q[41],q[24];
u1(pi/262144) q[24];
u1(pi/131072) q[41];
cx q[41],q[25];
u1(-pi/131072) q[25];
cx q[41],q[25];
u1(pi/131072) q[25];
u1(pi/65536) q[41];
cx q[41],q[26];
u1(-pi/65536) q[26];
cx q[41],q[26];
u1(pi/65536) q[26];
u1(pi/32768) q[41];
cx q[41],q[27];
u1(-pi/32768) q[27];
cx q[41],q[27];
u1(pi/32768) q[27];
u1(pi/16384) q[41];
cx q[41],q[28];
u1(-pi/16384) q[28];
cx q[41],q[28];
u1(pi/16384) q[28];
u1(pi/8192) q[41];
cx q[41],q[29];
u1(-pi/8192) q[29];
cx q[41],q[29];
u1(pi/8192) q[29];
u1(pi/4096) q[41];
cx q[41],q[30];
u1(-pi/4096) q[30];
cx q[41],q[30];
u1(pi/4096) q[30];
u1(pi/2048) q[41];
cx q[41],q[31];
u1(-pi/2048) q[31];
cx q[41],q[31];
u1(pi/2048) q[31];
u1(pi/1024) q[41];
cx q[41],q[32];
u1(-pi/1024) q[32];
cx q[41],q[32];
u1(pi/1024) q[32];
u1(pi/512) q[41];
cx q[41],q[33];
u1(-pi/512) q[33];
cx q[41],q[33];
u1(pi/512) q[33];
u1(pi/256) q[41];
cx q[41],q[34];
u1(-pi/256) q[34];
cx q[41],q[34];
u1(pi/256) q[34];
u1(pi/128) q[41];
cx q[41],q[35];
u1(-pi/128) q[35];
cx q[41],q[35];
u1(pi/128) q[35];
u1(pi/64) q[41];
cx q[41],q[36];
u1(-pi/64) q[36];
cx q[41],q[36];
u1(pi/64) q[36];
u1(pi/32) q[41];
cx q[41],q[37];
u1(-pi/32) q[37];
cx q[41],q[37];
u1(pi/32) q[37];
u1(pi/16) q[41];
cx q[41],q[38];
u1(-pi/16) q[38];
cx q[41],q[38];
u1(pi/16) q[38];
u1(pi/8) q[41];
cx q[41],q[39];
u1(-pi/8) q[39];
cx q[41],q[39];
u1(pi/8) q[39];
u1(pi/4) q[41];
cx q[41],q[40];
u1(-pi/4) q[40];
cx q[41],q[40];
u1(pi/4) q[40];
h q[41];
u1(pi/8796093022208) q[42];
cx q[42],q[0];
u1(-pi/8796093022208) q[0];
cx q[42],q[0];
u1(pi/8796093022208) q[0];
u1(pi/4398046511104) q[42];
cx q[42],q[1];
u1(-pi/4398046511104) q[1];
cx q[42],q[1];
u1(pi/4398046511104) q[1];
u1(pi/2199023255552) q[42];
cx q[42],q[2];
u1(-pi/2199023255552) q[2];
cx q[42],q[2];
u1(pi/2199023255552) q[2];
u1(pi/1099511627776) q[42];
cx q[42],q[3];
u1(-pi/1099511627776) q[3];
cx q[42],q[3];
u1(pi/1099511627776) q[3];
u1(pi/549755813888) q[42];
cx q[42],q[4];
u1(-pi/549755813888) q[4];
cx q[42],q[4];
u1(pi/549755813888) q[4];
u1(pi/274877906944) q[42];
cx q[42],q[5];
u1(-pi/274877906944) q[5];
cx q[42],q[5];
u1(pi/274877906944) q[5];
u1(pi/137438953472) q[42];
cx q[42],q[6];
u1(-pi/137438953472) q[6];
cx q[42],q[6];
u1(pi/137438953472) q[6];
u1(pi/68719476736) q[42];
cx q[42],q[7];
u1(-pi/68719476736) q[7];
cx q[42],q[7];
u1(pi/68719476736) q[7];
u1(pi/34359738368) q[42];
cx q[42],q[8];
u1(-pi/34359738368) q[8];
cx q[42],q[8];
u1(pi/34359738368) q[8];
u1(pi/17179869184) q[42];
cx q[42],q[9];
u1(-pi/17179869184) q[9];
cx q[42],q[9];
u1(pi/17179869184) q[9];
u1(pi/8589934592) q[42];
cx q[42],q[10];
u1(-pi/8589934592) q[10];
cx q[42],q[10];
u1(pi/8589934592) q[10];
u1(pi/4294967296) q[42];
cx q[42],q[11];
u1(-pi/4294967296) q[11];
cx q[42],q[11];
u1(pi/4294967296) q[11];
u1(pi/2147483648) q[42];
cx q[42],q[12];
u1(-pi/2147483648) q[12];
cx q[42],q[12];
u1(pi/2147483648) q[12];
u1(pi/1073741824) q[42];
cx q[42],q[13];
u1(-pi/1073741824) q[13];
cx q[42],q[13];
u1(pi/1073741824) q[13];
u1(pi/536870912) q[42];
cx q[42],q[14];
u1(-pi/536870912) q[14];
cx q[42],q[14];
u1(pi/536870912) q[14];
u1(pi/268435456) q[42];
cx q[42],q[15];
u1(-pi/268435456) q[15];
cx q[42],q[15];
u1(pi/268435456) q[15];
u1(pi/134217728) q[42];
cx q[42],q[16];
u1(-pi/134217728) q[16];
cx q[42],q[16];
u1(pi/134217728) q[16];
u1(pi/67108864) q[42];
cx q[42],q[17];
u1(-pi/67108864) q[17];
cx q[42],q[17];
u1(pi/67108864) q[17];
u1(pi/33554432) q[42];
cx q[42],q[18];
u1(-pi/33554432) q[18];
cx q[42],q[18];
u1(pi/33554432) q[18];
u1(pi/16777216) q[42];
cx q[42],q[19];
u1(-pi/16777216) q[19];
cx q[42],q[19];
u1(pi/16777216) q[19];
u1(pi/8388608) q[42];
cx q[42],q[20];
u1(-pi/8388608) q[20];
cx q[42],q[20];
u1(pi/8388608) q[20];
u1(pi/4194304) q[42];
cx q[42],q[21];
u1(-pi/4194304) q[21];
cx q[42],q[21];
u1(pi/4194304) q[21];
u1(pi/2097152) q[42];
cx q[42],q[22];
u1(-pi/2097152) q[22];
cx q[42],q[22];
u1(pi/2097152) q[22];
u1(pi/1048576) q[42];
cx q[42],q[23];
u1(-pi/1048576) q[23];
cx q[42],q[23];
u1(pi/1048576) q[23];
u1(pi/524288) q[42];
cx q[42],q[24];
u1(-pi/524288) q[24];
cx q[42],q[24];
u1(pi/524288) q[24];
u1(pi/262144) q[42];
cx q[42],q[25];
u1(-pi/262144) q[25];
cx q[42],q[25];
u1(pi/262144) q[25];
u1(pi/131072) q[42];
cx q[42],q[26];
u1(-pi/131072) q[26];
cx q[42],q[26];
u1(pi/131072) q[26];
u1(pi/65536) q[42];
cx q[42],q[27];
u1(-pi/65536) q[27];
cx q[42],q[27];
u1(pi/65536) q[27];
u1(pi/32768) q[42];
cx q[42],q[28];
u1(-pi/32768) q[28];
cx q[42],q[28];
u1(pi/32768) q[28];
u1(pi/16384) q[42];
cx q[42],q[29];
u1(-pi/16384) q[29];
cx q[42],q[29];
u1(pi/16384) q[29];
u1(pi/8192) q[42];
cx q[42],q[30];
u1(-pi/8192) q[30];
cx q[42],q[30];
u1(pi/8192) q[30];
u1(pi/4096) q[42];
cx q[42],q[31];
u1(-pi/4096) q[31];
cx q[42],q[31];
u1(pi/4096) q[31];
u1(pi/2048) q[42];
cx q[42],q[32];
u1(-pi/2048) q[32];
cx q[42],q[32];
u1(pi/2048) q[32];
u1(pi/1024) q[42];
cx q[42],q[33];
u1(-pi/1024) q[33];
cx q[42],q[33];
u1(pi/1024) q[33];
u1(pi/512) q[42];
cx q[42],q[34];
u1(-pi/512) q[34];
cx q[42],q[34];
u1(pi/512) q[34];
u1(pi/256) q[42];
cx q[42],q[35];
u1(-pi/256) q[35];
cx q[42],q[35];
u1(pi/256) q[35];
u1(pi/128) q[42];
cx q[42],q[36];
u1(-pi/128) q[36];
cx q[42],q[36];
u1(pi/128) q[36];
u1(pi/64) q[42];
cx q[42],q[37];
u1(-pi/64) q[37];
cx q[42],q[37];
u1(pi/64) q[37];
u1(pi/32) q[42];
cx q[42],q[38];
u1(-pi/32) q[38];
cx q[42],q[38];
u1(pi/32) q[38];
u1(pi/16) q[42];
cx q[42],q[39];
u1(-pi/16) q[39];
cx q[42],q[39];
u1(pi/16) q[39];
u1(pi/8) q[42];
cx q[42],q[40];
u1(-pi/8) q[40];
cx q[42],q[40];
u1(pi/8) q[40];
u1(pi/4) q[42];
cx q[42],q[41];
u1(-pi/4) q[41];
cx q[42],q[41];
u1(pi/4) q[41];
h q[42];
u1(pi/17592186044416) q[43];
cx q[43],q[0];
u1(-pi/17592186044416) q[0];
cx q[43],q[0];
u1(pi/17592186044416) q[0];
u1(pi/8796093022208) q[43];
cx q[43],q[1];
u1(-pi/8796093022208) q[1];
cx q[43],q[1];
u1(pi/8796093022208) q[1];
u1(pi/4398046511104) q[43];
cx q[43],q[2];
u1(-pi/4398046511104) q[2];
cx q[43],q[2];
u1(pi/4398046511104) q[2];
u1(pi/2199023255552) q[43];
cx q[43],q[3];
u1(-pi/2199023255552) q[3];
cx q[43],q[3];
u1(pi/2199023255552) q[3];
u1(pi/1099511627776) q[43];
cx q[43],q[4];
u1(-pi/1099511627776) q[4];
cx q[43],q[4];
u1(pi/1099511627776) q[4];
u1(pi/549755813888) q[43];
cx q[43],q[5];
u1(-pi/549755813888) q[5];
cx q[43],q[5];
u1(pi/549755813888) q[5];
u1(pi/274877906944) q[43];
cx q[43],q[6];
u1(-pi/274877906944) q[6];
cx q[43],q[6];
u1(pi/274877906944) q[6];
u1(pi/137438953472) q[43];
cx q[43],q[7];
u1(-pi/137438953472) q[7];
cx q[43],q[7];
u1(pi/137438953472) q[7];
u1(pi/68719476736) q[43];
cx q[43],q[8];
u1(-pi/68719476736) q[8];
cx q[43],q[8];
u1(pi/68719476736) q[8];
u1(pi/34359738368) q[43];
cx q[43],q[9];
u1(-pi/34359738368) q[9];
cx q[43],q[9];
u1(pi/34359738368) q[9];
u1(pi/17179869184) q[43];
cx q[43],q[10];
u1(-pi/17179869184) q[10];
cx q[43],q[10];
u1(pi/17179869184) q[10];
u1(pi/8589934592) q[43];
cx q[43],q[11];
u1(-pi/8589934592) q[11];
cx q[43],q[11];
u1(pi/8589934592) q[11];
u1(pi/4294967296) q[43];
cx q[43],q[12];
u1(-pi/4294967296) q[12];
cx q[43],q[12];
u1(pi/4294967296) q[12];
u1(pi/2147483648) q[43];
cx q[43],q[13];
u1(-pi/2147483648) q[13];
cx q[43],q[13];
u1(pi/2147483648) q[13];
u1(pi/1073741824) q[43];
cx q[43],q[14];
u1(-pi/1073741824) q[14];
cx q[43],q[14];
u1(pi/1073741824) q[14];
u1(pi/536870912) q[43];
cx q[43],q[15];
u1(-pi/536870912) q[15];
cx q[43],q[15];
u1(pi/536870912) q[15];
u1(pi/268435456) q[43];
cx q[43],q[16];
u1(-pi/268435456) q[16];
cx q[43],q[16];
u1(pi/268435456) q[16];
u1(pi/134217728) q[43];
cx q[43],q[17];
u1(-pi/134217728) q[17];
cx q[43],q[17];
u1(pi/134217728) q[17];
u1(pi/67108864) q[43];
cx q[43],q[18];
u1(-pi/67108864) q[18];
cx q[43],q[18];
u1(pi/67108864) q[18];
u1(pi/33554432) q[43];
cx q[43],q[19];
u1(-pi/33554432) q[19];
cx q[43],q[19];
u1(pi/33554432) q[19];
u1(pi/16777216) q[43];
cx q[43],q[20];
u1(-pi/16777216) q[20];
cx q[43],q[20];
u1(pi/16777216) q[20];
u1(pi/8388608) q[43];
cx q[43],q[21];
u1(-pi/8388608) q[21];
cx q[43],q[21];
u1(pi/8388608) q[21];
u1(pi/4194304) q[43];
cx q[43],q[22];
u1(-pi/4194304) q[22];
cx q[43],q[22];
u1(pi/4194304) q[22];
u1(pi/2097152) q[43];
cx q[43],q[23];
u1(-pi/2097152) q[23];
cx q[43],q[23];
u1(pi/2097152) q[23];
u1(pi/1048576) q[43];
cx q[43],q[24];
u1(-pi/1048576) q[24];
cx q[43],q[24];
u1(pi/1048576) q[24];
u1(pi/524288) q[43];
cx q[43],q[25];
u1(-pi/524288) q[25];
cx q[43],q[25];
u1(pi/524288) q[25];
u1(pi/262144) q[43];
cx q[43],q[26];
u1(-pi/262144) q[26];
cx q[43],q[26];
u1(pi/262144) q[26];
u1(pi/131072) q[43];
cx q[43],q[27];
u1(-pi/131072) q[27];
cx q[43],q[27];
u1(pi/131072) q[27];
u1(pi/65536) q[43];
cx q[43],q[28];
u1(-pi/65536) q[28];
cx q[43],q[28];
u1(pi/65536) q[28];
u1(pi/32768) q[43];
cx q[43],q[29];
u1(-pi/32768) q[29];
cx q[43],q[29];
u1(pi/32768) q[29];
u1(pi/16384) q[43];
cx q[43],q[30];
u1(-pi/16384) q[30];
cx q[43],q[30];
u1(pi/16384) q[30];
u1(pi/8192) q[43];
cx q[43],q[31];
u1(-pi/8192) q[31];
cx q[43],q[31];
u1(pi/8192) q[31];
u1(pi/4096) q[43];
cx q[43],q[32];
u1(-pi/4096) q[32];
cx q[43],q[32];
u1(pi/4096) q[32];
u1(pi/2048) q[43];
cx q[43],q[33];
u1(-pi/2048) q[33];
cx q[43],q[33];
u1(pi/2048) q[33];
u1(pi/1024) q[43];
cx q[43],q[34];
u1(-pi/1024) q[34];
cx q[43],q[34];
u1(pi/1024) q[34];
u1(pi/512) q[43];
cx q[43],q[35];
u1(-pi/512) q[35];
cx q[43],q[35];
u1(pi/512) q[35];
u1(pi/256) q[43];
cx q[43],q[36];
u1(-pi/256) q[36];
cx q[43],q[36];
u1(pi/256) q[36];
u1(pi/128) q[43];
cx q[43],q[37];
u1(-pi/128) q[37];
cx q[43],q[37];
u1(pi/128) q[37];
u1(pi/64) q[43];
cx q[43],q[38];
u1(-pi/64) q[38];
cx q[43],q[38];
u1(pi/64) q[38];
u1(pi/32) q[43];
cx q[43],q[39];
u1(-pi/32) q[39];
cx q[43],q[39];
u1(pi/32) q[39];
u1(pi/16) q[43];
cx q[43],q[40];
u1(-pi/16) q[40];
cx q[43],q[40];
u1(pi/16) q[40];
u1(pi/8) q[43];
cx q[43],q[41];
u1(-pi/8) q[41];
cx q[43],q[41];
u1(pi/8) q[41];
u1(pi/4) q[43];
cx q[43],q[42];
u1(-pi/4) q[42];
cx q[43],q[42];
u1(pi/4) q[42];
h q[43];
u1(pi/35184372088832) q[44];
cx q[44],q[0];
u1(-pi/35184372088832) q[0];
cx q[44],q[0];
u1(pi/35184372088832) q[0];
u1(pi/17592186044416) q[44];
cx q[44],q[1];
u1(-pi/17592186044416) q[1];
cx q[44],q[1];
u1(pi/17592186044416) q[1];
u1(pi/8796093022208) q[44];
cx q[44],q[2];
u1(-pi/8796093022208) q[2];
cx q[44],q[2];
u1(pi/8796093022208) q[2];
u1(pi/4398046511104) q[44];
cx q[44],q[3];
u1(-pi/4398046511104) q[3];
cx q[44],q[3];
u1(pi/4398046511104) q[3];
u1(pi/2199023255552) q[44];
cx q[44],q[4];
u1(-pi/2199023255552) q[4];
cx q[44],q[4];
u1(pi/2199023255552) q[4];
u1(pi/1099511627776) q[44];
cx q[44],q[5];
u1(-pi/1099511627776) q[5];
cx q[44],q[5];
u1(pi/1099511627776) q[5];
u1(pi/549755813888) q[44];
cx q[44],q[6];
u1(-pi/549755813888) q[6];
cx q[44],q[6];
u1(pi/549755813888) q[6];
u1(pi/274877906944) q[44];
cx q[44],q[7];
u1(-pi/274877906944) q[7];
cx q[44],q[7];
u1(pi/274877906944) q[7];
u1(pi/137438953472) q[44];
cx q[44],q[8];
u1(-pi/137438953472) q[8];
cx q[44],q[8];
u1(pi/137438953472) q[8];
u1(pi/68719476736) q[44];
cx q[44],q[9];
u1(-pi/68719476736) q[9];
cx q[44],q[9];
u1(pi/68719476736) q[9];
u1(pi/34359738368) q[44];
cx q[44],q[10];
u1(-pi/34359738368) q[10];
cx q[44],q[10];
u1(pi/34359738368) q[10];
u1(pi/17179869184) q[44];
cx q[44],q[11];
u1(-pi/17179869184) q[11];
cx q[44],q[11];
u1(pi/17179869184) q[11];
u1(pi/8589934592) q[44];
cx q[44],q[12];
u1(-pi/8589934592) q[12];
cx q[44],q[12];
u1(pi/8589934592) q[12];
u1(pi/4294967296) q[44];
cx q[44],q[13];
u1(-pi/4294967296) q[13];
cx q[44],q[13];
u1(pi/4294967296) q[13];
u1(pi/2147483648) q[44];
cx q[44],q[14];
u1(-pi/2147483648) q[14];
cx q[44],q[14];
u1(pi/2147483648) q[14];
u1(pi/1073741824) q[44];
cx q[44],q[15];
u1(-pi/1073741824) q[15];
cx q[44],q[15];
u1(pi/1073741824) q[15];
u1(pi/536870912) q[44];
cx q[44],q[16];
u1(-pi/536870912) q[16];
cx q[44],q[16];
u1(pi/536870912) q[16];
u1(pi/268435456) q[44];
cx q[44],q[17];
u1(-pi/268435456) q[17];
cx q[44],q[17];
u1(pi/268435456) q[17];
u1(pi/134217728) q[44];
cx q[44],q[18];
u1(-pi/134217728) q[18];
cx q[44],q[18];
u1(pi/134217728) q[18];
u1(pi/67108864) q[44];
cx q[44],q[19];
u1(-pi/67108864) q[19];
cx q[44],q[19];
u1(pi/67108864) q[19];
u1(pi/33554432) q[44];
cx q[44],q[20];
u1(-pi/33554432) q[20];
cx q[44],q[20];
u1(pi/33554432) q[20];
u1(pi/16777216) q[44];
cx q[44],q[21];
u1(-pi/16777216) q[21];
cx q[44],q[21];
u1(pi/16777216) q[21];
u1(pi/8388608) q[44];
cx q[44],q[22];
u1(-pi/8388608) q[22];
cx q[44],q[22];
u1(pi/8388608) q[22];
u1(pi/4194304) q[44];
cx q[44],q[23];
u1(-pi/4194304) q[23];
cx q[44],q[23];
u1(pi/4194304) q[23];
u1(pi/2097152) q[44];
cx q[44],q[24];
u1(-pi/2097152) q[24];
cx q[44],q[24];
u1(pi/2097152) q[24];
u1(pi/1048576) q[44];
cx q[44],q[25];
u1(-pi/1048576) q[25];
cx q[44],q[25];
u1(pi/1048576) q[25];
u1(pi/524288) q[44];
cx q[44],q[26];
u1(-pi/524288) q[26];
cx q[44],q[26];
u1(pi/524288) q[26];
u1(pi/262144) q[44];
cx q[44],q[27];
u1(-pi/262144) q[27];
cx q[44],q[27];
u1(pi/262144) q[27];
u1(pi/131072) q[44];
cx q[44],q[28];
u1(-pi/131072) q[28];
cx q[44],q[28];
u1(pi/131072) q[28];
u1(pi/65536) q[44];
cx q[44],q[29];
u1(-pi/65536) q[29];
cx q[44],q[29];
u1(pi/65536) q[29];
u1(pi/32768) q[44];
cx q[44],q[30];
u1(-pi/32768) q[30];
cx q[44],q[30];
u1(pi/32768) q[30];
u1(pi/16384) q[44];
cx q[44],q[31];
u1(-pi/16384) q[31];
cx q[44],q[31];
u1(pi/16384) q[31];
u1(pi/8192) q[44];
cx q[44],q[32];
u1(-pi/8192) q[32];
cx q[44],q[32];
u1(pi/8192) q[32];
u1(pi/4096) q[44];
cx q[44],q[33];
u1(-pi/4096) q[33];
cx q[44],q[33];
u1(pi/4096) q[33];
u1(pi/2048) q[44];
cx q[44],q[34];
u1(-pi/2048) q[34];
cx q[44],q[34];
u1(pi/2048) q[34];
u1(pi/1024) q[44];
cx q[44],q[35];
u1(-pi/1024) q[35];
cx q[44],q[35];
u1(pi/1024) q[35];
u1(pi/512) q[44];
cx q[44],q[36];
u1(-pi/512) q[36];
cx q[44],q[36];
u1(pi/512) q[36];
u1(pi/256) q[44];
cx q[44],q[37];
u1(-pi/256) q[37];
cx q[44],q[37];
u1(pi/256) q[37];
u1(pi/128) q[44];
cx q[44],q[38];
u1(-pi/128) q[38];
cx q[44],q[38];
u1(pi/128) q[38];
u1(pi/64) q[44];
cx q[44],q[39];
u1(-pi/64) q[39];
cx q[44],q[39];
u1(pi/64) q[39];
u1(pi/32) q[44];
cx q[44],q[40];
u1(-pi/32) q[40];
cx q[44],q[40];
u1(pi/32) q[40];
u1(pi/16) q[44];
cx q[44],q[41];
u1(-pi/16) q[41];
cx q[44],q[41];
u1(pi/16) q[41];
u1(pi/8) q[44];
cx q[44],q[42];
u1(-pi/8) q[42];
cx q[44],q[42];
u1(pi/8) q[42];
u1(pi/4) q[44];
cx q[44],q[43];
u1(-pi/4) q[43];
cx q[44],q[43];
u1(pi/4) q[43];
h q[44];
u1(pi/70368744177664) q[45];
cx q[45],q[0];
u1(-pi/70368744177664) q[0];
cx q[45],q[0];
u1(pi/70368744177664) q[0];
u1(pi/35184372088832) q[45];
cx q[45],q[1];
u1(-pi/35184372088832) q[1];
cx q[45],q[1];
u1(pi/35184372088832) q[1];
u1(pi/17592186044416) q[45];
cx q[45],q[2];
u1(-pi/17592186044416) q[2];
cx q[45],q[2];
u1(pi/17592186044416) q[2];
u1(pi/8796093022208) q[45];
cx q[45],q[3];
u1(-pi/8796093022208) q[3];
cx q[45],q[3];
u1(pi/8796093022208) q[3];
u1(pi/4398046511104) q[45];
cx q[45],q[4];
u1(-pi/4398046511104) q[4];
cx q[45],q[4];
u1(pi/4398046511104) q[4];
u1(pi/2199023255552) q[45];
cx q[45],q[5];
u1(-pi/2199023255552) q[5];
cx q[45],q[5];
u1(pi/2199023255552) q[5];
u1(pi/1099511627776) q[45];
cx q[45],q[6];
u1(-pi/1099511627776) q[6];
cx q[45],q[6];
u1(pi/1099511627776) q[6];
u1(pi/549755813888) q[45];
cx q[45],q[7];
u1(-pi/549755813888) q[7];
cx q[45],q[7];
u1(pi/549755813888) q[7];
u1(pi/274877906944) q[45];
cx q[45],q[8];
u1(-pi/274877906944) q[8];
cx q[45],q[8];
u1(pi/274877906944) q[8];
u1(pi/137438953472) q[45];
cx q[45],q[9];
u1(-pi/137438953472) q[9];
cx q[45],q[9];
u1(pi/137438953472) q[9];
u1(pi/68719476736) q[45];
cx q[45],q[10];
u1(-pi/68719476736) q[10];
cx q[45],q[10];
u1(pi/68719476736) q[10];
u1(pi/34359738368) q[45];
cx q[45],q[11];
u1(-pi/34359738368) q[11];
cx q[45],q[11];
u1(pi/34359738368) q[11];
u1(pi/17179869184) q[45];
cx q[45],q[12];
u1(-pi/17179869184) q[12];
cx q[45],q[12];
u1(pi/17179869184) q[12];
u1(pi/8589934592) q[45];
cx q[45],q[13];
u1(-pi/8589934592) q[13];
cx q[45],q[13];
u1(pi/8589934592) q[13];
u1(pi/4294967296) q[45];
cx q[45],q[14];
u1(-pi/4294967296) q[14];
cx q[45],q[14];
u1(pi/4294967296) q[14];
u1(pi/2147483648) q[45];
cx q[45],q[15];
u1(-pi/2147483648) q[15];
cx q[45],q[15];
u1(pi/2147483648) q[15];
u1(pi/1073741824) q[45];
cx q[45],q[16];
u1(-pi/1073741824) q[16];
cx q[45],q[16];
u1(pi/1073741824) q[16];
u1(pi/536870912) q[45];
cx q[45],q[17];
u1(-pi/536870912) q[17];
cx q[45],q[17];
u1(pi/536870912) q[17];
u1(pi/268435456) q[45];
cx q[45],q[18];
u1(-pi/268435456) q[18];
cx q[45],q[18];
u1(pi/268435456) q[18];
u1(pi/134217728) q[45];
cx q[45],q[19];
u1(-pi/134217728) q[19];
cx q[45],q[19];
u1(pi/134217728) q[19];
u1(pi/67108864) q[45];
cx q[45],q[20];
u1(-pi/67108864) q[20];
cx q[45],q[20];
u1(pi/67108864) q[20];
u1(pi/33554432) q[45];
cx q[45],q[21];
u1(-pi/33554432) q[21];
cx q[45],q[21];
u1(pi/33554432) q[21];
u1(pi/16777216) q[45];
cx q[45],q[22];
u1(-pi/16777216) q[22];
cx q[45],q[22];
u1(pi/16777216) q[22];
u1(pi/8388608) q[45];
cx q[45],q[23];
u1(-pi/8388608) q[23];
cx q[45],q[23];
u1(pi/8388608) q[23];
u1(pi/4194304) q[45];
cx q[45],q[24];
u1(-pi/4194304) q[24];
cx q[45],q[24];
u1(pi/4194304) q[24];
u1(pi/2097152) q[45];
cx q[45],q[25];
u1(-pi/2097152) q[25];
cx q[45],q[25];
u1(pi/2097152) q[25];
u1(pi/1048576) q[45];
cx q[45],q[26];
u1(-pi/1048576) q[26];
cx q[45],q[26];
u1(pi/1048576) q[26];
u1(pi/524288) q[45];
cx q[45],q[27];
u1(-pi/524288) q[27];
cx q[45],q[27];
u1(pi/524288) q[27];
u1(pi/262144) q[45];
cx q[45],q[28];
u1(-pi/262144) q[28];
cx q[45],q[28];
u1(pi/262144) q[28];
u1(pi/131072) q[45];
cx q[45],q[29];
u1(-pi/131072) q[29];
cx q[45],q[29];
u1(pi/131072) q[29];
u1(pi/65536) q[45];
cx q[45],q[30];
u1(-pi/65536) q[30];
cx q[45],q[30];
u1(pi/65536) q[30];
u1(pi/32768) q[45];
cx q[45],q[31];
u1(-pi/32768) q[31];
cx q[45],q[31];
u1(pi/32768) q[31];
u1(pi/16384) q[45];
cx q[45],q[32];
u1(-pi/16384) q[32];
cx q[45],q[32];
u1(pi/16384) q[32];
u1(pi/8192) q[45];
cx q[45],q[33];
u1(-pi/8192) q[33];
cx q[45],q[33];
u1(pi/8192) q[33];
u1(pi/4096) q[45];
cx q[45],q[34];
u1(-pi/4096) q[34];
cx q[45],q[34];
u1(pi/4096) q[34];
u1(pi/2048) q[45];
cx q[45],q[35];
u1(-pi/2048) q[35];
cx q[45],q[35];
u1(pi/2048) q[35];
u1(pi/1024) q[45];
cx q[45],q[36];
u1(-pi/1024) q[36];
cx q[45],q[36];
u1(pi/1024) q[36];
u1(pi/512) q[45];
cx q[45],q[37];
u1(-pi/512) q[37];
cx q[45],q[37];
u1(pi/512) q[37];
u1(pi/256) q[45];
cx q[45],q[38];
u1(-pi/256) q[38];
cx q[45],q[38];
u1(pi/256) q[38];
u1(pi/128) q[45];
cx q[45],q[39];
u1(-pi/128) q[39];
cx q[45],q[39];
u1(pi/128) q[39];
u1(pi/64) q[45];
cx q[45],q[40];
u1(-pi/64) q[40];
cx q[45],q[40];
u1(pi/64) q[40];
u1(pi/32) q[45];
cx q[45],q[41];
u1(-pi/32) q[41];
cx q[45],q[41];
u1(pi/32) q[41];
u1(pi/16) q[45];
cx q[45],q[42];
u1(-pi/16) q[42];
cx q[45],q[42];
u1(pi/16) q[42];
u1(pi/8) q[45];
cx q[45],q[43];
u1(-pi/8) q[43];
cx q[45],q[43];
u1(pi/8) q[43];
u1(pi/4) q[45];
cx q[45],q[44];
u1(-pi/4) q[44];
cx q[45],q[44];
u1(pi/4) q[44];
h q[45];
u1(pi/140737488355328) q[46];
cx q[46],q[0];
u1(-pi/140737488355328) q[0];
cx q[46],q[0];
u1(pi/140737488355328) q[0];
u1(pi/70368744177664) q[46];
cx q[46],q[1];
u1(-pi/70368744177664) q[1];
cx q[46],q[1];
u1(pi/70368744177664) q[1];
u1(pi/35184372088832) q[46];
cx q[46],q[2];
u1(-pi/35184372088832) q[2];
cx q[46],q[2];
u1(pi/35184372088832) q[2];
u1(pi/17592186044416) q[46];
cx q[46],q[3];
u1(-pi/17592186044416) q[3];
cx q[46],q[3];
u1(pi/17592186044416) q[3];
u1(pi/8796093022208) q[46];
cx q[46],q[4];
u1(-pi/8796093022208) q[4];
cx q[46],q[4];
u1(pi/8796093022208) q[4];
u1(pi/4398046511104) q[46];
cx q[46],q[5];
u1(-pi/4398046511104) q[5];
cx q[46],q[5];
u1(pi/4398046511104) q[5];
u1(pi/2199023255552) q[46];
cx q[46],q[6];
u1(-pi/2199023255552) q[6];
cx q[46],q[6];
u1(pi/2199023255552) q[6];
u1(pi/1099511627776) q[46];
cx q[46],q[7];
u1(-pi/1099511627776) q[7];
cx q[46],q[7];
u1(pi/1099511627776) q[7];
u1(pi/549755813888) q[46];
cx q[46],q[8];
u1(-pi/549755813888) q[8];
cx q[46],q[8];
u1(pi/549755813888) q[8];
u1(pi/274877906944) q[46];
cx q[46],q[9];
u1(-pi/274877906944) q[9];
cx q[46],q[9];
u1(pi/274877906944) q[9];
u1(pi/137438953472) q[46];
cx q[46],q[10];
u1(-pi/137438953472) q[10];
cx q[46],q[10];
u1(pi/137438953472) q[10];
u1(pi/68719476736) q[46];
cx q[46],q[11];
u1(-pi/68719476736) q[11];
cx q[46],q[11];
u1(pi/68719476736) q[11];
u1(pi/34359738368) q[46];
cx q[46],q[12];
u1(-pi/34359738368) q[12];
cx q[46],q[12];
u1(pi/34359738368) q[12];
u1(pi/17179869184) q[46];
cx q[46],q[13];
u1(-pi/17179869184) q[13];
cx q[46],q[13];
u1(pi/17179869184) q[13];
u1(pi/8589934592) q[46];
cx q[46],q[14];
u1(-pi/8589934592) q[14];
cx q[46],q[14];
u1(pi/8589934592) q[14];
u1(pi/4294967296) q[46];
cx q[46],q[15];
u1(-pi/4294967296) q[15];
cx q[46],q[15];
u1(pi/4294967296) q[15];
u1(pi/2147483648) q[46];
cx q[46],q[16];
u1(-pi/2147483648) q[16];
cx q[46],q[16];
u1(pi/2147483648) q[16];
u1(pi/1073741824) q[46];
cx q[46],q[17];
u1(-pi/1073741824) q[17];
cx q[46],q[17];
u1(pi/1073741824) q[17];
u1(pi/536870912) q[46];
cx q[46],q[18];
u1(-pi/536870912) q[18];
cx q[46],q[18];
u1(pi/536870912) q[18];
u1(pi/268435456) q[46];
cx q[46],q[19];
u1(-pi/268435456) q[19];
cx q[46],q[19];
u1(pi/268435456) q[19];
u1(pi/134217728) q[46];
cx q[46],q[20];
u1(-pi/134217728) q[20];
cx q[46],q[20];
u1(pi/134217728) q[20];
u1(pi/67108864) q[46];
cx q[46],q[21];
u1(-pi/67108864) q[21];
cx q[46],q[21];
u1(pi/67108864) q[21];
u1(pi/33554432) q[46];
cx q[46],q[22];
u1(-pi/33554432) q[22];
cx q[46],q[22];
u1(pi/33554432) q[22];
u1(pi/16777216) q[46];
cx q[46],q[23];
u1(-pi/16777216) q[23];
cx q[46],q[23];
u1(pi/16777216) q[23];
u1(pi/8388608) q[46];
cx q[46],q[24];
u1(-pi/8388608) q[24];
cx q[46],q[24];
u1(pi/8388608) q[24];
u1(pi/4194304) q[46];
cx q[46],q[25];
u1(-pi/4194304) q[25];
cx q[46],q[25];
u1(pi/4194304) q[25];
u1(pi/2097152) q[46];
cx q[46],q[26];
u1(-pi/2097152) q[26];
cx q[46],q[26];
u1(pi/2097152) q[26];
u1(pi/1048576) q[46];
cx q[46],q[27];
u1(-pi/1048576) q[27];
cx q[46],q[27];
u1(pi/1048576) q[27];
u1(pi/524288) q[46];
cx q[46],q[28];
u1(-pi/524288) q[28];
cx q[46],q[28];
u1(pi/524288) q[28];
u1(pi/262144) q[46];
cx q[46],q[29];
u1(-pi/262144) q[29];
cx q[46],q[29];
u1(pi/262144) q[29];
u1(pi/131072) q[46];
cx q[46],q[30];
u1(-pi/131072) q[30];
cx q[46],q[30];
u1(pi/131072) q[30];
u1(pi/65536) q[46];
cx q[46],q[31];
u1(-pi/65536) q[31];
cx q[46],q[31];
u1(pi/65536) q[31];
u1(pi/32768) q[46];
cx q[46],q[32];
u1(-pi/32768) q[32];
cx q[46],q[32];
u1(pi/32768) q[32];
u1(pi/16384) q[46];
cx q[46],q[33];
u1(-pi/16384) q[33];
cx q[46],q[33];
u1(pi/16384) q[33];
u1(pi/8192) q[46];
cx q[46],q[34];
u1(-pi/8192) q[34];
cx q[46],q[34];
u1(pi/8192) q[34];
u1(pi/4096) q[46];
cx q[46],q[35];
u1(-pi/4096) q[35];
cx q[46],q[35];
u1(pi/4096) q[35];
u1(pi/2048) q[46];
cx q[46],q[36];
u1(-pi/2048) q[36];
cx q[46],q[36];
u1(pi/2048) q[36];
u1(pi/1024) q[46];
cx q[46],q[37];
u1(-pi/1024) q[37];
cx q[46],q[37];
u1(pi/1024) q[37];
u1(pi/512) q[46];
cx q[46],q[38];
u1(-pi/512) q[38];
cx q[46],q[38];
u1(pi/512) q[38];
u1(pi/256) q[46];
cx q[46],q[39];
u1(-pi/256) q[39];
cx q[46],q[39];
u1(pi/256) q[39];
u1(pi/128) q[46];
cx q[46],q[40];
u1(-pi/128) q[40];
cx q[46],q[40];
u1(pi/128) q[40];
u1(pi/64) q[46];
cx q[46],q[41];
u1(-pi/64) q[41];
cx q[46],q[41];
u1(pi/64) q[41];
u1(pi/32) q[46];
cx q[46],q[42];
u1(-pi/32) q[42];
cx q[46],q[42];
u1(pi/32) q[42];
u1(pi/16) q[46];
cx q[46],q[43];
u1(-pi/16) q[43];
cx q[46],q[43];
u1(pi/16) q[43];
u1(pi/8) q[46];
cx q[46],q[44];
u1(-pi/8) q[44];
cx q[46],q[44];
u1(pi/8) q[44];
u1(pi/4) q[46];
cx q[46],q[45];
u1(-pi/4) q[45];
cx q[46],q[45];
u1(pi/4) q[45];
h q[46];
u1(pi/281474976710656) q[47];
cx q[47],q[0];
u1(-pi/281474976710656) q[0];
cx q[47],q[0];
u1(pi/281474976710656) q[0];
u1(pi/140737488355328) q[47];
cx q[47],q[1];
u1(-pi/140737488355328) q[1];
cx q[47],q[1];
u1(pi/140737488355328) q[1];
u1(pi/70368744177664) q[47];
cx q[47],q[2];
u1(-pi/70368744177664) q[2];
cx q[47],q[2];
u1(pi/70368744177664) q[2];
u1(pi/35184372088832) q[47];
cx q[47],q[3];
u1(-pi/35184372088832) q[3];
cx q[47],q[3];
u1(pi/35184372088832) q[3];
u1(pi/17592186044416) q[47];
cx q[47],q[4];
u1(-pi/17592186044416) q[4];
cx q[47],q[4];
u1(pi/17592186044416) q[4];
u1(pi/8796093022208) q[47];
cx q[47],q[5];
u1(-pi/8796093022208) q[5];
cx q[47],q[5];
u1(pi/8796093022208) q[5];
u1(pi/4398046511104) q[47];
cx q[47],q[6];
u1(-pi/4398046511104) q[6];
cx q[47],q[6];
u1(pi/4398046511104) q[6];
u1(pi/2199023255552) q[47];
cx q[47],q[7];
u1(-pi/2199023255552) q[7];
cx q[47],q[7];
u1(pi/2199023255552) q[7];
u1(pi/1099511627776) q[47];
cx q[47],q[8];
u1(-pi/1099511627776) q[8];
cx q[47],q[8];
u1(pi/1099511627776) q[8];
u1(pi/549755813888) q[47];
cx q[47],q[9];
u1(-pi/549755813888) q[9];
cx q[47],q[9];
u1(pi/549755813888) q[9];
u1(pi/274877906944) q[47];
cx q[47],q[10];
u1(-pi/274877906944) q[10];
cx q[47],q[10];
u1(pi/274877906944) q[10];
u1(pi/137438953472) q[47];
cx q[47],q[11];
u1(-pi/137438953472) q[11];
cx q[47],q[11];
u1(pi/137438953472) q[11];
u1(pi/68719476736) q[47];
cx q[47],q[12];
u1(-pi/68719476736) q[12];
cx q[47],q[12];
u1(pi/68719476736) q[12];
u1(pi/34359738368) q[47];
cx q[47],q[13];
u1(-pi/34359738368) q[13];
cx q[47],q[13];
u1(pi/34359738368) q[13];
u1(pi/17179869184) q[47];
cx q[47],q[14];
u1(-pi/17179869184) q[14];
cx q[47],q[14];
u1(pi/17179869184) q[14];
u1(pi/8589934592) q[47];
cx q[47],q[15];
u1(-pi/8589934592) q[15];
cx q[47],q[15];
u1(pi/8589934592) q[15];
u1(pi/4294967296) q[47];
cx q[47],q[16];
u1(-pi/4294967296) q[16];
cx q[47],q[16];
u1(pi/4294967296) q[16];
u1(pi/2147483648) q[47];
cx q[47],q[17];
u1(-pi/2147483648) q[17];
cx q[47],q[17];
u1(pi/2147483648) q[17];
u1(pi/1073741824) q[47];
cx q[47],q[18];
u1(-pi/1073741824) q[18];
cx q[47],q[18];
u1(pi/1073741824) q[18];
u1(pi/536870912) q[47];
cx q[47],q[19];
u1(-pi/536870912) q[19];
cx q[47],q[19];
u1(pi/536870912) q[19];
u1(pi/268435456) q[47];
cx q[47],q[20];
u1(-pi/268435456) q[20];
cx q[47],q[20];
u1(pi/268435456) q[20];
u1(pi/134217728) q[47];
cx q[47],q[21];
u1(-pi/134217728) q[21];
cx q[47],q[21];
u1(pi/134217728) q[21];
u1(pi/67108864) q[47];
cx q[47],q[22];
u1(-pi/67108864) q[22];
cx q[47],q[22];
u1(pi/67108864) q[22];
u1(pi/33554432) q[47];
cx q[47],q[23];
u1(-pi/33554432) q[23];
cx q[47],q[23];
u1(pi/33554432) q[23];
u1(pi/16777216) q[47];
cx q[47],q[24];
u1(-pi/16777216) q[24];
cx q[47],q[24];
u1(pi/16777216) q[24];
u1(pi/8388608) q[47];
cx q[47],q[25];
u1(-pi/8388608) q[25];
cx q[47],q[25];
u1(pi/8388608) q[25];
u1(pi/4194304) q[47];
cx q[47],q[26];
u1(-pi/4194304) q[26];
cx q[47],q[26];
u1(pi/4194304) q[26];
u1(pi/2097152) q[47];
cx q[47],q[27];
u1(-pi/2097152) q[27];
cx q[47],q[27];
u1(pi/2097152) q[27];
u1(pi/1048576) q[47];
cx q[47],q[28];
u1(-pi/1048576) q[28];
cx q[47],q[28];
u1(pi/1048576) q[28];
u1(pi/524288) q[47];
cx q[47],q[29];
u1(-pi/524288) q[29];
cx q[47],q[29];
u1(pi/524288) q[29];
u1(pi/262144) q[47];
cx q[47],q[30];
u1(-pi/262144) q[30];
cx q[47],q[30];
u1(pi/262144) q[30];
u1(pi/131072) q[47];
cx q[47],q[31];
u1(-pi/131072) q[31];
cx q[47],q[31];
u1(pi/131072) q[31];
u1(pi/65536) q[47];
cx q[47],q[32];
u1(-pi/65536) q[32];
cx q[47],q[32];
u1(pi/65536) q[32];
u1(pi/32768) q[47];
cx q[47],q[33];
u1(-pi/32768) q[33];
cx q[47],q[33];
u1(pi/32768) q[33];
u1(pi/16384) q[47];
cx q[47],q[34];
u1(-pi/16384) q[34];
cx q[47],q[34];
u1(pi/16384) q[34];
u1(pi/8192) q[47];
cx q[47],q[35];
u1(-pi/8192) q[35];
cx q[47],q[35];
u1(pi/8192) q[35];
u1(pi/4096) q[47];
cx q[47],q[36];
u1(-pi/4096) q[36];
cx q[47],q[36];
u1(pi/4096) q[36];
u1(pi/2048) q[47];
cx q[47],q[37];
u1(-pi/2048) q[37];
cx q[47],q[37];
u1(pi/2048) q[37];
u1(pi/1024) q[47];
cx q[47],q[38];
u1(-pi/1024) q[38];
cx q[47],q[38];
u1(pi/1024) q[38];
u1(pi/512) q[47];
cx q[47],q[39];
u1(-pi/512) q[39];
cx q[47],q[39];
u1(pi/512) q[39];
u1(pi/256) q[47];
cx q[47],q[40];
u1(-pi/256) q[40];
cx q[47],q[40];
u1(pi/256) q[40];
u1(pi/128) q[47];
cx q[47],q[41];
u1(-pi/128) q[41];
cx q[47],q[41];
u1(pi/128) q[41];
u1(pi/64) q[47];
cx q[47],q[42];
u1(-pi/64) q[42];
cx q[47],q[42];
u1(pi/64) q[42];
u1(pi/32) q[47];
cx q[47],q[43];
u1(-pi/32) q[43];
cx q[47],q[43];
u1(pi/32) q[43];
u1(pi/16) q[47];
cx q[47],q[44];
u1(-pi/16) q[44];
cx q[47],q[44];
u1(pi/16) q[44];
u1(pi/8) q[47];
cx q[47],q[45];
u1(-pi/8) q[45];
cx q[47],q[45];
u1(pi/8) q[45];
u1(pi/4) q[47];
cx q[47],q[46];
u1(-pi/4) q[46];
cx q[47],q[46];
u1(pi/4) q[46];
h q[47];
u1(0) q[48];
cx q[48],q[0];
u1(0) q[0];
cx q[48],q[0];
u1(0) q[0];
u1(pi/281474976710656) q[48];
cx q[48],q[1];
u1(-pi/281474976710656) q[1];
cx q[48],q[1];
u1(pi/281474976710656) q[1];
u1(pi/140737488355328) q[48];
cx q[48],q[2];
u1(-pi/140737488355328) q[2];
cx q[48],q[2];
u1(pi/140737488355328) q[2];
u1(pi/70368744177664) q[48];
cx q[48],q[3];
u1(-pi/70368744177664) q[3];
cx q[48],q[3];
u1(pi/70368744177664) q[3];
u1(pi/35184372088832) q[48];
cx q[48],q[4];
u1(-pi/35184372088832) q[4];
cx q[48],q[4];
u1(pi/35184372088832) q[4];
u1(pi/17592186044416) q[48];
cx q[48],q[5];
u1(-pi/17592186044416) q[5];
cx q[48],q[5];
u1(pi/17592186044416) q[5];
u1(pi/8796093022208) q[48];
cx q[48],q[6];
u1(-pi/8796093022208) q[6];
cx q[48],q[6];
u1(pi/8796093022208) q[6];
u1(pi/4398046511104) q[48];
cx q[48],q[7];
u1(-pi/4398046511104) q[7];
cx q[48],q[7];
u1(pi/4398046511104) q[7];
u1(pi/2199023255552) q[48];
cx q[48],q[8];
u1(-pi/2199023255552) q[8];
cx q[48],q[8];
u1(pi/2199023255552) q[8];
u1(pi/1099511627776) q[48];
cx q[48],q[9];
u1(-pi/1099511627776) q[9];
cx q[48],q[9];
u1(pi/1099511627776) q[9];
u1(pi/549755813888) q[48];
cx q[48],q[10];
u1(-pi/549755813888) q[10];
cx q[48],q[10];
u1(pi/549755813888) q[10];
u1(pi/274877906944) q[48];
cx q[48],q[11];
u1(-pi/274877906944) q[11];
cx q[48],q[11];
u1(pi/274877906944) q[11];
u1(pi/137438953472) q[48];
cx q[48],q[12];
u1(-pi/137438953472) q[12];
cx q[48],q[12];
u1(pi/137438953472) q[12];
u1(pi/68719476736) q[48];
cx q[48],q[13];
u1(-pi/68719476736) q[13];
cx q[48],q[13];
u1(pi/68719476736) q[13];
u1(pi/34359738368) q[48];
cx q[48],q[14];
u1(-pi/34359738368) q[14];
cx q[48],q[14];
u1(pi/34359738368) q[14];
u1(pi/17179869184) q[48];
cx q[48],q[15];
u1(-pi/17179869184) q[15];
cx q[48],q[15];
u1(pi/17179869184) q[15];
u1(pi/8589934592) q[48];
cx q[48],q[16];
u1(-pi/8589934592) q[16];
cx q[48],q[16];
u1(pi/8589934592) q[16];
u1(pi/4294967296) q[48];
cx q[48],q[17];
u1(-pi/4294967296) q[17];
cx q[48],q[17];
u1(pi/4294967296) q[17];
u1(pi/2147483648) q[48];
cx q[48],q[18];
u1(-pi/2147483648) q[18];
cx q[48],q[18];
u1(pi/2147483648) q[18];
u1(pi/1073741824) q[48];
cx q[48],q[19];
u1(-pi/1073741824) q[19];
cx q[48],q[19];
u1(pi/1073741824) q[19];
u1(pi/536870912) q[48];
cx q[48],q[20];
u1(-pi/536870912) q[20];
cx q[48],q[20];
u1(pi/536870912) q[20];
u1(pi/268435456) q[48];
cx q[48],q[21];
u1(-pi/268435456) q[21];
cx q[48],q[21];
u1(pi/268435456) q[21];
u1(pi/134217728) q[48];
cx q[48],q[22];
u1(-pi/134217728) q[22];
cx q[48],q[22];
u1(pi/134217728) q[22];
u1(pi/67108864) q[48];
cx q[48],q[23];
u1(-pi/67108864) q[23];
cx q[48],q[23];
u1(pi/67108864) q[23];
u1(pi/33554432) q[48];
cx q[48],q[24];
u1(-pi/33554432) q[24];
cx q[48],q[24];
u1(pi/33554432) q[24];
u1(pi/16777216) q[48];
cx q[48],q[25];
u1(-pi/16777216) q[25];
cx q[48],q[25];
u1(pi/16777216) q[25];
u1(pi/8388608) q[48];
cx q[48],q[26];
u1(-pi/8388608) q[26];
cx q[48],q[26];
u1(pi/8388608) q[26];
u1(pi/4194304) q[48];
cx q[48],q[27];
u1(-pi/4194304) q[27];
cx q[48],q[27];
u1(pi/4194304) q[27];
u1(pi/2097152) q[48];
cx q[48],q[28];
u1(-pi/2097152) q[28];
cx q[48],q[28];
u1(pi/2097152) q[28];
u1(pi/1048576) q[48];
cx q[48],q[29];
u1(-pi/1048576) q[29];
cx q[48],q[29];
u1(pi/1048576) q[29];
u1(pi/524288) q[48];
cx q[48],q[30];
u1(-pi/524288) q[30];
cx q[48],q[30];
u1(pi/524288) q[30];
u1(pi/262144) q[48];
cx q[48],q[31];
u1(-pi/262144) q[31];
cx q[48],q[31];
u1(pi/262144) q[31];
u1(pi/131072) q[48];
cx q[48],q[32];
u1(-pi/131072) q[32];
cx q[48],q[32];
u1(pi/131072) q[32];
u1(pi/65536) q[48];
cx q[48],q[33];
u1(-pi/65536) q[33];
cx q[48],q[33];
u1(pi/65536) q[33];
u1(pi/32768) q[48];
cx q[48],q[34];
u1(-pi/32768) q[34];
cx q[48],q[34];
u1(pi/32768) q[34];
u1(pi/16384) q[48];
cx q[48],q[35];
u1(-pi/16384) q[35];
cx q[48],q[35];
u1(pi/16384) q[35];
u1(pi/8192) q[48];
cx q[48],q[36];
u1(-pi/8192) q[36];
cx q[48],q[36];
u1(pi/8192) q[36];
u1(pi/4096) q[48];
cx q[48],q[37];
u1(-pi/4096) q[37];
cx q[48],q[37];
u1(pi/4096) q[37];
u1(pi/2048) q[48];
cx q[48],q[38];
u1(-pi/2048) q[38];
cx q[48],q[38];
u1(pi/2048) q[38];
u1(pi/1024) q[48];
cx q[48],q[39];
u1(-pi/1024) q[39];
cx q[48],q[39];
u1(pi/1024) q[39];
u1(pi/512) q[48];
cx q[48],q[40];
u1(-pi/512) q[40];
cx q[48],q[40];
u1(pi/512) q[40];
u1(pi/256) q[48];
cx q[48],q[41];
u1(-pi/256) q[41];
cx q[48],q[41];
u1(pi/256) q[41];
u1(pi/128) q[48];
cx q[48],q[42];
u1(-pi/128) q[42];
cx q[48],q[42];
u1(pi/128) q[42];
u1(pi/64) q[48];
cx q[48],q[43];
u1(-pi/64) q[43];
cx q[48],q[43];
u1(pi/64) q[43];
u1(pi/32) q[48];
cx q[48],q[44];
u1(-pi/32) q[44];
cx q[48],q[44];
u1(pi/32) q[44];
u1(pi/16) q[48];
cx q[48],q[45];
u1(-pi/16) q[45];
cx q[48],q[45];
u1(pi/16) q[45];
u1(pi/8) q[48];
cx q[48],q[46];
u1(-pi/8) q[46];
cx q[48],q[46];
u1(pi/8) q[46];
u1(pi/4) q[48];
cx q[48],q[47];
u1(-pi/4) q[47];
cx q[48],q[47];
u1(pi/4) q[47];
h q[48];
u1(0) q[49];
cx q[49],q[0];
u1(0) q[0];
cx q[49],q[0];
u1(0) q[0];
u1(0) q[49];
cx q[49],q[1];
u1(0) q[1];
cx q[49],q[1];
u1(0) q[1];
u1(pi/281474976710656) q[49];
cx q[49],q[2];
u1(-pi/281474976710656) q[2];
cx q[49],q[2];
u1(pi/281474976710656) q[2];
u1(pi/140737488355328) q[49];
cx q[49],q[3];
u1(-pi/140737488355328) q[3];
cx q[49],q[3];
u1(pi/140737488355328) q[3];
u1(pi/70368744177664) q[49];
cx q[49],q[4];
u1(-pi/70368744177664) q[4];
cx q[49],q[4];
u1(pi/70368744177664) q[4];
u1(pi/35184372088832) q[49];
cx q[49],q[5];
u1(-pi/35184372088832) q[5];
cx q[49],q[5];
u1(pi/35184372088832) q[5];
u1(pi/17592186044416) q[49];
cx q[49],q[6];
u1(-pi/17592186044416) q[6];
cx q[49],q[6];
u1(pi/17592186044416) q[6];
u1(pi/8796093022208) q[49];
cx q[49],q[7];
u1(-pi/8796093022208) q[7];
cx q[49],q[7];
u1(pi/8796093022208) q[7];
u1(pi/4398046511104) q[49];
cx q[49],q[8];
u1(-pi/4398046511104) q[8];
cx q[49],q[8];
u1(pi/4398046511104) q[8];
u1(pi/2199023255552) q[49];
cx q[49],q[9];
u1(-pi/2199023255552) q[9];
cx q[49],q[9];
u1(pi/2199023255552) q[9];
u1(pi/1099511627776) q[49];
cx q[49],q[10];
u1(-pi/1099511627776) q[10];
cx q[49],q[10];
u1(pi/1099511627776) q[10];
u1(pi/549755813888) q[49];
cx q[49],q[11];
u1(-pi/549755813888) q[11];
cx q[49],q[11];
u1(pi/549755813888) q[11];
u1(pi/274877906944) q[49];
cx q[49],q[12];
u1(-pi/274877906944) q[12];
cx q[49],q[12];
u1(pi/274877906944) q[12];
u1(pi/137438953472) q[49];
cx q[49],q[13];
u1(-pi/137438953472) q[13];
cx q[49],q[13];
u1(pi/137438953472) q[13];
u1(pi/68719476736) q[49];
cx q[49],q[14];
u1(-pi/68719476736) q[14];
cx q[49],q[14];
u1(pi/68719476736) q[14];
u1(pi/34359738368) q[49];
cx q[49],q[15];
u1(-pi/34359738368) q[15];
cx q[49],q[15];
u1(pi/34359738368) q[15];
u1(pi/17179869184) q[49];
cx q[49],q[16];
u1(-pi/17179869184) q[16];
cx q[49],q[16];
u1(pi/17179869184) q[16];
u1(pi/8589934592) q[49];
cx q[49],q[17];
u1(-pi/8589934592) q[17];
cx q[49],q[17];
u1(pi/8589934592) q[17];
u1(pi/4294967296) q[49];
cx q[49],q[18];
u1(-pi/4294967296) q[18];
cx q[49],q[18];
u1(pi/4294967296) q[18];
u1(pi/2147483648) q[49];
cx q[49],q[19];
u1(-pi/2147483648) q[19];
cx q[49],q[19];
u1(pi/2147483648) q[19];
u1(pi/1073741824) q[49];
cx q[49],q[20];
u1(-pi/1073741824) q[20];
cx q[49],q[20];
u1(pi/1073741824) q[20];
u1(pi/536870912) q[49];
cx q[49],q[21];
u1(-pi/536870912) q[21];
cx q[49],q[21];
u1(pi/536870912) q[21];
u1(pi/268435456) q[49];
cx q[49],q[22];
u1(-pi/268435456) q[22];
cx q[49],q[22];
u1(pi/268435456) q[22];
u1(pi/134217728) q[49];
cx q[49],q[23];
u1(-pi/134217728) q[23];
cx q[49],q[23];
u1(pi/134217728) q[23];
u1(pi/67108864) q[49];
cx q[49],q[24];
u1(-pi/67108864) q[24];
cx q[49],q[24];
u1(pi/67108864) q[24];
u1(pi/33554432) q[49];
cx q[49],q[25];
u1(-pi/33554432) q[25];
cx q[49],q[25];
u1(pi/33554432) q[25];
u1(pi/16777216) q[49];
cx q[49],q[26];
u1(-pi/16777216) q[26];
cx q[49],q[26];
u1(pi/16777216) q[26];
u1(pi/8388608) q[49];
cx q[49],q[27];
u1(-pi/8388608) q[27];
cx q[49],q[27];
u1(pi/8388608) q[27];
u1(pi/4194304) q[49];
cx q[49],q[28];
u1(-pi/4194304) q[28];
cx q[49],q[28];
u1(pi/4194304) q[28];
u1(pi/2097152) q[49];
cx q[49],q[29];
u1(-pi/2097152) q[29];
cx q[49],q[29];
u1(pi/2097152) q[29];
u1(pi/1048576) q[49];
cx q[49],q[30];
u1(-pi/1048576) q[30];
cx q[49],q[30];
u1(pi/1048576) q[30];
u1(pi/524288) q[49];
cx q[49],q[31];
u1(-pi/524288) q[31];
cx q[49],q[31];
u1(pi/524288) q[31];
u1(pi/262144) q[49];
cx q[49],q[32];
u1(-pi/262144) q[32];
cx q[49],q[32];
u1(pi/262144) q[32];
u1(pi/131072) q[49];
cx q[49],q[33];
u1(-pi/131072) q[33];
cx q[49],q[33];
u1(pi/131072) q[33];
u1(pi/65536) q[49];
cx q[49],q[34];
u1(-pi/65536) q[34];
cx q[49],q[34];
u1(pi/65536) q[34];
u1(pi/32768) q[49];
cx q[49],q[35];
u1(-pi/32768) q[35];
cx q[49],q[35];
u1(pi/32768) q[35];
u1(pi/16384) q[49];
cx q[49],q[36];
u1(-pi/16384) q[36];
cx q[49],q[36];
u1(pi/16384) q[36];
u1(pi/8192) q[49];
cx q[49],q[37];
u1(-pi/8192) q[37];
cx q[49],q[37];
u1(pi/8192) q[37];
u1(pi/4096) q[49];
cx q[49],q[38];
u1(-pi/4096) q[38];
cx q[49],q[38];
u1(pi/4096) q[38];
u1(pi/2048) q[49];
cx q[49],q[39];
u1(-pi/2048) q[39];
cx q[49],q[39];
u1(pi/2048) q[39];
u1(pi/1024) q[49];
cx q[49],q[40];
u1(-pi/1024) q[40];
cx q[49],q[40];
u1(pi/1024) q[40];
u1(pi/512) q[49];
cx q[49],q[41];
u1(-pi/512) q[41];
cx q[49],q[41];
u1(pi/512) q[41];
u1(pi/256) q[49];
cx q[49],q[42];
u1(-pi/256) q[42];
cx q[49],q[42];
u1(pi/256) q[42];
u1(pi/128) q[49];
cx q[49],q[43];
u1(-pi/128) q[43];
cx q[49],q[43];
u1(pi/128) q[43];
u1(pi/64) q[49];
cx q[49],q[44];
u1(-pi/64) q[44];
cx q[49],q[44];
u1(pi/64) q[44];
u1(pi/32) q[49];
cx q[49],q[45];
u1(-pi/32) q[45];
cx q[49],q[45];
u1(pi/32) q[45];
u1(pi/16) q[49];
cx q[49],q[46];
u1(-pi/16) q[46];
cx q[49],q[46];
u1(pi/16) q[46];
u1(pi/8) q[49];
cx q[49],q[47];
u1(-pi/8) q[47];
cx q[49],q[47];
u1(pi/8) q[47];
u1(pi/4) q[49];
cx q[49],q[48];
u1(-pi/4) q[48];
cx q[49],q[48];
u1(pi/4) q[48];
h q[49];
u1(0) q[50];
cx q[50],q[0];
u1(0) q[0];
cx q[50],q[0];
u1(0) q[0];
u1(0) q[50];
cx q[50],q[1];
u1(0) q[1];
cx q[50],q[1];
u1(0) q[1];
u1(0) q[50];
cx q[50],q[2];
u1(0) q[2];
cx q[50],q[2];
u1(0) q[2];
u1(pi/281474976710656) q[50];
cx q[50],q[3];
u1(-pi/281474976710656) q[3];
cx q[50],q[3];
u1(pi/281474976710656) q[3];
u1(pi/140737488355328) q[50];
cx q[50],q[4];
u1(-pi/140737488355328) q[4];
cx q[50],q[4];
u1(pi/140737488355328) q[4];
u1(pi/70368744177664) q[50];
cx q[50],q[5];
u1(-pi/70368744177664) q[5];
cx q[50],q[5];
u1(pi/70368744177664) q[5];
u1(pi/35184372088832) q[50];
cx q[50],q[6];
u1(-pi/35184372088832) q[6];
cx q[50],q[6];
u1(pi/35184372088832) q[6];
u1(pi/17592186044416) q[50];
cx q[50],q[7];
u1(-pi/17592186044416) q[7];
cx q[50],q[7];
u1(pi/17592186044416) q[7];
u1(pi/8796093022208) q[50];
cx q[50],q[8];
u1(-pi/8796093022208) q[8];
cx q[50],q[8];
u1(pi/8796093022208) q[8];
u1(pi/4398046511104) q[50];
cx q[50],q[9];
u1(-pi/4398046511104) q[9];
cx q[50],q[9];
u1(pi/4398046511104) q[9];
u1(pi/2199023255552) q[50];
cx q[50],q[10];
u1(-pi/2199023255552) q[10];
cx q[50],q[10];
u1(pi/2199023255552) q[10];
u1(pi/1099511627776) q[50];
cx q[50],q[11];
u1(-pi/1099511627776) q[11];
cx q[50],q[11];
u1(pi/1099511627776) q[11];
u1(pi/549755813888) q[50];
cx q[50],q[12];
u1(-pi/549755813888) q[12];
cx q[50],q[12];
u1(pi/549755813888) q[12];
u1(pi/274877906944) q[50];
cx q[50],q[13];
u1(-pi/274877906944) q[13];
cx q[50],q[13];
u1(pi/274877906944) q[13];
u1(pi/137438953472) q[50];
cx q[50],q[14];
u1(-pi/137438953472) q[14];
cx q[50],q[14];
u1(pi/137438953472) q[14];
u1(pi/68719476736) q[50];
cx q[50],q[15];
u1(-pi/68719476736) q[15];
cx q[50],q[15];
u1(pi/68719476736) q[15];
u1(pi/34359738368) q[50];
cx q[50],q[16];
u1(-pi/34359738368) q[16];
cx q[50],q[16];
u1(pi/34359738368) q[16];
u1(pi/17179869184) q[50];
cx q[50],q[17];
u1(-pi/17179869184) q[17];
cx q[50],q[17];
u1(pi/17179869184) q[17];
u1(pi/8589934592) q[50];
cx q[50],q[18];
u1(-pi/8589934592) q[18];
cx q[50],q[18];
u1(pi/8589934592) q[18];
u1(pi/4294967296) q[50];
cx q[50],q[19];
u1(-pi/4294967296) q[19];
cx q[50],q[19];
u1(pi/4294967296) q[19];
u1(pi/2147483648) q[50];
cx q[50],q[20];
u1(-pi/2147483648) q[20];
cx q[50],q[20];
u1(pi/2147483648) q[20];
u1(pi/1073741824) q[50];
cx q[50],q[21];
u1(-pi/1073741824) q[21];
cx q[50],q[21];
u1(pi/1073741824) q[21];
u1(pi/536870912) q[50];
cx q[50],q[22];
u1(-pi/536870912) q[22];
cx q[50],q[22];
u1(pi/536870912) q[22];
u1(pi/268435456) q[50];
cx q[50],q[23];
u1(-pi/268435456) q[23];
cx q[50],q[23];
u1(pi/268435456) q[23];
u1(pi/134217728) q[50];
cx q[50],q[24];
u1(-pi/134217728) q[24];
cx q[50],q[24];
u1(pi/134217728) q[24];
u1(pi/67108864) q[50];
cx q[50],q[25];
u1(-pi/67108864) q[25];
cx q[50],q[25];
u1(pi/67108864) q[25];
u1(pi/33554432) q[50];
cx q[50],q[26];
u1(-pi/33554432) q[26];
cx q[50],q[26];
u1(pi/33554432) q[26];
u1(pi/16777216) q[50];
cx q[50],q[27];
u1(-pi/16777216) q[27];
cx q[50],q[27];
u1(pi/16777216) q[27];
u1(pi/8388608) q[50];
cx q[50],q[28];
u1(-pi/8388608) q[28];
cx q[50],q[28];
u1(pi/8388608) q[28];
u1(pi/4194304) q[50];
cx q[50],q[29];
u1(-pi/4194304) q[29];
cx q[50],q[29];
u1(pi/4194304) q[29];
u1(pi/2097152) q[50];
cx q[50],q[30];
u1(-pi/2097152) q[30];
cx q[50],q[30];
u1(pi/2097152) q[30];
u1(pi/1048576) q[50];
cx q[50],q[31];
u1(-pi/1048576) q[31];
cx q[50],q[31];
u1(pi/1048576) q[31];
u1(pi/524288) q[50];
cx q[50],q[32];
u1(-pi/524288) q[32];
cx q[50],q[32];
u1(pi/524288) q[32];
u1(pi/262144) q[50];
cx q[50],q[33];
u1(-pi/262144) q[33];
cx q[50],q[33];
u1(pi/262144) q[33];
u1(pi/131072) q[50];
cx q[50],q[34];
u1(-pi/131072) q[34];
cx q[50],q[34];
u1(pi/131072) q[34];
u1(pi/65536) q[50];
cx q[50],q[35];
u1(-pi/65536) q[35];
cx q[50],q[35];
u1(pi/65536) q[35];
u1(pi/32768) q[50];
cx q[50],q[36];
u1(-pi/32768) q[36];
cx q[50],q[36];
u1(pi/32768) q[36];
u1(pi/16384) q[50];
cx q[50],q[37];
u1(-pi/16384) q[37];
cx q[50],q[37];
u1(pi/16384) q[37];
u1(pi/8192) q[50];
cx q[50],q[38];
u1(-pi/8192) q[38];
cx q[50],q[38];
u1(pi/8192) q[38];
u1(pi/4096) q[50];
cx q[50],q[39];
u1(-pi/4096) q[39];
cx q[50],q[39];
u1(pi/4096) q[39];
u1(pi/2048) q[50];
cx q[50],q[40];
u1(-pi/2048) q[40];
cx q[50],q[40];
u1(pi/2048) q[40];
u1(pi/1024) q[50];
cx q[50],q[41];
u1(-pi/1024) q[41];
cx q[50],q[41];
u1(pi/1024) q[41];
u1(pi/512) q[50];
cx q[50],q[42];
u1(-pi/512) q[42];
cx q[50],q[42];
u1(pi/512) q[42];
u1(pi/256) q[50];
cx q[50],q[43];
u1(-pi/256) q[43];
cx q[50],q[43];
u1(pi/256) q[43];
u1(pi/128) q[50];
cx q[50],q[44];
u1(-pi/128) q[44];
cx q[50],q[44];
u1(pi/128) q[44];
u1(pi/64) q[50];
cx q[50],q[45];
u1(-pi/64) q[45];
cx q[50],q[45];
u1(pi/64) q[45];
u1(pi/32) q[50];
cx q[50],q[46];
u1(-pi/32) q[46];
cx q[50],q[46];
u1(pi/32) q[46];
u1(pi/16) q[50];
cx q[50],q[47];
u1(-pi/16) q[47];
cx q[50],q[47];
u1(pi/16) q[47];
u1(pi/8) q[50];
cx q[50],q[48];
u1(-pi/8) q[48];
cx q[50],q[48];
u1(pi/8) q[48];
u1(pi/4) q[50];
cx q[50],q[49];
u1(-pi/4) q[49];
cx q[50],q[49];
u1(pi/4) q[49];
h q[50];
u1(0) q[51];
cx q[51],q[0];
u1(0) q[0];
cx q[51],q[0];
u1(0) q[0];
u1(0) q[51];
cx q[51],q[1];
u1(0) q[1];
cx q[51],q[1];
u1(0) q[1];
u1(0) q[51];
cx q[51],q[2];
u1(0) q[2];
cx q[51],q[2];
u1(0) q[2];
u1(0) q[51];
cx q[51],q[3];
u1(0) q[3];
cx q[51],q[3];
u1(0) q[3];
u1(pi/281474976710656) q[51];
cx q[51],q[4];
u1(-pi/281474976710656) q[4];
cx q[51],q[4];
u1(pi/281474976710656) q[4];
u1(pi/140737488355328) q[51];
cx q[51],q[5];
u1(-pi/140737488355328) q[5];
cx q[51],q[5];
u1(pi/140737488355328) q[5];
u1(pi/70368744177664) q[51];
cx q[51],q[6];
u1(-pi/70368744177664) q[6];
cx q[51],q[6];
u1(pi/70368744177664) q[6];
u1(pi/35184372088832) q[51];
cx q[51],q[7];
u1(-pi/35184372088832) q[7];
cx q[51],q[7];
u1(pi/35184372088832) q[7];
u1(pi/17592186044416) q[51];
cx q[51],q[8];
u1(-pi/17592186044416) q[8];
cx q[51],q[8];
u1(pi/17592186044416) q[8];
u1(pi/8796093022208) q[51];
cx q[51],q[9];
u1(-pi/8796093022208) q[9];
cx q[51],q[9];
u1(pi/8796093022208) q[9];
u1(pi/4398046511104) q[51];
cx q[51],q[10];
u1(-pi/4398046511104) q[10];
cx q[51],q[10];
u1(pi/4398046511104) q[10];
u1(pi/2199023255552) q[51];
cx q[51],q[11];
u1(-pi/2199023255552) q[11];
cx q[51],q[11];
u1(pi/2199023255552) q[11];
u1(pi/1099511627776) q[51];
cx q[51],q[12];
u1(-pi/1099511627776) q[12];
cx q[51],q[12];
u1(pi/1099511627776) q[12];
u1(pi/549755813888) q[51];
cx q[51],q[13];
u1(-pi/549755813888) q[13];
cx q[51],q[13];
u1(pi/549755813888) q[13];
u1(pi/274877906944) q[51];
cx q[51],q[14];
u1(-pi/274877906944) q[14];
cx q[51],q[14];
u1(pi/274877906944) q[14];
u1(pi/137438953472) q[51];
cx q[51],q[15];
u1(-pi/137438953472) q[15];
cx q[51],q[15];
u1(pi/137438953472) q[15];
u1(pi/68719476736) q[51];
cx q[51],q[16];
u1(-pi/68719476736) q[16];
cx q[51],q[16];
u1(pi/68719476736) q[16];
u1(pi/34359738368) q[51];
cx q[51],q[17];
u1(-pi/34359738368) q[17];
cx q[51],q[17];
u1(pi/34359738368) q[17];
u1(pi/17179869184) q[51];
cx q[51],q[18];
u1(-pi/17179869184) q[18];
cx q[51],q[18];
u1(pi/17179869184) q[18];
u1(pi/8589934592) q[51];
cx q[51],q[19];
u1(-pi/8589934592) q[19];
cx q[51],q[19];
u1(pi/8589934592) q[19];
u1(pi/4294967296) q[51];
cx q[51],q[20];
u1(-pi/4294967296) q[20];
cx q[51],q[20];
u1(pi/4294967296) q[20];
u1(pi/2147483648) q[51];
cx q[51],q[21];
u1(-pi/2147483648) q[21];
cx q[51],q[21];
u1(pi/2147483648) q[21];
u1(pi/1073741824) q[51];
cx q[51],q[22];
u1(-pi/1073741824) q[22];
cx q[51],q[22];
u1(pi/1073741824) q[22];
u1(pi/536870912) q[51];
cx q[51],q[23];
u1(-pi/536870912) q[23];
cx q[51],q[23];
u1(pi/536870912) q[23];
u1(pi/268435456) q[51];
cx q[51],q[24];
u1(-pi/268435456) q[24];
cx q[51],q[24];
u1(pi/268435456) q[24];
u1(pi/134217728) q[51];
cx q[51],q[25];
u1(-pi/134217728) q[25];
cx q[51],q[25];
u1(pi/134217728) q[25];
u1(pi/67108864) q[51];
cx q[51],q[26];
u1(-pi/67108864) q[26];
cx q[51],q[26];
u1(pi/67108864) q[26];
u1(pi/33554432) q[51];
cx q[51],q[27];
u1(-pi/33554432) q[27];
cx q[51],q[27];
u1(pi/33554432) q[27];
u1(pi/16777216) q[51];
cx q[51],q[28];
u1(-pi/16777216) q[28];
cx q[51],q[28];
u1(pi/16777216) q[28];
u1(pi/8388608) q[51];
cx q[51],q[29];
u1(-pi/8388608) q[29];
cx q[51],q[29];
u1(pi/8388608) q[29];
u1(pi/4194304) q[51];
cx q[51],q[30];
u1(-pi/4194304) q[30];
cx q[51],q[30];
u1(pi/4194304) q[30];
u1(pi/2097152) q[51];
cx q[51],q[31];
u1(-pi/2097152) q[31];
cx q[51],q[31];
u1(pi/2097152) q[31];
u1(pi/1048576) q[51];
cx q[51],q[32];
u1(-pi/1048576) q[32];
cx q[51],q[32];
u1(pi/1048576) q[32];
u1(pi/524288) q[51];
cx q[51],q[33];
u1(-pi/524288) q[33];
cx q[51],q[33];
u1(pi/524288) q[33];
u1(pi/262144) q[51];
cx q[51],q[34];
u1(-pi/262144) q[34];
cx q[51],q[34];
u1(pi/262144) q[34];
u1(pi/131072) q[51];
cx q[51],q[35];
u1(-pi/131072) q[35];
cx q[51],q[35];
u1(pi/131072) q[35];
u1(pi/65536) q[51];
cx q[51],q[36];
u1(-pi/65536) q[36];
cx q[51],q[36];
u1(pi/65536) q[36];
u1(pi/32768) q[51];
cx q[51],q[37];
u1(-pi/32768) q[37];
cx q[51],q[37];
u1(pi/32768) q[37];
u1(pi/16384) q[51];
cx q[51],q[38];
u1(-pi/16384) q[38];
cx q[51],q[38];
u1(pi/16384) q[38];
u1(pi/8192) q[51];
cx q[51],q[39];
u1(-pi/8192) q[39];
cx q[51],q[39];
u1(pi/8192) q[39];
u1(pi/4096) q[51];
cx q[51],q[40];
u1(-pi/4096) q[40];
cx q[51],q[40];
u1(pi/4096) q[40];
u1(pi/2048) q[51];
cx q[51],q[41];
u1(-pi/2048) q[41];
cx q[51],q[41];
u1(pi/2048) q[41];
u1(pi/1024) q[51];
cx q[51],q[42];
u1(-pi/1024) q[42];
cx q[51],q[42];
u1(pi/1024) q[42];
u1(pi/512) q[51];
cx q[51],q[43];
u1(-pi/512) q[43];
cx q[51],q[43];
u1(pi/512) q[43];
u1(pi/256) q[51];
cx q[51],q[44];
u1(-pi/256) q[44];
cx q[51],q[44];
u1(pi/256) q[44];
u1(pi/128) q[51];
cx q[51],q[45];
u1(-pi/128) q[45];
cx q[51],q[45];
u1(pi/128) q[45];
u1(pi/64) q[51];
cx q[51],q[46];
u1(-pi/64) q[46];
cx q[51],q[46];
u1(pi/64) q[46];
u1(pi/32) q[51];
cx q[51],q[47];
u1(-pi/32) q[47];
cx q[51],q[47];
u1(pi/32) q[47];
u1(pi/16) q[51];
cx q[51],q[48];
u1(-pi/16) q[48];
cx q[51],q[48];
u1(pi/16) q[48];
u1(pi/8) q[51];
cx q[51],q[49];
u1(-pi/8) q[49];
cx q[51],q[49];
u1(pi/8) q[49];
u1(pi/4) q[51];
cx q[51],q[50];
u1(-pi/4) q[50];
cx q[51],q[50];
u1(pi/4) q[50];
h q[51];
u1(0) q[52];
cx q[52],q[0];
u1(0) q[0];
cx q[52],q[0];
u1(0) q[0];
u1(0) q[52];
cx q[52],q[1];
u1(0) q[1];
cx q[52],q[1];
u1(0) q[1];
u1(0) q[52];
cx q[52],q[2];
u1(0) q[2];
cx q[52],q[2];
u1(0) q[2];
u1(0) q[52];
cx q[52],q[3];
u1(0) q[3];
cx q[52],q[3];
u1(0) q[3];
u1(0) q[52];
cx q[52],q[4];
u1(0) q[4];
cx q[52],q[4];
u1(0) q[4];
u1(pi/281474976710656) q[52];
cx q[52],q[5];
u1(-pi/281474976710656) q[5];
cx q[52],q[5];
u1(pi/281474976710656) q[5];
u1(pi/140737488355328) q[52];
cx q[52],q[6];
u1(-pi/140737488355328) q[6];
cx q[52],q[6];
u1(pi/140737488355328) q[6];
u1(pi/70368744177664) q[52];
cx q[52],q[7];
u1(-pi/70368744177664) q[7];
cx q[52],q[7];
u1(pi/70368744177664) q[7];
u1(pi/35184372088832) q[52];
cx q[52],q[8];
u1(-pi/35184372088832) q[8];
cx q[52],q[8];
u1(pi/35184372088832) q[8];
u1(pi/17592186044416) q[52];
cx q[52],q[9];
u1(-pi/17592186044416) q[9];
cx q[52],q[9];
u1(pi/17592186044416) q[9];
u1(pi/8796093022208) q[52];
cx q[52],q[10];
u1(-pi/8796093022208) q[10];
cx q[52],q[10];
u1(pi/8796093022208) q[10];
u1(pi/4398046511104) q[52];
cx q[52],q[11];
u1(-pi/4398046511104) q[11];
cx q[52],q[11];
u1(pi/4398046511104) q[11];
u1(pi/2199023255552) q[52];
cx q[52],q[12];
u1(-pi/2199023255552) q[12];
cx q[52],q[12];
u1(pi/2199023255552) q[12];
u1(pi/1099511627776) q[52];
cx q[52],q[13];
u1(-pi/1099511627776) q[13];
cx q[52],q[13];
u1(pi/1099511627776) q[13];
u1(pi/549755813888) q[52];
cx q[52],q[14];
u1(-pi/549755813888) q[14];
cx q[52],q[14];
u1(pi/549755813888) q[14];
u1(pi/274877906944) q[52];
cx q[52],q[15];
u1(-pi/274877906944) q[15];
cx q[52],q[15];
u1(pi/274877906944) q[15];
u1(pi/137438953472) q[52];
cx q[52],q[16];
u1(-pi/137438953472) q[16];
cx q[52],q[16];
u1(pi/137438953472) q[16];
u1(pi/68719476736) q[52];
cx q[52],q[17];
u1(-pi/68719476736) q[17];
cx q[52],q[17];
u1(pi/68719476736) q[17];
u1(pi/34359738368) q[52];
cx q[52],q[18];
u1(-pi/34359738368) q[18];
cx q[52],q[18];
u1(pi/34359738368) q[18];
u1(pi/17179869184) q[52];
cx q[52],q[19];
u1(-pi/17179869184) q[19];
cx q[52],q[19];
u1(pi/17179869184) q[19];
u1(pi/8589934592) q[52];
cx q[52],q[20];
u1(-pi/8589934592) q[20];
cx q[52],q[20];
u1(pi/8589934592) q[20];
u1(pi/4294967296) q[52];
cx q[52],q[21];
u1(-pi/4294967296) q[21];
cx q[52],q[21];
u1(pi/4294967296) q[21];
u1(pi/2147483648) q[52];
cx q[52],q[22];
u1(-pi/2147483648) q[22];
cx q[52],q[22];
u1(pi/2147483648) q[22];
u1(pi/1073741824) q[52];
cx q[52],q[23];
u1(-pi/1073741824) q[23];
cx q[52],q[23];
u1(pi/1073741824) q[23];
u1(pi/536870912) q[52];
cx q[52],q[24];
u1(-pi/536870912) q[24];
cx q[52],q[24];
u1(pi/536870912) q[24];
u1(pi/268435456) q[52];
cx q[52],q[25];
u1(-pi/268435456) q[25];
cx q[52],q[25];
u1(pi/268435456) q[25];
u1(pi/134217728) q[52];
cx q[52],q[26];
u1(-pi/134217728) q[26];
cx q[52],q[26];
u1(pi/134217728) q[26];
u1(pi/67108864) q[52];
cx q[52],q[27];
u1(-pi/67108864) q[27];
cx q[52],q[27];
u1(pi/67108864) q[27];
u1(pi/33554432) q[52];
cx q[52],q[28];
u1(-pi/33554432) q[28];
cx q[52],q[28];
u1(pi/33554432) q[28];
u1(pi/16777216) q[52];
cx q[52],q[29];
u1(-pi/16777216) q[29];
cx q[52],q[29];
u1(pi/16777216) q[29];
u1(pi/8388608) q[52];
cx q[52],q[30];
u1(-pi/8388608) q[30];
cx q[52],q[30];
u1(pi/8388608) q[30];
u1(pi/4194304) q[52];
cx q[52],q[31];
u1(-pi/4194304) q[31];
cx q[52],q[31];
u1(pi/4194304) q[31];
u1(pi/2097152) q[52];
cx q[52],q[32];
u1(-pi/2097152) q[32];
cx q[52],q[32];
u1(pi/2097152) q[32];
u1(pi/1048576) q[52];
cx q[52],q[33];
u1(-pi/1048576) q[33];
cx q[52],q[33];
u1(pi/1048576) q[33];
u1(pi/524288) q[52];
cx q[52],q[34];
u1(-pi/524288) q[34];
cx q[52],q[34];
u1(pi/524288) q[34];
u1(pi/262144) q[52];
cx q[52],q[35];
u1(-pi/262144) q[35];
cx q[52],q[35];
u1(pi/262144) q[35];
u1(pi/131072) q[52];
cx q[52],q[36];
u1(-pi/131072) q[36];
cx q[52],q[36];
u1(pi/131072) q[36];
u1(pi/65536) q[52];
cx q[52],q[37];
u1(-pi/65536) q[37];
cx q[52],q[37];
u1(pi/65536) q[37];
u1(pi/32768) q[52];
cx q[52],q[38];
u1(-pi/32768) q[38];
cx q[52],q[38];
u1(pi/32768) q[38];
u1(pi/16384) q[52];
cx q[52],q[39];
u1(-pi/16384) q[39];
cx q[52],q[39];
u1(pi/16384) q[39];
u1(pi/8192) q[52];
cx q[52],q[40];
u1(-pi/8192) q[40];
cx q[52],q[40];
u1(pi/8192) q[40];
u1(pi/4096) q[52];
cx q[52],q[41];
u1(-pi/4096) q[41];
cx q[52],q[41];
u1(pi/4096) q[41];
u1(pi/2048) q[52];
cx q[52],q[42];
u1(-pi/2048) q[42];
cx q[52],q[42];
u1(pi/2048) q[42];
u1(pi/1024) q[52];
cx q[52],q[43];
u1(-pi/1024) q[43];
cx q[52],q[43];
u1(pi/1024) q[43];
u1(pi/512) q[52];
cx q[52],q[44];
u1(-pi/512) q[44];
cx q[52],q[44];
u1(pi/512) q[44];
u1(pi/256) q[52];
cx q[52],q[45];
u1(-pi/256) q[45];
cx q[52],q[45];
u1(pi/256) q[45];
u1(pi/128) q[52];
cx q[52],q[46];
u1(-pi/128) q[46];
cx q[52],q[46];
u1(pi/128) q[46];
u1(pi/64) q[52];
cx q[52],q[47];
u1(-pi/64) q[47];
cx q[52],q[47];
u1(pi/64) q[47];
u1(pi/32) q[52];
cx q[52],q[48];
u1(-pi/32) q[48];
cx q[52],q[48];
u1(pi/32) q[48];
u1(pi/16) q[52];
cx q[52],q[49];
u1(-pi/16) q[49];
cx q[52],q[49];
u1(pi/16) q[49];
u1(pi/8) q[52];
cx q[52],q[50];
u1(-pi/8) q[50];
cx q[52],q[50];
u1(pi/8) q[50];
u1(pi/4) q[52];
cx q[52],q[51];
u1(-pi/4) q[51];
cx q[52],q[51];
u1(pi/4) q[51];
h q[52];
u1(0) q[53];
cx q[53],q[0];
u1(0) q[0];
cx q[53],q[0];
u1(0) q[0];
u1(0) q[53];
cx q[53],q[1];
u1(0) q[1];
cx q[53],q[1];
u1(0) q[1];
u1(0) q[53];
cx q[53],q[2];
u1(0) q[2];
cx q[53],q[2];
u1(0) q[2];
u1(0) q[53];
cx q[53],q[3];
u1(0) q[3];
cx q[53],q[3];
u1(0) q[3];
u1(0) q[53];
cx q[53],q[4];
u1(0) q[4];
cx q[53],q[4];
u1(0) q[4];
u1(0) q[53];
cx q[53],q[5];
u1(0) q[5];
cx q[53],q[5];
u1(0) q[5];
u1(pi/281474976710656) q[53];
cx q[53],q[6];
u1(-pi/281474976710656) q[6];
cx q[53],q[6];
u1(pi/281474976710656) q[6];
u1(pi/140737488355328) q[53];
cx q[53],q[7];
u1(-pi/140737488355328) q[7];
cx q[53],q[7];
u1(pi/140737488355328) q[7];
u1(pi/70368744177664) q[53];
cx q[53],q[8];
u1(-pi/70368744177664) q[8];
cx q[53],q[8];
u1(pi/70368744177664) q[8];
u1(pi/35184372088832) q[53];
cx q[53],q[9];
u1(-pi/35184372088832) q[9];
cx q[53],q[9];
u1(pi/35184372088832) q[9];
u1(pi/17592186044416) q[53];
cx q[53],q[10];
u1(-pi/17592186044416) q[10];
cx q[53],q[10];
u1(pi/17592186044416) q[10];
u1(pi/8796093022208) q[53];
cx q[53],q[11];
u1(-pi/8796093022208) q[11];
cx q[53],q[11];
u1(pi/8796093022208) q[11];
u1(pi/4398046511104) q[53];
cx q[53],q[12];
u1(-pi/4398046511104) q[12];
cx q[53],q[12];
u1(pi/4398046511104) q[12];
u1(pi/2199023255552) q[53];
cx q[53],q[13];
u1(-pi/2199023255552) q[13];
cx q[53],q[13];
u1(pi/2199023255552) q[13];
u1(pi/1099511627776) q[53];
cx q[53],q[14];
u1(-pi/1099511627776) q[14];
cx q[53],q[14];
u1(pi/1099511627776) q[14];
u1(pi/549755813888) q[53];
cx q[53],q[15];
u1(-pi/549755813888) q[15];
cx q[53],q[15];
u1(pi/549755813888) q[15];
u1(pi/274877906944) q[53];
cx q[53],q[16];
u1(-pi/274877906944) q[16];
cx q[53],q[16];
u1(pi/274877906944) q[16];
u1(pi/137438953472) q[53];
cx q[53],q[17];
u1(-pi/137438953472) q[17];
cx q[53],q[17];
u1(pi/137438953472) q[17];
u1(pi/68719476736) q[53];
cx q[53],q[18];
u1(-pi/68719476736) q[18];
cx q[53],q[18];
u1(pi/68719476736) q[18];
u1(pi/34359738368) q[53];
cx q[53],q[19];
u1(-pi/34359738368) q[19];
cx q[53],q[19];
u1(pi/34359738368) q[19];
u1(pi/17179869184) q[53];
cx q[53],q[20];
u1(-pi/17179869184) q[20];
cx q[53],q[20];
u1(pi/17179869184) q[20];
u1(pi/8589934592) q[53];
cx q[53],q[21];
u1(-pi/8589934592) q[21];
cx q[53],q[21];
u1(pi/8589934592) q[21];
u1(pi/4294967296) q[53];
cx q[53],q[22];
u1(-pi/4294967296) q[22];
cx q[53],q[22];
u1(pi/4294967296) q[22];
u1(pi/2147483648) q[53];
cx q[53],q[23];
u1(-pi/2147483648) q[23];
cx q[53],q[23];
u1(pi/2147483648) q[23];
u1(pi/1073741824) q[53];
cx q[53],q[24];
u1(-pi/1073741824) q[24];
cx q[53],q[24];
u1(pi/1073741824) q[24];
u1(pi/536870912) q[53];
cx q[53],q[25];
u1(-pi/536870912) q[25];
cx q[53],q[25];
u1(pi/536870912) q[25];
u1(pi/268435456) q[53];
cx q[53],q[26];
u1(-pi/268435456) q[26];
cx q[53],q[26];
u1(pi/268435456) q[26];
u1(pi/134217728) q[53];
cx q[53],q[27];
u1(-pi/134217728) q[27];
cx q[53],q[27];
u1(pi/134217728) q[27];
u1(pi/67108864) q[53];
cx q[53],q[28];
u1(-pi/67108864) q[28];
cx q[53],q[28];
u1(pi/67108864) q[28];
u1(pi/33554432) q[53];
cx q[53],q[29];
u1(-pi/33554432) q[29];
cx q[53],q[29];
u1(pi/33554432) q[29];
u1(pi/16777216) q[53];
cx q[53],q[30];
u1(-pi/16777216) q[30];
cx q[53],q[30];
u1(pi/16777216) q[30];
u1(pi/8388608) q[53];
cx q[53],q[31];
u1(-pi/8388608) q[31];
cx q[53],q[31];
u1(pi/8388608) q[31];
u1(pi/4194304) q[53];
cx q[53],q[32];
u1(-pi/4194304) q[32];
cx q[53],q[32];
u1(pi/4194304) q[32];
u1(pi/2097152) q[53];
cx q[53],q[33];
u1(-pi/2097152) q[33];
cx q[53],q[33];
u1(pi/2097152) q[33];
u1(pi/1048576) q[53];
cx q[53],q[34];
u1(-pi/1048576) q[34];
cx q[53],q[34];
u1(pi/1048576) q[34];
u1(pi/524288) q[53];
cx q[53],q[35];
u1(-pi/524288) q[35];
cx q[53],q[35];
u1(pi/524288) q[35];
u1(pi/262144) q[53];
cx q[53],q[36];
u1(-pi/262144) q[36];
cx q[53],q[36];
u1(pi/262144) q[36];
u1(pi/131072) q[53];
cx q[53],q[37];
u1(-pi/131072) q[37];
cx q[53],q[37];
u1(pi/131072) q[37];
u1(pi/65536) q[53];
cx q[53],q[38];
u1(-pi/65536) q[38];
cx q[53],q[38];
u1(pi/65536) q[38];
u1(pi/32768) q[53];
cx q[53],q[39];
u1(-pi/32768) q[39];
cx q[53],q[39];
u1(pi/32768) q[39];
u1(pi/16384) q[53];
cx q[53],q[40];
u1(-pi/16384) q[40];
cx q[53],q[40];
u1(pi/16384) q[40];
u1(pi/8192) q[53];
cx q[53],q[41];
u1(-pi/8192) q[41];
cx q[53],q[41];
u1(pi/8192) q[41];
u1(pi/4096) q[53];
cx q[53],q[42];
u1(-pi/4096) q[42];
cx q[53],q[42];
u1(pi/4096) q[42];
u1(pi/2048) q[53];
cx q[53],q[43];
u1(-pi/2048) q[43];
cx q[53],q[43];
u1(pi/2048) q[43];
u1(pi/1024) q[53];
cx q[53],q[44];
u1(-pi/1024) q[44];
cx q[53],q[44];
u1(pi/1024) q[44];
u1(pi/512) q[53];
cx q[53],q[45];
u1(-pi/512) q[45];
cx q[53],q[45];
u1(pi/512) q[45];
u1(pi/256) q[53];
cx q[53],q[46];
u1(-pi/256) q[46];
cx q[53],q[46];
u1(pi/256) q[46];
u1(pi/128) q[53];
cx q[53],q[47];
u1(-pi/128) q[47];
cx q[53],q[47];
u1(pi/128) q[47];
u1(pi/64) q[53];
cx q[53],q[48];
u1(-pi/64) q[48];
cx q[53],q[48];
u1(pi/64) q[48];
u1(pi/32) q[53];
cx q[53],q[49];
u1(-pi/32) q[49];
cx q[53],q[49];
u1(pi/32) q[49];
u1(pi/16) q[53];
cx q[53],q[50];
u1(-pi/16) q[50];
cx q[53],q[50];
u1(pi/16) q[50];
u1(pi/8) q[53];
cx q[53],q[51];
u1(-pi/8) q[51];
cx q[53],q[51];
u1(pi/8) q[51];
u1(pi/4) q[53];
cx q[53],q[52];
u1(-pi/4) q[52];
cx q[53],q[52];
u1(pi/4) q[52];
h q[53];
u1(0) q[54];
cx q[54],q[0];
u1(0) q[0];
cx q[54],q[0];
u1(0) q[0];
u1(0) q[54];
cx q[54],q[1];
u1(0) q[1];
cx q[54],q[1];
u1(0) q[1];
u1(0) q[54];
cx q[54],q[2];
u1(0) q[2];
cx q[54],q[2];
u1(0) q[2];
u1(0) q[54];
cx q[54],q[3];
u1(0) q[3];
cx q[54],q[3];
u1(0) q[3];
u1(0) q[54];
cx q[54],q[4];
u1(0) q[4];
cx q[54],q[4];
u1(0) q[4];
u1(0) q[54];
cx q[54],q[5];
u1(0) q[5];
cx q[54],q[5];
u1(0) q[5];
u1(0) q[54];
cx q[54],q[6];
u1(0) q[6];
cx q[54],q[6];
u1(0) q[6];
u1(pi/281474976710656) q[54];
cx q[54],q[7];
u1(-pi/281474976710656) q[7];
cx q[54],q[7];
u1(pi/281474976710656) q[7];
u1(pi/140737488355328) q[54];
cx q[54],q[8];
u1(-pi/140737488355328) q[8];
cx q[54],q[8];
u1(pi/140737488355328) q[8];
u1(pi/70368744177664) q[54];
cx q[54],q[9];
u1(-pi/70368744177664) q[9];
cx q[54],q[9];
u1(pi/70368744177664) q[9];
u1(pi/35184372088832) q[54];
cx q[54],q[10];
u1(-pi/35184372088832) q[10];
cx q[54],q[10];
u1(pi/35184372088832) q[10];
u1(pi/17592186044416) q[54];
cx q[54],q[11];
u1(-pi/17592186044416) q[11];
cx q[54],q[11];
u1(pi/17592186044416) q[11];
u1(pi/8796093022208) q[54];
cx q[54],q[12];
u1(-pi/8796093022208) q[12];
cx q[54],q[12];
u1(pi/8796093022208) q[12];
u1(pi/4398046511104) q[54];
cx q[54],q[13];
u1(-pi/4398046511104) q[13];
cx q[54],q[13];
u1(pi/4398046511104) q[13];
u1(pi/2199023255552) q[54];
cx q[54],q[14];
u1(-pi/2199023255552) q[14];
cx q[54],q[14];
u1(pi/2199023255552) q[14];
u1(pi/1099511627776) q[54];
cx q[54],q[15];
u1(-pi/1099511627776) q[15];
cx q[54],q[15];
u1(pi/1099511627776) q[15];
u1(pi/549755813888) q[54];
cx q[54],q[16];
u1(-pi/549755813888) q[16];
cx q[54],q[16];
u1(pi/549755813888) q[16];
u1(pi/274877906944) q[54];
cx q[54],q[17];
u1(-pi/274877906944) q[17];
cx q[54],q[17];
u1(pi/274877906944) q[17];
u1(pi/137438953472) q[54];
cx q[54],q[18];
u1(-pi/137438953472) q[18];
cx q[54],q[18];
u1(pi/137438953472) q[18];
u1(pi/68719476736) q[54];
cx q[54],q[19];
u1(-pi/68719476736) q[19];
cx q[54],q[19];
u1(pi/68719476736) q[19];
u1(pi/34359738368) q[54];
cx q[54],q[20];
u1(-pi/34359738368) q[20];
cx q[54],q[20];
u1(pi/34359738368) q[20];
u1(pi/17179869184) q[54];
cx q[54],q[21];
u1(-pi/17179869184) q[21];
cx q[54],q[21];
u1(pi/17179869184) q[21];
u1(pi/8589934592) q[54];
cx q[54],q[22];
u1(-pi/8589934592) q[22];
cx q[54],q[22];
u1(pi/8589934592) q[22];
u1(pi/4294967296) q[54];
cx q[54],q[23];
u1(-pi/4294967296) q[23];
cx q[54],q[23];
u1(pi/4294967296) q[23];
u1(pi/2147483648) q[54];
cx q[54],q[24];
u1(-pi/2147483648) q[24];
cx q[54],q[24];
u1(pi/2147483648) q[24];
u1(pi/1073741824) q[54];
cx q[54],q[25];
u1(-pi/1073741824) q[25];
cx q[54],q[25];
u1(pi/1073741824) q[25];
u1(pi/536870912) q[54];
cx q[54],q[26];
u1(-pi/536870912) q[26];
cx q[54],q[26];
u1(pi/536870912) q[26];
u1(pi/268435456) q[54];
cx q[54],q[27];
u1(-pi/268435456) q[27];
cx q[54],q[27];
u1(pi/268435456) q[27];
u1(pi/134217728) q[54];
cx q[54],q[28];
u1(-pi/134217728) q[28];
cx q[54],q[28];
u1(pi/134217728) q[28];
u1(pi/67108864) q[54];
cx q[54],q[29];
u1(-pi/67108864) q[29];
cx q[54],q[29];
u1(pi/67108864) q[29];
u1(pi/33554432) q[54];
cx q[54],q[30];
u1(-pi/33554432) q[30];
cx q[54],q[30];
u1(pi/33554432) q[30];
u1(pi/16777216) q[54];
cx q[54],q[31];
u1(-pi/16777216) q[31];
cx q[54],q[31];
u1(pi/16777216) q[31];
u1(pi/8388608) q[54];
cx q[54],q[32];
u1(-pi/8388608) q[32];
cx q[54],q[32];
u1(pi/8388608) q[32];
u1(pi/4194304) q[54];
cx q[54],q[33];
u1(-pi/4194304) q[33];
cx q[54],q[33];
u1(pi/4194304) q[33];
u1(pi/2097152) q[54];
cx q[54],q[34];
u1(-pi/2097152) q[34];
cx q[54],q[34];
u1(pi/2097152) q[34];
u1(pi/1048576) q[54];
cx q[54],q[35];
u1(-pi/1048576) q[35];
cx q[54],q[35];
u1(pi/1048576) q[35];
u1(pi/524288) q[54];
cx q[54],q[36];
u1(-pi/524288) q[36];
cx q[54],q[36];
u1(pi/524288) q[36];
u1(pi/262144) q[54];
cx q[54],q[37];
u1(-pi/262144) q[37];
cx q[54],q[37];
u1(pi/262144) q[37];
u1(pi/131072) q[54];
cx q[54],q[38];
u1(-pi/131072) q[38];
cx q[54],q[38];
u1(pi/131072) q[38];
u1(pi/65536) q[54];
cx q[54],q[39];
u1(-pi/65536) q[39];
cx q[54],q[39];
u1(pi/65536) q[39];
u1(pi/32768) q[54];
cx q[54],q[40];
u1(-pi/32768) q[40];
cx q[54],q[40];
u1(pi/32768) q[40];
u1(pi/16384) q[54];
cx q[54],q[41];
u1(-pi/16384) q[41];
cx q[54],q[41];
u1(pi/16384) q[41];
u1(pi/8192) q[54];
cx q[54],q[42];
u1(-pi/8192) q[42];
cx q[54],q[42];
u1(pi/8192) q[42];
u1(pi/4096) q[54];
cx q[54],q[43];
u1(-pi/4096) q[43];
cx q[54],q[43];
u1(pi/4096) q[43];
u1(pi/2048) q[54];
cx q[54],q[44];
u1(-pi/2048) q[44];
cx q[54],q[44];
u1(pi/2048) q[44];
u1(pi/1024) q[54];
cx q[54],q[45];
u1(-pi/1024) q[45];
cx q[54],q[45];
u1(pi/1024) q[45];
u1(pi/512) q[54];
cx q[54],q[46];
u1(-pi/512) q[46];
cx q[54],q[46];
u1(pi/512) q[46];
u1(pi/256) q[54];
cx q[54],q[47];
u1(-pi/256) q[47];
cx q[54],q[47];
u1(pi/256) q[47];
u1(pi/128) q[54];
cx q[54],q[48];
u1(-pi/128) q[48];
cx q[54],q[48];
u1(pi/128) q[48];
u1(pi/64) q[54];
cx q[54],q[49];
u1(-pi/64) q[49];
cx q[54],q[49];
u1(pi/64) q[49];
u1(pi/32) q[54];
cx q[54],q[50];
u1(-pi/32) q[50];
cx q[54],q[50];
u1(pi/32) q[50];
u1(pi/16) q[54];
cx q[54],q[51];
u1(-pi/16) q[51];
cx q[54],q[51];
u1(pi/16) q[51];
u1(pi/8) q[54];
cx q[54],q[52];
u1(-pi/8) q[52];
cx q[54],q[52];
u1(pi/8) q[52];
u1(pi/4) q[54];
cx q[54],q[53];
u1(-pi/4) q[53];
cx q[54],q[53];
u1(pi/4) q[53];
h q[54];
u1(0) q[55];
cx q[55],q[0];
u1(0) q[0];
cx q[55],q[0];
u1(0) q[0];
u1(0) q[55];
cx q[55],q[1];
u1(0) q[1];
cx q[55],q[1];
u1(0) q[1];
u1(0) q[55];
cx q[55],q[2];
u1(0) q[2];
cx q[55],q[2];
u1(0) q[2];
u1(0) q[55];
cx q[55],q[3];
u1(0) q[3];
cx q[55],q[3];
u1(0) q[3];
u1(0) q[55];
cx q[55],q[4];
u1(0) q[4];
cx q[55],q[4];
u1(0) q[4];
u1(0) q[55];
cx q[55],q[5];
u1(0) q[5];
cx q[55],q[5];
u1(0) q[5];
u1(0) q[55];
cx q[55],q[6];
u1(0) q[6];
cx q[55],q[6];
u1(0) q[6];
u1(0) q[55];
cx q[55],q[7];
u1(0) q[7];
cx q[55],q[7];
u1(0) q[7];
u1(pi/281474976710656) q[55];
cx q[55],q[8];
u1(-pi/281474976710656) q[8];
cx q[55],q[8];
u1(pi/281474976710656) q[8];
u1(pi/140737488355328) q[55];
cx q[55],q[9];
u1(-pi/140737488355328) q[9];
cx q[55],q[9];
u1(pi/140737488355328) q[9];
u1(pi/70368744177664) q[55];
cx q[55],q[10];
u1(-pi/70368744177664) q[10];
cx q[55],q[10];
u1(pi/70368744177664) q[10];
u1(pi/35184372088832) q[55];
cx q[55],q[11];
u1(-pi/35184372088832) q[11];
cx q[55],q[11];
u1(pi/35184372088832) q[11];
u1(pi/17592186044416) q[55];
cx q[55],q[12];
u1(-pi/17592186044416) q[12];
cx q[55],q[12];
u1(pi/17592186044416) q[12];
u1(pi/8796093022208) q[55];
cx q[55],q[13];
u1(-pi/8796093022208) q[13];
cx q[55],q[13];
u1(pi/8796093022208) q[13];
u1(pi/4398046511104) q[55];
cx q[55],q[14];
u1(-pi/4398046511104) q[14];
cx q[55],q[14];
u1(pi/4398046511104) q[14];
u1(pi/2199023255552) q[55];
cx q[55],q[15];
u1(-pi/2199023255552) q[15];
cx q[55],q[15];
u1(pi/2199023255552) q[15];
u1(pi/1099511627776) q[55];
cx q[55],q[16];
u1(-pi/1099511627776) q[16];
cx q[55],q[16];
u1(pi/1099511627776) q[16];
u1(pi/549755813888) q[55];
cx q[55],q[17];
u1(-pi/549755813888) q[17];
cx q[55],q[17];
u1(pi/549755813888) q[17];
u1(pi/274877906944) q[55];
cx q[55],q[18];
u1(-pi/274877906944) q[18];
cx q[55],q[18];
u1(pi/274877906944) q[18];
u1(pi/137438953472) q[55];
cx q[55],q[19];
u1(-pi/137438953472) q[19];
cx q[55],q[19];
u1(pi/137438953472) q[19];
u1(pi/68719476736) q[55];
cx q[55],q[20];
u1(-pi/68719476736) q[20];
cx q[55],q[20];
u1(pi/68719476736) q[20];
u1(pi/34359738368) q[55];
cx q[55],q[21];
u1(-pi/34359738368) q[21];
cx q[55],q[21];
u1(pi/34359738368) q[21];
u1(pi/17179869184) q[55];
cx q[55],q[22];
u1(-pi/17179869184) q[22];
cx q[55],q[22];
u1(pi/17179869184) q[22];
u1(pi/8589934592) q[55];
cx q[55],q[23];
u1(-pi/8589934592) q[23];
cx q[55],q[23];
u1(pi/8589934592) q[23];
u1(pi/4294967296) q[55];
cx q[55],q[24];
u1(-pi/4294967296) q[24];
cx q[55],q[24];
u1(pi/4294967296) q[24];
u1(pi/2147483648) q[55];
cx q[55],q[25];
u1(-pi/2147483648) q[25];
cx q[55],q[25];
u1(pi/2147483648) q[25];
u1(pi/1073741824) q[55];
cx q[55],q[26];
u1(-pi/1073741824) q[26];
cx q[55],q[26];
u1(pi/1073741824) q[26];
u1(pi/536870912) q[55];
cx q[55],q[27];
u1(-pi/536870912) q[27];
cx q[55],q[27];
u1(pi/536870912) q[27];
u1(pi/268435456) q[55];
cx q[55],q[28];
u1(-pi/268435456) q[28];
cx q[55],q[28];
u1(pi/268435456) q[28];
u1(pi/134217728) q[55];
cx q[55],q[29];
u1(-pi/134217728) q[29];
cx q[55],q[29];
u1(pi/134217728) q[29];
u1(pi/67108864) q[55];
cx q[55],q[30];
u1(-pi/67108864) q[30];
cx q[55],q[30];
u1(pi/67108864) q[30];
u1(pi/33554432) q[55];
cx q[55],q[31];
u1(-pi/33554432) q[31];
cx q[55],q[31];
u1(pi/33554432) q[31];
u1(pi/16777216) q[55];
cx q[55],q[32];
u1(-pi/16777216) q[32];
cx q[55],q[32];
u1(pi/16777216) q[32];
u1(pi/8388608) q[55];
cx q[55],q[33];
u1(-pi/8388608) q[33];
cx q[55],q[33];
u1(pi/8388608) q[33];
u1(pi/4194304) q[55];
cx q[55],q[34];
u1(-pi/4194304) q[34];
cx q[55],q[34];
u1(pi/4194304) q[34];
u1(pi/2097152) q[55];
cx q[55],q[35];
u1(-pi/2097152) q[35];
cx q[55],q[35];
u1(pi/2097152) q[35];
u1(pi/1048576) q[55];
cx q[55],q[36];
u1(-pi/1048576) q[36];
cx q[55],q[36];
u1(pi/1048576) q[36];
u1(pi/524288) q[55];
cx q[55],q[37];
u1(-pi/524288) q[37];
cx q[55],q[37];
u1(pi/524288) q[37];
u1(pi/262144) q[55];
cx q[55],q[38];
u1(-pi/262144) q[38];
cx q[55],q[38];
u1(pi/262144) q[38];
u1(pi/131072) q[55];
cx q[55],q[39];
u1(-pi/131072) q[39];
cx q[55],q[39];
u1(pi/131072) q[39];
u1(pi/65536) q[55];
cx q[55],q[40];
u1(-pi/65536) q[40];
cx q[55],q[40];
u1(pi/65536) q[40];
u1(pi/32768) q[55];
cx q[55],q[41];
u1(-pi/32768) q[41];
cx q[55],q[41];
u1(pi/32768) q[41];
u1(pi/16384) q[55];
cx q[55],q[42];
u1(-pi/16384) q[42];
cx q[55],q[42];
u1(pi/16384) q[42];
u1(pi/8192) q[55];
cx q[55],q[43];
u1(-pi/8192) q[43];
cx q[55],q[43];
u1(pi/8192) q[43];
u1(pi/4096) q[55];
cx q[55],q[44];
u1(-pi/4096) q[44];
cx q[55],q[44];
u1(pi/4096) q[44];
u1(pi/2048) q[55];
cx q[55],q[45];
u1(-pi/2048) q[45];
cx q[55],q[45];
u1(pi/2048) q[45];
u1(pi/1024) q[55];
cx q[55],q[46];
u1(-pi/1024) q[46];
cx q[55],q[46];
u1(pi/1024) q[46];
u1(pi/512) q[55];
cx q[55],q[47];
u1(-pi/512) q[47];
cx q[55],q[47];
u1(pi/512) q[47];
u1(pi/256) q[55];
cx q[55],q[48];
u1(-pi/256) q[48];
cx q[55],q[48];
u1(pi/256) q[48];
u1(pi/128) q[55];
cx q[55],q[49];
u1(-pi/128) q[49];
cx q[55],q[49];
u1(pi/128) q[49];
u1(pi/64) q[55];
cx q[55],q[50];
u1(-pi/64) q[50];
cx q[55],q[50];
u1(pi/64) q[50];
u1(pi/32) q[55];
cx q[55],q[51];
u1(-pi/32) q[51];
cx q[55],q[51];
u1(pi/32) q[51];
u1(pi/16) q[55];
cx q[55],q[52];
u1(-pi/16) q[52];
cx q[55],q[52];
u1(pi/16) q[52];
u1(pi/8) q[55];
cx q[55],q[53];
u1(-pi/8) q[53];
cx q[55],q[53];
u1(pi/8) q[53];
u1(pi/4) q[55];
cx q[55],q[54];
u1(-pi/4) q[54];
cx q[55],q[54];
u1(pi/4) q[54];
h q[55];
u1(0) q[56];
cx q[56],q[0];
u1(0) q[0];
cx q[56],q[0];
u1(0) q[0];
u1(0) q[56];
cx q[56],q[1];
u1(0) q[1];
cx q[56],q[1];
u1(0) q[1];
u1(0) q[56];
cx q[56],q[2];
u1(0) q[2];
cx q[56],q[2];
u1(0) q[2];
u1(0) q[56];
cx q[56],q[3];
u1(0) q[3];
cx q[56],q[3];
u1(0) q[3];
u1(0) q[56];
cx q[56],q[4];
u1(0) q[4];
cx q[56],q[4];
u1(0) q[4];
u1(0) q[56];
cx q[56],q[5];
u1(0) q[5];
cx q[56],q[5];
u1(0) q[5];
u1(0) q[56];
cx q[56],q[6];
u1(0) q[6];
cx q[56],q[6];
u1(0) q[6];
u1(0) q[56];
cx q[56],q[7];
u1(0) q[7];
cx q[56],q[7];
u1(0) q[7];
u1(0) q[56];
cx q[56],q[8];
u1(0) q[8];
cx q[56],q[8];
u1(0) q[8];
u1(pi/281474976710656) q[56];
cx q[56],q[9];
u1(-pi/281474976710656) q[9];
cx q[56],q[9];
u1(pi/281474976710656) q[9];
u1(pi/140737488355328) q[56];
cx q[56],q[10];
u1(-pi/140737488355328) q[10];
cx q[56],q[10];
u1(pi/140737488355328) q[10];
u1(pi/70368744177664) q[56];
cx q[56],q[11];
u1(-pi/70368744177664) q[11];
cx q[56],q[11];
u1(pi/70368744177664) q[11];
u1(pi/35184372088832) q[56];
cx q[56],q[12];
u1(-pi/35184372088832) q[12];
cx q[56],q[12];
u1(pi/35184372088832) q[12];
u1(pi/17592186044416) q[56];
cx q[56],q[13];
u1(-pi/17592186044416) q[13];
cx q[56],q[13];
u1(pi/17592186044416) q[13];
u1(pi/8796093022208) q[56];
cx q[56],q[14];
u1(-pi/8796093022208) q[14];
cx q[56],q[14];
u1(pi/8796093022208) q[14];
u1(pi/4398046511104) q[56];
cx q[56],q[15];
u1(-pi/4398046511104) q[15];
cx q[56],q[15];
u1(pi/4398046511104) q[15];
u1(pi/2199023255552) q[56];
cx q[56],q[16];
u1(-pi/2199023255552) q[16];
cx q[56],q[16];
u1(pi/2199023255552) q[16];
u1(pi/1099511627776) q[56];
cx q[56],q[17];
u1(-pi/1099511627776) q[17];
cx q[56],q[17];
u1(pi/1099511627776) q[17];
u1(pi/549755813888) q[56];
cx q[56],q[18];
u1(-pi/549755813888) q[18];
cx q[56],q[18];
u1(pi/549755813888) q[18];
u1(pi/274877906944) q[56];
cx q[56],q[19];
u1(-pi/274877906944) q[19];
cx q[56],q[19];
u1(pi/274877906944) q[19];
u1(pi/137438953472) q[56];
cx q[56],q[20];
u1(-pi/137438953472) q[20];
cx q[56],q[20];
u1(pi/137438953472) q[20];
u1(pi/68719476736) q[56];
cx q[56],q[21];
u1(-pi/68719476736) q[21];
cx q[56],q[21];
u1(pi/68719476736) q[21];
u1(pi/34359738368) q[56];
cx q[56],q[22];
u1(-pi/34359738368) q[22];
cx q[56],q[22];
u1(pi/34359738368) q[22];
u1(pi/17179869184) q[56];
cx q[56],q[23];
u1(-pi/17179869184) q[23];
cx q[56],q[23];
u1(pi/17179869184) q[23];
u1(pi/8589934592) q[56];
cx q[56],q[24];
u1(-pi/8589934592) q[24];
cx q[56],q[24];
u1(pi/8589934592) q[24];
u1(pi/4294967296) q[56];
cx q[56],q[25];
u1(-pi/4294967296) q[25];
cx q[56],q[25];
u1(pi/4294967296) q[25];
u1(pi/2147483648) q[56];
cx q[56],q[26];
u1(-pi/2147483648) q[26];
cx q[56],q[26];
u1(pi/2147483648) q[26];
u1(pi/1073741824) q[56];
cx q[56],q[27];
u1(-pi/1073741824) q[27];
cx q[56],q[27];
u1(pi/1073741824) q[27];
u1(pi/536870912) q[56];
cx q[56],q[28];
u1(-pi/536870912) q[28];
cx q[56],q[28];
u1(pi/536870912) q[28];
u1(pi/268435456) q[56];
cx q[56],q[29];
u1(-pi/268435456) q[29];
cx q[56],q[29];
u1(pi/268435456) q[29];
u1(pi/134217728) q[56];
cx q[56],q[30];
u1(-pi/134217728) q[30];
cx q[56],q[30];
u1(pi/134217728) q[30];
u1(pi/67108864) q[56];
cx q[56],q[31];
u1(-pi/67108864) q[31];
cx q[56],q[31];
u1(pi/67108864) q[31];
u1(pi/33554432) q[56];
cx q[56],q[32];
u1(-pi/33554432) q[32];
cx q[56],q[32];
u1(pi/33554432) q[32];
u1(pi/16777216) q[56];
cx q[56],q[33];
u1(-pi/16777216) q[33];
cx q[56],q[33];
u1(pi/16777216) q[33];
u1(pi/8388608) q[56];
cx q[56],q[34];
u1(-pi/8388608) q[34];
cx q[56],q[34];
u1(pi/8388608) q[34];
u1(pi/4194304) q[56];
cx q[56],q[35];
u1(-pi/4194304) q[35];
cx q[56],q[35];
u1(pi/4194304) q[35];
u1(pi/2097152) q[56];
cx q[56],q[36];
u1(-pi/2097152) q[36];
cx q[56],q[36];
u1(pi/2097152) q[36];
u1(pi/1048576) q[56];
cx q[56],q[37];
u1(-pi/1048576) q[37];
cx q[56],q[37];
u1(pi/1048576) q[37];
u1(pi/524288) q[56];
cx q[56],q[38];
u1(-pi/524288) q[38];
cx q[56],q[38];
u1(pi/524288) q[38];
u1(pi/262144) q[56];
cx q[56],q[39];
u1(-pi/262144) q[39];
cx q[56],q[39];
u1(pi/262144) q[39];
u1(pi/131072) q[56];
cx q[56],q[40];
u1(-pi/131072) q[40];
cx q[56],q[40];
u1(pi/131072) q[40];
u1(pi/65536) q[56];
cx q[56],q[41];
u1(-pi/65536) q[41];
cx q[56],q[41];
u1(pi/65536) q[41];
u1(pi/32768) q[56];
cx q[56],q[42];
u1(-pi/32768) q[42];
cx q[56],q[42];
u1(pi/32768) q[42];
u1(pi/16384) q[56];
cx q[56],q[43];
u1(-pi/16384) q[43];
cx q[56],q[43];
u1(pi/16384) q[43];
u1(pi/8192) q[56];
cx q[56],q[44];
u1(-pi/8192) q[44];
cx q[56],q[44];
u1(pi/8192) q[44];
u1(pi/4096) q[56];
cx q[56],q[45];
u1(-pi/4096) q[45];
cx q[56],q[45];
u1(pi/4096) q[45];
u1(pi/2048) q[56];
cx q[56],q[46];
u1(-pi/2048) q[46];
cx q[56],q[46];
u1(pi/2048) q[46];
u1(pi/1024) q[56];
cx q[56],q[47];
u1(-pi/1024) q[47];
cx q[56],q[47];
u1(pi/1024) q[47];
u1(pi/512) q[56];
cx q[56],q[48];
u1(-pi/512) q[48];
cx q[56],q[48];
u1(pi/512) q[48];
u1(pi/256) q[56];
cx q[56],q[49];
u1(-pi/256) q[49];
cx q[56],q[49];
u1(pi/256) q[49];
u1(pi/128) q[56];
cx q[56],q[50];
u1(-pi/128) q[50];
cx q[56],q[50];
u1(pi/128) q[50];
u1(pi/64) q[56];
cx q[56],q[51];
u1(-pi/64) q[51];
cx q[56],q[51];
u1(pi/64) q[51];
u1(pi/32) q[56];
cx q[56],q[52];
u1(-pi/32) q[52];
cx q[56],q[52];
u1(pi/32) q[52];
u1(pi/16) q[56];
cx q[56],q[53];
u1(-pi/16) q[53];
cx q[56],q[53];
u1(pi/16) q[53];
u1(pi/8) q[56];
cx q[56],q[54];
u1(-pi/8) q[54];
cx q[56],q[54];
u1(pi/8) q[54];
u1(pi/4) q[56];
cx q[56],q[55];
u1(-pi/4) q[55];
cx q[56],q[55];
u1(pi/4) q[55];
h q[56];
u1(0) q[57];
cx q[57],q[0];
u1(0) q[0];
cx q[57],q[0];
u1(0) q[0];
u1(0) q[57];
cx q[57],q[1];
u1(0) q[1];
cx q[57],q[1];
u1(0) q[1];
u1(0) q[57];
cx q[57],q[2];
u1(0) q[2];
cx q[57],q[2];
u1(0) q[2];
u1(0) q[57];
cx q[57],q[3];
u1(0) q[3];
cx q[57],q[3];
u1(0) q[3];
u1(0) q[57];
cx q[57],q[4];
u1(0) q[4];
cx q[57],q[4];
u1(0) q[4];
u1(0) q[57];
cx q[57],q[5];
u1(0) q[5];
cx q[57],q[5];
u1(0) q[5];
u1(0) q[57];
cx q[57],q[6];
u1(0) q[6];
cx q[57],q[6];
u1(0) q[6];
u1(0) q[57];
cx q[57],q[7];
u1(0) q[7];
cx q[57],q[7];
u1(0) q[7];
u1(0) q[57];
cx q[57],q[8];
u1(0) q[8];
cx q[57],q[8];
u1(0) q[8];
u1(0) q[57];
cx q[57],q[9];
u1(0) q[9];
cx q[57],q[9];
u1(0) q[9];
u1(pi/281474976710656) q[57];
cx q[57],q[10];
u1(-pi/281474976710656) q[10];
cx q[57],q[10];
u1(pi/281474976710656) q[10];
u1(pi/140737488355328) q[57];
cx q[57],q[11];
u1(-pi/140737488355328) q[11];
cx q[57],q[11];
u1(pi/140737488355328) q[11];
u1(pi/70368744177664) q[57];
cx q[57],q[12];
u1(-pi/70368744177664) q[12];
cx q[57],q[12];
u1(pi/70368744177664) q[12];
u1(pi/35184372088832) q[57];
cx q[57],q[13];
u1(-pi/35184372088832) q[13];
cx q[57],q[13];
u1(pi/35184372088832) q[13];
u1(pi/17592186044416) q[57];
cx q[57],q[14];
u1(-pi/17592186044416) q[14];
cx q[57],q[14];
u1(pi/17592186044416) q[14];
u1(pi/8796093022208) q[57];
cx q[57],q[15];
u1(-pi/8796093022208) q[15];
cx q[57],q[15];
u1(pi/8796093022208) q[15];
u1(pi/4398046511104) q[57];
cx q[57],q[16];
u1(-pi/4398046511104) q[16];
cx q[57],q[16];
u1(pi/4398046511104) q[16];
u1(pi/2199023255552) q[57];
cx q[57],q[17];
u1(-pi/2199023255552) q[17];
cx q[57],q[17];
u1(pi/2199023255552) q[17];
u1(pi/1099511627776) q[57];
cx q[57],q[18];
u1(-pi/1099511627776) q[18];
cx q[57],q[18];
u1(pi/1099511627776) q[18];
u1(pi/549755813888) q[57];
cx q[57],q[19];
u1(-pi/549755813888) q[19];
cx q[57],q[19];
u1(pi/549755813888) q[19];
u1(pi/274877906944) q[57];
cx q[57],q[20];
u1(-pi/274877906944) q[20];
cx q[57],q[20];
u1(pi/274877906944) q[20];
u1(pi/137438953472) q[57];
cx q[57],q[21];
u1(-pi/137438953472) q[21];
cx q[57],q[21];
u1(pi/137438953472) q[21];
u1(pi/68719476736) q[57];
cx q[57],q[22];
u1(-pi/68719476736) q[22];
cx q[57],q[22];
u1(pi/68719476736) q[22];
u1(pi/34359738368) q[57];
cx q[57],q[23];
u1(-pi/34359738368) q[23];
cx q[57],q[23];
u1(pi/34359738368) q[23];
u1(pi/17179869184) q[57];
cx q[57],q[24];
u1(-pi/17179869184) q[24];
cx q[57],q[24];
u1(pi/17179869184) q[24];
u1(pi/8589934592) q[57];
cx q[57],q[25];
u1(-pi/8589934592) q[25];
cx q[57],q[25];
u1(pi/8589934592) q[25];
u1(pi/4294967296) q[57];
cx q[57],q[26];
u1(-pi/4294967296) q[26];
cx q[57],q[26];
u1(pi/4294967296) q[26];
u1(pi/2147483648) q[57];
cx q[57],q[27];
u1(-pi/2147483648) q[27];
cx q[57],q[27];
u1(pi/2147483648) q[27];
u1(pi/1073741824) q[57];
cx q[57],q[28];
u1(-pi/1073741824) q[28];
cx q[57],q[28];
u1(pi/1073741824) q[28];
u1(pi/536870912) q[57];
cx q[57],q[29];
u1(-pi/536870912) q[29];
cx q[57],q[29];
u1(pi/536870912) q[29];
u1(pi/268435456) q[57];
cx q[57],q[30];
u1(-pi/268435456) q[30];
cx q[57],q[30];
u1(pi/268435456) q[30];
u1(pi/134217728) q[57];
cx q[57],q[31];
u1(-pi/134217728) q[31];
cx q[57],q[31];
u1(pi/134217728) q[31];
u1(pi/67108864) q[57];
cx q[57],q[32];
u1(-pi/67108864) q[32];
cx q[57],q[32];
u1(pi/67108864) q[32];
u1(pi/33554432) q[57];
cx q[57],q[33];
u1(-pi/33554432) q[33];
cx q[57],q[33];
u1(pi/33554432) q[33];
u1(pi/16777216) q[57];
cx q[57],q[34];
u1(-pi/16777216) q[34];
cx q[57],q[34];
u1(pi/16777216) q[34];
u1(pi/8388608) q[57];
cx q[57],q[35];
u1(-pi/8388608) q[35];
cx q[57],q[35];
u1(pi/8388608) q[35];
u1(pi/4194304) q[57];
cx q[57],q[36];
u1(-pi/4194304) q[36];
cx q[57],q[36];
u1(pi/4194304) q[36];
u1(pi/2097152) q[57];
cx q[57],q[37];
u1(-pi/2097152) q[37];
cx q[57],q[37];
u1(pi/2097152) q[37];
u1(pi/1048576) q[57];
cx q[57],q[38];
u1(-pi/1048576) q[38];
cx q[57],q[38];
u1(pi/1048576) q[38];
u1(pi/524288) q[57];
cx q[57],q[39];
u1(-pi/524288) q[39];
cx q[57],q[39];
u1(pi/524288) q[39];
u1(pi/262144) q[57];
cx q[57],q[40];
u1(-pi/262144) q[40];
cx q[57],q[40];
u1(pi/262144) q[40];
u1(pi/131072) q[57];
cx q[57],q[41];
u1(-pi/131072) q[41];
cx q[57],q[41];
u1(pi/131072) q[41];
u1(pi/65536) q[57];
cx q[57],q[42];
u1(-pi/65536) q[42];
cx q[57],q[42];
u1(pi/65536) q[42];
u1(pi/32768) q[57];
cx q[57],q[43];
u1(-pi/32768) q[43];
cx q[57],q[43];
u1(pi/32768) q[43];
u1(pi/16384) q[57];
cx q[57],q[44];
u1(-pi/16384) q[44];
cx q[57],q[44];
u1(pi/16384) q[44];
u1(pi/8192) q[57];
cx q[57],q[45];
u1(-pi/8192) q[45];
cx q[57],q[45];
u1(pi/8192) q[45];
u1(pi/4096) q[57];
cx q[57],q[46];
u1(-pi/4096) q[46];
cx q[57],q[46];
u1(pi/4096) q[46];
u1(pi/2048) q[57];
cx q[57],q[47];
u1(-pi/2048) q[47];
cx q[57],q[47];
u1(pi/2048) q[47];
u1(pi/1024) q[57];
cx q[57],q[48];
u1(-pi/1024) q[48];
cx q[57],q[48];
u1(pi/1024) q[48];
u1(pi/512) q[57];
cx q[57],q[49];
u1(-pi/512) q[49];
cx q[57],q[49];
u1(pi/512) q[49];
u1(pi/256) q[57];
cx q[57],q[50];
u1(-pi/256) q[50];
cx q[57],q[50];
u1(pi/256) q[50];
u1(pi/128) q[57];
cx q[57],q[51];
u1(-pi/128) q[51];
cx q[57],q[51];
u1(pi/128) q[51];
u1(pi/64) q[57];
cx q[57],q[52];
u1(-pi/64) q[52];
cx q[57],q[52];
u1(pi/64) q[52];
u1(pi/32) q[57];
cx q[57],q[53];
u1(-pi/32) q[53];
cx q[57],q[53];
u1(pi/32) q[53];
u1(pi/16) q[57];
cx q[57],q[54];
u1(-pi/16) q[54];
cx q[57],q[54];
u1(pi/16) q[54];
u1(pi/8) q[57];
cx q[57],q[55];
u1(-pi/8) q[55];
cx q[57],q[55];
u1(pi/8) q[55];
u1(pi/4) q[57];
cx q[57],q[56];
u1(-pi/4) q[56];
cx q[57],q[56];
u1(pi/4) q[56];
h q[57];
u1(0) q[58];
cx q[58],q[0];
u1(0) q[0];
cx q[58],q[0];
u1(0) q[0];
u1(0) q[58];
cx q[58],q[1];
u1(0) q[1];
cx q[58],q[1];
u1(0) q[1];
u1(0) q[58];
cx q[58],q[2];
u1(0) q[2];
cx q[58],q[2];
u1(0) q[2];
u1(0) q[58];
cx q[58],q[3];
u1(0) q[3];
cx q[58],q[3];
u1(0) q[3];
u1(0) q[58];
cx q[58],q[4];
u1(0) q[4];
cx q[58],q[4];
u1(0) q[4];
u1(0) q[58];
cx q[58],q[5];
u1(0) q[5];
cx q[58],q[5];
u1(0) q[5];
u1(0) q[58];
cx q[58],q[6];
u1(0) q[6];
cx q[58],q[6];
u1(0) q[6];
u1(0) q[58];
cx q[58],q[7];
u1(0) q[7];
cx q[58],q[7];
u1(0) q[7];
u1(0) q[58];
cx q[58],q[8];
u1(0) q[8];
cx q[58],q[8];
u1(0) q[8];
u1(0) q[58];
cx q[58],q[9];
u1(0) q[9];
cx q[58],q[9];
u1(0) q[9];
u1(0) q[58];
cx q[58],q[10];
u1(0) q[10];
cx q[58],q[10];
u1(0) q[10];
u1(pi/281474976710656) q[58];
cx q[58],q[11];
u1(-pi/281474976710656) q[11];
cx q[58],q[11];
u1(pi/281474976710656) q[11];
u1(pi/140737488355328) q[58];
cx q[58],q[12];
u1(-pi/140737488355328) q[12];
cx q[58],q[12];
u1(pi/140737488355328) q[12];
u1(pi/70368744177664) q[58];
cx q[58],q[13];
u1(-pi/70368744177664) q[13];
cx q[58],q[13];
u1(pi/70368744177664) q[13];
u1(pi/35184372088832) q[58];
cx q[58],q[14];
u1(-pi/35184372088832) q[14];
cx q[58],q[14];
u1(pi/35184372088832) q[14];
u1(pi/17592186044416) q[58];
cx q[58],q[15];
u1(-pi/17592186044416) q[15];
cx q[58],q[15];
u1(pi/17592186044416) q[15];
u1(pi/8796093022208) q[58];
cx q[58],q[16];
u1(-pi/8796093022208) q[16];
cx q[58],q[16];
u1(pi/8796093022208) q[16];
u1(pi/4398046511104) q[58];
cx q[58],q[17];
u1(-pi/4398046511104) q[17];
cx q[58],q[17];
u1(pi/4398046511104) q[17];
u1(pi/2199023255552) q[58];
cx q[58],q[18];
u1(-pi/2199023255552) q[18];
cx q[58],q[18];
u1(pi/2199023255552) q[18];
u1(pi/1099511627776) q[58];
cx q[58],q[19];
u1(-pi/1099511627776) q[19];
cx q[58],q[19];
u1(pi/1099511627776) q[19];
u1(pi/549755813888) q[58];
cx q[58],q[20];
u1(-pi/549755813888) q[20];
cx q[58],q[20];
u1(pi/549755813888) q[20];
u1(pi/274877906944) q[58];
cx q[58],q[21];
u1(-pi/274877906944) q[21];
cx q[58],q[21];
u1(pi/274877906944) q[21];
u1(pi/137438953472) q[58];
cx q[58],q[22];
u1(-pi/137438953472) q[22];
cx q[58],q[22];
u1(pi/137438953472) q[22];
u1(pi/68719476736) q[58];
cx q[58],q[23];
u1(-pi/68719476736) q[23];
cx q[58],q[23];
u1(pi/68719476736) q[23];
u1(pi/34359738368) q[58];
cx q[58],q[24];
u1(-pi/34359738368) q[24];
cx q[58],q[24];
u1(pi/34359738368) q[24];
u1(pi/17179869184) q[58];
cx q[58],q[25];
u1(-pi/17179869184) q[25];
cx q[58],q[25];
u1(pi/17179869184) q[25];
u1(pi/8589934592) q[58];
cx q[58],q[26];
u1(-pi/8589934592) q[26];
cx q[58],q[26];
u1(pi/8589934592) q[26];
u1(pi/4294967296) q[58];
cx q[58],q[27];
u1(-pi/4294967296) q[27];
cx q[58],q[27];
u1(pi/4294967296) q[27];
u1(pi/2147483648) q[58];
cx q[58],q[28];
u1(-pi/2147483648) q[28];
cx q[58],q[28];
u1(pi/2147483648) q[28];
u1(pi/1073741824) q[58];
cx q[58],q[29];
u1(-pi/1073741824) q[29];
cx q[58],q[29];
u1(pi/1073741824) q[29];
u1(pi/536870912) q[58];
cx q[58],q[30];
u1(-pi/536870912) q[30];
cx q[58],q[30];
u1(pi/536870912) q[30];
u1(pi/268435456) q[58];
cx q[58],q[31];
u1(-pi/268435456) q[31];
cx q[58],q[31];
u1(pi/268435456) q[31];
u1(pi/134217728) q[58];
cx q[58],q[32];
u1(-pi/134217728) q[32];
cx q[58],q[32];
u1(pi/134217728) q[32];
u1(pi/67108864) q[58];
cx q[58],q[33];
u1(-pi/67108864) q[33];
cx q[58],q[33];
u1(pi/67108864) q[33];
u1(pi/33554432) q[58];
cx q[58],q[34];
u1(-pi/33554432) q[34];
cx q[58],q[34];
u1(pi/33554432) q[34];
u1(pi/16777216) q[58];
cx q[58],q[35];
u1(-pi/16777216) q[35];
cx q[58],q[35];
u1(pi/16777216) q[35];
u1(pi/8388608) q[58];
cx q[58],q[36];
u1(-pi/8388608) q[36];
cx q[58],q[36];
u1(pi/8388608) q[36];
u1(pi/4194304) q[58];
cx q[58],q[37];
u1(-pi/4194304) q[37];
cx q[58],q[37];
u1(pi/4194304) q[37];
u1(pi/2097152) q[58];
cx q[58],q[38];
u1(-pi/2097152) q[38];
cx q[58],q[38];
u1(pi/2097152) q[38];
u1(pi/1048576) q[58];
cx q[58],q[39];
u1(-pi/1048576) q[39];
cx q[58],q[39];
u1(pi/1048576) q[39];
u1(pi/524288) q[58];
cx q[58],q[40];
u1(-pi/524288) q[40];
cx q[58],q[40];
u1(pi/524288) q[40];
u1(pi/262144) q[58];
cx q[58],q[41];
u1(-pi/262144) q[41];
cx q[58],q[41];
u1(pi/262144) q[41];
u1(pi/131072) q[58];
cx q[58],q[42];
u1(-pi/131072) q[42];
cx q[58],q[42];
u1(pi/131072) q[42];
u1(pi/65536) q[58];
cx q[58],q[43];
u1(-pi/65536) q[43];
cx q[58],q[43];
u1(pi/65536) q[43];
u1(pi/32768) q[58];
cx q[58],q[44];
u1(-pi/32768) q[44];
cx q[58],q[44];
u1(pi/32768) q[44];
u1(pi/16384) q[58];
cx q[58],q[45];
u1(-pi/16384) q[45];
cx q[58],q[45];
u1(pi/16384) q[45];
u1(pi/8192) q[58];
cx q[58],q[46];
u1(-pi/8192) q[46];
cx q[58],q[46];
u1(pi/8192) q[46];
u1(pi/4096) q[58];
cx q[58],q[47];
u1(-pi/4096) q[47];
cx q[58],q[47];
u1(pi/4096) q[47];
u1(pi/2048) q[58];
cx q[58],q[48];
u1(-pi/2048) q[48];
cx q[58],q[48];
u1(pi/2048) q[48];
u1(pi/1024) q[58];
cx q[58],q[49];
u1(-pi/1024) q[49];
cx q[58],q[49];
u1(pi/1024) q[49];
u1(pi/512) q[58];
cx q[58],q[50];
u1(-pi/512) q[50];
cx q[58],q[50];
u1(pi/512) q[50];
u1(pi/256) q[58];
cx q[58],q[51];
u1(-pi/256) q[51];
cx q[58],q[51];
u1(pi/256) q[51];
u1(pi/128) q[58];
cx q[58],q[52];
u1(-pi/128) q[52];
cx q[58],q[52];
u1(pi/128) q[52];
u1(pi/64) q[58];
cx q[58],q[53];
u1(-pi/64) q[53];
cx q[58],q[53];
u1(pi/64) q[53];
u1(pi/32) q[58];
cx q[58],q[54];
u1(-pi/32) q[54];
cx q[58],q[54];
u1(pi/32) q[54];
u1(pi/16) q[58];
cx q[58],q[55];
u1(-pi/16) q[55];
cx q[58],q[55];
u1(pi/16) q[55];
u1(pi/8) q[58];
cx q[58],q[56];
u1(-pi/8) q[56];
cx q[58],q[56];
u1(pi/8) q[56];
u1(pi/4) q[58];
cx q[58],q[57];
u1(-pi/4) q[57];
cx q[58],q[57];
u1(pi/4) q[57];
h q[58];
u1(0) q[59];
cx q[59],q[0];
u1(0) q[0];
cx q[59],q[0];
u1(0) q[0];
u1(0) q[59];
cx q[59],q[1];
u1(0) q[1];
cx q[59],q[1];
u1(0) q[1];
u1(0) q[59];
cx q[59],q[2];
u1(0) q[2];
cx q[59],q[2];
u1(0) q[2];
u1(0) q[59];
cx q[59],q[3];
u1(0) q[3];
cx q[59],q[3];
u1(0) q[3];
u1(0) q[59];
cx q[59],q[4];
u1(0) q[4];
cx q[59],q[4];
u1(0) q[4];
u1(0) q[59];
cx q[59],q[5];
u1(0) q[5];
cx q[59],q[5];
u1(0) q[5];
u1(0) q[59];
cx q[59],q[6];
u1(0) q[6];
cx q[59],q[6];
u1(0) q[6];
u1(0) q[59];
cx q[59],q[7];
u1(0) q[7];
cx q[59],q[7];
u1(0) q[7];
u1(0) q[59];
cx q[59],q[8];
u1(0) q[8];
cx q[59],q[8];
u1(0) q[8];
u1(0) q[59];
cx q[59],q[9];
u1(0) q[9];
cx q[59],q[9];
u1(0) q[9];
u1(0) q[59];
cx q[59],q[10];
u1(0) q[10];
cx q[59],q[10];
u1(0) q[10];
u1(0) q[59];
cx q[59],q[11];
u1(0) q[11];
cx q[59],q[11];
u1(0) q[11];
u1(pi/281474976710656) q[59];
cx q[59],q[12];
u1(-pi/281474976710656) q[12];
cx q[59],q[12];
u1(pi/281474976710656) q[12];
u1(pi/140737488355328) q[59];
cx q[59],q[13];
u1(-pi/140737488355328) q[13];
cx q[59],q[13];
u1(pi/140737488355328) q[13];
u1(pi/70368744177664) q[59];
cx q[59],q[14];
u1(-pi/70368744177664) q[14];
cx q[59],q[14];
u1(pi/70368744177664) q[14];
u1(pi/35184372088832) q[59];
cx q[59],q[15];
u1(-pi/35184372088832) q[15];
cx q[59],q[15];
u1(pi/35184372088832) q[15];
u1(pi/17592186044416) q[59];
cx q[59],q[16];
u1(-pi/17592186044416) q[16];
cx q[59],q[16];
u1(pi/17592186044416) q[16];
u1(pi/8796093022208) q[59];
cx q[59],q[17];
u1(-pi/8796093022208) q[17];
cx q[59],q[17];
u1(pi/8796093022208) q[17];
u1(pi/4398046511104) q[59];
cx q[59],q[18];
u1(-pi/4398046511104) q[18];
cx q[59],q[18];
u1(pi/4398046511104) q[18];
u1(pi/2199023255552) q[59];
cx q[59],q[19];
u1(-pi/2199023255552) q[19];
cx q[59],q[19];
u1(pi/2199023255552) q[19];
u1(pi/1099511627776) q[59];
cx q[59],q[20];
u1(-pi/1099511627776) q[20];
cx q[59],q[20];
u1(pi/1099511627776) q[20];
u1(pi/549755813888) q[59];
cx q[59],q[21];
u1(-pi/549755813888) q[21];
cx q[59],q[21];
u1(pi/549755813888) q[21];
u1(pi/274877906944) q[59];
cx q[59],q[22];
u1(-pi/274877906944) q[22];
cx q[59],q[22];
u1(pi/274877906944) q[22];
u1(pi/137438953472) q[59];
cx q[59],q[23];
u1(-pi/137438953472) q[23];
cx q[59],q[23];
u1(pi/137438953472) q[23];
u1(pi/68719476736) q[59];
cx q[59],q[24];
u1(-pi/68719476736) q[24];
cx q[59],q[24];
u1(pi/68719476736) q[24];
u1(pi/34359738368) q[59];
cx q[59],q[25];
u1(-pi/34359738368) q[25];
cx q[59],q[25];
u1(pi/34359738368) q[25];
u1(pi/17179869184) q[59];
cx q[59],q[26];
u1(-pi/17179869184) q[26];
cx q[59],q[26];
u1(pi/17179869184) q[26];
u1(pi/8589934592) q[59];
cx q[59],q[27];
u1(-pi/8589934592) q[27];
cx q[59],q[27];
u1(pi/8589934592) q[27];
u1(pi/4294967296) q[59];
cx q[59],q[28];
u1(-pi/4294967296) q[28];
cx q[59],q[28];
u1(pi/4294967296) q[28];
u1(pi/2147483648) q[59];
cx q[59],q[29];
u1(-pi/2147483648) q[29];
cx q[59],q[29];
u1(pi/2147483648) q[29];
u1(pi/1073741824) q[59];
cx q[59],q[30];
u1(-pi/1073741824) q[30];
cx q[59],q[30];
u1(pi/1073741824) q[30];
u1(pi/536870912) q[59];
cx q[59],q[31];
u1(-pi/536870912) q[31];
cx q[59],q[31];
u1(pi/536870912) q[31];
u1(pi/268435456) q[59];
cx q[59],q[32];
u1(-pi/268435456) q[32];
cx q[59],q[32];
u1(pi/268435456) q[32];
u1(pi/134217728) q[59];
cx q[59],q[33];
u1(-pi/134217728) q[33];
cx q[59],q[33];
u1(pi/134217728) q[33];
u1(pi/67108864) q[59];
cx q[59],q[34];
u1(-pi/67108864) q[34];
cx q[59],q[34];
u1(pi/67108864) q[34];
u1(pi/33554432) q[59];
cx q[59],q[35];
u1(-pi/33554432) q[35];
cx q[59],q[35];
u1(pi/33554432) q[35];
u1(pi/16777216) q[59];
cx q[59],q[36];
u1(-pi/16777216) q[36];
cx q[59],q[36];
u1(pi/16777216) q[36];
u1(pi/8388608) q[59];
cx q[59],q[37];
u1(-pi/8388608) q[37];
cx q[59],q[37];
u1(pi/8388608) q[37];
u1(pi/4194304) q[59];
cx q[59],q[38];
u1(-pi/4194304) q[38];
cx q[59],q[38];
u1(pi/4194304) q[38];
u1(pi/2097152) q[59];
cx q[59],q[39];
u1(-pi/2097152) q[39];
cx q[59],q[39];
u1(pi/2097152) q[39];
u1(pi/1048576) q[59];
cx q[59],q[40];
u1(-pi/1048576) q[40];
cx q[59],q[40];
u1(pi/1048576) q[40];
u1(pi/524288) q[59];
cx q[59],q[41];
u1(-pi/524288) q[41];
cx q[59],q[41];
u1(pi/524288) q[41];
u1(pi/262144) q[59];
cx q[59],q[42];
u1(-pi/262144) q[42];
cx q[59],q[42];
u1(pi/262144) q[42];
u1(pi/131072) q[59];
cx q[59],q[43];
u1(-pi/131072) q[43];
cx q[59],q[43];
u1(pi/131072) q[43];
u1(pi/65536) q[59];
cx q[59],q[44];
u1(-pi/65536) q[44];
cx q[59],q[44];
u1(pi/65536) q[44];
u1(pi/32768) q[59];
cx q[59],q[45];
u1(-pi/32768) q[45];
cx q[59],q[45];
u1(pi/32768) q[45];
u1(pi/16384) q[59];
cx q[59],q[46];
u1(-pi/16384) q[46];
cx q[59],q[46];
u1(pi/16384) q[46];
u1(pi/8192) q[59];
cx q[59],q[47];
u1(-pi/8192) q[47];
cx q[59],q[47];
u1(pi/8192) q[47];
u1(pi/4096) q[59];
cx q[59],q[48];
u1(-pi/4096) q[48];
cx q[59],q[48];
u1(pi/4096) q[48];
u1(pi/2048) q[59];
cx q[59],q[49];
u1(-pi/2048) q[49];
cx q[59],q[49];
u1(pi/2048) q[49];
u1(pi/1024) q[59];
cx q[59],q[50];
u1(-pi/1024) q[50];
cx q[59],q[50];
u1(pi/1024) q[50];
u1(pi/512) q[59];
cx q[59],q[51];
u1(-pi/512) q[51];
cx q[59],q[51];
u1(pi/512) q[51];
u1(pi/256) q[59];
cx q[59],q[52];
u1(-pi/256) q[52];
cx q[59],q[52];
u1(pi/256) q[52];
u1(pi/128) q[59];
cx q[59],q[53];
u1(-pi/128) q[53];
cx q[59],q[53];
u1(pi/128) q[53];
u1(pi/64) q[59];
cx q[59],q[54];
u1(-pi/64) q[54];
cx q[59],q[54];
u1(pi/64) q[54];
u1(pi/32) q[59];
cx q[59],q[55];
u1(-pi/32) q[55];
cx q[59],q[55];
u1(pi/32) q[55];
u1(pi/16) q[59];
cx q[59],q[56];
u1(-pi/16) q[56];
cx q[59],q[56];
u1(pi/16) q[56];
u1(pi/8) q[59];
cx q[59],q[57];
u1(-pi/8) q[57];
cx q[59],q[57];
u1(pi/8) q[57];
u1(pi/4) q[59];
cx q[59],q[58];
u1(-pi/4) q[58];
cx q[59],q[58];
u1(pi/4) q[58];
h q[59];
u1(0) q[60];
cx q[60],q[0];
u1(0) q[0];
cx q[60],q[0];
u1(0) q[0];
u1(0) q[60];
cx q[60],q[1];
u1(0) q[1];
cx q[60],q[1];
u1(0) q[1];
u1(0) q[60];
cx q[60],q[2];
u1(0) q[2];
cx q[60],q[2];
u1(0) q[2];
u1(0) q[60];
cx q[60],q[3];
u1(0) q[3];
cx q[60],q[3];
u1(0) q[3];
u1(0) q[60];
cx q[60],q[4];
u1(0) q[4];
cx q[60],q[4];
u1(0) q[4];
u1(0) q[60];
cx q[60],q[5];
u1(0) q[5];
cx q[60],q[5];
u1(0) q[5];
u1(0) q[60];
cx q[60],q[6];
u1(0) q[6];
cx q[60],q[6];
u1(0) q[6];
u1(0) q[60];
cx q[60],q[7];
u1(0) q[7];
cx q[60],q[7];
u1(0) q[7];
u1(0) q[60];
cx q[60],q[8];
u1(0) q[8];
cx q[60],q[8];
u1(0) q[8];
u1(0) q[60];
cx q[60],q[9];
u1(0) q[9];
cx q[60],q[9];
u1(0) q[9];
u1(0) q[60];
cx q[60],q[10];
u1(0) q[10];
cx q[60],q[10];
u1(0) q[10];
u1(0) q[60];
cx q[60],q[11];
u1(0) q[11];
cx q[60],q[11];
u1(0) q[11];
u1(0) q[60];
cx q[60],q[12];
u1(0) q[12];
cx q[60],q[12];
u1(0) q[12];
u1(pi/281474976710656) q[60];
cx q[60],q[13];
u1(-pi/281474976710656) q[13];
cx q[60],q[13];
u1(pi/281474976710656) q[13];
u1(pi/140737488355328) q[60];
cx q[60],q[14];
u1(-pi/140737488355328) q[14];
cx q[60],q[14];
u1(pi/140737488355328) q[14];
u1(pi/70368744177664) q[60];
cx q[60],q[15];
u1(-pi/70368744177664) q[15];
cx q[60],q[15];
u1(pi/70368744177664) q[15];
u1(pi/35184372088832) q[60];
cx q[60],q[16];
u1(-pi/35184372088832) q[16];
cx q[60],q[16];
u1(pi/35184372088832) q[16];
u1(pi/17592186044416) q[60];
cx q[60],q[17];
u1(-pi/17592186044416) q[17];
cx q[60],q[17];
u1(pi/17592186044416) q[17];
u1(pi/8796093022208) q[60];
cx q[60],q[18];
u1(-pi/8796093022208) q[18];
cx q[60],q[18];
u1(pi/8796093022208) q[18];
u1(pi/4398046511104) q[60];
cx q[60],q[19];
u1(-pi/4398046511104) q[19];
cx q[60],q[19];
u1(pi/4398046511104) q[19];
u1(pi/2199023255552) q[60];
cx q[60],q[20];
u1(-pi/2199023255552) q[20];
cx q[60],q[20];
u1(pi/2199023255552) q[20];
u1(pi/1099511627776) q[60];
cx q[60],q[21];
u1(-pi/1099511627776) q[21];
cx q[60],q[21];
u1(pi/1099511627776) q[21];
u1(pi/549755813888) q[60];
cx q[60],q[22];
u1(-pi/549755813888) q[22];
cx q[60],q[22];
u1(pi/549755813888) q[22];
u1(pi/274877906944) q[60];
cx q[60],q[23];
u1(-pi/274877906944) q[23];
cx q[60],q[23];
u1(pi/274877906944) q[23];
u1(pi/137438953472) q[60];
cx q[60],q[24];
u1(-pi/137438953472) q[24];
cx q[60],q[24];
u1(pi/137438953472) q[24];
u1(pi/68719476736) q[60];
cx q[60],q[25];
u1(-pi/68719476736) q[25];
cx q[60],q[25];
u1(pi/68719476736) q[25];
u1(pi/34359738368) q[60];
cx q[60],q[26];
u1(-pi/34359738368) q[26];
cx q[60],q[26];
u1(pi/34359738368) q[26];
u1(pi/17179869184) q[60];
cx q[60],q[27];
u1(-pi/17179869184) q[27];
cx q[60],q[27];
u1(pi/17179869184) q[27];
u1(pi/8589934592) q[60];
cx q[60],q[28];
u1(-pi/8589934592) q[28];
cx q[60],q[28];
u1(pi/8589934592) q[28];
u1(pi/4294967296) q[60];
cx q[60],q[29];
u1(-pi/4294967296) q[29];
cx q[60],q[29];
u1(pi/4294967296) q[29];
u1(pi/2147483648) q[60];
cx q[60],q[30];
u1(-pi/2147483648) q[30];
cx q[60],q[30];
u1(pi/2147483648) q[30];
u1(pi/1073741824) q[60];
cx q[60],q[31];
u1(-pi/1073741824) q[31];
cx q[60],q[31];
u1(pi/1073741824) q[31];
u1(pi/536870912) q[60];
cx q[60],q[32];
u1(-pi/536870912) q[32];
cx q[60],q[32];
u1(pi/536870912) q[32];
u1(pi/268435456) q[60];
cx q[60],q[33];
u1(-pi/268435456) q[33];
cx q[60],q[33];
u1(pi/268435456) q[33];
u1(pi/134217728) q[60];
cx q[60],q[34];
u1(-pi/134217728) q[34];
cx q[60],q[34];
u1(pi/134217728) q[34];
u1(pi/67108864) q[60];
cx q[60],q[35];
u1(-pi/67108864) q[35];
cx q[60],q[35];
u1(pi/67108864) q[35];
u1(pi/33554432) q[60];
cx q[60],q[36];
u1(-pi/33554432) q[36];
cx q[60],q[36];
u1(pi/33554432) q[36];
u1(pi/16777216) q[60];
cx q[60],q[37];
u1(-pi/16777216) q[37];
cx q[60],q[37];
u1(pi/16777216) q[37];
u1(pi/8388608) q[60];
cx q[60],q[38];
u1(-pi/8388608) q[38];
cx q[60],q[38];
u1(pi/8388608) q[38];
u1(pi/4194304) q[60];
cx q[60],q[39];
u1(-pi/4194304) q[39];
cx q[60],q[39];
u1(pi/4194304) q[39];
u1(pi/2097152) q[60];
cx q[60],q[40];
u1(-pi/2097152) q[40];
cx q[60],q[40];
u1(pi/2097152) q[40];
u1(pi/1048576) q[60];
cx q[60],q[41];
u1(-pi/1048576) q[41];
cx q[60],q[41];
u1(pi/1048576) q[41];
u1(pi/524288) q[60];
cx q[60],q[42];
u1(-pi/524288) q[42];
cx q[60],q[42];
u1(pi/524288) q[42];
u1(pi/262144) q[60];
cx q[60],q[43];
u1(-pi/262144) q[43];
cx q[60],q[43];
u1(pi/262144) q[43];
u1(pi/131072) q[60];
cx q[60],q[44];
u1(-pi/131072) q[44];
cx q[60],q[44];
u1(pi/131072) q[44];
u1(pi/65536) q[60];
cx q[60],q[45];
u1(-pi/65536) q[45];
cx q[60],q[45];
u1(pi/65536) q[45];
u1(pi/32768) q[60];
cx q[60],q[46];
u1(-pi/32768) q[46];
cx q[60],q[46];
u1(pi/32768) q[46];
u1(pi/16384) q[60];
cx q[60],q[47];
u1(-pi/16384) q[47];
cx q[60],q[47];
u1(pi/16384) q[47];
u1(pi/8192) q[60];
cx q[60],q[48];
u1(-pi/8192) q[48];
cx q[60],q[48];
u1(pi/8192) q[48];
u1(pi/4096) q[60];
cx q[60],q[49];
u1(-pi/4096) q[49];
cx q[60],q[49];
u1(pi/4096) q[49];
u1(pi/2048) q[60];
cx q[60],q[50];
u1(-pi/2048) q[50];
cx q[60],q[50];
u1(pi/2048) q[50];
u1(pi/1024) q[60];
cx q[60],q[51];
u1(-pi/1024) q[51];
cx q[60],q[51];
u1(pi/1024) q[51];
u1(pi/512) q[60];
cx q[60],q[52];
u1(-pi/512) q[52];
cx q[60],q[52];
u1(pi/512) q[52];
u1(pi/256) q[60];
cx q[60],q[53];
u1(-pi/256) q[53];
cx q[60],q[53];
u1(pi/256) q[53];
u1(pi/128) q[60];
cx q[60],q[54];
u1(-pi/128) q[54];
cx q[60],q[54];
u1(pi/128) q[54];
u1(pi/64) q[60];
cx q[60],q[55];
u1(-pi/64) q[55];
cx q[60],q[55];
u1(pi/64) q[55];
u1(pi/32) q[60];
cx q[60],q[56];
u1(-pi/32) q[56];
cx q[60],q[56];
u1(pi/32) q[56];
u1(pi/16) q[60];
cx q[60],q[57];
u1(-pi/16) q[57];
cx q[60],q[57];
u1(pi/16) q[57];
u1(pi/8) q[60];
cx q[60],q[58];
u1(-pi/8) q[58];
cx q[60],q[58];
u1(pi/8) q[58];
u1(pi/4) q[60];
cx q[60],q[59];
u1(-pi/4) q[59];
cx q[60],q[59];
u1(pi/4) q[59];
h q[60];
u1(0) q[61];
cx q[61],q[0];
u1(0) q[0];
cx q[61],q[0];
u1(0) q[0];
u1(0) q[61];
cx q[61],q[1];
u1(0) q[1];
cx q[61],q[1];
u1(0) q[1];
u1(0) q[61];
cx q[61],q[2];
u1(0) q[2];
cx q[61],q[2];
u1(0) q[2];
u1(0) q[61];
cx q[61],q[3];
u1(0) q[3];
cx q[61],q[3];
u1(0) q[3];
u1(0) q[61];
cx q[61],q[4];
u1(0) q[4];
cx q[61],q[4];
u1(0) q[4];
u1(0) q[61];
cx q[61],q[5];
u1(0) q[5];
cx q[61],q[5];
u1(0) q[5];
u1(0) q[61];
cx q[61],q[6];
u1(0) q[6];
cx q[61],q[6];
u1(0) q[6];
u1(0) q[61];
cx q[61],q[7];
u1(0) q[7];
cx q[61],q[7];
u1(0) q[7];
u1(0) q[61];
cx q[61],q[8];
u1(0) q[8];
cx q[61],q[8];
u1(0) q[8];
u1(0) q[61];
cx q[61],q[9];
u1(0) q[9];
cx q[61],q[9];
u1(0) q[9];
u1(0) q[61];
cx q[61],q[10];
u1(0) q[10];
cx q[61],q[10];
u1(0) q[10];
u1(0) q[61];
cx q[61],q[11];
u1(0) q[11];
cx q[61],q[11];
u1(0) q[11];
u1(0) q[61];
cx q[61],q[12];
u1(0) q[12];
cx q[61],q[12];
u1(0) q[12];
u1(0) q[61];
cx q[61],q[13];
u1(0) q[13];
cx q[61],q[13];
u1(0) q[13];
u1(pi/281474976710656) q[61];
cx q[61],q[14];
u1(-pi/281474976710656) q[14];
cx q[61],q[14];
u1(pi/281474976710656) q[14];
u1(pi/140737488355328) q[61];
cx q[61],q[15];
u1(-pi/140737488355328) q[15];
cx q[61],q[15];
u1(pi/140737488355328) q[15];
u1(pi/70368744177664) q[61];
cx q[61],q[16];
u1(-pi/70368744177664) q[16];
cx q[61],q[16];
u1(pi/70368744177664) q[16];
u1(pi/35184372088832) q[61];
cx q[61],q[17];
u1(-pi/35184372088832) q[17];
cx q[61],q[17];
u1(pi/35184372088832) q[17];
u1(pi/17592186044416) q[61];
cx q[61],q[18];
u1(-pi/17592186044416) q[18];
cx q[61],q[18];
u1(pi/17592186044416) q[18];
u1(pi/8796093022208) q[61];
cx q[61],q[19];
u1(-pi/8796093022208) q[19];
cx q[61],q[19];
u1(pi/8796093022208) q[19];
u1(pi/4398046511104) q[61];
cx q[61],q[20];
u1(-pi/4398046511104) q[20];
cx q[61],q[20];
u1(pi/4398046511104) q[20];
u1(pi/2199023255552) q[61];
cx q[61],q[21];
u1(-pi/2199023255552) q[21];
cx q[61],q[21];
u1(pi/2199023255552) q[21];
u1(pi/1099511627776) q[61];
cx q[61],q[22];
u1(-pi/1099511627776) q[22];
cx q[61],q[22];
u1(pi/1099511627776) q[22];
u1(pi/549755813888) q[61];
cx q[61],q[23];
u1(-pi/549755813888) q[23];
cx q[61],q[23];
u1(pi/549755813888) q[23];
u1(pi/274877906944) q[61];
cx q[61],q[24];
u1(-pi/274877906944) q[24];
cx q[61],q[24];
u1(pi/274877906944) q[24];
u1(pi/137438953472) q[61];
cx q[61],q[25];
u1(-pi/137438953472) q[25];
cx q[61],q[25];
u1(pi/137438953472) q[25];
u1(pi/68719476736) q[61];
cx q[61],q[26];
u1(-pi/68719476736) q[26];
cx q[61],q[26];
u1(pi/68719476736) q[26];
u1(pi/34359738368) q[61];
cx q[61],q[27];
u1(-pi/34359738368) q[27];
cx q[61],q[27];
u1(pi/34359738368) q[27];
u1(pi/17179869184) q[61];
cx q[61],q[28];
u1(-pi/17179869184) q[28];
cx q[61],q[28];
u1(pi/17179869184) q[28];
u1(pi/8589934592) q[61];
cx q[61],q[29];
u1(-pi/8589934592) q[29];
cx q[61],q[29];
u1(pi/8589934592) q[29];
u1(pi/4294967296) q[61];
cx q[61],q[30];
u1(-pi/4294967296) q[30];
cx q[61],q[30];
u1(pi/4294967296) q[30];
u1(pi/2147483648) q[61];
cx q[61],q[31];
u1(-pi/2147483648) q[31];
cx q[61],q[31];
u1(pi/2147483648) q[31];
u1(pi/1073741824) q[61];
cx q[61],q[32];
u1(-pi/1073741824) q[32];
cx q[61],q[32];
u1(pi/1073741824) q[32];
u1(pi/536870912) q[61];
cx q[61],q[33];
u1(-pi/536870912) q[33];
cx q[61],q[33];
u1(pi/536870912) q[33];
u1(pi/268435456) q[61];
cx q[61],q[34];
u1(-pi/268435456) q[34];
cx q[61],q[34];
u1(pi/268435456) q[34];
u1(pi/134217728) q[61];
cx q[61],q[35];
u1(-pi/134217728) q[35];
cx q[61],q[35];
u1(pi/134217728) q[35];
u1(pi/67108864) q[61];
cx q[61],q[36];
u1(-pi/67108864) q[36];
cx q[61],q[36];
u1(pi/67108864) q[36];
u1(pi/33554432) q[61];
cx q[61],q[37];
u1(-pi/33554432) q[37];
cx q[61],q[37];
u1(pi/33554432) q[37];
u1(pi/16777216) q[61];
cx q[61],q[38];
u1(-pi/16777216) q[38];
cx q[61],q[38];
u1(pi/16777216) q[38];
u1(pi/8388608) q[61];
cx q[61],q[39];
u1(-pi/8388608) q[39];
cx q[61],q[39];
u1(pi/8388608) q[39];
u1(pi/4194304) q[61];
cx q[61],q[40];
u1(-pi/4194304) q[40];
cx q[61],q[40];
u1(pi/4194304) q[40];
u1(pi/2097152) q[61];
cx q[61],q[41];
u1(-pi/2097152) q[41];
cx q[61],q[41];
u1(pi/2097152) q[41];
u1(pi/1048576) q[61];
cx q[61],q[42];
u1(-pi/1048576) q[42];
cx q[61],q[42];
u1(pi/1048576) q[42];
u1(pi/524288) q[61];
cx q[61],q[43];
u1(-pi/524288) q[43];
cx q[61],q[43];
u1(pi/524288) q[43];
u1(pi/262144) q[61];
cx q[61],q[44];
u1(-pi/262144) q[44];
cx q[61],q[44];
u1(pi/262144) q[44];
u1(pi/131072) q[61];
cx q[61],q[45];
u1(-pi/131072) q[45];
cx q[61],q[45];
u1(pi/131072) q[45];
u1(pi/65536) q[61];
cx q[61],q[46];
u1(-pi/65536) q[46];
cx q[61],q[46];
u1(pi/65536) q[46];
u1(pi/32768) q[61];
cx q[61],q[47];
u1(-pi/32768) q[47];
cx q[61],q[47];
u1(pi/32768) q[47];
u1(pi/16384) q[61];
cx q[61],q[48];
u1(-pi/16384) q[48];
cx q[61],q[48];
u1(pi/16384) q[48];
u1(pi/8192) q[61];
cx q[61],q[49];
u1(-pi/8192) q[49];
cx q[61],q[49];
u1(pi/8192) q[49];
u1(pi/4096) q[61];
cx q[61],q[50];
u1(-pi/4096) q[50];
cx q[61],q[50];
u1(pi/4096) q[50];
u1(pi/2048) q[61];
cx q[61],q[51];
u1(-pi/2048) q[51];
cx q[61],q[51];
u1(pi/2048) q[51];
u1(pi/1024) q[61];
cx q[61],q[52];
u1(-pi/1024) q[52];
cx q[61],q[52];
u1(pi/1024) q[52];
u1(pi/512) q[61];
cx q[61],q[53];
u1(-pi/512) q[53];
cx q[61],q[53];
u1(pi/512) q[53];
u1(pi/256) q[61];
cx q[61],q[54];
u1(-pi/256) q[54];
cx q[61],q[54];
u1(pi/256) q[54];
u1(pi/128) q[61];
cx q[61],q[55];
u1(-pi/128) q[55];
cx q[61],q[55];
u1(pi/128) q[55];
u1(pi/64) q[61];
cx q[61],q[56];
u1(-pi/64) q[56];
cx q[61],q[56];
u1(pi/64) q[56];
u1(pi/32) q[61];
cx q[61],q[57];
u1(-pi/32) q[57];
cx q[61],q[57];
u1(pi/32) q[57];
u1(pi/16) q[61];
cx q[61],q[58];
u1(-pi/16) q[58];
cx q[61],q[58];
u1(pi/16) q[58];
u1(pi/8) q[61];
cx q[61],q[59];
u1(-pi/8) q[59];
cx q[61],q[59];
u1(pi/8) q[59];
u1(pi/4) q[61];
cx q[61],q[60];
u1(-pi/4) q[60];
cx q[61],q[60];
u1(pi/4) q[60];
h q[61];
u1(0) q[62];
cx q[62],q[0];
u1(0) q[0];
cx q[62],q[0];
u1(0) q[0];
u1(0) q[62];
cx q[62],q[1];
u1(0) q[1];
cx q[62],q[1];
u1(0) q[1];
u1(0) q[62];
cx q[62],q[2];
u1(0) q[2];
cx q[62],q[2];
u1(0) q[2];
u1(0) q[62];
cx q[62],q[3];
u1(0) q[3];
cx q[62],q[3];
u1(0) q[3];
u1(0) q[62];
cx q[62],q[4];
u1(0) q[4];
cx q[62],q[4];
u1(0) q[4];
u1(0) q[62];
cx q[62],q[5];
u1(0) q[5];
cx q[62],q[5];
u1(0) q[5];
u1(0) q[62];
cx q[62],q[6];
u1(0) q[6];
cx q[62],q[6];
u1(0) q[6];
u1(0) q[62];
cx q[62],q[7];
u1(0) q[7];
cx q[62],q[7];
u1(0) q[7];
u1(0) q[62];
cx q[62],q[8];
u1(0) q[8];
cx q[62],q[8];
u1(0) q[8];
u1(0) q[62];
cx q[62],q[9];
u1(0) q[9];
cx q[62],q[9];
u1(0) q[9];
u1(0) q[62];
cx q[62],q[10];
u1(0) q[10];
cx q[62],q[10];
u1(0) q[10];
u1(0) q[62];
cx q[62],q[11];
u1(0) q[11];
cx q[62],q[11];
u1(0) q[11];
u1(0) q[62];
cx q[62],q[12];
u1(0) q[12];
cx q[62],q[12];
u1(0) q[12];
u1(0) q[62];
cx q[62],q[13];
u1(0) q[13];
cx q[62],q[13];
u1(0) q[13];
u1(0) q[62];
cx q[62],q[14];
u1(0) q[14];
cx q[62],q[14];
u1(0) q[14];
u1(pi/281474976710656) q[62];
cx q[62],q[15];
u1(-pi/281474976710656) q[15];
cx q[62],q[15];
u1(pi/281474976710656) q[15];
u1(pi/140737488355328) q[62];
cx q[62],q[16];
u1(-pi/140737488355328) q[16];
cx q[62],q[16];
u1(pi/140737488355328) q[16];
u1(pi/70368744177664) q[62];
cx q[62],q[17];
u1(-pi/70368744177664) q[17];
cx q[62],q[17];
u1(pi/70368744177664) q[17];
u1(pi/35184372088832) q[62];
cx q[62],q[18];
u1(-pi/35184372088832) q[18];
cx q[62],q[18];
u1(pi/35184372088832) q[18];
u1(pi/17592186044416) q[62];
cx q[62],q[19];
u1(-pi/17592186044416) q[19];
cx q[62],q[19];
u1(pi/17592186044416) q[19];
u1(pi/8796093022208) q[62];
cx q[62],q[20];
u1(-pi/8796093022208) q[20];
cx q[62],q[20];
u1(pi/8796093022208) q[20];
u1(pi/4398046511104) q[62];
cx q[62],q[21];
u1(-pi/4398046511104) q[21];
cx q[62],q[21];
u1(pi/4398046511104) q[21];
u1(pi/2199023255552) q[62];
cx q[62],q[22];
u1(-pi/2199023255552) q[22];
cx q[62],q[22];
u1(pi/2199023255552) q[22];
u1(pi/1099511627776) q[62];
cx q[62],q[23];
u1(-pi/1099511627776) q[23];
cx q[62],q[23];
u1(pi/1099511627776) q[23];
u1(pi/549755813888) q[62];
cx q[62],q[24];
u1(-pi/549755813888) q[24];
cx q[62],q[24];
u1(pi/549755813888) q[24];
u1(pi/274877906944) q[62];
cx q[62],q[25];
u1(-pi/274877906944) q[25];
cx q[62],q[25];
u1(pi/274877906944) q[25];
u1(pi/137438953472) q[62];
cx q[62],q[26];
u1(-pi/137438953472) q[26];
cx q[62],q[26];
u1(pi/137438953472) q[26];
u1(pi/68719476736) q[62];
cx q[62],q[27];
u1(-pi/68719476736) q[27];
cx q[62],q[27];
u1(pi/68719476736) q[27];
u1(pi/34359738368) q[62];
cx q[62],q[28];
u1(-pi/34359738368) q[28];
cx q[62],q[28];
u1(pi/34359738368) q[28];
u1(pi/17179869184) q[62];
cx q[62],q[29];
u1(-pi/17179869184) q[29];
cx q[62],q[29];
u1(pi/17179869184) q[29];
u1(pi/8589934592) q[62];
cx q[62],q[30];
u1(-pi/8589934592) q[30];
cx q[62],q[30];
u1(pi/8589934592) q[30];
u1(pi/4294967296) q[62];
cx q[62],q[31];
u1(-pi/4294967296) q[31];
cx q[62],q[31];
u1(pi/4294967296) q[31];
u1(pi/2147483648) q[62];
cx q[62],q[32];
u1(-pi/2147483648) q[32];
cx q[62],q[32];
u1(pi/2147483648) q[32];
u1(pi/1073741824) q[62];
cx q[62],q[33];
u1(-pi/1073741824) q[33];
cx q[62],q[33];
u1(pi/1073741824) q[33];
u1(pi/536870912) q[62];
cx q[62],q[34];
u1(-pi/536870912) q[34];
cx q[62],q[34];
u1(pi/536870912) q[34];
u1(pi/268435456) q[62];
cx q[62],q[35];
u1(-pi/268435456) q[35];
cx q[62],q[35];
u1(pi/268435456) q[35];
u1(pi/134217728) q[62];
cx q[62],q[36];
u1(-pi/134217728) q[36];
cx q[62],q[36];
u1(pi/134217728) q[36];
u1(pi/67108864) q[62];
cx q[62],q[37];
u1(-pi/67108864) q[37];
cx q[62],q[37];
u1(pi/67108864) q[37];
u1(pi/33554432) q[62];
cx q[62],q[38];
u1(-pi/33554432) q[38];
cx q[62],q[38];
u1(pi/33554432) q[38];
u1(pi/16777216) q[62];
cx q[62],q[39];
u1(-pi/16777216) q[39];
cx q[62],q[39];
u1(pi/16777216) q[39];
u1(pi/8388608) q[62];
cx q[62],q[40];
u1(-pi/8388608) q[40];
cx q[62],q[40];
u1(pi/8388608) q[40];
u1(pi/4194304) q[62];
cx q[62],q[41];
u1(-pi/4194304) q[41];
cx q[62],q[41];
u1(pi/4194304) q[41];
u1(pi/2097152) q[62];
cx q[62],q[42];
u1(-pi/2097152) q[42];
cx q[62],q[42];
u1(pi/2097152) q[42];
u1(pi/1048576) q[62];
cx q[62],q[43];
u1(-pi/1048576) q[43];
cx q[62],q[43];
u1(pi/1048576) q[43];
u1(pi/524288) q[62];
cx q[62],q[44];
u1(-pi/524288) q[44];
cx q[62],q[44];
u1(pi/524288) q[44];
u1(pi/262144) q[62];
cx q[62],q[45];
u1(-pi/262144) q[45];
cx q[62],q[45];
u1(pi/262144) q[45];
u1(pi/131072) q[62];
cx q[62],q[46];
u1(-pi/131072) q[46];
cx q[62],q[46];
u1(pi/131072) q[46];
u1(pi/65536) q[62];
cx q[62],q[47];
u1(-pi/65536) q[47];
cx q[62],q[47];
u1(pi/65536) q[47];
u1(pi/32768) q[62];
cx q[62],q[48];
u1(-pi/32768) q[48];
cx q[62],q[48];
u1(pi/32768) q[48];
u1(pi/16384) q[62];
cx q[62],q[49];
u1(-pi/16384) q[49];
cx q[62],q[49];
u1(pi/16384) q[49];
u1(pi/8192) q[62];
cx q[62],q[50];
u1(-pi/8192) q[50];
cx q[62],q[50];
u1(pi/8192) q[50];
u1(pi/4096) q[62];
cx q[62],q[51];
u1(-pi/4096) q[51];
cx q[62],q[51];
u1(pi/4096) q[51];
u1(pi/2048) q[62];
cx q[62],q[52];
u1(-pi/2048) q[52];
cx q[62],q[52];
u1(pi/2048) q[52];
u1(pi/1024) q[62];
cx q[62],q[53];
u1(-pi/1024) q[53];
cx q[62],q[53];
u1(pi/1024) q[53];
u1(pi/512) q[62];
cx q[62],q[54];
u1(-pi/512) q[54];
cx q[62],q[54];
u1(pi/512) q[54];
u1(pi/256) q[62];
cx q[62],q[55];
u1(-pi/256) q[55];
cx q[62],q[55];
u1(pi/256) q[55];
u1(pi/128) q[62];
cx q[62],q[56];
u1(-pi/128) q[56];
cx q[62],q[56];
u1(pi/128) q[56];
u1(pi/64) q[62];
cx q[62],q[57];
u1(-pi/64) q[57];
cx q[62],q[57];
u1(pi/64) q[57];
u1(pi/32) q[62];
cx q[62],q[58];
u1(-pi/32) q[58];
cx q[62],q[58];
u1(pi/32) q[58];
u1(pi/16) q[62];
cx q[62],q[59];
u1(-pi/16) q[59];
cx q[62],q[59];
u1(pi/16) q[59];
u1(pi/8) q[62];
cx q[62],q[60];
u1(-pi/8) q[60];
cx q[62],q[60];
u1(pi/8) q[60];
u1(pi/4) q[62];
cx q[62],q[61];
u1(-pi/4) q[61];
cx q[62],q[61];
u1(pi/4) q[61];
h q[62];
u1(0) q[63];
cx q[63],q[0];
u1(0) q[0];
cx q[63],q[0];
u1(0) q[0];
u1(0) q[63];
cx q[63],q[1];
u1(0) q[1];
cx q[63],q[1];
u1(0) q[1];
u1(0) q[63];
cx q[63],q[2];
u1(0) q[2];
cx q[63],q[2];
u1(0) q[2];
u1(0) q[63];
cx q[63],q[3];
u1(0) q[3];
cx q[63],q[3];
u1(0) q[3];
u1(0) q[63];
cx q[63],q[4];
u1(0) q[4];
cx q[63],q[4];
u1(0) q[4];
u1(0) q[63];
cx q[63],q[5];
u1(0) q[5];
cx q[63],q[5];
u1(0) q[5];
u1(0) q[63];
cx q[63],q[6];
u1(0) q[6];
cx q[63],q[6];
u1(0) q[6];
u1(0) q[63];
cx q[63],q[7];
u1(0) q[7];
cx q[63],q[7];
u1(0) q[7];
u1(0) q[63];
cx q[63],q[8];
u1(0) q[8];
cx q[63],q[8];
u1(0) q[8];
u1(0) q[63];
cx q[63],q[9];
u1(0) q[9];
cx q[63],q[9];
u1(0) q[9];
u1(0) q[63];
cx q[63],q[10];
u1(0) q[10];
cx q[63],q[10];
u1(0) q[10];
u1(0) q[63];
cx q[63],q[11];
u1(0) q[11];
cx q[63],q[11];
u1(0) q[11];
u1(0) q[63];
cx q[63],q[12];
u1(0) q[12];
cx q[63],q[12];
u1(0) q[12];
u1(0) q[63];
cx q[63],q[13];
u1(0) q[13];
cx q[63],q[13];
u1(0) q[13];
u1(0) q[63];
cx q[63],q[14];
u1(0) q[14];
cx q[63],q[14];
u1(0) q[14];
u1(0) q[63];
cx q[63],q[15];
u1(0) q[15];
cx q[63],q[15];
u1(0) q[15];
u1(pi/281474976710656) q[63];
cx q[63],q[16];
u1(-pi/281474976710656) q[16];
cx q[63],q[16];
u1(pi/281474976710656) q[16];
u1(pi/140737488355328) q[63];
cx q[63],q[17];
u1(-pi/140737488355328) q[17];
cx q[63],q[17];
u1(pi/140737488355328) q[17];
u1(pi/70368744177664) q[63];
cx q[63],q[18];
u1(-pi/70368744177664) q[18];
cx q[63],q[18];
u1(pi/70368744177664) q[18];
u1(pi/35184372088832) q[63];
cx q[63],q[19];
u1(-pi/35184372088832) q[19];
cx q[63],q[19];
u1(pi/35184372088832) q[19];
u1(pi/17592186044416) q[63];
cx q[63],q[20];
u1(-pi/17592186044416) q[20];
cx q[63],q[20];
u1(pi/17592186044416) q[20];
u1(pi/8796093022208) q[63];
cx q[63],q[21];
u1(-pi/8796093022208) q[21];
cx q[63],q[21];
u1(pi/8796093022208) q[21];
u1(pi/4398046511104) q[63];
cx q[63],q[22];
u1(-pi/4398046511104) q[22];
cx q[63],q[22];
u1(pi/4398046511104) q[22];
u1(pi/2199023255552) q[63];
cx q[63],q[23];
u1(-pi/2199023255552) q[23];
cx q[63],q[23];
u1(pi/2199023255552) q[23];
u1(pi/1099511627776) q[63];
cx q[63],q[24];
u1(-pi/1099511627776) q[24];
cx q[63],q[24];
u1(pi/1099511627776) q[24];
u1(pi/549755813888) q[63];
cx q[63],q[25];
u1(-pi/549755813888) q[25];
cx q[63],q[25];
u1(pi/549755813888) q[25];
u1(pi/274877906944) q[63];
cx q[63],q[26];
u1(-pi/274877906944) q[26];
cx q[63],q[26];
u1(pi/274877906944) q[26];
u1(pi/137438953472) q[63];
cx q[63],q[27];
u1(-pi/137438953472) q[27];
cx q[63],q[27];
u1(pi/137438953472) q[27];
u1(pi/68719476736) q[63];
cx q[63],q[28];
u1(-pi/68719476736) q[28];
cx q[63],q[28];
u1(pi/68719476736) q[28];
u1(pi/34359738368) q[63];
cx q[63],q[29];
u1(-pi/34359738368) q[29];
cx q[63],q[29];
u1(pi/34359738368) q[29];
u1(pi/17179869184) q[63];
cx q[63],q[30];
u1(-pi/17179869184) q[30];
cx q[63],q[30];
u1(pi/17179869184) q[30];
u1(pi/8589934592) q[63];
cx q[63],q[31];
u1(-pi/8589934592) q[31];
cx q[63],q[31];
u1(pi/8589934592) q[31];
u1(pi/4294967296) q[63];
cx q[63],q[32];
u1(-pi/4294967296) q[32];
cx q[63],q[32];
u1(pi/4294967296) q[32];
u1(pi/2147483648) q[63];
cx q[63],q[33];
u1(-pi/2147483648) q[33];
cx q[63],q[33];
u1(pi/2147483648) q[33];
u1(pi/1073741824) q[63];
cx q[63],q[34];
u1(-pi/1073741824) q[34];
cx q[63],q[34];
u1(pi/1073741824) q[34];
u1(pi/536870912) q[63];
cx q[63],q[35];
u1(-pi/536870912) q[35];
cx q[63],q[35];
u1(pi/536870912) q[35];
u1(pi/268435456) q[63];
cx q[63],q[36];
u1(-pi/268435456) q[36];
cx q[63],q[36];
u1(pi/268435456) q[36];
u1(pi/134217728) q[63];
cx q[63],q[37];
u1(-pi/134217728) q[37];
cx q[63],q[37];
u1(pi/134217728) q[37];
u1(pi/67108864) q[63];
cx q[63],q[38];
u1(-pi/67108864) q[38];
cx q[63],q[38];
u1(pi/67108864) q[38];
u1(pi/33554432) q[63];
cx q[63],q[39];
u1(-pi/33554432) q[39];
cx q[63],q[39];
u1(pi/33554432) q[39];
u1(pi/16777216) q[63];
cx q[63],q[40];
u1(-pi/16777216) q[40];
cx q[63],q[40];
u1(pi/16777216) q[40];
u1(pi/8388608) q[63];
cx q[63],q[41];
u1(-pi/8388608) q[41];
cx q[63],q[41];
u1(pi/8388608) q[41];
u1(pi/4194304) q[63];
cx q[63],q[42];
u1(-pi/4194304) q[42];
cx q[63],q[42];
u1(pi/4194304) q[42];
u1(pi/2097152) q[63];
cx q[63],q[43];
u1(-pi/2097152) q[43];
cx q[63],q[43];
u1(pi/2097152) q[43];
u1(pi/1048576) q[63];
cx q[63],q[44];
u1(-pi/1048576) q[44];
cx q[63],q[44];
u1(pi/1048576) q[44];
u1(pi/524288) q[63];
cx q[63],q[45];
u1(-pi/524288) q[45];
cx q[63],q[45];
u1(pi/524288) q[45];
u1(pi/262144) q[63];
cx q[63],q[46];
u1(-pi/262144) q[46];
cx q[63],q[46];
u1(pi/262144) q[46];
u1(pi/131072) q[63];
cx q[63],q[47];
u1(-pi/131072) q[47];
cx q[63],q[47];
u1(pi/131072) q[47];
u1(pi/65536) q[63];
cx q[63],q[48];
u1(-pi/65536) q[48];
cx q[63],q[48];
u1(pi/65536) q[48];
u1(pi/32768) q[63];
cx q[63],q[49];
u1(-pi/32768) q[49];
cx q[63],q[49];
u1(pi/32768) q[49];
u1(pi/16384) q[63];
cx q[63],q[50];
u1(-pi/16384) q[50];
cx q[63],q[50];
u1(pi/16384) q[50];
u1(pi/8192) q[63];
cx q[63],q[51];
u1(-pi/8192) q[51];
cx q[63],q[51];
u1(pi/8192) q[51];
u1(pi/4096) q[63];
cx q[63],q[52];
u1(-pi/4096) q[52];
cx q[63],q[52];
u1(pi/4096) q[52];
u1(pi/2048) q[63];
cx q[63],q[53];
u1(-pi/2048) q[53];
cx q[63],q[53];
u1(pi/2048) q[53];
u1(pi/1024) q[63];
cx q[63],q[54];
u1(-pi/1024) q[54];
cx q[63],q[54];
u1(pi/1024) q[54];
u1(pi/512) q[63];
cx q[63],q[55];
u1(-pi/512) q[55];
cx q[63],q[55];
u1(pi/512) q[55];
u1(pi/256) q[63];
cx q[63],q[56];
u1(-pi/256) q[56];
cx q[63],q[56];
u1(pi/256) q[56];
u1(pi/128) q[63];
cx q[63],q[57];
u1(-pi/128) q[57];
cx q[63],q[57];
u1(pi/128) q[57];
u1(pi/64) q[63];
cx q[63],q[58];
u1(-pi/64) q[58];
cx q[63],q[58];
u1(pi/64) q[58];
u1(pi/32) q[63];
cx q[63],q[59];
u1(-pi/32) q[59];
cx q[63],q[59];
u1(pi/32) q[59];
u1(pi/16) q[63];
cx q[63],q[60];
u1(-pi/16) q[60];
cx q[63],q[60];
u1(pi/16) q[60];
u1(pi/8) q[63];
cx q[63],q[61];
u1(-pi/8) q[61];
cx q[63],q[61];
u1(pi/8) q[61];
u1(pi/4) q[63];
cx q[63],q[62];
u1(-pi/4) q[62];
cx q[63],q[62];
u1(pi/4) q[62];
h q[63];
u1(0) q[64];
cx q[64],q[0];
u1(0) q[0];
cx q[64],q[0];
u1(0) q[0];
u1(0) q[64];
cx q[64],q[1];
u1(0) q[1];
cx q[64],q[1];
u1(0) q[1];
u1(0) q[64];
cx q[64],q[2];
u1(0) q[2];
cx q[64],q[2];
u1(0) q[2];
u1(0) q[64];
cx q[64],q[3];
u1(0) q[3];
cx q[64],q[3];
u1(0) q[3];
u1(0) q[64];
cx q[64],q[4];
u1(0) q[4];
cx q[64],q[4];
u1(0) q[4];
u1(0) q[64];
cx q[64],q[5];
u1(0) q[5];
cx q[64],q[5];
u1(0) q[5];
u1(0) q[64];
cx q[64],q[6];
u1(0) q[6];
cx q[64],q[6];
u1(0) q[6];
u1(0) q[64];
cx q[64],q[7];
u1(0) q[7];
cx q[64],q[7];
u1(0) q[7];
u1(0) q[64];
cx q[64],q[8];
u1(0) q[8];
cx q[64],q[8];
u1(0) q[8];
u1(0) q[64];
cx q[64],q[9];
u1(0) q[9];
cx q[64],q[9];
u1(0) q[9];
u1(0) q[64];
cx q[64],q[10];
u1(0) q[10];
cx q[64],q[10];
u1(0) q[10];
u1(0) q[64];
cx q[64],q[11];
u1(0) q[11];
cx q[64],q[11];
u1(0) q[11];
u1(0) q[64];
cx q[64],q[12];
u1(0) q[12];
cx q[64],q[12];
u1(0) q[12];
u1(0) q[64];
cx q[64],q[13];
u1(0) q[13];
cx q[64],q[13];
u1(0) q[13];
u1(0) q[64];
cx q[64],q[14];
u1(0) q[14];
cx q[64],q[14];
u1(0) q[14];
u1(0) q[64];
cx q[64],q[15];
u1(0) q[15];
cx q[64],q[15];
u1(0) q[15];
u1(0) q[64];
cx q[64],q[16];
u1(0) q[16];
cx q[64],q[16];
u1(0) q[16];
u1(pi/281474976710656) q[64];
cx q[64],q[17];
u1(-pi/281474976710656) q[17];
cx q[64],q[17];
u1(pi/281474976710656) q[17];
u1(pi/140737488355328) q[64];
cx q[64],q[18];
u1(-pi/140737488355328) q[18];
cx q[64],q[18];
u1(pi/140737488355328) q[18];
u1(pi/70368744177664) q[64];
cx q[64],q[19];
u1(-pi/70368744177664) q[19];
cx q[64],q[19];
u1(pi/70368744177664) q[19];
u1(pi/35184372088832) q[64];
cx q[64],q[20];
u1(-pi/35184372088832) q[20];
cx q[64],q[20];
u1(pi/35184372088832) q[20];
u1(pi/17592186044416) q[64];
cx q[64],q[21];
u1(-pi/17592186044416) q[21];
cx q[64],q[21];
u1(pi/17592186044416) q[21];
u1(pi/8796093022208) q[64];
cx q[64],q[22];
u1(-pi/8796093022208) q[22];
cx q[64],q[22];
u1(pi/8796093022208) q[22];
u1(pi/4398046511104) q[64];
cx q[64],q[23];
u1(-pi/4398046511104) q[23];
cx q[64],q[23];
u1(pi/4398046511104) q[23];
u1(pi/2199023255552) q[64];
cx q[64],q[24];
u1(-pi/2199023255552) q[24];
cx q[64],q[24];
u1(pi/2199023255552) q[24];
u1(pi/1099511627776) q[64];
cx q[64],q[25];
u1(-pi/1099511627776) q[25];
cx q[64],q[25];
u1(pi/1099511627776) q[25];
u1(pi/549755813888) q[64];
cx q[64],q[26];
u1(-pi/549755813888) q[26];
cx q[64],q[26];
u1(pi/549755813888) q[26];
u1(pi/274877906944) q[64];
cx q[64],q[27];
u1(-pi/274877906944) q[27];
cx q[64],q[27];
u1(pi/274877906944) q[27];
u1(pi/137438953472) q[64];
cx q[64],q[28];
u1(-pi/137438953472) q[28];
cx q[64],q[28];
u1(pi/137438953472) q[28];
u1(pi/68719476736) q[64];
cx q[64],q[29];
u1(-pi/68719476736) q[29];
cx q[64],q[29];
u1(pi/68719476736) q[29];
u1(pi/34359738368) q[64];
cx q[64],q[30];
u1(-pi/34359738368) q[30];
cx q[64],q[30];
u1(pi/34359738368) q[30];
u1(pi/17179869184) q[64];
cx q[64],q[31];
u1(-pi/17179869184) q[31];
cx q[64],q[31];
u1(pi/17179869184) q[31];
u1(pi/8589934592) q[64];
cx q[64],q[32];
u1(-pi/8589934592) q[32];
cx q[64],q[32];
u1(pi/8589934592) q[32];
u1(pi/4294967296) q[64];
cx q[64],q[33];
u1(-pi/4294967296) q[33];
cx q[64],q[33];
u1(pi/4294967296) q[33];
u1(pi/2147483648) q[64];
cx q[64],q[34];
u1(-pi/2147483648) q[34];
cx q[64],q[34];
u1(pi/2147483648) q[34];
u1(pi/1073741824) q[64];
cx q[64],q[35];
u1(-pi/1073741824) q[35];
cx q[64],q[35];
u1(pi/1073741824) q[35];
u1(pi/536870912) q[64];
cx q[64],q[36];
u1(-pi/536870912) q[36];
cx q[64],q[36];
u1(pi/536870912) q[36];
u1(pi/268435456) q[64];
cx q[64],q[37];
u1(-pi/268435456) q[37];
cx q[64],q[37];
u1(pi/268435456) q[37];
u1(pi/134217728) q[64];
cx q[64],q[38];
u1(-pi/134217728) q[38];
cx q[64],q[38];
u1(pi/134217728) q[38];
u1(pi/67108864) q[64];
cx q[64],q[39];
u1(-pi/67108864) q[39];
cx q[64],q[39];
u1(pi/67108864) q[39];
u1(pi/33554432) q[64];
cx q[64],q[40];
u1(-pi/33554432) q[40];
cx q[64],q[40];
u1(pi/33554432) q[40];
u1(pi/16777216) q[64];
cx q[64],q[41];
u1(-pi/16777216) q[41];
cx q[64],q[41];
u1(pi/16777216) q[41];
u1(pi/8388608) q[64];
cx q[64],q[42];
u1(-pi/8388608) q[42];
cx q[64],q[42];
u1(pi/8388608) q[42];
u1(pi/4194304) q[64];
cx q[64],q[43];
u1(-pi/4194304) q[43];
cx q[64],q[43];
u1(pi/4194304) q[43];
u1(pi/2097152) q[64];
cx q[64],q[44];
u1(-pi/2097152) q[44];
cx q[64],q[44];
u1(pi/2097152) q[44];
u1(pi/1048576) q[64];
cx q[64],q[45];
u1(-pi/1048576) q[45];
cx q[64],q[45];
u1(pi/1048576) q[45];
u1(pi/524288) q[64];
cx q[64],q[46];
u1(-pi/524288) q[46];
cx q[64],q[46];
u1(pi/524288) q[46];
u1(pi/262144) q[64];
cx q[64],q[47];
u1(-pi/262144) q[47];
cx q[64],q[47];
u1(pi/262144) q[47];
u1(pi/131072) q[64];
cx q[64],q[48];
u1(-pi/131072) q[48];
cx q[64],q[48];
u1(pi/131072) q[48];
u1(pi/65536) q[64];
cx q[64],q[49];
u1(-pi/65536) q[49];
cx q[64],q[49];
u1(pi/65536) q[49];
u1(pi/32768) q[64];
cx q[64],q[50];
u1(-pi/32768) q[50];
cx q[64],q[50];
u1(pi/32768) q[50];
u1(pi/16384) q[64];
cx q[64],q[51];
u1(-pi/16384) q[51];
cx q[64],q[51];
u1(pi/16384) q[51];
u1(pi/8192) q[64];
cx q[64],q[52];
u1(-pi/8192) q[52];
cx q[64],q[52];
u1(pi/8192) q[52];
u1(pi/4096) q[64];
cx q[64],q[53];
u1(-pi/4096) q[53];
cx q[64],q[53];
u1(pi/4096) q[53];
u1(pi/2048) q[64];
cx q[64],q[54];
u1(-pi/2048) q[54];
cx q[64],q[54];
u1(pi/2048) q[54];
u1(pi/1024) q[64];
cx q[64],q[55];
u1(-pi/1024) q[55];
cx q[64],q[55];
u1(pi/1024) q[55];
u1(pi/512) q[64];
cx q[64],q[56];
u1(-pi/512) q[56];
cx q[64],q[56];
u1(pi/512) q[56];
u1(pi/256) q[64];
cx q[64],q[57];
u1(-pi/256) q[57];
cx q[64],q[57];
u1(pi/256) q[57];
u1(pi/128) q[64];
cx q[64],q[58];
u1(-pi/128) q[58];
cx q[64],q[58];
u1(pi/128) q[58];
u1(pi/64) q[64];
cx q[64],q[59];
u1(-pi/64) q[59];
cx q[64],q[59];
u1(pi/64) q[59];
u1(pi/32) q[64];
cx q[64],q[60];
u1(-pi/32) q[60];
cx q[64],q[60];
u1(pi/32) q[60];
u1(pi/16) q[64];
cx q[64],q[61];
u1(-pi/16) q[61];
cx q[64],q[61];
u1(pi/16) q[61];
u1(pi/8) q[64];
cx q[64],q[62];
u1(-pi/8) q[62];
cx q[64],q[62];
u1(pi/8) q[62];
u1(pi/4) q[64];
cx q[64],q[63];
u1(-pi/4) q[63];
cx q[64],q[63];
u1(pi/4) q[63];
h q[64];
u1(0) q[65];
cx q[65],q[0];
u1(0) q[0];
cx q[65],q[0];
u1(0) q[0];
u1(0) q[65];
cx q[65],q[1];
u1(0) q[1];
cx q[65],q[1];
u1(0) q[1];
u1(0) q[65];
cx q[65],q[2];
u1(0) q[2];
cx q[65],q[2];
u1(0) q[2];
u1(0) q[65];
cx q[65],q[3];
u1(0) q[3];
cx q[65],q[3];
u1(0) q[3];
u1(0) q[65];
cx q[65],q[4];
u1(0) q[4];
cx q[65],q[4];
u1(0) q[4];
u1(0) q[65];
cx q[65],q[5];
u1(0) q[5];
cx q[65],q[5];
u1(0) q[5];
u1(0) q[65];
cx q[65],q[6];
u1(0) q[6];
cx q[65],q[6];
u1(0) q[6];
u1(0) q[65];
cx q[65],q[7];
u1(0) q[7];
cx q[65],q[7];
u1(0) q[7];
u1(0) q[65];
cx q[65],q[8];
u1(0) q[8];
cx q[65],q[8];
u1(0) q[8];
u1(0) q[65];
cx q[65],q[9];
u1(0) q[9];
cx q[65],q[9];
u1(0) q[9];
u1(0) q[65];
cx q[65],q[10];
u1(0) q[10];
cx q[65],q[10];
u1(0) q[10];
u1(0) q[65];
cx q[65],q[11];
u1(0) q[11];
cx q[65],q[11];
u1(0) q[11];
u1(0) q[65];
cx q[65],q[12];
u1(0) q[12];
cx q[65],q[12];
u1(0) q[12];
u1(0) q[65];
cx q[65],q[13];
u1(0) q[13];
cx q[65],q[13];
u1(0) q[13];
u1(0) q[65];
cx q[65],q[14];
u1(0) q[14];
cx q[65],q[14];
u1(0) q[14];
u1(0) q[65];
cx q[65],q[15];
u1(0) q[15];
cx q[65],q[15];
u1(0) q[15];
u1(0) q[65];
cx q[65],q[16];
u1(0) q[16];
cx q[65],q[16];
u1(0) q[16];
u1(0) q[65];
cx q[65],q[17];
u1(0) q[17];
cx q[65],q[17];
u1(0) q[17];
u1(pi/281474976710656) q[65];
cx q[65],q[18];
u1(-pi/281474976710656) q[18];
cx q[65],q[18];
u1(pi/281474976710656) q[18];
u1(pi/140737488355328) q[65];
cx q[65],q[19];
u1(-pi/140737488355328) q[19];
cx q[65],q[19];
u1(pi/140737488355328) q[19];
u1(pi/70368744177664) q[65];
cx q[65],q[20];
u1(-pi/70368744177664) q[20];
cx q[65],q[20];
u1(pi/70368744177664) q[20];
u1(pi/35184372088832) q[65];
cx q[65],q[21];
u1(-pi/35184372088832) q[21];
cx q[65],q[21];
u1(pi/35184372088832) q[21];
u1(pi/17592186044416) q[65];
cx q[65],q[22];
u1(-pi/17592186044416) q[22];
cx q[65],q[22];
u1(pi/17592186044416) q[22];
u1(pi/8796093022208) q[65];
cx q[65],q[23];
u1(-pi/8796093022208) q[23];
cx q[65],q[23];
u1(pi/8796093022208) q[23];
u1(pi/4398046511104) q[65];
cx q[65],q[24];
u1(-pi/4398046511104) q[24];
cx q[65],q[24];
u1(pi/4398046511104) q[24];
u1(pi/2199023255552) q[65];
cx q[65],q[25];
u1(-pi/2199023255552) q[25];
cx q[65],q[25];
u1(pi/2199023255552) q[25];
u1(pi/1099511627776) q[65];
cx q[65],q[26];
u1(-pi/1099511627776) q[26];
cx q[65],q[26];
u1(pi/1099511627776) q[26];
u1(pi/549755813888) q[65];
cx q[65],q[27];
u1(-pi/549755813888) q[27];
cx q[65],q[27];
u1(pi/549755813888) q[27];
u1(pi/274877906944) q[65];
cx q[65],q[28];
u1(-pi/274877906944) q[28];
cx q[65],q[28];
u1(pi/274877906944) q[28];
u1(pi/137438953472) q[65];
cx q[65],q[29];
u1(-pi/137438953472) q[29];
cx q[65],q[29];
u1(pi/137438953472) q[29];
u1(pi/68719476736) q[65];
cx q[65],q[30];
u1(-pi/68719476736) q[30];
cx q[65],q[30];
u1(pi/68719476736) q[30];
u1(pi/34359738368) q[65];
cx q[65],q[31];
u1(-pi/34359738368) q[31];
cx q[65],q[31];
u1(pi/34359738368) q[31];
u1(pi/17179869184) q[65];
cx q[65],q[32];
u1(-pi/17179869184) q[32];
cx q[65],q[32];
u1(pi/17179869184) q[32];
u1(pi/8589934592) q[65];
cx q[65],q[33];
u1(-pi/8589934592) q[33];
cx q[65],q[33];
u1(pi/8589934592) q[33];
u1(pi/4294967296) q[65];
cx q[65],q[34];
u1(-pi/4294967296) q[34];
cx q[65],q[34];
u1(pi/4294967296) q[34];
u1(pi/2147483648) q[65];
cx q[65],q[35];
u1(-pi/2147483648) q[35];
cx q[65],q[35];
u1(pi/2147483648) q[35];
u1(pi/1073741824) q[65];
cx q[65],q[36];
u1(-pi/1073741824) q[36];
cx q[65],q[36];
u1(pi/1073741824) q[36];
u1(pi/536870912) q[65];
cx q[65],q[37];
u1(-pi/536870912) q[37];
cx q[65],q[37];
u1(pi/536870912) q[37];
u1(pi/268435456) q[65];
cx q[65],q[38];
u1(-pi/268435456) q[38];
cx q[65],q[38];
u1(pi/268435456) q[38];
u1(pi/134217728) q[65];
cx q[65],q[39];
u1(-pi/134217728) q[39];
cx q[65],q[39];
u1(pi/134217728) q[39];
u1(pi/67108864) q[65];
cx q[65],q[40];
u1(-pi/67108864) q[40];
cx q[65],q[40];
u1(pi/67108864) q[40];
u1(pi/33554432) q[65];
cx q[65],q[41];
u1(-pi/33554432) q[41];
cx q[65],q[41];
u1(pi/33554432) q[41];
u1(pi/16777216) q[65];
cx q[65],q[42];
u1(-pi/16777216) q[42];
cx q[65],q[42];
u1(pi/16777216) q[42];
u1(pi/8388608) q[65];
cx q[65],q[43];
u1(-pi/8388608) q[43];
cx q[65],q[43];
u1(pi/8388608) q[43];
u1(pi/4194304) q[65];
cx q[65],q[44];
u1(-pi/4194304) q[44];
cx q[65],q[44];
u1(pi/4194304) q[44];
u1(pi/2097152) q[65];
cx q[65],q[45];
u1(-pi/2097152) q[45];
cx q[65],q[45];
u1(pi/2097152) q[45];
u1(pi/1048576) q[65];
cx q[65],q[46];
u1(-pi/1048576) q[46];
cx q[65],q[46];
u1(pi/1048576) q[46];
u1(pi/524288) q[65];
cx q[65],q[47];
u1(-pi/524288) q[47];
cx q[65],q[47];
u1(pi/524288) q[47];
u1(pi/262144) q[65];
cx q[65],q[48];
u1(-pi/262144) q[48];
cx q[65],q[48];
u1(pi/262144) q[48];
u1(pi/131072) q[65];
cx q[65],q[49];
u1(-pi/131072) q[49];
cx q[65],q[49];
u1(pi/131072) q[49];
u1(pi/65536) q[65];
cx q[65],q[50];
u1(-pi/65536) q[50];
cx q[65],q[50];
u1(pi/65536) q[50];
u1(pi/32768) q[65];
cx q[65],q[51];
u1(-pi/32768) q[51];
cx q[65],q[51];
u1(pi/32768) q[51];
u1(pi/16384) q[65];
cx q[65],q[52];
u1(-pi/16384) q[52];
cx q[65],q[52];
u1(pi/16384) q[52];
u1(pi/8192) q[65];
cx q[65],q[53];
u1(-pi/8192) q[53];
cx q[65],q[53];
u1(pi/8192) q[53];
u1(pi/4096) q[65];
cx q[65],q[54];
u1(-pi/4096) q[54];
cx q[65],q[54];
u1(pi/4096) q[54];
u1(pi/2048) q[65];
cx q[65],q[55];
u1(-pi/2048) q[55];
cx q[65],q[55];
u1(pi/2048) q[55];
u1(pi/1024) q[65];
cx q[65],q[56];
u1(-pi/1024) q[56];
cx q[65],q[56];
u1(pi/1024) q[56];
u1(pi/512) q[65];
cx q[65],q[57];
u1(-pi/512) q[57];
cx q[65],q[57];
u1(pi/512) q[57];
u1(pi/256) q[65];
cx q[65],q[58];
u1(-pi/256) q[58];
cx q[65],q[58];
u1(pi/256) q[58];
u1(pi/128) q[65];
cx q[65],q[59];
u1(-pi/128) q[59];
cx q[65],q[59];
u1(pi/128) q[59];
u1(pi/64) q[65];
cx q[65],q[60];
u1(-pi/64) q[60];
cx q[65],q[60];
u1(pi/64) q[60];
u1(pi/32) q[65];
cx q[65],q[61];
u1(-pi/32) q[61];
cx q[65],q[61];
u1(pi/32) q[61];
u1(pi/16) q[65];
cx q[65],q[62];
u1(-pi/16) q[62];
cx q[65],q[62];
u1(pi/16) q[62];
u1(pi/8) q[65];
cx q[65],q[63];
u1(-pi/8) q[63];
cx q[65],q[63];
u1(pi/8) q[63];
u1(pi/4) q[65];
cx q[65],q[64];
u1(-pi/4) q[64];
cx q[65],q[64];
u1(pi/4) q[64];
h q[65];
u1(0) q[66];
cx q[66],q[0];
u1(0) q[0];
cx q[66],q[0];
u1(0) q[0];
u1(0) q[66];
cx q[66],q[1];
u1(0) q[1];
cx q[66],q[1];
u1(0) q[1];
u1(0) q[66];
cx q[66],q[2];
u1(0) q[2];
cx q[66],q[2];
u1(0) q[2];
u1(0) q[66];
cx q[66],q[3];
u1(0) q[3];
cx q[66],q[3];
u1(0) q[3];
u1(0) q[66];
cx q[66],q[4];
u1(0) q[4];
cx q[66],q[4];
u1(0) q[4];
u1(0) q[66];
cx q[66],q[5];
u1(0) q[5];
cx q[66],q[5];
u1(0) q[5];
u1(0) q[66];
cx q[66],q[6];
u1(0) q[6];
cx q[66],q[6];
u1(0) q[6];
u1(0) q[66];
cx q[66],q[7];
u1(0) q[7];
cx q[66],q[7];
u1(0) q[7];
u1(0) q[66];
cx q[66],q[8];
u1(0) q[8];
cx q[66],q[8];
u1(0) q[8];
u1(0) q[66];
cx q[66],q[9];
u1(0) q[9];
cx q[66],q[9];
u1(0) q[9];
u1(0) q[66];
cx q[66],q[10];
u1(0) q[10];
cx q[66],q[10];
u1(0) q[10];
u1(0) q[66];
cx q[66],q[11];
u1(0) q[11];
cx q[66],q[11];
u1(0) q[11];
u1(0) q[66];
cx q[66],q[12];
u1(0) q[12];
cx q[66],q[12];
u1(0) q[12];
u1(0) q[66];
cx q[66],q[13];
u1(0) q[13];
cx q[66],q[13];
u1(0) q[13];
u1(0) q[66];
cx q[66],q[14];
u1(0) q[14];
cx q[66],q[14];
u1(0) q[14];
u1(0) q[66];
cx q[66],q[15];
u1(0) q[15];
cx q[66],q[15];
u1(0) q[15];
u1(0) q[66];
cx q[66],q[16];
u1(0) q[16];
cx q[66],q[16];
u1(0) q[16];
u1(0) q[66];
cx q[66],q[17];
u1(0) q[17];
cx q[66],q[17];
u1(0) q[17];
u1(0) q[66];
cx q[66],q[18];
u1(0) q[18];
cx q[66],q[18];
u1(0) q[18];
u1(pi/281474976710656) q[66];
cx q[66],q[19];
u1(-pi/281474976710656) q[19];
cx q[66],q[19];
u1(pi/281474976710656) q[19];
u1(pi/140737488355328) q[66];
cx q[66],q[20];
u1(-pi/140737488355328) q[20];
cx q[66],q[20];
u1(pi/140737488355328) q[20];
u1(pi/70368744177664) q[66];
cx q[66],q[21];
u1(-pi/70368744177664) q[21];
cx q[66],q[21];
u1(pi/70368744177664) q[21];
u1(pi/35184372088832) q[66];
cx q[66],q[22];
u1(-pi/35184372088832) q[22];
cx q[66],q[22];
u1(pi/35184372088832) q[22];
u1(pi/17592186044416) q[66];
cx q[66],q[23];
u1(-pi/17592186044416) q[23];
cx q[66],q[23];
u1(pi/17592186044416) q[23];
u1(pi/8796093022208) q[66];
cx q[66],q[24];
u1(-pi/8796093022208) q[24];
cx q[66],q[24];
u1(pi/8796093022208) q[24];
u1(pi/4398046511104) q[66];
cx q[66],q[25];
u1(-pi/4398046511104) q[25];
cx q[66],q[25];
u1(pi/4398046511104) q[25];
u1(pi/2199023255552) q[66];
cx q[66],q[26];
u1(-pi/2199023255552) q[26];
cx q[66],q[26];
u1(pi/2199023255552) q[26];
u1(pi/1099511627776) q[66];
cx q[66],q[27];
u1(-pi/1099511627776) q[27];
cx q[66],q[27];
u1(pi/1099511627776) q[27];
u1(pi/549755813888) q[66];
cx q[66],q[28];
u1(-pi/549755813888) q[28];
cx q[66],q[28];
u1(pi/549755813888) q[28];
u1(pi/274877906944) q[66];
cx q[66],q[29];
u1(-pi/274877906944) q[29];
cx q[66],q[29];
u1(pi/274877906944) q[29];
u1(pi/137438953472) q[66];
cx q[66],q[30];
u1(-pi/137438953472) q[30];
cx q[66],q[30];
u1(pi/137438953472) q[30];
u1(pi/68719476736) q[66];
cx q[66],q[31];
u1(-pi/68719476736) q[31];
cx q[66],q[31];
u1(pi/68719476736) q[31];
u1(pi/34359738368) q[66];
cx q[66],q[32];
u1(-pi/34359738368) q[32];
cx q[66],q[32];
u1(pi/34359738368) q[32];
u1(pi/17179869184) q[66];
cx q[66],q[33];
u1(-pi/17179869184) q[33];
cx q[66],q[33];
u1(pi/17179869184) q[33];
u1(pi/8589934592) q[66];
cx q[66],q[34];
u1(-pi/8589934592) q[34];
cx q[66],q[34];
u1(pi/8589934592) q[34];
u1(pi/4294967296) q[66];
cx q[66],q[35];
u1(-pi/4294967296) q[35];
cx q[66],q[35];
u1(pi/4294967296) q[35];
u1(pi/2147483648) q[66];
cx q[66],q[36];
u1(-pi/2147483648) q[36];
cx q[66],q[36];
u1(pi/2147483648) q[36];
u1(pi/1073741824) q[66];
cx q[66],q[37];
u1(-pi/1073741824) q[37];
cx q[66],q[37];
u1(pi/1073741824) q[37];
u1(pi/536870912) q[66];
cx q[66],q[38];
u1(-pi/536870912) q[38];
cx q[66],q[38];
u1(pi/536870912) q[38];
u1(pi/268435456) q[66];
cx q[66],q[39];
u1(-pi/268435456) q[39];
cx q[66],q[39];
u1(pi/268435456) q[39];
u1(pi/134217728) q[66];
cx q[66],q[40];
u1(-pi/134217728) q[40];
cx q[66],q[40];
u1(pi/134217728) q[40];
u1(pi/67108864) q[66];
cx q[66],q[41];
u1(-pi/67108864) q[41];
cx q[66],q[41];
u1(pi/67108864) q[41];
u1(pi/33554432) q[66];
cx q[66],q[42];
u1(-pi/33554432) q[42];
cx q[66],q[42];
u1(pi/33554432) q[42];
u1(pi/16777216) q[66];
cx q[66],q[43];
u1(-pi/16777216) q[43];
cx q[66],q[43];
u1(pi/16777216) q[43];
u1(pi/8388608) q[66];
cx q[66],q[44];
u1(-pi/8388608) q[44];
cx q[66],q[44];
u1(pi/8388608) q[44];
u1(pi/4194304) q[66];
cx q[66],q[45];
u1(-pi/4194304) q[45];
cx q[66],q[45];
u1(pi/4194304) q[45];
u1(pi/2097152) q[66];
cx q[66],q[46];
u1(-pi/2097152) q[46];
cx q[66],q[46];
u1(pi/2097152) q[46];
u1(pi/1048576) q[66];
cx q[66],q[47];
u1(-pi/1048576) q[47];
cx q[66],q[47];
u1(pi/1048576) q[47];
u1(pi/524288) q[66];
cx q[66],q[48];
u1(-pi/524288) q[48];
cx q[66],q[48];
u1(pi/524288) q[48];
u1(pi/262144) q[66];
cx q[66],q[49];
u1(-pi/262144) q[49];
cx q[66],q[49];
u1(pi/262144) q[49];
u1(pi/131072) q[66];
cx q[66],q[50];
u1(-pi/131072) q[50];
cx q[66],q[50];
u1(pi/131072) q[50];
u1(pi/65536) q[66];
cx q[66],q[51];
u1(-pi/65536) q[51];
cx q[66],q[51];
u1(pi/65536) q[51];
u1(pi/32768) q[66];
cx q[66],q[52];
u1(-pi/32768) q[52];
cx q[66],q[52];
u1(pi/32768) q[52];
u1(pi/16384) q[66];
cx q[66],q[53];
u1(-pi/16384) q[53];
cx q[66],q[53];
u1(pi/16384) q[53];
u1(pi/8192) q[66];
cx q[66],q[54];
u1(-pi/8192) q[54];
cx q[66],q[54];
u1(pi/8192) q[54];
u1(pi/4096) q[66];
cx q[66],q[55];
u1(-pi/4096) q[55];
cx q[66],q[55];
u1(pi/4096) q[55];
u1(pi/2048) q[66];
cx q[66],q[56];
u1(-pi/2048) q[56];
cx q[66],q[56];
u1(pi/2048) q[56];
u1(pi/1024) q[66];
cx q[66],q[57];
u1(-pi/1024) q[57];
cx q[66],q[57];
u1(pi/1024) q[57];
u1(pi/512) q[66];
cx q[66],q[58];
u1(-pi/512) q[58];
cx q[66],q[58];
u1(pi/512) q[58];
u1(pi/256) q[66];
cx q[66],q[59];
u1(-pi/256) q[59];
cx q[66],q[59];
u1(pi/256) q[59];
u1(pi/128) q[66];
cx q[66],q[60];
u1(-pi/128) q[60];
cx q[66],q[60];
u1(pi/128) q[60];
u1(pi/64) q[66];
cx q[66],q[61];
u1(-pi/64) q[61];
cx q[66],q[61];
u1(pi/64) q[61];
u1(pi/32) q[66];
cx q[66],q[62];
u1(-pi/32) q[62];
cx q[66],q[62];
u1(pi/32) q[62];
u1(pi/16) q[66];
cx q[66],q[63];
u1(-pi/16) q[63];
cx q[66],q[63];
u1(pi/16) q[63];
u1(pi/8) q[66];
cx q[66],q[64];
u1(-pi/8) q[64];
cx q[66],q[64];
u1(pi/8) q[64];
u1(pi/4) q[66];
cx q[66],q[65];
u1(-pi/4) q[65];
cx q[66],q[65];
u1(pi/4) q[65];
h q[66];
u1(0) q[67];
cx q[67],q[0];
u1(0) q[0];
cx q[67],q[0];
u1(0) q[0];
u1(0) q[67];
cx q[67],q[1];
u1(0) q[1];
cx q[67],q[1];
u1(0) q[1];
u1(0) q[67];
cx q[67],q[2];
u1(0) q[2];
cx q[67],q[2];
u1(0) q[2];
u1(0) q[67];
cx q[67],q[3];
u1(0) q[3];
cx q[67],q[3];
u1(0) q[3];
u1(0) q[67];
cx q[67],q[4];
u1(0) q[4];
cx q[67],q[4];
u1(0) q[4];
u1(0) q[67];
cx q[67],q[5];
u1(0) q[5];
cx q[67],q[5];
u1(0) q[5];
u1(0) q[67];
cx q[67],q[6];
u1(0) q[6];
cx q[67],q[6];
u1(0) q[6];
u1(0) q[67];
cx q[67],q[7];
u1(0) q[7];
cx q[67],q[7];
u1(0) q[7];
u1(0) q[67];
cx q[67],q[8];
u1(0) q[8];
cx q[67],q[8];
u1(0) q[8];
u1(0) q[67];
cx q[67],q[9];
u1(0) q[9];
cx q[67],q[9];
u1(0) q[9];
u1(0) q[67];
cx q[67],q[10];
u1(0) q[10];
cx q[67],q[10];
u1(0) q[10];
u1(0) q[67];
cx q[67],q[11];
u1(0) q[11];
cx q[67],q[11];
u1(0) q[11];
u1(0) q[67];
cx q[67],q[12];
u1(0) q[12];
cx q[67],q[12];
u1(0) q[12];
u1(0) q[67];
cx q[67],q[13];
u1(0) q[13];
cx q[67],q[13];
u1(0) q[13];
u1(0) q[67];
cx q[67],q[14];
u1(0) q[14];
cx q[67],q[14];
u1(0) q[14];
u1(0) q[67];
cx q[67],q[15];
u1(0) q[15];
cx q[67],q[15];
u1(0) q[15];
u1(0) q[67];
cx q[67],q[16];
u1(0) q[16];
cx q[67],q[16];
u1(0) q[16];
u1(0) q[67];
cx q[67],q[17];
u1(0) q[17];
cx q[67],q[17];
u1(0) q[17];
u1(0) q[67];
cx q[67],q[18];
u1(0) q[18];
cx q[67],q[18];
u1(0) q[18];
u1(0) q[67];
cx q[67],q[19];
u1(0) q[19];
cx q[67],q[19];
u1(0) q[19];
u1(pi/281474976710656) q[67];
cx q[67],q[20];
u1(-pi/281474976710656) q[20];
cx q[67],q[20];
u1(pi/281474976710656) q[20];
u1(pi/140737488355328) q[67];
cx q[67],q[21];
u1(-pi/140737488355328) q[21];
cx q[67],q[21];
u1(pi/140737488355328) q[21];
u1(pi/70368744177664) q[67];
cx q[67],q[22];
u1(-pi/70368744177664) q[22];
cx q[67],q[22];
u1(pi/70368744177664) q[22];
u1(pi/35184372088832) q[67];
cx q[67],q[23];
u1(-pi/35184372088832) q[23];
cx q[67],q[23];
u1(pi/35184372088832) q[23];
u1(pi/17592186044416) q[67];
cx q[67],q[24];
u1(-pi/17592186044416) q[24];
cx q[67],q[24];
u1(pi/17592186044416) q[24];
u1(pi/8796093022208) q[67];
cx q[67],q[25];
u1(-pi/8796093022208) q[25];
cx q[67],q[25];
u1(pi/8796093022208) q[25];
u1(pi/4398046511104) q[67];
cx q[67],q[26];
u1(-pi/4398046511104) q[26];
cx q[67],q[26];
u1(pi/4398046511104) q[26];
u1(pi/2199023255552) q[67];
cx q[67],q[27];
u1(-pi/2199023255552) q[27];
cx q[67],q[27];
u1(pi/2199023255552) q[27];
u1(pi/1099511627776) q[67];
cx q[67],q[28];
u1(-pi/1099511627776) q[28];
cx q[67],q[28];
u1(pi/1099511627776) q[28];
u1(pi/549755813888) q[67];
cx q[67],q[29];
u1(-pi/549755813888) q[29];
cx q[67],q[29];
u1(pi/549755813888) q[29];
u1(pi/274877906944) q[67];
cx q[67],q[30];
u1(-pi/274877906944) q[30];
cx q[67],q[30];
u1(pi/274877906944) q[30];
u1(pi/137438953472) q[67];
cx q[67],q[31];
u1(-pi/137438953472) q[31];
cx q[67],q[31];
u1(pi/137438953472) q[31];
u1(pi/68719476736) q[67];
cx q[67],q[32];
u1(-pi/68719476736) q[32];
cx q[67],q[32];
u1(pi/68719476736) q[32];
u1(pi/34359738368) q[67];
cx q[67],q[33];
u1(-pi/34359738368) q[33];
cx q[67],q[33];
u1(pi/34359738368) q[33];
u1(pi/17179869184) q[67];
cx q[67],q[34];
u1(-pi/17179869184) q[34];
cx q[67],q[34];
u1(pi/17179869184) q[34];
u1(pi/8589934592) q[67];
cx q[67],q[35];
u1(-pi/8589934592) q[35];
cx q[67],q[35];
u1(pi/8589934592) q[35];
u1(pi/4294967296) q[67];
cx q[67],q[36];
u1(-pi/4294967296) q[36];
cx q[67],q[36];
u1(pi/4294967296) q[36];
u1(pi/2147483648) q[67];
cx q[67],q[37];
u1(-pi/2147483648) q[37];
cx q[67],q[37];
u1(pi/2147483648) q[37];
u1(pi/1073741824) q[67];
cx q[67],q[38];
u1(-pi/1073741824) q[38];
cx q[67],q[38];
u1(pi/1073741824) q[38];
u1(pi/536870912) q[67];
cx q[67],q[39];
u1(-pi/536870912) q[39];
cx q[67],q[39];
u1(pi/536870912) q[39];
u1(pi/268435456) q[67];
cx q[67],q[40];
u1(-pi/268435456) q[40];
cx q[67],q[40];
u1(pi/268435456) q[40];
u1(pi/134217728) q[67];
cx q[67],q[41];
u1(-pi/134217728) q[41];
cx q[67],q[41];
u1(pi/134217728) q[41];
u1(pi/67108864) q[67];
cx q[67],q[42];
u1(-pi/67108864) q[42];
cx q[67],q[42];
u1(pi/67108864) q[42];
u1(pi/33554432) q[67];
cx q[67],q[43];
u1(-pi/33554432) q[43];
cx q[67],q[43];
u1(pi/33554432) q[43];
u1(pi/16777216) q[67];
cx q[67],q[44];
u1(-pi/16777216) q[44];
cx q[67],q[44];
u1(pi/16777216) q[44];
u1(pi/8388608) q[67];
cx q[67],q[45];
u1(-pi/8388608) q[45];
cx q[67],q[45];
u1(pi/8388608) q[45];
u1(pi/4194304) q[67];
cx q[67],q[46];
u1(-pi/4194304) q[46];
cx q[67],q[46];
u1(pi/4194304) q[46];
u1(pi/2097152) q[67];
cx q[67],q[47];
u1(-pi/2097152) q[47];
cx q[67],q[47];
u1(pi/2097152) q[47];
u1(pi/1048576) q[67];
cx q[67],q[48];
u1(-pi/1048576) q[48];
cx q[67],q[48];
u1(pi/1048576) q[48];
u1(pi/524288) q[67];
cx q[67],q[49];
u1(-pi/524288) q[49];
cx q[67],q[49];
u1(pi/524288) q[49];
u1(pi/262144) q[67];
cx q[67],q[50];
u1(-pi/262144) q[50];
cx q[67],q[50];
u1(pi/262144) q[50];
u1(pi/131072) q[67];
cx q[67],q[51];
u1(-pi/131072) q[51];
cx q[67],q[51];
u1(pi/131072) q[51];
u1(pi/65536) q[67];
cx q[67],q[52];
u1(-pi/65536) q[52];
cx q[67],q[52];
u1(pi/65536) q[52];
u1(pi/32768) q[67];
cx q[67],q[53];
u1(-pi/32768) q[53];
cx q[67],q[53];
u1(pi/32768) q[53];
u1(pi/16384) q[67];
cx q[67],q[54];
u1(-pi/16384) q[54];
cx q[67],q[54];
u1(pi/16384) q[54];
u1(pi/8192) q[67];
cx q[67],q[55];
u1(-pi/8192) q[55];
cx q[67],q[55];
u1(pi/8192) q[55];
u1(pi/4096) q[67];
cx q[67],q[56];
u1(-pi/4096) q[56];
cx q[67],q[56];
u1(pi/4096) q[56];
u1(pi/2048) q[67];
cx q[67],q[57];
u1(-pi/2048) q[57];
cx q[67],q[57];
u1(pi/2048) q[57];
u1(pi/1024) q[67];
cx q[67],q[58];
u1(-pi/1024) q[58];
cx q[67],q[58];
u1(pi/1024) q[58];
u1(pi/512) q[67];
cx q[67],q[59];
u1(-pi/512) q[59];
cx q[67],q[59];
u1(pi/512) q[59];
u1(pi/256) q[67];
cx q[67],q[60];
u1(-pi/256) q[60];
cx q[67],q[60];
u1(pi/256) q[60];
u1(pi/128) q[67];
cx q[67],q[61];
u1(-pi/128) q[61];
cx q[67],q[61];
u1(pi/128) q[61];
u1(pi/64) q[67];
cx q[67],q[62];
u1(-pi/64) q[62];
cx q[67],q[62];
u1(pi/64) q[62];
u1(pi/32) q[67];
cx q[67],q[63];
u1(-pi/32) q[63];
cx q[67],q[63];
u1(pi/32) q[63];
u1(pi/16) q[67];
cx q[67],q[64];
u1(-pi/16) q[64];
cx q[67],q[64];
u1(pi/16) q[64];
u1(pi/8) q[67];
cx q[67],q[65];
u1(-pi/8) q[65];
cx q[67],q[65];
u1(pi/8) q[65];
u1(pi/4) q[67];
cx q[67],q[66];
u1(-pi/4) q[66];
cx q[67],q[66];
u1(pi/4) q[66];
h q[67];
u1(0) q[68];
cx q[68],q[0];
u1(0) q[0];
cx q[68],q[0];
u1(0) q[0];
u1(0) q[68];
cx q[68],q[1];
u1(0) q[1];
cx q[68],q[1];
u1(0) q[1];
u1(0) q[68];
cx q[68],q[2];
u1(0) q[2];
cx q[68],q[2];
u1(0) q[2];
u1(0) q[68];
cx q[68],q[3];
u1(0) q[3];
cx q[68],q[3];
u1(0) q[3];
u1(0) q[68];
cx q[68],q[4];
u1(0) q[4];
cx q[68],q[4];
u1(0) q[4];
u1(0) q[68];
cx q[68],q[5];
u1(0) q[5];
cx q[68],q[5];
u1(0) q[5];
u1(0) q[68];
cx q[68],q[6];
u1(0) q[6];
cx q[68],q[6];
u1(0) q[6];
u1(0) q[68];
cx q[68],q[7];
u1(0) q[7];
cx q[68],q[7];
u1(0) q[7];
u1(0) q[68];
cx q[68],q[8];
u1(0) q[8];
cx q[68],q[8];
u1(0) q[8];
u1(0) q[68];
cx q[68],q[9];
u1(0) q[9];
cx q[68],q[9];
u1(0) q[9];
u1(0) q[68];
cx q[68],q[10];
u1(0) q[10];
cx q[68],q[10];
u1(0) q[10];
u1(0) q[68];
cx q[68],q[11];
u1(0) q[11];
cx q[68],q[11];
u1(0) q[11];
u1(0) q[68];
cx q[68],q[12];
u1(0) q[12];
cx q[68],q[12];
u1(0) q[12];
u1(0) q[68];
cx q[68],q[13];
u1(0) q[13];
cx q[68],q[13];
u1(0) q[13];
u1(0) q[68];
cx q[68],q[14];
u1(0) q[14];
cx q[68],q[14];
u1(0) q[14];
u1(0) q[68];
cx q[68],q[15];
u1(0) q[15];
cx q[68],q[15];
u1(0) q[15];
u1(0) q[68];
cx q[68],q[16];
u1(0) q[16];
cx q[68],q[16];
u1(0) q[16];
u1(0) q[68];
cx q[68],q[17];
u1(0) q[17];
cx q[68],q[17];
u1(0) q[17];
u1(0) q[68];
cx q[68],q[18];
u1(0) q[18];
cx q[68],q[18];
u1(0) q[18];
u1(0) q[68];
cx q[68],q[19];
u1(0) q[19];
cx q[68],q[19];
u1(0) q[19];
u1(0) q[68];
cx q[68],q[20];
u1(0) q[20];
cx q[68],q[20];
u1(0) q[20];
u1(pi/281474976710656) q[68];
cx q[68],q[21];
u1(-pi/281474976710656) q[21];
cx q[68],q[21];
u1(pi/281474976710656) q[21];
u1(pi/140737488355328) q[68];
cx q[68],q[22];
u1(-pi/140737488355328) q[22];
cx q[68],q[22];
u1(pi/140737488355328) q[22];
u1(pi/70368744177664) q[68];
cx q[68],q[23];
u1(-pi/70368744177664) q[23];
cx q[68],q[23];
u1(pi/70368744177664) q[23];
u1(pi/35184372088832) q[68];
cx q[68],q[24];
u1(-pi/35184372088832) q[24];
cx q[68],q[24];
u1(pi/35184372088832) q[24];
u1(pi/17592186044416) q[68];
cx q[68],q[25];
u1(-pi/17592186044416) q[25];
cx q[68],q[25];
u1(pi/17592186044416) q[25];
u1(pi/8796093022208) q[68];
cx q[68],q[26];
u1(-pi/8796093022208) q[26];
cx q[68],q[26];
u1(pi/8796093022208) q[26];
u1(pi/4398046511104) q[68];
cx q[68],q[27];
u1(-pi/4398046511104) q[27];
cx q[68],q[27];
u1(pi/4398046511104) q[27];
u1(pi/2199023255552) q[68];
cx q[68],q[28];
u1(-pi/2199023255552) q[28];
cx q[68],q[28];
u1(pi/2199023255552) q[28];
u1(pi/1099511627776) q[68];
cx q[68],q[29];
u1(-pi/1099511627776) q[29];
cx q[68],q[29];
u1(pi/1099511627776) q[29];
u1(pi/549755813888) q[68];
cx q[68],q[30];
u1(-pi/549755813888) q[30];
cx q[68],q[30];
u1(pi/549755813888) q[30];
u1(pi/274877906944) q[68];
cx q[68],q[31];
u1(-pi/274877906944) q[31];
cx q[68],q[31];
u1(pi/274877906944) q[31];
u1(pi/137438953472) q[68];
cx q[68],q[32];
u1(-pi/137438953472) q[32];
cx q[68],q[32];
u1(pi/137438953472) q[32];
u1(pi/68719476736) q[68];
cx q[68],q[33];
u1(-pi/68719476736) q[33];
cx q[68],q[33];
u1(pi/68719476736) q[33];
u1(pi/34359738368) q[68];
cx q[68],q[34];
u1(-pi/34359738368) q[34];
cx q[68],q[34];
u1(pi/34359738368) q[34];
u1(pi/17179869184) q[68];
cx q[68],q[35];
u1(-pi/17179869184) q[35];
cx q[68],q[35];
u1(pi/17179869184) q[35];
u1(pi/8589934592) q[68];
cx q[68],q[36];
u1(-pi/8589934592) q[36];
cx q[68],q[36];
u1(pi/8589934592) q[36];
u1(pi/4294967296) q[68];
cx q[68],q[37];
u1(-pi/4294967296) q[37];
cx q[68],q[37];
u1(pi/4294967296) q[37];
u1(pi/2147483648) q[68];
cx q[68],q[38];
u1(-pi/2147483648) q[38];
cx q[68],q[38];
u1(pi/2147483648) q[38];
u1(pi/1073741824) q[68];
cx q[68],q[39];
u1(-pi/1073741824) q[39];
cx q[68],q[39];
u1(pi/1073741824) q[39];
u1(pi/536870912) q[68];
cx q[68],q[40];
u1(-pi/536870912) q[40];
cx q[68],q[40];
u1(pi/536870912) q[40];
u1(pi/268435456) q[68];
cx q[68],q[41];
u1(-pi/268435456) q[41];
cx q[68],q[41];
u1(pi/268435456) q[41];
u1(pi/134217728) q[68];
cx q[68],q[42];
u1(-pi/134217728) q[42];
cx q[68],q[42];
u1(pi/134217728) q[42];
u1(pi/67108864) q[68];
cx q[68],q[43];
u1(-pi/67108864) q[43];
cx q[68],q[43];
u1(pi/67108864) q[43];
u1(pi/33554432) q[68];
cx q[68],q[44];
u1(-pi/33554432) q[44];
cx q[68],q[44];
u1(pi/33554432) q[44];
u1(pi/16777216) q[68];
cx q[68],q[45];
u1(-pi/16777216) q[45];
cx q[68],q[45];
u1(pi/16777216) q[45];
u1(pi/8388608) q[68];
cx q[68],q[46];
u1(-pi/8388608) q[46];
cx q[68],q[46];
u1(pi/8388608) q[46];
u1(pi/4194304) q[68];
cx q[68],q[47];
u1(-pi/4194304) q[47];
cx q[68],q[47];
u1(pi/4194304) q[47];
u1(pi/2097152) q[68];
cx q[68],q[48];
u1(-pi/2097152) q[48];
cx q[68],q[48];
u1(pi/2097152) q[48];
u1(pi/1048576) q[68];
cx q[68],q[49];
u1(-pi/1048576) q[49];
cx q[68],q[49];
u1(pi/1048576) q[49];
u1(pi/524288) q[68];
cx q[68],q[50];
u1(-pi/524288) q[50];
cx q[68],q[50];
u1(pi/524288) q[50];
u1(pi/262144) q[68];
cx q[68],q[51];
u1(-pi/262144) q[51];
cx q[68],q[51];
u1(pi/262144) q[51];
u1(pi/131072) q[68];
cx q[68],q[52];
u1(-pi/131072) q[52];
cx q[68],q[52];
u1(pi/131072) q[52];
u1(pi/65536) q[68];
cx q[68],q[53];
u1(-pi/65536) q[53];
cx q[68],q[53];
u1(pi/65536) q[53];
u1(pi/32768) q[68];
cx q[68],q[54];
u1(-pi/32768) q[54];
cx q[68],q[54];
u1(pi/32768) q[54];
u1(pi/16384) q[68];
cx q[68],q[55];
u1(-pi/16384) q[55];
cx q[68],q[55];
u1(pi/16384) q[55];
u1(pi/8192) q[68];
cx q[68],q[56];
u1(-pi/8192) q[56];
cx q[68],q[56];
u1(pi/8192) q[56];
u1(pi/4096) q[68];
cx q[68],q[57];
u1(-pi/4096) q[57];
cx q[68],q[57];
u1(pi/4096) q[57];
u1(pi/2048) q[68];
cx q[68],q[58];
u1(-pi/2048) q[58];
cx q[68],q[58];
u1(pi/2048) q[58];
u1(pi/1024) q[68];
cx q[68],q[59];
u1(-pi/1024) q[59];
cx q[68],q[59];
u1(pi/1024) q[59];
u1(pi/512) q[68];
cx q[68],q[60];
u1(-pi/512) q[60];
cx q[68],q[60];
u1(pi/512) q[60];
u1(pi/256) q[68];
cx q[68],q[61];
u1(-pi/256) q[61];
cx q[68],q[61];
u1(pi/256) q[61];
u1(pi/128) q[68];
cx q[68],q[62];
u1(-pi/128) q[62];
cx q[68],q[62];
u1(pi/128) q[62];
u1(pi/64) q[68];
cx q[68],q[63];
u1(-pi/64) q[63];
cx q[68],q[63];
u1(pi/64) q[63];
u1(pi/32) q[68];
cx q[68],q[64];
u1(-pi/32) q[64];
cx q[68],q[64];
u1(pi/32) q[64];
u1(pi/16) q[68];
cx q[68],q[65];
u1(-pi/16) q[65];
cx q[68],q[65];
u1(pi/16) q[65];
u1(pi/8) q[68];
cx q[68],q[66];
u1(-pi/8) q[66];
cx q[68],q[66];
u1(pi/8) q[66];
u1(pi/4) q[68];
cx q[68],q[67];
u1(-pi/4) q[67];
cx q[68],q[67];
u1(pi/4) q[67];
h q[68];
u1(0) q[69];
cx q[69],q[0];
u1(0) q[0];
cx q[69],q[0];
u1(0) q[0];
u1(0) q[69];
cx q[69],q[1];
u1(0) q[1];
cx q[69],q[1];
u1(0) q[1];
u1(0) q[69];
cx q[69],q[2];
u1(0) q[2];
cx q[69],q[2];
u1(0) q[2];
u1(0) q[69];
cx q[69],q[3];
u1(0) q[3];
cx q[69],q[3];
u1(0) q[3];
u1(0) q[69];
cx q[69],q[4];
u1(0) q[4];
cx q[69],q[4];
u1(0) q[4];
u1(0) q[69];
cx q[69],q[5];
u1(0) q[5];
cx q[69],q[5];
u1(0) q[5];
u1(0) q[69];
cx q[69],q[6];
u1(0) q[6];
cx q[69],q[6];
u1(0) q[6];
u1(0) q[69];
cx q[69],q[7];
u1(0) q[7];
cx q[69],q[7];
u1(0) q[7];
u1(0) q[69];
cx q[69],q[8];
u1(0) q[8];
cx q[69],q[8];
u1(0) q[8];
u1(0) q[69];
cx q[69],q[9];
u1(0) q[9];
cx q[69],q[9];
u1(0) q[9];
u1(0) q[69];
cx q[69],q[10];
u1(0) q[10];
cx q[69],q[10];
u1(0) q[10];
u1(0) q[69];
cx q[69],q[11];
u1(0) q[11];
cx q[69],q[11];
u1(0) q[11];
u1(0) q[69];
cx q[69],q[12];
u1(0) q[12];
cx q[69],q[12];
u1(0) q[12];
u1(0) q[69];
cx q[69],q[13];
u1(0) q[13];
cx q[69],q[13];
u1(0) q[13];
u1(0) q[69];
cx q[69],q[14];
u1(0) q[14];
cx q[69],q[14];
u1(0) q[14];
u1(0) q[69];
cx q[69],q[15];
u1(0) q[15];
cx q[69],q[15];
u1(0) q[15];
u1(0) q[69];
cx q[69],q[16];
u1(0) q[16];
cx q[69],q[16];
u1(0) q[16];
u1(0) q[69];
cx q[69],q[17];
u1(0) q[17];
cx q[69],q[17];
u1(0) q[17];
u1(0) q[69];
cx q[69],q[18];
u1(0) q[18];
cx q[69],q[18];
u1(0) q[18];
u1(0) q[69];
cx q[69],q[19];
u1(0) q[19];
cx q[69],q[19];
u1(0) q[19];
u1(0) q[69];
cx q[69],q[20];
u1(0) q[20];
cx q[69],q[20];
u1(0) q[20];
u1(0) q[69];
cx q[69],q[21];
u1(0) q[21];
cx q[69],q[21];
u1(0) q[21];
u1(pi/281474976710656) q[69];
cx q[69],q[22];
u1(-pi/281474976710656) q[22];
cx q[69],q[22];
u1(pi/281474976710656) q[22];
u1(pi/140737488355328) q[69];
cx q[69],q[23];
u1(-pi/140737488355328) q[23];
cx q[69],q[23];
u1(pi/140737488355328) q[23];
u1(pi/70368744177664) q[69];
cx q[69],q[24];
u1(-pi/70368744177664) q[24];
cx q[69],q[24];
u1(pi/70368744177664) q[24];
u1(pi/35184372088832) q[69];
cx q[69],q[25];
u1(-pi/35184372088832) q[25];
cx q[69],q[25];
u1(pi/35184372088832) q[25];
u1(pi/17592186044416) q[69];
cx q[69],q[26];
u1(-pi/17592186044416) q[26];
cx q[69],q[26];
u1(pi/17592186044416) q[26];
u1(pi/8796093022208) q[69];
cx q[69],q[27];
u1(-pi/8796093022208) q[27];
cx q[69],q[27];
u1(pi/8796093022208) q[27];
u1(pi/4398046511104) q[69];
cx q[69],q[28];
u1(-pi/4398046511104) q[28];
cx q[69],q[28];
u1(pi/4398046511104) q[28];
u1(pi/2199023255552) q[69];
cx q[69],q[29];
u1(-pi/2199023255552) q[29];
cx q[69],q[29];
u1(pi/2199023255552) q[29];
u1(pi/1099511627776) q[69];
cx q[69],q[30];
u1(-pi/1099511627776) q[30];
cx q[69],q[30];
u1(pi/1099511627776) q[30];
u1(pi/549755813888) q[69];
cx q[69],q[31];
u1(-pi/549755813888) q[31];
cx q[69],q[31];
u1(pi/549755813888) q[31];
u1(pi/274877906944) q[69];
cx q[69],q[32];
u1(-pi/274877906944) q[32];
cx q[69],q[32];
u1(pi/274877906944) q[32];
u1(pi/137438953472) q[69];
cx q[69],q[33];
u1(-pi/137438953472) q[33];
cx q[69],q[33];
u1(pi/137438953472) q[33];
u1(pi/68719476736) q[69];
cx q[69],q[34];
u1(-pi/68719476736) q[34];
cx q[69],q[34];
u1(pi/68719476736) q[34];
u1(pi/34359738368) q[69];
cx q[69],q[35];
u1(-pi/34359738368) q[35];
cx q[69],q[35];
u1(pi/34359738368) q[35];
u1(pi/17179869184) q[69];
cx q[69],q[36];
u1(-pi/17179869184) q[36];
cx q[69],q[36];
u1(pi/17179869184) q[36];
u1(pi/8589934592) q[69];
cx q[69],q[37];
u1(-pi/8589934592) q[37];
cx q[69],q[37];
u1(pi/8589934592) q[37];
u1(pi/4294967296) q[69];
cx q[69],q[38];
u1(-pi/4294967296) q[38];
cx q[69],q[38];
u1(pi/4294967296) q[38];
u1(pi/2147483648) q[69];
cx q[69],q[39];
u1(-pi/2147483648) q[39];
cx q[69],q[39];
u1(pi/2147483648) q[39];
u1(pi/1073741824) q[69];
cx q[69],q[40];
u1(-pi/1073741824) q[40];
cx q[69],q[40];
u1(pi/1073741824) q[40];
u1(pi/536870912) q[69];
cx q[69],q[41];
u1(-pi/536870912) q[41];
cx q[69],q[41];
u1(pi/536870912) q[41];
u1(pi/268435456) q[69];
cx q[69],q[42];
u1(-pi/268435456) q[42];
cx q[69],q[42];
u1(pi/268435456) q[42];
u1(pi/134217728) q[69];
cx q[69],q[43];
u1(-pi/134217728) q[43];
cx q[69],q[43];
u1(pi/134217728) q[43];
u1(pi/67108864) q[69];
cx q[69],q[44];
u1(-pi/67108864) q[44];
cx q[69],q[44];
u1(pi/67108864) q[44];
u1(pi/33554432) q[69];
cx q[69],q[45];
u1(-pi/33554432) q[45];
cx q[69],q[45];
u1(pi/33554432) q[45];
u1(pi/16777216) q[69];
cx q[69],q[46];
u1(-pi/16777216) q[46];
cx q[69],q[46];
u1(pi/16777216) q[46];
u1(pi/8388608) q[69];
cx q[69],q[47];
u1(-pi/8388608) q[47];
cx q[69],q[47];
u1(pi/8388608) q[47];
u1(pi/4194304) q[69];
cx q[69],q[48];
u1(-pi/4194304) q[48];
cx q[69],q[48];
u1(pi/4194304) q[48];
u1(pi/2097152) q[69];
cx q[69],q[49];
u1(-pi/2097152) q[49];
cx q[69],q[49];
u1(pi/2097152) q[49];
u1(pi/1048576) q[69];
cx q[69],q[50];
u1(-pi/1048576) q[50];
cx q[69],q[50];
u1(pi/1048576) q[50];
u1(pi/524288) q[69];
cx q[69],q[51];
u1(-pi/524288) q[51];
cx q[69],q[51];
u1(pi/524288) q[51];
u1(pi/262144) q[69];
cx q[69],q[52];
u1(-pi/262144) q[52];
cx q[69],q[52];
u1(pi/262144) q[52];
u1(pi/131072) q[69];
cx q[69],q[53];
u1(-pi/131072) q[53];
cx q[69],q[53];
u1(pi/131072) q[53];
u1(pi/65536) q[69];
cx q[69],q[54];
u1(-pi/65536) q[54];
cx q[69],q[54];
u1(pi/65536) q[54];
u1(pi/32768) q[69];
cx q[69],q[55];
u1(-pi/32768) q[55];
cx q[69],q[55];
u1(pi/32768) q[55];
u1(pi/16384) q[69];
cx q[69],q[56];
u1(-pi/16384) q[56];
cx q[69],q[56];
u1(pi/16384) q[56];
u1(pi/8192) q[69];
cx q[69],q[57];
u1(-pi/8192) q[57];
cx q[69],q[57];
u1(pi/8192) q[57];
u1(pi/4096) q[69];
cx q[69],q[58];
u1(-pi/4096) q[58];
cx q[69],q[58];
u1(pi/4096) q[58];
u1(pi/2048) q[69];
cx q[69],q[59];
u1(-pi/2048) q[59];
cx q[69],q[59];
u1(pi/2048) q[59];
u1(pi/1024) q[69];
cx q[69],q[60];
u1(-pi/1024) q[60];
cx q[69],q[60];
u1(pi/1024) q[60];
u1(pi/512) q[69];
cx q[69],q[61];
u1(-pi/512) q[61];
cx q[69],q[61];
u1(pi/512) q[61];
u1(pi/256) q[69];
cx q[69],q[62];
u1(-pi/256) q[62];
cx q[69],q[62];
u1(pi/256) q[62];
u1(pi/128) q[69];
cx q[69],q[63];
u1(-pi/128) q[63];
cx q[69],q[63];
u1(pi/128) q[63];
u1(pi/64) q[69];
cx q[69],q[64];
u1(-pi/64) q[64];
cx q[69],q[64];
u1(pi/64) q[64];
u1(pi/32) q[69];
cx q[69],q[65];
u1(-pi/32) q[65];
cx q[69],q[65];
u1(pi/32) q[65];
u1(pi/16) q[69];
cx q[69],q[66];
u1(-pi/16) q[66];
cx q[69],q[66];
u1(pi/16) q[66];
u1(pi/8) q[69];
cx q[69],q[67];
u1(-pi/8) q[67];
cx q[69],q[67];
u1(pi/8) q[67];
u1(pi/4) q[69];
cx q[69],q[68];
u1(-pi/4) q[68];
cx q[69],q[68];
u1(pi/4) q[68];
h q[69];
u1(0) q[70];
cx q[70],q[0];
u1(0) q[0];
cx q[70],q[0];
u1(0) q[0];
u1(0) q[70];
cx q[70],q[1];
u1(0) q[1];
cx q[70],q[1];
u1(0) q[1];
u1(0) q[70];
cx q[70],q[2];
u1(0) q[2];
cx q[70],q[2];
u1(0) q[2];
u1(0) q[70];
cx q[70],q[3];
u1(0) q[3];
cx q[70],q[3];
u1(0) q[3];
u1(0) q[70];
cx q[70],q[4];
u1(0) q[4];
cx q[70],q[4];
u1(0) q[4];
u1(0) q[70];
cx q[70],q[5];
u1(0) q[5];
cx q[70],q[5];
u1(0) q[5];
u1(0) q[70];
cx q[70],q[6];
u1(0) q[6];
cx q[70],q[6];
u1(0) q[6];
u1(0) q[70];
cx q[70],q[7];
u1(0) q[7];
cx q[70],q[7];
u1(0) q[7];
u1(0) q[70];
cx q[70],q[8];
u1(0) q[8];
cx q[70],q[8];
u1(0) q[8];
u1(0) q[70];
cx q[70],q[9];
u1(0) q[9];
cx q[70],q[9];
u1(0) q[9];
u1(0) q[70];
cx q[70],q[10];
u1(0) q[10];
cx q[70],q[10];
u1(0) q[10];
u1(0) q[70];
cx q[70],q[11];
u1(0) q[11];
cx q[70],q[11];
u1(0) q[11];
u1(0) q[70];
cx q[70],q[12];
u1(0) q[12];
cx q[70],q[12];
u1(0) q[12];
u1(0) q[70];
cx q[70],q[13];
u1(0) q[13];
cx q[70],q[13];
u1(0) q[13];
u1(0) q[70];
cx q[70],q[14];
u1(0) q[14];
cx q[70],q[14];
u1(0) q[14];
u1(0) q[70];
cx q[70],q[15];
u1(0) q[15];
cx q[70],q[15];
u1(0) q[15];
u1(0) q[70];
cx q[70],q[16];
u1(0) q[16];
cx q[70],q[16];
u1(0) q[16];
u1(0) q[70];
cx q[70],q[17];
u1(0) q[17];
cx q[70],q[17];
u1(0) q[17];
u1(0) q[70];
cx q[70],q[18];
u1(0) q[18];
cx q[70],q[18];
u1(0) q[18];
u1(0) q[70];
cx q[70],q[19];
u1(0) q[19];
cx q[70],q[19];
u1(0) q[19];
u1(0) q[70];
cx q[70],q[20];
u1(0) q[20];
cx q[70],q[20];
u1(0) q[20];
u1(0) q[70];
cx q[70],q[21];
u1(0) q[21];
cx q[70],q[21];
u1(0) q[21];
u1(0) q[70];
cx q[70],q[22];
u1(0) q[22];
cx q[70],q[22];
u1(0) q[22];
u1(pi/281474976710656) q[70];
cx q[70],q[23];
u1(-pi/281474976710656) q[23];
cx q[70],q[23];
u1(pi/281474976710656) q[23];
u1(pi/140737488355328) q[70];
cx q[70],q[24];
u1(-pi/140737488355328) q[24];
cx q[70],q[24];
u1(pi/140737488355328) q[24];
u1(pi/70368744177664) q[70];
cx q[70],q[25];
u1(-pi/70368744177664) q[25];
cx q[70],q[25];
u1(pi/70368744177664) q[25];
u1(pi/35184372088832) q[70];
cx q[70],q[26];
u1(-pi/35184372088832) q[26];
cx q[70],q[26];
u1(pi/35184372088832) q[26];
u1(pi/17592186044416) q[70];
cx q[70],q[27];
u1(-pi/17592186044416) q[27];
cx q[70],q[27];
u1(pi/17592186044416) q[27];
u1(pi/8796093022208) q[70];
cx q[70],q[28];
u1(-pi/8796093022208) q[28];
cx q[70],q[28];
u1(pi/8796093022208) q[28];
u1(pi/4398046511104) q[70];
cx q[70],q[29];
u1(-pi/4398046511104) q[29];
cx q[70],q[29];
u1(pi/4398046511104) q[29];
u1(pi/2199023255552) q[70];
cx q[70],q[30];
u1(-pi/2199023255552) q[30];
cx q[70],q[30];
u1(pi/2199023255552) q[30];
u1(pi/1099511627776) q[70];
cx q[70],q[31];
u1(-pi/1099511627776) q[31];
cx q[70],q[31];
u1(pi/1099511627776) q[31];
u1(pi/549755813888) q[70];
cx q[70],q[32];
u1(-pi/549755813888) q[32];
cx q[70],q[32];
u1(pi/549755813888) q[32];
u1(pi/274877906944) q[70];
cx q[70],q[33];
u1(-pi/274877906944) q[33];
cx q[70],q[33];
u1(pi/274877906944) q[33];
u1(pi/137438953472) q[70];
cx q[70],q[34];
u1(-pi/137438953472) q[34];
cx q[70],q[34];
u1(pi/137438953472) q[34];
u1(pi/68719476736) q[70];
cx q[70],q[35];
u1(-pi/68719476736) q[35];
cx q[70],q[35];
u1(pi/68719476736) q[35];
u1(pi/34359738368) q[70];
cx q[70],q[36];
u1(-pi/34359738368) q[36];
cx q[70],q[36];
u1(pi/34359738368) q[36];
u1(pi/17179869184) q[70];
cx q[70],q[37];
u1(-pi/17179869184) q[37];
cx q[70],q[37];
u1(pi/17179869184) q[37];
u1(pi/8589934592) q[70];
cx q[70],q[38];
u1(-pi/8589934592) q[38];
cx q[70],q[38];
u1(pi/8589934592) q[38];
u1(pi/4294967296) q[70];
cx q[70],q[39];
u1(-pi/4294967296) q[39];
cx q[70],q[39];
u1(pi/4294967296) q[39];
u1(pi/2147483648) q[70];
cx q[70],q[40];
u1(-pi/2147483648) q[40];
cx q[70],q[40];
u1(pi/2147483648) q[40];
u1(pi/1073741824) q[70];
cx q[70],q[41];
u1(-pi/1073741824) q[41];
cx q[70],q[41];
u1(pi/1073741824) q[41];
u1(pi/536870912) q[70];
cx q[70],q[42];
u1(-pi/536870912) q[42];
cx q[70],q[42];
u1(pi/536870912) q[42];
u1(pi/268435456) q[70];
cx q[70],q[43];
u1(-pi/268435456) q[43];
cx q[70],q[43];
u1(pi/268435456) q[43];
u1(pi/134217728) q[70];
cx q[70],q[44];
u1(-pi/134217728) q[44];
cx q[70],q[44];
u1(pi/134217728) q[44];
u1(pi/67108864) q[70];
cx q[70],q[45];
u1(-pi/67108864) q[45];
cx q[70],q[45];
u1(pi/67108864) q[45];
u1(pi/33554432) q[70];
cx q[70],q[46];
u1(-pi/33554432) q[46];
cx q[70],q[46];
u1(pi/33554432) q[46];
u1(pi/16777216) q[70];
cx q[70],q[47];
u1(-pi/16777216) q[47];
cx q[70],q[47];
u1(pi/16777216) q[47];
u1(pi/8388608) q[70];
cx q[70],q[48];
u1(-pi/8388608) q[48];
cx q[70],q[48];
u1(pi/8388608) q[48];
u1(pi/4194304) q[70];
cx q[70],q[49];
u1(-pi/4194304) q[49];
cx q[70],q[49];
u1(pi/4194304) q[49];
u1(pi/2097152) q[70];
cx q[70],q[50];
u1(-pi/2097152) q[50];
cx q[70],q[50];
u1(pi/2097152) q[50];
u1(pi/1048576) q[70];
cx q[70],q[51];
u1(-pi/1048576) q[51];
cx q[70],q[51];
u1(pi/1048576) q[51];
u1(pi/524288) q[70];
cx q[70],q[52];
u1(-pi/524288) q[52];
cx q[70],q[52];
u1(pi/524288) q[52];
u1(pi/262144) q[70];
cx q[70],q[53];
u1(-pi/262144) q[53];
cx q[70],q[53];
u1(pi/262144) q[53];
u1(pi/131072) q[70];
cx q[70],q[54];
u1(-pi/131072) q[54];
cx q[70],q[54];
u1(pi/131072) q[54];
u1(pi/65536) q[70];
cx q[70],q[55];
u1(-pi/65536) q[55];
cx q[70],q[55];
u1(pi/65536) q[55];
u1(pi/32768) q[70];
cx q[70],q[56];
u1(-pi/32768) q[56];
cx q[70],q[56];
u1(pi/32768) q[56];
u1(pi/16384) q[70];
cx q[70],q[57];
u1(-pi/16384) q[57];
cx q[70],q[57];
u1(pi/16384) q[57];
u1(pi/8192) q[70];
cx q[70],q[58];
u1(-pi/8192) q[58];
cx q[70],q[58];
u1(pi/8192) q[58];
u1(pi/4096) q[70];
cx q[70],q[59];
u1(-pi/4096) q[59];
cx q[70],q[59];
u1(pi/4096) q[59];
u1(pi/2048) q[70];
cx q[70],q[60];
u1(-pi/2048) q[60];
cx q[70],q[60];
u1(pi/2048) q[60];
u1(pi/1024) q[70];
cx q[70],q[61];
u1(-pi/1024) q[61];
cx q[70],q[61];
u1(pi/1024) q[61];
u1(pi/512) q[70];
cx q[70],q[62];
u1(-pi/512) q[62];
cx q[70],q[62];
u1(pi/512) q[62];
u1(pi/256) q[70];
cx q[70],q[63];
u1(-pi/256) q[63];
cx q[70],q[63];
u1(pi/256) q[63];
u1(pi/128) q[70];
cx q[70],q[64];
u1(-pi/128) q[64];
cx q[70],q[64];
u1(pi/128) q[64];
u1(pi/64) q[70];
cx q[70],q[65];
u1(-pi/64) q[65];
cx q[70],q[65];
u1(pi/64) q[65];
u1(pi/32) q[70];
cx q[70],q[66];
u1(-pi/32) q[66];
cx q[70],q[66];
u1(pi/32) q[66];
u1(pi/16) q[70];
cx q[70],q[67];
u1(-pi/16) q[67];
cx q[70],q[67];
u1(pi/16) q[67];
u1(pi/8) q[70];
cx q[70],q[68];
u1(-pi/8) q[68];
cx q[70],q[68];
u1(pi/8) q[68];
u1(pi/4) q[70];
cx q[70],q[69];
u1(-pi/4) q[69];
cx q[70],q[69];
u1(pi/4) q[69];
h q[70];
u1(0) q[71];
cx q[71],q[0];
u1(0) q[0];
cx q[71],q[0];
u1(0) q[0];
u1(0) q[71];
cx q[71],q[1];
u1(0) q[1];
cx q[71],q[1];
u1(0) q[1];
u1(0) q[71];
cx q[71],q[2];
u1(0) q[2];
cx q[71],q[2];
u1(0) q[2];
u1(0) q[71];
cx q[71],q[3];
u1(0) q[3];
cx q[71],q[3];
u1(0) q[3];
u1(0) q[71];
cx q[71],q[4];
u1(0) q[4];
cx q[71],q[4];
u1(0) q[4];
u1(0) q[71];
cx q[71],q[5];
u1(0) q[5];
cx q[71],q[5];
u1(0) q[5];
u1(0) q[71];
cx q[71],q[6];
u1(0) q[6];
cx q[71],q[6];
u1(0) q[6];
u1(0) q[71];
cx q[71],q[7];
u1(0) q[7];
cx q[71],q[7];
u1(0) q[7];
u1(0) q[71];
cx q[71],q[8];
u1(0) q[8];
cx q[71],q[8];
u1(0) q[8];
u1(0) q[71];
cx q[71],q[9];
u1(0) q[9];
cx q[71],q[9];
u1(0) q[9];
u1(0) q[71];
cx q[71],q[10];
u1(0) q[10];
cx q[71],q[10];
u1(0) q[10];
u1(0) q[71];
cx q[71],q[11];
u1(0) q[11];
cx q[71],q[11];
u1(0) q[11];
u1(0) q[71];
cx q[71],q[12];
u1(0) q[12];
cx q[71],q[12];
u1(0) q[12];
u1(0) q[71];
cx q[71],q[13];
u1(0) q[13];
cx q[71],q[13];
u1(0) q[13];
u1(0) q[71];
cx q[71],q[14];
u1(0) q[14];
cx q[71],q[14];
u1(0) q[14];
u1(0) q[71];
cx q[71],q[15];
u1(0) q[15];
cx q[71],q[15];
u1(0) q[15];
u1(0) q[71];
cx q[71],q[16];
u1(0) q[16];
cx q[71],q[16];
u1(0) q[16];
u1(0) q[71];
cx q[71],q[17];
u1(0) q[17];
cx q[71],q[17];
u1(0) q[17];
u1(0) q[71];
cx q[71],q[18];
u1(0) q[18];
cx q[71],q[18];
u1(0) q[18];
u1(0) q[71];
cx q[71],q[19];
u1(0) q[19];
cx q[71],q[19];
u1(0) q[19];
u1(0) q[71];
cx q[71],q[20];
u1(0) q[20];
cx q[71],q[20];
u1(0) q[20];
u1(0) q[71];
cx q[71],q[21];
u1(0) q[21];
cx q[71],q[21];
u1(0) q[21];
u1(0) q[71];
cx q[71],q[22];
u1(0) q[22];
cx q[71],q[22];
u1(0) q[22];
u1(0) q[71];
cx q[71],q[23];
u1(0) q[23];
cx q[71],q[23];
u1(0) q[23];
u1(pi/281474976710656) q[71];
cx q[71],q[24];
u1(-pi/281474976710656) q[24];
cx q[71],q[24];
u1(pi/281474976710656) q[24];
u1(pi/140737488355328) q[71];
cx q[71],q[25];
u1(-pi/140737488355328) q[25];
cx q[71],q[25];
u1(pi/140737488355328) q[25];
u1(pi/70368744177664) q[71];
cx q[71],q[26];
u1(-pi/70368744177664) q[26];
cx q[71],q[26];
u1(pi/70368744177664) q[26];
u1(pi/35184372088832) q[71];
cx q[71],q[27];
u1(-pi/35184372088832) q[27];
cx q[71],q[27];
u1(pi/35184372088832) q[27];
u1(pi/17592186044416) q[71];
cx q[71],q[28];
u1(-pi/17592186044416) q[28];
cx q[71],q[28];
u1(pi/17592186044416) q[28];
u1(pi/8796093022208) q[71];
cx q[71],q[29];
u1(-pi/8796093022208) q[29];
cx q[71],q[29];
u1(pi/8796093022208) q[29];
u1(pi/4398046511104) q[71];
cx q[71],q[30];
u1(-pi/4398046511104) q[30];
cx q[71],q[30];
u1(pi/4398046511104) q[30];
u1(pi/2199023255552) q[71];
cx q[71],q[31];
u1(-pi/2199023255552) q[31];
cx q[71],q[31];
u1(pi/2199023255552) q[31];
u1(pi/1099511627776) q[71];
cx q[71],q[32];
u1(-pi/1099511627776) q[32];
cx q[71],q[32];
u1(pi/1099511627776) q[32];
u1(pi/549755813888) q[71];
cx q[71],q[33];
u1(-pi/549755813888) q[33];
cx q[71],q[33];
u1(pi/549755813888) q[33];
u1(pi/274877906944) q[71];
cx q[71],q[34];
u1(-pi/274877906944) q[34];
cx q[71],q[34];
u1(pi/274877906944) q[34];
u1(pi/137438953472) q[71];
cx q[71],q[35];
u1(-pi/137438953472) q[35];
cx q[71],q[35];
u1(pi/137438953472) q[35];
u1(pi/68719476736) q[71];
cx q[71],q[36];
u1(-pi/68719476736) q[36];
cx q[71],q[36];
u1(pi/68719476736) q[36];
u1(pi/34359738368) q[71];
cx q[71],q[37];
u1(-pi/34359738368) q[37];
cx q[71],q[37];
u1(pi/34359738368) q[37];
u1(pi/17179869184) q[71];
cx q[71],q[38];
u1(-pi/17179869184) q[38];
cx q[71],q[38];
u1(pi/17179869184) q[38];
u1(pi/8589934592) q[71];
cx q[71],q[39];
u1(-pi/8589934592) q[39];
cx q[71],q[39];
u1(pi/8589934592) q[39];
u1(pi/4294967296) q[71];
cx q[71],q[40];
u1(-pi/4294967296) q[40];
cx q[71],q[40];
u1(pi/4294967296) q[40];
u1(pi/2147483648) q[71];
cx q[71],q[41];
u1(-pi/2147483648) q[41];
cx q[71],q[41];
u1(pi/2147483648) q[41];
u1(pi/1073741824) q[71];
cx q[71],q[42];
u1(-pi/1073741824) q[42];
cx q[71],q[42];
u1(pi/1073741824) q[42];
u1(pi/536870912) q[71];
cx q[71],q[43];
u1(-pi/536870912) q[43];
cx q[71],q[43];
u1(pi/536870912) q[43];
u1(pi/268435456) q[71];
cx q[71],q[44];
u1(-pi/268435456) q[44];
cx q[71],q[44];
u1(pi/268435456) q[44];
u1(pi/134217728) q[71];
cx q[71],q[45];
u1(-pi/134217728) q[45];
cx q[71],q[45];
u1(pi/134217728) q[45];
u1(pi/67108864) q[71];
cx q[71],q[46];
u1(-pi/67108864) q[46];
cx q[71],q[46];
u1(pi/67108864) q[46];
u1(pi/33554432) q[71];
cx q[71],q[47];
u1(-pi/33554432) q[47];
cx q[71],q[47];
u1(pi/33554432) q[47];
u1(pi/16777216) q[71];
cx q[71],q[48];
u1(-pi/16777216) q[48];
cx q[71],q[48];
u1(pi/16777216) q[48];
u1(pi/8388608) q[71];
cx q[71],q[49];
u1(-pi/8388608) q[49];
cx q[71],q[49];
u1(pi/8388608) q[49];
u1(pi/4194304) q[71];
cx q[71],q[50];
u1(-pi/4194304) q[50];
cx q[71],q[50];
u1(pi/4194304) q[50];
u1(pi/2097152) q[71];
cx q[71],q[51];
u1(-pi/2097152) q[51];
cx q[71],q[51];
u1(pi/2097152) q[51];
u1(pi/1048576) q[71];
cx q[71],q[52];
u1(-pi/1048576) q[52];
cx q[71],q[52];
u1(pi/1048576) q[52];
u1(pi/524288) q[71];
cx q[71],q[53];
u1(-pi/524288) q[53];
cx q[71],q[53];
u1(pi/524288) q[53];
u1(pi/262144) q[71];
cx q[71],q[54];
u1(-pi/262144) q[54];
cx q[71],q[54];
u1(pi/262144) q[54];
u1(pi/131072) q[71];
cx q[71],q[55];
u1(-pi/131072) q[55];
cx q[71],q[55];
u1(pi/131072) q[55];
u1(pi/65536) q[71];
cx q[71],q[56];
u1(-pi/65536) q[56];
cx q[71],q[56];
u1(pi/65536) q[56];
u1(pi/32768) q[71];
cx q[71],q[57];
u1(-pi/32768) q[57];
cx q[71],q[57];
u1(pi/32768) q[57];
u1(pi/16384) q[71];
cx q[71],q[58];
u1(-pi/16384) q[58];
cx q[71],q[58];
u1(pi/16384) q[58];
u1(pi/8192) q[71];
cx q[71],q[59];
u1(-pi/8192) q[59];
cx q[71],q[59];
u1(pi/8192) q[59];
u1(pi/4096) q[71];
cx q[71],q[60];
u1(-pi/4096) q[60];
cx q[71],q[60];
u1(pi/4096) q[60];
u1(pi/2048) q[71];
cx q[71],q[61];
u1(-pi/2048) q[61];
cx q[71],q[61];
u1(pi/2048) q[61];
u1(pi/1024) q[71];
cx q[71],q[62];
u1(-pi/1024) q[62];
cx q[71],q[62];
u1(pi/1024) q[62];
u1(pi/512) q[71];
cx q[71],q[63];
u1(-pi/512) q[63];
cx q[71],q[63];
u1(pi/512) q[63];
u1(pi/256) q[71];
cx q[71],q[64];
u1(-pi/256) q[64];
cx q[71],q[64];
u1(pi/256) q[64];
u1(pi/128) q[71];
cx q[71],q[65];
u1(-pi/128) q[65];
cx q[71],q[65];
u1(pi/128) q[65];
u1(pi/64) q[71];
cx q[71],q[66];
u1(-pi/64) q[66];
cx q[71],q[66];
u1(pi/64) q[66];
u1(pi/32) q[71];
cx q[71],q[67];
u1(-pi/32) q[67];
cx q[71],q[67];
u1(pi/32) q[67];
u1(pi/16) q[71];
cx q[71],q[68];
u1(-pi/16) q[68];
cx q[71],q[68];
u1(pi/16) q[68];
u1(pi/8) q[71];
cx q[71],q[69];
u1(-pi/8) q[69];
cx q[71],q[69];
u1(pi/8) q[69];
u1(pi/4) q[71];
cx q[71],q[70];
u1(-pi/4) q[70];
cx q[71],q[70];
u1(pi/4) q[70];
h q[71];
u1(0) q[72];
cx q[72],q[0];
u1(0) q[0];
cx q[72],q[0];
u1(0) q[0];
u1(0) q[72];
cx q[72],q[1];
u1(0) q[1];
cx q[72],q[1];
u1(0) q[1];
u1(0) q[72];
cx q[72],q[2];
u1(0) q[2];
cx q[72],q[2];
u1(0) q[2];
u1(0) q[72];
cx q[72],q[3];
u1(0) q[3];
cx q[72],q[3];
u1(0) q[3];
u1(0) q[72];
cx q[72],q[4];
u1(0) q[4];
cx q[72],q[4];
u1(0) q[4];
u1(0) q[72];
cx q[72],q[5];
u1(0) q[5];
cx q[72],q[5];
u1(0) q[5];
u1(0) q[72];
cx q[72],q[6];
u1(0) q[6];
cx q[72],q[6];
u1(0) q[6];
u1(0) q[72];
cx q[72],q[7];
u1(0) q[7];
cx q[72],q[7];
u1(0) q[7];
u1(0) q[72];
cx q[72],q[8];
u1(0) q[8];
cx q[72],q[8];
u1(0) q[8];
u1(0) q[72];
cx q[72],q[9];
u1(0) q[9];
cx q[72],q[9];
u1(0) q[9];
u1(0) q[72];
cx q[72],q[10];
u1(0) q[10];
cx q[72],q[10];
u1(0) q[10];
u1(0) q[72];
cx q[72],q[11];
u1(0) q[11];
cx q[72],q[11];
u1(0) q[11];
u1(0) q[72];
cx q[72],q[12];
u1(0) q[12];
cx q[72],q[12];
u1(0) q[12];
u1(0) q[72];
cx q[72],q[13];
u1(0) q[13];
cx q[72],q[13];
u1(0) q[13];
u1(0) q[72];
cx q[72],q[14];
u1(0) q[14];
cx q[72],q[14];
u1(0) q[14];
u1(0) q[72];
cx q[72],q[15];
u1(0) q[15];
cx q[72],q[15];
u1(0) q[15];
u1(0) q[72];
cx q[72],q[16];
u1(0) q[16];
cx q[72],q[16];
u1(0) q[16];
u1(0) q[72];
cx q[72],q[17];
u1(0) q[17];
cx q[72],q[17];
u1(0) q[17];
u1(0) q[72];
cx q[72],q[18];
u1(0) q[18];
cx q[72],q[18];
u1(0) q[18];
u1(0) q[72];
cx q[72],q[19];
u1(0) q[19];
cx q[72],q[19];
u1(0) q[19];
u1(0) q[72];
cx q[72],q[20];
u1(0) q[20];
cx q[72],q[20];
u1(0) q[20];
u1(0) q[72];
cx q[72],q[21];
u1(0) q[21];
cx q[72],q[21];
u1(0) q[21];
u1(0) q[72];
cx q[72],q[22];
u1(0) q[22];
cx q[72],q[22];
u1(0) q[22];
u1(0) q[72];
cx q[72],q[23];
u1(0) q[23];
cx q[72],q[23];
u1(0) q[23];
u1(0) q[72];
cx q[72],q[24];
u1(0) q[24];
cx q[72],q[24];
u1(0) q[24];
u1(pi/281474976710656) q[72];
cx q[72],q[25];
u1(-pi/281474976710656) q[25];
cx q[72],q[25];
u1(pi/281474976710656) q[25];
u1(pi/140737488355328) q[72];
cx q[72],q[26];
u1(-pi/140737488355328) q[26];
cx q[72],q[26];
u1(pi/140737488355328) q[26];
u1(pi/70368744177664) q[72];
cx q[72],q[27];
u1(-pi/70368744177664) q[27];
cx q[72],q[27];
u1(pi/70368744177664) q[27];
u1(pi/35184372088832) q[72];
cx q[72],q[28];
u1(-pi/35184372088832) q[28];
cx q[72],q[28];
u1(pi/35184372088832) q[28];
u1(pi/17592186044416) q[72];
cx q[72],q[29];
u1(-pi/17592186044416) q[29];
cx q[72],q[29];
u1(pi/17592186044416) q[29];
u1(pi/8796093022208) q[72];
cx q[72],q[30];
u1(-pi/8796093022208) q[30];
cx q[72],q[30];
u1(pi/8796093022208) q[30];
u1(pi/4398046511104) q[72];
cx q[72],q[31];
u1(-pi/4398046511104) q[31];
cx q[72],q[31];
u1(pi/4398046511104) q[31];
u1(pi/2199023255552) q[72];
cx q[72],q[32];
u1(-pi/2199023255552) q[32];
cx q[72],q[32];
u1(pi/2199023255552) q[32];
u1(pi/1099511627776) q[72];
cx q[72],q[33];
u1(-pi/1099511627776) q[33];
cx q[72],q[33];
u1(pi/1099511627776) q[33];
u1(pi/549755813888) q[72];
cx q[72],q[34];
u1(-pi/549755813888) q[34];
cx q[72],q[34];
u1(pi/549755813888) q[34];
u1(pi/274877906944) q[72];
cx q[72],q[35];
u1(-pi/274877906944) q[35];
cx q[72],q[35];
u1(pi/274877906944) q[35];
u1(pi/137438953472) q[72];
cx q[72],q[36];
u1(-pi/137438953472) q[36];
cx q[72],q[36];
u1(pi/137438953472) q[36];
u1(pi/68719476736) q[72];
cx q[72],q[37];
u1(-pi/68719476736) q[37];
cx q[72],q[37];
u1(pi/68719476736) q[37];
u1(pi/34359738368) q[72];
cx q[72],q[38];
u1(-pi/34359738368) q[38];
cx q[72],q[38];
u1(pi/34359738368) q[38];
u1(pi/17179869184) q[72];
cx q[72],q[39];
u1(-pi/17179869184) q[39];
cx q[72],q[39];
u1(pi/17179869184) q[39];
u1(pi/8589934592) q[72];
cx q[72],q[40];
u1(-pi/8589934592) q[40];
cx q[72],q[40];
u1(pi/8589934592) q[40];
u1(pi/4294967296) q[72];
cx q[72],q[41];
u1(-pi/4294967296) q[41];
cx q[72],q[41];
u1(pi/4294967296) q[41];
u1(pi/2147483648) q[72];
cx q[72],q[42];
u1(-pi/2147483648) q[42];
cx q[72],q[42];
u1(pi/2147483648) q[42];
u1(pi/1073741824) q[72];
cx q[72],q[43];
u1(-pi/1073741824) q[43];
cx q[72],q[43];
u1(pi/1073741824) q[43];
u1(pi/536870912) q[72];
cx q[72],q[44];
u1(-pi/536870912) q[44];
cx q[72],q[44];
u1(pi/536870912) q[44];
u1(pi/268435456) q[72];
cx q[72],q[45];
u1(-pi/268435456) q[45];
cx q[72],q[45];
u1(pi/268435456) q[45];
u1(pi/134217728) q[72];
cx q[72],q[46];
u1(-pi/134217728) q[46];
cx q[72],q[46];
u1(pi/134217728) q[46];
u1(pi/67108864) q[72];
cx q[72],q[47];
u1(-pi/67108864) q[47];
cx q[72],q[47];
u1(pi/67108864) q[47];
u1(pi/33554432) q[72];
cx q[72],q[48];
u1(-pi/33554432) q[48];
cx q[72],q[48];
u1(pi/33554432) q[48];
u1(pi/16777216) q[72];
cx q[72],q[49];
u1(-pi/16777216) q[49];
cx q[72],q[49];
u1(pi/16777216) q[49];
u1(pi/8388608) q[72];
cx q[72],q[50];
u1(-pi/8388608) q[50];
cx q[72],q[50];
u1(pi/8388608) q[50];
u1(pi/4194304) q[72];
cx q[72],q[51];
u1(-pi/4194304) q[51];
cx q[72],q[51];
u1(pi/4194304) q[51];
u1(pi/2097152) q[72];
cx q[72],q[52];
u1(-pi/2097152) q[52];
cx q[72],q[52];
u1(pi/2097152) q[52];
u1(pi/1048576) q[72];
cx q[72],q[53];
u1(-pi/1048576) q[53];
cx q[72],q[53];
u1(pi/1048576) q[53];
u1(pi/524288) q[72];
cx q[72],q[54];
u1(-pi/524288) q[54];
cx q[72],q[54];
u1(pi/524288) q[54];
u1(pi/262144) q[72];
cx q[72],q[55];
u1(-pi/262144) q[55];
cx q[72],q[55];
u1(pi/262144) q[55];
u1(pi/131072) q[72];
cx q[72],q[56];
u1(-pi/131072) q[56];
cx q[72],q[56];
u1(pi/131072) q[56];
u1(pi/65536) q[72];
cx q[72],q[57];
u1(-pi/65536) q[57];
cx q[72],q[57];
u1(pi/65536) q[57];
u1(pi/32768) q[72];
cx q[72],q[58];
u1(-pi/32768) q[58];
cx q[72],q[58];
u1(pi/32768) q[58];
u1(pi/16384) q[72];
cx q[72],q[59];
u1(-pi/16384) q[59];
cx q[72],q[59];
u1(pi/16384) q[59];
u1(pi/8192) q[72];
cx q[72],q[60];
u1(-pi/8192) q[60];
cx q[72],q[60];
u1(pi/8192) q[60];
u1(pi/4096) q[72];
cx q[72],q[61];
u1(-pi/4096) q[61];
cx q[72],q[61];
u1(pi/4096) q[61];
u1(pi/2048) q[72];
cx q[72],q[62];
u1(-pi/2048) q[62];
cx q[72],q[62];
u1(pi/2048) q[62];
u1(pi/1024) q[72];
cx q[72],q[63];
u1(-pi/1024) q[63];
cx q[72],q[63];
u1(pi/1024) q[63];
u1(pi/512) q[72];
cx q[72],q[64];
u1(-pi/512) q[64];
cx q[72],q[64];
u1(pi/512) q[64];
u1(pi/256) q[72];
cx q[72],q[65];
u1(-pi/256) q[65];
cx q[72],q[65];
u1(pi/256) q[65];
u1(pi/128) q[72];
cx q[72],q[66];
u1(-pi/128) q[66];
cx q[72],q[66];
u1(pi/128) q[66];
u1(pi/64) q[72];
cx q[72],q[67];
u1(-pi/64) q[67];
cx q[72],q[67];
u1(pi/64) q[67];
u1(pi/32) q[72];
cx q[72],q[68];
u1(-pi/32) q[68];
cx q[72],q[68];
u1(pi/32) q[68];
u1(pi/16) q[72];
cx q[72],q[69];
u1(-pi/16) q[69];
cx q[72],q[69];
u1(pi/16) q[69];
u1(pi/8) q[72];
cx q[72],q[70];
u1(-pi/8) q[70];
cx q[72],q[70];
u1(pi/8) q[70];
u1(pi/4) q[72];
cx q[72],q[71];
u1(-pi/4) q[71];
cx q[72],q[71];
u1(pi/4) q[71];
h q[72];
u1(0) q[73];
cx q[73],q[0];
u1(0) q[0];
cx q[73],q[0];
u1(0) q[0];
u1(0) q[73];
cx q[73],q[1];
u1(0) q[1];
cx q[73],q[1];
u1(0) q[1];
u1(0) q[73];
cx q[73],q[2];
u1(0) q[2];
cx q[73],q[2];
u1(0) q[2];
u1(0) q[73];
cx q[73],q[3];
u1(0) q[3];
cx q[73],q[3];
u1(0) q[3];
u1(0) q[73];
cx q[73],q[4];
u1(0) q[4];
cx q[73],q[4];
u1(0) q[4];
u1(0) q[73];
cx q[73],q[5];
u1(0) q[5];
cx q[73],q[5];
u1(0) q[5];
u1(0) q[73];
cx q[73],q[6];
u1(0) q[6];
cx q[73],q[6];
u1(0) q[6];
u1(0) q[73];
cx q[73],q[7];
u1(0) q[7];
cx q[73],q[7];
u1(0) q[7];
u1(0) q[73];
cx q[73],q[8];
u1(0) q[8];
cx q[73],q[8];
u1(0) q[8];
u1(0) q[73];
cx q[73],q[9];
u1(0) q[9];
cx q[73],q[9];
u1(0) q[9];
u1(0) q[73];
cx q[73],q[10];
u1(0) q[10];
cx q[73],q[10];
u1(0) q[10];
u1(0) q[73];
cx q[73],q[11];
u1(0) q[11];
cx q[73],q[11];
u1(0) q[11];
u1(0) q[73];
cx q[73],q[12];
u1(0) q[12];
cx q[73],q[12];
u1(0) q[12];
u1(0) q[73];
cx q[73],q[13];
u1(0) q[13];
cx q[73],q[13];
u1(0) q[13];
u1(0) q[73];
cx q[73],q[14];
u1(0) q[14];
cx q[73],q[14];
u1(0) q[14];
u1(0) q[73];
cx q[73],q[15];
u1(0) q[15];
cx q[73],q[15];
u1(0) q[15];
u1(0) q[73];
cx q[73],q[16];
u1(0) q[16];
cx q[73],q[16];
u1(0) q[16];
u1(0) q[73];
cx q[73],q[17];
u1(0) q[17];
cx q[73],q[17];
u1(0) q[17];
u1(0) q[73];
cx q[73],q[18];
u1(0) q[18];
cx q[73],q[18];
u1(0) q[18];
u1(0) q[73];
cx q[73],q[19];
u1(0) q[19];
cx q[73],q[19];
u1(0) q[19];
u1(0) q[73];
cx q[73],q[20];
u1(0) q[20];
cx q[73],q[20];
u1(0) q[20];
u1(0) q[73];
cx q[73],q[21];
u1(0) q[21];
cx q[73],q[21];
u1(0) q[21];
u1(0) q[73];
cx q[73],q[22];
u1(0) q[22];
cx q[73],q[22];
u1(0) q[22];
u1(0) q[73];
cx q[73],q[23];
u1(0) q[23];
cx q[73],q[23];
u1(0) q[23];
u1(0) q[73];
cx q[73],q[24];
u1(0) q[24];
cx q[73],q[24];
u1(0) q[24];
u1(0) q[73];
cx q[73],q[25];
u1(0) q[25];
cx q[73],q[25];
u1(0) q[25];
u1(pi/281474976710656) q[73];
cx q[73],q[26];
u1(-pi/281474976710656) q[26];
cx q[73],q[26];
u1(pi/281474976710656) q[26];
u1(pi/140737488355328) q[73];
cx q[73],q[27];
u1(-pi/140737488355328) q[27];
cx q[73],q[27];
u1(pi/140737488355328) q[27];
u1(pi/70368744177664) q[73];
cx q[73],q[28];
u1(-pi/70368744177664) q[28];
cx q[73],q[28];
u1(pi/70368744177664) q[28];
u1(pi/35184372088832) q[73];
cx q[73],q[29];
u1(-pi/35184372088832) q[29];
cx q[73],q[29];
u1(pi/35184372088832) q[29];
u1(pi/17592186044416) q[73];
cx q[73],q[30];
u1(-pi/17592186044416) q[30];
cx q[73],q[30];
u1(pi/17592186044416) q[30];
u1(pi/8796093022208) q[73];
cx q[73],q[31];
u1(-pi/8796093022208) q[31];
cx q[73],q[31];
u1(pi/8796093022208) q[31];
u1(pi/4398046511104) q[73];
cx q[73],q[32];
u1(-pi/4398046511104) q[32];
cx q[73],q[32];
u1(pi/4398046511104) q[32];
u1(pi/2199023255552) q[73];
cx q[73],q[33];
u1(-pi/2199023255552) q[33];
cx q[73],q[33];
u1(pi/2199023255552) q[33];
u1(pi/1099511627776) q[73];
cx q[73],q[34];
u1(-pi/1099511627776) q[34];
cx q[73],q[34];
u1(pi/1099511627776) q[34];
u1(pi/549755813888) q[73];
cx q[73],q[35];
u1(-pi/549755813888) q[35];
cx q[73],q[35];
u1(pi/549755813888) q[35];
u1(pi/274877906944) q[73];
cx q[73],q[36];
u1(-pi/274877906944) q[36];
cx q[73],q[36];
u1(pi/274877906944) q[36];
u1(pi/137438953472) q[73];
cx q[73],q[37];
u1(-pi/137438953472) q[37];
cx q[73],q[37];
u1(pi/137438953472) q[37];
u1(pi/68719476736) q[73];
cx q[73],q[38];
u1(-pi/68719476736) q[38];
cx q[73],q[38];
u1(pi/68719476736) q[38];
u1(pi/34359738368) q[73];
cx q[73],q[39];
u1(-pi/34359738368) q[39];
cx q[73],q[39];
u1(pi/34359738368) q[39];
u1(pi/17179869184) q[73];
cx q[73],q[40];
u1(-pi/17179869184) q[40];
cx q[73],q[40];
u1(pi/17179869184) q[40];
u1(pi/8589934592) q[73];
cx q[73],q[41];
u1(-pi/8589934592) q[41];
cx q[73],q[41];
u1(pi/8589934592) q[41];
u1(pi/4294967296) q[73];
cx q[73],q[42];
u1(-pi/4294967296) q[42];
cx q[73],q[42];
u1(pi/4294967296) q[42];
u1(pi/2147483648) q[73];
cx q[73],q[43];
u1(-pi/2147483648) q[43];
cx q[73],q[43];
u1(pi/2147483648) q[43];
u1(pi/1073741824) q[73];
cx q[73],q[44];
u1(-pi/1073741824) q[44];
cx q[73],q[44];
u1(pi/1073741824) q[44];
u1(pi/536870912) q[73];
cx q[73],q[45];
u1(-pi/536870912) q[45];
cx q[73],q[45];
u1(pi/536870912) q[45];
u1(pi/268435456) q[73];
cx q[73],q[46];
u1(-pi/268435456) q[46];
cx q[73],q[46];
u1(pi/268435456) q[46];
u1(pi/134217728) q[73];
cx q[73],q[47];
u1(-pi/134217728) q[47];
cx q[73],q[47];
u1(pi/134217728) q[47];
u1(pi/67108864) q[73];
cx q[73],q[48];
u1(-pi/67108864) q[48];
cx q[73],q[48];
u1(pi/67108864) q[48];
u1(pi/33554432) q[73];
cx q[73],q[49];
u1(-pi/33554432) q[49];
cx q[73],q[49];
u1(pi/33554432) q[49];
u1(pi/16777216) q[73];
cx q[73],q[50];
u1(-pi/16777216) q[50];
cx q[73],q[50];
u1(pi/16777216) q[50];
u1(pi/8388608) q[73];
cx q[73],q[51];
u1(-pi/8388608) q[51];
cx q[73],q[51];
u1(pi/8388608) q[51];
u1(pi/4194304) q[73];
cx q[73],q[52];
u1(-pi/4194304) q[52];
cx q[73],q[52];
u1(pi/4194304) q[52];
u1(pi/2097152) q[73];
cx q[73],q[53];
u1(-pi/2097152) q[53];
cx q[73],q[53];
u1(pi/2097152) q[53];
u1(pi/1048576) q[73];
cx q[73],q[54];
u1(-pi/1048576) q[54];
cx q[73],q[54];
u1(pi/1048576) q[54];
u1(pi/524288) q[73];
cx q[73],q[55];
u1(-pi/524288) q[55];
cx q[73],q[55];
u1(pi/524288) q[55];
u1(pi/262144) q[73];
cx q[73],q[56];
u1(-pi/262144) q[56];
cx q[73],q[56];
u1(pi/262144) q[56];
u1(pi/131072) q[73];
cx q[73],q[57];
u1(-pi/131072) q[57];
cx q[73],q[57];
u1(pi/131072) q[57];
u1(pi/65536) q[73];
cx q[73],q[58];
u1(-pi/65536) q[58];
cx q[73],q[58];
u1(pi/65536) q[58];
u1(pi/32768) q[73];
cx q[73],q[59];
u1(-pi/32768) q[59];
cx q[73],q[59];
u1(pi/32768) q[59];
u1(pi/16384) q[73];
cx q[73],q[60];
u1(-pi/16384) q[60];
cx q[73],q[60];
u1(pi/16384) q[60];
u1(pi/8192) q[73];
cx q[73],q[61];
u1(-pi/8192) q[61];
cx q[73],q[61];
u1(pi/8192) q[61];
u1(pi/4096) q[73];
cx q[73],q[62];
u1(-pi/4096) q[62];
cx q[73],q[62];
u1(pi/4096) q[62];
u1(pi/2048) q[73];
cx q[73],q[63];
u1(-pi/2048) q[63];
cx q[73],q[63];
u1(pi/2048) q[63];
u1(pi/1024) q[73];
cx q[73],q[64];
u1(-pi/1024) q[64];
cx q[73],q[64];
u1(pi/1024) q[64];
u1(pi/512) q[73];
cx q[73],q[65];
u1(-pi/512) q[65];
cx q[73],q[65];
u1(pi/512) q[65];
u1(pi/256) q[73];
cx q[73],q[66];
u1(-pi/256) q[66];
cx q[73],q[66];
u1(pi/256) q[66];
u1(pi/128) q[73];
cx q[73],q[67];
u1(-pi/128) q[67];
cx q[73],q[67];
u1(pi/128) q[67];
u1(pi/64) q[73];
cx q[73],q[68];
u1(-pi/64) q[68];
cx q[73],q[68];
u1(pi/64) q[68];
u1(pi/32) q[73];
cx q[73],q[69];
u1(-pi/32) q[69];
cx q[73],q[69];
u1(pi/32) q[69];
u1(pi/16) q[73];
cx q[73],q[70];
u1(-pi/16) q[70];
cx q[73],q[70];
u1(pi/16) q[70];
u1(pi/8) q[73];
cx q[73],q[71];
u1(-pi/8) q[71];
cx q[73],q[71];
u1(pi/8) q[71];
u1(pi/4) q[73];
cx q[73],q[72];
u1(-pi/4) q[72];
cx q[73],q[72];
u1(pi/4) q[72];
h q[73];
u1(0) q[74];
cx q[74],q[0];
u1(0) q[0];
cx q[74],q[0];
u1(0) q[0];
u1(0) q[74];
cx q[74],q[1];
u1(0) q[1];
cx q[74],q[1];
u1(0) q[1];
u1(0) q[74];
cx q[74],q[2];
u1(0) q[2];
cx q[74],q[2];
u1(0) q[2];
u1(0) q[74];
cx q[74],q[3];
u1(0) q[3];
cx q[74],q[3];
u1(0) q[3];
u1(0) q[74];
cx q[74],q[4];
u1(0) q[4];
cx q[74],q[4];
u1(0) q[4];
u1(0) q[74];
cx q[74],q[5];
u1(0) q[5];
cx q[74],q[5];
u1(0) q[5];
u1(0) q[74];
cx q[74],q[6];
u1(0) q[6];
cx q[74],q[6];
u1(0) q[6];
u1(0) q[74];
cx q[74],q[7];
u1(0) q[7];
cx q[74],q[7];
u1(0) q[7];
u1(0) q[74];
cx q[74],q[8];
u1(0) q[8];
cx q[74],q[8];
u1(0) q[8];
u1(0) q[74];
cx q[74],q[9];
u1(0) q[9];
cx q[74],q[9];
u1(0) q[9];
u1(0) q[74];
cx q[74],q[10];
u1(0) q[10];
cx q[74],q[10];
u1(0) q[10];
u1(0) q[74];
cx q[74],q[11];
u1(0) q[11];
cx q[74],q[11];
u1(0) q[11];
u1(0) q[74];
cx q[74],q[12];
u1(0) q[12];
cx q[74],q[12];
u1(0) q[12];
u1(0) q[74];
cx q[74],q[13];
u1(0) q[13];
cx q[74],q[13];
u1(0) q[13];
u1(0) q[74];
cx q[74],q[14];
u1(0) q[14];
cx q[74],q[14];
u1(0) q[14];
u1(0) q[74];
cx q[74],q[15];
u1(0) q[15];
cx q[74],q[15];
u1(0) q[15];
u1(0) q[74];
cx q[74],q[16];
u1(0) q[16];
cx q[74],q[16];
u1(0) q[16];
u1(0) q[74];
cx q[74],q[17];
u1(0) q[17];
cx q[74],q[17];
u1(0) q[17];
u1(0) q[74];
cx q[74],q[18];
u1(0) q[18];
cx q[74],q[18];
u1(0) q[18];
u1(0) q[74];
cx q[74],q[19];
u1(0) q[19];
cx q[74],q[19];
u1(0) q[19];
u1(0) q[74];
cx q[74],q[20];
u1(0) q[20];
cx q[74],q[20];
u1(0) q[20];
u1(0) q[74];
cx q[74],q[21];
u1(0) q[21];
cx q[74],q[21];
u1(0) q[21];
u1(0) q[74];
cx q[74],q[22];
u1(0) q[22];
cx q[74],q[22];
u1(0) q[22];
u1(0) q[74];
cx q[74],q[23];
u1(0) q[23];
cx q[74],q[23];
u1(0) q[23];
u1(0) q[74];
cx q[74],q[24];
u1(0) q[24];
cx q[74],q[24];
u1(0) q[24];
u1(0) q[74];
cx q[74],q[25];
u1(0) q[25];
cx q[74],q[25];
u1(0) q[25];
u1(0) q[74];
cx q[74],q[26];
u1(0) q[26];
cx q[74],q[26];
u1(0) q[26];
u1(pi/281474976710656) q[74];
cx q[74],q[27];
u1(-pi/281474976710656) q[27];
cx q[74],q[27];
u1(pi/281474976710656) q[27];
u1(pi/140737488355328) q[74];
cx q[74],q[28];
u1(-pi/140737488355328) q[28];
cx q[74],q[28];
u1(pi/140737488355328) q[28];
u1(pi/70368744177664) q[74];
cx q[74],q[29];
u1(-pi/70368744177664) q[29];
cx q[74],q[29];
u1(pi/70368744177664) q[29];
u1(pi/35184372088832) q[74];
cx q[74],q[30];
u1(-pi/35184372088832) q[30];
cx q[74],q[30];
u1(pi/35184372088832) q[30];
u1(pi/17592186044416) q[74];
cx q[74],q[31];
u1(-pi/17592186044416) q[31];
cx q[74],q[31];
u1(pi/17592186044416) q[31];
u1(pi/8796093022208) q[74];
cx q[74],q[32];
u1(-pi/8796093022208) q[32];
cx q[74],q[32];
u1(pi/8796093022208) q[32];
u1(pi/4398046511104) q[74];
cx q[74],q[33];
u1(-pi/4398046511104) q[33];
cx q[74],q[33];
u1(pi/4398046511104) q[33];
u1(pi/2199023255552) q[74];
cx q[74],q[34];
u1(-pi/2199023255552) q[34];
cx q[74],q[34];
u1(pi/2199023255552) q[34];
u1(pi/1099511627776) q[74];
cx q[74],q[35];
u1(-pi/1099511627776) q[35];
cx q[74],q[35];
u1(pi/1099511627776) q[35];
u1(pi/549755813888) q[74];
cx q[74],q[36];
u1(-pi/549755813888) q[36];
cx q[74],q[36];
u1(pi/549755813888) q[36];
u1(pi/274877906944) q[74];
cx q[74],q[37];
u1(-pi/274877906944) q[37];
cx q[74],q[37];
u1(pi/274877906944) q[37];
u1(pi/137438953472) q[74];
cx q[74],q[38];
u1(-pi/137438953472) q[38];
cx q[74],q[38];
u1(pi/137438953472) q[38];
u1(pi/68719476736) q[74];
cx q[74],q[39];
u1(-pi/68719476736) q[39];
cx q[74],q[39];
u1(pi/68719476736) q[39];
u1(pi/34359738368) q[74];
cx q[74],q[40];
u1(-pi/34359738368) q[40];
cx q[74],q[40];
u1(pi/34359738368) q[40];
u1(pi/17179869184) q[74];
cx q[74],q[41];
u1(-pi/17179869184) q[41];
cx q[74],q[41];
u1(pi/17179869184) q[41];
u1(pi/8589934592) q[74];
cx q[74],q[42];
u1(-pi/8589934592) q[42];
cx q[74],q[42];
u1(pi/8589934592) q[42];
u1(pi/4294967296) q[74];
cx q[74],q[43];
u1(-pi/4294967296) q[43];
cx q[74],q[43];
u1(pi/4294967296) q[43];
u1(pi/2147483648) q[74];
cx q[74],q[44];
u1(-pi/2147483648) q[44];
cx q[74],q[44];
u1(pi/2147483648) q[44];
u1(pi/1073741824) q[74];
cx q[74],q[45];
u1(-pi/1073741824) q[45];
cx q[74],q[45];
u1(pi/1073741824) q[45];
u1(pi/536870912) q[74];
cx q[74],q[46];
u1(-pi/536870912) q[46];
cx q[74],q[46];
u1(pi/536870912) q[46];
u1(pi/268435456) q[74];
cx q[74],q[47];
u1(-pi/268435456) q[47];
cx q[74],q[47];
u1(pi/268435456) q[47];
u1(pi/134217728) q[74];
cx q[74],q[48];
u1(-pi/134217728) q[48];
cx q[74],q[48];
u1(pi/134217728) q[48];
u1(pi/67108864) q[74];
cx q[74],q[49];
u1(-pi/67108864) q[49];
cx q[74],q[49];
u1(pi/67108864) q[49];
u1(pi/33554432) q[74];
cx q[74],q[50];
u1(-pi/33554432) q[50];
cx q[74],q[50];
u1(pi/33554432) q[50];
u1(pi/16777216) q[74];
cx q[74],q[51];
u1(-pi/16777216) q[51];
cx q[74],q[51];
u1(pi/16777216) q[51];
u1(pi/8388608) q[74];
cx q[74],q[52];
u1(-pi/8388608) q[52];
cx q[74],q[52];
u1(pi/8388608) q[52];
u1(pi/4194304) q[74];
cx q[74],q[53];
u1(-pi/4194304) q[53];
cx q[74],q[53];
u1(pi/4194304) q[53];
u1(pi/2097152) q[74];
cx q[74],q[54];
u1(-pi/2097152) q[54];
cx q[74],q[54];
u1(pi/2097152) q[54];
u1(pi/1048576) q[74];
cx q[74],q[55];
u1(-pi/1048576) q[55];
cx q[74],q[55];
u1(pi/1048576) q[55];
u1(pi/524288) q[74];
cx q[74],q[56];
u1(-pi/524288) q[56];
cx q[74],q[56];
u1(pi/524288) q[56];
u1(pi/262144) q[74];
cx q[74],q[57];
u1(-pi/262144) q[57];
cx q[74],q[57];
u1(pi/262144) q[57];
u1(pi/131072) q[74];
cx q[74],q[58];
u1(-pi/131072) q[58];
cx q[74],q[58];
u1(pi/131072) q[58];
u1(pi/65536) q[74];
cx q[74],q[59];
u1(-pi/65536) q[59];
cx q[74],q[59];
u1(pi/65536) q[59];
u1(pi/32768) q[74];
cx q[74],q[60];
u1(-pi/32768) q[60];
cx q[74],q[60];
u1(pi/32768) q[60];
u1(pi/16384) q[74];
cx q[74],q[61];
u1(-pi/16384) q[61];
cx q[74],q[61];
u1(pi/16384) q[61];
u1(pi/8192) q[74];
cx q[74],q[62];
u1(-pi/8192) q[62];
cx q[74],q[62];
u1(pi/8192) q[62];
u1(pi/4096) q[74];
cx q[74],q[63];
u1(-pi/4096) q[63];
cx q[74],q[63];
u1(pi/4096) q[63];
u1(pi/2048) q[74];
cx q[74],q[64];
u1(-pi/2048) q[64];
cx q[74],q[64];
u1(pi/2048) q[64];
u1(pi/1024) q[74];
cx q[74],q[65];
u1(-pi/1024) q[65];
cx q[74],q[65];
u1(pi/1024) q[65];
u1(pi/512) q[74];
cx q[74],q[66];
u1(-pi/512) q[66];
cx q[74],q[66];
u1(pi/512) q[66];
u1(pi/256) q[74];
cx q[74],q[67];
u1(-pi/256) q[67];
cx q[74],q[67];
u1(pi/256) q[67];
u1(pi/128) q[74];
cx q[74],q[68];
u1(-pi/128) q[68];
cx q[74],q[68];
u1(pi/128) q[68];
u1(pi/64) q[74];
cx q[74],q[69];
u1(-pi/64) q[69];
cx q[74],q[69];
u1(pi/64) q[69];
u1(pi/32) q[74];
cx q[74],q[70];
u1(-pi/32) q[70];
cx q[74],q[70];
u1(pi/32) q[70];
u1(pi/16) q[74];
cx q[74],q[71];
u1(-pi/16) q[71];
cx q[74],q[71];
u1(pi/16) q[71];
u1(pi/8) q[74];
cx q[74],q[72];
u1(-pi/8) q[72];
cx q[74],q[72];
u1(pi/8) q[72];
u1(pi/4) q[74];
cx q[74],q[73];
u1(-pi/4) q[73];
cx q[74],q[73];
u1(pi/4) q[73];
h q[74];
u1(0) q[75];
cx q[75],q[0];
u1(0) q[0];
cx q[75],q[0];
u1(0) q[0];
u1(0) q[75];
cx q[75],q[1];
u1(0) q[1];
cx q[75],q[1];
u1(0) q[1];
u1(0) q[75];
cx q[75],q[2];
u1(0) q[2];
cx q[75],q[2];
u1(0) q[2];
u1(0) q[75];
cx q[75],q[3];
u1(0) q[3];
cx q[75],q[3];
u1(0) q[3];
u1(0) q[75];
cx q[75],q[4];
u1(0) q[4];
cx q[75],q[4];
u1(0) q[4];
u1(0) q[75];
cx q[75],q[5];
u1(0) q[5];
cx q[75],q[5];
u1(0) q[5];
u1(0) q[75];
cx q[75],q[6];
u1(0) q[6];
cx q[75],q[6];
u1(0) q[6];
u1(0) q[75];
cx q[75],q[7];
u1(0) q[7];
cx q[75],q[7];
u1(0) q[7];
u1(0) q[75];
cx q[75],q[8];
u1(0) q[8];
cx q[75],q[8];
u1(0) q[8];
u1(0) q[75];
cx q[75],q[9];
u1(0) q[9];
cx q[75],q[9];
u1(0) q[9];
u1(0) q[75];
cx q[75],q[10];
u1(0) q[10];
cx q[75],q[10];
u1(0) q[10];
u1(0) q[75];
cx q[75],q[11];
u1(0) q[11];
cx q[75],q[11];
u1(0) q[11];
u1(0) q[75];
cx q[75],q[12];
u1(0) q[12];
cx q[75],q[12];
u1(0) q[12];
u1(0) q[75];
cx q[75],q[13];
u1(0) q[13];
cx q[75],q[13];
u1(0) q[13];
u1(0) q[75];
cx q[75],q[14];
u1(0) q[14];
cx q[75],q[14];
u1(0) q[14];
u1(0) q[75];
cx q[75],q[15];
u1(0) q[15];
cx q[75],q[15];
u1(0) q[15];
u1(0) q[75];
cx q[75],q[16];
u1(0) q[16];
cx q[75],q[16];
u1(0) q[16];
u1(0) q[75];
cx q[75],q[17];
u1(0) q[17];
cx q[75],q[17];
u1(0) q[17];
u1(0) q[75];
cx q[75],q[18];
u1(0) q[18];
cx q[75],q[18];
u1(0) q[18];
u1(0) q[75];
cx q[75],q[19];
u1(0) q[19];
cx q[75],q[19];
u1(0) q[19];
u1(0) q[75];
cx q[75],q[20];
u1(0) q[20];
cx q[75],q[20];
u1(0) q[20];
u1(0) q[75];
cx q[75],q[21];
u1(0) q[21];
cx q[75],q[21];
u1(0) q[21];
u1(0) q[75];
cx q[75],q[22];
u1(0) q[22];
cx q[75],q[22];
u1(0) q[22];
u1(0) q[75];
cx q[75],q[23];
u1(0) q[23];
cx q[75],q[23];
u1(0) q[23];
u1(0) q[75];
cx q[75],q[24];
u1(0) q[24];
cx q[75],q[24];
u1(0) q[24];
u1(0) q[75];
cx q[75],q[25];
u1(0) q[25];
cx q[75],q[25];
u1(0) q[25];
u1(0) q[75];
cx q[75],q[26];
u1(0) q[26];
cx q[75],q[26];
u1(0) q[26];
u1(0) q[75];
cx q[75],q[27];
u1(0) q[27];
cx q[75],q[27];
u1(0) q[27];
u1(pi/281474976710656) q[75];
cx q[75],q[28];
u1(-pi/281474976710656) q[28];
cx q[75],q[28];
u1(pi/281474976710656) q[28];
u1(pi/140737488355328) q[75];
cx q[75],q[29];
u1(-pi/140737488355328) q[29];
cx q[75],q[29];
u1(pi/140737488355328) q[29];
u1(pi/70368744177664) q[75];
cx q[75],q[30];
u1(-pi/70368744177664) q[30];
cx q[75],q[30];
u1(pi/70368744177664) q[30];
u1(pi/35184372088832) q[75];
cx q[75],q[31];
u1(-pi/35184372088832) q[31];
cx q[75],q[31];
u1(pi/35184372088832) q[31];
u1(pi/17592186044416) q[75];
cx q[75],q[32];
u1(-pi/17592186044416) q[32];
cx q[75],q[32];
u1(pi/17592186044416) q[32];
u1(pi/8796093022208) q[75];
cx q[75],q[33];
u1(-pi/8796093022208) q[33];
cx q[75],q[33];
u1(pi/8796093022208) q[33];
u1(pi/4398046511104) q[75];
cx q[75],q[34];
u1(-pi/4398046511104) q[34];
cx q[75],q[34];
u1(pi/4398046511104) q[34];
u1(pi/2199023255552) q[75];
cx q[75],q[35];
u1(-pi/2199023255552) q[35];
cx q[75],q[35];
u1(pi/2199023255552) q[35];
u1(pi/1099511627776) q[75];
cx q[75],q[36];
u1(-pi/1099511627776) q[36];
cx q[75],q[36];
u1(pi/1099511627776) q[36];
u1(pi/549755813888) q[75];
cx q[75],q[37];
u1(-pi/549755813888) q[37];
cx q[75],q[37];
u1(pi/549755813888) q[37];
u1(pi/274877906944) q[75];
cx q[75],q[38];
u1(-pi/274877906944) q[38];
cx q[75],q[38];
u1(pi/274877906944) q[38];
u1(pi/137438953472) q[75];
cx q[75],q[39];
u1(-pi/137438953472) q[39];
cx q[75],q[39];
u1(pi/137438953472) q[39];
u1(pi/68719476736) q[75];
cx q[75],q[40];
u1(-pi/68719476736) q[40];
cx q[75],q[40];
u1(pi/68719476736) q[40];
u1(pi/34359738368) q[75];
cx q[75],q[41];
u1(-pi/34359738368) q[41];
cx q[75],q[41];
u1(pi/34359738368) q[41];
u1(pi/17179869184) q[75];
cx q[75],q[42];
u1(-pi/17179869184) q[42];
cx q[75],q[42];
u1(pi/17179869184) q[42];
u1(pi/8589934592) q[75];
cx q[75],q[43];
u1(-pi/8589934592) q[43];
cx q[75],q[43];
u1(pi/8589934592) q[43];
u1(pi/4294967296) q[75];
cx q[75],q[44];
u1(-pi/4294967296) q[44];
cx q[75],q[44];
u1(pi/4294967296) q[44];
u1(pi/2147483648) q[75];
cx q[75],q[45];
u1(-pi/2147483648) q[45];
cx q[75],q[45];
u1(pi/2147483648) q[45];
u1(pi/1073741824) q[75];
cx q[75],q[46];
u1(-pi/1073741824) q[46];
cx q[75],q[46];
u1(pi/1073741824) q[46];
u1(pi/536870912) q[75];
cx q[75],q[47];
u1(-pi/536870912) q[47];
cx q[75],q[47];
u1(pi/536870912) q[47];
u1(pi/268435456) q[75];
cx q[75],q[48];
u1(-pi/268435456) q[48];
cx q[75],q[48];
u1(pi/268435456) q[48];
u1(pi/134217728) q[75];
cx q[75],q[49];
u1(-pi/134217728) q[49];
cx q[75],q[49];
u1(pi/134217728) q[49];
u1(pi/67108864) q[75];
cx q[75],q[50];
u1(-pi/67108864) q[50];
cx q[75],q[50];
u1(pi/67108864) q[50];
u1(pi/33554432) q[75];
cx q[75],q[51];
u1(-pi/33554432) q[51];
cx q[75],q[51];
u1(pi/33554432) q[51];
u1(pi/16777216) q[75];
cx q[75],q[52];
u1(-pi/16777216) q[52];
cx q[75],q[52];
u1(pi/16777216) q[52];
u1(pi/8388608) q[75];
cx q[75],q[53];
u1(-pi/8388608) q[53];
cx q[75],q[53];
u1(pi/8388608) q[53];
u1(pi/4194304) q[75];
cx q[75],q[54];
u1(-pi/4194304) q[54];
cx q[75],q[54];
u1(pi/4194304) q[54];
u1(pi/2097152) q[75];
cx q[75],q[55];
u1(-pi/2097152) q[55];
cx q[75],q[55];
u1(pi/2097152) q[55];
u1(pi/1048576) q[75];
cx q[75],q[56];
u1(-pi/1048576) q[56];
cx q[75],q[56];
u1(pi/1048576) q[56];
u1(pi/524288) q[75];
cx q[75],q[57];
u1(-pi/524288) q[57];
cx q[75],q[57];
u1(pi/524288) q[57];
u1(pi/262144) q[75];
cx q[75],q[58];
u1(-pi/262144) q[58];
cx q[75],q[58];
u1(pi/262144) q[58];
u1(pi/131072) q[75];
cx q[75],q[59];
u1(-pi/131072) q[59];
cx q[75],q[59];
u1(pi/131072) q[59];
u1(pi/65536) q[75];
cx q[75],q[60];
u1(-pi/65536) q[60];
cx q[75],q[60];
u1(pi/65536) q[60];
u1(pi/32768) q[75];
cx q[75],q[61];
u1(-pi/32768) q[61];
cx q[75],q[61];
u1(pi/32768) q[61];
u1(pi/16384) q[75];
cx q[75],q[62];
u1(-pi/16384) q[62];
cx q[75],q[62];
u1(pi/16384) q[62];
u1(pi/8192) q[75];
cx q[75],q[63];
u1(-pi/8192) q[63];
cx q[75],q[63];
u1(pi/8192) q[63];
u1(pi/4096) q[75];
cx q[75],q[64];
u1(-pi/4096) q[64];
cx q[75],q[64];
u1(pi/4096) q[64];
u1(pi/2048) q[75];
cx q[75],q[65];
u1(-pi/2048) q[65];
cx q[75],q[65];
u1(pi/2048) q[65];
u1(pi/1024) q[75];
cx q[75],q[66];
u1(-pi/1024) q[66];
cx q[75],q[66];
u1(pi/1024) q[66];
u1(pi/512) q[75];
cx q[75],q[67];
u1(-pi/512) q[67];
cx q[75],q[67];
u1(pi/512) q[67];
u1(pi/256) q[75];
cx q[75],q[68];
u1(-pi/256) q[68];
cx q[75],q[68];
u1(pi/256) q[68];
u1(pi/128) q[75];
cx q[75],q[69];
u1(-pi/128) q[69];
cx q[75],q[69];
u1(pi/128) q[69];
u1(pi/64) q[75];
cx q[75],q[70];
u1(-pi/64) q[70];
cx q[75],q[70];
u1(pi/64) q[70];
u1(pi/32) q[75];
cx q[75],q[71];
u1(-pi/32) q[71];
cx q[75],q[71];
u1(pi/32) q[71];
u1(pi/16) q[75];
cx q[75],q[72];
u1(-pi/16) q[72];
cx q[75],q[72];
u1(pi/16) q[72];
u1(pi/8) q[75];
cx q[75],q[73];
u1(-pi/8) q[73];
cx q[75],q[73];
u1(pi/8) q[73];
u1(pi/4) q[75];
cx q[75],q[74];
u1(-pi/4) q[74];
cx q[75],q[74];
u1(pi/4) q[74];
h q[75];
u1(0) q[76];
cx q[76],q[0];
u1(0) q[0];
cx q[76],q[0];
u1(0) q[0];
u1(0) q[76];
cx q[76],q[1];
u1(0) q[1];
cx q[76],q[1];
u1(0) q[1];
u1(0) q[76];
cx q[76],q[2];
u1(0) q[2];
cx q[76],q[2];
u1(0) q[2];
u1(0) q[76];
cx q[76],q[3];
u1(0) q[3];
cx q[76],q[3];
u1(0) q[3];
u1(0) q[76];
cx q[76],q[4];
u1(0) q[4];
cx q[76],q[4];
u1(0) q[4];
u1(0) q[76];
cx q[76],q[5];
u1(0) q[5];
cx q[76],q[5];
u1(0) q[5];
u1(0) q[76];
cx q[76],q[6];
u1(0) q[6];
cx q[76],q[6];
u1(0) q[6];
u1(0) q[76];
cx q[76],q[7];
u1(0) q[7];
cx q[76],q[7];
u1(0) q[7];
u1(0) q[76];
cx q[76],q[8];
u1(0) q[8];
cx q[76],q[8];
u1(0) q[8];
u1(0) q[76];
cx q[76],q[9];
u1(0) q[9];
cx q[76],q[9];
u1(0) q[9];
u1(0) q[76];
cx q[76],q[10];
u1(0) q[10];
cx q[76],q[10];
u1(0) q[10];
u1(0) q[76];
cx q[76],q[11];
u1(0) q[11];
cx q[76],q[11];
u1(0) q[11];
u1(0) q[76];
cx q[76],q[12];
u1(0) q[12];
cx q[76],q[12];
u1(0) q[12];
u1(0) q[76];
cx q[76],q[13];
u1(0) q[13];
cx q[76],q[13];
u1(0) q[13];
u1(0) q[76];
cx q[76],q[14];
u1(0) q[14];
cx q[76],q[14];
u1(0) q[14];
u1(0) q[76];
cx q[76],q[15];
u1(0) q[15];
cx q[76],q[15];
u1(0) q[15];
u1(0) q[76];
cx q[76],q[16];
u1(0) q[16];
cx q[76],q[16];
u1(0) q[16];
u1(0) q[76];
cx q[76],q[17];
u1(0) q[17];
cx q[76],q[17];
u1(0) q[17];
u1(0) q[76];
cx q[76],q[18];
u1(0) q[18];
cx q[76],q[18];
u1(0) q[18];
u1(0) q[76];
cx q[76],q[19];
u1(0) q[19];
cx q[76],q[19];
u1(0) q[19];
u1(0) q[76];
cx q[76],q[20];
u1(0) q[20];
cx q[76],q[20];
u1(0) q[20];
u1(0) q[76];
cx q[76],q[21];
u1(0) q[21];
cx q[76],q[21];
u1(0) q[21];
u1(0) q[76];
cx q[76],q[22];
u1(0) q[22];
cx q[76],q[22];
u1(0) q[22];
u1(0) q[76];
cx q[76],q[23];
u1(0) q[23];
cx q[76],q[23];
u1(0) q[23];
u1(0) q[76];
cx q[76],q[24];
u1(0) q[24];
cx q[76],q[24];
u1(0) q[24];
u1(0) q[76];
cx q[76],q[25];
u1(0) q[25];
cx q[76],q[25];
u1(0) q[25];
u1(0) q[76];
cx q[76],q[26];
u1(0) q[26];
cx q[76],q[26];
u1(0) q[26];
u1(0) q[76];
cx q[76],q[27];
u1(0) q[27];
cx q[76],q[27];
u1(0) q[27];
u1(0) q[76];
cx q[76],q[28];
u1(0) q[28];
cx q[76],q[28];
u1(0) q[28];
u1(pi/281474976710656) q[76];
cx q[76],q[29];
u1(-pi/281474976710656) q[29];
cx q[76],q[29];
u1(pi/281474976710656) q[29];
u1(pi/140737488355328) q[76];
cx q[76],q[30];
u1(-pi/140737488355328) q[30];
cx q[76],q[30];
u1(pi/140737488355328) q[30];
u1(pi/70368744177664) q[76];
cx q[76],q[31];
u1(-pi/70368744177664) q[31];
cx q[76],q[31];
u1(pi/70368744177664) q[31];
u1(pi/35184372088832) q[76];
cx q[76],q[32];
u1(-pi/35184372088832) q[32];
cx q[76],q[32];
u1(pi/35184372088832) q[32];
u1(pi/17592186044416) q[76];
cx q[76],q[33];
u1(-pi/17592186044416) q[33];
cx q[76],q[33];
u1(pi/17592186044416) q[33];
u1(pi/8796093022208) q[76];
cx q[76],q[34];
u1(-pi/8796093022208) q[34];
cx q[76],q[34];
u1(pi/8796093022208) q[34];
u1(pi/4398046511104) q[76];
cx q[76],q[35];
u1(-pi/4398046511104) q[35];
cx q[76],q[35];
u1(pi/4398046511104) q[35];
u1(pi/2199023255552) q[76];
cx q[76],q[36];
u1(-pi/2199023255552) q[36];
cx q[76],q[36];
u1(pi/2199023255552) q[36];
u1(pi/1099511627776) q[76];
cx q[76],q[37];
u1(-pi/1099511627776) q[37];
cx q[76],q[37];
u1(pi/1099511627776) q[37];
u1(pi/549755813888) q[76];
cx q[76],q[38];
u1(-pi/549755813888) q[38];
cx q[76],q[38];
u1(pi/549755813888) q[38];
u1(pi/274877906944) q[76];
cx q[76],q[39];
u1(-pi/274877906944) q[39];
cx q[76],q[39];
u1(pi/274877906944) q[39];
u1(pi/137438953472) q[76];
cx q[76],q[40];
u1(-pi/137438953472) q[40];
cx q[76],q[40];
u1(pi/137438953472) q[40];
u1(pi/68719476736) q[76];
cx q[76],q[41];
u1(-pi/68719476736) q[41];
cx q[76],q[41];
u1(pi/68719476736) q[41];
u1(pi/34359738368) q[76];
cx q[76],q[42];
u1(-pi/34359738368) q[42];
cx q[76],q[42];
u1(pi/34359738368) q[42];
u1(pi/17179869184) q[76];
cx q[76],q[43];
u1(-pi/17179869184) q[43];
cx q[76],q[43];
u1(pi/17179869184) q[43];
u1(pi/8589934592) q[76];
cx q[76],q[44];
u1(-pi/8589934592) q[44];
cx q[76],q[44];
u1(pi/8589934592) q[44];
u1(pi/4294967296) q[76];
cx q[76],q[45];
u1(-pi/4294967296) q[45];
cx q[76],q[45];
u1(pi/4294967296) q[45];
u1(pi/2147483648) q[76];
cx q[76],q[46];
u1(-pi/2147483648) q[46];
cx q[76],q[46];
u1(pi/2147483648) q[46];
u1(pi/1073741824) q[76];
cx q[76],q[47];
u1(-pi/1073741824) q[47];
cx q[76],q[47];
u1(pi/1073741824) q[47];
u1(pi/536870912) q[76];
cx q[76],q[48];
u1(-pi/536870912) q[48];
cx q[76],q[48];
u1(pi/536870912) q[48];
u1(pi/268435456) q[76];
cx q[76],q[49];
u1(-pi/268435456) q[49];
cx q[76],q[49];
u1(pi/268435456) q[49];
u1(pi/134217728) q[76];
cx q[76],q[50];
u1(-pi/134217728) q[50];
cx q[76],q[50];
u1(pi/134217728) q[50];
u1(pi/67108864) q[76];
cx q[76],q[51];
u1(-pi/67108864) q[51];
cx q[76],q[51];
u1(pi/67108864) q[51];
u1(pi/33554432) q[76];
cx q[76],q[52];
u1(-pi/33554432) q[52];
cx q[76],q[52];
u1(pi/33554432) q[52];
u1(pi/16777216) q[76];
cx q[76],q[53];
u1(-pi/16777216) q[53];
cx q[76],q[53];
u1(pi/16777216) q[53];
u1(pi/8388608) q[76];
cx q[76],q[54];
u1(-pi/8388608) q[54];
cx q[76],q[54];
u1(pi/8388608) q[54];
u1(pi/4194304) q[76];
cx q[76],q[55];
u1(-pi/4194304) q[55];
cx q[76],q[55];
u1(pi/4194304) q[55];
u1(pi/2097152) q[76];
cx q[76],q[56];
u1(-pi/2097152) q[56];
cx q[76],q[56];
u1(pi/2097152) q[56];
u1(pi/1048576) q[76];
cx q[76],q[57];
u1(-pi/1048576) q[57];
cx q[76],q[57];
u1(pi/1048576) q[57];
u1(pi/524288) q[76];
cx q[76],q[58];
u1(-pi/524288) q[58];
cx q[76],q[58];
u1(pi/524288) q[58];
u1(pi/262144) q[76];
cx q[76],q[59];
u1(-pi/262144) q[59];
cx q[76],q[59];
u1(pi/262144) q[59];
u1(pi/131072) q[76];
cx q[76],q[60];
u1(-pi/131072) q[60];
cx q[76],q[60];
u1(pi/131072) q[60];
u1(pi/65536) q[76];
cx q[76],q[61];
u1(-pi/65536) q[61];
cx q[76],q[61];
u1(pi/65536) q[61];
u1(pi/32768) q[76];
cx q[76],q[62];
u1(-pi/32768) q[62];
cx q[76],q[62];
u1(pi/32768) q[62];
u1(pi/16384) q[76];
cx q[76],q[63];
u1(-pi/16384) q[63];
cx q[76],q[63];
u1(pi/16384) q[63];
u1(pi/8192) q[76];
cx q[76],q[64];
u1(-pi/8192) q[64];
cx q[76],q[64];
u1(pi/8192) q[64];
u1(pi/4096) q[76];
cx q[76],q[65];
u1(-pi/4096) q[65];
cx q[76],q[65];
u1(pi/4096) q[65];
u1(pi/2048) q[76];
cx q[76],q[66];
u1(-pi/2048) q[66];
cx q[76],q[66];
u1(pi/2048) q[66];
u1(pi/1024) q[76];
cx q[76],q[67];
u1(-pi/1024) q[67];
cx q[76],q[67];
u1(pi/1024) q[67];
u1(pi/512) q[76];
cx q[76],q[68];
u1(-pi/512) q[68];
cx q[76],q[68];
u1(pi/512) q[68];
u1(pi/256) q[76];
cx q[76],q[69];
u1(-pi/256) q[69];
cx q[76],q[69];
u1(pi/256) q[69];
u1(pi/128) q[76];
cx q[76],q[70];
u1(-pi/128) q[70];
cx q[76],q[70];
u1(pi/128) q[70];
u1(pi/64) q[76];
cx q[76],q[71];
u1(-pi/64) q[71];
cx q[76],q[71];
u1(pi/64) q[71];
u1(pi/32) q[76];
cx q[76],q[72];
u1(-pi/32) q[72];
cx q[76],q[72];
u1(pi/32) q[72];
u1(pi/16) q[76];
cx q[76],q[73];
u1(-pi/16) q[73];
cx q[76],q[73];
u1(pi/16) q[73];
u1(pi/8) q[76];
cx q[76],q[74];
u1(-pi/8) q[74];
cx q[76],q[74];
u1(pi/8) q[74];
u1(pi/4) q[76];
cx q[76],q[75];
u1(-pi/4) q[75];
cx q[76],q[75];
u1(pi/4) q[75];
h q[76];
u1(0) q[77];
cx q[77],q[0];
u1(0) q[0];
cx q[77],q[0];
u1(0) q[0];
u1(0) q[77];
cx q[77],q[1];
u1(0) q[1];
cx q[77],q[1];
u1(0) q[1];
u1(0) q[77];
cx q[77],q[2];
u1(0) q[2];
cx q[77],q[2];
u1(0) q[2];
u1(0) q[77];
cx q[77],q[3];
u1(0) q[3];
cx q[77],q[3];
u1(0) q[3];
u1(0) q[77];
cx q[77],q[4];
u1(0) q[4];
cx q[77],q[4];
u1(0) q[4];
u1(0) q[77];
cx q[77],q[5];
u1(0) q[5];
cx q[77],q[5];
u1(0) q[5];
u1(0) q[77];
cx q[77],q[6];
u1(0) q[6];
cx q[77],q[6];
u1(0) q[6];
u1(0) q[77];
cx q[77],q[7];
u1(0) q[7];
cx q[77],q[7];
u1(0) q[7];
u1(0) q[77];
cx q[77],q[8];
u1(0) q[8];
cx q[77],q[8];
u1(0) q[8];
u1(0) q[77];
cx q[77],q[9];
u1(0) q[9];
cx q[77],q[9];
u1(0) q[9];
u1(0) q[77];
cx q[77],q[10];
u1(0) q[10];
cx q[77],q[10];
u1(0) q[10];
u1(0) q[77];
cx q[77],q[11];
u1(0) q[11];
cx q[77],q[11];
u1(0) q[11];
u1(0) q[77];
cx q[77],q[12];
u1(0) q[12];
cx q[77],q[12];
u1(0) q[12];
u1(0) q[77];
cx q[77],q[13];
u1(0) q[13];
cx q[77],q[13];
u1(0) q[13];
u1(0) q[77];
cx q[77],q[14];
u1(0) q[14];
cx q[77],q[14];
u1(0) q[14];
u1(0) q[77];
cx q[77],q[15];
u1(0) q[15];
cx q[77],q[15];
u1(0) q[15];
u1(0) q[77];
cx q[77],q[16];
u1(0) q[16];
cx q[77],q[16];
u1(0) q[16];
u1(0) q[77];
cx q[77],q[17];
u1(0) q[17];
cx q[77],q[17];
u1(0) q[17];
u1(0) q[77];
cx q[77],q[18];
u1(0) q[18];
cx q[77],q[18];
u1(0) q[18];
u1(0) q[77];
cx q[77],q[19];
u1(0) q[19];
cx q[77],q[19];
u1(0) q[19];
u1(0) q[77];
cx q[77],q[20];
u1(0) q[20];
cx q[77],q[20];
u1(0) q[20];
u1(0) q[77];
cx q[77],q[21];
u1(0) q[21];
cx q[77],q[21];
u1(0) q[21];
u1(0) q[77];
cx q[77],q[22];
u1(0) q[22];
cx q[77],q[22];
u1(0) q[22];
u1(0) q[77];
cx q[77],q[23];
u1(0) q[23];
cx q[77],q[23];
u1(0) q[23];
u1(0) q[77];
cx q[77],q[24];
u1(0) q[24];
cx q[77],q[24];
u1(0) q[24];
u1(0) q[77];
cx q[77],q[25];
u1(0) q[25];
cx q[77],q[25];
u1(0) q[25];
u1(0) q[77];
cx q[77],q[26];
u1(0) q[26];
cx q[77],q[26];
u1(0) q[26];
u1(0) q[77];
cx q[77],q[27];
u1(0) q[27];
cx q[77],q[27];
u1(0) q[27];
u1(0) q[77];
cx q[77],q[28];
u1(0) q[28];
cx q[77],q[28];
u1(0) q[28];
u1(0) q[77];
cx q[77],q[29];
u1(0) q[29];
cx q[77],q[29];
u1(0) q[29];
u1(pi/281474976710656) q[77];
cx q[77],q[30];
u1(-pi/281474976710656) q[30];
cx q[77],q[30];
u1(pi/281474976710656) q[30];
u1(pi/140737488355328) q[77];
cx q[77],q[31];
u1(-pi/140737488355328) q[31];
cx q[77],q[31];
u1(pi/140737488355328) q[31];
u1(pi/70368744177664) q[77];
cx q[77],q[32];
u1(-pi/70368744177664) q[32];
cx q[77],q[32];
u1(pi/70368744177664) q[32];
u1(pi/35184372088832) q[77];
cx q[77],q[33];
u1(-pi/35184372088832) q[33];
cx q[77],q[33];
u1(pi/35184372088832) q[33];
u1(pi/17592186044416) q[77];
cx q[77],q[34];
u1(-pi/17592186044416) q[34];
cx q[77],q[34];
u1(pi/17592186044416) q[34];
u1(pi/8796093022208) q[77];
cx q[77],q[35];
u1(-pi/8796093022208) q[35];
cx q[77],q[35];
u1(pi/8796093022208) q[35];
u1(pi/4398046511104) q[77];
cx q[77],q[36];
u1(-pi/4398046511104) q[36];
cx q[77],q[36];
u1(pi/4398046511104) q[36];
u1(pi/2199023255552) q[77];
cx q[77],q[37];
u1(-pi/2199023255552) q[37];
cx q[77],q[37];
u1(pi/2199023255552) q[37];
u1(pi/1099511627776) q[77];
cx q[77],q[38];
u1(-pi/1099511627776) q[38];
cx q[77],q[38];
u1(pi/1099511627776) q[38];
u1(pi/549755813888) q[77];
cx q[77],q[39];
u1(-pi/549755813888) q[39];
cx q[77],q[39];
u1(pi/549755813888) q[39];
u1(pi/274877906944) q[77];
cx q[77],q[40];
u1(-pi/274877906944) q[40];
cx q[77],q[40];
u1(pi/274877906944) q[40];
u1(pi/137438953472) q[77];
cx q[77],q[41];
u1(-pi/137438953472) q[41];
cx q[77],q[41];
u1(pi/137438953472) q[41];
u1(pi/68719476736) q[77];
cx q[77],q[42];
u1(-pi/68719476736) q[42];
cx q[77],q[42];
u1(pi/68719476736) q[42];
u1(pi/34359738368) q[77];
cx q[77],q[43];
u1(-pi/34359738368) q[43];
cx q[77],q[43];
u1(pi/34359738368) q[43];
u1(pi/17179869184) q[77];
cx q[77],q[44];
u1(-pi/17179869184) q[44];
cx q[77],q[44];
u1(pi/17179869184) q[44];
u1(pi/8589934592) q[77];
cx q[77],q[45];
u1(-pi/8589934592) q[45];
cx q[77],q[45];
u1(pi/8589934592) q[45];
u1(pi/4294967296) q[77];
cx q[77],q[46];
u1(-pi/4294967296) q[46];
cx q[77],q[46];
u1(pi/4294967296) q[46];
u1(pi/2147483648) q[77];
cx q[77],q[47];
u1(-pi/2147483648) q[47];
cx q[77],q[47];
u1(pi/2147483648) q[47];
u1(pi/1073741824) q[77];
cx q[77],q[48];
u1(-pi/1073741824) q[48];
cx q[77],q[48];
u1(pi/1073741824) q[48];
u1(pi/536870912) q[77];
cx q[77],q[49];
u1(-pi/536870912) q[49];
cx q[77],q[49];
u1(pi/536870912) q[49];
u1(pi/268435456) q[77];
cx q[77],q[50];
u1(-pi/268435456) q[50];
cx q[77],q[50];
u1(pi/268435456) q[50];
u1(pi/134217728) q[77];
cx q[77],q[51];
u1(-pi/134217728) q[51];
cx q[77],q[51];
u1(pi/134217728) q[51];
u1(pi/67108864) q[77];
cx q[77],q[52];
u1(-pi/67108864) q[52];
cx q[77],q[52];
u1(pi/67108864) q[52];
u1(pi/33554432) q[77];
cx q[77],q[53];
u1(-pi/33554432) q[53];
cx q[77],q[53];
u1(pi/33554432) q[53];
u1(pi/16777216) q[77];
cx q[77],q[54];
u1(-pi/16777216) q[54];
cx q[77],q[54];
u1(pi/16777216) q[54];
u1(pi/8388608) q[77];
cx q[77],q[55];
u1(-pi/8388608) q[55];
cx q[77],q[55];
u1(pi/8388608) q[55];
u1(pi/4194304) q[77];
cx q[77],q[56];
u1(-pi/4194304) q[56];
cx q[77],q[56];
u1(pi/4194304) q[56];
u1(pi/2097152) q[77];
cx q[77],q[57];
u1(-pi/2097152) q[57];
cx q[77],q[57];
u1(pi/2097152) q[57];
u1(pi/1048576) q[77];
cx q[77],q[58];
u1(-pi/1048576) q[58];
cx q[77],q[58];
u1(pi/1048576) q[58];
u1(pi/524288) q[77];
cx q[77],q[59];
u1(-pi/524288) q[59];
cx q[77],q[59];
u1(pi/524288) q[59];
u1(pi/262144) q[77];
cx q[77],q[60];
u1(-pi/262144) q[60];
cx q[77],q[60];
u1(pi/262144) q[60];
u1(pi/131072) q[77];
cx q[77],q[61];
u1(-pi/131072) q[61];
cx q[77],q[61];
u1(pi/131072) q[61];
u1(pi/65536) q[77];
cx q[77],q[62];
u1(-pi/65536) q[62];
cx q[77],q[62];
u1(pi/65536) q[62];
u1(pi/32768) q[77];
cx q[77],q[63];
u1(-pi/32768) q[63];
cx q[77],q[63];
u1(pi/32768) q[63];
u1(pi/16384) q[77];
cx q[77],q[64];
u1(-pi/16384) q[64];
cx q[77],q[64];
u1(pi/16384) q[64];
u1(pi/8192) q[77];
cx q[77],q[65];
u1(-pi/8192) q[65];
cx q[77],q[65];
u1(pi/8192) q[65];
u1(pi/4096) q[77];
cx q[77],q[66];
u1(-pi/4096) q[66];
cx q[77],q[66];
u1(pi/4096) q[66];
u1(pi/2048) q[77];
cx q[77],q[67];
u1(-pi/2048) q[67];
cx q[77],q[67];
u1(pi/2048) q[67];
u1(pi/1024) q[77];
cx q[77],q[68];
u1(-pi/1024) q[68];
cx q[77],q[68];
u1(pi/1024) q[68];
u1(pi/512) q[77];
cx q[77],q[69];
u1(-pi/512) q[69];
cx q[77],q[69];
u1(pi/512) q[69];
u1(pi/256) q[77];
cx q[77],q[70];
u1(-pi/256) q[70];
cx q[77],q[70];
u1(pi/256) q[70];
u1(pi/128) q[77];
cx q[77],q[71];
u1(-pi/128) q[71];
cx q[77],q[71];
u1(pi/128) q[71];
u1(pi/64) q[77];
cx q[77],q[72];
u1(-pi/64) q[72];
cx q[77],q[72];
u1(pi/64) q[72];
u1(pi/32) q[77];
cx q[77],q[73];
u1(-pi/32) q[73];
cx q[77],q[73];
u1(pi/32) q[73];
u1(pi/16) q[77];
cx q[77],q[74];
u1(-pi/16) q[74];
cx q[77],q[74];
u1(pi/16) q[74];
u1(pi/8) q[77];
cx q[77],q[75];
u1(-pi/8) q[75];
cx q[77],q[75];
u1(pi/8) q[75];
u1(pi/4) q[77];
cx q[77],q[76];
u1(-pi/4) q[76];
cx q[77],q[76];
u1(pi/4) q[76];
h q[77];
u1(0) q[78];
cx q[78],q[0];
u1(0) q[0];
cx q[78],q[0];
u1(0) q[0];
u1(0) q[78];
cx q[78],q[1];
u1(0) q[1];
cx q[78],q[1];
u1(0) q[1];
u1(0) q[78];
cx q[78],q[2];
u1(0) q[2];
cx q[78],q[2];
u1(0) q[2];
u1(0) q[78];
cx q[78],q[3];
u1(0) q[3];
cx q[78],q[3];
u1(0) q[3];
u1(0) q[78];
cx q[78],q[4];
u1(0) q[4];
cx q[78],q[4];
u1(0) q[4];
u1(0) q[78];
cx q[78],q[5];
u1(0) q[5];
cx q[78],q[5];
u1(0) q[5];
u1(0) q[78];
cx q[78],q[6];
u1(0) q[6];
cx q[78],q[6];
u1(0) q[6];
u1(0) q[78];
cx q[78],q[7];
u1(0) q[7];
cx q[78],q[7];
u1(0) q[7];
u1(0) q[78];
cx q[78],q[8];
u1(0) q[8];
cx q[78],q[8];
u1(0) q[8];
u1(0) q[78];
cx q[78],q[9];
u1(0) q[9];
cx q[78],q[9];
u1(0) q[9];
u1(0) q[78];
cx q[78],q[10];
u1(0) q[10];
cx q[78],q[10];
u1(0) q[10];
u1(0) q[78];
cx q[78],q[11];
u1(0) q[11];
cx q[78],q[11];
u1(0) q[11];
u1(0) q[78];
cx q[78],q[12];
u1(0) q[12];
cx q[78],q[12];
u1(0) q[12];
u1(0) q[78];
cx q[78],q[13];
u1(0) q[13];
cx q[78],q[13];
u1(0) q[13];
u1(0) q[78];
cx q[78],q[14];
u1(0) q[14];
cx q[78],q[14];
u1(0) q[14];
u1(0) q[78];
cx q[78],q[15];
u1(0) q[15];
cx q[78],q[15];
u1(0) q[15];
u1(0) q[78];
cx q[78],q[16];
u1(0) q[16];
cx q[78],q[16];
u1(0) q[16];
u1(0) q[78];
cx q[78],q[17];
u1(0) q[17];
cx q[78],q[17];
u1(0) q[17];
u1(0) q[78];
cx q[78],q[18];
u1(0) q[18];
cx q[78],q[18];
u1(0) q[18];
u1(0) q[78];
cx q[78],q[19];
u1(0) q[19];
cx q[78],q[19];
u1(0) q[19];
u1(0) q[78];
cx q[78],q[20];
u1(0) q[20];
cx q[78],q[20];
u1(0) q[20];
u1(0) q[78];
cx q[78],q[21];
u1(0) q[21];
cx q[78],q[21];
u1(0) q[21];
u1(0) q[78];
cx q[78],q[22];
u1(0) q[22];
cx q[78],q[22];
u1(0) q[22];
u1(0) q[78];
cx q[78],q[23];
u1(0) q[23];
cx q[78],q[23];
u1(0) q[23];
u1(0) q[78];
cx q[78],q[24];
u1(0) q[24];
cx q[78],q[24];
u1(0) q[24];
u1(0) q[78];
cx q[78],q[25];
u1(0) q[25];
cx q[78],q[25];
u1(0) q[25];
u1(0) q[78];
cx q[78],q[26];
u1(0) q[26];
cx q[78],q[26];
u1(0) q[26];
u1(0) q[78];
cx q[78],q[27];
u1(0) q[27];
cx q[78],q[27];
u1(0) q[27];
u1(0) q[78];
cx q[78],q[28];
u1(0) q[28];
cx q[78],q[28];
u1(0) q[28];
u1(0) q[78];
cx q[78],q[29];
u1(0) q[29];
cx q[78],q[29];
u1(0) q[29];
u1(0) q[78];
cx q[78],q[30];
u1(0) q[30];
cx q[78],q[30];
u1(0) q[30];
u1(pi/281474976710656) q[78];
cx q[78],q[31];
u1(-pi/281474976710656) q[31];
cx q[78],q[31];
u1(pi/281474976710656) q[31];
u1(pi/140737488355328) q[78];
cx q[78],q[32];
u1(-pi/140737488355328) q[32];
cx q[78],q[32];
u1(pi/140737488355328) q[32];
u1(pi/70368744177664) q[78];
cx q[78],q[33];
u1(-pi/70368744177664) q[33];
cx q[78],q[33];
u1(pi/70368744177664) q[33];
u1(pi/35184372088832) q[78];
cx q[78],q[34];
u1(-pi/35184372088832) q[34];
cx q[78],q[34];
u1(pi/35184372088832) q[34];
u1(pi/17592186044416) q[78];
cx q[78],q[35];
u1(-pi/17592186044416) q[35];
cx q[78],q[35];
u1(pi/17592186044416) q[35];
u1(pi/8796093022208) q[78];
cx q[78],q[36];
u1(-pi/8796093022208) q[36];
cx q[78],q[36];
u1(pi/8796093022208) q[36];
u1(pi/4398046511104) q[78];
cx q[78],q[37];
u1(-pi/4398046511104) q[37];
cx q[78],q[37];
u1(pi/4398046511104) q[37];
u1(pi/2199023255552) q[78];
cx q[78],q[38];
u1(-pi/2199023255552) q[38];
cx q[78],q[38];
u1(pi/2199023255552) q[38];
u1(pi/1099511627776) q[78];
cx q[78],q[39];
u1(-pi/1099511627776) q[39];
cx q[78],q[39];
u1(pi/1099511627776) q[39];
u1(pi/549755813888) q[78];
cx q[78],q[40];
u1(-pi/549755813888) q[40];
cx q[78],q[40];
u1(pi/549755813888) q[40];
u1(pi/274877906944) q[78];
cx q[78],q[41];
u1(-pi/274877906944) q[41];
cx q[78],q[41];
u1(pi/274877906944) q[41];
u1(pi/137438953472) q[78];
cx q[78],q[42];
u1(-pi/137438953472) q[42];
cx q[78],q[42];
u1(pi/137438953472) q[42];
u1(pi/68719476736) q[78];
cx q[78],q[43];
u1(-pi/68719476736) q[43];
cx q[78],q[43];
u1(pi/68719476736) q[43];
u1(pi/34359738368) q[78];
cx q[78],q[44];
u1(-pi/34359738368) q[44];
cx q[78],q[44];
u1(pi/34359738368) q[44];
u1(pi/17179869184) q[78];
cx q[78],q[45];
u1(-pi/17179869184) q[45];
cx q[78],q[45];
u1(pi/17179869184) q[45];
u1(pi/8589934592) q[78];
cx q[78],q[46];
u1(-pi/8589934592) q[46];
cx q[78],q[46];
u1(pi/8589934592) q[46];
u1(pi/4294967296) q[78];
cx q[78],q[47];
u1(-pi/4294967296) q[47];
cx q[78],q[47];
u1(pi/4294967296) q[47];
u1(pi/2147483648) q[78];
cx q[78],q[48];
u1(-pi/2147483648) q[48];
cx q[78],q[48];
u1(pi/2147483648) q[48];
u1(pi/1073741824) q[78];
cx q[78],q[49];
u1(-pi/1073741824) q[49];
cx q[78],q[49];
u1(pi/1073741824) q[49];
u1(pi/536870912) q[78];
cx q[78],q[50];
u1(-pi/536870912) q[50];
cx q[78],q[50];
u1(pi/536870912) q[50];
u1(pi/268435456) q[78];
cx q[78],q[51];
u1(-pi/268435456) q[51];
cx q[78],q[51];
u1(pi/268435456) q[51];
u1(pi/134217728) q[78];
cx q[78],q[52];
u1(-pi/134217728) q[52];
cx q[78],q[52];
u1(pi/134217728) q[52];
u1(pi/67108864) q[78];
cx q[78],q[53];
u1(-pi/67108864) q[53];
cx q[78],q[53];
u1(pi/67108864) q[53];
u1(pi/33554432) q[78];
cx q[78],q[54];
u1(-pi/33554432) q[54];
cx q[78],q[54];
u1(pi/33554432) q[54];
u1(pi/16777216) q[78];
cx q[78],q[55];
u1(-pi/16777216) q[55];
cx q[78],q[55];
u1(pi/16777216) q[55];
u1(pi/8388608) q[78];
cx q[78],q[56];
u1(-pi/8388608) q[56];
cx q[78],q[56];
u1(pi/8388608) q[56];
u1(pi/4194304) q[78];
cx q[78],q[57];
u1(-pi/4194304) q[57];
cx q[78],q[57];
u1(pi/4194304) q[57];
u1(pi/2097152) q[78];
cx q[78],q[58];
u1(-pi/2097152) q[58];
cx q[78],q[58];
u1(pi/2097152) q[58];
u1(pi/1048576) q[78];
cx q[78],q[59];
u1(-pi/1048576) q[59];
cx q[78],q[59];
u1(pi/1048576) q[59];
u1(pi/524288) q[78];
cx q[78],q[60];
u1(-pi/524288) q[60];
cx q[78],q[60];
u1(pi/524288) q[60];
u1(pi/262144) q[78];
cx q[78],q[61];
u1(-pi/262144) q[61];
cx q[78],q[61];
u1(pi/262144) q[61];
u1(pi/131072) q[78];
cx q[78],q[62];
u1(-pi/131072) q[62];
cx q[78],q[62];
u1(pi/131072) q[62];
u1(pi/65536) q[78];
cx q[78],q[63];
u1(-pi/65536) q[63];
cx q[78],q[63];
u1(pi/65536) q[63];
u1(pi/32768) q[78];
cx q[78],q[64];
u1(-pi/32768) q[64];
cx q[78],q[64];
u1(pi/32768) q[64];
u1(pi/16384) q[78];
cx q[78],q[65];
u1(-pi/16384) q[65];
cx q[78],q[65];
u1(pi/16384) q[65];
u1(pi/8192) q[78];
cx q[78],q[66];
u1(-pi/8192) q[66];
cx q[78],q[66];
u1(pi/8192) q[66];
u1(pi/4096) q[78];
cx q[78],q[67];
u1(-pi/4096) q[67];
cx q[78],q[67];
u1(pi/4096) q[67];
u1(pi/2048) q[78];
cx q[78],q[68];
u1(-pi/2048) q[68];
cx q[78],q[68];
u1(pi/2048) q[68];
u1(pi/1024) q[78];
cx q[78],q[69];
u1(-pi/1024) q[69];
cx q[78],q[69];
u1(pi/1024) q[69];
u1(pi/512) q[78];
cx q[78],q[70];
u1(-pi/512) q[70];
cx q[78],q[70];
u1(pi/512) q[70];
u1(pi/256) q[78];
cx q[78],q[71];
u1(-pi/256) q[71];
cx q[78],q[71];
u1(pi/256) q[71];
u1(pi/128) q[78];
cx q[78],q[72];
u1(-pi/128) q[72];
cx q[78],q[72];
u1(pi/128) q[72];
u1(pi/64) q[78];
cx q[78],q[73];
u1(-pi/64) q[73];
cx q[78],q[73];
u1(pi/64) q[73];
u1(pi/32) q[78];
cx q[78],q[74];
u1(-pi/32) q[74];
cx q[78],q[74];
u1(pi/32) q[74];
u1(pi/16) q[78];
cx q[78],q[75];
u1(-pi/16) q[75];
cx q[78],q[75];
u1(pi/16) q[75];
u1(pi/8) q[78];
cx q[78],q[76];
u1(-pi/8) q[76];
cx q[78],q[76];
u1(pi/8) q[76];
u1(pi/4) q[78];
cx q[78],q[77];
u1(-pi/4) q[77];
cx q[78],q[77];
u1(pi/4) q[77];
h q[78];
u1(0) q[79];
cx q[79],q[0];
u1(0) q[0];
cx q[79],q[0];
u1(0) q[0];
u1(0) q[79];
cx q[79],q[1];
u1(0) q[1];
cx q[79],q[1];
u1(0) q[1];
u1(0) q[79];
cx q[79],q[2];
u1(0) q[2];
cx q[79],q[2];
u1(0) q[2];
u1(0) q[79];
cx q[79],q[3];
u1(0) q[3];
cx q[79],q[3];
u1(0) q[3];
u1(0) q[79];
cx q[79],q[4];
u1(0) q[4];
cx q[79],q[4];
u1(0) q[4];
u1(0) q[79];
cx q[79],q[5];
u1(0) q[5];
cx q[79],q[5];
u1(0) q[5];
u1(0) q[79];
cx q[79],q[6];
u1(0) q[6];
cx q[79],q[6];
u1(0) q[6];
u1(0) q[79];
cx q[79],q[7];
u1(0) q[7];
cx q[79],q[7];
u1(0) q[7];
u1(0) q[79];
cx q[79],q[8];
u1(0) q[8];
cx q[79],q[8];
u1(0) q[8];
u1(0) q[79];
cx q[79],q[9];
u1(0) q[9];
cx q[79],q[9];
u1(0) q[9];
u1(0) q[79];
cx q[79],q[10];
u1(0) q[10];
cx q[79],q[10];
u1(0) q[10];
u1(0) q[79];
cx q[79],q[11];
u1(0) q[11];
cx q[79],q[11];
u1(0) q[11];
u1(0) q[79];
cx q[79],q[12];
u1(0) q[12];
cx q[79],q[12];
u1(0) q[12];
u1(0) q[79];
cx q[79],q[13];
u1(0) q[13];
cx q[79],q[13];
u1(0) q[13];
u1(0) q[79];
cx q[79],q[14];
u1(0) q[14];
cx q[79],q[14];
u1(0) q[14];
u1(0) q[79];
cx q[79],q[15];
u1(0) q[15];
cx q[79],q[15];
u1(0) q[15];
u1(0) q[79];
cx q[79],q[16];
u1(0) q[16];
cx q[79],q[16];
u1(0) q[16];
u1(0) q[79];
cx q[79],q[17];
u1(0) q[17];
cx q[79],q[17];
u1(0) q[17];
u1(0) q[79];
cx q[79],q[18];
u1(0) q[18];
cx q[79],q[18];
u1(0) q[18];
u1(0) q[79];
cx q[79],q[19];
u1(0) q[19];
cx q[79],q[19];
u1(0) q[19];
u1(0) q[79];
cx q[79],q[20];
u1(0) q[20];
cx q[79],q[20];
u1(0) q[20];
u1(0) q[79];
cx q[79],q[21];
u1(0) q[21];
cx q[79],q[21];
u1(0) q[21];
u1(0) q[79];
cx q[79],q[22];
u1(0) q[22];
cx q[79],q[22];
u1(0) q[22];
u1(0) q[79];
cx q[79],q[23];
u1(0) q[23];
cx q[79],q[23];
u1(0) q[23];
u1(0) q[79];
cx q[79],q[24];
u1(0) q[24];
cx q[79],q[24];
u1(0) q[24];
u1(0) q[79];
cx q[79],q[25];
u1(0) q[25];
cx q[79],q[25];
u1(0) q[25];
u1(0) q[79];
cx q[79],q[26];
u1(0) q[26];
cx q[79],q[26];
u1(0) q[26];
u1(0) q[79];
cx q[79],q[27];
u1(0) q[27];
cx q[79],q[27];
u1(0) q[27];
u1(0) q[79];
cx q[79],q[28];
u1(0) q[28];
cx q[79],q[28];
u1(0) q[28];
u1(0) q[79];
cx q[79],q[29];
u1(0) q[29];
cx q[79],q[29];
u1(0) q[29];
u1(0) q[79];
cx q[79],q[30];
u1(0) q[30];
cx q[79],q[30];
u1(0) q[30];
u1(0) q[79];
cx q[79],q[31];
u1(0) q[31];
cx q[79],q[31];
u1(0) q[31];
u1(pi/281474976710656) q[79];
cx q[79],q[32];
u1(-pi/281474976710656) q[32];
cx q[79],q[32];
u1(pi/281474976710656) q[32];
u1(pi/140737488355328) q[79];
cx q[79],q[33];
u1(-pi/140737488355328) q[33];
cx q[79],q[33];
u1(pi/140737488355328) q[33];
u1(pi/70368744177664) q[79];
cx q[79],q[34];
u1(-pi/70368744177664) q[34];
cx q[79],q[34];
u1(pi/70368744177664) q[34];
u1(pi/35184372088832) q[79];
cx q[79],q[35];
u1(-pi/35184372088832) q[35];
cx q[79],q[35];
u1(pi/35184372088832) q[35];
u1(pi/17592186044416) q[79];
cx q[79],q[36];
u1(-pi/17592186044416) q[36];
cx q[79],q[36];
u1(pi/17592186044416) q[36];
u1(pi/8796093022208) q[79];
cx q[79],q[37];
u1(-pi/8796093022208) q[37];
cx q[79],q[37];
u1(pi/8796093022208) q[37];
u1(pi/4398046511104) q[79];
cx q[79],q[38];
u1(-pi/4398046511104) q[38];
cx q[79],q[38];
u1(pi/4398046511104) q[38];
u1(pi/2199023255552) q[79];
cx q[79],q[39];
u1(-pi/2199023255552) q[39];
cx q[79],q[39];
u1(pi/2199023255552) q[39];
u1(pi/1099511627776) q[79];
cx q[79],q[40];
u1(-pi/1099511627776) q[40];
cx q[79],q[40];
u1(pi/1099511627776) q[40];
u1(pi/549755813888) q[79];
cx q[79],q[41];
u1(-pi/549755813888) q[41];
cx q[79],q[41];
u1(pi/549755813888) q[41];
u1(pi/274877906944) q[79];
cx q[79],q[42];
u1(-pi/274877906944) q[42];
cx q[79],q[42];
u1(pi/274877906944) q[42];
u1(pi/137438953472) q[79];
cx q[79],q[43];
u1(-pi/137438953472) q[43];
cx q[79],q[43];
u1(pi/137438953472) q[43];
u1(pi/68719476736) q[79];
cx q[79],q[44];
u1(-pi/68719476736) q[44];
cx q[79],q[44];
u1(pi/68719476736) q[44];
u1(pi/34359738368) q[79];
cx q[79],q[45];
u1(-pi/34359738368) q[45];
cx q[79],q[45];
u1(pi/34359738368) q[45];
u1(pi/17179869184) q[79];
cx q[79],q[46];
u1(-pi/17179869184) q[46];
cx q[79],q[46];
u1(pi/17179869184) q[46];
u1(pi/8589934592) q[79];
cx q[79],q[47];
u1(-pi/8589934592) q[47];
cx q[79],q[47];
u1(pi/8589934592) q[47];
u1(pi/4294967296) q[79];
cx q[79],q[48];
u1(-pi/4294967296) q[48];
cx q[79],q[48];
u1(pi/4294967296) q[48];
u1(pi/2147483648) q[79];
cx q[79],q[49];
u1(-pi/2147483648) q[49];
cx q[79],q[49];
u1(pi/2147483648) q[49];
u1(pi/1073741824) q[79];
cx q[79],q[50];
u1(-pi/1073741824) q[50];
cx q[79],q[50];
u1(pi/1073741824) q[50];
u1(pi/536870912) q[79];
cx q[79],q[51];
u1(-pi/536870912) q[51];
cx q[79],q[51];
u1(pi/536870912) q[51];
u1(pi/268435456) q[79];
cx q[79],q[52];
u1(-pi/268435456) q[52];
cx q[79],q[52];
u1(pi/268435456) q[52];
u1(pi/134217728) q[79];
cx q[79],q[53];
u1(-pi/134217728) q[53];
cx q[79],q[53];
u1(pi/134217728) q[53];
u1(pi/67108864) q[79];
cx q[79],q[54];
u1(-pi/67108864) q[54];
cx q[79],q[54];
u1(pi/67108864) q[54];
u1(pi/33554432) q[79];
cx q[79],q[55];
u1(-pi/33554432) q[55];
cx q[79],q[55];
u1(pi/33554432) q[55];
u1(pi/16777216) q[79];
cx q[79],q[56];
u1(-pi/16777216) q[56];
cx q[79],q[56];
u1(pi/16777216) q[56];
u1(pi/8388608) q[79];
cx q[79],q[57];
u1(-pi/8388608) q[57];
cx q[79],q[57];
u1(pi/8388608) q[57];
u1(pi/4194304) q[79];
cx q[79],q[58];
u1(-pi/4194304) q[58];
cx q[79],q[58];
u1(pi/4194304) q[58];
u1(pi/2097152) q[79];
cx q[79],q[59];
u1(-pi/2097152) q[59];
cx q[79],q[59];
u1(pi/2097152) q[59];
u1(pi/1048576) q[79];
cx q[79],q[60];
u1(-pi/1048576) q[60];
cx q[79],q[60];
u1(pi/1048576) q[60];
u1(pi/524288) q[79];
cx q[79],q[61];
u1(-pi/524288) q[61];
cx q[79],q[61];
u1(pi/524288) q[61];
u1(pi/262144) q[79];
cx q[79],q[62];
u1(-pi/262144) q[62];
cx q[79],q[62];
u1(pi/262144) q[62];
u1(pi/131072) q[79];
cx q[79],q[63];
u1(-pi/131072) q[63];
cx q[79],q[63];
u1(pi/131072) q[63];
u1(pi/65536) q[79];
cx q[79],q[64];
u1(-pi/65536) q[64];
cx q[79],q[64];
u1(pi/65536) q[64];
u1(pi/32768) q[79];
cx q[79],q[65];
u1(-pi/32768) q[65];
cx q[79],q[65];
u1(pi/32768) q[65];
u1(pi/16384) q[79];
cx q[79],q[66];
u1(-pi/16384) q[66];
cx q[79],q[66];
u1(pi/16384) q[66];
u1(pi/8192) q[79];
cx q[79],q[67];
u1(-pi/8192) q[67];
cx q[79],q[67];
u1(pi/8192) q[67];
u1(pi/4096) q[79];
cx q[79],q[68];
u1(-pi/4096) q[68];
cx q[79],q[68];
u1(pi/4096) q[68];
u1(pi/2048) q[79];
cx q[79],q[69];
u1(-pi/2048) q[69];
cx q[79],q[69];
u1(pi/2048) q[69];
u1(pi/1024) q[79];
cx q[79],q[70];
u1(-pi/1024) q[70];
cx q[79],q[70];
u1(pi/1024) q[70];
u1(pi/512) q[79];
cx q[79],q[71];
u1(-pi/512) q[71];
cx q[79],q[71];
u1(pi/512) q[71];
u1(pi/256) q[79];
cx q[79],q[72];
u1(-pi/256) q[72];
cx q[79],q[72];
u1(pi/256) q[72];
u1(pi/128) q[79];
cx q[79],q[73];
u1(-pi/128) q[73];
cx q[79],q[73];
u1(pi/128) q[73];
u1(pi/64) q[79];
cx q[79],q[74];
u1(-pi/64) q[74];
cx q[79],q[74];
u1(pi/64) q[74];
u1(pi/32) q[79];
cx q[79],q[75];
u1(-pi/32) q[75];
cx q[79],q[75];
u1(pi/32) q[75];
u1(pi/16) q[79];
cx q[79],q[76];
u1(-pi/16) q[76];
cx q[79],q[76];
u1(pi/16) q[76];
u1(pi/8) q[79];
cx q[79],q[77];
u1(-pi/8) q[77];
cx q[79],q[77];
u1(pi/8) q[77];
u1(pi/4) q[79];
cx q[79],q[78];
u1(-pi/4) q[78];
cx q[79],q[78];
u1(pi/4) q[78];
h q[79];
u1(0) q[80];
cx q[80],q[0];
u1(0) q[0];
cx q[80],q[0];
u1(0) q[0];
u1(0) q[80];
cx q[80],q[1];
u1(0) q[1];
cx q[80],q[1];
u1(0) q[1];
u1(0) q[80];
cx q[80],q[2];
u1(0) q[2];
cx q[80],q[2];
u1(0) q[2];
u1(0) q[80];
cx q[80],q[3];
u1(0) q[3];
cx q[80],q[3];
u1(0) q[3];
u1(0) q[80];
cx q[80],q[4];
u1(0) q[4];
cx q[80],q[4];
u1(0) q[4];
u1(0) q[80];
cx q[80],q[5];
u1(0) q[5];
cx q[80],q[5];
u1(0) q[5];
u1(0) q[80];
cx q[80],q[6];
u1(0) q[6];
cx q[80],q[6];
u1(0) q[6];
u1(0) q[80];
cx q[80],q[7];
u1(0) q[7];
cx q[80],q[7];
u1(0) q[7];
u1(0) q[80];
cx q[80],q[8];
u1(0) q[8];
cx q[80],q[8];
u1(0) q[8];
u1(0) q[80];
cx q[80],q[9];
u1(0) q[9];
cx q[80],q[9];
u1(0) q[9];
u1(0) q[80];
cx q[80],q[10];
u1(0) q[10];
cx q[80],q[10];
u1(0) q[10];
u1(0) q[80];
cx q[80],q[11];
u1(0) q[11];
cx q[80],q[11];
u1(0) q[11];
u1(0) q[80];
cx q[80],q[12];
u1(0) q[12];
cx q[80],q[12];
u1(0) q[12];
u1(0) q[80];
cx q[80],q[13];
u1(0) q[13];
cx q[80],q[13];
u1(0) q[13];
u1(0) q[80];
cx q[80],q[14];
u1(0) q[14];
cx q[80],q[14];
u1(0) q[14];
u1(0) q[80];
cx q[80],q[15];
u1(0) q[15];
cx q[80],q[15];
u1(0) q[15];
u1(0) q[80];
cx q[80],q[16];
u1(0) q[16];
cx q[80],q[16];
u1(0) q[16];
u1(0) q[80];
cx q[80],q[17];
u1(0) q[17];
cx q[80],q[17];
u1(0) q[17];
u1(0) q[80];
cx q[80],q[18];
u1(0) q[18];
cx q[80],q[18];
u1(0) q[18];
u1(0) q[80];
cx q[80],q[19];
u1(0) q[19];
cx q[80],q[19];
u1(0) q[19];
u1(0) q[80];
cx q[80],q[20];
u1(0) q[20];
cx q[80],q[20];
u1(0) q[20];
u1(0) q[80];
cx q[80],q[21];
u1(0) q[21];
cx q[80],q[21];
u1(0) q[21];
u1(0) q[80];
cx q[80],q[22];
u1(0) q[22];
cx q[80],q[22];
u1(0) q[22];
u1(0) q[80];
cx q[80],q[23];
u1(0) q[23];
cx q[80],q[23];
u1(0) q[23];
u1(0) q[80];
cx q[80],q[24];
u1(0) q[24];
cx q[80],q[24];
u1(0) q[24];
u1(0) q[80];
cx q[80],q[25];
u1(0) q[25];
cx q[80],q[25];
u1(0) q[25];
u1(0) q[80];
cx q[80],q[26];
u1(0) q[26];
cx q[80],q[26];
u1(0) q[26];
u1(0) q[80];
cx q[80],q[27];
u1(0) q[27];
cx q[80],q[27];
u1(0) q[27];
u1(0) q[80];
cx q[80],q[28];
u1(0) q[28];
cx q[80],q[28];
u1(0) q[28];
u1(0) q[80];
cx q[80],q[29];
u1(0) q[29];
cx q[80],q[29];
u1(0) q[29];
u1(0) q[80];
cx q[80],q[30];
u1(0) q[30];
cx q[80],q[30];
u1(0) q[30];
u1(0) q[80];
cx q[80],q[31];
u1(0) q[31];
cx q[80],q[31];
u1(0) q[31];
u1(0) q[80];
cx q[80],q[32];
u1(0) q[32];
cx q[80],q[32];
u1(0) q[32];
u1(pi/281474976710656) q[80];
cx q[80],q[33];
u1(-pi/281474976710656) q[33];
cx q[80],q[33];
u1(pi/281474976710656) q[33];
u1(pi/140737488355328) q[80];
cx q[80],q[34];
u1(-pi/140737488355328) q[34];
cx q[80],q[34];
u1(pi/140737488355328) q[34];
u1(pi/70368744177664) q[80];
cx q[80],q[35];
u1(-pi/70368744177664) q[35];
cx q[80],q[35];
u1(pi/70368744177664) q[35];
u1(pi/35184372088832) q[80];
cx q[80],q[36];
u1(-pi/35184372088832) q[36];
cx q[80],q[36];
u1(pi/35184372088832) q[36];
u1(pi/17592186044416) q[80];
cx q[80],q[37];
u1(-pi/17592186044416) q[37];
cx q[80],q[37];
u1(pi/17592186044416) q[37];
u1(pi/8796093022208) q[80];
cx q[80],q[38];
u1(-pi/8796093022208) q[38];
cx q[80],q[38];
u1(pi/8796093022208) q[38];
u1(pi/4398046511104) q[80];
cx q[80],q[39];
u1(-pi/4398046511104) q[39];
cx q[80],q[39];
u1(pi/4398046511104) q[39];
u1(pi/2199023255552) q[80];
cx q[80],q[40];
u1(-pi/2199023255552) q[40];
cx q[80],q[40];
u1(pi/2199023255552) q[40];
u1(pi/1099511627776) q[80];
cx q[80],q[41];
u1(-pi/1099511627776) q[41];
cx q[80],q[41];
u1(pi/1099511627776) q[41];
u1(pi/549755813888) q[80];
cx q[80],q[42];
u1(-pi/549755813888) q[42];
cx q[80],q[42];
u1(pi/549755813888) q[42];
u1(pi/274877906944) q[80];
cx q[80],q[43];
u1(-pi/274877906944) q[43];
cx q[80],q[43];
u1(pi/274877906944) q[43];
u1(pi/137438953472) q[80];
cx q[80],q[44];
u1(-pi/137438953472) q[44];
cx q[80],q[44];
u1(pi/137438953472) q[44];
u1(pi/68719476736) q[80];
cx q[80],q[45];
u1(-pi/68719476736) q[45];
cx q[80],q[45];
u1(pi/68719476736) q[45];
u1(pi/34359738368) q[80];
cx q[80],q[46];
u1(-pi/34359738368) q[46];
cx q[80],q[46];
u1(pi/34359738368) q[46];
u1(pi/17179869184) q[80];
cx q[80],q[47];
u1(-pi/17179869184) q[47];
cx q[80],q[47];
u1(pi/17179869184) q[47];
u1(pi/8589934592) q[80];
cx q[80],q[48];
u1(-pi/8589934592) q[48];
cx q[80],q[48];
u1(pi/8589934592) q[48];
u1(pi/4294967296) q[80];
cx q[80],q[49];
u1(-pi/4294967296) q[49];
cx q[80],q[49];
u1(pi/4294967296) q[49];
u1(pi/2147483648) q[80];
cx q[80],q[50];
u1(-pi/2147483648) q[50];
cx q[80],q[50];
u1(pi/2147483648) q[50];
u1(pi/1073741824) q[80];
cx q[80],q[51];
u1(-pi/1073741824) q[51];
cx q[80],q[51];
u1(pi/1073741824) q[51];
u1(pi/536870912) q[80];
cx q[80],q[52];
u1(-pi/536870912) q[52];
cx q[80],q[52];
u1(pi/536870912) q[52];
u1(pi/268435456) q[80];
cx q[80],q[53];
u1(-pi/268435456) q[53];
cx q[80],q[53];
u1(pi/268435456) q[53];
u1(pi/134217728) q[80];
cx q[80],q[54];
u1(-pi/134217728) q[54];
cx q[80],q[54];
u1(pi/134217728) q[54];
u1(pi/67108864) q[80];
cx q[80],q[55];
u1(-pi/67108864) q[55];
cx q[80],q[55];
u1(pi/67108864) q[55];
u1(pi/33554432) q[80];
cx q[80],q[56];
u1(-pi/33554432) q[56];
cx q[80],q[56];
u1(pi/33554432) q[56];
u1(pi/16777216) q[80];
cx q[80],q[57];
u1(-pi/16777216) q[57];
cx q[80],q[57];
u1(pi/16777216) q[57];
u1(pi/8388608) q[80];
cx q[80],q[58];
u1(-pi/8388608) q[58];
cx q[80],q[58];
u1(pi/8388608) q[58];
u1(pi/4194304) q[80];
cx q[80],q[59];
u1(-pi/4194304) q[59];
cx q[80],q[59];
u1(pi/4194304) q[59];
u1(pi/2097152) q[80];
cx q[80],q[60];
u1(-pi/2097152) q[60];
cx q[80],q[60];
u1(pi/2097152) q[60];
u1(pi/1048576) q[80];
cx q[80],q[61];
u1(-pi/1048576) q[61];
cx q[80],q[61];
u1(pi/1048576) q[61];
u1(pi/524288) q[80];
cx q[80],q[62];
u1(-pi/524288) q[62];
cx q[80],q[62];
u1(pi/524288) q[62];
u1(pi/262144) q[80];
cx q[80],q[63];
u1(-pi/262144) q[63];
cx q[80],q[63];
u1(pi/262144) q[63];
u1(pi/131072) q[80];
cx q[80],q[64];
u1(-pi/131072) q[64];
cx q[80],q[64];
u1(pi/131072) q[64];
u1(pi/65536) q[80];
cx q[80],q[65];
u1(-pi/65536) q[65];
cx q[80],q[65];
u1(pi/65536) q[65];
u1(pi/32768) q[80];
cx q[80],q[66];
u1(-pi/32768) q[66];
cx q[80],q[66];
u1(pi/32768) q[66];
u1(pi/16384) q[80];
cx q[80],q[67];
u1(-pi/16384) q[67];
cx q[80],q[67];
u1(pi/16384) q[67];
u1(pi/8192) q[80];
cx q[80],q[68];
u1(-pi/8192) q[68];
cx q[80],q[68];
u1(pi/8192) q[68];
u1(pi/4096) q[80];
cx q[80],q[69];
u1(-pi/4096) q[69];
cx q[80],q[69];
u1(pi/4096) q[69];
u1(pi/2048) q[80];
cx q[80],q[70];
u1(-pi/2048) q[70];
cx q[80],q[70];
u1(pi/2048) q[70];
u1(pi/1024) q[80];
cx q[80],q[71];
u1(-pi/1024) q[71];
cx q[80],q[71];
u1(pi/1024) q[71];
u1(pi/512) q[80];
cx q[80],q[72];
u1(-pi/512) q[72];
cx q[80],q[72];
u1(pi/512) q[72];
u1(pi/256) q[80];
cx q[80],q[73];
u1(-pi/256) q[73];
cx q[80],q[73];
u1(pi/256) q[73];
u1(pi/128) q[80];
cx q[80],q[74];
u1(-pi/128) q[74];
cx q[80],q[74];
u1(pi/128) q[74];
u1(pi/64) q[80];
cx q[80],q[75];
u1(-pi/64) q[75];
cx q[80],q[75];
u1(pi/64) q[75];
u1(pi/32) q[80];
cx q[80],q[76];
u1(-pi/32) q[76];
cx q[80],q[76];
u1(pi/32) q[76];
u1(pi/16) q[80];
cx q[80],q[77];
u1(-pi/16) q[77];
cx q[80],q[77];
u1(pi/16) q[77];
u1(pi/8) q[80];
cx q[80],q[78];
u1(-pi/8) q[78];
cx q[80],q[78];
u1(pi/8) q[78];
u1(pi/4) q[80];
cx q[80],q[79];
u1(-pi/4) q[79];
cx q[80],q[79];
u1(pi/4) q[79];
h q[80];
u1(0) q[81];
cx q[81],q[0];
u1(0) q[0];
cx q[81],q[0];
u1(0) q[0];
u1(0) q[81];
cx q[81],q[1];
u1(0) q[1];
cx q[81],q[1];
u1(0) q[1];
u1(0) q[81];
cx q[81],q[2];
u1(0) q[2];
cx q[81],q[2];
u1(0) q[2];
u1(0) q[81];
cx q[81],q[3];
u1(0) q[3];
cx q[81],q[3];
u1(0) q[3];
u1(0) q[81];
cx q[81],q[4];
u1(0) q[4];
cx q[81],q[4];
u1(0) q[4];
u1(0) q[81];
cx q[81],q[5];
u1(0) q[5];
cx q[81],q[5];
u1(0) q[5];
u1(0) q[81];
cx q[81],q[6];
u1(0) q[6];
cx q[81],q[6];
u1(0) q[6];
u1(0) q[81];
cx q[81],q[7];
u1(0) q[7];
cx q[81],q[7];
u1(0) q[7];
u1(0) q[81];
cx q[81],q[8];
u1(0) q[8];
cx q[81],q[8];
u1(0) q[8];
u1(0) q[81];
cx q[81],q[9];
u1(0) q[9];
cx q[81],q[9];
u1(0) q[9];
u1(0) q[81];
cx q[81],q[10];
u1(0) q[10];
cx q[81],q[10];
u1(0) q[10];
u1(0) q[81];
cx q[81],q[11];
u1(0) q[11];
cx q[81],q[11];
u1(0) q[11];
u1(0) q[81];
cx q[81],q[12];
u1(0) q[12];
cx q[81],q[12];
u1(0) q[12];
u1(0) q[81];
cx q[81],q[13];
u1(0) q[13];
cx q[81],q[13];
u1(0) q[13];
u1(0) q[81];
cx q[81],q[14];
u1(0) q[14];
cx q[81],q[14];
u1(0) q[14];
u1(0) q[81];
cx q[81],q[15];
u1(0) q[15];
cx q[81],q[15];
u1(0) q[15];
u1(0) q[81];
cx q[81],q[16];
u1(0) q[16];
cx q[81],q[16];
u1(0) q[16];
u1(0) q[81];
cx q[81],q[17];
u1(0) q[17];
cx q[81],q[17];
u1(0) q[17];
u1(0) q[81];
cx q[81],q[18];
u1(0) q[18];
cx q[81],q[18];
u1(0) q[18];
u1(0) q[81];
cx q[81],q[19];
u1(0) q[19];
cx q[81],q[19];
u1(0) q[19];
u1(0) q[81];
cx q[81],q[20];
u1(0) q[20];
cx q[81],q[20];
u1(0) q[20];
u1(0) q[81];
cx q[81],q[21];
u1(0) q[21];
cx q[81],q[21];
u1(0) q[21];
u1(0) q[81];
cx q[81],q[22];
u1(0) q[22];
cx q[81],q[22];
u1(0) q[22];
u1(0) q[81];
cx q[81],q[23];
u1(0) q[23];
cx q[81],q[23];
u1(0) q[23];
u1(0) q[81];
cx q[81],q[24];
u1(0) q[24];
cx q[81],q[24];
u1(0) q[24];
u1(0) q[81];
cx q[81],q[25];
u1(0) q[25];
cx q[81],q[25];
u1(0) q[25];
u1(0) q[81];
cx q[81],q[26];
u1(0) q[26];
cx q[81],q[26];
u1(0) q[26];
u1(0) q[81];
cx q[81],q[27];
u1(0) q[27];
cx q[81],q[27];
u1(0) q[27];
u1(0) q[81];
cx q[81],q[28];
u1(0) q[28];
cx q[81],q[28];
u1(0) q[28];
u1(0) q[81];
cx q[81],q[29];
u1(0) q[29];
cx q[81],q[29];
u1(0) q[29];
u1(0) q[81];
cx q[81],q[30];
u1(0) q[30];
cx q[81],q[30];
u1(0) q[30];
u1(0) q[81];
cx q[81],q[31];
u1(0) q[31];
cx q[81],q[31];
u1(0) q[31];
u1(0) q[81];
cx q[81],q[32];
u1(0) q[32];
cx q[81],q[32];
u1(0) q[32];
u1(0) q[81];
cx q[81],q[33];
u1(0) q[33];
cx q[81],q[33];
u1(0) q[33];
u1(pi/281474976710656) q[81];
cx q[81],q[34];
u1(-pi/281474976710656) q[34];
cx q[81],q[34];
u1(pi/281474976710656) q[34];
u1(pi/140737488355328) q[81];
cx q[81],q[35];
u1(-pi/140737488355328) q[35];
cx q[81],q[35];
u1(pi/140737488355328) q[35];
u1(pi/70368744177664) q[81];
cx q[81],q[36];
u1(-pi/70368744177664) q[36];
cx q[81],q[36];
u1(pi/70368744177664) q[36];
u1(pi/35184372088832) q[81];
cx q[81],q[37];
u1(-pi/35184372088832) q[37];
cx q[81],q[37];
u1(pi/35184372088832) q[37];
u1(pi/17592186044416) q[81];
cx q[81],q[38];
u1(-pi/17592186044416) q[38];
cx q[81],q[38];
u1(pi/17592186044416) q[38];
u1(pi/8796093022208) q[81];
cx q[81],q[39];
u1(-pi/8796093022208) q[39];
cx q[81],q[39];
u1(pi/8796093022208) q[39];
u1(pi/4398046511104) q[81];
cx q[81],q[40];
u1(-pi/4398046511104) q[40];
cx q[81],q[40];
u1(pi/4398046511104) q[40];
u1(pi/2199023255552) q[81];
cx q[81],q[41];
u1(-pi/2199023255552) q[41];
cx q[81],q[41];
u1(pi/2199023255552) q[41];
u1(pi/1099511627776) q[81];
cx q[81],q[42];
u1(-pi/1099511627776) q[42];
cx q[81],q[42];
u1(pi/1099511627776) q[42];
u1(pi/549755813888) q[81];
cx q[81],q[43];
u1(-pi/549755813888) q[43];
cx q[81],q[43];
u1(pi/549755813888) q[43];
u1(pi/274877906944) q[81];
cx q[81],q[44];
u1(-pi/274877906944) q[44];
cx q[81],q[44];
u1(pi/274877906944) q[44];
u1(pi/137438953472) q[81];
cx q[81],q[45];
u1(-pi/137438953472) q[45];
cx q[81],q[45];
u1(pi/137438953472) q[45];
u1(pi/68719476736) q[81];
cx q[81],q[46];
u1(-pi/68719476736) q[46];
cx q[81],q[46];
u1(pi/68719476736) q[46];
u1(pi/34359738368) q[81];
cx q[81],q[47];
u1(-pi/34359738368) q[47];
cx q[81],q[47];
u1(pi/34359738368) q[47];
u1(pi/17179869184) q[81];
cx q[81],q[48];
u1(-pi/17179869184) q[48];
cx q[81],q[48];
u1(pi/17179869184) q[48];
u1(pi/8589934592) q[81];
cx q[81],q[49];
u1(-pi/8589934592) q[49];
cx q[81],q[49];
u1(pi/8589934592) q[49];
u1(pi/4294967296) q[81];
cx q[81],q[50];
u1(-pi/4294967296) q[50];
cx q[81],q[50];
u1(pi/4294967296) q[50];
u1(pi/2147483648) q[81];
cx q[81],q[51];
u1(-pi/2147483648) q[51];
cx q[81],q[51];
u1(pi/2147483648) q[51];
u1(pi/1073741824) q[81];
cx q[81],q[52];
u1(-pi/1073741824) q[52];
cx q[81],q[52];
u1(pi/1073741824) q[52];
u1(pi/536870912) q[81];
cx q[81],q[53];
u1(-pi/536870912) q[53];
cx q[81],q[53];
u1(pi/536870912) q[53];
u1(pi/268435456) q[81];
cx q[81],q[54];
u1(-pi/268435456) q[54];
cx q[81],q[54];
u1(pi/268435456) q[54];
u1(pi/134217728) q[81];
cx q[81],q[55];
u1(-pi/134217728) q[55];
cx q[81],q[55];
u1(pi/134217728) q[55];
u1(pi/67108864) q[81];
cx q[81],q[56];
u1(-pi/67108864) q[56];
cx q[81],q[56];
u1(pi/67108864) q[56];
u1(pi/33554432) q[81];
cx q[81],q[57];
u1(-pi/33554432) q[57];
cx q[81],q[57];
u1(pi/33554432) q[57];
u1(pi/16777216) q[81];
cx q[81],q[58];
u1(-pi/16777216) q[58];
cx q[81],q[58];
u1(pi/16777216) q[58];
u1(pi/8388608) q[81];
cx q[81],q[59];
u1(-pi/8388608) q[59];
cx q[81],q[59];
u1(pi/8388608) q[59];
u1(pi/4194304) q[81];
cx q[81],q[60];
u1(-pi/4194304) q[60];
cx q[81],q[60];
u1(pi/4194304) q[60];
u1(pi/2097152) q[81];
cx q[81],q[61];
u1(-pi/2097152) q[61];
cx q[81],q[61];
u1(pi/2097152) q[61];
u1(pi/1048576) q[81];
cx q[81],q[62];
u1(-pi/1048576) q[62];
cx q[81],q[62];
u1(pi/1048576) q[62];
u1(pi/524288) q[81];
cx q[81],q[63];
u1(-pi/524288) q[63];
cx q[81],q[63];
u1(pi/524288) q[63];
u1(pi/262144) q[81];
cx q[81],q[64];
u1(-pi/262144) q[64];
cx q[81],q[64];
u1(pi/262144) q[64];
u1(pi/131072) q[81];
cx q[81],q[65];
u1(-pi/131072) q[65];
cx q[81],q[65];
u1(pi/131072) q[65];
u1(pi/65536) q[81];
cx q[81],q[66];
u1(-pi/65536) q[66];
cx q[81],q[66];
u1(pi/65536) q[66];
u1(pi/32768) q[81];
cx q[81],q[67];
u1(-pi/32768) q[67];
cx q[81],q[67];
u1(pi/32768) q[67];
u1(pi/16384) q[81];
cx q[81],q[68];
u1(-pi/16384) q[68];
cx q[81],q[68];
u1(pi/16384) q[68];
u1(pi/8192) q[81];
cx q[81],q[69];
u1(-pi/8192) q[69];
cx q[81],q[69];
u1(pi/8192) q[69];
u1(pi/4096) q[81];
cx q[81],q[70];
u1(-pi/4096) q[70];
cx q[81],q[70];
u1(pi/4096) q[70];
u1(pi/2048) q[81];
cx q[81],q[71];
u1(-pi/2048) q[71];
cx q[81],q[71];
u1(pi/2048) q[71];
u1(pi/1024) q[81];
cx q[81],q[72];
u1(-pi/1024) q[72];
cx q[81],q[72];
u1(pi/1024) q[72];
u1(pi/512) q[81];
cx q[81],q[73];
u1(-pi/512) q[73];
cx q[81],q[73];
u1(pi/512) q[73];
u1(pi/256) q[81];
cx q[81],q[74];
u1(-pi/256) q[74];
cx q[81],q[74];
u1(pi/256) q[74];
u1(pi/128) q[81];
cx q[81],q[75];
u1(-pi/128) q[75];
cx q[81],q[75];
u1(pi/128) q[75];
u1(pi/64) q[81];
cx q[81],q[76];
u1(-pi/64) q[76];
cx q[81],q[76];
u1(pi/64) q[76];
u1(pi/32) q[81];
cx q[81],q[77];
u1(-pi/32) q[77];
cx q[81],q[77];
u1(pi/32) q[77];
u1(pi/16) q[81];
cx q[81],q[78];
u1(-pi/16) q[78];
cx q[81],q[78];
u1(pi/16) q[78];
u1(pi/8) q[81];
cx q[81],q[79];
u1(-pi/8) q[79];
cx q[81],q[79];
u1(pi/8) q[79];
u1(pi/4) q[81];
cx q[81],q[80];
u1(-pi/4) q[80];
cx q[81],q[80];
u1(pi/4) q[80];
h q[81];
u1(0) q[82];
cx q[82],q[0];
u1(0) q[0];
cx q[82],q[0];
u1(0) q[0];
u1(0) q[82];
cx q[82],q[1];
u1(0) q[1];
cx q[82],q[1];
u1(0) q[1];
u1(0) q[82];
cx q[82],q[2];
u1(0) q[2];
cx q[82],q[2];
u1(0) q[2];
u1(0) q[82];
cx q[82],q[3];
u1(0) q[3];
cx q[82],q[3];
u1(0) q[3];
u1(0) q[82];
cx q[82],q[4];
u1(0) q[4];
cx q[82],q[4];
u1(0) q[4];
u1(0) q[82];
cx q[82],q[5];
u1(0) q[5];
cx q[82],q[5];
u1(0) q[5];
u1(0) q[82];
cx q[82],q[6];
u1(0) q[6];
cx q[82],q[6];
u1(0) q[6];
u1(0) q[82];
cx q[82],q[7];
u1(0) q[7];
cx q[82],q[7];
u1(0) q[7];
u1(0) q[82];
cx q[82],q[8];
u1(0) q[8];
cx q[82],q[8];
u1(0) q[8];
u1(0) q[82];
cx q[82],q[9];
u1(0) q[9];
cx q[82],q[9];
u1(0) q[9];
u1(0) q[82];
cx q[82],q[10];
u1(0) q[10];
cx q[82],q[10];
u1(0) q[10];
u1(0) q[82];
cx q[82],q[11];
u1(0) q[11];
cx q[82],q[11];
u1(0) q[11];
u1(0) q[82];
cx q[82],q[12];
u1(0) q[12];
cx q[82],q[12];
u1(0) q[12];
u1(0) q[82];
cx q[82],q[13];
u1(0) q[13];
cx q[82],q[13];
u1(0) q[13];
u1(0) q[82];
cx q[82],q[14];
u1(0) q[14];
cx q[82],q[14];
u1(0) q[14];
u1(0) q[82];
cx q[82],q[15];
u1(0) q[15];
cx q[82],q[15];
u1(0) q[15];
u1(0) q[82];
cx q[82],q[16];
u1(0) q[16];
cx q[82],q[16];
u1(0) q[16];
u1(0) q[82];
cx q[82],q[17];
u1(0) q[17];
cx q[82],q[17];
u1(0) q[17];
u1(0) q[82];
cx q[82],q[18];
u1(0) q[18];
cx q[82],q[18];
u1(0) q[18];
u1(0) q[82];
cx q[82],q[19];
u1(0) q[19];
cx q[82],q[19];
u1(0) q[19];
u1(0) q[82];
cx q[82],q[20];
u1(0) q[20];
cx q[82],q[20];
u1(0) q[20];
u1(0) q[82];
cx q[82],q[21];
u1(0) q[21];
cx q[82],q[21];
u1(0) q[21];
u1(0) q[82];
cx q[82],q[22];
u1(0) q[22];
cx q[82],q[22];
u1(0) q[22];
u1(0) q[82];
cx q[82],q[23];
u1(0) q[23];
cx q[82],q[23];
u1(0) q[23];
u1(0) q[82];
cx q[82],q[24];
u1(0) q[24];
cx q[82],q[24];
u1(0) q[24];
u1(0) q[82];
cx q[82],q[25];
u1(0) q[25];
cx q[82],q[25];
u1(0) q[25];
u1(0) q[82];
cx q[82],q[26];
u1(0) q[26];
cx q[82],q[26];
u1(0) q[26];
u1(0) q[82];
cx q[82],q[27];
u1(0) q[27];
cx q[82],q[27];
u1(0) q[27];
u1(0) q[82];
cx q[82],q[28];
u1(0) q[28];
cx q[82],q[28];
u1(0) q[28];
u1(0) q[82];
cx q[82],q[29];
u1(0) q[29];
cx q[82],q[29];
u1(0) q[29];
u1(0) q[82];
cx q[82],q[30];
u1(0) q[30];
cx q[82],q[30];
u1(0) q[30];
u1(0) q[82];
cx q[82],q[31];
u1(0) q[31];
cx q[82],q[31];
u1(0) q[31];
u1(0) q[82];
cx q[82],q[32];
u1(0) q[32];
cx q[82],q[32];
u1(0) q[32];
u1(0) q[82];
cx q[82],q[33];
u1(0) q[33];
cx q[82],q[33];
u1(0) q[33];
u1(0) q[82];
cx q[82],q[34];
u1(0) q[34];
cx q[82],q[34];
u1(0) q[34];
u1(pi/281474976710656) q[82];
cx q[82],q[35];
u1(-pi/281474976710656) q[35];
cx q[82],q[35];
u1(pi/281474976710656) q[35];
u1(pi/140737488355328) q[82];
cx q[82],q[36];
u1(-pi/140737488355328) q[36];
cx q[82],q[36];
u1(pi/140737488355328) q[36];
u1(pi/70368744177664) q[82];
cx q[82],q[37];
u1(-pi/70368744177664) q[37];
cx q[82],q[37];
u1(pi/70368744177664) q[37];
u1(pi/35184372088832) q[82];
cx q[82],q[38];
u1(-pi/35184372088832) q[38];
cx q[82],q[38];
u1(pi/35184372088832) q[38];
u1(pi/17592186044416) q[82];
cx q[82],q[39];
u1(-pi/17592186044416) q[39];
cx q[82],q[39];
u1(pi/17592186044416) q[39];
u1(pi/8796093022208) q[82];
cx q[82],q[40];
u1(-pi/8796093022208) q[40];
cx q[82],q[40];
u1(pi/8796093022208) q[40];
u1(pi/4398046511104) q[82];
cx q[82],q[41];
u1(-pi/4398046511104) q[41];
cx q[82],q[41];
u1(pi/4398046511104) q[41];
u1(pi/2199023255552) q[82];
cx q[82],q[42];
u1(-pi/2199023255552) q[42];
cx q[82],q[42];
u1(pi/2199023255552) q[42];
u1(pi/1099511627776) q[82];
cx q[82],q[43];
u1(-pi/1099511627776) q[43];
cx q[82],q[43];
u1(pi/1099511627776) q[43];
u1(pi/549755813888) q[82];
cx q[82],q[44];
u1(-pi/549755813888) q[44];
cx q[82],q[44];
u1(pi/549755813888) q[44];
u1(pi/274877906944) q[82];
cx q[82],q[45];
u1(-pi/274877906944) q[45];
cx q[82],q[45];
u1(pi/274877906944) q[45];
u1(pi/137438953472) q[82];
cx q[82],q[46];
u1(-pi/137438953472) q[46];
cx q[82],q[46];
u1(pi/137438953472) q[46];
u1(pi/68719476736) q[82];
cx q[82],q[47];
u1(-pi/68719476736) q[47];
cx q[82],q[47];
u1(pi/68719476736) q[47];
u1(pi/34359738368) q[82];
cx q[82],q[48];
u1(-pi/34359738368) q[48];
cx q[82],q[48];
u1(pi/34359738368) q[48];
u1(pi/17179869184) q[82];
cx q[82],q[49];
u1(-pi/17179869184) q[49];
cx q[82],q[49];
u1(pi/17179869184) q[49];
u1(pi/8589934592) q[82];
cx q[82],q[50];
u1(-pi/8589934592) q[50];
cx q[82],q[50];
u1(pi/8589934592) q[50];
u1(pi/4294967296) q[82];
cx q[82],q[51];
u1(-pi/4294967296) q[51];
cx q[82],q[51];
u1(pi/4294967296) q[51];
u1(pi/2147483648) q[82];
cx q[82],q[52];
u1(-pi/2147483648) q[52];
cx q[82],q[52];
u1(pi/2147483648) q[52];
u1(pi/1073741824) q[82];
cx q[82],q[53];
u1(-pi/1073741824) q[53];
cx q[82],q[53];
u1(pi/1073741824) q[53];
u1(pi/536870912) q[82];
cx q[82],q[54];
u1(-pi/536870912) q[54];
cx q[82],q[54];
u1(pi/536870912) q[54];
u1(pi/268435456) q[82];
cx q[82],q[55];
u1(-pi/268435456) q[55];
cx q[82],q[55];
u1(pi/268435456) q[55];
u1(pi/134217728) q[82];
cx q[82],q[56];
u1(-pi/134217728) q[56];
cx q[82],q[56];
u1(pi/134217728) q[56];
u1(pi/67108864) q[82];
cx q[82],q[57];
u1(-pi/67108864) q[57];
cx q[82],q[57];
u1(pi/67108864) q[57];
u1(pi/33554432) q[82];
cx q[82],q[58];
u1(-pi/33554432) q[58];
cx q[82],q[58];
u1(pi/33554432) q[58];
u1(pi/16777216) q[82];
cx q[82],q[59];
u1(-pi/16777216) q[59];
cx q[82],q[59];
u1(pi/16777216) q[59];
u1(pi/8388608) q[82];
cx q[82],q[60];
u1(-pi/8388608) q[60];
cx q[82],q[60];
u1(pi/8388608) q[60];
u1(pi/4194304) q[82];
cx q[82],q[61];
u1(-pi/4194304) q[61];
cx q[82],q[61];
u1(pi/4194304) q[61];
u1(pi/2097152) q[82];
cx q[82],q[62];
u1(-pi/2097152) q[62];
cx q[82],q[62];
u1(pi/2097152) q[62];
u1(pi/1048576) q[82];
cx q[82],q[63];
u1(-pi/1048576) q[63];
cx q[82],q[63];
u1(pi/1048576) q[63];
u1(pi/524288) q[82];
cx q[82],q[64];
u1(-pi/524288) q[64];
cx q[82],q[64];
u1(pi/524288) q[64];
u1(pi/262144) q[82];
cx q[82],q[65];
u1(-pi/262144) q[65];
cx q[82],q[65];
u1(pi/262144) q[65];
u1(pi/131072) q[82];
cx q[82],q[66];
u1(-pi/131072) q[66];
cx q[82],q[66];
u1(pi/131072) q[66];
u1(pi/65536) q[82];
cx q[82],q[67];
u1(-pi/65536) q[67];
cx q[82],q[67];
u1(pi/65536) q[67];
u1(pi/32768) q[82];
cx q[82],q[68];
u1(-pi/32768) q[68];
cx q[82],q[68];
u1(pi/32768) q[68];
u1(pi/16384) q[82];
cx q[82],q[69];
u1(-pi/16384) q[69];
cx q[82],q[69];
u1(pi/16384) q[69];
u1(pi/8192) q[82];
cx q[82],q[70];
u1(-pi/8192) q[70];
cx q[82],q[70];
u1(pi/8192) q[70];
u1(pi/4096) q[82];
cx q[82],q[71];
u1(-pi/4096) q[71];
cx q[82],q[71];
u1(pi/4096) q[71];
u1(pi/2048) q[82];
cx q[82],q[72];
u1(-pi/2048) q[72];
cx q[82],q[72];
u1(pi/2048) q[72];
u1(pi/1024) q[82];
cx q[82],q[73];
u1(-pi/1024) q[73];
cx q[82],q[73];
u1(pi/1024) q[73];
u1(pi/512) q[82];
cx q[82],q[74];
u1(-pi/512) q[74];
cx q[82],q[74];
u1(pi/512) q[74];
u1(pi/256) q[82];
cx q[82],q[75];
u1(-pi/256) q[75];
cx q[82],q[75];
u1(pi/256) q[75];
u1(pi/128) q[82];
cx q[82],q[76];
u1(-pi/128) q[76];
cx q[82],q[76];
u1(pi/128) q[76];
u1(pi/64) q[82];
cx q[82],q[77];
u1(-pi/64) q[77];
cx q[82],q[77];
u1(pi/64) q[77];
u1(pi/32) q[82];
cx q[82],q[78];
u1(-pi/32) q[78];
cx q[82],q[78];
u1(pi/32) q[78];
u1(pi/16) q[82];
cx q[82],q[79];
u1(-pi/16) q[79];
cx q[82],q[79];
u1(pi/16) q[79];
u1(pi/8) q[82];
cx q[82],q[80];
u1(-pi/8) q[80];
cx q[82],q[80];
u1(pi/8) q[80];
u1(pi/4) q[82];
cx q[82],q[81];
u1(-pi/4) q[81];
cx q[82],q[81];
u1(pi/4) q[81];
h q[82];
u1(0) q[83];
cx q[83],q[0];
u1(0) q[0];
cx q[83],q[0];
u1(0) q[0];
u1(0) q[83];
cx q[83],q[1];
u1(0) q[1];
cx q[83],q[1];
u1(0) q[1];
u1(0) q[83];
cx q[83],q[2];
u1(0) q[2];
cx q[83],q[2];
u1(0) q[2];
u1(0) q[83];
cx q[83],q[3];
u1(0) q[3];
cx q[83],q[3];
u1(0) q[3];
u1(0) q[83];
cx q[83],q[4];
u1(0) q[4];
cx q[83],q[4];
u1(0) q[4];
u1(0) q[83];
cx q[83],q[5];
u1(0) q[5];
cx q[83],q[5];
u1(0) q[5];
u1(0) q[83];
cx q[83],q[6];
u1(0) q[6];
cx q[83],q[6];
u1(0) q[6];
u1(0) q[83];
cx q[83],q[7];
u1(0) q[7];
cx q[83],q[7];
u1(0) q[7];
u1(0) q[83];
cx q[83],q[8];
u1(0) q[8];
cx q[83],q[8];
u1(0) q[8];
u1(0) q[83];
cx q[83],q[9];
u1(0) q[9];
cx q[83],q[9];
u1(0) q[9];
u1(0) q[83];
cx q[83],q[10];
u1(0) q[10];
cx q[83],q[10];
u1(0) q[10];
u1(0) q[83];
cx q[83],q[11];
u1(0) q[11];
cx q[83],q[11];
u1(0) q[11];
u1(0) q[83];
cx q[83],q[12];
u1(0) q[12];
cx q[83],q[12];
u1(0) q[12];
u1(0) q[83];
cx q[83],q[13];
u1(0) q[13];
cx q[83],q[13];
u1(0) q[13];
u1(0) q[83];
cx q[83],q[14];
u1(0) q[14];
cx q[83],q[14];
u1(0) q[14];
u1(0) q[83];
cx q[83],q[15];
u1(0) q[15];
cx q[83],q[15];
u1(0) q[15];
u1(0) q[83];
cx q[83],q[16];
u1(0) q[16];
cx q[83],q[16];
u1(0) q[16];
u1(0) q[83];
cx q[83],q[17];
u1(0) q[17];
cx q[83],q[17];
u1(0) q[17];
u1(0) q[83];
cx q[83],q[18];
u1(0) q[18];
cx q[83],q[18];
u1(0) q[18];
u1(0) q[83];
cx q[83],q[19];
u1(0) q[19];
cx q[83],q[19];
u1(0) q[19];
u1(0) q[83];
cx q[83],q[20];
u1(0) q[20];
cx q[83],q[20];
u1(0) q[20];
u1(0) q[83];
cx q[83],q[21];
u1(0) q[21];
cx q[83],q[21];
u1(0) q[21];
u1(0) q[83];
cx q[83],q[22];
u1(0) q[22];
cx q[83],q[22];
u1(0) q[22];
u1(0) q[83];
cx q[83],q[23];
u1(0) q[23];
cx q[83],q[23];
u1(0) q[23];
u1(0) q[83];
cx q[83],q[24];
u1(0) q[24];
cx q[83],q[24];
u1(0) q[24];
u1(0) q[83];
cx q[83],q[25];
u1(0) q[25];
cx q[83],q[25];
u1(0) q[25];
u1(0) q[83];
cx q[83],q[26];
u1(0) q[26];
cx q[83],q[26];
u1(0) q[26];
u1(0) q[83];
cx q[83],q[27];
u1(0) q[27];
cx q[83],q[27];
u1(0) q[27];
u1(0) q[83];
cx q[83],q[28];
u1(0) q[28];
cx q[83],q[28];
u1(0) q[28];
u1(0) q[83];
cx q[83],q[29];
u1(0) q[29];
cx q[83],q[29];
u1(0) q[29];
u1(0) q[83];
cx q[83],q[30];
u1(0) q[30];
cx q[83],q[30];
u1(0) q[30];
u1(0) q[83];
cx q[83],q[31];
u1(0) q[31];
cx q[83],q[31];
u1(0) q[31];
u1(0) q[83];
cx q[83],q[32];
u1(0) q[32];
cx q[83],q[32];
u1(0) q[32];
u1(0) q[83];
cx q[83],q[33];
u1(0) q[33];
cx q[83],q[33];
u1(0) q[33];
u1(0) q[83];
cx q[83],q[34];
u1(0) q[34];
cx q[83],q[34];
u1(0) q[34];
u1(0) q[83];
cx q[83],q[35];
u1(0) q[35];
cx q[83],q[35];
u1(0) q[35];
u1(pi/281474976710656) q[83];
cx q[83],q[36];
u1(-pi/281474976710656) q[36];
cx q[83],q[36];
u1(pi/281474976710656) q[36];
u1(pi/140737488355328) q[83];
cx q[83],q[37];
u1(-pi/140737488355328) q[37];
cx q[83],q[37];
u1(pi/140737488355328) q[37];
u1(pi/70368744177664) q[83];
cx q[83],q[38];
u1(-pi/70368744177664) q[38];
cx q[83],q[38];
u1(pi/70368744177664) q[38];
u1(pi/35184372088832) q[83];
cx q[83],q[39];
u1(-pi/35184372088832) q[39];
cx q[83],q[39];
u1(pi/35184372088832) q[39];
u1(pi/17592186044416) q[83];
cx q[83],q[40];
u1(-pi/17592186044416) q[40];
cx q[83],q[40];
u1(pi/17592186044416) q[40];
u1(pi/8796093022208) q[83];
cx q[83],q[41];
u1(-pi/8796093022208) q[41];
cx q[83],q[41];
u1(pi/8796093022208) q[41];
u1(pi/4398046511104) q[83];
cx q[83],q[42];
u1(-pi/4398046511104) q[42];
cx q[83],q[42];
u1(pi/4398046511104) q[42];
u1(pi/2199023255552) q[83];
cx q[83],q[43];
u1(-pi/2199023255552) q[43];
cx q[83],q[43];
u1(pi/2199023255552) q[43];
u1(pi/1099511627776) q[83];
cx q[83],q[44];
u1(-pi/1099511627776) q[44];
cx q[83],q[44];
u1(pi/1099511627776) q[44];
u1(pi/549755813888) q[83];
cx q[83],q[45];
u1(-pi/549755813888) q[45];
cx q[83],q[45];
u1(pi/549755813888) q[45];
u1(pi/274877906944) q[83];
cx q[83],q[46];
u1(-pi/274877906944) q[46];
cx q[83],q[46];
u1(pi/274877906944) q[46];
u1(pi/137438953472) q[83];
cx q[83],q[47];
u1(-pi/137438953472) q[47];
cx q[83],q[47];
u1(pi/137438953472) q[47];
u1(pi/68719476736) q[83];
cx q[83],q[48];
u1(-pi/68719476736) q[48];
cx q[83],q[48];
u1(pi/68719476736) q[48];
u1(pi/34359738368) q[83];
cx q[83],q[49];
u1(-pi/34359738368) q[49];
cx q[83],q[49];
u1(pi/34359738368) q[49];
u1(pi/17179869184) q[83];
cx q[83],q[50];
u1(-pi/17179869184) q[50];
cx q[83],q[50];
u1(pi/17179869184) q[50];
u1(pi/8589934592) q[83];
cx q[83],q[51];
u1(-pi/8589934592) q[51];
cx q[83],q[51];
u1(pi/8589934592) q[51];
u1(pi/4294967296) q[83];
cx q[83],q[52];
u1(-pi/4294967296) q[52];
cx q[83],q[52];
u1(pi/4294967296) q[52];
u1(pi/2147483648) q[83];
cx q[83],q[53];
u1(-pi/2147483648) q[53];
cx q[83],q[53];
u1(pi/2147483648) q[53];
u1(pi/1073741824) q[83];
cx q[83],q[54];
u1(-pi/1073741824) q[54];
cx q[83],q[54];
u1(pi/1073741824) q[54];
u1(pi/536870912) q[83];
cx q[83],q[55];
u1(-pi/536870912) q[55];
cx q[83],q[55];
u1(pi/536870912) q[55];
u1(pi/268435456) q[83];
cx q[83],q[56];
u1(-pi/268435456) q[56];
cx q[83],q[56];
u1(pi/268435456) q[56];
u1(pi/134217728) q[83];
cx q[83],q[57];
u1(-pi/134217728) q[57];
cx q[83],q[57];
u1(pi/134217728) q[57];
u1(pi/67108864) q[83];
cx q[83],q[58];
u1(-pi/67108864) q[58];
cx q[83],q[58];
u1(pi/67108864) q[58];
u1(pi/33554432) q[83];
cx q[83],q[59];
u1(-pi/33554432) q[59];
cx q[83],q[59];
u1(pi/33554432) q[59];
u1(pi/16777216) q[83];
cx q[83],q[60];
u1(-pi/16777216) q[60];
cx q[83],q[60];
u1(pi/16777216) q[60];
u1(pi/8388608) q[83];
cx q[83],q[61];
u1(-pi/8388608) q[61];
cx q[83],q[61];
u1(pi/8388608) q[61];
u1(pi/4194304) q[83];
cx q[83],q[62];
u1(-pi/4194304) q[62];
cx q[83],q[62];
u1(pi/4194304) q[62];
u1(pi/2097152) q[83];
cx q[83],q[63];
u1(-pi/2097152) q[63];
cx q[83],q[63];
u1(pi/2097152) q[63];
u1(pi/1048576) q[83];
cx q[83],q[64];
u1(-pi/1048576) q[64];
cx q[83],q[64];
u1(pi/1048576) q[64];
u1(pi/524288) q[83];
cx q[83],q[65];
u1(-pi/524288) q[65];
cx q[83],q[65];
u1(pi/524288) q[65];
u1(pi/262144) q[83];
cx q[83],q[66];
u1(-pi/262144) q[66];
cx q[83],q[66];
u1(pi/262144) q[66];
u1(pi/131072) q[83];
cx q[83],q[67];
u1(-pi/131072) q[67];
cx q[83],q[67];
u1(pi/131072) q[67];
u1(pi/65536) q[83];
cx q[83],q[68];
u1(-pi/65536) q[68];
cx q[83],q[68];
u1(pi/65536) q[68];
u1(pi/32768) q[83];
cx q[83],q[69];
u1(-pi/32768) q[69];
cx q[83],q[69];
u1(pi/32768) q[69];
u1(pi/16384) q[83];
cx q[83],q[70];
u1(-pi/16384) q[70];
cx q[83],q[70];
u1(pi/16384) q[70];
u1(pi/8192) q[83];
cx q[83],q[71];
u1(-pi/8192) q[71];
cx q[83],q[71];
u1(pi/8192) q[71];
u1(pi/4096) q[83];
cx q[83],q[72];
u1(-pi/4096) q[72];
cx q[83],q[72];
u1(pi/4096) q[72];
u1(pi/2048) q[83];
cx q[83],q[73];
u1(-pi/2048) q[73];
cx q[83],q[73];
u1(pi/2048) q[73];
u1(pi/1024) q[83];
cx q[83],q[74];
u1(-pi/1024) q[74];
cx q[83],q[74];
u1(pi/1024) q[74];
u1(pi/512) q[83];
cx q[83],q[75];
u1(-pi/512) q[75];
cx q[83],q[75];
u1(pi/512) q[75];
u1(pi/256) q[83];
cx q[83],q[76];
u1(-pi/256) q[76];
cx q[83],q[76];
u1(pi/256) q[76];
u1(pi/128) q[83];
cx q[83],q[77];
u1(-pi/128) q[77];
cx q[83],q[77];
u1(pi/128) q[77];
u1(pi/64) q[83];
cx q[83],q[78];
u1(-pi/64) q[78];
cx q[83],q[78];
u1(pi/64) q[78];
u1(pi/32) q[83];
cx q[83],q[79];
u1(-pi/32) q[79];
cx q[83],q[79];
u1(pi/32) q[79];
u1(pi/16) q[83];
cx q[83],q[80];
u1(-pi/16) q[80];
cx q[83],q[80];
u1(pi/16) q[80];
u1(pi/8) q[83];
cx q[83],q[81];
u1(-pi/8) q[81];
cx q[83],q[81];
u1(pi/8) q[81];
u1(pi/4) q[83];
cx q[83],q[82];
u1(-pi/4) q[82];
cx q[83],q[82];
u1(pi/4) q[82];
h q[83];
u1(0) q[84];
cx q[84],q[0];
u1(0) q[0];
cx q[84],q[0];
u1(0) q[0];
u1(0) q[84];
cx q[84],q[1];
u1(0) q[1];
cx q[84],q[1];
u1(0) q[1];
u1(0) q[84];
cx q[84],q[2];
u1(0) q[2];
cx q[84],q[2];
u1(0) q[2];
u1(0) q[84];
cx q[84],q[3];
u1(0) q[3];
cx q[84],q[3];
u1(0) q[3];
u1(0) q[84];
cx q[84],q[4];
u1(0) q[4];
cx q[84],q[4];
u1(0) q[4];
u1(0) q[84];
cx q[84],q[5];
u1(0) q[5];
cx q[84],q[5];
u1(0) q[5];
u1(0) q[84];
cx q[84],q[6];
u1(0) q[6];
cx q[84],q[6];
u1(0) q[6];
u1(0) q[84];
cx q[84],q[7];
u1(0) q[7];
cx q[84],q[7];
u1(0) q[7];
u1(0) q[84];
cx q[84],q[8];
u1(0) q[8];
cx q[84],q[8];
u1(0) q[8];
u1(0) q[84];
cx q[84],q[9];
u1(0) q[9];
cx q[84],q[9];
u1(0) q[9];
u1(0) q[84];
cx q[84],q[10];
u1(0) q[10];
cx q[84],q[10];
u1(0) q[10];
u1(0) q[84];
cx q[84],q[11];
u1(0) q[11];
cx q[84],q[11];
u1(0) q[11];
u1(0) q[84];
cx q[84],q[12];
u1(0) q[12];
cx q[84],q[12];
u1(0) q[12];
u1(0) q[84];
cx q[84],q[13];
u1(0) q[13];
cx q[84],q[13];
u1(0) q[13];
u1(0) q[84];
cx q[84],q[14];
u1(0) q[14];
cx q[84],q[14];
u1(0) q[14];
u1(0) q[84];
cx q[84],q[15];
u1(0) q[15];
cx q[84],q[15];
u1(0) q[15];
u1(0) q[84];
cx q[84],q[16];
u1(0) q[16];
cx q[84],q[16];
u1(0) q[16];
u1(0) q[84];
cx q[84],q[17];
u1(0) q[17];
cx q[84],q[17];
u1(0) q[17];
u1(0) q[84];
cx q[84],q[18];
u1(0) q[18];
cx q[84],q[18];
u1(0) q[18];
u1(0) q[84];
cx q[84],q[19];
u1(0) q[19];
cx q[84],q[19];
u1(0) q[19];
u1(0) q[84];
cx q[84],q[20];
u1(0) q[20];
cx q[84],q[20];
u1(0) q[20];
u1(0) q[84];
cx q[84],q[21];
u1(0) q[21];
cx q[84],q[21];
u1(0) q[21];
u1(0) q[84];
cx q[84],q[22];
u1(0) q[22];
cx q[84],q[22];
u1(0) q[22];
u1(0) q[84];
cx q[84],q[23];
u1(0) q[23];
cx q[84],q[23];
u1(0) q[23];
u1(0) q[84];
cx q[84],q[24];
u1(0) q[24];
cx q[84],q[24];
u1(0) q[24];
u1(0) q[84];
cx q[84],q[25];
u1(0) q[25];
cx q[84],q[25];
u1(0) q[25];
u1(0) q[84];
cx q[84],q[26];
u1(0) q[26];
cx q[84],q[26];
u1(0) q[26];
u1(0) q[84];
cx q[84],q[27];
u1(0) q[27];
cx q[84],q[27];
u1(0) q[27];
u1(0) q[84];
cx q[84],q[28];
u1(0) q[28];
cx q[84],q[28];
u1(0) q[28];
u1(0) q[84];
cx q[84],q[29];
u1(0) q[29];
cx q[84],q[29];
u1(0) q[29];
u1(0) q[84];
cx q[84],q[30];
u1(0) q[30];
cx q[84],q[30];
u1(0) q[30];
u1(0) q[84];
cx q[84],q[31];
u1(0) q[31];
cx q[84],q[31];
u1(0) q[31];
u1(0) q[84];
cx q[84],q[32];
u1(0) q[32];
cx q[84],q[32];
u1(0) q[32];
u1(0) q[84];
cx q[84],q[33];
u1(0) q[33];
cx q[84],q[33];
u1(0) q[33];
u1(0) q[84];
cx q[84],q[34];
u1(0) q[34];
cx q[84],q[34];
u1(0) q[34];
u1(0) q[84];
cx q[84],q[35];
u1(0) q[35];
cx q[84],q[35];
u1(0) q[35];
u1(0) q[84];
cx q[84],q[36];
u1(0) q[36];
cx q[84],q[36];
u1(0) q[36];
u1(pi/281474976710656) q[84];
cx q[84],q[37];
u1(-pi/281474976710656) q[37];
cx q[84],q[37];
u1(pi/281474976710656) q[37];
u1(pi/140737488355328) q[84];
cx q[84],q[38];
u1(-pi/140737488355328) q[38];
cx q[84],q[38];
u1(pi/140737488355328) q[38];
u1(pi/70368744177664) q[84];
cx q[84],q[39];
u1(-pi/70368744177664) q[39];
cx q[84],q[39];
u1(pi/70368744177664) q[39];
u1(pi/35184372088832) q[84];
cx q[84],q[40];
u1(-pi/35184372088832) q[40];
cx q[84],q[40];
u1(pi/35184372088832) q[40];
u1(pi/17592186044416) q[84];
cx q[84],q[41];
u1(-pi/17592186044416) q[41];
cx q[84],q[41];
u1(pi/17592186044416) q[41];
u1(pi/8796093022208) q[84];
cx q[84],q[42];
u1(-pi/8796093022208) q[42];
cx q[84],q[42];
u1(pi/8796093022208) q[42];
u1(pi/4398046511104) q[84];
cx q[84],q[43];
u1(-pi/4398046511104) q[43];
cx q[84],q[43];
u1(pi/4398046511104) q[43];
u1(pi/2199023255552) q[84];
cx q[84],q[44];
u1(-pi/2199023255552) q[44];
cx q[84],q[44];
u1(pi/2199023255552) q[44];
u1(pi/1099511627776) q[84];
cx q[84],q[45];
u1(-pi/1099511627776) q[45];
cx q[84],q[45];
u1(pi/1099511627776) q[45];
u1(pi/549755813888) q[84];
cx q[84],q[46];
u1(-pi/549755813888) q[46];
cx q[84],q[46];
u1(pi/549755813888) q[46];
u1(pi/274877906944) q[84];
cx q[84],q[47];
u1(-pi/274877906944) q[47];
cx q[84],q[47];
u1(pi/274877906944) q[47];
u1(pi/137438953472) q[84];
cx q[84],q[48];
u1(-pi/137438953472) q[48];
cx q[84],q[48];
u1(pi/137438953472) q[48];
u1(pi/68719476736) q[84];
cx q[84],q[49];
u1(-pi/68719476736) q[49];
cx q[84],q[49];
u1(pi/68719476736) q[49];
u1(pi/34359738368) q[84];
cx q[84],q[50];
u1(-pi/34359738368) q[50];
cx q[84],q[50];
u1(pi/34359738368) q[50];
u1(pi/17179869184) q[84];
cx q[84],q[51];
u1(-pi/17179869184) q[51];
cx q[84],q[51];
u1(pi/17179869184) q[51];
u1(pi/8589934592) q[84];
cx q[84],q[52];
u1(-pi/8589934592) q[52];
cx q[84],q[52];
u1(pi/8589934592) q[52];
u1(pi/4294967296) q[84];
cx q[84],q[53];
u1(-pi/4294967296) q[53];
cx q[84],q[53];
u1(pi/4294967296) q[53];
u1(pi/2147483648) q[84];
cx q[84],q[54];
u1(-pi/2147483648) q[54];
cx q[84],q[54];
u1(pi/2147483648) q[54];
u1(pi/1073741824) q[84];
cx q[84],q[55];
u1(-pi/1073741824) q[55];
cx q[84],q[55];
u1(pi/1073741824) q[55];
u1(pi/536870912) q[84];
cx q[84],q[56];
u1(-pi/536870912) q[56];
cx q[84],q[56];
u1(pi/536870912) q[56];
u1(pi/268435456) q[84];
cx q[84],q[57];
u1(-pi/268435456) q[57];
cx q[84],q[57];
u1(pi/268435456) q[57];
u1(pi/134217728) q[84];
cx q[84],q[58];
u1(-pi/134217728) q[58];
cx q[84],q[58];
u1(pi/134217728) q[58];
u1(pi/67108864) q[84];
cx q[84],q[59];
u1(-pi/67108864) q[59];
cx q[84],q[59];
u1(pi/67108864) q[59];
u1(pi/33554432) q[84];
cx q[84],q[60];
u1(-pi/33554432) q[60];
cx q[84],q[60];
u1(pi/33554432) q[60];
u1(pi/16777216) q[84];
cx q[84],q[61];
u1(-pi/16777216) q[61];
cx q[84],q[61];
u1(pi/16777216) q[61];
u1(pi/8388608) q[84];
cx q[84],q[62];
u1(-pi/8388608) q[62];
cx q[84],q[62];
u1(pi/8388608) q[62];
u1(pi/4194304) q[84];
cx q[84],q[63];
u1(-pi/4194304) q[63];
cx q[84],q[63];
u1(pi/4194304) q[63];
u1(pi/2097152) q[84];
cx q[84],q[64];
u1(-pi/2097152) q[64];
cx q[84],q[64];
u1(pi/2097152) q[64];
u1(pi/1048576) q[84];
cx q[84],q[65];
u1(-pi/1048576) q[65];
cx q[84],q[65];
u1(pi/1048576) q[65];
u1(pi/524288) q[84];
cx q[84],q[66];
u1(-pi/524288) q[66];
cx q[84],q[66];
u1(pi/524288) q[66];
u1(pi/262144) q[84];
cx q[84],q[67];
u1(-pi/262144) q[67];
cx q[84],q[67];
u1(pi/262144) q[67];
u1(pi/131072) q[84];
cx q[84],q[68];
u1(-pi/131072) q[68];
cx q[84],q[68];
u1(pi/131072) q[68];
u1(pi/65536) q[84];
cx q[84],q[69];
u1(-pi/65536) q[69];
cx q[84],q[69];
u1(pi/65536) q[69];
u1(pi/32768) q[84];
cx q[84],q[70];
u1(-pi/32768) q[70];
cx q[84],q[70];
u1(pi/32768) q[70];
u1(pi/16384) q[84];
cx q[84],q[71];
u1(-pi/16384) q[71];
cx q[84],q[71];
u1(pi/16384) q[71];
u1(pi/8192) q[84];
cx q[84],q[72];
u1(-pi/8192) q[72];
cx q[84],q[72];
u1(pi/8192) q[72];
u1(pi/4096) q[84];
cx q[84],q[73];
u1(-pi/4096) q[73];
cx q[84],q[73];
u1(pi/4096) q[73];
u1(pi/2048) q[84];
cx q[84],q[74];
u1(-pi/2048) q[74];
cx q[84],q[74];
u1(pi/2048) q[74];
u1(pi/1024) q[84];
cx q[84],q[75];
u1(-pi/1024) q[75];
cx q[84],q[75];
u1(pi/1024) q[75];
u1(pi/512) q[84];
cx q[84],q[76];
u1(-pi/512) q[76];
cx q[84],q[76];
u1(pi/512) q[76];
u1(pi/256) q[84];
cx q[84],q[77];
u1(-pi/256) q[77];
cx q[84],q[77];
u1(pi/256) q[77];
u1(pi/128) q[84];
cx q[84],q[78];
u1(-pi/128) q[78];
cx q[84],q[78];
u1(pi/128) q[78];
u1(pi/64) q[84];
cx q[84],q[79];
u1(-pi/64) q[79];
cx q[84],q[79];
u1(pi/64) q[79];
u1(pi/32) q[84];
cx q[84],q[80];
u1(-pi/32) q[80];
cx q[84],q[80];
u1(pi/32) q[80];
u1(pi/16) q[84];
cx q[84],q[81];
u1(-pi/16) q[81];
cx q[84],q[81];
u1(pi/16) q[81];
u1(pi/8) q[84];
cx q[84],q[82];
u1(-pi/8) q[82];
cx q[84],q[82];
u1(pi/8) q[82];
u1(pi/4) q[84];
cx q[84],q[83];
u1(-pi/4) q[83];
cx q[84],q[83];
u1(pi/4) q[83];
h q[84];
u1(0) q[85];
cx q[85],q[0];
u1(0) q[0];
cx q[85],q[0];
u1(0) q[0];
u1(0) q[85];
cx q[85],q[1];
u1(0) q[1];
cx q[85],q[1];
u1(0) q[1];
u1(0) q[85];
cx q[85],q[2];
u1(0) q[2];
cx q[85],q[2];
u1(0) q[2];
u1(0) q[85];
cx q[85],q[3];
u1(0) q[3];
cx q[85],q[3];
u1(0) q[3];
u1(0) q[85];
cx q[85],q[4];
u1(0) q[4];
cx q[85],q[4];
u1(0) q[4];
u1(0) q[85];
cx q[85],q[5];
u1(0) q[5];
cx q[85],q[5];
u1(0) q[5];
u1(0) q[85];
cx q[85],q[6];
u1(0) q[6];
cx q[85],q[6];
u1(0) q[6];
u1(0) q[85];
cx q[85],q[7];
u1(0) q[7];
cx q[85],q[7];
u1(0) q[7];
u1(0) q[85];
cx q[85],q[8];
u1(0) q[8];
cx q[85],q[8];
u1(0) q[8];
u1(0) q[85];
cx q[85],q[9];
u1(0) q[9];
cx q[85],q[9];
u1(0) q[9];
u1(0) q[85];
cx q[85],q[10];
u1(0) q[10];
cx q[85],q[10];
u1(0) q[10];
u1(0) q[85];
cx q[85],q[11];
u1(0) q[11];
cx q[85],q[11];
u1(0) q[11];
u1(0) q[85];
cx q[85],q[12];
u1(0) q[12];
cx q[85],q[12];
u1(0) q[12];
u1(0) q[85];
cx q[85],q[13];
u1(0) q[13];
cx q[85],q[13];
u1(0) q[13];
u1(0) q[85];
cx q[85],q[14];
u1(0) q[14];
cx q[85],q[14];
u1(0) q[14];
u1(0) q[85];
cx q[85],q[15];
u1(0) q[15];
cx q[85],q[15];
u1(0) q[15];
u1(0) q[85];
cx q[85],q[16];
u1(0) q[16];
cx q[85],q[16];
u1(0) q[16];
u1(0) q[85];
cx q[85],q[17];
u1(0) q[17];
cx q[85],q[17];
u1(0) q[17];
u1(0) q[85];
cx q[85],q[18];
u1(0) q[18];
cx q[85],q[18];
u1(0) q[18];
u1(0) q[85];
cx q[85],q[19];
u1(0) q[19];
cx q[85],q[19];
u1(0) q[19];
u1(0) q[85];
cx q[85],q[20];
u1(0) q[20];
cx q[85],q[20];
u1(0) q[20];
u1(0) q[85];
cx q[85],q[21];
u1(0) q[21];
cx q[85],q[21];
u1(0) q[21];
u1(0) q[85];
cx q[85],q[22];
u1(0) q[22];
cx q[85],q[22];
u1(0) q[22];
u1(0) q[85];
cx q[85],q[23];
u1(0) q[23];
cx q[85],q[23];
u1(0) q[23];
u1(0) q[85];
cx q[85],q[24];
u1(0) q[24];
cx q[85],q[24];
u1(0) q[24];
u1(0) q[85];
cx q[85],q[25];
u1(0) q[25];
cx q[85],q[25];
u1(0) q[25];
u1(0) q[85];
cx q[85],q[26];
u1(0) q[26];
cx q[85],q[26];
u1(0) q[26];
u1(0) q[85];
cx q[85],q[27];
u1(0) q[27];
cx q[85],q[27];
u1(0) q[27];
u1(0) q[85];
cx q[85],q[28];
u1(0) q[28];
cx q[85],q[28];
u1(0) q[28];
u1(0) q[85];
cx q[85],q[29];
u1(0) q[29];
cx q[85],q[29];
u1(0) q[29];
u1(0) q[85];
cx q[85],q[30];
u1(0) q[30];
cx q[85],q[30];
u1(0) q[30];
u1(0) q[85];
cx q[85],q[31];
u1(0) q[31];
cx q[85],q[31];
u1(0) q[31];
u1(0) q[85];
cx q[85],q[32];
u1(0) q[32];
cx q[85],q[32];
u1(0) q[32];
u1(0) q[85];
cx q[85],q[33];
u1(0) q[33];
cx q[85],q[33];
u1(0) q[33];
u1(0) q[85];
cx q[85],q[34];
u1(0) q[34];
cx q[85],q[34];
u1(0) q[34];
u1(0) q[85];
cx q[85],q[35];
u1(0) q[35];
cx q[85],q[35];
u1(0) q[35];
u1(0) q[85];
cx q[85],q[36];
u1(0) q[36];
cx q[85],q[36];
u1(0) q[36];
u1(0) q[85];
cx q[85],q[37];
u1(0) q[37];
cx q[85],q[37];
u1(0) q[37];
u1(pi/281474976710656) q[85];
cx q[85],q[38];
u1(-pi/281474976710656) q[38];
cx q[85],q[38];
u1(pi/281474976710656) q[38];
u1(pi/140737488355328) q[85];
cx q[85],q[39];
u1(-pi/140737488355328) q[39];
cx q[85],q[39];
u1(pi/140737488355328) q[39];
u1(pi/70368744177664) q[85];
cx q[85],q[40];
u1(-pi/70368744177664) q[40];
cx q[85],q[40];
u1(pi/70368744177664) q[40];
u1(pi/35184372088832) q[85];
cx q[85],q[41];
u1(-pi/35184372088832) q[41];
cx q[85],q[41];
u1(pi/35184372088832) q[41];
u1(pi/17592186044416) q[85];
cx q[85],q[42];
u1(-pi/17592186044416) q[42];
cx q[85],q[42];
u1(pi/17592186044416) q[42];
u1(pi/8796093022208) q[85];
cx q[85],q[43];
u1(-pi/8796093022208) q[43];
cx q[85],q[43];
u1(pi/8796093022208) q[43];
u1(pi/4398046511104) q[85];
cx q[85],q[44];
u1(-pi/4398046511104) q[44];
cx q[85],q[44];
u1(pi/4398046511104) q[44];
u1(pi/2199023255552) q[85];
cx q[85],q[45];
u1(-pi/2199023255552) q[45];
cx q[85],q[45];
u1(pi/2199023255552) q[45];
u1(pi/1099511627776) q[85];
cx q[85],q[46];
u1(-pi/1099511627776) q[46];
cx q[85],q[46];
u1(pi/1099511627776) q[46];
u1(pi/549755813888) q[85];
cx q[85],q[47];
u1(-pi/549755813888) q[47];
cx q[85],q[47];
u1(pi/549755813888) q[47];
u1(pi/274877906944) q[85];
cx q[85],q[48];
u1(-pi/274877906944) q[48];
cx q[85],q[48];
u1(pi/274877906944) q[48];
u1(pi/137438953472) q[85];
cx q[85],q[49];
u1(-pi/137438953472) q[49];
cx q[85],q[49];
u1(pi/137438953472) q[49];
u1(pi/68719476736) q[85];
cx q[85],q[50];
u1(-pi/68719476736) q[50];
cx q[85],q[50];
u1(pi/68719476736) q[50];
u1(pi/34359738368) q[85];
cx q[85],q[51];
u1(-pi/34359738368) q[51];
cx q[85],q[51];
u1(pi/34359738368) q[51];
u1(pi/17179869184) q[85];
cx q[85],q[52];
u1(-pi/17179869184) q[52];
cx q[85],q[52];
u1(pi/17179869184) q[52];
u1(pi/8589934592) q[85];
cx q[85],q[53];
u1(-pi/8589934592) q[53];
cx q[85],q[53];
u1(pi/8589934592) q[53];
u1(pi/4294967296) q[85];
cx q[85],q[54];
u1(-pi/4294967296) q[54];
cx q[85],q[54];
u1(pi/4294967296) q[54];
u1(pi/2147483648) q[85];
cx q[85],q[55];
u1(-pi/2147483648) q[55];
cx q[85],q[55];
u1(pi/2147483648) q[55];
u1(pi/1073741824) q[85];
cx q[85],q[56];
u1(-pi/1073741824) q[56];
cx q[85],q[56];
u1(pi/1073741824) q[56];
u1(pi/536870912) q[85];
cx q[85],q[57];
u1(-pi/536870912) q[57];
cx q[85],q[57];
u1(pi/536870912) q[57];
u1(pi/268435456) q[85];
cx q[85],q[58];
u1(-pi/268435456) q[58];
cx q[85],q[58];
u1(pi/268435456) q[58];
u1(pi/134217728) q[85];
cx q[85],q[59];
u1(-pi/134217728) q[59];
cx q[85],q[59];
u1(pi/134217728) q[59];
u1(pi/67108864) q[85];
cx q[85],q[60];
u1(-pi/67108864) q[60];
cx q[85],q[60];
u1(pi/67108864) q[60];
u1(pi/33554432) q[85];
cx q[85],q[61];
u1(-pi/33554432) q[61];
cx q[85],q[61];
u1(pi/33554432) q[61];
u1(pi/16777216) q[85];
cx q[85],q[62];
u1(-pi/16777216) q[62];
cx q[85],q[62];
u1(pi/16777216) q[62];
u1(pi/8388608) q[85];
cx q[85],q[63];
u1(-pi/8388608) q[63];
cx q[85],q[63];
u1(pi/8388608) q[63];
u1(pi/4194304) q[85];
cx q[85],q[64];
u1(-pi/4194304) q[64];
cx q[85],q[64];
u1(pi/4194304) q[64];
u1(pi/2097152) q[85];
cx q[85],q[65];
u1(-pi/2097152) q[65];
cx q[85],q[65];
u1(pi/2097152) q[65];
u1(pi/1048576) q[85];
cx q[85],q[66];
u1(-pi/1048576) q[66];
cx q[85],q[66];
u1(pi/1048576) q[66];
u1(pi/524288) q[85];
cx q[85],q[67];
u1(-pi/524288) q[67];
cx q[85],q[67];
u1(pi/524288) q[67];
u1(pi/262144) q[85];
cx q[85],q[68];
u1(-pi/262144) q[68];
cx q[85],q[68];
u1(pi/262144) q[68];
u1(pi/131072) q[85];
cx q[85],q[69];
u1(-pi/131072) q[69];
cx q[85],q[69];
u1(pi/131072) q[69];
u1(pi/65536) q[85];
cx q[85],q[70];
u1(-pi/65536) q[70];
cx q[85],q[70];
u1(pi/65536) q[70];
u1(pi/32768) q[85];
cx q[85],q[71];
u1(-pi/32768) q[71];
cx q[85],q[71];
u1(pi/32768) q[71];
u1(pi/16384) q[85];
cx q[85],q[72];
u1(-pi/16384) q[72];
cx q[85],q[72];
u1(pi/16384) q[72];
u1(pi/8192) q[85];
cx q[85],q[73];
u1(-pi/8192) q[73];
cx q[85],q[73];
u1(pi/8192) q[73];
u1(pi/4096) q[85];
cx q[85],q[74];
u1(-pi/4096) q[74];
cx q[85],q[74];
u1(pi/4096) q[74];
u1(pi/2048) q[85];
cx q[85],q[75];
u1(-pi/2048) q[75];
cx q[85],q[75];
u1(pi/2048) q[75];
u1(pi/1024) q[85];
cx q[85],q[76];
u1(-pi/1024) q[76];
cx q[85],q[76];
u1(pi/1024) q[76];
u1(pi/512) q[85];
cx q[85],q[77];
u1(-pi/512) q[77];
cx q[85],q[77];
u1(pi/512) q[77];
u1(pi/256) q[85];
cx q[85],q[78];
u1(-pi/256) q[78];
cx q[85],q[78];
u1(pi/256) q[78];
u1(pi/128) q[85];
cx q[85],q[79];
u1(-pi/128) q[79];
cx q[85],q[79];
u1(pi/128) q[79];
u1(pi/64) q[85];
cx q[85],q[80];
u1(-pi/64) q[80];
cx q[85],q[80];
u1(pi/64) q[80];
u1(pi/32) q[85];
cx q[85],q[81];
u1(-pi/32) q[81];
cx q[85],q[81];
u1(pi/32) q[81];
u1(pi/16) q[85];
cx q[85],q[82];
u1(-pi/16) q[82];
cx q[85],q[82];
u1(pi/16) q[82];
u1(pi/8) q[85];
cx q[85],q[83];
u1(-pi/8) q[83];
cx q[85],q[83];
u1(pi/8) q[83];
u1(pi/4) q[85];
cx q[85],q[84];
u1(-pi/4) q[84];
cx q[85],q[84];
u1(pi/4) q[84];
h q[85];
u1(0) q[86];
cx q[86],q[0];
u1(0) q[0];
cx q[86],q[0];
u1(0) q[0];
u1(0) q[86];
cx q[86],q[1];
u1(0) q[1];
cx q[86],q[1];
u1(0) q[1];
u1(0) q[86];
cx q[86],q[2];
u1(0) q[2];
cx q[86],q[2];
u1(0) q[2];
u1(0) q[86];
cx q[86],q[3];
u1(0) q[3];
cx q[86],q[3];
u1(0) q[3];
u1(0) q[86];
cx q[86],q[4];
u1(0) q[4];
cx q[86],q[4];
u1(0) q[4];
u1(0) q[86];
cx q[86],q[5];
u1(0) q[5];
cx q[86],q[5];
u1(0) q[5];
u1(0) q[86];
cx q[86],q[6];
u1(0) q[6];
cx q[86],q[6];
u1(0) q[6];
u1(0) q[86];
cx q[86],q[7];
u1(0) q[7];
cx q[86],q[7];
u1(0) q[7];
u1(0) q[86];
cx q[86],q[8];
u1(0) q[8];
cx q[86],q[8];
u1(0) q[8];
u1(0) q[86];
cx q[86],q[9];
u1(0) q[9];
cx q[86],q[9];
u1(0) q[9];
u1(0) q[86];
cx q[86],q[10];
u1(0) q[10];
cx q[86],q[10];
u1(0) q[10];
u1(0) q[86];
cx q[86],q[11];
u1(0) q[11];
cx q[86],q[11];
u1(0) q[11];
u1(0) q[86];
cx q[86],q[12];
u1(0) q[12];
cx q[86],q[12];
u1(0) q[12];
u1(0) q[86];
cx q[86],q[13];
u1(0) q[13];
cx q[86],q[13];
u1(0) q[13];
u1(0) q[86];
cx q[86],q[14];
u1(0) q[14];
cx q[86],q[14];
u1(0) q[14];
u1(0) q[86];
cx q[86],q[15];
u1(0) q[15];
cx q[86],q[15];
u1(0) q[15];
u1(0) q[86];
cx q[86],q[16];
u1(0) q[16];
cx q[86],q[16];
u1(0) q[16];
u1(0) q[86];
cx q[86],q[17];
u1(0) q[17];
cx q[86],q[17];
u1(0) q[17];
u1(0) q[86];
cx q[86],q[18];
u1(0) q[18];
cx q[86],q[18];
u1(0) q[18];
u1(0) q[86];
cx q[86],q[19];
u1(0) q[19];
cx q[86],q[19];
u1(0) q[19];
u1(0) q[86];
cx q[86],q[20];
u1(0) q[20];
cx q[86],q[20];
u1(0) q[20];
u1(0) q[86];
cx q[86],q[21];
u1(0) q[21];
cx q[86],q[21];
u1(0) q[21];
u1(0) q[86];
cx q[86],q[22];
u1(0) q[22];
cx q[86],q[22];
u1(0) q[22];
u1(0) q[86];
cx q[86],q[23];
u1(0) q[23];
cx q[86],q[23];
u1(0) q[23];
u1(0) q[86];
cx q[86],q[24];
u1(0) q[24];
cx q[86],q[24];
u1(0) q[24];
u1(0) q[86];
cx q[86],q[25];
u1(0) q[25];
cx q[86],q[25];
u1(0) q[25];
u1(0) q[86];
cx q[86],q[26];
u1(0) q[26];
cx q[86],q[26];
u1(0) q[26];
u1(0) q[86];
cx q[86],q[27];
u1(0) q[27];
cx q[86],q[27];
u1(0) q[27];
u1(0) q[86];
cx q[86],q[28];
u1(0) q[28];
cx q[86],q[28];
u1(0) q[28];
u1(0) q[86];
cx q[86],q[29];
u1(0) q[29];
cx q[86],q[29];
u1(0) q[29];
u1(0) q[86];
cx q[86],q[30];
u1(0) q[30];
cx q[86],q[30];
u1(0) q[30];
u1(0) q[86];
cx q[86],q[31];
u1(0) q[31];
cx q[86],q[31];
u1(0) q[31];
u1(0) q[86];
cx q[86],q[32];
u1(0) q[32];
cx q[86],q[32];
u1(0) q[32];
u1(0) q[86];
cx q[86],q[33];
u1(0) q[33];
cx q[86],q[33];
u1(0) q[33];
u1(0) q[86];
cx q[86],q[34];
u1(0) q[34];
cx q[86],q[34];
u1(0) q[34];
u1(0) q[86];
cx q[86],q[35];
u1(0) q[35];
cx q[86],q[35];
u1(0) q[35];
u1(0) q[86];
cx q[86],q[36];
u1(0) q[36];
cx q[86],q[36];
u1(0) q[36];
u1(0) q[86];
cx q[86],q[37];
u1(0) q[37];
cx q[86],q[37];
u1(0) q[37];
u1(0) q[86];
cx q[86],q[38];
u1(0) q[38];
cx q[86],q[38];
u1(0) q[38];
u1(pi/281474976710656) q[86];
cx q[86],q[39];
u1(-pi/281474976710656) q[39];
cx q[86],q[39];
u1(pi/281474976710656) q[39];
u1(pi/140737488355328) q[86];
cx q[86],q[40];
u1(-pi/140737488355328) q[40];
cx q[86],q[40];
u1(pi/140737488355328) q[40];
u1(pi/70368744177664) q[86];
cx q[86],q[41];
u1(-pi/70368744177664) q[41];
cx q[86],q[41];
u1(pi/70368744177664) q[41];
u1(pi/35184372088832) q[86];
cx q[86],q[42];
u1(-pi/35184372088832) q[42];
cx q[86],q[42];
u1(pi/35184372088832) q[42];
u1(pi/17592186044416) q[86];
cx q[86],q[43];
u1(-pi/17592186044416) q[43];
cx q[86],q[43];
u1(pi/17592186044416) q[43];
u1(pi/8796093022208) q[86];
cx q[86],q[44];
u1(-pi/8796093022208) q[44];
cx q[86],q[44];
u1(pi/8796093022208) q[44];
u1(pi/4398046511104) q[86];
cx q[86],q[45];
u1(-pi/4398046511104) q[45];
cx q[86],q[45];
u1(pi/4398046511104) q[45];
u1(pi/2199023255552) q[86];
cx q[86],q[46];
u1(-pi/2199023255552) q[46];
cx q[86],q[46];
u1(pi/2199023255552) q[46];
u1(pi/1099511627776) q[86];
cx q[86],q[47];
u1(-pi/1099511627776) q[47];
cx q[86],q[47];
u1(pi/1099511627776) q[47];
u1(pi/549755813888) q[86];
cx q[86],q[48];
u1(-pi/549755813888) q[48];
cx q[86],q[48];
u1(pi/549755813888) q[48];
u1(pi/274877906944) q[86];
cx q[86],q[49];
u1(-pi/274877906944) q[49];
cx q[86],q[49];
u1(pi/274877906944) q[49];
u1(pi/137438953472) q[86];
cx q[86],q[50];
u1(-pi/137438953472) q[50];
cx q[86],q[50];
u1(pi/137438953472) q[50];
u1(pi/68719476736) q[86];
cx q[86],q[51];
u1(-pi/68719476736) q[51];
cx q[86],q[51];
u1(pi/68719476736) q[51];
u1(pi/34359738368) q[86];
cx q[86],q[52];
u1(-pi/34359738368) q[52];
cx q[86],q[52];
u1(pi/34359738368) q[52];
u1(pi/17179869184) q[86];
cx q[86],q[53];
u1(-pi/17179869184) q[53];
cx q[86],q[53];
u1(pi/17179869184) q[53];
u1(pi/8589934592) q[86];
cx q[86],q[54];
u1(-pi/8589934592) q[54];
cx q[86],q[54];
u1(pi/8589934592) q[54];
u1(pi/4294967296) q[86];
cx q[86],q[55];
u1(-pi/4294967296) q[55];
cx q[86],q[55];
u1(pi/4294967296) q[55];
u1(pi/2147483648) q[86];
cx q[86],q[56];
u1(-pi/2147483648) q[56];
cx q[86],q[56];
u1(pi/2147483648) q[56];
u1(pi/1073741824) q[86];
cx q[86],q[57];
u1(-pi/1073741824) q[57];
cx q[86],q[57];
u1(pi/1073741824) q[57];
u1(pi/536870912) q[86];
cx q[86],q[58];
u1(-pi/536870912) q[58];
cx q[86],q[58];
u1(pi/536870912) q[58];
u1(pi/268435456) q[86];
cx q[86],q[59];
u1(-pi/268435456) q[59];
cx q[86],q[59];
u1(pi/268435456) q[59];
u1(pi/134217728) q[86];
cx q[86],q[60];
u1(-pi/134217728) q[60];
cx q[86],q[60];
u1(pi/134217728) q[60];
u1(pi/67108864) q[86];
cx q[86],q[61];
u1(-pi/67108864) q[61];
cx q[86],q[61];
u1(pi/67108864) q[61];
u1(pi/33554432) q[86];
cx q[86],q[62];
u1(-pi/33554432) q[62];
cx q[86],q[62];
u1(pi/33554432) q[62];
u1(pi/16777216) q[86];
cx q[86],q[63];
u1(-pi/16777216) q[63];
cx q[86],q[63];
u1(pi/16777216) q[63];
u1(pi/8388608) q[86];
cx q[86],q[64];
u1(-pi/8388608) q[64];
cx q[86],q[64];
u1(pi/8388608) q[64];
u1(pi/4194304) q[86];
cx q[86],q[65];
u1(-pi/4194304) q[65];
cx q[86],q[65];
u1(pi/4194304) q[65];
u1(pi/2097152) q[86];
cx q[86],q[66];
u1(-pi/2097152) q[66];
cx q[86],q[66];
u1(pi/2097152) q[66];
u1(pi/1048576) q[86];
cx q[86],q[67];
u1(-pi/1048576) q[67];
cx q[86],q[67];
u1(pi/1048576) q[67];
u1(pi/524288) q[86];
cx q[86],q[68];
u1(-pi/524288) q[68];
cx q[86],q[68];
u1(pi/524288) q[68];
u1(pi/262144) q[86];
cx q[86],q[69];
u1(-pi/262144) q[69];
cx q[86],q[69];
u1(pi/262144) q[69];
u1(pi/131072) q[86];
cx q[86],q[70];
u1(-pi/131072) q[70];
cx q[86],q[70];
u1(pi/131072) q[70];
u1(pi/65536) q[86];
cx q[86],q[71];
u1(-pi/65536) q[71];
cx q[86],q[71];
u1(pi/65536) q[71];
u1(pi/32768) q[86];
cx q[86],q[72];
u1(-pi/32768) q[72];
cx q[86],q[72];
u1(pi/32768) q[72];
u1(pi/16384) q[86];
cx q[86],q[73];
u1(-pi/16384) q[73];
cx q[86],q[73];
u1(pi/16384) q[73];
u1(pi/8192) q[86];
cx q[86],q[74];
u1(-pi/8192) q[74];
cx q[86],q[74];
u1(pi/8192) q[74];
u1(pi/4096) q[86];
cx q[86],q[75];
u1(-pi/4096) q[75];
cx q[86],q[75];
u1(pi/4096) q[75];
u1(pi/2048) q[86];
cx q[86],q[76];
u1(-pi/2048) q[76];
cx q[86],q[76];
u1(pi/2048) q[76];
u1(pi/1024) q[86];
cx q[86],q[77];
u1(-pi/1024) q[77];
cx q[86],q[77];
u1(pi/1024) q[77];
u1(pi/512) q[86];
cx q[86],q[78];
u1(-pi/512) q[78];
cx q[86],q[78];
u1(pi/512) q[78];
u1(pi/256) q[86];
cx q[86],q[79];
u1(-pi/256) q[79];
cx q[86],q[79];
u1(pi/256) q[79];
u1(pi/128) q[86];
cx q[86],q[80];
u1(-pi/128) q[80];
cx q[86],q[80];
u1(pi/128) q[80];
u1(pi/64) q[86];
cx q[86],q[81];
u1(-pi/64) q[81];
cx q[86],q[81];
u1(pi/64) q[81];
u1(pi/32) q[86];
cx q[86],q[82];
u1(-pi/32) q[82];
cx q[86],q[82];
u1(pi/32) q[82];
u1(pi/16) q[86];
cx q[86],q[83];
u1(-pi/16) q[83];
cx q[86],q[83];
u1(pi/16) q[83];
u1(pi/8) q[86];
cx q[86],q[84];
u1(-pi/8) q[84];
cx q[86],q[84];
u1(pi/8) q[84];
u1(pi/4) q[86];
cx q[86],q[85];
u1(-pi/4) q[85];
cx q[86],q[85];
u1(pi/4) q[85];
h q[86];
u1(0) q[87];
cx q[87],q[0];
u1(0) q[0];
cx q[87],q[0];
u1(0) q[0];
u1(0) q[87];
cx q[87],q[1];
u1(0) q[1];
cx q[87],q[1];
u1(0) q[1];
u1(0) q[87];
cx q[87],q[2];
u1(0) q[2];
cx q[87],q[2];
u1(0) q[2];
u1(0) q[87];
cx q[87],q[3];
u1(0) q[3];
cx q[87],q[3];
u1(0) q[3];
u1(0) q[87];
cx q[87],q[4];
u1(0) q[4];
cx q[87],q[4];
u1(0) q[4];
u1(0) q[87];
cx q[87],q[5];
u1(0) q[5];
cx q[87],q[5];
u1(0) q[5];
u1(0) q[87];
cx q[87],q[6];
u1(0) q[6];
cx q[87],q[6];
u1(0) q[6];
u1(0) q[87];
cx q[87],q[7];
u1(0) q[7];
cx q[87],q[7];
u1(0) q[7];
u1(0) q[87];
cx q[87],q[8];
u1(0) q[8];
cx q[87],q[8];
u1(0) q[8];
u1(0) q[87];
cx q[87],q[9];
u1(0) q[9];
cx q[87],q[9];
u1(0) q[9];
u1(0) q[87];
cx q[87],q[10];
u1(0) q[10];
cx q[87],q[10];
u1(0) q[10];
u1(0) q[87];
cx q[87],q[11];
u1(0) q[11];
cx q[87],q[11];
u1(0) q[11];
u1(0) q[87];
cx q[87],q[12];
u1(0) q[12];
cx q[87],q[12];
u1(0) q[12];
u1(0) q[87];
cx q[87],q[13];
u1(0) q[13];
cx q[87],q[13];
u1(0) q[13];
u1(0) q[87];
cx q[87],q[14];
u1(0) q[14];
cx q[87],q[14];
u1(0) q[14];
u1(0) q[87];
cx q[87],q[15];
u1(0) q[15];
cx q[87],q[15];
u1(0) q[15];
u1(0) q[87];
cx q[87],q[16];
u1(0) q[16];
cx q[87],q[16];
u1(0) q[16];
u1(0) q[87];
cx q[87],q[17];
u1(0) q[17];
cx q[87],q[17];
u1(0) q[17];
u1(0) q[87];
cx q[87],q[18];
u1(0) q[18];
cx q[87],q[18];
u1(0) q[18];
u1(0) q[87];
cx q[87],q[19];
u1(0) q[19];
cx q[87],q[19];
u1(0) q[19];
u1(0) q[87];
cx q[87],q[20];
u1(0) q[20];
cx q[87],q[20];
u1(0) q[20];
u1(0) q[87];
cx q[87],q[21];
u1(0) q[21];
cx q[87],q[21];
u1(0) q[21];
u1(0) q[87];
cx q[87],q[22];
u1(0) q[22];
cx q[87],q[22];
u1(0) q[22];
u1(0) q[87];
cx q[87],q[23];
u1(0) q[23];
cx q[87],q[23];
u1(0) q[23];
u1(0) q[87];
cx q[87],q[24];
u1(0) q[24];
cx q[87],q[24];
u1(0) q[24];
u1(0) q[87];
cx q[87],q[25];
u1(0) q[25];
cx q[87],q[25];
u1(0) q[25];
u1(0) q[87];
cx q[87],q[26];
u1(0) q[26];
cx q[87],q[26];
u1(0) q[26];
u1(0) q[87];
cx q[87],q[27];
u1(0) q[27];
cx q[87],q[27];
u1(0) q[27];
u1(0) q[87];
cx q[87],q[28];
u1(0) q[28];
cx q[87],q[28];
u1(0) q[28];
u1(0) q[87];
cx q[87],q[29];
u1(0) q[29];
cx q[87],q[29];
u1(0) q[29];
u1(0) q[87];
cx q[87],q[30];
u1(0) q[30];
cx q[87],q[30];
u1(0) q[30];
u1(0) q[87];
cx q[87],q[31];
u1(0) q[31];
cx q[87],q[31];
u1(0) q[31];
u1(0) q[87];
cx q[87],q[32];
u1(0) q[32];
cx q[87],q[32];
u1(0) q[32];
u1(0) q[87];
cx q[87],q[33];
u1(0) q[33];
cx q[87],q[33];
u1(0) q[33];
u1(0) q[87];
cx q[87],q[34];
u1(0) q[34];
cx q[87],q[34];
u1(0) q[34];
u1(0) q[87];
cx q[87],q[35];
u1(0) q[35];
cx q[87],q[35];
u1(0) q[35];
u1(0) q[87];
cx q[87],q[36];
u1(0) q[36];
cx q[87],q[36];
u1(0) q[36];
u1(0) q[87];
cx q[87],q[37];
u1(0) q[37];
cx q[87],q[37];
u1(0) q[37];
u1(0) q[87];
cx q[87],q[38];
u1(0) q[38];
cx q[87],q[38];
u1(0) q[38];
u1(0) q[87];
cx q[87],q[39];
u1(0) q[39];
cx q[87],q[39];
u1(0) q[39];
u1(pi/281474976710656) q[87];
cx q[87],q[40];
u1(-pi/281474976710656) q[40];
cx q[87],q[40];
u1(pi/281474976710656) q[40];
u1(pi/140737488355328) q[87];
cx q[87],q[41];
u1(-pi/140737488355328) q[41];
cx q[87],q[41];
u1(pi/140737488355328) q[41];
u1(pi/70368744177664) q[87];
cx q[87],q[42];
u1(-pi/70368744177664) q[42];
cx q[87],q[42];
u1(pi/70368744177664) q[42];
u1(pi/35184372088832) q[87];
cx q[87],q[43];
u1(-pi/35184372088832) q[43];
cx q[87],q[43];
u1(pi/35184372088832) q[43];
u1(pi/17592186044416) q[87];
cx q[87],q[44];
u1(-pi/17592186044416) q[44];
cx q[87],q[44];
u1(pi/17592186044416) q[44];
u1(pi/8796093022208) q[87];
cx q[87],q[45];
u1(-pi/8796093022208) q[45];
cx q[87],q[45];
u1(pi/8796093022208) q[45];
u1(pi/4398046511104) q[87];
cx q[87],q[46];
u1(-pi/4398046511104) q[46];
cx q[87],q[46];
u1(pi/4398046511104) q[46];
u1(pi/2199023255552) q[87];
cx q[87],q[47];
u1(-pi/2199023255552) q[47];
cx q[87],q[47];
u1(pi/2199023255552) q[47];
u1(pi/1099511627776) q[87];
cx q[87],q[48];
u1(-pi/1099511627776) q[48];
cx q[87],q[48];
u1(pi/1099511627776) q[48];
u1(pi/549755813888) q[87];
cx q[87],q[49];
u1(-pi/549755813888) q[49];
cx q[87],q[49];
u1(pi/549755813888) q[49];
u1(pi/274877906944) q[87];
cx q[87],q[50];
u1(-pi/274877906944) q[50];
cx q[87],q[50];
u1(pi/274877906944) q[50];
u1(pi/137438953472) q[87];
cx q[87],q[51];
u1(-pi/137438953472) q[51];
cx q[87],q[51];
u1(pi/137438953472) q[51];
u1(pi/68719476736) q[87];
cx q[87],q[52];
u1(-pi/68719476736) q[52];
cx q[87],q[52];
u1(pi/68719476736) q[52];
u1(pi/34359738368) q[87];
cx q[87],q[53];
u1(-pi/34359738368) q[53];
cx q[87],q[53];
u1(pi/34359738368) q[53];
u1(pi/17179869184) q[87];
cx q[87],q[54];
u1(-pi/17179869184) q[54];
cx q[87],q[54];
u1(pi/17179869184) q[54];
u1(pi/8589934592) q[87];
cx q[87],q[55];
u1(-pi/8589934592) q[55];
cx q[87],q[55];
u1(pi/8589934592) q[55];
u1(pi/4294967296) q[87];
cx q[87],q[56];
u1(-pi/4294967296) q[56];
cx q[87],q[56];
u1(pi/4294967296) q[56];
u1(pi/2147483648) q[87];
cx q[87],q[57];
u1(-pi/2147483648) q[57];
cx q[87],q[57];
u1(pi/2147483648) q[57];
u1(pi/1073741824) q[87];
cx q[87],q[58];
u1(-pi/1073741824) q[58];
cx q[87],q[58];
u1(pi/1073741824) q[58];
u1(pi/536870912) q[87];
cx q[87],q[59];
u1(-pi/536870912) q[59];
cx q[87],q[59];
u1(pi/536870912) q[59];
u1(pi/268435456) q[87];
cx q[87],q[60];
u1(-pi/268435456) q[60];
cx q[87],q[60];
u1(pi/268435456) q[60];
u1(pi/134217728) q[87];
cx q[87],q[61];
u1(-pi/134217728) q[61];
cx q[87],q[61];
u1(pi/134217728) q[61];
u1(pi/67108864) q[87];
cx q[87],q[62];
u1(-pi/67108864) q[62];
cx q[87],q[62];
u1(pi/67108864) q[62];
u1(pi/33554432) q[87];
cx q[87],q[63];
u1(-pi/33554432) q[63];
cx q[87],q[63];
u1(pi/33554432) q[63];
u1(pi/16777216) q[87];
cx q[87],q[64];
u1(-pi/16777216) q[64];
cx q[87],q[64];
u1(pi/16777216) q[64];
u1(pi/8388608) q[87];
cx q[87],q[65];
u1(-pi/8388608) q[65];
cx q[87],q[65];
u1(pi/8388608) q[65];
u1(pi/4194304) q[87];
cx q[87],q[66];
u1(-pi/4194304) q[66];
cx q[87],q[66];
u1(pi/4194304) q[66];
u1(pi/2097152) q[87];
cx q[87],q[67];
u1(-pi/2097152) q[67];
cx q[87],q[67];
u1(pi/2097152) q[67];
u1(pi/1048576) q[87];
cx q[87],q[68];
u1(-pi/1048576) q[68];
cx q[87],q[68];
u1(pi/1048576) q[68];
u1(pi/524288) q[87];
cx q[87],q[69];
u1(-pi/524288) q[69];
cx q[87],q[69];
u1(pi/524288) q[69];
u1(pi/262144) q[87];
cx q[87],q[70];
u1(-pi/262144) q[70];
cx q[87],q[70];
u1(pi/262144) q[70];
u1(pi/131072) q[87];
cx q[87],q[71];
u1(-pi/131072) q[71];
cx q[87],q[71];
u1(pi/131072) q[71];
u1(pi/65536) q[87];
cx q[87],q[72];
u1(-pi/65536) q[72];
cx q[87],q[72];
u1(pi/65536) q[72];
u1(pi/32768) q[87];
cx q[87],q[73];
u1(-pi/32768) q[73];
cx q[87],q[73];
u1(pi/32768) q[73];
u1(pi/16384) q[87];
cx q[87],q[74];
u1(-pi/16384) q[74];
cx q[87],q[74];
u1(pi/16384) q[74];
u1(pi/8192) q[87];
cx q[87],q[75];
u1(-pi/8192) q[75];
cx q[87],q[75];
u1(pi/8192) q[75];
u1(pi/4096) q[87];
cx q[87],q[76];
u1(-pi/4096) q[76];
cx q[87],q[76];
u1(pi/4096) q[76];
u1(pi/2048) q[87];
cx q[87],q[77];
u1(-pi/2048) q[77];
cx q[87],q[77];
u1(pi/2048) q[77];
u1(pi/1024) q[87];
cx q[87],q[78];
u1(-pi/1024) q[78];
cx q[87],q[78];
u1(pi/1024) q[78];
u1(pi/512) q[87];
cx q[87],q[79];
u1(-pi/512) q[79];
cx q[87],q[79];
u1(pi/512) q[79];
u1(pi/256) q[87];
cx q[87],q[80];
u1(-pi/256) q[80];
cx q[87],q[80];
u1(pi/256) q[80];
u1(pi/128) q[87];
cx q[87],q[81];
u1(-pi/128) q[81];
cx q[87],q[81];
u1(pi/128) q[81];
u1(pi/64) q[87];
cx q[87],q[82];
u1(-pi/64) q[82];
cx q[87],q[82];
u1(pi/64) q[82];
u1(pi/32) q[87];
cx q[87],q[83];
u1(-pi/32) q[83];
cx q[87],q[83];
u1(pi/32) q[83];
u1(pi/16) q[87];
cx q[87],q[84];
u1(-pi/16) q[84];
cx q[87],q[84];
u1(pi/16) q[84];
u1(pi/8) q[87];
cx q[87],q[85];
u1(-pi/8) q[85];
cx q[87],q[85];
u1(pi/8) q[85];
u1(pi/4) q[87];
cx q[87],q[86];
u1(-pi/4) q[86];
cx q[87],q[86];
u1(pi/4) q[86];
h q[87];
u1(0) q[88];
cx q[88],q[0];
u1(0) q[0];
cx q[88],q[0];
u1(0) q[0];
u1(0) q[88];
cx q[88],q[1];
u1(0) q[1];
cx q[88],q[1];
u1(0) q[1];
u1(0) q[88];
cx q[88],q[2];
u1(0) q[2];
cx q[88],q[2];
u1(0) q[2];
u1(0) q[88];
cx q[88],q[3];
u1(0) q[3];
cx q[88],q[3];
u1(0) q[3];
u1(0) q[88];
cx q[88],q[4];
u1(0) q[4];
cx q[88],q[4];
u1(0) q[4];
u1(0) q[88];
cx q[88],q[5];
u1(0) q[5];
cx q[88],q[5];
u1(0) q[5];
u1(0) q[88];
cx q[88],q[6];
u1(0) q[6];
cx q[88],q[6];
u1(0) q[6];
u1(0) q[88];
cx q[88],q[7];
u1(0) q[7];
cx q[88],q[7];
u1(0) q[7];
u1(0) q[88];
cx q[88],q[8];
u1(0) q[8];
cx q[88],q[8];
u1(0) q[8];
u1(0) q[88];
cx q[88],q[9];
u1(0) q[9];
cx q[88],q[9];
u1(0) q[9];
u1(0) q[88];
cx q[88],q[10];
u1(0) q[10];
cx q[88],q[10];
u1(0) q[10];
u1(0) q[88];
cx q[88],q[11];
u1(0) q[11];
cx q[88],q[11];
u1(0) q[11];
u1(0) q[88];
cx q[88],q[12];
u1(0) q[12];
cx q[88],q[12];
u1(0) q[12];
u1(0) q[88];
cx q[88],q[13];
u1(0) q[13];
cx q[88],q[13];
u1(0) q[13];
u1(0) q[88];
cx q[88],q[14];
u1(0) q[14];
cx q[88],q[14];
u1(0) q[14];
u1(0) q[88];
cx q[88],q[15];
u1(0) q[15];
cx q[88],q[15];
u1(0) q[15];
u1(0) q[88];
cx q[88],q[16];
u1(0) q[16];
cx q[88],q[16];
u1(0) q[16];
u1(0) q[88];
cx q[88],q[17];
u1(0) q[17];
cx q[88],q[17];
u1(0) q[17];
u1(0) q[88];
cx q[88],q[18];
u1(0) q[18];
cx q[88],q[18];
u1(0) q[18];
u1(0) q[88];
cx q[88],q[19];
u1(0) q[19];
cx q[88],q[19];
u1(0) q[19];
u1(0) q[88];
cx q[88],q[20];
u1(0) q[20];
cx q[88],q[20];
u1(0) q[20];
u1(0) q[88];
cx q[88],q[21];
u1(0) q[21];
cx q[88],q[21];
u1(0) q[21];
u1(0) q[88];
cx q[88],q[22];
u1(0) q[22];
cx q[88],q[22];
u1(0) q[22];
u1(0) q[88];
cx q[88],q[23];
u1(0) q[23];
cx q[88],q[23];
u1(0) q[23];
u1(0) q[88];
cx q[88],q[24];
u1(0) q[24];
cx q[88],q[24];
u1(0) q[24];
u1(0) q[88];
cx q[88],q[25];
u1(0) q[25];
cx q[88],q[25];
u1(0) q[25];
u1(0) q[88];
cx q[88],q[26];
u1(0) q[26];
cx q[88],q[26];
u1(0) q[26];
u1(0) q[88];
cx q[88],q[27];
u1(0) q[27];
cx q[88],q[27];
u1(0) q[27];
u1(0) q[88];
cx q[88],q[28];
u1(0) q[28];
cx q[88],q[28];
u1(0) q[28];
u1(0) q[88];
cx q[88],q[29];
u1(0) q[29];
cx q[88],q[29];
u1(0) q[29];
u1(0) q[88];
cx q[88],q[30];
u1(0) q[30];
cx q[88],q[30];
u1(0) q[30];
u1(0) q[88];
cx q[88],q[31];
u1(0) q[31];
cx q[88],q[31];
u1(0) q[31];
u1(0) q[88];
cx q[88],q[32];
u1(0) q[32];
cx q[88],q[32];
u1(0) q[32];
u1(0) q[88];
cx q[88],q[33];
u1(0) q[33];
cx q[88],q[33];
u1(0) q[33];
u1(0) q[88];
cx q[88],q[34];
u1(0) q[34];
cx q[88],q[34];
u1(0) q[34];
u1(0) q[88];
cx q[88],q[35];
u1(0) q[35];
cx q[88],q[35];
u1(0) q[35];
u1(0) q[88];
cx q[88],q[36];
u1(0) q[36];
cx q[88],q[36];
u1(0) q[36];
u1(0) q[88];
cx q[88],q[37];
u1(0) q[37];
cx q[88],q[37];
u1(0) q[37];
u1(0) q[88];
cx q[88],q[38];
u1(0) q[38];
cx q[88],q[38];
u1(0) q[38];
u1(0) q[88];
cx q[88],q[39];
u1(0) q[39];
cx q[88],q[39];
u1(0) q[39];
u1(0) q[88];
cx q[88],q[40];
u1(0) q[40];
cx q[88],q[40];
u1(0) q[40];
u1(pi/281474976710656) q[88];
cx q[88],q[41];
u1(-pi/281474976710656) q[41];
cx q[88],q[41];
u1(pi/281474976710656) q[41];
u1(pi/140737488355328) q[88];
cx q[88],q[42];
u1(-pi/140737488355328) q[42];
cx q[88],q[42];
u1(pi/140737488355328) q[42];
u1(pi/70368744177664) q[88];
cx q[88],q[43];
u1(-pi/70368744177664) q[43];
cx q[88],q[43];
u1(pi/70368744177664) q[43];
u1(pi/35184372088832) q[88];
cx q[88],q[44];
u1(-pi/35184372088832) q[44];
cx q[88],q[44];
u1(pi/35184372088832) q[44];
u1(pi/17592186044416) q[88];
cx q[88],q[45];
u1(-pi/17592186044416) q[45];
cx q[88],q[45];
u1(pi/17592186044416) q[45];
u1(pi/8796093022208) q[88];
cx q[88],q[46];
u1(-pi/8796093022208) q[46];
cx q[88],q[46];
u1(pi/8796093022208) q[46];
u1(pi/4398046511104) q[88];
cx q[88],q[47];
u1(-pi/4398046511104) q[47];
cx q[88],q[47];
u1(pi/4398046511104) q[47];
u1(pi/2199023255552) q[88];
cx q[88],q[48];
u1(-pi/2199023255552) q[48];
cx q[88],q[48];
u1(pi/2199023255552) q[48];
u1(pi/1099511627776) q[88];
cx q[88],q[49];
u1(-pi/1099511627776) q[49];
cx q[88],q[49];
u1(pi/1099511627776) q[49];
u1(pi/549755813888) q[88];
cx q[88],q[50];
u1(-pi/549755813888) q[50];
cx q[88],q[50];
u1(pi/549755813888) q[50];
u1(pi/274877906944) q[88];
cx q[88],q[51];
u1(-pi/274877906944) q[51];
cx q[88],q[51];
u1(pi/274877906944) q[51];
u1(pi/137438953472) q[88];
cx q[88],q[52];
u1(-pi/137438953472) q[52];
cx q[88],q[52];
u1(pi/137438953472) q[52];
u1(pi/68719476736) q[88];
cx q[88],q[53];
u1(-pi/68719476736) q[53];
cx q[88],q[53];
u1(pi/68719476736) q[53];
u1(pi/34359738368) q[88];
cx q[88],q[54];
u1(-pi/34359738368) q[54];
cx q[88],q[54];
u1(pi/34359738368) q[54];
u1(pi/17179869184) q[88];
cx q[88],q[55];
u1(-pi/17179869184) q[55];
cx q[88],q[55];
u1(pi/17179869184) q[55];
u1(pi/8589934592) q[88];
cx q[88],q[56];
u1(-pi/8589934592) q[56];
cx q[88],q[56];
u1(pi/8589934592) q[56];
u1(pi/4294967296) q[88];
cx q[88],q[57];
u1(-pi/4294967296) q[57];
cx q[88],q[57];
u1(pi/4294967296) q[57];
u1(pi/2147483648) q[88];
cx q[88],q[58];
u1(-pi/2147483648) q[58];
cx q[88],q[58];
u1(pi/2147483648) q[58];
u1(pi/1073741824) q[88];
cx q[88],q[59];
u1(-pi/1073741824) q[59];
cx q[88],q[59];
u1(pi/1073741824) q[59];
u1(pi/536870912) q[88];
cx q[88],q[60];
u1(-pi/536870912) q[60];
cx q[88],q[60];
u1(pi/536870912) q[60];
u1(pi/268435456) q[88];
cx q[88],q[61];
u1(-pi/268435456) q[61];
cx q[88],q[61];
u1(pi/268435456) q[61];
u1(pi/134217728) q[88];
cx q[88],q[62];
u1(-pi/134217728) q[62];
cx q[88],q[62];
u1(pi/134217728) q[62];
u1(pi/67108864) q[88];
cx q[88],q[63];
u1(-pi/67108864) q[63];
cx q[88],q[63];
u1(pi/67108864) q[63];
u1(pi/33554432) q[88];
cx q[88],q[64];
u1(-pi/33554432) q[64];
cx q[88],q[64];
u1(pi/33554432) q[64];
u1(pi/16777216) q[88];
cx q[88],q[65];
u1(-pi/16777216) q[65];
cx q[88],q[65];
u1(pi/16777216) q[65];
u1(pi/8388608) q[88];
cx q[88],q[66];
u1(-pi/8388608) q[66];
cx q[88],q[66];
u1(pi/8388608) q[66];
u1(pi/4194304) q[88];
cx q[88],q[67];
u1(-pi/4194304) q[67];
cx q[88],q[67];
u1(pi/4194304) q[67];
u1(pi/2097152) q[88];
cx q[88],q[68];
u1(-pi/2097152) q[68];
cx q[88],q[68];
u1(pi/2097152) q[68];
u1(pi/1048576) q[88];
cx q[88],q[69];
u1(-pi/1048576) q[69];
cx q[88],q[69];
u1(pi/1048576) q[69];
u1(pi/524288) q[88];
cx q[88],q[70];
u1(-pi/524288) q[70];
cx q[88],q[70];
u1(pi/524288) q[70];
u1(pi/262144) q[88];
cx q[88],q[71];
u1(-pi/262144) q[71];
cx q[88],q[71];
u1(pi/262144) q[71];
u1(pi/131072) q[88];
cx q[88],q[72];
u1(-pi/131072) q[72];
cx q[88],q[72];
u1(pi/131072) q[72];
u1(pi/65536) q[88];
cx q[88],q[73];
u1(-pi/65536) q[73];
cx q[88],q[73];
u1(pi/65536) q[73];
u1(pi/32768) q[88];
cx q[88],q[74];
u1(-pi/32768) q[74];
cx q[88],q[74];
u1(pi/32768) q[74];
u1(pi/16384) q[88];
cx q[88],q[75];
u1(-pi/16384) q[75];
cx q[88],q[75];
u1(pi/16384) q[75];
u1(pi/8192) q[88];
cx q[88],q[76];
u1(-pi/8192) q[76];
cx q[88],q[76];
u1(pi/8192) q[76];
u1(pi/4096) q[88];
cx q[88],q[77];
u1(-pi/4096) q[77];
cx q[88],q[77];
u1(pi/4096) q[77];
u1(pi/2048) q[88];
cx q[88],q[78];
u1(-pi/2048) q[78];
cx q[88],q[78];
u1(pi/2048) q[78];
u1(pi/1024) q[88];
cx q[88],q[79];
u1(-pi/1024) q[79];
cx q[88],q[79];
u1(pi/1024) q[79];
u1(pi/512) q[88];
cx q[88],q[80];
u1(-pi/512) q[80];
cx q[88],q[80];
u1(pi/512) q[80];
u1(pi/256) q[88];
cx q[88],q[81];
u1(-pi/256) q[81];
cx q[88],q[81];
u1(pi/256) q[81];
u1(pi/128) q[88];
cx q[88],q[82];
u1(-pi/128) q[82];
cx q[88],q[82];
u1(pi/128) q[82];
u1(pi/64) q[88];
cx q[88],q[83];
u1(-pi/64) q[83];
cx q[88],q[83];
u1(pi/64) q[83];
u1(pi/32) q[88];
cx q[88],q[84];
u1(-pi/32) q[84];
cx q[88],q[84];
u1(pi/32) q[84];
u1(pi/16) q[88];
cx q[88],q[85];
u1(-pi/16) q[85];
cx q[88],q[85];
u1(pi/16) q[85];
u1(pi/8) q[88];
cx q[88],q[86];
u1(-pi/8) q[86];
cx q[88],q[86];
u1(pi/8) q[86];
u1(pi/4) q[88];
cx q[88],q[87];
u1(-pi/4) q[87];
cx q[88],q[87];
u1(pi/4) q[87];
h q[88];
u1(0) q[89];
cx q[89],q[0];
u1(0) q[0];
cx q[89],q[0];
u1(0) q[0];
u1(0) q[89];
cx q[89],q[1];
u1(0) q[1];
cx q[89],q[1];
u1(0) q[1];
u1(0) q[89];
cx q[89],q[2];
u1(0) q[2];
cx q[89],q[2];
u1(0) q[2];
u1(0) q[89];
cx q[89],q[3];
u1(0) q[3];
cx q[89],q[3];
u1(0) q[3];
u1(0) q[89];
cx q[89],q[4];
u1(0) q[4];
cx q[89],q[4];
u1(0) q[4];
u1(0) q[89];
cx q[89],q[5];
u1(0) q[5];
cx q[89],q[5];
u1(0) q[5];
u1(0) q[89];
cx q[89],q[6];
u1(0) q[6];
cx q[89],q[6];
u1(0) q[6];
u1(0) q[89];
cx q[89],q[7];
u1(0) q[7];
cx q[89],q[7];
u1(0) q[7];
u1(0) q[89];
cx q[89],q[8];
u1(0) q[8];
cx q[89],q[8];
u1(0) q[8];
u1(0) q[89];
cx q[89],q[9];
u1(0) q[9];
cx q[89],q[9];
u1(0) q[9];
u1(0) q[89];
cx q[89],q[10];
u1(0) q[10];
cx q[89],q[10];
u1(0) q[10];
u1(0) q[89];
cx q[89],q[11];
u1(0) q[11];
cx q[89],q[11];
u1(0) q[11];
u1(0) q[89];
cx q[89],q[12];
u1(0) q[12];
cx q[89],q[12];
u1(0) q[12];
u1(0) q[89];
cx q[89],q[13];
u1(0) q[13];
cx q[89],q[13];
u1(0) q[13];
u1(0) q[89];
cx q[89],q[14];
u1(0) q[14];
cx q[89],q[14];
u1(0) q[14];
u1(0) q[89];
cx q[89],q[15];
u1(0) q[15];
cx q[89],q[15];
u1(0) q[15];
u1(0) q[89];
cx q[89],q[16];
u1(0) q[16];
cx q[89],q[16];
u1(0) q[16];
u1(0) q[89];
cx q[89],q[17];
u1(0) q[17];
cx q[89],q[17];
u1(0) q[17];
u1(0) q[89];
cx q[89],q[18];
u1(0) q[18];
cx q[89],q[18];
u1(0) q[18];
u1(0) q[89];
cx q[89],q[19];
u1(0) q[19];
cx q[89],q[19];
u1(0) q[19];
u1(0) q[89];
cx q[89],q[20];
u1(0) q[20];
cx q[89],q[20];
u1(0) q[20];
u1(0) q[89];
cx q[89],q[21];
u1(0) q[21];
cx q[89],q[21];
u1(0) q[21];
u1(0) q[89];
cx q[89],q[22];
u1(0) q[22];
cx q[89],q[22];
u1(0) q[22];
u1(0) q[89];
cx q[89],q[23];
u1(0) q[23];
cx q[89],q[23];
u1(0) q[23];
u1(0) q[89];
cx q[89],q[24];
u1(0) q[24];
cx q[89],q[24];
u1(0) q[24];
u1(0) q[89];
cx q[89],q[25];
u1(0) q[25];
cx q[89],q[25];
u1(0) q[25];
u1(0) q[89];
cx q[89],q[26];
u1(0) q[26];
cx q[89],q[26];
u1(0) q[26];
u1(0) q[89];
cx q[89],q[27];
u1(0) q[27];
cx q[89],q[27];
u1(0) q[27];
u1(0) q[89];
cx q[89],q[28];
u1(0) q[28];
cx q[89],q[28];
u1(0) q[28];
u1(0) q[89];
cx q[89],q[29];
u1(0) q[29];
cx q[89],q[29];
u1(0) q[29];
u1(0) q[89];
cx q[89],q[30];
u1(0) q[30];
cx q[89],q[30];
u1(0) q[30];
u1(0) q[89];
cx q[89],q[31];
u1(0) q[31];
cx q[89],q[31];
u1(0) q[31];
u1(0) q[89];
cx q[89],q[32];
u1(0) q[32];
cx q[89],q[32];
u1(0) q[32];
u1(0) q[89];
cx q[89],q[33];
u1(0) q[33];
cx q[89],q[33];
u1(0) q[33];
u1(0) q[89];
cx q[89],q[34];
u1(0) q[34];
cx q[89],q[34];
u1(0) q[34];
u1(0) q[89];
cx q[89],q[35];
u1(0) q[35];
cx q[89],q[35];
u1(0) q[35];
u1(0) q[89];
cx q[89],q[36];
u1(0) q[36];
cx q[89],q[36];
u1(0) q[36];
u1(0) q[89];
cx q[89],q[37];
u1(0) q[37];
cx q[89],q[37];
u1(0) q[37];
u1(0) q[89];
cx q[89],q[38];
u1(0) q[38];
cx q[89],q[38];
u1(0) q[38];
u1(0) q[89];
cx q[89],q[39];
u1(0) q[39];
cx q[89],q[39];
u1(0) q[39];
u1(0) q[89];
cx q[89],q[40];
u1(0) q[40];
cx q[89],q[40];
u1(0) q[40];
u1(0) q[89];
cx q[89],q[41];
u1(0) q[41];
cx q[89],q[41];
u1(0) q[41];
u1(pi/281474976710656) q[89];
cx q[89],q[42];
u1(-pi/281474976710656) q[42];
cx q[89],q[42];
u1(pi/281474976710656) q[42];
u1(pi/140737488355328) q[89];
cx q[89],q[43];
u1(-pi/140737488355328) q[43];
cx q[89],q[43];
u1(pi/140737488355328) q[43];
u1(pi/70368744177664) q[89];
cx q[89],q[44];
u1(-pi/70368744177664) q[44];
cx q[89],q[44];
u1(pi/70368744177664) q[44];
u1(pi/35184372088832) q[89];
cx q[89],q[45];
u1(-pi/35184372088832) q[45];
cx q[89],q[45];
u1(pi/35184372088832) q[45];
u1(pi/17592186044416) q[89];
cx q[89],q[46];
u1(-pi/17592186044416) q[46];
cx q[89],q[46];
u1(pi/17592186044416) q[46];
u1(pi/8796093022208) q[89];
cx q[89],q[47];
u1(-pi/8796093022208) q[47];
cx q[89],q[47];
u1(pi/8796093022208) q[47];
u1(pi/4398046511104) q[89];
cx q[89],q[48];
u1(-pi/4398046511104) q[48];
cx q[89],q[48];
u1(pi/4398046511104) q[48];
u1(pi/2199023255552) q[89];
cx q[89],q[49];
u1(-pi/2199023255552) q[49];
cx q[89],q[49];
u1(pi/2199023255552) q[49];
u1(pi/1099511627776) q[89];
cx q[89],q[50];
u1(-pi/1099511627776) q[50];
cx q[89],q[50];
u1(pi/1099511627776) q[50];
u1(pi/549755813888) q[89];
cx q[89],q[51];
u1(-pi/549755813888) q[51];
cx q[89],q[51];
u1(pi/549755813888) q[51];
u1(pi/274877906944) q[89];
cx q[89],q[52];
u1(-pi/274877906944) q[52];
cx q[89],q[52];
u1(pi/274877906944) q[52];
u1(pi/137438953472) q[89];
cx q[89],q[53];
u1(-pi/137438953472) q[53];
cx q[89],q[53];
u1(pi/137438953472) q[53];
u1(pi/68719476736) q[89];
cx q[89],q[54];
u1(-pi/68719476736) q[54];
cx q[89],q[54];
u1(pi/68719476736) q[54];
u1(pi/34359738368) q[89];
cx q[89],q[55];
u1(-pi/34359738368) q[55];
cx q[89],q[55];
u1(pi/34359738368) q[55];
u1(pi/17179869184) q[89];
cx q[89],q[56];
u1(-pi/17179869184) q[56];
cx q[89],q[56];
u1(pi/17179869184) q[56];
u1(pi/8589934592) q[89];
cx q[89],q[57];
u1(-pi/8589934592) q[57];
cx q[89],q[57];
u1(pi/8589934592) q[57];
u1(pi/4294967296) q[89];
cx q[89],q[58];
u1(-pi/4294967296) q[58];
cx q[89],q[58];
u1(pi/4294967296) q[58];
u1(pi/2147483648) q[89];
cx q[89],q[59];
u1(-pi/2147483648) q[59];
cx q[89],q[59];
u1(pi/2147483648) q[59];
u1(pi/1073741824) q[89];
cx q[89],q[60];
u1(-pi/1073741824) q[60];
cx q[89],q[60];
u1(pi/1073741824) q[60];
u1(pi/536870912) q[89];
cx q[89],q[61];
u1(-pi/536870912) q[61];
cx q[89],q[61];
u1(pi/536870912) q[61];
u1(pi/268435456) q[89];
cx q[89],q[62];
u1(-pi/268435456) q[62];
cx q[89],q[62];
u1(pi/268435456) q[62];
u1(pi/134217728) q[89];
cx q[89],q[63];
u1(-pi/134217728) q[63];
cx q[89],q[63];
u1(pi/134217728) q[63];
u1(pi/67108864) q[89];
cx q[89],q[64];
u1(-pi/67108864) q[64];
cx q[89],q[64];
u1(pi/67108864) q[64];
u1(pi/33554432) q[89];
cx q[89],q[65];
u1(-pi/33554432) q[65];
cx q[89],q[65];
u1(pi/33554432) q[65];
u1(pi/16777216) q[89];
cx q[89],q[66];
u1(-pi/16777216) q[66];
cx q[89],q[66];
u1(pi/16777216) q[66];
u1(pi/8388608) q[89];
cx q[89],q[67];
u1(-pi/8388608) q[67];
cx q[89],q[67];
u1(pi/8388608) q[67];
u1(pi/4194304) q[89];
cx q[89],q[68];
u1(-pi/4194304) q[68];
cx q[89],q[68];
u1(pi/4194304) q[68];
u1(pi/2097152) q[89];
cx q[89],q[69];
u1(-pi/2097152) q[69];
cx q[89],q[69];
u1(pi/2097152) q[69];
u1(pi/1048576) q[89];
cx q[89],q[70];
u1(-pi/1048576) q[70];
cx q[89],q[70];
u1(pi/1048576) q[70];
u1(pi/524288) q[89];
cx q[89],q[71];
u1(-pi/524288) q[71];
cx q[89],q[71];
u1(pi/524288) q[71];
u1(pi/262144) q[89];
cx q[89],q[72];
u1(-pi/262144) q[72];
cx q[89],q[72];
u1(pi/262144) q[72];
u1(pi/131072) q[89];
cx q[89],q[73];
u1(-pi/131072) q[73];
cx q[89],q[73];
u1(pi/131072) q[73];
u1(pi/65536) q[89];
cx q[89],q[74];
u1(-pi/65536) q[74];
cx q[89],q[74];
u1(pi/65536) q[74];
u1(pi/32768) q[89];
cx q[89],q[75];
u1(-pi/32768) q[75];
cx q[89],q[75];
u1(pi/32768) q[75];
u1(pi/16384) q[89];
cx q[89],q[76];
u1(-pi/16384) q[76];
cx q[89],q[76];
u1(pi/16384) q[76];
u1(pi/8192) q[89];
cx q[89],q[77];
u1(-pi/8192) q[77];
cx q[89],q[77];
u1(pi/8192) q[77];
u1(pi/4096) q[89];
cx q[89],q[78];
u1(-pi/4096) q[78];
cx q[89],q[78];
u1(pi/4096) q[78];
u1(pi/2048) q[89];
cx q[89],q[79];
u1(-pi/2048) q[79];
cx q[89],q[79];
u1(pi/2048) q[79];
u1(pi/1024) q[89];
cx q[89],q[80];
u1(-pi/1024) q[80];
cx q[89],q[80];
u1(pi/1024) q[80];
u1(pi/512) q[89];
cx q[89],q[81];
u1(-pi/512) q[81];
cx q[89],q[81];
u1(pi/512) q[81];
u1(pi/256) q[89];
cx q[89],q[82];
u1(-pi/256) q[82];
cx q[89],q[82];
u1(pi/256) q[82];
u1(pi/128) q[89];
cx q[89],q[83];
u1(-pi/128) q[83];
cx q[89],q[83];
u1(pi/128) q[83];
u1(pi/64) q[89];
cx q[89],q[84];
u1(-pi/64) q[84];
cx q[89],q[84];
u1(pi/64) q[84];
u1(pi/32) q[89];
cx q[89],q[85];
u1(-pi/32) q[85];
cx q[89],q[85];
u1(pi/32) q[85];
u1(pi/16) q[89];
cx q[89],q[86];
u1(-pi/16) q[86];
cx q[89],q[86];
u1(pi/16) q[86];
u1(pi/8) q[89];
cx q[89],q[87];
u1(-pi/8) q[87];
cx q[89],q[87];
u1(pi/8) q[87];
u1(pi/4) q[89];
cx q[89],q[88];
u1(-pi/4) q[88];
cx q[89],q[88];
u1(pi/4) q[88];
h q[89];
u1(0) q[90];
cx q[90],q[0];
u1(0) q[0];
cx q[90],q[0];
u1(0) q[0];
u1(0) q[90];
cx q[90],q[1];
u1(0) q[1];
cx q[90],q[1];
u1(0) q[1];
u1(0) q[90];
cx q[90],q[2];
u1(0) q[2];
cx q[90],q[2];
u1(0) q[2];
u1(0) q[90];
cx q[90],q[3];
u1(0) q[3];
cx q[90],q[3];
u1(0) q[3];
u1(0) q[90];
cx q[90],q[4];
u1(0) q[4];
cx q[90],q[4];
u1(0) q[4];
u1(0) q[90];
cx q[90],q[5];
u1(0) q[5];
cx q[90],q[5];
u1(0) q[5];
u1(0) q[90];
cx q[90],q[6];
u1(0) q[6];
cx q[90],q[6];
u1(0) q[6];
u1(0) q[90];
cx q[90],q[7];
u1(0) q[7];
cx q[90],q[7];
u1(0) q[7];
u1(0) q[90];
cx q[90],q[8];
u1(0) q[8];
cx q[90],q[8];
u1(0) q[8];
u1(0) q[90];
cx q[90],q[9];
u1(0) q[9];
cx q[90],q[9];
u1(0) q[9];
u1(0) q[90];
cx q[90],q[10];
u1(0) q[10];
cx q[90],q[10];
u1(0) q[10];
u1(0) q[90];
cx q[90],q[11];
u1(0) q[11];
cx q[90],q[11];
u1(0) q[11];
u1(0) q[90];
cx q[90],q[12];
u1(0) q[12];
cx q[90],q[12];
u1(0) q[12];
u1(0) q[90];
cx q[90],q[13];
u1(0) q[13];
cx q[90],q[13];
u1(0) q[13];
u1(0) q[90];
cx q[90],q[14];
u1(0) q[14];
cx q[90],q[14];
u1(0) q[14];
u1(0) q[90];
cx q[90],q[15];
u1(0) q[15];
cx q[90],q[15];
u1(0) q[15];
u1(0) q[90];
cx q[90],q[16];
u1(0) q[16];
cx q[90],q[16];
u1(0) q[16];
u1(0) q[90];
cx q[90],q[17];
u1(0) q[17];
cx q[90],q[17];
u1(0) q[17];
u1(0) q[90];
cx q[90],q[18];
u1(0) q[18];
cx q[90],q[18];
u1(0) q[18];
u1(0) q[90];
cx q[90],q[19];
u1(0) q[19];
cx q[90],q[19];
u1(0) q[19];
u1(0) q[90];
cx q[90],q[20];
u1(0) q[20];
cx q[90],q[20];
u1(0) q[20];
u1(0) q[90];
cx q[90],q[21];
u1(0) q[21];
cx q[90],q[21];
u1(0) q[21];
u1(0) q[90];
cx q[90],q[22];
u1(0) q[22];
cx q[90],q[22];
u1(0) q[22];
u1(0) q[90];
cx q[90],q[23];
u1(0) q[23];
cx q[90],q[23];
u1(0) q[23];
u1(0) q[90];
cx q[90],q[24];
u1(0) q[24];
cx q[90],q[24];
u1(0) q[24];
u1(0) q[90];
cx q[90],q[25];
u1(0) q[25];
cx q[90],q[25];
u1(0) q[25];
u1(0) q[90];
cx q[90],q[26];
u1(0) q[26];
cx q[90],q[26];
u1(0) q[26];
u1(0) q[90];
cx q[90],q[27];
u1(0) q[27];
cx q[90],q[27];
u1(0) q[27];
u1(0) q[90];
cx q[90],q[28];
u1(0) q[28];
cx q[90],q[28];
u1(0) q[28];
u1(0) q[90];
cx q[90],q[29];
u1(0) q[29];
cx q[90],q[29];
u1(0) q[29];
u1(0) q[90];
cx q[90],q[30];
u1(0) q[30];
cx q[90],q[30];
u1(0) q[30];
u1(0) q[90];
cx q[90],q[31];
u1(0) q[31];
cx q[90],q[31];
u1(0) q[31];
u1(0) q[90];
cx q[90],q[32];
u1(0) q[32];
cx q[90],q[32];
u1(0) q[32];
u1(0) q[90];
cx q[90],q[33];
u1(0) q[33];
cx q[90],q[33];
u1(0) q[33];
u1(0) q[90];
cx q[90],q[34];
u1(0) q[34];
cx q[90],q[34];
u1(0) q[34];
u1(0) q[90];
cx q[90],q[35];
u1(0) q[35];
cx q[90],q[35];
u1(0) q[35];
u1(0) q[90];
cx q[90],q[36];
u1(0) q[36];
cx q[90],q[36];
u1(0) q[36];
u1(0) q[90];
cx q[90],q[37];
u1(0) q[37];
cx q[90],q[37];
u1(0) q[37];
u1(0) q[90];
cx q[90],q[38];
u1(0) q[38];
cx q[90],q[38];
u1(0) q[38];
u1(0) q[90];
cx q[90],q[39];
u1(0) q[39];
cx q[90],q[39];
u1(0) q[39];
u1(0) q[90];
cx q[90],q[40];
u1(0) q[40];
cx q[90],q[40];
u1(0) q[40];
u1(0) q[90];
cx q[90],q[41];
u1(0) q[41];
cx q[90],q[41];
u1(0) q[41];
u1(0) q[90];
cx q[90],q[42];
u1(0) q[42];
cx q[90],q[42];
u1(0) q[42];
u1(pi/281474976710656) q[90];
cx q[90],q[43];
u1(-pi/281474976710656) q[43];
cx q[90],q[43];
u1(pi/281474976710656) q[43];
u1(pi/140737488355328) q[90];
cx q[90],q[44];
u1(-pi/140737488355328) q[44];
cx q[90],q[44];
u1(pi/140737488355328) q[44];
u1(pi/70368744177664) q[90];
cx q[90],q[45];
u1(-pi/70368744177664) q[45];
cx q[90],q[45];
u1(pi/70368744177664) q[45];
u1(pi/35184372088832) q[90];
cx q[90],q[46];
u1(-pi/35184372088832) q[46];
cx q[90],q[46];
u1(pi/35184372088832) q[46];
u1(pi/17592186044416) q[90];
cx q[90],q[47];
u1(-pi/17592186044416) q[47];
cx q[90],q[47];
u1(pi/17592186044416) q[47];
u1(pi/8796093022208) q[90];
cx q[90],q[48];
u1(-pi/8796093022208) q[48];
cx q[90],q[48];
u1(pi/8796093022208) q[48];
u1(pi/4398046511104) q[90];
cx q[90],q[49];
u1(-pi/4398046511104) q[49];
cx q[90],q[49];
u1(pi/4398046511104) q[49];
u1(pi/2199023255552) q[90];
cx q[90],q[50];
u1(-pi/2199023255552) q[50];
cx q[90],q[50];
u1(pi/2199023255552) q[50];
u1(pi/1099511627776) q[90];
cx q[90],q[51];
u1(-pi/1099511627776) q[51];
cx q[90],q[51];
u1(pi/1099511627776) q[51];
u1(pi/549755813888) q[90];
cx q[90],q[52];
u1(-pi/549755813888) q[52];
cx q[90],q[52];
u1(pi/549755813888) q[52];
u1(pi/274877906944) q[90];
cx q[90],q[53];
u1(-pi/274877906944) q[53];
cx q[90],q[53];
u1(pi/274877906944) q[53];
u1(pi/137438953472) q[90];
cx q[90],q[54];
u1(-pi/137438953472) q[54];
cx q[90],q[54];
u1(pi/137438953472) q[54];
u1(pi/68719476736) q[90];
cx q[90],q[55];
u1(-pi/68719476736) q[55];
cx q[90],q[55];
u1(pi/68719476736) q[55];
u1(pi/34359738368) q[90];
cx q[90],q[56];
u1(-pi/34359738368) q[56];
cx q[90],q[56];
u1(pi/34359738368) q[56];
u1(pi/17179869184) q[90];
cx q[90],q[57];
u1(-pi/17179869184) q[57];
cx q[90],q[57];
u1(pi/17179869184) q[57];
u1(pi/8589934592) q[90];
cx q[90],q[58];
u1(-pi/8589934592) q[58];
cx q[90],q[58];
u1(pi/8589934592) q[58];
u1(pi/4294967296) q[90];
cx q[90],q[59];
u1(-pi/4294967296) q[59];
cx q[90],q[59];
u1(pi/4294967296) q[59];
u1(pi/2147483648) q[90];
cx q[90],q[60];
u1(-pi/2147483648) q[60];
cx q[90],q[60];
u1(pi/2147483648) q[60];
u1(pi/1073741824) q[90];
cx q[90],q[61];
u1(-pi/1073741824) q[61];
cx q[90],q[61];
u1(pi/1073741824) q[61];
u1(pi/536870912) q[90];
cx q[90],q[62];
u1(-pi/536870912) q[62];
cx q[90],q[62];
u1(pi/536870912) q[62];
u1(pi/268435456) q[90];
cx q[90],q[63];
u1(-pi/268435456) q[63];
cx q[90],q[63];
u1(pi/268435456) q[63];
u1(pi/134217728) q[90];
cx q[90],q[64];
u1(-pi/134217728) q[64];
cx q[90],q[64];
u1(pi/134217728) q[64];
u1(pi/67108864) q[90];
cx q[90],q[65];
u1(-pi/67108864) q[65];
cx q[90],q[65];
u1(pi/67108864) q[65];
u1(pi/33554432) q[90];
cx q[90],q[66];
u1(-pi/33554432) q[66];
cx q[90],q[66];
u1(pi/33554432) q[66];
u1(pi/16777216) q[90];
cx q[90],q[67];
u1(-pi/16777216) q[67];
cx q[90],q[67];
u1(pi/16777216) q[67];
u1(pi/8388608) q[90];
cx q[90],q[68];
u1(-pi/8388608) q[68];
cx q[90],q[68];
u1(pi/8388608) q[68];
u1(pi/4194304) q[90];
cx q[90],q[69];
u1(-pi/4194304) q[69];
cx q[90],q[69];
u1(pi/4194304) q[69];
u1(pi/2097152) q[90];
cx q[90],q[70];
u1(-pi/2097152) q[70];
cx q[90],q[70];
u1(pi/2097152) q[70];
u1(pi/1048576) q[90];
cx q[90],q[71];
u1(-pi/1048576) q[71];
cx q[90],q[71];
u1(pi/1048576) q[71];
u1(pi/524288) q[90];
cx q[90],q[72];
u1(-pi/524288) q[72];
cx q[90],q[72];
u1(pi/524288) q[72];
u1(pi/262144) q[90];
cx q[90],q[73];
u1(-pi/262144) q[73];
cx q[90],q[73];
u1(pi/262144) q[73];
u1(pi/131072) q[90];
cx q[90],q[74];
u1(-pi/131072) q[74];
cx q[90],q[74];
u1(pi/131072) q[74];
u1(pi/65536) q[90];
cx q[90],q[75];
u1(-pi/65536) q[75];
cx q[90],q[75];
u1(pi/65536) q[75];
u1(pi/32768) q[90];
cx q[90],q[76];
u1(-pi/32768) q[76];
cx q[90],q[76];
u1(pi/32768) q[76];
u1(pi/16384) q[90];
cx q[90],q[77];
u1(-pi/16384) q[77];
cx q[90],q[77];
u1(pi/16384) q[77];
u1(pi/8192) q[90];
cx q[90],q[78];
u1(-pi/8192) q[78];
cx q[90],q[78];
u1(pi/8192) q[78];
u1(pi/4096) q[90];
cx q[90],q[79];
u1(-pi/4096) q[79];
cx q[90],q[79];
u1(pi/4096) q[79];
u1(pi/2048) q[90];
cx q[90],q[80];
u1(-pi/2048) q[80];
cx q[90],q[80];
u1(pi/2048) q[80];
u1(pi/1024) q[90];
cx q[90],q[81];
u1(-pi/1024) q[81];
cx q[90],q[81];
u1(pi/1024) q[81];
u1(pi/512) q[90];
cx q[90],q[82];
u1(-pi/512) q[82];
cx q[90],q[82];
u1(pi/512) q[82];
u1(pi/256) q[90];
cx q[90],q[83];
u1(-pi/256) q[83];
cx q[90],q[83];
u1(pi/256) q[83];
u1(pi/128) q[90];
cx q[90],q[84];
u1(-pi/128) q[84];
cx q[90],q[84];
u1(pi/128) q[84];
u1(pi/64) q[90];
cx q[90],q[85];
u1(-pi/64) q[85];
cx q[90],q[85];
u1(pi/64) q[85];
u1(pi/32) q[90];
cx q[90],q[86];
u1(-pi/32) q[86];
cx q[90],q[86];
u1(pi/32) q[86];
u1(pi/16) q[90];
cx q[90],q[87];
u1(-pi/16) q[87];
cx q[90],q[87];
u1(pi/16) q[87];
u1(pi/8) q[90];
cx q[90],q[88];
u1(-pi/8) q[88];
cx q[90],q[88];
u1(pi/8) q[88];
u1(pi/4) q[90];
cx q[90],q[89];
u1(-pi/4) q[89];
cx q[90],q[89];
u1(pi/4) q[89];
h q[90];
u1(0) q[91];
cx q[91],q[0];
u1(0) q[0];
cx q[91],q[0];
u1(0) q[0];
u1(0) q[91];
cx q[91],q[1];
u1(0) q[1];
cx q[91],q[1];
u1(0) q[1];
u1(0) q[91];
cx q[91],q[2];
u1(0) q[2];
cx q[91],q[2];
u1(0) q[2];
u1(0) q[91];
cx q[91],q[3];
u1(0) q[3];
cx q[91],q[3];
u1(0) q[3];
u1(0) q[91];
cx q[91],q[4];
u1(0) q[4];
cx q[91],q[4];
u1(0) q[4];
u1(0) q[91];
cx q[91],q[5];
u1(0) q[5];
cx q[91],q[5];
u1(0) q[5];
u1(0) q[91];
cx q[91],q[6];
u1(0) q[6];
cx q[91],q[6];
u1(0) q[6];
u1(0) q[91];
cx q[91],q[7];
u1(0) q[7];
cx q[91],q[7];
u1(0) q[7];
u1(0) q[91];
cx q[91],q[8];
u1(0) q[8];
cx q[91],q[8];
u1(0) q[8];
u1(0) q[91];
cx q[91],q[9];
u1(0) q[9];
cx q[91],q[9];
u1(0) q[9];
u1(0) q[91];
cx q[91],q[10];
u1(0) q[10];
cx q[91],q[10];
u1(0) q[10];
u1(0) q[91];
cx q[91],q[11];
u1(0) q[11];
cx q[91],q[11];
u1(0) q[11];
u1(0) q[91];
cx q[91],q[12];
u1(0) q[12];
cx q[91],q[12];
u1(0) q[12];
u1(0) q[91];
cx q[91],q[13];
u1(0) q[13];
cx q[91],q[13];
u1(0) q[13];
u1(0) q[91];
cx q[91],q[14];
u1(0) q[14];
cx q[91],q[14];
u1(0) q[14];
u1(0) q[91];
cx q[91],q[15];
u1(0) q[15];
cx q[91],q[15];
u1(0) q[15];
u1(0) q[91];
cx q[91],q[16];
u1(0) q[16];
cx q[91],q[16];
u1(0) q[16];
u1(0) q[91];
cx q[91],q[17];
u1(0) q[17];
cx q[91],q[17];
u1(0) q[17];
u1(0) q[91];
cx q[91],q[18];
u1(0) q[18];
cx q[91],q[18];
u1(0) q[18];
u1(0) q[91];
cx q[91],q[19];
u1(0) q[19];
cx q[91],q[19];
u1(0) q[19];
u1(0) q[91];
cx q[91],q[20];
u1(0) q[20];
cx q[91],q[20];
u1(0) q[20];
u1(0) q[91];
cx q[91],q[21];
u1(0) q[21];
cx q[91],q[21];
u1(0) q[21];
u1(0) q[91];
cx q[91],q[22];
u1(0) q[22];
cx q[91],q[22];
u1(0) q[22];
u1(0) q[91];
cx q[91],q[23];
u1(0) q[23];
cx q[91],q[23];
u1(0) q[23];
u1(0) q[91];
cx q[91],q[24];
u1(0) q[24];
cx q[91],q[24];
u1(0) q[24];
u1(0) q[91];
cx q[91],q[25];
u1(0) q[25];
cx q[91],q[25];
u1(0) q[25];
u1(0) q[91];
cx q[91],q[26];
u1(0) q[26];
cx q[91],q[26];
u1(0) q[26];
u1(0) q[91];
cx q[91],q[27];
u1(0) q[27];
cx q[91],q[27];
u1(0) q[27];
u1(0) q[91];
cx q[91],q[28];
u1(0) q[28];
cx q[91],q[28];
u1(0) q[28];
u1(0) q[91];
cx q[91],q[29];
u1(0) q[29];
cx q[91],q[29];
u1(0) q[29];
u1(0) q[91];
cx q[91],q[30];
u1(0) q[30];
cx q[91],q[30];
u1(0) q[30];
u1(0) q[91];
cx q[91],q[31];
u1(0) q[31];
cx q[91],q[31];
u1(0) q[31];
u1(0) q[91];
cx q[91],q[32];
u1(0) q[32];
cx q[91],q[32];
u1(0) q[32];
u1(0) q[91];
cx q[91],q[33];
u1(0) q[33];
cx q[91],q[33];
u1(0) q[33];
u1(0) q[91];
cx q[91],q[34];
u1(0) q[34];
cx q[91],q[34];
u1(0) q[34];
u1(0) q[91];
cx q[91],q[35];
u1(0) q[35];
cx q[91],q[35];
u1(0) q[35];
u1(0) q[91];
cx q[91],q[36];
u1(0) q[36];
cx q[91],q[36];
u1(0) q[36];
u1(0) q[91];
cx q[91],q[37];
u1(0) q[37];
cx q[91],q[37];
u1(0) q[37];
u1(0) q[91];
cx q[91],q[38];
u1(0) q[38];
cx q[91],q[38];
u1(0) q[38];
u1(0) q[91];
cx q[91],q[39];
u1(0) q[39];
cx q[91],q[39];
u1(0) q[39];
u1(0) q[91];
cx q[91],q[40];
u1(0) q[40];
cx q[91],q[40];
u1(0) q[40];
u1(0) q[91];
cx q[91],q[41];
u1(0) q[41];
cx q[91],q[41];
u1(0) q[41];
u1(0) q[91];
cx q[91],q[42];
u1(0) q[42];
cx q[91],q[42];
u1(0) q[42];
u1(0) q[91];
cx q[91],q[43];
u1(0) q[43];
cx q[91],q[43];
u1(0) q[43];
u1(pi/281474976710656) q[91];
cx q[91],q[44];
u1(-pi/281474976710656) q[44];
cx q[91],q[44];
u1(pi/281474976710656) q[44];
u1(pi/140737488355328) q[91];
cx q[91],q[45];
u1(-pi/140737488355328) q[45];
cx q[91],q[45];
u1(pi/140737488355328) q[45];
u1(pi/70368744177664) q[91];
cx q[91],q[46];
u1(-pi/70368744177664) q[46];
cx q[91],q[46];
u1(pi/70368744177664) q[46];
u1(pi/35184372088832) q[91];
cx q[91],q[47];
u1(-pi/35184372088832) q[47];
cx q[91],q[47];
u1(pi/35184372088832) q[47];
u1(pi/17592186044416) q[91];
cx q[91],q[48];
u1(-pi/17592186044416) q[48];
cx q[91],q[48];
u1(pi/17592186044416) q[48];
u1(pi/8796093022208) q[91];
cx q[91],q[49];
u1(-pi/8796093022208) q[49];
cx q[91],q[49];
u1(pi/8796093022208) q[49];
u1(pi/4398046511104) q[91];
cx q[91],q[50];
u1(-pi/4398046511104) q[50];
cx q[91],q[50];
u1(pi/4398046511104) q[50];
u1(pi/2199023255552) q[91];
cx q[91],q[51];
u1(-pi/2199023255552) q[51];
cx q[91],q[51];
u1(pi/2199023255552) q[51];
u1(pi/1099511627776) q[91];
cx q[91],q[52];
u1(-pi/1099511627776) q[52];
cx q[91],q[52];
u1(pi/1099511627776) q[52];
u1(pi/549755813888) q[91];
cx q[91],q[53];
u1(-pi/549755813888) q[53];
cx q[91],q[53];
u1(pi/549755813888) q[53];
u1(pi/274877906944) q[91];
cx q[91],q[54];
u1(-pi/274877906944) q[54];
cx q[91],q[54];
u1(pi/274877906944) q[54];
u1(pi/137438953472) q[91];
cx q[91],q[55];
u1(-pi/137438953472) q[55];
cx q[91],q[55];
u1(pi/137438953472) q[55];
u1(pi/68719476736) q[91];
cx q[91],q[56];
u1(-pi/68719476736) q[56];
cx q[91],q[56];
u1(pi/68719476736) q[56];
u1(pi/34359738368) q[91];
cx q[91],q[57];
u1(-pi/34359738368) q[57];
cx q[91],q[57];
u1(pi/34359738368) q[57];
u1(pi/17179869184) q[91];
cx q[91],q[58];
u1(-pi/17179869184) q[58];
cx q[91],q[58];
u1(pi/17179869184) q[58];
u1(pi/8589934592) q[91];
cx q[91],q[59];
u1(-pi/8589934592) q[59];
cx q[91],q[59];
u1(pi/8589934592) q[59];
u1(pi/4294967296) q[91];
cx q[91],q[60];
u1(-pi/4294967296) q[60];
cx q[91],q[60];
u1(pi/4294967296) q[60];
u1(pi/2147483648) q[91];
cx q[91],q[61];
u1(-pi/2147483648) q[61];
cx q[91],q[61];
u1(pi/2147483648) q[61];
u1(pi/1073741824) q[91];
cx q[91],q[62];
u1(-pi/1073741824) q[62];
cx q[91],q[62];
u1(pi/1073741824) q[62];
u1(pi/536870912) q[91];
cx q[91],q[63];
u1(-pi/536870912) q[63];
cx q[91],q[63];
u1(pi/536870912) q[63];
u1(pi/268435456) q[91];
cx q[91],q[64];
u1(-pi/268435456) q[64];
cx q[91],q[64];
u1(pi/268435456) q[64];
u1(pi/134217728) q[91];
cx q[91],q[65];
u1(-pi/134217728) q[65];
cx q[91],q[65];
u1(pi/134217728) q[65];
u1(pi/67108864) q[91];
cx q[91],q[66];
u1(-pi/67108864) q[66];
cx q[91],q[66];
u1(pi/67108864) q[66];
u1(pi/33554432) q[91];
cx q[91],q[67];
u1(-pi/33554432) q[67];
cx q[91],q[67];
u1(pi/33554432) q[67];
u1(pi/16777216) q[91];
cx q[91],q[68];
u1(-pi/16777216) q[68];
cx q[91],q[68];
u1(pi/16777216) q[68];
u1(pi/8388608) q[91];
cx q[91],q[69];
u1(-pi/8388608) q[69];
cx q[91],q[69];
u1(pi/8388608) q[69];
u1(pi/4194304) q[91];
cx q[91],q[70];
u1(-pi/4194304) q[70];
cx q[91],q[70];
u1(pi/4194304) q[70];
u1(pi/2097152) q[91];
cx q[91],q[71];
u1(-pi/2097152) q[71];
cx q[91],q[71];
u1(pi/2097152) q[71];
u1(pi/1048576) q[91];
cx q[91],q[72];
u1(-pi/1048576) q[72];
cx q[91],q[72];
u1(pi/1048576) q[72];
u1(pi/524288) q[91];
cx q[91],q[73];
u1(-pi/524288) q[73];
cx q[91],q[73];
u1(pi/524288) q[73];
u1(pi/262144) q[91];
cx q[91],q[74];
u1(-pi/262144) q[74];
cx q[91],q[74];
u1(pi/262144) q[74];
u1(pi/131072) q[91];
cx q[91],q[75];
u1(-pi/131072) q[75];
cx q[91],q[75];
u1(pi/131072) q[75];
u1(pi/65536) q[91];
cx q[91],q[76];
u1(-pi/65536) q[76];
cx q[91],q[76];
u1(pi/65536) q[76];
u1(pi/32768) q[91];
cx q[91],q[77];
u1(-pi/32768) q[77];
cx q[91],q[77];
u1(pi/32768) q[77];
u1(pi/16384) q[91];
cx q[91],q[78];
u1(-pi/16384) q[78];
cx q[91],q[78];
u1(pi/16384) q[78];
u1(pi/8192) q[91];
cx q[91],q[79];
u1(-pi/8192) q[79];
cx q[91],q[79];
u1(pi/8192) q[79];
u1(pi/4096) q[91];
cx q[91],q[80];
u1(-pi/4096) q[80];
cx q[91],q[80];
u1(pi/4096) q[80];
u1(pi/2048) q[91];
cx q[91],q[81];
u1(-pi/2048) q[81];
cx q[91],q[81];
u1(pi/2048) q[81];
u1(pi/1024) q[91];
cx q[91],q[82];
u1(-pi/1024) q[82];
cx q[91],q[82];
u1(pi/1024) q[82];
u1(pi/512) q[91];
cx q[91],q[83];
u1(-pi/512) q[83];
cx q[91],q[83];
u1(pi/512) q[83];
u1(pi/256) q[91];
cx q[91],q[84];
u1(-pi/256) q[84];
cx q[91],q[84];
u1(pi/256) q[84];
u1(pi/128) q[91];
cx q[91],q[85];
u1(-pi/128) q[85];
cx q[91],q[85];
u1(pi/128) q[85];
u1(pi/64) q[91];
cx q[91],q[86];
u1(-pi/64) q[86];
cx q[91],q[86];
u1(pi/64) q[86];
u1(pi/32) q[91];
cx q[91],q[87];
u1(-pi/32) q[87];
cx q[91],q[87];
u1(pi/32) q[87];
u1(pi/16) q[91];
cx q[91],q[88];
u1(-pi/16) q[88];
cx q[91],q[88];
u1(pi/16) q[88];
u1(pi/8) q[91];
cx q[91],q[89];
u1(-pi/8) q[89];
cx q[91],q[89];
u1(pi/8) q[89];
u1(pi/4) q[91];
cx q[91],q[90];
u1(-pi/4) q[90];
cx q[91],q[90];
u1(pi/4) q[90];
h q[91];
u1(0) q[92];
cx q[92],q[0];
u1(0) q[0];
cx q[92],q[0];
u1(0) q[0];
u1(0) q[92];
cx q[92],q[1];
u1(0) q[1];
cx q[92],q[1];
u1(0) q[1];
u1(0) q[92];
cx q[92],q[2];
u1(0) q[2];
cx q[92],q[2];
u1(0) q[2];
u1(0) q[92];
cx q[92],q[3];
u1(0) q[3];
cx q[92],q[3];
u1(0) q[3];
u1(0) q[92];
cx q[92],q[4];
u1(0) q[4];
cx q[92],q[4];
u1(0) q[4];
u1(0) q[92];
cx q[92],q[5];
u1(0) q[5];
cx q[92],q[5];
u1(0) q[5];
u1(0) q[92];
cx q[92],q[6];
u1(0) q[6];
cx q[92],q[6];
u1(0) q[6];
u1(0) q[92];
cx q[92],q[7];
u1(0) q[7];
cx q[92],q[7];
u1(0) q[7];
u1(0) q[92];
cx q[92],q[8];
u1(0) q[8];
cx q[92],q[8];
u1(0) q[8];
u1(0) q[92];
cx q[92],q[9];
u1(0) q[9];
cx q[92],q[9];
u1(0) q[9];
u1(0) q[92];
cx q[92],q[10];
u1(0) q[10];
cx q[92],q[10];
u1(0) q[10];
u1(0) q[92];
cx q[92],q[11];
u1(0) q[11];
cx q[92],q[11];
u1(0) q[11];
u1(0) q[92];
cx q[92],q[12];
u1(0) q[12];
cx q[92],q[12];
u1(0) q[12];
u1(0) q[92];
cx q[92],q[13];
u1(0) q[13];
cx q[92],q[13];
u1(0) q[13];
u1(0) q[92];
cx q[92],q[14];
u1(0) q[14];
cx q[92],q[14];
u1(0) q[14];
u1(0) q[92];
cx q[92],q[15];
u1(0) q[15];
cx q[92],q[15];
u1(0) q[15];
u1(0) q[92];
cx q[92],q[16];
u1(0) q[16];
cx q[92],q[16];
u1(0) q[16];
u1(0) q[92];
cx q[92],q[17];
u1(0) q[17];
cx q[92],q[17];
u1(0) q[17];
u1(0) q[92];
cx q[92],q[18];
u1(0) q[18];
cx q[92],q[18];
u1(0) q[18];
u1(0) q[92];
cx q[92],q[19];
u1(0) q[19];
cx q[92],q[19];
u1(0) q[19];
u1(0) q[92];
cx q[92],q[20];
u1(0) q[20];
cx q[92],q[20];
u1(0) q[20];
u1(0) q[92];
cx q[92],q[21];
u1(0) q[21];
cx q[92],q[21];
u1(0) q[21];
u1(0) q[92];
cx q[92],q[22];
u1(0) q[22];
cx q[92],q[22];
u1(0) q[22];
u1(0) q[92];
cx q[92],q[23];
u1(0) q[23];
cx q[92],q[23];
u1(0) q[23];
u1(0) q[92];
cx q[92],q[24];
u1(0) q[24];
cx q[92],q[24];
u1(0) q[24];
u1(0) q[92];
cx q[92],q[25];
u1(0) q[25];
cx q[92],q[25];
u1(0) q[25];
u1(0) q[92];
cx q[92],q[26];
u1(0) q[26];
cx q[92],q[26];
u1(0) q[26];
u1(0) q[92];
cx q[92],q[27];
u1(0) q[27];
cx q[92],q[27];
u1(0) q[27];
u1(0) q[92];
cx q[92],q[28];
u1(0) q[28];
cx q[92],q[28];
u1(0) q[28];
u1(0) q[92];
cx q[92],q[29];
u1(0) q[29];
cx q[92],q[29];
u1(0) q[29];
u1(0) q[92];
cx q[92],q[30];
u1(0) q[30];
cx q[92],q[30];
u1(0) q[30];
u1(0) q[92];
cx q[92],q[31];
u1(0) q[31];
cx q[92],q[31];
u1(0) q[31];
u1(0) q[92];
cx q[92],q[32];
u1(0) q[32];
cx q[92],q[32];
u1(0) q[32];
u1(0) q[92];
cx q[92],q[33];
u1(0) q[33];
cx q[92],q[33];
u1(0) q[33];
u1(0) q[92];
cx q[92],q[34];
u1(0) q[34];
cx q[92],q[34];
u1(0) q[34];
u1(0) q[92];
cx q[92],q[35];
u1(0) q[35];
cx q[92],q[35];
u1(0) q[35];
u1(0) q[92];
cx q[92],q[36];
u1(0) q[36];
cx q[92],q[36];
u1(0) q[36];
u1(0) q[92];
cx q[92],q[37];
u1(0) q[37];
cx q[92],q[37];
u1(0) q[37];
u1(0) q[92];
cx q[92],q[38];
u1(0) q[38];
cx q[92],q[38];
u1(0) q[38];
u1(0) q[92];
cx q[92],q[39];
u1(0) q[39];
cx q[92],q[39];
u1(0) q[39];
u1(0) q[92];
cx q[92],q[40];
u1(0) q[40];
cx q[92],q[40];
u1(0) q[40];
u1(0) q[92];
cx q[92],q[41];
u1(0) q[41];
cx q[92],q[41];
u1(0) q[41];
u1(0) q[92];
cx q[92],q[42];
u1(0) q[42];
cx q[92],q[42];
u1(0) q[42];
u1(0) q[92];
cx q[92],q[43];
u1(0) q[43];
cx q[92],q[43];
u1(0) q[43];
u1(0) q[92];
cx q[92],q[44];
u1(0) q[44];
cx q[92],q[44];
u1(0) q[44];
u1(pi/281474976710656) q[92];
cx q[92],q[45];
u1(-pi/281474976710656) q[45];
cx q[92],q[45];
u1(pi/281474976710656) q[45];
u1(pi/140737488355328) q[92];
cx q[92],q[46];
u1(-pi/140737488355328) q[46];
cx q[92],q[46];
u1(pi/140737488355328) q[46];
u1(pi/70368744177664) q[92];
cx q[92],q[47];
u1(-pi/70368744177664) q[47];
cx q[92],q[47];
u1(pi/70368744177664) q[47];
u1(pi/35184372088832) q[92];
cx q[92],q[48];
u1(-pi/35184372088832) q[48];
cx q[92],q[48];
u1(pi/35184372088832) q[48];
u1(pi/17592186044416) q[92];
cx q[92],q[49];
u1(-pi/17592186044416) q[49];
cx q[92],q[49];
u1(pi/17592186044416) q[49];
u1(pi/8796093022208) q[92];
cx q[92],q[50];
u1(-pi/8796093022208) q[50];
cx q[92],q[50];
u1(pi/8796093022208) q[50];
u1(pi/4398046511104) q[92];
cx q[92],q[51];
u1(-pi/4398046511104) q[51];
cx q[92],q[51];
u1(pi/4398046511104) q[51];
u1(pi/2199023255552) q[92];
cx q[92],q[52];
u1(-pi/2199023255552) q[52];
cx q[92],q[52];
u1(pi/2199023255552) q[52];
u1(pi/1099511627776) q[92];
cx q[92],q[53];
u1(-pi/1099511627776) q[53];
cx q[92],q[53];
u1(pi/1099511627776) q[53];
u1(pi/549755813888) q[92];
cx q[92],q[54];
u1(-pi/549755813888) q[54];
cx q[92],q[54];
u1(pi/549755813888) q[54];
u1(pi/274877906944) q[92];
cx q[92],q[55];
u1(-pi/274877906944) q[55];
cx q[92],q[55];
u1(pi/274877906944) q[55];
u1(pi/137438953472) q[92];
cx q[92],q[56];
u1(-pi/137438953472) q[56];
cx q[92],q[56];
u1(pi/137438953472) q[56];
u1(pi/68719476736) q[92];
cx q[92],q[57];
u1(-pi/68719476736) q[57];
cx q[92],q[57];
u1(pi/68719476736) q[57];
u1(pi/34359738368) q[92];
cx q[92],q[58];
u1(-pi/34359738368) q[58];
cx q[92],q[58];
u1(pi/34359738368) q[58];
u1(pi/17179869184) q[92];
cx q[92],q[59];
u1(-pi/17179869184) q[59];
cx q[92],q[59];
u1(pi/17179869184) q[59];
u1(pi/8589934592) q[92];
cx q[92],q[60];
u1(-pi/8589934592) q[60];
cx q[92],q[60];
u1(pi/8589934592) q[60];
u1(pi/4294967296) q[92];
cx q[92],q[61];
u1(-pi/4294967296) q[61];
cx q[92],q[61];
u1(pi/4294967296) q[61];
u1(pi/2147483648) q[92];
cx q[92],q[62];
u1(-pi/2147483648) q[62];
cx q[92],q[62];
u1(pi/2147483648) q[62];
u1(pi/1073741824) q[92];
cx q[92],q[63];
u1(-pi/1073741824) q[63];
cx q[92],q[63];
u1(pi/1073741824) q[63];
u1(pi/536870912) q[92];
cx q[92],q[64];
u1(-pi/536870912) q[64];
cx q[92],q[64];
u1(pi/536870912) q[64];
u1(pi/268435456) q[92];
cx q[92],q[65];
u1(-pi/268435456) q[65];
cx q[92],q[65];
u1(pi/268435456) q[65];
u1(pi/134217728) q[92];
cx q[92],q[66];
u1(-pi/134217728) q[66];
cx q[92],q[66];
u1(pi/134217728) q[66];
u1(pi/67108864) q[92];
cx q[92],q[67];
u1(-pi/67108864) q[67];
cx q[92],q[67];
u1(pi/67108864) q[67];
u1(pi/33554432) q[92];
cx q[92],q[68];
u1(-pi/33554432) q[68];
cx q[92],q[68];
u1(pi/33554432) q[68];
u1(pi/16777216) q[92];
cx q[92],q[69];
u1(-pi/16777216) q[69];
cx q[92],q[69];
u1(pi/16777216) q[69];
u1(pi/8388608) q[92];
cx q[92],q[70];
u1(-pi/8388608) q[70];
cx q[92],q[70];
u1(pi/8388608) q[70];
u1(pi/4194304) q[92];
cx q[92],q[71];
u1(-pi/4194304) q[71];
cx q[92],q[71];
u1(pi/4194304) q[71];
u1(pi/2097152) q[92];
cx q[92],q[72];
u1(-pi/2097152) q[72];
cx q[92],q[72];
u1(pi/2097152) q[72];
u1(pi/1048576) q[92];
cx q[92],q[73];
u1(-pi/1048576) q[73];
cx q[92],q[73];
u1(pi/1048576) q[73];
u1(pi/524288) q[92];
cx q[92],q[74];
u1(-pi/524288) q[74];
cx q[92],q[74];
u1(pi/524288) q[74];
u1(pi/262144) q[92];
cx q[92],q[75];
u1(-pi/262144) q[75];
cx q[92],q[75];
u1(pi/262144) q[75];
u1(pi/131072) q[92];
cx q[92],q[76];
u1(-pi/131072) q[76];
cx q[92],q[76];
u1(pi/131072) q[76];
u1(pi/65536) q[92];
cx q[92],q[77];
u1(-pi/65536) q[77];
cx q[92],q[77];
u1(pi/65536) q[77];
u1(pi/32768) q[92];
cx q[92],q[78];
u1(-pi/32768) q[78];
cx q[92],q[78];
u1(pi/32768) q[78];
u1(pi/16384) q[92];
cx q[92],q[79];
u1(-pi/16384) q[79];
cx q[92],q[79];
u1(pi/16384) q[79];
u1(pi/8192) q[92];
cx q[92],q[80];
u1(-pi/8192) q[80];
cx q[92],q[80];
u1(pi/8192) q[80];
u1(pi/4096) q[92];
cx q[92],q[81];
u1(-pi/4096) q[81];
cx q[92],q[81];
u1(pi/4096) q[81];
u1(pi/2048) q[92];
cx q[92],q[82];
u1(-pi/2048) q[82];
cx q[92],q[82];
u1(pi/2048) q[82];
u1(pi/1024) q[92];
cx q[92],q[83];
u1(-pi/1024) q[83];
cx q[92],q[83];
u1(pi/1024) q[83];
u1(pi/512) q[92];
cx q[92],q[84];
u1(-pi/512) q[84];
cx q[92],q[84];
u1(pi/512) q[84];
u1(pi/256) q[92];
cx q[92],q[85];
u1(-pi/256) q[85];
cx q[92],q[85];
u1(pi/256) q[85];
u1(pi/128) q[92];
cx q[92],q[86];
u1(-pi/128) q[86];
cx q[92],q[86];
u1(pi/128) q[86];
u1(pi/64) q[92];
cx q[92],q[87];
u1(-pi/64) q[87];
cx q[92],q[87];
u1(pi/64) q[87];
u1(pi/32) q[92];
cx q[92],q[88];
u1(-pi/32) q[88];
cx q[92],q[88];
u1(pi/32) q[88];
u1(pi/16) q[92];
cx q[92],q[89];
u1(-pi/16) q[89];
cx q[92],q[89];
u1(pi/16) q[89];
u1(pi/8) q[92];
cx q[92],q[90];
u1(-pi/8) q[90];
cx q[92],q[90];
u1(pi/8) q[90];
u1(pi/4) q[92];
cx q[92],q[91];
u1(-pi/4) q[91];
cx q[92],q[91];
u1(pi/4) q[91];
h q[92];
u1(0) q[93];
cx q[93],q[0];
u1(0) q[0];
cx q[93],q[0];
u1(0) q[0];
u1(0) q[93];
cx q[93],q[1];
u1(0) q[1];
cx q[93],q[1];
u1(0) q[1];
u1(0) q[93];
cx q[93],q[2];
u1(0) q[2];
cx q[93],q[2];
u1(0) q[2];
u1(0) q[93];
cx q[93],q[3];
u1(0) q[3];
cx q[93],q[3];
u1(0) q[3];
u1(0) q[93];
cx q[93],q[4];
u1(0) q[4];
cx q[93],q[4];
u1(0) q[4];
u1(0) q[93];
cx q[93],q[5];
u1(0) q[5];
cx q[93],q[5];
u1(0) q[5];
u1(0) q[93];
cx q[93],q[6];
u1(0) q[6];
cx q[93],q[6];
u1(0) q[6];
u1(0) q[93];
cx q[93],q[7];
u1(0) q[7];
cx q[93],q[7];
u1(0) q[7];
u1(0) q[93];
cx q[93],q[8];
u1(0) q[8];
cx q[93],q[8];
u1(0) q[8];
u1(0) q[93];
cx q[93],q[9];
u1(0) q[9];
cx q[93],q[9];
u1(0) q[9];
u1(0) q[93];
cx q[93],q[10];
u1(0) q[10];
cx q[93],q[10];
u1(0) q[10];
u1(0) q[93];
cx q[93],q[11];
u1(0) q[11];
cx q[93],q[11];
u1(0) q[11];
u1(0) q[93];
cx q[93],q[12];
u1(0) q[12];
cx q[93],q[12];
u1(0) q[12];
u1(0) q[93];
cx q[93],q[13];
u1(0) q[13];
cx q[93],q[13];
u1(0) q[13];
u1(0) q[93];
cx q[93],q[14];
u1(0) q[14];
cx q[93],q[14];
u1(0) q[14];
u1(0) q[93];
cx q[93],q[15];
u1(0) q[15];
cx q[93],q[15];
u1(0) q[15];
u1(0) q[93];
cx q[93],q[16];
u1(0) q[16];
cx q[93],q[16];
u1(0) q[16];
u1(0) q[93];
cx q[93],q[17];
u1(0) q[17];
cx q[93],q[17];
u1(0) q[17];
u1(0) q[93];
cx q[93],q[18];
u1(0) q[18];
cx q[93],q[18];
u1(0) q[18];
u1(0) q[93];
cx q[93],q[19];
u1(0) q[19];
cx q[93],q[19];
u1(0) q[19];
u1(0) q[93];
cx q[93],q[20];
u1(0) q[20];
cx q[93],q[20];
u1(0) q[20];
u1(0) q[93];
cx q[93],q[21];
u1(0) q[21];
cx q[93],q[21];
u1(0) q[21];
u1(0) q[93];
cx q[93],q[22];
u1(0) q[22];
cx q[93],q[22];
u1(0) q[22];
u1(0) q[93];
cx q[93],q[23];
u1(0) q[23];
cx q[93],q[23];
u1(0) q[23];
u1(0) q[93];
cx q[93],q[24];
u1(0) q[24];
cx q[93],q[24];
u1(0) q[24];
u1(0) q[93];
cx q[93],q[25];
u1(0) q[25];
cx q[93],q[25];
u1(0) q[25];
u1(0) q[93];
cx q[93],q[26];
u1(0) q[26];
cx q[93],q[26];
u1(0) q[26];
u1(0) q[93];
cx q[93],q[27];
u1(0) q[27];
cx q[93],q[27];
u1(0) q[27];
u1(0) q[93];
cx q[93],q[28];
u1(0) q[28];
cx q[93],q[28];
u1(0) q[28];
u1(0) q[93];
cx q[93],q[29];
u1(0) q[29];
cx q[93],q[29];
u1(0) q[29];
u1(0) q[93];
cx q[93],q[30];
u1(0) q[30];
cx q[93],q[30];
u1(0) q[30];
u1(0) q[93];
cx q[93],q[31];
u1(0) q[31];
cx q[93],q[31];
u1(0) q[31];
u1(0) q[93];
cx q[93],q[32];
u1(0) q[32];
cx q[93],q[32];
u1(0) q[32];
u1(0) q[93];
cx q[93],q[33];
u1(0) q[33];
cx q[93],q[33];
u1(0) q[33];
u1(0) q[93];
cx q[93],q[34];
u1(0) q[34];
cx q[93],q[34];
u1(0) q[34];
u1(0) q[93];
cx q[93],q[35];
u1(0) q[35];
cx q[93],q[35];
u1(0) q[35];
u1(0) q[93];
cx q[93],q[36];
u1(0) q[36];
cx q[93],q[36];
u1(0) q[36];
u1(0) q[93];
cx q[93],q[37];
u1(0) q[37];
cx q[93],q[37];
u1(0) q[37];
u1(0) q[93];
cx q[93],q[38];
u1(0) q[38];
cx q[93],q[38];
u1(0) q[38];
u1(0) q[93];
cx q[93],q[39];
u1(0) q[39];
cx q[93],q[39];
u1(0) q[39];
u1(0) q[93];
cx q[93],q[40];
u1(0) q[40];
cx q[93],q[40];
u1(0) q[40];
u1(0) q[93];
cx q[93],q[41];
u1(0) q[41];
cx q[93],q[41];
u1(0) q[41];
u1(0) q[93];
cx q[93],q[42];
u1(0) q[42];
cx q[93],q[42];
u1(0) q[42];
u1(0) q[93];
cx q[93],q[43];
u1(0) q[43];
cx q[93],q[43];
u1(0) q[43];
u1(0) q[93];
cx q[93],q[44];
u1(0) q[44];
cx q[93],q[44];
u1(0) q[44];
u1(0) q[93];
cx q[93],q[45];
u1(0) q[45];
cx q[93],q[45];
u1(0) q[45];
u1(pi/281474976710656) q[93];
cx q[93],q[46];
u1(-pi/281474976710656) q[46];
cx q[93],q[46];
u1(pi/281474976710656) q[46];
u1(pi/140737488355328) q[93];
cx q[93],q[47];
u1(-pi/140737488355328) q[47];
cx q[93],q[47];
u1(pi/140737488355328) q[47];
u1(pi/70368744177664) q[93];
cx q[93],q[48];
u1(-pi/70368744177664) q[48];
cx q[93],q[48];
u1(pi/70368744177664) q[48];
u1(pi/35184372088832) q[93];
cx q[93],q[49];
u1(-pi/35184372088832) q[49];
cx q[93],q[49];
u1(pi/35184372088832) q[49];
u1(pi/17592186044416) q[93];
cx q[93],q[50];
u1(-pi/17592186044416) q[50];
cx q[93],q[50];
u1(pi/17592186044416) q[50];
u1(pi/8796093022208) q[93];
cx q[93],q[51];
u1(-pi/8796093022208) q[51];
cx q[93],q[51];
u1(pi/8796093022208) q[51];
u1(pi/4398046511104) q[93];
cx q[93],q[52];
u1(-pi/4398046511104) q[52];
cx q[93],q[52];
u1(pi/4398046511104) q[52];
u1(pi/2199023255552) q[93];
cx q[93],q[53];
u1(-pi/2199023255552) q[53];
cx q[93],q[53];
u1(pi/2199023255552) q[53];
u1(pi/1099511627776) q[93];
cx q[93],q[54];
u1(-pi/1099511627776) q[54];
cx q[93],q[54];
u1(pi/1099511627776) q[54];
u1(pi/549755813888) q[93];
cx q[93],q[55];
u1(-pi/549755813888) q[55];
cx q[93],q[55];
u1(pi/549755813888) q[55];
u1(pi/274877906944) q[93];
cx q[93],q[56];
u1(-pi/274877906944) q[56];
cx q[93],q[56];
u1(pi/274877906944) q[56];
u1(pi/137438953472) q[93];
cx q[93],q[57];
u1(-pi/137438953472) q[57];
cx q[93],q[57];
u1(pi/137438953472) q[57];
u1(pi/68719476736) q[93];
cx q[93],q[58];
u1(-pi/68719476736) q[58];
cx q[93],q[58];
u1(pi/68719476736) q[58];
u1(pi/34359738368) q[93];
cx q[93],q[59];
u1(-pi/34359738368) q[59];
cx q[93],q[59];
u1(pi/34359738368) q[59];
u1(pi/17179869184) q[93];
cx q[93],q[60];
u1(-pi/17179869184) q[60];
cx q[93],q[60];
u1(pi/17179869184) q[60];
u1(pi/8589934592) q[93];
cx q[93],q[61];
u1(-pi/8589934592) q[61];
cx q[93],q[61];
u1(pi/8589934592) q[61];
u1(pi/4294967296) q[93];
cx q[93],q[62];
u1(-pi/4294967296) q[62];
cx q[93],q[62];
u1(pi/4294967296) q[62];
u1(pi/2147483648) q[93];
cx q[93],q[63];
u1(-pi/2147483648) q[63];
cx q[93],q[63];
u1(pi/2147483648) q[63];
u1(pi/1073741824) q[93];
cx q[93],q[64];
u1(-pi/1073741824) q[64];
cx q[93],q[64];
u1(pi/1073741824) q[64];
u1(pi/536870912) q[93];
cx q[93],q[65];
u1(-pi/536870912) q[65];
cx q[93],q[65];
u1(pi/536870912) q[65];
u1(pi/268435456) q[93];
cx q[93],q[66];
u1(-pi/268435456) q[66];
cx q[93],q[66];
u1(pi/268435456) q[66];
u1(pi/134217728) q[93];
cx q[93],q[67];
u1(-pi/134217728) q[67];
cx q[93],q[67];
u1(pi/134217728) q[67];
u1(pi/67108864) q[93];
cx q[93],q[68];
u1(-pi/67108864) q[68];
cx q[93],q[68];
u1(pi/67108864) q[68];
u1(pi/33554432) q[93];
cx q[93],q[69];
u1(-pi/33554432) q[69];
cx q[93],q[69];
u1(pi/33554432) q[69];
u1(pi/16777216) q[93];
cx q[93],q[70];
u1(-pi/16777216) q[70];
cx q[93],q[70];
u1(pi/16777216) q[70];
u1(pi/8388608) q[93];
cx q[93],q[71];
u1(-pi/8388608) q[71];
cx q[93],q[71];
u1(pi/8388608) q[71];
u1(pi/4194304) q[93];
cx q[93],q[72];
u1(-pi/4194304) q[72];
cx q[93],q[72];
u1(pi/4194304) q[72];
u1(pi/2097152) q[93];
cx q[93],q[73];
u1(-pi/2097152) q[73];
cx q[93],q[73];
u1(pi/2097152) q[73];
u1(pi/1048576) q[93];
cx q[93],q[74];
u1(-pi/1048576) q[74];
cx q[93],q[74];
u1(pi/1048576) q[74];
u1(pi/524288) q[93];
cx q[93],q[75];
u1(-pi/524288) q[75];
cx q[93],q[75];
u1(pi/524288) q[75];
u1(pi/262144) q[93];
cx q[93],q[76];
u1(-pi/262144) q[76];
cx q[93],q[76];
u1(pi/262144) q[76];
u1(pi/131072) q[93];
cx q[93],q[77];
u1(-pi/131072) q[77];
cx q[93],q[77];
u1(pi/131072) q[77];
u1(pi/65536) q[93];
cx q[93],q[78];
u1(-pi/65536) q[78];
cx q[93],q[78];
u1(pi/65536) q[78];
u1(pi/32768) q[93];
cx q[93],q[79];
u1(-pi/32768) q[79];
cx q[93],q[79];
u1(pi/32768) q[79];
u1(pi/16384) q[93];
cx q[93],q[80];
u1(-pi/16384) q[80];
cx q[93],q[80];
u1(pi/16384) q[80];
u1(pi/8192) q[93];
cx q[93],q[81];
u1(-pi/8192) q[81];
cx q[93],q[81];
u1(pi/8192) q[81];
u1(pi/4096) q[93];
cx q[93],q[82];
u1(-pi/4096) q[82];
cx q[93],q[82];
u1(pi/4096) q[82];
u1(pi/2048) q[93];
cx q[93],q[83];
u1(-pi/2048) q[83];
cx q[93],q[83];
u1(pi/2048) q[83];
u1(pi/1024) q[93];
cx q[93],q[84];
u1(-pi/1024) q[84];
cx q[93],q[84];
u1(pi/1024) q[84];
u1(pi/512) q[93];
cx q[93],q[85];
u1(-pi/512) q[85];
cx q[93],q[85];
u1(pi/512) q[85];
u1(pi/256) q[93];
cx q[93],q[86];
u1(-pi/256) q[86];
cx q[93],q[86];
u1(pi/256) q[86];
u1(pi/128) q[93];
cx q[93],q[87];
u1(-pi/128) q[87];
cx q[93],q[87];
u1(pi/128) q[87];
u1(pi/64) q[93];
cx q[93],q[88];
u1(-pi/64) q[88];
cx q[93],q[88];
u1(pi/64) q[88];
u1(pi/32) q[93];
cx q[93],q[89];
u1(-pi/32) q[89];
cx q[93],q[89];
u1(pi/32) q[89];
u1(pi/16) q[93];
cx q[93],q[90];
u1(-pi/16) q[90];
cx q[93],q[90];
u1(pi/16) q[90];
u1(pi/8) q[93];
cx q[93],q[91];
u1(-pi/8) q[91];
cx q[93],q[91];
u1(pi/8) q[91];
u1(pi/4) q[93];
cx q[93],q[92];
u1(-pi/4) q[92];
cx q[93],q[92];
u1(pi/4) q[92];
h q[93];
u1(0) q[94];
cx q[94],q[0];
u1(0) q[0];
cx q[94],q[0];
u1(0) q[0];
u1(0) q[94];
cx q[94],q[1];
u1(0) q[1];
cx q[94],q[1];
u1(0) q[1];
u1(0) q[94];
cx q[94],q[2];
u1(0) q[2];
cx q[94],q[2];
u1(0) q[2];
u1(0) q[94];
cx q[94],q[3];
u1(0) q[3];
cx q[94],q[3];
u1(0) q[3];
u1(0) q[94];
cx q[94],q[4];
u1(0) q[4];
cx q[94],q[4];
u1(0) q[4];
u1(0) q[94];
cx q[94],q[5];
u1(0) q[5];
cx q[94],q[5];
u1(0) q[5];
u1(0) q[94];
cx q[94],q[6];
u1(0) q[6];
cx q[94],q[6];
u1(0) q[6];
u1(0) q[94];
cx q[94],q[7];
u1(0) q[7];
cx q[94],q[7];
u1(0) q[7];
u1(0) q[94];
cx q[94],q[8];
u1(0) q[8];
cx q[94],q[8];
u1(0) q[8];
u1(0) q[94];
cx q[94],q[9];
u1(0) q[9];
cx q[94],q[9];
u1(0) q[9];
u1(0) q[94];
cx q[94],q[10];
u1(0) q[10];
cx q[94],q[10];
u1(0) q[10];
u1(0) q[94];
cx q[94],q[11];
u1(0) q[11];
cx q[94],q[11];
u1(0) q[11];
u1(0) q[94];
cx q[94],q[12];
u1(0) q[12];
cx q[94],q[12];
u1(0) q[12];
u1(0) q[94];
cx q[94],q[13];
u1(0) q[13];
cx q[94],q[13];
u1(0) q[13];
u1(0) q[94];
cx q[94],q[14];
u1(0) q[14];
cx q[94],q[14];
u1(0) q[14];
u1(0) q[94];
cx q[94],q[15];
u1(0) q[15];
cx q[94],q[15];
u1(0) q[15];
u1(0) q[94];
cx q[94],q[16];
u1(0) q[16];
cx q[94],q[16];
u1(0) q[16];
u1(0) q[94];
cx q[94],q[17];
u1(0) q[17];
cx q[94],q[17];
u1(0) q[17];
u1(0) q[94];
cx q[94],q[18];
u1(0) q[18];
cx q[94],q[18];
u1(0) q[18];
u1(0) q[94];
cx q[94],q[19];
u1(0) q[19];
cx q[94],q[19];
u1(0) q[19];
u1(0) q[94];
cx q[94],q[20];
u1(0) q[20];
cx q[94],q[20];
u1(0) q[20];
u1(0) q[94];
cx q[94],q[21];
u1(0) q[21];
cx q[94],q[21];
u1(0) q[21];
u1(0) q[94];
cx q[94],q[22];
u1(0) q[22];
cx q[94],q[22];
u1(0) q[22];
u1(0) q[94];
cx q[94],q[23];
u1(0) q[23];
cx q[94],q[23];
u1(0) q[23];
u1(0) q[94];
cx q[94],q[24];
u1(0) q[24];
cx q[94],q[24];
u1(0) q[24];
u1(0) q[94];
cx q[94],q[25];
u1(0) q[25];
cx q[94],q[25];
u1(0) q[25];
u1(0) q[94];
cx q[94],q[26];
u1(0) q[26];
cx q[94],q[26];
u1(0) q[26];
u1(0) q[94];
cx q[94],q[27];
u1(0) q[27];
cx q[94],q[27];
u1(0) q[27];
u1(0) q[94];
cx q[94],q[28];
u1(0) q[28];
cx q[94],q[28];
u1(0) q[28];
u1(0) q[94];
cx q[94],q[29];
u1(0) q[29];
cx q[94],q[29];
u1(0) q[29];
u1(0) q[94];
cx q[94],q[30];
u1(0) q[30];
cx q[94],q[30];
u1(0) q[30];
u1(0) q[94];
cx q[94],q[31];
u1(0) q[31];
cx q[94],q[31];
u1(0) q[31];
u1(0) q[94];
cx q[94],q[32];
u1(0) q[32];
cx q[94],q[32];
u1(0) q[32];
u1(0) q[94];
cx q[94],q[33];
u1(0) q[33];
cx q[94],q[33];
u1(0) q[33];
u1(0) q[94];
cx q[94],q[34];
u1(0) q[34];
cx q[94],q[34];
u1(0) q[34];
u1(0) q[94];
cx q[94],q[35];
u1(0) q[35];
cx q[94],q[35];
u1(0) q[35];
u1(0) q[94];
cx q[94],q[36];
u1(0) q[36];
cx q[94],q[36];
u1(0) q[36];
u1(0) q[94];
cx q[94],q[37];
u1(0) q[37];
cx q[94],q[37];
u1(0) q[37];
u1(0) q[94];
cx q[94],q[38];
u1(0) q[38];
cx q[94],q[38];
u1(0) q[38];
u1(0) q[94];
cx q[94],q[39];
u1(0) q[39];
cx q[94],q[39];
u1(0) q[39];
u1(0) q[94];
cx q[94],q[40];
u1(0) q[40];
cx q[94],q[40];
u1(0) q[40];
u1(0) q[94];
cx q[94],q[41];
u1(0) q[41];
cx q[94],q[41];
u1(0) q[41];
u1(0) q[94];
cx q[94],q[42];
u1(0) q[42];
cx q[94],q[42];
u1(0) q[42];
u1(0) q[94];
cx q[94],q[43];
u1(0) q[43];
cx q[94],q[43];
u1(0) q[43];
u1(0) q[94];
cx q[94],q[44];
u1(0) q[44];
cx q[94],q[44];
u1(0) q[44];
u1(0) q[94];
cx q[94],q[45];
u1(0) q[45];
cx q[94],q[45];
u1(0) q[45];
u1(0) q[94];
cx q[94],q[46];
u1(0) q[46];
cx q[94],q[46];
u1(0) q[46];
u1(pi/281474976710656) q[94];
cx q[94],q[47];
u1(-pi/281474976710656) q[47];
cx q[94],q[47];
u1(pi/281474976710656) q[47];
u1(pi/140737488355328) q[94];
cx q[94],q[48];
u1(-pi/140737488355328) q[48];
cx q[94],q[48];
u1(pi/140737488355328) q[48];
u1(pi/70368744177664) q[94];
cx q[94],q[49];
u1(-pi/70368744177664) q[49];
cx q[94],q[49];
u1(pi/70368744177664) q[49];
u1(pi/35184372088832) q[94];
cx q[94],q[50];
u1(-pi/35184372088832) q[50];
cx q[94],q[50];
u1(pi/35184372088832) q[50];
u1(pi/17592186044416) q[94];
cx q[94],q[51];
u1(-pi/17592186044416) q[51];
cx q[94],q[51];
u1(pi/17592186044416) q[51];
u1(pi/8796093022208) q[94];
cx q[94],q[52];
u1(-pi/8796093022208) q[52];
cx q[94],q[52];
u1(pi/8796093022208) q[52];
u1(pi/4398046511104) q[94];
cx q[94],q[53];
u1(-pi/4398046511104) q[53];
cx q[94],q[53];
u1(pi/4398046511104) q[53];
u1(pi/2199023255552) q[94];
cx q[94],q[54];
u1(-pi/2199023255552) q[54];
cx q[94],q[54];
u1(pi/2199023255552) q[54];
u1(pi/1099511627776) q[94];
cx q[94],q[55];
u1(-pi/1099511627776) q[55];
cx q[94],q[55];
u1(pi/1099511627776) q[55];
u1(pi/549755813888) q[94];
cx q[94],q[56];
u1(-pi/549755813888) q[56];
cx q[94],q[56];
u1(pi/549755813888) q[56];
u1(pi/274877906944) q[94];
cx q[94],q[57];
u1(-pi/274877906944) q[57];
cx q[94],q[57];
u1(pi/274877906944) q[57];
u1(pi/137438953472) q[94];
cx q[94],q[58];
u1(-pi/137438953472) q[58];
cx q[94],q[58];
u1(pi/137438953472) q[58];
u1(pi/68719476736) q[94];
cx q[94],q[59];
u1(-pi/68719476736) q[59];
cx q[94],q[59];
u1(pi/68719476736) q[59];
u1(pi/34359738368) q[94];
cx q[94],q[60];
u1(-pi/34359738368) q[60];
cx q[94],q[60];
u1(pi/34359738368) q[60];
u1(pi/17179869184) q[94];
cx q[94],q[61];
u1(-pi/17179869184) q[61];
cx q[94],q[61];
u1(pi/17179869184) q[61];
u1(pi/8589934592) q[94];
cx q[94],q[62];
u1(-pi/8589934592) q[62];
cx q[94],q[62];
u1(pi/8589934592) q[62];
u1(pi/4294967296) q[94];
cx q[94],q[63];
u1(-pi/4294967296) q[63];
cx q[94],q[63];
u1(pi/4294967296) q[63];
u1(pi/2147483648) q[94];
cx q[94],q[64];
u1(-pi/2147483648) q[64];
cx q[94],q[64];
u1(pi/2147483648) q[64];
u1(pi/1073741824) q[94];
cx q[94],q[65];
u1(-pi/1073741824) q[65];
cx q[94],q[65];
u1(pi/1073741824) q[65];
u1(pi/536870912) q[94];
cx q[94],q[66];
u1(-pi/536870912) q[66];
cx q[94],q[66];
u1(pi/536870912) q[66];
u1(pi/268435456) q[94];
cx q[94],q[67];
u1(-pi/268435456) q[67];
cx q[94],q[67];
u1(pi/268435456) q[67];
u1(pi/134217728) q[94];
cx q[94],q[68];
u1(-pi/134217728) q[68];
cx q[94],q[68];
u1(pi/134217728) q[68];
u1(pi/67108864) q[94];
cx q[94],q[69];
u1(-pi/67108864) q[69];
cx q[94],q[69];
u1(pi/67108864) q[69];
u1(pi/33554432) q[94];
cx q[94],q[70];
u1(-pi/33554432) q[70];
cx q[94],q[70];
u1(pi/33554432) q[70];
u1(pi/16777216) q[94];
cx q[94],q[71];
u1(-pi/16777216) q[71];
cx q[94],q[71];
u1(pi/16777216) q[71];
u1(pi/8388608) q[94];
cx q[94],q[72];
u1(-pi/8388608) q[72];
cx q[94],q[72];
u1(pi/8388608) q[72];
u1(pi/4194304) q[94];
cx q[94],q[73];
u1(-pi/4194304) q[73];
cx q[94],q[73];
u1(pi/4194304) q[73];
u1(pi/2097152) q[94];
cx q[94],q[74];
u1(-pi/2097152) q[74];
cx q[94],q[74];
u1(pi/2097152) q[74];
u1(pi/1048576) q[94];
cx q[94],q[75];
u1(-pi/1048576) q[75];
cx q[94],q[75];
u1(pi/1048576) q[75];
u1(pi/524288) q[94];
cx q[94],q[76];
u1(-pi/524288) q[76];
cx q[94],q[76];
u1(pi/524288) q[76];
u1(pi/262144) q[94];
cx q[94],q[77];
u1(-pi/262144) q[77];
cx q[94],q[77];
u1(pi/262144) q[77];
u1(pi/131072) q[94];
cx q[94],q[78];
u1(-pi/131072) q[78];
cx q[94],q[78];
u1(pi/131072) q[78];
u1(pi/65536) q[94];
cx q[94],q[79];
u1(-pi/65536) q[79];
cx q[94],q[79];
u1(pi/65536) q[79];
u1(pi/32768) q[94];
cx q[94],q[80];
u1(-pi/32768) q[80];
cx q[94],q[80];
u1(pi/32768) q[80];
u1(pi/16384) q[94];
cx q[94],q[81];
u1(-pi/16384) q[81];
cx q[94],q[81];
u1(pi/16384) q[81];
u1(pi/8192) q[94];
cx q[94],q[82];
u1(-pi/8192) q[82];
cx q[94],q[82];
u1(pi/8192) q[82];
u1(pi/4096) q[94];
cx q[94],q[83];
u1(-pi/4096) q[83];
cx q[94],q[83];
u1(pi/4096) q[83];
u1(pi/2048) q[94];
cx q[94],q[84];
u1(-pi/2048) q[84];
cx q[94],q[84];
u1(pi/2048) q[84];
u1(pi/1024) q[94];
cx q[94],q[85];
u1(-pi/1024) q[85];
cx q[94],q[85];
u1(pi/1024) q[85];
u1(pi/512) q[94];
cx q[94],q[86];
u1(-pi/512) q[86];
cx q[94],q[86];
u1(pi/512) q[86];
u1(pi/256) q[94];
cx q[94],q[87];
u1(-pi/256) q[87];
cx q[94],q[87];
u1(pi/256) q[87];
u1(pi/128) q[94];
cx q[94],q[88];
u1(-pi/128) q[88];
cx q[94],q[88];
u1(pi/128) q[88];
u1(pi/64) q[94];
cx q[94],q[89];
u1(-pi/64) q[89];
cx q[94],q[89];
u1(pi/64) q[89];
u1(pi/32) q[94];
cx q[94],q[90];
u1(-pi/32) q[90];
cx q[94],q[90];
u1(pi/32) q[90];
u1(pi/16) q[94];
cx q[94],q[91];
u1(-pi/16) q[91];
cx q[94],q[91];
u1(pi/16) q[91];
u1(pi/8) q[94];
cx q[94],q[92];
u1(-pi/8) q[92];
cx q[94],q[92];
u1(pi/8) q[92];
u1(pi/4) q[94];
cx q[94],q[93];
u1(-pi/4) q[93];
cx q[94],q[93];
u1(pi/4) q[93];
h q[94];
u1(0) q[95];
cx q[95],q[0];
u1(0) q[0];
cx q[95],q[0];
u1(0) q[0];
u1(0) q[95];
cx q[95],q[1];
u1(0) q[1];
cx q[95],q[1];
u1(0) q[1];
u1(0) q[95];
cx q[95],q[2];
u1(0) q[2];
cx q[95],q[2];
u1(0) q[2];
u1(0) q[95];
cx q[95],q[3];
u1(0) q[3];
cx q[95],q[3];
u1(0) q[3];
u1(0) q[95];
cx q[95],q[4];
u1(0) q[4];
cx q[95],q[4];
u1(0) q[4];
u1(0) q[95];
cx q[95],q[5];
u1(0) q[5];
cx q[95],q[5];
u1(0) q[5];
u1(0) q[95];
cx q[95],q[6];
u1(0) q[6];
cx q[95],q[6];
u1(0) q[6];
u1(0) q[95];
cx q[95],q[7];
u1(0) q[7];
cx q[95],q[7];
u1(0) q[7];
u1(0) q[95];
cx q[95],q[8];
u1(0) q[8];
cx q[95],q[8];
u1(0) q[8];
u1(0) q[95];
cx q[95],q[9];
u1(0) q[9];
cx q[95],q[9];
u1(0) q[9];
u1(0) q[95];
cx q[95],q[10];
u1(0) q[10];
cx q[95],q[10];
u1(0) q[10];
u1(0) q[95];
cx q[95],q[11];
u1(0) q[11];
cx q[95],q[11];
u1(0) q[11];
u1(0) q[95];
cx q[95],q[12];
u1(0) q[12];
cx q[95],q[12];
u1(0) q[12];
u1(0) q[95];
cx q[95],q[13];
u1(0) q[13];
cx q[95],q[13];
u1(0) q[13];
u1(0) q[95];
cx q[95],q[14];
u1(0) q[14];
cx q[95],q[14];
u1(0) q[14];
u1(0) q[95];
cx q[95],q[15];
u1(0) q[15];
cx q[95],q[15];
u1(0) q[15];
u1(0) q[95];
cx q[95],q[16];
u1(0) q[16];
cx q[95],q[16];
u1(0) q[16];
u1(0) q[95];
cx q[95],q[17];
u1(0) q[17];
cx q[95],q[17];
u1(0) q[17];
u1(0) q[95];
cx q[95],q[18];
u1(0) q[18];
cx q[95],q[18];
u1(0) q[18];
u1(0) q[95];
cx q[95],q[19];
u1(0) q[19];
cx q[95],q[19];
u1(0) q[19];
u1(0) q[95];
cx q[95],q[20];
u1(0) q[20];
cx q[95],q[20];
u1(0) q[20];
u1(0) q[95];
cx q[95],q[21];
u1(0) q[21];
cx q[95],q[21];
u1(0) q[21];
u1(0) q[95];
cx q[95],q[22];
u1(0) q[22];
cx q[95],q[22];
u1(0) q[22];
u1(0) q[95];
cx q[95],q[23];
u1(0) q[23];
cx q[95],q[23];
u1(0) q[23];
u1(0) q[95];
cx q[95],q[24];
u1(0) q[24];
cx q[95],q[24];
u1(0) q[24];
u1(0) q[95];
cx q[95],q[25];
u1(0) q[25];
cx q[95],q[25];
u1(0) q[25];
u1(0) q[95];
cx q[95],q[26];
u1(0) q[26];
cx q[95],q[26];
u1(0) q[26];
u1(0) q[95];
cx q[95],q[27];
u1(0) q[27];
cx q[95],q[27];
u1(0) q[27];
u1(0) q[95];
cx q[95],q[28];
u1(0) q[28];
cx q[95],q[28];
u1(0) q[28];
u1(0) q[95];
cx q[95],q[29];
u1(0) q[29];
cx q[95],q[29];
u1(0) q[29];
u1(0) q[95];
cx q[95],q[30];
u1(0) q[30];
cx q[95],q[30];
u1(0) q[30];
u1(0) q[95];
cx q[95],q[31];
u1(0) q[31];
cx q[95],q[31];
u1(0) q[31];
u1(0) q[95];
cx q[95],q[32];
u1(0) q[32];
cx q[95],q[32];
u1(0) q[32];
u1(0) q[95];
cx q[95],q[33];
u1(0) q[33];
cx q[95],q[33];
u1(0) q[33];
u1(0) q[95];
cx q[95],q[34];
u1(0) q[34];
cx q[95],q[34];
u1(0) q[34];
u1(0) q[95];
cx q[95],q[35];
u1(0) q[35];
cx q[95],q[35];
u1(0) q[35];
u1(0) q[95];
cx q[95],q[36];
u1(0) q[36];
cx q[95],q[36];
u1(0) q[36];
u1(0) q[95];
cx q[95],q[37];
u1(0) q[37];
cx q[95],q[37];
u1(0) q[37];
u1(0) q[95];
cx q[95],q[38];
u1(0) q[38];
cx q[95],q[38];
u1(0) q[38];
u1(0) q[95];
cx q[95],q[39];
u1(0) q[39];
cx q[95],q[39];
u1(0) q[39];
u1(0) q[95];
cx q[95],q[40];
u1(0) q[40];
cx q[95],q[40];
u1(0) q[40];
u1(0) q[95];
cx q[95],q[41];
u1(0) q[41];
cx q[95],q[41];
u1(0) q[41];
u1(0) q[95];
cx q[95],q[42];
u1(0) q[42];
cx q[95],q[42];
u1(0) q[42];
u1(0) q[95];
cx q[95],q[43];
u1(0) q[43];
cx q[95],q[43];
u1(0) q[43];
u1(0) q[95];
cx q[95],q[44];
u1(0) q[44];
cx q[95],q[44];
u1(0) q[44];
u1(0) q[95];
cx q[95],q[45];
u1(0) q[45];
cx q[95],q[45];
u1(0) q[45];
u1(0) q[95];
cx q[95],q[46];
u1(0) q[46];
cx q[95],q[46];
u1(0) q[46];
u1(0) q[95];
cx q[95],q[47];
u1(0) q[47];
cx q[95],q[47];
u1(0) q[47];
u1(pi/281474976710656) q[95];
cx q[95],q[48];
u1(-pi/281474976710656) q[48];
cx q[95],q[48];
u1(pi/281474976710656) q[48];
u1(pi/140737488355328) q[95];
cx q[95],q[49];
u1(-pi/140737488355328) q[49];
cx q[95],q[49];
u1(pi/140737488355328) q[49];
u1(pi/70368744177664) q[95];
cx q[95],q[50];
u1(-pi/70368744177664) q[50];
cx q[95],q[50];
u1(pi/70368744177664) q[50];
u1(pi/35184372088832) q[95];
cx q[95],q[51];
u1(-pi/35184372088832) q[51];
cx q[95],q[51];
u1(pi/35184372088832) q[51];
u1(pi/17592186044416) q[95];
cx q[95],q[52];
u1(-pi/17592186044416) q[52];
cx q[95],q[52];
u1(pi/17592186044416) q[52];
u1(pi/8796093022208) q[95];
cx q[95],q[53];
u1(-pi/8796093022208) q[53];
cx q[95],q[53];
u1(pi/8796093022208) q[53];
u1(pi/4398046511104) q[95];
cx q[95],q[54];
u1(-pi/4398046511104) q[54];
cx q[95],q[54];
u1(pi/4398046511104) q[54];
u1(pi/2199023255552) q[95];
cx q[95],q[55];
u1(-pi/2199023255552) q[55];
cx q[95],q[55];
u1(pi/2199023255552) q[55];
u1(pi/1099511627776) q[95];
cx q[95],q[56];
u1(-pi/1099511627776) q[56];
cx q[95],q[56];
u1(pi/1099511627776) q[56];
u1(pi/549755813888) q[95];
cx q[95],q[57];
u1(-pi/549755813888) q[57];
cx q[95],q[57];
u1(pi/549755813888) q[57];
u1(pi/274877906944) q[95];
cx q[95],q[58];
u1(-pi/274877906944) q[58];
cx q[95],q[58];
u1(pi/274877906944) q[58];
u1(pi/137438953472) q[95];
cx q[95],q[59];
u1(-pi/137438953472) q[59];
cx q[95],q[59];
u1(pi/137438953472) q[59];
u1(pi/68719476736) q[95];
cx q[95],q[60];
u1(-pi/68719476736) q[60];
cx q[95],q[60];
u1(pi/68719476736) q[60];
u1(pi/34359738368) q[95];
cx q[95],q[61];
u1(-pi/34359738368) q[61];
cx q[95],q[61];
u1(pi/34359738368) q[61];
u1(pi/17179869184) q[95];
cx q[95],q[62];
u1(-pi/17179869184) q[62];
cx q[95],q[62];
u1(pi/17179869184) q[62];
u1(pi/8589934592) q[95];
cx q[95],q[63];
u1(-pi/8589934592) q[63];
cx q[95],q[63];
u1(pi/8589934592) q[63];
u1(pi/4294967296) q[95];
cx q[95],q[64];
u1(-pi/4294967296) q[64];
cx q[95],q[64];
u1(pi/4294967296) q[64];
u1(pi/2147483648) q[95];
cx q[95],q[65];
u1(-pi/2147483648) q[65];
cx q[95],q[65];
u1(pi/2147483648) q[65];
u1(pi/1073741824) q[95];
cx q[95],q[66];
u1(-pi/1073741824) q[66];
cx q[95],q[66];
u1(pi/1073741824) q[66];
u1(pi/536870912) q[95];
cx q[95],q[67];
u1(-pi/536870912) q[67];
cx q[95],q[67];
u1(pi/536870912) q[67];
u1(pi/268435456) q[95];
cx q[95],q[68];
u1(-pi/268435456) q[68];
cx q[95],q[68];
u1(pi/268435456) q[68];
u1(pi/134217728) q[95];
cx q[95],q[69];
u1(-pi/134217728) q[69];
cx q[95],q[69];
u1(pi/134217728) q[69];
u1(pi/67108864) q[95];
cx q[95],q[70];
u1(-pi/67108864) q[70];
cx q[95],q[70];
u1(pi/67108864) q[70];
u1(pi/33554432) q[95];
cx q[95],q[71];
u1(-pi/33554432) q[71];
cx q[95],q[71];
u1(pi/33554432) q[71];
u1(pi/16777216) q[95];
cx q[95],q[72];
u1(-pi/16777216) q[72];
cx q[95],q[72];
u1(pi/16777216) q[72];
u1(pi/8388608) q[95];
cx q[95],q[73];
u1(-pi/8388608) q[73];
cx q[95],q[73];
u1(pi/8388608) q[73];
u1(pi/4194304) q[95];
cx q[95],q[74];
u1(-pi/4194304) q[74];
cx q[95],q[74];
u1(pi/4194304) q[74];
u1(pi/2097152) q[95];
cx q[95],q[75];
u1(-pi/2097152) q[75];
cx q[95],q[75];
u1(pi/2097152) q[75];
u1(pi/1048576) q[95];
cx q[95],q[76];
u1(-pi/1048576) q[76];
cx q[95],q[76];
u1(pi/1048576) q[76];
u1(pi/524288) q[95];
cx q[95],q[77];
u1(-pi/524288) q[77];
cx q[95],q[77];
u1(pi/524288) q[77];
u1(pi/262144) q[95];
cx q[95],q[78];
u1(-pi/262144) q[78];
cx q[95],q[78];
u1(pi/262144) q[78];
u1(pi/131072) q[95];
cx q[95],q[79];
u1(-pi/131072) q[79];
cx q[95],q[79];
u1(pi/131072) q[79];
u1(pi/65536) q[95];
cx q[95],q[80];
u1(-pi/65536) q[80];
cx q[95],q[80];
u1(pi/65536) q[80];
u1(pi/32768) q[95];
cx q[95],q[81];
u1(-pi/32768) q[81];
cx q[95],q[81];
u1(pi/32768) q[81];
u1(pi/16384) q[95];
cx q[95],q[82];
u1(-pi/16384) q[82];
cx q[95],q[82];
u1(pi/16384) q[82];
u1(pi/8192) q[95];
cx q[95],q[83];
u1(-pi/8192) q[83];
cx q[95],q[83];
u1(pi/8192) q[83];
u1(pi/4096) q[95];
cx q[95],q[84];
u1(-pi/4096) q[84];
cx q[95],q[84];
u1(pi/4096) q[84];
u1(pi/2048) q[95];
cx q[95],q[85];
u1(-pi/2048) q[85];
cx q[95],q[85];
u1(pi/2048) q[85];
u1(pi/1024) q[95];
cx q[95],q[86];
u1(-pi/1024) q[86];
cx q[95],q[86];
u1(pi/1024) q[86];
u1(pi/512) q[95];
cx q[95],q[87];
u1(-pi/512) q[87];
cx q[95],q[87];
u1(pi/512) q[87];
u1(pi/256) q[95];
cx q[95],q[88];
u1(-pi/256) q[88];
cx q[95],q[88];
u1(pi/256) q[88];
u1(pi/128) q[95];
cx q[95],q[89];
u1(-pi/128) q[89];
cx q[95],q[89];
u1(pi/128) q[89];
u1(pi/64) q[95];
cx q[95],q[90];
u1(-pi/64) q[90];
cx q[95],q[90];
u1(pi/64) q[90];
u1(pi/32) q[95];
cx q[95],q[91];
u1(-pi/32) q[91];
cx q[95],q[91];
u1(pi/32) q[91];
u1(pi/16) q[95];
cx q[95],q[92];
u1(-pi/16) q[92];
cx q[95],q[92];
u1(pi/16) q[92];
u1(pi/8) q[95];
cx q[95],q[93];
u1(-pi/8) q[93];
cx q[95],q[93];
u1(pi/8) q[93];
u1(pi/4) q[95];
cx q[95],q[94];
u1(-pi/4) q[94];
cx q[95],q[94];
u1(pi/4) q[94];
h q[95];
u1(0) q[96];
cx q[96],q[0];
u1(0) q[0];
cx q[96],q[0];
u1(0) q[0];
u1(0) q[96];
cx q[96],q[1];
u1(0) q[1];
cx q[96],q[1];
u1(0) q[1];
u1(0) q[96];
cx q[96],q[2];
u1(0) q[2];
cx q[96],q[2];
u1(0) q[2];
u1(0) q[96];
cx q[96],q[3];
u1(0) q[3];
cx q[96],q[3];
u1(0) q[3];
u1(0) q[96];
cx q[96],q[4];
u1(0) q[4];
cx q[96],q[4];
u1(0) q[4];
u1(0) q[96];
cx q[96],q[5];
u1(0) q[5];
cx q[96],q[5];
u1(0) q[5];
u1(0) q[96];
cx q[96],q[6];
u1(0) q[6];
cx q[96],q[6];
u1(0) q[6];
u1(0) q[96];
cx q[96],q[7];
u1(0) q[7];
cx q[96],q[7];
u1(0) q[7];
u1(0) q[96];
cx q[96],q[8];
u1(0) q[8];
cx q[96],q[8];
u1(0) q[8];
u1(0) q[96];
cx q[96],q[9];
u1(0) q[9];
cx q[96],q[9];
u1(0) q[9];
u1(0) q[96];
cx q[96],q[10];
u1(0) q[10];
cx q[96],q[10];
u1(0) q[10];
u1(0) q[96];
cx q[96],q[11];
u1(0) q[11];
cx q[96],q[11];
u1(0) q[11];
u1(0) q[96];
cx q[96],q[12];
u1(0) q[12];
cx q[96],q[12];
u1(0) q[12];
u1(0) q[96];
cx q[96],q[13];
u1(0) q[13];
cx q[96],q[13];
u1(0) q[13];
u1(0) q[96];
cx q[96],q[14];
u1(0) q[14];
cx q[96],q[14];
u1(0) q[14];
u1(0) q[96];
cx q[96],q[15];
u1(0) q[15];
cx q[96],q[15];
u1(0) q[15];
u1(0) q[96];
cx q[96],q[16];
u1(0) q[16];
cx q[96],q[16];
u1(0) q[16];
u1(0) q[96];
cx q[96],q[17];
u1(0) q[17];
cx q[96],q[17];
u1(0) q[17];
u1(0) q[96];
cx q[96],q[18];
u1(0) q[18];
cx q[96],q[18];
u1(0) q[18];
u1(0) q[96];
cx q[96],q[19];
u1(0) q[19];
cx q[96],q[19];
u1(0) q[19];
u1(0) q[96];
cx q[96],q[20];
u1(0) q[20];
cx q[96],q[20];
u1(0) q[20];
u1(0) q[96];
cx q[96],q[21];
u1(0) q[21];
cx q[96],q[21];
u1(0) q[21];
u1(0) q[96];
cx q[96],q[22];
u1(0) q[22];
cx q[96],q[22];
u1(0) q[22];
u1(0) q[96];
cx q[96],q[23];
u1(0) q[23];
cx q[96],q[23];
u1(0) q[23];
u1(0) q[96];
cx q[96],q[24];
u1(0) q[24];
cx q[96],q[24];
u1(0) q[24];
u1(0) q[96];
cx q[96],q[25];
u1(0) q[25];
cx q[96],q[25];
u1(0) q[25];
u1(0) q[96];
cx q[96],q[26];
u1(0) q[26];
cx q[96],q[26];
u1(0) q[26];
u1(0) q[96];
cx q[96],q[27];
u1(0) q[27];
cx q[96],q[27];
u1(0) q[27];
u1(0) q[96];
cx q[96],q[28];
u1(0) q[28];
cx q[96],q[28];
u1(0) q[28];
u1(0) q[96];
cx q[96],q[29];
u1(0) q[29];
cx q[96],q[29];
u1(0) q[29];
u1(0) q[96];
cx q[96],q[30];
u1(0) q[30];
cx q[96],q[30];
u1(0) q[30];
u1(0) q[96];
cx q[96],q[31];
u1(0) q[31];
cx q[96],q[31];
u1(0) q[31];
u1(0) q[96];
cx q[96],q[32];
u1(0) q[32];
cx q[96],q[32];
u1(0) q[32];
u1(0) q[96];
cx q[96],q[33];
u1(0) q[33];
cx q[96],q[33];
u1(0) q[33];
u1(0) q[96];
cx q[96],q[34];
u1(0) q[34];
cx q[96],q[34];
u1(0) q[34];
u1(0) q[96];
cx q[96],q[35];
u1(0) q[35];
cx q[96],q[35];
u1(0) q[35];
u1(0) q[96];
cx q[96],q[36];
u1(0) q[36];
cx q[96],q[36];
u1(0) q[36];
u1(0) q[96];
cx q[96],q[37];
u1(0) q[37];
cx q[96],q[37];
u1(0) q[37];
u1(0) q[96];
cx q[96],q[38];
u1(0) q[38];
cx q[96],q[38];
u1(0) q[38];
u1(0) q[96];
cx q[96],q[39];
u1(0) q[39];
cx q[96],q[39];
u1(0) q[39];
u1(0) q[96];
cx q[96],q[40];
u1(0) q[40];
cx q[96],q[40];
u1(0) q[40];
u1(0) q[96];
cx q[96],q[41];
u1(0) q[41];
cx q[96],q[41];
u1(0) q[41];
u1(0) q[96];
cx q[96],q[42];
u1(0) q[42];
cx q[96],q[42];
u1(0) q[42];
u1(0) q[96];
cx q[96],q[43];
u1(0) q[43];
cx q[96],q[43];
u1(0) q[43];
u1(0) q[96];
cx q[96],q[44];
u1(0) q[44];
cx q[96],q[44];
u1(0) q[44];
u1(0) q[96];
cx q[96],q[45];
u1(0) q[45];
cx q[96],q[45];
u1(0) q[45];
u1(0) q[96];
cx q[96],q[46];
u1(0) q[46];
cx q[96],q[46];
u1(0) q[46];
u1(0) q[96];
cx q[96],q[47];
u1(0) q[47];
cx q[96],q[47];
u1(0) q[47];
u1(0) q[96];
cx q[96],q[48];
u1(0) q[48];
cx q[96],q[48];
u1(0) q[48];
u1(pi/281474976710656) q[96];
cx q[96],q[49];
u1(-pi/281474976710656) q[49];
cx q[96],q[49];
u1(pi/281474976710656) q[49];
u1(pi/140737488355328) q[96];
cx q[96],q[50];
u1(-pi/140737488355328) q[50];
cx q[96],q[50];
u1(pi/140737488355328) q[50];
u1(pi/70368744177664) q[96];
cx q[96],q[51];
u1(-pi/70368744177664) q[51];
cx q[96],q[51];
u1(pi/70368744177664) q[51];
u1(pi/35184372088832) q[96];
cx q[96],q[52];
u1(-pi/35184372088832) q[52];
cx q[96],q[52];
u1(pi/35184372088832) q[52];
u1(pi/17592186044416) q[96];
cx q[96],q[53];
u1(-pi/17592186044416) q[53];
cx q[96],q[53];
u1(pi/17592186044416) q[53];
u1(pi/8796093022208) q[96];
cx q[96],q[54];
u1(-pi/8796093022208) q[54];
cx q[96],q[54];
u1(pi/8796093022208) q[54];
u1(pi/4398046511104) q[96];
cx q[96],q[55];
u1(-pi/4398046511104) q[55];
cx q[96],q[55];
u1(pi/4398046511104) q[55];
u1(pi/2199023255552) q[96];
cx q[96],q[56];
u1(-pi/2199023255552) q[56];
cx q[96],q[56];
u1(pi/2199023255552) q[56];
u1(pi/1099511627776) q[96];
cx q[96],q[57];
u1(-pi/1099511627776) q[57];
cx q[96],q[57];
u1(pi/1099511627776) q[57];
u1(pi/549755813888) q[96];
cx q[96],q[58];
u1(-pi/549755813888) q[58];
cx q[96],q[58];
u1(pi/549755813888) q[58];
u1(pi/274877906944) q[96];
cx q[96],q[59];
u1(-pi/274877906944) q[59];
cx q[96],q[59];
u1(pi/274877906944) q[59];
u1(pi/137438953472) q[96];
cx q[96],q[60];
u1(-pi/137438953472) q[60];
cx q[96],q[60];
u1(pi/137438953472) q[60];
u1(pi/68719476736) q[96];
cx q[96],q[61];
u1(-pi/68719476736) q[61];
cx q[96],q[61];
u1(pi/68719476736) q[61];
u1(pi/34359738368) q[96];
cx q[96],q[62];
u1(-pi/34359738368) q[62];
cx q[96],q[62];
u1(pi/34359738368) q[62];
u1(pi/17179869184) q[96];
cx q[96],q[63];
u1(-pi/17179869184) q[63];
cx q[96],q[63];
u1(pi/17179869184) q[63];
u1(pi/8589934592) q[96];
cx q[96],q[64];
u1(-pi/8589934592) q[64];
cx q[96],q[64];
u1(pi/8589934592) q[64];
u1(pi/4294967296) q[96];
cx q[96],q[65];
u1(-pi/4294967296) q[65];
cx q[96],q[65];
u1(pi/4294967296) q[65];
u1(pi/2147483648) q[96];
cx q[96],q[66];
u1(-pi/2147483648) q[66];
cx q[96],q[66];
u1(pi/2147483648) q[66];
u1(pi/1073741824) q[96];
cx q[96],q[67];
u1(-pi/1073741824) q[67];
cx q[96],q[67];
u1(pi/1073741824) q[67];
u1(pi/536870912) q[96];
cx q[96],q[68];
u1(-pi/536870912) q[68];
cx q[96],q[68];
u1(pi/536870912) q[68];
u1(pi/268435456) q[96];
cx q[96],q[69];
u1(-pi/268435456) q[69];
cx q[96],q[69];
u1(pi/268435456) q[69];
u1(pi/134217728) q[96];
cx q[96],q[70];
u1(-pi/134217728) q[70];
cx q[96],q[70];
u1(pi/134217728) q[70];
u1(pi/67108864) q[96];
cx q[96],q[71];
u1(-pi/67108864) q[71];
cx q[96],q[71];
u1(pi/67108864) q[71];
u1(pi/33554432) q[96];
cx q[96],q[72];
u1(-pi/33554432) q[72];
cx q[96],q[72];
u1(pi/33554432) q[72];
u1(pi/16777216) q[96];
cx q[96],q[73];
u1(-pi/16777216) q[73];
cx q[96],q[73];
u1(pi/16777216) q[73];
u1(pi/8388608) q[96];
cx q[96],q[74];
u1(-pi/8388608) q[74];
cx q[96],q[74];
u1(pi/8388608) q[74];
u1(pi/4194304) q[96];
cx q[96],q[75];
u1(-pi/4194304) q[75];
cx q[96],q[75];
u1(pi/4194304) q[75];
u1(pi/2097152) q[96];
cx q[96],q[76];
u1(-pi/2097152) q[76];
cx q[96],q[76];
u1(pi/2097152) q[76];
u1(pi/1048576) q[96];
cx q[96],q[77];
u1(-pi/1048576) q[77];
cx q[96],q[77];
u1(pi/1048576) q[77];
u1(pi/524288) q[96];
cx q[96],q[78];
u1(-pi/524288) q[78];
cx q[96],q[78];
u1(pi/524288) q[78];
u1(pi/262144) q[96];
cx q[96],q[79];
u1(-pi/262144) q[79];
cx q[96],q[79];
u1(pi/262144) q[79];
u1(pi/131072) q[96];
cx q[96],q[80];
u1(-pi/131072) q[80];
cx q[96],q[80];
u1(pi/131072) q[80];
u1(pi/65536) q[96];
cx q[96],q[81];
u1(-pi/65536) q[81];
cx q[96],q[81];
u1(pi/65536) q[81];
u1(pi/32768) q[96];
cx q[96],q[82];
u1(-pi/32768) q[82];
cx q[96],q[82];
u1(pi/32768) q[82];
u1(pi/16384) q[96];
cx q[96],q[83];
u1(-pi/16384) q[83];
cx q[96],q[83];
u1(pi/16384) q[83];
u1(pi/8192) q[96];
cx q[96],q[84];
u1(-pi/8192) q[84];
cx q[96],q[84];
u1(pi/8192) q[84];
u1(pi/4096) q[96];
cx q[96],q[85];
u1(-pi/4096) q[85];
cx q[96],q[85];
u1(pi/4096) q[85];
u1(pi/2048) q[96];
cx q[96],q[86];
u1(-pi/2048) q[86];
cx q[96],q[86];
u1(pi/2048) q[86];
u1(pi/1024) q[96];
cx q[96],q[87];
u1(-pi/1024) q[87];
cx q[96],q[87];
u1(pi/1024) q[87];
u1(pi/512) q[96];
cx q[96],q[88];
u1(-pi/512) q[88];
cx q[96],q[88];
u1(pi/512) q[88];
u1(pi/256) q[96];
cx q[96],q[89];
u1(-pi/256) q[89];
cx q[96],q[89];
u1(pi/256) q[89];
u1(pi/128) q[96];
cx q[96],q[90];
u1(-pi/128) q[90];
cx q[96],q[90];
u1(pi/128) q[90];
u1(pi/64) q[96];
cx q[96],q[91];
u1(-pi/64) q[91];
cx q[96],q[91];
u1(pi/64) q[91];
u1(pi/32) q[96];
cx q[96],q[92];
u1(-pi/32) q[92];
cx q[96],q[92];
u1(pi/32) q[92];
u1(pi/16) q[96];
cx q[96],q[93];
u1(-pi/16) q[93];
cx q[96],q[93];
u1(pi/16) q[93];
u1(pi/8) q[96];
cx q[96],q[94];
u1(-pi/8) q[94];
cx q[96],q[94];
u1(pi/8) q[94];
u1(pi/4) q[96];
cx q[96],q[95];
u1(-pi/4) q[95];
cx q[96],q[95];
u1(pi/4) q[95];
h q[96];
u1(0) q[97];
cx q[97],q[0];
u1(0) q[0];
cx q[97],q[0];
u1(0) q[0];
u1(0) q[97];
cx q[97],q[1];
u1(0) q[1];
cx q[97],q[1];
u1(0) q[1];
u1(0) q[97];
cx q[97],q[2];
u1(0) q[2];
cx q[97],q[2];
u1(0) q[2];
u1(0) q[97];
cx q[97],q[3];
u1(0) q[3];
cx q[97],q[3];
u1(0) q[3];
u1(0) q[97];
cx q[97],q[4];
u1(0) q[4];
cx q[97],q[4];
u1(0) q[4];
u1(0) q[97];
cx q[97],q[5];
u1(0) q[5];
cx q[97],q[5];
u1(0) q[5];
u1(0) q[97];
cx q[97],q[6];
u1(0) q[6];
cx q[97],q[6];
u1(0) q[6];
u1(0) q[97];
cx q[97],q[7];
u1(0) q[7];
cx q[97],q[7];
u1(0) q[7];
u1(0) q[97];
cx q[97],q[8];
u1(0) q[8];
cx q[97],q[8];
u1(0) q[8];
u1(0) q[97];
cx q[97],q[9];
u1(0) q[9];
cx q[97],q[9];
u1(0) q[9];
u1(0) q[97];
cx q[97],q[10];
u1(0) q[10];
cx q[97],q[10];
u1(0) q[10];
u1(0) q[97];
cx q[97],q[11];
u1(0) q[11];
cx q[97],q[11];
u1(0) q[11];
u1(0) q[97];
cx q[97],q[12];
u1(0) q[12];
cx q[97],q[12];
u1(0) q[12];
u1(0) q[97];
cx q[97],q[13];
u1(0) q[13];
cx q[97],q[13];
u1(0) q[13];
u1(0) q[97];
cx q[97],q[14];
u1(0) q[14];
cx q[97],q[14];
u1(0) q[14];
u1(0) q[97];
cx q[97],q[15];
u1(0) q[15];
cx q[97],q[15];
u1(0) q[15];
u1(0) q[97];
cx q[97],q[16];
u1(0) q[16];
cx q[97],q[16];
u1(0) q[16];
u1(0) q[97];
cx q[97],q[17];
u1(0) q[17];
cx q[97],q[17];
u1(0) q[17];
u1(0) q[97];
cx q[97],q[18];
u1(0) q[18];
cx q[97],q[18];
u1(0) q[18];
u1(0) q[97];
cx q[97],q[19];
u1(0) q[19];
cx q[97],q[19];
u1(0) q[19];
u1(0) q[97];
cx q[97],q[20];
u1(0) q[20];
cx q[97],q[20];
u1(0) q[20];
u1(0) q[97];
cx q[97],q[21];
u1(0) q[21];
cx q[97],q[21];
u1(0) q[21];
u1(0) q[97];
cx q[97],q[22];
u1(0) q[22];
cx q[97],q[22];
u1(0) q[22];
u1(0) q[97];
cx q[97],q[23];
u1(0) q[23];
cx q[97],q[23];
u1(0) q[23];
u1(0) q[97];
cx q[97],q[24];
u1(0) q[24];
cx q[97],q[24];
u1(0) q[24];
u1(0) q[97];
cx q[97],q[25];
u1(0) q[25];
cx q[97],q[25];
u1(0) q[25];
u1(0) q[97];
cx q[97],q[26];
u1(0) q[26];
cx q[97],q[26];
u1(0) q[26];
u1(0) q[97];
cx q[97],q[27];
u1(0) q[27];
cx q[97],q[27];
u1(0) q[27];
u1(0) q[97];
cx q[97],q[28];
u1(0) q[28];
cx q[97],q[28];
u1(0) q[28];
u1(0) q[97];
cx q[97],q[29];
u1(0) q[29];
cx q[97],q[29];
u1(0) q[29];
u1(0) q[97];
cx q[97],q[30];
u1(0) q[30];
cx q[97],q[30];
u1(0) q[30];
u1(0) q[97];
cx q[97],q[31];
u1(0) q[31];
cx q[97],q[31];
u1(0) q[31];
u1(0) q[97];
cx q[97],q[32];
u1(0) q[32];
cx q[97],q[32];
u1(0) q[32];
u1(0) q[97];
cx q[97],q[33];
u1(0) q[33];
cx q[97],q[33];
u1(0) q[33];
u1(0) q[97];
cx q[97],q[34];
u1(0) q[34];
cx q[97],q[34];
u1(0) q[34];
u1(0) q[97];
cx q[97],q[35];
u1(0) q[35];
cx q[97],q[35];
u1(0) q[35];
u1(0) q[97];
cx q[97],q[36];
u1(0) q[36];
cx q[97],q[36];
u1(0) q[36];
u1(0) q[97];
cx q[97],q[37];
u1(0) q[37];
cx q[97],q[37];
u1(0) q[37];
u1(0) q[97];
cx q[97],q[38];
u1(0) q[38];
cx q[97],q[38];
u1(0) q[38];
u1(0) q[97];
cx q[97],q[39];
u1(0) q[39];
cx q[97],q[39];
u1(0) q[39];
u1(0) q[97];
cx q[97],q[40];
u1(0) q[40];
cx q[97],q[40];
u1(0) q[40];
u1(0) q[97];
cx q[97],q[41];
u1(0) q[41];
cx q[97],q[41];
u1(0) q[41];
u1(0) q[97];
cx q[97],q[42];
u1(0) q[42];
cx q[97],q[42];
u1(0) q[42];
u1(0) q[97];
cx q[97],q[43];
u1(0) q[43];
cx q[97],q[43];
u1(0) q[43];
u1(0) q[97];
cx q[97],q[44];
u1(0) q[44];
cx q[97],q[44];
u1(0) q[44];
u1(0) q[97];
cx q[97],q[45];
u1(0) q[45];
cx q[97],q[45];
u1(0) q[45];
u1(0) q[97];
cx q[97],q[46];
u1(0) q[46];
cx q[97],q[46];
u1(0) q[46];
u1(0) q[97];
cx q[97],q[47];
u1(0) q[47];
cx q[97],q[47];
u1(0) q[47];
u1(0) q[97];
cx q[97],q[48];
u1(0) q[48];
cx q[97],q[48];
u1(0) q[48];
u1(0) q[97];
cx q[97],q[49];
u1(0) q[49];
cx q[97],q[49];
u1(0) q[49];
u1(pi/281474976710656) q[97];
cx q[97],q[50];
u1(-pi/281474976710656) q[50];
cx q[97],q[50];
u1(pi/281474976710656) q[50];
u1(pi/140737488355328) q[97];
cx q[97],q[51];
u1(-pi/140737488355328) q[51];
cx q[97],q[51];
u1(pi/140737488355328) q[51];
u1(pi/70368744177664) q[97];
cx q[97],q[52];
u1(-pi/70368744177664) q[52];
cx q[97],q[52];
u1(pi/70368744177664) q[52];
u1(pi/35184372088832) q[97];
cx q[97],q[53];
u1(-pi/35184372088832) q[53];
cx q[97],q[53];
u1(pi/35184372088832) q[53];
u1(pi/17592186044416) q[97];
cx q[97],q[54];
u1(-pi/17592186044416) q[54];
cx q[97],q[54];
u1(pi/17592186044416) q[54];
u1(pi/8796093022208) q[97];
cx q[97],q[55];
u1(-pi/8796093022208) q[55];
cx q[97],q[55];
u1(pi/8796093022208) q[55];
u1(pi/4398046511104) q[97];
cx q[97],q[56];
u1(-pi/4398046511104) q[56];
cx q[97],q[56];
u1(pi/4398046511104) q[56];
u1(pi/2199023255552) q[97];
cx q[97],q[57];
u1(-pi/2199023255552) q[57];
cx q[97],q[57];
u1(pi/2199023255552) q[57];
u1(pi/1099511627776) q[97];
cx q[97],q[58];
u1(-pi/1099511627776) q[58];
cx q[97],q[58];
u1(pi/1099511627776) q[58];
u1(pi/549755813888) q[97];
cx q[97],q[59];
u1(-pi/549755813888) q[59];
cx q[97],q[59];
u1(pi/549755813888) q[59];
u1(pi/274877906944) q[97];
cx q[97],q[60];
u1(-pi/274877906944) q[60];
cx q[97],q[60];
u1(pi/274877906944) q[60];
u1(pi/137438953472) q[97];
cx q[97],q[61];
u1(-pi/137438953472) q[61];
cx q[97],q[61];
u1(pi/137438953472) q[61];
u1(pi/68719476736) q[97];
cx q[97],q[62];
u1(-pi/68719476736) q[62];
cx q[97],q[62];
u1(pi/68719476736) q[62];
u1(pi/34359738368) q[97];
cx q[97],q[63];
u1(-pi/34359738368) q[63];
cx q[97],q[63];
u1(pi/34359738368) q[63];
u1(pi/17179869184) q[97];
cx q[97],q[64];
u1(-pi/17179869184) q[64];
cx q[97],q[64];
u1(pi/17179869184) q[64];
u1(pi/8589934592) q[97];
cx q[97],q[65];
u1(-pi/8589934592) q[65];
cx q[97],q[65];
u1(pi/8589934592) q[65];
u1(pi/4294967296) q[97];
cx q[97],q[66];
u1(-pi/4294967296) q[66];
cx q[97],q[66];
u1(pi/4294967296) q[66];
u1(pi/2147483648) q[97];
cx q[97],q[67];
u1(-pi/2147483648) q[67];
cx q[97],q[67];
u1(pi/2147483648) q[67];
u1(pi/1073741824) q[97];
cx q[97],q[68];
u1(-pi/1073741824) q[68];
cx q[97],q[68];
u1(pi/1073741824) q[68];
u1(pi/536870912) q[97];
cx q[97],q[69];
u1(-pi/536870912) q[69];
cx q[97],q[69];
u1(pi/536870912) q[69];
u1(pi/268435456) q[97];
cx q[97],q[70];
u1(-pi/268435456) q[70];
cx q[97],q[70];
u1(pi/268435456) q[70];
u1(pi/134217728) q[97];
cx q[97],q[71];
u1(-pi/134217728) q[71];
cx q[97],q[71];
u1(pi/134217728) q[71];
u1(pi/67108864) q[97];
cx q[97],q[72];
u1(-pi/67108864) q[72];
cx q[97],q[72];
u1(pi/67108864) q[72];
u1(pi/33554432) q[97];
cx q[97],q[73];
u1(-pi/33554432) q[73];
cx q[97],q[73];
u1(pi/33554432) q[73];
u1(pi/16777216) q[97];
cx q[97],q[74];
u1(-pi/16777216) q[74];
cx q[97],q[74];
u1(pi/16777216) q[74];
u1(pi/8388608) q[97];
cx q[97],q[75];
u1(-pi/8388608) q[75];
cx q[97],q[75];
u1(pi/8388608) q[75];
u1(pi/4194304) q[97];
cx q[97],q[76];
u1(-pi/4194304) q[76];
cx q[97],q[76];
u1(pi/4194304) q[76];
u1(pi/2097152) q[97];
cx q[97],q[77];
u1(-pi/2097152) q[77];
cx q[97],q[77];
u1(pi/2097152) q[77];
u1(pi/1048576) q[97];
cx q[97],q[78];
u1(-pi/1048576) q[78];
cx q[97],q[78];
u1(pi/1048576) q[78];
u1(pi/524288) q[97];
cx q[97],q[79];
u1(-pi/524288) q[79];
cx q[97],q[79];
u1(pi/524288) q[79];
u1(pi/262144) q[97];
cx q[97],q[80];
u1(-pi/262144) q[80];
cx q[97],q[80];
u1(pi/262144) q[80];
u1(pi/131072) q[97];
cx q[97],q[81];
u1(-pi/131072) q[81];
cx q[97],q[81];
u1(pi/131072) q[81];
u1(pi/65536) q[97];
cx q[97],q[82];
u1(-pi/65536) q[82];
cx q[97],q[82];
u1(pi/65536) q[82];
u1(pi/32768) q[97];
cx q[97],q[83];
u1(-pi/32768) q[83];
cx q[97],q[83];
u1(pi/32768) q[83];
u1(pi/16384) q[97];
cx q[97],q[84];
u1(-pi/16384) q[84];
cx q[97],q[84];
u1(pi/16384) q[84];
u1(pi/8192) q[97];
cx q[97],q[85];
u1(-pi/8192) q[85];
cx q[97],q[85];
u1(pi/8192) q[85];
u1(pi/4096) q[97];
cx q[97],q[86];
u1(-pi/4096) q[86];
cx q[97],q[86];
u1(pi/4096) q[86];
u1(pi/2048) q[97];
cx q[97],q[87];
u1(-pi/2048) q[87];
cx q[97],q[87];
u1(pi/2048) q[87];
u1(pi/1024) q[97];
cx q[97],q[88];
u1(-pi/1024) q[88];
cx q[97],q[88];
u1(pi/1024) q[88];
u1(pi/512) q[97];
cx q[97],q[89];
u1(-pi/512) q[89];
cx q[97],q[89];
u1(pi/512) q[89];
u1(pi/256) q[97];
cx q[97],q[90];
u1(-pi/256) q[90];
cx q[97],q[90];
u1(pi/256) q[90];
u1(pi/128) q[97];
cx q[97],q[91];
u1(-pi/128) q[91];
cx q[97],q[91];
u1(pi/128) q[91];
u1(pi/64) q[97];
cx q[97],q[92];
u1(-pi/64) q[92];
cx q[97],q[92];
u1(pi/64) q[92];
u1(pi/32) q[97];
cx q[97],q[93];
u1(-pi/32) q[93];
cx q[97],q[93];
u1(pi/32) q[93];
u1(pi/16) q[97];
cx q[97],q[94];
u1(-pi/16) q[94];
cx q[97],q[94];
u1(pi/16) q[94];
u1(pi/8) q[97];
cx q[97],q[95];
u1(-pi/8) q[95];
cx q[97],q[95];
u1(pi/8) q[95];
u1(pi/4) q[97];
cx q[97],q[96];
u1(-pi/4) q[96];
cx q[97],q[96];
u1(pi/4) q[96];
h q[97];
u1(0) q[98];
cx q[98],q[0];
u1(0) q[0];
cx q[98],q[0];
u1(0) q[0];
u1(0) q[98];
cx q[98],q[1];
u1(0) q[1];
cx q[98],q[1];
u1(0) q[1];
u1(0) q[98];
cx q[98],q[2];
u1(0) q[2];
cx q[98],q[2];
u1(0) q[2];
u1(0) q[98];
cx q[98],q[3];
u1(0) q[3];
cx q[98],q[3];
u1(0) q[3];
u1(0) q[98];
cx q[98],q[4];
u1(0) q[4];
cx q[98],q[4];
u1(0) q[4];
u1(0) q[98];
cx q[98],q[5];
u1(0) q[5];
cx q[98],q[5];
u1(0) q[5];
u1(0) q[98];
cx q[98],q[6];
u1(0) q[6];
cx q[98],q[6];
u1(0) q[6];
u1(0) q[98];
cx q[98],q[7];
u1(0) q[7];
cx q[98],q[7];
u1(0) q[7];
u1(0) q[98];
cx q[98],q[8];
u1(0) q[8];
cx q[98],q[8];
u1(0) q[8];
u1(0) q[98];
cx q[98],q[9];
u1(0) q[9];
cx q[98],q[9];
u1(0) q[9];
u1(0) q[98];
cx q[98],q[10];
u1(0) q[10];
cx q[98],q[10];
u1(0) q[10];
u1(0) q[98];
cx q[98],q[11];
u1(0) q[11];
cx q[98],q[11];
u1(0) q[11];
u1(0) q[98];
cx q[98],q[12];
u1(0) q[12];
cx q[98],q[12];
u1(0) q[12];
u1(0) q[98];
cx q[98],q[13];
u1(0) q[13];
cx q[98],q[13];
u1(0) q[13];
u1(0) q[98];
cx q[98],q[14];
u1(0) q[14];
cx q[98],q[14];
u1(0) q[14];
u1(0) q[98];
cx q[98],q[15];
u1(0) q[15];
cx q[98],q[15];
u1(0) q[15];
u1(0) q[98];
cx q[98],q[16];
u1(0) q[16];
cx q[98],q[16];
u1(0) q[16];
u1(0) q[98];
cx q[98],q[17];
u1(0) q[17];
cx q[98],q[17];
u1(0) q[17];
u1(0) q[98];
cx q[98],q[18];
u1(0) q[18];
cx q[98],q[18];
u1(0) q[18];
u1(0) q[98];
cx q[98],q[19];
u1(0) q[19];
cx q[98],q[19];
u1(0) q[19];
u1(0) q[98];
cx q[98],q[20];
u1(0) q[20];
cx q[98],q[20];
u1(0) q[20];
u1(0) q[98];
cx q[98],q[21];
u1(0) q[21];
cx q[98],q[21];
u1(0) q[21];
u1(0) q[98];
cx q[98],q[22];
u1(0) q[22];
cx q[98],q[22];
u1(0) q[22];
u1(0) q[98];
cx q[98],q[23];
u1(0) q[23];
cx q[98],q[23];
u1(0) q[23];
u1(0) q[98];
cx q[98],q[24];
u1(0) q[24];
cx q[98],q[24];
u1(0) q[24];
u1(0) q[98];
cx q[98],q[25];
u1(0) q[25];
cx q[98],q[25];
u1(0) q[25];
u1(0) q[98];
cx q[98],q[26];
u1(0) q[26];
cx q[98],q[26];
u1(0) q[26];
u1(0) q[98];
cx q[98],q[27];
u1(0) q[27];
cx q[98],q[27];
u1(0) q[27];
u1(0) q[98];
cx q[98],q[28];
u1(0) q[28];
cx q[98],q[28];
u1(0) q[28];
u1(0) q[98];
cx q[98],q[29];
u1(0) q[29];
cx q[98],q[29];
u1(0) q[29];
u1(0) q[98];
cx q[98],q[30];
u1(0) q[30];
cx q[98],q[30];
u1(0) q[30];
u1(0) q[98];
cx q[98],q[31];
u1(0) q[31];
cx q[98],q[31];
u1(0) q[31];
u1(0) q[98];
cx q[98],q[32];
u1(0) q[32];
cx q[98],q[32];
u1(0) q[32];
u1(0) q[98];
cx q[98],q[33];
u1(0) q[33];
cx q[98],q[33];
u1(0) q[33];
u1(0) q[98];
cx q[98],q[34];
u1(0) q[34];
cx q[98],q[34];
u1(0) q[34];
u1(0) q[98];
cx q[98],q[35];
u1(0) q[35];
cx q[98],q[35];
u1(0) q[35];
u1(0) q[98];
cx q[98],q[36];
u1(0) q[36];
cx q[98],q[36];
u1(0) q[36];
u1(0) q[98];
cx q[98],q[37];
u1(0) q[37];
cx q[98],q[37];
u1(0) q[37];
u1(0) q[98];
cx q[98],q[38];
u1(0) q[38];
cx q[98],q[38];
u1(0) q[38];
u1(0) q[98];
cx q[98],q[39];
u1(0) q[39];
cx q[98],q[39];
u1(0) q[39];
u1(0) q[98];
cx q[98],q[40];
u1(0) q[40];
cx q[98],q[40];
u1(0) q[40];
u1(0) q[98];
cx q[98],q[41];
u1(0) q[41];
cx q[98],q[41];
u1(0) q[41];
u1(0) q[98];
cx q[98],q[42];
u1(0) q[42];
cx q[98],q[42];
u1(0) q[42];
u1(0) q[98];
cx q[98],q[43];
u1(0) q[43];
cx q[98],q[43];
u1(0) q[43];
u1(0) q[98];
cx q[98],q[44];
u1(0) q[44];
cx q[98],q[44];
u1(0) q[44];
u1(0) q[98];
cx q[98],q[45];
u1(0) q[45];
cx q[98],q[45];
u1(0) q[45];
u1(0) q[98];
cx q[98],q[46];
u1(0) q[46];
cx q[98],q[46];
u1(0) q[46];
u1(0) q[98];
cx q[98],q[47];
u1(0) q[47];
cx q[98],q[47];
u1(0) q[47];
u1(0) q[98];
cx q[98],q[48];
u1(0) q[48];
cx q[98],q[48];
u1(0) q[48];
u1(0) q[98];
cx q[98],q[49];
u1(0) q[49];
cx q[98],q[49];
u1(0) q[49];
u1(0) q[98];
cx q[98],q[50];
u1(0) q[50];
cx q[98],q[50];
u1(0) q[50];
u1(pi/281474976710656) q[98];
cx q[98],q[51];
u1(-pi/281474976710656) q[51];
cx q[98],q[51];
u1(pi/281474976710656) q[51];
u1(pi/140737488355328) q[98];
cx q[98],q[52];
u1(-pi/140737488355328) q[52];
cx q[98],q[52];
u1(pi/140737488355328) q[52];
u1(pi/70368744177664) q[98];
cx q[98],q[53];
u1(-pi/70368744177664) q[53];
cx q[98],q[53];
u1(pi/70368744177664) q[53];
u1(pi/35184372088832) q[98];
cx q[98],q[54];
u1(-pi/35184372088832) q[54];
cx q[98],q[54];
u1(pi/35184372088832) q[54];
u1(pi/17592186044416) q[98];
cx q[98],q[55];
u1(-pi/17592186044416) q[55];
cx q[98],q[55];
u1(pi/17592186044416) q[55];
u1(pi/8796093022208) q[98];
cx q[98],q[56];
u1(-pi/8796093022208) q[56];
cx q[98],q[56];
u1(pi/8796093022208) q[56];
u1(pi/4398046511104) q[98];
cx q[98],q[57];
u1(-pi/4398046511104) q[57];
cx q[98],q[57];
u1(pi/4398046511104) q[57];
u1(pi/2199023255552) q[98];
cx q[98],q[58];
u1(-pi/2199023255552) q[58];
cx q[98],q[58];
u1(pi/2199023255552) q[58];
u1(pi/1099511627776) q[98];
cx q[98],q[59];
u1(-pi/1099511627776) q[59];
cx q[98],q[59];
u1(pi/1099511627776) q[59];
u1(pi/549755813888) q[98];
cx q[98],q[60];
u1(-pi/549755813888) q[60];
cx q[98],q[60];
u1(pi/549755813888) q[60];
u1(pi/274877906944) q[98];
cx q[98],q[61];
u1(-pi/274877906944) q[61];
cx q[98],q[61];
u1(pi/274877906944) q[61];
u1(pi/137438953472) q[98];
cx q[98],q[62];
u1(-pi/137438953472) q[62];
cx q[98],q[62];
u1(pi/137438953472) q[62];
u1(pi/68719476736) q[98];
cx q[98],q[63];
u1(-pi/68719476736) q[63];
cx q[98],q[63];
u1(pi/68719476736) q[63];
u1(pi/34359738368) q[98];
cx q[98],q[64];
u1(-pi/34359738368) q[64];
cx q[98],q[64];
u1(pi/34359738368) q[64];
u1(pi/17179869184) q[98];
cx q[98],q[65];
u1(-pi/17179869184) q[65];
cx q[98],q[65];
u1(pi/17179869184) q[65];
u1(pi/8589934592) q[98];
cx q[98],q[66];
u1(-pi/8589934592) q[66];
cx q[98],q[66];
u1(pi/8589934592) q[66];
u1(pi/4294967296) q[98];
cx q[98],q[67];
u1(-pi/4294967296) q[67];
cx q[98],q[67];
u1(pi/4294967296) q[67];
u1(pi/2147483648) q[98];
cx q[98],q[68];
u1(-pi/2147483648) q[68];
cx q[98],q[68];
u1(pi/2147483648) q[68];
u1(pi/1073741824) q[98];
cx q[98],q[69];
u1(-pi/1073741824) q[69];
cx q[98],q[69];
u1(pi/1073741824) q[69];
u1(pi/536870912) q[98];
cx q[98],q[70];
u1(-pi/536870912) q[70];
cx q[98],q[70];
u1(pi/536870912) q[70];
u1(pi/268435456) q[98];
cx q[98],q[71];
u1(-pi/268435456) q[71];
cx q[98],q[71];
u1(pi/268435456) q[71];
u1(pi/134217728) q[98];
cx q[98],q[72];
u1(-pi/134217728) q[72];
cx q[98],q[72];
u1(pi/134217728) q[72];
u1(pi/67108864) q[98];
cx q[98],q[73];
u1(-pi/67108864) q[73];
cx q[98],q[73];
u1(pi/67108864) q[73];
u1(pi/33554432) q[98];
cx q[98],q[74];
u1(-pi/33554432) q[74];
cx q[98],q[74];
u1(pi/33554432) q[74];
u1(pi/16777216) q[98];
cx q[98],q[75];
u1(-pi/16777216) q[75];
cx q[98],q[75];
u1(pi/16777216) q[75];
u1(pi/8388608) q[98];
cx q[98],q[76];
u1(-pi/8388608) q[76];
cx q[98],q[76];
u1(pi/8388608) q[76];
u1(pi/4194304) q[98];
cx q[98],q[77];
u1(-pi/4194304) q[77];
cx q[98],q[77];
u1(pi/4194304) q[77];
u1(pi/2097152) q[98];
cx q[98],q[78];
u1(-pi/2097152) q[78];
cx q[98],q[78];
u1(pi/2097152) q[78];
u1(pi/1048576) q[98];
cx q[98],q[79];
u1(-pi/1048576) q[79];
cx q[98],q[79];
u1(pi/1048576) q[79];
u1(pi/524288) q[98];
cx q[98],q[80];
u1(-pi/524288) q[80];
cx q[98],q[80];
u1(pi/524288) q[80];
u1(pi/262144) q[98];
cx q[98],q[81];
u1(-pi/262144) q[81];
cx q[98],q[81];
u1(pi/262144) q[81];
u1(pi/131072) q[98];
cx q[98],q[82];
u1(-pi/131072) q[82];
cx q[98],q[82];
u1(pi/131072) q[82];
u1(pi/65536) q[98];
cx q[98],q[83];
u1(-pi/65536) q[83];
cx q[98],q[83];
u1(pi/65536) q[83];
u1(pi/32768) q[98];
cx q[98],q[84];
u1(-pi/32768) q[84];
cx q[98],q[84];
u1(pi/32768) q[84];
u1(pi/16384) q[98];
cx q[98],q[85];
u1(-pi/16384) q[85];
cx q[98],q[85];
u1(pi/16384) q[85];
u1(pi/8192) q[98];
cx q[98],q[86];
u1(-pi/8192) q[86];
cx q[98],q[86];
u1(pi/8192) q[86];
u1(pi/4096) q[98];
cx q[98],q[87];
u1(-pi/4096) q[87];
cx q[98],q[87];
u1(pi/4096) q[87];
u1(pi/2048) q[98];
cx q[98],q[88];
u1(-pi/2048) q[88];
cx q[98],q[88];
u1(pi/2048) q[88];
u1(pi/1024) q[98];
cx q[98],q[89];
u1(-pi/1024) q[89];
cx q[98],q[89];
u1(pi/1024) q[89];
u1(pi/512) q[98];
cx q[98],q[90];
u1(-pi/512) q[90];
cx q[98],q[90];
u1(pi/512) q[90];
u1(pi/256) q[98];
cx q[98],q[91];
u1(-pi/256) q[91];
cx q[98],q[91];
u1(pi/256) q[91];
u1(pi/128) q[98];
cx q[98],q[92];
u1(-pi/128) q[92];
cx q[98],q[92];
u1(pi/128) q[92];
u1(pi/64) q[98];
cx q[98],q[93];
u1(-pi/64) q[93];
cx q[98],q[93];
u1(pi/64) q[93];
u1(pi/32) q[98];
cx q[98],q[94];
u1(-pi/32) q[94];
cx q[98],q[94];
u1(pi/32) q[94];
u1(pi/16) q[98];
cx q[98],q[95];
u1(-pi/16) q[95];
cx q[98],q[95];
u1(pi/16) q[95];
u1(pi/8) q[98];
cx q[98],q[96];
u1(-pi/8) q[96];
cx q[98],q[96];
u1(pi/8) q[96];
u1(pi/4) q[98];
cx q[98],q[97];
u1(-pi/4) q[97];
cx q[98],q[97];
u1(pi/4) q[97];
h q[98];
u1(0) q[99];
cx q[99],q[0];
u1(0) q[0];
cx q[99],q[0];
u1(0) q[0];
u1(0) q[99];
cx q[99],q[1];
u1(0) q[1];
cx q[99],q[1];
u1(0) q[1];
u1(0) q[99];
cx q[99],q[2];
u1(0) q[2];
cx q[99],q[2];
u1(0) q[2];
u1(0) q[99];
cx q[99],q[3];
u1(0) q[3];
cx q[99],q[3];
u1(0) q[3];
u1(0) q[99];
cx q[99],q[4];
u1(0) q[4];
cx q[99],q[4];
u1(0) q[4];
u1(0) q[99];
cx q[99],q[5];
u1(0) q[5];
cx q[99],q[5];
u1(0) q[5];
u1(0) q[99];
cx q[99],q[6];
u1(0) q[6];
cx q[99],q[6];
u1(0) q[6];
u1(0) q[99];
cx q[99],q[7];
u1(0) q[7];
cx q[99],q[7];
u1(0) q[7];
u1(0) q[99];
cx q[99],q[8];
u1(0) q[8];
cx q[99],q[8];
u1(0) q[8];
u1(0) q[99];
cx q[99],q[9];
u1(0) q[9];
cx q[99],q[9];
u1(0) q[9];
u1(0) q[99];
cx q[99],q[10];
u1(0) q[10];
cx q[99],q[10];
u1(0) q[10];
u1(0) q[99];
cx q[99],q[11];
u1(0) q[11];
cx q[99],q[11];
u1(0) q[11];
u1(0) q[99];
cx q[99],q[12];
u1(0) q[12];
cx q[99],q[12];
u1(0) q[12];
u1(0) q[99];
cx q[99],q[13];
u1(0) q[13];
cx q[99],q[13];
u1(0) q[13];
u1(0) q[99];
cx q[99],q[14];
u1(0) q[14];
cx q[99],q[14];
u1(0) q[14];
u1(0) q[99];
cx q[99],q[15];
u1(0) q[15];
cx q[99],q[15];
u1(0) q[15];
u1(0) q[99];
cx q[99],q[16];
u1(0) q[16];
cx q[99],q[16];
u1(0) q[16];
u1(0) q[99];
cx q[99],q[17];
u1(0) q[17];
cx q[99],q[17];
u1(0) q[17];
u1(0) q[99];
cx q[99],q[18];
u1(0) q[18];
cx q[99],q[18];
u1(0) q[18];
u1(0) q[99];
cx q[99],q[19];
u1(0) q[19];
cx q[99],q[19];
u1(0) q[19];
u1(0) q[99];
cx q[99],q[20];
u1(0) q[20];
cx q[99],q[20];
u1(0) q[20];
u1(0) q[99];
cx q[99],q[21];
u1(0) q[21];
cx q[99],q[21];
u1(0) q[21];
u1(0) q[99];
cx q[99],q[22];
u1(0) q[22];
cx q[99],q[22];
u1(0) q[22];
u1(0) q[99];
cx q[99],q[23];
u1(0) q[23];
cx q[99],q[23];
u1(0) q[23];
u1(0) q[99];
cx q[99],q[24];
u1(0) q[24];
cx q[99],q[24];
u1(0) q[24];
u1(0) q[99];
cx q[99],q[25];
u1(0) q[25];
cx q[99],q[25];
u1(0) q[25];
u1(0) q[99];
cx q[99],q[26];
u1(0) q[26];
cx q[99],q[26];
u1(0) q[26];
u1(0) q[99];
cx q[99],q[27];
u1(0) q[27];
cx q[99],q[27];
u1(0) q[27];
u1(0) q[99];
cx q[99],q[28];
u1(0) q[28];
cx q[99],q[28];
u1(0) q[28];
u1(0) q[99];
cx q[99],q[29];
u1(0) q[29];
cx q[99],q[29];
u1(0) q[29];
u1(0) q[99];
cx q[99],q[30];
u1(0) q[30];
cx q[99],q[30];
u1(0) q[30];
u1(0) q[99];
cx q[99],q[31];
u1(0) q[31];
cx q[99],q[31];
u1(0) q[31];
u1(0) q[99];
cx q[99],q[32];
u1(0) q[32];
cx q[99],q[32];
u1(0) q[32];
u1(0) q[99];
cx q[99],q[33];
u1(0) q[33];
cx q[99],q[33];
u1(0) q[33];
u1(0) q[99];
cx q[99],q[34];
u1(0) q[34];
cx q[99],q[34];
u1(0) q[34];
u1(0) q[99];
cx q[99],q[35];
u1(0) q[35];
cx q[99],q[35];
u1(0) q[35];
u1(0) q[99];
cx q[99],q[36];
u1(0) q[36];
cx q[99],q[36];
u1(0) q[36];
u1(0) q[99];
cx q[99],q[37];
u1(0) q[37];
cx q[99],q[37];
u1(0) q[37];
u1(0) q[99];
cx q[99],q[38];
u1(0) q[38];
cx q[99],q[38];
u1(0) q[38];
u1(0) q[99];
cx q[99],q[39];
u1(0) q[39];
cx q[99],q[39];
u1(0) q[39];
u1(0) q[99];
cx q[99],q[40];
u1(0) q[40];
cx q[99],q[40];
u1(0) q[40];
u1(0) q[99];
cx q[99],q[41];
u1(0) q[41];
cx q[99],q[41];
u1(0) q[41];
u1(0) q[99];
cx q[99],q[42];
u1(0) q[42];
cx q[99],q[42];
u1(0) q[42];
u1(0) q[99];
cx q[99],q[43];
u1(0) q[43];
cx q[99],q[43];
u1(0) q[43];
u1(0) q[99];
cx q[99],q[44];
u1(0) q[44];
cx q[99],q[44];
u1(0) q[44];
u1(0) q[99];
cx q[99],q[45];
u1(0) q[45];
cx q[99],q[45];
u1(0) q[45];
u1(0) q[99];
cx q[99],q[46];
u1(0) q[46];
cx q[99],q[46];
u1(0) q[46];
u1(0) q[99];
cx q[99],q[47];
u1(0) q[47];
cx q[99],q[47];
u1(0) q[47];
u1(0) q[99];
cx q[99],q[48];
u1(0) q[48];
cx q[99],q[48];
u1(0) q[48];
u1(0) q[99];
cx q[99],q[49];
u1(0) q[49];
cx q[99],q[49];
u1(0) q[49];
u1(0) q[99];
cx q[99],q[50];
u1(0) q[50];
cx q[99],q[50];
u1(0) q[50];
u1(0) q[99];
cx q[99],q[51];
u1(0) q[51];
cx q[99],q[51];
u1(0) q[51];
u1(pi/281474976710656) q[99];
cx q[99],q[52];
u1(-pi/281474976710656) q[52];
cx q[99],q[52];
u1(pi/281474976710656) q[52];
u1(pi/140737488355328) q[99];
cx q[99],q[53];
u1(-pi/140737488355328) q[53];
cx q[99],q[53];
u1(pi/140737488355328) q[53];
u1(pi/70368744177664) q[99];
cx q[99],q[54];
u1(-pi/70368744177664) q[54];
cx q[99],q[54];
u1(pi/70368744177664) q[54];
u1(pi/35184372088832) q[99];
cx q[99],q[55];
u1(-pi/35184372088832) q[55];
cx q[99],q[55];
u1(pi/35184372088832) q[55];
u1(pi/17592186044416) q[99];
cx q[99],q[56];
u1(-pi/17592186044416) q[56];
cx q[99],q[56];
u1(pi/17592186044416) q[56];
u1(pi/8796093022208) q[99];
cx q[99],q[57];
u1(-pi/8796093022208) q[57];
cx q[99],q[57];
u1(pi/8796093022208) q[57];
u1(pi/4398046511104) q[99];
cx q[99],q[58];
u1(-pi/4398046511104) q[58];
cx q[99],q[58];
u1(pi/4398046511104) q[58];
u1(pi/2199023255552) q[99];
cx q[99],q[59];
u1(-pi/2199023255552) q[59];
cx q[99],q[59];
u1(pi/2199023255552) q[59];
u1(pi/1099511627776) q[99];
cx q[99],q[60];
u1(-pi/1099511627776) q[60];
cx q[99],q[60];
u1(pi/1099511627776) q[60];
u1(pi/549755813888) q[99];
cx q[99],q[61];
u1(-pi/549755813888) q[61];
cx q[99],q[61];
u1(pi/549755813888) q[61];
u1(pi/274877906944) q[99];
cx q[99],q[62];
u1(-pi/274877906944) q[62];
cx q[99],q[62];
u1(pi/274877906944) q[62];
u1(pi/137438953472) q[99];
cx q[99],q[63];
u1(-pi/137438953472) q[63];
cx q[99],q[63];
u1(pi/137438953472) q[63];
u1(pi/68719476736) q[99];
cx q[99],q[64];
u1(-pi/68719476736) q[64];
cx q[99],q[64];
u1(pi/68719476736) q[64];
u1(pi/34359738368) q[99];
cx q[99],q[65];
u1(-pi/34359738368) q[65];
cx q[99],q[65];
u1(pi/34359738368) q[65];
u1(pi/17179869184) q[99];
cx q[99],q[66];
u1(-pi/17179869184) q[66];
cx q[99],q[66];
u1(pi/17179869184) q[66];
u1(pi/8589934592) q[99];
cx q[99],q[67];
u1(-pi/8589934592) q[67];
cx q[99],q[67];
u1(pi/8589934592) q[67];
u1(pi/4294967296) q[99];
cx q[99],q[68];
u1(-pi/4294967296) q[68];
cx q[99],q[68];
u1(pi/4294967296) q[68];
u1(pi/2147483648) q[99];
cx q[99],q[69];
u1(-pi/2147483648) q[69];
cx q[99],q[69];
u1(pi/2147483648) q[69];
u1(pi/1073741824) q[99];
cx q[99],q[70];
u1(-pi/1073741824) q[70];
cx q[99],q[70];
u1(pi/1073741824) q[70];
u1(pi/536870912) q[99];
cx q[99],q[71];
u1(-pi/536870912) q[71];
cx q[99],q[71];
u1(pi/536870912) q[71];
u1(pi/268435456) q[99];
cx q[99],q[72];
u1(-pi/268435456) q[72];
cx q[99],q[72];
u1(pi/268435456) q[72];
u1(pi/134217728) q[99];
cx q[99],q[73];
u1(-pi/134217728) q[73];
cx q[99],q[73];
u1(pi/134217728) q[73];
u1(pi/67108864) q[99];
cx q[99],q[74];
u1(-pi/67108864) q[74];
cx q[99],q[74];
u1(pi/67108864) q[74];
u1(pi/33554432) q[99];
cx q[99],q[75];
u1(-pi/33554432) q[75];
cx q[99],q[75];
u1(pi/33554432) q[75];
u1(pi/16777216) q[99];
cx q[99],q[76];
u1(-pi/16777216) q[76];
cx q[99],q[76];
u1(pi/16777216) q[76];
u1(pi/8388608) q[99];
cx q[99],q[77];
u1(-pi/8388608) q[77];
cx q[99],q[77];
u1(pi/8388608) q[77];
u1(pi/4194304) q[99];
cx q[99],q[78];
u1(-pi/4194304) q[78];
cx q[99],q[78];
u1(pi/4194304) q[78];
u1(pi/2097152) q[99];
cx q[99],q[79];
u1(-pi/2097152) q[79];
cx q[99],q[79];
u1(pi/2097152) q[79];
u1(pi/1048576) q[99];
cx q[99],q[80];
u1(-pi/1048576) q[80];
cx q[99],q[80];
u1(pi/1048576) q[80];
u1(pi/524288) q[99];
cx q[99],q[81];
u1(-pi/524288) q[81];
cx q[99],q[81];
u1(pi/524288) q[81];
u1(pi/262144) q[99];
cx q[99],q[82];
u1(-pi/262144) q[82];
cx q[99],q[82];
u1(pi/262144) q[82];
u1(pi/131072) q[99];
cx q[99],q[83];
u1(-pi/131072) q[83];
cx q[99],q[83];
u1(pi/131072) q[83];
u1(pi/65536) q[99];
cx q[99],q[84];
u1(-pi/65536) q[84];
cx q[99],q[84];
u1(pi/65536) q[84];
u1(pi/32768) q[99];
cx q[99],q[85];
u1(-pi/32768) q[85];
cx q[99],q[85];
u1(pi/32768) q[85];
u1(pi/16384) q[99];
cx q[99],q[86];
u1(-pi/16384) q[86];
cx q[99],q[86];
u1(pi/16384) q[86];
u1(pi/8192) q[99];
cx q[99],q[87];
u1(-pi/8192) q[87];
cx q[99],q[87];
u1(pi/8192) q[87];
u1(pi/4096) q[99];
cx q[99],q[88];
u1(-pi/4096) q[88];
cx q[99],q[88];
u1(pi/4096) q[88];
u1(pi/2048) q[99];
cx q[99],q[89];
u1(-pi/2048) q[89];
cx q[99],q[89];
u1(pi/2048) q[89];
u1(pi/1024) q[99];
cx q[99],q[90];
u1(-pi/1024) q[90];
cx q[99],q[90];
u1(pi/1024) q[90];
u1(pi/512) q[99];
cx q[99],q[91];
u1(-pi/512) q[91];
cx q[99],q[91];
u1(pi/512) q[91];
u1(pi/256) q[99];
cx q[99],q[92];
u1(-pi/256) q[92];
cx q[99],q[92];
u1(pi/256) q[92];
u1(pi/128) q[99];
cx q[99],q[93];
u1(-pi/128) q[93];
cx q[99],q[93];
u1(pi/128) q[93];
u1(pi/64) q[99];
cx q[99],q[94];
u1(-pi/64) q[94];
cx q[99],q[94];
u1(pi/64) q[94];
u1(pi/32) q[99];
cx q[99],q[95];
u1(-pi/32) q[95];
cx q[99],q[95];
u1(pi/32) q[95];
u1(pi/16) q[99];
cx q[99],q[96];
u1(-pi/16) q[96];
cx q[99],q[96];
u1(pi/16) q[96];
u1(pi/8) q[99];
cx q[99],q[97];
u1(-pi/8) q[97];
cx q[99],q[97];
u1(pi/8) q[97];
u1(pi/4) q[99];
cx q[99],q[98];
u1(-pi/4) q[98];
cx q[99],q[98];
u1(pi/4) q[98];
h q[99];
u1(0) q[100];
cx q[100],q[0];
u1(0) q[0];
cx q[100],q[0];
u1(0) q[0];
u1(0) q[100];
cx q[100],q[1];
u1(0) q[1];
cx q[100],q[1];
u1(0) q[1];
u1(0) q[100];
cx q[100],q[2];
u1(0) q[2];
cx q[100],q[2];
u1(0) q[2];
u1(0) q[100];
cx q[100],q[3];
u1(0) q[3];
cx q[100],q[3];
u1(0) q[3];
u1(0) q[100];
cx q[100],q[4];
u1(0) q[4];
cx q[100],q[4];
u1(0) q[4];
u1(0) q[100];
cx q[100],q[5];
u1(0) q[5];
cx q[100],q[5];
u1(0) q[5];
u1(0) q[100];
cx q[100],q[6];
u1(0) q[6];
cx q[100],q[6];
u1(0) q[6];
u1(0) q[100];
cx q[100],q[7];
u1(0) q[7];
cx q[100],q[7];
u1(0) q[7];
u1(0) q[100];
cx q[100],q[8];
u1(0) q[8];
cx q[100],q[8];
u1(0) q[8];
u1(0) q[100];
cx q[100],q[9];
u1(0) q[9];
cx q[100],q[9];
u1(0) q[9];
u1(0) q[100];
cx q[100],q[10];
u1(0) q[10];
cx q[100],q[10];
u1(0) q[10];
u1(0) q[100];
cx q[100],q[11];
u1(0) q[11];
cx q[100],q[11];
u1(0) q[11];
u1(0) q[100];
cx q[100],q[12];
u1(0) q[12];
cx q[100],q[12];
u1(0) q[12];
u1(0) q[100];
cx q[100],q[13];
u1(0) q[13];
cx q[100],q[13];
u1(0) q[13];
u1(0) q[100];
cx q[100],q[14];
u1(0) q[14];
cx q[100],q[14];
u1(0) q[14];
u1(0) q[100];
cx q[100],q[15];
u1(0) q[15];
cx q[100],q[15];
u1(0) q[15];
u1(0) q[100];
cx q[100],q[16];
u1(0) q[16];
cx q[100],q[16];
u1(0) q[16];
u1(0) q[100];
cx q[100],q[17];
u1(0) q[17];
cx q[100],q[17];
u1(0) q[17];
u1(0) q[100];
cx q[100],q[18];
u1(0) q[18];
cx q[100],q[18];
u1(0) q[18];
u1(0) q[100];
cx q[100],q[19];
u1(0) q[19];
cx q[100],q[19];
u1(0) q[19];
u1(0) q[100];
cx q[100],q[20];
u1(0) q[20];
cx q[100],q[20];
u1(0) q[20];
u1(0) q[100];
cx q[100],q[21];
u1(0) q[21];
cx q[100],q[21];
u1(0) q[21];
u1(0) q[100];
cx q[100],q[22];
u1(0) q[22];
cx q[100],q[22];
u1(0) q[22];
u1(0) q[100];
cx q[100],q[23];
u1(0) q[23];
cx q[100],q[23];
u1(0) q[23];
u1(0) q[100];
cx q[100],q[24];
u1(0) q[24];
cx q[100],q[24];
u1(0) q[24];
u1(0) q[100];
cx q[100],q[25];
u1(0) q[25];
cx q[100],q[25];
u1(0) q[25];
u1(0) q[100];
cx q[100],q[26];
u1(0) q[26];
cx q[100],q[26];
u1(0) q[26];
u1(0) q[100];
cx q[100],q[27];
u1(0) q[27];
cx q[100],q[27];
u1(0) q[27];
u1(0) q[100];
cx q[100],q[28];
u1(0) q[28];
cx q[100],q[28];
u1(0) q[28];
u1(0) q[100];
cx q[100],q[29];
u1(0) q[29];
cx q[100],q[29];
u1(0) q[29];
u1(0) q[100];
cx q[100],q[30];
u1(0) q[30];
cx q[100],q[30];
u1(0) q[30];
u1(0) q[100];
cx q[100],q[31];
u1(0) q[31];
cx q[100],q[31];
u1(0) q[31];
u1(0) q[100];
cx q[100],q[32];
u1(0) q[32];
cx q[100],q[32];
u1(0) q[32];
u1(0) q[100];
cx q[100],q[33];
u1(0) q[33];
cx q[100],q[33];
u1(0) q[33];
u1(0) q[100];
cx q[100],q[34];
u1(0) q[34];
cx q[100],q[34];
u1(0) q[34];
u1(0) q[100];
cx q[100],q[35];
u1(0) q[35];
cx q[100],q[35];
u1(0) q[35];
u1(0) q[100];
cx q[100],q[36];
u1(0) q[36];
cx q[100],q[36];
u1(0) q[36];
u1(0) q[100];
cx q[100],q[37];
u1(0) q[37];
cx q[100],q[37];
u1(0) q[37];
u1(0) q[100];
cx q[100],q[38];
u1(0) q[38];
cx q[100],q[38];
u1(0) q[38];
u1(0) q[100];
cx q[100],q[39];
u1(0) q[39];
cx q[100],q[39];
u1(0) q[39];
u1(0) q[100];
cx q[100],q[40];
u1(0) q[40];
cx q[100],q[40];
u1(0) q[40];
u1(0) q[100];
cx q[100],q[41];
u1(0) q[41];
cx q[100],q[41];
u1(0) q[41];
u1(0) q[100];
cx q[100],q[42];
u1(0) q[42];
cx q[100],q[42];
u1(0) q[42];
u1(0) q[100];
cx q[100],q[43];
u1(0) q[43];
cx q[100],q[43];
u1(0) q[43];
u1(0) q[100];
cx q[100],q[44];
u1(0) q[44];
cx q[100],q[44];
u1(0) q[44];
u1(0) q[100];
cx q[100],q[45];
u1(0) q[45];
cx q[100],q[45];
u1(0) q[45];
u1(0) q[100];
cx q[100],q[46];
u1(0) q[46];
cx q[100],q[46];
u1(0) q[46];
u1(0) q[100];
cx q[100],q[47];
u1(0) q[47];
cx q[100],q[47];
u1(0) q[47];
u1(0) q[100];
cx q[100],q[48];
u1(0) q[48];
cx q[100],q[48];
u1(0) q[48];
u1(0) q[100];
cx q[100],q[49];
u1(0) q[49];
cx q[100],q[49];
u1(0) q[49];
u1(0) q[100];
cx q[100],q[50];
u1(0) q[50];
cx q[100],q[50];
u1(0) q[50];
u1(0) q[100];
cx q[100],q[51];
u1(0) q[51];
cx q[100],q[51];
u1(0) q[51];
u1(0) q[100];
cx q[100],q[52];
u1(0) q[52];
cx q[100],q[52];
u1(0) q[52];
u1(pi/281474976710656) q[100];
cx q[100],q[53];
u1(-pi/281474976710656) q[53];
cx q[100],q[53];
u1(pi/281474976710656) q[53];
u1(pi/140737488355328) q[100];
cx q[100],q[54];
u1(-pi/140737488355328) q[54];
cx q[100],q[54];
u1(pi/140737488355328) q[54];
u1(pi/70368744177664) q[100];
cx q[100],q[55];
u1(-pi/70368744177664) q[55];
cx q[100],q[55];
u1(pi/70368744177664) q[55];
u1(pi/35184372088832) q[100];
cx q[100],q[56];
u1(-pi/35184372088832) q[56];
cx q[100],q[56];
u1(pi/35184372088832) q[56];
u1(pi/17592186044416) q[100];
cx q[100],q[57];
u1(-pi/17592186044416) q[57];
cx q[100],q[57];
u1(pi/17592186044416) q[57];
u1(pi/8796093022208) q[100];
cx q[100],q[58];
u1(-pi/8796093022208) q[58];
cx q[100],q[58];
u1(pi/8796093022208) q[58];
u1(pi/4398046511104) q[100];
cx q[100],q[59];
u1(-pi/4398046511104) q[59];
cx q[100],q[59];
u1(pi/4398046511104) q[59];
u1(pi/2199023255552) q[100];
cx q[100],q[60];
u1(-pi/2199023255552) q[60];
cx q[100],q[60];
u1(pi/2199023255552) q[60];
u1(pi/1099511627776) q[100];
cx q[100],q[61];
u1(-pi/1099511627776) q[61];
cx q[100],q[61];
u1(pi/1099511627776) q[61];
u1(pi/549755813888) q[100];
cx q[100],q[62];
u1(-pi/549755813888) q[62];
cx q[100],q[62];
u1(pi/549755813888) q[62];
u1(pi/274877906944) q[100];
cx q[100],q[63];
u1(-pi/274877906944) q[63];
cx q[100],q[63];
u1(pi/274877906944) q[63];
u1(pi/137438953472) q[100];
cx q[100],q[64];
u1(-pi/137438953472) q[64];
cx q[100],q[64];
u1(pi/137438953472) q[64];
u1(pi/68719476736) q[100];
cx q[100],q[65];
u1(-pi/68719476736) q[65];
cx q[100],q[65];
u1(pi/68719476736) q[65];
u1(pi/34359738368) q[100];
cx q[100],q[66];
u1(-pi/34359738368) q[66];
cx q[100],q[66];
u1(pi/34359738368) q[66];
u1(pi/17179869184) q[100];
cx q[100],q[67];
u1(-pi/17179869184) q[67];
cx q[100],q[67];
u1(pi/17179869184) q[67];
u1(pi/8589934592) q[100];
cx q[100],q[68];
u1(-pi/8589934592) q[68];
cx q[100],q[68];
u1(pi/8589934592) q[68];
u1(pi/4294967296) q[100];
cx q[100],q[69];
u1(-pi/4294967296) q[69];
cx q[100],q[69];
u1(pi/4294967296) q[69];
u1(pi/2147483648) q[100];
cx q[100],q[70];
u1(-pi/2147483648) q[70];
cx q[100],q[70];
u1(pi/2147483648) q[70];
u1(pi/1073741824) q[100];
cx q[100],q[71];
u1(-pi/1073741824) q[71];
cx q[100],q[71];
u1(pi/1073741824) q[71];
u1(pi/536870912) q[100];
cx q[100],q[72];
u1(-pi/536870912) q[72];
cx q[100],q[72];
u1(pi/536870912) q[72];
u1(pi/268435456) q[100];
cx q[100],q[73];
u1(-pi/268435456) q[73];
cx q[100],q[73];
u1(pi/268435456) q[73];
u1(pi/134217728) q[100];
cx q[100],q[74];
u1(-pi/134217728) q[74];
cx q[100],q[74];
u1(pi/134217728) q[74];
u1(pi/67108864) q[100];
cx q[100],q[75];
u1(-pi/67108864) q[75];
cx q[100],q[75];
u1(pi/67108864) q[75];
u1(pi/33554432) q[100];
cx q[100],q[76];
u1(-pi/33554432) q[76];
cx q[100],q[76];
u1(pi/33554432) q[76];
u1(pi/16777216) q[100];
cx q[100],q[77];
u1(-pi/16777216) q[77];
cx q[100],q[77];
u1(pi/16777216) q[77];
u1(pi/8388608) q[100];
cx q[100],q[78];
u1(-pi/8388608) q[78];
cx q[100],q[78];
u1(pi/8388608) q[78];
u1(pi/4194304) q[100];
cx q[100],q[79];
u1(-pi/4194304) q[79];
cx q[100],q[79];
u1(pi/4194304) q[79];
u1(pi/2097152) q[100];
cx q[100],q[80];
u1(-pi/2097152) q[80];
cx q[100],q[80];
u1(pi/2097152) q[80];
u1(pi/1048576) q[100];
cx q[100],q[81];
u1(-pi/1048576) q[81];
cx q[100],q[81];
u1(pi/1048576) q[81];
u1(pi/524288) q[100];
cx q[100],q[82];
u1(-pi/524288) q[82];
cx q[100],q[82];
u1(pi/524288) q[82];
u1(pi/262144) q[100];
cx q[100],q[83];
u1(-pi/262144) q[83];
cx q[100],q[83];
u1(pi/262144) q[83];
u1(pi/131072) q[100];
cx q[100],q[84];
u1(-pi/131072) q[84];
cx q[100],q[84];
u1(pi/131072) q[84];
u1(pi/65536) q[100];
cx q[100],q[85];
u1(-pi/65536) q[85];
cx q[100],q[85];
u1(pi/65536) q[85];
u1(pi/32768) q[100];
cx q[100],q[86];
u1(-pi/32768) q[86];
cx q[100],q[86];
u1(pi/32768) q[86];
u1(pi/16384) q[100];
cx q[100],q[87];
u1(-pi/16384) q[87];
cx q[100],q[87];
u1(pi/16384) q[87];
u1(pi/8192) q[100];
cx q[100],q[88];
u1(-pi/8192) q[88];
cx q[100],q[88];
u1(pi/8192) q[88];
u1(pi/4096) q[100];
cx q[100],q[89];
u1(-pi/4096) q[89];
cx q[100],q[89];
u1(pi/4096) q[89];
u1(pi/2048) q[100];
cx q[100],q[90];
u1(-pi/2048) q[90];
cx q[100],q[90];
u1(pi/2048) q[90];
u1(pi/1024) q[100];
cx q[100],q[91];
u1(-pi/1024) q[91];
cx q[100],q[91];
u1(pi/1024) q[91];
u1(pi/512) q[100];
cx q[100],q[92];
u1(-pi/512) q[92];
cx q[100],q[92];
u1(pi/512) q[92];
u1(pi/256) q[100];
cx q[100],q[93];
u1(-pi/256) q[93];
cx q[100],q[93];
u1(pi/256) q[93];
u1(pi/128) q[100];
cx q[100],q[94];
u1(-pi/128) q[94];
cx q[100],q[94];
u1(pi/128) q[94];
u1(pi/64) q[100];
cx q[100],q[95];
u1(-pi/64) q[95];
cx q[100],q[95];
u1(pi/64) q[95];
u1(pi/32) q[100];
cx q[100],q[96];
u1(-pi/32) q[96];
cx q[100],q[96];
u1(pi/32) q[96];
u1(pi/16) q[100];
cx q[100],q[97];
u1(-pi/16) q[97];
cx q[100],q[97];
u1(pi/16) q[97];
u1(pi/8) q[100];
cx q[100],q[98];
u1(-pi/8) q[98];
cx q[100],q[98];
u1(pi/8) q[98];
u1(pi/4) q[100];
cx q[100],q[99];
u1(-pi/4) q[99];
cx q[100],q[99];
u1(pi/4) q[99];
h q[100];
u1(0) q[101];
cx q[101],q[0];
u1(0) q[0];
cx q[101],q[0];
u1(0) q[0];
u1(0) q[101];
cx q[101],q[1];
u1(0) q[1];
cx q[101],q[1];
u1(0) q[1];
u1(0) q[101];
cx q[101],q[2];
u1(0) q[2];
cx q[101],q[2];
u1(0) q[2];
u1(0) q[101];
cx q[101],q[3];
u1(0) q[3];
cx q[101],q[3];
u1(0) q[3];
u1(0) q[101];
cx q[101],q[4];
u1(0) q[4];
cx q[101],q[4];
u1(0) q[4];
u1(0) q[101];
cx q[101],q[5];
u1(0) q[5];
cx q[101],q[5];
u1(0) q[5];
u1(0) q[101];
cx q[101],q[6];
u1(0) q[6];
cx q[101],q[6];
u1(0) q[6];
u1(0) q[101];
cx q[101],q[7];
u1(0) q[7];
cx q[101],q[7];
u1(0) q[7];
u1(0) q[101];
cx q[101],q[8];
u1(0) q[8];
cx q[101],q[8];
u1(0) q[8];
u1(0) q[101];
cx q[101],q[9];
u1(0) q[9];
cx q[101],q[9];
u1(0) q[9];
u1(0) q[101];
cx q[101],q[10];
u1(0) q[10];
cx q[101],q[10];
u1(0) q[10];
u1(0) q[101];
cx q[101],q[11];
u1(0) q[11];
cx q[101],q[11];
u1(0) q[11];
u1(0) q[101];
cx q[101],q[12];
u1(0) q[12];
cx q[101],q[12];
u1(0) q[12];
u1(0) q[101];
cx q[101],q[13];
u1(0) q[13];
cx q[101],q[13];
u1(0) q[13];
u1(0) q[101];
cx q[101],q[14];
u1(0) q[14];
cx q[101],q[14];
u1(0) q[14];
u1(0) q[101];
cx q[101],q[15];
u1(0) q[15];
cx q[101],q[15];
u1(0) q[15];
u1(0) q[101];
cx q[101],q[16];
u1(0) q[16];
cx q[101],q[16];
u1(0) q[16];
u1(0) q[101];
cx q[101],q[17];
u1(0) q[17];
cx q[101],q[17];
u1(0) q[17];
u1(0) q[101];
cx q[101],q[18];
u1(0) q[18];
cx q[101],q[18];
u1(0) q[18];
u1(0) q[101];
cx q[101],q[19];
u1(0) q[19];
cx q[101],q[19];
u1(0) q[19];
u1(0) q[101];
cx q[101],q[20];
u1(0) q[20];
cx q[101],q[20];
u1(0) q[20];
u1(0) q[101];
cx q[101],q[21];
u1(0) q[21];
cx q[101],q[21];
u1(0) q[21];
u1(0) q[101];
cx q[101],q[22];
u1(0) q[22];
cx q[101],q[22];
u1(0) q[22];
u1(0) q[101];
cx q[101],q[23];
u1(0) q[23];
cx q[101],q[23];
u1(0) q[23];
u1(0) q[101];
cx q[101],q[24];
u1(0) q[24];
cx q[101],q[24];
u1(0) q[24];
u1(0) q[101];
cx q[101],q[25];
u1(0) q[25];
cx q[101],q[25];
u1(0) q[25];
u1(0) q[101];
cx q[101],q[26];
u1(0) q[26];
cx q[101],q[26];
u1(0) q[26];
u1(0) q[101];
cx q[101],q[27];
u1(0) q[27];
cx q[101],q[27];
u1(0) q[27];
u1(0) q[101];
cx q[101],q[28];
u1(0) q[28];
cx q[101],q[28];
u1(0) q[28];
u1(0) q[101];
cx q[101],q[29];
u1(0) q[29];
cx q[101],q[29];
u1(0) q[29];
u1(0) q[101];
cx q[101],q[30];
u1(0) q[30];
cx q[101],q[30];
u1(0) q[30];
u1(0) q[101];
cx q[101],q[31];
u1(0) q[31];
cx q[101],q[31];
u1(0) q[31];
u1(0) q[101];
cx q[101],q[32];
u1(0) q[32];
cx q[101],q[32];
u1(0) q[32];
u1(0) q[101];
cx q[101],q[33];
u1(0) q[33];
cx q[101],q[33];
u1(0) q[33];
u1(0) q[101];
cx q[101],q[34];
u1(0) q[34];
cx q[101],q[34];
u1(0) q[34];
u1(0) q[101];
cx q[101],q[35];
u1(0) q[35];
cx q[101],q[35];
u1(0) q[35];
u1(0) q[101];
cx q[101],q[36];
u1(0) q[36];
cx q[101],q[36];
u1(0) q[36];
u1(0) q[101];
cx q[101],q[37];
u1(0) q[37];
cx q[101],q[37];
u1(0) q[37];
u1(0) q[101];
cx q[101],q[38];
u1(0) q[38];
cx q[101],q[38];
u1(0) q[38];
u1(0) q[101];
cx q[101],q[39];
u1(0) q[39];
cx q[101],q[39];
u1(0) q[39];
u1(0) q[101];
cx q[101],q[40];
u1(0) q[40];
cx q[101],q[40];
u1(0) q[40];
u1(0) q[101];
cx q[101],q[41];
u1(0) q[41];
cx q[101],q[41];
u1(0) q[41];
u1(0) q[101];
cx q[101],q[42];
u1(0) q[42];
cx q[101],q[42];
u1(0) q[42];
u1(0) q[101];
cx q[101],q[43];
u1(0) q[43];
cx q[101],q[43];
u1(0) q[43];
u1(0) q[101];
cx q[101],q[44];
u1(0) q[44];
cx q[101],q[44];
u1(0) q[44];
u1(0) q[101];
cx q[101],q[45];
u1(0) q[45];
cx q[101],q[45];
u1(0) q[45];
u1(0) q[101];
cx q[101],q[46];
u1(0) q[46];
cx q[101],q[46];
u1(0) q[46];
u1(0) q[101];
cx q[101],q[47];
u1(0) q[47];
cx q[101],q[47];
u1(0) q[47];
u1(0) q[101];
cx q[101],q[48];
u1(0) q[48];
cx q[101],q[48];
u1(0) q[48];
u1(0) q[101];
cx q[101],q[49];
u1(0) q[49];
cx q[101],q[49];
u1(0) q[49];
u1(0) q[101];
cx q[101],q[50];
u1(0) q[50];
cx q[101],q[50];
u1(0) q[50];
u1(0) q[101];
cx q[101],q[51];
u1(0) q[51];
cx q[101],q[51];
u1(0) q[51];
u1(0) q[101];
cx q[101],q[52];
u1(0) q[52];
cx q[101],q[52];
u1(0) q[52];
u1(0) q[101];
cx q[101],q[53];
u1(0) q[53];
cx q[101],q[53];
u1(0) q[53];
u1(pi/281474976710656) q[101];
cx q[101],q[54];
u1(-pi/281474976710656) q[54];
cx q[101],q[54];
u1(pi/281474976710656) q[54];
u1(pi/140737488355328) q[101];
cx q[101],q[55];
u1(-pi/140737488355328) q[55];
cx q[101],q[55];
u1(pi/140737488355328) q[55];
u1(pi/70368744177664) q[101];
cx q[101],q[56];
u1(-pi/70368744177664) q[56];
cx q[101],q[56];
u1(pi/70368744177664) q[56];
u1(pi/35184372088832) q[101];
cx q[101],q[57];
u1(-pi/35184372088832) q[57];
cx q[101],q[57];
u1(pi/35184372088832) q[57];
u1(pi/17592186044416) q[101];
cx q[101],q[58];
u1(-pi/17592186044416) q[58];
cx q[101],q[58];
u1(pi/17592186044416) q[58];
u1(pi/8796093022208) q[101];
cx q[101],q[59];
u1(-pi/8796093022208) q[59];
cx q[101],q[59];
u1(pi/8796093022208) q[59];
u1(pi/4398046511104) q[101];
cx q[101],q[60];
u1(-pi/4398046511104) q[60];
cx q[101],q[60];
u1(pi/4398046511104) q[60];
u1(pi/2199023255552) q[101];
cx q[101],q[61];
u1(-pi/2199023255552) q[61];
cx q[101],q[61];
u1(pi/2199023255552) q[61];
u1(pi/1099511627776) q[101];
cx q[101],q[62];
u1(-pi/1099511627776) q[62];
cx q[101],q[62];
u1(pi/1099511627776) q[62];
u1(pi/549755813888) q[101];
cx q[101],q[63];
u1(-pi/549755813888) q[63];
cx q[101],q[63];
u1(pi/549755813888) q[63];
u1(pi/274877906944) q[101];
cx q[101],q[64];
u1(-pi/274877906944) q[64];
cx q[101],q[64];
u1(pi/274877906944) q[64];
u1(pi/137438953472) q[101];
cx q[101],q[65];
u1(-pi/137438953472) q[65];
cx q[101],q[65];
u1(pi/137438953472) q[65];
u1(pi/68719476736) q[101];
cx q[101],q[66];
u1(-pi/68719476736) q[66];
cx q[101],q[66];
u1(pi/68719476736) q[66];
u1(pi/34359738368) q[101];
cx q[101],q[67];
u1(-pi/34359738368) q[67];
cx q[101],q[67];
u1(pi/34359738368) q[67];
u1(pi/17179869184) q[101];
cx q[101],q[68];
u1(-pi/17179869184) q[68];
cx q[101],q[68];
u1(pi/17179869184) q[68];
u1(pi/8589934592) q[101];
cx q[101],q[69];
u1(-pi/8589934592) q[69];
cx q[101],q[69];
u1(pi/8589934592) q[69];
u1(pi/4294967296) q[101];
cx q[101],q[70];
u1(-pi/4294967296) q[70];
cx q[101],q[70];
u1(pi/4294967296) q[70];
u1(pi/2147483648) q[101];
cx q[101],q[71];
u1(-pi/2147483648) q[71];
cx q[101],q[71];
u1(pi/2147483648) q[71];
u1(pi/1073741824) q[101];
cx q[101],q[72];
u1(-pi/1073741824) q[72];
cx q[101],q[72];
u1(pi/1073741824) q[72];
u1(pi/536870912) q[101];
cx q[101],q[73];
u1(-pi/536870912) q[73];
cx q[101],q[73];
u1(pi/536870912) q[73];
u1(pi/268435456) q[101];
cx q[101],q[74];
u1(-pi/268435456) q[74];
cx q[101],q[74];
u1(pi/268435456) q[74];
u1(pi/134217728) q[101];
cx q[101],q[75];
u1(-pi/134217728) q[75];
cx q[101],q[75];
u1(pi/134217728) q[75];
u1(pi/67108864) q[101];
cx q[101],q[76];
u1(-pi/67108864) q[76];
cx q[101],q[76];
u1(pi/67108864) q[76];
u1(pi/33554432) q[101];
cx q[101],q[77];
u1(-pi/33554432) q[77];
cx q[101],q[77];
u1(pi/33554432) q[77];
u1(pi/16777216) q[101];
cx q[101],q[78];
u1(-pi/16777216) q[78];
cx q[101],q[78];
u1(pi/16777216) q[78];
u1(pi/8388608) q[101];
cx q[101],q[79];
u1(-pi/8388608) q[79];
cx q[101],q[79];
u1(pi/8388608) q[79];
u1(pi/4194304) q[101];
cx q[101],q[80];
u1(-pi/4194304) q[80];
cx q[101],q[80];
u1(pi/4194304) q[80];
u1(pi/2097152) q[101];
cx q[101],q[81];
u1(-pi/2097152) q[81];
cx q[101],q[81];
u1(pi/2097152) q[81];
u1(pi/1048576) q[101];
cx q[101],q[82];
u1(-pi/1048576) q[82];
cx q[101],q[82];
u1(pi/1048576) q[82];
u1(pi/524288) q[101];
cx q[101],q[83];
u1(-pi/524288) q[83];
cx q[101],q[83];
u1(pi/524288) q[83];
u1(pi/262144) q[101];
cx q[101],q[84];
u1(-pi/262144) q[84];
cx q[101],q[84];
u1(pi/262144) q[84];
u1(pi/131072) q[101];
cx q[101],q[85];
u1(-pi/131072) q[85];
cx q[101],q[85];
u1(pi/131072) q[85];
u1(pi/65536) q[101];
cx q[101],q[86];
u1(-pi/65536) q[86];
cx q[101],q[86];
u1(pi/65536) q[86];
u1(pi/32768) q[101];
cx q[101],q[87];
u1(-pi/32768) q[87];
cx q[101],q[87];
u1(pi/32768) q[87];
u1(pi/16384) q[101];
cx q[101],q[88];
u1(-pi/16384) q[88];
cx q[101],q[88];
u1(pi/16384) q[88];
u1(pi/8192) q[101];
cx q[101],q[89];
u1(-pi/8192) q[89];
cx q[101],q[89];
u1(pi/8192) q[89];
u1(pi/4096) q[101];
cx q[101],q[90];
u1(-pi/4096) q[90];
cx q[101],q[90];
u1(pi/4096) q[90];
u1(pi/2048) q[101];
cx q[101],q[91];
u1(-pi/2048) q[91];
cx q[101],q[91];
u1(pi/2048) q[91];
u1(pi/1024) q[101];
cx q[101],q[92];
u1(-pi/1024) q[92];
cx q[101],q[92];
u1(pi/1024) q[92];
u1(pi/512) q[101];
cx q[101],q[93];
u1(-pi/512) q[93];
cx q[101],q[93];
u1(pi/512) q[93];
u1(pi/256) q[101];
cx q[101],q[94];
u1(-pi/256) q[94];
cx q[101],q[94];
u1(pi/256) q[94];
u1(pi/128) q[101];
cx q[101],q[95];
u1(-pi/128) q[95];
cx q[101],q[95];
u1(pi/128) q[95];
u1(pi/64) q[101];
cx q[101],q[96];
u1(-pi/64) q[96];
cx q[101],q[96];
u1(pi/64) q[96];
u1(pi/32) q[101];
cx q[101],q[97];
u1(-pi/32) q[97];
cx q[101],q[97];
u1(pi/32) q[97];
u1(pi/16) q[101];
cx q[101],q[98];
u1(-pi/16) q[98];
cx q[101],q[98];
u1(pi/16) q[98];
u1(pi/8) q[101];
cx q[101],q[99];
u1(-pi/8) q[99];
cx q[101],q[99];
u1(pi/8) q[99];
u1(pi/4) q[101];
cx q[101],q[100];
u1(-pi/4) q[100];
cx q[101],q[100];
u1(pi/4) q[100];
h q[101];
u1(0) q[102];
cx q[102],q[0];
u1(0) q[0];
cx q[102],q[0];
u1(0) q[0];
u1(0) q[102];
cx q[102],q[1];
u1(0) q[1];
cx q[102],q[1];
u1(0) q[1];
u1(0) q[102];
cx q[102],q[2];
u1(0) q[2];
cx q[102],q[2];
u1(0) q[2];
u1(0) q[102];
cx q[102],q[3];
u1(0) q[3];
cx q[102],q[3];
u1(0) q[3];
u1(0) q[102];
cx q[102],q[4];
u1(0) q[4];
cx q[102],q[4];
u1(0) q[4];
u1(0) q[102];
cx q[102],q[5];
u1(0) q[5];
cx q[102],q[5];
u1(0) q[5];
u1(0) q[102];
cx q[102],q[6];
u1(0) q[6];
cx q[102],q[6];
u1(0) q[6];
u1(0) q[102];
cx q[102],q[7];
u1(0) q[7];
cx q[102],q[7];
u1(0) q[7];
u1(0) q[102];
cx q[102],q[8];
u1(0) q[8];
cx q[102],q[8];
u1(0) q[8];
u1(0) q[102];
cx q[102],q[9];
u1(0) q[9];
cx q[102],q[9];
u1(0) q[9];
u1(0) q[102];
cx q[102],q[10];
u1(0) q[10];
cx q[102],q[10];
u1(0) q[10];
u1(0) q[102];
cx q[102],q[11];
u1(0) q[11];
cx q[102],q[11];
u1(0) q[11];
u1(0) q[102];
cx q[102],q[12];
u1(0) q[12];
cx q[102],q[12];
u1(0) q[12];
u1(0) q[102];
cx q[102],q[13];
u1(0) q[13];
cx q[102],q[13];
u1(0) q[13];
u1(0) q[102];
cx q[102],q[14];
u1(0) q[14];
cx q[102],q[14];
u1(0) q[14];
u1(0) q[102];
cx q[102],q[15];
u1(0) q[15];
cx q[102],q[15];
u1(0) q[15];
u1(0) q[102];
cx q[102],q[16];
u1(0) q[16];
cx q[102],q[16];
u1(0) q[16];
u1(0) q[102];
cx q[102],q[17];
u1(0) q[17];
cx q[102],q[17];
u1(0) q[17];
u1(0) q[102];
cx q[102],q[18];
u1(0) q[18];
cx q[102],q[18];
u1(0) q[18];
u1(0) q[102];
cx q[102],q[19];
u1(0) q[19];
cx q[102],q[19];
u1(0) q[19];
u1(0) q[102];
cx q[102],q[20];
u1(0) q[20];
cx q[102],q[20];
u1(0) q[20];
u1(0) q[102];
cx q[102],q[21];
u1(0) q[21];
cx q[102],q[21];
u1(0) q[21];
u1(0) q[102];
cx q[102],q[22];
u1(0) q[22];
cx q[102],q[22];
u1(0) q[22];
u1(0) q[102];
cx q[102],q[23];
u1(0) q[23];
cx q[102],q[23];
u1(0) q[23];
u1(0) q[102];
cx q[102],q[24];
u1(0) q[24];
cx q[102],q[24];
u1(0) q[24];
u1(0) q[102];
cx q[102],q[25];
u1(0) q[25];
cx q[102],q[25];
u1(0) q[25];
u1(0) q[102];
cx q[102],q[26];
u1(0) q[26];
cx q[102],q[26];
u1(0) q[26];
u1(0) q[102];
cx q[102],q[27];
u1(0) q[27];
cx q[102],q[27];
u1(0) q[27];
u1(0) q[102];
cx q[102],q[28];
u1(0) q[28];
cx q[102],q[28];
u1(0) q[28];
u1(0) q[102];
cx q[102],q[29];
u1(0) q[29];
cx q[102],q[29];
u1(0) q[29];
u1(0) q[102];
cx q[102],q[30];
u1(0) q[30];
cx q[102],q[30];
u1(0) q[30];
u1(0) q[102];
cx q[102],q[31];
u1(0) q[31];
cx q[102],q[31];
u1(0) q[31];
u1(0) q[102];
cx q[102],q[32];
u1(0) q[32];
cx q[102],q[32];
u1(0) q[32];
u1(0) q[102];
cx q[102],q[33];
u1(0) q[33];
cx q[102],q[33];
u1(0) q[33];
u1(0) q[102];
cx q[102],q[34];
u1(0) q[34];
cx q[102],q[34];
u1(0) q[34];
u1(0) q[102];
cx q[102],q[35];
u1(0) q[35];
cx q[102],q[35];
u1(0) q[35];
u1(0) q[102];
cx q[102],q[36];
u1(0) q[36];
cx q[102],q[36];
u1(0) q[36];
u1(0) q[102];
cx q[102],q[37];
u1(0) q[37];
cx q[102],q[37];
u1(0) q[37];
u1(0) q[102];
cx q[102],q[38];
u1(0) q[38];
cx q[102],q[38];
u1(0) q[38];
u1(0) q[102];
cx q[102],q[39];
u1(0) q[39];
cx q[102],q[39];
u1(0) q[39];
u1(0) q[102];
cx q[102],q[40];
u1(0) q[40];
cx q[102],q[40];
u1(0) q[40];
u1(0) q[102];
cx q[102],q[41];
u1(0) q[41];
cx q[102],q[41];
u1(0) q[41];
u1(0) q[102];
cx q[102],q[42];
u1(0) q[42];
cx q[102],q[42];
u1(0) q[42];
u1(0) q[102];
cx q[102],q[43];
u1(0) q[43];
cx q[102],q[43];
u1(0) q[43];
u1(0) q[102];
cx q[102],q[44];
u1(0) q[44];
cx q[102],q[44];
u1(0) q[44];
u1(0) q[102];
cx q[102],q[45];
u1(0) q[45];
cx q[102],q[45];
u1(0) q[45];
u1(0) q[102];
cx q[102],q[46];
u1(0) q[46];
cx q[102],q[46];
u1(0) q[46];
u1(0) q[102];
cx q[102],q[47];
u1(0) q[47];
cx q[102],q[47];
u1(0) q[47];
u1(0) q[102];
cx q[102],q[48];
u1(0) q[48];
cx q[102],q[48];
u1(0) q[48];
u1(0) q[102];
cx q[102],q[49];
u1(0) q[49];
cx q[102],q[49];
u1(0) q[49];
u1(0) q[102];
cx q[102],q[50];
u1(0) q[50];
cx q[102],q[50];
u1(0) q[50];
u1(0) q[102];
cx q[102],q[51];
u1(0) q[51];
cx q[102],q[51];
u1(0) q[51];
u1(0) q[102];
cx q[102],q[52];
u1(0) q[52];
cx q[102],q[52];
u1(0) q[52];
u1(0) q[102];
cx q[102],q[53];
u1(0) q[53];
cx q[102],q[53];
u1(0) q[53];
u1(0) q[102];
cx q[102],q[54];
u1(0) q[54];
cx q[102],q[54];
u1(0) q[54];
u1(pi/281474976710656) q[102];
cx q[102],q[55];
u1(-pi/281474976710656) q[55];
cx q[102],q[55];
u1(pi/281474976710656) q[55];
u1(pi/140737488355328) q[102];
cx q[102],q[56];
u1(-pi/140737488355328) q[56];
cx q[102],q[56];
u1(pi/140737488355328) q[56];
u1(pi/70368744177664) q[102];
cx q[102],q[57];
u1(-pi/70368744177664) q[57];
cx q[102],q[57];
u1(pi/70368744177664) q[57];
u1(pi/35184372088832) q[102];
cx q[102],q[58];
u1(-pi/35184372088832) q[58];
cx q[102],q[58];
u1(pi/35184372088832) q[58];
u1(pi/17592186044416) q[102];
cx q[102],q[59];
u1(-pi/17592186044416) q[59];
cx q[102],q[59];
u1(pi/17592186044416) q[59];
u1(pi/8796093022208) q[102];
cx q[102],q[60];
u1(-pi/8796093022208) q[60];
cx q[102],q[60];
u1(pi/8796093022208) q[60];
u1(pi/4398046511104) q[102];
cx q[102],q[61];
u1(-pi/4398046511104) q[61];
cx q[102],q[61];
u1(pi/4398046511104) q[61];
u1(pi/2199023255552) q[102];
cx q[102],q[62];
u1(-pi/2199023255552) q[62];
cx q[102],q[62];
u1(pi/2199023255552) q[62];
u1(pi/1099511627776) q[102];
cx q[102],q[63];
u1(-pi/1099511627776) q[63];
cx q[102],q[63];
u1(pi/1099511627776) q[63];
u1(pi/549755813888) q[102];
cx q[102],q[64];
u1(-pi/549755813888) q[64];
cx q[102],q[64];
u1(pi/549755813888) q[64];
u1(pi/274877906944) q[102];
cx q[102],q[65];
u1(-pi/274877906944) q[65];
cx q[102],q[65];
u1(pi/274877906944) q[65];
u1(pi/137438953472) q[102];
cx q[102],q[66];
u1(-pi/137438953472) q[66];
cx q[102],q[66];
u1(pi/137438953472) q[66];
u1(pi/68719476736) q[102];
cx q[102],q[67];
u1(-pi/68719476736) q[67];
cx q[102],q[67];
u1(pi/68719476736) q[67];
u1(pi/34359738368) q[102];
cx q[102],q[68];
u1(-pi/34359738368) q[68];
cx q[102],q[68];
u1(pi/34359738368) q[68];
u1(pi/17179869184) q[102];
cx q[102],q[69];
u1(-pi/17179869184) q[69];
cx q[102],q[69];
u1(pi/17179869184) q[69];
u1(pi/8589934592) q[102];
cx q[102],q[70];
u1(-pi/8589934592) q[70];
cx q[102],q[70];
u1(pi/8589934592) q[70];
u1(pi/4294967296) q[102];
cx q[102],q[71];
u1(-pi/4294967296) q[71];
cx q[102],q[71];
u1(pi/4294967296) q[71];
u1(pi/2147483648) q[102];
cx q[102],q[72];
u1(-pi/2147483648) q[72];
cx q[102],q[72];
u1(pi/2147483648) q[72];
u1(pi/1073741824) q[102];
cx q[102],q[73];
u1(-pi/1073741824) q[73];
cx q[102],q[73];
u1(pi/1073741824) q[73];
u1(pi/536870912) q[102];
cx q[102],q[74];
u1(-pi/536870912) q[74];
cx q[102],q[74];
u1(pi/536870912) q[74];
u1(pi/268435456) q[102];
cx q[102],q[75];
u1(-pi/268435456) q[75];
cx q[102],q[75];
u1(pi/268435456) q[75];
u1(pi/134217728) q[102];
cx q[102],q[76];
u1(-pi/134217728) q[76];
cx q[102],q[76];
u1(pi/134217728) q[76];
u1(pi/67108864) q[102];
cx q[102],q[77];
u1(-pi/67108864) q[77];
cx q[102],q[77];
u1(pi/67108864) q[77];
u1(pi/33554432) q[102];
cx q[102],q[78];
u1(-pi/33554432) q[78];
cx q[102],q[78];
u1(pi/33554432) q[78];
u1(pi/16777216) q[102];
cx q[102],q[79];
u1(-pi/16777216) q[79];
cx q[102],q[79];
u1(pi/16777216) q[79];
u1(pi/8388608) q[102];
cx q[102],q[80];
u1(-pi/8388608) q[80];
cx q[102],q[80];
u1(pi/8388608) q[80];
u1(pi/4194304) q[102];
cx q[102],q[81];
u1(-pi/4194304) q[81];
cx q[102],q[81];
u1(pi/4194304) q[81];
u1(pi/2097152) q[102];
cx q[102],q[82];
u1(-pi/2097152) q[82];
cx q[102],q[82];
u1(pi/2097152) q[82];
u1(pi/1048576) q[102];
cx q[102],q[83];
u1(-pi/1048576) q[83];
cx q[102],q[83];
u1(pi/1048576) q[83];
u1(pi/524288) q[102];
cx q[102],q[84];
u1(-pi/524288) q[84];
cx q[102],q[84];
u1(pi/524288) q[84];
u1(pi/262144) q[102];
cx q[102],q[85];
u1(-pi/262144) q[85];
cx q[102],q[85];
u1(pi/262144) q[85];
u1(pi/131072) q[102];
cx q[102],q[86];
u1(-pi/131072) q[86];
cx q[102],q[86];
u1(pi/131072) q[86];
u1(pi/65536) q[102];
cx q[102],q[87];
u1(-pi/65536) q[87];
cx q[102],q[87];
u1(pi/65536) q[87];
u1(pi/32768) q[102];
cx q[102],q[88];
u1(-pi/32768) q[88];
cx q[102],q[88];
u1(pi/32768) q[88];
u1(pi/16384) q[102];
cx q[102],q[89];
u1(-pi/16384) q[89];
cx q[102],q[89];
u1(pi/16384) q[89];
u1(pi/8192) q[102];
cx q[102],q[90];
u1(-pi/8192) q[90];
cx q[102],q[90];
u1(pi/8192) q[90];
u1(pi/4096) q[102];
cx q[102],q[91];
u1(-pi/4096) q[91];
cx q[102],q[91];
u1(pi/4096) q[91];
u1(pi/2048) q[102];
cx q[102],q[92];
u1(-pi/2048) q[92];
cx q[102],q[92];
u1(pi/2048) q[92];
u1(pi/1024) q[102];
cx q[102],q[93];
u1(-pi/1024) q[93];
cx q[102],q[93];
u1(pi/1024) q[93];
u1(pi/512) q[102];
cx q[102],q[94];
u1(-pi/512) q[94];
cx q[102],q[94];
u1(pi/512) q[94];
u1(pi/256) q[102];
cx q[102],q[95];
u1(-pi/256) q[95];
cx q[102],q[95];
u1(pi/256) q[95];
u1(pi/128) q[102];
cx q[102],q[96];
u1(-pi/128) q[96];
cx q[102],q[96];
u1(pi/128) q[96];
u1(pi/64) q[102];
cx q[102],q[97];
u1(-pi/64) q[97];
cx q[102],q[97];
u1(pi/64) q[97];
u1(pi/32) q[102];
cx q[102],q[98];
u1(-pi/32) q[98];
cx q[102],q[98];
u1(pi/32) q[98];
u1(pi/16) q[102];
cx q[102],q[99];
u1(-pi/16) q[99];
cx q[102],q[99];
u1(pi/16) q[99];
u1(pi/8) q[102];
cx q[102],q[100];
u1(-pi/8) q[100];
cx q[102],q[100];
u1(pi/8) q[100];
u1(pi/4) q[102];
cx q[102],q[101];
u1(-pi/4) q[101];
cx q[102],q[101];
u1(pi/4) q[101];
h q[102];
u1(0) q[103];
cx q[103],q[0];
u1(0) q[0];
cx q[103],q[0];
u1(0) q[0];
u1(0) q[103];
cx q[103],q[1];
u1(0) q[1];
cx q[103],q[1];
u1(0) q[1];
u1(0) q[103];
cx q[103],q[2];
u1(0) q[2];
cx q[103],q[2];
u1(0) q[2];
u1(0) q[103];
cx q[103],q[3];
u1(0) q[3];
cx q[103],q[3];
u1(0) q[3];
u1(0) q[103];
cx q[103],q[4];
u1(0) q[4];
cx q[103],q[4];
u1(0) q[4];
u1(0) q[103];
cx q[103],q[5];
u1(0) q[5];
cx q[103],q[5];
u1(0) q[5];
u1(0) q[103];
cx q[103],q[6];
u1(0) q[6];
cx q[103],q[6];
u1(0) q[6];
u1(0) q[103];
cx q[103],q[7];
u1(0) q[7];
cx q[103],q[7];
u1(0) q[7];
u1(0) q[103];
cx q[103],q[8];
u1(0) q[8];
cx q[103],q[8];
u1(0) q[8];
u1(0) q[103];
cx q[103],q[9];
u1(0) q[9];
cx q[103],q[9];
u1(0) q[9];
u1(0) q[103];
cx q[103],q[10];
u1(0) q[10];
cx q[103],q[10];
u1(0) q[10];
u1(0) q[103];
cx q[103],q[11];
u1(0) q[11];
cx q[103],q[11];
u1(0) q[11];
u1(0) q[103];
cx q[103],q[12];
u1(0) q[12];
cx q[103],q[12];
u1(0) q[12];
u1(0) q[103];
cx q[103],q[13];
u1(0) q[13];
cx q[103],q[13];
u1(0) q[13];
u1(0) q[103];
cx q[103],q[14];
u1(0) q[14];
cx q[103],q[14];
u1(0) q[14];
u1(0) q[103];
cx q[103],q[15];
u1(0) q[15];
cx q[103],q[15];
u1(0) q[15];
u1(0) q[103];
cx q[103],q[16];
u1(0) q[16];
cx q[103],q[16];
u1(0) q[16];
u1(0) q[103];
cx q[103],q[17];
u1(0) q[17];
cx q[103],q[17];
u1(0) q[17];
u1(0) q[103];
cx q[103],q[18];
u1(0) q[18];
cx q[103],q[18];
u1(0) q[18];
u1(0) q[103];
cx q[103],q[19];
u1(0) q[19];
cx q[103],q[19];
u1(0) q[19];
u1(0) q[103];
cx q[103],q[20];
u1(0) q[20];
cx q[103],q[20];
u1(0) q[20];
u1(0) q[103];
cx q[103],q[21];
u1(0) q[21];
cx q[103],q[21];
u1(0) q[21];
u1(0) q[103];
cx q[103],q[22];
u1(0) q[22];
cx q[103],q[22];
u1(0) q[22];
u1(0) q[103];
cx q[103],q[23];
u1(0) q[23];
cx q[103],q[23];
u1(0) q[23];
u1(0) q[103];
cx q[103],q[24];
u1(0) q[24];
cx q[103],q[24];
u1(0) q[24];
u1(0) q[103];
cx q[103],q[25];
u1(0) q[25];
cx q[103],q[25];
u1(0) q[25];
u1(0) q[103];
cx q[103],q[26];
u1(0) q[26];
cx q[103],q[26];
u1(0) q[26];
u1(0) q[103];
cx q[103],q[27];
u1(0) q[27];
cx q[103],q[27];
u1(0) q[27];
u1(0) q[103];
cx q[103],q[28];
u1(0) q[28];
cx q[103],q[28];
u1(0) q[28];
u1(0) q[103];
cx q[103],q[29];
u1(0) q[29];
cx q[103],q[29];
u1(0) q[29];
u1(0) q[103];
cx q[103],q[30];
u1(0) q[30];
cx q[103],q[30];
u1(0) q[30];
u1(0) q[103];
cx q[103],q[31];
u1(0) q[31];
cx q[103],q[31];
u1(0) q[31];
u1(0) q[103];
cx q[103],q[32];
u1(0) q[32];
cx q[103],q[32];
u1(0) q[32];
u1(0) q[103];
cx q[103],q[33];
u1(0) q[33];
cx q[103],q[33];
u1(0) q[33];
u1(0) q[103];
cx q[103],q[34];
u1(0) q[34];
cx q[103],q[34];
u1(0) q[34];
u1(0) q[103];
cx q[103],q[35];
u1(0) q[35];
cx q[103],q[35];
u1(0) q[35];
u1(0) q[103];
cx q[103],q[36];
u1(0) q[36];
cx q[103],q[36];
u1(0) q[36];
u1(0) q[103];
cx q[103],q[37];
u1(0) q[37];
cx q[103],q[37];
u1(0) q[37];
u1(0) q[103];
cx q[103],q[38];
u1(0) q[38];
cx q[103],q[38];
u1(0) q[38];
u1(0) q[103];
cx q[103],q[39];
u1(0) q[39];
cx q[103],q[39];
u1(0) q[39];
u1(0) q[103];
cx q[103],q[40];
u1(0) q[40];
cx q[103],q[40];
u1(0) q[40];
u1(0) q[103];
cx q[103],q[41];
u1(0) q[41];
cx q[103],q[41];
u1(0) q[41];
u1(0) q[103];
cx q[103],q[42];
u1(0) q[42];
cx q[103],q[42];
u1(0) q[42];
u1(0) q[103];
cx q[103],q[43];
u1(0) q[43];
cx q[103],q[43];
u1(0) q[43];
u1(0) q[103];
cx q[103],q[44];
u1(0) q[44];
cx q[103],q[44];
u1(0) q[44];
u1(0) q[103];
cx q[103],q[45];
u1(0) q[45];
cx q[103],q[45];
u1(0) q[45];
u1(0) q[103];
cx q[103],q[46];
u1(0) q[46];
cx q[103],q[46];
u1(0) q[46];
u1(0) q[103];
cx q[103],q[47];
u1(0) q[47];
cx q[103],q[47];
u1(0) q[47];
u1(0) q[103];
cx q[103],q[48];
u1(0) q[48];
cx q[103],q[48];
u1(0) q[48];
u1(0) q[103];
cx q[103],q[49];
u1(0) q[49];
cx q[103],q[49];
u1(0) q[49];
u1(0) q[103];
cx q[103],q[50];
u1(0) q[50];
cx q[103],q[50];
u1(0) q[50];
u1(0) q[103];
cx q[103],q[51];
u1(0) q[51];
cx q[103],q[51];
u1(0) q[51];
u1(0) q[103];
cx q[103],q[52];
u1(0) q[52];
cx q[103],q[52];
u1(0) q[52];
u1(0) q[103];
cx q[103],q[53];
u1(0) q[53];
cx q[103],q[53];
u1(0) q[53];
u1(0) q[103];
cx q[103],q[54];
u1(0) q[54];
cx q[103],q[54];
u1(0) q[54];
u1(0) q[103];
cx q[103],q[55];
u1(0) q[55];
cx q[103],q[55];
u1(0) q[55];
u1(pi/281474976710656) q[103];
cx q[103],q[56];
u1(-pi/281474976710656) q[56];
cx q[103],q[56];
u1(pi/281474976710656) q[56];
u1(pi/140737488355328) q[103];
cx q[103],q[57];
u1(-pi/140737488355328) q[57];
cx q[103],q[57];
u1(pi/140737488355328) q[57];
u1(pi/70368744177664) q[103];
cx q[103],q[58];
u1(-pi/70368744177664) q[58];
cx q[103],q[58];
u1(pi/70368744177664) q[58];
u1(pi/35184372088832) q[103];
cx q[103],q[59];
u1(-pi/35184372088832) q[59];
cx q[103],q[59];
u1(pi/35184372088832) q[59];
u1(pi/17592186044416) q[103];
cx q[103],q[60];
u1(-pi/17592186044416) q[60];
cx q[103],q[60];
u1(pi/17592186044416) q[60];
u1(pi/8796093022208) q[103];
cx q[103],q[61];
u1(-pi/8796093022208) q[61];
cx q[103],q[61];
u1(pi/8796093022208) q[61];
u1(pi/4398046511104) q[103];
cx q[103],q[62];
u1(-pi/4398046511104) q[62];
cx q[103],q[62];
u1(pi/4398046511104) q[62];
u1(pi/2199023255552) q[103];
cx q[103],q[63];
u1(-pi/2199023255552) q[63];
cx q[103],q[63];
u1(pi/2199023255552) q[63];
u1(pi/1099511627776) q[103];
cx q[103],q[64];
u1(-pi/1099511627776) q[64];
cx q[103],q[64];
u1(pi/1099511627776) q[64];
u1(pi/549755813888) q[103];
cx q[103],q[65];
u1(-pi/549755813888) q[65];
cx q[103],q[65];
u1(pi/549755813888) q[65];
u1(pi/274877906944) q[103];
cx q[103],q[66];
u1(-pi/274877906944) q[66];
cx q[103],q[66];
u1(pi/274877906944) q[66];
u1(pi/137438953472) q[103];
cx q[103],q[67];
u1(-pi/137438953472) q[67];
cx q[103],q[67];
u1(pi/137438953472) q[67];
u1(pi/68719476736) q[103];
cx q[103],q[68];
u1(-pi/68719476736) q[68];
cx q[103],q[68];
u1(pi/68719476736) q[68];
u1(pi/34359738368) q[103];
cx q[103],q[69];
u1(-pi/34359738368) q[69];
cx q[103],q[69];
u1(pi/34359738368) q[69];
u1(pi/17179869184) q[103];
cx q[103],q[70];
u1(-pi/17179869184) q[70];
cx q[103],q[70];
u1(pi/17179869184) q[70];
u1(pi/8589934592) q[103];
cx q[103],q[71];
u1(-pi/8589934592) q[71];
cx q[103],q[71];
u1(pi/8589934592) q[71];
u1(pi/4294967296) q[103];
cx q[103],q[72];
u1(-pi/4294967296) q[72];
cx q[103],q[72];
u1(pi/4294967296) q[72];
u1(pi/2147483648) q[103];
cx q[103],q[73];
u1(-pi/2147483648) q[73];
cx q[103],q[73];
u1(pi/2147483648) q[73];
u1(pi/1073741824) q[103];
cx q[103],q[74];
u1(-pi/1073741824) q[74];
cx q[103],q[74];
u1(pi/1073741824) q[74];
u1(pi/536870912) q[103];
cx q[103],q[75];
u1(-pi/536870912) q[75];
cx q[103],q[75];
u1(pi/536870912) q[75];
u1(pi/268435456) q[103];
cx q[103],q[76];
u1(-pi/268435456) q[76];
cx q[103],q[76];
u1(pi/268435456) q[76];
u1(pi/134217728) q[103];
cx q[103],q[77];
u1(-pi/134217728) q[77];
cx q[103],q[77];
u1(pi/134217728) q[77];
u1(pi/67108864) q[103];
cx q[103],q[78];
u1(-pi/67108864) q[78];
cx q[103],q[78];
u1(pi/67108864) q[78];
u1(pi/33554432) q[103];
cx q[103],q[79];
u1(-pi/33554432) q[79];
cx q[103],q[79];
u1(pi/33554432) q[79];
u1(pi/16777216) q[103];
cx q[103],q[80];
u1(-pi/16777216) q[80];
cx q[103],q[80];
u1(pi/16777216) q[80];
u1(pi/8388608) q[103];
cx q[103],q[81];
u1(-pi/8388608) q[81];
cx q[103],q[81];
u1(pi/8388608) q[81];
u1(pi/4194304) q[103];
cx q[103],q[82];
u1(-pi/4194304) q[82];
cx q[103],q[82];
u1(pi/4194304) q[82];
u1(pi/2097152) q[103];
cx q[103],q[83];
u1(-pi/2097152) q[83];
cx q[103],q[83];
u1(pi/2097152) q[83];
u1(pi/1048576) q[103];
cx q[103],q[84];
u1(-pi/1048576) q[84];
cx q[103],q[84];
u1(pi/1048576) q[84];
u1(pi/524288) q[103];
cx q[103],q[85];
u1(-pi/524288) q[85];
cx q[103],q[85];
u1(pi/524288) q[85];
u1(pi/262144) q[103];
cx q[103],q[86];
u1(-pi/262144) q[86];
cx q[103],q[86];
u1(pi/262144) q[86];
u1(pi/131072) q[103];
cx q[103],q[87];
u1(-pi/131072) q[87];
cx q[103],q[87];
u1(pi/131072) q[87];
u1(pi/65536) q[103];
cx q[103],q[88];
u1(-pi/65536) q[88];
cx q[103],q[88];
u1(pi/65536) q[88];
u1(pi/32768) q[103];
cx q[103],q[89];
u1(-pi/32768) q[89];
cx q[103],q[89];
u1(pi/32768) q[89];
u1(pi/16384) q[103];
cx q[103],q[90];
u1(-pi/16384) q[90];
cx q[103],q[90];
u1(pi/16384) q[90];
u1(pi/8192) q[103];
cx q[103],q[91];
u1(-pi/8192) q[91];
cx q[103],q[91];
u1(pi/8192) q[91];
u1(pi/4096) q[103];
cx q[103],q[92];
u1(-pi/4096) q[92];
cx q[103],q[92];
u1(pi/4096) q[92];
u1(pi/2048) q[103];
cx q[103],q[93];
u1(-pi/2048) q[93];
cx q[103],q[93];
u1(pi/2048) q[93];
u1(pi/1024) q[103];
cx q[103],q[94];
u1(-pi/1024) q[94];
cx q[103],q[94];
u1(pi/1024) q[94];
u1(pi/512) q[103];
cx q[103],q[95];
u1(-pi/512) q[95];
cx q[103],q[95];
u1(pi/512) q[95];
u1(pi/256) q[103];
cx q[103],q[96];
u1(-pi/256) q[96];
cx q[103],q[96];
u1(pi/256) q[96];
u1(pi/128) q[103];
cx q[103],q[97];
u1(-pi/128) q[97];
cx q[103],q[97];
u1(pi/128) q[97];
u1(pi/64) q[103];
cx q[103],q[98];
u1(-pi/64) q[98];
cx q[103],q[98];
u1(pi/64) q[98];
u1(pi/32) q[103];
cx q[103],q[99];
u1(-pi/32) q[99];
cx q[103],q[99];
u1(pi/32) q[99];
u1(pi/16) q[103];
cx q[103],q[100];
u1(-pi/16) q[100];
cx q[103],q[100];
u1(pi/16) q[100];
u1(pi/8) q[103];
cx q[103],q[101];
u1(-pi/8) q[101];
cx q[103],q[101];
u1(pi/8) q[101];
u1(pi/4) q[103];
cx q[103],q[102];
u1(-pi/4) q[102];
cx q[103],q[102];
u1(pi/4) q[102];
h q[103];
u1(0) q[104];
cx q[104],q[0];
u1(0) q[0];
cx q[104],q[0];
u1(0) q[0];
u1(0) q[104];
cx q[104],q[1];
u1(0) q[1];
cx q[104],q[1];
u1(0) q[1];
u1(0) q[104];
cx q[104],q[2];
u1(0) q[2];
cx q[104],q[2];
u1(0) q[2];
u1(0) q[104];
cx q[104],q[3];
u1(0) q[3];
cx q[104],q[3];
u1(0) q[3];
u1(0) q[104];
cx q[104],q[4];
u1(0) q[4];
cx q[104],q[4];
u1(0) q[4];
u1(0) q[104];
cx q[104],q[5];
u1(0) q[5];
cx q[104],q[5];
u1(0) q[5];
u1(0) q[104];
cx q[104],q[6];
u1(0) q[6];
cx q[104],q[6];
u1(0) q[6];
u1(0) q[104];
cx q[104],q[7];
u1(0) q[7];
cx q[104],q[7];
u1(0) q[7];
u1(0) q[104];
cx q[104],q[8];
u1(0) q[8];
cx q[104],q[8];
u1(0) q[8];
u1(0) q[104];
cx q[104],q[9];
u1(0) q[9];
cx q[104],q[9];
u1(0) q[9];
u1(0) q[104];
cx q[104],q[10];
u1(0) q[10];
cx q[104],q[10];
u1(0) q[10];
u1(0) q[104];
cx q[104],q[11];
u1(0) q[11];
cx q[104],q[11];
u1(0) q[11];
u1(0) q[104];
cx q[104],q[12];
u1(0) q[12];
cx q[104],q[12];
u1(0) q[12];
u1(0) q[104];
cx q[104],q[13];
u1(0) q[13];
cx q[104],q[13];
u1(0) q[13];
u1(0) q[104];
cx q[104],q[14];
u1(0) q[14];
cx q[104],q[14];
u1(0) q[14];
u1(0) q[104];
cx q[104],q[15];
u1(0) q[15];
cx q[104],q[15];
u1(0) q[15];
u1(0) q[104];
cx q[104],q[16];
u1(0) q[16];
cx q[104],q[16];
u1(0) q[16];
u1(0) q[104];
cx q[104],q[17];
u1(0) q[17];
cx q[104],q[17];
u1(0) q[17];
u1(0) q[104];
cx q[104],q[18];
u1(0) q[18];
cx q[104],q[18];
u1(0) q[18];
u1(0) q[104];
cx q[104],q[19];
u1(0) q[19];
cx q[104],q[19];
u1(0) q[19];
u1(0) q[104];
cx q[104],q[20];
u1(0) q[20];
cx q[104],q[20];
u1(0) q[20];
u1(0) q[104];
cx q[104],q[21];
u1(0) q[21];
cx q[104],q[21];
u1(0) q[21];
u1(0) q[104];
cx q[104],q[22];
u1(0) q[22];
cx q[104],q[22];
u1(0) q[22];
u1(0) q[104];
cx q[104],q[23];
u1(0) q[23];
cx q[104],q[23];
u1(0) q[23];
u1(0) q[104];
cx q[104],q[24];
u1(0) q[24];
cx q[104],q[24];
u1(0) q[24];
u1(0) q[104];
cx q[104],q[25];
u1(0) q[25];
cx q[104],q[25];
u1(0) q[25];
u1(0) q[104];
cx q[104],q[26];
u1(0) q[26];
cx q[104],q[26];
u1(0) q[26];
u1(0) q[104];
cx q[104],q[27];
u1(0) q[27];
cx q[104],q[27];
u1(0) q[27];
u1(0) q[104];
cx q[104],q[28];
u1(0) q[28];
cx q[104],q[28];
u1(0) q[28];
u1(0) q[104];
cx q[104],q[29];
u1(0) q[29];
cx q[104],q[29];
u1(0) q[29];
u1(0) q[104];
cx q[104],q[30];
u1(0) q[30];
cx q[104],q[30];
u1(0) q[30];
u1(0) q[104];
cx q[104],q[31];
u1(0) q[31];
cx q[104],q[31];
u1(0) q[31];
u1(0) q[104];
cx q[104],q[32];
u1(0) q[32];
cx q[104],q[32];
u1(0) q[32];
u1(0) q[104];
cx q[104],q[33];
u1(0) q[33];
cx q[104],q[33];
u1(0) q[33];
u1(0) q[104];
cx q[104],q[34];
u1(0) q[34];
cx q[104],q[34];
u1(0) q[34];
u1(0) q[104];
cx q[104],q[35];
u1(0) q[35];
cx q[104],q[35];
u1(0) q[35];
u1(0) q[104];
cx q[104],q[36];
u1(0) q[36];
cx q[104],q[36];
u1(0) q[36];
u1(0) q[104];
cx q[104],q[37];
u1(0) q[37];
cx q[104],q[37];
u1(0) q[37];
u1(0) q[104];
cx q[104],q[38];
u1(0) q[38];
cx q[104],q[38];
u1(0) q[38];
u1(0) q[104];
cx q[104],q[39];
u1(0) q[39];
cx q[104],q[39];
u1(0) q[39];
u1(0) q[104];
cx q[104],q[40];
u1(0) q[40];
cx q[104],q[40];
u1(0) q[40];
u1(0) q[104];
cx q[104],q[41];
u1(0) q[41];
cx q[104],q[41];
u1(0) q[41];
u1(0) q[104];
cx q[104],q[42];
u1(0) q[42];
cx q[104],q[42];
u1(0) q[42];
u1(0) q[104];
cx q[104],q[43];
u1(0) q[43];
cx q[104],q[43];
u1(0) q[43];
u1(0) q[104];
cx q[104],q[44];
u1(0) q[44];
cx q[104],q[44];
u1(0) q[44];
u1(0) q[104];
cx q[104],q[45];
u1(0) q[45];
cx q[104],q[45];
u1(0) q[45];
u1(0) q[104];
cx q[104],q[46];
u1(0) q[46];
cx q[104],q[46];
u1(0) q[46];
u1(0) q[104];
cx q[104],q[47];
u1(0) q[47];
cx q[104],q[47];
u1(0) q[47];
u1(0) q[104];
cx q[104],q[48];
u1(0) q[48];
cx q[104],q[48];
u1(0) q[48];
u1(0) q[104];
cx q[104],q[49];
u1(0) q[49];
cx q[104],q[49];
u1(0) q[49];
u1(0) q[104];
cx q[104],q[50];
u1(0) q[50];
cx q[104],q[50];
u1(0) q[50];
u1(0) q[104];
cx q[104],q[51];
u1(0) q[51];
cx q[104],q[51];
u1(0) q[51];
u1(0) q[104];
cx q[104],q[52];
u1(0) q[52];
cx q[104],q[52];
u1(0) q[52];
u1(0) q[104];
cx q[104],q[53];
u1(0) q[53];
cx q[104],q[53];
u1(0) q[53];
u1(0) q[104];
cx q[104],q[54];
u1(0) q[54];
cx q[104],q[54];
u1(0) q[54];
u1(0) q[104];
cx q[104],q[55];
u1(0) q[55];
cx q[104],q[55];
u1(0) q[55];
u1(0) q[104];
cx q[104],q[56];
u1(0) q[56];
cx q[104],q[56];
u1(0) q[56];
u1(pi/281474976710656) q[104];
cx q[104],q[57];
u1(-pi/281474976710656) q[57];
cx q[104],q[57];
u1(pi/281474976710656) q[57];
u1(pi/140737488355328) q[104];
cx q[104],q[58];
u1(-pi/140737488355328) q[58];
cx q[104],q[58];
u1(pi/140737488355328) q[58];
u1(pi/70368744177664) q[104];
cx q[104],q[59];
u1(-pi/70368744177664) q[59];
cx q[104],q[59];
u1(pi/70368744177664) q[59];
u1(pi/35184372088832) q[104];
cx q[104],q[60];
u1(-pi/35184372088832) q[60];
cx q[104],q[60];
u1(pi/35184372088832) q[60];
u1(pi/17592186044416) q[104];
cx q[104],q[61];
u1(-pi/17592186044416) q[61];
cx q[104],q[61];
u1(pi/17592186044416) q[61];
u1(pi/8796093022208) q[104];
cx q[104],q[62];
u1(-pi/8796093022208) q[62];
cx q[104],q[62];
u1(pi/8796093022208) q[62];
u1(pi/4398046511104) q[104];
cx q[104],q[63];
u1(-pi/4398046511104) q[63];
cx q[104],q[63];
u1(pi/4398046511104) q[63];
u1(pi/2199023255552) q[104];
cx q[104],q[64];
u1(-pi/2199023255552) q[64];
cx q[104],q[64];
u1(pi/2199023255552) q[64];
u1(pi/1099511627776) q[104];
cx q[104],q[65];
u1(-pi/1099511627776) q[65];
cx q[104],q[65];
u1(pi/1099511627776) q[65];
u1(pi/549755813888) q[104];
cx q[104],q[66];
u1(-pi/549755813888) q[66];
cx q[104],q[66];
u1(pi/549755813888) q[66];
u1(pi/274877906944) q[104];
cx q[104],q[67];
u1(-pi/274877906944) q[67];
cx q[104],q[67];
u1(pi/274877906944) q[67];
u1(pi/137438953472) q[104];
cx q[104],q[68];
u1(-pi/137438953472) q[68];
cx q[104],q[68];
u1(pi/137438953472) q[68];
u1(pi/68719476736) q[104];
cx q[104],q[69];
u1(-pi/68719476736) q[69];
cx q[104],q[69];
u1(pi/68719476736) q[69];
u1(pi/34359738368) q[104];
cx q[104],q[70];
u1(-pi/34359738368) q[70];
cx q[104],q[70];
u1(pi/34359738368) q[70];
u1(pi/17179869184) q[104];
cx q[104],q[71];
u1(-pi/17179869184) q[71];
cx q[104],q[71];
u1(pi/17179869184) q[71];
u1(pi/8589934592) q[104];
cx q[104],q[72];
u1(-pi/8589934592) q[72];
cx q[104],q[72];
u1(pi/8589934592) q[72];
u1(pi/4294967296) q[104];
cx q[104],q[73];
u1(-pi/4294967296) q[73];
cx q[104],q[73];
u1(pi/4294967296) q[73];
u1(pi/2147483648) q[104];
cx q[104],q[74];
u1(-pi/2147483648) q[74];
cx q[104],q[74];
u1(pi/2147483648) q[74];
u1(pi/1073741824) q[104];
cx q[104],q[75];
u1(-pi/1073741824) q[75];
cx q[104],q[75];
u1(pi/1073741824) q[75];
u1(pi/536870912) q[104];
cx q[104],q[76];
u1(-pi/536870912) q[76];
cx q[104],q[76];
u1(pi/536870912) q[76];
u1(pi/268435456) q[104];
cx q[104],q[77];
u1(-pi/268435456) q[77];
cx q[104],q[77];
u1(pi/268435456) q[77];
u1(pi/134217728) q[104];
cx q[104],q[78];
u1(-pi/134217728) q[78];
cx q[104],q[78];
u1(pi/134217728) q[78];
u1(pi/67108864) q[104];
cx q[104],q[79];
u1(-pi/67108864) q[79];
cx q[104],q[79];
u1(pi/67108864) q[79];
u1(pi/33554432) q[104];
cx q[104],q[80];
u1(-pi/33554432) q[80];
cx q[104],q[80];
u1(pi/33554432) q[80];
u1(pi/16777216) q[104];
cx q[104],q[81];
u1(-pi/16777216) q[81];
cx q[104],q[81];
u1(pi/16777216) q[81];
u1(pi/8388608) q[104];
cx q[104],q[82];
u1(-pi/8388608) q[82];
cx q[104],q[82];
u1(pi/8388608) q[82];
u1(pi/4194304) q[104];
cx q[104],q[83];
u1(-pi/4194304) q[83];
cx q[104],q[83];
u1(pi/4194304) q[83];
u1(pi/2097152) q[104];
cx q[104],q[84];
u1(-pi/2097152) q[84];
cx q[104],q[84];
u1(pi/2097152) q[84];
u1(pi/1048576) q[104];
cx q[104],q[85];
u1(-pi/1048576) q[85];
cx q[104],q[85];
u1(pi/1048576) q[85];
u1(pi/524288) q[104];
cx q[104],q[86];
u1(-pi/524288) q[86];
cx q[104],q[86];
u1(pi/524288) q[86];
u1(pi/262144) q[104];
cx q[104],q[87];
u1(-pi/262144) q[87];
cx q[104],q[87];
u1(pi/262144) q[87];
u1(pi/131072) q[104];
cx q[104],q[88];
u1(-pi/131072) q[88];
cx q[104],q[88];
u1(pi/131072) q[88];
u1(pi/65536) q[104];
cx q[104],q[89];
u1(-pi/65536) q[89];
cx q[104],q[89];
u1(pi/65536) q[89];
u1(pi/32768) q[104];
cx q[104],q[90];
u1(-pi/32768) q[90];
cx q[104],q[90];
u1(pi/32768) q[90];
u1(pi/16384) q[104];
cx q[104],q[91];
u1(-pi/16384) q[91];
cx q[104],q[91];
u1(pi/16384) q[91];
u1(pi/8192) q[104];
cx q[104],q[92];
u1(-pi/8192) q[92];
cx q[104],q[92];
u1(pi/8192) q[92];
u1(pi/4096) q[104];
cx q[104],q[93];
u1(-pi/4096) q[93];
cx q[104],q[93];
u1(pi/4096) q[93];
u1(pi/2048) q[104];
cx q[104],q[94];
u1(-pi/2048) q[94];
cx q[104],q[94];
u1(pi/2048) q[94];
u1(pi/1024) q[104];
cx q[104],q[95];
u1(-pi/1024) q[95];
cx q[104],q[95];
u1(pi/1024) q[95];
u1(pi/512) q[104];
cx q[104],q[96];
u1(-pi/512) q[96];
cx q[104],q[96];
u1(pi/512) q[96];
u1(pi/256) q[104];
cx q[104],q[97];
u1(-pi/256) q[97];
cx q[104],q[97];
u1(pi/256) q[97];
u1(pi/128) q[104];
cx q[104],q[98];
u1(-pi/128) q[98];
cx q[104],q[98];
u1(pi/128) q[98];
u1(pi/64) q[104];
cx q[104],q[99];
u1(-pi/64) q[99];
cx q[104],q[99];
u1(pi/64) q[99];
u1(pi/32) q[104];
cx q[104],q[100];
u1(-pi/32) q[100];
cx q[104],q[100];
u1(pi/32) q[100];
u1(pi/16) q[104];
cx q[104],q[101];
u1(-pi/16) q[101];
cx q[104],q[101];
u1(pi/16) q[101];
u1(pi/8) q[104];
cx q[104],q[102];
u1(-pi/8) q[102];
cx q[104],q[102];
u1(pi/8) q[102];
u1(pi/4) q[104];
cx q[104],q[103];
u1(-pi/4) q[103];
cx q[104],q[103];
u1(pi/4) q[103];
h q[104];
u1(0) q[105];
cx q[105],q[0];
u1(0) q[0];
cx q[105],q[0];
u1(0) q[0];
u1(0) q[105];
cx q[105],q[1];
u1(0) q[1];
cx q[105],q[1];
u1(0) q[1];
u1(0) q[105];
cx q[105],q[2];
u1(0) q[2];
cx q[105],q[2];
u1(0) q[2];
u1(0) q[105];
cx q[105],q[3];
u1(0) q[3];
cx q[105],q[3];
u1(0) q[3];
u1(0) q[105];
cx q[105],q[4];
u1(0) q[4];
cx q[105],q[4];
u1(0) q[4];
u1(0) q[105];
cx q[105],q[5];
u1(0) q[5];
cx q[105],q[5];
u1(0) q[5];
u1(0) q[105];
cx q[105],q[6];
u1(0) q[6];
cx q[105],q[6];
u1(0) q[6];
u1(0) q[105];
cx q[105],q[7];
u1(0) q[7];
cx q[105],q[7];
u1(0) q[7];
u1(0) q[105];
cx q[105],q[8];
u1(0) q[8];
cx q[105],q[8];
u1(0) q[8];
u1(0) q[105];
cx q[105],q[9];
u1(0) q[9];
cx q[105],q[9];
u1(0) q[9];
u1(0) q[105];
cx q[105],q[10];
u1(0) q[10];
cx q[105],q[10];
u1(0) q[10];
u1(0) q[105];
cx q[105],q[11];
u1(0) q[11];
cx q[105],q[11];
u1(0) q[11];
u1(0) q[105];
cx q[105],q[12];
u1(0) q[12];
cx q[105],q[12];
u1(0) q[12];
u1(0) q[105];
cx q[105],q[13];
u1(0) q[13];
cx q[105],q[13];
u1(0) q[13];
u1(0) q[105];
cx q[105],q[14];
u1(0) q[14];
cx q[105],q[14];
u1(0) q[14];
u1(0) q[105];
cx q[105],q[15];
u1(0) q[15];
cx q[105],q[15];
u1(0) q[15];
u1(0) q[105];
cx q[105],q[16];
u1(0) q[16];
cx q[105],q[16];
u1(0) q[16];
u1(0) q[105];
cx q[105],q[17];
u1(0) q[17];
cx q[105],q[17];
u1(0) q[17];
u1(0) q[105];
cx q[105],q[18];
u1(0) q[18];
cx q[105],q[18];
u1(0) q[18];
u1(0) q[105];
cx q[105],q[19];
u1(0) q[19];
cx q[105],q[19];
u1(0) q[19];
u1(0) q[105];
cx q[105],q[20];
u1(0) q[20];
cx q[105],q[20];
u1(0) q[20];
u1(0) q[105];
cx q[105],q[21];
u1(0) q[21];
cx q[105],q[21];
u1(0) q[21];
u1(0) q[105];
cx q[105],q[22];
u1(0) q[22];
cx q[105],q[22];
u1(0) q[22];
u1(0) q[105];
cx q[105],q[23];
u1(0) q[23];
cx q[105],q[23];
u1(0) q[23];
u1(0) q[105];
cx q[105],q[24];
u1(0) q[24];
cx q[105],q[24];
u1(0) q[24];
u1(0) q[105];
cx q[105],q[25];
u1(0) q[25];
cx q[105],q[25];
u1(0) q[25];
u1(0) q[105];
cx q[105],q[26];
u1(0) q[26];
cx q[105],q[26];
u1(0) q[26];
u1(0) q[105];
cx q[105],q[27];
u1(0) q[27];
cx q[105],q[27];
u1(0) q[27];
u1(0) q[105];
cx q[105],q[28];
u1(0) q[28];
cx q[105],q[28];
u1(0) q[28];
u1(0) q[105];
cx q[105],q[29];
u1(0) q[29];
cx q[105],q[29];
u1(0) q[29];
u1(0) q[105];
cx q[105],q[30];
u1(0) q[30];
cx q[105],q[30];
u1(0) q[30];
u1(0) q[105];
cx q[105],q[31];
u1(0) q[31];
cx q[105],q[31];
u1(0) q[31];
u1(0) q[105];
cx q[105],q[32];
u1(0) q[32];
cx q[105],q[32];
u1(0) q[32];
u1(0) q[105];
cx q[105],q[33];
u1(0) q[33];
cx q[105],q[33];
u1(0) q[33];
u1(0) q[105];
cx q[105],q[34];
u1(0) q[34];
cx q[105],q[34];
u1(0) q[34];
u1(0) q[105];
cx q[105],q[35];
u1(0) q[35];
cx q[105],q[35];
u1(0) q[35];
u1(0) q[105];
cx q[105],q[36];
u1(0) q[36];
cx q[105],q[36];
u1(0) q[36];
u1(0) q[105];
cx q[105],q[37];
u1(0) q[37];
cx q[105],q[37];
u1(0) q[37];
u1(0) q[105];
cx q[105],q[38];
u1(0) q[38];
cx q[105],q[38];
u1(0) q[38];
u1(0) q[105];
cx q[105],q[39];
u1(0) q[39];
cx q[105],q[39];
u1(0) q[39];
u1(0) q[105];
cx q[105],q[40];
u1(0) q[40];
cx q[105],q[40];
u1(0) q[40];
u1(0) q[105];
cx q[105],q[41];
u1(0) q[41];
cx q[105],q[41];
u1(0) q[41];
u1(0) q[105];
cx q[105],q[42];
u1(0) q[42];
cx q[105],q[42];
u1(0) q[42];
u1(0) q[105];
cx q[105],q[43];
u1(0) q[43];
cx q[105],q[43];
u1(0) q[43];
u1(0) q[105];
cx q[105],q[44];
u1(0) q[44];
cx q[105],q[44];
u1(0) q[44];
u1(0) q[105];
cx q[105],q[45];
u1(0) q[45];
cx q[105],q[45];
u1(0) q[45];
u1(0) q[105];
cx q[105],q[46];
u1(0) q[46];
cx q[105],q[46];
u1(0) q[46];
u1(0) q[105];
cx q[105],q[47];
u1(0) q[47];
cx q[105],q[47];
u1(0) q[47];
u1(0) q[105];
cx q[105],q[48];
u1(0) q[48];
cx q[105],q[48];
u1(0) q[48];
u1(0) q[105];
cx q[105],q[49];
u1(0) q[49];
cx q[105],q[49];
u1(0) q[49];
u1(0) q[105];
cx q[105],q[50];
u1(0) q[50];
cx q[105],q[50];
u1(0) q[50];
u1(0) q[105];
cx q[105],q[51];
u1(0) q[51];
cx q[105],q[51];
u1(0) q[51];
u1(0) q[105];
cx q[105],q[52];
u1(0) q[52];
cx q[105],q[52];
u1(0) q[52];
u1(0) q[105];
cx q[105],q[53];
u1(0) q[53];
cx q[105],q[53];
u1(0) q[53];
u1(0) q[105];
cx q[105],q[54];
u1(0) q[54];
cx q[105],q[54];
u1(0) q[54];
u1(0) q[105];
cx q[105],q[55];
u1(0) q[55];
cx q[105],q[55];
u1(0) q[55];
u1(0) q[105];
cx q[105],q[56];
u1(0) q[56];
cx q[105],q[56];
u1(0) q[56];
u1(0) q[105];
cx q[105],q[57];
u1(0) q[57];
cx q[105],q[57];
u1(0) q[57];
u1(pi/281474976710656) q[105];
cx q[105],q[58];
u1(-pi/281474976710656) q[58];
cx q[105],q[58];
u1(pi/281474976710656) q[58];
u1(pi/140737488355328) q[105];
cx q[105],q[59];
u1(-pi/140737488355328) q[59];
cx q[105],q[59];
u1(pi/140737488355328) q[59];
u1(pi/70368744177664) q[105];
cx q[105],q[60];
u1(-pi/70368744177664) q[60];
cx q[105],q[60];
u1(pi/70368744177664) q[60];
u1(pi/35184372088832) q[105];
cx q[105],q[61];
u1(-pi/35184372088832) q[61];
cx q[105],q[61];
u1(pi/35184372088832) q[61];
u1(pi/17592186044416) q[105];
cx q[105],q[62];
u1(-pi/17592186044416) q[62];
cx q[105],q[62];
u1(pi/17592186044416) q[62];
u1(pi/8796093022208) q[105];
cx q[105],q[63];
u1(-pi/8796093022208) q[63];
cx q[105],q[63];
u1(pi/8796093022208) q[63];
u1(pi/4398046511104) q[105];
cx q[105],q[64];
u1(-pi/4398046511104) q[64];
cx q[105],q[64];
u1(pi/4398046511104) q[64];
u1(pi/2199023255552) q[105];
cx q[105],q[65];
u1(-pi/2199023255552) q[65];
cx q[105],q[65];
u1(pi/2199023255552) q[65];
u1(pi/1099511627776) q[105];
cx q[105],q[66];
u1(-pi/1099511627776) q[66];
cx q[105],q[66];
u1(pi/1099511627776) q[66];
u1(pi/549755813888) q[105];
cx q[105],q[67];
u1(-pi/549755813888) q[67];
cx q[105],q[67];
u1(pi/549755813888) q[67];
u1(pi/274877906944) q[105];
cx q[105],q[68];
u1(-pi/274877906944) q[68];
cx q[105],q[68];
u1(pi/274877906944) q[68];
u1(pi/137438953472) q[105];
cx q[105],q[69];
u1(-pi/137438953472) q[69];
cx q[105],q[69];
u1(pi/137438953472) q[69];
u1(pi/68719476736) q[105];
cx q[105],q[70];
u1(-pi/68719476736) q[70];
cx q[105],q[70];
u1(pi/68719476736) q[70];
u1(pi/34359738368) q[105];
cx q[105],q[71];
u1(-pi/34359738368) q[71];
cx q[105],q[71];
u1(pi/34359738368) q[71];
u1(pi/17179869184) q[105];
cx q[105],q[72];
u1(-pi/17179869184) q[72];
cx q[105],q[72];
u1(pi/17179869184) q[72];
u1(pi/8589934592) q[105];
cx q[105],q[73];
u1(-pi/8589934592) q[73];
cx q[105],q[73];
u1(pi/8589934592) q[73];
u1(pi/4294967296) q[105];
cx q[105],q[74];
u1(-pi/4294967296) q[74];
cx q[105],q[74];
u1(pi/4294967296) q[74];
u1(pi/2147483648) q[105];
cx q[105],q[75];
u1(-pi/2147483648) q[75];
cx q[105],q[75];
u1(pi/2147483648) q[75];
u1(pi/1073741824) q[105];
cx q[105],q[76];
u1(-pi/1073741824) q[76];
cx q[105],q[76];
u1(pi/1073741824) q[76];
u1(pi/536870912) q[105];
cx q[105],q[77];
u1(-pi/536870912) q[77];
cx q[105],q[77];
u1(pi/536870912) q[77];
u1(pi/268435456) q[105];
cx q[105],q[78];
u1(-pi/268435456) q[78];
cx q[105],q[78];
u1(pi/268435456) q[78];
u1(pi/134217728) q[105];
cx q[105],q[79];
u1(-pi/134217728) q[79];
cx q[105],q[79];
u1(pi/134217728) q[79];
u1(pi/67108864) q[105];
cx q[105],q[80];
u1(-pi/67108864) q[80];
cx q[105],q[80];
u1(pi/67108864) q[80];
u1(pi/33554432) q[105];
cx q[105],q[81];
u1(-pi/33554432) q[81];
cx q[105],q[81];
u1(pi/33554432) q[81];
u1(pi/16777216) q[105];
cx q[105],q[82];
u1(-pi/16777216) q[82];
cx q[105],q[82];
u1(pi/16777216) q[82];
u1(pi/8388608) q[105];
cx q[105],q[83];
u1(-pi/8388608) q[83];
cx q[105],q[83];
u1(pi/8388608) q[83];
u1(pi/4194304) q[105];
cx q[105],q[84];
u1(-pi/4194304) q[84];
cx q[105],q[84];
u1(pi/4194304) q[84];
u1(pi/2097152) q[105];
cx q[105],q[85];
u1(-pi/2097152) q[85];
cx q[105],q[85];
u1(pi/2097152) q[85];
u1(pi/1048576) q[105];
cx q[105],q[86];
u1(-pi/1048576) q[86];
cx q[105],q[86];
u1(pi/1048576) q[86];
u1(pi/524288) q[105];
cx q[105],q[87];
u1(-pi/524288) q[87];
cx q[105],q[87];
u1(pi/524288) q[87];
u1(pi/262144) q[105];
cx q[105],q[88];
u1(-pi/262144) q[88];
cx q[105],q[88];
u1(pi/262144) q[88];
u1(pi/131072) q[105];
cx q[105],q[89];
u1(-pi/131072) q[89];
cx q[105],q[89];
u1(pi/131072) q[89];
u1(pi/65536) q[105];
cx q[105],q[90];
u1(-pi/65536) q[90];
cx q[105],q[90];
u1(pi/65536) q[90];
u1(pi/32768) q[105];
cx q[105],q[91];
u1(-pi/32768) q[91];
cx q[105],q[91];
u1(pi/32768) q[91];
u1(pi/16384) q[105];
cx q[105],q[92];
u1(-pi/16384) q[92];
cx q[105],q[92];
u1(pi/16384) q[92];
u1(pi/8192) q[105];
cx q[105],q[93];
u1(-pi/8192) q[93];
cx q[105],q[93];
u1(pi/8192) q[93];
u1(pi/4096) q[105];
cx q[105],q[94];
u1(-pi/4096) q[94];
cx q[105],q[94];
u1(pi/4096) q[94];
u1(pi/2048) q[105];
cx q[105],q[95];
u1(-pi/2048) q[95];
cx q[105],q[95];
u1(pi/2048) q[95];
u1(pi/1024) q[105];
cx q[105],q[96];
u1(-pi/1024) q[96];
cx q[105],q[96];
u1(pi/1024) q[96];
u1(pi/512) q[105];
cx q[105],q[97];
u1(-pi/512) q[97];
cx q[105],q[97];
u1(pi/512) q[97];
u1(pi/256) q[105];
cx q[105],q[98];
u1(-pi/256) q[98];
cx q[105],q[98];
u1(pi/256) q[98];
u1(pi/128) q[105];
cx q[105],q[99];
u1(-pi/128) q[99];
cx q[105],q[99];
u1(pi/128) q[99];
u1(pi/64) q[105];
cx q[105],q[100];
u1(-pi/64) q[100];
cx q[105],q[100];
u1(pi/64) q[100];
u1(pi/32) q[105];
cx q[105],q[101];
u1(-pi/32) q[101];
cx q[105],q[101];
u1(pi/32) q[101];
u1(pi/16) q[105];
cx q[105],q[102];
u1(-pi/16) q[102];
cx q[105],q[102];
u1(pi/16) q[102];
u1(pi/8) q[105];
cx q[105],q[103];
u1(-pi/8) q[103];
cx q[105],q[103];
u1(pi/8) q[103];
u1(pi/4) q[105];
cx q[105],q[104];
u1(-pi/4) q[104];
cx q[105],q[104];
u1(pi/4) q[104];
h q[105];
u1(0) q[106];
cx q[106],q[0];
u1(0) q[0];
cx q[106],q[0];
u1(0) q[0];
u1(0) q[106];
cx q[106],q[1];
u1(0) q[1];
cx q[106],q[1];
u1(0) q[1];
u1(0) q[106];
cx q[106],q[2];
u1(0) q[2];
cx q[106],q[2];
u1(0) q[2];
u1(0) q[106];
cx q[106],q[3];
u1(0) q[3];
cx q[106],q[3];
u1(0) q[3];
u1(0) q[106];
cx q[106],q[4];
u1(0) q[4];
cx q[106],q[4];
u1(0) q[4];
u1(0) q[106];
cx q[106],q[5];
u1(0) q[5];
cx q[106],q[5];
u1(0) q[5];
u1(0) q[106];
cx q[106],q[6];
u1(0) q[6];
cx q[106],q[6];
u1(0) q[6];
u1(0) q[106];
cx q[106],q[7];
u1(0) q[7];
cx q[106],q[7];
u1(0) q[7];
u1(0) q[106];
cx q[106],q[8];
u1(0) q[8];
cx q[106],q[8];
u1(0) q[8];
u1(0) q[106];
cx q[106],q[9];
u1(0) q[9];
cx q[106],q[9];
u1(0) q[9];
u1(0) q[106];
cx q[106],q[10];
u1(0) q[10];
cx q[106],q[10];
u1(0) q[10];
u1(0) q[106];
cx q[106],q[11];
u1(0) q[11];
cx q[106],q[11];
u1(0) q[11];
u1(0) q[106];
cx q[106],q[12];
u1(0) q[12];
cx q[106],q[12];
u1(0) q[12];
u1(0) q[106];
cx q[106],q[13];
u1(0) q[13];
cx q[106],q[13];
u1(0) q[13];
u1(0) q[106];
cx q[106],q[14];
u1(0) q[14];
cx q[106],q[14];
u1(0) q[14];
u1(0) q[106];
cx q[106],q[15];
u1(0) q[15];
cx q[106],q[15];
u1(0) q[15];
u1(0) q[106];
cx q[106],q[16];
u1(0) q[16];
cx q[106],q[16];
u1(0) q[16];
u1(0) q[106];
cx q[106],q[17];
u1(0) q[17];
cx q[106],q[17];
u1(0) q[17];
u1(0) q[106];
cx q[106],q[18];
u1(0) q[18];
cx q[106],q[18];
u1(0) q[18];
u1(0) q[106];
cx q[106],q[19];
u1(0) q[19];
cx q[106],q[19];
u1(0) q[19];
u1(0) q[106];
cx q[106],q[20];
u1(0) q[20];
cx q[106],q[20];
u1(0) q[20];
u1(0) q[106];
cx q[106],q[21];
u1(0) q[21];
cx q[106],q[21];
u1(0) q[21];
u1(0) q[106];
cx q[106],q[22];
u1(0) q[22];
cx q[106],q[22];
u1(0) q[22];
u1(0) q[106];
cx q[106],q[23];
u1(0) q[23];
cx q[106],q[23];
u1(0) q[23];
u1(0) q[106];
cx q[106],q[24];
u1(0) q[24];
cx q[106],q[24];
u1(0) q[24];
u1(0) q[106];
cx q[106],q[25];
u1(0) q[25];
cx q[106],q[25];
u1(0) q[25];
u1(0) q[106];
cx q[106],q[26];
u1(0) q[26];
cx q[106],q[26];
u1(0) q[26];
u1(0) q[106];
cx q[106],q[27];
u1(0) q[27];
cx q[106],q[27];
u1(0) q[27];
u1(0) q[106];
cx q[106],q[28];
u1(0) q[28];
cx q[106],q[28];
u1(0) q[28];
u1(0) q[106];
cx q[106],q[29];
u1(0) q[29];
cx q[106],q[29];
u1(0) q[29];
u1(0) q[106];
cx q[106],q[30];
u1(0) q[30];
cx q[106],q[30];
u1(0) q[30];
u1(0) q[106];
cx q[106],q[31];
u1(0) q[31];
cx q[106],q[31];
u1(0) q[31];
u1(0) q[106];
cx q[106],q[32];
u1(0) q[32];
cx q[106],q[32];
u1(0) q[32];
u1(0) q[106];
cx q[106],q[33];
u1(0) q[33];
cx q[106],q[33];
u1(0) q[33];
u1(0) q[106];
cx q[106],q[34];
u1(0) q[34];
cx q[106],q[34];
u1(0) q[34];
u1(0) q[106];
cx q[106],q[35];
u1(0) q[35];
cx q[106],q[35];
u1(0) q[35];
u1(0) q[106];
cx q[106],q[36];
u1(0) q[36];
cx q[106],q[36];
u1(0) q[36];
u1(0) q[106];
cx q[106],q[37];
u1(0) q[37];
cx q[106],q[37];
u1(0) q[37];
u1(0) q[106];
cx q[106],q[38];
u1(0) q[38];
cx q[106],q[38];
u1(0) q[38];
u1(0) q[106];
cx q[106],q[39];
u1(0) q[39];
cx q[106],q[39];
u1(0) q[39];
u1(0) q[106];
cx q[106],q[40];
u1(0) q[40];
cx q[106],q[40];
u1(0) q[40];
u1(0) q[106];
cx q[106],q[41];
u1(0) q[41];
cx q[106],q[41];
u1(0) q[41];
u1(0) q[106];
cx q[106],q[42];
u1(0) q[42];
cx q[106],q[42];
u1(0) q[42];
u1(0) q[106];
cx q[106],q[43];
u1(0) q[43];
cx q[106],q[43];
u1(0) q[43];
u1(0) q[106];
cx q[106],q[44];
u1(0) q[44];
cx q[106],q[44];
u1(0) q[44];
u1(0) q[106];
cx q[106],q[45];
u1(0) q[45];
cx q[106],q[45];
u1(0) q[45];
u1(0) q[106];
cx q[106],q[46];
u1(0) q[46];
cx q[106],q[46];
u1(0) q[46];
u1(0) q[106];
cx q[106],q[47];
u1(0) q[47];
cx q[106],q[47];
u1(0) q[47];
u1(0) q[106];
cx q[106],q[48];
u1(0) q[48];
cx q[106],q[48];
u1(0) q[48];
u1(0) q[106];
cx q[106],q[49];
u1(0) q[49];
cx q[106],q[49];
u1(0) q[49];
u1(0) q[106];
cx q[106],q[50];
u1(0) q[50];
cx q[106],q[50];
u1(0) q[50];
u1(0) q[106];
cx q[106],q[51];
u1(0) q[51];
cx q[106],q[51];
u1(0) q[51];
u1(0) q[106];
cx q[106],q[52];
u1(0) q[52];
cx q[106],q[52];
u1(0) q[52];
u1(0) q[106];
cx q[106],q[53];
u1(0) q[53];
cx q[106],q[53];
u1(0) q[53];
u1(0) q[106];
cx q[106],q[54];
u1(0) q[54];
cx q[106],q[54];
u1(0) q[54];
u1(0) q[106];
cx q[106],q[55];
u1(0) q[55];
cx q[106],q[55];
u1(0) q[55];
u1(0) q[106];
cx q[106],q[56];
u1(0) q[56];
cx q[106],q[56];
u1(0) q[56];
u1(0) q[106];
cx q[106],q[57];
u1(0) q[57];
cx q[106],q[57];
u1(0) q[57];
u1(0) q[106];
cx q[106],q[58];
u1(0) q[58];
cx q[106],q[58];
u1(0) q[58];
u1(pi/281474976710656) q[106];
cx q[106],q[59];
u1(-pi/281474976710656) q[59];
cx q[106],q[59];
u1(pi/281474976710656) q[59];
u1(pi/140737488355328) q[106];
cx q[106],q[60];
u1(-pi/140737488355328) q[60];
cx q[106],q[60];
u1(pi/140737488355328) q[60];
u1(pi/70368744177664) q[106];
cx q[106],q[61];
u1(-pi/70368744177664) q[61];
cx q[106],q[61];
u1(pi/70368744177664) q[61];
u1(pi/35184372088832) q[106];
cx q[106],q[62];
u1(-pi/35184372088832) q[62];
cx q[106],q[62];
u1(pi/35184372088832) q[62];
u1(pi/17592186044416) q[106];
cx q[106],q[63];
u1(-pi/17592186044416) q[63];
cx q[106],q[63];
u1(pi/17592186044416) q[63];
u1(pi/8796093022208) q[106];
cx q[106],q[64];
u1(-pi/8796093022208) q[64];
cx q[106],q[64];
u1(pi/8796093022208) q[64];
u1(pi/4398046511104) q[106];
cx q[106],q[65];
u1(-pi/4398046511104) q[65];
cx q[106],q[65];
u1(pi/4398046511104) q[65];
u1(pi/2199023255552) q[106];
cx q[106],q[66];
u1(-pi/2199023255552) q[66];
cx q[106],q[66];
u1(pi/2199023255552) q[66];
u1(pi/1099511627776) q[106];
cx q[106],q[67];
u1(-pi/1099511627776) q[67];
cx q[106],q[67];
u1(pi/1099511627776) q[67];
u1(pi/549755813888) q[106];
cx q[106],q[68];
u1(-pi/549755813888) q[68];
cx q[106],q[68];
u1(pi/549755813888) q[68];
u1(pi/274877906944) q[106];
cx q[106],q[69];
u1(-pi/274877906944) q[69];
cx q[106],q[69];
u1(pi/274877906944) q[69];
u1(pi/137438953472) q[106];
cx q[106],q[70];
u1(-pi/137438953472) q[70];
cx q[106],q[70];
u1(pi/137438953472) q[70];
u1(pi/68719476736) q[106];
cx q[106],q[71];
u1(-pi/68719476736) q[71];
cx q[106],q[71];
u1(pi/68719476736) q[71];
u1(pi/34359738368) q[106];
cx q[106],q[72];
u1(-pi/34359738368) q[72];
cx q[106],q[72];
u1(pi/34359738368) q[72];
u1(pi/17179869184) q[106];
cx q[106],q[73];
u1(-pi/17179869184) q[73];
cx q[106],q[73];
u1(pi/17179869184) q[73];
u1(pi/8589934592) q[106];
cx q[106],q[74];
u1(-pi/8589934592) q[74];
cx q[106],q[74];
u1(pi/8589934592) q[74];
u1(pi/4294967296) q[106];
cx q[106],q[75];
u1(-pi/4294967296) q[75];
cx q[106],q[75];
u1(pi/4294967296) q[75];
u1(pi/2147483648) q[106];
cx q[106],q[76];
u1(-pi/2147483648) q[76];
cx q[106],q[76];
u1(pi/2147483648) q[76];
u1(pi/1073741824) q[106];
cx q[106],q[77];
u1(-pi/1073741824) q[77];
cx q[106],q[77];
u1(pi/1073741824) q[77];
u1(pi/536870912) q[106];
cx q[106],q[78];
u1(-pi/536870912) q[78];
cx q[106],q[78];
u1(pi/536870912) q[78];
u1(pi/268435456) q[106];
cx q[106],q[79];
u1(-pi/268435456) q[79];
cx q[106],q[79];
u1(pi/268435456) q[79];
u1(pi/134217728) q[106];
cx q[106],q[80];
u1(-pi/134217728) q[80];
cx q[106],q[80];
u1(pi/134217728) q[80];
u1(pi/67108864) q[106];
cx q[106],q[81];
u1(-pi/67108864) q[81];
cx q[106],q[81];
u1(pi/67108864) q[81];
u1(pi/33554432) q[106];
cx q[106],q[82];
u1(-pi/33554432) q[82];
cx q[106],q[82];
u1(pi/33554432) q[82];
u1(pi/16777216) q[106];
cx q[106],q[83];
u1(-pi/16777216) q[83];
cx q[106],q[83];
u1(pi/16777216) q[83];
u1(pi/8388608) q[106];
cx q[106],q[84];
u1(-pi/8388608) q[84];
cx q[106],q[84];
u1(pi/8388608) q[84];
u1(pi/4194304) q[106];
cx q[106],q[85];
u1(-pi/4194304) q[85];
cx q[106],q[85];
u1(pi/4194304) q[85];
u1(pi/2097152) q[106];
cx q[106],q[86];
u1(-pi/2097152) q[86];
cx q[106],q[86];
u1(pi/2097152) q[86];
u1(pi/1048576) q[106];
cx q[106],q[87];
u1(-pi/1048576) q[87];
cx q[106],q[87];
u1(pi/1048576) q[87];
u1(pi/524288) q[106];
cx q[106],q[88];
u1(-pi/524288) q[88];
cx q[106],q[88];
u1(pi/524288) q[88];
u1(pi/262144) q[106];
cx q[106],q[89];
u1(-pi/262144) q[89];
cx q[106],q[89];
u1(pi/262144) q[89];
u1(pi/131072) q[106];
cx q[106],q[90];
u1(-pi/131072) q[90];
cx q[106],q[90];
u1(pi/131072) q[90];
u1(pi/65536) q[106];
cx q[106],q[91];
u1(-pi/65536) q[91];
cx q[106],q[91];
u1(pi/65536) q[91];
u1(pi/32768) q[106];
cx q[106],q[92];
u1(-pi/32768) q[92];
cx q[106],q[92];
u1(pi/32768) q[92];
u1(pi/16384) q[106];
cx q[106],q[93];
u1(-pi/16384) q[93];
cx q[106],q[93];
u1(pi/16384) q[93];
u1(pi/8192) q[106];
cx q[106],q[94];
u1(-pi/8192) q[94];
cx q[106],q[94];
u1(pi/8192) q[94];
u1(pi/4096) q[106];
cx q[106],q[95];
u1(-pi/4096) q[95];
cx q[106],q[95];
u1(pi/4096) q[95];
u1(pi/2048) q[106];
cx q[106],q[96];
u1(-pi/2048) q[96];
cx q[106],q[96];
u1(pi/2048) q[96];
u1(pi/1024) q[106];
cx q[106],q[97];
u1(-pi/1024) q[97];
cx q[106],q[97];
u1(pi/1024) q[97];
u1(pi/512) q[106];
cx q[106],q[98];
u1(-pi/512) q[98];
cx q[106],q[98];
u1(pi/512) q[98];
u1(pi/256) q[106];
cx q[106],q[99];
u1(-pi/256) q[99];
cx q[106],q[99];
u1(pi/256) q[99];
u1(pi/128) q[106];
cx q[106],q[100];
u1(-pi/128) q[100];
cx q[106],q[100];
u1(pi/128) q[100];
u1(pi/64) q[106];
cx q[106],q[101];
u1(-pi/64) q[101];
cx q[106],q[101];
u1(pi/64) q[101];
u1(pi/32) q[106];
cx q[106],q[102];
u1(-pi/32) q[102];
cx q[106],q[102];
u1(pi/32) q[102];
u1(pi/16) q[106];
cx q[106],q[103];
u1(-pi/16) q[103];
cx q[106],q[103];
u1(pi/16) q[103];
u1(pi/8) q[106];
cx q[106],q[104];
u1(-pi/8) q[104];
cx q[106],q[104];
u1(pi/8) q[104];
u1(pi/4) q[106];
cx q[106],q[105];
u1(-pi/4) q[105];
cx q[106],q[105];
u1(pi/4) q[105];
h q[106];
u1(0) q[107];
cx q[107],q[0];
u1(0) q[0];
cx q[107],q[0];
u1(0) q[0];
u1(0) q[107];
cx q[107],q[1];
u1(0) q[1];
cx q[107],q[1];
u1(0) q[1];
u1(0) q[107];
cx q[107],q[2];
u1(0) q[2];
cx q[107],q[2];
u1(0) q[2];
u1(0) q[107];
cx q[107],q[3];
u1(0) q[3];
cx q[107],q[3];
u1(0) q[3];
u1(0) q[107];
cx q[107],q[4];
u1(0) q[4];
cx q[107],q[4];
u1(0) q[4];
u1(0) q[107];
cx q[107],q[5];
u1(0) q[5];
cx q[107],q[5];
u1(0) q[5];
u1(0) q[107];
cx q[107],q[6];
u1(0) q[6];
cx q[107],q[6];
u1(0) q[6];
u1(0) q[107];
cx q[107],q[7];
u1(0) q[7];
cx q[107],q[7];
u1(0) q[7];
u1(0) q[107];
cx q[107],q[8];
u1(0) q[8];
cx q[107],q[8];
u1(0) q[8];
u1(0) q[107];
cx q[107],q[9];
u1(0) q[9];
cx q[107],q[9];
u1(0) q[9];
u1(0) q[107];
cx q[107],q[10];
u1(0) q[10];
cx q[107],q[10];
u1(0) q[10];
u1(0) q[107];
cx q[107],q[11];
u1(0) q[11];
cx q[107],q[11];
u1(0) q[11];
u1(0) q[107];
cx q[107],q[12];
u1(0) q[12];
cx q[107],q[12];
u1(0) q[12];
u1(0) q[107];
cx q[107],q[13];
u1(0) q[13];
cx q[107],q[13];
u1(0) q[13];
u1(0) q[107];
cx q[107],q[14];
u1(0) q[14];
cx q[107],q[14];
u1(0) q[14];
u1(0) q[107];
cx q[107],q[15];
u1(0) q[15];
cx q[107],q[15];
u1(0) q[15];
u1(0) q[107];
cx q[107],q[16];
u1(0) q[16];
cx q[107],q[16];
u1(0) q[16];
u1(0) q[107];
cx q[107],q[17];
u1(0) q[17];
cx q[107],q[17];
u1(0) q[17];
u1(0) q[107];
cx q[107],q[18];
u1(0) q[18];
cx q[107],q[18];
u1(0) q[18];
u1(0) q[107];
cx q[107],q[19];
u1(0) q[19];
cx q[107],q[19];
u1(0) q[19];
u1(0) q[107];
cx q[107],q[20];
u1(0) q[20];
cx q[107],q[20];
u1(0) q[20];
u1(0) q[107];
cx q[107],q[21];
u1(0) q[21];
cx q[107],q[21];
u1(0) q[21];
u1(0) q[107];
cx q[107],q[22];
u1(0) q[22];
cx q[107],q[22];
u1(0) q[22];
u1(0) q[107];
cx q[107],q[23];
u1(0) q[23];
cx q[107],q[23];
u1(0) q[23];
u1(0) q[107];
cx q[107],q[24];
u1(0) q[24];
cx q[107],q[24];
u1(0) q[24];
u1(0) q[107];
cx q[107],q[25];
u1(0) q[25];
cx q[107],q[25];
u1(0) q[25];
u1(0) q[107];
cx q[107],q[26];
u1(0) q[26];
cx q[107],q[26];
u1(0) q[26];
u1(0) q[107];
cx q[107],q[27];
u1(0) q[27];
cx q[107],q[27];
u1(0) q[27];
u1(0) q[107];
cx q[107],q[28];
u1(0) q[28];
cx q[107],q[28];
u1(0) q[28];
u1(0) q[107];
cx q[107],q[29];
u1(0) q[29];
cx q[107],q[29];
u1(0) q[29];
u1(0) q[107];
cx q[107],q[30];
u1(0) q[30];
cx q[107],q[30];
u1(0) q[30];
u1(0) q[107];
cx q[107],q[31];
u1(0) q[31];
cx q[107],q[31];
u1(0) q[31];
u1(0) q[107];
cx q[107],q[32];
u1(0) q[32];
cx q[107],q[32];
u1(0) q[32];
u1(0) q[107];
cx q[107],q[33];
u1(0) q[33];
cx q[107],q[33];
u1(0) q[33];
u1(0) q[107];
cx q[107],q[34];
u1(0) q[34];
cx q[107],q[34];
u1(0) q[34];
u1(0) q[107];
cx q[107],q[35];
u1(0) q[35];
cx q[107],q[35];
u1(0) q[35];
u1(0) q[107];
cx q[107],q[36];
u1(0) q[36];
cx q[107],q[36];
u1(0) q[36];
u1(0) q[107];
cx q[107],q[37];
u1(0) q[37];
cx q[107],q[37];
u1(0) q[37];
u1(0) q[107];
cx q[107],q[38];
u1(0) q[38];
cx q[107],q[38];
u1(0) q[38];
u1(0) q[107];
cx q[107],q[39];
u1(0) q[39];
cx q[107],q[39];
u1(0) q[39];
u1(0) q[107];
cx q[107],q[40];
u1(0) q[40];
cx q[107],q[40];
u1(0) q[40];
u1(0) q[107];
cx q[107],q[41];
u1(0) q[41];
cx q[107],q[41];
u1(0) q[41];
u1(0) q[107];
cx q[107],q[42];
u1(0) q[42];
cx q[107],q[42];
u1(0) q[42];
u1(0) q[107];
cx q[107],q[43];
u1(0) q[43];
cx q[107],q[43];
u1(0) q[43];
u1(0) q[107];
cx q[107],q[44];
u1(0) q[44];
cx q[107],q[44];
u1(0) q[44];
u1(0) q[107];
cx q[107],q[45];
u1(0) q[45];
cx q[107],q[45];
u1(0) q[45];
u1(0) q[107];
cx q[107],q[46];
u1(0) q[46];
cx q[107],q[46];
u1(0) q[46];
u1(0) q[107];
cx q[107],q[47];
u1(0) q[47];
cx q[107],q[47];
u1(0) q[47];
u1(0) q[107];
cx q[107],q[48];
u1(0) q[48];
cx q[107],q[48];
u1(0) q[48];
u1(0) q[107];
cx q[107],q[49];
u1(0) q[49];
cx q[107],q[49];
u1(0) q[49];
u1(0) q[107];
cx q[107],q[50];
u1(0) q[50];
cx q[107],q[50];
u1(0) q[50];
u1(0) q[107];
cx q[107],q[51];
u1(0) q[51];
cx q[107],q[51];
u1(0) q[51];
u1(0) q[107];
cx q[107],q[52];
u1(0) q[52];
cx q[107],q[52];
u1(0) q[52];
u1(0) q[107];
cx q[107],q[53];
u1(0) q[53];
cx q[107],q[53];
u1(0) q[53];
u1(0) q[107];
cx q[107],q[54];
u1(0) q[54];
cx q[107],q[54];
u1(0) q[54];
u1(0) q[107];
cx q[107],q[55];
u1(0) q[55];
cx q[107],q[55];
u1(0) q[55];
u1(0) q[107];
cx q[107],q[56];
u1(0) q[56];
cx q[107],q[56];
u1(0) q[56];
u1(0) q[107];
cx q[107],q[57];
u1(0) q[57];
cx q[107],q[57];
u1(0) q[57];
u1(0) q[107];
cx q[107],q[58];
u1(0) q[58];
cx q[107],q[58];
u1(0) q[58];
u1(0) q[107];
cx q[107],q[59];
u1(0) q[59];
cx q[107],q[59];
u1(0) q[59];
u1(pi/281474976710656) q[107];
cx q[107],q[60];
u1(-pi/281474976710656) q[60];
cx q[107],q[60];
u1(pi/281474976710656) q[60];
u1(pi/140737488355328) q[107];
cx q[107],q[61];
u1(-pi/140737488355328) q[61];
cx q[107],q[61];
u1(pi/140737488355328) q[61];
u1(pi/70368744177664) q[107];
cx q[107],q[62];
u1(-pi/70368744177664) q[62];
cx q[107],q[62];
u1(pi/70368744177664) q[62];
u1(pi/35184372088832) q[107];
cx q[107],q[63];
u1(-pi/35184372088832) q[63];
cx q[107],q[63];
u1(pi/35184372088832) q[63];
u1(pi/17592186044416) q[107];
cx q[107],q[64];
u1(-pi/17592186044416) q[64];
cx q[107],q[64];
u1(pi/17592186044416) q[64];
u1(pi/8796093022208) q[107];
cx q[107],q[65];
u1(-pi/8796093022208) q[65];
cx q[107],q[65];
u1(pi/8796093022208) q[65];
u1(pi/4398046511104) q[107];
cx q[107],q[66];
u1(-pi/4398046511104) q[66];
cx q[107],q[66];
u1(pi/4398046511104) q[66];
u1(pi/2199023255552) q[107];
cx q[107],q[67];
u1(-pi/2199023255552) q[67];
cx q[107],q[67];
u1(pi/2199023255552) q[67];
u1(pi/1099511627776) q[107];
cx q[107],q[68];
u1(-pi/1099511627776) q[68];
cx q[107],q[68];
u1(pi/1099511627776) q[68];
u1(pi/549755813888) q[107];
cx q[107],q[69];
u1(-pi/549755813888) q[69];
cx q[107],q[69];
u1(pi/549755813888) q[69];
u1(pi/274877906944) q[107];
cx q[107],q[70];
u1(-pi/274877906944) q[70];
cx q[107],q[70];
u1(pi/274877906944) q[70];
u1(pi/137438953472) q[107];
cx q[107],q[71];
u1(-pi/137438953472) q[71];
cx q[107],q[71];
u1(pi/137438953472) q[71];
u1(pi/68719476736) q[107];
cx q[107],q[72];
u1(-pi/68719476736) q[72];
cx q[107],q[72];
u1(pi/68719476736) q[72];
u1(pi/34359738368) q[107];
cx q[107],q[73];
u1(-pi/34359738368) q[73];
cx q[107],q[73];
u1(pi/34359738368) q[73];
u1(pi/17179869184) q[107];
cx q[107],q[74];
u1(-pi/17179869184) q[74];
cx q[107],q[74];
u1(pi/17179869184) q[74];
u1(pi/8589934592) q[107];
cx q[107],q[75];
u1(-pi/8589934592) q[75];
cx q[107],q[75];
u1(pi/8589934592) q[75];
u1(pi/4294967296) q[107];
cx q[107],q[76];
u1(-pi/4294967296) q[76];
cx q[107],q[76];
u1(pi/4294967296) q[76];
u1(pi/2147483648) q[107];
cx q[107],q[77];
u1(-pi/2147483648) q[77];
cx q[107],q[77];
u1(pi/2147483648) q[77];
u1(pi/1073741824) q[107];
cx q[107],q[78];
u1(-pi/1073741824) q[78];
cx q[107],q[78];
u1(pi/1073741824) q[78];
u1(pi/536870912) q[107];
cx q[107],q[79];
u1(-pi/536870912) q[79];
cx q[107],q[79];
u1(pi/536870912) q[79];
u1(pi/268435456) q[107];
cx q[107],q[80];
u1(-pi/268435456) q[80];
cx q[107],q[80];
u1(pi/268435456) q[80];
u1(pi/134217728) q[107];
cx q[107],q[81];
u1(-pi/134217728) q[81];
cx q[107],q[81];
u1(pi/134217728) q[81];
u1(pi/67108864) q[107];
cx q[107],q[82];
u1(-pi/67108864) q[82];
cx q[107],q[82];
u1(pi/67108864) q[82];
u1(pi/33554432) q[107];
cx q[107],q[83];
u1(-pi/33554432) q[83];
cx q[107],q[83];
u1(pi/33554432) q[83];
u1(pi/16777216) q[107];
cx q[107],q[84];
u1(-pi/16777216) q[84];
cx q[107],q[84];
u1(pi/16777216) q[84];
u1(pi/8388608) q[107];
cx q[107],q[85];
u1(-pi/8388608) q[85];
cx q[107],q[85];
u1(pi/8388608) q[85];
u1(pi/4194304) q[107];
cx q[107],q[86];
u1(-pi/4194304) q[86];
cx q[107],q[86];
u1(pi/4194304) q[86];
u1(pi/2097152) q[107];
cx q[107],q[87];
u1(-pi/2097152) q[87];
cx q[107],q[87];
u1(pi/2097152) q[87];
u1(pi/1048576) q[107];
cx q[107],q[88];
u1(-pi/1048576) q[88];
cx q[107],q[88];
u1(pi/1048576) q[88];
u1(pi/524288) q[107];
cx q[107],q[89];
u1(-pi/524288) q[89];
cx q[107],q[89];
u1(pi/524288) q[89];
u1(pi/262144) q[107];
cx q[107],q[90];
u1(-pi/262144) q[90];
cx q[107],q[90];
u1(pi/262144) q[90];
u1(pi/131072) q[107];
cx q[107],q[91];
u1(-pi/131072) q[91];
cx q[107],q[91];
u1(pi/131072) q[91];
u1(pi/65536) q[107];
cx q[107],q[92];
u1(-pi/65536) q[92];
cx q[107],q[92];
u1(pi/65536) q[92];
u1(pi/32768) q[107];
cx q[107],q[93];
u1(-pi/32768) q[93];
cx q[107],q[93];
u1(pi/32768) q[93];
u1(pi/16384) q[107];
cx q[107],q[94];
u1(-pi/16384) q[94];
cx q[107],q[94];
u1(pi/16384) q[94];
u1(pi/8192) q[107];
cx q[107],q[95];
u1(-pi/8192) q[95];
cx q[107],q[95];
u1(pi/8192) q[95];
u1(pi/4096) q[107];
cx q[107],q[96];
u1(-pi/4096) q[96];
cx q[107],q[96];
u1(pi/4096) q[96];
u1(pi/2048) q[107];
cx q[107],q[97];
u1(-pi/2048) q[97];
cx q[107],q[97];
u1(pi/2048) q[97];
u1(pi/1024) q[107];
cx q[107],q[98];
u1(-pi/1024) q[98];
cx q[107],q[98];
u1(pi/1024) q[98];
u1(pi/512) q[107];
cx q[107],q[99];
u1(-pi/512) q[99];
cx q[107],q[99];
u1(pi/512) q[99];
u1(pi/256) q[107];
cx q[107],q[100];
u1(-pi/256) q[100];
cx q[107],q[100];
u1(pi/256) q[100];
u1(pi/128) q[107];
cx q[107],q[101];
u1(-pi/128) q[101];
cx q[107],q[101];
u1(pi/128) q[101];
u1(pi/64) q[107];
cx q[107],q[102];
u1(-pi/64) q[102];
cx q[107],q[102];
u1(pi/64) q[102];
u1(pi/32) q[107];
cx q[107],q[103];
u1(-pi/32) q[103];
cx q[107],q[103];
u1(pi/32) q[103];
u1(pi/16) q[107];
cx q[107],q[104];
u1(-pi/16) q[104];
cx q[107],q[104];
u1(pi/16) q[104];
u1(pi/8) q[107];
cx q[107],q[105];
u1(-pi/8) q[105];
cx q[107],q[105];
u1(pi/8) q[105];
u1(pi/4) q[107];
cx q[107],q[106];
u1(-pi/4) q[106];
cx q[107],q[106];
u1(pi/4) q[106];
h q[107];
u1(0) q[108];
cx q[108],q[0];
u1(0) q[0];
cx q[108],q[0];
u1(0) q[0];
u1(0) q[108];
cx q[108],q[1];
u1(0) q[1];
cx q[108],q[1];
u1(0) q[1];
u1(0) q[108];
cx q[108],q[2];
u1(0) q[2];
cx q[108],q[2];
u1(0) q[2];
u1(0) q[108];
cx q[108],q[3];
u1(0) q[3];
cx q[108],q[3];
u1(0) q[3];
u1(0) q[108];
cx q[108],q[4];
u1(0) q[4];
cx q[108],q[4];
u1(0) q[4];
u1(0) q[108];
cx q[108],q[5];
u1(0) q[5];
cx q[108],q[5];
u1(0) q[5];
u1(0) q[108];
cx q[108],q[6];
u1(0) q[6];
cx q[108],q[6];
u1(0) q[6];
u1(0) q[108];
cx q[108],q[7];
u1(0) q[7];
cx q[108],q[7];
u1(0) q[7];
u1(0) q[108];
cx q[108],q[8];
u1(0) q[8];
cx q[108],q[8];
u1(0) q[8];
u1(0) q[108];
cx q[108],q[9];
u1(0) q[9];
cx q[108],q[9];
u1(0) q[9];
u1(0) q[108];
cx q[108],q[10];
u1(0) q[10];
cx q[108],q[10];
u1(0) q[10];
u1(0) q[108];
cx q[108],q[11];
u1(0) q[11];
cx q[108],q[11];
u1(0) q[11];
u1(0) q[108];
cx q[108],q[12];
u1(0) q[12];
cx q[108],q[12];
u1(0) q[12];
u1(0) q[108];
cx q[108],q[13];
u1(0) q[13];
cx q[108],q[13];
u1(0) q[13];
u1(0) q[108];
cx q[108],q[14];
u1(0) q[14];
cx q[108],q[14];
u1(0) q[14];
u1(0) q[108];
cx q[108],q[15];
u1(0) q[15];
cx q[108],q[15];
u1(0) q[15];
u1(0) q[108];
cx q[108],q[16];
u1(0) q[16];
cx q[108],q[16];
u1(0) q[16];
u1(0) q[108];
cx q[108],q[17];
u1(0) q[17];
cx q[108],q[17];
u1(0) q[17];
u1(0) q[108];
cx q[108],q[18];
u1(0) q[18];
cx q[108],q[18];
u1(0) q[18];
u1(0) q[108];
cx q[108],q[19];
u1(0) q[19];
cx q[108],q[19];
u1(0) q[19];
u1(0) q[108];
cx q[108],q[20];
u1(0) q[20];
cx q[108],q[20];
u1(0) q[20];
u1(0) q[108];
cx q[108],q[21];
u1(0) q[21];
cx q[108],q[21];
u1(0) q[21];
u1(0) q[108];
cx q[108],q[22];
u1(0) q[22];
cx q[108],q[22];
u1(0) q[22];
u1(0) q[108];
cx q[108],q[23];
u1(0) q[23];
cx q[108],q[23];
u1(0) q[23];
u1(0) q[108];
cx q[108],q[24];
u1(0) q[24];
cx q[108],q[24];
u1(0) q[24];
u1(0) q[108];
cx q[108],q[25];
u1(0) q[25];
cx q[108],q[25];
u1(0) q[25];
u1(0) q[108];
cx q[108],q[26];
u1(0) q[26];
cx q[108],q[26];
u1(0) q[26];
u1(0) q[108];
cx q[108],q[27];
u1(0) q[27];
cx q[108],q[27];
u1(0) q[27];
u1(0) q[108];
cx q[108],q[28];
u1(0) q[28];
cx q[108],q[28];
u1(0) q[28];
u1(0) q[108];
cx q[108],q[29];
u1(0) q[29];
cx q[108],q[29];
u1(0) q[29];
u1(0) q[108];
cx q[108],q[30];
u1(0) q[30];
cx q[108],q[30];
u1(0) q[30];
u1(0) q[108];
cx q[108],q[31];
u1(0) q[31];
cx q[108],q[31];
u1(0) q[31];
u1(0) q[108];
cx q[108],q[32];
u1(0) q[32];
cx q[108],q[32];
u1(0) q[32];
u1(0) q[108];
cx q[108],q[33];
u1(0) q[33];
cx q[108],q[33];
u1(0) q[33];
u1(0) q[108];
cx q[108],q[34];
u1(0) q[34];
cx q[108],q[34];
u1(0) q[34];
u1(0) q[108];
cx q[108],q[35];
u1(0) q[35];
cx q[108],q[35];
u1(0) q[35];
u1(0) q[108];
cx q[108],q[36];
u1(0) q[36];
cx q[108],q[36];
u1(0) q[36];
u1(0) q[108];
cx q[108],q[37];
u1(0) q[37];
cx q[108],q[37];
u1(0) q[37];
u1(0) q[108];
cx q[108],q[38];
u1(0) q[38];
cx q[108],q[38];
u1(0) q[38];
u1(0) q[108];
cx q[108],q[39];
u1(0) q[39];
cx q[108],q[39];
u1(0) q[39];
u1(0) q[108];
cx q[108],q[40];
u1(0) q[40];
cx q[108],q[40];
u1(0) q[40];
u1(0) q[108];
cx q[108],q[41];
u1(0) q[41];
cx q[108],q[41];
u1(0) q[41];
u1(0) q[108];
cx q[108],q[42];
u1(0) q[42];
cx q[108],q[42];
u1(0) q[42];
u1(0) q[108];
cx q[108],q[43];
u1(0) q[43];
cx q[108],q[43];
u1(0) q[43];
u1(0) q[108];
cx q[108],q[44];
u1(0) q[44];
cx q[108],q[44];
u1(0) q[44];
u1(0) q[108];
cx q[108],q[45];
u1(0) q[45];
cx q[108],q[45];
u1(0) q[45];
u1(0) q[108];
cx q[108],q[46];
u1(0) q[46];
cx q[108],q[46];
u1(0) q[46];
u1(0) q[108];
cx q[108],q[47];
u1(0) q[47];
cx q[108],q[47];
u1(0) q[47];
u1(0) q[108];
cx q[108],q[48];
u1(0) q[48];
cx q[108],q[48];
u1(0) q[48];
u1(0) q[108];
cx q[108],q[49];
u1(0) q[49];
cx q[108],q[49];
u1(0) q[49];
u1(0) q[108];
cx q[108],q[50];
u1(0) q[50];
cx q[108],q[50];
u1(0) q[50];
u1(0) q[108];
cx q[108],q[51];
u1(0) q[51];
cx q[108],q[51];
u1(0) q[51];
u1(0) q[108];
cx q[108],q[52];
u1(0) q[52];
cx q[108],q[52];
u1(0) q[52];
u1(0) q[108];
cx q[108],q[53];
u1(0) q[53];
cx q[108],q[53];
u1(0) q[53];
u1(0) q[108];
cx q[108],q[54];
u1(0) q[54];
cx q[108],q[54];
u1(0) q[54];
u1(0) q[108];
cx q[108],q[55];
u1(0) q[55];
cx q[108],q[55];
u1(0) q[55];
u1(0) q[108];
cx q[108],q[56];
u1(0) q[56];
cx q[108],q[56];
u1(0) q[56];
u1(0) q[108];
cx q[108],q[57];
u1(0) q[57];
cx q[108],q[57];
u1(0) q[57];
u1(0) q[108];
cx q[108],q[58];
u1(0) q[58];
cx q[108],q[58];
u1(0) q[58];
u1(0) q[108];
cx q[108],q[59];
u1(0) q[59];
cx q[108],q[59];
u1(0) q[59];
u1(0) q[108];
cx q[108],q[60];
u1(0) q[60];
cx q[108],q[60];
u1(0) q[60];
u1(pi/281474976710656) q[108];
cx q[108],q[61];
u1(-pi/281474976710656) q[61];
cx q[108],q[61];
u1(pi/281474976710656) q[61];
u1(pi/140737488355328) q[108];
cx q[108],q[62];
u1(-pi/140737488355328) q[62];
cx q[108],q[62];
u1(pi/140737488355328) q[62];
u1(pi/70368744177664) q[108];
cx q[108],q[63];
u1(-pi/70368744177664) q[63];
cx q[108],q[63];
u1(pi/70368744177664) q[63];
u1(pi/35184372088832) q[108];
cx q[108],q[64];
u1(-pi/35184372088832) q[64];
cx q[108],q[64];
u1(pi/35184372088832) q[64];
u1(pi/17592186044416) q[108];
cx q[108],q[65];
u1(-pi/17592186044416) q[65];
cx q[108],q[65];
u1(pi/17592186044416) q[65];
u1(pi/8796093022208) q[108];
cx q[108],q[66];
u1(-pi/8796093022208) q[66];
cx q[108],q[66];
u1(pi/8796093022208) q[66];
u1(pi/4398046511104) q[108];
cx q[108],q[67];
u1(-pi/4398046511104) q[67];
cx q[108],q[67];
u1(pi/4398046511104) q[67];
u1(pi/2199023255552) q[108];
cx q[108],q[68];
u1(-pi/2199023255552) q[68];
cx q[108],q[68];
u1(pi/2199023255552) q[68];
u1(pi/1099511627776) q[108];
cx q[108],q[69];
u1(-pi/1099511627776) q[69];
cx q[108],q[69];
u1(pi/1099511627776) q[69];
u1(pi/549755813888) q[108];
cx q[108],q[70];
u1(-pi/549755813888) q[70];
cx q[108],q[70];
u1(pi/549755813888) q[70];
u1(pi/274877906944) q[108];
cx q[108],q[71];
u1(-pi/274877906944) q[71];
cx q[108],q[71];
u1(pi/274877906944) q[71];
u1(pi/137438953472) q[108];
cx q[108],q[72];
u1(-pi/137438953472) q[72];
cx q[108],q[72];
u1(pi/137438953472) q[72];
u1(pi/68719476736) q[108];
cx q[108],q[73];
u1(-pi/68719476736) q[73];
cx q[108],q[73];
u1(pi/68719476736) q[73];
u1(pi/34359738368) q[108];
cx q[108],q[74];
u1(-pi/34359738368) q[74];
cx q[108],q[74];
u1(pi/34359738368) q[74];
u1(pi/17179869184) q[108];
cx q[108],q[75];
u1(-pi/17179869184) q[75];
cx q[108],q[75];
u1(pi/17179869184) q[75];
u1(pi/8589934592) q[108];
cx q[108],q[76];
u1(-pi/8589934592) q[76];
cx q[108],q[76];
u1(pi/8589934592) q[76];
u1(pi/4294967296) q[108];
cx q[108],q[77];
u1(-pi/4294967296) q[77];
cx q[108],q[77];
u1(pi/4294967296) q[77];
u1(pi/2147483648) q[108];
cx q[108],q[78];
u1(-pi/2147483648) q[78];
cx q[108],q[78];
u1(pi/2147483648) q[78];
u1(pi/1073741824) q[108];
cx q[108],q[79];
u1(-pi/1073741824) q[79];
cx q[108],q[79];
u1(pi/1073741824) q[79];
u1(pi/536870912) q[108];
cx q[108],q[80];
u1(-pi/536870912) q[80];
cx q[108],q[80];
u1(pi/536870912) q[80];
u1(pi/268435456) q[108];
cx q[108],q[81];
u1(-pi/268435456) q[81];
cx q[108],q[81];
u1(pi/268435456) q[81];
u1(pi/134217728) q[108];
cx q[108],q[82];
u1(-pi/134217728) q[82];
cx q[108],q[82];
u1(pi/134217728) q[82];
u1(pi/67108864) q[108];
cx q[108],q[83];
u1(-pi/67108864) q[83];
cx q[108],q[83];
u1(pi/67108864) q[83];
u1(pi/33554432) q[108];
cx q[108],q[84];
u1(-pi/33554432) q[84];
cx q[108],q[84];
u1(pi/33554432) q[84];
u1(pi/16777216) q[108];
cx q[108],q[85];
u1(-pi/16777216) q[85];
cx q[108],q[85];
u1(pi/16777216) q[85];
u1(pi/8388608) q[108];
cx q[108],q[86];
u1(-pi/8388608) q[86];
cx q[108],q[86];
u1(pi/8388608) q[86];
u1(pi/4194304) q[108];
cx q[108],q[87];
u1(-pi/4194304) q[87];
cx q[108],q[87];
u1(pi/4194304) q[87];
u1(pi/2097152) q[108];
cx q[108],q[88];
u1(-pi/2097152) q[88];
cx q[108],q[88];
u1(pi/2097152) q[88];
u1(pi/1048576) q[108];
cx q[108],q[89];
u1(-pi/1048576) q[89];
cx q[108],q[89];
u1(pi/1048576) q[89];
u1(pi/524288) q[108];
cx q[108],q[90];
u1(-pi/524288) q[90];
cx q[108],q[90];
u1(pi/524288) q[90];
u1(pi/262144) q[108];
cx q[108],q[91];
u1(-pi/262144) q[91];
cx q[108],q[91];
u1(pi/262144) q[91];
u1(pi/131072) q[108];
cx q[108],q[92];
u1(-pi/131072) q[92];
cx q[108],q[92];
u1(pi/131072) q[92];
u1(pi/65536) q[108];
cx q[108],q[93];
u1(-pi/65536) q[93];
cx q[108],q[93];
u1(pi/65536) q[93];
u1(pi/32768) q[108];
cx q[108],q[94];
u1(-pi/32768) q[94];
cx q[108],q[94];
u1(pi/32768) q[94];
u1(pi/16384) q[108];
cx q[108],q[95];
u1(-pi/16384) q[95];
cx q[108],q[95];
u1(pi/16384) q[95];
u1(pi/8192) q[108];
cx q[108],q[96];
u1(-pi/8192) q[96];
cx q[108],q[96];
u1(pi/8192) q[96];
u1(pi/4096) q[108];
cx q[108],q[97];
u1(-pi/4096) q[97];
cx q[108],q[97];
u1(pi/4096) q[97];
u1(pi/2048) q[108];
cx q[108],q[98];
u1(-pi/2048) q[98];
cx q[108],q[98];
u1(pi/2048) q[98];
u1(pi/1024) q[108];
cx q[108],q[99];
u1(-pi/1024) q[99];
cx q[108],q[99];
u1(pi/1024) q[99];
u1(pi/512) q[108];
cx q[108],q[100];
u1(-pi/512) q[100];
cx q[108],q[100];
u1(pi/512) q[100];
u1(pi/256) q[108];
cx q[108],q[101];
u1(-pi/256) q[101];
cx q[108],q[101];
u1(pi/256) q[101];
u1(pi/128) q[108];
cx q[108],q[102];
u1(-pi/128) q[102];
cx q[108],q[102];
u1(pi/128) q[102];
u1(pi/64) q[108];
cx q[108],q[103];
u1(-pi/64) q[103];
cx q[108],q[103];
u1(pi/64) q[103];
u1(pi/32) q[108];
cx q[108],q[104];
u1(-pi/32) q[104];
cx q[108],q[104];
u1(pi/32) q[104];
u1(pi/16) q[108];
cx q[108],q[105];
u1(-pi/16) q[105];
cx q[108],q[105];
u1(pi/16) q[105];
u1(pi/8) q[108];
cx q[108],q[106];
u1(-pi/8) q[106];
cx q[108],q[106];
u1(pi/8) q[106];
u1(pi/4) q[108];
cx q[108],q[107];
u1(-pi/4) q[107];
cx q[108],q[107];
u1(pi/4) q[107];
h q[108];
u1(0) q[109];
cx q[109],q[0];
u1(0) q[0];
cx q[109],q[0];
u1(0) q[0];
u1(0) q[109];
cx q[109],q[1];
u1(0) q[1];
cx q[109],q[1];
u1(0) q[1];
u1(0) q[109];
cx q[109],q[2];
u1(0) q[2];
cx q[109],q[2];
u1(0) q[2];
u1(0) q[109];
cx q[109],q[3];
u1(0) q[3];
cx q[109],q[3];
u1(0) q[3];
u1(0) q[109];
cx q[109],q[4];
u1(0) q[4];
cx q[109],q[4];
u1(0) q[4];
u1(0) q[109];
cx q[109],q[5];
u1(0) q[5];
cx q[109],q[5];
u1(0) q[5];
u1(0) q[109];
cx q[109],q[6];
u1(0) q[6];
cx q[109],q[6];
u1(0) q[6];
u1(0) q[109];
cx q[109],q[7];
u1(0) q[7];
cx q[109],q[7];
u1(0) q[7];
u1(0) q[109];
cx q[109],q[8];
u1(0) q[8];
cx q[109],q[8];
u1(0) q[8];
u1(0) q[109];
cx q[109],q[9];
u1(0) q[9];
cx q[109],q[9];
u1(0) q[9];
u1(0) q[109];
cx q[109],q[10];
u1(0) q[10];
cx q[109],q[10];
u1(0) q[10];
u1(0) q[109];
cx q[109],q[11];
u1(0) q[11];
cx q[109],q[11];
u1(0) q[11];
u1(0) q[109];
cx q[109],q[12];
u1(0) q[12];
cx q[109],q[12];
u1(0) q[12];
u1(0) q[109];
cx q[109],q[13];
u1(0) q[13];
cx q[109],q[13];
u1(0) q[13];
u1(0) q[109];
cx q[109],q[14];
u1(0) q[14];
cx q[109],q[14];
u1(0) q[14];
u1(0) q[109];
cx q[109],q[15];
u1(0) q[15];
cx q[109],q[15];
u1(0) q[15];
u1(0) q[109];
cx q[109],q[16];
u1(0) q[16];
cx q[109],q[16];
u1(0) q[16];
u1(0) q[109];
cx q[109],q[17];
u1(0) q[17];
cx q[109],q[17];
u1(0) q[17];
u1(0) q[109];
cx q[109],q[18];
u1(0) q[18];
cx q[109],q[18];
u1(0) q[18];
u1(0) q[109];
cx q[109],q[19];
u1(0) q[19];
cx q[109],q[19];
u1(0) q[19];
u1(0) q[109];
cx q[109],q[20];
u1(0) q[20];
cx q[109],q[20];
u1(0) q[20];
u1(0) q[109];
cx q[109],q[21];
u1(0) q[21];
cx q[109],q[21];
u1(0) q[21];
u1(0) q[109];
cx q[109],q[22];
u1(0) q[22];
cx q[109],q[22];
u1(0) q[22];
u1(0) q[109];
cx q[109],q[23];
u1(0) q[23];
cx q[109],q[23];
u1(0) q[23];
u1(0) q[109];
cx q[109],q[24];
u1(0) q[24];
cx q[109],q[24];
u1(0) q[24];
u1(0) q[109];
cx q[109],q[25];
u1(0) q[25];
cx q[109],q[25];
u1(0) q[25];
u1(0) q[109];
cx q[109],q[26];
u1(0) q[26];
cx q[109],q[26];
u1(0) q[26];
u1(0) q[109];
cx q[109],q[27];
u1(0) q[27];
cx q[109],q[27];
u1(0) q[27];
u1(0) q[109];
cx q[109],q[28];
u1(0) q[28];
cx q[109],q[28];
u1(0) q[28];
u1(0) q[109];
cx q[109],q[29];
u1(0) q[29];
cx q[109],q[29];
u1(0) q[29];
u1(0) q[109];
cx q[109],q[30];
u1(0) q[30];
cx q[109],q[30];
u1(0) q[30];
u1(0) q[109];
cx q[109],q[31];
u1(0) q[31];
cx q[109],q[31];
u1(0) q[31];
u1(0) q[109];
cx q[109],q[32];
u1(0) q[32];
cx q[109],q[32];
u1(0) q[32];
u1(0) q[109];
cx q[109],q[33];
u1(0) q[33];
cx q[109],q[33];
u1(0) q[33];
u1(0) q[109];
cx q[109],q[34];
u1(0) q[34];
cx q[109],q[34];
u1(0) q[34];
u1(0) q[109];
cx q[109],q[35];
u1(0) q[35];
cx q[109],q[35];
u1(0) q[35];
u1(0) q[109];
cx q[109],q[36];
u1(0) q[36];
cx q[109],q[36];
u1(0) q[36];
u1(0) q[109];
cx q[109],q[37];
u1(0) q[37];
cx q[109],q[37];
u1(0) q[37];
u1(0) q[109];
cx q[109],q[38];
u1(0) q[38];
cx q[109],q[38];
u1(0) q[38];
u1(0) q[109];
cx q[109],q[39];
u1(0) q[39];
cx q[109],q[39];
u1(0) q[39];
u1(0) q[109];
cx q[109],q[40];
u1(0) q[40];
cx q[109],q[40];
u1(0) q[40];
u1(0) q[109];
cx q[109],q[41];
u1(0) q[41];
cx q[109],q[41];
u1(0) q[41];
u1(0) q[109];
cx q[109],q[42];
u1(0) q[42];
cx q[109],q[42];
u1(0) q[42];
u1(0) q[109];
cx q[109],q[43];
u1(0) q[43];
cx q[109],q[43];
u1(0) q[43];
u1(0) q[109];
cx q[109],q[44];
u1(0) q[44];
cx q[109],q[44];
u1(0) q[44];
u1(0) q[109];
cx q[109],q[45];
u1(0) q[45];
cx q[109],q[45];
u1(0) q[45];
u1(0) q[109];
cx q[109],q[46];
u1(0) q[46];
cx q[109],q[46];
u1(0) q[46];
u1(0) q[109];
cx q[109],q[47];
u1(0) q[47];
cx q[109],q[47];
u1(0) q[47];
u1(0) q[109];
cx q[109],q[48];
u1(0) q[48];
cx q[109],q[48];
u1(0) q[48];
u1(0) q[109];
cx q[109],q[49];
u1(0) q[49];
cx q[109],q[49];
u1(0) q[49];
u1(0) q[109];
cx q[109],q[50];
u1(0) q[50];
cx q[109],q[50];
u1(0) q[50];
u1(0) q[109];
cx q[109],q[51];
u1(0) q[51];
cx q[109],q[51];
u1(0) q[51];
u1(0) q[109];
cx q[109],q[52];
u1(0) q[52];
cx q[109],q[52];
u1(0) q[52];
u1(0) q[109];
cx q[109],q[53];
u1(0) q[53];
cx q[109],q[53];
u1(0) q[53];
u1(0) q[109];
cx q[109],q[54];
u1(0) q[54];
cx q[109],q[54];
u1(0) q[54];
u1(0) q[109];
cx q[109],q[55];
u1(0) q[55];
cx q[109],q[55];
u1(0) q[55];
u1(0) q[109];
cx q[109],q[56];
u1(0) q[56];
cx q[109],q[56];
u1(0) q[56];
u1(0) q[109];
cx q[109],q[57];
u1(0) q[57];
cx q[109],q[57];
u1(0) q[57];
u1(0) q[109];
cx q[109],q[58];
u1(0) q[58];
cx q[109],q[58];
u1(0) q[58];
u1(0) q[109];
cx q[109],q[59];
u1(0) q[59];
cx q[109],q[59];
u1(0) q[59];
u1(0) q[109];
cx q[109],q[60];
u1(0) q[60];
cx q[109],q[60];
u1(0) q[60];
u1(0) q[109];
cx q[109],q[61];
u1(0) q[61];
cx q[109],q[61];
u1(0) q[61];
u1(pi/281474976710656) q[109];
cx q[109],q[62];
u1(-pi/281474976710656) q[62];
cx q[109],q[62];
u1(pi/281474976710656) q[62];
u1(pi/140737488355328) q[109];
cx q[109],q[63];
u1(-pi/140737488355328) q[63];
cx q[109],q[63];
u1(pi/140737488355328) q[63];
u1(pi/70368744177664) q[109];
cx q[109],q[64];
u1(-pi/70368744177664) q[64];
cx q[109],q[64];
u1(pi/70368744177664) q[64];
u1(pi/35184372088832) q[109];
cx q[109],q[65];
u1(-pi/35184372088832) q[65];
cx q[109],q[65];
u1(pi/35184372088832) q[65];
u1(pi/17592186044416) q[109];
cx q[109],q[66];
u1(-pi/17592186044416) q[66];
cx q[109],q[66];
u1(pi/17592186044416) q[66];
u1(pi/8796093022208) q[109];
cx q[109],q[67];
u1(-pi/8796093022208) q[67];
cx q[109],q[67];
u1(pi/8796093022208) q[67];
u1(pi/4398046511104) q[109];
cx q[109],q[68];
u1(-pi/4398046511104) q[68];
cx q[109],q[68];
u1(pi/4398046511104) q[68];
u1(pi/2199023255552) q[109];
cx q[109],q[69];
u1(-pi/2199023255552) q[69];
cx q[109],q[69];
u1(pi/2199023255552) q[69];
u1(pi/1099511627776) q[109];
cx q[109],q[70];
u1(-pi/1099511627776) q[70];
cx q[109],q[70];
u1(pi/1099511627776) q[70];
u1(pi/549755813888) q[109];
cx q[109],q[71];
u1(-pi/549755813888) q[71];
cx q[109],q[71];
u1(pi/549755813888) q[71];
u1(pi/274877906944) q[109];
cx q[109],q[72];
u1(-pi/274877906944) q[72];
cx q[109],q[72];
u1(pi/274877906944) q[72];
u1(pi/137438953472) q[109];
cx q[109],q[73];
u1(-pi/137438953472) q[73];
cx q[109],q[73];
u1(pi/137438953472) q[73];
u1(pi/68719476736) q[109];
cx q[109],q[74];
u1(-pi/68719476736) q[74];
cx q[109],q[74];
u1(pi/68719476736) q[74];
u1(pi/34359738368) q[109];
cx q[109],q[75];
u1(-pi/34359738368) q[75];
cx q[109],q[75];
u1(pi/34359738368) q[75];
u1(pi/17179869184) q[109];
cx q[109],q[76];
u1(-pi/17179869184) q[76];
cx q[109],q[76];
u1(pi/17179869184) q[76];
u1(pi/8589934592) q[109];
cx q[109],q[77];
u1(-pi/8589934592) q[77];
cx q[109],q[77];
u1(pi/8589934592) q[77];
u1(pi/4294967296) q[109];
cx q[109],q[78];
u1(-pi/4294967296) q[78];
cx q[109],q[78];
u1(pi/4294967296) q[78];
u1(pi/2147483648) q[109];
cx q[109],q[79];
u1(-pi/2147483648) q[79];
cx q[109],q[79];
u1(pi/2147483648) q[79];
u1(pi/1073741824) q[109];
cx q[109],q[80];
u1(-pi/1073741824) q[80];
cx q[109],q[80];
u1(pi/1073741824) q[80];
u1(pi/536870912) q[109];
cx q[109],q[81];
u1(-pi/536870912) q[81];
cx q[109],q[81];
u1(pi/536870912) q[81];
u1(pi/268435456) q[109];
cx q[109],q[82];
u1(-pi/268435456) q[82];
cx q[109],q[82];
u1(pi/268435456) q[82];
u1(pi/134217728) q[109];
cx q[109],q[83];
u1(-pi/134217728) q[83];
cx q[109],q[83];
u1(pi/134217728) q[83];
u1(pi/67108864) q[109];
cx q[109],q[84];
u1(-pi/67108864) q[84];
cx q[109],q[84];
u1(pi/67108864) q[84];
u1(pi/33554432) q[109];
cx q[109],q[85];
u1(-pi/33554432) q[85];
cx q[109],q[85];
u1(pi/33554432) q[85];
u1(pi/16777216) q[109];
cx q[109],q[86];
u1(-pi/16777216) q[86];
cx q[109],q[86];
u1(pi/16777216) q[86];
u1(pi/8388608) q[109];
cx q[109],q[87];
u1(-pi/8388608) q[87];
cx q[109],q[87];
u1(pi/8388608) q[87];
u1(pi/4194304) q[109];
cx q[109],q[88];
u1(-pi/4194304) q[88];
cx q[109],q[88];
u1(pi/4194304) q[88];
u1(pi/2097152) q[109];
cx q[109],q[89];
u1(-pi/2097152) q[89];
cx q[109],q[89];
u1(pi/2097152) q[89];
u1(pi/1048576) q[109];
cx q[109],q[90];
u1(-pi/1048576) q[90];
cx q[109],q[90];
u1(pi/1048576) q[90];
u1(pi/524288) q[109];
cx q[109],q[91];
u1(-pi/524288) q[91];
cx q[109],q[91];
u1(pi/524288) q[91];
u1(pi/262144) q[109];
cx q[109],q[92];
u1(-pi/262144) q[92];
cx q[109],q[92];
u1(pi/262144) q[92];
u1(pi/131072) q[109];
cx q[109],q[93];
u1(-pi/131072) q[93];
cx q[109],q[93];
u1(pi/131072) q[93];
u1(pi/65536) q[109];
cx q[109],q[94];
u1(-pi/65536) q[94];
cx q[109],q[94];
u1(pi/65536) q[94];
u1(pi/32768) q[109];
cx q[109],q[95];
u1(-pi/32768) q[95];
cx q[109],q[95];
u1(pi/32768) q[95];
u1(pi/16384) q[109];
cx q[109],q[96];
u1(-pi/16384) q[96];
cx q[109],q[96];
u1(pi/16384) q[96];
u1(pi/8192) q[109];
cx q[109],q[97];
u1(-pi/8192) q[97];
cx q[109],q[97];
u1(pi/8192) q[97];
u1(pi/4096) q[109];
cx q[109],q[98];
u1(-pi/4096) q[98];
cx q[109],q[98];
u1(pi/4096) q[98];
u1(pi/2048) q[109];
cx q[109],q[99];
u1(-pi/2048) q[99];
cx q[109],q[99];
u1(pi/2048) q[99];
u1(pi/1024) q[109];
cx q[109],q[100];
u1(-pi/1024) q[100];
cx q[109],q[100];
u1(pi/1024) q[100];
u1(pi/512) q[109];
cx q[109],q[101];
u1(-pi/512) q[101];
cx q[109],q[101];
u1(pi/512) q[101];
u1(pi/256) q[109];
cx q[109],q[102];
u1(-pi/256) q[102];
cx q[109],q[102];
u1(pi/256) q[102];
u1(pi/128) q[109];
cx q[109],q[103];
u1(-pi/128) q[103];
cx q[109],q[103];
u1(pi/128) q[103];
u1(pi/64) q[109];
cx q[109],q[104];
u1(-pi/64) q[104];
cx q[109],q[104];
u1(pi/64) q[104];
u1(pi/32) q[109];
cx q[109],q[105];
u1(-pi/32) q[105];
cx q[109],q[105];
u1(pi/32) q[105];
u1(pi/16) q[109];
cx q[109],q[106];
u1(-pi/16) q[106];
cx q[109],q[106];
u1(pi/16) q[106];
u1(pi/8) q[109];
cx q[109],q[107];
u1(-pi/8) q[107];
cx q[109],q[107];
u1(pi/8) q[107];
u1(pi/4) q[109];
cx q[109],q[108];
u1(-pi/4) q[108];
cx q[109],q[108];
u1(pi/4) q[108];
h q[109];
u1(0) q[110];
cx q[110],q[0];
u1(0) q[0];
cx q[110],q[0];
u1(0) q[0];
u1(0) q[110];
cx q[110],q[1];
u1(0) q[1];
cx q[110],q[1];
u1(0) q[1];
u1(0) q[110];
cx q[110],q[2];
u1(0) q[2];
cx q[110],q[2];
u1(0) q[2];
u1(0) q[110];
cx q[110],q[3];
u1(0) q[3];
cx q[110],q[3];
u1(0) q[3];
u1(0) q[110];
cx q[110],q[4];
u1(0) q[4];
cx q[110],q[4];
u1(0) q[4];
u1(0) q[110];
cx q[110],q[5];
u1(0) q[5];
cx q[110],q[5];
u1(0) q[5];
u1(0) q[110];
cx q[110],q[6];
u1(0) q[6];
cx q[110],q[6];
u1(0) q[6];
u1(0) q[110];
cx q[110],q[7];
u1(0) q[7];
cx q[110],q[7];
u1(0) q[7];
u1(0) q[110];
cx q[110],q[8];
u1(0) q[8];
cx q[110],q[8];
u1(0) q[8];
u1(0) q[110];
cx q[110],q[9];
u1(0) q[9];
cx q[110],q[9];
u1(0) q[9];
u1(0) q[110];
cx q[110],q[10];
u1(0) q[10];
cx q[110],q[10];
u1(0) q[10];
u1(0) q[110];
cx q[110],q[11];
u1(0) q[11];
cx q[110],q[11];
u1(0) q[11];
u1(0) q[110];
cx q[110],q[12];
u1(0) q[12];
cx q[110],q[12];
u1(0) q[12];
u1(0) q[110];
cx q[110],q[13];
u1(0) q[13];
cx q[110],q[13];
u1(0) q[13];
u1(0) q[110];
cx q[110],q[14];
u1(0) q[14];
cx q[110],q[14];
u1(0) q[14];
u1(0) q[110];
cx q[110],q[15];
u1(0) q[15];
cx q[110],q[15];
u1(0) q[15];
u1(0) q[110];
cx q[110],q[16];
u1(0) q[16];
cx q[110],q[16];
u1(0) q[16];
u1(0) q[110];
cx q[110],q[17];
u1(0) q[17];
cx q[110],q[17];
u1(0) q[17];
u1(0) q[110];
cx q[110],q[18];
u1(0) q[18];
cx q[110],q[18];
u1(0) q[18];
u1(0) q[110];
cx q[110],q[19];
u1(0) q[19];
cx q[110],q[19];
u1(0) q[19];
u1(0) q[110];
cx q[110],q[20];
u1(0) q[20];
cx q[110],q[20];
u1(0) q[20];
u1(0) q[110];
cx q[110],q[21];
u1(0) q[21];
cx q[110],q[21];
u1(0) q[21];
u1(0) q[110];
cx q[110],q[22];
u1(0) q[22];
cx q[110],q[22];
u1(0) q[22];
u1(0) q[110];
cx q[110],q[23];
u1(0) q[23];
cx q[110],q[23];
u1(0) q[23];
u1(0) q[110];
cx q[110],q[24];
u1(0) q[24];
cx q[110],q[24];
u1(0) q[24];
u1(0) q[110];
cx q[110],q[25];
u1(0) q[25];
cx q[110],q[25];
u1(0) q[25];
u1(0) q[110];
cx q[110],q[26];
u1(0) q[26];
cx q[110],q[26];
u1(0) q[26];
u1(0) q[110];
cx q[110],q[27];
u1(0) q[27];
cx q[110],q[27];
u1(0) q[27];
u1(0) q[110];
cx q[110],q[28];
u1(0) q[28];
cx q[110],q[28];
u1(0) q[28];
u1(0) q[110];
cx q[110],q[29];
u1(0) q[29];
cx q[110],q[29];
u1(0) q[29];
u1(0) q[110];
cx q[110],q[30];
u1(0) q[30];
cx q[110],q[30];
u1(0) q[30];
u1(0) q[110];
cx q[110],q[31];
u1(0) q[31];
cx q[110],q[31];
u1(0) q[31];
u1(0) q[110];
cx q[110],q[32];
u1(0) q[32];
cx q[110],q[32];
u1(0) q[32];
u1(0) q[110];
cx q[110],q[33];
u1(0) q[33];
cx q[110],q[33];
u1(0) q[33];
u1(0) q[110];
cx q[110],q[34];
u1(0) q[34];
cx q[110],q[34];
u1(0) q[34];
u1(0) q[110];
cx q[110],q[35];
u1(0) q[35];
cx q[110],q[35];
u1(0) q[35];
u1(0) q[110];
cx q[110],q[36];
u1(0) q[36];
cx q[110],q[36];
u1(0) q[36];
u1(0) q[110];
cx q[110],q[37];
u1(0) q[37];
cx q[110],q[37];
u1(0) q[37];
u1(0) q[110];
cx q[110],q[38];
u1(0) q[38];
cx q[110],q[38];
u1(0) q[38];
u1(0) q[110];
cx q[110],q[39];
u1(0) q[39];
cx q[110],q[39];
u1(0) q[39];
u1(0) q[110];
cx q[110],q[40];
u1(0) q[40];
cx q[110],q[40];
u1(0) q[40];
u1(0) q[110];
cx q[110],q[41];
u1(0) q[41];
cx q[110],q[41];
u1(0) q[41];
u1(0) q[110];
cx q[110],q[42];
u1(0) q[42];
cx q[110],q[42];
u1(0) q[42];
u1(0) q[110];
cx q[110],q[43];
u1(0) q[43];
cx q[110],q[43];
u1(0) q[43];
u1(0) q[110];
cx q[110],q[44];
u1(0) q[44];
cx q[110],q[44];
u1(0) q[44];
u1(0) q[110];
cx q[110],q[45];
u1(0) q[45];
cx q[110],q[45];
u1(0) q[45];
u1(0) q[110];
cx q[110],q[46];
u1(0) q[46];
cx q[110],q[46];
u1(0) q[46];
u1(0) q[110];
cx q[110],q[47];
u1(0) q[47];
cx q[110],q[47];
u1(0) q[47];
u1(0) q[110];
cx q[110],q[48];
u1(0) q[48];
cx q[110],q[48];
u1(0) q[48];
u1(0) q[110];
cx q[110],q[49];
u1(0) q[49];
cx q[110],q[49];
u1(0) q[49];
u1(0) q[110];
cx q[110],q[50];
u1(0) q[50];
cx q[110],q[50];
u1(0) q[50];
u1(0) q[110];
cx q[110],q[51];
u1(0) q[51];
cx q[110],q[51];
u1(0) q[51];
u1(0) q[110];
cx q[110],q[52];
u1(0) q[52];
cx q[110],q[52];
u1(0) q[52];
u1(0) q[110];
cx q[110],q[53];
u1(0) q[53];
cx q[110],q[53];
u1(0) q[53];
u1(0) q[110];
cx q[110],q[54];
u1(0) q[54];
cx q[110],q[54];
u1(0) q[54];
u1(0) q[110];
cx q[110],q[55];
u1(0) q[55];
cx q[110],q[55];
u1(0) q[55];
u1(0) q[110];
cx q[110],q[56];
u1(0) q[56];
cx q[110],q[56];
u1(0) q[56];
u1(0) q[110];
cx q[110],q[57];
u1(0) q[57];
cx q[110],q[57];
u1(0) q[57];
u1(0) q[110];
cx q[110],q[58];
u1(0) q[58];
cx q[110],q[58];
u1(0) q[58];
u1(0) q[110];
cx q[110],q[59];
u1(0) q[59];
cx q[110],q[59];
u1(0) q[59];
u1(0) q[110];
cx q[110],q[60];
u1(0) q[60];
cx q[110],q[60];
u1(0) q[60];
u1(0) q[110];
cx q[110],q[61];
u1(0) q[61];
cx q[110],q[61];
u1(0) q[61];
u1(0) q[110];
cx q[110],q[62];
u1(0) q[62];
cx q[110],q[62];
u1(0) q[62];
u1(pi/281474976710656) q[110];
cx q[110],q[63];
u1(-pi/281474976710656) q[63];
cx q[110],q[63];
u1(pi/281474976710656) q[63];
u1(pi/140737488355328) q[110];
cx q[110],q[64];
u1(-pi/140737488355328) q[64];
cx q[110],q[64];
u1(pi/140737488355328) q[64];
u1(pi/70368744177664) q[110];
cx q[110],q[65];
u1(-pi/70368744177664) q[65];
cx q[110],q[65];
u1(pi/70368744177664) q[65];
u1(pi/35184372088832) q[110];
cx q[110],q[66];
u1(-pi/35184372088832) q[66];
cx q[110],q[66];
u1(pi/35184372088832) q[66];
u1(pi/17592186044416) q[110];
cx q[110],q[67];
u1(-pi/17592186044416) q[67];
cx q[110],q[67];
u1(pi/17592186044416) q[67];
u1(pi/8796093022208) q[110];
cx q[110],q[68];
u1(-pi/8796093022208) q[68];
cx q[110],q[68];
u1(pi/8796093022208) q[68];
u1(pi/4398046511104) q[110];
cx q[110],q[69];
u1(-pi/4398046511104) q[69];
cx q[110],q[69];
u1(pi/4398046511104) q[69];
u1(pi/2199023255552) q[110];
cx q[110],q[70];
u1(-pi/2199023255552) q[70];
cx q[110],q[70];
u1(pi/2199023255552) q[70];
u1(pi/1099511627776) q[110];
cx q[110],q[71];
u1(-pi/1099511627776) q[71];
cx q[110],q[71];
u1(pi/1099511627776) q[71];
u1(pi/549755813888) q[110];
cx q[110],q[72];
u1(-pi/549755813888) q[72];
cx q[110],q[72];
u1(pi/549755813888) q[72];
u1(pi/274877906944) q[110];
cx q[110],q[73];
u1(-pi/274877906944) q[73];
cx q[110],q[73];
u1(pi/274877906944) q[73];
u1(pi/137438953472) q[110];
cx q[110],q[74];
u1(-pi/137438953472) q[74];
cx q[110],q[74];
u1(pi/137438953472) q[74];
u1(pi/68719476736) q[110];
cx q[110],q[75];
u1(-pi/68719476736) q[75];
cx q[110],q[75];
u1(pi/68719476736) q[75];
u1(pi/34359738368) q[110];
cx q[110],q[76];
u1(-pi/34359738368) q[76];
cx q[110],q[76];
u1(pi/34359738368) q[76];
u1(pi/17179869184) q[110];
cx q[110],q[77];
u1(-pi/17179869184) q[77];
cx q[110],q[77];
u1(pi/17179869184) q[77];
u1(pi/8589934592) q[110];
cx q[110],q[78];
u1(-pi/8589934592) q[78];
cx q[110],q[78];
u1(pi/8589934592) q[78];
u1(pi/4294967296) q[110];
cx q[110],q[79];
u1(-pi/4294967296) q[79];
cx q[110],q[79];
u1(pi/4294967296) q[79];
u1(pi/2147483648) q[110];
cx q[110],q[80];
u1(-pi/2147483648) q[80];
cx q[110],q[80];
u1(pi/2147483648) q[80];
u1(pi/1073741824) q[110];
cx q[110],q[81];
u1(-pi/1073741824) q[81];
cx q[110],q[81];
u1(pi/1073741824) q[81];
u1(pi/536870912) q[110];
cx q[110],q[82];
u1(-pi/536870912) q[82];
cx q[110],q[82];
u1(pi/536870912) q[82];
u1(pi/268435456) q[110];
cx q[110],q[83];
u1(-pi/268435456) q[83];
cx q[110],q[83];
u1(pi/268435456) q[83];
u1(pi/134217728) q[110];
cx q[110],q[84];
u1(-pi/134217728) q[84];
cx q[110],q[84];
u1(pi/134217728) q[84];
u1(pi/67108864) q[110];
cx q[110],q[85];
u1(-pi/67108864) q[85];
cx q[110],q[85];
u1(pi/67108864) q[85];
u1(pi/33554432) q[110];
cx q[110],q[86];
u1(-pi/33554432) q[86];
cx q[110],q[86];
u1(pi/33554432) q[86];
u1(pi/16777216) q[110];
cx q[110],q[87];
u1(-pi/16777216) q[87];
cx q[110],q[87];
u1(pi/16777216) q[87];
u1(pi/8388608) q[110];
cx q[110],q[88];
u1(-pi/8388608) q[88];
cx q[110],q[88];
u1(pi/8388608) q[88];
u1(pi/4194304) q[110];
cx q[110],q[89];
u1(-pi/4194304) q[89];
cx q[110],q[89];
u1(pi/4194304) q[89];
u1(pi/2097152) q[110];
cx q[110],q[90];
u1(-pi/2097152) q[90];
cx q[110],q[90];
u1(pi/2097152) q[90];
u1(pi/1048576) q[110];
cx q[110],q[91];
u1(-pi/1048576) q[91];
cx q[110],q[91];
u1(pi/1048576) q[91];
u1(pi/524288) q[110];
cx q[110],q[92];
u1(-pi/524288) q[92];
cx q[110],q[92];
u1(pi/524288) q[92];
u1(pi/262144) q[110];
cx q[110],q[93];
u1(-pi/262144) q[93];
cx q[110],q[93];
u1(pi/262144) q[93];
u1(pi/131072) q[110];
cx q[110],q[94];
u1(-pi/131072) q[94];
cx q[110],q[94];
u1(pi/131072) q[94];
u1(pi/65536) q[110];
cx q[110],q[95];
u1(-pi/65536) q[95];
cx q[110],q[95];
u1(pi/65536) q[95];
u1(pi/32768) q[110];
cx q[110],q[96];
u1(-pi/32768) q[96];
cx q[110],q[96];
u1(pi/32768) q[96];
u1(pi/16384) q[110];
cx q[110],q[97];
u1(-pi/16384) q[97];
cx q[110],q[97];
u1(pi/16384) q[97];
u1(pi/8192) q[110];
cx q[110],q[98];
u1(-pi/8192) q[98];
cx q[110],q[98];
u1(pi/8192) q[98];
u1(pi/4096) q[110];
cx q[110],q[99];
u1(-pi/4096) q[99];
cx q[110],q[99];
u1(pi/4096) q[99];
u1(pi/2048) q[110];
cx q[110],q[100];
u1(-pi/2048) q[100];
cx q[110],q[100];
u1(pi/2048) q[100];
u1(pi/1024) q[110];
cx q[110],q[101];
u1(-pi/1024) q[101];
cx q[110],q[101];
u1(pi/1024) q[101];
u1(pi/512) q[110];
cx q[110],q[102];
u1(-pi/512) q[102];
cx q[110],q[102];
u1(pi/512) q[102];
u1(pi/256) q[110];
cx q[110],q[103];
u1(-pi/256) q[103];
cx q[110],q[103];
u1(pi/256) q[103];
u1(pi/128) q[110];
cx q[110],q[104];
u1(-pi/128) q[104];
cx q[110],q[104];
u1(pi/128) q[104];
u1(pi/64) q[110];
cx q[110],q[105];
u1(-pi/64) q[105];
cx q[110],q[105];
u1(pi/64) q[105];
u1(pi/32) q[110];
cx q[110],q[106];
u1(-pi/32) q[106];
cx q[110],q[106];
u1(pi/32) q[106];
u1(pi/16) q[110];
cx q[110],q[107];
u1(-pi/16) q[107];
cx q[110],q[107];
u1(pi/16) q[107];
u1(pi/8) q[110];
cx q[110],q[108];
u1(-pi/8) q[108];
cx q[110],q[108];
u1(pi/8) q[108];
u1(pi/4) q[110];
cx q[110],q[109];
u1(-pi/4) q[109];
cx q[110],q[109];
u1(pi/4) q[109];
h q[110];
u1(0) q[111];
cx q[111],q[0];
u1(0) q[0];
cx q[111],q[0];
u1(0) q[0];
u1(0) q[111];
cx q[111],q[1];
u1(0) q[1];
cx q[111],q[1];
u1(0) q[1];
u1(0) q[111];
cx q[111],q[2];
u1(0) q[2];
cx q[111],q[2];
u1(0) q[2];
u1(0) q[111];
cx q[111],q[3];
u1(0) q[3];
cx q[111],q[3];
u1(0) q[3];
u1(0) q[111];
cx q[111],q[4];
u1(0) q[4];
cx q[111],q[4];
u1(0) q[4];
u1(0) q[111];
cx q[111],q[5];
u1(0) q[5];
cx q[111],q[5];
u1(0) q[5];
u1(0) q[111];
cx q[111],q[6];
u1(0) q[6];
cx q[111],q[6];
u1(0) q[6];
u1(0) q[111];
cx q[111],q[7];
u1(0) q[7];
cx q[111],q[7];
u1(0) q[7];
u1(0) q[111];
cx q[111],q[8];
u1(0) q[8];
cx q[111],q[8];
u1(0) q[8];
u1(0) q[111];
cx q[111],q[9];
u1(0) q[9];
cx q[111],q[9];
u1(0) q[9];
u1(0) q[111];
cx q[111],q[10];
u1(0) q[10];
cx q[111],q[10];
u1(0) q[10];
u1(0) q[111];
cx q[111],q[11];
u1(0) q[11];
cx q[111],q[11];
u1(0) q[11];
u1(0) q[111];
cx q[111],q[12];
u1(0) q[12];
cx q[111],q[12];
u1(0) q[12];
u1(0) q[111];
cx q[111],q[13];
u1(0) q[13];
cx q[111],q[13];
u1(0) q[13];
u1(0) q[111];
cx q[111],q[14];
u1(0) q[14];
cx q[111],q[14];
u1(0) q[14];
u1(0) q[111];
cx q[111],q[15];
u1(0) q[15];
cx q[111],q[15];
u1(0) q[15];
u1(0) q[111];
cx q[111],q[16];
u1(0) q[16];
cx q[111],q[16];
u1(0) q[16];
u1(0) q[111];
cx q[111],q[17];
u1(0) q[17];
cx q[111],q[17];
u1(0) q[17];
u1(0) q[111];
cx q[111],q[18];
u1(0) q[18];
cx q[111],q[18];
u1(0) q[18];
u1(0) q[111];
cx q[111],q[19];
u1(0) q[19];
cx q[111],q[19];
u1(0) q[19];
u1(0) q[111];
cx q[111],q[20];
u1(0) q[20];
cx q[111],q[20];
u1(0) q[20];
u1(0) q[111];
cx q[111],q[21];
u1(0) q[21];
cx q[111],q[21];
u1(0) q[21];
u1(0) q[111];
cx q[111],q[22];
u1(0) q[22];
cx q[111],q[22];
u1(0) q[22];
u1(0) q[111];
cx q[111],q[23];
u1(0) q[23];
cx q[111],q[23];
u1(0) q[23];
u1(0) q[111];
cx q[111],q[24];
u1(0) q[24];
cx q[111],q[24];
u1(0) q[24];
u1(0) q[111];
cx q[111],q[25];
u1(0) q[25];
cx q[111],q[25];
u1(0) q[25];
u1(0) q[111];
cx q[111],q[26];
u1(0) q[26];
cx q[111],q[26];
u1(0) q[26];
u1(0) q[111];
cx q[111],q[27];
u1(0) q[27];
cx q[111],q[27];
u1(0) q[27];
u1(0) q[111];
cx q[111],q[28];
u1(0) q[28];
cx q[111],q[28];
u1(0) q[28];
u1(0) q[111];
cx q[111],q[29];
u1(0) q[29];
cx q[111],q[29];
u1(0) q[29];
u1(0) q[111];
cx q[111],q[30];
u1(0) q[30];
cx q[111],q[30];
u1(0) q[30];
u1(0) q[111];
cx q[111],q[31];
u1(0) q[31];
cx q[111],q[31];
u1(0) q[31];
u1(0) q[111];
cx q[111],q[32];
u1(0) q[32];
cx q[111],q[32];
u1(0) q[32];
u1(0) q[111];
cx q[111],q[33];
u1(0) q[33];
cx q[111],q[33];
u1(0) q[33];
u1(0) q[111];
cx q[111],q[34];
u1(0) q[34];
cx q[111],q[34];
u1(0) q[34];
u1(0) q[111];
cx q[111],q[35];
u1(0) q[35];
cx q[111],q[35];
u1(0) q[35];
u1(0) q[111];
cx q[111],q[36];
u1(0) q[36];
cx q[111],q[36];
u1(0) q[36];
u1(0) q[111];
cx q[111],q[37];
u1(0) q[37];
cx q[111],q[37];
u1(0) q[37];
u1(0) q[111];
cx q[111],q[38];
u1(0) q[38];
cx q[111],q[38];
u1(0) q[38];
u1(0) q[111];
cx q[111],q[39];
u1(0) q[39];
cx q[111],q[39];
u1(0) q[39];
u1(0) q[111];
cx q[111],q[40];
u1(0) q[40];
cx q[111],q[40];
u1(0) q[40];
u1(0) q[111];
cx q[111],q[41];
u1(0) q[41];
cx q[111],q[41];
u1(0) q[41];
u1(0) q[111];
cx q[111],q[42];
u1(0) q[42];
cx q[111],q[42];
u1(0) q[42];
u1(0) q[111];
cx q[111],q[43];
u1(0) q[43];
cx q[111],q[43];
u1(0) q[43];
u1(0) q[111];
cx q[111],q[44];
u1(0) q[44];
cx q[111],q[44];
u1(0) q[44];
u1(0) q[111];
cx q[111],q[45];
u1(0) q[45];
cx q[111],q[45];
u1(0) q[45];
u1(0) q[111];
cx q[111],q[46];
u1(0) q[46];
cx q[111],q[46];
u1(0) q[46];
u1(0) q[111];
cx q[111],q[47];
u1(0) q[47];
cx q[111],q[47];
u1(0) q[47];
u1(0) q[111];
cx q[111],q[48];
u1(0) q[48];
cx q[111],q[48];
u1(0) q[48];
u1(0) q[111];
cx q[111],q[49];
u1(0) q[49];
cx q[111],q[49];
u1(0) q[49];
u1(0) q[111];
cx q[111],q[50];
u1(0) q[50];
cx q[111],q[50];
u1(0) q[50];
u1(0) q[111];
cx q[111],q[51];
u1(0) q[51];
cx q[111],q[51];
u1(0) q[51];
u1(0) q[111];
cx q[111],q[52];
u1(0) q[52];
cx q[111],q[52];
u1(0) q[52];
u1(0) q[111];
cx q[111],q[53];
u1(0) q[53];
cx q[111],q[53];
u1(0) q[53];
u1(0) q[111];
cx q[111],q[54];
u1(0) q[54];
cx q[111],q[54];
u1(0) q[54];
u1(0) q[111];
cx q[111],q[55];
u1(0) q[55];
cx q[111],q[55];
u1(0) q[55];
u1(0) q[111];
cx q[111],q[56];
u1(0) q[56];
cx q[111],q[56];
u1(0) q[56];
u1(0) q[111];
cx q[111],q[57];
u1(0) q[57];
cx q[111],q[57];
u1(0) q[57];
u1(0) q[111];
cx q[111],q[58];
u1(0) q[58];
cx q[111],q[58];
u1(0) q[58];
u1(0) q[111];
cx q[111],q[59];
u1(0) q[59];
cx q[111],q[59];
u1(0) q[59];
u1(0) q[111];
cx q[111],q[60];
u1(0) q[60];
cx q[111],q[60];
u1(0) q[60];
u1(0) q[111];
cx q[111],q[61];
u1(0) q[61];
cx q[111],q[61];
u1(0) q[61];
u1(0) q[111];
cx q[111],q[62];
u1(0) q[62];
cx q[111],q[62];
u1(0) q[62];
u1(0) q[111];
cx q[111],q[63];
u1(0) q[63];
cx q[111],q[63];
u1(0) q[63];
u1(pi/281474976710656) q[111];
cx q[111],q[64];
u1(-pi/281474976710656) q[64];
cx q[111],q[64];
u1(pi/281474976710656) q[64];
u1(pi/140737488355328) q[111];
cx q[111],q[65];
u1(-pi/140737488355328) q[65];
cx q[111],q[65];
u1(pi/140737488355328) q[65];
u1(pi/70368744177664) q[111];
cx q[111],q[66];
u1(-pi/70368744177664) q[66];
cx q[111],q[66];
u1(pi/70368744177664) q[66];
u1(pi/35184372088832) q[111];
cx q[111],q[67];
u1(-pi/35184372088832) q[67];
cx q[111],q[67];
u1(pi/35184372088832) q[67];
u1(pi/17592186044416) q[111];
cx q[111],q[68];
u1(-pi/17592186044416) q[68];
cx q[111],q[68];
u1(pi/17592186044416) q[68];
u1(pi/8796093022208) q[111];
cx q[111],q[69];
u1(-pi/8796093022208) q[69];
cx q[111],q[69];
u1(pi/8796093022208) q[69];
u1(pi/4398046511104) q[111];
cx q[111],q[70];
u1(-pi/4398046511104) q[70];
cx q[111],q[70];
u1(pi/4398046511104) q[70];
u1(pi/2199023255552) q[111];
cx q[111],q[71];
u1(-pi/2199023255552) q[71];
cx q[111],q[71];
u1(pi/2199023255552) q[71];
u1(pi/1099511627776) q[111];
cx q[111],q[72];
u1(-pi/1099511627776) q[72];
cx q[111],q[72];
u1(pi/1099511627776) q[72];
u1(pi/549755813888) q[111];
cx q[111],q[73];
u1(-pi/549755813888) q[73];
cx q[111],q[73];
u1(pi/549755813888) q[73];
u1(pi/274877906944) q[111];
cx q[111],q[74];
u1(-pi/274877906944) q[74];
cx q[111],q[74];
u1(pi/274877906944) q[74];
u1(pi/137438953472) q[111];
cx q[111],q[75];
u1(-pi/137438953472) q[75];
cx q[111],q[75];
u1(pi/137438953472) q[75];
u1(pi/68719476736) q[111];
cx q[111],q[76];
u1(-pi/68719476736) q[76];
cx q[111],q[76];
u1(pi/68719476736) q[76];
u1(pi/34359738368) q[111];
cx q[111],q[77];
u1(-pi/34359738368) q[77];
cx q[111],q[77];
u1(pi/34359738368) q[77];
u1(pi/17179869184) q[111];
cx q[111],q[78];
u1(-pi/17179869184) q[78];
cx q[111],q[78];
u1(pi/17179869184) q[78];
u1(pi/8589934592) q[111];
cx q[111],q[79];
u1(-pi/8589934592) q[79];
cx q[111],q[79];
u1(pi/8589934592) q[79];
u1(pi/4294967296) q[111];
cx q[111],q[80];
u1(-pi/4294967296) q[80];
cx q[111],q[80];
u1(pi/4294967296) q[80];
u1(pi/2147483648) q[111];
cx q[111],q[81];
u1(-pi/2147483648) q[81];
cx q[111],q[81];
u1(pi/2147483648) q[81];
u1(pi/1073741824) q[111];
cx q[111],q[82];
u1(-pi/1073741824) q[82];
cx q[111],q[82];
u1(pi/1073741824) q[82];
u1(pi/536870912) q[111];
cx q[111],q[83];
u1(-pi/536870912) q[83];
cx q[111],q[83];
u1(pi/536870912) q[83];
u1(pi/268435456) q[111];
cx q[111],q[84];
u1(-pi/268435456) q[84];
cx q[111],q[84];
u1(pi/268435456) q[84];
u1(pi/134217728) q[111];
cx q[111],q[85];
u1(-pi/134217728) q[85];
cx q[111],q[85];
u1(pi/134217728) q[85];
u1(pi/67108864) q[111];
cx q[111],q[86];
u1(-pi/67108864) q[86];
cx q[111],q[86];
u1(pi/67108864) q[86];
u1(pi/33554432) q[111];
cx q[111],q[87];
u1(-pi/33554432) q[87];
cx q[111],q[87];
u1(pi/33554432) q[87];
u1(pi/16777216) q[111];
cx q[111],q[88];
u1(-pi/16777216) q[88];
cx q[111],q[88];
u1(pi/16777216) q[88];
u1(pi/8388608) q[111];
cx q[111],q[89];
u1(-pi/8388608) q[89];
cx q[111],q[89];
u1(pi/8388608) q[89];
u1(pi/4194304) q[111];
cx q[111],q[90];
u1(-pi/4194304) q[90];
cx q[111],q[90];
u1(pi/4194304) q[90];
u1(pi/2097152) q[111];
cx q[111],q[91];
u1(-pi/2097152) q[91];
cx q[111],q[91];
u1(pi/2097152) q[91];
u1(pi/1048576) q[111];
cx q[111],q[92];
u1(-pi/1048576) q[92];
cx q[111],q[92];
u1(pi/1048576) q[92];
u1(pi/524288) q[111];
cx q[111],q[93];
u1(-pi/524288) q[93];
cx q[111],q[93];
u1(pi/524288) q[93];
u1(pi/262144) q[111];
cx q[111],q[94];
u1(-pi/262144) q[94];
cx q[111],q[94];
u1(pi/262144) q[94];
u1(pi/131072) q[111];
cx q[111],q[95];
u1(-pi/131072) q[95];
cx q[111],q[95];
u1(pi/131072) q[95];
u1(pi/65536) q[111];
cx q[111],q[96];
u1(-pi/65536) q[96];
cx q[111],q[96];
u1(pi/65536) q[96];
u1(pi/32768) q[111];
cx q[111],q[97];
u1(-pi/32768) q[97];
cx q[111],q[97];
u1(pi/32768) q[97];
u1(pi/16384) q[111];
cx q[111],q[98];
u1(-pi/16384) q[98];
cx q[111],q[98];
u1(pi/16384) q[98];
u1(pi/8192) q[111];
cx q[111],q[99];
u1(-pi/8192) q[99];
cx q[111],q[99];
u1(pi/8192) q[99];
u1(pi/4096) q[111];
cx q[111],q[100];
u1(-pi/4096) q[100];
cx q[111],q[100];
u1(pi/4096) q[100];
u1(pi/2048) q[111];
cx q[111],q[101];
u1(-pi/2048) q[101];
cx q[111],q[101];
u1(pi/2048) q[101];
u1(pi/1024) q[111];
cx q[111],q[102];
u1(-pi/1024) q[102];
cx q[111],q[102];
u1(pi/1024) q[102];
u1(pi/512) q[111];
cx q[111],q[103];
u1(-pi/512) q[103];
cx q[111],q[103];
u1(pi/512) q[103];
u1(pi/256) q[111];
cx q[111],q[104];
u1(-pi/256) q[104];
cx q[111],q[104];
u1(pi/256) q[104];
u1(pi/128) q[111];
cx q[111],q[105];
u1(-pi/128) q[105];
cx q[111],q[105];
u1(pi/128) q[105];
u1(pi/64) q[111];
cx q[111],q[106];
u1(-pi/64) q[106];
cx q[111],q[106];
u1(pi/64) q[106];
u1(pi/32) q[111];
cx q[111],q[107];
u1(-pi/32) q[107];
cx q[111],q[107];
u1(pi/32) q[107];
u1(pi/16) q[111];
cx q[111],q[108];
u1(-pi/16) q[108];
cx q[111],q[108];
u1(pi/16) q[108];
u1(pi/8) q[111];
cx q[111],q[109];
u1(-pi/8) q[109];
cx q[111],q[109];
u1(pi/8) q[109];
u1(pi/4) q[111];
cx q[111],q[110];
u1(-pi/4) q[110];
cx q[111],q[110];
u1(pi/4) q[110];
h q[111];
u1(0) q[112];
cx q[112],q[0];
u1(0) q[0];
cx q[112],q[0];
u1(0) q[0];
u1(0) q[112];
cx q[112],q[1];
u1(0) q[1];
cx q[112],q[1];
u1(0) q[1];
u1(0) q[112];
cx q[112],q[2];
u1(0) q[2];
cx q[112],q[2];
u1(0) q[2];
u1(0) q[112];
cx q[112],q[3];
u1(0) q[3];
cx q[112],q[3];
u1(0) q[3];
u1(0) q[112];
cx q[112],q[4];
u1(0) q[4];
cx q[112],q[4];
u1(0) q[4];
u1(0) q[112];
cx q[112],q[5];
u1(0) q[5];
cx q[112],q[5];
u1(0) q[5];
u1(0) q[112];
cx q[112],q[6];
u1(0) q[6];
cx q[112],q[6];
u1(0) q[6];
u1(0) q[112];
cx q[112],q[7];
u1(0) q[7];
cx q[112],q[7];
u1(0) q[7];
u1(0) q[112];
cx q[112],q[8];
u1(0) q[8];
cx q[112],q[8];
u1(0) q[8];
u1(0) q[112];
cx q[112],q[9];
u1(0) q[9];
cx q[112],q[9];
u1(0) q[9];
u1(0) q[112];
cx q[112],q[10];
u1(0) q[10];
cx q[112],q[10];
u1(0) q[10];
u1(0) q[112];
cx q[112],q[11];
u1(0) q[11];
cx q[112],q[11];
u1(0) q[11];
u1(0) q[112];
cx q[112],q[12];
u1(0) q[12];
cx q[112],q[12];
u1(0) q[12];
u1(0) q[112];
cx q[112],q[13];
u1(0) q[13];
cx q[112],q[13];
u1(0) q[13];
u1(0) q[112];
cx q[112],q[14];
u1(0) q[14];
cx q[112],q[14];
u1(0) q[14];
u1(0) q[112];
cx q[112],q[15];
u1(0) q[15];
cx q[112],q[15];
u1(0) q[15];
u1(0) q[112];
cx q[112],q[16];
u1(0) q[16];
cx q[112],q[16];
u1(0) q[16];
u1(0) q[112];
cx q[112],q[17];
u1(0) q[17];
cx q[112],q[17];
u1(0) q[17];
u1(0) q[112];
cx q[112],q[18];
u1(0) q[18];
cx q[112],q[18];
u1(0) q[18];
u1(0) q[112];
cx q[112],q[19];
u1(0) q[19];
cx q[112],q[19];
u1(0) q[19];
u1(0) q[112];
cx q[112],q[20];
u1(0) q[20];
cx q[112],q[20];
u1(0) q[20];
u1(0) q[112];
cx q[112],q[21];
u1(0) q[21];
cx q[112],q[21];
u1(0) q[21];
u1(0) q[112];
cx q[112],q[22];
u1(0) q[22];
cx q[112],q[22];
u1(0) q[22];
u1(0) q[112];
cx q[112],q[23];
u1(0) q[23];
cx q[112],q[23];
u1(0) q[23];
u1(0) q[112];
cx q[112],q[24];
u1(0) q[24];
cx q[112],q[24];
u1(0) q[24];
u1(0) q[112];
cx q[112],q[25];
u1(0) q[25];
cx q[112],q[25];
u1(0) q[25];
u1(0) q[112];
cx q[112],q[26];
u1(0) q[26];
cx q[112],q[26];
u1(0) q[26];
u1(0) q[112];
cx q[112],q[27];
u1(0) q[27];
cx q[112],q[27];
u1(0) q[27];
u1(0) q[112];
cx q[112],q[28];
u1(0) q[28];
cx q[112],q[28];
u1(0) q[28];
u1(0) q[112];
cx q[112],q[29];
u1(0) q[29];
cx q[112],q[29];
u1(0) q[29];
u1(0) q[112];
cx q[112],q[30];
u1(0) q[30];
cx q[112],q[30];
u1(0) q[30];
u1(0) q[112];
cx q[112],q[31];
u1(0) q[31];
cx q[112],q[31];
u1(0) q[31];
u1(0) q[112];
cx q[112],q[32];
u1(0) q[32];
cx q[112],q[32];
u1(0) q[32];
u1(0) q[112];
cx q[112],q[33];
u1(0) q[33];
cx q[112],q[33];
u1(0) q[33];
u1(0) q[112];
cx q[112],q[34];
u1(0) q[34];
cx q[112],q[34];
u1(0) q[34];
u1(0) q[112];
cx q[112],q[35];
u1(0) q[35];
cx q[112],q[35];
u1(0) q[35];
u1(0) q[112];
cx q[112],q[36];
u1(0) q[36];
cx q[112],q[36];
u1(0) q[36];
u1(0) q[112];
cx q[112],q[37];
u1(0) q[37];
cx q[112],q[37];
u1(0) q[37];
u1(0) q[112];
cx q[112],q[38];
u1(0) q[38];
cx q[112],q[38];
u1(0) q[38];
u1(0) q[112];
cx q[112],q[39];
u1(0) q[39];
cx q[112],q[39];
u1(0) q[39];
u1(0) q[112];
cx q[112],q[40];
u1(0) q[40];
cx q[112],q[40];
u1(0) q[40];
u1(0) q[112];
cx q[112],q[41];
u1(0) q[41];
cx q[112],q[41];
u1(0) q[41];
u1(0) q[112];
cx q[112],q[42];
u1(0) q[42];
cx q[112],q[42];
u1(0) q[42];
u1(0) q[112];
cx q[112],q[43];
u1(0) q[43];
cx q[112],q[43];
u1(0) q[43];
u1(0) q[112];
cx q[112],q[44];
u1(0) q[44];
cx q[112],q[44];
u1(0) q[44];
u1(0) q[112];
cx q[112],q[45];
u1(0) q[45];
cx q[112],q[45];
u1(0) q[45];
u1(0) q[112];
cx q[112],q[46];
u1(0) q[46];
cx q[112],q[46];
u1(0) q[46];
u1(0) q[112];
cx q[112],q[47];
u1(0) q[47];
cx q[112],q[47];
u1(0) q[47];
u1(0) q[112];
cx q[112],q[48];
u1(0) q[48];
cx q[112],q[48];
u1(0) q[48];
u1(0) q[112];
cx q[112],q[49];
u1(0) q[49];
cx q[112],q[49];
u1(0) q[49];
u1(0) q[112];
cx q[112],q[50];
u1(0) q[50];
cx q[112],q[50];
u1(0) q[50];
u1(0) q[112];
cx q[112],q[51];
u1(0) q[51];
cx q[112],q[51];
u1(0) q[51];
u1(0) q[112];
cx q[112],q[52];
u1(0) q[52];
cx q[112],q[52];
u1(0) q[52];
u1(0) q[112];
cx q[112],q[53];
u1(0) q[53];
cx q[112],q[53];
u1(0) q[53];
u1(0) q[112];
cx q[112],q[54];
u1(0) q[54];
cx q[112],q[54];
u1(0) q[54];
u1(0) q[112];
cx q[112],q[55];
u1(0) q[55];
cx q[112],q[55];
u1(0) q[55];
u1(0) q[112];
cx q[112],q[56];
u1(0) q[56];
cx q[112],q[56];
u1(0) q[56];
u1(0) q[112];
cx q[112],q[57];
u1(0) q[57];
cx q[112],q[57];
u1(0) q[57];
u1(0) q[112];
cx q[112],q[58];
u1(0) q[58];
cx q[112],q[58];
u1(0) q[58];
u1(0) q[112];
cx q[112],q[59];
u1(0) q[59];
cx q[112],q[59];
u1(0) q[59];
u1(0) q[112];
cx q[112],q[60];
u1(0) q[60];
cx q[112],q[60];
u1(0) q[60];
u1(0) q[112];
cx q[112],q[61];
u1(0) q[61];
cx q[112],q[61];
u1(0) q[61];
u1(0) q[112];
cx q[112],q[62];
u1(0) q[62];
cx q[112],q[62];
u1(0) q[62];
u1(0) q[112];
cx q[112],q[63];
u1(0) q[63];
cx q[112],q[63];
u1(0) q[63];
u1(0) q[112];
cx q[112],q[64];
u1(0) q[64];
cx q[112],q[64];
u1(0) q[64];
u1(pi/281474976710656) q[112];
cx q[112],q[65];
u1(-pi/281474976710656) q[65];
cx q[112],q[65];
u1(pi/281474976710656) q[65];
u1(pi/140737488355328) q[112];
cx q[112],q[66];
u1(-pi/140737488355328) q[66];
cx q[112],q[66];
u1(pi/140737488355328) q[66];
u1(pi/70368744177664) q[112];
cx q[112],q[67];
u1(-pi/70368744177664) q[67];
cx q[112],q[67];
u1(pi/70368744177664) q[67];
u1(pi/35184372088832) q[112];
cx q[112],q[68];
u1(-pi/35184372088832) q[68];
cx q[112],q[68];
u1(pi/35184372088832) q[68];
u1(pi/17592186044416) q[112];
cx q[112],q[69];
u1(-pi/17592186044416) q[69];
cx q[112],q[69];
u1(pi/17592186044416) q[69];
u1(pi/8796093022208) q[112];
cx q[112],q[70];
u1(-pi/8796093022208) q[70];
cx q[112],q[70];
u1(pi/8796093022208) q[70];
u1(pi/4398046511104) q[112];
cx q[112],q[71];
u1(-pi/4398046511104) q[71];
cx q[112],q[71];
u1(pi/4398046511104) q[71];
u1(pi/2199023255552) q[112];
cx q[112],q[72];
u1(-pi/2199023255552) q[72];
cx q[112],q[72];
u1(pi/2199023255552) q[72];
u1(pi/1099511627776) q[112];
cx q[112],q[73];
u1(-pi/1099511627776) q[73];
cx q[112],q[73];
u1(pi/1099511627776) q[73];
u1(pi/549755813888) q[112];
cx q[112],q[74];
u1(-pi/549755813888) q[74];
cx q[112],q[74];
u1(pi/549755813888) q[74];
u1(pi/274877906944) q[112];
cx q[112],q[75];
u1(-pi/274877906944) q[75];
cx q[112],q[75];
u1(pi/274877906944) q[75];
u1(pi/137438953472) q[112];
cx q[112],q[76];
u1(-pi/137438953472) q[76];
cx q[112],q[76];
u1(pi/137438953472) q[76];
u1(pi/68719476736) q[112];
cx q[112],q[77];
u1(-pi/68719476736) q[77];
cx q[112],q[77];
u1(pi/68719476736) q[77];
u1(pi/34359738368) q[112];
cx q[112],q[78];
u1(-pi/34359738368) q[78];
cx q[112],q[78];
u1(pi/34359738368) q[78];
u1(pi/17179869184) q[112];
cx q[112],q[79];
u1(-pi/17179869184) q[79];
cx q[112],q[79];
u1(pi/17179869184) q[79];
u1(pi/8589934592) q[112];
cx q[112],q[80];
u1(-pi/8589934592) q[80];
cx q[112],q[80];
u1(pi/8589934592) q[80];
u1(pi/4294967296) q[112];
cx q[112],q[81];
u1(-pi/4294967296) q[81];
cx q[112],q[81];
u1(pi/4294967296) q[81];
u1(pi/2147483648) q[112];
cx q[112],q[82];
u1(-pi/2147483648) q[82];
cx q[112],q[82];
u1(pi/2147483648) q[82];
u1(pi/1073741824) q[112];
cx q[112],q[83];
u1(-pi/1073741824) q[83];
cx q[112],q[83];
u1(pi/1073741824) q[83];
u1(pi/536870912) q[112];
cx q[112],q[84];
u1(-pi/536870912) q[84];
cx q[112],q[84];
u1(pi/536870912) q[84];
u1(pi/268435456) q[112];
cx q[112],q[85];
u1(-pi/268435456) q[85];
cx q[112],q[85];
u1(pi/268435456) q[85];
u1(pi/134217728) q[112];
cx q[112],q[86];
u1(-pi/134217728) q[86];
cx q[112],q[86];
u1(pi/134217728) q[86];
u1(pi/67108864) q[112];
cx q[112],q[87];
u1(-pi/67108864) q[87];
cx q[112],q[87];
u1(pi/67108864) q[87];
u1(pi/33554432) q[112];
cx q[112],q[88];
u1(-pi/33554432) q[88];
cx q[112],q[88];
u1(pi/33554432) q[88];
u1(pi/16777216) q[112];
cx q[112],q[89];
u1(-pi/16777216) q[89];
cx q[112],q[89];
u1(pi/16777216) q[89];
u1(pi/8388608) q[112];
cx q[112],q[90];
u1(-pi/8388608) q[90];
cx q[112],q[90];
u1(pi/8388608) q[90];
u1(pi/4194304) q[112];
cx q[112],q[91];
u1(-pi/4194304) q[91];
cx q[112],q[91];
u1(pi/4194304) q[91];
u1(pi/2097152) q[112];
cx q[112],q[92];
u1(-pi/2097152) q[92];
cx q[112],q[92];
u1(pi/2097152) q[92];
u1(pi/1048576) q[112];
cx q[112],q[93];
u1(-pi/1048576) q[93];
cx q[112],q[93];
u1(pi/1048576) q[93];
u1(pi/524288) q[112];
cx q[112],q[94];
u1(-pi/524288) q[94];
cx q[112],q[94];
u1(pi/524288) q[94];
u1(pi/262144) q[112];
cx q[112],q[95];
u1(-pi/262144) q[95];
cx q[112],q[95];
u1(pi/262144) q[95];
u1(pi/131072) q[112];
cx q[112],q[96];
u1(-pi/131072) q[96];
cx q[112],q[96];
u1(pi/131072) q[96];
u1(pi/65536) q[112];
cx q[112],q[97];
u1(-pi/65536) q[97];
cx q[112],q[97];
u1(pi/65536) q[97];
u1(pi/32768) q[112];
cx q[112],q[98];
u1(-pi/32768) q[98];
cx q[112],q[98];
u1(pi/32768) q[98];
u1(pi/16384) q[112];
cx q[112],q[99];
u1(-pi/16384) q[99];
cx q[112],q[99];
u1(pi/16384) q[99];
u1(pi/8192) q[112];
cx q[112],q[100];
u1(-pi/8192) q[100];
cx q[112],q[100];
u1(pi/8192) q[100];
u1(pi/4096) q[112];
cx q[112],q[101];
u1(-pi/4096) q[101];
cx q[112],q[101];
u1(pi/4096) q[101];
u1(pi/2048) q[112];
cx q[112],q[102];
u1(-pi/2048) q[102];
cx q[112],q[102];
u1(pi/2048) q[102];
u1(pi/1024) q[112];
cx q[112],q[103];
u1(-pi/1024) q[103];
cx q[112],q[103];
u1(pi/1024) q[103];
u1(pi/512) q[112];
cx q[112],q[104];
u1(-pi/512) q[104];
cx q[112],q[104];
u1(pi/512) q[104];
u1(pi/256) q[112];
cx q[112],q[105];
u1(-pi/256) q[105];
cx q[112],q[105];
u1(pi/256) q[105];
u1(pi/128) q[112];
cx q[112],q[106];
u1(-pi/128) q[106];
cx q[112],q[106];
u1(pi/128) q[106];
u1(pi/64) q[112];
cx q[112],q[107];
u1(-pi/64) q[107];
cx q[112],q[107];
u1(pi/64) q[107];
u1(pi/32) q[112];
cx q[112],q[108];
u1(-pi/32) q[108];
cx q[112],q[108];
u1(pi/32) q[108];
u1(pi/16) q[112];
cx q[112],q[109];
u1(-pi/16) q[109];
cx q[112],q[109];
u1(pi/16) q[109];
u1(pi/8) q[112];
cx q[112],q[110];
u1(-pi/8) q[110];
cx q[112],q[110];
u1(pi/8) q[110];
u1(pi/4) q[112];
cx q[112],q[111];
u1(-pi/4) q[111];
cx q[112],q[111];
u1(pi/4) q[111];
h q[112];
u1(0) q[113];
cx q[113],q[0];
u1(0) q[0];
cx q[113],q[0];
u1(0) q[0];
u1(0) q[113];
cx q[113],q[1];
u1(0) q[1];
cx q[113],q[1];
u1(0) q[1];
u1(0) q[113];
cx q[113],q[2];
u1(0) q[2];
cx q[113],q[2];
u1(0) q[2];
u1(0) q[113];
cx q[113],q[3];
u1(0) q[3];
cx q[113],q[3];
u1(0) q[3];
u1(0) q[113];
cx q[113],q[4];
u1(0) q[4];
cx q[113],q[4];
u1(0) q[4];
u1(0) q[113];
cx q[113],q[5];
u1(0) q[5];
cx q[113],q[5];
u1(0) q[5];
u1(0) q[113];
cx q[113],q[6];
u1(0) q[6];
cx q[113],q[6];
u1(0) q[6];
u1(0) q[113];
cx q[113],q[7];
u1(0) q[7];
cx q[113],q[7];
u1(0) q[7];
u1(0) q[113];
cx q[113],q[8];
u1(0) q[8];
cx q[113],q[8];
u1(0) q[8];
u1(0) q[113];
cx q[113],q[9];
u1(0) q[9];
cx q[113],q[9];
u1(0) q[9];
u1(0) q[113];
cx q[113],q[10];
u1(0) q[10];
cx q[113],q[10];
u1(0) q[10];
u1(0) q[113];
cx q[113],q[11];
u1(0) q[11];
cx q[113],q[11];
u1(0) q[11];
u1(0) q[113];
cx q[113],q[12];
u1(0) q[12];
cx q[113],q[12];
u1(0) q[12];
u1(0) q[113];
cx q[113],q[13];
u1(0) q[13];
cx q[113],q[13];
u1(0) q[13];
u1(0) q[113];
cx q[113],q[14];
u1(0) q[14];
cx q[113],q[14];
u1(0) q[14];
u1(0) q[113];
cx q[113],q[15];
u1(0) q[15];
cx q[113],q[15];
u1(0) q[15];
u1(0) q[113];
cx q[113],q[16];
u1(0) q[16];
cx q[113],q[16];
u1(0) q[16];
u1(0) q[113];
cx q[113],q[17];
u1(0) q[17];
cx q[113],q[17];
u1(0) q[17];
u1(0) q[113];
cx q[113],q[18];
u1(0) q[18];
cx q[113],q[18];
u1(0) q[18];
u1(0) q[113];
cx q[113],q[19];
u1(0) q[19];
cx q[113],q[19];
u1(0) q[19];
u1(0) q[113];
cx q[113],q[20];
u1(0) q[20];
cx q[113],q[20];
u1(0) q[20];
u1(0) q[113];
cx q[113],q[21];
u1(0) q[21];
cx q[113],q[21];
u1(0) q[21];
u1(0) q[113];
cx q[113],q[22];
u1(0) q[22];
cx q[113],q[22];
u1(0) q[22];
u1(0) q[113];
cx q[113],q[23];
u1(0) q[23];
cx q[113],q[23];
u1(0) q[23];
u1(0) q[113];
cx q[113],q[24];
u1(0) q[24];
cx q[113],q[24];
u1(0) q[24];
u1(0) q[113];
cx q[113],q[25];
u1(0) q[25];
cx q[113],q[25];
u1(0) q[25];
u1(0) q[113];
cx q[113],q[26];
u1(0) q[26];
cx q[113],q[26];
u1(0) q[26];
u1(0) q[113];
cx q[113],q[27];
u1(0) q[27];
cx q[113],q[27];
u1(0) q[27];
u1(0) q[113];
cx q[113],q[28];
u1(0) q[28];
cx q[113],q[28];
u1(0) q[28];
u1(0) q[113];
cx q[113],q[29];
u1(0) q[29];
cx q[113],q[29];
u1(0) q[29];
u1(0) q[113];
cx q[113],q[30];
u1(0) q[30];
cx q[113],q[30];
u1(0) q[30];
u1(0) q[113];
cx q[113],q[31];
u1(0) q[31];
cx q[113],q[31];
u1(0) q[31];
u1(0) q[113];
cx q[113],q[32];
u1(0) q[32];
cx q[113],q[32];
u1(0) q[32];
u1(0) q[113];
cx q[113],q[33];
u1(0) q[33];
cx q[113],q[33];
u1(0) q[33];
u1(0) q[113];
cx q[113],q[34];
u1(0) q[34];
cx q[113],q[34];
u1(0) q[34];
u1(0) q[113];
cx q[113],q[35];
u1(0) q[35];
cx q[113],q[35];
u1(0) q[35];
u1(0) q[113];
cx q[113],q[36];
u1(0) q[36];
cx q[113],q[36];
u1(0) q[36];
u1(0) q[113];
cx q[113],q[37];
u1(0) q[37];
cx q[113],q[37];
u1(0) q[37];
u1(0) q[113];
cx q[113],q[38];
u1(0) q[38];
cx q[113],q[38];
u1(0) q[38];
u1(0) q[113];
cx q[113],q[39];
u1(0) q[39];
cx q[113],q[39];
u1(0) q[39];
u1(0) q[113];
cx q[113],q[40];
u1(0) q[40];
cx q[113],q[40];
u1(0) q[40];
u1(0) q[113];
cx q[113],q[41];
u1(0) q[41];
cx q[113],q[41];
u1(0) q[41];
u1(0) q[113];
cx q[113],q[42];
u1(0) q[42];
cx q[113],q[42];
u1(0) q[42];
u1(0) q[113];
cx q[113],q[43];
u1(0) q[43];
cx q[113],q[43];
u1(0) q[43];
u1(0) q[113];
cx q[113],q[44];
u1(0) q[44];
cx q[113],q[44];
u1(0) q[44];
u1(0) q[113];
cx q[113],q[45];
u1(0) q[45];
cx q[113],q[45];
u1(0) q[45];
u1(0) q[113];
cx q[113],q[46];
u1(0) q[46];
cx q[113],q[46];
u1(0) q[46];
u1(0) q[113];
cx q[113],q[47];
u1(0) q[47];
cx q[113],q[47];
u1(0) q[47];
u1(0) q[113];
cx q[113],q[48];
u1(0) q[48];
cx q[113],q[48];
u1(0) q[48];
u1(0) q[113];
cx q[113],q[49];
u1(0) q[49];
cx q[113],q[49];
u1(0) q[49];
u1(0) q[113];
cx q[113],q[50];
u1(0) q[50];
cx q[113],q[50];
u1(0) q[50];
u1(0) q[113];
cx q[113],q[51];
u1(0) q[51];
cx q[113],q[51];
u1(0) q[51];
u1(0) q[113];
cx q[113],q[52];
u1(0) q[52];
cx q[113],q[52];
u1(0) q[52];
u1(0) q[113];
cx q[113],q[53];
u1(0) q[53];
cx q[113],q[53];
u1(0) q[53];
u1(0) q[113];
cx q[113],q[54];
u1(0) q[54];
cx q[113],q[54];
u1(0) q[54];
u1(0) q[113];
cx q[113],q[55];
u1(0) q[55];
cx q[113],q[55];
u1(0) q[55];
u1(0) q[113];
cx q[113],q[56];
u1(0) q[56];
cx q[113],q[56];
u1(0) q[56];
u1(0) q[113];
cx q[113],q[57];
u1(0) q[57];
cx q[113],q[57];
u1(0) q[57];
u1(0) q[113];
cx q[113],q[58];
u1(0) q[58];
cx q[113],q[58];
u1(0) q[58];
u1(0) q[113];
cx q[113],q[59];
u1(0) q[59];
cx q[113],q[59];
u1(0) q[59];
u1(0) q[113];
cx q[113],q[60];
u1(0) q[60];
cx q[113],q[60];
u1(0) q[60];
u1(0) q[113];
cx q[113],q[61];
u1(0) q[61];
cx q[113],q[61];
u1(0) q[61];
u1(0) q[113];
cx q[113],q[62];
u1(0) q[62];
cx q[113],q[62];
u1(0) q[62];
u1(0) q[113];
cx q[113],q[63];
u1(0) q[63];
cx q[113],q[63];
u1(0) q[63];
u1(0) q[113];
cx q[113],q[64];
u1(0) q[64];
cx q[113],q[64];
u1(0) q[64];
u1(0) q[113];
cx q[113],q[65];
u1(0) q[65];
cx q[113],q[65];
u1(0) q[65];
u1(pi/281474976710656) q[113];
cx q[113],q[66];
u1(-pi/281474976710656) q[66];
cx q[113],q[66];
u1(pi/281474976710656) q[66];
u1(pi/140737488355328) q[113];
cx q[113],q[67];
u1(-pi/140737488355328) q[67];
cx q[113],q[67];
u1(pi/140737488355328) q[67];
u1(pi/70368744177664) q[113];
cx q[113],q[68];
u1(-pi/70368744177664) q[68];
cx q[113],q[68];
u1(pi/70368744177664) q[68];
u1(pi/35184372088832) q[113];
cx q[113],q[69];
u1(-pi/35184372088832) q[69];
cx q[113],q[69];
u1(pi/35184372088832) q[69];
u1(pi/17592186044416) q[113];
cx q[113],q[70];
u1(-pi/17592186044416) q[70];
cx q[113],q[70];
u1(pi/17592186044416) q[70];
u1(pi/8796093022208) q[113];
cx q[113],q[71];
u1(-pi/8796093022208) q[71];
cx q[113],q[71];
u1(pi/8796093022208) q[71];
u1(pi/4398046511104) q[113];
cx q[113],q[72];
u1(-pi/4398046511104) q[72];
cx q[113],q[72];
u1(pi/4398046511104) q[72];
u1(pi/2199023255552) q[113];
cx q[113],q[73];
u1(-pi/2199023255552) q[73];
cx q[113],q[73];
u1(pi/2199023255552) q[73];
u1(pi/1099511627776) q[113];
cx q[113],q[74];
u1(-pi/1099511627776) q[74];
cx q[113],q[74];
u1(pi/1099511627776) q[74];
u1(pi/549755813888) q[113];
cx q[113],q[75];
u1(-pi/549755813888) q[75];
cx q[113],q[75];
u1(pi/549755813888) q[75];
u1(pi/274877906944) q[113];
cx q[113],q[76];
u1(-pi/274877906944) q[76];
cx q[113],q[76];
u1(pi/274877906944) q[76];
u1(pi/137438953472) q[113];
cx q[113],q[77];
u1(-pi/137438953472) q[77];
cx q[113],q[77];
u1(pi/137438953472) q[77];
u1(pi/68719476736) q[113];
cx q[113],q[78];
u1(-pi/68719476736) q[78];
cx q[113],q[78];
u1(pi/68719476736) q[78];
u1(pi/34359738368) q[113];
cx q[113],q[79];
u1(-pi/34359738368) q[79];
cx q[113],q[79];
u1(pi/34359738368) q[79];
u1(pi/17179869184) q[113];
cx q[113],q[80];
u1(-pi/17179869184) q[80];
cx q[113],q[80];
u1(pi/17179869184) q[80];
u1(pi/8589934592) q[113];
cx q[113],q[81];
u1(-pi/8589934592) q[81];
cx q[113],q[81];
u1(pi/8589934592) q[81];
u1(pi/4294967296) q[113];
cx q[113],q[82];
u1(-pi/4294967296) q[82];
cx q[113],q[82];
u1(pi/4294967296) q[82];
u1(pi/2147483648) q[113];
cx q[113],q[83];
u1(-pi/2147483648) q[83];
cx q[113],q[83];
u1(pi/2147483648) q[83];
u1(pi/1073741824) q[113];
cx q[113],q[84];
u1(-pi/1073741824) q[84];
cx q[113],q[84];
u1(pi/1073741824) q[84];
u1(pi/536870912) q[113];
cx q[113],q[85];
u1(-pi/536870912) q[85];
cx q[113],q[85];
u1(pi/536870912) q[85];
u1(pi/268435456) q[113];
cx q[113],q[86];
u1(-pi/268435456) q[86];
cx q[113],q[86];
u1(pi/268435456) q[86];
u1(pi/134217728) q[113];
cx q[113],q[87];
u1(-pi/134217728) q[87];
cx q[113],q[87];
u1(pi/134217728) q[87];
u1(pi/67108864) q[113];
cx q[113],q[88];
u1(-pi/67108864) q[88];
cx q[113],q[88];
u1(pi/67108864) q[88];
u1(pi/33554432) q[113];
cx q[113],q[89];
u1(-pi/33554432) q[89];
cx q[113],q[89];
u1(pi/33554432) q[89];
u1(pi/16777216) q[113];
cx q[113],q[90];
u1(-pi/16777216) q[90];
cx q[113],q[90];
u1(pi/16777216) q[90];
u1(pi/8388608) q[113];
cx q[113],q[91];
u1(-pi/8388608) q[91];
cx q[113],q[91];
u1(pi/8388608) q[91];
u1(pi/4194304) q[113];
cx q[113],q[92];
u1(-pi/4194304) q[92];
cx q[113],q[92];
u1(pi/4194304) q[92];
u1(pi/2097152) q[113];
cx q[113],q[93];
u1(-pi/2097152) q[93];
cx q[113],q[93];
u1(pi/2097152) q[93];
u1(pi/1048576) q[113];
cx q[113],q[94];
u1(-pi/1048576) q[94];
cx q[113],q[94];
u1(pi/1048576) q[94];
u1(pi/524288) q[113];
cx q[113],q[95];
u1(-pi/524288) q[95];
cx q[113],q[95];
u1(pi/524288) q[95];
u1(pi/262144) q[113];
cx q[113],q[96];
u1(-pi/262144) q[96];
cx q[113],q[96];
u1(pi/262144) q[96];
u1(pi/131072) q[113];
cx q[113],q[97];
u1(-pi/131072) q[97];
cx q[113],q[97];
u1(pi/131072) q[97];
u1(pi/65536) q[113];
cx q[113],q[98];
u1(-pi/65536) q[98];
cx q[113],q[98];
u1(pi/65536) q[98];
u1(pi/32768) q[113];
cx q[113],q[99];
u1(-pi/32768) q[99];
cx q[113],q[99];
u1(pi/32768) q[99];
u1(pi/16384) q[113];
cx q[113],q[100];
u1(-pi/16384) q[100];
cx q[113],q[100];
u1(pi/16384) q[100];
u1(pi/8192) q[113];
cx q[113],q[101];
u1(-pi/8192) q[101];
cx q[113],q[101];
u1(pi/8192) q[101];
u1(pi/4096) q[113];
cx q[113],q[102];
u1(-pi/4096) q[102];
cx q[113],q[102];
u1(pi/4096) q[102];
u1(pi/2048) q[113];
cx q[113],q[103];
u1(-pi/2048) q[103];
cx q[113],q[103];
u1(pi/2048) q[103];
u1(pi/1024) q[113];
cx q[113],q[104];
u1(-pi/1024) q[104];
cx q[113],q[104];
u1(pi/1024) q[104];
u1(pi/512) q[113];
cx q[113],q[105];
u1(-pi/512) q[105];
cx q[113],q[105];
u1(pi/512) q[105];
u1(pi/256) q[113];
cx q[113],q[106];
u1(-pi/256) q[106];
cx q[113],q[106];
u1(pi/256) q[106];
u1(pi/128) q[113];
cx q[113],q[107];
u1(-pi/128) q[107];
cx q[113],q[107];
u1(pi/128) q[107];
u1(pi/64) q[113];
cx q[113],q[108];
u1(-pi/64) q[108];
cx q[113],q[108];
u1(pi/64) q[108];
u1(pi/32) q[113];
cx q[113],q[109];
u1(-pi/32) q[109];
cx q[113],q[109];
u1(pi/32) q[109];
u1(pi/16) q[113];
cx q[113],q[110];
u1(-pi/16) q[110];
cx q[113],q[110];
u1(pi/16) q[110];
u1(pi/8) q[113];
cx q[113],q[111];
u1(-pi/8) q[111];
cx q[113],q[111];
u1(pi/8) q[111];
u1(pi/4) q[113];
cx q[113],q[112];
u1(-pi/4) q[112];
cx q[113],q[112];
u1(pi/4) q[112];
h q[113];
u1(0) q[114];
cx q[114],q[0];
u1(0) q[0];
cx q[114],q[0];
u1(0) q[0];
u1(0) q[114];
cx q[114],q[1];
u1(0) q[1];
cx q[114],q[1];
u1(0) q[1];
u1(0) q[114];
cx q[114],q[2];
u1(0) q[2];
cx q[114],q[2];
u1(0) q[2];
u1(0) q[114];
cx q[114],q[3];
u1(0) q[3];
cx q[114],q[3];
u1(0) q[3];
u1(0) q[114];
cx q[114],q[4];
u1(0) q[4];
cx q[114],q[4];
u1(0) q[4];
u1(0) q[114];
cx q[114],q[5];
u1(0) q[5];
cx q[114],q[5];
u1(0) q[5];
u1(0) q[114];
cx q[114],q[6];
u1(0) q[6];
cx q[114],q[6];
u1(0) q[6];
u1(0) q[114];
cx q[114],q[7];
u1(0) q[7];
cx q[114],q[7];
u1(0) q[7];
u1(0) q[114];
cx q[114],q[8];
u1(0) q[8];
cx q[114],q[8];
u1(0) q[8];
u1(0) q[114];
cx q[114],q[9];
u1(0) q[9];
cx q[114],q[9];
u1(0) q[9];
u1(0) q[114];
cx q[114],q[10];
u1(0) q[10];
cx q[114],q[10];
u1(0) q[10];
u1(0) q[114];
cx q[114],q[11];
u1(0) q[11];
cx q[114],q[11];
u1(0) q[11];
u1(0) q[114];
cx q[114],q[12];
u1(0) q[12];
cx q[114],q[12];
u1(0) q[12];
u1(0) q[114];
cx q[114],q[13];
u1(0) q[13];
cx q[114],q[13];
u1(0) q[13];
u1(0) q[114];
cx q[114],q[14];
u1(0) q[14];
cx q[114],q[14];
u1(0) q[14];
u1(0) q[114];
cx q[114],q[15];
u1(0) q[15];
cx q[114],q[15];
u1(0) q[15];
u1(0) q[114];
cx q[114],q[16];
u1(0) q[16];
cx q[114],q[16];
u1(0) q[16];
u1(0) q[114];
cx q[114],q[17];
u1(0) q[17];
cx q[114],q[17];
u1(0) q[17];
u1(0) q[114];
cx q[114],q[18];
u1(0) q[18];
cx q[114],q[18];
u1(0) q[18];
u1(0) q[114];
cx q[114],q[19];
u1(0) q[19];
cx q[114],q[19];
u1(0) q[19];
u1(0) q[114];
cx q[114],q[20];
u1(0) q[20];
cx q[114],q[20];
u1(0) q[20];
u1(0) q[114];
cx q[114],q[21];
u1(0) q[21];
cx q[114],q[21];
u1(0) q[21];
u1(0) q[114];
cx q[114],q[22];
u1(0) q[22];
cx q[114],q[22];
u1(0) q[22];
u1(0) q[114];
cx q[114],q[23];
u1(0) q[23];
cx q[114],q[23];
u1(0) q[23];
u1(0) q[114];
cx q[114],q[24];
u1(0) q[24];
cx q[114],q[24];
u1(0) q[24];
u1(0) q[114];
cx q[114],q[25];
u1(0) q[25];
cx q[114],q[25];
u1(0) q[25];
u1(0) q[114];
cx q[114],q[26];
u1(0) q[26];
cx q[114],q[26];
u1(0) q[26];
u1(0) q[114];
cx q[114],q[27];
u1(0) q[27];
cx q[114],q[27];
u1(0) q[27];
u1(0) q[114];
cx q[114],q[28];
u1(0) q[28];
cx q[114],q[28];
u1(0) q[28];
u1(0) q[114];
cx q[114],q[29];
u1(0) q[29];
cx q[114],q[29];
u1(0) q[29];
u1(0) q[114];
cx q[114],q[30];
u1(0) q[30];
cx q[114],q[30];
u1(0) q[30];
u1(0) q[114];
cx q[114],q[31];
u1(0) q[31];
cx q[114],q[31];
u1(0) q[31];
u1(0) q[114];
cx q[114],q[32];
u1(0) q[32];
cx q[114],q[32];
u1(0) q[32];
u1(0) q[114];
cx q[114],q[33];
u1(0) q[33];
cx q[114],q[33];
u1(0) q[33];
u1(0) q[114];
cx q[114],q[34];
u1(0) q[34];
cx q[114],q[34];
u1(0) q[34];
u1(0) q[114];
cx q[114],q[35];
u1(0) q[35];
cx q[114],q[35];
u1(0) q[35];
u1(0) q[114];
cx q[114],q[36];
u1(0) q[36];
cx q[114],q[36];
u1(0) q[36];
u1(0) q[114];
cx q[114],q[37];
u1(0) q[37];
cx q[114],q[37];
u1(0) q[37];
u1(0) q[114];
cx q[114],q[38];
u1(0) q[38];
cx q[114],q[38];
u1(0) q[38];
u1(0) q[114];
cx q[114],q[39];
u1(0) q[39];
cx q[114],q[39];
u1(0) q[39];
u1(0) q[114];
cx q[114],q[40];
u1(0) q[40];
cx q[114],q[40];
u1(0) q[40];
u1(0) q[114];
cx q[114],q[41];
u1(0) q[41];
cx q[114],q[41];
u1(0) q[41];
u1(0) q[114];
cx q[114],q[42];
u1(0) q[42];
cx q[114],q[42];
u1(0) q[42];
u1(0) q[114];
cx q[114],q[43];
u1(0) q[43];
cx q[114],q[43];
u1(0) q[43];
u1(0) q[114];
cx q[114],q[44];
u1(0) q[44];
cx q[114],q[44];
u1(0) q[44];
u1(0) q[114];
cx q[114],q[45];
u1(0) q[45];
cx q[114],q[45];
u1(0) q[45];
u1(0) q[114];
cx q[114],q[46];
u1(0) q[46];
cx q[114],q[46];
u1(0) q[46];
u1(0) q[114];
cx q[114],q[47];
u1(0) q[47];
cx q[114],q[47];
u1(0) q[47];
u1(0) q[114];
cx q[114],q[48];
u1(0) q[48];
cx q[114],q[48];
u1(0) q[48];
u1(0) q[114];
cx q[114],q[49];
u1(0) q[49];
cx q[114],q[49];
u1(0) q[49];
u1(0) q[114];
cx q[114],q[50];
u1(0) q[50];
cx q[114],q[50];
u1(0) q[50];
u1(0) q[114];
cx q[114],q[51];
u1(0) q[51];
cx q[114],q[51];
u1(0) q[51];
u1(0) q[114];
cx q[114],q[52];
u1(0) q[52];
cx q[114],q[52];
u1(0) q[52];
u1(0) q[114];
cx q[114],q[53];
u1(0) q[53];
cx q[114],q[53];
u1(0) q[53];
u1(0) q[114];
cx q[114],q[54];
u1(0) q[54];
cx q[114],q[54];
u1(0) q[54];
u1(0) q[114];
cx q[114],q[55];
u1(0) q[55];
cx q[114],q[55];
u1(0) q[55];
u1(0) q[114];
cx q[114],q[56];
u1(0) q[56];
cx q[114],q[56];
u1(0) q[56];
u1(0) q[114];
cx q[114],q[57];
u1(0) q[57];
cx q[114],q[57];
u1(0) q[57];
u1(0) q[114];
cx q[114],q[58];
u1(0) q[58];
cx q[114],q[58];
u1(0) q[58];
u1(0) q[114];
cx q[114],q[59];
u1(0) q[59];
cx q[114],q[59];
u1(0) q[59];
u1(0) q[114];
cx q[114],q[60];
u1(0) q[60];
cx q[114],q[60];
u1(0) q[60];
u1(0) q[114];
cx q[114],q[61];
u1(0) q[61];
cx q[114],q[61];
u1(0) q[61];
u1(0) q[114];
cx q[114],q[62];
u1(0) q[62];
cx q[114],q[62];
u1(0) q[62];
u1(0) q[114];
cx q[114],q[63];
u1(0) q[63];
cx q[114],q[63];
u1(0) q[63];
u1(0) q[114];
cx q[114],q[64];
u1(0) q[64];
cx q[114],q[64];
u1(0) q[64];
u1(0) q[114];
cx q[114],q[65];
u1(0) q[65];
cx q[114],q[65];
u1(0) q[65];
u1(0) q[114];
cx q[114],q[66];
u1(0) q[66];
cx q[114],q[66];
u1(0) q[66];
u1(pi/281474976710656) q[114];
cx q[114],q[67];
u1(-pi/281474976710656) q[67];
cx q[114],q[67];
u1(pi/281474976710656) q[67];
u1(pi/140737488355328) q[114];
cx q[114],q[68];
u1(-pi/140737488355328) q[68];
cx q[114],q[68];
u1(pi/140737488355328) q[68];
u1(pi/70368744177664) q[114];
cx q[114],q[69];
u1(-pi/70368744177664) q[69];
cx q[114],q[69];
u1(pi/70368744177664) q[69];
u1(pi/35184372088832) q[114];
cx q[114],q[70];
u1(-pi/35184372088832) q[70];
cx q[114],q[70];
u1(pi/35184372088832) q[70];
u1(pi/17592186044416) q[114];
cx q[114],q[71];
u1(-pi/17592186044416) q[71];
cx q[114],q[71];
u1(pi/17592186044416) q[71];
u1(pi/8796093022208) q[114];
cx q[114],q[72];
u1(-pi/8796093022208) q[72];
cx q[114],q[72];
u1(pi/8796093022208) q[72];
u1(pi/4398046511104) q[114];
cx q[114],q[73];
u1(-pi/4398046511104) q[73];
cx q[114],q[73];
u1(pi/4398046511104) q[73];
u1(pi/2199023255552) q[114];
cx q[114],q[74];
u1(-pi/2199023255552) q[74];
cx q[114],q[74];
u1(pi/2199023255552) q[74];
u1(pi/1099511627776) q[114];
cx q[114],q[75];
u1(-pi/1099511627776) q[75];
cx q[114],q[75];
u1(pi/1099511627776) q[75];
u1(pi/549755813888) q[114];
cx q[114],q[76];
u1(-pi/549755813888) q[76];
cx q[114],q[76];
u1(pi/549755813888) q[76];
u1(pi/274877906944) q[114];
cx q[114],q[77];
u1(-pi/274877906944) q[77];
cx q[114],q[77];
u1(pi/274877906944) q[77];
u1(pi/137438953472) q[114];
cx q[114],q[78];
u1(-pi/137438953472) q[78];
cx q[114],q[78];
u1(pi/137438953472) q[78];
u1(pi/68719476736) q[114];
cx q[114],q[79];
u1(-pi/68719476736) q[79];
cx q[114],q[79];
u1(pi/68719476736) q[79];
u1(pi/34359738368) q[114];
cx q[114],q[80];
u1(-pi/34359738368) q[80];
cx q[114],q[80];
u1(pi/34359738368) q[80];
u1(pi/17179869184) q[114];
cx q[114],q[81];
u1(-pi/17179869184) q[81];
cx q[114],q[81];
u1(pi/17179869184) q[81];
u1(pi/8589934592) q[114];
cx q[114],q[82];
u1(-pi/8589934592) q[82];
cx q[114],q[82];
u1(pi/8589934592) q[82];
u1(pi/4294967296) q[114];
cx q[114],q[83];
u1(-pi/4294967296) q[83];
cx q[114],q[83];
u1(pi/4294967296) q[83];
u1(pi/2147483648) q[114];
cx q[114],q[84];
u1(-pi/2147483648) q[84];
cx q[114],q[84];
u1(pi/2147483648) q[84];
u1(pi/1073741824) q[114];
cx q[114],q[85];
u1(-pi/1073741824) q[85];
cx q[114],q[85];
u1(pi/1073741824) q[85];
u1(pi/536870912) q[114];
cx q[114],q[86];
u1(-pi/536870912) q[86];
cx q[114],q[86];
u1(pi/536870912) q[86];
u1(pi/268435456) q[114];
cx q[114],q[87];
u1(-pi/268435456) q[87];
cx q[114],q[87];
u1(pi/268435456) q[87];
u1(pi/134217728) q[114];
cx q[114],q[88];
u1(-pi/134217728) q[88];
cx q[114],q[88];
u1(pi/134217728) q[88];
u1(pi/67108864) q[114];
cx q[114],q[89];
u1(-pi/67108864) q[89];
cx q[114],q[89];
u1(pi/67108864) q[89];
u1(pi/33554432) q[114];
cx q[114],q[90];
u1(-pi/33554432) q[90];
cx q[114],q[90];
u1(pi/33554432) q[90];
u1(pi/16777216) q[114];
cx q[114],q[91];
u1(-pi/16777216) q[91];
cx q[114],q[91];
u1(pi/16777216) q[91];
u1(pi/8388608) q[114];
cx q[114],q[92];
u1(-pi/8388608) q[92];
cx q[114],q[92];
u1(pi/8388608) q[92];
u1(pi/4194304) q[114];
cx q[114],q[93];
u1(-pi/4194304) q[93];
cx q[114],q[93];
u1(pi/4194304) q[93];
u1(pi/2097152) q[114];
cx q[114],q[94];
u1(-pi/2097152) q[94];
cx q[114],q[94];
u1(pi/2097152) q[94];
u1(pi/1048576) q[114];
cx q[114],q[95];
u1(-pi/1048576) q[95];
cx q[114],q[95];
u1(pi/1048576) q[95];
u1(pi/524288) q[114];
cx q[114],q[96];
u1(-pi/524288) q[96];
cx q[114],q[96];
u1(pi/524288) q[96];
u1(pi/262144) q[114];
cx q[114],q[97];
u1(-pi/262144) q[97];
cx q[114],q[97];
u1(pi/262144) q[97];
u1(pi/131072) q[114];
cx q[114],q[98];
u1(-pi/131072) q[98];
cx q[114],q[98];
u1(pi/131072) q[98];
u1(pi/65536) q[114];
cx q[114],q[99];
u1(-pi/65536) q[99];
cx q[114],q[99];
u1(pi/65536) q[99];
u1(pi/32768) q[114];
cx q[114],q[100];
u1(-pi/32768) q[100];
cx q[114],q[100];
u1(pi/32768) q[100];
u1(pi/16384) q[114];
cx q[114],q[101];
u1(-pi/16384) q[101];
cx q[114],q[101];
u1(pi/16384) q[101];
u1(pi/8192) q[114];
cx q[114],q[102];
u1(-pi/8192) q[102];
cx q[114],q[102];
u1(pi/8192) q[102];
u1(pi/4096) q[114];
cx q[114],q[103];
u1(-pi/4096) q[103];
cx q[114],q[103];
u1(pi/4096) q[103];
u1(pi/2048) q[114];
cx q[114],q[104];
u1(-pi/2048) q[104];
cx q[114],q[104];
u1(pi/2048) q[104];
u1(pi/1024) q[114];
cx q[114],q[105];
u1(-pi/1024) q[105];
cx q[114],q[105];
u1(pi/1024) q[105];
u1(pi/512) q[114];
cx q[114],q[106];
u1(-pi/512) q[106];
cx q[114],q[106];
u1(pi/512) q[106];
u1(pi/256) q[114];
cx q[114],q[107];
u1(-pi/256) q[107];
cx q[114],q[107];
u1(pi/256) q[107];
u1(pi/128) q[114];
cx q[114],q[108];
u1(-pi/128) q[108];
cx q[114],q[108];
u1(pi/128) q[108];
u1(pi/64) q[114];
cx q[114],q[109];
u1(-pi/64) q[109];
cx q[114],q[109];
u1(pi/64) q[109];
u1(pi/32) q[114];
cx q[114],q[110];
u1(-pi/32) q[110];
cx q[114],q[110];
u1(pi/32) q[110];
u1(pi/16) q[114];
cx q[114],q[111];
u1(-pi/16) q[111];
cx q[114],q[111];
u1(pi/16) q[111];
u1(pi/8) q[114];
cx q[114],q[112];
u1(-pi/8) q[112];
cx q[114],q[112];
u1(pi/8) q[112];
u1(pi/4) q[114];
cx q[114],q[113];
u1(-pi/4) q[113];
cx q[114],q[113];
u1(pi/4) q[113];
h q[114];
u1(0) q[115];
cx q[115],q[0];
u1(0) q[0];
cx q[115],q[0];
u1(0) q[0];
u1(0) q[115];
cx q[115],q[1];
u1(0) q[1];
cx q[115],q[1];
u1(0) q[1];
u1(0) q[115];
cx q[115],q[2];
u1(0) q[2];
cx q[115],q[2];
u1(0) q[2];
u1(0) q[115];
cx q[115],q[3];
u1(0) q[3];
cx q[115],q[3];
u1(0) q[3];
u1(0) q[115];
cx q[115],q[4];
u1(0) q[4];
cx q[115],q[4];
u1(0) q[4];
u1(0) q[115];
cx q[115],q[5];
u1(0) q[5];
cx q[115],q[5];
u1(0) q[5];
u1(0) q[115];
cx q[115],q[6];
u1(0) q[6];
cx q[115],q[6];
u1(0) q[6];
u1(0) q[115];
cx q[115],q[7];
u1(0) q[7];
cx q[115],q[7];
u1(0) q[7];
u1(0) q[115];
cx q[115],q[8];
u1(0) q[8];
cx q[115],q[8];
u1(0) q[8];
u1(0) q[115];
cx q[115],q[9];
u1(0) q[9];
cx q[115],q[9];
u1(0) q[9];
u1(0) q[115];
cx q[115],q[10];
u1(0) q[10];
cx q[115],q[10];
u1(0) q[10];
u1(0) q[115];
cx q[115],q[11];
u1(0) q[11];
cx q[115],q[11];
u1(0) q[11];
u1(0) q[115];
cx q[115],q[12];
u1(0) q[12];
cx q[115],q[12];
u1(0) q[12];
u1(0) q[115];
cx q[115],q[13];
u1(0) q[13];
cx q[115],q[13];
u1(0) q[13];
u1(0) q[115];
cx q[115],q[14];
u1(0) q[14];
cx q[115],q[14];
u1(0) q[14];
u1(0) q[115];
cx q[115],q[15];
u1(0) q[15];
cx q[115],q[15];
u1(0) q[15];
u1(0) q[115];
cx q[115],q[16];
u1(0) q[16];
cx q[115],q[16];
u1(0) q[16];
u1(0) q[115];
cx q[115],q[17];
u1(0) q[17];
cx q[115],q[17];
u1(0) q[17];
u1(0) q[115];
cx q[115],q[18];
u1(0) q[18];
cx q[115],q[18];
u1(0) q[18];
u1(0) q[115];
cx q[115],q[19];
u1(0) q[19];
cx q[115],q[19];
u1(0) q[19];
u1(0) q[115];
cx q[115],q[20];
u1(0) q[20];
cx q[115],q[20];
u1(0) q[20];
u1(0) q[115];
cx q[115],q[21];
u1(0) q[21];
cx q[115],q[21];
u1(0) q[21];
u1(0) q[115];
cx q[115],q[22];
u1(0) q[22];
cx q[115],q[22];
u1(0) q[22];
u1(0) q[115];
cx q[115],q[23];
u1(0) q[23];
cx q[115],q[23];
u1(0) q[23];
u1(0) q[115];
cx q[115],q[24];
u1(0) q[24];
cx q[115],q[24];
u1(0) q[24];
u1(0) q[115];
cx q[115],q[25];
u1(0) q[25];
cx q[115],q[25];
u1(0) q[25];
u1(0) q[115];
cx q[115],q[26];
u1(0) q[26];
cx q[115],q[26];
u1(0) q[26];
u1(0) q[115];
cx q[115],q[27];
u1(0) q[27];
cx q[115],q[27];
u1(0) q[27];
u1(0) q[115];
cx q[115],q[28];
u1(0) q[28];
cx q[115],q[28];
u1(0) q[28];
u1(0) q[115];
cx q[115],q[29];
u1(0) q[29];
cx q[115],q[29];
u1(0) q[29];
u1(0) q[115];
cx q[115],q[30];
u1(0) q[30];
cx q[115],q[30];
u1(0) q[30];
u1(0) q[115];
cx q[115],q[31];
u1(0) q[31];
cx q[115],q[31];
u1(0) q[31];
u1(0) q[115];
cx q[115],q[32];
u1(0) q[32];
cx q[115],q[32];
u1(0) q[32];
u1(0) q[115];
cx q[115],q[33];
u1(0) q[33];
cx q[115],q[33];
u1(0) q[33];
u1(0) q[115];
cx q[115],q[34];
u1(0) q[34];
cx q[115],q[34];
u1(0) q[34];
u1(0) q[115];
cx q[115],q[35];
u1(0) q[35];
cx q[115],q[35];
u1(0) q[35];
u1(0) q[115];
cx q[115],q[36];
u1(0) q[36];
cx q[115],q[36];
u1(0) q[36];
u1(0) q[115];
cx q[115],q[37];
u1(0) q[37];
cx q[115],q[37];
u1(0) q[37];
u1(0) q[115];
cx q[115],q[38];
u1(0) q[38];
cx q[115],q[38];
u1(0) q[38];
u1(0) q[115];
cx q[115],q[39];
u1(0) q[39];
cx q[115],q[39];
u1(0) q[39];
u1(0) q[115];
cx q[115],q[40];
u1(0) q[40];
cx q[115],q[40];
u1(0) q[40];
u1(0) q[115];
cx q[115],q[41];
u1(0) q[41];
cx q[115],q[41];
u1(0) q[41];
u1(0) q[115];
cx q[115],q[42];
u1(0) q[42];
cx q[115],q[42];
u1(0) q[42];
u1(0) q[115];
cx q[115],q[43];
u1(0) q[43];
cx q[115],q[43];
u1(0) q[43];
u1(0) q[115];
cx q[115],q[44];
u1(0) q[44];
cx q[115],q[44];
u1(0) q[44];
u1(0) q[115];
cx q[115],q[45];
u1(0) q[45];
cx q[115],q[45];
u1(0) q[45];
u1(0) q[115];
cx q[115],q[46];
u1(0) q[46];
cx q[115],q[46];
u1(0) q[46];
u1(0) q[115];
cx q[115],q[47];
u1(0) q[47];
cx q[115],q[47];
u1(0) q[47];
u1(0) q[115];
cx q[115],q[48];
u1(0) q[48];
cx q[115],q[48];
u1(0) q[48];
u1(0) q[115];
cx q[115],q[49];
u1(0) q[49];
cx q[115],q[49];
u1(0) q[49];
u1(0) q[115];
cx q[115],q[50];
u1(0) q[50];
cx q[115],q[50];
u1(0) q[50];
u1(0) q[115];
cx q[115],q[51];
u1(0) q[51];
cx q[115],q[51];
u1(0) q[51];
u1(0) q[115];
cx q[115],q[52];
u1(0) q[52];
cx q[115],q[52];
u1(0) q[52];
u1(0) q[115];
cx q[115],q[53];
u1(0) q[53];
cx q[115],q[53];
u1(0) q[53];
u1(0) q[115];
cx q[115],q[54];
u1(0) q[54];
cx q[115],q[54];
u1(0) q[54];
u1(0) q[115];
cx q[115],q[55];
u1(0) q[55];
cx q[115],q[55];
u1(0) q[55];
u1(0) q[115];
cx q[115],q[56];
u1(0) q[56];
cx q[115],q[56];
u1(0) q[56];
u1(0) q[115];
cx q[115],q[57];
u1(0) q[57];
cx q[115],q[57];
u1(0) q[57];
u1(0) q[115];
cx q[115],q[58];
u1(0) q[58];
cx q[115],q[58];
u1(0) q[58];
u1(0) q[115];
cx q[115],q[59];
u1(0) q[59];
cx q[115],q[59];
u1(0) q[59];
u1(0) q[115];
cx q[115],q[60];
u1(0) q[60];
cx q[115],q[60];
u1(0) q[60];
u1(0) q[115];
cx q[115],q[61];
u1(0) q[61];
cx q[115],q[61];
u1(0) q[61];
u1(0) q[115];
cx q[115],q[62];
u1(0) q[62];
cx q[115],q[62];
u1(0) q[62];
u1(0) q[115];
cx q[115],q[63];
u1(0) q[63];
cx q[115],q[63];
u1(0) q[63];
u1(0) q[115];
cx q[115],q[64];
u1(0) q[64];
cx q[115],q[64];
u1(0) q[64];
u1(0) q[115];
cx q[115],q[65];
u1(0) q[65];
cx q[115],q[65];
u1(0) q[65];
u1(0) q[115];
cx q[115],q[66];
u1(0) q[66];
cx q[115],q[66];
u1(0) q[66];
u1(0) q[115];
cx q[115],q[67];
u1(0) q[67];
cx q[115],q[67];
u1(0) q[67];
u1(pi/281474976710656) q[115];
cx q[115],q[68];
u1(-pi/281474976710656) q[68];
cx q[115],q[68];
u1(pi/281474976710656) q[68];
u1(pi/140737488355328) q[115];
cx q[115],q[69];
u1(-pi/140737488355328) q[69];
cx q[115],q[69];
u1(pi/140737488355328) q[69];
u1(pi/70368744177664) q[115];
cx q[115],q[70];
u1(-pi/70368744177664) q[70];
cx q[115],q[70];
u1(pi/70368744177664) q[70];
u1(pi/35184372088832) q[115];
cx q[115],q[71];
u1(-pi/35184372088832) q[71];
cx q[115],q[71];
u1(pi/35184372088832) q[71];
u1(pi/17592186044416) q[115];
cx q[115],q[72];
u1(-pi/17592186044416) q[72];
cx q[115],q[72];
u1(pi/17592186044416) q[72];
u1(pi/8796093022208) q[115];
cx q[115],q[73];
u1(-pi/8796093022208) q[73];
cx q[115],q[73];
u1(pi/8796093022208) q[73];
u1(pi/4398046511104) q[115];
cx q[115],q[74];
u1(-pi/4398046511104) q[74];
cx q[115],q[74];
u1(pi/4398046511104) q[74];
u1(pi/2199023255552) q[115];
cx q[115],q[75];
u1(-pi/2199023255552) q[75];
cx q[115],q[75];
u1(pi/2199023255552) q[75];
u1(pi/1099511627776) q[115];
cx q[115],q[76];
u1(-pi/1099511627776) q[76];
cx q[115],q[76];
u1(pi/1099511627776) q[76];
u1(pi/549755813888) q[115];
cx q[115],q[77];
u1(-pi/549755813888) q[77];
cx q[115],q[77];
u1(pi/549755813888) q[77];
u1(pi/274877906944) q[115];
cx q[115],q[78];
u1(-pi/274877906944) q[78];
cx q[115],q[78];
u1(pi/274877906944) q[78];
u1(pi/137438953472) q[115];
cx q[115],q[79];
u1(-pi/137438953472) q[79];
cx q[115],q[79];
u1(pi/137438953472) q[79];
u1(pi/68719476736) q[115];
cx q[115],q[80];
u1(-pi/68719476736) q[80];
cx q[115],q[80];
u1(pi/68719476736) q[80];
u1(pi/34359738368) q[115];
cx q[115],q[81];
u1(-pi/34359738368) q[81];
cx q[115],q[81];
u1(pi/34359738368) q[81];
u1(pi/17179869184) q[115];
cx q[115],q[82];
u1(-pi/17179869184) q[82];
cx q[115],q[82];
u1(pi/17179869184) q[82];
u1(pi/8589934592) q[115];
cx q[115],q[83];
u1(-pi/8589934592) q[83];
cx q[115],q[83];
u1(pi/8589934592) q[83];
u1(pi/4294967296) q[115];
cx q[115],q[84];
u1(-pi/4294967296) q[84];
cx q[115],q[84];
u1(pi/4294967296) q[84];
u1(pi/2147483648) q[115];
cx q[115],q[85];
u1(-pi/2147483648) q[85];
cx q[115],q[85];
u1(pi/2147483648) q[85];
u1(pi/1073741824) q[115];
cx q[115],q[86];
u1(-pi/1073741824) q[86];
cx q[115],q[86];
u1(pi/1073741824) q[86];
u1(pi/536870912) q[115];
cx q[115],q[87];
u1(-pi/536870912) q[87];
cx q[115],q[87];
u1(pi/536870912) q[87];
u1(pi/268435456) q[115];
cx q[115],q[88];
u1(-pi/268435456) q[88];
cx q[115],q[88];
u1(pi/268435456) q[88];
u1(pi/134217728) q[115];
cx q[115],q[89];
u1(-pi/134217728) q[89];
cx q[115],q[89];
u1(pi/134217728) q[89];
u1(pi/67108864) q[115];
cx q[115],q[90];
u1(-pi/67108864) q[90];
cx q[115],q[90];
u1(pi/67108864) q[90];
u1(pi/33554432) q[115];
cx q[115],q[91];
u1(-pi/33554432) q[91];
cx q[115],q[91];
u1(pi/33554432) q[91];
u1(pi/16777216) q[115];
cx q[115],q[92];
u1(-pi/16777216) q[92];
cx q[115],q[92];
u1(pi/16777216) q[92];
u1(pi/8388608) q[115];
cx q[115],q[93];
u1(-pi/8388608) q[93];
cx q[115],q[93];
u1(pi/8388608) q[93];
u1(pi/4194304) q[115];
cx q[115],q[94];
u1(-pi/4194304) q[94];
cx q[115],q[94];
u1(pi/4194304) q[94];
u1(pi/2097152) q[115];
cx q[115],q[95];
u1(-pi/2097152) q[95];
cx q[115],q[95];
u1(pi/2097152) q[95];
u1(pi/1048576) q[115];
cx q[115],q[96];
u1(-pi/1048576) q[96];
cx q[115],q[96];
u1(pi/1048576) q[96];
u1(pi/524288) q[115];
cx q[115],q[97];
u1(-pi/524288) q[97];
cx q[115],q[97];
u1(pi/524288) q[97];
u1(pi/262144) q[115];
cx q[115],q[98];
u1(-pi/262144) q[98];
cx q[115],q[98];
u1(pi/262144) q[98];
u1(pi/131072) q[115];
cx q[115],q[99];
u1(-pi/131072) q[99];
cx q[115],q[99];
u1(pi/131072) q[99];
u1(pi/65536) q[115];
cx q[115],q[100];
u1(-pi/65536) q[100];
cx q[115],q[100];
u1(pi/65536) q[100];
u1(pi/32768) q[115];
cx q[115],q[101];
u1(-pi/32768) q[101];
cx q[115],q[101];
u1(pi/32768) q[101];
u1(pi/16384) q[115];
cx q[115],q[102];
u1(-pi/16384) q[102];
cx q[115],q[102];
u1(pi/16384) q[102];
u1(pi/8192) q[115];
cx q[115],q[103];
u1(-pi/8192) q[103];
cx q[115],q[103];
u1(pi/8192) q[103];
u1(pi/4096) q[115];
cx q[115],q[104];
u1(-pi/4096) q[104];
cx q[115],q[104];
u1(pi/4096) q[104];
u1(pi/2048) q[115];
cx q[115],q[105];
u1(-pi/2048) q[105];
cx q[115],q[105];
u1(pi/2048) q[105];
u1(pi/1024) q[115];
cx q[115],q[106];
u1(-pi/1024) q[106];
cx q[115],q[106];
u1(pi/1024) q[106];
u1(pi/512) q[115];
cx q[115],q[107];
u1(-pi/512) q[107];
cx q[115],q[107];
u1(pi/512) q[107];
u1(pi/256) q[115];
cx q[115],q[108];
u1(-pi/256) q[108];
cx q[115],q[108];
u1(pi/256) q[108];
u1(pi/128) q[115];
cx q[115],q[109];
u1(-pi/128) q[109];
cx q[115],q[109];
u1(pi/128) q[109];
u1(pi/64) q[115];
cx q[115],q[110];
u1(-pi/64) q[110];
cx q[115],q[110];
u1(pi/64) q[110];
u1(pi/32) q[115];
cx q[115],q[111];
u1(-pi/32) q[111];
cx q[115],q[111];
u1(pi/32) q[111];
u1(pi/16) q[115];
cx q[115],q[112];
u1(-pi/16) q[112];
cx q[115],q[112];
u1(pi/16) q[112];
u1(pi/8) q[115];
cx q[115],q[113];
u1(-pi/8) q[113];
cx q[115],q[113];
u1(pi/8) q[113];
u1(pi/4) q[115];
cx q[115],q[114];
u1(-pi/4) q[114];
cx q[115],q[114];
u1(pi/4) q[114];
h q[115];
u1(0) q[116];
cx q[116],q[0];
u1(0) q[0];
cx q[116],q[0];
u1(0) q[0];
u1(0) q[116];
cx q[116],q[1];
u1(0) q[1];
cx q[116],q[1];
u1(0) q[1];
u1(0) q[116];
cx q[116],q[2];
u1(0) q[2];
cx q[116],q[2];
u1(0) q[2];
u1(0) q[116];
cx q[116],q[3];
u1(0) q[3];
cx q[116],q[3];
u1(0) q[3];
u1(0) q[116];
cx q[116],q[4];
u1(0) q[4];
cx q[116],q[4];
u1(0) q[4];
u1(0) q[116];
cx q[116],q[5];
u1(0) q[5];
cx q[116],q[5];
u1(0) q[5];
u1(0) q[116];
cx q[116],q[6];
u1(0) q[6];
cx q[116],q[6];
u1(0) q[6];
u1(0) q[116];
cx q[116],q[7];
u1(0) q[7];
cx q[116],q[7];
u1(0) q[7];
u1(0) q[116];
cx q[116],q[8];
u1(0) q[8];
cx q[116],q[8];
u1(0) q[8];
u1(0) q[116];
cx q[116],q[9];
u1(0) q[9];
cx q[116],q[9];
u1(0) q[9];
u1(0) q[116];
cx q[116],q[10];
u1(0) q[10];
cx q[116],q[10];
u1(0) q[10];
u1(0) q[116];
cx q[116],q[11];
u1(0) q[11];
cx q[116],q[11];
u1(0) q[11];
u1(0) q[116];
cx q[116],q[12];
u1(0) q[12];
cx q[116],q[12];
u1(0) q[12];
u1(0) q[116];
cx q[116],q[13];
u1(0) q[13];
cx q[116],q[13];
u1(0) q[13];
u1(0) q[116];
cx q[116],q[14];
u1(0) q[14];
cx q[116],q[14];
u1(0) q[14];
u1(0) q[116];
cx q[116],q[15];
u1(0) q[15];
cx q[116],q[15];
u1(0) q[15];
u1(0) q[116];
cx q[116],q[16];
u1(0) q[16];
cx q[116],q[16];
u1(0) q[16];
u1(0) q[116];
cx q[116],q[17];
u1(0) q[17];
cx q[116],q[17];
u1(0) q[17];
u1(0) q[116];
cx q[116],q[18];
u1(0) q[18];
cx q[116],q[18];
u1(0) q[18];
u1(0) q[116];
cx q[116],q[19];
u1(0) q[19];
cx q[116],q[19];
u1(0) q[19];
u1(0) q[116];
cx q[116],q[20];
u1(0) q[20];
cx q[116],q[20];
u1(0) q[20];
u1(0) q[116];
cx q[116],q[21];
u1(0) q[21];
cx q[116],q[21];
u1(0) q[21];
u1(0) q[116];
cx q[116],q[22];
u1(0) q[22];
cx q[116],q[22];
u1(0) q[22];
u1(0) q[116];
cx q[116],q[23];
u1(0) q[23];
cx q[116],q[23];
u1(0) q[23];
u1(0) q[116];
cx q[116],q[24];
u1(0) q[24];
cx q[116],q[24];
u1(0) q[24];
u1(0) q[116];
cx q[116],q[25];
u1(0) q[25];
cx q[116],q[25];
u1(0) q[25];
u1(0) q[116];
cx q[116],q[26];
u1(0) q[26];
cx q[116],q[26];
u1(0) q[26];
u1(0) q[116];
cx q[116],q[27];
u1(0) q[27];
cx q[116],q[27];
u1(0) q[27];
u1(0) q[116];
cx q[116],q[28];
u1(0) q[28];
cx q[116],q[28];
u1(0) q[28];
u1(0) q[116];
cx q[116],q[29];
u1(0) q[29];
cx q[116],q[29];
u1(0) q[29];
u1(0) q[116];
cx q[116],q[30];
u1(0) q[30];
cx q[116],q[30];
u1(0) q[30];
u1(0) q[116];
cx q[116],q[31];
u1(0) q[31];
cx q[116],q[31];
u1(0) q[31];
u1(0) q[116];
cx q[116],q[32];
u1(0) q[32];
cx q[116],q[32];
u1(0) q[32];
u1(0) q[116];
cx q[116],q[33];
u1(0) q[33];
cx q[116],q[33];
u1(0) q[33];
u1(0) q[116];
cx q[116],q[34];
u1(0) q[34];
cx q[116],q[34];
u1(0) q[34];
u1(0) q[116];
cx q[116],q[35];
u1(0) q[35];
cx q[116],q[35];
u1(0) q[35];
u1(0) q[116];
cx q[116],q[36];
u1(0) q[36];
cx q[116],q[36];
u1(0) q[36];
u1(0) q[116];
cx q[116],q[37];
u1(0) q[37];
cx q[116],q[37];
u1(0) q[37];
u1(0) q[116];
cx q[116],q[38];
u1(0) q[38];
cx q[116],q[38];
u1(0) q[38];
u1(0) q[116];
cx q[116],q[39];
u1(0) q[39];
cx q[116],q[39];
u1(0) q[39];
u1(0) q[116];
cx q[116],q[40];
u1(0) q[40];
cx q[116],q[40];
u1(0) q[40];
u1(0) q[116];
cx q[116],q[41];
u1(0) q[41];
cx q[116],q[41];
u1(0) q[41];
u1(0) q[116];
cx q[116],q[42];
u1(0) q[42];
cx q[116],q[42];
u1(0) q[42];
u1(0) q[116];
cx q[116],q[43];
u1(0) q[43];
cx q[116],q[43];
u1(0) q[43];
u1(0) q[116];
cx q[116],q[44];
u1(0) q[44];
cx q[116],q[44];
u1(0) q[44];
u1(0) q[116];
cx q[116],q[45];
u1(0) q[45];
cx q[116],q[45];
u1(0) q[45];
u1(0) q[116];
cx q[116],q[46];
u1(0) q[46];
cx q[116],q[46];
u1(0) q[46];
u1(0) q[116];
cx q[116],q[47];
u1(0) q[47];
cx q[116],q[47];
u1(0) q[47];
u1(0) q[116];
cx q[116],q[48];
u1(0) q[48];
cx q[116],q[48];
u1(0) q[48];
u1(0) q[116];
cx q[116],q[49];
u1(0) q[49];
cx q[116],q[49];
u1(0) q[49];
u1(0) q[116];
cx q[116],q[50];
u1(0) q[50];
cx q[116],q[50];
u1(0) q[50];
u1(0) q[116];
cx q[116],q[51];
u1(0) q[51];
cx q[116],q[51];
u1(0) q[51];
u1(0) q[116];
cx q[116],q[52];
u1(0) q[52];
cx q[116],q[52];
u1(0) q[52];
u1(0) q[116];
cx q[116],q[53];
u1(0) q[53];
cx q[116],q[53];
u1(0) q[53];
u1(0) q[116];
cx q[116],q[54];
u1(0) q[54];
cx q[116],q[54];
u1(0) q[54];
u1(0) q[116];
cx q[116],q[55];
u1(0) q[55];
cx q[116],q[55];
u1(0) q[55];
u1(0) q[116];
cx q[116],q[56];
u1(0) q[56];
cx q[116],q[56];
u1(0) q[56];
u1(0) q[116];
cx q[116],q[57];
u1(0) q[57];
cx q[116],q[57];
u1(0) q[57];
u1(0) q[116];
cx q[116],q[58];
u1(0) q[58];
cx q[116],q[58];
u1(0) q[58];
u1(0) q[116];
cx q[116],q[59];
u1(0) q[59];
cx q[116],q[59];
u1(0) q[59];
u1(0) q[116];
cx q[116],q[60];
u1(0) q[60];
cx q[116],q[60];
u1(0) q[60];
u1(0) q[116];
cx q[116],q[61];
u1(0) q[61];
cx q[116],q[61];
u1(0) q[61];
u1(0) q[116];
cx q[116],q[62];
u1(0) q[62];
cx q[116],q[62];
u1(0) q[62];
u1(0) q[116];
cx q[116],q[63];
u1(0) q[63];
cx q[116],q[63];
u1(0) q[63];
u1(0) q[116];
cx q[116],q[64];
u1(0) q[64];
cx q[116],q[64];
u1(0) q[64];
u1(0) q[116];
cx q[116],q[65];
u1(0) q[65];
cx q[116],q[65];
u1(0) q[65];
u1(0) q[116];
cx q[116],q[66];
u1(0) q[66];
cx q[116],q[66];
u1(0) q[66];
u1(0) q[116];
cx q[116],q[67];
u1(0) q[67];
cx q[116],q[67];
u1(0) q[67];
u1(0) q[116];
cx q[116],q[68];
u1(0) q[68];
cx q[116],q[68];
u1(0) q[68];
u1(pi/281474976710656) q[116];
cx q[116],q[69];
u1(-pi/281474976710656) q[69];
cx q[116],q[69];
u1(pi/281474976710656) q[69];
u1(pi/140737488355328) q[116];
cx q[116],q[70];
u1(-pi/140737488355328) q[70];
cx q[116],q[70];
u1(pi/140737488355328) q[70];
u1(pi/70368744177664) q[116];
cx q[116],q[71];
u1(-pi/70368744177664) q[71];
cx q[116],q[71];
u1(pi/70368744177664) q[71];
u1(pi/35184372088832) q[116];
cx q[116],q[72];
u1(-pi/35184372088832) q[72];
cx q[116],q[72];
u1(pi/35184372088832) q[72];
u1(pi/17592186044416) q[116];
cx q[116],q[73];
u1(-pi/17592186044416) q[73];
cx q[116],q[73];
u1(pi/17592186044416) q[73];
u1(pi/8796093022208) q[116];
cx q[116],q[74];
u1(-pi/8796093022208) q[74];
cx q[116],q[74];
u1(pi/8796093022208) q[74];
u1(pi/4398046511104) q[116];
cx q[116],q[75];
u1(-pi/4398046511104) q[75];
cx q[116],q[75];
u1(pi/4398046511104) q[75];
u1(pi/2199023255552) q[116];
cx q[116],q[76];
u1(-pi/2199023255552) q[76];
cx q[116],q[76];
u1(pi/2199023255552) q[76];
u1(pi/1099511627776) q[116];
cx q[116],q[77];
u1(-pi/1099511627776) q[77];
cx q[116],q[77];
u1(pi/1099511627776) q[77];
u1(pi/549755813888) q[116];
cx q[116],q[78];
u1(-pi/549755813888) q[78];
cx q[116],q[78];
u1(pi/549755813888) q[78];
u1(pi/274877906944) q[116];
cx q[116],q[79];
u1(-pi/274877906944) q[79];
cx q[116],q[79];
u1(pi/274877906944) q[79];
u1(pi/137438953472) q[116];
cx q[116],q[80];
u1(-pi/137438953472) q[80];
cx q[116],q[80];
u1(pi/137438953472) q[80];
u1(pi/68719476736) q[116];
cx q[116],q[81];
u1(-pi/68719476736) q[81];
cx q[116],q[81];
u1(pi/68719476736) q[81];
u1(pi/34359738368) q[116];
cx q[116],q[82];
u1(-pi/34359738368) q[82];
cx q[116],q[82];
u1(pi/34359738368) q[82];
u1(pi/17179869184) q[116];
cx q[116],q[83];
u1(-pi/17179869184) q[83];
cx q[116],q[83];
u1(pi/17179869184) q[83];
u1(pi/8589934592) q[116];
cx q[116],q[84];
u1(-pi/8589934592) q[84];
cx q[116],q[84];
u1(pi/8589934592) q[84];
u1(pi/4294967296) q[116];
cx q[116],q[85];
u1(-pi/4294967296) q[85];
cx q[116],q[85];
u1(pi/4294967296) q[85];
u1(pi/2147483648) q[116];
cx q[116],q[86];
u1(-pi/2147483648) q[86];
cx q[116],q[86];
u1(pi/2147483648) q[86];
u1(pi/1073741824) q[116];
cx q[116],q[87];
u1(-pi/1073741824) q[87];
cx q[116],q[87];
u1(pi/1073741824) q[87];
u1(pi/536870912) q[116];
cx q[116],q[88];
u1(-pi/536870912) q[88];
cx q[116],q[88];
u1(pi/536870912) q[88];
u1(pi/268435456) q[116];
cx q[116],q[89];
u1(-pi/268435456) q[89];
cx q[116],q[89];
u1(pi/268435456) q[89];
u1(pi/134217728) q[116];
cx q[116],q[90];
u1(-pi/134217728) q[90];
cx q[116],q[90];
u1(pi/134217728) q[90];
u1(pi/67108864) q[116];
cx q[116],q[91];
u1(-pi/67108864) q[91];
cx q[116],q[91];
u1(pi/67108864) q[91];
u1(pi/33554432) q[116];
cx q[116],q[92];
u1(-pi/33554432) q[92];
cx q[116],q[92];
u1(pi/33554432) q[92];
u1(pi/16777216) q[116];
cx q[116],q[93];
u1(-pi/16777216) q[93];
cx q[116],q[93];
u1(pi/16777216) q[93];
u1(pi/8388608) q[116];
cx q[116],q[94];
u1(-pi/8388608) q[94];
cx q[116],q[94];
u1(pi/8388608) q[94];
u1(pi/4194304) q[116];
cx q[116],q[95];
u1(-pi/4194304) q[95];
cx q[116],q[95];
u1(pi/4194304) q[95];
u1(pi/2097152) q[116];
cx q[116],q[96];
u1(-pi/2097152) q[96];
cx q[116],q[96];
u1(pi/2097152) q[96];
u1(pi/1048576) q[116];
cx q[116],q[97];
u1(-pi/1048576) q[97];
cx q[116],q[97];
u1(pi/1048576) q[97];
u1(pi/524288) q[116];
cx q[116],q[98];
u1(-pi/524288) q[98];
cx q[116],q[98];
u1(pi/524288) q[98];
u1(pi/262144) q[116];
cx q[116],q[99];
u1(-pi/262144) q[99];
cx q[116],q[99];
u1(pi/262144) q[99];
u1(pi/131072) q[116];
cx q[116],q[100];
u1(-pi/131072) q[100];
cx q[116],q[100];
u1(pi/131072) q[100];
u1(pi/65536) q[116];
cx q[116],q[101];
u1(-pi/65536) q[101];
cx q[116],q[101];
u1(pi/65536) q[101];
u1(pi/32768) q[116];
cx q[116],q[102];
u1(-pi/32768) q[102];
cx q[116],q[102];
u1(pi/32768) q[102];
u1(pi/16384) q[116];
cx q[116],q[103];
u1(-pi/16384) q[103];
cx q[116],q[103];
u1(pi/16384) q[103];
u1(pi/8192) q[116];
cx q[116],q[104];
u1(-pi/8192) q[104];
cx q[116],q[104];
u1(pi/8192) q[104];
u1(pi/4096) q[116];
cx q[116],q[105];
u1(-pi/4096) q[105];
cx q[116],q[105];
u1(pi/4096) q[105];
u1(pi/2048) q[116];
cx q[116],q[106];
u1(-pi/2048) q[106];
cx q[116],q[106];
u1(pi/2048) q[106];
u1(pi/1024) q[116];
cx q[116],q[107];
u1(-pi/1024) q[107];
cx q[116],q[107];
u1(pi/1024) q[107];
u1(pi/512) q[116];
cx q[116],q[108];
u1(-pi/512) q[108];
cx q[116],q[108];
u1(pi/512) q[108];
u1(pi/256) q[116];
cx q[116],q[109];
u1(-pi/256) q[109];
cx q[116],q[109];
u1(pi/256) q[109];
u1(pi/128) q[116];
cx q[116],q[110];
u1(-pi/128) q[110];
cx q[116],q[110];
u1(pi/128) q[110];
u1(pi/64) q[116];
cx q[116],q[111];
u1(-pi/64) q[111];
cx q[116],q[111];
u1(pi/64) q[111];
u1(pi/32) q[116];
cx q[116],q[112];
u1(-pi/32) q[112];
cx q[116],q[112];
u1(pi/32) q[112];
u1(pi/16) q[116];
cx q[116],q[113];
u1(-pi/16) q[113];
cx q[116],q[113];
u1(pi/16) q[113];
u1(pi/8) q[116];
cx q[116],q[114];
u1(-pi/8) q[114];
cx q[116],q[114];
u1(pi/8) q[114];
u1(pi/4) q[116];
cx q[116],q[115];
u1(-pi/4) q[115];
cx q[116],q[115];
u1(pi/4) q[115];
h q[116];
u1(0) q[117];
cx q[117],q[0];
u1(0) q[0];
cx q[117],q[0];
u1(0) q[0];
u1(0) q[117];
cx q[117],q[1];
u1(0) q[1];
cx q[117],q[1];
u1(0) q[1];
u1(0) q[117];
cx q[117],q[2];
u1(0) q[2];
cx q[117],q[2];
u1(0) q[2];
u1(0) q[117];
cx q[117],q[3];
u1(0) q[3];
cx q[117],q[3];
u1(0) q[3];
u1(0) q[117];
cx q[117],q[4];
u1(0) q[4];
cx q[117],q[4];
u1(0) q[4];
u1(0) q[117];
cx q[117],q[5];
u1(0) q[5];
cx q[117],q[5];
u1(0) q[5];
u1(0) q[117];
cx q[117],q[6];
u1(0) q[6];
cx q[117],q[6];
u1(0) q[6];
u1(0) q[117];
cx q[117],q[7];
u1(0) q[7];
cx q[117],q[7];
u1(0) q[7];
u1(0) q[117];
cx q[117],q[8];
u1(0) q[8];
cx q[117],q[8];
u1(0) q[8];
u1(0) q[117];
cx q[117],q[9];
u1(0) q[9];
cx q[117],q[9];
u1(0) q[9];
u1(0) q[117];
cx q[117],q[10];
u1(0) q[10];
cx q[117],q[10];
u1(0) q[10];
u1(0) q[117];
cx q[117],q[11];
u1(0) q[11];
cx q[117],q[11];
u1(0) q[11];
u1(0) q[117];
cx q[117],q[12];
u1(0) q[12];
cx q[117],q[12];
u1(0) q[12];
u1(0) q[117];
cx q[117],q[13];
u1(0) q[13];
cx q[117],q[13];
u1(0) q[13];
u1(0) q[117];
cx q[117],q[14];
u1(0) q[14];
cx q[117],q[14];
u1(0) q[14];
u1(0) q[117];
cx q[117],q[15];
u1(0) q[15];
cx q[117],q[15];
u1(0) q[15];
u1(0) q[117];
cx q[117],q[16];
u1(0) q[16];
cx q[117],q[16];
u1(0) q[16];
u1(0) q[117];
cx q[117],q[17];
u1(0) q[17];
cx q[117],q[17];
u1(0) q[17];
u1(0) q[117];
cx q[117],q[18];
u1(0) q[18];
cx q[117],q[18];
u1(0) q[18];
u1(0) q[117];
cx q[117],q[19];
u1(0) q[19];
cx q[117],q[19];
u1(0) q[19];
u1(0) q[117];
cx q[117],q[20];
u1(0) q[20];
cx q[117],q[20];
u1(0) q[20];
u1(0) q[117];
cx q[117],q[21];
u1(0) q[21];
cx q[117],q[21];
u1(0) q[21];
u1(0) q[117];
cx q[117],q[22];
u1(0) q[22];
cx q[117],q[22];
u1(0) q[22];
u1(0) q[117];
cx q[117],q[23];
u1(0) q[23];
cx q[117],q[23];
u1(0) q[23];
u1(0) q[117];
cx q[117],q[24];
u1(0) q[24];
cx q[117],q[24];
u1(0) q[24];
u1(0) q[117];
cx q[117],q[25];
u1(0) q[25];
cx q[117],q[25];
u1(0) q[25];
u1(0) q[117];
cx q[117],q[26];
u1(0) q[26];
cx q[117],q[26];
u1(0) q[26];
u1(0) q[117];
cx q[117],q[27];
u1(0) q[27];
cx q[117],q[27];
u1(0) q[27];
u1(0) q[117];
cx q[117],q[28];
u1(0) q[28];
cx q[117],q[28];
u1(0) q[28];
u1(0) q[117];
cx q[117],q[29];
u1(0) q[29];
cx q[117],q[29];
u1(0) q[29];
u1(0) q[117];
cx q[117],q[30];
u1(0) q[30];
cx q[117],q[30];
u1(0) q[30];
u1(0) q[117];
cx q[117],q[31];
u1(0) q[31];
cx q[117],q[31];
u1(0) q[31];
u1(0) q[117];
cx q[117],q[32];
u1(0) q[32];
cx q[117],q[32];
u1(0) q[32];
u1(0) q[117];
cx q[117],q[33];
u1(0) q[33];
cx q[117],q[33];
u1(0) q[33];
u1(0) q[117];
cx q[117],q[34];
u1(0) q[34];
cx q[117],q[34];
u1(0) q[34];
u1(0) q[117];
cx q[117],q[35];
u1(0) q[35];
cx q[117],q[35];
u1(0) q[35];
u1(0) q[117];
cx q[117],q[36];
u1(0) q[36];
cx q[117],q[36];
u1(0) q[36];
u1(0) q[117];
cx q[117],q[37];
u1(0) q[37];
cx q[117],q[37];
u1(0) q[37];
u1(0) q[117];
cx q[117],q[38];
u1(0) q[38];
cx q[117],q[38];
u1(0) q[38];
u1(0) q[117];
cx q[117],q[39];
u1(0) q[39];
cx q[117],q[39];
u1(0) q[39];
u1(0) q[117];
cx q[117],q[40];
u1(0) q[40];
cx q[117],q[40];
u1(0) q[40];
u1(0) q[117];
cx q[117],q[41];
u1(0) q[41];
cx q[117],q[41];
u1(0) q[41];
u1(0) q[117];
cx q[117],q[42];
u1(0) q[42];
cx q[117],q[42];
u1(0) q[42];
u1(0) q[117];
cx q[117],q[43];
u1(0) q[43];
cx q[117],q[43];
u1(0) q[43];
u1(0) q[117];
cx q[117],q[44];
u1(0) q[44];
cx q[117],q[44];
u1(0) q[44];
u1(0) q[117];
cx q[117],q[45];
u1(0) q[45];
cx q[117],q[45];
u1(0) q[45];
u1(0) q[117];
cx q[117],q[46];
u1(0) q[46];
cx q[117],q[46];
u1(0) q[46];
u1(0) q[117];
cx q[117],q[47];
u1(0) q[47];
cx q[117],q[47];
u1(0) q[47];
u1(0) q[117];
cx q[117],q[48];
u1(0) q[48];
cx q[117],q[48];
u1(0) q[48];
u1(0) q[117];
cx q[117],q[49];
u1(0) q[49];
cx q[117],q[49];
u1(0) q[49];
u1(0) q[117];
cx q[117],q[50];
u1(0) q[50];
cx q[117],q[50];
u1(0) q[50];
u1(0) q[117];
cx q[117],q[51];
u1(0) q[51];
cx q[117],q[51];
u1(0) q[51];
u1(0) q[117];
cx q[117],q[52];
u1(0) q[52];
cx q[117],q[52];
u1(0) q[52];
u1(0) q[117];
cx q[117],q[53];
u1(0) q[53];
cx q[117],q[53];
u1(0) q[53];
u1(0) q[117];
cx q[117],q[54];
u1(0) q[54];
cx q[117],q[54];
u1(0) q[54];
u1(0) q[117];
cx q[117],q[55];
u1(0) q[55];
cx q[117],q[55];
u1(0) q[55];
u1(0) q[117];
cx q[117],q[56];
u1(0) q[56];
cx q[117],q[56];
u1(0) q[56];
u1(0) q[117];
cx q[117],q[57];
u1(0) q[57];
cx q[117],q[57];
u1(0) q[57];
u1(0) q[117];
cx q[117],q[58];
u1(0) q[58];
cx q[117],q[58];
u1(0) q[58];
u1(0) q[117];
cx q[117],q[59];
u1(0) q[59];
cx q[117],q[59];
u1(0) q[59];
u1(0) q[117];
cx q[117],q[60];
u1(0) q[60];
cx q[117],q[60];
u1(0) q[60];
u1(0) q[117];
cx q[117],q[61];
u1(0) q[61];
cx q[117],q[61];
u1(0) q[61];
u1(0) q[117];
cx q[117],q[62];
u1(0) q[62];
cx q[117],q[62];
u1(0) q[62];
u1(0) q[117];
cx q[117],q[63];
u1(0) q[63];
cx q[117],q[63];
u1(0) q[63];
u1(0) q[117];
cx q[117],q[64];
u1(0) q[64];
cx q[117],q[64];
u1(0) q[64];
u1(0) q[117];
cx q[117],q[65];
u1(0) q[65];
cx q[117],q[65];
u1(0) q[65];
u1(0) q[117];
cx q[117],q[66];
u1(0) q[66];
cx q[117],q[66];
u1(0) q[66];
u1(0) q[117];
cx q[117],q[67];
u1(0) q[67];
cx q[117],q[67];
u1(0) q[67];
u1(0) q[117];
cx q[117],q[68];
u1(0) q[68];
cx q[117],q[68];
u1(0) q[68];
u1(0) q[117];
cx q[117],q[69];
u1(0) q[69];
cx q[117],q[69];
u1(0) q[69];
u1(pi/281474976710656) q[117];
cx q[117],q[70];
u1(-pi/281474976710656) q[70];
cx q[117],q[70];
u1(pi/281474976710656) q[70];
u1(pi/140737488355328) q[117];
cx q[117],q[71];
u1(-pi/140737488355328) q[71];
cx q[117],q[71];
u1(pi/140737488355328) q[71];
u1(pi/70368744177664) q[117];
cx q[117],q[72];
u1(-pi/70368744177664) q[72];
cx q[117],q[72];
u1(pi/70368744177664) q[72];
u1(pi/35184372088832) q[117];
cx q[117],q[73];
u1(-pi/35184372088832) q[73];
cx q[117],q[73];
u1(pi/35184372088832) q[73];
u1(pi/17592186044416) q[117];
cx q[117],q[74];
u1(-pi/17592186044416) q[74];
cx q[117],q[74];
u1(pi/17592186044416) q[74];
u1(pi/8796093022208) q[117];
cx q[117],q[75];
u1(-pi/8796093022208) q[75];
cx q[117],q[75];
u1(pi/8796093022208) q[75];
u1(pi/4398046511104) q[117];
cx q[117],q[76];
u1(-pi/4398046511104) q[76];
cx q[117],q[76];
u1(pi/4398046511104) q[76];
u1(pi/2199023255552) q[117];
cx q[117],q[77];
u1(-pi/2199023255552) q[77];
cx q[117],q[77];
u1(pi/2199023255552) q[77];
u1(pi/1099511627776) q[117];
cx q[117],q[78];
u1(-pi/1099511627776) q[78];
cx q[117],q[78];
u1(pi/1099511627776) q[78];
u1(pi/549755813888) q[117];
cx q[117],q[79];
u1(-pi/549755813888) q[79];
cx q[117],q[79];
u1(pi/549755813888) q[79];
u1(pi/274877906944) q[117];
cx q[117],q[80];
u1(-pi/274877906944) q[80];
cx q[117],q[80];
u1(pi/274877906944) q[80];
u1(pi/137438953472) q[117];
cx q[117],q[81];
u1(-pi/137438953472) q[81];
cx q[117],q[81];
u1(pi/137438953472) q[81];
u1(pi/68719476736) q[117];
cx q[117],q[82];
u1(-pi/68719476736) q[82];
cx q[117],q[82];
u1(pi/68719476736) q[82];
u1(pi/34359738368) q[117];
cx q[117],q[83];
u1(-pi/34359738368) q[83];
cx q[117],q[83];
u1(pi/34359738368) q[83];
u1(pi/17179869184) q[117];
cx q[117],q[84];
u1(-pi/17179869184) q[84];
cx q[117],q[84];
u1(pi/17179869184) q[84];
u1(pi/8589934592) q[117];
cx q[117],q[85];
u1(-pi/8589934592) q[85];
cx q[117],q[85];
u1(pi/8589934592) q[85];
u1(pi/4294967296) q[117];
cx q[117],q[86];
u1(-pi/4294967296) q[86];
cx q[117],q[86];
u1(pi/4294967296) q[86];
u1(pi/2147483648) q[117];
cx q[117],q[87];
u1(-pi/2147483648) q[87];
cx q[117],q[87];
u1(pi/2147483648) q[87];
u1(pi/1073741824) q[117];
cx q[117],q[88];
u1(-pi/1073741824) q[88];
cx q[117],q[88];
u1(pi/1073741824) q[88];
u1(pi/536870912) q[117];
cx q[117],q[89];
u1(-pi/536870912) q[89];
cx q[117],q[89];
u1(pi/536870912) q[89];
u1(pi/268435456) q[117];
cx q[117],q[90];
u1(-pi/268435456) q[90];
cx q[117],q[90];
u1(pi/268435456) q[90];
u1(pi/134217728) q[117];
cx q[117],q[91];
u1(-pi/134217728) q[91];
cx q[117],q[91];
u1(pi/134217728) q[91];
u1(pi/67108864) q[117];
cx q[117],q[92];
u1(-pi/67108864) q[92];
cx q[117],q[92];
u1(pi/67108864) q[92];
u1(pi/33554432) q[117];
cx q[117],q[93];
u1(-pi/33554432) q[93];
cx q[117],q[93];
u1(pi/33554432) q[93];
u1(pi/16777216) q[117];
cx q[117],q[94];
u1(-pi/16777216) q[94];
cx q[117],q[94];
u1(pi/16777216) q[94];
u1(pi/8388608) q[117];
cx q[117],q[95];
u1(-pi/8388608) q[95];
cx q[117],q[95];
u1(pi/8388608) q[95];
u1(pi/4194304) q[117];
cx q[117],q[96];
u1(-pi/4194304) q[96];
cx q[117],q[96];
u1(pi/4194304) q[96];
u1(pi/2097152) q[117];
cx q[117],q[97];
u1(-pi/2097152) q[97];
cx q[117],q[97];
u1(pi/2097152) q[97];
u1(pi/1048576) q[117];
cx q[117],q[98];
u1(-pi/1048576) q[98];
cx q[117],q[98];
u1(pi/1048576) q[98];
u1(pi/524288) q[117];
cx q[117],q[99];
u1(-pi/524288) q[99];
cx q[117],q[99];
u1(pi/524288) q[99];
u1(pi/262144) q[117];
cx q[117],q[100];
u1(-pi/262144) q[100];
cx q[117],q[100];
u1(pi/262144) q[100];
u1(pi/131072) q[117];
cx q[117],q[101];
u1(-pi/131072) q[101];
cx q[117],q[101];
u1(pi/131072) q[101];
u1(pi/65536) q[117];
cx q[117],q[102];
u1(-pi/65536) q[102];
cx q[117],q[102];
u1(pi/65536) q[102];
u1(pi/32768) q[117];
cx q[117],q[103];
u1(-pi/32768) q[103];
cx q[117],q[103];
u1(pi/32768) q[103];
u1(pi/16384) q[117];
cx q[117],q[104];
u1(-pi/16384) q[104];
cx q[117],q[104];
u1(pi/16384) q[104];
u1(pi/8192) q[117];
cx q[117],q[105];
u1(-pi/8192) q[105];
cx q[117],q[105];
u1(pi/8192) q[105];
u1(pi/4096) q[117];
cx q[117],q[106];
u1(-pi/4096) q[106];
cx q[117],q[106];
u1(pi/4096) q[106];
u1(pi/2048) q[117];
cx q[117],q[107];
u1(-pi/2048) q[107];
cx q[117],q[107];
u1(pi/2048) q[107];
u1(pi/1024) q[117];
cx q[117],q[108];
u1(-pi/1024) q[108];
cx q[117],q[108];
u1(pi/1024) q[108];
u1(pi/512) q[117];
cx q[117],q[109];
u1(-pi/512) q[109];
cx q[117],q[109];
u1(pi/512) q[109];
u1(pi/256) q[117];
cx q[117],q[110];
u1(-pi/256) q[110];
cx q[117],q[110];
u1(pi/256) q[110];
u1(pi/128) q[117];
cx q[117],q[111];
u1(-pi/128) q[111];
cx q[117],q[111];
u1(pi/128) q[111];
u1(pi/64) q[117];
cx q[117],q[112];
u1(-pi/64) q[112];
cx q[117],q[112];
u1(pi/64) q[112];
u1(pi/32) q[117];
cx q[117],q[113];
u1(-pi/32) q[113];
cx q[117],q[113];
u1(pi/32) q[113];
u1(pi/16) q[117];
cx q[117],q[114];
u1(-pi/16) q[114];
cx q[117],q[114];
u1(pi/16) q[114];
u1(pi/8) q[117];
cx q[117],q[115];
u1(-pi/8) q[115];
cx q[117],q[115];
u1(pi/8) q[115];
u1(pi/4) q[117];
cx q[117],q[116];
u1(-pi/4) q[116];
cx q[117],q[116];
u1(pi/4) q[116];
h q[117];
u1(0) q[118];
cx q[118],q[0];
u1(0) q[0];
cx q[118],q[0];
u1(0) q[0];
u1(0) q[118];
cx q[118],q[1];
u1(0) q[1];
cx q[118],q[1];
u1(0) q[1];
u1(0) q[118];
cx q[118],q[2];
u1(0) q[2];
cx q[118],q[2];
u1(0) q[2];
u1(0) q[118];
cx q[118],q[3];
u1(0) q[3];
cx q[118],q[3];
u1(0) q[3];
u1(0) q[118];
cx q[118],q[4];
u1(0) q[4];
cx q[118],q[4];
u1(0) q[4];
u1(0) q[118];
cx q[118],q[5];
u1(0) q[5];
cx q[118],q[5];
u1(0) q[5];
u1(0) q[118];
cx q[118],q[6];
u1(0) q[6];
cx q[118],q[6];
u1(0) q[6];
u1(0) q[118];
cx q[118],q[7];
u1(0) q[7];
cx q[118],q[7];
u1(0) q[7];
u1(0) q[118];
cx q[118],q[8];
u1(0) q[8];
cx q[118],q[8];
u1(0) q[8];
u1(0) q[118];
cx q[118],q[9];
u1(0) q[9];
cx q[118],q[9];
u1(0) q[9];
u1(0) q[118];
cx q[118],q[10];
u1(0) q[10];
cx q[118],q[10];
u1(0) q[10];
u1(0) q[118];
cx q[118],q[11];
u1(0) q[11];
cx q[118],q[11];
u1(0) q[11];
u1(0) q[118];
cx q[118],q[12];
u1(0) q[12];
cx q[118],q[12];
u1(0) q[12];
u1(0) q[118];
cx q[118],q[13];
u1(0) q[13];
cx q[118],q[13];
u1(0) q[13];
u1(0) q[118];
cx q[118],q[14];
u1(0) q[14];
cx q[118],q[14];
u1(0) q[14];
u1(0) q[118];
cx q[118],q[15];
u1(0) q[15];
cx q[118],q[15];
u1(0) q[15];
u1(0) q[118];
cx q[118],q[16];
u1(0) q[16];
cx q[118],q[16];
u1(0) q[16];
u1(0) q[118];
cx q[118],q[17];
u1(0) q[17];
cx q[118],q[17];
u1(0) q[17];
u1(0) q[118];
cx q[118],q[18];
u1(0) q[18];
cx q[118],q[18];
u1(0) q[18];
u1(0) q[118];
cx q[118],q[19];
u1(0) q[19];
cx q[118],q[19];
u1(0) q[19];
u1(0) q[118];
cx q[118],q[20];
u1(0) q[20];
cx q[118],q[20];
u1(0) q[20];
u1(0) q[118];
cx q[118],q[21];
u1(0) q[21];
cx q[118],q[21];
u1(0) q[21];
u1(0) q[118];
cx q[118],q[22];
u1(0) q[22];
cx q[118],q[22];
u1(0) q[22];
u1(0) q[118];
cx q[118],q[23];
u1(0) q[23];
cx q[118],q[23];
u1(0) q[23];
u1(0) q[118];
cx q[118],q[24];
u1(0) q[24];
cx q[118],q[24];
u1(0) q[24];
u1(0) q[118];
cx q[118],q[25];
u1(0) q[25];
cx q[118],q[25];
u1(0) q[25];
u1(0) q[118];
cx q[118],q[26];
u1(0) q[26];
cx q[118],q[26];
u1(0) q[26];
u1(0) q[118];
cx q[118],q[27];
u1(0) q[27];
cx q[118],q[27];
u1(0) q[27];
u1(0) q[118];
cx q[118],q[28];
u1(0) q[28];
cx q[118],q[28];
u1(0) q[28];
u1(0) q[118];
cx q[118],q[29];
u1(0) q[29];
cx q[118],q[29];
u1(0) q[29];
u1(0) q[118];
cx q[118],q[30];
u1(0) q[30];
cx q[118],q[30];
u1(0) q[30];
u1(0) q[118];
cx q[118],q[31];
u1(0) q[31];
cx q[118],q[31];
u1(0) q[31];
u1(0) q[118];
cx q[118],q[32];
u1(0) q[32];
cx q[118],q[32];
u1(0) q[32];
u1(0) q[118];
cx q[118],q[33];
u1(0) q[33];
cx q[118],q[33];
u1(0) q[33];
u1(0) q[118];
cx q[118],q[34];
u1(0) q[34];
cx q[118],q[34];
u1(0) q[34];
u1(0) q[118];
cx q[118],q[35];
u1(0) q[35];
cx q[118],q[35];
u1(0) q[35];
u1(0) q[118];
cx q[118],q[36];
u1(0) q[36];
cx q[118],q[36];
u1(0) q[36];
u1(0) q[118];
cx q[118],q[37];
u1(0) q[37];
cx q[118],q[37];
u1(0) q[37];
u1(0) q[118];
cx q[118],q[38];
u1(0) q[38];
cx q[118],q[38];
u1(0) q[38];
u1(0) q[118];
cx q[118],q[39];
u1(0) q[39];
cx q[118],q[39];
u1(0) q[39];
u1(0) q[118];
cx q[118],q[40];
u1(0) q[40];
cx q[118],q[40];
u1(0) q[40];
u1(0) q[118];
cx q[118],q[41];
u1(0) q[41];
cx q[118],q[41];
u1(0) q[41];
u1(0) q[118];
cx q[118],q[42];
u1(0) q[42];
cx q[118],q[42];
u1(0) q[42];
u1(0) q[118];
cx q[118],q[43];
u1(0) q[43];
cx q[118],q[43];
u1(0) q[43];
u1(0) q[118];
cx q[118],q[44];
u1(0) q[44];
cx q[118],q[44];
u1(0) q[44];
u1(0) q[118];
cx q[118],q[45];
u1(0) q[45];
cx q[118],q[45];
u1(0) q[45];
u1(0) q[118];
cx q[118],q[46];
u1(0) q[46];
cx q[118],q[46];
u1(0) q[46];
u1(0) q[118];
cx q[118],q[47];
u1(0) q[47];
cx q[118],q[47];
u1(0) q[47];
u1(0) q[118];
cx q[118],q[48];
u1(0) q[48];
cx q[118],q[48];
u1(0) q[48];
u1(0) q[118];
cx q[118],q[49];
u1(0) q[49];
cx q[118],q[49];
u1(0) q[49];
u1(0) q[118];
cx q[118],q[50];
u1(0) q[50];
cx q[118],q[50];
u1(0) q[50];
u1(0) q[118];
cx q[118],q[51];
u1(0) q[51];
cx q[118],q[51];
u1(0) q[51];
u1(0) q[118];
cx q[118],q[52];
u1(0) q[52];
cx q[118],q[52];
u1(0) q[52];
u1(0) q[118];
cx q[118],q[53];
u1(0) q[53];
cx q[118],q[53];
u1(0) q[53];
u1(0) q[118];
cx q[118],q[54];
u1(0) q[54];
cx q[118],q[54];
u1(0) q[54];
u1(0) q[118];
cx q[118],q[55];
u1(0) q[55];
cx q[118],q[55];
u1(0) q[55];
u1(0) q[118];
cx q[118],q[56];
u1(0) q[56];
cx q[118],q[56];
u1(0) q[56];
u1(0) q[118];
cx q[118],q[57];
u1(0) q[57];
cx q[118],q[57];
u1(0) q[57];
u1(0) q[118];
cx q[118],q[58];
u1(0) q[58];
cx q[118],q[58];
u1(0) q[58];
u1(0) q[118];
cx q[118],q[59];
u1(0) q[59];
cx q[118],q[59];
u1(0) q[59];
u1(0) q[118];
cx q[118],q[60];
u1(0) q[60];
cx q[118],q[60];
u1(0) q[60];
u1(0) q[118];
cx q[118],q[61];
u1(0) q[61];
cx q[118],q[61];
u1(0) q[61];
u1(0) q[118];
cx q[118],q[62];
u1(0) q[62];
cx q[118],q[62];
u1(0) q[62];
u1(0) q[118];
cx q[118],q[63];
u1(0) q[63];
cx q[118],q[63];
u1(0) q[63];
u1(0) q[118];
cx q[118],q[64];
u1(0) q[64];
cx q[118],q[64];
u1(0) q[64];
u1(0) q[118];
cx q[118],q[65];
u1(0) q[65];
cx q[118],q[65];
u1(0) q[65];
u1(0) q[118];
cx q[118],q[66];
u1(0) q[66];
cx q[118],q[66];
u1(0) q[66];
u1(0) q[118];
cx q[118],q[67];
u1(0) q[67];
cx q[118],q[67];
u1(0) q[67];
u1(0) q[118];
cx q[118],q[68];
u1(0) q[68];
cx q[118],q[68];
u1(0) q[68];
u1(0) q[118];
cx q[118],q[69];
u1(0) q[69];
cx q[118],q[69];
u1(0) q[69];
u1(0) q[118];
cx q[118],q[70];
u1(0) q[70];
cx q[118],q[70];
u1(0) q[70];
u1(pi/281474976710656) q[118];
cx q[118],q[71];
u1(-pi/281474976710656) q[71];
cx q[118],q[71];
u1(pi/281474976710656) q[71];
u1(pi/140737488355328) q[118];
cx q[118],q[72];
u1(-pi/140737488355328) q[72];
cx q[118],q[72];
u1(pi/140737488355328) q[72];
u1(pi/70368744177664) q[118];
cx q[118],q[73];
u1(-pi/70368744177664) q[73];
cx q[118],q[73];
u1(pi/70368744177664) q[73];
u1(pi/35184372088832) q[118];
cx q[118],q[74];
u1(-pi/35184372088832) q[74];
cx q[118],q[74];
u1(pi/35184372088832) q[74];
u1(pi/17592186044416) q[118];
cx q[118],q[75];
u1(-pi/17592186044416) q[75];
cx q[118],q[75];
u1(pi/17592186044416) q[75];
u1(pi/8796093022208) q[118];
cx q[118],q[76];
u1(-pi/8796093022208) q[76];
cx q[118],q[76];
u1(pi/8796093022208) q[76];
u1(pi/4398046511104) q[118];
cx q[118],q[77];
u1(-pi/4398046511104) q[77];
cx q[118],q[77];
u1(pi/4398046511104) q[77];
u1(pi/2199023255552) q[118];
cx q[118],q[78];
u1(-pi/2199023255552) q[78];
cx q[118],q[78];
u1(pi/2199023255552) q[78];
u1(pi/1099511627776) q[118];
cx q[118],q[79];
u1(-pi/1099511627776) q[79];
cx q[118],q[79];
u1(pi/1099511627776) q[79];
u1(pi/549755813888) q[118];
cx q[118],q[80];
u1(-pi/549755813888) q[80];
cx q[118],q[80];
u1(pi/549755813888) q[80];
u1(pi/274877906944) q[118];
cx q[118],q[81];
u1(-pi/274877906944) q[81];
cx q[118],q[81];
u1(pi/274877906944) q[81];
u1(pi/137438953472) q[118];
cx q[118],q[82];
u1(-pi/137438953472) q[82];
cx q[118],q[82];
u1(pi/137438953472) q[82];
u1(pi/68719476736) q[118];
cx q[118],q[83];
u1(-pi/68719476736) q[83];
cx q[118],q[83];
u1(pi/68719476736) q[83];
u1(pi/34359738368) q[118];
cx q[118],q[84];
u1(-pi/34359738368) q[84];
cx q[118],q[84];
u1(pi/34359738368) q[84];
u1(pi/17179869184) q[118];
cx q[118],q[85];
u1(-pi/17179869184) q[85];
cx q[118],q[85];
u1(pi/17179869184) q[85];
u1(pi/8589934592) q[118];
cx q[118],q[86];
u1(-pi/8589934592) q[86];
cx q[118],q[86];
u1(pi/8589934592) q[86];
u1(pi/4294967296) q[118];
cx q[118],q[87];
u1(-pi/4294967296) q[87];
cx q[118],q[87];
u1(pi/4294967296) q[87];
u1(pi/2147483648) q[118];
cx q[118],q[88];
u1(-pi/2147483648) q[88];
cx q[118],q[88];
u1(pi/2147483648) q[88];
u1(pi/1073741824) q[118];
cx q[118],q[89];
u1(-pi/1073741824) q[89];
cx q[118],q[89];
u1(pi/1073741824) q[89];
u1(pi/536870912) q[118];
cx q[118],q[90];
u1(-pi/536870912) q[90];
cx q[118],q[90];
u1(pi/536870912) q[90];
u1(pi/268435456) q[118];
cx q[118],q[91];
u1(-pi/268435456) q[91];
cx q[118],q[91];
u1(pi/268435456) q[91];
u1(pi/134217728) q[118];
cx q[118],q[92];
u1(-pi/134217728) q[92];
cx q[118],q[92];
u1(pi/134217728) q[92];
u1(pi/67108864) q[118];
cx q[118],q[93];
u1(-pi/67108864) q[93];
cx q[118],q[93];
u1(pi/67108864) q[93];
u1(pi/33554432) q[118];
cx q[118],q[94];
u1(-pi/33554432) q[94];
cx q[118],q[94];
u1(pi/33554432) q[94];
u1(pi/16777216) q[118];
cx q[118],q[95];
u1(-pi/16777216) q[95];
cx q[118],q[95];
u1(pi/16777216) q[95];
u1(pi/8388608) q[118];
cx q[118],q[96];
u1(-pi/8388608) q[96];
cx q[118],q[96];
u1(pi/8388608) q[96];
u1(pi/4194304) q[118];
cx q[118],q[97];
u1(-pi/4194304) q[97];
cx q[118],q[97];
u1(pi/4194304) q[97];
u1(pi/2097152) q[118];
cx q[118],q[98];
u1(-pi/2097152) q[98];
cx q[118],q[98];
u1(pi/2097152) q[98];
u1(pi/1048576) q[118];
cx q[118],q[99];
u1(-pi/1048576) q[99];
cx q[118],q[99];
u1(pi/1048576) q[99];
u1(pi/524288) q[118];
cx q[118],q[100];
u1(-pi/524288) q[100];
cx q[118],q[100];
u1(pi/524288) q[100];
u1(pi/262144) q[118];
cx q[118],q[101];
u1(-pi/262144) q[101];
cx q[118],q[101];
u1(pi/262144) q[101];
u1(pi/131072) q[118];
cx q[118],q[102];
u1(-pi/131072) q[102];
cx q[118],q[102];
u1(pi/131072) q[102];
u1(pi/65536) q[118];
cx q[118],q[103];
u1(-pi/65536) q[103];
cx q[118],q[103];
u1(pi/65536) q[103];
u1(pi/32768) q[118];
cx q[118],q[104];
u1(-pi/32768) q[104];
cx q[118],q[104];
u1(pi/32768) q[104];
u1(pi/16384) q[118];
cx q[118],q[105];
u1(-pi/16384) q[105];
cx q[118],q[105];
u1(pi/16384) q[105];
u1(pi/8192) q[118];
cx q[118],q[106];
u1(-pi/8192) q[106];
cx q[118],q[106];
u1(pi/8192) q[106];
u1(pi/4096) q[118];
cx q[118],q[107];
u1(-pi/4096) q[107];
cx q[118],q[107];
u1(pi/4096) q[107];
u1(pi/2048) q[118];
cx q[118],q[108];
u1(-pi/2048) q[108];
cx q[118],q[108];
u1(pi/2048) q[108];
u1(pi/1024) q[118];
cx q[118],q[109];
u1(-pi/1024) q[109];
cx q[118],q[109];
u1(pi/1024) q[109];
u1(pi/512) q[118];
cx q[118],q[110];
u1(-pi/512) q[110];
cx q[118],q[110];
u1(pi/512) q[110];
u1(pi/256) q[118];
cx q[118],q[111];
u1(-pi/256) q[111];
cx q[118],q[111];
u1(pi/256) q[111];
u1(pi/128) q[118];
cx q[118],q[112];
u1(-pi/128) q[112];
cx q[118],q[112];
u1(pi/128) q[112];
u1(pi/64) q[118];
cx q[118],q[113];
u1(-pi/64) q[113];
cx q[118],q[113];
u1(pi/64) q[113];
u1(pi/32) q[118];
cx q[118],q[114];
u1(-pi/32) q[114];
cx q[118],q[114];
u1(pi/32) q[114];
u1(pi/16) q[118];
cx q[118],q[115];
u1(-pi/16) q[115];
cx q[118],q[115];
u1(pi/16) q[115];
u1(pi/8) q[118];
cx q[118],q[116];
u1(-pi/8) q[116];
cx q[118],q[116];
u1(pi/8) q[116];
u1(pi/4) q[118];
cx q[118],q[117];
u1(-pi/4) q[117];
cx q[118],q[117];
u1(pi/4) q[117];
h q[118];
u1(0) q[119];
cx q[119],q[0];
u1(0) q[0];
cx q[119],q[0];
u1(0) q[0];
u1(0) q[119];
cx q[119],q[1];
u1(0) q[1];
cx q[119],q[1];
u1(0) q[1];
u1(0) q[119];
cx q[119],q[2];
u1(0) q[2];
cx q[119],q[2];
u1(0) q[2];
u1(0) q[119];
cx q[119],q[3];
u1(0) q[3];
cx q[119],q[3];
u1(0) q[3];
u1(0) q[119];
cx q[119],q[4];
u1(0) q[4];
cx q[119],q[4];
u1(0) q[4];
u1(0) q[119];
cx q[119],q[5];
u1(0) q[5];
cx q[119],q[5];
u1(0) q[5];
u1(0) q[119];
cx q[119],q[6];
u1(0) q[6];
cx q[119],q[6];
u1(0) q[6];
u1(0) q[119];
cx q[119],q[7];
u1(0) q[7];
cx q[119],q[7];
u1(0) q[7];
u1(0) q[119];
cx q[119],q[8];
u1(0) q[8];
cx q[119],q[8];
u1(0) q[8];
u1(0) q[119];
cx q[119],q[9];
u1(0) q[9];
cx q[119],q[9];
u1(0) q[9];
u1(0) q[119];
cx q[119],q[10];
u1(0) q[10];
cx q[119],q[10];
u1(0) q[10];
u1(0) q[119];
cx q[119],q[11];
u1(0) q[11];
cx q[119],q[11];
u1(0) q[11];
u1(0) q[119];
cx q[119],q[12];
u1(0) q[12];
cx q[119],q[12];
u1(0) q[12];
u1(0) q[119];
cx q[119],q[13];
u1(0) q[13];
cx q[119],q[13];
u1(0) q[13];
u1(0) q[119];
cx q[119],q[14];
u1(0) q[14];
cx q[119],q[14];
u1(0) q[14];
u1(0) q[119];
cx q[119],q[15];
u1(0) q[15];
cx q[119],q[15];
u1(0) q[15];
u1(0) q[119];
cx q[119],q[16];
u1(0) q[16];
cx q[119],q[16];
u1(0) q[16];
u1(0) q[119];
cx q[119],q[17];
u1(0) q[17];
cx q[119],q[17];
u1(0) q[17];
u1(0) q[119];
cx q[119],q[18];
u1(0) q[18];
cx q[119],q[18];
u1(0) q[18];
u1(0) q[119];
cx q[119],q[19];
u1(0) q[19];
cx q[119],q[19];
u1(0) q[19];
u1(0) q[119];
cx q[119],q[20];
u1(0) q[20];
cx q[119],q[20];
u1(0) q[20];
u1(0) q[119];
cx q[119],q[21];
u1(0) q[21];
cx q[119],q[21];
u1(0) q[21];
u1(0) q[119];
cx q[119],q[22];
u1(0) q[22];
cx q[119],q[22];
u1(0) q[22];
u1(0) q[119];
cx q[119],q[23];
u1(0) q[23];
cx q[119],q[23];
u1(0) q[23];
u1(0) q[119];
cx q[119],q[24];
u1(0) q[24];
cx q[119],q[24];
u1(0) q[24];
u1(0) q[119];
cx q[119],q[25];
u1(0) q[25];
cx q[119],q[25];
u1(0) q[25];
u1(0) q[119];
cx q[119],q[26];
u1(0) q[26];
cx q[119],q[26];
u1(0) q[26];
u1(0) q[119];
cx q[119],q[27];
u1(0) q[27];
cx q[119],q[27];
u1(0) q[27];
u1(0) q[119];
cx q[119],q[28];
u1(0) q[28];
cx q[119],q[28];
u1(0) q[28];
u1(0) q[119];
cx q[119],q[29];
u1(0) q[29];
cx q[119],q[29];
u1(0) q[29];
u1(0) q[119];
cx q[119],q[30];
u1(0) q[30];
cx q[119],q[30];
u1(0) q[30];
u1(0) q[119];
cx q[119],q[31];
u1(0) q[31];
cx q[119],q[31];
u1(0) q[31];
u1(0) q[119];
cx q[119],q[32];
u1(0) q[32];
cx q[119],q[32];
u1(0) q[32];
u1(0) q[119];
cx q[119],q[33];
u1(0) q[33];
cx q[119],q[33];
u1(0) q[33];
u1(0) q[119];
cx q[119],q[34];
u1(0) q[34];
cx q[119],q[34];
u1(0) q[34];
u1(0) q[119];
cx q[119],q[35];
u1(0) q[35];
cx q[119],q[35];
u1(0) q[35];
u1(0) q[119];
cx q[119],q[36];
u1(0) q[36];
cx q[119],q[36];
u1(0) q[36];
u1(0) q[119];
cx q[119],q[37];
u1(0) q[37];
cx q[119],q[37];
u1(0) q[37];
u1(0) q[119];
cx q[119],q[38];
u1(0) q[38];
cx q[119],q[38];
u1(0) q[38];
u1(0) q[119];
cx q[119],q[39];
u1(0) q[39];
cx q[119],q[39];
u1(0) q[39];
u1(0) q[119];
cx q[119],q[40];
u1(0) q[40];
cx q[119],q[40];
u1(0) q[40];
u1(0) q[119];
cx q[119],q[41];
u1(0) q[41];
cx q[119],q[41];
u1(0) q[41];
u1(0) q[119];
cx q[119],q[42];
u1(0) q[42];
cx q[119],q[42];
u1(0) q[42];
u1(0) q[119];
cx q[119],q[43];
u1(0) q[43];
cx q[119],q[43];
u1(0) q[43];
u1(0) q[119];
cx q[119],q[44];
u1(0) q[44];
cx q[119],q[44];
u1(0) q[44];
u1(0) q[119];
cx q[119],q[45];
u1(0) q[45];
cx q[119],q[45];
u1(0) q[45];
u1(0) q[119];
cx q[119],q[46];
u1(0) q[46];
cx q[119],q[46];
u1(0) q[46];
u1(0) q[119];
cx q[119],q[47];
u1(0) q[47];
cx q[119],q[47];
u1(0) q[47];
u1(0) q[119];
cx q[119],q[48];
u1(0) q[48];
cx q[119],q[48];
u1(0) q[48];
u1(0) q[119];
cx q[119],q[49];
u1(0) q[49];
cx q[119],q[49];
u1(0) q[49];
u1(0) q[119];
cx q[119],q[50];
u1(0) q[50];
cx q[119],q[50];
u1(0) q[50];
u1(0) q[119];
cx q[119],q[51];
u1(0) q[51];
cx q[119],q[51];
u1(0) q[51];
u1(0) q[119];
cx q[119],q[52];
u1(0) q[52];
cx q[119],q[52];
u1(0) q[52];
u1(0) q[119];
cx q[119],q[53];
u1(0) q[53];
cx q[119],q[53];
u1(0) q[53];
u1(0) q[119];
cx q[119],q[54];
u1(0) q[54];
cx q[119],q[54];
u1(0) q[54];
u1(0) q[119];
cx q[119],q[55];
u1(0) q[55];
cx q[119],q[55];
u1(0) q[55];
u1(0) q[119];
cx q[119],q[56];
u1(0) q[56];
cx q[119],q[56];
u1(0) q[56];
u1(0) q[119];
cx q[119],q[57];
u1(0) q[57];
cx q[119],q[57];
u1(0) q[57];
u1(0) q[119];
cx q[119],q[58];
u1(0) q[58];
cx q[119],q[58];
u1(0) q[58];
u1(0) q[119];
cx q[119],q[59];
u1(0) q[59];
cx q[119],q[59];
u1(0) q[59];
u1(0) q[119];
cx q[119],q[60];
u1(0) q[60];
cx q[119],q[60];
u1(0) q[60];
u1(0) q[119];
cx q[119],q[61];
u1(0) q[61];
cx q[119],q[61];
u1(0) q[61];
u1(0) q[119];
cx q[119],q[62];
u1(0) q[62];
cx q[119],q[62];
u1(0) q[62];
u1(0) q[119];
cx q[119],q[63];
u1(0) q[63];
cx q[119],q[63];
u1(0) q[63];
u1(0) q[119];
cx q[119],q[64];
u1(0) q[64];
cx q[119],q[64];
u1(0) q[64];
u1(0) q[119];
cx q[119],q[65];
u1(0) q[65];
cx q[119],q[65];
u1(0) q[65];
u1(0) q[119];
cx q[119],q[66];
u1(0) q[66];
cx q[119],q[66];
u1(0) q[66];
u1(0) q[119];
cx q[119],q[67];
u1(0) q[67];
cx q[119],q[67];
u1(0) q[67];
u1(0) q[119];
cx q[119],q[68];
u1(0) q[68];
cx q[119],q[68];
u1(0) q[68];
u1(0) q[119];
cx q[119],q[69];
u1(0) q[69];
cx q[119],q[69];
u1(0) q[69];
u1(0) q[119];
cx q[119],q[70];
u1(0) q[70];
cx q[119],q[70];
u1(0) q[70];
u1(0) q[119];
cx q[119],q[71];
u1(0) q[71];
cx q[119],q[71];
u1(0) q[71];
u1(pi/281474976710656) q[119];
cx q[119],q[72];
u1(-pi/281474976710656) q[72];
cx q[119],q[72];
u1(pi/281474976710656) q[72];
u1(pi/140737488355328) q[119];
cx q[119],q[73];
u1(-pi/140737488355328) q[73];
cx q[119],q[73];
u1(pi/140737488355328) q[73];
u1(pi/70368744177664) q[119];
cx q[119],q[74];
u1(-pi/70368744177664) q[74];
cx q[119],q[74];
u1(pi/70368744177664) q[74];
u1(pi/35184372088832) q[119];
cx q[119],q[75];
u1(-pi/35184372088832) q[75];
cx q[119],q[75];
u1(pi/35184372088832) q[75];
u1(pi/17592186044416) q[119];
cx q[119],q[76];
u1(-pi/17592186044416) q[76];
cx q[119],q[76];
u1(pi/17592186044416) q[76];
u1(pi/8796093022208) q[119];
cx q[119],q[77];
u1(-pi/8796093022208) q[77];
cx q[119],q[77];
u1(pi/8796093022208) q[77];
u1(pi/4398046511104) q[119];
cx q[119],q[78];
u1(-pi/4398046511104) q[78];
cx q[119],q[78];
u1(pi/4398046511104) q[78];
u1(pi/2199023255552) q[119];
cx q[119],q[79];
u1(-pi/2199023255552) q[79];
cx q[119],q[79];
u1(pi/2199023255552) q[79];
u1(pi/1099511627776) q[119];
cx q[119],q[80];
u1(-pi/1099511627776) q[80];
cx q[119],q[80];
u1(pi/1099511627776) q[80];
u1(pi/549755813888) q[119];
cx q[119],q[81];
u1(-pi/549755813888) q[81];
cx q[119],q[81];
u1(pi/549755813888) q[81];
u1(pi/274877906944) q[119];
cx q[119],q[82];
u1(-pi/274877906944) q[82];
cx q[119],q[82];
u1(pi/274877906944) q[82];
u1(pi/137438953472) q[119];
cx q[119],q[83];
u1(-pi/137438953472) q[83];
cx q[119],q[83];
u1(pi/137438953472) q[83];
u1(pi/68719476736) q[119];
cx q[119],q[84];
u1(-pi/68719476736) q[84];
cx q[119],q[84];
u1(pi/68719476736) q[84];
u1(pi/34359738368) q[119];
cx q[119],q[85];
u1(-pi/34359738368) q[85];
cx q[119],q[85];
u1(pi/34359738368) q[85];
u1(pi/17179869184) q[119];
cx q[119],q[86];
u1(-pi/17179869184) q[86];
cx q[119],q[86];
u1(pi/17179869184) q[86];
u1(pi/8589934592) q[119];
cx q[119],q[87];
u1(-pi/8589934592) q[87];
cx q[119],q[87];
u1(pi/8589934592) q[87];
u1(pi/4294967296) q[119];
cx q[119],q[88];
u1(-pi/4294967296) q[88];
cx q[119],q[88];
u1(pi/4294967296) q[88];
u1(pi/2147483648) q[119];
cx q[119],q[89];
u1(-pi/2147483648) q[89];
cx q[119],q[89];
u1(pi/2147483648) q[89];
u1(pi/1073741824) q[119];
cx q[119],q[90];
u1(-pi/1073741824) q[90];
cx q[119],q[90];
u1(pi/1073741824) q[90];
u1(pi/536870912) q[119];
cx q[119],q[91];
u1(-pi/536870912) q[91];
cx q[119],q[91];
u1(pi/536870912) q[91];
u1(pi/268435456) q[119];
cx q[119],q[92];
u1(-pi/268435456) q[92];
cx q[119],q[92];
u1(pi/268435456) q[92];
u1(pi/134217728) q[119];
cx q[119],q[93];
u1(-pi/134217728) q[93];
cx q[119],q[93];
u1(pi/134217728) q[93];
u1(pi/67108864) q[119];
cx q[119],q[94];
u1(-pi/67108864) q[94];
cx q[119],q[94];
u1(pi/67108864) q[94];
u1(pi/33554432) q[119];
cx q[119],q[95];
u1(-pi/33554432) q[95];
cx q[119],q[95];
u1(pi/33554432) q[95];
u1(pi/16777216) q[119];
cx q[119],q[96];
u1(-pi/16777216) q[96];
cx q[119],q[96];
u1(pi/16777216) q[96];
u1(pi/8388608) q[119];
cx q[119],q[97];
u1(-pi/8388608) q[97];
cx q[119],q[97];
u1(pi/8388608) q[97];
u1(pi/4194304) q[119];
cx q[119],q[98];
u1(-pi/4194304) q[98];
cx q[119],q[98];
u1(pi/4194304) q[98];
u1(pi/2097152) q[119];
cx q[119],q[99];
u1(-pi/2097152) q[99];
cx q[119],q[99];
u1(pi/2097152) q[99];
u1(pi/1048576) q[119];
cx q[119],q[100];
u1(-pi/1048576) q[100];
cx q[119],q[100];
u1(pi/1048576) q[100];
u1(pi/524288) q[119];
cx q[119],q[101];
u1(-pi/524288) q[101];
cx q[119],q[101];
u1(pi/524288) q[101];
u1(pi/262144) q[119];
cx q[119],q[102];
u1(-pi/262144) q[102];
cx q[119],q[102];
u1(pi/262144) q[102];
u1(pi/131072) q[119];
cx q[119],q[103];
u1(-pi/131072) q[103];
cx q[119],q[103];
u1(pi/131072) q[103];
u1(pi/65536) q[119];
cx q[119],q[104];
u1(-pi/65536) q[104];
cx q[119],q[104];
u1(pi/65536) q[104];
u1(pi/32768) q[119];
cx q[119],q[105];
u1(-pi/32768) q[105];
cx q[119],q[105];
u1(pi/32768) q[105];
u1(pi/16384) q[119];
cx q[119],q[106];
u1(-pi/16384) q[106];
cx q[119],q[106];
u1(pi/16384) q[106];
u1(pi/8192) q[119];
cx q[119],q[107];
u1(-pi/8192) q[107];
cx q[119],q[107];
u1(pi/8192) q[107];
u1(pi/4096) q[119];
cx q[119],q[108];
u1(-pi/4096) q[108];
cx q[119],q[108];
u1(pi/4096) q[108];
u1(pi/2048) q[119];
cx q[119],q[109];
u1(-pi/2048) q[109];
cx q[119],q[109];
u1(pi/2048) q[109];
u1(pi/1024) q[119];
cx q[119],q[110];
u1(-pi/1024) q[110];
cx q[119],q[110];
u1(pi/1024) q[110];
u1(pi/512) q[119];
cx q[119],q[111];
u1(-pi/512) q[111];
cx q[119],q[111];
u1(pi/512) q[111];
u1(pi/256) q[119];
cx q[119],q[112];
u1(-pi/256) q[112];
cx q[119],q[112];
u1(pi/256) q[112];
u1(pi/128) q[119];
cx q[119],q[113];
u1(-pi/128) q[113];
cx q[119],q[113];
u1(pi/128) q[113];
u1(pi/64) q[119];
cx q[119],q[114];
u1(-pi/64) q[114];
cx q[119],q[114];
u1(pi/64) q[114];
u1(pi/32) q[119];
cx q[119],q[115];
u1(-pi/32) q[115];
cx q[119],q[115];
u1(pi/32) q[115];
u1(pi/16) q[119];
cx q[119],q[116];
u1(-pi/16) q[116];
cx q[119],q[116];
u1(pi/16) q[116];
u1(pi/8) q[119];
cx q[119],q[117];
u1(-pi/8) q[117];
cx q[119],q[117];
u1(pi/8) q[117];
u1(pi/4) q[119];
cx q[119],q[118];
u1(-pi/4) q[118];
cx q[119],q[118];
u1(pi/4) q[118];
h q[119];
u1(0) q[120];
cx q[120],q[0];
u1(0) q[0];
cx q[120],q[0];
u1(0) q[0];
u1(0) q[120];
cx q[120],q[1];
u1(0) q[1];
cx q[120],q[1];
u1(0) q[1];
u1(0) q[120];
cx q[120],q[2];
u1(0) q[2];
cx q[120],q[2];
u1(0) q[2];
u1(0) q[120];
cx q[120],q[3];
u1(0) q[3];
cx q[120],q[3];
u1(0) q[3];
u1(0) q[120];
cx q[120],q[4];
u1(0) q[4];
cx q[120],q[4];
u1(0) q[4];
u1(0) q[120];
cx q[120],q[5];
u1(0) q[5];
cx q[120],q[5];
u1(0) q[5];
u1(0) q[120];
cx q[120],q[6];
u1(0) q[6];
cx q[120],q[6];
u1(0) q[6];
u1(0) q[120];
cx q[120],q[7];
u1(0) q[7];
cx q[120],q[7];
u1(0) q[7];
u1(0) q[120];
cx q[120],q[8];
u1(0) q[8];
cx q[120],q[8];
u1(0) q[8];
u1(0) q[120];
cx q[120],q[9];
u1(0) q[9];
cx q[120],q[9];
u1(0) q[9];
u1(0) q[120];
cx q[120],q[10];
u1(0) q[10];
cx q[120],q[10];
u1(0) q[10];
u1(0) q[120];
cx q[120],q[11];
u1(0) q[11];
cx q[120],q[11];
u1(0) q[11];
u1(0) q[120];
cx q[120],q[12];
u1(0) q[12];
cx q[120],q[12];
u1(0) q[12];
u1(0) q[120];
cx q[120],q[13];
u1(0) q[13];
cx q[120],q[13];
u1(0) q[13];
u1(0) q[120];
cx q[120],q[14];
u1(0) q[14];
cx q[120],q[14];
u1(0) q[14];
u1(0) q[120];
cx q[120],q[15];
u1(0) q[15];
cx q[120],q[15];
u1(0) q[15];
u1(0) q[120];
cx q[120],q[16];
u1(0) q[16];
cx q[120],q[16];
u1(0) q[16];
u1(0) q[120];
cx q[120],q[17];
u1(0) q[17];
cx q[120],q[17];
u1(0) q[17];
u1(0) q[120];
cx q[120],q[18];
u1(0) q[18];
cx q[120],q[18];
u1(0) q[18];
u1(0) q[120];
cx q[120],q[19];
u1(0) q[19];
cx q[120],q[19];
u1(0) q[19];
u1(0) q[120];
cx q[120],q[20];
u1(0) q[20];
cx q[120],q[20];
u1(0) q[20];
u1(0) q[120];
cx q[120],q[21];
u1(0) q[21];
cx q[120],q[21];
u1(0) q[21];
u1(0) q[120];
cx q[120],q[22];
u1(0) q[22];
cx q[120],q[22];
u1(0) q[22];
u1(0) q[120];
cx q[120],q[23];
u1(0) q[23];
cx q[120],q[23];
u1(0) q[23];
u1(0) q[120];
cx q[120],q[24];
u1(0) q[24];
cx q[120],q[24];
u1(0) q[24];
u1(0) q[120];
cx q[120],q[25];
u1(0) q[25];
cx q[120],q[25];
u1(0) q[25];
u1(0) q[120];
cx q[120],q[26];
u1(0) q[26];
cx q[120],q[26];
u1(0) q[26];
u1(0) q[120];
cx q[120],q[27];
u1(0) q[27];
cx q[120],q[27];
u1(0) q[27];
u1(0) q[120];
cx q[120],q[28];
u1(0) q[28];
cx q[120],q[28];
u1(0) q[28];
u1(0) q[120];
cx q[120],q[29];
u1(0) q[29];
cx q[120],q[29];
u1(0) q[29];
u1(0) q[120];
cx q[120],q[30];
u1(0) q[30];
cx q[120],q[30];
u1(0) q[30];
u1(0) q[120];
cx q[120],q[31];
u1(0) q[31];
cx q[120],q[31];
u1(0) q[31];
u1(0) q[120];
cx q[120],q[32];
u1(0) q[32];
cx q[120],q[32];
u1(0) q[32];
u1(0) q[120];
cx q[120],q[33];
u1(0) q[33];
cx q[120],q[33];
u1(0) q[33];
u1(0) q[120];
cx q[120],q[34];
u1(0) q[34];
cx q[120],q[34];
u1(0) q[34];
u1(0) q[120];
cx q[120],q[35];
u1(0) q[35];
cx q[120],q[35];
u1(0) q[35];
u1(0) q[120];
cx q[120],q[36];
u1(0) q[36];
cx q[120],q[36];
u1(0) q[36];
u1(0) q[120];
cx q[120],q[37];
u1(0) q[37];
cx q[120],q[37];
u1(0) q[37];
u1(0) q[120];
cx q[120],q[38];
u1(0) q[38];
cx q[120],q[38];
u1(0) q[38];
u1(0) q[120];
cx q[120],q[39];
u1(0) q[39];
cx q[120],q[39];
u1(0) q[39];
u1(0) q[120];
cx q[120],q[40];
u1(0) q[40];
cx q[120],q[40];
u1(0) q[40];
u1(0) q[120];
cx q[120],q[41];
u1(0) q[41];
cx q[120],q[41];
u1(0) q[41];
u1(0) q[120];
cx q[120],q[42];
u1(0) q[42];
cx q[120],q[42];
u1(0) q[42];
u1(0) q[120];
cx q[120],q[43];
u1(0) q[43];
cx q[120],q[43];
u1(0) q[43];
u1(0) q[120];
cx q[120],q[44];
u1(0) q[44];
cx q[120],q[44];
u1(0) q[44];
u1(0) q[120];
cx q[120],q[45];
u1(0) q[45];
cx q[120],q[45];
u1(0) q[45];
u1(0) q[120];
cx q[120],q[46];
u1(0) q[46];
cx q[120],q[46];
u1(0) q[46];
u1(0) q[120];
cx q[120],q[47];
u1(0) q[47];
cx q[120],q[47];
u1(0) q[47];
u1(0) q[120];
cx q[120],q[48];
u1(0) q[48];
cx q[120],q[48];
u1(0) q[48];
u1(0) q[120];
cx q[120],q[49];
u1(0) q[49];
cx q[120],q[49];
u1(0) q[49];
u1(0) q[120];
cx q[120],q[50];
u1(0) q[50];
cx q[120],q[50];
u1(0) q[50];
u1(0) q[120];
cx q[120],q[51];
u1(0) q[51];
cx q[120],q[51];
u1(0) q[51];
u1(0) q[120];
cx q[120],q[52];
u1(0) q[52];
cx q[120],q[52];
u1(0) q[52];
u1(0) q[120];
cx q[120],q[53];
u1(0) q[53];
cx q[120],q[53];
u1(0) q[53];
u1(0) q[120];
cx q[120],q[54];
u1(0) q[54];
cx q[120],q[54];
u1(0) q[54];
u1(0) q[120];
cx q[120],q[55];
u1(0) q[55];
cx q[120],q[55];
u1(0) q[55];
u1(0) q[120];
cx q[120],q[56];
u1(0) q[56];
cx q[120],q[56];
u1(0) q[56];
u1(0) q[120];
cx q[120],q[57];
u1(0) q[57];
cx q[120],q[57];
u1(0) q[57];
u1(0) q[120];
cx q[120],q[58];
u1(0) q[58];
cx q[120],q[58];
u1(0) q[58];
u1(0) q[120];
cx q[120],q[59];
u1(0) q[59];
cx q[120],q[59];
u1(0) q[59];
u1(0) q[120];
cx q[120],q[60];
u1(0) q[60];
cx q[120],q[60];
u1(0) q[60];
u1(0) q[120];
cx q[120],q[61];
u1(0) q[61];
cx q[120],q[61];
u1(0) q[61];
u1(0) q[120];
cx q[120],q[62];
u1(0) q[62];
cx q[120],q[62];
u1(0) q[62];
u1(0) q[120];
cx q[120],q[63];
u1(0) q[63];
cx q[120],q[63];
u1(0) q[63];
u1(0) q[120];
cx q[120],q[64];
u1(0) q[64];
cx q[120],q[64];
u1(0) q[64];
u1(0) q[120];
cx q[120],q[65];
u1(0) q[65];
cx q[120],q[65];
u1(0) q[65];
u1(0) q[120];
cx q[120],q[66];
u1(0) q[66];
cx q[120],q[66];
u1(0) q[66];
u1(0) q[120];
cx q[120],q[67];
u1(0) q[67];
cx q[120],q[67];
u1(0) q[67];
u1(0) q[120];
cx q[120],q[68];
u1(0) q[68];
cx q[120],q[68];
u1(0) q[68];
u1(0) q[120];
cx q[120],q[69];
u1(0) q[69];
cx q[120],q[69];
u1(0) q[69];
u1(0) q[120];
cx q[120],q[70];
u1(0) q[70];
cx q[120],q[70];
u1(0) q[70];
u1(0) q[120];
cx q[120],q[71];
u1(0) q[71];
cx q[120],q[71];
u1(0) q[71];
u1(0) q[120];
cx q[120],q[72];
u1(0) q[72];
cx q[120],q[72];
u1(0) q[72];
u1(pi/281474976710656) q[120];
cx q[120],q[73];
u1(-pi/281474976710656) q[73];
cx q[120],q[73];
u1(pi/281474976710656) q[73];
u1(pi/140737488355328) q[120];
cx q[120],q[74];
u1(-pi/140737488355328) q[74];
cx q[120],q[74];
u1(pi/140737488355328) q[74];
u1(pi/70368744177664) q[120];
cx q[120],q[75];
u1(-pi/70368744177664) q[75];
cx q[120],q[75];
u1(pi/70368744177664) q[75];
u1(pi/35184372088832) q[120];
cx q[120],q[76];
u1(-pi/35184372088832) q[76];
cx q[120],q[76];
u1(pi/35184372088832) q[76];
u1(pi/17592186044416) q[120];
cx q[120],q[77];
u1(-pi/17592186044416) q[77];
cx q[120],q[77];
u1(pi/17592186044416) q[77];
u1(pi/8796093022208) q[120];
cx q[120],q[78];
u1(-pi/8796093022208) q[78];
cx q[120],q[78];
u1(pi/8796093022208) q[78];
u1(pi/4398046511104) q[120];
cx q[120],q[79];
u1(-pi/4398046511104) q[79];
cx q[120],q[79];
u1(pi/4398046511104) q[79];
u1(pi/2199023255552) q[120];
cx q[120],q[80];
u1(-pi/2199023255552) q[80];
cx q[120],q[80];
u1(pi/2199023255552) q[80];
u1(pi/1099511627776) q[120];
cx q[120],q[81];
u1(-pi/1099511627776) q[81];
cx q[120],q[81];
u1(pi/1099511627776) q[81];
u1(pi/549755813888) q[120];
cx q[120],q[82];
u1(-pi/549755813888) q[82];
cx q[120],q[82];
u1(pi/549755813888) q[82];
u1(pi/274877906944) q[120];
cx q[120],q[83];
u1(-pi/274877906944) q[83];
cx q[120],q[83];
u1(pi/274877906944) q[83];
u1(pi/137438953472) q[120];
cx q[120],q[84];
u1(-pi/137438953472) q[84];
cx q[120],q[84];
u1(pi/137438953472) q[84];
u1(pi/68719476736) q[120];
cx q[120],q[85];
u1(-pi/68719476736) q[85];
cx q[120],q[85];
u1(pi/68719476736) q[85];
u1(pi/34359738368) q[120];
cx q[120],q[86];
u1(-pi/34359738368) q[86];
cx q[120],q[86];
u1(pi/34359738368) q[86];
u1(pi/17179869184) q[120];
cx q[120],q[87];
u1(-pi/17179869184) q[87];
cx q[120],q[87];
u1(pi/17179869184) q[87];
u1(pi/8589934592) q[120];
cx q[120],q[88];
u1(-pi/8589934592) q[88];
cx q[120],q[88];
u1(pi/8589934592) q[88];
u1(pi/4294967296) q[120];
cx q[120],q[89];
u1(-pi/4294967296) q[89];
cx q[120],q[89];
u1(pi/4294967296) q[89];
u1(pi/2147483648) q[120];
cx q[120],q[90];
u1(-pi/2147483648) q[90];
cx q[120],q[90];
u1(pi/2147483648) q[90];
u1(pi/1073741824) q[120];
cx q[120],q[91];
u1(-pi/1073741824) q[91];
cx q[120],q[91];
u1(pi/1073741824) q[91];
u1(pi/536870912) q[120];
cx q[120],q[92];
u1(-pi/536870912) q[92];
cx q[120],q[92];
u1(pi/536870912) q[92];
u1(pi/268435456) q[120];
cx q[120],q[93];
u1(-pi/268435456) q[93];
cx q[120],q[93];
u1(pi/268435456) q[93];
u1(pi/134217728) q[120];
cx q[120],q[94];
u1(-pi/134217728) q[94];
cx q[120],q[94];
u1(pi/134217728) q[94];
u1(pi/67108864) q[120];
cx q[120],q[95];
u1(-pi/67108864) q[95];
cx q[120],q[95];
u1(pi/67108864) q[95];
u1(pi/33554432) q[120];
cx q[120],q[96];
u1(-pi/33554432) q[96];
cx q[120],q[96];
u1(pi/33554432) q[96];
u1(pi/16777216) q[120];
cx q[120],q[97];
u1(-pi/16777216) q[97];
cx q[120],q[97];
u1(pi/16777216) q[97];
u1(pi/8388608) q[120];
cx q[120],q[98];
u1(-pi/8388608) q[98];
cx q[120],q[98];
u1(pi/8388608) q[98];
u1(pi/4194304) q[120];
cx q[120],q[99];
u1(-pi/4194304) q[99];
cx q[120],q[99];
u1(pi/4194304) q[99];
u1(pi/2097152) q[120];
cx q[120],q[100];
u1(-pi/2097152) q[100];
cx q[120],q[100];
u1(pi/2097152) q[100];
u1(pi/1048576) q[120];
cx q[120],q[101];
u1(-pi/1048576) q[101];
cx q[120],q[101];
u1(pi/1048576) q[101];
u1(pi/524288) q[120];
cx q[120],q[102];
u1(-pi/524288) q[102];
cx q[120],q[102];
u1(pi/524288) q[102];
u1(pi/262144) q[120];
cx q[120],q[103];
u1(-pi/262144) q[103];
cx q[120],q[103];
u1(pi/262144) q[103];
u1(pi/131072) q[120];
cx q[120],q[104];
u1(-pi/131072) q[104];
cx q[120],q[104];
u1(pi/131072) q[104];
u1(pi/65536) q[120];
cx q[120],q[105];
u1(-pi/65536) q[105];
cx q[120],q[105];
u1(pi/65536) q[105];
u1(pi/32768) q[120];
cx q[120],q[106];
u1(-pi/32768) q[106];
cx q[120],q[106];
u1(pi/32768) q[106];
u1(pi/16384) q[120];
cx q[120],q[107];
u1(-pi/16384) q[107];
cx q[120],q[107];
u1(pi/16384) q[107];
u1(pi/8192) q[120];
cx q[120],q[108];
u1(-pi/8192) q[108];
cx q[120],q[108];
u1(pi/8192) q[108];
u1(pi/4096) q[120];
cx q[120],q[109];
u1(-pi/4096) q[109];
cx q[120],q[109];
u1(pi/4096) q[109];
u1(pi/2048) q[120];
cx q[120],q[110];
u1(-pi/2048) q[110];
cx q[120],q[110];
u1(pi/2048) q[110];
u1(pi/1024) q[120];
cx q[120],q[111];
u1(-pi/1024) q[111];
cx q[120],q[111];
u1(pi/1024) q[111];
u1(pi/512) q[120];
cx q[120],q[112];
u1(-pi/512) q[112];
cx q[120],q[112];
u1(pi/512) q[112];
u1(pi/256) q[120];
cx q[120],q[113];
u1(-pi/256) q[113];
cx q[120],q[113];
u1(pi/256) q[113];
u1(pi/128) q[120];
cx q[120],q[114];
u1(-pi/128) q[114];
cx q[120],q[114];
u1(pi/128) q[114];
u1(pi/64) q[120];
cx q[120],q[115];
u1(-pi/64) q[115];
cx q[120],q[115];
u1(pi/64) q[115];
u1(pi/32) q[120];
cx q[120],q[116];
u1(-pi/32) q[116];
cx q[120],q[116];
u1(pi/32) q[116];
u1(pi/16) q[120];
cx q[120],q[117];
u1(-pi/16) q[117];
cx q[120],q[117];
u1(pi/16) q[117];
u1(pi/8) q[120];
cx q[120],q[118];
u1(-pi/8) q[118];
cx q[120],q[118];
u1(pi/8) q[118];
u1(pi/4) q[120];
cx q[120],q[119];
u1(-pi/4) q[119];
cx q[120],q[119];
u1(pi/4) q[119];
h q[120];
u1(0) q[121];
cx q[121],q[0];
u1(0) q[0];
cx q[121],q[0];
u1(0) q[0];
u1(0) q[121];
cx q[121],q[1];
u1(0) q[1];
cx q[121],q[1];
u1(0) q[1];
u1(0) q[121];
cx q[121],q[2];
u1(0) q[2];
cx q[121],q[2];
u1(0) q[2];
u1(0) q[121];
cx q[121],q[3];
u1(0) q[3];
cx q[121],q[3];
u1(0) q[3];
u1(0) q[121];
cx q[121],q[4];
u1(0) q[4];
cx q[121],q[4];
u1(0) q[4];
u1(0) q[121];
cx q[121],q[5];
u1(0) q[5];
cx q[121],q[5];
u1(0) q[5];
u1(0) q[121];
cx q[121],q[6];
u1(0) q[6];
cx q[121],q[6];
u1(0) q[6];
u1(0) q[121];
cx q[121],q[7];
u1(0) q[7];
cx q[121],q[7];
u1(0) q[7];
u1(0) q[121];
cx q[121],q[8];
u1(0) q[8];
cx q[121],q[8];
u1(0) q[8];
u1(0) q[121];
cx q[121],q[9];
u1(0) q[9];
cx q[121],q[9];
u1(0) q[9];
u1(0) q[121];
cx q[121],q[10];
u1(0) q[10];
cx q[121],q[10];
u1(0) q[10];
u1(0) q[121];
cx q[121],q[11];
u1(0) q[11];
cx q[121],q[11];
u1(0) q[11];
u1(0) q[121];
cx q[121],q[12];
u1(0) q[12];
cx q[121],q[12];
u1(0) q[12];
u1(0) q[121];
cx q[121],q[13];
u1(0) q[13];
cx q[121],q[13];
u1(0) q[13];
u1(0) q[121];
cx q[121],q[14];
u1(0) q[14];
cx q[121],q[14];
u1(0) q[14];
u1(0) q[121];
cx q[121],q[15];
u1(0) q[15];
cx q[121],q[15];
u1(0) q[15];
u1(0) q[121];
cx q[121],q[16];
u1(0) q[16];
cx q[121],q[16];
u1(0) q[16];
u1(0) q[121];
cx q[121],q[17];
u1(0) q[17];
cx q[121],q[17];
u1(0) q[17];
u1(0) q[121];
cx q[121],q[18];
u1(0) q[18];
cx q[121],q[18];
u1(0) q[18];
u1(0) q[121];
cx q[121],q[19];
u1(0) q[19];
cx q[121],q[19];
u1(0) q[19];
u1(0) q[121];
cx q[121],q[20];
u1(0) q[20];
cx q[121],q[20];
u1(0) q[20];
u1(0) q[121];
cx q[121],q[21];
u1(0) q[21];
cx q[121],q[21];
u1(0) q[21];
u1(0) q[121];
cx q[121],q[22];
u1(0) q[22];
cx q[121],q[22];
u1(0) q[22];
u1(0) q[121];
cx q[121],q[23];
u1(0) q[23];
cx q[121],q[23];
u1(0) q[23];
u1(0) q[121];
cx q[121],q[24];
u1(0) q[24];
cx q[121],q[24];
u1(0) q[24];
u1(0) q[121];
cx q[121],q[25];
u1(0) q[25];
cx q[121],q[25];
u1(0) q[25];
u1(0) q[121];
cx q[121],q[26];
u1(0) q[26];
cx q[121],q[26];
u1(0) q[26];
u1(0) q[121];
cx q[121],q[27];
u1(0) q[27];
cx q[121],q[27];
u1(0) q[27];
u1(0) q[121];
cx q[121],q[28];
u1(0) q[28];
cx q[121],q[28];
u1(0) q[28];
u1(0) q[121];
cx q[121],q[29];
u1(0) q[29];
cx q[121],q[29];
u1(0) q[29];
u1(0) q[121];
cx q[121],q[30];
u1(0) q[30];
cx q[121],q[30];
u1(0) q[30];
u1(0) q[121];
cx q[121],q[31];
u1(0) q[31];
cx q[121],q[31];
u1(0) q[31];
u1(0) q[121];
cx q[121],q[32];
u1(0) q[32];
cx q[121],q[32];
u1(0) q[32];
u1(0) q[121];
cx q[121],q[33];
u1(0) q[33];
cx q[121],q[33];
u1(0) q[33];
u1(0) q[121];
cx q[121],q[34];
u1(0) q[34];
cx q[121],q[34];
u1(0) q[34];
u1(0) q[121];
cx q[121],q[35];
u1(0) q[35];
cx q[121],q[35];
u1(0) q[35];
u1(0) q[121];
cx q[121],q[36];
u1(0) q[36];
cx q[121],q[36];
u1(0) q[36];
u1(0) q[121];
cx q[121],q[37];
u1(0) q[37];
cx q[121],q[37];
u1(0) q[37];
u1(0) q[121];
cx q[121],q[38];
u1(0) q[38];
cx q[121],q[38];
u1(0) q[38];
u1(0) q[121];
cx q[121],q[39];
u1(0) q[39];
cx q[121],q[39];
u1(0) q[39];
u1(0) q[121];
cx q[121],q[40];
u1(0) q[40];
cx q[121],q[40];
u1(0) q[40];
u1(0) q[121];
cx q[121],q[41];
u1(0) q[41];
cx q[121],q[41];
u1(0) q[41];
u1(0) q[121];
cx q[121],q[42];
u1(0) q[42];
cx q[121],q[42];
u1(0) q[42];
u1(0) q[121];
cx q[121],q[43];
u1(0) q[43];
cx q[121],q[43];
u1(0) q[43];
u1(0) q[121];
cx q[121],q[44];
u1(0) q[44];
cx q[121],q[44];
u1(0) q[44];
u1(0) q[121];
cx q[121],q[45];
u1(0) q[45];
cx q[121],q[45];
u1(0) q[45];
u1(0) q[121];
cx q[121],q[46];
u1(0) q[46];
cx q[121],q[46];
u1(0) q[46];
u1(0) q[121];
cx q[121],q[47];
u1(0) q[47];
cx q[121],q[47];
u1(0) q[47];
u1(0) q[121];
cx q[121],q[48];
u1(0) q[48];
cx q[121],q[48];
u1(0) q[48];
u1(0) q[121];
cx q[121],q[49];
u1(0) q[49];
cx q[121],q[49];
u1(0) q[49];
u1(0) q[121];
cx q[121],q[50];
u1(0) q[50];
cx q[121],q[50];
u1(0) q[50];
u1(0) q[121];
cx q[121],q[51];
u1(0) q[51];
cx q[121],q[51];
u1(0) q[51];
u1(0) q[121];
cx q[121],q[52];
u1(0) q[52];
cx q[121],q[52];
u1(0) q[52];
u1(0) q[121];
cx q[121],q[53];
u1(0) q[53];
cx q[121],q[53];
u1(0) q[53];
u1(0) q[121];
cx q[121],q[54];
u1(0) q[54];
cx q[121],q[54];
u1(0) q[54];
u1(0) q[121];
cx q[121],q[55];
u1(0) q[55];
cx q[121],q[55];
u1(0) q[55];
u1(0) q[121];
cx q[121],q[56];
u1(0) q[56];
cx q[121],q[56];
u1(0) q[56];
u1(0) q[121];
cx q[121],q[57];
u1(0) q[57];
cx q[121],q[57];
u1(0) q[57];
u1(0) q[121];
cx q[121],q[58];
u1(0) q[58];
cx q[121],q[58];
u1(0) q[58];
u1(0) q[121];
cx q[121],q[59];
u1(0) q[59];
cx q[121],q[59];
u1(0) q[59];
u1(0) q[121];
cx q[121],q[60];
u1(0) q[60];
cx q[121],q[60];
u1(0) q[60];
u1(0) q[121];
cx q[121],q[61];
u1(0) q[61];
cx q[121],q[61];
u1(0) q[61];
u1(0) q[121];
cx q[121],q[62];
u1(0) q[62];
cx q[121],q[62];
u1(0) q[62];
u1(0) q[121];
cx q[121],q[63];
u1(0) q[63];
cx q[121],q[63];
u1(0) q[63];
u1(0) q[121];
cx q[121],q[64];
u1(0) q[64];
cx q[121],q[64];
u1(0) q[64];
u1(0) q[121];
cx q[121],q[65];
u1(0) q[65];
cx q[121],q[65];
u1(0) q[65];
u1(0) q[121];
cx q[121],q[66];
u1(0) q[66];
cx q[121],q[66];
u1(0) q[66];
u1(0) q[121];
cx q[121],q[67];
u1(0) q[67];
cx q[121],q[67];
u1(0) q[67];
u1(0) q[121];
cx q[121],q[68];
u1(0) q[68];
cx q[121],q[68];
u1(0) q[68];
u1(0) q[121];
cx q[121],q[69];
u1(0) q[69];
cx q[121],q[69];
u1(0) q[69];
u1(0) q[121];
cx q[121],q[70];
u1(0) q[70];
cx q[121],q[70];
u1(0) q[70];
u1(0) q[121];
cx q[121],q[71];
u1(0) q[71];
cx q[121],q[71];
u1(0) q[71];
u1(0) q[121];
cx q[121],q[72];
u1(0) q[72];
cx q[121],q[72];
u1(0) q[72];
u1(0) q[121];
cx q[121],q[73];
u1(0) q[73];
cx q[121],q[73];
u1(0) q[73];
u1(pi/281474976710656) q[121];
cx q[121],q[74];
u1(-pi/281474976710656) q[74];
cx q[121],q[74];
u1(pi/281474976710656) q[74];
u1(pi/140737488355328) q[121];
cx q[121],q[75];
u1(-pi/140737488355328) q[75];
cx q[121],q[75];
u1(pi/140737488355328) q[75];
u1(pi/70368744177664) q[121];
cx q[121],q[76];
u1(-pi/70368744177664) q[76];
cx q[121],q[76];
u1(pi/70368744177664) q[76];
u1(pi/35184372088832) q[121];
cx q[121],q[77];
u1(-pi/35184372088832) q[77];
cx q[121],q[77];
u1(pi/35184372088832) q[77];
u1(pi/17592186044416) q[121];
cx q[121],q[78];
u1(-pi/17592186044416) q[78];
cx q[121],q[78];
u1(pi/17592186044416) q[78];
u1(pi/8796093022208) q[121];
cx q[121],q[79];
u1(-pi/8796093022208) q[79];
cx q[121],q[79];
u1(pi/8796093022208) q[79];
u1(pi/4398046511104) q[121];
cx q[121],q[80];
u1(-pi/4398046511104) q[80];
cx q[121],q[80];
u1(pi/4398046511104) q[80];
u1(pi/2199023255552) q[121];
cx q[121],q[81];
u1(-pi/2199023255552) q[81];
cx q[121],q[81];
u1(pi/2199023255552) q[81];
u1(pi/1099511627776) q[121];
cx q[121],q[82];
u1(-pi/1099511627776) q[82];
cx q[121],q[82];
u1(pi/1099511627776) q[82];
u1(pi/549755813888) q[121];
cx q[121],q[83];
u1(-pi/549755813888) q[83];
cx q[121],q[83];
u1(pi/549755813888) q[83];
u1(pi/274877906944) q[121];
cx q[121],q[84];
u1(-pi/274877906944) q[84];
cx q[121],q[84];
u1(pi/274877906944) q[84];
u1(pi/137438953472) q[121];
cx q[121],q[85];
u1(-pi/137438953472) q[85];
cx q[121],q[85];
u1(pi/137438953472) q[85];
u1(pi/68719476736) q[121];
cx q[121],q[86];
u1(-pi/68719476736) q[86];
cx q[121],q[86];
u1(pi/68719476736) q[86];
u1(pi/34359738368) q[121];
cx q[121],q[87];
u1(-pi/34359738368) q[87];
cx q[121],q[87];
u1(pi/34359738368) q[87];
u1(pi/17179869184) q[121];
cx q[121],q[88];
u1(-pi/17179869184) q[88];
cx q[121],q[88];
u1(pi/17179869184) q[88];
u1(pi/8589934592) q[121];
cx q[121],q[89];
u1(-pi/8589934592) q[89];
cx q[121],q[89];
u1(pi/8589934592) q[89];
u1(pi/4294967296) q[121];
cx q[121],q[90];
u1(-pi/4294967296) q[90];
cx q[121],q[90];
u1(pi/4294967296) q[90];
u1(pi/2147483648) q[121];
cx q[121],q[91];
u1(-pi/2147483648) q[91];
cx q[121],q[91];
u1(pi/2147483648) q[91];
u1(pi/1073741824) q[121];
cx q[121],q[92];
u1(-pi/1073741824) q[92];
cx q[121],q[92];
u1(pi/1073741824) q[92];
u1(pi/536870912) q[121];
cx q[121],q[93];
u1(-pi/536870912) q[93];
cx q[121],q[93];
u1(pi/536870912) q[93];
u1(pi/268435456) q[121];
cx q[121],q[94];
u1(-pi/268435456) q[94];
cx q[121],q[94];
u1(pi/268435456) q[94];
u1(pi/134217728) q[121];
cx q[121],q[95];
u1(-pi/134217728) q[95];
cx q[121],q[95];
u1(pi/134217728) q[95];
u1(pi/67108864) q[121];
cx q[121],q[96];
u1(-pi/67108864) q[96];
cx q[121],q[96];
u1(pi/67108864) q[96];
u1(pi/33554432) q[121];
cx q[121],q[97];
u1(-pi/33554432) q[97];
cx q[121],q[97];
u1(pi/33554432) q[97];
u1(pi/16777216) q[121];
cx q[121],q[98];
u1(-pi/16777216) q[98];
cx q[121],q[98];
u1(pi/16777216) q[98];
u1(pi/8388608) q[121];
cx q[121],q[99];
u1(-pi/8388608) q[99];
cx q[121],q[99];
u1(pi/8388608) q[99];
u1(pi/4194304) q[121];
cx q[121],q[100];
u1(-pi/4194304) q[100];
cx q[121],q[100];
u1(pi/4194304) q[100];
u1(pi/2097152) q[121];
cx q[121],q[101];
u1(-pi/2097152) q[101];
cx q[121],q[101];
u1(pi/2097152) q[101];
u1(pi/1048576) q[121];
cx q[121],q[102];
u1(-pi/1048576) q[102];
cx q[121],q[102];
u1(pi/1048576) q[102];
u1(pi/524288) q[121];
cx q[121],q[103];
u1(-pi/524288) q[103];
cx q[121],q[103];
u1(pi/524288) q[103];
u1(pi/262144) q[121];
cx q[121],q[104];
u1(-pi/262144) q[104];
cx q[121],q[104];
u1(pi/262144) q[104];
u1(pi/131072) q[121];
cx q[121],q[105];
u1(-pi/131072) q[105];
cx q[121],q[105];
u1(pi/131072) q[105];
u1(pi/65536) q[121];
cx q[121],q[106];
u1(-pi/65536) q[106];
cx q[121],q[106];
u1(pi/65536) q[106];
u1(pi/32768) q[121];
cx q[121],q[107];
u1(-pi/32768) q[107];
cx q[121],q[107];
u1(pi/32768) q[107];
u1(pi/16384) q[121];
cx q[121],q[108];
u1(-pi/16384) q[108];
cx q[121],q[108];
u1(pi/16384) q[108];
u1(pi/8192) q[121];
cx q[121],q[109];
u1(-pi/8192) q[109];
cx q[121],q[109];
u1(pi/8192) q[109];
u1(pi/4096) q[121];
cx q[121],q[110];
u1(-pi/4096) q[110];
cx q[121],q[110];
u1(pi/4096) q[110];
u1(pi/2048) q[121];
cx q[121],q[111];
u1(-pi/2048) q[111];
cx q[121],q[111];
u1(pi/2048) q[111];
u1(pi/1024) q[121];
cx q[121],q[112];
u1(-pi/1024) q[112];
cx q[121],q[112];
u1(pi/1024) q[112];
u1(pi/512) q[121];
cx q[121],q[113];
u1(-pi/512) q[113];
cx q[121],q[113];
u1(pi/512) q[113];
u1(pi/256) q[121];
cx q[121],q[114];
u1(-pi/256) q[114];
cx q[121],q[114];
u1(pi/256) q[114];
u1(pi/128) q[121];
cx q[121],q[115];
u1(-pi/128) q[115];
cx q[121],q[115];
u1(pi/128) q[115];
u1(pi/64) q[121];
cx q[121],q[116];
u1(-pi/64) q[116];
cx q[121],q[116];
u1(pi/64) q[116];
u1(pi/32) q[121];
cx q[121],q[117];
u1(-pi/32) q[117];
cx q[121],q[117];
u1(pi/32) q[117];
u1(pi/16) q[121];
cx q[121],q[118];
u1(-pi/16) q[118];
cx q[121],q[118];
u1(pi/16) q[118];
u1(pi/8) q[121];
cx q[121],q[119];
u1(-pi/8) q[119];
cx q[121],q[119];
u1(pi/8) q[119];
u1(pi/4) q[121];
cx q[121],q[120];
u1(-pi/4) q[120];
cx q[121],q[120];
u1(pi/4) q[120];
h q[121];
u1(0) q[122];
cx q[122],q[0];
u1(0) q[0];
cx q[122],q[0];
u1(0) q[0];
u1(0) q[122];
cx q[122],q[1];
u1(0) q[1];
cx q[122],q[1];
u1(0) q[1];
u1(0) q[122];
cx q[122],q[2];
u1(0) q[2];
cx q[122],q[2];
u1(0) q[2];
u1(0) q[122];
cx q[122],q[3];
u1(0) q[3];
cx q[122],q[3];
u1(0) q[3];
u1(0) q[122];
cx q[122],q[4];
u1(0) q[4];
cx q[122],q[4];
u1(0) q[4];
u1(0) q[122];
cx q[122],q[5];
u1(0) q[5];
cx q[122],q[5];
u1(0) q[5];
u1(0) q[122];
cx q[122],q[6];
u1(0) q[6];
cx q[122],q[6];
u1(0) q[6];
u1(0) q[122];
cx q[122],q[7];
u1(0) q[7];
cx q[122],q[7];
u1(0) q[7];
u1(0) q[122];
cx q[122],q[8];
u1(0) q[8];
cx q[122],q[8];
u1(0) q[8];
u1(0) q[122];
cx q[122],q[9];
u1(0) q[9];
cx q[122],q[9];
u1(0) q[9];
u1(0) q[122];
cx q[122],q[10];
u1(0) q[10];
cx q[122],q[10];
u1(0) q[10];
u1(0) q[122];
cx q[122],q[11];
u1(0) q[11];
cx q[122],q[11];
u1(0) q[11];
u1(0) q[122];
cx q[122],q[12];
u1(0) q[12];
cx q[122],q[12];
u1(0) q[12];
u1(0) q[122];
cx q[122],q[13];
u1(0) q[13];
cx q[122],q[13];
u1(0) q[13];
u1(0) q[122];
cx q[122],q[14];
u1(0) q[14];
cx q[122],q[14];
u1(0) q[14];
u1(0) q[122];
cx q[122],q[15];
u1(0) q[15];
cx q[122],q[15];
u1(0) q[15];
u1(0) q[122];
cx q[122],q[16];
u1(0) q[16];
cx q[122],q[16];
u1(0) q[16];
u1(0) q[122];
cx q[122],q[17];
u1(0) q[17];
cx q[122],q[17];
u1(0) q[17];
u1(0) q[122];
cx q[122],q[18];
u1(0) q[18];
cx q[122],q[18];
u1(0) q[18];
u1(0) q[122];
cx q[122],q[19];
u1(0) q[19];
cx q[122],q[19];
u1(0) q[19];
u1(0) q[122];
cx q[122],q[20];
u1(0) q[20];
cx q[122],q[20];
u1(0) q[20];
u1(0) q[122];
cx q[122],q[21];
u1(0) q[21];
cx q[122],q[21];
u1(0) q[21];
u1(0) q[122];
cx q[122],q[22];
u1(0) q[22];
cx q[122],q[22];
u1(0) q[22];
u1(0) q[122];
cx q[122],q[23];
u1(0) q[23];
cx q[122],q[23];
u1(0) q[23];
u1(0) q[122];
cx q[122],q[24];
u1(0) q[24];
cx q[122],q[24];
u1(0) q[24];
u1(0) q[122];
cx q[122],q[25];
u1(0) q[25];
cx q[122],q[25];
u1(0) q[25];
u1(0) q[122];
cx q[122],q[26];
u1(0) q[26];
cx q[122],q[26];
u1(0) q[26];
u1(0) q[122];
cx q[122],q[27];
u1(0) q[27];
cx q[122],q[27];
u1(0) q[27];
u1(0) q[122];
cx q[122],q[28];
u1(0) q[28];
cx q[122],q[28];
u1(0) q[28];
u1(0) q[122];
cx q[122],q[29];
u1(0) q[29];
cx q[122],q[29];
u1(0) q[29];
u1(0) q[122];
cx q[122],q[30];
u1(0) q[30];
cx q[122],q[30];
u1(0) q[30];
u1(0) q[122];
cx q[122],q[31];
u1(0) q[31];
cx q[122],q[31];
u1(0) q[31];
u1(0) q[122];
cx q[122],q[32];
u1(0) q[32];
cx q[122],q[32];
u1(0) q[32];
u1(0) q[122];
cx q[122],q[33];
u1(0) q[33];
cx q[122],q[33];
u1(0) q[33];
u1(0) q[122];
cx q[122],q[34];
u1(0) q[34];
cx q[122],q[34];
u1(0) q[34];
u1(0) q[122];
cx q[122],q[35];
u1(0) q[35];
cx q[122],q[35];
u1(0) q[35];
u1(0) q[122];
cx q[122],q[36];
u1(0) q[36];
cx q[122],q[36];
u1(0) q[36];
u1(0) q[122];
cx q[122],q[37];
u1(0) q[37];
cx q[122],q[37];
u1(0) q[37];
u1(0) q[122];
cx q[122],q[38];
u1(0) q[38];
cx q[122],q[38];
u1(0) q[38];
u1(0) q[122];
cx q[122],q[39];
u1(0) q[39];
cx q[122],q[39];
u1(0) q[39];
u1(0) q[122];
cx q[122],q[40];
u1(0) q[40];
cx q[122],q[40];
u1(0) q[40];
u1(0) q[122];
cx q[122],q[41];
u1(0) q[41];
cx q[122],q[41];
u1(0) q[41];
u1(0) q[122];
cx q[122],q[42];
u1(0) q[42];
cx q[122],q[42];
u1(0) q[42];
u1(0) q[122];
cx q[122],q[43];
u1(0) q[43];
cx q[122],q[43];
u1(0) q[43];
u1(0) q[122];
cx q[122],q[44];
u1(0) q[44];
cx q[122],q[44];
u1(0) q[44];
u1(0) q[122];
cx q[122],q[45];
u1(0) q[45];
cx q[122],q[45];
u1(0) q[45];
u1(0) q[122];
cx q[122],q[46];
u1(0) q[46];
cx q[122],q[46];
u1(0) q[46];
u1(0) q[122];
cx q[122],q[47];
u1(0) q[47];
cx q[122],q[47];
u1(0) q[47];
u1(0) q[122];
cx q[122],q[48];
u1(0) q[48];
cx q[122],q[48];
u1(0) q[48];
u1(0) q[122];
cx q[122],q[49];
u1(0) q[49];
cx q[122],q[49];
u1(0) q[49];
u1(0) q[122];
cx q[122],q[50];
u1(0) q[50];
cx q[122],q[50];
u1(0) q[50];
u1(0) q[122];
cx q[122],q[51];
u1(0) q[51];
cx q[122],q[51];
u1(0) q[51];
u1(0) q[122];
cx q[122],q[52];
u1(0) q[52];
cx q[122],q[52];
u1(0) q[52];
u1(0) q[122];
cx q[122],q[53];
u1(0) q[53];
cx q[122],q[53];
u1(0) q[53];
u1(0) q[122];
cx q[122],q[54];
u1(0) q[54];
cx q[122],q[54];
u1(0) q[54];
u1(0) q[122];
cx q[122],q[55];
u1(0) q[55];
cx q[122],q[55];
u1(0) q[55];
u1(0) q[122];
cx q[122],q[56];
u1(0) q[56];
cx q[122],q[56];
u1(0) q[56];
u1(0) q[122];
cx q[122],q[57];
u1(0) q[57];
cx q[122],q[57];
u1(0) q[57];
u1(0) q[122];
cx q[122],q[58];
u1(0) q[58];
cx q[122],q[58];
u1(0) q[58];
u1(0) q[122];
cx q[122],q[59];
u1(0) q[59];
cx q[122],q[59];
u1(0) q[59];
u1(0) q[122];
cx q[122],q[60];
u1(0) q[60];
cx q[122],q[60];
u1(0) q[60];
u1(0) q[122];
cx q[122],q[61];
u1(0) q[61];
cx q[122],q[61];
u1(0) q[61];
u1(0) q[122];
cx q[122],q[62];
u1(0) q[62];
cx q[122],q[62];
u1(0) q[62];
u1(0) q[122];
cx q[122],q[63];
u1(0) q[63];
cx q[122],q[63];
u1(0) q[63];
u1(0) q[122];
cx q[122],q[64];
u1(0) q[64];
cx q[122],q[64];
u1(0) q[64];
u1(0) q[122];
cx q[122],q[65];
u1(0) q[65];
cx q[122],q[65];
u1(0) q[65];
u1(0) q[122];
cx q[122],q[66];
u1(0) q[66];
cx q[122],q[66];
u1(0) q[66];
u1(0) q[122];
cx q[122],q[67];
u1(0) q[67];
cx q[122],q[67];
u1(0) q[67];
u1(0) q[122];
cx q[122],q[68];
u1(0) q[68];
cx q[122],q[68];
u1(0) q[68];
u1(0) q[122];
cx q[122],q[69];
u1(0) q[69];
cx q[122],q[69];
u1(0) q[69];
u1(0) q[122];
cx q[122],q[70];
u1(0) q[70];
cx q[122],q[70];
u1(0) q[70];
u1(0) q[122];
cx q[122],q[71];
u1(0) q[71];
cx q[122],q[71];
u1(0) q[71];
u1(0) q[122];
cx q[122],q[72];
u1(0) q[72];
cx q[122],q[72];
u1(0) q[72];
u1(0) q[122];
cx q[122],q[73];
u1(0) q[73];
cx q[122],q[73];
u1(0) q[73];
u1(0) q[122];
cx q[122],q[74];
u1(0) q[74];
cx q[122],q[74];
u1(0) q[74];
u1(pi/281474976710656) q[122];
cx q[122],q[75];
u1(-pi/281474976710656) q[75];
cx q[122],q[75];
u1(pi/281474976710656) q[75];
u1(pi/140737488355328) q[122];
cx q[122],q[76];
u1(-pi/140737488355328) q[76];
cx q[122],q[76];
u1(pi/140737488355328) q[76];
u1(pi/70368744177664) q[122];
cx q[122],q[77];
u1(-pi/70368744177664) q[77];
cx q[122],q[77];
u1(pi/70368744177664) q[77];
u1(pi/35184372088832) q[122];
cx q[122],q[78];
u1(-pi/35184372088832) q[78];
cx q[122],q[78];
u1(pi/35184372088832) q[78];
u1(pi/17592186044416) q[122];
cx q[122],q[79];
u1(-pi/17592186044416) q[79];
cx q[122],q[79];
u1(pi/17592186044416) q[79];
u1(pi/8796093022208) q[122];
cx q[122],q[80];
u1(-pi/8796093022208) q[80];
cx q[122],q[80];
u1(pi/8796093022208) q[80];
u1(pi/4398046511104) q[122];
cx q[122],q[81];
u1(-pi/4398046511104) q[81];
cx q[122],q[81];
u1(pi/4398046511104) q[81];
u1(pi/2199023255552) q[122];
cx q[122],q[82];
u1(-pi/2199023255552) q[82];
cx q[122],q[82];
u1(pi/2199023255552) q[82];
u1(pi/1099511627776) q[122];
cx q[122],q[83];
u1(-pi/1099511627776) q[83];
cx q[122],q[83];
u1(pi/1099511627776) q[83];
u1(pi/549755813888) q[122];
cx q[122],q[84];
u1(-pi/549755813888) q[84];
cx q[122],q[84];
u1(pi/549755813888) q[84];
u1(pi/274877906944) q[122];
cx q[122],q[85];
u1(-pi/274877906944) q[85];
cx q[122],q[85];
u1(pi/274877906944) q[85];
u1(pi/137438953472) q[122];
cx q[122],q[86];
u1(-pi/137438953472) q[86];
cx q[122],q[86];
u1(pi/137438953472) q[86];
u1(pi/68719476736) q[122];
cx q[122],q[87];
u1(-pi/68719476736) q[87];
cx q[122],q[87];
u1(pi/68719476736) q[87];
u1(pi/34359738368) q[122];
cx q[122],q[88];
u1(-pi/34359738368) q[88];
cx q[122],q[88];
u1(pi/34359738368) q[88];
u1(pi/17179869184) q[122];
cx q[122],q[89];
u1(-pi/17179869184) q[89];
cx q[122],q[89];
u1(pi/17179869184) q[89];
u1(pi/8589934592) q[122];
cx q[122],q[90];
u1(-pi/8589934592) q[90];
cx q[122],q[90];
u1(pi/8589934592) q[90];
u1(pi/4294967296) q[122];
cx q[122],q[91];
u1(-pi/4294967296) q[91];
cx q[122],q[91];
u1(pi/4294967296) q[91];
u1(pi/2147483648) q[122];
cx q[122],q[92];
u1(-pi/2147483648) q[92];
cx q[122],q[92];
u1(pi/2147483648) q[92];
u1(pi/1073741824) q[122];
cx q[122],q[93];
u1(-pi/1073741824) q[93];
cx q[122],q[93];
u1(pi/1073741824) q[93];
u1(pi/536870912) q[122];
cx q[122],q[94];
u1(-pi/536870912) q[94];
cx q[122],q[94];
u1(pi/536870912) q[94];
u1(pi/268435456) q[122];
cx q[122],q[95];
u1(-pi/268435456) q[95];
cx q[122],q[95];
u1(pi/268435456) q[95];
u1(pi/134217728) q[122];
cx q[122],q[96];
u1(-pi/134217728) q[96];
cx q[122],q[96];
u1(pi/134217728) q[96];
u1(pi/67108864) q[122];
cx q[122],q[97];
u1(-pi/67108864) q[97];
cx q[122],q[97];
u1(pi/67108864) q[97];
u1(pi/33554432) q[122];
cx q[122],q[98];
u1(-pi/33554432) q[98];
cx q[122],q[98];
u1(pi/33554432) q[98];
u1(pi/16777216) q[122];
cx q[122],q[99];
u1(-pi/16777216) q[99];
cx q[122],q[99];
u1(pi/16777216) q[99];
u1(pi/8388608) q[122];
cx q[122],q[100];
u1(-pi/8388608) q[100];
cx q[122],q[100];
u1(pi/8388608) q[100];
u1(pi/4194304) q[122];
cx q[122],q[101];
u1(-pi/4194304) q[101];
cx q[122],q[101];
u1(pi/4194304) q[101];
u1(pi/2097152) q[122];
cx q[122],q[102];
u1(-pi/2097152) q[102];
cx q[122],q[102];
u1(pi/2097152) q[102];
u1(pi/1048576) q[122];
cx q[122],q[103];
u1(-pi/1048576) q[103];
cx q[122],q[103];
u1(pi/1048576) q[103];
u1(pi/524288) q[122];
cx q[122],q[104];
u1(-pi/524288) q[104];
cx q[122],q[104];
u1(pi/524288) q[104];
u1(pi/262144) q[122];
cx q[122],q[105];
u1(-pi/262144) q[105];
cx q[122],q[105];
u1(pi/262144) q[105];
u1(pi/131072) q[122];
cx q[122],q[106];
u1(-pi/131072) q[106];
cx q[122],q[106];
u1(pi/131072) q[106];
u1(pi/65536) q[122];
cx q[122],q[107];
u1(-pi/65536) q[107];
cx q[122],q[107];
u1(pi/65536) q[107];
u1(pi/32768) q[122];
cx q[122],q[108];
u1(-pi/32768) q[108];
cx q[122],q[108];
u1(pi/32768) q[108];
u1(pi/16384) q[122];
cx q[122],q[109];
u1(-pi/16384) q[109];
cx q[122],q[109];
u1(pi/16384) q[109];
u1(pi/8192) q[122];
cx q[122],q[110];
u1(-pi/8192) q[110];
cx q[122],q[110];
u1(pi/8192) q[110];
u1(pi/4096) q[122];
cx q[122],q[111];
u1(-pi/4096) q[111];
cx q[122],q[111];
u1(pi/4096) q[111];
u1(pi/2048) q[122];
cx q[122],q[112];
u1(-pi/2048) q[112];
cx q[122],q[112];
u1(pi/2048) q[112];
u1(pi/1024) q[122];
cx q[122],q[113];
u1(-pi/1024) q[113];
cx q[122],q[113];
u1(pi/1024) q[113];
u1(pi/512) q[122];
cx q[122],q[114];
u1(-pi/512) q[114];
cx q[122],q[114];
u1(pi/512) q[114];
u1(pi/256) q[122];
cx q[122],q[115];
u1(-pi/256) q[115];
cx q[122],q[115];
u1(pi/256) q[115];
u1(pi/128) q[122];
cx q[122],q[116];
u1(-pi/128) q[116];
cx q[122],q[116];
u1(pi/128) q[116];
u1(pi/64) q[122];
cx q[122],q[117];
u1(-pi/64) q[117];
cx q[122],q[117];
u1(pi/64) q[117];
u1(pi/32) q[122];
cx q[122],q[118];
u1(-pi/32) q[118];
cx q[122],q[118];
u1(pi/32) q[118];
u1(pi/16) q[122];
cx q[122],q[119];
u1(-pi/16) q[119];
cx q[122],q[119];
u1(pi/16) q[119];
u1(pi/8) q[122];
cx q[122],q[120];
u1(-pi/8) q[120];
cx q[122],q[120];
u1(pi/8) q[120];
u1(pi/4) q[122];
cx q[122],q[121];
u1(-pi/4) q[121];
cx q[122],q[121];
u1(pi/4) q[121];
h q[122];
u1(0) q[123];
cx q[123],q[0];
u1(0) q[0];
cx q[123],q[0];
u1(0) q[0];
u1(0) q[123];
cx q[123],q[1];
u1(0) q[1];
cx q[123],q[1];
u1(0) q[1];
u1(0) q[123];
cx q[123],q[2];
u1(0) q[2];
cx q[123],q[2];
u1(0) q[2];
u1(0) q[123];
cx q[123],q[3];
u1(0) q[3];
cx q[123],q[3];
u1(0) q[3];
u1(0) q[123];
cx q[123],q[4];
u1(0) q[4];
cx q[123],q[4];
u1(0) q[4];
u1(0) q[123];
cx q[123],q[5];
u1(0) q[5];
cx q[123],q[5];
u1(0) q[5];
u1(0) q[123];
cx q[123],q[6];
u1(0) q[6];
cx q[123],q[6];
u1(0) q[6];
u1(0) q[123];
cx q[123],q[7];
u1(0) q[7];
cx q[123],q[7];
u1(0) q[7];
u1(0) q[123];
cx q[123],q[8];
u1(0) q[8];
cx q[123],q[8];
u1(0) q[8];
u1(0) q[123];
cx q[123],q[9];
u1(0) q[9];
cx q[123],q[9];
u1(0) q[9];
u1(0) q[123];
cx q[123],q[10];
u1(0) q[10];
cx q[123],q[10];
u1(0) q[10];
u1(0) q[123];
cx q[123],q[11];
u1(0) q[11];
cx q[123],q[11];
u1(0) q[11];
u1(0) q[123];
cx q[123],q[12];
u1(0) q[12];
cx q[123],q[12];
u1(0) q[12];
u1(0) q[123];
cx q[123],q[13];
u1(0) q[13];
cx q[123],q[13];
u1(0) q[13];
u1(0) q[123];
cx q[123],q[14];
u1(0) q[14];
cx q[123],q[14];
u1(0) q[14];
u1(0) q[123];
cx q[123],q[15];
u1(0) q[15];
cx q[123],q[15];
u1(0) q[15];
u1(0) q[123];
cx q[123],q[16];
u1(0) q[16];
cx q[123],q[16];
u1(0) q[16];
u1(0) q[123];
cx q[123],q[17];
u1(0) q[17];
cx q[123],q[17];
u1(0) q[17];
u1(0) q[123];
cx q[123],q[18];
u1(0) q[18];
cx q[123],q[18];
u1(0) q[18];
u1(0) q[123];
cx q[123],q[19];
u1(0) q[19];
cx q[123],q[19];
u1(0) q[19];
u1(0) q[123];
cx q[123],q[20];
u1(0) q[20];
cx q[123],q[20];
u1(0) q[20];
u1(0) q[123];
cx q[123],q[21];
u1(0) q[21];
cx q[123],q[21];
u1(0) q[21];
u1(0) q[123];
cx q[123],q[22];
u1(0) q[22];
cx q[123],q[22];
u1(0) q[22];
u1(0) q[123];
cx q[123],q[23];
u1(0) q[23];
cx q[123],q[23];
u1(0) q[23];
u1(0) q[123];
cx q[123],q[24];
u1(0) q[24];
cx q[123],q[24];
u1(0) q[24];
u1(0) q[123];
cx q[123],q[25];
u1(0) q[25];
cx q[123],q[25];
u1(0) q[25];
u1(0) q[123];
cx q[123],q[26];
u1(0) q[26];
cx q[123],q[26];
u1(0) q[26];
u1(0) q[123];
cx q[123],q[27];
u1(0) q[27];
cx q[123],q[27];
u1(0) q[27];
u1(0) q[123];
cx q[123],q[28];
u1(0) q[28];
cx q[123],q[28];
u1(0) q[28];
u1(0) q[123];
cx q[123],q[29];
u1(0) q[29];
cx q[123],q[29];
u1(0) q[29];
u1(0) q[123];
cx q[123],q[30];
u1(0) q[30];
cx q[123],q[30];
u1(0) q[30];
u1(0) q[123];
cx q[123],q[31];
u1(0) q[31];
cx q[123],q[31];
u1(0) q[31];
u1(0) q[123];
cx q[123],q[32];
u1(0) q[32];
cx q[123],q[32];
u1(0) q[32];
u1(0) q[123];
cx q[123],q[33];
u1(0) q[33];
cx q[123],q[33];
u1(0) q[33];
u1(0) q[123];
cx q[123],q[34];
u1(0) q[34];
cx q[123],q[34];
u1(0) q[34];
u1(0) q[123];
cx q[123],q[35];
u1(0) q[35];
cx q[123],q[35];
u1(0) q[35];
u1(0) q[123];
cx q[123],q[36];
u1(0) q[36];
cx q[123],q[36];
u1(0) q[36];
u1(0) q[123];
cx q[123],q[37];
u1(0) q[37];
cx q[123],q[37];
u1(0) q[37];
u1(0) q[123];
cx q[123],q[38];
u1(0) q[38];
cx q[123],q[38];
u1(0) q[38];
u1(0) q[123];
cx q[123],q[39];
u1(0) q[39];
cx q[123],q[39];
u1(0) q[39];
u1(0) q[123];
cx q[123],q[40];
u1(0) q[40];
cx q[123],q[40];
u1(0) q[40];
u1(0) q[123];
cx q[123],q[41];
u1(0) q[41];
cx q[123],q[41];
u1(0) q[41];
u1(0) q[123];
cx q[123],q[42];
u1(0) q[42];
cx q[123],q[42];
u1(0) q[42];
u1(0) q[123];
cx q[123],q[43];
u1(0) q[43];
cx q[123],q[43];
u1(0) q[43];
u1(0) q[123];
cx q[123],q[44];
u1(0) q[44];
cx q[123],q[44];
u1(0) q[44];
u1(0) q[123];
cx q[123],q[45];
u1(0) q[45];
cx q[123],q[45];
u1(0) q[45];
u1(0) q[123];
cx q[123],q[46];
u1(0) q[46];
cx q[123],q[46];
u1(0) q[46];
u1(0) q[123];
cx q[123],q[47];
u1(0) q[47];
cx q[123],q[47];
u1(0) q[47];
u1(0) q[123];
cx q[123],q[48];
u1(0) q[48];
cx q[123],q[48];
u1(0) q[48];
u1(0) q[123];
cx q[123],q[49];
u1(0) q[49];
cx q[123],q[49];
u1(0) q[49];
u1(0) q[123];
cx q[123],q[50];
u1(0) q[50];
cx q[123],q[50];
u1(0) q[50];
u1(0) q[123];
cx q[123],q[51];
u1(0) q[51];
cx q[123],q[51];
u1(0) q[51];
u1(0) q[123];
cx q[123],q[52];
u1(0) q[52];
cx q[123],q[52];
u1(0) q[52];
u1(0) q[123];
cx q[123],q[53];
u1(0) q[53];
cx q[123],q[53];
u1(0) q[53];
u1(0) q[123];
cx q[123],q[54];
u1(0) q[54];
cx q[123],q[54];
u1(0) q[54];
u1(0) q[123];
cx q[123],q[55];
u1(0) q[55];
cx q[123],q[55];
u1(0) q[55];
u1(0) q[123];
cx q[123],q[56];
u1(0) q[56];
cx q[123],q[56];
u1(0) q[56];
u1(0) q[123];
cx q[123],q[57];
u1(0) q[57];
cx q[123],q[57];
u1(0) q[57];
u1(0) q[123];
cx q[123],q[58];
u1(0) q[58];
cx q[123],q[58];
u1(0) q[58];
u1(0) q[123];
cx q[123],q[59];
u1(0) q[59];
cx q[123],q[59];
u1(0) q[59];
u1(0) q[123];
cx q[123],q[60];
u1(0) q[60];
cx q[123],q[60];
u1(0) q[60];
u1(0) q[123];
cx q[123],q[61];
u1(0) q[61];
cx q[123],q[61];
u1(0) q[61];
u1(0) q[123];
cx q[123],q[62];
u1(0) q[62];
cx q[123],q[62];
u1(0) q[62];
u1(0) q[123];
cx q[123],q[63];
u1(0) q[63];
cx q[123],q[63];
u1(0) q[63];
u1(0) q[123];
cx q[123],q[64];
u1(0) q[64];
cx q[123],q[64];
u1(0) q[64];
u1(0) q[123];
cx q[123],q[65];
u1(0) q[65];
cx q[123],q[65];
u1(0) q[65];
u1(0) q[123];
cx q[123],q[66];
u1(0) q[66];
cx q[123],q[66];
u1(0) q[66];
u1(0) q[123];
cx q[123],q[67];
u1(0) q[67];
cx q[123],q[67];
u1(0) q[67];
u1(0) q[123];
cx q[123],q[68];
u1(0) q[68];
cx q[123],q[68];
u1(0) q[68];
u1(0) q[123];
cx q[123],q[69];
u1(0) q[69];
cx q[123],q[69];
u1(0) q[69];
u1(0) q[123];
cx q[123],q[70];
u1(0) q[70];
cx q[123],q[70];
u1(0) q[70];
u1(0) q[123];
cx q[123],q[71];
u1(0) q[71];
cx q[123],q[71];
u1(0) q[71];
u1(0) q[123];
cx q[123],q[72];
u1(0) q[72];
cx q[123],q[72];
u1(0) q[72];
u1(0) q[123];
cx q[123],q[73];
u1(0) q[73];
cx q[123],q[73];
u1(0) q[73];
u1(0) q[123];
cx q[123],q[74];
u1(0) q[74];
cx q[123],q[74];
u1(0) q[74];
u1(0) q[123];
cx q[123],q[75];
u1(0) q[75];
cx q[123],q[75];
u1(0) q[75];
u1(pi/281474976710656) q[123];
cx q[123],q[76];
u1(-pi/281474976710656) q[76];
cx q[123],q[76];
u1(pi/281474976710656) q[76];
u1(pi/140737488355328) q[123];
cx q[123],q[77];
u1(-pi/140737488355328) q[77];
cx q[123],q[77];
u1(pi/140737488355328) q[77];
u1(pi/70368744177664) q[123];
cx q[123],q[78];
u1(-pi/70368744177664) q[78];
cx q[123],q[78];
u1(pi/70368744177664) q[78];
u1(pi/35184372088832) q[123];
cx q[123],q[79];
u1(-pi/35184372088832) q[79];
cx q[123],q[79];
u1(pi/35184372088832) q[79];
u1(pi/17592186044416) q[123];
cx q[123],q[80];
u1(-pi/17592186044416) q[80];
cx q[123],q[80];
u1(pi/17592186044416) q[80];
u1(pi/8796093022208) q[123];
cx q[123],q[81];
u1(-pi/8796093022208) q[81];
cx q[123],q[81];
u1(pi/8796093022208) q[81];
u1(pi/4398046511104) q[123];
cx q[123],q[82];
u1(-pi/4398046511104) q[82];
cx q[123],q[82];
u1(pi/4398046511104) q[82];
u1(pi/2199023255552) q[123];
cx q[123],q[83];
u1(-pi/2199023255552) q[83];
cx q[123],q[83];
u1(pi/2199023255552) q[83];
u1(pi/1099511627776) q[123];
cx q[123],q[84];
u1(-pi/1099511627776) q[84];
cx q[123],q[84];
u1(pi/1099511627776) q[84];
u1(pi/549755813888) q[123];
cx q[123],q[85];
u1(-pi/549755813888) q[85];
cx q[123],q[85];
u1(pi/549755813888) q[85];
u1(pi/274877906944) q[123];
cx q[123],q[86];
u1(-pi/274877906944) q[86];
cx q[123],q[86];
u1(pi/274877906944) q[86];
u1(pi/137438953472) q[123];
cx q[123],q[87];
u1(-pi/137438953472) q[87];
cx q[123],q[87];
u1(pi/137438953472) q[87];
u1(pi/68719476736) q[123];
cx q[123],q[88];
u1(-pi/68719476736) q[88];
cx q[123],q[88];
u1(pi/68719476736) q[88];
u1(pi/34359738368) q[123];
cx q[123],q[89];
u1(-pi/34359738368) q[89];
cx q[123],q[89];
u1(pi/34359738368) q[89];
u1(pi/17179869184) q[123];
cx q[123],q[90];
u1(-pi/17179869184) q[90];
cx q[123],q[90];
u1(pi/17179869184) q[90];
u1(pi/8589934592) q[123];
cx q[123],q[91];
u1(-pi/8589934592) q[91];
cx q[123],q[91];
u1(pi/8589934592) q[91];
u1(pi/4294967296) q[123];
cx q[123],q[92];
u1(-pi/4294967296) q[92];
cx q[123],q[92];
u1(pi/4294967296) q[92];
u1(pi/2147483648) q[123];
cx q[123],q[93];
u1(-pi/2147483648) q[93];
cx q[123],q[93];
u1(pi/2147483648) q[93];
u1(pi/1073741824) q[123];
cx q[123],q[94];
u1(-pi/1073741824) q[94];
cx q[123],q[94];
u1(pi/1073741824) q[94];
u1(pi/536870912) q[123];
cx q[123],q[95];
u1(-pi/536870912) q[95];
cx q[123],q[95];
u1(pi/536870912) q[95];
u1(pi/268435456) q[123];
cx q[123],q[96];
u1(-pi/268435456) q[96];
cx q[123],q[96];
u1(pi/268435456) q[96];
u1(pi/134217728) q[123];
cx q[123],q[97];
u1(-pi/134217728) q[97];
cx q[123],q[97];
u1(pi/134217728) q[97];
u1(pi/67108864) q[123];
cx q[123],q[98];
u1(-pi/67108864) q[98];
cx q[123],q[98];
u1(pi/67108864) q[98];
u1(pi/33554432) q[123];
cx q[123],q[99];
u1(-pi/33554432) q[99];
cx q[123],q[99];
u1(pi/33554432) q[99];
u1(pi/16777216) q[123];
cx q[123],q[100];
u1(-pi/16777216) q[100];
cx q[123],q[100];
u1(pi/16777216) q[100];
u1(pi/8388608) q[123];
cx q[123],q[101];
u1(-pi/8388608) q[101];
cx q[123],q[101];
u1(pi/8388608) q[101];
u1(pi/4194304) q[123];
cx q[123],q[102];
u1(-pi/4194304) q[102];
cx q[123],q[102];
u1(pi/4194304) q[102];
u1(pi/2097152) q[123];
cx q[123],q[103];
u1(-pi/2097152) q[103];
cx q[123],q[103];
u1(pi/2097152) q[103];
u1(pi/1048576) q[123];
cx q[123],q[104];
u1(-pi/1048576) q[104];
cx q[123],q[104];
u1(pi/1048576) q[104];
u1(pi/524288) q[123];
cx q[123],q[105];
u1(-pi/524288) q[105];
cx q[123],q[105];
u1(pi/524288) q[105];
u1(pi/262144) q[123];
cx q[123],q[106];
u1(-pi/262144) q[106];
cx q[123],q[106];
u1(pi/262144) q[106];
u1(pi/131072) q[123];
cx q[123],q[107];
u1(-pi/131072) q[107];
cx q[123],q[107];
u1(pi/131072) q[107];
u1(pi/65536) q[123];
cx q[123],q[108];
u1(-pi/65536) q[108];
cx q[123],q[108];
u1(pi/65536) q[108];
u1(pi/32768) q[123];
cx q[123],q[109];
u1(-pi/32768) q[109];
cx q[123],q[109];
u1(pi/32768) q[109];
u1(pi/16384) q[123];
cx q[123],q[110];
u1(-pi/16384) q[110];
cx q[123],q[110];
u1(pi/16384) q[110];
u1(pi/8192) q[123];
cx q[123],q[111];
u1(-pi/8192) q[111];
cx q[123],q[111];
u1(pi/8192) q[111];
u1(pi/4096) q[123];
cx q[123],q[112];
u1(-pi/4096) q[112];
cx q[123],q[112];
u1(pi/4096) q[112];
u1(pi/2048) q[123];
cx q[123],q[113];
u1(-pi/2048) q[113];
cx q[123],q[113];
u1(pi/2048) q[113];
u1(pi/1024) q[123];
cx q[123],q[114];
u1(-pi/1024) q[114];
cx q[123],q[114];
u1(pi/1024) q[114];
u1(pi/512) q[123];
cx q[123],q[115];
u1(-pi/512) q[115];
cx q[123],q[115];
u1(pi/512) q[115];
u1(pi/256) q[123];
cx q[123],q[116];
u1(-pi/256) q[116];
cx q[123],q[116];
u1(pi/256) q[116];
u1(pi/128) q[123];
cx q[123],q[117];
u1(-pi/128) q[117];
cx q[123],q[117];
u1(pi/128) q[117];
u1(pi/64) q[123];
cx q[123],q[118];
u1(-pi/64) q[118];
cx q[123],q[118];
u1(pi/64) q[118];
u1(pi/32) q[123];
cx q[123],q[119];
u1(-pi/32) q[119];
cx q[123],q[119];
u1(pi/32) q[119];
u1(pi/16) q[123];
cx q[123],q[120];
u1(-pi/16) q[120];
cx q[123],q[120];
u1(pi/16) q[120];
u1(pi/8) q[123];
cx q[123],q[121];
u1(-pi/8) q[121];
cx q[123],q[121];
u1(pi/8) q[121];
u1(pi/4) q[123];
cx q[123],q[122];
u1(-pi/4) q[122];
cx q[123],q[122];
u1(pi/4) q[122];
h q[123];
u1(0) q[124];
cx q[124],q[0];
u1(0) q[0];
cx q[124],q[0];
u1(0) q[0];
u1(0) q[124];
cx q[124],q[1];
u1(0) q[1];
cx q[124],q[1];
u1(0) q[1];
u1(0) q[124];
cx q[124],q[2];
u1(0) q[2];
cx q[124],q[2];
u1(0) q[2];
u1(0) q[124];
cx q[124],q[3];
u1(0) q[3];
cx q[124],q[3];
u1(0) q[3];
u1(0) q[124];
cx q[124],q[4];
u1(0) q[4];
cx q[124],q[4];
u1(0) q[4];
u1(0) q[124];
cx q[124],q[5];
u1(0) q[5];
cx q[124],q[5];
u1(0) q[5];
u1(0) q[124];
cx q[124],q[6];
u1(0) q[6];
cx q[124],q[6];
u1(0) q[6];
u1(0) q[124];
cx q[124],q[7];
u1(0) q[7];
cx q[124],q[7];
u1(0) q[7];
u1(0) q[124];
cx q[124],q[8];
u1(0) q[8];
cx q[124],q[8];
u1(0) q[8];
u1(0) q[124];
cx q[124],q[9];
u1(0) q[9];
cx q[124],q[9];
u1(0) q[9];
u1(0) q[124];
cx q[124],q[10];
u1(0) q[10];
cx q[124],q[10];
u1(0) q[10];
u1(0) q[124];
cx q[124],q[11];
u1(0) q[11];
cx q[124],q[11];
u1(0) q[11];
u1(0) q[124];
cx q[124],q[12];
u1(0) q[12];
cx q[124],q[12];
u1(0) q[12];
u1(0) q[124];
cx q[124],q[13];
u1(0) q[13];
cx q[124],q[13];
u1(0) q[13];
u1(0) q[124];
cx q[124],q[14];
u1(0) q[14];
cx q[124],q[14];
u1(0) q[14];
u1(0) q[124];
cx q[124],q[15];
u1(0) q[15];
cx q[124],q[15];
u1(0) q[15];
u1(0) q[124];
cx q[124],q[16];
u1(0) q[16];
cx q[124],q[16];
u1(0) q[16];
u1(0) q[124];
cx q[124],q[17];
u1(0) q[17];
cx q[124],q[17];
u1(0) q[17];
u1(0) q[124];
cx q[124],q[18];
u1(0) q[18];
cx q[124],q[18];
u1(0) q[18];
u1(0) q[124];
cx q[124],q[19];
u1(0) q[19];
cx q[124],q[19];
u1(0) q[19];
u1(0) q[124];
cx q[124],q[20];
u1(0) q[20];
cx q[124],q[20];
u1(0) q[20];
u1(0) q[124];
cx q[124],q[21];
u1(0) q[21];
cx q[124],q[21];
u1(0) q[21];
u1(0) q[124];
cx q[124],q[22];
u1(0) q[22];
cx q[124],q[22];
u1(0) q[22];
u1(0) q[124];
cx q[124],q[23];
u1(0) q[23];
cx q[124],q[23];
u1(0) q[23];
u1(0) q[124];
cx q[124],q[24];
u1(0) q[24];
cx q[124],q[24];
u1(0) q[24];
u1(0) q[124];
cx q[124],q[25];
u1(0) q[25];
cx q[124],q[25];
u1(0) q[25];
u1(0) q[124];
cx q[124],q[26];
u1(0) q[26];
cx q[124],q[26];
u1(0) q[26];
u1(0) q[124];
cx q[124],q[27];
u1(0) q[27];
cx q[124],q[27];
u1(0) q[27];
u1(0) q[124];
cx q[124],q[28];
u1(0) q[28];
cx q[124],q[28];
u1(0) q[28];
u1(0) q[124];
cx q[124],q[29];
u1(0) q[29];
cx q[124],q[29];
u1(0) q[29];
u1(0) q[124];
cx q[124],q[30];
u1(0) q[30];
cx q[124],q[30];
u1(0) q[30];
u1(0) q[124];
cx q[124],q[31];
u1(0) q[31];
cx q[124],q[31];
u1(0) q[31];
u1(0) q[124];
cx q[124],q[32];
u1(0) q[32];
cx q[124],q[32];
u1(0) q[32];
u1(0) q[124];
cx q[124],q[33];
u1(0) q[33];
cx q[124],q[33];
u1(0) q[33];
u1(0) q[124];
cx q[124],q[34];
u1(0) q[34];
cx q[124],q[34];
u1(0) q[34];
u1(0) q[124];
cx q[124],q[35];
u1(0) q[35];
cx q[124],q[35];
u1(0) q[35];
u1(0) q[124];
cx q[124],q[36];
u1(0) q[36];
cx q[124],q[36];
u1(0) q[36];
u1(0) q[124];
cx q[124],q[37];
u1(0) q[37];
cx q[124],q[37];
u1(0) q[37];
u1(0) q[124];
cx q[124],q[38];
u1(0) q[38];
cx q[124],q[38];
u1(0) q[38];
u1(0) q[124];
cx q[124],q[39];
u1(0) q[39];
cx q[124],q[39];
u1(0) q[39];
u1(0) q[124];
cx q[124],q[40];
u1(0) q[40];
cx q[124],q[40];
u1(0) q[40];
u1(0) q[124];
cx q[124],q[41];
u1(0) q[41];
cx q[124],q[41];
u1(0) q[41];
u1(0) q[124];
cx q[124],q[42];
u1(0) q[42];
cx q[124],q[42];
u1(0) q[42];
u1(0) q[124];
cx q[124],q[43];
u1(0) q[43];
cx q[124],q[43];
u1(0) q[43];
u1(0) q[124];
cx q[124],q[44];
u1(0) q[44];
cx q[124],q[44];
u1(0) q[44];
u1(0) q[124];
cx q[124],q[45];
u1(0) q[45];
cx q[124],q[45];
u1(0) q[45];
u1(0) q[124];
cx q[124],q[46];
u1(0) q[46];
cx q[124],q[46];
u1(0) q[46];
u1(0) q[124];
cx q[124],q[47];
u1(0) q[47];
cx q[124],q[47];
u1(0) q[47];
u1(0) q[124];
cx q[124],q[48];
u1(0) q[48];
cx q[124],q[48];
u1(0) q[48];
u1(0) q[124];
cx q[124],q[49];
u1(0) q[49];
cx q[124],q[49];
u1(0) q[49];
u1(0) q[124];
cx q[124],q[50];
u1(0) q[50];
cx q[124],q[50];
u1(0) q[50];
u1(0) q[124];
cx q[124],q[51];
u1(0) q[51];
cx q[124],q[51];
u1(0) q[51];
u1(0) q[124];
cx q[124],q[52];
u1(0) q[52];
cx q[124],q[52];
u1(0) q[52];
u1(0) q[124];
cx q[124],q[53];
u1(0) q[53];
cx q[124],q[53];
u1(0) q[53];
u1(0) q[124];
cx q[124],q[54];
u1(0) q[54];
cx q[124],q[54];
u1(0) q[54];
u1(0) q[124];
cx q[124],q[55];
u1(0) q[55];
cx q[124],q[55];
u1(0) q[55];
u1(0) q[124];
cx q[124],q[56];
u1(0) q[56];
cx q[124],q[56];
u1(0) q[56];
u1(0) q[124];
cx q[124],q[57];
u1(0) q[57];
cx q[124],q[57];
u1(0) q[57];
u1(0) q[124];
cx q[124],q[58];
u1(0) q[58];
cx q[124],q[58];
u1(0) q[58];
u1(0) q[124];
cx q[124],q[59];
u1(0) q[59];
cx q[124],q[59];
u1(0) q[59];
u1(0) q[124];
cx q[124],q[60];
u1(0) q[60];
cx q[124],q[60];
u1(0) q[60];
u1(0) q[124];
cx q[124],q[61];
u1(0) q[61];
cx q[124],q[61];
u1(0) q[61];
u1(0) q[124];
cx q[124],q[62];
u1(0) q[62];
cx q[124],q[62];
u1(0) q[62];
u1(0) q[124];
cx q[124],q[63];
u1(0) q[63];
cx q[124],q[63];
u1(0) q[63];
u1(0) q[124];
cx q[124],q[64];
u1(0) q[64];
cx q[124],q[64];
u1(0) q[64];
u1(0) q[124];
cx q[124],q[65];
u1(0) q[65];
cx q[124],q[65];
u1(0) q[65];
u1(0) q[124];
cx q[124],q[66];
u1(0) q[66];
cx q[124],q[66];
u1(0) q[66];
u1(0) q[124];
cx q[124],q[67];
u1(0) q[67];
cx q[124],q[67];
u1(0) q[67];
u1(0) q[124];
cx q[124],q[68];
u1(0) q[68];
cx q[124],q[68];
u1(0) q[68];
u1(0) q[124];
cx q[124],q[69];
u1(0) q[69];
cx q[124],q[69];
u1(0) q[69];
u1(0) q[124];
cx q[124],q[70];
u1(0) q[70];
cx q[124],q[70];
u1(0) q[70];
u1(0) q[124];
cx q[124],q[71];
u1(0) q[71];
cx q[124],q[71];
u1(0) q[71];
u1(0) q[124];
cx q[124],q[72];
u1(0) q[72];
cx q[124],q[72];
u1(0) q[72];
u1(0) q[124];
cx q[124],q[73];
u1(0) q[73];
cx q[124],q[73];
u1(0) q[73];
u1(0) q[124];
cx q[124],q[74];
u1(0) q[74];
cx q[124],q[74];
u1(0) q[74];
u1(0) q[124];
cx q[124],q[75];
u1(0) q[75];
cx q[124],q[75];
u1(0) q[75];
u1(0) q[124];
cx q[124],q[76];
u1(0) q[76];
cx q[124],q[76];
u1(0) q[76];
u1(pi/281474976710656) q[124];
cx q[124],q[77];
u1(-pi/281474976710656) q[77];
cx q[124],q[77];
u1(pi/281474976710656) q[77];
u1(pi/140737488355328) q[124];
cx q[124],q[78];
u1(-pi/140737488355328) q[78];
cx q[124],q[78];
u1(pi/140737488355328) q[78];
u1(pi/70368744177664) q[124];
cx q[124],q[79];
u1(-pi/70368744177664) q[79];
cx q[124],q[79];
u1(pi/70368744177664) q[79];
u1(pi/35184372088832) q[124];
cx q[124],q[80];
u1(-pi/35184372088832) q[80];
cx q[124],q[80];
u1(pi/35184372088832) q[80];
u1(pi/17592186044416) q[124];
cx q[124],q[81];
u1(-pi/17592186044416) q[81];
cx q[124],q[81];
u1(pi/17592186044416) q[81];
u1(pi/8796093022208) q[124];
cx q[124],q[82];
u1(-pi/8796093022208) q[82];
cx q[124],q[82];
u1(pi/8796093022208) q[82];
u1(pi/4398046511104) q[124];
cx q[124],q[83];
u1(-pi/4398046511104) q[83];
cx q[124],q[83];
u1(pi/4398046511104) q[83];
u1(pi/2199023255552) q[124];
cx q[124],q[84];
u1(-pi/2199023255552) q[84];
cx q[124],q[84];
u1(pi/2199023255552) q[84];
u1(pi/1099511627776) q[124];
cx q[124],q[85];
u1(-pi/1099511627776) q[85];
cx q[124],q[85];
u1(pi/1099511627776) q[85];
u1(pi/549755813888) q[124];
cx q[124],q[86];
u1(-pi/549755813888) q[86];
cx q[124],q[86];
u1(pi/549755813888) q[86];
u1(pi/274877906944) q[124];
cx q[124],q[87];
u1(-pi/274877906944) q[87];
cx q[124],q[87];
u1(pi/274877906944) q[87];
u1(pi/137438953472) q[124];
cx q[124],q[88];
u1(-pi/137438953472) q[88];
cx q[124],q[88];
u1(pi/137438953472) q[88];
u1(pi/68719476736) q[124];
cx q[124],q[89];
u1(-pi/68719476736) q[89];
cx q[124],q[89];
u1(pi/68719476736) q[89];
u1(pi/34359738368) q[124];
cx q[124],q[90];
u1(-pi/34359738368) q[90];
cx q[124],q[90];
u1(pi/34359738368) q[90];
u1(pi/17179869184) q[124];
cx q[124],q[91];
u1(-pi/17179869184) q[91];
cx q[124],q[91];
u1(pi/17179869184) q[91];
u1(pi/8589934592) q[124];
cx q[124],q[92];
u1(-pi/8589934592) q[92];
cx q[124],q[92];
u1(pi/8589934592) q[92];
u1(pi/4294967296) q[124];
cx q[124],q[93];
u1(-pi/4294967296) q[93];
cx q[124],q[93];
u1(pi/4294967296) q[93];
u1(pi/2147483648) q[124];
cx q[124],q[94];
u1(-pi/2147483648) q[94];
cx q[124],q[94];
u1(pi/2147483648) q[94];
u1(pi/1073741824) q[124];
cx q[124],q[95];
u1(-pi/1073741824) q[95];
cx q[124],q[95];
u1(pi/1073741824) q[95];
u1(pi/536870912) q[124];
cx q[124],q[96];
u1(-pi/536870912) q[96];
cx q[124],q[96];
u1(pi/536870912) q[96];
u1(pi/268435456) q[124];
cx q[124],q[97];
u1(-pi/268435456) q[97];
cx q[124],q[97];
u1(pi/268435456) q[97];
u1(pi/134217728) q[124];
cx q[124],q[98];
u1(-pi/134217728) q[98];
cx q[124],q[98];
u1(pi/134217728) q[98];
u1(pi/67108864) q[124];
cx q[124],q[99];
u1(-pi/67108864) q[99];
cx q[124],q[99];
u1(pi/67108864) q[99];
u1(pi/33554432) q[124];
cx q[124],q[100];
u1(-pi/33554432) q[100];
cx q[124],q[100];
u1(pi/33554432) q[100];
u1(pi/16777216) q[124];
cx q[124],q[101];
u1(-pi/16777216) q[101];
cx q[124],q[101];
u1(pi/16777216) q[101];
u1(pi/8388608) q[124];
cx q[124],q[102];
u1(-pi/8388608) q[102];
cx q[124],q[102];
u1(pi/8388608) q[102];
u1(pi/4194304) q[124];
cx q[124],q[103];
u1(-pi/4194304) q[103];
cx q[124],q[103];
u1(pi/4194304) q[103];
u1(pi/2097152) q[124];
cx q[124],q[104];
u1(-pi/2097152) q[104];
cx q[124],q[104];
u1(pi/2097152) q[104];
u1(pi/1048576) q[124];
cx q[124],q[105];
u1(-pi/1048576) q[105];
cx q[124],q[105];
u1(pi/1048576) q[105];
u1(pi/524288) q[124];
cx q[124],q[106];
u1(-pi/524288) q[106];
cx q[124],q[106];
u1(pi/524288) q[106];
u1(pi/262144) q[124];
cx q[124],q[107];
u1(-pi/262144) q[107];
cx q[124],q[107];
u1(pi/262144) q[107];
u1(pi/131072) q[124];
cx q[124],q[108];
u1(-pi/131072) q[108];
cx q[124],q[108];
u1(pi/131072) q[108];
u1(pi/65536) q[124];
cx q[124],q[109];
u1(-pi/65536) q[109];
cx q[124],q[109];
u1(pi/65536) q[109];
u1(pi/32768) q[124];
cx q[124],q[110];
u1(-pi/32768) q[110];
cx q[124],q[110];
u1(pi/32768) q[110];
u1(pi/16384) q[124];
cx q[124],q[111];
u1(-pi/16384) q[111];
cx q[124],q[111];
u1(pi/16384) q[111];
u1(pi/8192) q[124];
cx q[124],q[112];
u1(-pi/8192) q[112];
cx q[124],q[112];
u1(pi/8192) q[112];
u1(pi/4096) q[124];
cx q[124],q[113];
u1(-pi/4096) q[113];
cx q[124],q[113];
u1(pi/4096) q[113];
u1(pi/2048) q[124];
cx q[124],q[114];
u1(-pi/2048) q[114];
cx q[124],q[114];
u1(pi/2048) q[114];
u1(pi/1024) q[124];
cx q[124],q[115];
u1(-pi/1024) q[115];
cx q[124],q[115];
u1(pi/1024) q[115];
u1(pi/512) q[124];
cx q[124],q[116];
u1(-pi/512) q[116];
cx q[124],q[116];
u1(pi/512) q[116];
u1(pi/256) q[124];
cx q[124],q[117];
u1(-pi/256) q[117];
cx q[124],q[117];
u1(pi/256) q[117];
u1(pi/128) q[124];
cx q[124],q[118];
u1(-pi/128) q[118];
cx q[124],q[118];
u1(pi/128) q[118];
u1(pi/64) q[124];
cx q[124],q[119];
u1(-pi/64) q[119];
cx q[124],q[119];
u1(pi/64) q[119];
u1(pi/32) q[124];
cx q[124],q[120];
u1(-pi/32) q[120];
cx q[124],q[120];
u1(pi/32) q[120];
u1(pi/16) q[124];
cx q[124],q[121];
u1(-pi/16) q[121];
cx q[124],q[121];
u1(pi/16) q[121];
u1(pi/8) q[124];
cx q[124],q[122];
u1(-pi/8) q[122];
cx q[124],q[122];
u1(pi/8) q[122];
u1(pi/4) q[124];
cx q[124],q[123];
u1(-pi/4) q[123];
cx q[124],q[123];
u1(pi/4) q[123];
h q[124];
u1(0) q[125];
cx q[125],q[0];
u1(0) q[0];
cx q[125],q[0];
u1(0) q[0];
u1(0) q[125];
cx q[125],q[1];
u1(0) q[1];
cx q[125],q[1];
u1(0) q[1];
u1(0) q[125];
cx q[125],q[2];
u1(0) q[2];
cx q[125],q[2];
u1(0) q[2];
u1(0) q[125];
cx q[125],q[3];
u1(0) q[3];
cx q[125],q[3];
u1(0) q[3];
u1(0) q[125];
cx q[125],q[4];
u1(0) q[4];
cx q[125],q[4];
u1(0) q[4];
u1(0) q[125];
cx q[125],q[5];
u1(0) q[5];
cx q[125],q[5];
u1(0) q[5];
u1(0) q[125];
cx q[125],q[6];
u1(0) q[6];
cx q[125],q[6];
u1(0) q[6];
u1(0) q[125];
cx q[125],q[7];
u1(0) q[7];
cx q[125],q[7];
u1(0) q[7];
u1(0) q[125];
cx q[125],q[8];
u1(0) q[8];
cx q[125],q[8];
u1(0) q[8];
u1(0) q[125];
cx q[125],q[9];
u1(0) q[9];
cx q[125],q[9];
u1(0) q[9];
u1(0) q[125];
cx q[125],q[10];
u1(0) q[10];
cx q[125],q[10];
u1(0) q[10];
u1(0) q[125];
cx q[125],q[11];
u1(0) q[11];
cx q[125],q[11];
u1(0) q[11];
u1(0) q[125];
cx q[125],q[12];
u1(0) q[12];
cx q[125],q[12];
u1(0) q[12];
u1(0) q[125];
cx q[125],q[13];
u1(0) q[13];
cx q[125],q[13];
u1(0) q[13];
u1(0) q[125];
cx q[125],q[14];
u1(0) q[14];
cx q[125],q[14];
u1(0) q[14];
u1(0) q[125];
cx q[125],q[15];
u1(0) q[15];
cx q[125],q[15];
u1(0) q[15];
u1(0) q[125];
cx q[125],q[16];
u1(0) q[16];
cx q[125],q[16];
u1(0) q[16];
u1(0) q[125];
cx q[125],q[17];
u1(0) q[17];
cx q[125],q[17];
u1(0) q[17];
u1(0) q[125];
cx q[125],q[18];
u1(0) q[18];
cx q[125],q[18];
u1(0) q[18];
u1(0) q[125];
cx q[125],q[19];
u1(0) q[19];
cx q[125],q[19];
u1(0) q[19];
u1(0) q[125];
cx q[125],q[20];
u1(0) q[20];
cx q[125],q[20];
u1(0) q[20];
u1(0) q[125];
cx q[125],q[21];
u1(0) q[21];
cx q[125],q[21];
u1(0) q[21];
u1(0) q[125];
cx q[125],q[22];
u1(0) q[22];
cx q[125],q[22];
u1(0) q[22];
u1(0) q[125];
cx q[125],q[23];
u1(0) q[23];
cx q[125],q[23];
u1(0) q[23];
u1(0) q[125];
cx q[125],q[24];
u1(0) q[24];
cx q[125],q[24];
u1(0) q[24];
u1(0) q[125];
cx q[125],q[25];
u1(0) q[25];
cx q[125],q[25];
u1(0) q[25];
u1(0) q[125];
cx q[125],q[26];
u1(0) q[26];
cx q[125],q[26];
u1(0) q[26];
u1(0) q[125];
cx q[125],q[27];
u1(0) q[27];
cx q[125],q[27];
u1(0) q[27];
u1(0) q[125];
cx q[125],q[28];
u1(0) q[28];
cx q[125],q[28];
u1(0) q[28];
u1(0) q[125];
cx q[125],q[29];
u1(0) q[29];
cx q[125],q[29];
u1(0) q[29];
u1(0) q[125];
cx q[125],q[30];
u1(0) q[30];
cx q[125],q[30];
u1(0) q[30];
u1(0) q[125];
cx q[125],q[31];
u1(0) q[31];
cx q[125],q[31];
u1(0) q[31];
u1(0) q[125];
cx q[125],q[32];
u1(0) q[32];
cx q[125],q[32];
u1(0) q[32];
u1(0) q[125];
cx q[125],q[33];
u1(0) q[33];
cx q[125],q[33];
u1(0) q[33];
u1(0) q[125];
cx q[125],q[34];
u1(0) q[34];
cx q[125],q[34];
u1(0) q[34];
u1(0) q[125];
cx q[125],q[35];
u1(0) q[35];
cx q[125],q[35];
u1(0) q[35];
u1(0) q[125];
cx q[125],q[36];
u1(0) q[36];
cx q[125],q[36];
u1(0) q[36];
u1(0) q[125];
cx q[125],q[37];
u1(0) q[37];
cx q[125],q[37];
u1(0) q[37];
u1(0) q[125];
cx q[125],q[38];
u1(0) q[38];
cx q[125],q[38];
u1(0) q[38];
u1(0) q[125];
cx q[125],q[39];
u1(0) q[39];
cx q[125],q[39];
u1(0) q[39];
u1(0) q[125];
cx q[125],q[40];
u1(0) q[40];
cx q[125],q[40];
u1(0) q[40];
u1(0) q[125];
cx q[125],q[41];
u1(0) q[41];
cx q[125],q[41];
u1(0) q[41];
u1(0) q[125];
cx q[125],q[42];
u1(0) q[42];
cx q[125],q[42];
u1(0) q[42];
u1(0) q[125];
cx q[125],q[43];
u1(0) q[43];
cx q[125],q[43];
u1(0) q[43];
u1(0) q[125];
cx q[125],q[44];
u1(0) q[44];
cx q[125],q[44];
u1(0) q[44];
u1(0) q[125];
cx q[125],q[45];
u1(0) q[45];
cx q[125],q[45];
u1(0) q[45];
u1(0) q[125];
cx q[125],q[46];
u1(0) q[46];
cx q[125],q[46];
u1(0) q[46];
u1(0) q[125];
cx q[125],q[47];
u1(0) q[47];
cx q[125],q[47];
u1(0) q[47];
u1(0) q[125];
cx q[125],q[48];
u1(0) q[48];
cx q[125],q[48];
u1(0) q[48];
u1(0) q[125];
cx q[125],q[49];
u1(0) q[49];
cx q[125],q[49];
u1(0) q[49];
u1(0) q[125];
cx q[125],q[50];
u1(0) q[50];
cx q[125],q[50];
u1(0) q[50];
u1(0) q[125];
cx q[125],q[51];
u1(0) q[51];
cx q[125],q[51];
u1(0) q[51];
u1(0) q[125];
cx q[125],q[52];
u1(0) q[52];
cx q[125],q[52];
u1(0) q[52];
u1(0) q[125];
cx q[125],q[53];
u1(0) q[53];
cx q[125],q[53];
u1(0) q[53];
u1(0) q[125];
cx q[125],q[54];
u1(0) q[54];
cx q[125],q[54];
u1(0) q[54];
u1(0) q[125];
cx q[125],q[55];
u1(0) q[55];
cx q[125],q[55];
u1(0) q[55];
u1(0) q[125];
cx q[125],q[56];
u1(0) q[56];
cx q[125],q[56];
u1(0) q[56];
u1(0) q[125];
cx q[125],q[57];
u1(0) q[57];
cx q[125],q[57];
u1(0) q[57];
u1(0) q[125];
cx q[125],q[58];
u1(0) q[58];
cx q[125],q[58];
u1(0) q[58];
u1(0) q[125];
cx q[125],q[59];
u1(0) q[59];
cx q[125],q[59];
u1(0) q[59];
u1(0) q[125];
cx q[125],q[60];
u1(0) q[60];
cx q[125],q[60];
u1(0) q[60];
u1(0) q[125];
cx q[125],q[61];
u1(0) q[61];
cx q[125],q[61];
u1(0) q[61];
u1(0) q[125];
cx q[125],q[62];
u1(0) q[62];
cx q[125],q[62];
u1(0) q[62];
u1(0) q[125];
cx q[125],q[63];
u1(0) q[63];
cx q[125],q[63];
u1(0) q[63];
u1(0) q[125];
cx q[125],q[64];
u1(0) q[64];
cx q[125],q[64];
u1(0) q[64];
u1(0) q[125];
cx q[125],q[65];
u1(0) q[65];
cx q[125],q[65];
u1(0) q[65];
u1(0) q[125];
cx q[125],q[66];
u1(0) q[66];
cx q[125],q[66];
u1(0) q[66];
u1(0) q[125];
cx q[125],q[67];
u1(0) q[67];
cx q[125],q[67];
u1(0) q[67];
u1(0) q[125];
cx q[125],q[68];
u1(0) q[68];
cx q[125],q[68];
u1(0) q[68];
u1(0) q[125];
cx q[125],q[69];
u1(0) q[69];
cx q[125],q[69];
u1(0) q[69];
u1(0) q[125];
cx q[125],q[70];
u1(0) q[70];
cx q[125],q[70];
u1(0) q[70];
u1(0) q[125];
cx q[125],q[71];
u1(0) q[71];
cx q[125],q[71];
u1(0) q[71];
u1(0) q[125];
cx q[125],q[72];
u1(0) q[72];
cx q[125],q[72];
u1(0) q[72];
u1(0) q[125];
cx q[125],q[73];
u1(0) q[73];
cx q[125],q[73];
u1(0) q[73];
u1(0) q[125];
cx q[125],q[74];
u1(0) q[74];
cx q[125],q[74];
u1(0) q[74];
u1(0) q[125];
cx q[125],q[75];
u1(0) q[75];
cx q[125],q[75];
u1(0) q[75];
u1(0) q[125];
cx q[125],q[76];
u1(0) q[76];
cx q[125],q[76];
u1(0) q[76];
u1(0) q[125];
cx q[125],q[77];
u1(0) q[77];
cx q[125],q[77];
u1(0) q[77];
u1(pi/281474976710656) q[125];
cx q[125],q[78];
u1(-pi/281474976710656) q[78];
cx q[125],q[78];
u1(pi/281474976710656) q[78];
u1(pi/140737488355328) q[125];
cx q[125],q[79];
u1(-pi/140737488355328) q[79];
cx q[125],q[79];
u1(pi/140737488355328) q[79];
u1(pi/70368744177664) q[125];
cx q[125],q[80];
u1(-pi/70368744177664) q[80];
cx q[125],q[80];
u1(pi/70368744177664) q[80];
u1(pi/35184372088832) q[125];
cx q[125],q[81];
u1(-pi/35184372088832) q[81];
cx q[125],q[81];
u1(pi/35184372088832) q[81];
u1(pi/17592186044416) q[125];
cx q[125],q[82];
u1(-pi/17592186044416) q[82];
cx q[125],q[82];
u1(pi/17592186044416) q[82];
u1(pi/8796093022208) q[125];
cx q[125],q[83];
u1(-pi/8796093022208) q[83];
cx q[125],q[83];
u1(pi/8796093022208) q[83];
u1(pi/4398046511104) q[125];
cx q[125],q[84];
u1(-pi/4398046511104) q[84];
cx q[125],q[84];
u1(pi/4398046511104) q[84];
u1(pi/2199023255552) q[125];
cx q[125],q[85];
u1(-pi/2199023255552) q[85];
cx q[125],q[85];
u1(pi/2199023255552) q[85];
u1(pi/1099511627776) q[125];
cx q[125],q[86];
u1(-pi/1099511627776) q[86];
cx q[125],q[86];
u1(pi/1099511627776) q[86];
u1(pi/549755813888) q[125];
cx q[125],q[87];
u1(-pi/549755813888) q[87];
cx q[125],q[87];
u1(pi/549755813888) q[87];
u1(pi/274877906944) q[125];
cx q[125],q[88];
u1(-pi/274877906944) q[88];
cx q[125],q[88];
u1(pi/274877906944) q[88];
u1(pi/137438953472) q[125];
cx q[125],q[89];
u1(-pi/137438953472) q[89];
cx q[125],q[89];
u1(pi/137438953472) q[89];
u1(pi/68719476736) q[125];
cx q[125],q[90];
u1(-pi/68719476736) q[90];
cx q[125],q[90];
u1(pi/68719476736) q[90];
u1(pi/34359738368) q[125];
cx q[125],q[91];
u1(-pi/34359738368) q[91];
cx q[125],q[91];
u1(pi/34359738368) q[91];
u1(pi/17179869184) q[125];
cx q[125],q[92];
u1(-pi/17179869184) q[92];
cx q[125],q[92];
u1(pi/17179869184) q[92];
u1(pi/8589934592) q[125];
cx q[125],q[93];
u1(-pi/8589934592) q[93];
cx q[125],q[93];
u1(pi/8589934592) q[93];
u1(pi/4294967296) q[125];
cx q[125],q[94];
u1(-pi/4294967296) q[94];
cx q[125],q[94];
u1(pi/4294967296) q[94];
u1(pi/2147483648) q[125];
cx q[125],q[95];
u1(-pi/2147483648) q[95];
cx q[125],q[95];
u1(pi/2147483648) q[95];
u1(pi/1073741824) q[125];
cx q[125],q[96];
u1(-pi/1073741824) q[96];
cx q[125],q[96];
u1(pi/1073741824) q[96];
u1(pi/536870912) q[125];
cx q[125],q[97];
u1(-pi/536870912) q[97];
cx q[125],q[97];
u1(pi/536870912) q[97];
u1(pi/268435456) q[125];
cx q[125],q[98];
u1(-pi/268435456) q[98];
cx q[125],q[98];
u1(pi/268435456) q[98];
u1(pi/134217728) q[125];
cx q[125],q[99];
u1(-pi/134217728) q[99];
cx q[125],q[99];
u1(pi/134217728) q[99];
u1(pi/67108864) q[125];
cx q[125],q[100];
u1(-pi/67108864) q[100];
cx q[125],q[100];
u1(pi/67108864) q[100];
u1(pi/33554432) q[125];
cx q[125],q[101];
u1(-pi/33554432) q[101];
cx q[125],q[101];
u1(pi/33554432) q[101];
u1(pi/16777216) q[125];
cx q[125],q[102];
u1(-pi/16777216) q[102];
cx q[125],q[102];
u1(pi/16777216) q[102];
u1(pi/8388608) q[125];
cx q[125],q[103];
u1(-pi/8388608) q[103];
cx q[125],q[103];
u1(pi/8388608) q[103];
u1(pi/4194304) q[125];
cx q[125],q[104];
u1(-pi/4194304) q[104];
cx q[125],q[104];
u1(pi/4194304) q[104];
u1(pi/2097152) q[125];
cx q[125],q[105];
u1(-pi/2097152) q[105];
cx q[125],q[105];
u1(pi/2097152) q[105];
u1(pi/1048576) q[125];
cx q[125],q[106];
u1(-pi/1048576) q[106];
cx q[125],q[106];
u1(pi/1048576) q[106];
u1(pi/524288) q[125];
cx q[125],q[107];
u1(-pi/524288) q[107];
cx q[125],q[107];
u1(pi/524288) q[107];
u1(pi/262144) q[125];
cx q[125],q[108];
u1(-pi/262144) q[108];
cx q[125],q[108];
u1(pi/262144) q[108];
u1(pi/131072) q[125];
cx q[125],q[109];
u1(-pi/131072) q[109];
cx q[125],q[109];
u1(pi/131072) q[109];
u1(pi/65536) q[125];
cx q[125],q[110];
u1(-pi/65536) q[110];
cx q[125],q[110];
u1(pi/65536) q[110];
u1(pi/32768) q[125];
cx q[125],q[111];
u1(-pi/32768) q[111];
cx q[125],q[111];
u1(pi/32768) q[111];
u1(pi/16384) q[125];
cx q[125],q[112];
u1(-pi/16384) q[112];
cx q[125],q[112];
u1(pi/16384) q[112];
u1(pi/8192) q[125];
cx q[125],q[113];
u1(-pi/8192) q[113];
cx q[125],q[113];
u1(pi/8192) q[113];
u1(pi/4096) q[125];
cx q[125],q[114];
u1(-pi/4096) q[114];
cx q[125],q[114];
u1(pi/4096) q[114];
u1(pi/2048) q[125];
cx q[125],q[115];
u1(-pi/2048) q[115];
cx q[125],q[115];
u1(pi/2048) q[115];
u1(pi/1024) q[125];
cx q[125],q[116];
u1(-pi/1024) q[116];
cx q[125],q[116];
u1(pi/1024) q[116];
u1(pi/512) q[125];
cx q[125],q[117];
u1(-pi/512) q[117];
cx q[125],q[117];
u1(pi/512) q[117];
u1(pi/256) q[125];
cx q[125],q[118];
u1(-pi/256) q[118];
cx q[125],q[118];
u1(pi/256) q[118];
u1(pi/128) q[125];
cx q[125],q[119];
u1(-pi/128) q[119];
cx q[125],q[119];
u1(pi/128) q[119];
u1(pi/64) q[125];
cx q[125],q[120];
u1(-pi/64) q[120];
cx q[125],q[120];
u1(pi/64) q[120];
u1(pi/32) q[125];
cx q[125],q[121];
u1(-pi/32) q[121];
cx q[125],q[121];
u1(pi/32) q[121];
u1(pi/16) q[125];
cx q[125],q[122];
u1(-pi/16) q[122];
cx q[125],q[122];
u1(pi/16) q[122];
u1(pi/8) q[125];
cx q[125],q[123];
u1(-pi/8) q[123];
cx q[125],q[123];
u1(pi/8) q[123];
u1(pi/4) q[125];
cx q[125],q[124];
u1(-pi/4) q[124];
cx q[125],q[124];
u1(pi/4) q[124];
h q[125];
u1(0) q[126];
cx q[126],q[0];
u1(0) q[0];
cx q[126],q[0];
u1(0) q[0];
u1(0) q[126];
cx q[126],q[1];
u1(0) q[1];
cx q[126],q[1];
u1(0) q[1];
u1(0) q[126];
cx q[126],q[2];
u1(0) q[2];
cx q[126],q[2];
u1(0) q[2];
u1(0) q[126];
cx q[126],q[3];
u1(0) q[3];
cx q[126],q[3];
u1(0) q[3];
u1(0) q[126];
cx q[126],q[4];
u1(0) q[4];
cx q[126],q[4];
u1(0) q[4];
u1(0) q[126];
cx q[126],q[5];
u1(0) q[5];
cx q[126],q[5];
u1(0) q[5];
u1(0) q[126];
cx q[126],q[6];
u1(0) q[6];
cx q[126],q[6];
u1(0) q[6];
u1(0) q[126];
cx q[126],q[7];
u1(0) q[7];
cx q[126],q[7];
u1(0) q[7];
u1(0) q[126];
cx q[126],q[8];
u1(0) q[8];
cx q[126],q[8];
u1(0) q[8];
u1(0) q[126];
cx q[126],q[9];
u1(0) q[9];
cx q[126],q[9];
u1(0) q[9];
u1(0) q[126];
cx q[126],q[10];
u1(0) q[10];
cx q[126],q[10];
u1(0) q[10];
u1(0) q[126];
cx q[126],q[11];
u1(0) q[11];
cx q[126],q[11];
u1(0) q[11];
u1(0) q[126];
cx q[126],q[12];
u1(0) q[12];
cx q[126],q[12];
u1(0) q[12];
u1(0) q[126];
cx q[126],q[13];
u1(0) q[13];
cx q[126],q[13];
u1(0) q[13];
u1(0) q[126];
cx q[126],q[14];
u1(0) q[14];
cx q[126],q[14];
u1(0) q[14];
u1(0) q[126];
cx q[126],q[15];
u1(0) q[15];
cx q[126],q[15];
u1(0) q[15];
u1(0) q[126];
cx q[126],q[16];
u1(0) q[16];
cx q[126],q[16];
u1(0) q[16];
u1(0) q[126];
cx q[126],q[17];
u1(0) q[17];
cx q[126],q[17];
u1(0) q[17];
u1(0) q[126];
cx q[126],q[18];
u1(0) q[18];
cx q[126],q[18];
u1(0) q[18];
u1(0) q[126];
cx q[126],q[19];
u1(0) q[19];
cx q[126],q[19];
u1(0) q[19];
u1(0) q[126];
cx q[126],q[20];
u1(0) q[20];
cx q[126],q[20];
u1(0) q[20];
u1(0) q[126];
cx q[126],q[21];
u1(0) q[21];
cx q[126],q[21];
u1(0) q[21];
u1(0) q[126];
cx q[126],q[22];
u1(0) q[22];
cx q[126],q[22];
u1(0) q[22];
u1(0) q[126];
cx q[126],q[23];
u1(0) q[23];
cx q[126],q[23];
u1(0) q[23];
u1(0) q[126];
cx q[126],q[24];
u1(0) q[24];
cx q[126],q[24];
u1(0) q[24];
u1(0) q[126];
cx q[126],q[25];
u1(0) q[25];
cx q[126],q[25];
u1(0) q[25];
u1(0) q[126];
cx q[126],q[26];
u1(0) q[26];
cx q[126],q[26];
u1(0) q[26];
u1(0) q[126];
cx q[126],q[27];
u1(0) q[27];
cx q[126],q[27];
u1(0) q[27];
u1(0) q[126];
cx q[126],q[28];
u1(0) q[28];
cx q[126],q[28];
u1(0) q[28];
u1(0) q[126];
cx q[126],q[29];
u1(0) q[29];
cx q[126],q[29];
u1(0) q[29];
u1(0) q[126];
cx q[126],q[30];
u1(0) q[30];
cx q[126],q[30];
u1(0) q[30];
u1(0) q[126];
cx q[126],q[31];
u1(0) q[31];
cx q[126],q[31];
u1(0) q[31];
u1(0) q[126];
cx q[126],q[32];
u1(0) q[32];
cx q[126],q[32];
u1(0) q[32];
u1(0) q[126];
cx q[126],q[33];
u1(0) q[33];
cx q[126],q[33];
u1(0) q[33];
u1(0) q[126];
cx q[126],q[34];
u1(0) q[34];
cx q[126],q[34];
u1(0) q[34];
u1(0) q[126];
cx q[126],q[35];
u1(0) q[35];
cx q[126],q[35];
u1(0) q[35];
u1(0) q[126];
cx q[126],q[36];
u1(0) q[36];
cx q[126],q[36];
u1(0) q[36];
u1(0) q[126];
cx q[126],q[37];
u1(0) q[37];
cx q[126],q[37];
u1(0) q[37];
u1(0) q[126];
cx q[126],q[38];
u1(0) q[38];
cx q[126],q[38];
u1(0) q[38];
u1(0) q[126];
cx q[126],q[39];
u1(0) q[39];
cx q[126],q[39];
u1(0) q[39];
u1(0) q[126];
cx q[126],q[40];
u1(0) q[40];
cx q[126],q[40];
u1(0) q[40];
u1(0) q[126];
cx q[126],q[41];
u1(0) q[41];
cx q[126],q[41];
u1(0) q[41];
u1(0) q[126];
cx q[126],q[42];
u1(0) q[42];
cx q[126],q[42];
u1(0) q[42];
u1(0) q[126];
cx q[126],q[43];
u1(0) q[43];
cx q[126],q[43];
u1(0) q[43];
u1(0) q[126];
cx q[126],q[44];
u1(0) q[44];
cx q[126],q[44];
u1(0) q[44];
u1(0) q[126];
cx q[126],q[45];
u1(0) q[45];
cx q[126],q[45];
u1(0) q[45];
u1(0) q[126];
cx q[126],q[46];
u1(0) q[46];
cx q[126],q[46];
u1(0) q[46];
u1(0) q[126];
cx q[126],q[47];
u1(0) q[47];
cx q[126],q[47];
u1(0) q[47];
u1(0) q[126];
cx q[126],q[48];
u1(0) q[48];
cx q[126],q[48];
u1(0) q[48];
u1(0) q[126];
cx q[126],q[49];
u1(0) q[49];
cx q[126],q[49];
u1(0) q[49];
u1(0) q[126];
cx q[126],q[50];
u1(0) q[50];
cx q[126],q[50];
u1(0) q[50];
u1(0) q[126];
cx q[126],q[51];
u1(0) q[51];
cx q[126],q[51];
u1(0) q[51];
u1(0) q[126];
cx q[126],q[52];
u1(0) q[52];
cx q[126],q[52];
u1(0) q[52];
u1(0) q[126];
cx q[126],q[53];
u1(0) q[53];
cx q[126],q[53];
u1(0) q[53];
u1(0) q[126];
cx q[126],q[54];
u1(0) q[54];
cx q[126],q[54];
u1(0) q[54];
u1(0) q[126];
cx q[126],q[55];
u1(0) q[55];
cx q[126],q[55];
u1(0) q[55];
u1(0) q[126];
cx q[126],q[56];
u1(0) q[56];
cx q[126],q[56];
u1(0) q[56];
u1(0) q[126];
cx q[126],q[57];
u1(0) q[57];
cx q[126],q[57];
u1(0) q[57];
u1(0) q[126];
cx q[126],q[58];
u1(0) q[58];
cx q[126],q[58];
u1(0) q[58];
u1(0) q[126];
cx q[126],q[59];
u1(0) q[59];
cx q[126],q[59];
u1(0) q[59];
u1(0) q[126];
cx q[126],q[60];
u1(0) q[60];
cx q[126],q[60];
u1(0) q[60];
u1(0) q[126];
cx q[126],q[61];
u1(0) q[61];
cx q[126],q[61];
u1(0) q[61];
u1(0) q[126];
cx q[126],q[62];
u1(0) q[62];
cx q[126],q[62];
u1(0) q[62];
u1(0) q[126];
cx q[126],q[63];
u1(0) q[63];
cx q[126],q[63];
u1(0) q[63];
u1(0) q[126];
cx q[126],q[64];
u1(0) q[64];
cx q[126],q[64];
u1(0) q[64];
u1(0) q[126];
cx q[126],q[65];
u1(0) q[65];
cx q[126],q[65];
u1(0) q[65];
u1(0) q[126];
cx q[126],q[66];
u1(0) q[66];
cx q[126],q[66];
u1(0) q[66];
u1(0) q[126];
cx q[126],q[67];
u1(0) q[67];
cx q[126],q[67];
u1(0) q[67];
u1(0) q[126];
cx q[126],q[68];
u1(0) q[68];
cx q[126],q[68];
u1(0) q[68];
u1(0) q[126];
cx q[126],q[69];
u1(0) q[69];
cx q[126],q[69];
u1(0) q[69];
u1(0) q[126];
cx q[126],q[70];
u1(0) q[70];
cx q[126],q[70];
u1(0) q[70];
u1(0) q[126];
cx q[126],q[71];
u1(0) q[71];
cx q[126],q[71];
u1(0) q[71];
u1(0) q[126];
cx q[126],q[72];
u1(0) q[72];
cx q[126],q[72];
u1(0) q[72];
u1(0) q[126];
cx q[126],q[73];
u1(0) q[73];
cx q[126],q[73];
u1(0) q[73];
u1(0) q[126];
cx q[126],q[74];
u1(0) q[74];
cx q[126],q[74];
u1(0) q[74];
u1(0) q[126];
cx q[126],q[75];
u1(0) q[75];
cx q[126],q[75];
u1(0) q[75];
u1(0) q[126];
cx q[126],q[76];
u1(0) q[76];
cx q[126],q[76];
u1(0) q[76];
u1(0) q[126];
cx q[126],q[77];
u1(0) q[77];
cx q[126],q[77];
u1(0) q[77];
u1(0) q[126];
cx q[126],q[78];
u1(0) q[78];
cx q[126],q[78];
u1(0) q[78];
u1(pi/281474976710656) q[126];
cx q[126],q[79];
u1(-pi/281474976710656) q[79];
cx q[126],q[79];
u1(pi/281474976710656) q[79];
u1(pi/140737488355328) q[126];
cx q[126],q[80];
u1(-pi/140737488355328) q[80];
cx q[126],q[80];
u1(pi/140737488355328) q[80];
u1(pi/70368744177664) q[126];
cx q[126],q[81];
u1(-pi/70368744177664) q[81];
cx q[126],q[81];
u1(pi/70368744177664) q[81];
u1(pi/35184372088832) q[126];
cx q[126],q[82];
u1(-pi/35184372088832) q[82];
cx q[126],q[82];
u1(pi/35184372088832) q[82];
u1(pi/17592186044416) q[126];
cx q[126],q[83];
u1(-pi/17592186044416) q[83];
cx q[126],q[83];
u1(pi/17592186044416) q[83];
u1(pi/8796093022208) q[126];
cx q[126],q[84];
u1(-pi/8796093022208) q[84];
cx q[126],q[84];
u1(pi/8796093022208) q[84];
u1(pi/4398046511104) q[126];
cx q[126],q[85];
u1(-pi/4398046511104) q[85];
cx q[126],q[85];
u1(pi/4398046511104) q[85];
u1(pi/2199023255552) q[126];
cx q[126],q[86];
u1(-pi/2199023255552) q[86];
cx q[126],q[86];
u1(pi/2199023255552) q[86];
u1(pi/1099511627776) q[126];
cx q[126],q[87];
u1(-pi/1099511627776) q[87];
cx q[126],q[87];
u1(pi/1099511627776) q[87];
u1(pi/549755813888) q[126];
cx q[126],q[88];
u1(-pi/549755813888) q[88];
cx q[126],q[88];
u1(pi/549755813888) q[88];
u1(pi/274877906944) q[126];
cx q[126],q[89];
u1(-pi/274877906944) q[89];
cx q[126],q[89];
u1(pi/274877906944) q[89];
u1(pi/137438953472) q[126];
cx q[126],q[90];
u1(-pi/137438953472) q[90];
cx q[126],q[90];
u1(pi/137438953472) q[90];
u1(pi/68719476736) q[126];
cx q[126],q[91];
u1(-pi/68719476736) q[91];
cx q[126],q[91];
u1(pi/68719476736) q[91];
u1(pi/34359738368) q[126];
cx q[126],q[92];
u1(-pi/34359738368) q[92];
cx q[126],q[92];
u1(pi/34359738368) q[92];
u1(pi/17179869184) q[126];
cx q[126],q[93];
u1(-pi/17179869184) q[93];
cx q[126],q[93];
u1(pi/17179869184) q[93];
u1(pi/8589934592) q[126];
cx q[126],q[94];
u1(-pi/8589934592) q[94];
cx q[126],q[94];
u1(pi/8589934592) q[94];
u1(pi/4294967296) q[126];
cx q[126],q[95];
u1(-pi/4294967296) q[95];
cx q[126],q[95];
u1(pi/4294967296) q[95];
u1(pi/2147483648) q[126];
cx q[126],q[96];
u1(-pi/2147483648) q[96];
cx q[126],q[96];
u1(pi/2147483648) q[96];
u1(pi/1073741824) q[126];
cx q[126],q[97];
u1(-pi/1073741824) q[97];
cx q[126],q[97];
u1(pi/1073741824) q[97];
u1(pi/536870912) q[126];
cx q[126],q[98];
u1(-pi/536870912) q[98];
cx q[126],q[98];
u1(pi/536870912) q[98];
u1(pi/268435456) q[126];
cx q[126],q[99];
u1(-pi/268435456) q[99];
cx q[126],q[99];
u1(pi/268435456) q[99];
u1(pi/134217728) q[126];
cx q[126],q[100];
u1(-pi/134217728) q[100];
cx q[126],q[100];
u1(pi/134217728) q[100];
u1(pi/67108864) q[126];
cx q[126],q[101];
u1(-pi/67108864) q[101];
cx q[126],q[101];
u1(pi/67108864) q[101];
u1(pi/33554432) q[126];
cx q[126],q[102];
u1(-pi/33554432) q[102];
cx q[126],q[102];
u1(pi/33554432) q[102];
u1(pi/16777216) q[126];
cx q[126],q[103];
u1(-pi/16777216) q[103];
cx q[126],q[103];
u1(pi/16777216) q[103];
u1(pi/8388608) q[126];
cx q[126],q[104];
u1(-pi/8388608) q[104];
cx q[126],q[104];
u1(pi/8388608) q[104];
u1(pi/4194304) q[126];
cx q[126],q[105];
u1(-pi/4194304) q[105];
cx q[126],q[105];
u1(pi/4194304) q[105];
u1(pi/2097152) q[126];
cx q[126],q[106];
u1(-pi/2097152) q[106];
cx q[126],q[106];
u1(pi/2097152) q[106];
u1(pi/1048576) q[126];
cx q[126],q[107];
u1(-pi/1048576) q[107];
cx q[126],q[107];
u1(pi/1048576) q[107];
u1(pi/524288) q[126];
cx q[126],q[108];
u1(-pi/524288) q[108];
cx q[126],q[108];
u1(pi/524288) q[108];
u1(pi/262144) q[126];
cx q[126],q[109];
u1(-pi/262144) q[109];
cx q[126],q[109];
u1(pi/262144) q[109];
u1(pi/131072) q[126];
cx q[126],q[110];
u1(-pi/131072) q[110];
cx q[126],q[110];
u1(pi/131072) q[110];
u1(pi/65536) q[126];
cx q[126],q[111];
u1(-pi/65536) q[111];
cx q[126],q[111];
u1(pi/65536) q[111];
u1(pi/32768) q[126];
cx q[126],q[112];
u1(-pi/32768) q[112];
cx q[126],q[112];
u1(pi/32768) q[112];
u1(pi/16384) q[126];
cx q[126],q[113];
u1(-pi/16384) q[113];
cx q[126],q[113];
u1(pi/16384) q[113];
u1(pi/8192) q[126];
cx q[126],q[114];
u1(-pi/8192) q[114];
cx q[126],q[114];
u1(pi/8192) q[114];
u1(pi/4096) q[126];
cx q[126],q[115];
u1(-pi/4096) q[115];
cx q[126],q[115];
u1(pi/4096) q[115];
u1(pi/2048) q[126];
cx q[126],q[116];
u1(-pi/2048) q[116];
cx q[126],q[116];
u1(pi/2048) q[116];
u1(pi/1024) q[126];
cx q[126],q[117];
u1(-pi/1024) q[117];
cx q[126],q[117];
u1(pi/1024) q[117];
u1(pi/512) q[126];
cx q[126],q[118];
u1(-pi/512) q[118];
cx q[126],q[118];
u1(pi/512) q[118];
u1(pi/256) q[126];
cx q[126],q[119];
u1(-pi/256) q[119];
cx q[126],q[119];
u1(pi/256) q[119];
u1(pi/128) q[126];
cx q[126],q[120];
u1(-pi/128) q[120];
cx q[126],q[120];
u1(pi/128) q[120];
u1(pi/64) q[126];
cx q[126],q[121];
u1(-pi/64) q[121];
cx q[126],q[121];
u1(pi/64) q[121];
u1(pi/32) q[126];
cx q[126],q[122];
u1(-pi/32) q[122];
cx q[126],q[122];
u1(pi/32) q[122];
u1(pi/16) q[126];
cx q[126],q[123];
u1(-pi/16) q[123];
cx q[126],q[123];
u1(pi/16) q[123];
u1(pi/8) q[126];
cx q[126],q[124];
u1(-pi/8) q[124];
cx q[126],q[124];
u1(pi/8) q[124];
u1(pi/4) q[126];
cx q[126],q[125];
u1(-pi/4) q[125];
cx q[126],q[125];
u1(pi/4) q[125];
h q[126];
u1(0) q[127];
cx q[127],q[0];
u1(0) q[0];
cx q[127],q[0];
u1(0) q[0];
u1(0) q[127];
cx q[127],q[1];
u1(0) q[1];
cx q[127],q[1];
u1(0) q[1];
u1(0) q[127];
cx q[127],q[2];
u1(0) q[2];
cx q[127],q[2];
u1(0) q[2];
u1(0) q[127];
cx q[127],q[3];
u1(0) q[3];
cx q[127],q[3];
u1(0) q[3];
u1(0) q[127];
cx q[127],q[4];
u1(0) q[4];
cx q[127],q[4];
u1(0) q[4];
u1(0) q[127];
cx q[127],q[5];
u1(0) q[5];
cx q[127],q[5];
u1(0) q[5];
u1(0) q[127];
cx q[127],q[6];
u1(0) q[6];
cx q[127],q[6];
u1(0) q[6];
u1(0) q[127];
cx q[127],q[7];
u1(0) q[7];
cx q[127],q[7];
u1(0) q[7];
u1(0) q[127];
cx q[127],q[8];
u1(0) q[8];
cx q[127],q[8];
u1(0) q[8];
u1(0) q[127];
cx q[127],q[9];
u1(0) q[9];
cx q[127],q[9];
u1(0) q[9];
u1(0) q[127];
cx q[127],q[10];
u1(0) q[10];
cx q[127],q[10];
u1(0) q[10];
u1(0) q[127];
cx q[127],q[11];
u1(0) q[11];
cx q[127],q[11];
u1(0) q[11];
u1(0) q[127];
cx q[127],q[12];
u1(0) q[12];
cx q[127],q[12];
u1(0) q[12];
u1(0) q[127];
cx q[127],q[13];
u1(0) q[13];
cx q[127],q[13];
u1(0) q[13];
u1(0) q[127];
cx q[127],q[14];
u1(0) q[14];
cx q[127],q[14];
u1(0) q[14];
u1(0) q[127];
cx q[127],q[15];
u1(0) q[15];
cx q[127],q[15];
u1(0) q[15];
u1(0) q[127];
cx q[127],q[16];
u1(0) q[16];
cx q[127],q[16];
u1(0) q[16];
u1(0) q[127];
cx q[127],q[17];
u1(0) q[17];
cx q[127],q[17];
u1(0) q[17];
u1(0) q[127];
cx q[127],q[18];
u1(0) q[18];
cx q[127],q[18];
u1(0) q[18];
u1(0) q[127];
cx q[127],q[19];
u1(0) q[19];
cx q[127],q[19];
u1(0) q[19];
u1(0) q[127];
cx q[127],q[20];
u1(0) q[20];
cx q[127],q[20];
u1(0) q[20];
u1(0) q[127];
cx q[127],q[21];
u1(0) q[21];
cx q[127],q[21];
u1(0) q[21];
u1(0) q[127];
cx q[127],q[22];
u1(0) q[22];
cx q[127],q[22];
u1(0) q[22];
u1(0) q[127];
cx q[127],q[23];
u1(0) q[23];
cx q[127],q[23];
u1(0) q[23];
u1(0) q[127];
cx q[127],q[24];
u1(0) q[24];
cx q[127],q[24];
u1(0) q[24];
u1(0) q[127];
cx q[127],q[25];
u1(0) q[25];
cx q[127],q[25];
u1(0) q[25];
u1(0) q[127];
cx q[127],q[26];
u1(0) q[26];
cx q[127],q[26];
u1(0) q[26];
u1(0) q[127];
cx q[127],q[27];
u1(0) q[27];
cx q[127],q[27];
u1(0) q[27];
u1(0) q[127];
cx q[127],q[28];
u1(0) q[28];
cx q[127],q[28];
u1(0) q[28];
u1(0) q[127];
cx q[127],q[29];
u1(0) q[29];
cx q[127],q[29];
u1(0) q[29];
u1(0) q[127];
cx q[127],q[30];
u1(0) q[30];
cx q[127],q[30];
u1(0) q[30];
u1(0) q[127];
cx q[127],q[31];
u1(0) q[31];
cx q[127],q[31];
u1(0) q[31];
u1(0) q[127];
cx q[127],q[32];
u1(0) q[32];
cx q[127],q[32];
u1(0) q[32];
u1(0) q[127];
cx q[127],q[33];
u1(0) q[33];
cx q[127],q[33];
u1(0) q[33];
u1(0) q[127];
cx q[127],q[34];
u1(0) q[34];
cx q[127],q[34];
u1(0) q[34];
u1(0) q[127];
cx q[127],q[35];
u1(0) q[35];
cx q[127],q[35];
u1(0) q[35];
u1(0) q[127];
cx q[127],q[36];
u1(0) q[36];
cx q[127],q[36];
u1(0) q[36];
u1(0) q[127];
cx q[127],q[37];
u1(0) q[37];
cx q[127],q[37];
u1(0) q[37];
u1(0) q[127];
cx q[127],q[38];
u1(0) q[38];
cx q[127],q[38];
u1(0) q[38];
u1(0) q[127];
cx q[127],q[39];
u1(0) q[39];
cx q[127],q[39];
u1(0) q[39];
u1(0) q[127];
cx q[127],q[40];
u1(0) q[40];
cx q[127],q[40];
u1(0) q[40];
u1(0) q[127];
cx q[127],q[41];
u1(0) q[41];
cx q[127],q[41];
u1(0) q[41];
u1(0) q[127];
cx q[127],q[42];
u1(0) q[42];
cx q[127],q[42];
u1(0) q[42];
u1(0) q[127];
cx q[127],q[43];
u1(0) q[43];
cx q[127],q[43];
u1(0) q[43];
u1(0) q[127];
cx q[127],q[44];
u1(0) q[44];
cx q[127],q[44];
u1(0) q[44];
u1(0) q[127];
cx q[127],q[45];
u1(0) q[45];
cx q[127],q[45];
u1(0) q[45];
u1(0) q[127];
cx q[127],q[46];
u1(0) q[46];
cx q[127],q[46];
u1(0) q[46];
u1(0) q[127];
cx q[127],q[47];
u1(0) q[47];
cx q[127],q[47];
u1(0) q[47];
u1(0) q[127];
cx q[127],q[48];
u1(0) q[48];
cx q[127],q[48];
u1(0) q[48];
u1(0) q[127];
cx q[127],q[49];
u1(0) q[49];
cx q[127],q[49];
u1(0) q[49];
u1(0) q[127];
cx q[127],q[50];
u1(0) q[50];
cx q[127],q[50];
u1(0) q[50];
u1(0) q[127];
cx q[127],q[51];
u1(0) q[51];
cx q[127],q[51];
u1(0) q[51];
u1(0) q[127];
cx q[127],q[52];
u1(0) q[52];
cx q[127],q[52];
u1(0) q[52];
u1(0) q[127];
cx q[127],q[53];
u1(0) q[53];
cx q[127],q[53];
u1(0) q[53];
u1(0) q[127];
cx q[127],q[54];
u1(0) q[54];
cx q[127],q[54];
u1(0) q[54];
u1(0) q[127];
cx q[127],q[55];
u1(0) q[55];
cx q[127],q[55];
u1(0) q[55];
u1(0) q[127];
cx q[127],q[56];
u1(0) q[56];
cx q[127],q[56];
u1(0) q[56];
u1(0) q[127];
cx q[127],q[57];
u1(0) q[57];
cx q[127],q[57];
u1(0) q[57];
u1(0) q[127];
cx q[127],q[58];
u1(0) q[58];
cx q[127],q[58];
u1(0) q[58];
u1(0) q[127];
cx q[127],q[59];
u1(0) q[59];
cx q[127],q[59];
u1(0) q[59];
u1(0) q[127];
cx q[127],q[60];
u1(0) q[60];
cx q[127],q[60];
u1(0) q[60];
u1(0) q[127];
cx q[127],q[61];
u1(0) q[61];
cx q[127],q[61];
u1(0) q[61];
u1(0) q[127];
cx q[127],q[62];
u1(0) q[62];
cx q[127],q[62];
u1(0) q[62];
u1(0) q[127];
cx q[127],q[63];
u1(0) q[63];
cx q[127],q[63];
u1(0) q[63];
u1(0) q[127];
cx q[127],q[64];
u1(0) q[64];
cx q[127],q[64];
u1(0) q[64];
u1(0) q[127];
cx q[127],q[65];
u1(0) q[65];
cx q[127],q[65];
u1(0) q[65];
u1(0) q[127];
cx q[127],q[66];
u1(0) q[66];
cx q[127],q[66];
u1(0) q[66];
u1(0) q[127];
cx q[127],q[67];
u1(0) q[67];
cx q[127],q[67];
u1(0) q[67];
u1(0) q[127];
cx q[127],q[68];
u1(0) q[68];
cx q[127],q[68];
u1(0) q[68];
u1(0) q[127];
cx q[127],q[69];
u1(0) q[69];
cx q[127],q[69];
u1(0) q[69];
u1(0) q[127];
cx q[127],q[70];
u1(0) q[70];
cx q[127],q[70];
u1(0) q[70];
u1(0) q[127];
cx q[127],q[71];
u1(0) q[71];
cx q[127],q[71];
u1(0) q[71];
u1(0) q[127];
cx q[127],q[72];
u1(0) q[72];
cx q[127],q[72];
u1(0) q[72];
u1(0) q[127];
cx q[127],q[73];
u1(0) q[73];
cx q[127],q[73];
u1(0) q[73];
u1(0) q[127];
cx q[127],q[74];
u1(0) q[74];
cx q[127],q[74];
u1(0) q[74];
u1(0) q[127];
cx q[127],q[75];
u1(0) q[75];
cx q[127],q[75];
u1(0) q[75];
u1(0) q[127];
cx q[127],q[76];
u1(0) q[76];
cx q[127],q[76];
u1(0) q[76];
u1(0) q[127];
cx q[127],q[77];
u1(0) q[77];
cx q[127],q[77];
u1(0) q[77];
u1(0) q[127];
cx q[127],q[78];
u1(0) q[78];
cx q[127],q[78];
u1(0) q[78];
u1(0) q[127];
cx q[127],q[79];
u1(0) q[79];
cx q[127],q[79];
u1(0) q[79];
u1(pi/281474976710656) q[127];
cx q[127],q[80];
u1(-pi/281474976710656) q[80];
cx q[127],q[80];
u1(pi/281474976710656) q[80];
u1(pi/140737488355328) q[127];
cx q[127],q[81];
u1(-pi/140737488355328) q[81];
cx q[127],q[81];
u1(pi/140737488355328) q[81];
u1(pi/70368744177664) q[127];
cx q[127],q[82];
u1(-pi/70368744177664) q[82];
cx q[127],q[82];
u1(pi/70368744177664) q[82];
u1(pi/35184372088832) q[127];
cx q[127],q[83];
u1(-pi/35184372088832) q[83];
cx q[127],q[83];
u1(pi/35184372088832) q[83];
u1(pi/17592186044416) q[127];
cx q[127],q[84];
u1(-pi/17592186044416) q[84];
cx q[127],q[84];
u1(pi/17592186044416) q[84];
u1(pi/8796093022208) q[127];
cx q[127],q[85];
u1(-pi/8796093022208) q[85];
cx q[127],q[85];
u1(pi/8796093022208) q[85];
u1(pi/4398046511104) q[127];
cx q[127],q[86];
u1(-pi/4398046511104) q[86];
cx q[127],q[86];
u1(pi/4398046511104) q[86];
u1(pi/2199023255552) q[127];
cx q[127],q[87];
u1(-pi/2199023255552) q[87];
cx q[127],q[87];
u1(pi/2199023255552) q[87];
u1(pi/1099511627776) q[127];
cx q[127],q[88];
u1(-pi/1099511627776) q[88];
cx q[127],q[88];
u1(pi/1099511627776) q[88];
u1(pi/549755813888) q[127];
cx q[127],q[89];
u1(-pi/549755813888) q[89];
cx q[127],q[89];
u1(pi/549755813888) q[89];
u1(pi/274877906944) q[127];
cx q[127],q[90];
u1(-pi/274877906944) q[90];
cx q[127],q[90];
u1(pi/274877906944) q[90];
u1(pi/137438953472) q[127];
cx q[127],q[91];
u1(-pi/137438953472) q[91];
cx q[127],q[91];
u1(pi/137438953472) q[91];
u1(pi/68719476736) q[127];
cx q[127],q[92];
u1(-pi/68719476736) q[92];
cx q[127],q[92];
u1(pi/68719476736) q[92];
u1(pi/34359738368) q[127];
cx q[127],q[93];
u1(-pi/34359738368) q[93];
cx q[127],q[93];
u1(pi/34359738368) q[93];
u1(pi/17179869184) q[127];
cx q[127],q[94];
u1(-pi/17179869184) q[94];
cx q[127],q[94];
u1(pi/17179869184) q[94];
u1(pi/8589934592) q[127];
cx q[127],q[95];
u1(-pi/8589934592) q[95];
cx q[127],q[95];
u1(pi/8589934592) q[95];
u1(pi/4294967296) q[127];
cx q[127],q[96];
u1(-pi/4294967296) q[96];
cx q[127],q[96];
u1(pi/4294967296) q[96];
u1(pi/2147483648) q[127];
cx q[127],q[97];
u1(-pi/2147483648) q[97];
cx q[127],q[97];
u1(pi/2147483648) q[97];
u1(pi/1073741824) q[127];
cx q[127],q[98];
u1(-pi/1073741824) q[98];
cx q[127],q[98];
u1(pi/1073741824) q[98];
u1(pi/536870912) q[127];
cx q[127],q[99];
u1(-pi/536870912) q[99];
cx q[127],q[99];
u1(pi/536870912) q[99];
u1(pi/268435456) q[127];
cx q[127],q[100];
u1(-pi/268435456) q[100];
cx q[127],q[100];
u1(pi/268435456) q[100];
u1(pi/134217728) q[127];
cx q[127],q[101];
u1(-pi/134217728) q[101];
cx q[127],q[101];
u1(pi/134217728) q[101];
u1(pi/67108864) q[127];
cx q[127],q[102];
u1(-pi/67108864) q[102];
cx q[127],q[102];
u1(pi/67108864) q[102];
u1(pi/33554432) q[127];
cx q[127],q[103];
u1(-pi/33554432) q[103];
cx q[127],q[103];
u1(pi/33554432) q[103];
u1(pi/16777216) q[127];
cx q[127],q[104];
u1(-pi/16777216) q[104];
cx q[127],q[104];
u1(pi/16777216) q[104];
u1(pi/8388608) q[127];
cx q[127],q[105];
u1(-pi/8388608) q[105];
cx q[127],q[105];
u1(pi/8388608) q[105];
u1(pi/4194304) q[127];
cx q[127],q[106];
u1(-pi/4194304) q[106];
cx q[127],q[106];
u1(pi/4194304) q[106];
u1(pi/2097152) q[127];
cx q[127],q[107];
u1(-pi/2097152) q[107];
cx q[127],q[107];
u1(pi/2097152) q[107];
u1(pi/1048576) q[127];
cx q[127],q[108];
u1(-pi/1048576) q[108];
cx q[127],q[108];
u1(pi/1048576) q[108];
u1(pi/524288) q[127];
cx q[127],q[109];
u1(-pi/524288) q[109];
cx q[127],q[109];
u1(pi/524288) q[109];
u1(pi/262144) q[127];
cx q[127],q[110];
u1(-pi/262144) q[110];
cx q[127],q[110];
u1(pi/262144) q[110];
u1(pi/131072) q[127];
cx q[127],q[111];
u1(-pi/131072) q[111];
cx q[127],q[111];
u1(pi/131072) q[111];
u1(pi/65536) q[127];
cx q[127],q[112];
u1(-pi/65536) q[112];
cx q[127],q[112];
u1(pi/65536) q[112];
u1(pi/32768) q[127];
cx q[127],q[113];
u1(-pi/32768) q[113];
cx q[127],q[113];
u1(pi/32768) q[113];
u1(pi/16384) q[127];
cx q[127],q[114];
u1(-pi/16384) q[114];
cx q[127],q[114];
u1(pi/16384) q[114];
u1(pi/8192) q[127];
cx q[127],q[115];
u1(-pi/8192) q[115];
cx q[127],q[115];
u1(pi/8192) q[115];
u1(pi/4096) q[127];
cx q[127],q[116];
u1(-pi/4096) q[116];
cx q[127],q[116];
u1(pi/4096) q[116];
u1(pi/2048) q[127];
cx q[127],q[117];
u1(-pi/2048) q[117];
cx q[127],q[117];
u1(pi/2048) q[117];
u1(pi/1024) q[127];
cx q[127],q[118];
u1(-pi/1024) q[118];
cx q[127],q[118];
u1(pi/1024) q[118];
u1(pi/512) q[127];
cx q[127],q[119];
u1(-pi/512) q[119];
cx q[127],q[119];
u1(pi/512) q[119];
u1(pi/256) q[127];
cx q[127],q[120];
u1(-pi/256) q[120];
cx q[127],q[120];
u1(pi/256) q[120];
u1(pi/128) q[127];
cx q[127],q[121];
u1(-pi/128) q[121];
cx q[127],q[121];
u1(pi/128) q[121];
u1(pi/64) q[127];
cx q[127],q[122];
u1(-pi/64) q[122];
cx q[127],q[122];
u1(pi/64) q[122];
u1(pi/32) q[127];
cx q[127],q[123];
u1(-pi/32) q[123];
cx q[127],q[123];
u1(pi/32) q[123];
u1(pi/16) q[127];
cx q[127],q[124];
u1(-pi/16) q[124];
cx q[127],q[124];
u1(pi/16) q[124];
u1(pi/8) q[127];
cx q[127],q[125];
u1(-pi/8) q[125];
cx q[127],q[125];
u1(pi/8) q[125];
u1(pi/4) q[127];
cx q[127],q[126];
u1(-pi/4) q[126];
cx q[127],q[126];
u1(pi/4) q[126];
h q[127];
u1(0) q[128];
cx q[128],q[0];
u1(0) q[0];
cx q[128],q[0];
u1(0) q[0];
u1(0) q[128];
cx q[128],q[1];
u1(0) q[1];
cx q[128],q[1];
u1(0) q[1];
u1(0) q[128];
cx q[128],q[2];
u1(0) q[2];
cx q[128],q[2];
u1(0) q[2];
u1(0) q[128];
cx q[128],q[3];
u1(0) q[3];
cx q[128],q[3];
u1(0) q[3];
u1(0) q[128];
cx q[128],q[4];
u1(0) q[4];
cx q[128],q[4];
u1(0) q[4];
u1(0) q[128];
cx q[128],q[5];
u1(0) q[5];
cx q[128],q[5];
u1(0) q[5];
u1(0) q[128];
cx q[128],q[6];
u1(0) q[6];
cx q[128],q[6];
u1(0) q[6];
u1(0) q[128];
cx q[128],q[7];
u1(0) q[7];
cx q[128],q[7];
u1(0) q[7];
u1(0) q[128];
cx q[128],q[8];
u1(0) q[8];
cx q[128],q[8];
u1(0) q[8];
u1(0) q[128];
cx q[128],q[9];
u1(0) q[9];
cx q[128],q[9];
u1(0) q[9];
u1(0) q[128];
cx q[128],q[10];
u1(0) q[10];
cx q[128],q[10];
u1(0) q[10];
u1(0) q[128];
cx q[128],q[11];
u1(0) q[11];
cx q[128],q[11];
u1(0) q[11];
u1(0) q[128];
cx q[128],q[12];
u1(0) q[12];
cx q[128],q[12];
u1(0) q[12];
u1(0) q[128];
cx q[128],q[13];
u1(0) q[13];
cx q[128],q[13];
u1(0) q[13];
u1(0) q[128];
cx q[128],q[14];
u1(0) q[14];
cx q[128],q[14];
u1(0) q[14];
u1(0) q[128];
cx q[128],q[15];
u1(0) q[15];
cx q[128],q[15];
u1(0) q[15];
u1(0) q[128];
cx q[128],q[16];
u1(0) q[16];
cx q[128],q[16];
u1(0) q[16];
u1(0) q[128];
cx q[128],q[17];
u1(0) q[17];
cx q[128],q[17];
u1(0) q[17];
u1(0) q[128];
cx q[128],q[18];
u1(0) q[18];
cx q[128],q[18];
u1(0) q[18];
u1(0) q[128];
cx q[128],q[19];
u1(0) q[19];
cx q[128],q[19];
u1(0) q[19];
u1(0) q[128];
cx q[128],q[20];
u1(0) q[20];
cx q[128],q[20];
u1(0) q[20];
u1(0) q[128];
cx q[128],q[21];
u1(0) q[21];
cx q[128],q[21];
u1(0) q[21];
u1(0) q[128];
cx q[128],q[22];
u1(0) q[22];
cx q[128],q[22];
u1(0) q[22];
u1(0) q[128];
cx q[128],q[23];
u1(0) q[23];
cx q[128],q[23];
u1(0) q[23];
u1(0) q[128];
cx q[128],q[24];
u1(0) q[24];
cx q[128],q[24];
u1(0) q[24];
u1(0) q[128];
cx q[128],q[25];
u1(0) q[25];
cx q[128],q[25];
u1(0) q[25];
u1(0) q[128];
cx q[128],q[26];
u1(0) q[26];
cx q[128],q[26];
u1(0) q[26];
u1(0) q[128];
cx q[128],q[27];
u1(0) q[27];
cx q[128],q[27];
u1(0) q[27];
u1(0) q[128];
cx q[128],q[28];
u1(0) q[28];
cx q[128],q[28];
u1(0) q[28];
u1(0) q[128];
cx q[128],q[29];
u1(0) q[29];
cx q[128],q[29];
u1(0) q[29];
u1(0) q[128];
cx q[128],q[30];
u1(0) q[30];
cx q[128],q[30];
u1(0) q[30];
u1(0) q[128];
cx q[128],q[31];
u1(0) q[31];
cx q[128],q[31];
u1(0) q[31];
u1(0) q[128];
cx q[128],q[32];
u1(0) q[32];
cx q[128],q[32];
u1(0) q[32];
u1(0) q[128];
cx q[128],q[33];
u1(0) q[33];
cx q[128],q[33];
u1(0) q[33];
u1(0) q[128];
cx q[128],q[34];
u1(0) q[34];
cx q[128],q[34];
u1(0) q[34];
u1(0) q[128];
cx q[128],q[35];
u1(0) q[35];
cx q[128],q[35];
u1(0) q[35];
u1(0) q[128];
cx q[128],q[36];
u1(0) q[36];
cx q[128],q[36];
u1(0) q[36];
u1(0) q[128];
cx q[128],q[37];
u1(0) q[37];
cx q[128],q[37];
u1(0) q[37];
u1(0) q[128];
cx q[128],q[38];
u1(0) q[38];
cx q[128],q[38];
u1(0) q[38];
u1(0) q[128];
cx q[128],q[39];
u1(0) q[39];
cx q[128],q[39];
u1(0) q[39];
u1(0) q[128];
cx q[128],q[40];
u1(0) q[40];
cx q[128],q[40];
u1(0) q[40];
u1(0) q[128];
cx q[128],q[41];
u1(0) q[41];
cx q[128],q[41];
u1(0) q[41];
u1(0) q[128];
cx q[128],q[42];
u1(0) q[42];
cx q[128],q[42];
u1(0) q[42];
u1(0) q[128];
cx q[128],q[43];
u1(0) q[43];
cx q[128],q[43];
u1(0) q[43];
u1(0) q[128];
cx q[128],q[44];
u1(0) q[44];
cx q[128],q[44];
u1(0) q[44];
u1(0) q[128];
cx q[128],q[45];
u1(0) q[45];
cx q[128],q[45];
u1(0) q[45];
u1(0) q[128];
cx q[128],q[46];
u1(0) q[46];
cx q[128],q[46];
u1(0) q[46];
u1(0) q[128];
cx q[128],q[47];
u1(0) q[47];
cx q[128],q[47];
u1(0) q[47];
u1(0) q[128];
cx q[128],q[48];
u1(0) q[48];
cx q[128],q[48];
u1(0) q[48];
u1(0) q[128];
cx q[128],q[49];
u1(0) q[49];
cx q[128],q[49];
u1(0) q[49];
u1(0) q[128];
cx q[128],q[50];
u1(0) q[50];
cx q[128],q[50];
u1(0) q[50];
u1(0) q[128];
cx q[128],q[51];
u1(0) q[51];
cx q[128],q[51];
u1(0) q[51];
u1(0) q[128];
cx q[128],q[52];
u1(0) q[52];
cx q[128],q[52];
u1(0) q[52];
u1(0) q[128];
cx q[128],q[53];
u1(0) q[53];
cx q[128],q[53];
u1(0) q[53];
u1(0) q[128];
cx q[128],q[54];
u1(0) q[54];
cx q[128],q[54];
u1(0) q[54];
u1(0) q[128];
cx q[128],q[55];
u1(0) q[55];
cx q[128],q[55];
u1(0) q[55];
u1(0) q[128];
cx q[128],q[56];
u1(0) q[56];
cx q[128],q[56];
u1(0) q[56];
u1(0) q[128];
cx q[128],q[57];
u1(0) q[57];
cx q[128],q[57];
u1(0) q[57];
u1(0) q[128];
cx q[128],q[58];
u1(0) q[58];
cx q[128],q[58];
u1(0) q[58];
u1(0) q[128];
cx q[128],q[59];
u1(0) q[59];
cx q[128],q[59];
u1(0) q[59];
u1(0) q[128];
cx q[128],q[60];
u1(0) q[60];
cx q[128],q[60];
u1(0) q[60];
u1(0) q[128];
cx q[128],q[61];
u1(0) q[61];
cx q[128],q[61];
u1(0) q[61];
u1(0) q[128];
cx q[128],q[62];
u1(0) q[62];
cx q[128],q[62];
u1(0) q[62];
u1(0) q[128];
cx q[128],q[63];
u1(0) q[63];
cx q[128],q[63];
u1(0) q[63];
u1(0) q[128];
cx q[128],q[64];
u1(0) q[64];
cx q[128],q[64];
u1(0) q[64];
u1(0) q[128];
cx q[128],q[65];
u1(0) q[65];
cx q[128],q[65];
u1(0) q[65];
u1(0) q[128];
cx q[128],q[66];
u1(0) q[66];
cx q[128],q[66];
u1(0) q[66];
u1(0) q[128];
cx q[128],q[67];
u1(0) q[67];
cx q[128],q[67];
u1(0) q[67];
u1(0) q[128];
cx q[128],q[68];
u1(0) q[68];
cx q[128],q[68];
u1(0) q[68];
u1(0) q[128];
cx q[128],q[69];
u1(0) q[69];
cx q[128],q[69];
u1(0) q[69];
u1(0) q[128];
cx q[128],q[70];
u1(0) q[70];
cx q[128],q[70];
u1(0) q[70];
u1(0) q[128];
cx q[128],q[71];
u1(0) q[71];
cx q[128],q[71];
u1(0) q[71];
u1(0) q[128];
cx q[128],q[72];
u1(0) q[72];
cx q[128],q[72];
u1(0) q[72];
u1(0) q[128];
cx q[128],q[73];
u1(0) q[73];
cx q[128],q[73];
u1(0) q[73];
u1(0) q[128];
cx q[128],q[74];
u1(0) q[74];
cx q[128],q[74];
u1(0) q[74];
u1(0) q[128];
cx q[128],q[75];
u1(0) q[75];
cx q[128],q[75];
u1(0) q[75];
u1(0) q[128];
cx q[128],q[76];
u1(0) q[76];
cx q[128],q[76];
u1(0) q[76];
u1(0) q[128];
cx q[128],q[77];
u1(0) q[77];
cx q[128],q[77];
u1(0) q[77];
u1(0) q[128];
cx q[128],q[78];
u1(0) q[78];
cx q[128],q[78];
u1(0) q[78];
u1(0) q[128];
cx q[128],q[79];
u1(0) q[79];
cx q[128],q[79];
u1(0) q[79];
u1(0) q[128];
cx q[128],q[80];
u1(0) q[80];
cx q[128],q[80];
u1(0) q[80];
u1(pi/281474976710656) q[128];
cx q[128],q[81];
u1(-pi/281474976710656) q[81];
cx q[128],q[81];
u1(pi/281474976710656) q[81];
u1(pi/140737488355328) q[128];
cx q[128],q[82];
u1(-pi/140737488355328) q[82];
cx q[128],q[82];
u1(pi/140737488355328) q[82];
u1(pi/70368744177664) q[128];
cx q[128],q[83];
u1(-pi/70368744177664) q[83];
cx q[128],q[83];
u1(pi/70368744177664) q[83];
u1(pi/35184372088832) q[128];
cx q[128],q[84];
u1(-pi/35184372088832) q[84];
cx q[128],q[84];
u1(pi/35184372088832) q[84];
u1(pi/17592186044416) q[128];
cx q[128],q[85];
u1(-pi/17592186044416) q[85];
cx q[128],q[85];
u1(pi/17592186044416) q[85];
u1(pi/8796093022208) q[128];
cx q[128],q[86];
u1(-pi/8796093022208) q[86];
cx q[128],q[86];
u1(pi/8796093022208) q[86];
u1(pi/4398046511104) q[128];
cx q[128],q[87];
u1(-pi/4398046511104) q[87];
cx q[128],q[87];
u1(pi/4398046511104) q[87];
u1(pi/2199023255552) q[128];
cx q[128],q[88];
u1(-pi/2199023255552) q[88];
cx q[128],q[88];
u1(pi/2199023255552) q[88];
u1(pi/1099511627776) q[128];
cx q[128],q[89];
u1(-pi/1099511627776) q[89];
cx q[128],q[89];
u1(pi/1099511627776) q[89];
u1(pi/549755813888) q[128];
cx q[128],q[90];
u1(-pi/549755813888) q[90];
cx q[128],q[90];
u1(pi/549755813888) q[90];
u1(pi/274877906944) q[128];
cx q[128],q[91];
u1(-pi/274877906944) q[91];
cx q[128],q[91];
u1(pi/274877906944) q[91];
u1(pi/137438953472) q[128];
cx q[128],q[92];
u1(-pi/137438953472) q[92];
cx q[128],q[92];
u1(pi/137438953472) q[92];
u1(pi/68719476736) q[128];
cx q[128],q[93];
u1(-pi/68719476736) q[93];
cx q[128],q[93];
u1(pi/68719476736) q[93];
u1(pi/34359738368) q[128];
cx q[128],q[94];
u1(-pi/34359738368) q[94];
cx q[128],q[94];
u1(pi/34359738368) q[94];
u1(pi/17179869184) q[128];
cx q[128],q[95];
u1(-pi/17179869184) q[95];
cx q[128],q[95];
u1(pi/17179869184) q[95];
u1(pi/8589934592) q[128];
cx q[128],q[96];
u1(-pi/8589934592) q[96];
cx q[128],q[96];
u1(pi/8589934592) q[96];
u1(pi/4294967296) q[128];
cx q[128],q[97];
u1(-pi/4294967296) q[97];
cx q[128],q[97];
u1(pi/4294967296) q[97];
u1(pi/2147483648) q[128];
cx q[128],q[98];
u1(-pi/2147483648) q[98];
cx q[128],q[98];
u1(pi/2147483648) q[98];
u1(pi/1073741824) q[128];
cx q[128],q[99];
u1(-pi/1073741824) q[99];
cx q[128],q[99];
u1(pi/1073741824) q[99];
u1(pi/536870912) q[128];
cx q[128],q[100];
u1(-pi/536870912) q[100];
cx q[128],q[100];
u1(pi/536870912) q[100];
u1(pi/268435456) q[128];
cx q[128],q[101];
u1(-pi/268435456) q[101];
cx q[128],q[101];
u1(pi/268435456) q[101];
u1(pi/134217728) q[128];
cx q[128],q[102];
u1(-pi/134217728) q[102];
cx q[128],q[102];
u1(pi/134217728) q[102];
u1(pi/67108864) q[128];
cx q[128],q[103];
u1(-pi/67108864) q[103];
cx q[128],q[103];
u1(pi/67108864) q[103];
u1(pi/33554432) q[128];
cx q[128],q[104];
u1(-pi/33554432) q[104];
cx q[128],q[104];
u1(pi/33554432) q[104];
u1(pi/16777216) q[128];
cx q[128],q[105];
u1(-pi/16777216) q[105];
cx q[128],q[105];
u1(pi/16777216) q[105];
u1(pi/8388608) q[128];
cx q[128],q[106];
u1(-pi/8388608) q[106];
cx q[128],q[106];
u1(pi/8388608) q[106];
u1(pi/4194304) q[128];
cx q[128],q[107];
u1(-pi/4194304) q[107];
cx q[128],q[107];
u1(pi/4194304) q[107];
u1(pi/2097152) q[128];
cx q[128],q[108];
u1(-pi/2097152) q[108];
cx q[128],q[108];
u1(pi/2097152) q[108];
u1(pi/1048576) q[128];
cx q[128],q[109];
u1(-pi/1048576) q[109];
cx q[128],q[109];
u1(pi/1048576) q[109];
u1(pi/524288) q[128];
cx q[128],q[110];
u1(-pi/524288) q[110];
cx q[128],q[110];
u1(pi/524288) q[110];
u1(pi/262144) q[128];
cx q[128],q[111];
u1(-pi/262144) q[111];
cx q[128],q[111];
u1(pi/262144) q[111];
u1(pi/131072) q[128];
cx q[128],q[112];
u1(-pi/131072) q[112];
cx q[128],q[112];
u1(pi/131072) q[112];
u1(pi/65536) q[128];
cx q[128],q[113];
u1(-pi/65536) q[113];
cx q[128],q[113];
u1(pi/65536) q[113];
u1(pi/32768) q[128];
cx q[128],q[114];
u1(-pi/32768) q[114];
cx q[128],q[114];
u1(pi/32768) q[114];
u1(pi/16384) q[128];
cx q[128],q[115];
u1(-pi/16384) q[115];
cx q[128],q[115];
u1(pi/16384) q[115];
u1(pi/8192) q[128];
cx q[128],q[116];
u1(-pi/8192) q[116];
cx q[128],q[116];
u1(pi/8192) q[116];
u1(pi/4096) q[128];
cx q[128],q[117];
u1(-pi/4096) q[117];
cx q[128],q[117];
u1(pi/4096) q[117];
u1(pi/2048) q[128];
cx q[128],q[118];
u1(-pi/2048) q[118];
cx q[128],q[118];
u1(pi/2048) q[118];
u1(pi/1024) q[128];
cx q[128],q[119];
u1(-pi/1024) q[119];
cx q[128],q[119];
u1(pi/1024) q[119];
u1(pi/512) q[128];
cx q[128],q[120];
u1(-pi/512) q[120];
cx q[128],q[120];
u1(pi/512) q[120];
u1(pi/256) q[128];
cx q[128],q[121];
u1(-pi/256) q[121];
cx q[128],q[121];
u1(pi/256) q[121];
u1(pi/128) q[128];
cx q[128],q[122];
u1(-pi/128) q[122];
cx q[128],q[122];
u1(pi/128) q[122];
u1(pi/64) q[128];
cx q[128],q[123];
u1(-pi/64) q[123];
cx q[128],q[123];
u1(pi/64) q[123];
u1(pi/32) q[128];
cx q[128],q[124];
u1(-pi/32) q[124];
cx q[128],q[124];
u1(pi/32) q[124];
u1(pi/16) q[128];
cx q[128],q[125];
u1(-pi/16) q[125];
cx q[128],q[125];
u1(pi/16) q[125];
u1(pi/8) q[128];
cx q[128],q[126];
u1(-pi/8) q[126];
cx q[128],q[126];
u1(pi/8) q[126];
u1(pi/4) q[128];
cx q[128],q[127];
u1(-pi/4) q[127];
cx q[128],q[127];
u1(pi/4) q[127];
h q[128];
u1(0) q[129];
cx q[129],q[0];
u1(0) q[0];
cx q[129],q[0];
u1(0) q[0];
u1(0) q[129];
cx q[129],q[1];
u1(0) q[1];
cx q[129],q[1];
u1(0) q[1];
u1(0) q[129];
cx q[129],q[2];
u1(0) q[2];
cx q[129],q[2];
u1(0) q[2];
u1(0) q[129];
cx q[129],q[3];
u1(0) q[3];
cx q[129],q[3];
u1(0) q[3];
u1(0) q[129];
cx q[129],q[4];
u1(0) q[4];
cx q[129],q[4];
u1(0) q[4];
u1(0) q[129];
cx q[129],q[5];
u1(0) q[5];
cx q[129],q[5];
u1(0) q[5];
u1(0) q[129];
cx q[129],q[6];
u1(0) q[6];
cx q[129],q[6];
u1(0) q[6];
u1(0) q[129];
cx q[129],q[7];
u1(0) q[7];
cx q[129],q[7];
u1(0) q[7];
u1(0) q[129];
cx q[129],q[8];
u1(0) q[8];
cx q[129],q[8];
u1(0) q[8];
u1(0) q[129];
cx q[129],q[9];
u1(0) q[9];
cx q[129],q[9];
u1(0) q[9];
u1(0) q[129];
cx q[129],q[10];
u1(0) q[10];
cx q[129],q[10];
u1(0) q[10];
u1(0) q[129];
cx q[129],q[11];
u1(0) q[11];
cx q[129],q[11];
u1(0) q[11];
u1(0) q[129];
cx q[129],q[12];
u1(0) q[12];
cx q[129],q[12];
u1(0) q[12];
u1(0) q[129];
cx q[129],q[13];
u1(0) q[13];
cx q[129],q[13];
u1(0) q[13];
u1(0) q[129];
cx q[129],q[14];
u1(0) q[14];
cx q[129],q[14];
u1(0) q[14];
u1(0) q[129];
cx q[129],q[15];
u1(0) q[15];
cx q[129],q[15];
u1(0) q[15];
u1(0) q[129];
cx q[129],q[16];
u1(0) q[16];
cx q[129],q[16];
u1(0) q[16];
u1(0) q[129];
cx q[129],q[17];
u1(0) q[17];
cx q[129],q[17];
u1(0) q[17];
u1(0) q[129];
cx q[129],q[18];
u1(0) q[18];
cx q[129],q[18];
u1(0) q[18];
u1(0) q[129];
cx q[129],q[19];
u1(0) q[19];
cx q[129],q[19];
u1(0) q[19];
u1(0) q[129];
cx q[129],q[20];
u1(0) q[20];
cx q[129],q[20];
u1(0) q[20];
u1(0) q[129];
cx q[129],q[21];
u1(0) q[21];
cx q[129],q[21];
u1(0) q[21];
u1(0) q[129];
cx q[129],q[22];
u1(0) q[22];
cx q[129],q[22];
u1(0) q[22];
u1(0) q[129];
cx q[129],q[23];
u1(0) q[23];
cx q[129],q[23];
u1(0) q[23];
u1(0) q[129];
cx q[129],q[24];
u1(0) q[24];
cx q[129],q[24];
u1(0) q[24];
u1(0) q[129];
cx q[129],q[25];
u1(0) q[25];
cx q[129],q[25];
u1(0) q[25];
u1(0) q[129];
cx q[129],q[26];
u1(0) q[26];
cx q[129],q[26];
u1(0) q[26];
u1(0) q[129];
cx q[129],q[27];
u1(0) q[27];
cx q[129],q[27];
u1(0) q[27];
u1(0) q[129];
cx q[129],q[28];
u1(0) q[28];
cx q[129],q[28];
u1(0) q[28];
u1(0) q[129];
cx q[129],q[29];
u1(0) q[29];
cx q[129],q[29];
u1(0) q[29];
u1(0) q[129];
cx q[129],q[30];
u1(0) q[30];
cx q[129],q[30];
u1(0) q[30];
u1(0) q[129];
cx q[129],q[31];
u1(0) q[31];
cx q[129],q[31];
u1(0) q[31];
u1(0) q[129];
cx q[129],q[32];
u1(0) q[32];
cx q[129],q[32];
u1(0) q[32];
u1(0) q[129];
cx q[129],q[33];
u1(0) q[33];
cx q[129],q[33];
u1(0) q[33];
u1(0) q[129];
cx q[129],q[34];
u1(0) q[34];
cx q[129],q[34];
u1(0) q[34];
u1(0) q[129];
cx q[129],q[35];
u1(0) q[35];
cx q[129],q[35];
u1(0) q[35];
u1(0) q[129];
cx q[129],q[36];
u1(0) q[36];
cx q[129],q[36];
u1(0) q[36];
u1(0) q[129];
cx q[129],q[37];
u1(0) q[37];
cx q[129],q[37];
u1(0) q[37];
u1(0) q[129];
cx q[129],q[38];
u1(0) q[38];
cx q[129],q[38];
u1(0) q[38];
u1(0) q[129];
cx q[129],q[39];
u1(0) q[39];
cx q[129],q[39];
u1(0) q[39];
u1(0) q[129];
cx q[129],q[40];
u1(0) q[40];
cx q[129],q[40];
u1(0) q[40];
u1(0) q[129];
cx q[129],q[41];
u1(0) q[41];
cx q[129],q[41];
u1(0) q[41];
u1(0) q[129];
cx q[129],q[42];
u1(0) q[42];
cx q[129],q[42];
u1(0) q[42];
u1(0) q[129];
cx q[129],q[43];
u1(0) q[43];
cx q[129],q[43];
u1(0) q[43];
u1(0) q[129];
cx q[129],q[44];
u1(0) q[44];
cx q[129],q[44];
u1(0) q[44];
u1(0) q[129];
cx q[129],q[45];
u1(0) q[45];
cx q[129],q[45];
u1(0) q[45];
u1(0) q[129];
cx q[129],q[46];
u1(0) q[46];
cx q[129],q[46];
u1(0) q[46];
u1(0) q[129];
cx q[129],q[47];
u1(0) q[47];
cx q[129],q[47];
u1(0) q[47];
u1(0) q[129];
cx q[129],q[48];
u1(0) q[48];
cx q[129],q[48];
u1(0) q[48];
u1(0) q[129];
cx q[129],q[49];
u1(0) q[49];
cx q[129],q[49];
u1(0) q[49];
u1(0) q[129];
cx q[129],q[50];
u1(0) q[50];
cx q[129],q[50];
u1(0) q[50];
u1(0) q[129];
cx q[129],q[51];
u1(0) q[51];
cx q[129],q[51];
u1(0) q[51];
u1(0) q[129];
cx q[129],q[52];
u1(0) q[52];
cx q[129],q[52];
u1(0) q[52];
u1(0) q[129];
cx q[129],q[53];
u1(0) q[53];
cx q[129],q[53];
u1(0) q[53];
u1(0) q[129];
cx q[129],q[54];
u1(0) q[54];
cx q[129],q[54];
u1(0) q[54];
u1(0) q[129];
cx q[129],q[55];
u1(0) q[55];
cx q[129],q[55];
u1(0) q[55];
u1(0) q[129];
cx q[129],q[56];
u1(0) q[56];
cx q[129],q[56];
u1(0) q[56];
u1(0) q[129];
cx q[129],q[57];
u1(0) q[57];
cx q[129],q[57];
u1(0) q[57];
u1(0) q[129];
cx q[129],q[58];
u1(0) q[58];
cx q[129],q[58];
u1(0) q[58];
u1(0) q[129];
cx q[129],q[59];
u1(0) q[59];
cx q[129],q[59];
u1(0) q[59];
u1(0) q[129];
cx q[129],q[60];
u1(0) q[60];
cx q[129],q[60];
u1(0) q[60];
u1(0) q[129];
cx q[129],q[61];
u1(0) q[61];
cx q[129],q[61];
u1(0) q[61];
u1(0) q[129];
cx q[129],q[62];
u1(0) q[62];
cx q[129],q[62];
u1(0) q[62];
u1(0) q[129];
cx q[129],q[63];
u1(0) q[63];
cx q[129],q[63];
u1(0) q[63];
u1(0) q[129];
cx q[129],q[64];
u1(0) q[64];
cx q[129],q[64];
u1(0) q[64];
u1(0) q[129];
cx q[129],q[65];
u1(0) q[65];
cx q[129],q[65];
u1(0) q[65];
u1(0) q[129];
cx q[129],q[66];
u1(0) q[66];
cx q[129],q[66];
u1(0) q[66];
u1(0) q[129];
cx q[129],q[67];
u1(0) q[67];
cx q[129],q[67];
u1(0) q[67];
u1(0) q[129];
cx q[129],q[68];
u1(0) q[68];
cx q[129],q[68];
u1(0) q[68];
u1(0) q[129];
cx q[129],q[69];
u1(0) q[69];
cx q[129],q[69];
u1(0) q[69];
u1(0) q[129];
cx q[129],q[70];
u1(0) q[70];
cx q[129],q[70];
u1(0) q[70];
u1(0) q[129];
cx q[129],q[71];
u1(0) q[71];
cx q[129],q[71];
u1(0) q[71];
u1(0) q[129];
cx q[129],q[72];
u1(0) q[72];
cx q[129],q[72];
u1(0) q[72];
u1(0) q[129];
cx q[129],q[73];
u1(0) q[73];
cx q[129],q[73];
u1(0) q[73];
u1(0) q[129];
cx q[129],q[74];
u1(0) q[74];
cx q[129],q[74];
u1(0) q[74];
u1(0) q[129];
cx q[129],q[75];
u1(0) q[75];
cx q[129],q[75];
u1(0) q[75];
u1(0) q[129];
cx q[129],q[76];
u1(0) q[76];
cx q[129],q[76];
u1(0) q[76];
u1(0) q[129];
cx q[129],q[77];
u1(0) q[77];
cx q[129],q[77];
u1(0) q[77];
u1(0) q[129];
cx q[129],q[78];
u1(0) q[78];
cx q[129],q[78];
u1(0) q[78];
u1(0) q[129];
cx q[129],q[79];
u1(0) q[79];
cx q[129],q[79];
u1(0) q[79];
u1(0) q[129];
cx q[129],q[80];
u1(0) q[80];
cx q[129],q[80];
u1(0) q[80];
u1(0) q[129];
cx q[129],q[81];
u1(0) q[81];
cx q[129],q[81];
u1(0) q[81];
u1(pi/281474976710656) q[129];
cx q[129],q[82];
u1(-pi/281474976710656) q[82];
cx q[129],q[82];
u1(pi/281474976710656) q[82];
u1(pi/140737488355328) q[129];
cx q[129],q[83];
u1(-pi/140737488355328) q[83];
cx q[129],q[83];
u1(pi/140737488355328) q[83];
u1(pi/70368744177664) q[129];
cx q[129],q[84];
u1(-pi/70368744177664) q[84];
cx q[129],q[84];
u1(pi/70368744177664) q[84];
u1(pi/35184372088832) q[129];
cx q[129],q[85];
u1(-pi/35184372088832) q[85];
cx q[129],q[85];
u1(pi/35184372088832) q[85];
u1(pi/17592186044416) q[129];
cx q[129],q[86];
u1(-pi/17592186044416) q[86];
cx q[129],q[86];
u1(pi/17592186044416) q[86];
u1(pi/8796093022208) q[129];
cx q[129],q[87];
u1(-pi/8796093022208) q[87];
cx q[129],q[87];
u1(pi/8796093022208) q[87];
u1(pi/4398046511104) q[129];
cx q[129],q[88];
u1(-pi/4398046511104) q[88];
cx q[129],q[88];
u1(pi/4398046511104) q[88];
u1(pi/2199023255552) q[129];
cx q[129],q[89];
u1(-pi/2199023255552) q[89];
cx q[129],q[89];
u1(pi/2199023255552) q[89];
u1(pi/1099511627776) q[129];
cx q[129],q[90];
u1(-pi/1099511627776) q[90];
cx q[129],q[90];
u1(pi/1099511627776) q[90];
u1(pi/549755813888) q[129];
cx q[129],q[91];
u1(-pi/549755813888) q[91];
cx q[129],q[91];
u1(pi/549755813888) q[91];
u1(pi/274877906944) q[129];
cx q[129],q[92];
u1(-pi/274877906944) q[92];
cx q[129],q[92];
u1(pi/274877906944) q[92];
u1(pi/137438953472) q[129];
cx q[129],q[93];
u1(-pi/137438953472) q[93];
cx q[129],q[93];
u1(pi/137438953472) q[93];
u1(pi/68719476736) q[129];
cx q[129],q[94];
u1(-pi/68719476736) q[94];
cx q[129],q[94];
u1(pi/68719476736) q[94];
u1(pi/34359738368) q[129];
cx q[129],q[95];
u1(-pi/34359738368) q[95];
cx q[129],q[95];
u1(pi/34359738368) q[95];
u1(pi/17179869184) q[129];
cx q[129],q[96];
u1(-pi/17179869184) q[96];
cx q[129],q[96];
u1(pi/17179869184) q[96];
u1(pi/8589934592) q[129];
cx q[129],q[97];
u1(-pi/8589934592) q[97];
cx q[129],q[97];
u1(pi/8589934592) q[97];
u1(pi/4294967296) q[129];
cx q[129],q[98];
u1(-pi/4294967296) q[98];
cx q[129],q[98];
u1(pi/4294967296) q[98];
u1(pi/2147483648) q[129];
cx q[129],q[99];
u1(-pi/2147483648) q[99];
cx q[129],q[99];
u1(pi/2147483648) q[99];
u1(pi/1073741824) q[129];
cx q[129],q[100];
u1(-pi/1073741824) q[100];
cx q[129],q[100];
u1(pi/1073741824) q[100];
u1(pi/536870912) q[129];
cx q[129],q[101];
u1(-pi/536870912) q[101];
cx q[129],q[101];
u1(pi/536870912) q[101];
u1(pi/268435456) q[129];
cx q[129],q[102];
u1(-pi/268435456) q[102];
cx q[129],q[102];
u1(pi/268435456) q[102];
u1(pi/134217728) q[129];
cx q[129],q[103];
u1(-pi/134217728) q[103];
cx q[129],q[103];
u1(pi/134217728) q[103];
u1(pi/67108864) q[129];
cx q[129],q[104];
u1(-pi/67108864) q[104];
cx q[129],q[104];
u1(pi/67108864) q[104];
u1(pi/33554432) q[129];
cx q[129],q[105];
u1(-pi/33554432) q[105];
cx q[129],q[105];
u1(pi/33554432) q[105];
u1(pi/16777216) q[129];
cx q[129],q[106];
u1(-pi/16777216) q[106];
cx q[129],q[106];
u1(pi/16777216) q[106];
u1(pi/8388608) q[129];
cx q[129],q[107];
u1(-pi/8388608) q[107];
cx q[129],q[107];
u1(pi/8388608) q[107];
u1(pi/4194304) q[129];
cx q[129],q[108];
u1(-pi/4194304) q[108];
cx q[129],q[108];
u1(pi/4194304) q[108];
u1(pi/2097152) q[129];
cx q[129],q[109];
u1(-pi/2097152) q[109];
cx q[129],q[109];
u1(pi/2097152) q[109];
u1(pi/1048576) q[129];
cx q[129],q[110];
u1(-pi/1048576) q[110];
cx q[129],q[110];
u1(pi/1048576) q[110];
u1(pi/524288) q[129];
cx q[129],q[111];
u1(-pi/524288) q[111];
cx q[129],q[111];
u1(pi/524288) q[111];
u1(pi/262144) q[129];
cx q[129],q[112];
u1(-pi/262144) q[112];
cx q[129],q[112];
u1(pi/262144) q[112];
u1(pi/131072) q[129];
cx q[129],q[113];
u1(-pi/131072) q[113];
cx q[129],q[113];
u1(pi/131072) q[113];
u1(pi/65536) q[129];
cx q[129],q[114];
u1(-pi/65536) q[114];
cx q[129],q[114];
u1(pi/65536) q[114];
u1(pi/32768) q[129];
cx q[129],q[115];
u1(-pi/32768) q[115];
cx q[129],q[115];
u1(pi/32768) q[115];
u1(pi/16384) q[129];
cx q[129],q[116];
u1(-pi/16384) q[116];
cx q[129],q[116];
u1(pi/16384) q[116];
u1(pi/8192) q[129];
cx q[129],q[117];
u1(-pi/8192) q[117];
cx q[129],q[117];
u1(pi/8192) q[117];
u1(pi/4096) q[129];
cx q[129],q[118];
u1(-pi/4096) q[118];
cx q[129],q[118];
u1(pi/4096) q[118];
u1(pi/2048) q[129];
cx q[129],q[119];
u1(-pi/2048) q[119];
cx q[129],q[119];
u1(pi/2048) q[119];
u1(pi/1024) q[129];
cx q[129],q[120];
u1(-pi/1024) q[120];
cx q[129],q[120];
u1(pi/1024) q[120];
u1(pi/512) q[129];
cx q[129],q[121];
u1(-pi/512) q[121];
cx q[129],q[121];
u1(pi/512) q[121];
u1(pi/256) q[129];
cx q[129],q[122];
u1(-pi/256) q[122];
cx q[129],q[122];
u1(pi/256) q[122];
u1(pi/128) q[129];
cx q[129],q[123];
u1(-pi/128) q[123];
cx q[129],q[123];
u1(pi/128) q[123];
u1(pi/64) q[129];
cx q[129],q[124];
u1(-pi/64) q[124];
cx q[129],q[124];
u1(pi/64) q[124];
u1(pi/32) q[129];
cx q[129],q[125];
u1(-pi/32) q[125];
cx q[129],q[125];
u1(pi/32) q[125];
u1(pi/16) q[129];
cx q[129],q[126];
u1(-pi/16) q[126];
cx q[129],q[126];
u1(pi/16) q[126];
u1(pi/8) q[129];
cx q[129],q[127];
u1(-pi/8) q[127];
cx q[129],q[127];
u1(pi/8) q[127];
u1(pi/4) q[129];
cx q[129],q[128];
u1(-pi/4) q[128];
cx q[129],q[128];
u1(pi/4) q[128];
h q[129];
u1(0) q[130];
cx q[130],q[0];
u1(0) q[0];
cx q[130],q[0];
u1(0) q[0];
u1(0) q[130];
cx q[130],q[1];
u1(0) q[1];
cx q[130],q[1];
u1(0) q[1];
u1(0) q[130];
cx q[130],q[2];
u1(0) q[2];
cx q[130],q[2];
u1(0) q[2];
u1(0) q[130];
cx q[130],q[3];
u1(0) q[3];
cx q[130],q[3];
u1(0) q[3];
u1(0) q[130];
cx q[130],q[4];
u1(0) q[4];
cx q[130],q[4];
u1(0) q[4];
u1(0) q[130];
cx q[130],q[5];
u1(0) q[5];
cx q[130],q[5];
u1(0) q[5];
u1(0) q[130];
cx q[130],q[6];
u1(0) q[6];
cx q[130],q[6];
u1(0) q[6];
u1(0) q[130];
cx q[130],q[7];
u1(0) q[7];
cx q[130],q[7];
u1(0) q[7];
u1(0) q[130];
cx q[130],q[8];
u1(0) q[8];
cx q[130],q[8];
u1(0) q[8];
u1(0) q[130];
cx q[130],q[9];
u1(0) q[9];
cx q[130],q[9];
u1(0) q[9];
u1(0) q[130];
cx q[130],q[10];
u1(0) q[10];
cx q[130],q[10];
u1(0) q[10];
u1(0) q[130];
cx q[130],q[11];
u1(0) q[11];
cx q[130],q[11];
u1(0) q[11];
u1(0) q[130];
cx q[130],q[12];
u1(0) q[12];
cx q[130],q[12];
u1(0) q[12];
u1(0) q[130];
cx q[130],q[13];
u1(0) q[13];
cx q[130],q[13];
u1(0) q[13];
u1(0) q[130];
cx q[130],q[14];
u1(0) q[14];
cx q[130],q[14];
u1(0) q[14];
u1(0) q[130];
cx q[130],q[15];
u1(0) q[15];
cx q[130],q[15];
u1(0) q[15];
u1(0) q[130];
cx q[130],q[16];
u1(0) q[16];
cx q[130],q[16];
u1(0) q[16];
u1(0) q[130];
cx q[130],q[17];
u1(0) q[17];
cx q[130],q[17];
u1(0) q[17];
u1(0) q[130];
cx q[130],q[18];
u1(0) q[18];
cx q[130],q[18];
u1(0) q[18];
u1(0) q[130];
cx q[130],q[19];
u1(0) q[19];
cx q[130],q[19];
u1(0) q[19];
u1(0) q[130];
cx q[130],q[20];
u1(0) q[20];
cx q[130],q[20];
u1(0) q[20];
u1(0) q[130];
cx q[130],q[21];
u1(0) q[21];
cx q[130],q[21];
u1(0) q[21];
u1(0) q[130];
cx q[130],q[22];
u1(0) q[22];
cx q[130],q[22];
u1(0) q[22];
u1(0) q[130];
cx q[130],q[23];
u1(0) q[23];
cx q[130],q[23];
u1(0) q[23];
u1(0) q[130];
cx q[130],q[24];
u1(0) q[24];
cx q[130],q[24];
u1(0) q[24];
u1(0) q[130];
cx q[130],q[25];
u1(0) q[25];
cx q[130],q[25];
u1(0) q[25];
u1(0) q[130];
cx q[130],q[26];
u1(0) q[26];
cx q[130],q[26];
u1(0) q[26];
u1(0) q[130];
cx q[130],q[27];
u1(0) q[27];
cx q[130],q[27];
u1(0) q[27];
u1(0) q[130];
cx q[130],q[28];
u1(0) q[28];
cx q[130],q[28];
u1(0) q[28];
u1(0) q[130];
cx q[130],q[29];
u1(0) q[29];
cx q[130],q[29];
u1(0) q[29];
u1(0) q[130];
cx q[130],q[30];
u1(0) q[30];
cx q[130],q[30];
u1(0) q[30];
u1(0) q[130];
cx q[130],q[31];
u1(0) q[31];
cx q[130],q[31];
u1(0) q[31];
u1(0) q[130];
cx q[130],q[32];
u1(0) q[32];
cx q[130],q[32];
u1(0) q[32];
u1(0) q[130];
cx q[130],q[33];
u1(0) q[33];
cx q[130],q[33];
u1(0) q[33];
u1(0) q[130];
cx q[130],q[34];
u1(0) q[34];
cx q[130],q[34];
u1(0) q[34];
u1(0) q[130];
cx q[130],q[35];
u1(0) q[35];
cx q[130],q[35];
u1(0) q[35];
u1(0) q[130];
cx q[130],q[36];
u1(0) q[36];
cx q[130],q[36];
u1(0) q[36];
u1(0) q[130];
cx q[130],q[37];
u1(0) q[37];
cx q[130],q[37];
u1(0) q[37];
u1(0) q[130];
cx q[130],q[38];
u1(0) q[38];
cx q[130],q[38];
u1(0) q[38];
u1(0) q[130];
cx q[130],q[39];
u1(0) q[39];
cx q[130],q[39];
u1(0) q[39];
u1(0) q[130];
cx q[130],q[40];
u1(0) q[40];
cx q[130],q[40];
u1(0) q[40];
u1(0) q[130];
cx q[130],q[41];
u1(0) q[41];
cx q[130],q[41];
u1(0) q[41];
u1(0) q[130];
cx q[130],q[42];
u1(0) q[42];
cx q[130],q[42];
u1(0) q[42];
u1(0) q[130];
cx q[130],q[43];
u1(0) q[43];
cx q[130],q[43];
u1(0) q[43];
u1(0) q[130];
cx q[130],q[44];
u1(0) q[44];
cx q[130],q[44];
u1(0) q[44];
u1(0) q[130];
cx q[130],q[45];
u1(0) q[45];
cx q[130],q[45];
u1(0) q[45];
u1(0) q[130];
cx q[130],q[46];
u1(0) q[46];
cx q[130],q[46];
u1(0) q[46];
u1(0) q[130];
cx q[130],q[47];
u1(0) q[47];
cx q[130],q[47];
u1(0) q[47];
u1(0) q[130];
cx q[130],q[48];
u1(0) q[48];
cx q[130],q[48];
u1(0) q[48];
u1(0) q[130];
cx q[130],q[49];
u1(0) q[49];
cx q[130],q[49];
u1(0) q[49];
u1(0) q[130];
cx q[130],q[50];
u1(0) q[50];
cx q[130],q[50];
u1(0) q[50];
u1(0) q[130];
cx q[130],q[51];
u1(0) q[51];
cx q[130],q[51];
u1(0) q[51];
u1(0) q[130];
cx q[130],q[52];
u1(0) q[52];
cx q[130],q[52];
u1(0) q[52];
u1(0) q[130];
cx q[130],q[53];
u1(0) q[53];
cx q[130],q[53];
u1(0) q[53];
u1(0) q[130];
cx q[130],q[54];
u1(0) q[54];
cx q[130],q[54];
u1(0) q[54];
u1(0) q[130];
cx q[130],q[55];
u1(0) q[55];
cx q[130],q[55];
u1(0) q[55];
u1(0) q[130];
cx q[130],q[56];
u1(0) q[56];
cx q[130],q[56];
u1(0) q[56];
u1(0) q[130];
cx q[130],q[57];
u1(0) q[57];
cx q[130],q[57];
u1(0) q[57];
u1(0) q[130];
cx q[130],q[58];
u1(0) q[58];
cx q[130],q[58];
u1(0) q[58];
u1(0) q[130];
cx q[130],q[59];
u1(0) q[59];
cx q[130],q[59];
u1(0) q[59];
u1(0) q[130];
cx q[130],q[60];
u1(0) q[60];
cx q[130],q[60];
u1(0) q[60];
u1(0) q[130];
cx q[130],q[61];
u1(0) q[61];
cx q[130],q[61];
u1(0) q[61];
u1(0) q[130];
cx q[130],q[62];
u1(0) q[62];
cx q[130],q[62];
u1(0) q[62];
u1(0) q[130];
cx q[130],q[63];
u1(0) q[63];
cx q[130],q[63];
u1(0) q[63];
u1(0) q[130];
cx q[130],q[64];
u1(0) q[64];
cx q[130],q[64];
u1(0) q[64];
u1(0) q[130];
cx q[130],q[65];
u1(0) q[65];
cx q[130],q[65];
u1(0) q[65];
u1(0) q[130];
cx q[130],q[66];
u1(0) q[66];
cx q[130],q[66];
u1(0) q[66];
u1(0) q[130];
cx q[130],q[67];
u1(0) q[67];
cx q[130],q[67];
u1(0) q[67];
u1(0) q[130];
cx q[130],q[68];
u1(0) q[68];
cx q[130],q[68];
u1(0) q[68];
u1(0) q[130];
cx q[130],q[69];
u1(0) q[69];
cx q[130],q[69];
u1(0) q[69];
u1(0) q[130];
cx q[130],q[70];
u1(0) q[70];
cx q[130],q[70];
u1(0) q[70];
u1(0) q[130];
cx q[130],q[71];
u1(0) q[71];
cx q[130],q[71];
u1(0) q[71];
u1(0) q[130];
cx q[130],q[72];
u1(0) q[72];
cx q[130],q[72];
u1(0) q[72];
u1(0) q[130];
cx q[130],q[73];
u1(0) q[73];
cx q[130],q[73];
u1(0) q[73];
u1(0) q[130];
cx q[130],q[74];
u1(0) q[74];
cx q[130],q[74];
u1(0) q[74];
u1(0) q[130];
cx q[130],q[75];
u1(0) q[75];
cx q[130],q[75];
u1(0) q[75];
u1(0) q[130];
cx q[130],q[76];
u1(0) q[76];
cx q[130],q[76];
u1(0) q[76];
u1(0) q[130];
cx q[130],q[77];
u1(0) q[77];
cx q[130],q[77];
u1(0) q[77];
u1(0) q[130];
cx q[130],q[78];
u1(0) q[78];
cx q[130],q[78];
u1(0) q[78];
u1(0) q[130];
cx q[130],q[79];
u1(0) q[79];
cx q[130],q[79];
u1(0) q[79];
u1(0) q[130];
cx q[130],q[80];
u1(0) q[80];
cx q[130],q[80];
u1(0) q[80];
u1(0) q[130];
cx q[130],q[81];
u1(0) q[81];
cx q[130],q[81];
u1(0) q[81];
u1(0) q[130];
cx q[130],q[82];
u1(0) q[82];
cx q[130],q[82];
u1(0) q[82];
u1(pi/281474976710656) q[130];
cx q[130],q[83];
u1(-pi/281474976710656) q[83];
cx q[130],q[83];
u1(pi/281474976710656) q[83];
u1(pi/140737488355328) q[130];
cx q[130],q[84];
u1(-pi/140737488355328) q[84];
cx q[130],q[84];
u1(pi/140737488355328) q[84];
u1(pi/70368744177664) q[130];
cx q[130],q[85];
u1(-pi/70368744177664) q[85];
cx q[130],q[85];
u1(pi/70368744177664) q[85];
u1(pi/35184372088832) q[130];
cx q[130],q[86];
u1(-pi/35184372088832) q[86];
cx q[130],q[86];
u1(pi/35184372088832) q[86];
u1(pi/17592186044416) q[130];
cx q[130],q[87];
u1(-pi/17592186044416) q[87];
cx q[130],q[87];
u1(pi/17592186044416) q[87];
u1(pi/8796093022208) q[130];
cx q[130],q[88];
u1(-pi/8796093022208) q[88];
cx q[130],q[88];
u1(pi/8796093022208) q[88];
u1(pi/4398046511104) q[130];
cx q[130],q[89];
u1(-pi/4398046511104) q[89];
cx q[130],q[89];
u1(pi/4398046511104) q[89];
u1(pi/2199023255552) q[130];
cx q[130],q[90];
u1(-pi/2199023255552) q[90];
cx q[130],q[90];
u1(pi/2199023255552) q[90];
u1(pi/1099511627776) q[130];
cx q[130],q[91];
u1(-pi/1099511627776) q[91];
cx q[130],q[91];
u1(pi/1099511627776) q[91];
u1(pi/549755813888) q[130];
cx q[130],q[92];
u1(-pi/549755813888) q[92];
cx q[130],q[92];
u1(pi/549755813888) q[92];
u1(pi/274877906944) q[130];
cx q[130],q[93];
u1(-pi/274877906944) q[93];
cx q[130],q[93];
u1(pi/274877906944) q[93];
u1(pi/137438953472) q[130];
cx q[130],q[94];
u1(-pi/137438953472) q[94];
cx q[130],q[94];
u1(pi/137438953472) q[94];
u1(pi/68719476736) q[130];
cx q[130],q[95];
u1(-pi/68719476736) q[95];
cx q[130],q[95];
u1(pi/68719476736) q[95];
u1(pi/34359738368) q[130];
cx q[130],q[96];
u1(-pi/34359738368) q[96];
cx q[130],q[96];
u1(pi/34359738368) q[96];
u1(pi/17179869184) q[130];
cx q[130],q[97];
u1(-pi/17179869184) q[97];
cx q[130],q[97];
u1(pi/17179869184) q[97];
u1(pi/8589934592) q[130];
cx q[130],q[98];
u1(-pi/8589934592) q[98];
cx q[130],q[98];
u1(pi/8589934592) q[98];
u1(pi/4294967296) q[130];
cx q[130],q[99];
u1(-pi/4294967296) q[99];
cx q[130],q[99];
u1(pi/4294967296) q[99];
u1(pi/2147483648) q[130];
cx q[130],q[100];
u1(-pi/2147483648) q[100];
cx q[130],q[100];
u1(pi/2147483648) q[100];
u1(pi/1073741824) q[130];
cx q[130],q[101];
u1(-pi/1073741824) q[101];
cx q[130],q[101];
u1(pi/1073741824) q[101];
u1(pi/536870912) q[130];
cx q[130],q[102];
u1(-pi/536870912) q[102];
cx q[130],q[102];
u1(pi/536870912) q[102];
u1(pi/268435456) q[130];
cx q[130],q[103];
u1(-pi/268435456) q[103];
cx q[130],q[103];
u1(pi/268435456) q[103];
u1(pi/134217728) q[130];
cx q[130],q[104];
u1(-pi/134217728) q[104];
cx q[130],q[104];
u1(pi/134217728) q[104];
u1(pi/67108864) q[130];
cx q[130],q[105];
u1(-pi/67108864) q[105];
cx q[130],q[105];
u1(pi/67108864) q[105];
u1(pi/33554432) q[130];
cx q[130],q[106];
u1(-pi/33554432) q[106];
cx q[130],q[106];
u1(pi/33554432) q[106];
u1(pi/16777216) q[130];
cx q[130],q[107];
u1(-pi/16777216) q[107];
cx q[130],q[107];
u1(pi/16777216) q[107];
u1(pi/8388608) q[130];
cx q[130],q[108];
u1(-pi/8388608) q[108];
cx q[130],q[108];
u1(pi/8388608) q[108];
u1(pi/4194304) q[130];
cx q[130],q[109];
u1(-pi/4194304) q[109];
cx q[130],q[109];
u1(pi/4194304) q[109];
u1(pi/2097152) q[130];
cx q[130],q[110];
u1(-pi/2097152) q[110];
cx q[130],q[110];
u1(pi/2097152) q[110];
u1(pi/1048576) q[130];
cx q[130],q[111];
u1(-pi/1048576) q[111];
cx q[130],q[111];
u1(pi/1048576) q[111];
u1(pi/524288) q[130];
cx q[130],q[112];
u1(-pi/524288) q[112];
cx q[130],q[112];
u1(pi/524288) q[112];
u1(pi/262144) q[130];
cx q[130],q[113];
u1(-pi/262144) q[113];
cx q[130],q[113];
u1(pi/262144) q[113];
u1(pi/131072) q[130];
cx q[130],q[114];
u1(-pi/131072) q[114];
cx q[130],q[114];
u1(pi/131072) q[114];
u1(pi/65536) q[130];
cx q[130],q[115];
u1(-pi/65536) q[115];
cx q[130],q[115];
u1(pi/65536) q[115];
u1(pi/32768) q[130];
cx q[130],q[116];
u1(-pi/32768) q[116];
cx q[130],q[116];
u1(pi/32768) q[116];
u1(pi/16384) q[130];
cx q[130],q[117];
u1(-pi/16384) q[117];
cx q[130],q[117];
u1(pi/16384) q[117];
u1(pi/8192) q[130];
cx q[130],q[118];
u1(-pi/8192) q[118];
cx q[130],q[118];
u1(pi/8192) q[118];
u1(pi/4096) q[130];
cx q[130],q[119];
u1(-pi/4096) q[119];
cx q[130],q[119];
u1(pi/4096) q[119];
u1(pi/2048) q[130];
cx q[130],q[120];
u1(-pi/2048) q[120];
cx q[130],q[120];
u1(pi/2048) q[120];
u1(pi/1024) q[130];
cx q[130],q[121];
u1(-pi/1024) q[121];
cx q[130],q[121];
u1(pi/1024) q[121];
u1(pi/512) q[130];
cx q[130],q[122];
u1(-pi/512) q[122];
cx q[130],q[122];
u1(pi/512) q[122];
u1(pi/256) q[130];
cx q[130],q[123];
u1(-pi/256) q[123];
cx q[130],q[123];
u1(pi/256) q[123];
u1(pi/128) q[130];
cx q[130],q[124];
u1(-pi/128) q[124];
cx q[130],q[124];
u1(pi/128) q[124];
u1(pi/64) q[130];
cx q[130],q[125];
u1(-pi/64) q[125];
cx q[130],q[125];
u1(pi/64) q[125];
u1(pi/32) q[130];
cx q[130],q[126];
u1(-pi/32) q[126];
cx q[130],q[126];
u1(pi/32) q[126];
u1(pi/16) q[130];
cx q[130],q[127];
u1(-pi/16) q[127];
cx q[130],q[127];
u1(pi/16) q[127];
u1(pi/8) q[130];
cx q[130],q[128];
u1(-pi/8) q[128];
cx q[130],q[128];
u1(pi/8) q[128];
u1(pi/4) q[130];
cx q[130],q[129];
u1(-pi/4) q[129];
cx q[130],q[129];
u1(pi/4) q[129];
h q[130];
u1(0) q[131];
cx q[131],q[0];
u1(0) q[0];
cx q[131],q[0];
u1(0) q[0];
u1(0) q[131];
cx q[131],q[1];
u1(0) q[1];
cx q[131],q[1];
u1(0) q[1];
u1(0) q[131];
cx q[131],q[2];
u1(0) q[2];
cx q[131],q[2];
u1(0) q[2];
u1(0) q[131];
cx q[131],q[3];
u1(0) q[3];
cx q[131],q[3];
u1(0) q[3];
u1(0) q[131];
cx q[131],q[4];
u1(0) q[4];
cx q[131],q[4];
u1(0) q[4];
u1(0) q[131];
cx q[131],q[5];
u1(0) q[5];
cx q[131],q[5];
u1(0) q[5];
u1(0) q[131];
cx q[131],q[6];
u1(0) q[6];
cx q[131],q[6];
u1(0) q[6];
u1(0) q[131];
cx q[131],q[7];
u1(0) q[7];
cx q[131],q[7];
u1(0) q[7];
u1(0) q[131];
cx q[131],q[8];
u1(0) q[8];
cx q[131],q[8];
u1(0) q[8];
u1(0) q[131];
cx q[131],q[9];
u1(0) q[9];
cx q[131],q[9];
u1(0) q[9];
u1(0) q[131];
cx q[131],q[10];
u1(0) q[10];
cx q[131],q[10];
u1(0) q[10];
u1(0) q[131];
cx q[131],q[11];
u1(0) q[11];
cx q[131],q[11];
u1(0) q[11];
u1(0) q[131];
cx q[131],q[12];
u1(0) q[12];
cx q[131],q[12];
u1(0) q[12];
u1(0) q[131];
cx q[131],q[13];
u1(0) q[13];
cx q[131],q[13];
u1(0) q[13];
u1(0) q[131];
cx q[131],q[14];
u1(0) q[14];
cx q[131],q[14];
u1(0) q[14];
u1(0) q[131];
cx q[131],q[15];
u1(0) q[15];
cx q[131],q[15];
u1(0) q[15];
u1(0) q[131];
cx q[131],q[16];
u1(0) q[16];
cx q[131],q[16];
u1(0) q[16];
u1(0) q[131];
cx q[131],q[17];
u1(0) q[17];
cx q[131],q[17];
u1(0) q[17];
u1(0) q[131];
cx q[131],q[18];
u1(0) q[18];
cx q[131],q[18];
u1(0) q[18];
u1(0) q[131];
cx q[131],q[19];
u1(0) q[19];
cx q[131],q[19];
u1(0) q[19];
u1(0) q[131];
cx q[131],q[20];
u1(0) q[20];
cx q[131],q[20];
u1(0) q[20];
u1(0) q[131];
cx q[131],q[21];
u1(0) q[21];
cx q[131],q[21];
u1(0) q[21];
u1(0) q[131];
cx q[131],q[22];
u1(0) q[22];
cx q[131],q[22];
u1(0) q[22];
u1(0) q[131];
cx q[131],q[23];
u1(0) q[23];
cx q[131],q[23];
u1(0) q[23];
u1(0) q[131];
cx q[131],q[24];
u1(0) q[24];
cx q[131],q[24];
u1(0) q[24];
u1(0) q[131];
cx q[131],q[25];
u1(0) q[25];
cx q[131],q[25];
u1(0) q[25];
u1(0) q[131];
cx q[131],q[26];
u1(0) q[26];
cx q[131],q[26];
u1(0) q[26];
u1(0) q[131];
cx q[131],q[27];
u1(0) q[27];
cx q[131],q[27];
u1(0) q[27];
u1(0) q[131];
cx q[131],q[28];
u1(0) q[28];
cx q[131],q[28];
u1(0) q[28];
u1(0) q[131];
cx q[131],q[29];
u1(0) q[29];
cx q[131],q[29];
u1(0) q[29];
u1(0) q[131];
cx q[131],q[30];
u1(0) q[30];
cx q[131],q[30];
u1(0) q[30];
u1(0) q[131];
cx q[131],q[31];
u1(0) q[31];
cx q[131],q[31];
u1(0) q[31];
u1(0) q[131];
cx q[131],q[32];
u1(0) q[32];
cx q[131],q[32];
u1(0) q[32];
u1(0) q[131];
cx q[131],q[33];
u1(0) q[33];
cx q[131],q[33];
u1(0) q[33];
u1(0) q[131];
cx q[131],q[34];
u1(0) q[34];
cx q[131],q[34];
u1(0) q[34];
u1(0) q[131];
cx q[131],q[35];
u1(0) q[35];
cx q[131],q[35];
u1(0) q[35];
u1(0) q[131];
cx q[131],q[36];
u1(0) q[36];
cx q[131],q[36];
u1(0) q[36];
u1(0) q[131];
cx q[131],q[37];
u1(0) q[37];
cx q[131],q[37];
u1(0) q[37];
u1(0) q[131];
cx q[131],q[38];
u1(0) q[38];
cx q[131],q[38];
u1(0) q[38];
u1(0) q[131];
cx q[131],q[39];
u1(0) q[39];
cx q[131],q[39];
u1(0) q[39];
u1(0) q[131];
cx q[131],q[40];
u1(0) q[40];
cx q[131],q[40];
u1(0) q[40];
u1(0) q[131];
cx q[131],q[41];
u1(0) q[41];
cx q[131],q[41];
u1(0) q[41];
u1(0) q[131];
cx q[131],q[42];
u1(0) q[42];
cx q[131],q[42];
u1(0) q[42];
u1(0) q[131];
cx q[131],q[43];
u1(0) q[43];
cx q[131],q[43];
u1(0) q[43];
u1(0) q[131];
cx q[131],q[44];
u1(0) q[44];
cx q[131],q[44];
u1(0) q[44];
u1(0) q[131];
cx q[131],q[45];
u1(0) q[45];
cx q[131],q[45];
u1(0) q[45];
u1(0) q[131];
cx q[131],q[46];
u1(0) q[46];
cx q[131],q[46];
u1(0) q[46];
u1(0) q[131];
cx q[131],q[47];
u1(0) q[47];
cx q[131],q[47];
u1(0) q[47];
u1(0) q[131];
cx q[131],q[48];
u1(0) q[48];
cx q[131],q[48];
u1(0) q[48];
u1(0) q[131];
cx q[131],q[49];
u1(0) q[49];
cx q[131],q[49];
u1(0) q[49];
u1(0) q[131];
cx q[131],q[50];
u1(0) q[50];
cx q[131],q[50];
u1(0) q[50];
u1(0) q[131];
cx q[131],q[51];
u1(0) q[51];
cx q[131],q[51];
u1(0) q[51];
u1(0) q[131];
cx q[131],q[52];
u1(0) q[52];
cx q[131],q[52];
u1(0) q[52];
u1(0) q[131];
cx q[131],q[53];
u1(0) q[53];
cx q[131],q[53];
u1(0) q[53];
u1(0) q[131];
cx q[131],q[54];
u1(0) q[54];
cx q[131],q[54];
u1(0) q[54];
u1(0) q[131];
cx q[131],q[55];
u1(0) q[55];
cx q[131],q[55];
u1(0) q[55];
u1(0) q[131];
cx q[131],q[56];
u1(0) q[56];
cx q[131],q[56];
u1(0) q[56];
u1(0) q[131];
cx q[131],q[57];
u1(0) q[57];
cx q[131],q[57];
u1(0) q[57];
u1(0) q[131];
cx q[131],q[58];
u1(0) q[58];
cx q[131],q[58];
u1(0) q[58];
u1(0) q[131];
cx q[131],q[59];
u1(0) q[59];
cx q[131],q[59];
u1(0) q[59];
u1(0) q[131];
cx q[131],q[60];
u1(0) q[60];
cx q[131],q[60];
u1(0) q[60];
u1(0) q[131];
cx q[131],q[61];
u1(0) q[61];
cx q[131],q[61];
u1(0) q[61];
u1(0) q[131];
cx q[131],q[62];
u1(0) q[62];
cx q[131],q[62];
u1(0) q[62];
u1(0) q[131];
cx q[131],q[63];
u1(0) q[63];
cx q[131],q[63];
u1(0) q[63];
u1(0) q[131];
cx q[131],q[64];
u1(0) q[64];
cx q[131],q[64];
u1(0) q[64];
u1(0) q[131];
cx q[131],q[65];
u1(0) q[65];
cx q[131],q[65];
u1(0) q[65];
u1(0) q[131];
cx q[131],q[66];
u1(0) q[66];
cx q[131],q[66];
u1(0) q[66];
u1(0) q[131];
cx q[131],q[67];
u1(0) q[67];
cx q[131],q[67];
u1(0) q[67];
u1(0) q[131];
cx q[131],q[68];
u1(0) q[68];
cx q[131],q[68];
u1(0) q[68];
u1(0) q[131];
cx q[131],q[69];
u1(0) q[69];
cx q[131],q[69];
u1(0) q[69];
u1(0) q[131];
cx q[131],q[70];
u1(0) q[70];
cx q[131],q[70];
u1(0) q[70];
u1(0) q[131];
cx q[131],q[71];
u1(0) q[71];
cx q[131],q[71];
u1(0) q[71];
u1(0) q[131];
cx q[131],q[72];
u1(0) q[72];
cx q[131],q[72];
u1(0) q[72];
u1(0) q[131];
cx q[131],q[73];
u1(0) q[73];
cx q[131],q[73];
u1(0) q[73];
u1(0) q[131];
cx q[131],q[74];
u1(0) q[74];
cx q[131],q[74];
u1(0) q[74];
u1(0) q[131];
cx q[131],q[75];
u1(0) q[75];
cx q[131],q[75];
u1(0) q[75];
u1(0) q[131];
cx q[131],q[76];
u1(0) q[76];
cx q[131],q[76];
u1(0) q[76];
u1(0) q[131];
cx q[131],q[77];
u1(0) q[77];
cx q[131],q[77];
u1(0) q[77];
u1(0) q[131];
cx q[131],q[78];
u1(0) q[78];
cx q[131],q[78];
u1(0) q[78];
u1(0) q[131];
cx q[131],q[79];
u1(0) q[79];
cx q[131],q[79];
u1(0) q[79];
u1(0) q[131];
cx q[131],q[80];
u1(0) q[80];
cx q[131],q[80];
u1(0) q[80];
u1(0) q[131];
cx q[131],q[81];
u1(0) q[81];
cx q[131],q[81];
u1(0) q[81];
u1(0) q[131];
cx q[131],q[82];
u1(0) q[82];
cx q[131],q[82];
u1(0) q[82];
u1(0) q[131];
cx q[131],q[83];
u1(0) q[83];
cx q[131],q[83];
u1(0) q[83];
u1(pi/281474976710656) q[131];
cx q[131],q[84];
u1(-pi/281474976710656) q[84];
cx q[131],q[84];
u1(pi/281474976710656) q[84];
u1(pi/140737488355328) q[131];
cx q[131],q[85];
u1(-pi/140737488355328) q[85];
cx q[131],q[85];
u1(pi/140737488355328) q[85];
u1(pi/70368744177664) q[131];
cx q[131],q[86];
u1(-pi/70368744177664) q[86];
cx q[131],q[86];
u1(pi/70368744177664) q[86];
u1(pi/35184372088832) q[131];
cx q[131],q[87];
u1(-pi/35184372088832) q[87];
cx q[131],q[87];
u1(pi/35184372088832) q[87];
u1(pi/17592186044416) q[131];
cx q[131],q[88];
u1(-pi/17592186044416) q[88];
cx q[131],q[88];
u1(pi/17592186044416) q[88];
u1(pi/8796093022208) q[131];
cx q[131],q[89];
u1(-pi/8796093022208) q[89];
cx q[131],q[89];
u1(pi/8796093022208) q[89];
u1(pi/4398046511104) q[131];
cx q[131],q[90];
u1(-pi/4398046511104) q[90];
cx q[131],q[90];
u1(pi/4398046511104) q[90];
u1(pi/2199023255552) q[131];
cx q[131],q[91];
u1(-pi/2199023255552) q[91];
cx q[131],q[91];
u1(pi/2199023255552) q[91];
u1(pi/1099511627776) q[131];
cx q[131],q[92];
u1(-pi/1099511627776) q[92];
cx q[131],q[92];
u1(pi/1099511627776) q[92];
u1(pi/549755813888) q[131];
cx q[131],q[93];
u1(-pi/549755813888) q[93];
cx q[131],q[93];
u1(pi/549755813888) q[93];
u1(pi/274877906944) q[131];
cx q[131],q[94];
u1(-pi/274877906944) q[94];
cx q[131],q[94];
u1(pi/274877906944) q[94];
u1(pi/137438953472) q[131];
cx q[131],q[95];
u1(-pi/137438953472) q[95];
cx q[131],q[95];
u1(pi/137438953472) q[95];
u1(pi/68719476736) q[131];
cx q[131],q[96];
u1(-pi/68719476736) q[96];
cx q[131],q[96];
u1(pi/68719476736) q[96];
u1(pi/34359738368) q[131];
cx q[131],q[97];
u1(-pi/34359738368) q[97];
cx q[131],q[97];
u1(pi/34359738368) q[97];
u1(pi/17179869184) q[131];
cx q[131],q[98];
u1(-pi/17179869184) q[98];
cx q[131],q[98];
u1(pi/17179869184) q[98];
u1(pi/8589934592) q[131];
cx q[131],q[99];
u1(-pi/8589934592) q[99];
cx q[131],q[99];
u1(pi/8589934592) q[99];
u1(pi/4294967296) q[131];
cx q[131],q[100];
u1(-pi/4294967296) q[100];
cx q[131],q[100];
u1(pi/4294967296) q[100];
u1(pi/2147483648) q[131];
cx q[131],q[101];
u1(-pi/2147483648) q[101];
cx q[131],q[101];
u1(pi/2147483648) q[101];
u1(pi/1073741824) q[131];
cx q[131],q[102];
u1(-pi/1073741824) q[102];
cx q[131],q[102];
u1(pi/1073741824) q[102];
u1(pi/536870912) q[131];
cx q[131],q[103];
u1(-pi/536870912) q[103];
cx q[131],q[103];
u1(pi/536870912) q[103];
u1(pi/268435456) q[131];
cx q[131],q[104];
u1(-pi/268435456) q[104];
cx q[131],q[104];
u1(pi/268435456) q[104];
u1(pi/134217728) q[131];
cx q[131],q[105];
u1(-pi/134217728) q[105];
cx q[131],q[105];
u1(pi/134217728) q[105];
u1(pi/67108864) q[131];
cx q[131],q[106];
u1(-pi/67108864) q[106];
cx q[131],q[106];
u1(pi/67108864) q[106];
u1(pi/33554432) q[131];
cx q[131],q[107];
u1(-pi/33554432) q[107];
cx q[131],q[107];
u1(pi/33554432) q[107];
u1(pi/16777216) q[131];
cx q[131],q[108];
u1(-pi/16777216) q[108];
cx q[131],q[108];
u1(pi/16777216) q[108];
u1(pi/8388608) q[131];
cx q[131],q[109];
u1(-pi/8388608) q[109];
cx q[131],q[109];
u1(pi/8388608) q[109];
u1(pi/4194304) q[131];
cx q[131],q[110];
u1(-pi/4194304) q[110];
cx q[131],q[110];
u1(pi/4194304) q[110];
u1(pi/2097152) q[131];
cx q[131],q[111];
u1(-pi/2097152) q[111];
cx q[131],q[111];
u1(pi/2097152) q[111];
u1(pi/1048576) q[131];
cx q[131],q[112];
u1(-pi/1048576) q[112];
cx q[131],q[112];
u1(pi/1048576) q[112];
u1(pi/524288) q[131];
cx q[131],q[113];
u1(-pi/524288) q[113];
cx q[131],q[113];
u1(pi/524288) q[113];
u1(pi/262144) q[131];
cx q[131],q[114];
u1(-pi/262144) q[114];
cx q[131],q[114];
u1(pi/262144) q[114];
u1(pi/131072) q[131];
cx q[131],q[115];
u1(-pi/131072) q[115];
cx q[131],q[115];
u1(pi/131072) q[115];
u1(pi/65536) q[131];
cx q[131],q[116];
u1(-pi/65536) q[116];
cx q[131],q[116];
u1(pi/65536) q[116];
u1(pi/32768) q[131];
cx q[131],q[117];
u1(-pi/32768) q[117];
cx q[131],q[117];
u1(pi/32768) q[117];
u1(pi/16384) q[131];
cx q[131],q[118];
u1(-pi/16384) q[118];
cx q[131],q[118];
u1(pi/16384) q[118];
u1(pi/8192) q[131];
cx q[131],q[119];
u1(-pi/8192) q[119];
cx q[131],q[119];
u1(pi/8192) q[119];
u1(pi/4096) q[131];
cx q[131],q[120];
u1(-pi/4096) q[120];
cx q[131],q[120];
u1(pi/4096) q[120];
u1(pi/2048) q[131];
cx q[131],q[121];
u1(-pi/2048) q[121];
cx q[131],q[121];
u1(pi/2048) q[121];
u1(pi/1024) q[131];
cx q[131],q[122];
u1(-pi/1024) q[122];
cx q[131],q[122];
u1(pi/1024) q[122];
u1(pi/512) q[131];
cx q[131],q[123];
u1(-pi/512) q[123];
cx q[131],q[123];
u1(pi/512) q[123];
u1(pi/256) q[131];
cx q[131],q[124];
u1(-pi/256) q[124];
cx q[131],q[124];
u1(pi/256) q[124];
u1(pi/128) q[131];
cx q[131],q[125];
u1(-pi/128) q[125];
cx q[131],q[125];
u1(pi/128) q[125];
u1(pi/64) q[131];
cx q[131],q[126];
u1(-pi/64) q[126];
cx q[131],q[126];
u1(pi/64) q[126];
u1(pi/32) q[131];
cx q[131],q[127];
u1(-pi/32) q[127];
cx q[131],q[127];
u1(pi/32) q[127];
u1(pi/16) q[131];
cx q[131],q[128];
u1(-pi/16) q[128];
cx q[131],q[128];
u1(pi/16) q[128];
u1(pi/8) q[131];
cx q[131],q[129];
u1(-pi/8) q[129];
cx q[131],q[129];
u1(pi/8) q[129];
u1(pi/4) q[131];
cx q[131],q[130];
u1(-pi/4) q[130];
cx q[131],q[130];
u1(pi/4) q[130];
h q[131];
u1(0) q[132];
cx q[132],q[0];
u1(0) q[0];
cx q[132],q[0];
u1(0) q[0];
u1(0) q[132];
cx q[132],q[1];
u1(0) q[1];
cx q[132],q[1];
u1(0) q[1];
u1(0) q[132];
cx q[132],q[2];
u1(0) q[2];
cx q[132],q[2];
u1(0) q[2];
u1(0) q[132];
cx q[132],q[3];
u1(0) q[3];
cx q[132],q[3];
u1(0) q[3];
u1(0) q[132];
cx q[132],q[4];
u1(0) q[4];
cx q[132],q[4];
u1(0) q[4];
u1(0) q[132];
cx q[132],q[5];
u1(0) q[5];
cx q[132],q[5];
u1(0) q[5];
u1(0) q[132];
cx q[132],q[6];
u1(0) q[6];
cx q[132],q[6];
u1(0) q[6];
u1(0) q[132];
cx q[132],q[7];
u1(0) q[7];
cx q[132],q[7];
u1(0) q[7];
u1(0) q[132];
cx q[132],q[8];
u1(0) q[8];
cx q[132],q[8];
u1(0) q[8];
u1(0) q[132];
cx q[132],q[9];
u1(0) q[9];
cx q[132],q[9];
u1(0) q[9];
u1(0) q[132];
cx q[132],q[10];
u1(0) q[10];
cx q[132],q[10];
u1(0) q[10];
u1(0) q[132];
cx q[132],q[11];
u1(0) q[11];
cx q[132],q[11];
u1(0) q[11];
u1(0) q[132];
cx q[132],q[12];
u1(0) q[12];
cx q[132],q[12];
u1(0) q[12];
u1(0) q[132];
cx q[132],q[13];
u1(0) q[13];
cx q[132],q[13];
u1(0) q[13];
u1(0) q[132];
cx q[132],q[14];
u1(0) q[14];
cx q[132],q[14];
u1(0) q[14];
u1(0) q[132];
cx q[132],q[15];
u1(0) q[15];
cx q[132],q[15];
u1(0) q[15];
u1(0) q[132];
cx q[132],q[16];
u1(0) q[16];
cx q[132],q[16];
u1(0) q[16];
u1(0) q[132];
cx q[132],q[17];
u1(0) q[17];
cx q[132],q[17];
u1(0) q[17];
u1(0) q[132];
cx q[132],q[18];
u1(0) q[18];
cx q[132],q[18];
u1(0) q[18];
u1(0) q[132];
cx q[132],q[19];
u1(0) q[19];
cx q[132],q[19];
u1(0) q[19];
u1(0) q[132];
cx q[132],q[20];
u1(0) q[20];
cx q[132],q[20];
u1(0) q[20];
u1(0) q[132];
cx q[132],q[21];
u1(0) q[21];
cx q[132],q[21];
u1(0) q[21];
u1(0) q[132];
cx q[132],q[22];
u1(0) q[22];
cx q[132],q[22];
u1(0) q[22];
u1(0) q[132];
cx q[132],q[23];
u1(0) q[23];
cx q[132],q[23];
u1(0) q[23];
u1(0) q[132];
cx q[132],q[24];
u1(0) q[24];
cx q[132],q[24];
u1(0) q[24];
u1(0) q[132];
cx q[132],q[25];
u1(0) q[25];
cx q[132],q[25];
u1(0) q[25];
u1(0) q[132];
cx q[132],q[26];
u1(0) q[26];
cx q[132],q[26];
u1(0) q[26];
u1(0) q[132];
cx q[132],q[27];
u1(0) q[27];
cx q[132],q[27];
u1(0) q[27];
u1(0) q[132];
cx q[132],q[28];
u1(0) q[28];
cx q[132],q[28];
u1(0) q[28];
u1(0) q[132];
cx q[132],q[29];
u1(0) q[29];
cx q[132],q[29];
u1(0) q[29];
u1(0) q[132];
cx q[132],q[30];
u1(0) q[30];
cx q[132],q[30];
u1(0) q[30];
u1(0) q[132];
cx q[132],q[31];
u1(0) q[31];
cx q[132],q[31];
u1(0) q[31];
u1(0) q[132];
cx q[132],q[32];
u1(0) q[32];
cx q[132],q[32];
u1(0) q[32];
u1(0) q[132];
cx q[132],q[33];
u1(0) q[33];
cx q[132],q[33];
u1(0) q[33];
u1(0) q[132];
cx q[132],q[34];
u1(0) q[34];
cx q[132],q[34];
u1(0) q[34];
u1(0) q[132];
cx q[132],q[35];
u1(0) q[35];
cx q[132],q[35];
u1(0) q[35];
u1(0) q[132];
cx q[132],q[36];
u1(0) q[36];
cx q[132],q[36];
u1(0) q[36];
u1(0) q[132];
cx q[132],q[37];
u1(0) q[37];
cx q[132],q[37];
u1(0) q[37];
u1(0) q[132];
cx q[132],q[38];
u1(0) q[38];
cx q[132],q[38];
u1(0) q[38];
u1(0) q[132];
cx q[132],q[39];
u1(0) q[39];
cx q[132],q[39];
u1(0) q[39];
u1(0) q[132];
cx q[132],q[40];
u1(0) q[40];
cx q[132],q[40];
u1(0) q[40];
u1(0) q[132];
cx q[132],q[41];
u1(0) q[41];
cx q[132],q[41];
u1(0) q[41];
u1(0) q[132];
cx q[132],q[42];
u1(0) q[42];
cx q[132],q[42];
u1(0) q[42];
u1(0) q[132];
cx q[132],q[43];
u1(0) q[43];
cx q[132],q[43];
u1(0) q[43];
u1(0) q[132];
cx q[132],q[44];
u1(0) q[44];
cx q[132],q[44];
u1(0) q[44];
u1(0) q[132];
cx q[132],q[45];
u1(0) q[45];
cx q[132],q[45];
u1(0) q[45];
u1(0) q[132];
cx q[132],q[46];
u1(0) q[46];
cx q[132],q[46];
u1(0) q[46];
u1(0) q[132];
cx q[132],q[47];
u1(0) q[47];
cx q[132],q[47];
u1(0) q[47];
u1(0) q[132];
cx q[132],q[48];
u1(0) q[48];
cx q[132],q[48];
u1(0) q[48];
u1(0) q[132];
cx q[132],q[49];
u1(0) q[49];
cx q[132],q[49];
u1(0) q[49];
u1(0) q[132];
cx q[132],q[50];
u1(0) q[50];
cx q[132],q[50];
u1(0) q[50];
u1(0) q[132];
cx q[132],q[51];
u1(0) q[51];
cx q[132],q[51];
u1(0) q[51];
u1(0) q[132];
cx q[132],q[52];
u1(0) q[52];
cx q[132],q[52];
u1(0) q[52];
u1(0) q[132];
cx q[132],q[53];
u1(0) q[53];
cx q[132],q[53];
u1(0) q[53];
u1(0) q[132];
cx q[132],q[54];
u1(0) q[54];
cx q[132],q[54];
u1(0) q[54];
u1(0) q[132];
cx q[132],q[55];
u1(0) q[55];
cx q[132],q[55];
u1(0) q[55];
u1(0) q[132];
cx q[132],q[56];
u1(0) q[56];
cx q[132],q[56];
u1(0) q[56];
u1(0) q[132];
cx q[132],q[57];
u1(0) q[57];
cx q[132],q[57];
u1(0) q[57];
u1(0) q[132];
cx q[132],q[58];
u1(0) q[58];
cx q[132],q[58];
u1(0) q[58];
u1(0) q[132];
cx q[132],q[59];
u1(0) q[59];
cx q[132],q[59];
u1(0) q[59];
u1(0) q[132];
cx q[132],q[60];
u1(0) q[60];
cx q[132],q[60];
u1(0) q[60];
u1(0) q[132];
cx q[132],q[61];
u1(0) q[61];
cx q[132],q[61];
u1(0) q[61];
u1(0) q[132];
cx q[132],q[62];
u1(0) q[62];
cx q[132],q[62];
u1(0) q[62];
u1(0) q[132];
cx q[132],q[63];
u1(0) q[63];
cx q[132],q[63];
u1(0) q[63];
u1(0) q[132];
cx q[132],q[64];
u1(0) q[64];
cx q[132],q[64];
u1(0) q[64];
u1(0) q[132];
cx q[132],q[65];
u1(0) q[65];
cx q[132],q[65];
u1(0) q[65];
u1(0) q[132];
cx q[132],q[66];
u1(0) q[66];
cx q[132],q[66];
u1(0) q[66];
u1(0) q[132];
cx q[132],q[67];
u1(0) q[67];
cx q[132],q[67];
u1(0) q[67];
u1(0) q[132];
cx q[132],q[68];
u1(0) q[68];
cx q[132],q[68];
u1(0) q[68];
u1(0) q[132];
cx q[132],q[69];
u1(0) q[69];
cx q[132],q[69];
u1(0) q[69];
u1(0) q[132];
cx q[132],q[70];
u1(0) q[70];
cx q[132],q[70];
u1(0) q[70];
u1(0) q[132];
cx q[132],q[71];
u1(0) q[71];
cx q[132],q[71];
u1(0) q[71];
u1(0) q[132];
cx q[132],q[72];
u1(0) q[72];
cx q[132],q[72];
u1(0) q[72];
u1(0) q[132];
cx q[132],q[73];
u1(0) q[73];
cx q[132],q[73];
u1(0) q[73];
u1(0) q[132];
cx q[132],q[74];
u1(0) q[74];
cx q[132],q[74];
u1(0) q[74];
u1(0) q[132];
cx q[132],q[75];
u1(0) q[75];
cx q[132],q[75];
u1(0) q[75];
u1(0) q[132];
cx q[132],q[76];
u1(0) q[76];
cx q[132],q[76];
u1(0) q[76];
u1(0) q[132];
cx q[132],q[77];
u1(0) q[77];
cx q[132],q[77];
u1(0) q[77];
u1(0) q[132];
cx q[132],q[78];
u1(0) q[78];
cx q[132],q[78];
u1(0) q[78];
u1(0) q[132];
cx q[132],q[79];
u1(0) q[79];
cx q[132],q[79];
u1(0) q[79];
u1(0) q[132];
cx q[132],q[80];
u1(0) q[80];
cx q[132],q[80];
u1(0) q[80];
u1(0) q[132];
cx q[132],q[81];
u1(0) q[81];
cx q[132],q[81];
u1(0) q[81];
u1(0) q[132];
cx q[132],q[82];
u1(0) q[82];
cx q[132],q[82];
u1(0) q[82];
u1(0) q[132];
cx q[132],q[83];
u1(0) q[83];
cx q[132],q[83];
u1(0) q[83];
u1(0) q[132];
cx q[132],q[84];
u1(0) q[84];
cx q[132],q[84];
u1(0) q[84];
u1(pi/281474976710656) q[132];
cx q[132],q[85];
u1(-pi/281474976710656) q[85];
cx q[132],q[85];
u1(pi/281474976710656) q[85];
u1(pi/140737488355328) q[132];
cx q[132],q[86];
u1(-pi/140737488355328) q[86];
cx q[132],q[86];
u1(pi/140737488355328) q[86];
u1(pi/70368744177664) q[132];
cx q[132],q[87];
u1(-pi/70368744177664) q[87];
cx q[132],q[87];
u1(pi/70368744177664) q[87];
u1(pi/35184372088832) q[132];
cx q[132],q[88];
u1(-pi/35184372088832) q[88];
cx q[132],q[88];
u1(pi/35184372088832) q[88];
u1(pi/17592186044416) q[132];
cx q[132],q[89];
u1(-pi/17592186044416) q[89];
cx q[132],q[89];
u1(pi/17592186044416) q[89];
u1(pi/8796093022208) q[132];
cx q[132],q[90];
u1(-pi/8796093022208) q[90];
cx q[132],q[90];
u1(pi/8796093022208) q[90];
u1(pi/4398046511104) q[132];
cx q[132],q[91];
u1(-pi/4398046511104) q[91];
cx q[132],q[91];
u1(pi/4398046511104) q[91];
u1(pi/2199023255552) q[132];
cx q[132],q[92];
u1(-pi/2199023255552) q[92];
cx q[132],q[92];
u1(pi/2199023255552) q[92];
u1(pi/1099511627776) q[132];
cx q[132],q[93];
u1(-pi/1099511627776) q[93];
cx q[132],q[93];
u1(pi/1099511627776) q[93];
u1(pi/549755813888) q[132];
cx q[132],q[94];
u1(-pi/549755813888) q[94];
cx q[132],q[94];
u1(pi/549755813888) q[94];
u1(pi/274877906944) q[132];
cx q[132],q[95];
u1(-pi/274877906944) q[95];
cx q[132],q[95];
u1(pi/274877906944) q[95];
u1(pi/137438953472) q[132];
cx q[132],q[96];
u1(-pi/137438953472) q[96];
cx q[132],q[96];
u1(pi/137438953472) q[96];
u1(pi/68719476736) q[132];
cx q[132],q[97];
u1(-pi/68719476736) q[97];
cx q[132],q[97];
u1(pi/68719476736) q[97];
u1(pi/34359738368) q[132];
cx q[132],q[98];
u1(-pi/34359738368) q[98];
cx q[132],q[98];
u1(pi/34359738368) q[98];
u1(pi/17179869184) q[132];
cx q[132],q[99];
u1(-pi/17179869184) q[99];
cx q[132],q[99];
u1(pi/17179869184) q[99];
u1(pi/8589934592) q[132];
cx q[132],q[100];
u1(-pi/8589934592) q[100];
cx q[132],q[100];
u1(pi/8589934592) q[100];
u1(pi/4294967296) q[132];
cx q[132],q[101];
u1(-pi/4294967296) q[101];
cx q[132],q[101];
u1(pi/4294967296) q[101];
u1(pi/2147483648) q[132];
cx q[132],q[102];
u1(-pi/2147483648) q[102];
cx q[132],q[102];
u1(pi/2147483648) q[102];
u1(pi/1073741824) q[132];
cx q[132],q[103];
u1(-pi/1073741824) q[103];
cx q[132],q[103];
u1(pi/1073741824) q[103];
u1(pi/536870912) q[132];
cx q[132],q[104];
u1(-pi/536870912) q[104];
cx q[132],q[104];
u1(pi/536870912) q[104];
u1(pi/268435456) q[132];
cx q[132],q[105];
u1(-pi/268435456) q[105];
cx q[132],q[105];
u1(pi/268435456) q[105];
u1(pi/134217728) q[132];
cx q[132],q[106];
u1(-pi/134217728) q[106];
cx q[132],q[106];
u1(pi/134217728) q[106];
u1(pi/67108864) q[132];
cx q[132],q[107];
u1(-pi/67108864) q[107];
cx q[132],q[107];
u1(pi/67108864) q[107];
u1(pi/33554432) q[132];
cx q[132],q[108];
u1(-pi/33554432) q[108];
cx q[132],q[108];
u1(pi/33554432) q[108];
u1(pi/16777216) q[132];
cx q[132],q[109];
u1(-pi/16777216) q[109];
cx q[132],q[109];
u1(pi/16777216) q[109];
u1(pi/8388608) q[132];
cx q[132],q[110];
u1(-pi/8388608) q[110];
cx q[132],q[110];
u1(pi/8388608) q[110];
u1(pi/4194304) q[132];
cx q[132],q[111];
u1(-pi/4194304) q[111];
cx q[132],q[111];
u1(pi/4194304) q[111];
u1(pi/2097152) q[132];
cx q[132],q[112];
u1(-pi/2097152) q[112];
cx q[132],q[112];
u1(pi/2097152) q[112];
u1(pi/1048576) q[132];
cx q[132],q[113];
u1(-pi/1048576) q[113];
cx q[132],q[113];
u1(pi/1048576) q[113];
u1(pi/524288) q[132];
cx q[132],q[114];
u1(-pi/524288) q[114];
cx q[132],q[114];
u1(pi/524288) q[114];
u1(pi/262144) q[132];
cx q[132],q[115];
u1(-pi/262144) q[115];
cx q[132],q[115];
u1(pi/262144) q[115];
u1(pi/131072) q[132];
cx q[132],q[116];
u1(-pi/131072) q[116];
cx q[132],q[116];
u1(pi/131072) q[116];
u1(pi/65536) q[132];
cx q[132],q[117];
u1(-pi/65536) q[117];
cx q[132],q[117];
u1(pi/65536) q[117];
u1(pi/32768) q[132];
cx q[132],q[118];
u1(-pi/32768) q[118];
cx q[132],q[118];
u1(pi/32768) q[118];
u1(pi/16384) q[132];
cx q[132],q[119];
u1(-pi/16384) q[119];
cx q[132],q[119];
u1(pi/16384) q[119];
u1(pi/8192) q[132];
cx q[132],q[120];
u1(-pi/8192) q[120];
cx q[132],q[120];
u1(pi/8192) q[120];
u1(pi/4096) q[132];
cx q[132],q[121];
u1(-pi/4096) q[121];
cx q[132],q[121];
u1(pi/4096) q[121];
u1(pi/2048) q[132];
cx q[132],q[122];
u1(-pi/2048) q[122];
cx q[132],q[122];
u1(pi/2048) q[122];
u1(pi/1024) q[132];
cx q[132],q[123];
u1(-pi/1024) q[123];
cx q[132],q[123];
u1(pi/1024) q[123];
u1(pi/512) q[132];
cx q[132],q[124];
u1(-pi/512) q[124];
cx q[132],q[124];
u1(pi/512) q[124];
u1(pi/256) q[132];
cx q[132],q[125];
u1(-pi/256) q[125];
cx q[132],q[125];
u1(pi/256) q[125];
u1(pi/128) q[132];
cx q[132],q[126];
u1(-pi/128) q[126];
cx q[132],q[126];
u1(pi/128) q[126];
u1(pi/64) q[132];
cx q[132],q[127];
u1(-pi/64) q[127];
cx q[132],q[127];
u1(pi/64) q[127];
u1(pi/32) q[132];
cx q[132],q[128];
u1(-pi/32) q[128];
cx q[132],q[128];
u1(pi/32) q[128];
u1(pi/16) q[132];
cx q[132],q[129];
u1(-pi/16) q[129];
cx q[132],q[129];
u1(pi/16) q[129];
u1(pi/8) q[132];
cx q[132],q[130];
u1(-pi/8) q[130];
cx q[132],q[130];
u1(pi/8) q[130];
u1(pi/4) q[132];
cx q[132],q[131];
u1(-pi/4) q[131];
cx q[132],q[131];
u1(pi/4) q[131];
h q[132];
u1(0) q[133];
cx q[133],q[0];
u1(0) q[0];
cx q[133],q[0];
u1(0) q[0];
u1(0) q[133];
cx q[133],q[1];
u1(0) q[1];
cx q[133],q[1];
u1(0) q[1];
u1(0) q[133];
cx q[133],q[2];
u1(0) q[2];
cx q[133],q[2];
u1(0) q[2];
u1(0) q[133];
cx q[133],q[3];
u1(0) q[3];
cx q[133],q[3];
u1(0) q[3];
u1(0) q[133];
cx q[133],q[4];
u1(0) q[4];
cx q[133],q[4];
u1(0) q[4];
u1(0) q[133];
cx q[133],q[5];
u1(0) q[5];
cx q[133],q[5];
u1(0) q[5];
u1(0) q[133];
cx q[133],q[6];
u1(0) q[6];
cx q[133],q[6];
u1(0) q[6];
u1(0) q[133];
cx q[133],q[7];
u1(0) q[7];
cx q[133],q[7];
u1(0) q[7];
u1(0) q[133];
cx q[133],q[8];
u1(0) q[8];
cx q[133],q[8];
u1(0) q[8];
u1(0) q[133];
cx q[133],q[9];
u1(0) q[9];
cx q[133],q[9];
u1(0) q[9];
u1(0) q[133];
cx q[133],q[10];
u1(0) q[10];
cx q[133],q[10];
u1(0) q[10];
u1(0) q[133];
cx q[133],q[11];
u1(0) q[11];
cx q[133],q[11];
u1(0) q[11];
u1(0) q[133];
cx q[133],q[12];
u1(0) q[12];
cx q[133],q[12];
u1(0) q[12];
u1(0) q[133];
cx q[133],q[13];
u1(0) q[13];
cx q[133],q[13];
u1(0) q[13];
u1(0) q[133];
cx q[133],q[14];
u1(0) q[14];
cx q[133],q[14];
u1(0) q[14];
u1(0) q[133];
cx q[133],q[15];
u1(0) q[15];
cx q[133],q[15];
u1(0) q[15];
u1(0) q[133];
cx q[133],q[16];
u1(0) q[16];
cx q[133],q[16];
u1(0) q[16];
u1(0) q[133];
cx q[133],q[17];
u1(0) q[17];
cx q[133],q[17];
u1(0) q[17];
u1(0) q[133];
cx q[133],q[18];
u1(0) q[18];
cx q[133],q[18];
u1(0) q[18];
u1(0) q[133];
cx q[133],q[19];
u1(0) q[19];
cx q[133],q[19];
u1(0) q[19];
u1(0) q[133];
cx q[133],q[20];
u1(0) q[20];
cx q[133],q[20];
u1(0) q[20];
u1(0) q[133];
cx q[133],q[21];
u1(0) q[21];
cx q[133],q[21];
u1(0) q[21];
u1(0) q[133];
cx q[133],q[22];
u1(0) q[22];
cx q[133],q[22];
u1(0) q[22];
u1(0) q[133];
cx q[133],q[23];
u1(0) q[23];
cx q[133],q[23];
u1(0) q[23];
u1(0) q[133];
cx q[133],q[24];
u1(0) q[24];
cx q[133],q[24];
u1(0) q[24];
u1(0) q[133];
cx q[133],q[25];
u1(0) q[25];
cx q[133],q[25];
u1(0) q[25];
u1(0) q[133];
cx q[133],q[26];
u1(0) q[26];
cx q[133],q[26];
u1(0) q[26];
u1(0) q[133];
cx q[133],q[27];
u1(0) q[27];
cx q[133],q[27];
u1(0) q[27];
u1(0) q[133];
cx q[133],q[28];
u1(0) q[28];
cx q[133],q[28];
u1(0) q[28];
u1(0) q[133];
cx q[133],q[29];
u1(0) q[29];
cx q[133],q[29];
u1(0) q[29];
u1(0) q[133];
cx q[133],q[30];
u1(0) q[30];
cx q[133],q[30];
u1(0) q[30];
u1(0) q[133];
cx q[133],q[31];
u1(0) q[31];
cx q[133],q[31];
u1(0) q[31];
u1(0) q[133];
cx q[133],q[32];
u1(0) q[32];
cx q[133],q[32];
u1(0) q[32];
u1(0) q[133];
cx q[133],q[33];
u1(0) q[33];
cx q[133],q[33];
u1(0) q[33];
u1(0) q[133];
cx q[133],q[34];
u1(0) q[34];
cx q[133],q[34];
u1(0) q[34];
u1(0) q[133];
cx q[133],q[35];
u1(0) q[35];
cx q[133],q[35];
u1(0) q[35];
u1(0) q[133];
cx q[133],q[36];
u1(0) q[36];
cx q[133],q[36];
u1(0) q[36];
u1(0) q[133];
cx q[133],q[37];
u1(0) q[37];
cx q[133],q[37];
u1(0) q[37];
u1(0) q[133];
cx q[133],q[38];
u1(0) q[38];
cx q[133],q[38];
u1(0) q[38];
u1(0) q[133];
cx q[133],q[39];
u1(0) q[39];
cx q[133],q[39];
u1(0) q[39];
u1(0) q[133];
cx q[133],q[40];
u1(0) q[40];
cx q[133],q[40];
u1(0) q[40];
u1(0) q[133];
cx q[133],q[41];
u1(0) q[41];
cx q[133],q[41];
u1(0) q[41];
u1(0) q[133];
cx q[133],q[42];
u1(0) q[42];
cx q[133],q[42];
u1(0) q[42];
u1(0) q[133];
cx q[133],q[43];
u1(0) q[43];
cx q[133],q[43];
u1(0) q[43];
u1(0) q[133];
cx q[133],q[44];
u1(0) q[44];
cx q[133],q[44];
u1(0) q[44];
u1(0) q[133];
cx q[133],q[45];
u1(0) q[45];
cx q[133],q[45];
u1(0) q[45];
u1(0) q[133];
cx q[133],q[46];
u1(0) q[46];
cx q[133],q[46];
u1(0) q[46];
u1(0) q[133];
cx q[133],q[47];
u1(0) q[47];
cx q[133],q[47];
u1(0) q[47];
u1(0) q[133];
cx q[133],q[48];
u1(0) q[48];
cx q[133],q[48];
u1(0) q[48];
u1(0) q[133];
cx q[133],q[49];
u1(0) q[49];
cx q[133],q[49];
u1(0) q[49];
u1(0) q[133];
cx q[133],q[50];
u1(0) q[50];
cx q[133],q[50];
u1(0) q[50];
u1(0) q[133];
cx q[133],q[51];
u1(0) q[51];
cx q[133],q[51];
u1(0) q[51];
u1(0) q[133];
cx q[133],q[52];
u1(0) q[52];
cx q[133],q[52];
u1(0) q[52];
u1(0) q[133];
cx q[133],q[53];
u1(0) q[53];
cx q[133],q[53];
u1(0) q[53];
u1(0) q[133];
cx q[133],q[54];
u1(0) q[54];
cx q[133],q[54];
u1(0) q[54];
u1(0) q[133];
cx q[133],q[55];
u1(0) q[55];
cx q[133],q[55];
u1(0) q[55];
u1(0) q[133];
cx q[133],q[56];
u1(0) q[56];
cx q[133],q[56];
u1(0) q[56];
u1(0) q[133];
cx q[133],q[57];
u1(0) q[57];
cx q[133],q[57];
u1(0) q[57];
u1(0) q[133];
cx q[133],q[58];
u1(0) q[58];
cx q[133],q[58];
u1(0) q[58];
u1(0) q[133];
cx q[133],q[59];
u1(0) q[59];
cx q[133],q[59];
u1(0) q[59];
u1(0) q[133];
cx q[133],q[60];
u1(0) q[60];
cx q[133],q[60];
u1(0) q[60];
u1(0) q[133];
cx q[133],q[61];
u1(0) q[61];
cx q[133],q[61];
u1(0) q[61];
u1(0) q[133];
cx q[133],q[62];
u1(0) q[62];
cx q[133],q[62];
u1(0) q[62];
u1(0) q[133];
cx q[133],q[63];
u1(0) q[63];
cx q[133],q[63];
u1(0) q[63];
u1(0) q[133];
cx q[133],q[64];
u1(0) q[64];
cx q[133],q[64];
u1(0) q[64];
u1(0) q[133];
cx q[133],q[65];
u1(0) q[65];
cx q[133],q[65];
u1(0) q[65];
u1(0) q[133];
cx q[133],q[66];
u1(0) q[66];
cx q[133],q[66];
u1(0) q[66];
u1(0) q[133];
cx q[133],q[67];
u1(0) q[67];
cx q[133],q[67];
u1(0) q[67];
u1(0) q[133];
cx q[133],q[68];
u1(0) q[68];
cx q[133],q[68];
u1(0) q[68];
u1(0) q[133];
cx q[133],q[69];
u1(0) q[69];
cx q[133],q[69];
u1(0) q[69];
u1(0) q[133];
cx q[133],q[70];
u1(0) q[70];
cx q[133],q[70];
u1(0) q[70];
u1(0) q[133];
cx q[133],q[71];
u1(0) q[71];
cx q[133],q[71];
u1(0) q[71];
u1(0) q[133];
cx q[133],q[72];
u1(0) q[72];
cx q[133],q[72];
u1(0) q[72];
u1(0) q[133];
cx q[133],q[73];
u1(0) q[73];
cx q[133],q[73];
u1(0) q[73];
u1(0) q[133];
cx q[133],q[74];
u1(0) q[74];
cx q[133],q[74];
u1(0) q[74];
u1(0) q[133];
cx q[133],q[75];
u1(0) q[75];
cx q[133],q[75];
u1(0) q[75];
u1(0) q[133];
cx q[133],q[76];
u1(0) q[76];
cx q[133],q[76];
u1(0) q[76];
u1(0) q[133];
cx q[133],q[77];
u1(0) q[77];
cx q[133],q[77];
u1(0) q[77];
u1(0) q[133];
cx q[133],q[78];
u1(0) q[78];
cx q[133],q[78];
u1(0) q[78];
u1(0) q[133];
cx q[133],q[79];
u1(0) q[79];
cx q[133],q[79];
u1(0) q[79];
u1(0) q[133];
cx q[133],q[80];
u1(0) q[80];
cx q[133],q[80];
u1(0) q[80];
u1(0) q[133];
cx q[133],q[81];
u1(0) q[81];
cx q[133],q[81];
u1(0) q[81];
u1(0) q[133];
cx q[133],q[82];
u1(0) q[82];
cx q[133],q[82];
u1(0) q[82];
u1(0) q[133];
cx q[133],q[83];
u1(0) q[83];
cx q[133],q[83];
u1(0) q[83];
u1(0) q[133];
cx q[133],q[84];
u1(0) q[84];
cx q[133],q[84];
u1(0) q[84];
u1(0) q[133];
cx q[133],q[85];
u1(0) q[85];
cx q[133],q[85];
u1(0) q[85];
u1(pi/281474976710656) q[133];
cx q[133],q[86];
u1(-pi/281474976710656) q[86];
cx q[133],q[86];
u1(pi/281474976710656) q[86];
u1(pi/140737488355328) q[133];
cx q[133],q[87];
u1(-pi/140737488355328) q[87];
cx q[133],q[87];
u1(pi/140737488355328) q[87];
u1(pi/70368744177664) q[133];
cx q[133],q[88];
u1(-pi/70368744177664) q[88];
cx q[133],q[88];
u1(pi/70368744177664) q[88];
u1(pi/35184372088832) q[133];
cx q[133],q[89];
u1(-pi/35184372088832) q[89];
cx q[133],q[89];
u1(pi/35184372088832) q[89];
u1(pi/17592186044416) q[133];
cx q[133],q[90];
u1(-pi/17592186044416) q[90];
cx q[133],q[90];
u1(pi/17592186044416) q[90];
u1(pi/8796093022208) q[133];
cx q[133],q[91];
u1(-pi/8796093022208) q[91];
cx q[133],q[91];
u1(pi/8796093022208) q[91];
u1(pi/4398046511104) q[133];
cx q[133],q[92];
u1(-pi/4398046511104) q[92];
cx q[133],q[92];
u1(pi/4398046511104) q[92];
u1(pi/2199023255552) q[133];
cx q[133],q[93];
u1(-pi/2199023255552) q[93];
cx q[133],q[93];
u1(pi/2199023255552) q[93];
u1(pi/1099511627776) q[133];
cx q[133],q[94];
u1(-pi/1099511627776) q[94];
cx q[133],q[94];
u1(pi/1099511627776) q[94];
u1(pi/549755813888) q[133];
cx q[133],q[95];
u1(-pi/549755813888) q[95];
cx q[133],q[95];
u1(pi/549755813888) q[95];
u1(pi/274877906944) q[133];
cx q[133],q[96];
u1(-pi/274877906944) q[96];
cx q[133],q[96];
u1(pi/274877906944) q[96];
u1(pi/137438953472) q[133];
cx q[133],q[97];
u1(-pi/137438953472) q[97];
cx q[133],q[97];
u1(pi/137438953472) q[97];
u1(pi/68719476736) q[133];
cx q[133],q[98];
u1(-pi/68719476736) q[98];
cx q[133],q[98];
u1(pi/68719476736) q[98];
u1(pi/34359738368) q[133];
cx q[133],q[99];
u1(-pi/34359738368) q[99];
cx q[133],q[99];
u1(pi/34359738368) q[99];
u1(pi/17179869184) q[133];
cx q[133],q[100];
u1(-pi/17179869184) q[100];
cx q[133],q[100];
u1(pi/17179869184) q[100];
u1(pi/8589934592) q[133];
cx q[133],q[101];
u1(-pi/8589934592) q[101];
cx q[133],q[101];
u1(pi/8589934592) q[101];
u1(pi/4294967296) q[133];
cx q[133],q[102];
u1(-pi/4294967296) q[102];
cx q[133],q[102];
u1(pi/4294967296) q[102];
u1(pi/2147483648) q[133];
cx q[133],q[103];
u1(-pi/2147483648) q[103];
cx q[133],q[103];
u1(pi/2147483648) q[103];
u1(pi/1073741824) q[133];
cx q[133],q[104];
u1(-pi/1073741824) q[104];
cx q[133],q[104];
u1(pi/1073741824) q[104];
u1(pi/536870912) q[133];
cx q[133],q[105];
u1(-pi/536870912) q[105];
cx q[133],q[105];
u1(pi/536870912) q[105];
u1(pi/268435456) q[133];
cx q[133],q[106];
u1(-pi/268435456) q[106];
cx q[133],q[106];
u1(pi/268435456) q[106];
u1(pi/134217728) q[133];
cx q[133],q[107];
u1(-pi/134217728) q[107];
cx q[133],q[107];
u1(pi/134217728) q[107];
u1(pi/67108864) q[133];
cx q[133],q[108];
u1(-pi/67108864) q[108];
cx q[133],q[108];
u1(pi/67108864) q[108];
u1(pi/33554432) q[133];
cx q[133],q[109];
u1(-pi/33554432) q[109];
cx q[133],q[109];
u1(pi/33554432) q[109];
u1(pi/16777216) q[133];
cx q[133],q[110];
u1(-pi/16777216) q[110];
cx q[133],q[110];
u1(pi/16777216) q[110];
u1(pi/8388608) q[133];
cx q[133],q[111];
u1(-pi/8388608) q[111];
cx q[133],q[111];
u1(pi/8388608) q[111];
u1(pi/4194304) q[133];
cx q[133],q[112];
u1(-pi/4194304) q[112];
cx q[133],q[112];
u1(pi/4194304) q[112];
u1(pi/2097152) q[133];
cx q[133],q[113];
u1(-pi/2097152) q[113];
cx q[133],q[113];
u1(pi/2097152) q[113];
u1(pi/1048576) q[133];
cx q[133],q[114];
u1(-pi/1048576) q[114];
cx q[133],q[114];
u1(pi/1048576) q[114];
u1(pi/524288) q[133];
cx q[133],q[115];
u1(-pi/524288) q[115];
cx q[133],q[115];
u1(pi/524288) q[115];
u1(pi/262144) q[133];
cx q[133],q[116];
u1(-pi/262144) q[116];
cx q[133],q[116];
u1(pi/262144) q[116];
u1(pi/131072) q[133];
cx q[133],q[117];
u1(-pi/131072) q[117];
cx q[133],q[117];
u1(pi/131072) q[117];
u1(pi/65536) q[133];
cx q[133],q[118];
u1(-pi/65536) q[118];
cx q[133],q[118];
u1(pi/65536) q[118];
u1(pi/32768) q[133];
cx q[133],q[119];
u1(-pi/32768) q[119];
cx q[133],q[119];
u1(pi/32768) q[119];
u1(pi/16384) q[133];
cx q[133],q[120];
u1(-pi/16384) q[120];
cx q[133],q[120];
u1(pi/16384) q[120];
u1(pi/8192) q[133];
cx q[133],q[121];
u1(-pi/8192) q[121];
cx q[133],q[121];
u1(pi/8192) q[121];
u1(pi/4096) q[133];
cx q[133],q[122];
u1(-pi/4096) q[122];
cx q[133],q[122];
u1(pi/4096) q[122];
u1(pi/2048) q[133];
cx q[133],q[123];
u1(-pi/2048) q[123];
cx q[133],q[123];
u1(pi/2048) q[123];
u1(pi/1024) q[133];
cx q[133],q[124];
u1(-pi/1024) q[124];
cx q[133],q[124];
u1(pi/1024) q[124];
u1(pi/512) q[133];
cx q[133],q[125];
u1(-pi/512) q[125];
cx q[133],q[125];
u1(pi/512) q[125];
u1(pi/256) q[133];
cx q[133],q[126];
u1(-pi/256) q[126];
cx q[133],q[126];
u1(pi/256) q[126];
u1(pi/128) q[133];
cx q[133],q[127];
u1(-pi/128) q[127];
cx q[133],q[127];
u1(pi/128) q[127];
u1(pi/64) q[133];
cx q[133],q[128];
u1(-pi/64) q[128];
cx q[133],q[128];
u1(pi/64) q[128];
u1(pi/32) q[133];
cx q[133],q[129];
u1(-pi/32) q[129];
cx q[133],q[129];
u1(pi/32) q[129];
u1(pi/16) q[133];
cx q[133],q[130];
u1(-pi/16) q[130];
cx q[133],q[130];
u1(pi/16) q[130];
u1(pi/8) q[133];
cx q[133],q[131];
u1(-pi/8) q[131];
cx q[133],q[131];
u1(pi/8) q[131];
u1(pi/4) q[133];
cx q[133],q[132];
u1(-pi/4) q[132];
cx q[133],q[132];
u1(pi/4) q[132];
h q[133];
u1(0) q[134];
cx q[134],q[0];
u1(0) q[0];
cx q[134],q[0];
u1(0) q[0];
u1(0) q[134];
cx q[134],q[1];
u1(0) q[1];
cx q[134],q[1];
u1(0) q[1];
u1(0) q[134];
cx q[134],q[2];
u1(0) q[2];
cx q[134],q[2];
u1(0) q[2];
u1(0) q[134];
cx q[134],q[3];
u1(0) q[3];
cx q[134],q[3];
u1(0) q[3];
u1(0) q[134];
cx q[134],q[4];
u1(0) q[4];
cx q[134],q[4];
u1(0) q[4];
u1(0) q[134];
cx q[134],q[5];
u1(0) q[5];
cx q[134],q[5];
u1(0) q[5];
u1(0) q[134];
cx q[134],q[6];
u1(0) q[6];
cx q[134],q[6];
u1(0) q[6];
u1(0) q[134];
cx q[134],q[7];
u1(0) q[7];
cx q[134],q[7];
u1(0) q[7];
u1(0) q[134];
cx q[134],q[8];
u1(0) q[8];
cx q[134],q[8];
u1(0) q[8];
u1(0) q[134];
cx q[134],q[9];
u1(0) q[9];
cx q[134],q[9];
u1(0) q[9];
u1(0) q[134];
cx q[134],q[10];
u1(0) q[10];
cx q[134],q[10];
u1(0) q[10];
u1(0) q[134];
cx q[134],q[11];
u1(0) q[11];
cx q[134],q[11];
u1(0) q[11];
u1(0) q[134];
cx q[134],q[12];
u1(0) q[12];
cx q[134],q[12];
u1(0) q[12];
u1(0) q[134];
cx q[134],q[13];
u1(0) q[13];
cx q[134],q[13];
u1(0) q[13];
u1(0) q[134];
cx q[134],q[14];
u1(0) q[14];
cx q[134],q[14];
u1(0) q[14];
u1(0) q[134];
cx q[134],q[15];
u1(0) q[15];
cx q[134],q[15];
u1(0) q[15];
u1(0) q[134];
cx q[134],q[16];
u1(0) q[16];
cx q[134],q[16];
u1(0) q[16];
u1(0) q[134];
cx q[134],q[17];
u1(0) q[17];
cx q[134],q[17];
u1(0) q[17];
u1(0) q[134];
cx q[134],q[18];
u1(0) q[18];
cx q[134],q[18];
u1(0) q[18];
u1(0) q[134];
cx q[134],q[19];
u1(0) q[19];
cx q[134],q[19];
u1(0) q[19];
u1(0) q[134];
cx q[134],q[20];
u1(0) q[20];
cx q[134],q[20];
u1(0) q[20];
u1(0) q[134];
cx q[134],q[21];
u1(0) q[21];
cx q[134],q[21];
u1(0) q[21];
u1(0) q[134];
cx q[134],q[22];
u1(0) q[22];
cx q[134],q[22];
u1(0) q[22];
u1(0) q[134];
cx q[134],q[23];
u1(0) q[23];
cx q[134],q[23];
u1(0) q[23];
u1(0) q[134];
cx q[134],q[24];
u1(0) q[24];
cx q[134],q[24];
u1(0) q[24];
u1(0) q[134];
cx q[134],q[25];
u1(0) q[25];
cx q[134],q[25];
u1(0) q[25];
u1(0) q[134];
cx q[134],q[26];
u1(0) q[26];
cx q[134],q[26];
u1(0) q[26];
u1(0) q[134];
cx q[134],q[27];
u1(0) q[27];
cx q[134],q[27];
u1(0) q[27];
u1(0) q[134];
cx q[134],q[28];
u1(0) q[28];
cx q[134],q[28];
u1(0) q[28];
u1(0) q[134];
cx q[134],q[29];
u1(0) q[29];
cx q[134],q[29];
u1(0) q[29];
u1(0) q[134];
cx q[134],q[30];
u1(0) q[30];
cx q[134],q[30];
u1(0) q[30];
u1(0) q[134];
cx q[134],q[31];
u1(0) q[31];
cx q[134],q[31];
u1(0) q[31];
u1(0) q[134];
cx q[134],q[32];
u1(0) q[32];
cx q[134],q[32];
u1(0) q[32];
u1(0) q[134];
cx q[134],q[33];
u1(0) q[33];
cx q[134],q[33];
u1(0) q[33];
u1(0) q[134];
cx q[134],q[34];
u1(0) q[34];
cx q[134],q[34];
u1(0) q[34];
u1(0) q[134];
cx q[134],q[35];
u1(0) q[35];
cx q[134],q[35];
u1(0) q[35];
u1(0) q[134];
cx q[134],q[36];
u1(0) q[36];
cx q[134],q[36];
u1(0) q[36];
u1(0) q[134];
cx q[134],q[37];
u1(0) q[37];
cx q[134],q[37];
u1(0) q[37];
u1(0) q[134];
cx q[134],q[38];
u1(0) q[38];
cx q[134],q[38];
u1(0) q[38];
u1(0) q[134];
cx q[134],q[39];
u1(0) q[39];
cx q[134],q[39];
u1(0) q[39];
u1(0) q[134];
cx q[134],q[40];
u1(0) q[40];
cx q[134],q[40];
u1(0) q[40];
u1(0) q[134];
cx q[134],q[41];
u1(0) q[41];
cx q[134],q[41];
u1(0) q[41];
u1(0) q[134];
cx q[134],q[42];
u1(0) q[42];
cx q[134],q[42];
u1(0) q[42];
u1(0) q[134];
cx q[134],q[43];
u1(0) q[43];
cx q[134],q[43];
u1(0) q[43];
u1(0) q[134];
cx q[134],q[44];
u1(0) q[44];
cx q[134],q[44];
u1(0) q[44];
u1(0) q[134];
cx q[134],q[45];
u1(0) q[45];
cx q[134],q[45];
u1(0) q[45];
u1(0) q[134];
cx q[134],q[46];
u1(0) q[46];
cx q[134],q[46];
u1(0) q[46];
u1(0) q[134];
cx q[134],q[47];
u1(0) q[47];
cx q[134],q[47];
u1(0) q[47];
u1(0) q[134];
cx q[134],q[48];
u1(0) q[48];
cx q[134],q[48];
u1(0) q[48];
u1(0) q[134];
cx q[134],q[49];
u1(0) q[49];
cx q[134],q[49];
u1(0) q[49];
u1(0) q[134];
cx q[134],q[50];
u1(0) q[50];
cx q[134],q[50];
u1(0) q[50];
u1(0) q[134];
cx q[134],q[51];
u1(0) q[51];
cx q[134],q[51];
u1(0) q[51];
u1(0) q[134];
cx q[134],q[52];
u1(0) q[52];
cx q[134],q[52];
u1(0) q[52];
u1(0) q[134];
cx q[134],q[53];
u1(0) q[53];
cx q[134],q[53];
u1(0) q[53];
u1(0) q[134];
cx q[134],q[54];
u1(0) q[54];
cx q[134],q[54];
u1(0) q[54];
u1(0) q[134];
cx q[134],q[55];
u1(0) q[55];
cx q[134],q[55];
u1(0) q[55];
u1(0) q[134];
cx q[134],q[56];
u1(0) q[56];
cx q[134],q[56];
u1(0) q[56];
u1(0) q[134];
cx q[134],q[57];
u1(0) q[57];
cx q[134],q[57];
u1(0) q[57];
u1(0) q[134];
cx q[134],q[58];
u1(0) q[58];
cx q[134],q[58];
u1(0) q[58];
u1(0) q[134];
cx q[134],q[59];
u1(0) q[59];
cx q[134],q[59];
u1(0) q[59];
u1(0) q[134];
cx q[134],q[60];
u1(0) q[60];
cx q[134],q[60];
u1(0) q[60];
u1(0) q[134];
cx q[134],q[61];
u1(0) q[61];
cx q[134],q[61];
u1(0) q[61];
u1(0) q[134];
cx q[134],q[62];
u1(0) q[62];
cx q[134],q[62];
u1(0) q[62];
u1(0) q[134];
cx q[134],q[63];
u1(0) q[63];
cx q[134],q[63];
u1(0) q[63];
u1(0) q[134];
cx q[134],q[64];
u1(0) q[64];
cx q[134],q[64];
u1(0) q[64];
u1(0) q[134];
cx q[134],q[65];
u1(0) q[65];
cx q[134],q[65];
u1(0) q[65];
u1(0) q[134];
cx q[134],q[66];
u1(0) q[66];
cx q[134],q[66];
u1(0) q[66];
u1(0) q[134];
cx q[134],q[67];
u1(0) q[67];
cx q[134],q[67];
u1(0) q[67];
u1(0) q[134];
cx q[134],q[68];
u1(0) q[68];
cx q[134],q[68];
u1(0) q[68];
u1(0) q[134];
cx q[134],q[69];
u1(0) q[69];
cx q[134],q[69];
u1(0) q[69];
u1(0) q[134];
cx q[134],q[70];
u1(0) q[70];
cx q[134],q[70];
u1(0) q[70];
u1(0) q[134];
cx q[134],q[71];
u1(0) q[71];
cx q[134],q[71];
u1(0) q[71];
u1(0) q[134];
cx q[134],q[72];
u1(0) q[72];
cx q[134],q[72];
u1(0) q[72];
u1(0) q[134];
cx q[134],q[73];
u1(0) q[73];
cx q[134],q[73];
u1(0) q[73];
u1(0) q[134];
cx q[134],q[74];
u1(0) q[74];
cx q[134],q[74];
u1(0) q[74];
u1(0) q[134];
cx q[134],q[75];
u1(0) q[75];
cx q[134],q[75];
u1(0) q[75];
u1(0) q[134];
cx q[134],q[76];
u1(0) q[76];
cx q[134],q[76];
u1(0) q[76];
u1(0) q[134];
cx q[134],q[77];
u1(0) q[77];
cx q[134],q[77];
u1(0) q[77];
u1(0) q[134];
cx q[134],q[78];
u1(0) q[78];
cx q[134],q[78];
u1(0) q[78];
u1(0) q[134];
cx q[134],q[79];
u1(0) q[79];
cx q[134],q[79];
u1(0) q[79];
u1(0) q[134];
cx q[134],q[80];
u1(0) q[80];
cx q[134],q[80];
u1(0) q[80];
u1(0) q[134];
cx q[134],q[81];
u1(0) q[81];
cx q[134],q[81];
u1(0) q[81];
u1(0) q[134];
cx q[134],q[82];
u1(0) q[82];
cx q[134],q[82];
u1(0) q[82];
u1(0) q[134];
cx q[134],q[83];
u1(0) q[83];
cx q[134],q[83];
u1(0) q[83];
u1(0) q[134];
cx q[134],q[84];
u1(0) q[84];
cx q[134],q[84];
u1(0) q[84];
u1(0) q[134];
cx q[134],q[85];
u1(0) q[85];
cx q[134],q[85];
u1(0) q[85];
u1(0) q[134];
cx q[134],q[86];
u1(0) q[86];
cx q[134],q[86];
u1(0) q[86];
u1(pi/281474976710656) q[134];
cx q[134],q[87];
u1(-pi/281474976710656) q[87];
cx q[134],q[87];
u1(pi/281474976710656) q[87];
u1(pi/140737488355328) q[134];
cx q[134],q[88];
u1(-pi/140737488355328) q[88];
cx q[134],q[88];
u1(pi/140737488355328) q[88];
u1(pi/70368744177664) q[134];
cx q[134],q[89];
u1(-pi/70368744177664) q[89];
cx q[134],q[89];
u1(pi/70368744177664) q[89];
u1(pi/35184372088832) q[134];
cx q[134],q[90];
u1(-pi/35184372088832) q[90];
cx q[134],q[90];
u1(pi/35184372088832) q[90];
u1(pi/17592186044416) q[134];
cx q[134],q[91];
u1(-pi/17592186044416) q[91];
cx q[134],q[91];
u1(pi/17592186044416) q[91];
u1(pi/8796093022208) q[134];
cx q[134],q[92];
u1(-pi/8796093022208) q[92];
cx q[134],q[92];
u1(pi/8796093022208) q[92];
u1(pi/4398046511104) q[134];
cx q[134],q[93];
u1(-pi/4398046511104) q[93];
cx q[134],q[93];
u1(pi/4398046511104) q[93];
u1(pi/2199023255552) q[134];
cx q[134],q[94];
u1(-pi/2199023255552) q[94];
cx q[134],q[94];
u1(pi/2199023255552) q[94];
u1(pi/1099511627776) q[134];
cx q[134],q[95];
u1(-pi/1099511627776) q[95];
cx q[134],q[95];
u1(pi/1099511627776) q[95];
u1(pi/549755813888) q[134];
cx q[134],q[96];
u1(-pi/549755813888) q[96];
cx q[134],q[96];
u1(pi/549755813888) q[96];
u1(pi/274877906944) q[134];
cx q[134],q[97];
u1(-pi/274877906944) q[97];
cx q[134],q[97];
u1(pi/274877906944) q[97];
u1(pi/137438953472) q[134];
cx q[134],q[98];
u1(-pi/137438953472) q[98];
cx q[134],q[98];
u1(pi/137438953472) q[98];
u1(pi/68719476736) q[134];
cx q[134],q[99];
u1(-pi/68719476736) q[99];
cx q[134],q[99];
u1(pi/68719476736) q[99];
u1(pi/34359738368) q[134];
cx q[134],q[100];
u1(-pi/34359738368) q[100];
cx q[134],q[100];
u1(pi/34359738368) q[100];
u1(pi/17179869184) q[134];
cx q[134],q[101];
u1(-pi/17179869184) q[101];
cx q[134],q[101];
u1(pi/17179869184) q[101];
u1(pi/8589934592) q[134];
cx q[134],q[102];
u1(-pi/8589934592) q[102];
cx q[134],q[102];
u1(pi/8589934592) q[102];
u1(pi/4294967296) q[134];
cx q[134],q[103];
u1(-pi/4294967296) q[103];
cx q[134],q[103];
u1(pi/4294967296) q[103];
u1(pi/2147483648) q[134];
cx q[134],q[104];
u1(-pi/2147483648) q[104];
cx q[134],q[104];
u1(pi/2147483648) q[104];
u1(pi/1073741824) q[134];
cx q[134],q[105];
u1(-pi/1073741824) q[105];
cx q[134],q[105];
u1(pi/1073741824) q[105];
u1(pi/536870912) q[134];
cx q[134],q[106];
u1(-pi/536870912) q[106];
cx q[134],q[106];
u1(pi/536870912) q[106];
u1(pi/268435456) q[134];
cx q[134],q[107];
u1(-pi/268435456) q[107];
cx q[134],q[107];
u1(pi/268435456) q[107];
u1(pi/134217728) q[134];
cx q[134],q[108];
u1(-pi/134217728) q[108];
cx q[134],q[108];
u1(pi/134217728) q[108];
u1(pi/67108864) q[134];
cx q[134],q[109];
u1(-pi/67108864) q[109];
cx q[134],q[109];
u1(pi/67108864) q[109];
u1(pi/33554432) q[134];
cx q[134],q[110];
u1(-pi/33554432) q[110];
cx q[134],q[110];
u1(pi/33554432) q[110];
u1(pi/16777216) q[134];
cx q[134],q[111];
u1(-pi/16777216) q[111];
cx q[134],q[111];
u1(pi/16777216) q[111];
u1(pi/8388608) q[134];
cx q[134],q[112];
u1(-pi/8388608) q[112];
cx q[134],q[112];
u1(pi/8388608) q[112];
u1(pi/4194304) q[134];
cx q[134],q[113];
u1(-pi/4194304) q[113];
cx q[134],q[113];
u1(pi/4194304) q[113];
u1(pi/2097152) q[134];
cx q[134],q[114];
u1(-pi/2097152) q[114];
cx q[134],q[114];
u1(pi/2097152) q[114];
u1(pi/1048576) q[134];
cx q[134],q[115];
u1(-pi/1048576) q[115];
cx q[134],q[115];
u1(pi/1048576) q[115];
u1(pi/524288) q[134];
cx q[134],q[116];
u1(-pi/524288) q[116];
cx q[134],q[116];
u1(pi/524288) q[116];
u1(pi/262144) q[134];
cx q[134],q[117];
u1(-pi/262144) q[117];
cx q[134],q[117];
u1(pi/262144) q[117];
u1(pi/131072) q[134];
cx q[134],q[118];
u1(-pi/131072) q[118];
cx q[134],q[118];
u1(pi/131072) q[118];
u1(pi/65536) q[134];
cx q[134],q[119];
u1(-pi/65536) q[119];
cx q[134],q[119];
u1(pi/65536) q[119];
u1(pi/32768) q[134];
cx q[134],q[120];
u1(-pi/32768) q[120];
cx q[134],q[120];
u1(pi/32768) q[120];
u1(pi/16384) q[134];
cx q[134],q[121];
u1(-pi/16384) q[121];
cx q[134],q[121];
u1(pi/16384) q[121];
u1(pi/8192) q[134];
cx q[134],q[122];
u1(-pi/8192) q[122];
cx q[134],q[122];
u1(pi/8192) q[122];
u1(pi/4096) q[134];
cx q[134],q[123];
u1(-pi/4096) q[123];
cx q[134],q[123];
u1(pi/4096) q[123];
u1(pi/2048) q[134];
cx q[134],q[124];
u1(-pi/2048) q[124];
cx q[134],q[124];
u1(pi/2048) q[124];
u1(pi/1024) q[134];
cx q[134],q[125];
u1(-pi/1024) q[125];
cx q[134],q[125];
u1(pi/1024) q[125];
u1(pi/512) q[134];
cx q[134],q[126];
u1(-pi/512) q[126];
cx q[134],q[126];
u1(pi/512) q[126];
u1(pi/256) q[134];
cx q[134],q[127];
u1(-pi/256) q[127];
cx q[134],q[127];
u1(pi/256) q[127];
u1(pi/128) q[134];
cx q[134],q[128];
u1(-pi/128) q[128];
cx q[134],q[128];
u1(pi/128) q[128];
u1(pi/64) q[134];
cx q[134],q[129];
u1(-pi/64) q[129];
cx q[134],q[129];
u1(pi/64) q[129];
u1(pi/32) q[134];
cx q[134],q[130];
u1(-pi/32) q[130];
cx q[134],q[130];
u1(pi/32) q[130];
u1(pi/16) q[134];
cx q[134],q[131];
u1(-pi/16) q[131];
cx q[134],q[131];
u1(pi/16) q[131];
u1(pi/8) q[134];
cx q[134],q[132];
u1(-pi/8) q[132];
cx q[134],q[132];
u1(pi/8) q[132];
u1(pi/4) q[134];
cx q[134],q[133];
u1(-pi/4) q[133];
cx q[134],q[133];
u1(pi/4) q[133];
h q[134];
u1(0) q[135];
cx q[135],q[0];
u1(0) q[0];
cx q[135],q[0];
u1(0) q[0];
u1(0) q[135];
cx q[135],q[1];
u1(0) q[1];
cx q[135],q[1];
u1(0) q[1];
u1(0) q[135];
cx q[135],q[2];
u1(0) q[2];
cx q[135],q[2];
u1(0) q[2];
u1(0) q[135];
cx q[135],q[3];
u1(0) q[3];
cx q[135],q[3];
u1(0) q[3];
u1(0) q[135];
cx q[135],q[4];
u1(0) q[4];
cx q[135],q[4];
u1(0) q[4];
u1(0) q[135];
cx q[135],q[5];
u1(0) q[5];
cx q[135],q[5];
u1(0) q[5];
u1(0) q[135];
cx q[135],q[6];
u1(0) q[6];
cx q[135],q[6];
u1(0) q[6];
u1(0) q[135];
cx q[135],q[7];
u1(0) q[7];
cx q[135],q[7];
u1(0) q[7];
u1(0) q[135];
cx q[135],q[8];
u1(0) q[8];
cx q[135],q[8];
u1(0) q[8];
u1(0) q[135];
cx q[135],q[9];
u1(0) q[9];
cx q[135],q[9];
u1(0) q[9];
u1(0) q[135];
cx q[135],q[10];
u1(0) q[10];
cx q[135],q[10];
u1(0) q[10];
u1(0) q[135];
cx q[135],q[11];
u1(0) q[11];
cx q[135],q[11];
u1(0) q[11];
u1(0) q[135];
cx q[135],q[12];
u1(0) q[12];
cx q[135],q[12];
u1(0) q[12];
u1(0) q[135];
cx q[135],q[13];
u1(0) q[13];
cx q[135],q[13];
u1(0) q[13];
u1(0) q[135];
cx q[135],q[14];
u1(0) q[14];
cx q[135],q[14];
u1(0) q[14];
u1(0) q[135];
cx q[135],q[15];
u1(0) q[15];
cx q[135],q[15];
u1(0) q[15];
u1(0) q[135];
cx q[135],q[16];
u1(0) q[16];
cx q[135],q[16];
u1(0) q[16];
u1(0) q[135];
cx q[135],q[17];
u1(0) q[17];
cx q[135],q[17];
u1(0) q[17];
u1(0) q[135];
cx q[135],q[18];
u1(0) q[18];
cx q[135],q[18];
u1(0) q[18];
u1(0) q[135];
cx q[135],q[19];
u1(0) q[19];
cx q[135],q[19];
u1(0) q[19];
u1(0) q[135];
cx q[135],q[20];
u1(0) q[20];
cx q[135],q[20];
u1(0) q[20];
u1(0) q[135];
cx q[135],q[21];
u1(0) q[21];
cx q[135],q[21];
u1(0) q[21];
u1(0) q[135];
cx q[135],q[22];
u1(0) q[22];
cx q[135],q[22];
u1(0) q[22];
u1(0) q[135];
cx q[135],q[23];
u1(0) q[23];
cx q[135],q[23];
u1(0) q[23];
u1(0) q[135];
cx q[135],q[24];
u1(0) q[24];
cx q[135],q[24];
u1(0) q[24];
u1(0) q[135];
cx q[135],q[25];
u1(0) q[25];
cx q[135],q[25];
u1(0) q[25];
u1(0) q[135];
cx q[135],q[26];
u1(0) q[26];
cx q[135],q[26];
u1(0) q[26];
u1(0) q[135];
cx q[135],q[27];
u1(0) q[27];
cx q[135],q[27];
u1(0) q[27];
u1(0) q[135];
cx q[135],q[28];
u1(0) q[28];
cx q[135],q[28];
u1(0) q[28];
u1(0) q[135];
cx q[135],q[29];
u1(0) q[29];
cx q[135],q[29];
u1(0) q[29];
u1(0) q[135];
cx q[135],q[30];
u1(0) q[30];
cx q[135],q[30];
u1(0) q[30];
u1(0) q[135];
cx q[135],q[31];
u1(0) q[31];
cx q[135],q[31];
u1(0) q[31];
u1(0) q[135];
cx q[135],q[32];
u1(0) q[32];
cx q[135],q[32];
u1(0) q[32];
u1(0) q[135];
cx q[135],q[33];
u1(0) q[33];
cx q[135],q[33];
u1(0) q[33];
u1(0) q[135];
cx q[135],q[34];
u1(0) q[34];
cx q[135],q[34];
u1(0) q[34];
u1(0) q[135];
cx q[135],q[35];
u1(0) q[35];
cx q[135],q[35];
u1(0) q[35];
u1(0) q[135];
cx q[135],q[36];
u1(0) q[36];
cx q[135],q[36];
u1(0) q[36];
u1(0) q[135];
cx q[135],q[37];
u1(0) q[37];
cx q[135],q[37];
u1(0) q[37];
u1(0) q[135];
cx q[135],q[38];
u1(0) q[38];
cx q[135],q[38];
u1(0) q[38];
u1(0) q[135];
cx q[135],q[39];
u1(0) q[39];
cx q[135],q[39];
u1(0) q[39];
u1(0) q[135];
cx q[135],q[40];
u1(0) q[40];
cx q[135],q[40];
u1(0) q[40];
u1(0) q[135];
cx q[135],q[41];
u1(0) q[41];
cx q[135],q[41];
u1(0) q[41];
u1(0) q[135];
cx q[135],q[42];
u1(0) q[42];
cx q[135],q[42];
u1(0) q[42];
u1(0) q[135];
cx q[135],q[43];
u1(0) q[43];
cx q[135],q[43];
u1(0) q[43];
u1(0) q[135];
cx q[135],q[44];
u1(0) q[44];
cx q[135],q[44];
u1(0) q[44];
u1(0) q[135];
cx q[135],q[45];
u1(0) q[45];
cx q[135],q[45];
u1(0) q[45];
u1(0) q[135];
cx q[135],q[46];
u1(0) q[46];
cx q[135],q[46];
u1(0) q[46];
u1(0) q[135];
cx q[135],q[47];
u1(0) q[47];
cx q[135],q[47];
u1(0) q[47];
u1(0) q[135];
cx q[135],q[48];
u1(0) q[48];
cx q[135],q[48];
u1(0) q[48];
u1(0) q[135];
cx q[135],q[49];
u1(0) q[49];
cx q[135],q[49];
u1(0) q[49];
u1(0) q[135];
cx q[135],q[50];
u1(0) q[50];
cx q[135],q[50];
u1(0) q[50];
u1(0) q[135];
cx q[135],q[51];
u1(0) q[51];
cx q[135],q[51];
u1(0) q[51];
u1(0) q[135];
cx q[135],q[52];
u1(0) q[52];
cx q[135],q[52];
u1(0) q[52];
u1(0) q[135];
cx q[135],q[53];
u1(0) q[53];
cx q[135],q[53];
u1(0) q[53];
u1(0) q[135];
cx q[135],q[54];
u1(0) q[54];
cx q[135],q[54];
u1(0) q[54];
u1(0) q[135];
cx q[135],q[55];
u1(0) q[55];
cx q[135],q[55];
u1(0) q[55];
u1(0) q[135];
cx q[135],q[56];
u1(0) q[56];
cx q[135],q[56];
u1(0) q[56];
u1(0) q[135];
cx q[135],q[57];
u1(0) q[57];
cx q[135],q[57];
u1(0) q[57];
u1(0) q[135];
cx q[135],q[58];
u1(0) q[58];
cx q[135],q[58];
u1(0) q[58];
u1(0) q[135];
cx q[135],q[59];
u1(0) q[59];
cx q[135],q[59];
u1(0) q[59];
u1(0) q[135];
cx q[135],q[60];
u1(0) q[60];
cx q[135],q[60];
u1(0) q[60];
u1(0) q[135];
cx q[135],q[61];
u1(0) q[61];
cx q[135],q[61];
u1(0) q[61];
u1(0) q[135];
cx q[135],q[62];
u1(0) q[62];
cx q[135],q[62];
u1(0) q[62];
u1(0) q[135];
cx q[135],q[63];
u1(0) q[63];
cx q[135],q[63];
u1(0) q[63];
u1(0) q[135];
cx q[135],q[64];
u1(0) q[64];
cx q[135],q[64];
u1(0) q[64];
u1(0) q[135];
cx q[135],q[65];
u1(0) q[65];
cx q[135],q[65];
u1(0) q[65];
u1(0) q[135];
cx q[135],q[66];
u1(0) q[66];
cx q[135],q[66];
u1(0) q[66];
u1(0) q[135];
cx q[135],q[67];
u1(0) q[67];
cx q[135],q[67];
u1(0) q[67];
u1(0) q[135];
cx q[135],q[68];
u1(0) q[68];
cx q[135],q[68];
u1(0) q[68];
u1(0) q[135];
cx q[135],q[69];
u1(0) q[69];
cx q[135],q[69];
u1(0) q[69];
u1(0) q[135];
cx q[135],q[70];
u1(0) q[70];
cx q[135],q[70];
u1(0) q[70];
u1(0) q[135];
cx q[135],q[71];
u1(0) q[71];
cx q[135],q[71];
u1(0) q[71];
u1(0) q[135];
cx q[135],q[72];
u1(0) q[72];
cx q[135],q[72];
u1(0) q[72];
u1(0) q[135];
cx q[135],q[73];
u1(0) q[73];
cx q[135],q[73];
u1(0) q[73];
u1(0) q[135];
cx q[135],q[74];
u1(0) q[74];
cx q[135],q[74];
u1(0) q[74];
u1(0) q[135];
cx q[135],q[75];
u1(0) q[75];
cx q[135],q[75];
u1(0) q[75];
u1(0) q[135];
cx q[135],q[76];
u1(0) q[76];
cx q[135],q[76];
u1(0) q[76];
u1(0) q[135];
cx q[135],q[77];
u1(0) q[77];
cx q[135],q[77];
u1(0) q[77];
u1(0) q[135];
cx q[135],q[78];
u1(0) q[78];
cx q[135],q[78];
u1(0) q[78];
u1(0) q[135];
cx q[135],q[79];
u1(0) q[79];
cx q[135],q[79];
u1(0) q[79];
u1(0) q[135];
cx q[135],q[80];
u1(0) q[80];
cx q[135],q[80];
u1(0) q[80];
u1(0) q[135];
cx q[135],q[81];
u1(0) q[81];
cx q[135],q[81];
u1(0) q[81];
u1(0) q[135];
cx q[135],q[82];
u1(0) q[82];
cx q[135],q[82];
u1(0) q[82];
u1(0) q[135];
cx q[135],q[83];
u1(0) q[83];
cx q[135],q[83];
u1(0) q[83];
u1(0) q[135];
cx q[135],q[84];
u1(0) q[84];
cx q[135],q[84];
u1(0) q[84];
u1(0) q[135];
cx q[135],q[85];
u1(0) q[85];
cx q[135],q[85];
u1(0) q[85];
u1(0) q[135];
cx q[135],q[86];
u1(0) q[86];
cx q[135],q[86];
u1(0) q[86];
u1(0) q[135];
cx q[135],q[87];
u1(0) q[87];
cx q[135],q[87];
u1(0) q[87];
u1(pi/281474976710656) q[135];
cx q[135],q[88];
u1(-pi/281474976710656) q[88];
cx q[135],q[88];
u1(pi/281474976710656) q[88];
u1(pi/140737488355328) q[135];
cx q[135],q[89];
u1(-pi/140737488355328) q[89];
cx q[135],q[89];
u1(pi/140737488355328) q[89];
u1(pi/70368744177664) q[135];
cx q[135],q[90];
u1(-pi/70368744177664) q[90];
cx q[135],q[90];
u1(pi/70368744177664) q[90];
u1(pi/35184372088832) q[135];
cx q[135],q[91];
u1(-pi/35184372088832) q[91];
cx q[135],q[91];
u1(pi/35184372088832) q[91];
u1(pi/17592186044416) q[135];
cx q[135],q[92];
u1(-pi/17592186044416) q[92];
cx q[135],q[92];
u1(pi/17592186044416) q[92];
u1(pi/8796093022208) q[135];
cx q[135],q[93];
u1(-pi/8796093022208) q[93];
cx q[135],q[93];
u1(pi/8796093022208) q[93];
u1(pi/4398046511104) q[135];
cx q[135],q[94];
u1(-pi/4398046511104) q[94];
cx q[135],q[94];
u1(pi/4398046511104) q[94];
u1(pi/2199023255552) q[135];
cx q[135],q[95];
u1(-pi/2199023255552) q[95];
cx q[135],q[95];
u1(pi/2199023255552) q[95];
u1(pi/1099511627776) q[135];
cx q[135],q[96];
u1(-pi/1099511627776) q[96];
cx q[135],q[96];
u1(pi/1099511627776) q[96];
u1(pi/549755813888) q[135];
cx q[135],q[97];
u1(-pi/549755813888) q[97];
cx q[135],q[97];
u1(pi/549755813888) q[97];
u1(pi/274877906944) q[135];
cx q[135],q[98];
u1(-pi/274877906944) q[98];
cx q[135],q[98];
u1(pi/274877906944) q[98];
u1(pi/137438953472) q[135];
cx q[135],q[99];
u1(-pi/137438953472) q[99];
cx q[135],q[99];
u1(pi/137438953472) q[99];
u1(pi/68719476736) q[135];
cx q[135],q[100];
u1(-pi/68719476736) q[100];
cx q[135],q[100];
u1(pi/68719476736) q[100];
u1(pi/34359738368) q[135];
cx q[135],q[101];
u1(-pi/34359738368) q[101];
cx q[135],q[101];
u1(pi/34359738368) q[101];
u1(pi/17179869184) q[135];
cx q[135],q[102];
u1(-pi/17179869184) q[102];
cx q[135],q[102];
u1(pi/17179869184) q[102];
u1(pi/8589934592) q[135];
cx q[135],q[103];
u1(-pi/8589934592) q[103];
cx q[135],q[103];
u1(pi/8589934592) q[103];
u1(pi/4294967296) q[135];
cx q[135],q[104];
u1(-pi/4294967296) q[104];
cx q[135],q[104];
u1(pi/4294967296) q[104];
u1(pi/2147483648) q[135];
cx q[135],q[105];
u1(-pi/2147483648) q[105];
cx q[135],q[105];
u1(pi/2147483648) q[105];
u1(pi/1073741824) q[135];
cx q[135],q[106];
u1(-pi/1073741824) q[106];
cx q[135],q[106];
u1(pi/1073741824) q[106];
u1(pi/536870912) q[135];
cx q[135],q[107];
u1(-pi/536870912) q[107];
cx q[135],q[107];
u1(pi/536870912) q[107];
u1(pi/268435456) q[135];
cx q[135],q[108];
u1(-pi/268435456) q[108];
cx q[135],q[108];
u1(pi/268435456) q[108];
u1(pi/134217728) q[135];
cx q[135],q[109];
u1(-pi/134217728) q[109];
cx q[135],q[109];
u1(pi/134217728) q[109];
u1(pi/67108864) q[135];
cx q[135],q[110];
u1(-pi/67108864) q[110];
cx q[135],q[110];
u1(pi/67108864) q[110];
u1(pi/33554432) q[135];
cx q[135],q[111];
u1(-pi/33554432) q[111];
cx q[135],q[111];
u1(pi/33554432) q[111];
u1(pi/16777216) q[135];
cx q[135],q[112];
u1(-pi/16777216) q[112];
cx q[135],q[112];
u1(pi/16777216) q[112];
u1(pi/8388608) q[135];
cx q[135],q[113];
u1(-pi/8388608) q[113];
cx q[135],q[113];
u1(pi/8388608) q[113];
u1(pi/4194304) q[135];
cx q[135],q[114];
u1(-pi/4194304) q[114];
cx q[135],q[114];
u1(pi/4194304) q[114];
u1(pi/2097152) q[135];
cx q[135],q[115];
u1(-pi/2097152) q[115];
cx q[135],q[115];
u1(pi/2097152) q[115];
u1(pi/1048576) q[135];
cx q[135],q[116];
u1(-pi/1048576) q[116];
cx q[135],q[116];
u1(pi/1048576) q[116];
u1(pi/524288) q[135];
cx q[135],q[117];
u1(-pi/524288) q[117];
cx q[135],q[117];
u1(pi/524288) q[117];
u1(pi/262144) q[135];
cx q[135],q[118];
u1(-pi/262144) q[118];
cx q[135],q[118];
u1(pi/262144) q[118];
u1(pi/131072) q[135];
cx q[135],q[119];
u1(-pi/131072) q[119];
cx q[135],q[119];
u1(pi/131072) q[119];
u1(pi/65536) q[135];
cx q[135],q[120];
u1(-pi/65536) q[120];
cx q[135],q[120];
u1(pi/65536) q[120];
u1(pi/32768) q[135];
cx q[135],q[121];
u1(-pi/32768) q[121];
cx q[135],q[121];
u1(pi/32768) q[121];
u1(pi/16384) q[135];
cx q[135],q[122];
u1(-pi/16384) q[122];
cx q[135],q[122];
u1(pi/16384) q[122];
u1(pi/8192) q[135];
cx q[135],q[123];
u1(-pi/8192) q[123];
cx q[135],q[123];
u1(pi/8192) q[123];
u1(pi/4096) q[135];
cx q[135],q[124];
u1(-pi/4096) q[124];
cx q[135],q[124];
u1(pi/4096) q[124];
u1(pi/2048) q[135];
cx q[135],q[125];
u1(-pi/2048) q[125];
cx q[135],q[125];
u1(pi/2048) q[125];
u1(pi/1024) q[135];
cx q[135],q[126];
u1(-pi/1024) q[126];
cx q[135],q[126];
u1(pi/1024) q[126];
u1(pi/512) q[135];
cx q[135],q[127];
u1(-pi/512) q[127];
cx q[135],q[127];
u1(pi/512) q[127];
u1(pi/256) q[135];
cx q[135],q[128];
u1(-pi/256) q[128];
cx q[135],q[128];
u1(pi/256) q[128];
u1(pi/128) q[135];
cx q[135],q[129];
u1(-pi/128) q[129];
cx q[135],q[129];
u1(pi/128) q[129];
u1(pi/64) q[135];
cx q[135],q[130];
u1(-pi/64) q[130];
cx q[135],q[130];
u1(pi/64) q[130];
u1(pi/32) q[135];
cx q[135],q[131];
u1(-pi/32) q[131];
cx q[135],q[131];
u1(pi/32) q[131];
u1(pi/16) q[135];
cx q[135],q[132];
u1(-pi/16) q[132];
cx q[135],q[132];
u1(pi/16) q[132];
u1(pi/8) q[135];
cx q[135],q[133];
u1(-pi/8) q[133];
cx q[135],q[133];
u1(pi/8) q[133];
u1(pi/4) q[135];
cx q[135],q[134];
u1(-pi/4) q[134];
cx q[135],q[134];
u1(pi/4) q[134];
h q[135];
u1(0) q[136];
cx q[136],q[0];
u1(0) q[0];
cx q[136],q[0];
u1(0) q[0];
u1(0) q[136];
cx q[136],q[1];
u1(0) q[1];
cx q[136],q[1];
u1(0) q[1];
u1(0) q[136];
cx q[136],q[2];
u1(0) q[2];
cx q[136],q[2];
u1(0) q[2];
u1(0) q[136];
cx q[136],q[3];
u1(0) q[3];
cx q[136],q[3];
u1(0) q[3];
u1(0) q[136];
cx q[136],q[4];
u1(0) q[4];
cx q[136],q[4];
u1(0) q[4];
u1(0) q[136];
cx q[136],q[5];
u1(0) q[5];
cx q[136],q[5];
u1(0) q[5];
u1(0) q[136];
cx q[136],q[6];
u1(0) q[6];
cx q[136],q[6];
u1(0) q[6];
u1(0) q[136];
cx q[136],q[7];
u1(0) q[7];
cx q[136],q[7];
u1(0) q[7];
u1(0) q[136];
cx q[136],q[8];
u1(0) q[8];
cx q[136],q[8];
u1(0) q[8];
u1(0) q[136];
cx q[136],q[9];
u1(0) q[9];
cx q[136],q[9];
u1(0) q[9];
u1(0) q[136];
cx q[136],q[10];
u1(0) q[10];
cx q[136],q[10];
u1(0) q[10];
u1(0) q[136];
cx q[136],q[11];
u1(0) q[11];
cx q[136],q[11];
u1(0) q[11];
u1(0) q[136];
cx q[136],q[12];
u1(0) q[12];
cx q[136],q[12];
u1(0) q[12];
u1(0) q[136];
cx q[136],q[13];
u1(0) q[13];
cx q[136],q[13];
u1(0) q[13];
u1(0) q[136];
cx q[136],q[14];
u1(0) q[14];
cx q[136],q[14];
u1(0) q[14];
u1(0) q[136];
cx q[136],q[15];
u1(0) q[15];
cx q[136],q[15];
u1(0) q[15];
u1(0) q[136];
cx q[136],q[16];
u1(0) q[16];
cx q[136],q[16];
u1(0) q[16];
u1(0) q[136];
cx q[136],q[17];
u1(0) q[17];
cx q[136],q[17];
u1(0) q[17];
u1(0) q[136];
cx q[136],q[18];
u1(0) q[18];
cx q[136],q[18];
u1(0) q[18];
u1(0) q[136];
cx q[136],q[19];
u1(0) q[19];
cx q[136],q[19];
u1(0) q[19];
u1(0) q[136];
cx q[136],q[20];
u1(0) q[20];
cx q[136],q[20];
u1(0) q[20];
u1(0) q[136];
cx q[136],q[21];
u1(0) q[21];
cx q[136],q[21];
u1(0) q[21];
u1(0) q[136];
cx q[136],q[22];
u1(0) q[22];
cx q[136],q[22];
u1(0) q[22];
u1(0) q[136];
cx q[136],q[23];
u1(0) q[23];
cx q[136],q[23];
u1(0) q[23];
u1(0) q[136];
cx q[136],q[24];
u1(0) q[24];
cx q[136],q[24];
u1(0) q[24];
u1(0) q[136];
cx q[136],q[25];
u1(0) q[25];
cx q[136],q[25];
u1(0) q[25];
u1(0) q[136];
cx q[136],q[26];
u1(0) q[26];
cx q[136],q[26];
u1(0) q[26];
u1(0) q[136];
cx q[136],q[27];
u1(0) q[27];
cx q[136],q[27];
u1(0) q[27];
u1(0) q[136];
cx q[136],q[28];
u1(0) q[28];
cx q[136],q[28];
u1(0) q[28];
u1(0) q[136];
cx q[136],q[29];
u1(0) q[29];
cx q[136],q[29];
u1(0) q[29];
u1(0) q[136];
cx q[136],q[30];
u1(0) q[30];
cx q[136],q[30];
u1(0) q[30];
u1(0) q[136];
cx q[136],q[31];
u1(0) q[31];
cx q[136],q[31];
u1(0) q[31];
u1(0) q[136];
cx q[136],q[32];
u1(0) q[32];
cx q[136],q[32];
u1(0) q[32];
u1(0) q[136];
cx q[136],q[33];
u1(0) q[33];
cx q[136],q[33];
u1(0) q[33];
u1(0) q[136];
cx q[136],q[34];
u1(0) q[34];
cx q[136],q[34];
u1(0) q[34];
u1(0) q[136];
cx q[136],q[35];
u1(0) q[35];
cx q[136],q[35];
u1(0) q[35];
u1(0) q[136];
cx q[136],q[36];
u1(0) q[36];
cx q[136],q[36];
u1(0) q[36];
u1(0) q[136];
cx q[136],q[37];
u1(0) q[37];
cx q[136],q[37];
u1(0) q[37];
u1(0) q[136];
cx q[136],q[38];
u1(0) q[38];
cx q[136],q[38];
u1(0) q[38];
u1(0) q[136];
cx q[136],q[39];
u1(0) q[39];
cx q[136],q[39];
u1(0) q[39];
u1(0) q[136];
cx q[136],q[40];
u1(0) q[40];
cx q[136],q[40];
u1(0) q[40];
u1(0) q[136];
cx q[136],q[41];
u1(0) q[41];
cx q[136],q[41];
u1(0) q[41];
u1(0) q[136];
cx q[136],q[42];
u1(0) q[42];
cx q[136],q[42];
u1(0) q[42];
u1(0) q[136];
cx q[136],q[43];
u1(0) q[43];
cx q[136],q[43];
u1(0) q[43];
u1(0) q[136];
cx q[136],q[44];
u1(0) q[44];
cx q[136],q[44];
u1(0) q[44];
u1(0) q[136];
cx q[136],q[45];
u1(0) q[45];
cx q[136],q[45];
u1(0) q[45];
u1(0) q[136];
cx q[136],q[46];
u1(0) q[46];
cx q[136],q[46];
u1(0) q[46];
u1(0) q[136];
cx q[136],q[47];
u1(0) q[47];
cx q[136],q[47];
u1(0) q[47];
u1(0) q[136];
cx q[136],q[48];
u1(0) q[48];
cx q[136],q[48];
u1(0) q[48];
u1(0) q[136];
cx q[136],q[49];
u1(0) q[49];
cx q[136],q[49];
u1(0) q[49];
u1(0) q[136];
cx q[136],q[50];
u1(0) q[50];
cx q[136],q[50];
u1(0) q[50];
u1(0) q[136];
cx q[136],q[51];
u1(0) q[51];
cx q[136],q[51];
u1(0) q[51];
u1(0) q[136];
cx q[136],q[52];
u1(0) q[52];
cx q[136],q[52];
u1(0) q[52];
u1(0) q[136];
cx q[136],q[53];
u1(0) q[53];
cx q[136],q[53];
u1(0) q[53];
u1(0) q[136];
cx q[136],q[54];
u1(0) q[54];
cx q[136],q[54];
u1(0) q[54];
u1(0) q[136];
cx q[136],q[55];
u1(0) q[55];
cx q[136],q[55];
u1(0) q[55];
u1(0) q[136];
cx q[136],q[56];
u1(0) q[56];
cx q[136],q[56];
u1(0) q[56];
u1(0) q[136];
cx q[136],q[57];
u1(0) q[57];
cx q[136],q[57];
u1(0) q[57];
u1(0) q[136];
cx q[136],q[58];
u1(0) q[58];
cx q[136],q[58];
u1(0) q[58];
u1(0) q[136];
cx q[136],q[59];
u1(0) q[59];
cx q[136],q[59];
u1(0) q[59];
u1(0) q[136];
cx q[136],q[60];
u1(0) q[60];
cx q[136],q[60];
u1(0) q[60];
u1(0) q[136];
cx q[136],q[61];
u1(0) q[61];
cx q[136],q[61];
u1(0) q[61];
u1(0) q[136];
cx q[136],q[62];
u1(0) q[62];
cx q[136],q[62];
u1(0) q[62];
u1(0) q[136];
cx q[136],q[63];
u1(0) q[63];
cx q[136],q[63];
u1(0) q[63];
u1(0) q[136];
cx q[136],q[64];
u1(0) q[64];
cx q[136],q[64];
u1(0) q[64];
u1(0) q[136];
cx q[136],q[65];
u1(0) q[65];
cx q[136],q[65];
u1(0) q[65];
u1(0) q[136];
cx q[136],q[66];
u1(0) q[66];
cx q[136],q[66];
u1(0) q[66];
u1(0) q[136];
cx q[136],q[67];
u1(0) q[67];
cx q[136],q[67];
u1(0) q[67];
u1(0) q[136];
cx q[136],q[68];
u1(0) q[68];
cx q[136],q[68];
u1(0) q[68];
u1(0) q[136];
cx q[136],q[69];
u1(0) q[69];
cx q[136],q[69];
u1(0) q[69];
u1(0) q[136];
cx q[136],q[70];
u1(0) q[70];
cx q[136],q[70];
u1(0) q[70];
u1(0) q[136];
cx q[136],q[71];
u1(0) q[71];
cx q[136],q[71];
u1(0) q[71];
u1(0) q[136];
cx q[136],q[72];
u1(0) q[72];
cx q[136],q[72];
u1(0) q[72];
u1(0) q[136];
cx q[136],q[73];
u1(0) q[73];
cx q[136],q[73];
u1(0) q[73];
u1(0) q[136];
cx q[136],q[74];
u1(0) q[74];
cx q[136],q[74];
u1(0) q[74];
u1(0) q[136];
cx q[136],q[75];
u1(0) q[75];
cx q[136],q[75];
u1(0) q[75];
u1(0) q[136];
cx q[136],q[76];
u1(0) q[76];
cx q[136],q[76];
u1(0) q[76];
u1(0) q[136];
cx q[136],q[77];
u1(0) q[77];
cx q[136],q[77];
u1(0) q[77];
u1(0) q[136];
cx q[136],q[78];
u1(0) q[78];
cx q[136],q[78];
u1(0) q[78];
u1(0) q[136];
cx q[136],q[79];
u1(0) q[79];
cx q[136],q[79];
u1(0) q[79];
u1(0) q[136];
cx q[136],q[80];
u1(0) q[80];
cx q[136],q[80];
u1(0) q[80];
u1(0) q[136];
cx q[136],q[81];
u1(0) q[81];
cx q[136],q[81];
u1(0) q[81];
u1(0) q[136];
cx q[136],q[82];
u1(0) q[82];
cx q[136],q[82];
u1(0) q[82];
u1(0) q[136];
cx q[136],q[83];
u1(0) q[83];
cx q[136],q[83];
u1(0) q[83];
u1(0) q[136];
cx q[136],q[84];
u1(0) q[84];
cx q[136],q[84];
u1(0) q[84];
u1(0) q[136];
cx q[136],q[85];
u1(0) q[85];
cx q[136],q[85];
u1(0) q[85];
u1(0) q[136];
cx q[136],q[86];
u1(0) q[86];
cx q[136],q[86];
u1(0) q[86];
u1(0) q[136];
cx q[136],q[87];
u1(0) q[87];
cx q[136],q[87];
u1(0) q[87];
u1(0) q[136];
cx q[136],q[88];
u1(0) q[88];
cx q[136],q[88];
u1(0) q[88];
u1(pi/281474976710656) q[136];
cx q[136],q[89];
u1(-pi/281474976710656) q[89];
cx q[136],q[89];
u1(pi/281474976710656) q[89];
u1(pi/140737488355328) q[136];
cx q[136],q[90];
u1(-pi/140737488355328) q[90];
cx q[136],q[90];
u1(pi/140737488355328) q[90];
u1(pi/70368744177664) q[136];
cx q[136],q[91];
u1(-pi/70368744177664) q[91];
cx q[136],q[91];
u1(pi/70368744177664) q[91];
u1(pi/35184372088832) q[136];
cx q[136],q[92];
u1(-pi/35184372088832) q[92];
cx q[136],q[92];
u1(pi/35184372088832) q[92];
u1(pi/17592186044416) q[136];
cx q[136],q[93];
u1(-pi/17592186044416) q[93];
cx q[136],q[93];
u1(pi/17592186044416) q[93];
u1(pi/8796093022208) q[136];
cx q[136],q[94];
u1(-pi/8796093022208) q[94];
cx q[136],q[94];
u1(pi/8796093022208) q[94];
u1(pi/4398046511104) q[136];
cx q[136],q[95];
u1(-pi/4398046511104) q[95];
cx q[136],q[95];
u1(pi/4398046511104) q[95];
u1(pi/2199023255552) q[136];
cx q[136],q[96];
u1(-pi/2199023255552) q[96];
cx q[136],q[96];
u1(pi/2199023255552) q[96];
u1(pi/1099511627776) q[136];
cx q[136],q[97];
u1(-pi/1099511627776) q[97];
cx q[136],q[97];
u1(pi/1099511627776) q[97];
u1(pi/549755813888) q[136];
cx q[136],q[98];
u1(-pi/549755813888) q[98];
cx q[136],q[98];
u1(pi/549755813888) q[98];
u1(pi/274877906944) q[136];
cx q[136],q[99];
u1(-pi/274877906944) q[99];
cx q[136],q[99];
u1(pi/274877906944) q[99];
u1(pi/137438953472) q[136];
cx q[136],q[100];
u1(-pi/137438953472) q[100];
cx q[136],q[100];
u1(pi/137438953472) q[100];
u1(pi/68719476736) q[136];
cx q[136],q[101];
u1(-pi/68719476736) q[101];
cx q[136],q[101];
u1(pi/68719476736) q[101];
u1(pi/34359738368) q[136];
cx q[136],q[102];
u1(-pi/34359738368) q[102];
cx q[136],q[102];
u1(pi/34359738368) q[102];
u1(pi/17179869184) q[136];
cx q[136],q[103];
u1(-pi/17179869184) q[103];
cx q[136],q[103];
u1(pi/17179869184) q[103];
u1(pi/8589934592) q[136];
cx q[136],q[104];
u1(-pi/8589934592) q[104];
cx q[136],q[104];
u1(pi/8589934592) q[104];
u1(pi/4294967296) q[136];
cx q[136],q[105];
u1(-pi/4294967296) q[105];
cx q[136],q[105];
u1(pi/4294967296) q[105];
u1(pi/2147483648) q[136];
cx q[136],q[106];
u1(-pi/2147483648) q[106];
cx q[136],q[106];
u1(pi/2147483648) q[106];
u1(pi/1073741824) q[136];
cx q[136],q[107];
u1(-pi/1073741824) q[107];
cx q[136],q[107];
u1(pi/1073741824) q[107];
u1(pi/536870912) q[136];
cx q[136],q[108];
u1(-pi/536870912) q[108];
cx q[136],q[108];
u1(pi/536870912) q[108];
u1(pi/268435456) q[136];
cx q[136],q[109];
u1(-pi/268435456) q[109];
cx q[136],q[109];
u1(pi/268435456) q[109];
u1(pi/134217728) q[136];
cx q[136],q[110];
u1(-pi/134217728) q[110];
cx q[136],q[110];
u1(pi/134217728) q[110];
u1(pi/67108864) q[136];
cx q[136],q[111];
u1(-pi/67108864) q[111];
cx q[136],q[111];
u1(pi/67108864) q[111];
u1(pi/33554432) q[136];
cx q[136],q[112];
u1(-pi/33554432) q[112];
cx q[136],q[112];
u1(pi/33554432) q[112];
u1(pi/16777216) q[136];
cx q[136],q[113];
u1(-pi/16777216) q[113];
cx q[136],q[113];
u1(pi/16777216) q[113];
u1(pi/8388608) q[136];
cx q[136],q[114];
u1(-pi/8388608) q[114];
cx q[136],q[114];
u1(pi/8388608) q[114];
u1(pi/4194304) q[136];
cx q[136],q[115];
u1(-pi/4194304) q[115];
cx q[136],q[115];
u1(pi/4194304) q[115];
u1(pi/2097152) q[136];
cx q[136],q[116];
u1(-pi/2097152) q[116];
cx q[136],q[116];
u1(pi/2097152) q[116];
u1(pi/1048576) q[136];
cx q[136],q[117];
u1(-pi/1048576) q[117];
cx q[136],q[117];
u1(pi/1048576) q[117];
u1(pi/524288) q[136];
cx q[136],q[118];
u1(-pi/524288) q[118];
cx q[136],q[118];
u1(pi/524288) q[118];
u1(pi/262144) q[136];
cx q[136],q[119];
u1(-pi/262144) q[119];
cx q[136],q[119];
u1(pi/262144) q[119];
u1(pi/131072) q[136];
cx q[136],q[120];
u1(-pi/131072) q[120];
cx q[136],q[120];
u1(pi/131072) q[120];
u1(pi/65536) q[136];
cx q[136],q[121];
u1(-pi/65536) q[121];
cx q[136],q[121];
u1(pi/65536) q[121];
u1(pi/32768) q[136];
cx q[136],q[122];
u1(-pi/32768) q[122];
cx q[136],q[122];
u1(pi/32768) q[122];
u1(pi/16384) q[136];
cx q[136],q[123];
u1(-pi/16384) q[123];
cx q[136],q[123];
u1(pi/16384) q[123];
u1(pi/8192) q[136];
cx q[136],q[124];
u1(-pi/8192) q[124];
cx q[136],q[124];
u1(pi/8192) q[124];
u1(pi/4096) q[136];
cx q[136],q[125];
u1(-pi/4096) q[125];
cx q[136],q[125];
u1(pi/4096) q[125];
u1(pi/2048) q[136];
cx q[136],q[126];
u1(-pi/2048) q[126];
cx q[136],q[126];
u1(pi/2048) q[126];
u1(pi/1024) q[136];
cx q[136],q[127];
u1(-pi/1024) q[127];
cx q[136],q[127];
u1(pi/1024) q[127];
u1(pi/512) q[136];
cx q[136],q[128];
u1(-pi/512) q[128];
cx q[136],q[128];
u1(pi/512) q[128];
u1(pi/256) q[136];
cx q[136],q[129];
u1(-pi/256) q[129];
cx q[136],q[129];
u1(pi/256) q[129];
u1(pi/128) q[136];
cx q[136],q[130];
u1(-pi/128) q[130];
cx q[136],q[130];
u1(pi/128) q[130];
u1(pi/64) q[136];
cx q[136],q[131];
u1(-pi/64) q[131];
cx q[136],q[131];
u1(pi/64) q[131];
u1(pi/32) q[136];
cx q[136],q[132];
u1(-pi/32) q[132];
cx q[136],q[132];
u1(pi/32) q[132];
u1(pi/16) q[136];
cx q[136],q[133];
u1(-pi/16) q[133];
cx q[136],q[133];
u1(pi/16) q[133];
u1(pi/8) q[136];
cx q[136],q[134];
u1(-pi/8) q[134];
cx q[136],q[134];
u1(pi/8) q[134];
u1(pi/4) q[136];
cx q[136],q[135];
u1(-pi/4) q[135];
cx q[136],q[135];
u1(pi/4) q[135];
h q[136];
u1(0) q[137];
cx q[137],q[0];
u1(0) q[0];
cx q[137],q[0];
u1(0) q[0];
u1(0) q[137];
cx q[137],q[1];
u1(0) q[1];
cx q[137],q[1];
u1(0) q[1];
u1(0) q[137];
cx q[137],q[2];
u1(0) q[2];
cx q[137],q[2];
u1(0) q[2];
u1(0) q[137];
cx q[137],q[3];
u1(0) q[3];
cx q[137],q[3];
u1(0) q[3];
u1(0) q[137];
cx q[137],q[4];
u1(0) q[4];
cx q[137],q[4];
u1(0) q[4];
u1(0) q[137];
cx q[137],q[5];
u1(0) q[5];
cx q[137],q[5];
u1(0) q[5];
u1(0) q[137];
cx q[137],q[6];
u1(0) q[6];
cx q[137],q[6];
u1(0) q[6];
u1(0) q[137];
cx q[137],q[7];
u1(0) q[7];
cx q[137],q[7];
u1(0) q[7];
u1(0) q[137];
cx q[137],q[8];
u1(0) q[8];
cx q[137],q[8];
u1(0) q[8];
u1(0) q[137];
cx q[137],q[9];
u1(0) q[9];
cx q[137],q[9];
u1(0) q[9];
u1(0) q[137];
cx q[137],q[10];
u1(0) q[10];
cx q[137],q[10];
u1(0) q[10];
u1(0) q[137];
cx q[137],q[11];
u1(0) q[11];
cx q[137],q[11];
u1(0) q[11];
u1(0) q[137];
cx q[137],q[12];
u1(0) q[12];
cx q[137],q[12];
u1(0) q[12];
u1(0) q[137];
cx q[137],q[13];
u1(0) q[13];
cx q[137],q[13];
u1(0) q[13];
u1(0) q[137];
cx q[137],q[14];
u1(0) q[14];
cx q[137],q[14];
u1(0) q[14];
u1(0) q[137];
cx q[137],q[15];
u1(0) q[15];
cx q[137],q[15];
u1(0) q[15];
u1(0) q[137];
cx q[137],q[16];
u1(0) q[16];
cx q[137],q[16];
u1(0) q[16];
u1(0) q[137];
cx q[137],q[17];
u1(0) q[17];
cx q[137],q[17];
u1(0) q[17];
u1(0) q[137];
cx q[137],q[18];
u1(0) q[18];
cx q[137],q[18];
u1(0) q[18];
u1(0) q[137];
cx q[137],q[19];
u1(0) q[19];
cx q[137],q[19];
u1(0) q[19];
u1(0) q[137];
cx q[137],q[20];
u1(0) q[20];
cx q[137],q[20];
u1(0) q[20];
u1(0) q[137];
cx q[137],q[21];
u1(0) q[21];
cx q[137],q[21];
u1(0) q[21];
u1(0) q[137];
cx q[137],q[22];
u1(0) q[22];
cx q[137],q[22];
u1(0) q[22];
u1(0) q[137];
cx q[137],q[23];
u1(0) q[23];
cx q[137],q[23];
u1(0) q[23];
u1(0) q[137];
cx q[137],q[24];
u1(0) q[24];
cx q[137],q[24];
u1(0) q[24];
u1(0) q[137];
cx q[137],q[25];
u1(0) q[25];
cx q[137],q[25];
u1(0) q[25];
u1(0) q[137];
cx q[137],q[26];
u1(0) q[26];
cx q[137],q[26];
u1(0) q[26];
u1(0) q[137];
cx q[137],q[27];
u1(0) q[27];
cx q[137],q[27];
u1(0) q[27];
u1(0) q[137];
cx q[137],q[28];
u1(0) q[28];
cx q[137],q[28];
u1(0) q[28];
u1(0) q[137];
cx q[137],q[29];
u1(0) q[29];
cx q[137],q[29];
u1(0) q[29];
u1(0) q[137];
cx q[137],q[30];
u1(0) q[30];
cx q[137],q[30];
u1(0) q[30];
u1(0) q[137];
cx q[137],q[31];
u1(0) q[31];
cx q[137],q[31];
u1(0) q[31];
u1(0) q[137];
cx q[137],q[32];
u1(0) q[32];
cx q[137],q[32];
u1(0) q[32];
u1(0) q[137];
cx q[137],q[33];
u1(0) q[33];
cx q[137],q[33];
u1(0) q[33];
u1(0) q[137];
cx q[137],q[34];
u1(0) q[34];
cx q[137],q[34];
u1(0) q[34];
u1(0) q[137];
cx q[137],q[35];
u1(0) q[35];
cx q[137],q[35];
u1(0) q[35];
u1(0) q[137];
cx q[137],q[36];
u1(0) q[36];
cx q[137],q[36];
u1(0) q[36];
u1(0) q[137];
cx q[137],q[37];
u1(0) q[37];
cx q[137],q[37];
u1(0) q[37];
u1(0) q[137];
cx q[137],q[38];
u1(0) q[38];
cx q[137],q[38];
u1(0) q[38];
u1(0) q[137];
cx q[137],q[39];
u1(0) q[39];
cx q[137],q[39];
u1(0) q[39];
u1(0) q[137];
cx q[137],q[40];
u1(0) q[40];
cx q[137],q[40];
u1(0) q[40];
u1(0) q[137];
cx q[137],q[41];
u1(0) q[41];
cx q[137],q[41];
u1(0) q[41];
u1(0) q[137];
cx q[137],q[42];
u1(0) q[42];
cx q[137],q[42];
u1(0) q[42];
u1(0) q[137];
cx q[137],q[43];
u1(0) q[43];
cx q[137],q[43];
u1(0) q[43];
u1(0) q[137];
cx q[137],q[44];
u1(0) q[44];
cx q[137],q[44];
u1(0) q[44];
u1(0) q[137];
cx q[137],q[45];
u1(0) q[45];
cx q[137],q[45];
u1(0) q[45];
u1(0) q[137];
cx q[137],q[46];
u1(0) q[46];
cx q[137],q[46];
u1(0) q[46];
u1(0) q[137];
cx q[137],q[47];
u1(0) q[47];
cx q[137],q[47];
u1(0) q[47];
u1(0) q[137];
cx q[137],q[48];
u1(0) q[48];
cx q[137],q[48];
u1(0) q[48];
u1(0) q[137];
cx q[137],q[49];
u1(0) q[49];
cx q[137],q[49];
u1(0) q[49];
u1(0) q[137];
cx q[137],q[50];
u1(0) q[50];
cx q[137],q[50];
u1(0) q[50];
u1(0) q[137];
cx q[137],q[51];
u1(0) q[51];
cx q[137],q[51];
u1(0) q[51];
u1(0) q[137];
cx q[137],q[52];
u1(0) q[52];
cx q[137],q[52];
u1(0) q[52];
u1(0) q[137];
cx q[137],q[53];
u1(0) q[53];
cx q[137],q[53];
u1(0) q[53];
u1(0) q[137];
cx q[137],q[54];
u1(0) q[54];
cx q[137],q[54];
u1(0) q[54];
u1(0) q[137];
cx q[137],q[55];
u1(0) q[55];
cx q[137],q[55];
u1(0) q[55];
u1(0) q[137];
cx q[137],q[56];
u1(0) q[56];
cx q[137],q[56];
u1(0) q[56];
u1(0) q[137];
cx q[137],q[57];
u1(0) q[57];
cx q[137],q[57];
u1(0) q[57];
u1(0) q[137];
cx q[137],q[58];
u1(0) q[58];
cx q[137],q[58];
u1(0) q[58];
u1(0) q[137];
cx q[137],q[59];
u1(0) q[59];
cx q[137],q[59];
u1(0) q[59];
u1(0) q[137];
cx q[137],q[60];
u1(0) q[60];
cx q[137],q[60];
u1(0) q[60];
u1(0) q[137];
cx q[137],q[61];
u1(0) q[61];
cx q[137],q[61];
u1(0) q[61];
u1(0) q[137];
cx q[137],q[62];
u1(0) q[62];
cx q[137],q[62];
u1(0) q[62];
u1(0) q[137];
cx q[137],q[63];
u1(0) q[63];
cx q[137],q[63];
u1(0) q[63];
u1(0) q[137];
cx q[137],q[64];
u1(0) q[64];
cx q[137],q[64];
u1(0) q[64];
u1(0) q[137];
cx q[137],q[65];
u1(0) q[65];
cx q[137],q[65];
u1(0) q[65];
u1(0) q[137];
cx q[137],q[66];
u1(0) q[66];
cx q[137],q[66];
u1(0) q[66];
u1(0) q[137];
cx q[137],q[67];
u1(0) q[67];
cx q[137],q[67];
u1(0) q[67];
u1(0) q[137];
cx q[137],q[68];
u1(0) q[68];
cx q[137],q[68];
u1(0) q[68];
u1(0) q[137];
cx q[137],q[69];
u1(0) q[69];
cx q[137],q[69];
u1(0) q[69];
u1(0) q[137];
cx q[137],q[70];
u1(0) q[70];
cx q[137],q[70];
u1(0) q[70];
u1(0) q[137];
cx q[137],q[71];
u1(0) q[71];
cx q[137],q[71];
u1(0) q[71];
u1(0) q[137];
cx q[137],q[72];
u1(0) q[72];
cx q[137],q[72];
u1(0) q[72];
u1(0) q[137];
cx q[137],q[73];
u1(0) q[73];
cx q[137],q[73];
u1(0) q[73];
u1(0) q[137];
cx q[137],q[74];
u1(0) q[74];
cx q[137],q[74];
u1(0) q[74];
u1(0) q[137];
cx q[137],q[75];
u1(0) q[75];
cx q[137],q[75];
u1(0) q[75];
u1(0) q[137];
cx q[137],q[76];
u1(0) q[76];
cx q[137],q[76];
u1(0) q[76];
u1(0) q[137];
cx q[137],q[77];
u1(0) q[77];
cx q[137],q[77];
u1(0) q[77];
u1(0) q[137];
cx q[137],q[78];
u1(0) q[78];
cx q[137],q[78];
u1(0) q[78];
u1(0) q[137];
cx q[137],q[79];
u1(0) q[79];
cx q[137],q[79];
u1(0) q[79];
u1(0) q[137];
cx q[137],q[80];
u1(0) q[80];
cx q[137],q[80];
u1(0) q[80];
u1(0) q[137];
cx q[137],q[81];
u1(0) q[81];
cx q[137],q[81];
u1(0) q[81];
u1(0) q[137];
cx q[137],q[82];
u1(0) q[82];
cx q[137],q[82];
u1(0) q[82];
u1(0) q[137];
cx q[137],q[83];
u1(0) q[83];
cx q[137],q[83];
u1(0) q[83];
u1(0) q[137];
cx q[137],q[84];
u1(0) q[84];
cx q[137],q[84];
u1(0) q[84];
u1(0) q[137];
cx q[137],q[85];
u1(0) q[85];
cx q[137],q[85];
u1(0) q[85];
u1(0) q[137];
cx q[137],q[86];
u1(0) q[86];
cx q[137],q[86];
u1(0) q[86];
u1(0) q[137];
cx q[137],q[87];
u1(0) q[87];
cx q[137],q[87];
u1(0) q[87];
u1(0) q[137];
cx q[137],q[88];
u1(0) q[88];
cx q[137],q[88];
u1(0) q[88];
u1(0) q[137];
cx q[137],q[89];
u1(0) q[89];
cx q[137],q[89];
u1(0) q[89];
u1(pi/281474976710656) q[137];
cx q[137],q[90];
u1(-pi/281474976710656) q[90];
cx q[137],q[90];
u1(pi/281474976710656) q[90];
u1(pi/140737488355328) q[137];
cx q[137],q[91];
u1(-pi/140737488355328) q[91];
cx q[137],q[91];
u1(pi/140737488355328) q[91];
u1(pi/70368744177664) q[137];
cx q[137],q[92];
u1(-pi/70368744177664) q[92];
cx q[137],q[92];
u1(pi/70368744177664) q[92];
u1(pi/35184372088832) q[137];
cx q[137],q[93];
u1(-pi/35184372088832) q[93];
cx q[137],q[93];
u1(pi/35184372088832) q[93];
u1(pi/17592186044416) q[137];
cx q[137],q[94];
u1(-pi/17592186044416) q[94];
cx q[137],q[94];
u1(pi/17592186044416) q[94];
u1(pi/8796093022208) q[137];
cx q[137],q[95];
u1(-pi/8796093022208) q[95];
cx q[137],q[95];
u1(pi/8796093022208) q[95];
u1(pi/4398046511104) q[137];
cx q[137],q[96];
u1(-pi/4398046511104) q[96];
cx q[137],q[96];
u1(pi/4398046511104) q[96];
u1(pi/2199023255552) q[137];
cx q[137],q[97];
u1(-pi/2199023255552) q[97];
cx q[137],q[97];
u1(pi/2199023255552) q[97];
u1(pi/1099511627776) q[137];
cx q[137],q[98];
u1(-pi/1099511627776) q[98];
cx q[137],q[98];
u1(pi/1099511627776) q[98];
u1(pi/549755813888) q[137];
cx q[137],q[99];
u1(-pi/549755813888) q[99];
cx q[137],q[99];
u1(pi/549755813888) q[99];
u1(pi/274877906944) q[137];
cx q[137],q[100];
u1(-pi/274877906944) q[100];
cx q[137],q[100];
u1(pi/274877906944) q[100];
u1(pi/137438953472) q[137];
cx q[137],q[101];
u1(-pi/137438953472) q[101];
cx q[137],q[101];
u1(pi/137438953472) q[101];
u1(pi/68719476736) q[137];
cx q[137],q[102];
u1(-pi/68719476736) q[102];
cx q[137],q[102];
u1(pi/68719476736) q[102];
u1(pi/34359738368) q[137];
cx q[137],q[103];
u1(-pi/34359738368) q[103];
cx q[137],q[103];
u1(pi/34359738368) q[103];
u1(pi/17179869184) q[137];
cx q[137],q[104];
u1(-pi/17179869184) q[104];
cx q[137],q[104];
u1(pi/17179869184) q[104];
u1(pi/8589934592) q[137];
cx q[137],q[105];
u1(-pi/8589934592) q[105];
cx q[137],q[105];
u1(pi/8589934592) q[105];
u1(pi/4294967296) q[137];
cx q[137],q[106];
u1(-pi/4294967296) q[106];
cx q[137],q[106];
u1(pi/4294967296) q[106];
u1(pi/2147483648) q[137];
cx q[137],q[107];
u1(-pi/2147483648) q[107];
cx q[137],q[107];
u1(pi/2147483648) q[107];
u1(pi/1073741824) q[137];
cx q[137],q[108];
u1(-pi/1073741824) q[108];
cx q[137],q[108];
u1(pi/1073741824) q[108];
u1(pi/536870912) q[137];
cx q[137],q[109];
u1(-pi/536870912) q[109];
cx q[137],q[109];
u1(pi/536870912) q[109];
u1(pi/268435456) q[137];
cx q[137],q[110];
u1(-pi/268435456) q[110];
cx q[137],q[110];
u1(pi/268435456) q[110];
u1(pi/134217728) q[137];
cx q[137],q[111];
u1(-pi/134217728) q[111];
cx q[137],q[111];
u1(pi/134217728) q[111];
u1(pi/67108864) q[137];
cx q[137],q[112];
u1(-pi/67108864) q[112];
cx q[137],q[112];
u1(pi/67108864) q[112];
u1(pi/33554432) q[137];
cx q[137],q[113];
u1(-pi/33554432) q[113];
cx q[137],q[113];
u1(pi/33554432) q[113];
u1(pi/16777216) q[137];
cx q[137],q[114];
u1(-pi/16777216) q[114];
cx q[137],q[114];
u1(pi/16777216) q[114];
u1(pi/8388608) q[137];
cx q[137],q[115];
u1(-pi/8388608) q[115];
cx q[137],q[115];
u1(pi/8388608) q[115];
u1(pi/4194304) q[137];
cx q[137],q[116];
u1(-pi/4194304) q[116];
cx q[137],q[116];
u1(pi/4194304) q[116];
u1(pi/2097152) q[137];
cx q[137],q[117];
u1(-pi/2097152) q[117];
cx q[137],q[117];
u1(pi/2097152) q[117];
u1(pi/1048576) q[137];
cx q[137],q[118];
u1(-pi/1048576) q[118];
cx q[137],q[118];
u1(pi/1048576) q[118];
u1(pi/524288) q[137];
cx q[137],q[119];
u1(-pi/524288) q[119];
cx q[137],q[119];
u1(pi/524288) q[119];
u1(pi/262144) q[137];
cx q[137],q[120];
u1(-pi/262144) q[120];
cx q[137],q[120];
u1(pi/262144) q[120];
u1(pi/131072) q[137];
cx q[137],q[121];
u1(-pi/131072) q[121];
cx q[137],q[121];
u1(pi/131072) q[121];
u1(pi/65536) q[137];
cx q[137],q[122];
u1(-pi/65536) q[122];
cx q[137],q[122];
u1(pi/65536) q[122];
u1(pi/32768) q[137];
cx q[137],q[123];
u1(-pi/32768) q[123];
cx q[137],q[123];
u1(pi/32768) q[123];
u1(pi/16384) q[137];
cx q[137],q[124];
u1(-pi/16384) q[124];
cx q[137],q[124];
u1(pi/16384) q[124];
u1(pi/8192) q[137];
cx q[137],q[125];
u1(-pi/8192) q[125];
cx q[137],q[125];
u1(pi/8192) q[125];
u1(pi/4096) q[137];
cx q[137],q[126];
u1(-pi/4096) q[126];
cx q[137],q[126];
u1(pi/4096) q[126];
u1(pi/2048) q[137];
cx q[137],q[127];
u1(-pi/2048) q[127];
cx q[137],q[127];
u1(pi/2048) q[127];
u1(pi/1024) q[137];
cx q[137],q[128];
u1(-pi/1024) q[128];
cx q[137],q[128];
u1(pi/1024) q[128];
u1(pi/512) q[137];
cx q[137],q[129];
u1(-pi/512) q[129];
cx q[137],q[129];
u1(pi/512) q[129];
u1(pi/256) q[137];
cx q[137],q[130];
u1(-pi/256) q[130];
cx q[137],q[130];
u1(pi/256) q[130];
u1(pi/128) q[137];
cx q[137],q[131];
u1(-pi/128) q[131];
cx q[137],q[131];
u1(pi/128) q[131];
u1(pi/64) q[137];
cx q[137],q[132];
u1(-pi/64) q[132];
cx q[137],q[132];
u1(pi/64) q[132];
u1(pi/32) q[137];
cx q[137],q[133];
u1(-pi/32) q[133];
cx q[137],q[133];
u1(pi/32) q[133];
u1(pi/16) q[137];
cx q[137],q[134];
u1(-pi/16) q[134];
cx q[137],q[134];
u1(pi/16) q[134];
u1(pi/8) q[137];
cx q[137],q[135];
u1(-pi/8) q[135];
cx q[137],q[135];
u1(pi/8) q[135];
u1(pi/4) q[137];
cx q[137],q[136];
u1(-pi/4) q[136];
cx q[137],q[136];
u1(pi/4) q[136];
h q[137];
u1(0) q[138];
cx q[138],q[0];
u1(0) q[0];
cx q[138],q[0];
u1(0) q[0];
u1(0) q[138];
cx q[138],q[1];
u1(0) q[1];
cx q[138],q[1];
u1(0) q[1];
u1(0) q[138];
cx q[138],q[2];
u1(0) q[2];
cx q[138],q[2];
u1(0) q[2];
u1(0) q[138];
cx q[138],q[3];
u1(0) q[3];
cx q[138],q[3];
u1(0) q[3];
u1(0) q[138];
cx q[138],q[4];
u1(0) q[4];
cx q[138],q[4];
u1(0) q[4];
u1(0) q[138];
cx q[138],q[5];
u1(0) q[5];
cx q[138],q[5];
u1(0) q[5];
u1(0) q[138];
cx q[138],q[6];
u1(0) q[6];
cx q[138],q[6];
u1(0) q[6];
u1(0) q[138];
cx q[138],q[7];
u1(0) q[7];
cx q[138],q[7];
u1(0) q[7];
u1(0) q[138];
cx q[138],q[8];
u1(0) q[8];
cx q[138],q[8];
u1(0) q[8];
u1(0) q[138];
cx q[138],q[9];
u1(0) q[9];
cx q[138],q[9];
u1(0) q[9];
u1(0) q[138];
cx q[138],q[10];
u1(0) q[10];
cx q[138],q[10];
u1(0) q[10];
u1(0) q[138];
cx q[138],q[11];
u1(0) q[11];
cx q[138],q[11];
u1(0) q[11];
u1(0) q[138];
cx q[138],q[12];
u1(0) q[12];
cx q[138],q[12];
u1(0) q[12];
u1(0) q[138];
cx q[138],q[13];
u1(0) q[13];
cx q[138],q[13];
u1(0) q[13];
u1(0) q[138];
cx q[138],q[14];
u1(0) q[14];
cx q[138],q[14];
u1(0) q[14];
u1(0) q[138];
cx q[138],q[15];
u1(0) q[15];
cx q[138],q[15];
u1(0) q[15];
u1(0) q[138];
cx q[138],q[16];
u1(0) q[16];
cx q[138],q[16];
u1(0) q[16];
u1(0) q[138];
cx q[138],q[17];
u1(0) q[17];
cx q[138],q[17];
u1(0) q[17];
u1(0) q[138];
cx q[138],q[18];
u1(0) q[18];
cx q[138],q[18];
u1(0) q[18];
u1(0) q[138];
cx q[138],q[19];
u1(0) q[19];
cx q[138],q[19];
u1(0) q[19];
u1(0) q[138];
cx q[138],q[20];
u1(0) q[20];
cx q[138],q[20];
u1(0) q[20];
u1(0) q[138];
cx q[138],q[21];
u1(0) q[21];
cx q[138],q[21];
u1(0) q[21];
u1(0) q[138];
cx q[138],q[22];
u1(0) q[22];
cx q[138],q[22];
u1(0) q[22];
u1(0) q[138];
cx q[138],q[23];
u1(0) q[23];
cx q[138],q[23];
u1(0) q[23];
u1(0) q[138];
cx q[138],q[24];
u1(0) q[24];
cx q[138],q[24];
u1(0) q[24];
u1(0) q[138];
cx q[138],q[25];
u1(0) q[25];
cx q[138],q[25];
u1(0) q[25];
u1(0) q[138];
cx q[138],q[26];
u1(0) q[26];
cx q[138],q[26];
u1(0) q[26];
u1(0) q[138];
cx q[138],q[27];
u1(0) q[27];
cx q[138],q[27];
u1(0) q[27];
u1(0) q[138];
cx q[138],q[28];
u1(0) q[28];
cx q[138],q[28];
u1(0) q[28];
u1(0) q[138];
cx q[138],q[29];
u1(0) q[29];
cx q[138],q[29];
u1(0) q[29];
u1(0) q[138];
cx q[138],q[30];
u1(0) q[30];
cx q[138],q[30];
u1(0) q[30];
u1(0) q[138];
cx q[138],q[31];
u1(0) q[31];
cx q[138],q[31];
u1(0) q[31];
u1(0) q[138];
cx q[138],q[32];
u1(0) q[32];
cx q[138],q[32];
u1(0) q[32];
u1(0) q[138];
cx q[138],q[33];
u1(0) q[33];
cx q[138],q[33];
u1(0) q[33];
u1(0) q[138];
cx q[138],q[34];
u1(0) q[34];
cx q[138],q[34];
u1(0) q[34];
u1(0) q[138];
cx q[138],q[35];
u1(0) q[35];
cx q[138],q[35];
u1(0) q[35];
u1(0) q[138];
cx q[138],q[36];
u1(0) q[36];
cx q[138],q[36];
u1(0) q[36];
u1(0) q[138];
cx q[138],q[37];
u1(0) q[37];
cx q[138],q[37];
u1(0) q[37];
u1(0) q[138];
cx q[138],q[38];
u1(0) q[38];
cx q[138],q[38];
u1(0) q[38];
u1(0) q[138];
cx q[138],q[39];
u1(0) q[39];
cx q[138],q[39];
u1(0) q[39];
u1(0) q[138];
cx q[138],q[40];
u1(0) q[40];
cx q[138],q[40];
u1(0) q[40];
u1(0) q[138];
cx q[138],q[41];
u1(0) q[41];
cx q[138],q[41];
u1(0) q[41];
u1(0) q[138];
cx q[138],q[42];
u1(0) q[42];
cx q[138],q[42];
u1(0) q[42];
u1(0) q[138];
cx q[138],q[43];
u1(0) q[43];
cx q[138],q[43];
u1(0) q[43];
u1(0) q[138];
cx q[138],q[44];
u1(0) q[44];
cx q[138],q[44];
u1(0) q[44];
u1(0) q[138];
cx q[138],q[45];
u1(0) q[45];
cx q[138],q[45];
u1(0) q[45];
u1(0) q[138];
cx q[138],q[46];
u1(0) q[46];
cx q[138],q[46];
u1(0) q[46];
u1(0) q[138];
cx q[138],q[47];
u1(0) q[47];
cx q[138],q[47];
u1(0) q[47];
u1(0) q[138];
cx q[138],q[48];
u1(0) q[48];
cx q[138],q[48];
u1(0) q[48];
u1(0) q[138];
cx q[138],q[49];
u1(0) q[49];
cx q[138],q[49];
u1(0) q[49];
u1(0) q[138];
cx q[138],q[50];
u1(0) q[50];
cx q[138],q[50];
u1(0) q[50];
u1(0) q[138];
cx q[138],q[51];
u1(0) q[51];
cx q[138],q[51];
u1(0) q[51];
u1(0) q[138];
cx q[138],q[52];
u1(0) q[52];
cx q[138],q[52];
u1(0) q[52];
u1(0) q[138];
cx q[138],q[53];
u1(0) q[53];
cx q[138],q[53];
u1(0) q[53];
u1(0) q[138];
cx q[138],q[54];
u1(0) q[54];
cx q[138],q[54];
u1(0) q[54];
u1(0) q[138];
cx q[138],q[55];
u1(0) q[55];
cx q[138],q[55];
u1(0) q[55];
u1(0) q[138];
cx q[138],q[56];
u1(0) q[56];
cx q[138],q[56];
u1(0) q[56];
u1(0) q[138];
cx q[138],q[57];
u1(0) q[57];
cx q[138],q[57];
u1(0) q[57];
u1(0) q[138];
cx q[138],q[58];
u1(0) q[58];
cx q[138],q[58];
u1(0) q[58];
u1(0) q[138];
cx q[138],q[59];
u1(0) q[59];
cx q[138],q[59];
u1(0) q[59];
u1(0) q[138];
cx q[138],q[60];
u1(0) q[60];
cx q[138],q[60];
u1(0) q[60];
u1(0) q[138];
cx q[138],q[61];
u1(0) q[61];
cx q[138],q[61];
u1(0) q[61];
u1(0) q[138];
cx q[138],q[62];
u1(0) q[62];
cx q[138],q[62];
u1(0) q[62];
u1(0) q[138];
cx q[138],q[63];
u1(0) q[63];
cx q[138],q[63];
u1(0) q[63];
u1(0) q[138];
cx q[138],q[64];
u1(0) q[64];
cx q[138],q[64];
u1(0) q[64];
u1(0) q[138];
cx q[138],q[65];
u1(0) q[65];
cx q[138],q[65];
u1(0) q[65];
u1(0) q[138];
cx q[138],q[66];
u1(0) q[66];
cx q[138],q[66];
u1(0) q[66];
u1(0) q[138];
cx q[138],q[67];
u1(0) q[67];
cx q[138],q[67];
u1(0) q[67];
u1(0) q[138];
cx q[138],q[68];
u1(0) q[68];
cx q[138],q[68];
u1(0) q[68];
u1(0) q[138];
cx q[138],q[69];
u1(0) q[69];
cx q[138],q[69];
u1(0) q[69];
u1(0) q[138];
cx q[138],q[70];
u1(0) q[70];
cx q[138],q[70];
u1(0) q[70];
u1(0) q[138];
cx q[138],q[71];
u1(0) q[71];
cx q[138],q[71];
u1(0) q[71];
u1(0) q[138];
cx q[138],q[72];
u1(0) q[72];
cx q[138],q[72];
u1(0) q[72];
u1(0) q[138];
cx q[138],q[73];
u1(0) q[73];
cx q[138],q[73];
u1(0) q[73];
u1(0) q[138];
cx q[138],q[74];
u1(0) q[74];
cx q[138],q[74];
u1(0) q[74];
u1(0) q[138];
cx q[138],q[75];
u1(0) q[75];
cx q[138],q[75];
u1(0) q[75];
u1(0) q[138];
cx q[138],q[76];
u1(0) q[76];
cx q[138],q[76];
u1(0) q[76];
u1(0) q[138];
cx q[138],q[77];
u1(0) q[77];
cx q[138],q[77];
u1(0) q[77];
u1(0) q[138];
cx q[138],q[78];
u1(0) q[78];
cx q[138],q[78];
u1(0) q[78];
u1(0) q[138];
cx q[138],q[79];
u1(0) q[79];
cx q[138],q[79];
u1(0) q[79];
u1(0) q[138];
cx q[138],q[80];
u1(0) q[80];
cx q[138],q[80];
u1(0) q[80];
u1(0) q[138];
cx q[138],q[81];
u1(0) q[81];
cx q[138],q[81];
u1(0) q[81];
u1(0) q[138];
cx q[138],q[82];
u1(0) q[82];
cx q[138],q[82];
u1(0) q[82];
u1(0) q[138];
cx q[138],q[83];
u1(0) q[83];
cx q[138],q[83];
u1(0) q[83];
u1(0) q[138];
cx q[138],q[84];
u1(0) q[84];
cx q[138],q[84];
u1(0) q[84];
u1(0) q[138];
cx q[138],q[85];
u1(0) q[85];
cx q[138],q[85];
u1(0) q[85];
u1(0) q[138];
cx q[138],q[86];
u1(0) q[86];
cx q[138],q[86];
u1(0) q[86];
u1(0) q[138];
cx q[138],q[87];
u1(0) q[87];
cx q[138],q[87];
u1(0) q[87];
u1(0) q[138];
cx q[138],q[88];
u1(0) q[88];
cx q[138],q[88];
u1(0) q[88];
u1(0) q[138];
cx q[138],q[89];
u1(0) q[89];
cx q[138],q[89];
u1(0) q[89];
u1(0) q[138];
cx q[138],q[90];
u1(0) q[90];
cx q[138],q[90];
u1(0) q[90];
u1(pi/281474976710656) q[138];
cx q[138],q[91];
u1(-pi/281474976710656) q[91];
cx q[138],q[91];
u1(pi/281474976710656) q[91];
u1(pi/140737488355328) q[138];
cx q[138],q[92];
u1(-pi/140737488355328) q[92];
cx q[138],q[92];
u1(pi/140737488355328) q[92];
u1(pi/70368744177664) q[138];
cx q[138],q[93];
u1(-pi/70368744177664) q[93];
cx q[138],q[93];
u1(pi/70368744177664) q[93];
u1(pi/35184372088832) q[138];
cx q[138],q[94];
u1(-pi/35184372088832) q[94];
cx q[138],q[94];
u1(pi/35184372088832) q[94];
u1(pi/17592186044416) q[138];
cx q[138],q[95];
u1(-pi/17592186044416) q[95];
cx q[138],q[95];
u1(pi/17592186044416) q[95];
u1(pi/8796093022208) q[138];
cx q[138],q[96];
u1(-pi/8796093022208) q[96];
cx q[138],q[96];
u1(pi/8796093022208) q[96];
u1(pi/4398046511104) q[138];
cx q[138],q[97];
u1(-pi/4398046511104) q[97];
cx q[138],q[97];
u1(pi/4398046511104) q[97];
u1(pi/2199023255552) q[138];
cx q[138],q[98];
u1(-pi/2199023255552) q[98];
cx q[138],q[98];
u1(pi/2199023255552) q[98];
u1(pi/1099511627776) q[138];
cx q[138],q[99];
u1(-pi/1099511627776) q[99];
cx q[138],q[99];
u1(pi/1099511627776) q[99];
u1(pi/549755813888) q[138];
cx q[138],q[100];
u1(-pi/549755813888) q[100];
cx q[138],q[100];
u1(pi/549755813888) q[100];
u1(pi/274877906944) q[138];
cx q[138],q[101];
u1(-pi/274877906944) q[101];
cx q[138],q[101];
u1(pi/274877906944) q[101];
u1(pi/137438953472) q[138];
cx q[138],q[102];
u1(-pi/137438953472) q[102];
cx q[138],q[102];
u1(pi/137438953472) q[102];
u1(pi/68719476736) q[138];
cx q[138],q[103];
u1(-pi/68719476736) q[103];
cx q[138],q[103];
u1(pi/68719476736) q[103];
u1(pi/34359738368) q[138];
cx q[138],q[104];
u1(-pi/34359738368) q[104];
cx q[138],q[104];
u1(pi/34359738368) q[104];
u1(pi/17179869184) q[138];
cx q[138],q[105];
u1(-pi/17179869184) q[105];
cx q[138],q[105];
u1(pi/17179869184) q[105];
u1(pi/8589934592) q[138];
cx q[138],q[106];
u1(-pi/8589934592) q[106];
cx q[138],q[106];
u1(pi/8589934592) q[106];
u1(pi/4294967296) q[138];
cx q[138],q[107];
u1(-pi/4294967296) q[107];
cx q[138],q[107];
u1(pi/4294967296) q[107];
u1(pi/2147483648) q[138];
cx q[138],q[108];
u1(-pi/2147483648) q[108];
cx q[138],q[108];
u1(pi/2147483648) q[108];
u1(pi/1073741824) q[138];
cx q[138],q[109];
u1(-pi/1073741824) q[109];
cx q[138],q[109];
u1(pi/1073741824) q[109];
u1(pi/536870912) q[138];
cx q[138],q[110];
u1(-pi/536870912) q[110];
cx q[138],q[110];
u1(pi/536870912) q[110];
u1(pi/268435456) q[138];
cx q[138],q[111];
u1(-pi/268435456) q[111];
cx q[138],q[111];
u1(pi/268435456) q[111];
u1(pi/134217728) q[138];
cx q[138],q[112];
u1(-pi/134217728) q[112];
cx q[138],q[112];
u1(pi/134217728) q[112];
u1(pi/67108864) q[138];
cx q[138],q[113];
u1(-pi/67108864) q[113];
cx q[138],q[113];
u1(pi/67108864) q[113];
u1(pi/33554432) q[138];
cx q[138],q[114];
u1(-pi/33554432) q[114];
cx q[138],q[114];
u1(pi/33554432) q[114];
u1(pi/16777216) q[138];
cx q[138],q[115];
u1(-pi/16777216) q[115];
cx q[138],q[115];
u1(pi/16777216) q[115];
u1(pi/8388608) q[138];
cx q[138],q[116];
u1(-pi/8388608) q[116];
cx q[138],q[116];
u1(pi/8388608) q[116];
u1(pi/4194304) q[138];
cx q[138],q[117];
u1(-pi/4194304) q[117];
cx q[138],q[117];
u1(pi/4194304) q[117];
u1(pi/2097152) q[138];
cx q[138],q[118];
u1(-pi/2097152) q[118];
cx q[138],q[118];
u1(pi/2097152) q[118];
u1(pi/1048576) q[138];
cx q[138],q[119];
u1(-pi/1048576) q[119];
cx q[138],q[119];
u1(pi/1048576) q[119];
u1(pi/524288) q[138];
cx q[138],q[120];
u1(-pi/524288) q[120];
cx q[138],q[120];
u1(pi/524288) q[120];
u1(pi/262144) q[138];
cx q[138],q[121];
u1(-pi/262144) q[121];
cx q[138],q[121];
u1(pi/262144) q[121];
u1(pi/131072) q[138];
cx q[138],q[122];
u1(-pi/131072) q[122];
cx q[138],q[122];
u1(pi/131072) q[122];
u1(pi/65536) q[138];
cx q[138],q[123];
u1(-pi/65536) q[123];
cx q[138],q[123];
u1(pi/65536) q[123];
u1(pi/32768) q[138];
cx q[138],q[124];
u1(-pi/32768) q[124];
cx q[138],q[124];
u1(pi/32768) q[124];
u1(pi/16384) q[138];
cx q[138],q[125];
u1(-pi/16384) q[125];
cx q[138],q[125];
u1(pi/16384) q[125];
u1(pi/8192) q[138];
cx q[138],q[126];
u1(-pi/8192) q[126];
cx q[138],q[126];
u1(pi/8192) q[126];
u1(pi/4096) q[138];
cx q[138],q[127];
u1(-pi/4096) q[127];
cx q[138],q[127];
u1(pi/4096) q[127];
u1(pi/2048) q[138];
cx q[138],q[128];
u1(-pi/2048) q[128];
cx q[138],q[128];
u1(pi/2048) q[128];
u1(pi/1024) q[138];
cx q[138],q[129];
u1(-pi/1024) q[129];
cx q[138],q[129];
u1(pi/1024) q[129];
u1(pi/512) q[138];
cx q[138],q[130];
u1(-pi/512) q[130];
cx q[138],q[130];
u1(pi/512) q[130];
u1(pi/256) q[138];
cx q[138],q[131];
u1(-pi/256) q[131];
cx q[138],q[131];
u1(pi/256) q[131];
u1(pi/128) q[138];
cx q[138],q[132];
u1(-pi/128) q[132];
cx q[138],q[132];
u1(pi/128) q[132];
u1(pi/64) q[138];
cx q[138],q[133];
u1(-pi/64) q[133];
cx q[138],q[133];
u1(pi/64) q[133];
u1(pi/32) q[138];
cx q[138],q[134];
u1(-pi/32) q[134];
cx q[138],q[134];
u1(pi/32) q[134];
u1(pi/16) q[138];
cx q[138],q[135];
u1(-pi/16) q[135];
cx q[138],q[135];
u1(pi/16) q[135];
u1(pi/8) q[138];
cx q[138],q[136];
u1(-pi/8) q[136];
cx q[138],q[136];
u1(pi/8) q[136];
u1(pi/4) q[138];
cx q[138],q[137];
u1(-pi/4) q[137];
cx q[138],q[137];
u1(pi/4) q[137];
h q[138];
u1(0) q[139];
cx q[139],q[0];
u1(0) q[0];
cx q[139],q[0];
u1(0) q[0];
u1(0) q[139];
cx q[139],q[1];
u1(0) q[1];
cx q[139],q[1];
u1(0) q[1];
u1(0) q[139];
cx q[139],q[2];
u1(0) q[2];
cx q[139],q[2];
u1(0) q[2];
u1(0) q[139];
cx q[139],q[3];
u1(0) q[3];
cx q[139],q[3];
u1(0) q[3];
u1(0) q[139];
cx q[139],q[4];
u1(0) q[4];
cx q[139],q[4];
u1(0) q[4];
u1(0) q[139];
cx q[139],q[5];
u1(0) q[5];
cx q[139],q[5];
u1(0) q[5];
u1(0) q[139];
cx q[139],q[6];
u1(0) q[6];
cx q[139],q[6];
u1(0) q[6];
u1(0) q[139];
cx q[139],q[7];
u1(0) q[7];
cx q[139],q[7];
u1(0) q[7];
u1(0) q[139];
cx q[139],q[8];
u1(0) q[8];
cx q[139],q[8];
u1(0) q[8];
u1(0) q[139];
cx q[139],q[9];
u1(0) q[9];
cx q[139],q[9];
u1(0) q[9];
u1(0) q[139];
cx q[139],q[10];
u1(0) q[10];
cx q[139],q[10];
u1(0) q[10];
u1(0) q[139];
cx q[139],q[11];
u1(0) q[11];
cx q[139],q[11];
u1(0) q[11];
u1(0) q[139];
cx q[139],q[12];
u1(0) q[12];
cx q[139],q[12];
u1(0) q[12];
u1(0) q[139];
cx q[139],q[13];
u1(0) q[13];
cx q[139],q[13];
u1(0) q[13];
u1(0) q[139];
cx q[139],q[14];
u1(0) q[14];
cx q[139],q[14];
u1(0) q[14];
u1(0) q[139];
cx q[139],q[15];
u1(0) q[15];
cx q[139],q[15];
u1(0) q[15];
u1(0) q[139];
cx q[139],q[16];
u1(0) q[16];
cx q[139],q[16];
u1(0) q[16];
u1(0) q[139];
cx q[139],q[17];
u1(0) q[17];
cx q[139],q[17];
u1(0) q[17];
u1(0) q[139];
cx q[139],q[18];
u1(0) q[18];
cx q[139],q[18];
u1(0) q[18];
u1(0) q[139];
cx q[139],q[19];
u1(0) q[19];
cx q[139],q[19];
u1(0) q[19];
u1(0) q[139];
cx q[139],q[20];
u1(0) q[20];
cx q[139],q[20];
u1(0) q[20];
u1(0) q[139];
cx q[139],q[21];
u1(0) q[21];
cx q[139],q[21];
u1(0) q[21];
u1(0) q[139];
cx q[139],q[22];
u1(0) q[22];
cx q[139],q[22];
u1(0) q[22];
u1(0) q[139];
cx q[139],q[23];
u1(0) q[23];
cx q[139],q[23];
u1(0) q[23];
u1(0) q[139];
cx q[139],q[24];
u1(0) q[24];
cx q[139],q[24];
u1(0) q[24];
u1(0) q[139];
cx q[139],q[25];
u1(0) q[25];
cx q[139],q[25];
u1(0) q[25];
u1(0) q[139];
cx q[139],q[26];
u1(0) q[26];
cx q[139],q[26];
u1(0) q[26];
u1(0) q[139];
cx q[139],q[27];
u1(0) q[27];
cx q[139],q[27];
u1(0) q[27];
u1(0) q[139];
cx q[139],q[28];
u1(0) q[28];
cx q[139],q[28];
u1(0) q[28];
u1(0) q[139];
cx q[139],q[29];
u1(0) q[29];
cx q[139],q[29];
u1(0) q[29];
u1(0) q[139];
cx q[139],q[30];
u1(0) q[30];
cx q[139],q[30];
u1(0) q[30];
u1(0) q[139];
cx q[139],q[31];
u1(0) q[31];
cx q[139],q[31];
u1(0) q[31];
u1(0) q[139];
cx q[139],q[32];
u1(0) q[32];
cx q[139],q[32];
u1(0) q[32];
u1(0) q[139];
cx q[139],q[33];
u1(0) q[33];
cx q[139],q[33];
u1(0) q[33];
u1(0) q[139];
cx q[139],q[34];
u1(0) q[34];
cx q[139],q[34];
u1(0) q[34];
u1(0) q[139];
cx q[139],q[35];
u1(0) q[35];
cx q[139],q[35];
u1(0) q[35];
u1(0) q[139];
cx q[139],q[36];
u1(0) q[36];
cx q[139],q[36];
u1(0) q[36];
u1(0) q[139];
cx q[139],q[37];
u1(0) q[37];
cx q[139],q[37];
u1(0) q[37];
u1(0) q[139];
cx q[139],q[38];
u1(0) q[38];
cx q[139],q[38];
u1(0) q[38];
u1(0) q[139];
cx q[139],q[39];
u1(0) q[39];
cx q[139],q[39];
u1(0) q[39];
u1(0) q[139];
cx q[139],q[40];
u1(0) q[40];
cx q[139],q[40];
u1(0) q[40];
u1(0) q[139];
cx q[139],q[41];
u1(0) q[41];
cx q[139],q[41];
u1(0) q[41];
u1(0) q[139];
cx q[139],q[42];
u1(0) q[42];
cx q[139],q[42];
u1(0) q[42];
u1(0) q[139];
cx q[139],q[43];
u1(0) q[43];
cx q[139],q[43];
u1(0) q[43];
u1(0) q[139];
cx q[139],q[44];
u1(0) q[44];
cx q[139],q[44];
u1(0) q[44];
u1(0) q[139];
cx q[139],q[45];
u1(0) q[45];
cx q[139],q[45];
u1(0) q[45];
u1(0) q[139];
cx q[139],q[46];
u1(0) q[46];
cx q[139],q[46];
u1(0) q[46];
u1(0) q[139];
cx q[139],q[47];
u1(0) q[47];
cx q[139],q[47];
u1(0) q[47];
u1(0) q[139];
cx q[139],q[48];
u1(0) q[48];
cx q[139],q[48];
u1(0) q[48];
u1(0) q[139];
cx q[139],q[49];
u1(0) q[49];
cx q[139],q[49];
u1(0) q[49];
u1(0) q[139];
cx q[139],q[50];
u1(0) q[50];
cx q[139],q[50];
u1(0) q[50];
u1(0) q[139];
cx q[139],q[51];
u1(0) q[51];
cx q[139],q[51];
u1(0) q[51];
u1(0) q[139];
cx q[139],q[52];
u1(0) q[52];
cx q[139],q[52];
u1(0) q[52];
u1(0) q[139];
cx q[139],q[53];
u1(0) q[53];
cx q[139],q[53];
u1(0) q[53];
u1(0) q[139];
cx q[139],q[54];
u1(0) q[54];
cx q[139],q[54];
u1(0) q[54];
u1(0) q[139];
cx q[139],q[55];
u1(0) q[55];
cx q[139],q[55];
u1(0) q[55];
u1(0) q[139];
cx q[139],q[56];
u1(0) q[56];
cx q[139],q[56];
u1(0) q[56];
u1(0) q[139];
cx q[139],q[57];
u1(0) q[57];
cx q[139],q[57];
u1(0) q[57];
u1(0) q[139];
cx q[139],q[58];
u1(0) q[58];
cx q[139],q[58];
u1(0) q[58];
u1(0) q[139];
cx q[139],q[59];
u1(0) q[59];
cx q[139],q[59];
u1(0) q[59];
u1(0) q[139];
cx q[139],q[60];
u1(0) q[60];
cx q[139],q[60];
u1(0) q[60];
u1(0) q[139];
cx q[139],q[61];
u1(0) q[61];
cx q[139],q[61];
u1(0) q[61];
u1(0) q[139];
cx q[139],q[62];
u1(0) q[62];
cx q[139],q[62];
u1(0) q[62];
u1(0) q[139];
cx q[139],q[63];
u1(0) q[63];
cx q[139],q[63];
u1(0) q[63];
u1(0) q[139];
cx q[139],q[64];
u1(0) q[64];
cx q[139],q[64];
u1(0) q[64];
u1(0) q[139];
cx q[139],q[65];
u1(0) q[65];
cx q[139],q[65];
u1(0) q[65];
u1(0) q[139];
cx q[139],q[66];
u1(0) q[66];
cx q[139],q[66];
u1(0) q[66];
u1(0) q[139];
cx q[139],q[67];
u1(0) q[67];
cx q[139],q[67];
u1(0) q[67];
u1(0) q[139];
cx q[139],q[68];
u1(0) q[68];
cx q[139],q[68];
u1(0) q[68];
u1(0) q[139];
cx q[139],q[69];
u1(0) q[69];
cx q[139],q[69];
u1(0) q[69];
u1(0) q[139];
cx q[139],q[70];
u1(0) q[70];
cx q[139],q[70];
u1(0) q[70];
u1(0) q[139];
cx q[139],q[71];
u1(0) q[71];
cx q[139],q[71];
u1(0) q[71];
u1(0) q[139];
cx q[139],q[72];
u1(0) q[72];
cx q[139],q[72];
u1(0) q[72];
u1(0) q[139];
cx q[139],q[73];
u1(0) q[73];
cx q[139],q[73];
u1(0) q[73];
u1(0) q[139];
cx q[139],q[74];
u1(0) q[74];
cx q[139],q[74];
u1(0) q[74];
u1(0) q[139];
cx q[139],q[75];
u1(0) q[75];
cx q[139],q[75];
u1(0) q[75];
u1(0) q[139];
cx q[139],q[76];
u1(0) q[76];
cx q[139],q[76];
u1(0) q[76];
u1(0) q[139];
cx q[139],q[77];
u1(0) q[77];
cx q[139],q[77];
u1(0) q[77];
u1(0) q[139];
cx q[139],q[78];
u1(0) q[78];
cx q[139],q[78];
u1(0) q[78];
u1(0) q[139];
cx q[139],q[79];
u1(0) q[79];
cx q[139],q[79];
u1(0) q[79];
u1(0) q[139];
cx q[139],q[80];
u1(0) q[80];
cx q[139],q[80];
u1(0) q[80];
u1(0) q[139];
cx q[139],q[81];
u1(0) q[81];
cx q[139],q[81];
u1(0) q[81];
u1(0) q[139];
cx q[139],q[82];
u1(0) q[82];
cx q[139],q[82];
u1(0) q[82];
u1(0) q[139];
cx q[139],q[83];
u1(0) q[83];
cx q[139],q[83];
u1(0) q[83];
u1(0) q[139];
cx q[139],q[84];
u1(0) q[84];
cx q[139],q[84];
u1(0) q[84];
u1(0) q[139];
cx q[139],q[85];
u1(0) q[85];
cx q[139],q[85];
u1(0) q[85];
u1(0) q[139];
cx q[139],q[86];
u1(0) q[86];
cx q[139],q[86];
u1(0) q[86];
u1(0) q[139];
cx q[139],q[87];
u1(0) q[87];
cx q[139],q[87];
u1(0) q[87];
u1(0) q[139];
cx q[139],q[88];
u1(0) q[88];
cx q[139],q[88];
u1(0) q[88];
u1(0) q[139];
cx q[139],q[89];
u1(0) q[89];
cx q[139],q[89];
u1(0) q[89];
u1(0) q[139];
cx q[139],q[90];
u1(0) q[90];
cx q[139],q[90];
u1(0) q[90];
u1(0) q[139];
cx q[139],q[91];
u1(0) q[91];
cx q[139],q[91];
u1(0) q[91];
u1(pi/281474976710656) q[139];
cx q[139],q[92];
u1(-pi/281474976710656) q[92];
cx q[139],q[92];
u1(pi/281474976710656) q[92];
u1(pi/140737488355328) q[139];
cx q[139],q[93];
u1(-pi/140737488355328) q[93];
cx q[139],q[93];
u1(pi/140737488355328) q[93];
u1(pi/70368744177664) q[139];
cx q[139],q[94];
u1(-pi/70368744177664) q[94];
cx q[139],q[94];
u1(pi/70368744177664) q[94];
u1(pi/35184372088832) q[139];
cx q[139],q[95];
u1(-pi/35184372088832) q[95];
cx q[139],q[95];
u1(pi/35184372088832) q[95];
u1(pi/17592186044416) q[139];
cx q[139],q[96];
u1(-pi/17592186044416) q[96];
cx q[139],q[96];
u1(pi/17592186044416) q[96];
u1(pi/8796093022208) q[139];
cx q[139],q[97];
u1(-pi/8796093022208) q[97];
cx q[139],q[97];
u1(pi/8796093022208) q[97];
u1(pi/4398046511104) q[139];
cx q[139],q[98];
u1(-pi/4398046511104) q[98];
cx q[139],q[98];
u1(pi/4398046511104) q[98];
u1(pi/2199023255552) q[139];
cx q[139],q[99];
u1(-pi/2199023255552) q[99];
cx q[139],q[99];
u1(pi/2199023255552) q[99];
u1(pi/1099511627776) q[139];
cx q[139],q[100];
u1(-pi/1099511627776) q[100];
cx q[139],q[100];
u1(pi/1099511627776) q[100];
u1(pi/549755813888) q[139];
cx q[139],q[101];
u1(-pi/549755813888) q[101];
cx q[139],q[101];
u1(pi/549755813888) q[101];
u1(pi/274877906944) q[139];
cx q[139],q[102];
u1(-pi/274877906944) q[102];
cx q[139],q[102];
u1(pi/274877906944) q[102];
u1(pi/137438953472) q[139];
cx q[139],q[103];
u1(-pi/137438953472) q[103];
cx q[139],q[103];
u1(pi/137438953472) q[103];
u1(pi/68719476736) q[139];
cx q[139],q[104];
u1(-pi/68719476736) q[104];
cx q[139],q[104];
u1(pi/68719476736) q[104];
u1(pi/34359738368) q[139];
cx q[139],q[105];
u1(-pi/34359738368) q[105];
cx q[139],q[105];
u1(pi/34359738368) q[105];
u1(pi/17179869184) q[139];
cx q[139],q[106];
u1(-pi/17179869184) q[106];
cx q[139],q[106];
u1(pi/17179869184) q[106];
u1(pi/8589934592) q[139];
cx q[139],q[107];
u1(-pi/8589934592) q[107];
cx q[139],q[107];
u1(pi/8589934592) q[107];
u1(pi/4294967296) q[139];
cx q[139],q[108];
u1(-pi/4294967296) q[108];
cx q[139],q[108];
u1(pi/4294967296) q[108];
u1(pi/2147483648) q[139];
cx q[139],q[109];
u1(-pi/2147483648) q[109];
cx q[139],q[109];
u1(pi/2147483648) q[109];
u1(pi/1073741824) q[139];
cx q[139],q[110];
u1(-pi/1073741824) q[110];
cx q[139],q[110];
u1(pi/1073741824) q[110];
u1(pi/536870912) q[139];
cx q[139],q[111];
u1(-pi/536870912) q[111];
cx q[139],q[111];
u1(pi/536870912) q[111];
u1(pi/268435456) q[139];
cx q[139],q[112];
u1(-pi/268435456) q[112];
cx q[139],q[112];
u1(pi/268435456) q[112];
u1(pi/134217728) q[139];
cx q[139],q[113];
u1(-pi/134217728) q[113];
cx q[139],q[113];
u1(pi/134217728) q[113];
u1(pi/67108864) q[139];
cx q[139],q[114];
u1(-pi/67108864) q[114];
cx q[139],q[114];
u1(pi/67108864) q[114];
u1(pi/33554432) q[139];
cx q[139],q[115];
u1(-pi/33554432) q[115];
cx q[139],q[115];
u1(pi/33554432) q[115];
u1(pi/16777216) q[139];
cx q[139],q[116];
u1(-pi/16777216) q[116];
cx q[139],q[116];
u1(pi/16777216) q[116];
u1(pi/8388608) q[139];
cx q[139],q[117];
u1(-pi/8388608) q[117];
cx q[139],q[117];
u1(pi/8388608) q[117];
u1(pi/4194304) q[139];
cx q[139],q[118];
u1(-pi/4194304) q[118];
cx q[139],q[118];
u1(pi/4194304) q[118];
u1(pi/2097152) q[139];
cx q[139],q[119];
u1(-pi/2097152) q[119];
cx q[139],q[119];
u1(pi/2097152) q[119];
u1(pi/1048576) q[139];
cx q[139],q[120];
u1(-pi/1048576) q[120];
cx q[139],q[120];
u1(pi/1048576) q[120];
u1(pi/524288) q[139];
cx q[139],q[121];
u1(-pi/524288) q[121];
cx q[139],q[121];
u1(pi/524288) q[121];
u1(pi/262144) q[139];
cx q[139],q[122];
u1(-pi/262144) q[122];
cx q[139],q[122];
u1(pi/262144) q[122];
u1(pi/131072) q[139];
cx q[139],q[123];
u1(-pi/131072) q[123];
cx q[139],q[123];
u1(pi/131072) q[123];
u1(pi/65536) q[139];
cx q[139],q[124];
u1(-pi/65536) q[124];
cx q[139],q[124];
u1(pi/65536) q[124];
u1(pi/32768) q[139];
cx q[139],q[125];
u1(-pi/32768) q[125];
cx q[139],q[125];
u1(pi/32768) q[125];
u1(pi/16384) q[139];
cx q[139],q[126];
u1(-pi/16384) q[126];
cx q[139],q[126];
u1(pi/16384) q[126];
u1(pi/8192) q[139];
cx q[139],q[127];
u1(-pi/8192) q[127];
cx q[139],q[127];
u1(pi/8192) q[127];
u1(pi/4096) q[139];
cx q[139],q[128];
u1(-pi/4096) q[128];
cx q[139],q[128];
u1(pi/4096) q[128];
u1(pi/2048) q[139];
cx q[139],q[129];
u1(-pi/2048) q[129];
cx q[139],q[129];
u1(pi/2048) q[129];
u1(pi/1024) q[139];
cx q[139],q[130];
u1(-pi/1024) q[130];
cx q[139],q[130];
u1(pi/1024) q[130];
u1(pi/512) q[139];
cx q[139],q[131];
u1(-pi/512) q[131];
cx q[139],q[131];
u1(pi/512) q[131];
u1(pi/256) q[139];
cx q[139],q[132];
u1(-pi/256) q[132];
cx q[139],q[132];
u1(pi/256) q[132];
u1(pi/128) q[139];
cx q[139],q[133];
u1(-pi/128) q[133];
cx q[139],q[133];
u1(pi/128) q[133];
u1(pi/64) q[139];
cx q[139],q[134];
u1(-pi/64) q[134];
cx q[139],q[134];
u1(pi/64) q[134];
u1(pi/32) q[139];
cx q[139],q[135];
u1(-pi/32) q[135];
cx q[139],q[135];
u1(pi/32) q[135];
u1(pi/16) q[139];
cx q[139],q[136];
u1(-pi/16) q[136];
cx q[139],q[136];
u1(pi/16) q[136];
u1(pi/8) q[139];
cx q[139],q[137];
u1(-pi/8) q[137];
cx q[139],q[137];
u1(pi/8) q[137];
u1(pi/4) q[139];
cx q[139],q[138];
u1(-pi/4) q[138];
cx q[139],q[138];
u1(pi/4) q[138];
h q[139];
u1(0) q[140];
cx q[140],q[0];
u1(0) q[0];
cx q[140],q[0];
u1(0) q[0];
u1(0) q[140];
cx q[140],q[1];
u1(0) q[1];
cx q[140],q[1];
u1(0) q[1];
u1(0) q[140];
cx q[140],q[2];
u1(0) q[2];
cx q[140],q[2];
u1(0) q[2];
u1(0) q[140];
cx q[140],q[3];
u1(0) q[3];
cx q[140],q[3];
u1(0) q[3];
u1(0) q[140];
cx q[140],q[4];
u1(0) q[4];
cx q[140],q[4];
u1(0) q[4];
u1(0) q[140];
cx q[140],q[5];
u1(0) q[5];
cx q[140],q[5];
u1(0) q[5];
u1(0) q[140];
cx q[140],q[6];
u1(0) q[6];
cx q[140],q[6];
u1(0) q[6];
u1(0) q[140];
cx q[140],q[7];
u1(0) q[7];
cx q[140],q[7];
u1(0) q[7];
u1(0) q[140];
cx q[140],q[8];
u1(0) q[8];
cx q[140],q[8];
u1(0) q[8];
u1(0) q[140];
cx q[140],q[9];
u1(0) q[9];
cx q[140],q[9];
u1(0) q[9];
u1(0) q[140];
cx q[140],q[10];
u1(0) q[10];
cx q[140],q[10];
u1(0) q[10];
u1(0) q[140];
cx q[140],q[11];
u1(0) q[11];
cx q[140],q[11];
u1(0) q[11];
u1(0) q[140];
cx q[140],q[12];
u1(0) q[12];
cx q[140],q[12];
u1(0) q[12];
u1(0) q[140];
cx q[140],q[13];
u1(0) q[13];
cx q[140],q[13];
u1(0) q[13];
u1(0) q[140];
cx q[140],q[14];
u1(0) q[14];
cx q[140],q[14];
u1(0) q[14];
u1(0) q[140];
cx q[140],q[15];
u1(0) q[15];
cx q[140],q[15];
u1(0) q[15];
u1(0) q[140];
cx q[140],q[16];
u1(0) q[16];
cx q[140],q[16];
u1(0) q[16];
u1(0) q[140];
cx q[140],q[17];
u1(0) q[17];
cx q[140],q[17];
u1(0) q[17];
u1(0) q[140];
cx q[140],q[18];
u1(0) q[18];
cx q[140],q[18];
u1(0) q[18];
u1(0) q[140];
cx q[140],q[19];
u1(0) q[19];
cx q[140],q[19];
u1(0) q[19];
u1(0) q[140];
cx q[140],q[20];
u1(0) q[20];
cx q[140],q[20];
u1(0) q[20];
u1(0) q[140];
cx q[140],q[21];
u1(0) q[21];
cx q[140],q[21];
u1(0) q[21];
u1(0) q[140];
cx q[140],q[22];
u1(0) q[22];
cx q[140],q[22];
u1(0) q[22];
u1(0) q[140];
cx q[140],q[23];
u1(0) q[23];
cx q[140],q[23];
u1(0) q[23];
u1(0) q[140];
cx q[140],q[24];
u1(0) q[24];
cx q[140],q[24];
u1(0) q[24];
u1(0) q[140];
cx q[140],q[25];
u1(0) q[25];
cx q[140],q[25];
u1(0) q[25];
u1(0) q[140];
cx q[140],q[26];
u1(0) q[26];
cx q[140],q[26];
u1(0) q[26];
u1(0) q[140];
cx q[140],q[27];
u1(0) q[27];
cx q[140],q[27];
u1(0) q[27];
u1(0) q[140];
cx q[140],q[28];
u1(0) q[28];
cx q[140],q[28];
u1(0) q[28];
u1(0) q[140];
cx q[140],q[29];
u1(0) q[29];
cx q[140],q[29];
u1(0) q[29];
u1(0) q[140];
cx q[140],q[30];
u1(0) q[30];
cx q[140],q[30];
u1(0) q[30];
u1(0) q[140];
cx q[140],q[31];
u1(0) q[31];
cx q[140],q[31];
u1(0) q[31];
u1(0) q[140];
cx q[140],q[32];
u1(0) q[32];
cx q[140],q[32];
u1(0) q[32];
u1(0) q[140];
cx q[140],q[33];
u1(0) q[33];
cx q[140],q[33];
u1(0) q[33];
u1(0) q[140];
cx q[140],q[34];
u1(0) q[34];
cx q[140],q[34];
u1(0) q[34];
u1(0) q[140];
cx q[140],q[35];
u1(0) q[35];
cx q[140],q[35];
u1(0) q[35];
u1(0) q[140];
cx q[140],q[36];
u1(0) q[36];
cx q[140],q[36];
u1(0) q[36];
u1(0) q[140];
cx q[140],q[37];
u1(0) q[37];
cx q[140],q[37];
u1(0) q[37];
u1(0) q[140];
cx q[140],q[38];
u1(0) q[38];
cx q[140],q[38];
u1(0) q[38];
u1(0) q[140];
cx q[140],q[39];
u1(0) q[39];
cx q[140],q[39];
u1(0) q[39];
u1(0) q[140];
cx q[140],q[40];
u1(0) q[40];
cx q[140],q[40];
u1(0) q[40];
u1(0) q[140];
cx q[140],q[41];
u1(0) q[41];
cx q[140],q[41];
u1(0) q[41];
u1(0) q[140];
cx q[140],q[42];
u1(0) q[42];
cx q[140],q[42];
u1(0) q[42];
u1(0) q[140];
cx q[140],q[43];
u1(0) q[43];
cx q[140],q[43];
u1(0) q[43];
u1(0) q[140];
cx q[140],q[44];
u1(0) q[44];
cx q[140],q[44];
u1(0) q[44];
u1(0) q[140];
cx q[140],q[45];
u1(0) q[45];
cx q[140],q[45];
u1(0) q[45];
u1(0) q[140];
cx q[140],q[46];
u1(0) q[46];
cx q[140],q[46];
u1(0) q[46];
u1(0) q[140];
cx q[140],q[47];
u1(0) q[47];
cx q[140],q[47];
u1(0) q[47];
u1(0) q[140];
cx q[140],q[48];
u1(0) q[48];
cx q[140],q[48];
u1(0) q[48];
u1(0) q[140];
cx q[140],q[49];
u1(0) q[49];
cx q[140],q[49];
u1(0) q[49];
u1(0) q[140];
cx q[140],q[50];
u1(0) q[50];
cx q[140],q[50];
u1(0) q[50];
u1(0) q[140];
cx q[140],q[51];
u1(0) q[51];
cx q[140],q[51];
u1(0) q[51];
u1(0) q[140];
cx q[140],q[52];
u1(0) q[52];
cx q[140],q[52];
u1(0) q[52];
u1(0) q[140];
cx q[140],q[53];
u1(0) q[53];
cx q[140],q[53];
u1(0) q[53];
u1(0) q[140];
cx q[140],q[54];
u1(0) q[54];
cx q[140],q[54];
u1(0) q[54];
u1(0) q[140];
cx q[140],q[55];
u1(0) q[55];
cx q[140],q[55];
u1(0) q[55];
u1(0) q[140];
cx q[140],q[56];
u1(0) q[56];
cx q[140],q[56];
u1(0) q[56];
u1(0) q[140];
cx q[140],q[57];
u1(0) q[57];
cx q[140],q[57];
u1(0) q[57];
u1(0) q[140];
cx q[140],q[58];
u1(0) q[58];
cx q[140],q[58];
u1(0) q[58];
u1(0) q[140];
cx q[140],q[59];
u1(0) q[59];
cx q[140],q[59];
u1(0) q[59];
u1(0) q[140];
cx q[140],q[60];
u1(0) q[60];
cx q[140],q[60];
u1(0) q[60];
u1(0) q[140];
cx q[140],q[61];
u1(0) q[61];
cx q[140],q[61];
u1(0) q[61];
u1(0) q[140];
cx q[140],q[62];
u1(0) q[62];
cx q[140],q[62];
u1(0) q[62];
u1(0) q[140];
cx q[140],q[63];
u1(0) q[63];
cx q[140],q[63];
u1(0) q[63];
u1(0) q[140];
cx q[140],q[64];
u1(0) q[64];
cx q[140],q[64];
u1(0) q[64];
u1(0) q[140];
cx q[140],q[65];
u1(0) q[65];
cx q[140],q[65];
u1(0) q[65];
u1(0) q[140];
cx q[140],q[66];
u1(0) q[66];
cx q[140],q[66];
u1(0) q[66];
u1(0) q[140];
cx q[140],q[67];
u1(0) q[67];
cx q[140],q[67];
u1(0) q[67];
u1(0) q[140];
cx q[140],q[68];
u1(0) q[68];
cx q[140],q[68];
u1(0) q[68];
u1(0) q[140];
cx q[140],q[69];
u1(0) q[69];
cx q[140],q[69];
u1(0) q[69];
u1(0) q[140];
cx q[140],q[70];
u1(0) q[70];
cx q[140],q[70];
u1(0) q[70];
u1(0) q[140];
cx q[140],q[71];
u1(0) q[71];
cx q[140],q[71];
u1(0) q[71];
u1(0) q[140];
cx q[140],q[72];
u1(0) q[72];
cx q[140],q[72];
u1(0) q[72];
u1(0) q[140];
cx q[140],q[73];
u1(0) q[73];
cx q[140],q[73];
u1(0) q[73];
u1(0) q[140];
cx q[140],q[74];
u1(0) q[74];
cx q[140],q[74];
u1(0) q[74];
u1(0) q[140];
cx q[140],q[75];
u1(0) q[75];
cx q[140],q[75];
u1(0) q[75];
u1(0) q[140];
cx q[140],q[76];
u1(0) q[76];
cx q[140],q[76];
u1(0) q[76];
u1(0) q[140];
cx q[140],q[77];
u1(0) q[77];
cx q[140],q[77];
u1(0) q[77];
u1(0) q[140];
cx q[140],q[78];
u1(0) q[78];
cx q[140],q[78];
u1(0) q[78];
u1(0) q[140];
cx q[140],q[79];
u1(0) q[79];
cx q[140],q[79];
u1(0) q[79];
u1(0) q[140];
cx q[140],q[80];
u1(0) q[80];
cx q[140],q[80];
u1(0) q[80];
u1(0) q[140];
cx q[140],q[81];
u1(0) q[81];
cx q[140],q[81];
u1(0) q[81];
u1(0) q[140];
cx q[140],q[82];
u1(0) q[82];
cx q[140],q[82];
u1(0) q[82];
u1(0) q[140];
cx q[140],q[83];
u1(0) q[83];
cx q[140],q[83];
u1(0) q[83];
u1(0) q[140];
cx q[140],q[84];
u1(0) q[84];
cx q[140],q[84];
u1(0) q[84];
u1(0) q[140];
cx q[140],q[85];
u1(0) q[85];
cx q[140],q[85];
u1(0) q[85];
u1(0) q[140];
cx q[140],q[86];
u1(0) q[86];
cx q[140],q[86];
u1(0) q[86];
u1(0) q[140];
cx q[140],q[87];
u1(0) q[87];
cx q[140],q[87];
u1(0) q[87];
u1(0) q[140];
cx q[140],q[88];
u1(0) q[88];
cx q[140],q[88];
u1(0) q[88];
u1(0) q[140];
cx q[140],q[89];
u1(0) q[89];
cx q[140],q[89];
u1(0) q[89];
u1(0) q[140];
cx q[140],q[90];
u1(0) q[90];
cx q[140],q[90];
u1(0) q[90];
u1(0) q[140];
cx q[140],q[91];
u1(0) q[91];
cx q[140],q[91];
u1(0) q[91];
u1(0) q[140];
cx q[140],q[92];
u1(0) q[92];
cx q[140],q[92];
u1(0) q[92];
u1(pi/281474976710656) q[140];
cx q[140],q[93];
u1(-pi/281474976710656) q[93];
cx q[140],q[93];
u1(pi/281474976710656) q[93];
u1(pi/140737488355328) q[140];
cx q[140],q[94];
u1(-pi/140737488355328) q[94];
cx q[140],q[94];
u1(pi/140737488355328) q[94];
u1(pi/70368744177664) q[140];
cx q[140],q[95];
u1(-pi/70368744177664) q[95];
cx q[140],q[95];
u1(pi/70368744177664) q[95];
u1(pi/35184372088832) q[140];
cx q[140],q[96];
u1(-pi/35184372088832) q[96];
cx q[140],q[96];
u1(pi/35184372088832) q[96];
u1(pi/17592186044416) q[140];
cx q[140],q[97];
u1(-pi/17592186044416) q[97];
cx q[140],q[97];
u1(pi/17592186044416) q[97];
u1(pi/8796093022208) q[140];
cx q[140],q[98];
u1(-pi/8796093022208) q[98];
cx q[140],q[98];
u1(pi/8796093022208) q[98];
u1(pi/4398046511104) q[140];
cx q[140],q[99];
u1(-pi/4398046511104) q[99];
cx q[140],q[99];
u1(pi/4398046511104) q[99];
u1(pi/2199023255552) q[140];
cx q[140],q[100];
u1(-pi/2199023255552) q[100];
cx q[140],q[100];
u1(pi/2199023255552) q[100];
u1(pi/1099511627776) q[140];
cx q[140],q[101];
u1(-pi/1099511627776) q[101];
cx q[140],q[101];
u1(pi/1099511627776) q[101];
u1(pi/549755813888) q[140];
cx q[140],q[102];
u1(-pi/549755813888) q[102];
cx q[140],q[102];
u1(pi/549755813888) q[102];
u1(pi/274877906944) q[140];
cx q[140],q[103];
u1(-pi/274877906944) q[103];
cx q[140],q[103];
u1(pi/274877906944) q[103];
u1(pi/137438953472) q[140];
cx q[140],q[104];
u1(-pi/137438953472) q[104];
cx q[140],q[104];
u1(pi/137438953472) q[104];
u1(pi/68719476736) q[140];
cx q[140],q[105];
u1(-pi/68719476736) q[105];
cx q[140],q[105];
u1(pi/68719476736) q[105];
u1(pi/34359738368) q[140];
cx q[140],q[106];
u1(-pi/34359738368) q[106];
cx q[140],q[106];
u1(pi/34359738368) q[106];
u1(pi/17179869184) q[140];
cx q[140],q[107];
u1(-pi/17179869184) q[107];
cx q[140],q[107];
u1(pi/17179869184) q[107];
u1(pi/8589934592) q[140];
cx q[140],q[108];
u1(-pi/8589934592) q[108];
cx q[140],q[108];
u1(pi/8589934592) q[108];
u1(pi/4294967296) q[140];
cx q[140],q[109];
u1(-pi/4294967296) q[109];
cx q[140],q[109];
u1(pi/4294967296) q[109];
u1(pi/2147483648) q[140];
cx q[140],q[110];
u1(-pi/2147483648) q[110];
cx q[140],q[110];
u1(pi/2147483648) q[110];
u1(pi/1073741824) q[140];
cx q[140],q[111];
u1(-pi/1073741824) q[111];
cx q[140],q[111];
u1(pi/1073741824) q[111];
u1(pi/536870912) q[140];
cx q[140],q[112];
u1(-pi/536870912) q[112];
cx q[140],q[112];
u1(pi/536870912) q[112];
u1(pi/268435456) q[140];
cx q[140],q[113];
u1(-pi/268435456) q[113];
cx q[140],q[113];
u1(pi/268435456) q[113];
u1(pi/134217728) q[140];
cx q[140],q[114];
u1(-pi/134217728) q[114];
cx q[140],q[114];
u1(pi/134217728) q[114];
u1(pi/67108864) q[140];
cx q[140],q[115];
u1(-pi/67108864) q[115];
cx q[140],q[115];
u1(pi/67108864) q[115];
u1(pi/33554432) q[140];
cx q[140],q[116];
u1(-pi/33554432) q[116];
cx q[140],q[116];
u1(pi/33554432) q[116];
u1(pi/16777216) q[140];
cx q[140],q[117];
u1(-pi/16777216) q[117];
cx q[140],q[117];
u1(pi/16777216) q[117];
u1(pi/8388608) q[140];
cx q[140],q[118];
u1(-pi/8388608) q[118];
cx q[140],q[118];
u1(pi/8388608) q[118];
u1(pi/4194304) q[140];
cx q[140],q[119];
u1(-pi/4194304) q[119];
cx q[140],q[119];
u1(pi/4194304) q[119];
u1(pi/2097152) q[140];
cx q[140],q[120];
u1(-pi/2097152) q[120];
cx q[140],q[120];
u1(pi/2097152) q[120];
u1(pi/1048576) q[140];
cx q[140],q[121];
u1(-pi/1048576) q[121];
cx q[140],q[121];
u1(pi/1048576) q[121];
u1(pi/524288) q[140];
cx q[140],q[122];
u1(-pi/524288) q[122];
cx q[140],q[122];
u1(pi/524288) q[122];
u1(pi/262144) q[140];
cx q[140],q[123];
u1(-pi/262144) q[123];
cx q[140],q[123];
u1(pi/262144) q[123];
u1(pi/131072) q[140];
cx q[140],q[124];
u1(-pi/131072) q[124];
cx q[140],q[124];
u1(pi/131072) q[124];
u1(pi/65536) q[140];
cx q[140],q[125];
u1(-pi/65536) q[125];
cx q[140],q[125];
u1(pi/65536) q[125];
u1(pi/32768) q[140];
cx q[140],q[126];
u1(-pi/32768) q[126];
cx q[140],q[126];
u1(pi/32768) q[126];
u1(pi/16384) q[140];
cx q[140],q[127];
u1(-pi/16384) q[127];
cx q[140],q[127];
u1(pi/16384) q[127];
u1(pi/8192) q[140];
cx q[140],q[128];
u1(-pi/8192) q[128];
cx q[140],q[128];
u1(pi/8192) q[128];
u1(pi/4096) q[140];
cx q[140],q[129];
u1(-pi/4096) q[129];
cx q[140],q[129];
u1(pi/4096) q[129];
u1(pi/2048) q[140];
cx q[140],q[130];
u1(-pi/2048) q[130];
cx q[140],q[130];
u1(pi/2048) q[130];
u1(pi/1024) q[140];
cx q[140],q[131];
u1(-pi/1024) q[131];
cx q[140],q[131];
u1(pi/1024) q[131];
u1(pi/512) q[140];
cx q[140],q[132];
u1(-pi/512) q[132];
cx q[140],q[132];
u1(pi/512) q[132];
u1(pi/256) q[140];
cx q[140],q[133];
u1(-pi/256) q[133];
cx q[140],q[133];
u1(pi/256) q[133];
u1(pi/128) q[140];
cx q[140],q[134];
u1(-pi/128) q[134];
cx q[140],q[134];
u1(pi/128) q[134];
u1(pi/64) q[140];
cx q[140],q[135];
u1(-pi/64) q[135];
cx q[140],q[135];
u1(pi/64) q[135];
u1(pi/32) q[140];
cx q[140],q[136];
u1(-pi/32) q[136];
cx q[140],q[136];
u1(pi/32) q[136];
u1(pi/16) q[140];
cx q[140],q[137];
u1(-pi/16) q[137];
cx q[140],q[137];
u1(pi/16) q[137];
u1(pi/8) q[140];
cx q[140],q[138];
u1(-pi/8) q[138];
cx q[140],q[138];
u1(pi/8) q[138];
u1(pi/4) q[140];
cx q[140],q[139];
u1(-pi/4) q[139];
cx q[140],q[139];
u1(pi/4) q[139];
h q[140];
u1(0) q[141];
cx q[141],q[0];
u1(0) q[0];
cx q[141],q[0];
u1(0) q[0];
u1(0) q[141];
cx q[141],q[1];
u1(0) q[1];
cx q[141],q[1];
u1(0) q[1];
u1(0) q[141];
cx q[141],q[2];
u1(0) q[2];
cx q[141],q[2];
u1(0) q[2];
u1(0) q[141];
cx q[141],q[3];
u1(0) q[3];
cx q[141],q[3];
u1(0) q[3];
u1(0) q[141];
cx q[141],q[4];
u1(0) q[4];
cx q[141],q[4];
u1(0) q[4];
u1(0) q[141];
cx q[141],q[5];
u1(0) q[5];
cx q[141],q[5];
u1(0) q[5];
u1(0) q[141];
cx q[141],q[6];
u1(0) q[6];
cx q[141],q[6];
u1(0) q[6];
u1(0) q[141];
cx q[141],q[7];
u1(0) q[7];
cx q[141],q[7];
u1(0) q[7];
u1(0) q[141];
cx q[141],q[8];
u1(0) q[8];
cx q[141],q[8];
u1(0) q[8];
u1(0) q[141];
cx q[141],q[9];
u1(0) q[9];
cx q[141],q[9];
u1(0) q[9];
u1(0) q[141];
cx q[141],q[10];
u1(0) q[10];
cx q[141],q[10];
u1(0) q[10];
u1(0) q[141];
cx q[141],q[11];
u1(0) q[11];
cx q[141],q[11];
u1(0) q[11];
u1(0) q[141];
cx q[141],q[12];
u1(0) q[12];
cx q[141],q[12];
u1(0) q[12];
u1(0) q[141];
cx q[141],q[13];
u1(0) q[13];
cx q[141],q[13];
u1(0) q[13];
u1(0) q[141];
cx q[141],q[14];
u1(0) q[14];
cx q[141],q[14];
u1(0) q[14];
u1(0) q[141];
cx q[141],q[15];
u1(0) q[15];
cx q[141],q[15];
u1(0) q[15];
u1(0) q[141];
cx q[141],q[16];
u1(0) q[16];
cx q[141],q[16];
u1(0) q[16];
u1(0) q[141];
cx q[141],q[17];
u1(0) q[17];
cx q[141],q[17];
u1(0) q[17];
u1(0) q[141];
cx q[141],q[18];
u1(0) q[18];
cx q[141],q[18];
u1(0) q[18];
u1(0) q[141];
cx q[141],q[19];
u1(0) q[19];
cx q[141],q[19];
u1(0) q[19];
u1(0) q[141];
cx q[141],q[20];
u1(0) q[20];
cx q[141],q[20];
u1(0) q[20];
u1(0) q[141];
cx q[141],q[21];
u1(0) q[21];
cx q[141],q[21];
u1(0) q[21];
u1(0) q[141];
cx q[141],q[22];
u1(0) q[22];
cx q[141],q[22];
u1(0) q[22];
u1(0) q[141];
cx q[141],q[23];
u1(0) q[23];
cx q[141],q[23];
u1(0) q[23];
u1(0) q[141];
cx q[141],q[24];
u1(0) q[24];
cx q[141],q[24];
u1(0) q[24];
u1(0) q[141];
cx q[141],q[25];
u1(0) q[25];
cx q[141],q[25];
u1(0) q[25];
u1(0) q[141];
cx q[141],q[26];
u1(0) q[26];
cx q[141],q[26];
u1(0) q[26];
u1(0) q[141];
cx q[141],q[27];
u1(0) q[27];
cx q[141],q[27];
u1(0) q[27];
u1(0) q[141];
cx q[141],q[28];
u1(0) q[28];
cx q[141],q[28];
u1(0) q[28];
u1(0) q[141];
cx q[141],q[29];
u1(0) q[29];
cx q[141],q[29];
u1(0) q[29];
u1(0) q[141];
cx q[141],q[30];
u1(0) q[30];
cx q[141],q[30];
u1(0) q[30];
u1(0) q[141];
cx q[141],q[31];
u1(0) q[31];
cx q[141],q[31];
u1(0) q[31];
u1(0) q[141];
cx q[141],q[32];
u1(0) q[32];
cx q[141],q[32];
u1(0) q[32];
u1(0) q[141];
cx q[141],q[33];
u1(0) q[33];
cx q[141],q[33];
u1(0) q[33];
u1(0) q[141];
cx q[141],q[34];
u1(0) q[34];
cx q[141],q[34];
u1(0) q[34];
u1(0) q[141];
cx q[141],q[35];
u1(0) q[35];
cx q[141],q[35];
u1(0) q[35];
u1(0) q[141];
cx q[141],q[36];
u1(0) q[36];
cx q[141],q[36];
u1(0) q[36];
u1(0) q[141];
cx q[141],q[37];
u1(0) q[37];
cx q[141],q[37];
u1(0) q[37];
u1(0) q[141];
cx q[141],q[38];
u1(0) q[38];
cx q[141],q[38];
u1(0) q[38];
u1(0) q[141];
cx q[141],q[39];
u1(0) q[39];
cx q[141],q[39];
u1(0) q[39];
u1(0) q[141];
cx q[141],q[40];
u1(0) q[40];
cx q[141],q[40];
u1(0) q[40];
u1(0) q[141];
cx q[141],q[41];
u1(0) q[41];
cx q[141],q[41];
u1(0) q[41];
u1(0) q[141];
cx q[141],q[42];
u1(0) q[42];
cx q[141],q[42];
u1(0) q[42];
u1(0) q[141];
cx q[141],q[43];
u1(0) q[43];
cx q[141],q[43];
u1(0) q[43];
u1(0) q[141];
cx q[141],q[44];
u1(0) q[44];
cx q[141],q[44];
u1(0) q[44];
u1(0) q[141];
cx q[141],q[45];
u1(0) q[45];
cx q[141],q[45];
u1(0) q[45];
u1(0) q[141];
cx q[141],q[46];
u1(0) q[46];
cx q[141],q[46];
u1(0) q[46];
u1(0) q[141];
cx q[141],q[47];
u1(0) q[47];
cx q[141],q[47];
u1(0) q[47];
u1(0) q[141];
cx q[141],q[48];
u1(0) q[48];
cx q[141],q[48];
u1(0) q[48];
u1(0) q[141];
cx q[141],q[49];
u1(0) q[49];
cx q[141],q[49];
u1(0) q[49];
u1(0) q[141];
cx q[141],q[50];
u1(0) q[50];
cx q[141],q[50];
u1(0) q[50];
u1(0) q[141];
cx q[141],q[51];
u1(0) q[51];
cx q[141],q[51];
u1(0) q[51];
u1(0) q[141];
cx q[141],q[52];
u1(0) q[52];
cx q[141],q[52];
u1(0) q[52];
u1(0) q[141];
cx q[141],q[53];
u1(0) q[53];
cx q[141],q[53];
u1(0) q[53];
u1(0) q[141];
cx q[141],q[54];
u1(0) q[54];
cx q[141],q[54];
u1(0) q[54];
u1(0) q[141];
cx q[141],q[55];
u1(0) q[55];
cx q[141],q[55];
u1(0) q[55];
u1(0) q[141];
cx q[141],q[56];
u1(0) q[56];
cx q[141],q[56];
u1(0) q[56];
u1(0) q[141];
cx q[141],q[57];
u1(0) q[57];
cx q[141],q[57];
u1(0) q[57];
u1(0) q[141];
cx q[141],q[58];
u1(0) q[58];
cx q[141],q[58];
u1(0) q[58];
u1(0) q[141];
cx q[141],q[59];
u1(0) q[59];
cx q[141],q[59];
u1(0) q[59];
u1(0) q[141];
cx q[141],q[60];
u1(0) q[60];
cx q[141],q[60];
u1(0) q[60];
u1(0) q[141];
cx q[141],q[61];
u1(0) q[61];
cx q[141],q[61];
u1(0) q[61];
u1(0) q[141];
cx q[141],q[62];
u1(0) q[62];
cx q[141],q[62];
u1(0) q[62];
u1(0) q[141];
cx q[141],q[63];
u1(0) q[63];
cx q[141],q[63];
u1(0) q[63];
u1(0) q[141];
cx q[141],q[64];
u1(0) q[64];
cx q[141],q[64];
u1(0) q[64];
u1(0) q[141];
cx q[141],q[65];
u1(0) q[65];
cx q[141],q[65];
u1(0) q[65];
u1(0) q[141];
cx q[141],q[66];
u1(0) q[66];
cx q[141],q[66];
u1(0) q[66];
u1(0) q[141];
cx q[141],q[67];
u1(0) q[67];
cx q[141],q[67];
u1(0) q[67];
u1(0) q[141];
cx q[141],q[68];
u1(0) q[68];
cx q[141],q[68];
u1(0) q[68];
u1(0) q[141];
cx q[141],q[69];
u1(0) q[69];
cx q[141],q[69];
u1(0) q[69];
u1(0) q[141];
cx q[141],q[70];
u1(0) q[70];
cx q[141],q[70];
u1(0) q[70];
u1(0) q[141];
cx q[141],q[71];
u1(0) q[71];
cx q[141],q[71];
u1(0) q[71];
u1(0) q[141];
cx q[141],q[72];
u1(0) q[72];
cx q[141],q[72];
u1(0) q[72];
u1(0) q[141];
cx q[141],q[73];
u1(0) q[73];
cx q[141],q[73];
u1(0) q[73];
u1(0) q[141];
cx q[141],q[74];
u1(0) q[74];
cx q[141],q[74];
u1(0) q[74];
u1(0) q[141];
cx q[141],q[75];
u1(0) q[75];
cx q[141],q[75];
u1(0) q[75];
u1(0) q[141];
cx q[141],q[76];
u1(0) q[76];
cx q[141],q[76];
u1(0) q[76];
u1(0) q[141];
cx q[141],q[77];
u1(0) q[77];
cx q[141],q[77];
u1(0) q[77];
u1(0) q[141];
cx q[141],q[78];
u1(0) q[78];
cx q[141],q[78];
u1(0) q[78];
u1(0) q[141];
cx q[141],q[79];
u1(0) q[79];
cx q[141],q[79];
u1(0) q[79];
u1(0) q[141];
cx q[141],q[80];
u1(0) q[80];
cx q[141],q[80];
u1(0) q[80];
u1(0) q[141];
cx q[141],q[81];
u1(0) q[81];
cx q[141],q[81];
u1(0) q[81];
u1(0) q[141];
cx q[141],q[82];
u1(0) q[82];
cx q[141],q[82];
u1(0) q[82];
u1(0) q[141];
cx q[141],q[83];
u1(0) q[83];
cx q[141],q[83];
u1(0) q[83];
u1(0) q[141];
cx q[141],q[84];
u1(0) q[84];
cx q[141],q[84];
u1(0) q[84];
u1(0) q[141];
cx q[141],q[85];
u1(0) q[85];
cx q[141],q[85];
u1(0) q[85];
u1(0) q[141];
cx q[141],q[86];
u1(0) q[86];
cx q[141],q[86];
u1(0) q[86];
u1(0) q[141];
cx q[141],q[87];
u1(0) q[87];
cx q[141],q[87];
u1(0) q[87];
u1(0) q[141];
cx q[141],q[88];
u1(0) q[88];
cx q[141],q[88];
u1(0) q[88];
u1(0) q[141];
cx q[141],q[89];
u1(0) q[89];
cx q[141],q[89];
u1(0) q[89];
u1(0) q[141];
cx q[141],q[90];
u1(0) q[90];
cx q[141],q[90];
u1(0) q[90];
u1(0) q[141];
cx q[141],q[91];
u1(0) q[91];
cx q[141],q[91];
u1(0) q[91];
u1(0) q[141];
cx q[141],q[92];
u1(0) q[92];
cx q[141],q[92];
u1(0) q[92];
u1(0) q[141];
cx q[141],q[93];
u1(0) q[93];
cx q[141],q[93];
u1(0) q[93];
u1(pi/281474976710656) q[141];
cx q[141],q[94];
u1(-pi/281474976710656) q[94];
cx q[141],q[94];
u1(pi/281474976710656) q[94];
u1(pi/140737488355328) q[141];
cx q[141],q[95];
u1(-pi/140737488355328) q[95];
cx q[141],q[95];
u1(pi/140737488355328) q[95];
u1(pi/70368744177664) q[141];
cx q[141],q[96];
u1(-pi/70368744177664) q[96];
cx q[141],q[96];
u1(pi/70368744177664) q[96];
u1(pi/35184372088832) q[141];
cx q[141],q[97];
u1(-pi/35184372088832) q[97];
cx q[141],q[97];
u1(pi/35184372088832) q[97];
u1(pi/17592186044416) q[141];
cx q[141],q[98];
u1(-pi/17592186044416) q[98];
cx q[141],q[98];
u1(pi/17592186044416) q[98];
u1(pi/8796093022208) q[141];
cx q[141],q[99];
u1(-pi/8796093022208) q[99];
cx q[141],q[99];
u1(pi/8796093022208) q[99];
u1(pi/4398046511104) q[141];
cx q[141],q[100];
u1(-pi/4398046511104) q[100];
cx q[141],q[100];
u1(pi/4398046511104) q[100];
u1(pi/2199023255552) q[141];
cx q[141],q[101];
u1(-pi/2199023255552) q[101];
cx q[141],q[101];
u1(pi/2199023255552) q[101];
u1(pi/1099511627776) q[141];
cx q[141],q[102];
u1(-pi/1099511627776) q[102];
cx q[141],q[102];
u1(pi/1099511627776) q[102];
u1(pi/549755813888) q[141];
cx q[141],q[103];
u1(-pi/549755813888) q[103];
cx q[141],q[103];
u1(pi/549755813888) q[103];
u1(pi/274877906944) q[141];
cx q[141],q[104];
u1(-pi/274877906944) q[104];
cx q[141],q[104];
u1(pi/274877906944) q[104];
u1(pi/137438953472) q[141];
cx q[141],q[105];
u1(-pi/137438953472) q[105];
cx q[141],q[105];
u1(pi/137438953472) q[105];
u1(pi/68719476736) q[141];
cx q[141],q[106];
u1(-pi/68719476736) q[106];
cx q[141],q[106];
u1(pi/68719476736) q[106];
u1(pi/34359738368) q[141];
cx q[141],q[107];
u1(-pi/34359738368) q[107];
cx q[141],q[107];
u1(pi/34359738368) q[107];
u1(pi/17179869184) q[141];
cx q[141],q[108];
u1(-pi/17179869184) q[108];
cx q[141],q[108];
u1(pi/17179869184) q[108];
u1(pi/8589934592) q[141];
cx q[141],q[109];
u1(-pi/8589934592) q[109];
cx q[141],q[109];
u1(pi/8589934592) q[109];
u1(pi/4294967296) q[141];
cx q[141],q[110];
u1(-pi/4294967296) q[110];
cx q[141],q[110];
u1(pi/4294967296) q[110];
u1(pi/2147483648) q[141];
cx q[141],q[111];
u1(-pi/2147483648) q[111];
cx q[141],q[111];
u1(pi/2147483648) q[111];
u1(pi/1073741824) q[141];
cx q[141],q[112];
u1(-pi/1073741824) q[112];
cx q[141],q[112];
u1(pi/1073741824) q[112];
u1(pi/536870912) q[141];
cx q[141],q[113];
u1(-pi/536870912) q[113];
cx q[141],q[113];
u1(pi/536870912) q[113];
u1(pi/268435456) q[141];
cx q[141],q[114];
u1(-pi/268435456) q[114];
cx q[141],q[114];
u1(pi/268435456) q[114];
u1(pi/134217728) q[141];
cx q[141],q[115];
u1(-pi/134217728) q[115];
cx q[141],q[115];
u1(pi/134217728) q[115];
u1(pi/67108864) q[141];
cx q[141],q[116];
u1(-pi/67108864) q[116];
cx q[141],q[116];
u1(pi/67108864) q[116];
u1(pi/33554432) q[141];
cx q[141],q[117];
u1(-pi/33554432) q[117];
cx q[141],q[117];
u1(pi/33554432) q[117];
u1(pi/16777216) q[141];
cx q[141],q[118];
u1(-pi/16777216) q[118];
cx q[141],q[118];
u1(pi/16777216) q[118];
u1(pi/8388608) q[141];
cx q[141],q[119];
u1(-pi/8388608) q[119];
cx q[141],q[119];
u1(pi/8388608) q[119];
u1(pi/4194304) q[141];
cx q[141],q[120];
u1(-pi/4194304) q[120];
cx q[141],q[120];
u1(pi/4194304) q[120];
u1(pi/2097152) q[141];
cx q[141],q[121];
u1(-pi/2097152) q[121];
cx q[141],q[121];
u1(pi/2097152) q[121];
u1(pi/1048576) q[141];
cx q[141],q[122];
u1(-pi/1048576) q[122];
cx q[141],q[122];
u1(pi/1048576) q[122];
u1(pi/524288) q[141];
cx q[141],q[123];
u1(-pi/524288) q[123];
cx q[141],q[123];
u1(pi/524288) q[123];
u1(pi/262144) q[141];
cx q[141],q[124];
u1(-pi/262144) q[124];
cx q[141],q[124];
u1(pi/262144) q[124];
u1(pi/131072) q[141];
cx q[141],q[125];
u1(-pi/131072) q[125];
cx q[141],q[125];
u1(pi/131072) q[125];
u1(pi/65536) q[141];
cx q[141],q[126];
u1(-pi/65536) q[126];
cx q[141],q[126];
u1(pi/65536) q[126];
u1(pi/32768) q[141];
cx q[141],q[127];
u1(-pi/32768) q[127];
cx q[141],q[127];
u1(pi/32768) q[127];
u1(pi/16384) q[141];
cx q[141],q[128];
u1(-pi/16384) q[128];
cx q[141],q[128];
u1(pi/16384) q[128];
u1(pi/8192) q[141];
cx q[141],q[129];
u1(-pi/8192) q[129];
cx q[141],q[129];
u1(pi/8192) q[129];
u1(pi/4096) q[141];
cx q[141],q[130];
u1(-pi/4096) q[130];
cx q[141],q[130];
u1(pi/4096) q[130];
u1(pi/2048) q[141];
cx q[141],q[131];
u1(-pi/2048) q[131];
cx q[141],q[131];
u1(pi/2048) q[131];
u1(pi/1024) q[141];
cx q[141],q[132];
u1(-pi/1024) q[132];
cx q[141],q[132];
u1(pi/1024) q[132];
u1(pi/512) q[141];
cx q[141],q[133];
u1(-pi/512) q[133];
cx q[141],q[133];
u1(pi/512) q[133];
u1(pi/256) q[141];
cx q[141],q[134];
u1(-pi/256) q[134];
cx q[141],q[134];
u1(pi/256) q[134];
u1(pi/128) q[141];
cx q[141],q[135];
u1(-pi/128) q[135];
cx q[141],q[135];
u1(pi/128) q[135];
u1(pi/64) q[141];
cx q[141],q[136];
u1(-pi/64) q[136];
cx q[141],q[136];
u1(pi/64) q[136];
u1(pi/32) q[141];
cx q[141],q[137];
u1(-pi/32) q[137];
cx q[141],q[137];
u1(pi/32) q[137];
u1(pi/16) q[141];
cx q[141],q[138];
u1(-pi/16) q[138];
cx q[141],q[138];
u1(pi/16) q[138];
u1(pi/8) q[141];
cx q[141],q[139];
u1(-pi/8) q[139];
cx q[141],q[139];
u1(pi/8) q[139];
u1(pi/4) q[141];
cx q[141],q[140];
u1(-pi/4) q[140];
cx q[141],q[140];
u1(pi/4) q[140];
h q[141];
u1(0) q[142];
cx q[142],q[0];
u1(0) q[0];
cx q[142],q[0];
u1(0) q[0];
u1(0) q[142];
cx q[142],q[1];
u1(0) q[1];
cx q[142],q[1];
u1(0) q[1];
u1(0) q[142];
cx q[142],q[2];
u1(0) q[2];
cx q[142],q[2];
u1(0) q[2];
u1(0) q[142];
cx q[142],q[3];
u1(0) q[3];
cx q[142],q[3];
u1(0) q[3];
u1(0) q[142];
cx q[142],q[4];
u1(0) q[4];
cx q[142],q[4];
u1(0) q[4];
u1(0) q[142];
cx q[142],q[5];
u1(0) q[5];
cx q[142],q[5];
u1(0) q[5];
u1(0) q[142];
cx q[142],q[6];
u1(0) q[6];
cx q[142],q[6];
u1(0) q[6];
u1(0) q[142];
cx q[142],q[7];
u1(0) q[7];
cx q[142],q[7];
u1(0) q[7];
u1(0) q[142];
cx q[142],q[8];
u1(0) q[8];
cx q[142],q[8];
u1(0) q[8];
u1(0) q[142];
cx q[142],q[9];
u1(0) q[9];
cx q[142],q[9];
u1(0) q[9];
u1(0) q[142];
cx q[142],q[10];
u1(0) q[10];
cx q[142],q[10];
u1(0) q[10];
u1(0) q[142];
cx q[142],q[11];
u1(0) q[11];
cx q[142],q[11];
u1(0) q[11];
u1(0) q[142];
cx q[142],q[12];
u1(0) q[12];
cx q[142],q[12];
u1(0) q[12];
u1(0) q[142];
cx q[142],q[13];
u1(0) q[13];
cx q[142],q[13];
u1(0) q[13];
u1(0) q[142];
cx q[142],q[14];
u1(0) q[14];
cx q[142],q[14];
u1(0) q[14];
u1(0) q[142];
cx q[142],q[15];
u1(0) q[15];
cx q[142],q[15];
u1(0) q[15];
u1(0) q[142];
cx q[142],q[16];
u1(0) q[16];
cx q[142],q[16];
u1(0) q[16];
u1(0) q[142];
cx q[142],q[17];
u1(0) q[17];
cx q[142],q[17];
u1(0) q[17];
u1(0) q[142];
cx q[142],q[18];
u1(0) q[18];
cx q[142],q[18];
u1(0) q[18];
u1(0) q[142];
cx q[142],q[19];
u1(0) q[19];
cx q[142],q[19];
u1(0) q[19];
u1(0) q[142];
cx q[142],q[20];
u1(0) q[20];
cx q[142],q[20];
u1(0) q[20];
u1(0) q[142];
cx q[142],q[21];
u1(0) q[21];
cx q[142],q[21];
u1(0) q[21];
u1(0) q[142];
cx q[142],q[22];
u1(0) q[22];
cx q[142],q[22];
u1(0) q[22];
u1(0) q[142];
cx q[142],q[23];
u1(0) q[23];
cx q[142],q[23];
u1(0) q[23];
u1(0) q[142];
cx q[142],q[24];
u1(0) q[24];
cx q[142],q[24];
u1(0) q[24];
u1(0) q[142];
cx q[142],q[25];
u1(0) q[25];
cx q[142],q[25];
u1(0) q[25];
u1(0) q[142];
cx q[142],q[26];
u1(0) q[26];
cx q[142],q[26];
u1(0) q[26];
u1(0) q[142];
cx q[142],q[27];
u1(0) q[27];
cx q[142],q[27];
u1(0) q[27];
u1(0) q[142];
cx q[142],q[28];
u1(0) q[28];
cx q[142],q[28];
u1(0) q[28];
u1(0) q[142];
cx q[142],q[29];
u1(0) q[29];
cx q[142],q[29];
u1(0) q[29];
u1(0) q[142];
cx q[142],q[30];
u1(0) q[30];
cx q[142],q[30];
u1(0) q[30];
u1(0) q[142];
cx q[142],q[31];
u1(0) q[31];
cx q[142],q[31];
u1(0) q[31];
u1(0) q[142];
cx q[142],q[32];
u1(0) q[32];
cx q[142],q[32];
u1(0) q[32];
u1(0) q[142];
cx q[142],q[33];
u1(0) q[33];
cx q[142],q[33];
u1(0) q[33];
u1(0) q[142];
cx q[142],q[34];
u1(0) q[34];
cx q[142],q[34];
u1(0) q[34];
u1(0) q[142];
cx q[142],q[35];
u1(0) q[35];
cx q[142],q[35];
u1(0) q[35];
u1(0) q[142];
cx q[142],q[36];
u1(0) q[36];
cx q[142],q[36];
u1(0) q[36];
u1(0) q[142];
cx q[142],q[37];
u1(0) q[37];
cx q[142],q[37];
u1(0) q[37];
u1(0) q[142];
cx q[142],q[38];
u1(0) q[38];
cx q[142],q[38];
u1(0) q[38];
u1(0) q[142];
cx q[142],q[39];
u1(0) q[39];
cx q[142],q[39];
u1(0) q[39];
u1(0) q[142];
cx q[142],q[40];
u1(0) q[40];
cx q[142],q[40];
u1(0) q[40];
u1(0) q[142];
cx q[142],q[41];
u1(0) q[41];
cx q[142],q[41];
u1(0) q[41];
u1(0) q[142];
cx q[142],q[42];
u1(0) q[42];
cx q[142],q[42];
u1(0) q[42];
u1(0) q[142];
cx q[142],q[43];
u1(0) q[43];
cx q[142],q[43];
u1(0) q[43];
u1(0) q[142];
cx q[142],q[44];
u1(0) q[44];
cx q[142],q[44];
u1(0) q[44];
u1(0) q[142];
cx q[142],q[45];
u1(0) q[45];
cx q[142],q[45];
u1(0) q[45];
u1(0) q[142];
cx q[142],q[46];
u1(0) q[46];
cx q[142],q[46];
u1(0) q[46];
u1(0) q[142];
cx q[142],q[47];
u1(0) q[47];
cx q[142],q[47];
u1(0) q[47];
u1(0) q[142];
cx q[142],q[48];
u1(0) q[48];
cx q[142],q[48];
u1(0) q[48];
u1(0) q[142];
cx q[142],q[49];
u1(0) q[49];
cx q[142],q[49];
u1(0) q[49];
u1(0) q[142];
cx q[142],q[50];
u1(0) q[50];
cx q[142],q[50];
u1(0) q[50];
u1(0) q[142];
cx q[142],q[51];
u1(0) q[51];
cx q[142],q[51];
u1(0) q[51];
u1(0) q[142];
cx q[142],q[52];
u1(0) q[52];
cx q[142],q[52];
u1(0) q[52];
u1(0) q[142];
cx q[142],q[53];
u1(0) q[53];
cx q[142],q[53];
u1(0) q[53];
u1(0) q[142];
cx q[142],q[54];
u1(0) q[54];
cx q[142],q[54];
u1(0) q[54];
u1(0) q[142];
cx q[142],q[55];
u1(0) q[55];
cx q[142],q[55];
u1(0) q[55];
u1(0) q[142];
cx q[142],q[56];
u1(0) q[56];
cx q[142],q[56];
u1(0) q[56];
u1(0) q[142];
cx q[142],q[57];
u1(0) q[57];
cx q[142],q[57];
u1(0) q[57];
u1(0) q[142];
cx q[142],q[58];
u1(0) q[58];
cx q[142],q[58];
u1(0) q[58];
u1(0) q[142];
cx q[142],q[59];
u1(0) q[59];
cx q[142],q[59];
u1(0) q[59];
u1(0) q[142];
cx q[142],q[60];
u1(0) q[60];
cx q[142],q[60];
u1(0) q[60];
u1(0) q[142];
cx q[142],q[61];
u1(0) q[61];
cx q[142],q[61];
u1(0) q[61];
u1(0) q[142];
cx q[142],q[62];
u1(0) q[62];
cx q[142],q[62];
u1(0) q[62];
u1(0) q[142];
cx q[142],q[63];
u1(0) q[63];
cx q[142],q[63];
u1(0) q[63];
u1(0) q[142];
cx q[142],q[64];
u1(0) q[64];
cx q[142],q[64];
u1(0) q[64];
u1(0) q[142];
cx q[142],q[65];
u1(0) q[65];
cx q[142],q[65];
u1(0) q[65];
u1(0) q[142];
cx q[142],q[66];
u1(0) q[66];
cx q[142],q[66];
u1(0) q[66];
u1(0) q[142];
cx q[142],q[67];
u1(0) q[67];
cx q[142],q[67];
u1(0) q[67];
u1(0) q[142];
cx q[142],q[68];
u1(0) q[68];
cx q[142],q[68];
u1(0) q[68];
u1(0) q[142];
cx q[142],q[69];
u1(0) q[69];
cx q[142],q[69];
u1(0) q[69];
u1(0) q[142];
cx q[142],q[70];
u1(0) q[70];
cx q[142],q[70];
u1(0) q[70];
u1(0) q[142];
cx q[142],q[71];
u1(0) q[71];
cx q[142],q[71];
u1(0) q[71];
u1(0) q[142];
cx q[142],q[72];
u1(0) q[72];
cx q[142],q[72];
u1(0) q[72];
u1(0) q[142];
cx q[142],q[73];
u1(0) q[73];
cx q[142],q[73];
u1(0) q[73];
u1(0) q[142];
cx q[142],q[74];
u1(0) q[74];
cx q[142],q[74];
u1(0) q[74];
u1(0) q[142];
cx q[142],q[75];
u1(0) q[75];
cx q[142],q[75];
u1(0) q[75];
u1(0) q[142];
cx q[142],q[76];
u1(0) q[76];
cx q[142],q[76];
u1(0) q[76];
u1(0) q[142];
cx q[142],q[77];
u1(0) q[77];
cx q[142],q[77];
u1(0) q[77];
u1(0) q[142];
cx q[142],q[78];
u1(0) q[78];
cx q[142],q[78];
u1(0) q[78];
u1(0) q[142];
cx q[142],q[79];
u1(0) q[79];
cx q[142],q[79];
u1(0) q[79];
u1(0) q[142];
cx q[142],q[80];
u1(0) q[80];
cx q[142],q[80];
u1(0) q[80];
u1(0) q[142];
cx q[142],q[81];
u1(0) q[81];
cx q[142],q[81];
u1(0) q[81];
u1(0) q[142];
cx q[142],q[82];
u1(0) q[82];
cx q[142],q[82];
u1(0) q[82];
u1(0) q[142];
cx q[142],q[83];
u1(0) q[83];
cx q[142],q[83];
u1(0) q[83];
u1(0) q[142];
cx q[142],q[84];
u1(0) q[84];
cx q[142],q[84];
u1(0) q[84];
u1(0) q[142];
cx q[142],q[85];
u1(0) q[85];
cx q[142],q[85];
u1(0) q[85];
u1(0) q[142];
cx q[142],q[86];
u1(0) q[86];
cx q[142],q[86];
u1(0) q[86];
u1(0) q[142];
cx q[142],q[87];
u1(0) q[87];
cx q[142],q[87];
u1(0) q[87];
u1(0) q[142];
cx q[142],q[88];
u1(0) q[88];
cx q[142],q[88];
u1(0) q[88];
u1(0) q[142];
cx q[142],q[89];
u1(0) q[89];
cx q[142],q[89];
u1(0) q[89];
u1(0) q[142];
cx q[142],q[90];
u1(0) q[90];
cx q[142],q[90];
u1(0) q[90];
u1(0) q[142];
cx q[142],q[91];
u1(0) q[91];
cx q[142],q[91];
u1(0) q[91];
u1(0) q[142];
cx q[142],q[92];
u1(0) q[92];
cx q[142],q[92];
u1(0) q[92];
u1(0) q[142];
cx q[142],q[93];
u1(0) q[93];
cx q[142],q[93];
u1(0) q[93];
u1(0) q[142];
cx q[142],q[94];
u1(0) q[94];
cx q[142],q[94];
u1(0) q[94];
u1(pi/281474976710656) q[142];
cx q[142],q[95];
u1(-pi/281474976710656) q[95];
cx q[142],q[95];
u1(pi/281474976710656) q[95];
u1(pi/140737488355328) q[142];
cx q[142],q[96];
u1(-pi/140737488355328) q[96];
cx q[142],q[96];
u1(pi/140737488355328) q[96];
u1(pi/70368744177664) q[142];
cx q[142],q[97];
u1(-pi/70368744177664) q[97];
cx q[142],q[97];
u1(pi/70368744177664) q[97];
u1(pi/35184372088832) q[142];
cx q[142],q[98];
u1(-pi/35184372088832) q[98];
cx q[142],q[98];
u1(pi/35184372088832) q[98];
u1(pi/17592186044416) q[142];
cx q[142],q[99];
u1(-pi/17592186044416) q[99];
cx q[142],q[99];
u1(pi/17592186044416) q[99];
u1(pi/8796093022208) q[142];
cx q[142],q[100];
u1(-pi/8796093022208) q[100];
cx q[142],q[100];
u1(pi/8796093022208) q[100];
u1(pi/4398046511104) q[142];
cx q[142],q[101];
u1(-pi/4398046511104) q[101];
cx q[142],q[101];
u1(pi/4398046511104) q[101];
u1(pi/2199023255552) q[142];
cx q[142],q[102];
u1(-pi/2199023255552) q[102];
cx q[142],q[102];
u1(pi/2199023255552) q[102];
u1(pi/1099511627776) q[142];
cx q[142],q[103];
u1(-pi/1099511627776) q[103];
cx q[142],q[103];
u1(pi/1099511627776) q[103];
u1(pi/549755813888) q[142];
cx q[142],q[104];
u1(-pi/549755813888) q[104];
cx q[142],q[104];
u1(pi/549755813888) q[104];
u1(pi/274877906944) q[142];
cx q[142],q[105];
u1(-pi/274877906944) q[105];
cx q[142],q[105];
u1(pi/274877906944) q[105];
u1(pi/137438953472) q[142];
cx q[142],q[106];
u1(-pi/137438953472) q[106];
cx q[142],q[106];
u1(pi/137438953472) q[106];
u1(pi/68719476736) q[142];
cx q[142],q[107];
u1(-pi/68719476736) q[107];
cx q[142],q[107];
u1(pi/68719476736) q[107];
u1(pi/34359738368) q[142];
cx q[142],q[108];
u1(-pi/34359738368) q[108];
cx q[142],q[108];
u1(pi/34359738368) q[108];
u1(pi/17179869184) q[142];
cx q[142],q[109];
u1(-pi/17179869184) q[109];
cx q[142],q[109];
u1(pi/17179869184) q[109];
u1(pi/8589934592) q[142];
cx q[142],q[110];
u1(-pi/8589934592) q[110];
cx q[142],q[110];
u1(pi/8589934592) q[110];
u1(pi/4294967296) q[142];
cx q[142],q[111];
u1(-pi/4294967296) q[111];
cx q[142],q[111];
u1(pi/4294967296) q[111];
u1(pi/2147483648) q[142];
cx q[142],q[112];
u1(-pi/2147483648) q[112];
cx q[142],q[112];
u1(pi/2147483648) q[112];
u1(pi/1073741824) q[142];
cx q[142],q[113];
u1(-pi/1073741824) q[113];
cx q[142],q[113];
u1(pi/1073741824) q[113];
u1(pi/536870912) q[142];
cx q[142],q[114];
u1(-pi/536870912) q[114];
cx q[142],q[114];
u1(pi/536870912) q[114];
u1(pi/268435456) q[142];
cx q[142],q[115];
u1(-pi/268435456) q[115];
cx q[142],q[115];
u1(pi/268435456) q[115];
u1(pi/134217728) q[142];
cx q[142],q[116];
u1(-pi/134217728) q[116];
cx q[142],q[116];
u1(pi/134217728) q[116];
u1(pi/67108864) q[142];
cx q[142],q[117];
u1(-pi/67108864) q[117];
cx q[142],q[117];
u1(pi/67108864) q[117];
u1(pi/33554432) q[142];
cx q[142],q[118];
u1(-pi/33554432) q[118];
cx q[142],q[118];
u1(pi/33554432) q[118];
u1(pi/16777216) q[142];
cx q[142],q[119];
u1(-pi/16777216) q[119];
cx q[142],q[119];
u1(pi/16777216) q[119];
u1(pi/8388608) q[142];
cx q[142],q[120];
u1(-pi/8388608) q[120];
cx q[142],q[120];
u1(pi/8388608) q[120];
u1(pi/4194304) q[142];
cx q[142],q[121];
u1(-pi/4194304) q[121];
cx q[142],q[121];
u1(pi/4194304) q[121];
u1(pi/2097152) q[142];
cx q[142],q[122];
u1(-pi/2097152) q[122];
cx q[142],q[122];
u1(pi/2097152) q[122];
u1(pi/1048576) q[142];
cx q[142],q[123];
u1(-pi/1048576) q[123];
cx q[142],q[123];
u1(pi/1048576) q[123];
u1(pi/524288) q[142];
cx q[142],q[124];
u1(-pi/524288) q[124];
cx q[142],q[124];
u1(pi/524288) q[124];
u1(pi/262144) q[142];
cx q[142],q[125];
u1(-pi/262144) q[125];
cx q[142],q[125];
u1(pi/262144) q[125];
u1(pi/131072) q[142];
cx q[142],q[126];
u1(-pi/131072) q[126];
cx q[142],q[126];
u1(pi/131072) q[126];
u1(pi/65536) q[142];
cx q[142],q[127];
u1(-pi/65536) q[127];
cx q[142],q[127];
u1(pi/65536) q[127];
u1(pi/32768) q[142];
cx q[142],q[128];
u1(-pi/32768) q[128];
cx q[142],q[128];
u1(pi/32768) q[128];
u1(pi/16384) q[142];
cx q[142],q[129];
u1(-pi/16384) q[129];
cx q[142],q[129];
u1(pi/16384) q[129];
u1(pi/8192) q[142];
cx q[142],q[130];
u1(-pi/8192) q[130];
cx q[142],q[130];
u1(pi/8192) q[130];
u1(pi/4096) q[142];
cx q[142],q[131];
u1(-pi/4096) q[131];
cx q[142],q[131];
u1(pi/4096) q[131];
u1(pi/2048) q[142];
cx q[142],q[132];
u1(-pi/2048) q[132];
cx q[142],q[132];
u1(pi/2048) q[132];
u1(pi/1024) q[142];
cx q[142],q[133];
u1(-pi/1024) q[133];
cx q[142],q[133];
u1(pi/1024) q[133];
u1(pi/512) q[142];
cx q[142],q[134];
u1(-pi/512) q[134];
cx q[142],q[134];
u1(pi/512) q[134];
u1(pi/256) q[142];
cx q[142],q[135];
u1(-pi/256) q[135];
cx q[142],q[135];
u1(pi/256) q[135];
u1(pi/128) q[142];
cx q[142],q[136];
u1(-pi/128) q[136];
cx q[142],q[136];
u1(pi/128) q[136];
u1(pi/64) q[142];
cx q[142],q[137];
u1(-pi/64) q[137];
cx q[142],q[137];
u1(pi/64) q[137];
u1(pi/32) q[142];
cx q[142],q[138];
u1(-pi/32) q[138];
cx q[142],q[138];
u1(pi/32) q[138];
u1(pi/16) q[142];
cx q[142],q[139];
u1(-pi/16) q[139];
cx q[142],q[139];
u1(pi/16) q[139];
u1(pi/8) q[142];
cx q[142],q[140];
u1(-pi/8) q[140];
cx q[142],q[140];
u1(pi/8) q[140];
u1(pi/4) q[142];
cx q[142],q[141];
u1(-pi/4) q[141];
cx q[142],q[141];
u1(pi/4) q[141];
h q[142];
u1(0) q[143];
cx q[143],q[0];
u1(0) q[0];
cx q[143],q[0];
u1(0) q[0];
u1(0) q[143];
cx q[143],q[1];
u1(0) q[1];
cx q[143],q[1];
u1(0) q[1];
u1(0) q[143];
cx q[143],q[2];
u1(0) q[2];
cx q[143],q[2];
u1(0) q[2];
u1(0) q[143];
cx q[143],q[3];
u1(0) q[3];
cx q[143],q[3];
u1(0) q[3];
u1(0) q[143];
cx q[143],q[4];
u1(0) q[4];
cx q[143],q[4];
u1(0) q[4];
u1(0) q[143];
cx q[143],q[5];
u1(0) q[5];
cx q[143],q[5];
u1(0) q[5];
u1(0) q[143];
cx q[143],q[6];
u1(0) q[6];
cx q[143],q[6];
u1(0) q[6];
u1(0) q[143];
cx q[143],q[7];
u1(0) q[7];
cx q[143],q[7];
u1(0) q[7];
u1(0) q[143];
cx q[143],q[8];
u1(0) q[8];
cx q[143],q[8];
u1(0) q[8];
u1(0) q[143];
cx q[143],q[9];
u1(0) q[9];
cx q[143],q[9];
u1(0) q[9];
u1(0) q[143];
cx q[143],q[10];
u1(0) q[10];
cx q[143],q[10];
u1(0) q[10];
u1(0) q[143];
cx q[143],q[11];
u1(0) q[11];
cx q[143],q[11];
u1(0) q[11];
u1(0) q[143];
cx q[143],q[12];
u1(0) q[12];
cx q[143],q[12];
u1(0) q[12];
u1(0) q[143];
cx q[143],q[13];
u1(0) q[13];
cx q[143],q[13];
u1(0) q[13];
u1(0) q[143];
cx q[143],q[14];
u1(0) q[14];
cx q[143],q[14];
u1(0) q[14];
u1(0) q[143];
cx q[143],q[15];
u1(0) q[15];
cx q[143],q[15];
u1(0) q[15];
u1(0) q[143];
cx q[143],q[16];
u1(0) q[16];
cx q[143],q[16];
u1(0) q[16];
u1(0) q[143];
cx q[143],q[17];
u1(0) q[17];
cx q[143],q[17];
u1(0) q[17];
u1(0) q[143];
cx q[143],q[18];
u1(0) q[18];
cx q[143],q[18];
u1(0) q[18];
u1(0) q[143];
cx q[143],q[19];
u1(0) q[19];
cx q[143],q[19];
u1(0) q[19];
u1(0) q[143];
cx q[143],q[20];
u1(0) q[20];
cx q[143],q[20];
u1(0) q[20];
u1(0) q[143];
cx q[143],q[21];
u1(0) q[21];
cx q[143],q[21];
u1(0) q[21];
u1(0) q[143];
cx q[143],q[22];
u1(0) q[22];
cx q[143],q[22];
u1(0) q[22];
u1(0) q[143];
cx q[143],q[23];
u1(0) q[23];
cx q[143],q[23];
u1(0) q[23];
u1(0) q[143];
cx q[143],q[24];
u1(0) q[24];
cx q[143],q[24];
u1(0) q[24];
u1(0) q[143];
cx q[143],q[25];
u1(0) q[25];
cx q[143],q[25];
u1(0) q[25];
u1(0) q[143];
cx q[143],q[26];
u1(0) q[26];
cx q[143],q[26];
u1(0) q[26];
u1(0) q[143];
cx q[143],q[27];
u1(0) q[27];
cx q[143],q[27];
u1(0) q[27];
u1(0) q[143];
cx q[143],q[28];
u1(0) q[28];
cx q[143],q[28];
u1(0) q[28];
u1(0) q[143];
cx q[143],q[29];
u1(0) q[29];
cx q[143],q[29];
u1(0) q[29];
u1(0) q[143];
cx q[143],q[30];
u1(0) q[30];
cx q[143],q[30];
u1(0) q[30];
u1(0) q[143];
cx q[143],q[31];
u1(0) q[31];
cx q[143],q[31];
u1(0) q[31];
u1(0) q[143];
cx q[143],q[32];
u1(0) q[32];
cx q[143],q[32];
u1(0) q[32];
u1(0) q[143];
cx q[143],q[33];
u1(0) q[33];
cx q[143],q[33];
u1(0) q[33];
u1(0) q[143];
cx q[143],q[34];
u1(0) q[34];
cx q[143],q[34];
u1(0) q[34];
u1(0) q[143];
cx q[143],q[35];
u1(0) q[35];
cx q[143],q[35];
u1(0) q[35];
u1(0) q[143];
cx q[143],q[36];
u1(0) q[36];
cx q[143],q[36];
u1(0) q[36];
u1(0) q[143];
cx q[143],q[37];
u1(0) q[37];
cx q[143],q[37];
u1(0) q[37];
u1(0) q[143];
cx q[143],q[38];
u1(0) q[38];
cx q[143],q[38];
u1(0) q[38];
u1(0) q[143];
cx q[143],q[39];
u1(0) q[39];
cx q[143],q[39];
u1(0) q[39];
u1(0) q[143];
cx q[143],q[40];
u1(0) q[40];
cx q[143],q[40];
u1(0) q[40];
u1(0) q[143];
cx q[143],q[41];
u1(0) q[41];
cx q[143],q[41];
u1(0) q[41];
u1(0) q[143];
cx q[143],q[42];
u1(0) q[42];
cx q[143],q[42];
u1(0) q[42];
u1(0) q[143];
cx q[143],q[43];
u1(0) q[43];
cx q[143],q[43];
u1(0) q[43];
u1(0) q[143];
cx q[143],q[44];
u1(0) q[44];
cx q[143],q[44];
u1(0) q[44];
u1(0) q[143];
cx q[143],q[45];
u1(0) q[45];
cx q[143],q[45];
u1(0) q[45];
u1(0) q[143];
cx q[143],q[46];
u1(0) q[46];
cx q[143],q[46];
u1(0) q[46];
u1(0) q[143];
cx q[143],q[47];
u1(0) q[47];
cx q[143],q[47];
u1(0) q[47];
u1(0) q[143];
cx q[143],q[48];
u1(0) q[48];
cx q[143],q[48];
u1(0) q[48];
u1(0) q[143];
cx q[143],q[49];
u1(0) q[49];
cx q[143],q[49];
u1(0) q[49];
u1(0) q[143];
cx q[143],q[50];
u1(0) q[50];
cx q[143],q[50];
u1(0) q[50];
u1(0) q[143];
cx q[143],q[51];
u1(0) q[51];
cx q[143],q[51];
u1(0) q[51];
u1(0) q[143];
cx q[143],q[52];
u1(0) q[52];
cx q[143],q[52];
u1(0) q[52];
u1(0) q[143];
cx q[143],q[53];
u1(0) q[53];
cx q[143],q[53];
u1(0) q[53];
u1(0) q[143];
cx q[143],q[54];
u1(0) q[54];
cx q[143],q[54];
u1(0) q[54];
u1(0) q[143];
cx q[143],q[55];
u1(0) q[55];
cx q[143],q[55];
u1(0) q[55];
u1(0) q[143];
cx q[143],q[56];
u1(0) q[56];
cx q[143],q[56];
u1(0) q[56];
u1(0) q[143];
cx q[143],q[57];
u1(0) q[57];
cx q[143],q[57];
u1(0) q[57];
u1(0) q[143];
cx q[143],q[58];
u1(0) q[58];
cx q[143],q[58];
u1(0) q[58];
u1(0) q[143];
cx q[143],q[59];
u1(0) q[59];
cx q[143],q[59];
u1(0) q[59];
u1(0) q[143];
cx q[143],q[60];
u1(0) q[60];
cx q[143],q[60];
u1(0) q[60];
u1(0) q[143];
cx q[143],q[61];
u1(0) q[61];
cx q[143],q[61];
u1(0) q[61];
u1(0) q[143];
cx q[143],q[62];
u1(0) q[62];
cx q[143],q[62];
u1(0) q[62];
u1(0) q[143];
cx q[143],q[63];
u1(0) q[63];
cx q[143],q[63];
u1(0) q[63];
u1(0) q[143];
cx q[143],q[64];
u1(0) q[64];
cx q[143],q[64];
u1(0) q[64];
u1(0) q[143];
cx q[143],q[65];
u1(0) q[65];
cx q[143],q[65];
u1(0) q[65];
u1(0) q[143];
cx q[143],q[66];
u1(0) q[66];
cx q[143],q[66];
u1(0) q[66];
u1(0) q[143];
cx q[143],q[67];
u1(0) q[67];
cx q[143],q[67];
u1(0) q[67];
u1(0) q[143];
cx q[143],q[68];
u1(0) q[68];
cx q[143],q[68];
u1(0) q[68];
u1(0) q[143];
cx q[143],q[69];
u1(0) q[69];
cx q[143],q[69];
u1(0) q[69];
u1(0) q[143];
cx q[143],q[70];
u1(0) q[70];
cx q[143],q[70];
u1(0) q[70];
u1(0) q[143];
cx q[143],q[71];
u1(0) q[71];
cx q[143],q[71];
u1(0) q[71];
u1(0) q[143];
cx q[143],q[72];
u1(0) q[72];
cx q[143],q[72];
u1(0) q[72];
u1(0) q[143];
cx q[143],q[73];
u1(0) q[73];
cx q[143],q[73];
u1(0) q[73];
u1(0) q[143];
cx q[143],q[74];
u1(0) q[74];
cx q[143],q[74];
u1(0) q[74];
u1(0) q[143];
cx q[143],q[75];
u1(0) q[75];
cx q[143],q[75];
u1(0) q[75];
u1(0) q[143];
cx q[143],q[76];
u1(0) q[76];
cx q[143],q[76];
u1(0) q[76];
u1(0) q[143];
cx q[143],q[77];
u1(0) q[77];
cx q[143],q[77];
u1(0) q[77];
u1(0) q[143];
cx q[143],q[78];
u1(0) q[78];
cx q[143],q[78];
u1(0) q[78];
u1(0) q[143];
cx q[143],q[79];
u1(0) q[79];
cx q[143],q[79];
u1(0) q[79];
u1(0) q[143];
cx q[143],q[80];
u1(0) q[80];
cx q[143],q[80];
u1(0) q[80];
u1(0) q[143];
cx q[143],q[81];
u1(0) q[81];
cx q[143],q[81];
u1(0) q[81];
u1(0) q[143];
cx q[143],q[82];
u1(0) q[82];
cx q[143],q[82];
u1(0) q[82];
u1(0) q[143];
cx q[143],q[83];
u1(0) q[83];
cx q[143],q[83];
u1(0) q[83];
u1(0) q[143];
cx q[143],q[84];
u1(0) q[84];
cx q[143],q[84];
u1(0) q[84];
u1(0) q[143];
cx q[143],q[85];
u1(0) q[85];
cx q[143],q[85];
u1(0) q[85];
u1(0) q[143];
cx q[143],q[86];
u1(0) q[86];
cx q[143],q[86];
u1(0) q[86];
u1(0) q[143];
cx q[143],q[87];
u1(0) q[87];
cx q[143],q[87];
u1(0) q[87];
u1(0) q[143];
cx q[143],q[88];
u1(0) q[88];
cx q[143],q[88];
u1(0) q[88];
u1(0) q[143];
cx q[143],q[89];
u1(0) q[89];
cx q[143],q[89];
u1(0) q[89];
u1(0) q[143];
cx q[143],q[90];
u1(0) q[90];
cx q[143],q[90];
u1(0) q[90];
u1(0) q[143];
cx q[143],q[91];
u1(0) q[91];
cx q[143],q[91];
u1(0) q[91];
u1(0) q[143];
cx q[143],q[92];
u1(0) q[92];
cx q[143],q[92];
u1(0) q[92];
u1(0) q[143];
cx q[143],q[93];
u1(0) q[93];
cx q[143],q[93];
u1(0) q[93];
u1(0) q[143];
cx q[143],q[94];
u1(0) q[94];
cx q[143],q[94];
u1(0) q[94];
u1(0) q[143];
cx q[143],q[95];
u1(0) q[95];
cx q[143],q[95];
u1(0) q[95];
u1(pi/281474976710656) q[143];
cx q[143],q[96];
u1(-pi/281474976710656) q[96];
cx q[143],q[96];
u1(pi/281474976710656) q[96];
u1(pi/140737488355328) q[143];
cx q[143],q[97];
u1(-pi/140737488355328) q[97];
cx q[143],q[97];
u1(pi/140737488355328) q[97];
u1(pi/70368744177664) q[143];
cx q[143],q[98];
u1(-pi/70368744177664) q[98];
cx q[143],q[98];
u1(pi/70368744177664) q[98];
u1(pi/35184372088832) q[143];
cx q[143],q[99];
u1(-pi/35184372088832) q[99];
cx q[143],q[99];
u1(pi/35184372088832) q[99];
u1(pi/17592186044416) q[143];
cx q[143],q[100];
u1(-pi/17592186044416) q[100];
cx q[143],q[100];
u1(pi/17592186044416) q[100];
u1(pi/8796093022208) q[143];
cx q[143],q[101];
u1(-pi/8796093022208) q[101];
cx q[143],q[101];
u1(pi/8796093022208) q[101];
u1(pi/4398046511104) q[143];
cx q[143],q[102];
u1(-pi/4398046511104) q[102];
cx q[143],q[102];
u1(pi/4398046511104) q[102];
u1(pi/2199023255552) q[143];
cx q[143],q[103];
u1(-pi/2199023255552) q[103];
cx q[143],q[103];
u1(pi/2199023255552) q[103];
u1(pi/1099511627776) q[143];
cx q[143],q[104];
u1(-pi/1099511627776) q[104];
cx q[143],q[104];
u1(pi/1099511627776) q[104];
u1(pi/549755813888) q[143];
cx q[143],q[105];
u1(-pi/549755813888) q[105];
cx q[143],q[105];
u1(pi/549755813888) q[105];
u1(pi/274877906944) q[143];
cx q[143],q[106];
u1(-pi/274877906944) q[106];
cx q[143],q[106];
u1(pi/274877906944) q[106];
u1(pi/137438953472) q[143];
cx q[143],q[107];
u1(-pi/137438953472) q[107];
cx q[143],q[107];
u1(pi/137438953472) q[107];
u1(pi/68719476736) q[143];
cx q[143],q[108];
u1(-pi/68719476736) q[108];
cx q[143],q[108];
u1(pi/68719476736) q[108];
u1(pi/34359738368) q[143];
cx q[143],q[109];
u1(-pi/34359738368) q[109];
cx q[143],q[109];
u1(pi/34359738368) q[109];
u1(pi/17179869184) q[143];
cx q[143],q[110];
u1(-pi/17179869184) q[110];
cx q[143],q[110];
u1(pi/17179869184) q[110];
u1(pi/8589934592) q[143];
cx q[143],q[111];
u1(-pi/8589934592) q[111];
cx q[143],q[111];
u1(pi/8589934592) q[111];
u1(pi/4294967296) q[143];
cx q[143],q[112];
u1(-pi/4294967296) q[112];
cx q[143],q[112];
u1(pi/4294967296) q[112];
u1(pi/2147483648) q[143];
cx q[143],q[113];
u1(-pi/2147483648) q[113];
cx q[143],q[113];
u1(pi/2147483648) q[113];
u1(pi/1073741824) q[143];
cx q[143],q[114];
u1(-pi/1073741824) q[114];
cx q[143],q[114];
u1(pi/1073741824) q[114];
u1(pi/536870912) q[143];
cx q[143],q[115];
u1(-pi/536870912) q[115];
cx q[143],q[115];
u1(pi/536870912) q[115];
u1(pi/268435456) q[143];
cx q[143],q[116];
u1(-pi/268435456) q[116];
cx q[143],q[116];
u1(pi/268435456) q[116];
u1(pi/134217728) q[143];
cx q[143],q[117];
u1(-pi/134217728) q[117];
cx q[143],q[117];
u1(pi/134217728) q[117];
u1(pi/67108864) q[143];
cx q[143],q[118];
u1(-pi/67108864) q[118];
cx q[143],q[118];
u1(pi/67108864) q[118];
u1(pi/33554432) q[143];
cx q[143],q[119];
u1(-pi/33554432) q[119];
cx q[143],q[119];
u1(pi/33554432) q[119];
u1(pi/16777216) q[143];
cx q[143],q[120];
u1(-pi/16777216) q[120];
cx q[143],q[120];
u1(pi/16777216) q[120];
u1(pi/8388608) q[143];
cx q[143],q[121];
u1(-pi/8388608) q[121];
cx q[143],q[121];
u1(pi/8388608) q[121];
u1(pi/4194304) q[143];
cx q[143],q[122];
u1(-pi/4194304) q[122];
cx q[143],q[122];
u1(pi/4194304) q[122];
u1(pi/2097152) q[143];
cx q[143],q[123];
u1(-pi/2097152) q[123];
cx q[143],q[123];
u1(pi/2097152) q[123];
u1(pi/1048576) q[143];
cx q[143],q[124];
u1(-pi/1048576) q[124];
cx q[143],q[124];
u1(pi/1048576) q[124];
u1(pi/524288) q[143];
cx q[143],q[125];
u1(-pi/524288) q[125];
cx q[143],q[125];
u1(pi/524288) q[125];
u1(pi/262144) q[143];
cx q[143],q[126];
u1(-pi/262144) q[126];
cx q[143],q[126];
u1(pi/262144) q[126];
u1(pi/131072) q[143];
cx q[143],q[127];
u1(-pi/131072) q[127];
cx q[143],q[127];
u1(pi/131072) q[127];
u1(pi/65536) q[143];
cx q[143],q[128];
u1(-pi/65536) q[128];
cx q[143],q[128];
u1(pi/65536) q[128];
u1(pi/32768) q[143];
cx q[143],q[129];
u1(-pi/32768) q[129];
cx q[143],q[129];
u1(pi/32768) q[129];
u1(pi/16384) q[143];
cx q[143],q[130];
u1(-pi/16384) q[130];
cx q[143],q[130];
u1(pi/16384) q[130];
u1(pi/8192) q[143];
cx q[143],q[131];
u1(-pi/8192) q[131];
cx q[143],q[131];
u1(pi/8192) q[131];
u1(pi/4096) q[143];
cx q[143],q[132];
u1(-pi/4096) q[132];
cx q[143],q[132];
u1(pi/4096) q[132];
u1(pi/2048) q[143];
cx q[143],q[133];
u1(-pi/2048) q[133];
cx q[143],q[133];
u1(pi/2048) q[133];
u1(pi/1024) q[143];
cx q[143],q[134];
u1(-pi/1024) q[134];
cx q[143],q[134];
u1(pi/1024) q[134];
u1(pi/512) q[143];
cx q[143],q[135];
u1(-pi/512) q[135];
cx q[143],q[135];
u1(pi/512) q[135];
u1(pi/256) q[143];
cx q[143],q[136];
u1(-pi/256) q[136];
cx q[143],q[136];
u1(pi/256) q[136];
u1(pi/128) q[143];
cx q[143],q[137];
u1(-pi/128) q[137];
cx q[143],q[137];
u1(pi/128) q[137];
u1(pi/64) q[143];
cx q[143],q[138];
u1(-pi/64) q[138];
cx q[143],q[138];
u1(pi/64) q[138];
u1(pi/32) q[143];
cx q[143],q[139];
u1(-pi/32) q[139];
cx q[143],q[139];
u1(pi/32) q[139];
u1(pi/16) q[143];
cx q[143],q[140];
u1(-pi/16) q[140];
cx q[143],q[140];
u1(pi/16) q[140];
u1(pi/8) q[143];
cx q[143],q[141];
u1(-pi/8) q[141];
cx q[143],q[141];
u1(pi/8) q[141];
u1(pi/4) q[143];
cx q[143],q[142];
u1(-pi/4) q[142];
cx q[143],q[142];
u1(pi/4) q[142];
h q[143];
u1(0) q[144];
cx q[144],q[0];
u1(0) q[0];
cx q[144],q[0];
u1(0) q[0];
u1(0) q[144];
cx q[144],q[1];
u1(0) q[1];
cx q[144],q[1];
u1(0) q[1];
u1(0) q[144];
cx q[144],q[2];
u1(0) q[2];
cx q[144],q[2];
u1(0) q[2];
u1(0) q[144];
cx q[144],q[3];
u1(0) q[3];
cx q[144],q[3];
u1(0) q[3];
u1(0) q[144];
cx q[144],q[4];
u1(0) q[4];
cx q[144],q[4];
u1(0) q[4];
u1(0) q[144];
cx q[144],q[5];
u1(0) q[5];
cx q[144],q[5];
u1(0) q[5];
u1(0) q[144];
cx q[144],q[6];
u1(0) q[6];
cx q[144],q[6];
u1(0) q[6];
u1(0) q[144];
cx q[144],q[7];
u1(0) q[7];
cx q[144],q[7];
u1(0) q[7];
u1(0) q[144];
cx q[144],q[8];
u1(0) q[8];
cx q[144],q[8];
u1(0) q[8];
u1(0) q[144];
cx q[144],q[9];
u1(0) q[9];
cx q[144],q[9];
u1(0) q[9];
u1(0) q[144];
cx q[144],q[10];
u1(0) q[10];
cx q[144],q[10];
u1(0) q[10];
u1(0) q[144];
cx q[144],q[11];
u1(0) q[11];
cx q[144],q[11];
u1(0) q[11];
u1(0) q[144];
cx q[144],q[12];
u1(0) q[12];
cx q[144],q[12];
u1(0) q[12];
u1(0) q[144];
cx q[144],q[13];
u1(0) q[13];
cx q[144],q[13];
u1(0) q[13];
u1(0) q[144];
cx q[144],q[14];
u1(0) q[14];
cx q[144],q[14];
u1(0) q[14];
u1(0) q[144];
cx q[144],q[15];
u1(0) q[15];
cx q[144],q[15];
u1(0) q[15];
u1(0) q[144];
cx q[144],q[16];
u1(0) q[16];
cx q[144],q[16];
u1(0) q[16];
u1(0) q[144];
cx q[144],q[17];
u1(0) q[17];
cx q[144],q[17];
u1(0) q[17];
u1(0) q[144];
cx q[144],q[18];
u1(0) q[18];
cx q[144],q[18];
u1(0) q[18];
u1(0) q[144];
cx q[144],q[19];
u1(0) q[19];
cx q[144],q[19];
u1(0) q[19];
u1(0) q[144];
cx q[144],q[20];
u1(0) q[20];
cx q[144],q[20];
u1(0) q[20];
u1(0) q[144];
cx q[144],q[21];
u1(0) q[21];
cx q[144],q[21];
u1(0) q[21];
u1(0) q[144];
cx q[144],q[22];
u1(0) q[22];
cx q[144],q[22];
u1(0) q[22];
u1(0) q[144];
cx q[144],q[23];
u1(0) q[23];
cx q[144],q[23];
u1(0) q[23];
u1(0) q[144];
cx q[144],q[24];
u1(0) q[24];
cx q[144],q[24];
u1(0) q[24];
u1(0) q[144];
cx q[144],q[25];
u1(0) q[25];
cx q[144],q[25];
u1(0) q[25];
u1(0) q[144];
cx q[144],q[26];
u1(0) q[26];
cx q[144],q[26];
u1(0) q[26];
u1(0) q[144];
cx q[144],q[27];
u1(0) q[27];
cx q[144],q[27];
u1(0) q[27];
u1(0) q[144];
cx q[144],q[28];
u1(0) q[28];
cx q[144],q[28];
u1(0) q[28];
u1(0) q[144];
cx q[144],q[29];
u1(0) q[29];
cx q[144],q[29];
u1(0) q[29];
u1(0) q[144];
cx q[144],q[30];
u1(0) q[30];
cx q[144],q[30];
u1(0) q[30];
u1(0) q[144];
cx q[144],q[31];
u1(0) q[31];
cx q[144],q[31];
u1(0) q[31];
u1(0) q[144];
cx q[144],q[32];
u1(0) q[32];
cx q[144],q[32];
u1(0) q[32];
u1(0) q[144];
cx q[144],q[33];
u1(0) q[33];
cx q[144],q[33];
u1(0) q[33];
u1(0) q[144];
cx q[144],q[34];
u1(0) q[34];
cx q[144],q[34];
u1(0) q[34];
u1(0) q[144];
cx q[144],q[35];
u1(0) q[35];
cx q[144],q[35];
u1(0) q[35];
u1(0) q[144];
cx q[144],q[36];
u1(0) q[36];
cx q[144],q[36];
u1(0) q[36];
u1(0) q[144];
cx q[144],q[37];
u1(0) q[37];
cx q[144],q[37];
u1(0) q[37];
u1(0) q[144];
cx q[144],q[38];
u1(0) q[38];
cx q[144],q[38];
u1(0) q[38];
u1(0) q[144];
cx q[144],q[39];
u1(0) q[39];
cx q[144],q[39];
u1(0) q[39];
u1(0) q[144];
cx q[144],q[40];
u1(0) q[40];
cx q[144],q[40];
u1(0) q[40];
u1(0) q[144];
cx q[144],q[41];
u1(0) q[41];
cx q[144],q[41];
u1(0) q[41];
u1(0) q[144];
cx q[144],q[42];
u1(0) q[42];
cx q[144],q[42];
u1(0) q[42];
u1(0) q[144];
cx q[144],q[43];
u1(0) q[43];
cx q[144],q[43];
u1(0) q[43];
u1(0) q[144];
cx q[144],q[44];
u1(0) q[44];
cx q[144],q[44];
u1(0) q[44];
u1(0) q[144];
cx q[144],q[45];
u1(0) q[45];
cx q[144],q[45];
u1(0) q[45];
u1(0) q[144];
cx q[144],q[46];
u1(0) q[46];
cx q[144],q[46];
u1(0) q[46];
u1(0) q[144];
cx q[144],q[47];
u1(0) q[47];
cx q[144],q[47];
u1(0) q[47];
u1(0) q[144];
cx q[144],q[48];
u1(0) q[48];
cx q[144],q[48];
u1(0) q[48];
u1(0) q[144];
cx q[144],q[49];
u1(0) q[49];
cx q[144],q[49];
u1(0) q[49];
u1(0) q[144];
cx q[144],q[50];
u1(0) q[50];
cx q[144],q[50];
u1(0) q[50];
u1(0) q[144];
cx q[144],q[51];
u1(0) q[51];
cx q[144],q[51];
u1(0) q[51];
u1(0) q[144];
cx q[144],q[52];
u1(0) q[52];
cx q[144],q[52];
u1(0) q[52];
u1(0) q[144];
cx q[144],q[53];
u1(0) q[53];
cx q[144],q[53];
u1(0) q[53];
u1(0) q[144];
cx q[144],q[54];
u1(0) q[54];
cx q[144],q[54];
u1(0) q[54];
u1(0) q[144];
cx q[144],q[55];
u1(0) q[55];
cx q[144],q[55];
u1(0) q[55];
u1(0) q[144];
cx q[144],q[56];
u1(0) q[56];
cx q[144],q[56];
u1(0) q[56];
u1(0) q[144];
cx q[144],q[57];
u1(0) q[57];
cx q[144],q[57];
u1(0) q[57];
u1(0) q[144];
cx q[144],q[58];
u1(0) q[58];
cx q[144],q[58];
u1(0) q[58];
u1(0) q[144];
cx q[144],q[59];
u1(0) q[59];
cx q[144],q[59];
u1(0) q[59];
u1(0) q[144];
cx q[144],q[60];
u1(0) q[60];
cx q[144],q[60];
u1(0) q[60];
u1(0) q[144];
cx q[144],q[61];
u1(0) q[61];
cx q[144],q[61];
u1(0) q[61];
u1(0) q[144];
cx q[144],q[62];
u1(0) q[62];
cx q[144],q[62];
u1(0) q[62];
u1(0) q[144];
cx q[144],q[63];
u1(0) q[63];
cx q[144],q[63];
u1(0) q[63];
u1(0) q[144];
cx q[144],q[64];
u1(0) q[64];
cx q[144],q[64];
u1(0) q[64];
u1(0) q[144];
cx q[144],q[65];
u1(0) q[65];
cx q[144],q[65];
u1(0) q[65];
u1(0) q[144];
cx q[144],q[66];
u1(0) q[66];
cx q[144],q[66];
u1(0) q[66];
u1(0) q[144];
cx q[144],q[67];
u1(0) q[67];
cx q[144],q[67];
u1(0) q[67];
u1(0) q[144];
cx q[144],q[68];
u1(0) q[68];
cx q[144],q[68];
u1(0) q[68];
u1(0) q[144];
cx q[144],q[69];
u1(0) q[69];
cx q[144],q[69];
u1(0) q[69];
u1(0) q[144];
cx q[144],q[70];
u1(0) q[70];
cx q[144],q[70];
u1(0) q[70];
u1(0) q[144];
cx q[144],q[71];
u1(0) q[71];
cx q[144],q[71];
u1(0) q[71];
u1(0) q[144];
cx q[144],q[72];
u1(0) q[72];
cx q[144],q[72];
u1(0) q[72];
u1(0) q[144];
cx q[144],q[73];
u1(0) q[73];
cx q[144],q[73];
u1(0) q[73];
u1(0) q[144];
cx q[144],q[74];
u1(0) q[74];
cx q[144],q[74];
u1(0) q[74];
u1(0) q[144];
cx q[144],q[75];
u1(0) q[75];
cx q[144],q[75];
u1(0) q[75];
u1(0) q[144];
cx q[144],q[76];
u1(0) q[76];
cx q[144],q[76];
u1(0) q[76];
u1(0) q[144];
cx q[144],q[77];
u1(0) q[77];
cx q[144],q[77];
u1(0) q[77];
u1(0) q[144];
cx q[144],q[78];
u1(0) q[78];
cx q[144],q[78];
u1(0) q[78];
u1(0) q[144];
cx q[144],q[79];
u1(0) q[79];
cx q[144],q[79];
u1(0) q[79];
u1(0) q[144];
cx q[144],q[80];
u1(0) q[80];
cx q[144],q[80];
u1(0) q[80];
u1(0) q[144];
cx q[144],q[81];
u1(0) q[81];
cx q[144],q[81];
u1(0) q[81];
u1(0) q[144];
cx q[144],q[82];
u1(0) q[82];
cx q[144],q[82];
u1(0) q[82];
u1(0) q[144];
cx q[144],q[83];
u1(0) q[83];
cx q[144],q[83];
u1(0) q[83];
u1(0) q[144];
cx q[144],q[84];
u1(0) q[84];
cx q[144],q[84];
u1(0) q[84];
u1(0) q[144];
cx q[144],q[85];
u1(0) q[85];
cx q[144],q[85];
u1(0) q[85];
u1(0) q[144];
cx q[144],q[86];
u1(0) q[86];
cx q[144],q[86];
u1(0) q[86];
u1(0) q[144];
cx q[144],q[87];
u1(0) q[87];
cx q[144],q[87];
u1(0) q[87];
u1(0) q[144];
cx q[144],q[88];
u1(0) q[88];
cx q[144],q[88];
u1(0) q[88];
u1(0) q[144];
cx q[144],q[89];
u1(0) q[89];
cx q[144],q[89];
u1(0) q[89];
u1(0) q[144];
cx q[144],q[90];
u1(0) q[90];
cx q[144],q[90];
u1(0) q[90];
u1(0) q[144];
cx q[144],q[91];
u1(0) q[91];
cx q[144],q[91];
u1(0) q[91];
u1(0) q[144];
cx q[144],q[92];
u1(0) q[92];
cx q[144],q[92];
u1(0) q[92];
u1(0) q[144];
cx q[144],q[93];
u1(0) q[93];
cx q[144],q[93];
u1(0) q[93];
u1(0) q[144];
cx q[144],q[94];
u1(0) q[94];
cx q[144],q[94];
u1(0) q[94];
u1(0) q[144];
cx q[144],q[95];
u1(0) q[95];
cx q[144],q[95];
u1(0) q[95];
u1(0) q[144];
cx q[144],q[96];
u1(0) q[96];
cx q[144],q[96];
u1(0) q[96];
u1(pi/281474976710656) q[144];
cx q[144],q[97];
u1(-pi/281474976710656) q[97];
cx q[144],q[97];
u1(pi/281474976710656) q[97];
u1(pi/140737488355328) q[144];
cx q[144],q[98];
u1(-pi/140737488355328) q[98];
cx q[144],q[98];
u1(pi/140737488355328) q[98];
u1(pi/70368744177664) q[144];
cx q[144],q[99];
u1(-pi/70368744177664) q[99];
cx q[144],q[99];
u1(pi/70368744177664) q[99];
u1(pi/35184372088832) q[144];
cx q[144],q[100];
u1(-pi/35184372088832) q[100];
cx q[144],q[100];
u1(pi/35184372088832) q[100];
u1(pi/17592186044416) q[144];
cx q[144],q[101];
u1(-pi/17592186044416) q[101];
cx q[144],q[101];
u1(pi/17592186044416) q[101];
u1(pi/8796093022208) q[144];
cx q[144],q[102];
u1(-pi/8796093022208) q[102];
cx q[144],q[102];
u1(pi/8796093022208) q[102];
u1(pi/4398046511104) q[144];
cx q[144],q[103];
u1(-pi/4398046511104) q[103];
cx q[144],q[103];
u1(pi/4398046511104) q[103];
u1(pi/2199023255552) q[144];
cx q[144],q[104];
u1(-pi/2199023255552) q[104];
cx q[144],q[104];
u1(pi/2199023255552) q[104];
u1(pi/1099511627776) q[144];
cx q[144],q[105];
u1(-pi/1099511627776) q[105];
cx q[144],q[105];
u1(pi/1099511627776) q[105];
u1(pi/549755813888) q[144];
cx q[144],q[106];
u1(-pi/549755813888) q[106];
cx q[144],q[106];
u1(pi/549755813888) q[106];
u1(pi/274877906944) q[144];
cx q[144],q[107];
u1(-pi/274877906944) q[107];
cx q[144],q[107];
u1(pi/274877906944) q[107];
u1(pi/137438953472) q[144];
cx q[144],q[108];
u1(-pi/137438953472) q[108];
cx q[144],q[108];
u1(pi/137438953472) q[108];
u1(pi/68719476736) q[144];
cx q[144],q[109];
u1(-pi/68719476736) q[109];
cx q[144],q[109];
u1(pi/68719476736) q[109];
u1(pi/34359738368) q[144];
cx q[144],q[110];
u1(-pi/34359738368) q[110];
cx q[144],q[110];
u1(pi/34359738368) q[110];
u1(pi/17179869184) q[144];
cx q[144],q[111];
u1(-pi/17179869184) q[111];
cx q[144],q[111];
u1(pi/17179869184) q[111];
u1(pi/8589934592) q[144];
cx q[144],q[112];
u1(-pi/8589934592) q[112];
cx q[144],q[112];
u1(pi/8589934592) q[112];
u1(pi/4294967296) q[144];
cx q[144],q[113];
u1(-pi/4294967296) q[113];
cx q[144],q[113];
u1(pi/4294967296) q[113];
u1(pi/2147483648) q[144];
cx q[144],q[114];
u1(-pi/2147483648) q[114];
cx q[144],q[114];
u1(pi/2147483648) q[114];
u1(pi/1073741824) q[144];
cx q[144],q[115];
u1(-pi/1073741824) q[115];
cx q[144],q[115];
u1(pi/1073741824) q[115];
u1(pi/536870912) q[144];
cx q[144],q[116];
u1(-pi/536870912) q[116];
cx q[144],q[116];
u1(pi/536870912) q[116];
u1(pi/268435456) q[144];
cx q[144],q[117];
u1(-pi/268435456) q[117];
cx q[144],q[117];
u1(pi/268435456) q[117];
u1(pi/134217728) q[144];
cx q[144],q[118];
u1(-pi/134217728) q[118];
cx q[144],q[118];
u1(pi/134217728) q[118];
u1(pi/67108864) q[144];
cx q[144],q[119];
u1(-pi/67108864) q[119];
cx q[144],q[119];
u1(pi/67108864) q[119];
u1(pi/33554432) q[144];
cx q[144],q[120];
u1(-pi/33554432) q[120];
cx q[144],q[120];
u1(pi/33554432) q[120];
u1(pi/16777216) q[144];
cx q[144],q[121];
u1(-pi/16777216) q[121];
cx q[144],q[121];
u1(pi/16777216) q[121];
u1(pi/8388608) q[144];
cx q[144],q[122];
u1(-pi/8388608) q[122];
cx q[144],q[122];
u1(pi/8388608) q[122];
u1(pi/4194304) q[144];
cx q[144],q[123];
u1(-pi/4194304) q[123];
cx q[144],q[123];
u1(pi/4194304) q[123];
u1(pi/2097152) q[144];
cx q[144],q[124];
u1(-pi/2097152) q[124];
cx q[144],q[124];
u1(pi/2097152) q[124];
u1(pi/1048576) q[144];
cx q[144],q[125];
u1(-pi/1048576) q[125];
cx q[144],q[125];
u1(pi/1048576) q[125];
u1(pi/524288) q[144];
cx q[144],q[126];
u1(-pi/524288) q[126];
cx q[144],q[126];
u1(pi/524288) q[126];
u1(pi/262144) q[144];
cx q[144],q[127];
u1(-pi/262144) q[127];
cx q[144],q[127];
u1(pi/262144) q[127];
u1(pi/131072) q[144];
cx q[144],q[128];
u1(-pi/131072) q[128];
cx q[144],q[128];
u1(pi/131072) q[128];
u1(pi/65536) q[144];
cx q[144],q[129];
u1(-pi/65536) q[129];
cx q[144],q[129];
u1(pi/65536) q[129];
u1(pi/32768) q[144];
cx q[144],q[130];
u1(-pi/32768) q[130];
cx q[144],q[130];
u1(pi/32768) q[130];
u1(pi/16384) q[144];
cx q[144],q[131];
u1(-pi/16384) q[131];
cx q[144],q[131];
u1(pi/16384) q[131];
u1(pi/8192) q[144];
cx q[144],q[132];
u1(-pi/8192) q[132];
cx q[144],q[132];
u1(pi/8192) q[132];
u1(pi/4096) q[144];
cx q[144],q[133];
u1(-pi/4096) q[133];
cx q[144],q[133];
u1(pi/4096) q[133];
u1(pi/2048) q[144];
cx q[144],q[134];
u1(-pi/2048) q[134];
cx q[144],q[134];
u1(pi/2048) q[134];
u1(pi/1024) q[144];
cx q[144],q[135];
u1(-pi/1024) q[135];
cx q[144],q[135];
u1(pi/1024) q[135];
u1(pi/512) q[144];
cx q[144],q[136];
u1(-pi/512) q[136];
cx q[144],q[136];
u1(pi/512) q[136];
u1(pi/256) q[144];
cx q[144],q[137];
u1(-pi/256) q[137];
cx q[144],q[137];
u1(pi/256) q[137];
u1(pi/128) q[144];
cx q[144],q[138];
u1(-pi/128) q[138];
cx q[144],q[138];
u1(pi/128) q[138];
u1(pi/64) q[144];
cx q[144],q[139];
u1(-pi/64) q[139];
cx q[144],q[139];
u1(pi/64) q[139];
u1(pi/32) q[144];
cx q[144],q[140];
u1(-pi/32) q[140];
cx q[144],q[140];
u1(pi/32) q[140];
u1(pi/16) q[144];
cx q[144],q[141];
u1(-pi/16) q[141];
cx q[144],q[141];
u1(pi/16) q[141];
u1(pi/8) q[144];
cx q[144],q[142];
u1(-pi/8) q[142];
cx q[144],q[142];
u1(pi/8) q[142];
u1(pi/4) q[144];
cx q[144],q[143];
u1(-pi/4) q[143];
cx q[144],q[143];
u1(pi/4) q[143];
h q[144];
u1(0) q[145];
cx q[145],q[0];
u1(0) q[0];
cx q[145],q[0];
u1(0) q[0];
u1(0) q[145];
cx q[145],q[1];
u1(0) q[1];
cx q[145],q[1];
u1(0) q[1];
u1(0) q[145];
cx q[145],q[2];
u1(0) q[2];
cx q[145],q[2];
u1(0) q[2];
u1(0) q[145];
cx q[145],q[3];
u1(0) q[3];
cx q[145],q[3];
u1(0) q[3];
u1(0) q[145];
cx q[145],q[4];
u1(0) q[4];
cx q[145],q[4];
u1(0) q[4];
u1(0) q[145];
cx q[145],q[5];
u1(0) q[5];
cx q[145],q[5];
u1(0) q[5];
u1(0) q[145];
cx q[145],q[6];
u1(0) q[6];
cx q[145],q[6];
u1(0) q[6];
u1(0) q[145];
cx q[145],q[7];
u1(0) q[7];
cx q[145],q[7];
u1(0) q[7];
u1(0) q[145];
cx q[145],q[8];
u1(0) q[8];
cx q[145],q[8];
u1(0) q[8];
u1(0) q[145];
cx q[145],q[9];
u1(0) q[9];
cx q[145],q[9];
u1(0) q[9];
u1(0) q[145];
cx q[145],q[10];
u1(0) q[10];
cx q[145],q[10];
u1(0) q[10];
u1(0) q[145];
cx q[145],q[11];
u1(0) q[11];
cx q[145],q[11];
u1(0) q[11];
u1(0) q[145];
cx q[145],q[12];
u1(0) q[12];
cx q[145],q[12];
u1(0) q[12];
u1(0) q[145];
cx q[145],q[13];
u1(0) q[13];
cx q[145],q[13];
u1(0) q[13];
u1(0) q[145];
cx q[145],q[14];
u1(0) q[14];
cx q[145],q[14];
u1(0) q[14];
u1(0) q[145];
cx q[145],q[15];
u1(0) q[15];
cx q[145],q[15];
u1(0) q[15];
u1(0) q[145];
cx q[145],q[16];
u1(0) q[16];
cx q[145],q[16];
u1(0) q[16];
u1(0) q[145];
cx q[145],q[17];
u1(0) q[17];
cx q[145],q[17];
u1(0) q[17];
u1(0) q[145];
cx q[145],q[18];
u1(0) q[18];
cx q[145],q[18];
u1(0) q[18];
u1(0) q[145];
cx q[145],q[19];
u1(0) q[19];
cx q[145],q[19];
u1(0) q[19];
u1(0) q[145];
cx q[145],q[20];
u1(0) q[20];
cx q[145],q[20];
u1(0) q[20];
u1(0) q[145];
cx q[145],q[21];
u1(0) q[21];
cx q[145],q[21];
u1(0) q[21];
u1(0) q[145];
cx q[145],q[22];
u1(0) q[22];
cx q[145],q[22];
u1(0) q[22];
u1(0) q[145];
cx q[145],q[23];
u1(0) q[23];
cx q[145],q[23];
u1(0) q[23];
u1(0) q[145];
cx q[145],q[24];
u1(0) q[24];
cx q[145],q[24];
u1(0) q[24];
u1(0) q[145];
cx q[145],q[25];
u1(0) q[25];
cx q[145],q[25];
u1(0) q[25];
u1(0) q[145];
cx q[145],q[26];
u1(0) q[26];
cx q[145],q[26];
u1(0) q[26];
u1(0) q[145];
cx q[145],q[27];
u1(0) q[27];
cx q[145],q[27];
u1(0) q[27];
u1(0) q[145];
cx q[145],q[28];
u1(0) q[28];
cx q[145],q[28];
u1(0) q[28];
u1(0) q[145];
cx q[145],q[29];
u1(0) q[29];
cx q[145],q[29];
u1(0) q[29];
u1(0) q[145];
cx q[145],q[30];
u1(0) q[30];
cx q[145],q[30];
u1(0) q[30];
u1(0) q[145];
cx q[145],q[31];
u1(0) q[31];
cx q[145],q[31];
u1(0) q[31];
u1(0) q[145];
cx q[145],q[32];
u1(0) q[32];
cx q[145],q[32];
u1(0) q[32];
u1(0) q[145];
cx q[145],q[33];
u1(0) q[33];
cx q[145],q[33];
u1(0) q[33];
u1(0) q[145];
cx q[145],q[34];
u1(0) q[34];
cx q[145],q[34];
u1(0) q[34];
u1(0) q[145];
cx q[145],q[35];
u1(0) q[35];
cx q[145],q[35];
u1(0) q[35];
u1(0) q[145];
cx q[145],q[36];
u1(0) q[36];
cx q[145],q[36];
u1(0) q[36];
u1(0) q[145];
cx q[145],q[37];
u1(0) q[37];
cx q[145],q[37];
u1(0) q[37];
u1(0) q[145];
cx q[145],q[38];
u1(0) q[38];
cx q[145],q[38];
u1(0) q[38];
u1(0) q[145];
cx q[145],q[39];
u1(0) q[39];
cx q[145],q[39];
u1(0) q[39];
u1(0) q[145];
cx q[145],q[40];
u1(0) q[40];
cx q[145],q[40];
u1(0) q[40];
u1(0) q[145];
cx q[145],q[41];
u1(0) q[41];
cx q[145],q[41];
u1(0) q[41];
u1(0) q[145];
cx q[145],q[42];
u1(0) q[42];
cx q[145],q[42];
u1(0) q[42];
u1(0) q[145];
cx q[145],q[43];
u1(0) q[43];
cx q[145],q[43];
u1(0) q[43];
u1(0) q[145];
cx q[145],q[44];
u1(0) q[44];
cx q[145],q[44];
u1(0) q[44];
u1(0) q[145];
cx q[145],q[45];
u1(0) q[45];
cx q[145],q[45];
u1(0) q[45];
u1(0) q[145];
cx q[145],q[46];
u1(0) q[46];
cx q[145],q[46];
u1(0) q[46];
u1(0) q[145];
cx q[145],q[47];
u1(0) q[47];
cx q[145],q[47];
u1(0) q[47];
u1(0) q[145];
cx q[145],q[48];
u1(0) q[48];
cx q[145],q[48];
u1(0) q[48];
u1(0) q[145];
cx q[145],q[49];
u1(0) q[49];
cx q[145],q[49];
u1(0) q[49];
u1(0) q[145];
cx q[145],q[50];
u1(0) q[50];
cx q[145],q[50];
u1(0) q[50];
u1(0) q[145];
cx q[145],q[51];
u1(0) q[51];
cx q[145],q[51];
u1(0) q[51];
u1(0) q[145];
cx q[145],q[52];
u1(0) q[52];
cx q[145],q[52];
u1(0) q[52];
u1(0) q[145];
cx q[145],q[53];
u1(0) q[53];
cx q[145],q[53];
u1(0) q[53];
u1(0) q[145];
cx q[145],q[54];
u1(0) q[54];
cx q[145],q[54];
u1(0) q[54];
u1(0) q[145];
cx q[145],q[55];
u1(0) q[55];
cx q[145],q[55];
u1(0) q[55];
u1(0) q[145];
cx q[145],q[56];
u1(0) q[56];
cx q[145],q[56];
u1(0) q[56];
u1(0) q[145];
cx q[145],q[57];
u1(0) q[57];
cx q[145],q[57];
u1(0) q[57];
u1(0) q[145];
cx q[145],q[58];
u1(0) q[58];
cx q[145],q[58];
u1(0) q[58];
u1(0) q[145];
cx q[145],q[59];
u1(0) q[59];
cx q[145],q[59];
u1(0) q[59];
u1(0) q[145];
cx q[145],q[60];
u1(0) q[60];
cx q[145],q[60];
u1(0) q[60];
u1(0) q[145];
cx q[145],q[61];
u1(0) q[61];
cx q[145],q[61];
u1(0) q[61];
u1(0) q[145];
cx q[145],q[62];
u1(0) q[62];
cx q[145],q[62];
u1(0) q[62];
u1(0) q[145];
cx q[145],q[63];
u1(0) q[63];
cx q[145],q[63];
u1(0) q[63];
u1(0) q[145];
cx q[145],q[64];
u1(0) q[64];
cx q[145],q[64];
u1(0) q[64];
u1(0) q[145];
cx q[145],q[65];
u1(0) q[65];
cx q[145],q[65];
u1(0) q[65];
u1(0) q[145];
cx q[145],q[66];
u1(0) q[66];
cx q[145],q[66];
u1(0) q[66];
u1(0) q[145];
cx q[145],q[67];
u1(0) q[67];
cx q[145],q[67];
u1(0) q[67];
u1(0) q[145];
cx q[145],q[68];
u1(0) q[68];
cx q[145],q[68];
u1(0) q[68];
u1(0) q[145];
cx q[145],q[69];
u1(0) q[69];
cx q[145],q[69];
u1(0) q[69];
u1(0) q[145];
cx q[145],q[70];
u1(0) q[70];
cx q[145],q[70];
u1(0) q[70];
u1(0) q[145];
cx q[145],q[71];
u1(0) q[71];
cx q[145],q[71];
u1(0) q[71];
u1(0) q[145];
cx q[145],q[72];
u1(0) q[72];
cx q[145],q[72];
u1(0) q[72];
u1(0) q[145];
cx q[145],q[73];
u1(0) q[73];
cx q[145],q[73];
u1(0) q[73];
u1(0) q[145];
cx q[145],q[74];
u1(0) q[74];
cx q[145],q[74];
u1(0) q[74];
u1(0) q[145];
cx q[145],q[75];
u1(0) q[75];
cx q[145],q[75];
u1(0) q[75];
u1(0) q[145];
cx q[145],q[76];
u1(0) q[76];
cx q[145],q[76];
u1(0) q[76];
u1(0) q[145];
cx q[145],q[77];
u1(0) q[77];
cx q[145],q[77];
u1(0) q[77];
u1(0) q[145];
cx q[145],q[78];
u1(0) q[78];
cx q[145],q[78];
u1(0) q[78];
u1(0) q[145];
cx q[145],q[79];
u1(0) q[79];
cx q[145],q[79];
u1(0) q[79];
u1(0) q[145];
cx q[145],q[80];
u1(0) q[80];
cx q[145],q[80];
u1(0) q[80];
u1(0) q[145];
cx q[145],q[81];
u1(0) q[81];
cx q[145],q[81];
u1(0) q[81];
u1(0) q[145];
cx q[145],q[82];
u1(0) q[82];
cx q[145],q[82];
u1(0) q[82];
u1(0) q[145];
cx q[145],q[83];
u1(0) q[83];
cx q[145],q[83];
u1(0) q[83];
u1(0) q[145];
cx q[145],q[84];
u1(0) q[84];
cx q[145],q[84];
u1(0) q[84];
u1(0) q[145];
cx q[145],q[85];
u1(0) q[85];
cx q[145],q[85];
u1(0) q[85];
u1(0) q[145];
cx q[145],q[86];
u1(0) q[86];
cx q[145],q[86];
u1(0) q[86];
u1(0) q[145];
cx q[145],q[87];
u1(0) q[87];
cx q[145],q[87];
u1(0) q[87];
u1(0) q[145];
cx q[145],q[88];
u1(0) q[88];
cx q[145],q[88];
u1(0) q[88];
u1(0) q[145];
cx q[145],q[89];
u1(0) q[89];
cx q[145],q[89];
u1(0) q[89];
u1(0) q[145];
cx q[145],q[90];
u1(0) q[90];
cx q[145],q[90];
u1(0) q[90];
u1(0) q[145];
cx q[145],q[91];
u1(0) q[91];
cx q[145],q[91];
u1(0) q[91];
u1(0) q[145];
cx q[145],q[92];
u1(0) q[92];
cx q[145],q[92];
u1(0) q[92];
u1(0) q[145];
cx q[145],q[93];
u1(0) q[93];
cx q[145],q[93];
u1(0) q[93];
u1(0) q[145];
cx q[145],q[94];
u1(0) q[94];
cx q[145],q[94];
u1(0) q[94];
u1(0) q[145];
cx q[145],q[95];
u1(0) q[95];
cx q[145],q[95];
u1(0) q[95];
u1(0) q[145];
cx q[145],q[96];
u1(0) q[96];
cx q[145],q[96];
u1(0) q[96];
u1(0) q[145];
cx q[145],q[97];
u1(0) q[97];
cx q[145],q[97];
u1(0) q[97];
u1(pi/281474976710656) q[145];
cx q[145],q[98];
u1(-pi/281474976710656) q[98];
cx q[145],q[98];
u1(pi/281474976710656) q[98];
u1(pi/140737488355328) q[145];
cx q[145],q[99];
u1(-pi/140737488355328) q[99];
cx q[145],q[99];
u1(pi/140737488355328) q[99];
u1(pi/70368744177664) q[145];
cx q[145],q[100];
u1(-pi/70368744177664) q[100];
cx q[145],q[100];
u1(pi/70368744177664) q[100];
u1(pi/35184372088832) q[145];
cx q[145],q[101];
u1(-pi/35184372088832) q[101];
cx q[145],q[101];
u1(pi/35184372088832) q[101];
u1(pi/17592186044416) q[145];
cx q[145],q[102];
u1(-pi/17592186044416) q[102];
cx q[145],q[102];
u1(pi/17592186044416) q[102];
u1(pi/8796093022208) q[145];
cx q[145],q[103];
u1(-pi/8796093022208) q[103];
cx q[145],q[103];
u1(pi/8796093022208) q[103];
u1(pi/4398046511104) q[145];
cx q[145],q[104];
u1(-pi/4398046511104) q[104];
cx q[145],q[104];
u1(pi/4398046511104) q[104];
u1(pi/2199023255552) q[145];
cx q[145],q[105];
u1(-pi/2199023255552) q[105];
cx q[145],q[105];
u1(pi/2199023255552) q[105];
u1(pi/1099511627776) q[145];
cx q[145],q[106];
u1(-pi/1099511627776) q[106];
cx q[145],q[106];
u1(pi/1099511627776) q[106];
u1(pi/549755813888) q[145];
cx q[145],q[107];
u1(-pi/549755813888) q[107];
cx q[145],q[107];
u1(pi/549755813888) q[107];
u1(pi/274877906944) q[145];
cx q[145],q[108];
u1(-pi/274877906944) q[108];
cx q[145],q[108];
u1(pi/274877906944) q[108];
u1(pi/137438953472) q[145];
cx q[145],q[109];
u1(-pi/137438953472) q[109];
cx q[145],q[109];
u1(pi/137438953472) q[109];
u1(pi/68719476736) q[145];
cx q[145],q[110];
u1(-pi/68719476736) q[110];
cx q[145],q[110];
u1(pi/68719476736) q[110];
u1(pi/34359738368) q[145];
cx q[145],q[111];
u1(-pi/34359738368) q[111];
cx q[145],q[111];
u1(pi/34359738368) q[111];
u1(pi/17179869184) q[145];
cx q[145],q[112];
u1(-pi/17179869184) q[112];
cx q[145],q[112];
u1(pi/17179869184) q[112];
u1(pi/8589934592) q[145];
cx q[145],q[113];
u1(-pi/8589934592) q[113];
cx q[145],q[113];
u1(pi/8589934592) q[113];
u1(pi/4294967296) q[145];
cx q[145],q[114];
u1(-pi/4294967296) q[114];
cx q[145],q[114];
u1(pi/4294967296) q[114];
u1(pi/2147483648) q[145];
cx q[145],q[115];
u1(-pi/2147483648) q[115];
cx q[145],q[115];
u1(pi/2147483648) q[115];
u1(pi/1073741824) q[145];
cx q[145],q[116];
u1(-pi/1073741824) q[116];
cx q[145],q[116];
u1(pi/1073741824) q[116];
u1(pi/536870912) q[145];
cx q[145],q[117];
u1(-pi/536870912) q[117];
cx q[145],q[117];
u1(pi/536870912) q[117];
u1(pi/268435456) q[145];
cx q[145],q[118];
u1(-pi/268435456) q[118];
cx q[145],q[118];
u1(pi/268435456) q[118];
u1(pi/134217728) q[145];
cx q[145],q[119];
u1(-pi/134217728) q[119];
cx q[145],q[119];
u1(pi/134217728) q[119];
u1(pi/67108864) q[145];
cx q[145],q[120];
u1(-pi/67108864) q[120];
cx q[145],q[120];
u1(pi/67108864) q[120];
u1(pi/33554432) q[145];
cx q[145],q[121];
u1(-pi/33554432) q[121];
cx q[145],q[121];
u1(pi/33554432) q[121];
u1(pi/16777216) q[145];
cx q[145],q[122];
u1(-pi/16777216) q[122];
cx q[145],q[122];
u1(pi/16777216) q[122];
u1(pi/8388608) q[145];
cx q[145],q[123];
u1(-pi/8388608) q[123];
cx q[145],q[123];
u1(pi/8388608) q[123];
u1(pi/4194304) q[145];
cx q[145],q[124];
u1(-pi/4194304) q[124];
cx q[145],q[124];
u1(pi/4194304) q[124];
u1(pi/2097152) q[145];
cx q[145],q[125];
u1(-pi/2097152) q[125];
cx q[145],q[125];
u1(pi/2097152) q[125];
u1(pi/1048576) q[145];
cx q[145],q[126];
u1(-pi/1048576) q[126];
cx q[145],q[126];
u1(pi/1048576) q[126];
u1(pi/524288) q[145];
cx q[145],q[127];
u1(-pi/524288) q[127];
cx q[145],q[127];
u1(pi/524288) q[127];
u1(pi/262144) q[145];
cx q[145],q[128];
u1(-pi/262144) q[128];
cx q[145],q[128];
u1(pi/262144) q[128];
u1(pi/131072) q[145];
cx q[145],q[129];
u1(-pi/131072) q[129];
cx q[145],q[129];
u1(pi/131072) q[129];
u1(pi/65536) q[145];
cx q[145],q[130];
u1(-pi/65536) q[130];
cx q[145],q[130];
u1(pi/65536) q[130];
u1(pi/32768) q[145];
cx q[145],q[131];
u1(-pi/32768) q[131];
cx q[145],q[131];
u1(pi/32768) q[131];
u1(pi/16384) q[145];
cx q[145],q[132];
u1(-pi/16384) q[132];
cx q[145],q[132];
u1(pi/16384) q[132];
u1(pi/8192) q[145];
cx q[145],q[133];
u1(-pi/8192) q[133];
cx q[145],q[133];
u1(pi/8192) q[133];
u1(pi/4096) q[145];
cx q[145],q[134];
u1(-pi/4096) q[134];
cx q[145],q[134];
u1(pi/4096) q[134];
u1(pi/2048) q[145];
cx q[145],q[135];
u1(-pi/2048) q[135];
cx q[145],q[135];
u1(pi/2048) q[135];
u1(pi/1024) q[145];
cx q[145],q[136];
u1(-pi/1024) q[136];
cx q[145],q[136];
u1(pi/1024) q[136];
u1(pi/512) q[145];
cx q[145],q[137];
u1(-pi/512) q[137];
cx q[145],q[137];
u1(pi/512) q[137];
u1(pi/256) q[145];
cx q[145],q[138];
u1(-pi/256) q[138];
cx q[145],q[138];
u1(pi/256) q[138];
u1(pi/128) q[145];
cx q[145],q[139];
u1(-pi/128) q[139];
cx q[145],q[139];
u1(pi/128) q[139];
u1(pi/64) q[145];
cx q[145],q[140];
u1(-pi/64) q[140];
cx q[145],q[140];
u1(pi/64) q[140];
u1(pi/32) q[145];
cx q[145],q[141];
u1(-pi/32) q[141];
cx q[145],q[141];
u1(pi/32) q[141];
u1(pi/16) q[145];
cx q[145],q[142];
u1(-pi/16) q[142];
cx q[145],q[142];
u1(pi/16) q[142];
u1(pi/8) q[145];
cx q[145],q[143];
u1(-pi/8) q[143];
cx q[145],q[143];
u1(pi/8) q[143];
u1(pi/4) q[145];
cx q[145],q[144];
u1(-pi/4) q[144];
cx q[145],q[144];
u1(pi/4) q[144];
h q[145];
u1(0) q[146];
cx q[146],q[0];
u1(0) q[0];
cx q[146],q[0];
u1(0) q[0];
u1(0) q[146];
cx q[146],q[1];
u1(0) q[1];
cx q[146],q[1];
u1(0) q[1];
u1(0) q[146];
cx q[146],q[2];
u1(0) q[2];
cx q[146],q[2];
u1(0) q[2];
u1(0) q[146];
cx q[146],q[3];
u1(0) q[3];
cx q[146],q[3];
u1(0) q[3];
u1(0) q[146];
cx q[146],q[4];
u1(0) q[4];
cx q[146],q[4];
u1(0) q[4];
u1(0) q[146];
cx q[146],q[5];
u1(0) q[5];
cx q[146],q[5];
u1(0) q[5];
u1(0) q[146];
cx q[146],q[6];
u1(0) q[6];
cx q[146],q[6];
u1(0) q[6];
u1(0) q[146];
cx q[146],q[7];
u1(0) q[7];
cx q[146],q[7];
u1(0) q[7];
u1(0) q[146];
cx q[146],q[8];
u1(0) q[8];
cx q[146],q[8];
u1(0) q[8];
u1(0) q[146];
cx q[146],q[9];
u1(0) q[9];
cx q[146],q[9];
u1(0) q[9];
u1(0) q[146];
cx q[146],q[10];
u1(0) q[10];
cx q[146],q[10];
u1(0) q[10];
u1(0) q[146];
cx q[146],q[11];
u1(0) q[11];
cx q[146],q[11];
u1(0) q[11];
u1(0) q[146];
cx q[146],q[12];
u1(0) q[12];
cx q[146],q[12];
u1(0) q[12];
u1(0) q[146];
cx q[146],q[13];
u1(0) q[13];
cx q[146],q[13];
u1(0) q[13];
u1(0) q[146];
cx q[146],q[14];
u1(0) q[14];
cx q[146],q[14];
u1(0) q[14];
u1(0) q[146];
cx q[146],q[15];
u1(0) q[15];
cx q[146],q[15];
u1(0) q[15];
u1(0) q[146];
cx q[146],q[16];
u1(0) q[16];
cx q[146],q[16];
u1(0) q[16];
u1(0) q[146];
cx q[146],q[17];
u1(0) q[17];
cx q[146],q[17];
u1(0) q[17];
u1(0) q[146];
cx q[146],q[18];
u1(0) q[18];
cx q[146],q[18];
u1(0) q[18];
u1(0) q[146];
cx q[146],q[19];
u1(0) q[19];
cx q[146],q[19];
u1(0) q[19];
u1(0) q[146];
cx q[146],q[20];
u1(0) q[20];
cx q[146],q[20];
u1(0) q[20];
u1(0) q[146];
cx q[146],q[21];
u1(0) q[21];
cx q[146],q[21];
u1(0) q[21];
u1(0) q[146];
cx q[146],q[22];
u1(0) q[22];
cx q[146],q[22];
u1(0) q[22];
u1(0) q[146];
cx q[146],q[23];
u1(0) q[23];
cx q[146],q[23];
u1(0) q[23];
u1(0) q[146];
cx q[146],q[24];
u1(0) q[24];
cx q[146],q[24];
u1(0) q[24];
u1(0) q[146];
cx q[146],q[25];
u1(0) q[25];
cx q[146],q[25];
u1(0) q[25];
u1(0) q[146];
cx q[146],q[26];
u1(0) q[26];
cx q[146],q[26];
u1(0) q[26];
u1(0) q[146];
cx q[146],q[27];
u1(0) q[27];
cx q[146],q[27];
u1(0) q[27];
u1(0) q[146];
cx q[146],q[28];
u1(0) q[28];
cx q[146],q[28];
u1(0) q[28];
u1(0) q[146];
cx q[146],q[29];
u1(0) q[29];
cx q[146],q[29];
u1(0) q[29];
u1(0) q[146];
cx q[146],q[30];
u1(0) q[30];
cx q[146],q[30];
u1(0) q[30];
u1(0) q[146];
cx q[146],q[31];
u1(0) q[31];
cx q[146],q[31];
u1(0) q[31];
u1(0) q[146];
cx q[146],q[32];
u1(0) q[32];
cx q[146],q[32];
u1(0) q[32];
u1(0) q[146];
cx q[146],q[33];
u1(0) q[33];
cx q[146],q[33];
u1(0) q[33];
u1(0) q[146];
cx q[146],q[34];
u1(0) q[34];
cx q[146],q[34];
u1(0) q[34];
u1(0) q[146];
cx q[146],q[35];
u1(0) q[35];
cx q[146],q[35];
u1(0) q[35];
u1(0) q[146];
cx q[146],q[36];
u1(0) q[36];
cx q[146],q[36];
u1(0) q[36];
u1(0) q[146];
cx q[146],q[37];
u1(0) q[37];
cx q[146],q[37];
u1(0) q[37];
u1(0) q[146];
cx q[146],q[38];
u1(0) q[38];
cx q[146],q[38];
u1(0) q[38];
u1(0) q[146];
cx q[146],q[39];
u1(0) q[39];
cx q[146],q[39];
u1(0) q[39];
u1(0) q[146];
cx q[146],q[40];
u1(0) q[40];
cx q[146],q[40];
u1(0) q[40];
u1(0) q[146];
cx q[146],q[41];
u1(0) q[41];
cx q[146],q[41];
u1(0) q[41];
u1(0) q[146];
cx q[146],q[42];
u1(0) q[42];
cx q[146],q[42];
u1(0) q[42];
u1(0) q[146];
cx q[146],q[43];
u1(0) q[43];
cx q[146],q[43];
u1(0) q[43];
u1(0) q[146];
cx q[146],q[44];
u1(0) q[44];
cx q[146],q[44];
u1(0) q[44];
u1(0) q[146];
cx q[146],q[45];
u1(0) q[45];
cx q[146],q[45];
u1(0) q[45];
u1(0) q[146];
cx q[146],q[46];
u1(0) q[46];
cx q[146],q[46];
u1(0) q[46];
u1(0) q[146];
cx q[146],q[47];
u1(0) q[47];
cx q[146],q[47];
u1(0) q[47];
u1(0) q[146];
cx q[146],q[48];
u1(0) q[48];
cx q[146],q[48];
u1(0) q[48];
u1(0) q[146];
cx q[146],q[49];
u1(0) q[49];
cx q[146],q[49];
u1(0) q[49];
u1(0) q[146];
cx q[146],q[50];
u1(0) q[50];
cx q[146],q[50];
u1(0) q[50];
u1(0) q[146];
cx q[146],q[51];
u1(0) q[51];
cx q[146],q[51];
u1(0) q[51];
u1(0) q[146];
cx q[146],q[52];
u1(0) q[52];
cx q[146],q[52];
u1(0) q[52];
u1(0) q[146];
cx q[146],q[53];
u1(0) q[53];
cx q[146],q[53];
u1(0) q[53];
u1(0) q[146];
cx q[146],q[54];
u1(0) q[54];
cx q[146],q[54];
u1(0) q[54];
u1(0) q[146];
cx q[146],q[55];
u1(0) q[55];
cx q[146],q[55];
u1(0) q[55];
u1(0) q[146];
cx q[146],q[56];
u1(0) q[56];
cx q[146],q[56];
u1(0) q[56];
u1(0) q[146];
cx q[146],q[57];
u1(0) q[57];
cx q[146],q[57];
u1(0) q[57];
u1(0) q[146];
cx q[146],q[58];
u1(0) q[58];
cx q[146],q[58];
u1(0) q[58];
u1(0) q[146];
cx q[146],q[59];
u1(0) q[59];
cx q[146],q[59];
u1(0) q[59];
u1(0) q[146];
cx q[146],q[60];
u1(0) q[60];
cx q[146],q[60];
u1(0) q[60];
u1(0) q[146];
cx q[146],q[61];
u1(0) q[61];
cx q[146],q[61];
u1(0) q[61];
u1(0) q[146];
cx q[146],q[62];
u1(0) q[62];
cx q[146],q[62];
u1(0) q[62];
u1(0) q[146];
cx q[146],q[63];
u1(0) q[63];
cx q[146],q[63];
u1(0) q[63];
u1(0) q[146];
cx q[146],q[64];
u1(0) q[64];
cx q[146],q[64];
u1(0) q[64];
u1(0) q[146];
cx q[146],q[65];
u1(0) q[65];
cx q[146],q[65];
u1(0) q[65];
u1(0) q[146];
cx q[146],q[66];
u1(0) q[66];
cx q[146],q[66];
u1(0) q[66];
u1(0) q[146];
cx q[146],q[67];
u1(0) q[67];
cx q[146],q[67];
u1(0) q[67];
u1(0) q[146];
cx q[146],q[68];
u1(0) q[68];
cx q[146],q[68];
u1(0) q[68];
u1(0) q[146];
cx q[146],q[69];
u1(0) q[69];
cx q[146],q[69];
u1(0) q[69];
u1(0) q[146];
cx q[146],q[70];
u1(0) q[70];
cx q[146],q[70];
u1(0) q[70];
u1(0) q[146];
cx q[146],q[71];
u1(0) q[71];
cx q[146],q[71];
u1(0) q[71];
u1(0) q[146];
cx q[146],q[72];
u1(0) q[72];
cx q[146],q[72];
u1(0) q[72];
u1(0) q[146];
cx q[146],q[73];
u1(0) q[73];
cx q[146],q[73];
u1(0) q[73];
u1(0) q[146];
cx q[146],q[74];
u1(0) q[74];
cx q[146],q[74];
u1(0) q[74];
u1(0) q[146];
cx q[146],q[75];
u1(0) q[75];
cx q[146],q[75];
u1(0) q[75];
u1(0) q[146];
cx q[146],q[76];
u1(0) q[76];
cx q[146],q[76];
u1(0) q[76];
u1(0) q[146];
cx q[146],q[77];
u1(0) q[77];
cx q[146],q[77];
u1(0) q[77];
u1(0) q[146];
cx q[146],q[78];
u1(0) q[78];
cx q[146],q[78];
u1(0) q[78];
u1(0) q[146];
cx q[146],q[79];
u1(0) q[79];
cx q[146],q[79];
u1(0) q[79];
u1(0) q[146];
cx q[146],q[80];
u1(0) q[80];
cx q[146],q[80];
u1(0) q[80];
u1(0) q[146];
cx q[146],q[81];
u1(0) q[81];
cx q[146],q[81];
u1(0) q[81];
u1(0) q[146];
cx q[146],q[82];
u1(0) q[82];
cx q[146],q[82];
u1(0) q[82];
u1(0) q[146];
cx q[146],q[83];
u1(0) q[83];
cx q[146],q[83];
u1(0) q[83];
u1(0) q[146];
cx q[146],q[84];
u1(0) q[84];
cx q[146],q[84];
u1(0) q[84];
u1(0) q[146];
cx q[146],q[85];
u1(0) q[85];
cx q[146],q[85];
u1(0) q[85];
u1(0) q[146];
cx q[146],q[86];
u1(0) q[86];
cx q[146],q[86];
u1(0) q[86];
u1(0) q[146];
cx q[146],q[87];
u1(0) q[87];
cx q[146],q[87];
u1(0) q[87];
u1(0) q[146];
cx q[146],q[88];
u1(0) q[88];
cx q[146],q[88];
u1(0) q[88];
u1(0) q[146];
cx q[146],q[89];
u1(0) q[89];
cx q[146],q[89];
u1(0) q[89];
u1(0) q[146];
cx q[146],q[90];
u1(0) q[90];
cx q[146],q[90];
u1(0) q[90];
u1(0) q[146];
cx q[146],q[91];
u1(0) q[91];
cx q[146],q[91];
u1(0) q[91];
u1(0) q[146];
cx q[146],q[92];
u1(0) q[92];
cx q[146],q[92];
u1(0) q[92];
u1(0) q[146];
cx q[146],q[93];
u1(0) q[93];
cx q[146],q[93];
u1(0) q[93];
u1(0) q[146];
cx q[146],q[94];
u1(0) q[94];
cx q[146],q[94];
u1(0) q[94];
u1(0) q[146];
cx q[146],q[95];
u1(0) q[95];
cx q[146],q[95];
u1(0) q[95];
u1(0) q[146];
cx q[146],q[96];
u1(0) q[96];
cx q[146],q[96];
u1(0) q[96];
u1(0) q[146];
cx q[146],q[97];
u1(0) q[97];
cx q[146],q[97];
u1(0) q[97];
u1(0) q[146];
cx q[146],q[98];
u1(0) q[98];
cx q[146],q[98];
u1(0) q[98];
u1(pi/281474976710656) q[146];
cx q[146],q[99];
u1(-pi/281474976710656) q[99];
cx q[146],q[99];
u1(pi/281474976710656) q[99];
u1(pi/140737488355328) q[146];
cx q[146],q[100];
u1(-pi/140737488355328) q[100];
cx q[146],q[100];
u1(pi/140737488355328) q[100];
u1(pi/70368744177664) q[146];
cx q[146],q[101];
u1(-pi/70368744177664) q[101];
cx q[146],q[101];
u1(pi/70368744177664) q[101];
u1(pi/35184372088832) q[146];
cx q[146],q[102];
u1(-pi/35184372088832) q[102];
cx q[146],q[102];
u1(pi/35184372088832) q[102];
u1(pi/17592186044416) q[146];
cx q[146],q[103];
u1(-pi/17592186044416) q[103];
cx q[146],q[103];
u1(pi/17592186044416) q[103];
u1(pi/8796093022208) q[146];
cx q[146],q[104];
u1(-pi/8796093022208) q[104];
cx q[146],q[104];
u1(pi/8796093022208) q[104];
u1(pi/4398046511104) q[146];
cx q[146],q[105];
u1(-pi/4398046511104) q[105];
cx q[146],q[105];
u1(pi/4398046511104) q[105];
u1(pi/2199023255552) q[146];
cx q[146],q[106];
u1(-pi/2199023255552) q[106];
cx q[146],q[106];
u1(pi/2199023255552) q[106];
u1(pi/1099511627776) q[146];
cx q[146],q[107];
u1(-pi/1099511627776) q[107];
cx q[146],q[107];
u1(pi/1099511627776) q[107];
u1(pi/549755813888) q[146];
cx q[146],q[108];
u1(-pi/549755813888) q[108];
cx q[146],q[108];
u1(pi/549755813888) q[108];
u1(pi/274877906944) q[146];
cx q[146],q[109];
u1(-pi/274877906944) q[109];
cx q[146],q[109];
u1(pi/274877906944) q[109];
u1(pi/137438953472) q[146];
cx q[146],q[110];
u1(-pi/137438953472) q[110];
cx q[146],q[110];
u1(pi/137438953472) q[110];
u1(pi/68719476736) q[146];
cx q[146],q[111];
u1(-pi/68719476736) q[111];
cx q[146],q[111];
u1(pi/68719476736) q[111];
u1(pi/34359738368) q[146];
cx q[146],q[112];
u1(-pi/34359738368) q[112];
cx q[146],q[112];
u1(pi/34359738368) q[112];
u1(pi/17179869184) q[146];
cx q[146],q[113];
u1(-pi/17179869184) q[113];
cx q[146],q[113];
u1(pi/17179869184) q[113];
u1(pi/8589934592) q[146];
cx q[146],q[114];
u1(-pi/8589934592) q[114];
cx q[146],q[114];
u1(pi/8589934592) q[114];
u1(pi/4294967296) q[146];
cx q[146],q[115];
u1(-pi/4294967296) q[115];
cx q[146],q[115];
u1(pi/4294967296) q[115];
u1(pi/2147483648) q[146];
cx q[146],q[116];
u1(-pi/2147483648) q[116];
cx q[146],q[116];
u1(pi/2147483648) q[116];
u1(pi/1073741824) q[146];
cx q[146],q[117];
u1(-pi/1073741824) q[117];
cx q[146],q[117];
u1(pi/1073741824) q[117];
u1(pi/536870912) q[146];
cx q[146],q[118];
u1(-pi/536870912) q[118];
cx q[146],q[118];
u1(pi/536870912) q[118];
u1(pi/268435456) q[146];
cx q[146],q[119];
u1(-pi/268435456) q[119];
cx q[146],q[119];
u1(pi/268435456) q[119];
u1(pi/134217728) q[146];
cx q[146],q[120];
u1(-pi/134217728) q[120];
cx q[146],q[120];
u1(pi/134217728) q[120];
u1(pi/67108864) q[146];
cx q[146],q[121];
u1(-pi/67108864) q[121];
cx q[146],q[121];
u1(pi/67108864) q[121];
u1(pi/33554432) q[146];
cx q[146],q[122];
u1(-pi/33554432) q[122];
cx q[146],q[122];
u1(pi/33554432) q[122];
u1(pi/16777216) q[146];
cx q[146],q[123];
u1(-pi/16777216) q[123];
cx q[146],q[123];
u1(pi/16777216) q[123];
u1(pi/8388608) q[146];
cx q[146],q[124];
u1(-pi/8388608) q[124];
cx q[146],q[124];
u1(pi/8388608) q[124];
u1(pi/4194304) q[146];
cx q[146],q[125];
u1(-pi/4194304) q[125];
cx q[146],q[125];
u1(pi/4194304) q[125];
u1(pi/2097152) q[146];
cx q[146],q[126];
u1(-pi/2097152) q[126];
cx q[146],q[126];
u1(pi/2097152) q[126];
u1(pi/1048576) q[146];
cx q[146],q[127];
u1(-pi/1048576) q[127];
cx q[146],q[127];
u1(pi/1048576) q[127];
u1(pi/524288) q[146];
cx q[146],q[128];
u1(-pi/524288) q[128];
cx q[146],q[128];
u1(pi/524288) q[128];
u1(pi/262144) q[146];
cx q[146],q[129];
u1(-pi/262144) q[129];
cx q[146],q[129];
u1(pi/262144) q[129];
u1(pi/131072) q[146];
cx q[146],q[130];
u1(-pi/131072) q[130];
cx q[146],q[130];
u1(pi/131072) q[130];
u1(pi/65536) q[146];
cx q[146],q[131];
u1(-pi/65536) q[131];
cx q[146],q[131];
u1(pi/65536) q[131];
u1(pi/32768) q[146];
cx q[146],q[132];
u1(-pi/32768) q[132];
cx q[146],q[132];
u1(pi/32768) q[132];
u1(pi/16384) q[146];
cx q[146],q[133];
u1(-pi/16384) q[133];
cx q[146],q[133];
u1(pi/16384) q[133];
u1(pi/8192) q[146];
cx q[146],q[134];
u1(-pi/8192) q[134];
cx q[146],q[134];
u1(pi/8192) q[134];
u1(pi/4096) q[146];
cx q[146],q[135];
u1(-pi/4096) q[135];
cx q[146],q[135];
u1(pi/4096) q[135];
u1(pi/2048) q[146];
cx q[146],q[136];
u1(-pi/2048) q[136];
cx q[146],q[136];
u1(pi/2048) q[136];
u1(pi/1024) q[146];
cx q[146],q[137];
u1(-pi/1024) q[137];
cx q[146],q[137];
u1(pi/1024) q[137];
u1(pi/512) q[146];
cx q[146],q[138];
u1(-pi/512) q[138];
cx q[146],q[138];
u1(pi/512) q[138];
u1(pi/256) q[146];
cx q[146],q[139];
u1(-pi/256) q[139];
cx q[146],q[139];
u1(pi/256) q[139];
u1(pi/128) q[146];
cx q[146],q[140];
u1(-pi/128) q[140];
cx q[146],q[140];
u1(pi/128) q[140];
u1(pi/64) q[146];
cx q[146],q[141];
u1(-pi/64) q[141];
cx q[146],q[141];
u1(pi/64) q[141];
u1(pi/32) q[146];
cx q[146],q[142];
u1(-pi/32) q[142];
cx q[146],q[142];
u1(pi/32) q[142];
u1(pi/16) q[146];
cx q[146],q[143];
u1(-pi/16) q[143];
cx q[146],q[143];
u1(pi/16) q[143];
u1(pi/8) q[146];
cx q[146],q[144];
u1(-pi/8) q[144];
cx q[146],q[144];
u1(pi/8) q[144];
u1(pi/4) q[146];
cx q[146],q[145];
u1(-pi/4) q[145];
cx q[146],q[145];
u1(pi/4) q[145];
h q[146];
u1(0) q[147];
cx q[147],q[0];
u1(0) q[0];
cx q[147],q[0];
u1(0) q[0];
u1(0) q[147];
cx q[147],q[1];
u1(0) q[1];
cx q[147],q[1];
u1(0) q[1];
u1(0) q[147];
cx q[147],q[2];
u1(0) q[2];
cx q[147],q[2];
u1(0) q[2];
u1(0) q[147];
cx q[147],q[3];
u1(0) q[3];
cx q[147],q[3];
u1(0) q[3];
u1(0) q[147];
cx q[147],q[4];
u1(0) q[4];
cx q[147],q[4];
u1(0) q[4];
u1(0) q[147];
cx q[147],q[5];
u1(0) q[5];
cx q[147],q[5];
u1(0) q[5];
u1(0) q[147];
cx q[147],q[6];
u1(0) q[6];
cx q[147],q[6];
u1(0) q[6];
u1(0) q[147];
cx q[147],q[7];
u1(0) q[7];
cx q[147],q[7];
u1(0) q[7];
u1(0) q[147];
cx q[147],q[8];
u1(0) q[8];
cx q[147],q[8];
u1(0) q[8];
u1(0) q[147];
cx q[147],q[9];
u1(0) q[9];
cx q[147],q[9];
u1(0) q[9];
u1(0) q[147];
cx q[147],q[10];
u1(0) q[10];
cx q[147],q[10];
u1(0) q[10];
u1(0) q[147];
cx q[147],q[11];
u1(0) q[11];
cx q[147],q[11];
u1(0) q[11];
u1(0) q[147];
cx q[147],q[12];
u1(0) q[12];
cx q[147],q[12];
u1(0) q[12];
u1(0) q[147];
cx q[147],q[13];
u1(0) q[13];
cx q[147],q[13];
u1(0) q[13];
u1(0) q[147];
cx q[147],q[14];
u1(0) q[14];
cx q[147],q[14];
u1(0) q[14];
u1(0) q[147];
cx q[147],q[15];
u1(0) q[15];
cx q[147],q[15];
u1(0) q[15];
u1(0) q[147];
cx q[147],q[16];
u1(0) q[16];
cx q[147],q[16];
u1(0) q[16];
u1(0) q[147];
cx q[147],q[17];
u1(0) q[17];
cx q[147],q[17];
u1(0) q[17];
u1(0) q[147];
cx q[147],q[18];
u1(0) q[18];
cx q[147],q[18];
u1(0) q[18];
u1(0) q[147];
cx q[147],q[19];
u1(0) q[19];
cx q[147],q[19];
u1(0) q[19];
u1(0) q[147];
cx q[147],q[20];
u1(0) q[20];
cx q[147],q[20];
u1(0) q[20];
u1(0) q[147];
cx q[147],q[21];
u1(0) q[21];
cx q[147],q[21];
u1(0) q[21];
u1(0) q[147];
cx q[147],q[22];
u1(0) q[22];
cx q[147],q[22];
u1(0) q[22];
u1(0) q[147];
cx q[147],q[23];
u1(0) q[23];
cx q[147],q[23];
u1(0) q[23];
u1(0) q[147];
cx q[147],q[24];
u1(0) q[24];
cx q[147],q[24];
u1(0) q[24];
u1(0) q[147];
cx q[147],q[25];
u1(0) q[25];
cx q[147],q[25];
u1(0) q[25];
u1(0) q[147];
cx q[147],q[26];
u1(0) q[26];
cx q[147],q[26];
u1(0) q[26];
u1(0) q[147];
cx q[147],q[27];
u1(0) q[27];
cx q[147],q[27];
u1(0) q[27];
u1(0) q[147];
cx q[147],q[28];
u1(0) q[28];
cx q[147],q[28];
u1(0) q[28];
u1(0) q[147];
cx q[147],q[29];
u1(0) q[29];
cx q[147],q[29];
u1(0) q[29];
u1(0) q[147];
cx q[147],q[30];
u1(0) q[30];
cx q[147],q[30];
u1(0) q[30];
u1(0) q[147];
cx q[147],q[31];
u1(0) q[31];
cx q[147],q[31];
u1(0) q[31];
u1(0) q[147];
cx q[147],q[32];
u1(0) q[32];
cx q[147],q[32];
u1(0) q[32];
u1(0) q[147];
cx q[147],q[33];
u1(0) q[33];
cx q[147],q[33];
u1(0) q[33];
u1(0) q[147];
cx q[147],q[34];
u1(0) q[34];
cx q[147],q[34];
u1(0) q[34];
u1(0) q[147];
cx q[147],q[35];
u1(0) q[35];
cx q[147],q[35];
u1(0) q[35];
u1(0) q[147];
cx q[147],q[36];
u1(0) q[36];
cx q[147],q[36];
u1(0) q[36];
u1(0) q[147];
cx q[147],q[37];
u1(0) q[37];
cx q[147],q[37];
u1(0) q[37];
u1(0) q[147];
cx q[147],q[38];
u1(0) q[38];
cx q[147],q[38];
u1(0) q[38];
u1(0) q[147];
cx q[147],q[39];
u1(0) q[39];
cx q[147],q[39];
u1(0) q[39];
u1(0) q[147];
cx q[147],q[40];
u1(0) q[40];
cx q[147],q[40];
u1(0) q[40];
u1(0) q[147];
cx q[147],q[41];
u1(0) q[41];
cx q[147],q[41];
u1(0) q[41];
u1(0) q[147];
cx q[147],q[42];
u1(0) q[42];
cx q[147],q[42];
u1(0) q[42];
u1(0) q[147];
cx q[147],q[43];
u1(0) q[43];
cx q[147],q[43];
u1(0) q[43];
u1(0) q[147];
cx q[147],q[44];
u1(0) q[44];
cx q[147],q[44];
u1(0) q[44];
u1(0) q[147];
cx q[147],q[45];
u1(0) q[45];
cx q[147],q[45];
u1(0) q[45];
u1(0) q[147];
cx q[147],q[46];
u1(0) q[46];
cx q[147],q[46];
u1(0) q[46];
u1(0) q[147];
cx q[147],q[47];
u1(0) q[47];
cx q[147],q[47];
u1(0) q[47];
u1(0) q[147];
cx q[147],q[48];
u1(0) q[48];
cx q[147],q[48];
u1(0) q[48];
u1(0) q[147];
cx q[147],q[49];
u1(0) q[49];
cx q[147],q[49];
u1(0) q[49];
u1(0) q[147];
cx q[147],q[50];
u1(0) q[50];
cx q[147],q[50];
u1(0) q[50];
u1(0) q[147];
cx q[147],q[51];
u1(0) q[51];
cx q[147],q[51];
u1(0) q[51];
u1(0) q[147];
cx q[147],q[52];
u1(0) q[52];
cx q[147],q[52];
u1(0) q[52];
u1(0) q[147];
cx q[147],q[53];
u1(0) q[53];
cx q[147],q[53];
u1(0) q[53];
u1(0) q[147];
cx q[147],q[54];
u1(0) q[54];
cx q[147],q[54];
u1(0) q[54];
u1(0) q[147];
cx q[147],q[55];
u1(0) q[55];
cx q[147],q[55];
u1(0) q[55];
u1(0) q[147];
cx q[147],q[56];
u1(0) q[56];
cx q[147],q[56];
u1(0) q[56];
u1(0) q[147];
cx q[147],q[57];
u1(0) q[57];
cx q[147],q[57];
u1(0) q[57];
u1(0) q[147];
cx q[147],q[58];
u1(0) q[58];
cx q[147],q[58];
u1(0) q[58];
u1(0) q[147];
cx q[147],q[59];
u1(0) q[59];
cx q[147],q[59];
u1(0) q[59];
u1(0) q[147];
cx q[147],q[60];
u1(0) q[60];
cx q[147],q[60];
u1(0) q[60];
u1(0) q[147];
cx q[147],q[61];
u1(0) q[61];
cx q[147],q[61];
u1(0) q[61];
u1(0) q[147];
cx q[147],q[62];
u1(0) q[62];
cx q[147],q[62];
u1(0) q[62];
u1(0) q[147];
cx q[147],q[63];
u1(0) q[63];
cx q[147],q[63];
u1(0) q[63];
u1(0) q[147];
cx q[147],q[64];
u1(0) q[64];
cx q[147],q[64];
u1(0) q[64];
u1(0) q[147];
cx q[147],q[65];
u1(0) q[65];
cx q[147],q[65];
u1(0) q[65];
u1(0) q[147];
cx q[147],q[66];
u1(0) q[66];
cx q[147],q[66];
u1(0) q[66];
u1(0) q[147];
cx q[147],q[67];
u1(0) q[67];
cx q[147],q[67];
u1(0) q[67];
u1(0) q[147];
cx q[147],q[68];
u1(0) q[68];
cx q[147],q[68];
u1(0) q[68];
u1(0) q[147];
cx q[147],q[69];
u1(0) q[69];
cx q[147],q[69];
u1(0) q[69];
u1(0) q[147];
cx q[147],q[70];
u1(0) q[70];
cx q[147],q[70];
u1(0) q[70];
u1(0) q[147];
cx q[147],q[71];
u1(0) q[71];
cx q[147],q[71];
u1(0) q[71];
u1(0) q[147];
cx q[147],q[72];
u1(0) q[72];
cx q[147],q[72];
u1(0) q[72];
u1(0) q[147];
cx q[147],q[73];
u1(0) q[73];
cx q[147],q[73];
u1(0) q[73];
u1(0) q[147];
cx q[147],q[74];
u1(0) q[74];
cx q[147],q[74];
u1(0) q[74];
u1(0) q[147];
cx q[147],q[75];
u1(0) q[75];
cx q[147],q[75];
u1(0) q[75];
u1(0) q[147];
cx q[147],q[76];
u1(0) q[76];
cx q[147],q[76];
u1(0) q[76];
u1(0) q[147];
cx q[147],q[77];
u1(0) q[77];
cx q[147],q[77];
u1(0) q[77];
u1(0) q[147];
cx q[147],q[78];
u1(0) q[78];
cx q[147],q[78];
u1(0) q[78];
u1(0) q[147];
cx q[147],q[79];
u1(0) q[79];
cx q[147],q[79];
u1(0) q[79];
u1(0) q[147];
cx q[147],q[80];
u1(0) q[80];
cx q[147],q[80];
u1(0) q[80];
u1(0) q[147];
cx q[147],q[81];
u1(0) q[81];
cx q[147],q[81];
u1(0) q[81];
u1(0) q[147];
cx q[147],q[82];
u1(0) q[82];
cx q[147],q[82];
u1(0) q[82];
u1(0) q[147];
cx q[147],q[83];
u1(0) q[83];
cx q[147],q[83];
u1(0) q[83];
u1(0) q[147];
cx q[147],q[84];
u1(0) q[84];
cx q[147],q[84];
u1(0) q[84];
u1(0) q[147];
cx q[147],q[85];
u1(0) q[85];
cx q[147],q[85];
u1(0) q[85];
u1(0) q[147];
cx q[147],q[86];
u1(0) q[86];
cx q[147],q[86];
u1(0) q[86];
u1(0) q[147];
cx q[147],q[87];
u1(0) q[87];
cx q[147],q[87];
u1(0) q[87];
u1(0) q[147];
cx q[147],q[88];
u1(0) q[88];
cx q[147],q[88];
u1(0) q[88];
u1(0) q[147];
cx q[147],q[89];
u1(0) q[89];
cx q[147],q[89];
u1(0) q[89];
u1(0) q[147];
cx q[147],q[90];
u1(0) q[90];
cx q[147],q[90];
u1(0) q[90];
u1(0) q[147];
cx q[147],q[91];
u1(0) q[91];
cx q[147],q[91];
u1(0) q[91];
u1(0) q[147];
cx q[147],q[92];
u1(0) q[92];
cx q[147],q[92];
u1(0) q[92];
u1(0) q[147];
cx q[147],q[93];
u1(0) q[93];
cx q[147],q[93];
u1(0) q[93];
u1(0) q[147];
cx q[147],q[94];
u1(0) q[94];
cx q[147],q[94];
u1(0) q[94];
u1(0) q[147];
cx q[147],q[95];
u1(0) q[95];
cx q[147],q[95];
u1(0) q[95];
u1(0) q[147];
cx q[147],q[96];
u1(0) q[96];
cx q[147],q[96];
u1(0) q[96];
u1(0) q[147];
cx q[147],q[97];
u1(0) q[97];
cx q[147],q[97];
u1(0) q[97];
u1(0) q[147];
cx q[147],q[98];
u1(0) q[98];
cx q[147],q[98];
u1(0) q[98];
u1(0) q[147];
cx q[147],q[99];
u1(0) q[99];
cx q[147],q[99];
u1(0) q[99];
u1(pi/281474976710656) q[147];
cx q[147],q[100];
u1(-pi/281474976710656) q[100];
cx q[147],q[100];
u1(pi/281474976710656) q[100];
u1(pi/140737488355328) q[147];
cx q[147],q[101];
u1(-pi/140737488355328) q[101];
cx q[147],q[101];
u1(pi/140737488355328) q[101];
u1(pi/70368744177664) q[147];
cx q[147],q[102];
u1(-pi/70368744177664) q[102];
cx q[147],q[102];
u1(pi/70368744177664) q[102];
u1(pi/35184372088832) q[147];
cx q[147],q[103];
u1(-pi/35184372088832) q[103];
cx q[147],q[103];
u1(pi/35184372088832) q[103];
u1(pi/17592186044416) q[147];
cx q[147],q[104];
u1(-pi/17592186044416) q[104];
cx q[147],q[104];
u1(pi/17592186044416) q[104];
u1(pi/8796093022208) q[147];
cx q[147],q[105];
u1(-pi/8796093022208) q[105];
cx q[147],q[105];
u1(pi/8796093022208) q[105];
u1(pi/4398046511104) q[147];
cx q[147],q[106];
u1(-pi/4398046511104) q[106];
cx q[147],q[106];
u1(pi/4398046511104) q[106];
u1(pi/2199023255552) q[147];
cx q[147],q[107];
u1(-pi/2199023255552) q[107];
cx q[147],q[107];
u1(pi/2199023255552) q[107];
u1(pi/1099511627776) q[147];
cx q[147],q[108];
u1(-pi/1099511627776) q[108];
cx q[147],q[108];
u1(pi/1099511627776) q[108];
u1(pi/549755813888) q[147];
cx q[147],q[109];
u1(-pi/549755813888) q[109];
cx q[147],q[109];
u1(pi/549755813888) q[109];
u1(pi/274877906944) q[147];
cx q[147],q[110];
u1(-pi/274877906944) q[110];
cx q[147],q[110];
u1(pi/274877906944) q[110];
u1(pi/137438953472) q[147];
cx q[147],q[111];
u1(-pi/137438953472) q[111];
cx q[147],q[111];
u1(pi/137438953472) q[111];
u1(pi/68719476736) q[147];
cx q[147],q[112];
u1(-pi/68719476736) q[112];
cx q[147],q[112];
u1(pi/68719476736) q[112];
u1(pi/34359738368) q[147];
cx q[147],q[113];
u1(-pi/34359738368) q[113];
cx q[147],q[113];
u1(pi/34359738368) q[113];
u1(pi/17179869184) q[147];
cx q[147],q[114];
u1(-pi/17179869184) q[114];
cx q[147],q[114];
u1(pi/17179869184) q[114];
u1(pi/8589934592) q[147];
cx q[147],q[115];
u1(-pi/8589934592) q[115];
cx q[147],q[115];
u1(pi/8589934592) q[115];
u1(pi/4294967296) q[147];
cx q[147],q[116];
u1(-pi/4294967296) q[116];
cx q[147],q[116];
u1(pi/4294967296) q[116];
u1(pi/2147483648) q[147];
cx q[147],q[117];
u1(-pi/2147483648) q[117];
cx q[147],q[117];
u1(pi/2147483648) q[117];
u1(pi/1073741824) q[147];
cx q[147],q[118];
u1(-pi/1073741824) q[118];
cx q[147],q[118];
u1(pi/1073741824) q[118];
u1(pi/536870912) q[147];
cx q[147],q[119];
u1(-pi/536870912) q[119];
cx q[147],q[119];
u1(pi/536870912) q[119];
u1(pi/268435456) q[147];
cx q[147],q[120];
u1(-pi/268435456) q[120];
cx q[147],q[120];
u1(pi/268435456) q[120];
u1(pi/134217728) q[147];
cx q[147],q[121];
u1(-pi/134217728) q[121];
cx q[147],q[121];
u1(pi/134217728) q[121];
u1(pi/67108864) q[147];
cx q[147],q[122];
u1(-pi/67108864) q[122];
cx q[147],q[122];
u1(pi/67108864) q[122];
u1(pi/33554432) q[147];
cx q[147],q[123];
u1(-pi/33554432) q[123];
cx q[147],q[123];
u1(pi/33554432) q[123];
u1(pi/16777216) q[147];
cx q[147],q[124];
u1(-pi/16777216) q[124];
cx q[147],q[124];
u1(pi/16777216) q[124];
u1(pi/8388608) q[147];
cx q[147],q[125];
u1(-pi/8388608) q[125];
cx q[147],q[125];
u1(pi/8388608) q[125];
u1(pi/4194304) q[147];
cx q[147],q[126];
u1(-pi/4194304) q[126];
cx q[147],q[126];
u1(pi/4194304) q[126];
u1(pi/2097152) q[147];
cx q[147],q[127];
u1(-pi/2097152) q[127];
cx q[147],q[127];
u1(pi/2097152) q[127];
u1(pi/1048576) q[147];
cx q[147],q[128];
u1(-pi/1048576) q[128];
cx q[147],q[128];
u1(pi/1048576) q[128];
u1(pi/524288) q[147];
cx q[147],q[129];
u1(-pi/524288) q[129];
cx q[147],q[129];
u1(pi/524288) q[129];
u1(pi/262144) q[147];
cx q[147],q[130];
u1(-pi/262144) q[130];
cx q[147],q[130];
u1(pi/262144) q[130];
u1(pi/131072) q[147];
cx q[147],q[131];
u1(-pi/131072) q[131];
cx q[147],q[131];
u1(pi/131072) q[131];
u1(pi/65536) q[147];
cx q[147],q[132];
u1(-pi/65536) q[132];
cx q[147],q[132];
u1(pi/65536) q[132];
u1(pi/32768) q[147];
cx q[147],q[133];
u1(-pi/32768) q[133];
cx q[147],q[133];
u1(pi/32768) q[133];
u1(pi/16384) q[147];
cx q[147],q[134];
u1(-pi/16384) q[134];
cx q[147],q[134];
u1(pi/16384) q[134];
u1(pi/8192) q[147];
cx q[147],q[135];
u1(-pi/8192) q[135];
cx q[147],q[135];
u1(pi/8192) q[135];
u1(pi/4096) q[147];
cx q[147],q[136];
u1(-pi/4096) q[136];
cx q[147],q[136];
u1(pi/4096) q[136];
u1(pi/2048) q[147];
cx q[147],q[137];
u1(-pi/2048) q[137];
cx q[147],q[137];
u1(pi/2048) q[137];
u1(pi/1024) q[147];
cx q[147],q[138];
u1(-pi/1024) q[138];
cx q[147],q[138];
u1(pi/1024) q[138];
u1(pi/512) q[147];
cx q[147],q[139];
u1(-pi/512) q[139];
cx q[147],q[139];
u1(pi/512) q[139];
u1(pi/256) q[147];
cx q[147],q[140];
u1(-pi/256) q[140];
cx q[147],q[140];
u1(pi/256) q[140];
u1(pi/128) q[147];
cx q[147],q[141];
u1(-pi/128) q[141];
cx q[147],q[141];
u1(pi/128) q[141];
u1(pi/64) q[147];
cx q[147],q[142];
u1(-pi/64) q[142];
cx q[147],q[142];
u1(pi/64) q[142];
u1(pi/32) q[147];
cx q[147],q[143];
u1(-pi/32) q[143];
cx q[147],q[143];
u1(pi/32) q[143];
u1(pi/16) q[147];
cx q[147],q[144];
u1(-pi/16) q[144];
cx q[147],q[144];
u1(pi/16) q[144];
u1(pi/8) q[147];
cx q[147],q[145];
u1(-pi/8) q[145];
cx q[147],q[145];
u1(pi/8) q[145];
u1(pi/4) q[147];
cx q[147],q[146];
u1(-pi/4) q[146];
cx q[147],q[146];
u1(pi/4) q[146];
h q[147];
u1(0) q[148];
cx q[148],q[0];
u1(0) q[0];
cx q[148],q[0];
u1(0) q[0];
u1(0) q[148];
cx q[148],q[1];
u1(0) q[1];
cx q[148],q[1];
u1(0) q[1];
u1(0) q[148];
cx q[148],q[2];
u1(0) q[2];
cx q[148],q[2];
u1(0) q[2];
u1(0) q[148];
cx q[148],q[3];
u1(0) q[3];
cx q[148],q[3];
u1(0) q[3];
u1(0) q[148];
cx q[148],q[4];
u1(0) q[4];
cx q[148],q[4];
u1(0) q[4];
u1(0) q[148];
cx q[148],q[5];
u1(0) q[5];
cx q[148],q[5];
u1(0) q[5];
u1(0) q[148];
cx q[148],q[6];
u1(0) q[6];
cx q[148],q[6];
u1(0) q[6];
u1(0) q[148];
cx q[148],q[7];
u1(0) q[7];
cx q[148],q[7];
u1(0) q[7];
u1(0) q[148];
cx q[148],q[8];
u1(0) q[8];
cx q[148],q[8];
u1(0) q[8];
u1(0) q[148];
cx q[148],q[9];
u1(0) q[9];
cx q[148],q[9];
u1(0) q[9];
u1(0) q[148];
cx q[148],q[10];
u1(0) q[10];
cx q[148],q[10];
u1(0) q[10];
u1(0) q[148];
cx q[148],q[11];
u1(0) q[11];
cx q[148],q[11];
u1(0) q[11];
u1(0) q[148];
cx q[148],q[12];
u1(0) q[12];
cx q[148],q[12];
u1(0) q[12];
u1(0) q[148];
cx q[148],q[13];
u1(0) q[13];
cx q[148],q[13];
u1(0) q[13];
u1(0) q[148];
cx q[148],q[14];
u1(0) q[14];
cx q[148],q[14];
u1(0) q[14];
u1(0) q[148];
cx q[148],q[15];
u1(0) q[15];
cx q[148],q[15];
u1(0) q[15];
u1(0) q[148];
cx q[148],q[16];
u1(0) q[16];
cx q[148],q[16];
u1(0) q[16];
u1(0) q[148];
cx q[148],q[17];
u1(0) q[17];
cx q[148],q[17];
u1(0) q[17];
u1(0) q[148];
cx q[148],q[18];
u1(0) q[18];
cx q[148],q[18];
u1(0) q[18];
u1(0) q[148];
cx q[148],q[19];
u1(0) q[19];
cx q[148],q[19];
u1(0) q[19];
u1(0) q[148];
cx q[148],q[20];
u1(0) q[20];
cx q[148],q[20];
u1(0) q[20];
u1(0) q[148];
cx q[148],q[21];
u1(0) q[21];
cx q[148],q[21];
u1(0) q[21];
u1(0) q[148];
cx q[148],q[22];
u1(0) q[22];
cx q[148],q[22];
u1(0) q[22];
u1(0) q[148];
cx q[148],q[23];
u1(0) q[23];
cx q[148],q[23];
u1(0) q[23];
u1(0) q[148];
cx q[148],q[24];
u1(0) q[24];
cx q[148],q[24];
u1(0) q[24];
u1(0) q[148];
cx q[148],q[25];
u1(0) q[25];
cx q[148],q[25];
u1(0) q[25];
u1(0) q[148];
cx q[148],q[26];
u1(0) q[26];
cx q[148],q[26];
u1(0) q[26];
u1(0) q[148];
cx q[148],q[27];
u1(0) q[27];
cx q[148],q[27];
u1(0) q[27];
u1(0) q[148];
cx q[148],q[28];
u1(0) q[28];
cx q[148],q[28];
u1(0) q[28];
u1(0) q[148];
cx q[148],q[29];
u1(0) q[29];
cx q[148],q[29];
u1(0) q[29];
u1(0) q[148];
cx q[148],q[30];
u1(0) q[30];
cx q[148],q[30];
u1(0) q[30];
u1(0) q[148];
cx q[148],q[31];
u1(0) q[31];
cx q[148],q[31];
u1(0) q[31];
u1(0) q[148];
cx q[148],q[32];
u1(0) q[32];
cx q[148],q[32];
u1(0) q[32];
u1(0) q[148];
cx q[148],q[33];
u1(0) q[33];
cx q[148],q[33];
u1(0) q[33];
u1(0) q[148];
cx q[148],q[34];
u1(0) q[34];
cx q[148],q[34];
u1(0) q[34];
u1(0) q[148];
cx q[148],q[35];
u1(0) q[35];
cx q[148],q[35];
u1(0) q[35];
u1(0) q[148];
cx q[148],q[36];
u1(0) q[36];
cx q[148],q[36];
u1(0) q[36];
u1(0) q[148];
cx q[148],q[37];
u1(0) q[37];
cx q[148],q[37];
u1(0) q[37];
u1(0) q[148];
cx q[148],q[38];
u1(0) q[38];
cx q[148],q[38];
u1(0) q[38];
u1(0) q[148];
cx q[148],q[39];
u1(0) q[39];
cx q[148],q[39];
u1(0) q[39];
u1(0) q[148];
cx q[148],q[40];
u1(0) q[40];
cx q[148],q[40];
u1(0) q[40];
u1(0) q[148];
cx q[148],q[41];
u1(0) q[41];
cx q[148],q[41];
u1(0) q[41];
u1(0) q[148];
cx q[148],q[42];
u1(0) q[42];
cx q[148],q[42];
u1(0) q[42];
u1(0) q[148];
cx q[148],q[43];
u1(0) q[43];
cx q[148],q[43];
u1(0) q[43];
u1(0) q[148];
cx q[148],q[44];
u1(0) q[44];
cx q[148],q[44];
u1(0) q[44];
u1(0) q[148];
cx q[148],q[45];
u1(0) q[45];
cx q[148],q[45];
u1(0) q[45];
u1(0) q[148];
cx q[148],q[46];
u1(0) q[46];
cx q[148],q[46];
u1(0) q[46];
u1(0) q[148];
cx q[148],q[47];
u1(0) q[47];
cx q[148],q[47];
u1(0) q[47];
u1(0) q[148];
cx q[148],q[48];
u1(0) q[48];
cx q[148],q[48];
u1(0) q[48];
u1(0) q[148];
cx q[148],q[49];
u1(0) q[49];
cx q[148],q[49];
u1(0) q[49];
u1(0) q[148];
cx q[148],q[50];
u1(0) q[50];
cx q[148],q[50];
u1(0) q[50];
u1(0) q[148];
cx q[148],q[51];
u1(0) q[51];
cx q[148],q[51];
u1(0) q[51];
u1(0) q[148];
cx q[148],q[52];
u1(0) q[52];
cx q[148],q[52];
u1(0) q[52];
u1(0) q[148];
cx q[148],q[53];
u1(0) q[53];
cx q[148],q[53];
u1(0) q[53];
u1(0) q[148];
cx q[148],q[54];
u1(0) q[54];
cx q[148],q[54];
u1(0) q[54];
u1(0) q[148];
cx q[148],q[55];
u1(0) q[55];
cx q[148],q[55];
u1(0) q[55];
u1(0) q[148];
cx q[148],q[56];
u1(0) q[56];
cx q[148],q[56];
u1(0) q[56];
u1(0) q[148];
cx q[148],q[57];
u1(0) q[57];
cx q[148],q[57];
u1(0) q[57];
u1(0) q[148];
cx q[148],q[58];
u1(0) q[58];
cx q[148],q[58];
u1(0) q[58];
u1(0) q[148];
cx q[148],q[59];
u1(0) q[59];
cx q[148],q[59];
u1(0) q[59];
u1(0) q[148];
cx q[148],q[60];
u1(0) q[60];
cx q[148],q[60];
u1(0) q[60];
u1(0) q[148];
cx q[148],q[61];
u1(0) q[61];
cx q[148],q[61];
u1(0) q[61];
u1(0) q[148];
cx q[148],q[62];
u1(0) q[62];
cx q[148],q[62];
u1(0) q[62];
u1(0) q[148];
cx q[148],q[63];
u1(0) q[63];
cx q[148],q[63];
u1(0) q[63];
u1(0) q[148];
cx q[148],q[64];
u1(0) q[64];
cx q[148],q[64];
u1(0) q[64];
u1(0) q[148];
cx q[148],q[65];
u1(0) q[65];
cx q[148],q[65];
u1(0) q[65];
u1(0) q[148];
cx q[148],q[66];
u1(0) q[66];
cx q[148],q[66];
u1(0) q[66];
u1(0) q[148];
cx q[148],q[67];
u1(0) q[67];
cx q[148],q[67];
u1(0) q[67];
u1(0) q[148];
cx q[148],q[68];
u1(0) q[68];
cx q[148],q[68];
u1(0) q[68];
u1(0) q[148];
cx q[148],q[69];
u1(0) q[69];
cx q[148],q[69];
u1(0) q[69];
u1(0) q[148];
cx q[148],q[70];
u1(0) q[70];
cx q[148],q[70];
u1(0) q[70];
u1(0) q[148];
cx q[148],q[71];
u1(0) q[71];
cx q[148],q[71];
u1(0) q[71];
u1(0) q[148];
cx q[148],q[72];
u1(0) q[72];
cx q[148],q[72];
u1(0) q[72];
u1(0) q[148];
cx q[148],q[73];
u1(0) q[73];
cx q[148],q[73];
u1(0) q[73];
u1(0) q[148];
cx q[148],q[74];
u1(0) q[74];
cx q[148],q[74];
u1(0) q[74];
u1(0) q[148];
cx q[148],q[75];
u1(0) q[75];
cx q[148],q[75];
u1(0) q[75];
u1(0) q[148];
cx q[148],q[76];
u1(0) q[76];
cx q[148],q[76];
u1(0) q[76];
u1(0) q[148];
cx q[148],q[77];
u1(0) q[77];
cx q[148],q[77];
u1(0) q[77];
u1(0) q[148];
cx q[148],q[78];
u1(0) q[78];
cx q[148],q[78];
u1(0) q[78];
u1(0) q[148];
cx q[148],q[79];
u1(0) q[79];
cx q[148],q[79];
u1(0) q[79];
u1(0) q[148];
cx q[148],q[80];
u1(0) q[80];
cx q[148],q[80];
u1(0) q[80];
u1(0) q[148];
cx q[148],q[81];
u1(0) q[81];
cx q[148],q[81];
u1(0) q[81];
u1(0) q[148];
cx q[148],q[82];
u1(0) q[82];
cx q[148],q[82];
u1(0) q[82];
u1(0) q[148];
cx q[148],q[83];
u1(0) q[83];
cx q[148],q[83];
u1(0) q[83];
u1(0) q[148];
cx q[148],q[84];
u1(0) q[84];
cx q[148],q[84];
u1(0) q[84];
u1(0) q[148];
cx q[148],q[85];
u1(0) q[85];
cx q[148],q[85];
u1(0) q[85];
u1(0) q[148];
cx q[148],q[86];
u1(0) q[86];
cx q[148],q[86];
u1(0) q[86];
u1(0) q[148];
cx q[148],q[87];
u1(0) q[87];
cx q[148],q[87];
u1(0) q[87];
u1(0) q[148];
cx q[148],q[88];
u1(0) q[88];
cx q[148],q[88];
u1(0) q[88];
u1(0) q[148];
cx q[148],q[89];
u1(0) q[89];
cx q[148],q[89];
u1(0) q[89];
u1(0) q[148];
cx q[148],q[90];
u1(0) q[90];
cx q[148],q[90];
u1(0) q[90];
u1(0) q[148];
cx q[148],q[91];
u1(0) q[91];
cx q[148],q[91];
u1(0) q[91];
u1(0) q[148];
cx q[148],q[92];
u1(0) q[92];
cx q[148],q[92];
u1(0) q[92];
u1(0) q[148];
cx q[148],q[93];
u1(0) q[93];
cx q[148],q[93];
u1(0) q[93];
u1(0) q[148];
cx q[148],q[94];
u1(0) q[94];
cx q[148],q[94];
u1(0) q[94];
u1(0) q[148];
cx q[148],q[95];
u1(0) q[95];
cx q[148],q[95];
u1(0) q[95];
u1(0) q[148];
cx q[148],q[96];
u1(0) q[96];
cx q[148],q[96];
u1(0) q[96];
u1(0) q[148];
cx q[148],q[97];
u1(0) q[97];
cx q[148],q[97];
u1(0) q[97];
u1(0) q[148];
cx q[148],q[98];
u1(0) q[98];
cx q[148],q[98];
u1(0) q[98];
u1(0) q[148];
cx q[148],q[99];
u1(0) q[99];
cx q[148],q[99];
u1(0) q[99];
u1(0) q[148];
cx q[148],q[100];
u1(0) q[100];
cx q[148],q[100];
u1(0) q[100];
u1(pi/281474976710656) q[148];
cx q[148],q[101];
u1(-pi/281474976710656) q[101];
cx q[148],q[101];
u1(pi/281474976710656) q[101];
u1(pi/140737488355328) q[148];
cx q[148],q[102];
u1(-pi/140737488355328) q[102];
cx q[148],q[102];
u1(pi/140737488355328) q[102];
u1(pi/70368744177664) q[148];
cx q[148],q[103];
u1(-pi/70368744177664) q[103];
cx q[148],q[103];
u1(pi/70368744177664) q[103];
u1(pi/35184372088832) q[148];
cx q[148],q[104];
u1(-pi/35184372088832) q[104];
cx q[148],q[104];
u1(pi/35184372088832) q[104];
u1(pi/17592186044416) q[148];
cx q[148],q[105];
u1(-pi/17592186044416) q[105];
cx q[148],q[105];
u1(pi/17592186044416) q[105];
u1(pi/8796093022208) q[148];
cx q[148],q[106];
u1(-pi/8796093022208) q[106];
cx q[148],q[106];
u1(pi/8796093022208) q[106];
u1(pi/4398046511104) q[148];
cx q[148],q[107];
u1(-pi/4398046511104) q[107];
cx q[148],q[107];
u1(pi/4398046511104) q[107];
u1(pi/2199023255552) q[148];
cx q[148],q[108];
u1(-pi/2199023255552) q[108];
cx q[148],q[108];
u1(pi/2199023255552) q[108];
u1(pi/1099511627776) q[148];
cx q[148],q[109];
u1(-pi/1099511627776) q[109];
cx q[148],q[109];
u1(pi/1099511627776) q[109];
u1(pi/549755813888) q[148];
cx q[148],q[110];
u1(-pi/549755813888) q[110];
cx q[148],q[110];
u1(pi/549755813888) q[110];
u1(pi/274877906944) q[148];
cx q[148],q[111];
u1(-pi/274877906944) q[111];
cx q[148],q[111];
u1(pi/274877906944) q[111];
u1(pi/137438953472) q[148];
cx q[148],q[112];
u1(-pi/137438953472) q[112];
cx q[148],q[112];
u1(pi/137438953472) q[112];
u1(pi/68719476736) q[148];
cx q[148],q[113];
u1(-pi/68719476736) q[113];
cx q[148],q[113];
u1(pi/68719476736) q[113];
u1(pi/34359738368) q[148];
cx q[148],q[114];
u1(-pi/34359738368) q[114];
cx q[148],q[114];
u1(pi/34359738368) q[114];
u1(pi/17179869184) q[148];
cx q[148],q[115];
u1(-pi/17179869184) q[115];
cx q[148],q[115];
u1(pi/17179869184) q[115];
u1(pi/8589934592) q[148];
cx q[148],q[116];
u1(-pi/8589934592) q[116];
cx q[148],q[116];
u1(pi/8589934592) q[116];
u1(pi/4294967296) q[148];
cx q[148],q[117];
u1(-pi/4294967296) q[117];
cx q[148],q[117];
u1(pi/4294967296) q[117];
u1(pi/2147483648) q[148];
cx q[148],q[118];
u1(-pi/2147483648) q[118];
cx q[148],q[118];
u1(pi/2147483648) q[118];
u1(pi/1073741824) q[148];
cx q[148],q[119];
u1(-pi/1073741824) q[119];
cx q[148],q[119];
u1(pi/1073741824) q[119];
u1(pi/536870912) q[148];
cx q[148],q[120];
u1(-pi/536870912) q[120];
cx q[148],q[120];
u1(pi/536870912) q[120];
u1(pi/268435456) q[148];
cx q[148],q[121];
u1(-pi/268435456) q[121];
cx q[148],q[121];
u1(pi/268435456) q[121];
u1(pi/134217728) q[148];
cx q[148],q[122];
u1(-pi/134217728) q[122];
cx q[148],q[122];
u1(pi/134217728) q[122];
u1(pi/67108864) q[148];
cx q[148],q[123];
u1(-pi/67108864) q[123];
cx q[148],q[123];
u1(pi/67108864) q[123];
u1(pi/33554432) q[148];
cx q[148],q[124];
u1(-pi/33554432) q[124];
cx q[148],q[124];
u1(pi/33554432) q[124];
u1(pi/16777216) q[148];
cx q[148],q[125];
u1(-pi/16777216) q[125];
cx q[148],q[125];
u1(pi/16777216) q[125];
u1(pi/8388608) q[148];
cx q[148],q[126];
u1(-pi/8388608) q[126];
cx q[148],q[126];
u1(pi/8388608) q[126];
u1(pi/4194304) q[148];
cx q[148],q[127];
u1(-pi/4194304) q[127];
cx q[148],q[127];
u1(pi/4194304) q[127];
u1(pi/2097152) q[148];
cx q[148],q[128];
u1(-pi/2097152) q[128];
cx q[148],q[128];
u1(pi/2097152) q[128];
u1(pi/1048576) q[148];
cx q[148],q[129];
u1(-pi/1048576) q[129];
cx q[148],q[129];
u1(pi/1048576) q[129];
u1(pi/524288) q[148];
cx q[148],q[130];
u1(-pi/524288) q[130];
cx q[148],q[130];
u1(pi/524288) q[130];
u1(pi/262144) q[148];
cx q[148],q[131];
u1(-pi/262144) q[131];
cx q[148],q[131];
u1(pi/262144) q[131];
u1(pi/131072) q[148];
cx q[148],q[132];
u1(-pi/131072) q[132];
cx q[148],q[132];
u1(pi/131072) q[132];
u1(pi/65536) q[148];
cx q[148],q[133];
u1(-pi/65536) q[133];
cx q[148],q[133];
u1(pi/65536) q[133];
u1(pi/32768) q[148];
cx q[148],q[134];
u1(-pi/32768) q[134];
cx q[148],q[134];
u1(pi/32768) q[134];
u1(pi/16384) q[148];
cx q[148],q[135];
u1(-pi/16384) q[135];
cx q[148],q[135];
u1(pi/16384) q[135];
u1(pi/8192) q[148];
cx q[148],q[136];
u1(-pi/8192) q[136];
cx q[148],q[136];
u1(pi/8192) q[136];
u1(pi/4096) q[148];
cx q[148],q[137];
u1(-pi/4096) q[137];
cx q[148],q[137];
u1(pi/4096) q[137];
u1(pi/2048) q[148];
cx q[148],q[138];
u1(-pi/2048) q[138];
cx q[148],q[138];
u1(pi/2048) q[138];
u1(pi/1024) q[148];
cx q[148],q[139];
u1(-pi/1024) q[139];
cx q[148],q[139];
u1(pi/1024) q[139];
u1(pi/512) q[148];
cx q[148],q[140];
u1(-pi/512) q[140];
cx q[148],q[140];
u1(pi/512) q[140];
u1(pi/256) q[148];
cx q[148],q[141];
u1(-pi/256) q[141];
cx q[148],q[141];
u1(pi/256) q[141];
u1(pi/128) q[148];
cx q[148],q[142];
u1(-pi/128) q[142];
cx q[148],q[142];
u1(pi/128) q[142];
u1(pi/64) q[148];
cx q[148],q[143];
u1(-pi/64) q[143];
cx q[148],q[143];
u1(pi/64) q[143];
u1(pi/32) q[148];
cx q[148],q[144];
u1(-pi/32) q[144];
cx q[148],q[144];
u1(pi/32) q[144];
u1(pi/16) q[148];
cx q[148],q[145];
u1(-pi/16) q[145];
cx q[148],q[145];
u1(pi/16) q[145];
u1(pi/8) q[148];
cx q[148],q[146];
u1(-pi/8) q[146];
cx q[148],q[146];
u1(pi/8) q[146];
u1(pi/4) q[148];
cx q[148],q[147];
u1(-pi/4) q[147];
cx q[148],q[147];
u1(pi/4) q[147];
h q[148];
u1(0) q[149];
cx q[149],q[0];
u1(0) q[0];
cx q[149],q[0];
u1(0) q[0];
u1(0) q[149];
cx q[149],q[1];
u1(0) q[1];
cx q[149],q[1];
u1(0) q[1];
u1(0) q[149];
cx q[149],q[2];
u1(0) q[2];
cx q[149],q[2];
u1(0) q[2];
u1(0) q[149];
cx q[149],q[3];
u1(0) q[3];
cx q[149],q[3];
u1(0) q[3];
u1(0) q[149];
cx q[149],q[4];
u1(0) q[4];
cx q[149],q[4];
u1(0) q[4];
u1(0) q[149];
cx q[149],q[5];
u1(0) q[5];
cx q[149],q[5];
u1(0) q[5];
u1(0) q[149];
cx q[149],q[6];
u1(0) q[6];
cx q[149],q[6];
u1(0) q[6];
u1(0) q[149];
cx q[149],q[7];
u1(0) q[7];
cx q[149],q[7];
u1(0) q[7];
u1(0) q[149];
cx q[149],q[8];
u1(0) q[8];
cx q[149],q[8];
u1(0) q[8];
u1(0) q[149];
cx q[149],q[9];
u1(0) q[9];
cx q[149],q[9];
u1(0) q[9];
u1(0) q[149];
cx q[149],q[10];
u1(0) q[10];
cx q[149],q[10];
u1(0) q[10];
u1(0) q[149];
cx q[149],q[11];
u1(0) q[11];
cx q[149],q[11];
u1(0) q[11];
u1(0) q[149];
cx q[149],q[12];
u1(0) q[12];
cx q[149],q[12];
u1(0) q[12];
u1(0) q[149];
cx q[149],q[13];
u1(0) q[13];
cx q[149],q[13];
u1(0) q[13];
u1(0) q[149];
cx q[149],q[14];
u1(0) q[14];
cx q[149],q[14];
u1(0) q[14];
u1(0) q[149];
cx q[149],q[15];
u1(0) q[15];
cx q[149],q[15];
u1(0) q[15];
u1(0) q[149];
cx q[149],q[16];
u1(0) q[16];
cx q[149],q[16];
u1(0) q[16];
u1(0) q[149];
cx q[149],q[17];
u1(0) q[17];
cx q[149],q[17];
u1(0) q[17];
u1(0) q[149];
cx q[149],q[18];
u1(0) q[18];
cx q[149],q[18];
u1(0) q[18];
u1(0) q[149];
cx q[149],q[19];
u1(0) q[19];
cx q[149],q[19];
u1(0) q[19];
u1(0) q[149];
cx q[149],q[20];
u1(0) q[20];
cx q[149],q[20];
u1(0) q[20];
u1(0) q[149];
cx q[149],q[21];
u1(0) q[21];
cx q[149],q[21];
u1(0) q[21];
u1(0) q[149];
cx q[149],q[22];
u1(0) q[22];
cx q[149],q[22];
u1(0) q[22];
u1(0) q[149];
cx q[149],q[23];
u1(0) q[23];
cx q[149],q[23];
u1(0) q[23];
u1(0) q[149];
cx q[149],q[24];
u1(0) q[24];
cx q[149],q[24];
u1(0) q[24];
u1(0) q[149];
cx q[149],q[25];
u1(0) q[25];
cx q[149],q[25];
u1(0) q[25];
u1(0) q[149];
cx q[149],q[26];
u1(0) q[26];
cx q[149],q[26];
u1(0) q[26];
u1(0) q[149];
cx q[149],q[27];
u1(0) q[27];
cx q[149],q[27];
u1(0) q[27];
u1(0) q[149];
cx q[149],q[28];
u1(0) q[28];
cx q[149],q[28];
u1(0) q[28];
u1(0) q[149];
cx q[149],q[29];
u1(0) q[29];
cx q[149],q[29];
u1(0) q[29];
u1(0) q[149];
cx q[149],q[30];
u1(0) q[30];
cx q[149],q[30];
u1(0) q[30];
u1(0) q[149];
cx q[149],q[31];
u1(0) q[31];
cx q[149],q[31];
u1(0) q[31];
u1(0) q[149];
cx q[149],q[32];
u1(0) q[32];
cx q[149],q[32];
u1(0) q[32];
u1(0) q[149];
cx q[149],q[33];
u1(0) q[33];
cx q[149],q[33];
u1(0) q[33];
u1(0) q[149];
cx q[149],q[34];
u1(0) q[34];
cx q[149],q[34];
u1(0) q[34];
u1(0) q[149];
cx q[149],q[35];
u1(0) q[35];
cx q[149],q[35];
u1(0) q[35];
u1(0) q[149];
cx q[149],q[36];
u1(0) q[36];
cx q[149],q[36];
u1(0) q[36];
u1(0) q[149];
cx q[149],q[37];
u1(0) q[37];
cx q[149],q[37];
u1(0) q[37];
u1(0) q[149];
cx q[149],q[38];
u1(0) q[38];
cx q[149],q[38];
u1(0) q[38];
u1(0) q[149];
cx q[149],q[39];
u1(0) q[39];
cx q[149],q[39];
u1(0) q[39];
u1(0) q[149];
cx q[149],q[40];
u1(0) q[40];
cx q[149],q[40];
u1(0) q[40];
u1(0) q[149];
cx q[149],q[41];
u1(0) q[41];
cx q[149],q[41];
u1(0) q[41];
u1(0) q[149];
cx q[149],q[42];
u1(0) q[42];
cx q[149],q[42];
u1(0) q[42];
u1(0) q[149];
cx q[149],q[43];
u1(0) q[43];
cx q[149],q[43];
u1(0) q[43];
u1(0) q[149];
cx q[149],q[44];
u1(0) q[44];
cx q[149],q[44];
u1(0) q[44];
u1(0) q[149];
cx q[149],q[45];
u1(0) q[45];
cx q[149],q[45];
u1(0) q[45];
u1(0) q[149];
cx q[149],q[46];
u1(0) q[46];
cx q[149],q[46];
u1(0) q[46];
u1(0) q[149];
cx q[149],q[47];
u1(0) q[47];
cx q[149],q[47];
u1(0) q[47];
u1(0) q[149];
cx q[149],q[48];
u1(0) q[48];
cx q[149],q[48];
u1(0) q[48];
u1(0) q[149];
cx q[149],q[49];
u1(0) q[49];
cx q[149],q[49];
u1(0) q[49];
u1(0) q[149];
cx q[149],q[50];
u1(0) q[50];
cx q[149],q[50];
u1(0) q[50];
u1(0) q[149];
cx q[149],q[51];
u1(0) q[51];
cx q[149],q[51];
u1(0) q[51];
u1(0) q[149];
cx q[149],q[52];
u1(0) q[52];
cx q[149],q[52];
u1(0) q[52];
u1(0) q[149];
cx q[149],q[53];
u1(0) q[53];
cx q[149],q[53];
u1(0) q[53];
u1(0) q[149];
cx q[149],q[54];
u1(0) q[54];
cx q[149],q[54];
u1(0) q[54];
u1(0) q[149];
cx q[149],q[55];
u1(0) q[55];
cx q[149],q[55];
u1(0) q[55];
u1(0) q[149];
cx q[149],q[56];
u1(0) q[56];
cx q[149],q[56];
u1(0) q[56];
u1(0) q[149];
cx q[149],q[57];
u1(0) q[57];
cx q[149],q[57];
u1(0) q[57];
u1(0) q[149];
cx q[149],q[58];
u1(0) q[58];
cx q[149],q[58];
u1(0) q[58];
u1(0) q[149];
cx q[149],q[59];
u1(0) q[59];
cx q[149],q[59];
u1(0) q[59];
u1(0) q[149];
cx q[149],q[60];
u1(0) q[60];
cx q[149],q[60];
u1(0) q[60];
u1(0) q[149];
cx q[149],q[61];
u1(0) q[61];
cx q[149],q[61];
u1(0) q[61];
u1(0) q[149];
cx q[149],q[62];
u1(0) q[62];
cx q[149],q[62];
u1(0) q[62];
u1(0) q[149];
cx q[149],q[63];
u1(0) q[63];
cx q[149],q[63];
u1(0) q[63];
u1(0) q[149];
cx q[149],q[64];
u1(0) q[64];
cx q[149],q[64];
u1(0) q[64];
u1(0) q[149];
cx q[149],q[65];
u1(0) q[65];
cx q[149],q[65];
u1(0) q[65];
u1(0) q[149];
cx q[149],q[66];
u1(0) q[66];
cx q[149],q[66];
u1(0) q[66];
u1(0) q[149];
cx q[149],q[67];
u1(0) q[67];
cx q[149],q[67];
u1(0) q[67];
u1(0) q[149];
cx q[149],q[68];
u1(0) q[68];
cx q[149],q[68];
u1(0) q[68];
u1(0) q[149];
cx q[149],q[69];
u1(0) q[69];
cx q[149],q[69];
u1(0) q[69];
u1(0) q[149];
cx q[149],q[70];
u1(0) q[70];
cx q[149],q[70];
u1(0) q[70];
u1(0) q[149];
cx q[149],q[71];
u1(0) q[71];
cx q[149],q[71];
u1(0) q[71];
u1(0) q[149];
cx q[149],q[72];
u1(0) q[72];
cx q[149],q[72];
u1(0) q[72];
u1(0) q[149];
cx q[149],q[73];
u1(0) q[73];
cx q[149],q[73];
u1(0) q[73];
u1(0) q[149];
cx q[149],q[74];
u1(0) q[74];
cx q[149],q[74];
u1(0) q[74];
u1(0) q[149];
cx q[149],q[75];
u1(0) q[75];
cx q[149],q[75];
u1(0) q[75];
u1(0) q[149];
cx q[149],q[76];
u1(0) q[76];
cx q[149],q[76];
u1(0) q[76];
u1(0) q[149];
cx q[149],q[77];
u1(0) q[77];
cx q[149],q[77];
u1(0) q[77];
u1(0) q[149];
cx q[149],q[78];
u1(0) q[78];
cx q[149],q[78];
u1(0) q[78];
u1(0) q[149];
cx q[149],q[79];
u1(0) q[79];
cx q[149],q[79];
u1(0) q[79];
u1(0) q[149];
cx q[149],q[80];
u1(0) q[80];
cx q[149],q[80];
u1(0) q[80];
u1(0) q[149];
cx q[149],q[81];
u1(0) q[81];
cx q[149],q[81];
u1(0) q[81];
u1(0) q[149];
cx q[149],q[82];
u1(0) q[82];
cx q[149],q[82];
u1(0) q[82];
u1(0) q[149];
cx q[149],q[83];
u1(0) q[83];
cx q[149],q[83];
u1(0) q[83];
u1(0) q[149];
cx q[149],q[84];
u1(0) q[84];
cx q[149],q[84];
u1(0) q[84];
u1(0) q[149];
cx q[149],q[85];
u1(0) q[85];
cx q[149],q[85];
u1(0) q[85];
u1(0) q[149];
cx q[149],q[86];
u1(0) q[86];
cx q[149],q[86];
u1(0) q[86];
u1(0) q[149];
cx q[149],q[87];
u1(0) q[87];
cx q[149],q[87];
u1(0) q[87];
u1(0) q[149];
cx q[149],q[88];
u1(0) q[88];
cx q[149],q[88];
u1(0) q[88];
u1(0) q[149];
cx q[149],q[89];
u1(0) q[89];
cx q[149],q[89];
u1(0) q[89];
u1(0) q[149];
cx q[149],q[90];
u1(0) q[90];
cx q[149],q[90];
u1(0) q[90];
u1(0) q[149];
cx q[149],q[91];
u1(0) q[91];
cx q[149],q[91];
u1(0) q[91];
u1(0) q[149];
cx q[149],q[92];
u1(0) q[92];
cx q[149],q[92];
u1(0) q[92];
u1(0) q[149];
cx q[149],q[93];
u1(0) q[93];
cx q[149],q[93];
u1(0) q[93];
u1(0) q[149];
cx q[149],q[94];
u1(0) q[94];
cx q[149],q[94];
u1(0) q[94];
u1(0) q[149];
cx q[149],q[95];
u1(0) q[95];
cx q[149],q[95];
u1(0) q[95];
u1(0) q[149];
cx q[149],q[96];
u1(0) q[96];
cx q[149],q[96];
u1(0) q[96];
u1(0) q[149];
cx q[149],q[97];
u1(0) q[97];
cx q[149],q[97];
u1(0) q[97];
u1(0) q[149];
cx q[149],q[98];
u1(0) q[98];
cx q[149],q[98];
u1(0) q[98];
u1(0) q[149];
cx q[149],q[99];
u1(0) q[99];
cx q[149],q[99];
u1(0) q[99];
u1(0) q[149];
cx q[149],q[100];
u1(0) q[100];
cx q[149],q[100];
u1(0) q[100];
u1(0) q[149];
cx q[149],q[101];
u1(0) q[101];
cx q[149],q[101];
u1(0) q[101];
u1(pi/281474976710656) q[149];
cx q[149],q[102];
u1(-pi/281474976710656) q[102];
cx q[149],q[102];
u1(pi/281474976710656) q[102];
u1(pi/140737488355328) q[149];
cx q[149],q[103];
u1(-pi/140737488355328) q[103];
cx q[149],q[103];
u1(pi/140737488355328) q[103];
u1(pi/70368744177664) q[149];
cx q[149],q[104];
u1(-pi/70368744177664) q[104];
cx q[149],q[104];
u1(pi/70368744177664) q[104];
u1(pi/35184372088832) q[149];
cx q[149],q[105];
u1(-pi/35184372088832) q[105];
cx q[149],q[105];
u1(pi/35184372088832) q[105];
u1(pi/17592186044416) q[149];
cx q[149],q[106];
u1(-pi/17592186044416) q[106];
cx q[149],q[106];
u1(pi/17592186044416) q[106];
u1(pi/8796093022208) q[149];
cx q[149],q[107];
u1(-pi/8796093022208) q[107];
cx q[149],q[107];
u1(pi/8796093022208) q[107];
u1(pi/4398046511104) q[149];
cx q[149],q[108];
u1(-pi/4398046511104) q[108];
cx q[149],q[108];
u1(pi/4398046511104) q[108];
u1(pi/2199023255552) q[149];
cx q[149],q[109];
u1(-pi/2199023255552) q[109];
cx q[149],q[109];
u1(pi/2199023255552) q[109];
u1(pi/1099511627776) q[149];
cx q[149],q[110];
u1(-pi/1099511627776) q[110];
cx q[149],q[110];
u1(pi/1099511627776) q[110];
u1(pi/549755813888) q[149];
cx q[149],q[111];
u1(-pi/549755813888) q[111];
cx q[149],q[111];
u1(pi/549755813888) q[111];
u1(pi/274877906944) q[149];
cx q[149],q[112];
u1(-pi/274877906944) q[112];
cx q[149],q[112];
u1(pi/274877906944) q[112];
u1(pi/137438953472) q[149];
cx q[149],q[113];
u1(-pi/137438953472) q[113];
cx q[149],q[113];
u1(pi/137438953472) q[113];
u1(pi/68719476736) q[149];
cx q[149],q[114];
u1(-pi/68719476736) q[114];
cx q[149],q[114];
u1(pi/68719476736) q[114];
u1(pi/34359738368) q[149];
cx q[149],q[115];
u1(-pi/34359738368) q[115];
cx q[149],q[115];
u1(pi/34359738368) q[115];
u1(pi/17179869184) q[149];
cx q[149],q[116];
u1(-pi/17179869184) q[116];
cx q[149],q[116];
u1(pi/17179869184) q[116];
u1(pi/8589934592) q[149];
cx q[149],q[117];
u1(-pi/8589934592) q[117];
cx q[149],q[117];
u1(pi/8589934592) q[117];
u1(pi/4294967296) q[149];
cx q[149],q[118];
u1(-pi/4294967296) q[118];
cx q[149],q[118];
u1(pi/4294967296) q[118];
u1(pi/2147483648) q[149];
cx q[149],q[119];
u1(-pi/2147483648) q[119];
cx q[149],q[119];
u1(pi/2147483648) q[119];
u1(pi/1073741824) q[149];
cx q[149],q[120];
u1(-pi/1073741824) q[120];
cx q[149],q[120];
u1(pi/1073741824) q[120];
u1(pi/536870912) q[149];
cx q[149],q[121];
u1(-pi/536870912) q[121];
cx q[149],q[121];
u1(pi/536870912) q[121];
u1(pi/268435456) q[149];
cx q[149],q[122];
u1(-pi/268435456) q[122];
cx q[149],q[122];
u1(pi/268435456) q[122];
u1(pi/134217728) q[149];
cx q[149],q[123];
u1(-pi/134217728) q[123];
cx q[149],q[123];
u1(pi/134217728) q[123];
u1(pi/67108864) q[149];
cx q[149],q[124];
u1(-pi/67108864) q[124];
cx q[149],q[124];
u1(pi/67108864) q[124];
u1(pi/33554432) q[149];
cx q[149],q[125];
u1(-pi/33554432) q[125];
cx q[149],q[125];
u1(pi/33554432) q[125];
u1(pi/16777216) q[149];
cx q[149],q[126];
u1(-pi/16777216) q[126];
cx q[149],q[126];
u1(pi/16777216) q[126];
u1(pi/8388608) q[149];
cx q[149],q[127];
u1(-pi/8388608) q[127];
cx q[149],q[127];
u1(pi/8388608) q[127];
u1(pi/4194304) q[149];
cx q[149],q[128];
u1(-pi/4194304) q[128];
cx q[149],q[128];
u1(pi/4194304) q[128];
u1(pi/2097152) q[149];
cx q[149],q[129];
u1(-pi/2097152) q[129];
cx q[149],q[129];
u1(pi/2097152) q[129];
u1(pi/1048576) q[149];
cx q[149],q[130];
u1(-pi/1048576) q[130];
cx q[149],q[130];
u1(pi/1048576) q[130];
u1(pi/524288) q[149];
cx q[149],q[131];
u1(-pi/524288) q[131];
cx q[149],q[131];
u1(pi/524288) q[131];
u1(pi/262144) q[149];
cx q[149],q[132];
u1(-pi/262144) q[132];
cx q[149],q[132];
u1(pi/262144) q[132];
u1(pi/131072) q[149];
cx q[149],q[133];
u1(-pi/131072) q[133];
cx q[149],q[133];
u1(pi/131072) q[133];
u1(pi/65536) q[149];
cx q[149],q[134];
u1(-pi/65536) q[134];
cx q[149],q[134];
u1(pi/65536) q[134];
u1(pi/32768) q[149];
cx q[149],q[135];
u1(-pi/32768) q[135];
cx q[149],q[135];
u1(pi/32768) q[135];
u1(pi/16384) q[149];
cx q[149],q[136];
u1(-pi/16384) q[136];
cx q[149],q[136];
u1(pi/16384) q[136];
u1(pi/8192) q[149];
cx q[149],q[137];
u1(-pi/8192) q[137];
cx q[149],q[137];
u1(pi/8192) q[137];
u1(pi/4096) q[149];
cx q[149],q[138];
u1(-pi/4096) q[138];
cx q[149],q[138];
u1(pi/4096) q[138];
u1(pi/2048) q[149];
cx q[149],q[139];
u1(-pi/2048) q[139];
cx q[149],q[139];
u1(pi/2048) q[139];
u1(pi/1024) q[149];
cx q[149],q[140];
u1(-pi/1024) q[140];
cx q[149],q[140];
u1(pi/1024) q[140];
u1(pi/512) q[149];
cx q[149],q[141];
u1(-pi/512) q[141];
cx q[149],q[141];
u1(pi/512) q[141];
u1(pi/256) q[149];
cx q[149],q[142];
u1(-pi/256) q[142];
cx q[149],q[142];
u1(pi/256) q[142];
u1(pi/128) q[149];
cx q[149],q[143];
u1(-pi/128) q[143];
cx q[149],q[143];
u1(pi/128) q[143];
u1(pi/64) q[149];
cx q[149],q[144];
u1(-pi/64) q[144];
cx q[149],q[144];
u1(pi/64) q[144];
u1(pi/32) q[149];
cx q[149],q[145];
u1(-pi/32) q[145];
cx q[149],q[145];
u1(pi/32) q[145];
u1(pi/16) q[149];
cx q[149],q[146];
u1(-pi/16) q[146];
cx q[149],q[146];
u1(pi/16) q[146];
u1(pi/8) q[149];
cx q[149],q[147];
u1(-pi/8) q[147];
cx q[149],q[147];
u1(pi/8) q[147];
u1(pi/4) q[149];
cx q[149],q[148];
u1(-pi/4) q[148];
cx q[149],q[148];
u1(pi/4) q[148];
h q[149];
u1(0) q[150];
cx q[150],q[0];
u1(0) q[0];
cx q[150],q[0];
u1(0) q[0];
u1(0) q[150];
cx q[150],q[1];
u1(0) q[1];
cx q[150],q[1];
u1(0) q[1];
u1(0) q[150];
cx q[150],q[2];
u1(0) q[2];
cx q[150],q[2];
u1(0) q[2];
u1(0) q[150];
cx q[150],q[3];
u1(0) q[3];
cx q[150],q[3];
u1(0) q[3];
u1(0) q[150];
cx q[150],q[4];
u1(0) q[4];
cx q[150],q[4];
u1(0) q[4];
u1(0) q[150];
cx q[150],q[5];
u1(0) q[5];
cx q[150],q[5];
u1(0) q[5];
u1(0) q[150];
cx q[150],q[6];
u1(0) q[6];
cx q[150],q[6];
u1(0) q[6];
u1(0) q[150];
cx q[150],q[7];
u1(0) q[7];
cx q[150],q[7];
u1(0) q[7];
u1(0) q[150];
cx q[150],q[8];
u1(0) q[8];
cx q[150],q[8];
u1(0) q[8];
u1(0) q[150];
cx q[150],q[9];
u1(0) q[9];
cx q[150],q[9];
u1(0) q[9];
u1(0) q[150];
cx q[150],q[10];
u1(0) q[10];
cx q[150],q[10];
u1(0) q[10];
u1(0) q[150];
cx q[150],q[11];
u1(0) q[11];
cx q[150],q[11];
u1(0) q[11];
u1(0) q[150];
cx q[150],q[12];
u1(0) q[12];
cx q[150],q[12];
u1(0) q[12];
u1(0) q[150];
cx q[150],q[13];
u1(0) q[13];
cx q[150],q[13];
u1(0) q[13];
u1(0) q[150];
cx q[150],q[14];
u1(0) q[14];
cx q[150],q[14];
u1(0) q[14];
u1(0) q[150];
cx q[150],q[15];
u1(0) q[15];
cx q[150],q[15];
u1(0) q[15];
u1(0) q[150];
cx q[150],q[16];
u1(0) q[16];
cx q[150],q[16];
u1(0) q[16];
u1(0) q[150];
cx q[150],q[17];
u1(0) q[17];
cx q[150],q[17];
u1(0) q[17];
u1(0) q[150];
cx q[150],q[18];
u1(0) q[18];
cx q[150],q[18];
u1(0) q[18];
u1(0) q[150];
cx q[150],q[19];
u1(0) q[19];
cx q[150],q[19];
u1(0) q[19];
u1(0) q[150];
cx q[150],q[20];
u1(0) q[20];
cx q[150],q[20];
u1(0) q[20];
u1(0) q[150];
cx q[150],q[21];
u1(0) q[21];
cx q[150],q[21];
u1(0) q[21];
u1(0) q[150];
cx q[150],q[22];
u1(0) q[22];
cx q[150],q[22];
u1(0) q[22];
u1(0) q[150];
cx q[150],q[23];
u1(0) q[23];
cx q[150],q[23];
u1(0) q[23];
u1(0) q[150];
cx q[150],q[24];
u1(0) q[24];
cx q[150],q[24];
u1(0) q[24];
u1(0) q[150];
cx q[150],q[25];
u1(0) q[25];
cx q[150],q[25];
u1(0) q[25];
u1(0) q[150];
cx q[150],q[26];
u1(0) q[26];
cx q[150],q[26];
u1(0) q[26];
u1(0) q[150];
cx q[150],q[27];
u1(0) q[27];
cx q[150],q[27];
u1(0) q[27];
u1(0) q[150];
cx q[150],q[28];
u1(0) q[28];
cx q[150],q[28];
u1(0) q[28];
u1(0) q[150];
cx q[150],q[29];
u1(0) q[29];
cx q[150],q[29];
u1(0) q[29];
u1(0) q[150];
cx q[150],q[30];
u1(0) q[30];
cx q[150],q[30];
u1(0) q[30];
u1(0) q[150];
cx q[150],q[31];
u1(0) q[31];
cx q[150],q[31];
u1(0) q[31];
u1(0) q[150];
cx q[150],q[32];
u1(0) q[32];
cx q[150],q[32];
u1(0) q[32];
u1(0) q[150];
cx q[150],q[33];
u1(0) q[33];
cx q[150],q[33];
u1(0) q[33];
u1(0) q[150];
cx q[150],q[34];
u1(0) q[34];
cx q[150],q[34];
u1(0) q[34];
u1(0) q[150];
cx q[150],q[35];
u1(0) q[35];
cx q[150],q[35];
u1(0) q[35];
u1(0) q[150];
cx q[150],q[36];
u1(0) q[36];
cx q[150],q[36];
u1(0) q[36];
u1(0) q[150];
cx q[150],q[37];
u1(0) q[37];
cx q[150],q[37];
u1(0) q[37];
u1(0) q[150];
cx q[150],q[38];
u1(0) q[38];
cx q[150],q[38];
u1(0) q[38];
u1(0) q[150];
cx q[150],q[39];
u1(0) q[39];
cx q[150],q[39];
u1(0) q[39];
u1(0) q[150];
cx q[150],q[40];
u1(0) q[40];
cx q[150],q[40];
u1(0) q[40];
u1(0) q[150];
cx q[150],q[41];
u1(0) q[41];
cx q[150],q[41];
u1(0) q[41];
u1(0) q[150];
cx q[150],q[42];
u1(0) q[42];
cx q[150],q[42];
u1(0) q[42];
u1(0) q[150];
cx q[150],q[43];
u1(0) q[43];
cx q[150],q[43];
u1(0) q[43];
u1(0) q[150];
cx q[150],q[44];
u1(0) q[44];
cx q[150],q[44];
u1(0) q[44];
u1(0) q[150];
cx q[150],q[45];
u1(0) q[45];
cx q[150],q[45];
u1(0) q[45];
u1(0) q[150];
cx q[150],q[46];
u1(0) q[46];
cx q[150],q[46];
u1(0) q[46];
u1(0) q[150];
cx q[150],q[47];
u1(0) q[47];
cx q[150],q[47];
u1(0) q[47];
u1(0) q[150];
cx q[150],q[48];
u1(0) q[48];
cx q[150],q[48];
u1(0) q[48];
u1(0) q[150];
cx q[150],q[49];
u1(0) q[49];
cx q[150],q[49];
u1(0) q[49];
u1(0) q[150];
cx q[150],q[50];
u1(0) q[50];
cx q[150],q[50];
u1(0) q[50];
u1(0) q[150];
cx q[150],q[51];
u1(0) q[51];
cx q[150],q[51];
u1(0) q[51];
u1(0) q[150];
cx q[150],q[52];
u1(0) q[52];
cx q[150],q[52];
u1(0) q[52];
u1(0) q[150];
cx q[150],q[53];
u1(0) q[53];
cx q[150],q[53];
u1(0) q[53];
u1(0) q[150];
cx q[150],q[54];
u1(0) q[54];
cx q[150],q[54];
u1(0) q[54];
u1(0) q[150];
cx q[150],q[55];
u1(0) q[55];
cx q[150],q[55];
u1(0) q[55];
u1(0) q[150];
cx q[150],q[56];
u1(0) q[56];
cx q[150],q[56];
u1(0) q[56];
u1(0) q[150];
cx q[150],q[57];
u1(0) q[57];
cx q[150],q[57];
u1(0) q[57];
u1(0) q[150];
cx q[150],q[58];
u1(0) q[58];
cx q[150],q[58];
u1(0) q[58];
u1(0) q[150];
cx q[150],q[59];
u1(0) q[59];
cx q[150],q[59];
u1(0) q[59];
u1(0) q[150];
cx q[150],q[60];
u1(0) q[60];
cx q[150],q[60];
u1(0) q[60];
u1(0) q[150];
cx q[150],q[61];
u1(0) q[61];
cx q[150],q[61];
u1(0) q[61];
u1(0) q[150];
cx q[150],q[62];
u1(0) q[62];
cx q[150],q[62];
u1(0) q[62];
u1(0) q[150];
cx q[150],q[63];
u1(0) q[63];
cx q[150],q[63];
u1(0) q[63];
u1(0) q[150];
cx q[150],q[64];
u1(0) q[64];
cx q[150],q[64];
u1(0) q[64];
u1(0) q[150];
cx q[150],q[65];
u1(0) q[65];
cx q[150],q[65];
u1(0) q[65];
u1(0) q[150];
cx q[150],q[66];
u1(0) q[66];
cx q[150],q[66];
u1(0) q[66];
u1(0) q[150];
cx q[150],q[67];
u1(0) q[67];
cx q[150],q[67];
u1(0) q[67];
u1(0) q[150];
cx q[150],q[68];
u1(0) q[68];
cx q[150],q[68];
u1(0) q[68];
u1(0) q[150];
cx q[150],q[69];
u1(0) q[69];
cx q[150],q[69];
u1(0) q[69];
u1(0) q[150];
cx q[150],q[70];
u1(0) q[70];
cx q[150],q[70];
u1(0) q[70];
u1(0) q[150];
cx q[150],q[71];
u1(0) q[71];
cx q[150],q[71];
u1(0) q[71];
u1(0) q[150];
cx q[150],q[72];
u1(0) q[72];
cx q[150],q[72];
u1(0) q[72];
u1(0) q[150];
cx q[150],q[73];
u1(0) q[73];
cx q[150],q[73];
u1(0) q[73];
u1(0) q[150];
cx q[150],q[74];
u1(0) q[74];
cx q[150],q[74];
u1(0) q[74];
u1(0) q[150];
cx q[150],q[75];
u1(0) q[75];
cx q[150],q[75];
u1(0) q[75];
u1(0) q[150];
cx q[150],q[76];
u1(0) q[76];
cx q[150],q[76];
u1(0) q[76];
u1(0) q[150];
cx q[150],q[77];
u1(0) q[77];
cx q[150],q[77];
u1(0) q[77];
u1(0) q[150];
cx q[150],q[78];
u1(0) q[78];
cx q[150],q[78];
u1(0) q[78];
u1(0) q[150];
cx q[150],q[79];
u1(0) q[79];
cx q[150],q[79];
u1(0) q[79];
u1(0) q[150];
cx q[150],q[80];
u1(0) q[80];
cx q[150],q[80];
u1(0) q[80];
u1(0) q[150];
cx q[150],q[81];
u1(0) q[81];
cx q[150],q[81];
u1(0) q[81];
u1(0) q[150];
cx q[150],q[82];
u1(0) q[82];
cx q[150],q[82];
u1(0) q[82];
u1(0) q[150];
cx q[150],q[83];
u1(0) q[83];
cx q[150],q[83];
u1(0) q[83];
u1(0) q[150];
cx q[150],q[84];
u1(0) q[84];
cx q[150],q[84];
u1(0) q[84];
u1(0) q[150];
cx q[150],q[85];
u1(0) q[85];
cx q[150],q[85];
u1(0) q[85];
u1(0) q[150];
cx q[150],q[86];
u1(0) q[86];
cx q[150],q[86];
u1(0) q[86];
u1(0) q[150];
cx q[150],q[87];
u1(0) q[87];
cx q[150],q[87];
u1(0) q[87];
u1(0) q[150];
cx q[150],q[88];
u1(0) q[88];
cx q[150],q[88];
u1(0) q[88];
u1(0) q[150];
cx q[150],q[89];
u1(0) q[89];
cx q[150],q[89];
u1(0) q[89];
u1(0) q[150];
cx q[150],q[90];
u1(0) q[90];
cx q[150],q[90];
u1(0) q[90];
u1(0) q[150];
cx q[150],q[91];
u1(0) q[91];
cx q[150],q[91];
u1(0) q[91];
u1(0) q[150];
cx q[150],q[92];
u1(0) q[92];
cx q[150],q[92];
u1(0) q[92];
u1(0) q[150];
cx q[150],q[93];
u1(0) q[93];
cx q[150],q[93];
u1(0) q[93];
u1(0) q[150];
cx q[150],q[94];
u1(0) q[94];
cx q[150],q[94];
u1(0) q[94];
u1(0) q[150];
cx q[150],q[95];
u1(0) q[95];
cx q[150],q[95];
u1(0) q[95];
u1(0) q[150];
cx q[150],q[96];
u1(0) q[96];
cx q[150],q[96];
u1(0) q[96];
u1(0) q[150];
cx q[150],q[97];
u1(0) q[97];
cx q[150],q[97];
u1(0) q[97];
u1(0) q[150];
cx q[150],q[98];
u1(0) q[98];
cx q[150],q[98];
u1(0) q[98];
u1(0) q[150];
cx q[150],q[99];
u1(0) q[99];
cx q[150],q[99];
u1(0) q[99];
u1(0) q[150];
cx q[150],q[100];
u1(0) q[100];
cx q[150],q[100];
u1(0) q[100];
u1(0) q[150];
cx q[150],q[101];
u1(0) q[101];
cx q[150],q[101];
u1(0) q[101];
u1(0) q[150];
cx q[150],q[102];
u1(0) q[102];
cx q[150],q[102];
u1(0) q[102];
u1(pi/281474976710656) q[150];
cx q[150],q[103];
u1(-pi/281474976710656) q[103];
cx q[150],q[103];
u1(pi/281474976710656) q[103];
u1(pi/140737488355328) q[150];
cx q[150],q[104];
u1(-pi/140737488355328) q[104];
cx q[150],q[104];
u1(pi/140737488355328) q[104];
u1(pi/70368744177664) q[150];
cx q[150],q[105];
u1(-pi/70368744177664) q[105];
cx q[150],q[105];
u1(pi/70368744177664) q[105];
u1(pi/35184372088832) q[150];
cx q[150],q[106];
u1(-pi/35184372088832) q[106];
cx q[150],q[106];
u1(pi/35184372088832) q[106];
u1(pi/17592186044416) q[150];
cx q[150],q[107];
u1(-pi/17592186044416) q[107];
cx q[150],q[107];
u1(pi/17592186044416) q[107];
u1(pi/8796093022208) q[150];
cx q[150],q[108];
u1(-pi/8796093022208) q[108];
cx q[150],q[108];
u1(pi/8796093022208) q[108];
u1(pi/4398046511104) q[150];
cx q[150],q[109];
u1(-pi/4398046511104) q[109];
cx q[150],q[109];
u1(pi/4398046511104) q[109];
u1(pi/2199023255552) q[150];
cx q[150],q[110];
u1(-pi/2199023255552) q[110];
cx q[150],q[110];
u1(pi/2199023255552) q[110];
u1(pi/1099511627776) q[150];
cx q[150],q[111];
u1(-pi/1099511627776) q[111];
cx q[150],q[111];
u1(pi/1099511627776) q[111];
u1(pi/549755813888) q[150];
cx q[150],q[112];
u1(-pi/549755813888) q[112];
cx q[150],q[112];
u1(pi/549755813888) q[112];
u1(pi/274877906944) q[150];
cx q[150],q[113];
u1(-pi/274877906944) q[113];
cx q[150],q[113];
u1(pi/274877906944) q[113];
u1(pi/137438953472) q[150];
cx q[150],q[114];
u1(-pi/137438953472) q[114];
cx q[150],q[114];
u1(pi/137438953472) q[114];
u1(pi/68719476736) q[150];
cx q[150],q[115];
u1(-pi/68719476736) q[115];
cx q[150],q[115];
u1(pi/68719476736) q[115];
u1(pi/34359738368) q[150];
cx q[150],q[116];
u1(-pi/34359738368) q[116];
cx q[150],q[116];
u1(pi/34359738368) q[116];
u1(pi/17179869184) q[150];
cx q[150],q[117];
u1(-pi/17179869184) q[117];
cx q[150],q[117];
u1(pi/17179869184) q[117];
u1(pi/8589934592) q[150];
cx q[150],q[118];
u1(-pi/8589934592) q[118];
cx q[150],q[118];
u1(pi/8589934592) q[118];
u1(pi/4294967296) q[150];
cx q[150],q[119];
u1(-pi/4294967296) q[119];
cx q[150],q[119];
u1(pi/4294967296) q[119];
u1(pi/2147483648) q[150];
cx q[150],q[120];
u1(-pi/2147483648) q[120];
cx q[150],q[120];
u1(pi/2147483648) q[120];
u1(pi/1073741824) q[150];
cx q[150],q[121];
u1(-pi/1073741824) q[121];
cx q[150],q[121];
u1(pi/1073741824) q[121];
u1(pi/536870912) q[150];
cx q[150],q[122];
u1(-pi/536870912) q[122];
cx q[150],q[122];
u1(pi/536870912) q[122];
u1(pi/268435456) q[150];
cx q[150],q[123];
u1(-pi/268435456) q[123];
cx q[150],q[123];
u1(pi/268435456) q[123];
u1(pi/134217728) q[150];
cx q[150],q[124];
u1(-pi/134217728) q[124];
cx q[150],q[124];
u1(pi/134217728) q[124];
u1(pi/67108864) q[150];
cx q[150],q[125];
u1(-pi/67108864) q[125];
cx q[150],q[125];
u1(pi/67108864) q[125];
u1(pi/33554432) q[150];
cx q[150],q[126];
u1(-pi/33554432) q[126];
cx q[150],q[126];
u1(pi/33554432) q[126];
u1(pi/16777216) q[150];
cx q[150],q[127];
u1(-pi/16777216) q[127];
cx q[150],q[127];
u1(pi/16777216) q[127];
u1(pi/8388608) q[150];
cx q[150],q[128];
u1(-pi/8388608) q[128];
cx q[150],q[128];
u1(pi/8388608) q[128];
u1(pi/4194304) q[150];
cx q[150],q[129];
u1(-pi/4194304) q[129];
cx q[150],q[129];
u1(pi/4194304) q[129];
u1(pi/2097152) q[150];
cx q[150],q[130];
u1(-pi/2097152) q[130];
cx q[150],q[130];
u1(pi/2097152) q[130];
u1(pi/1048576) q[150];
cx q[150],q[131];
u1(-pi/1048576) q[131];
cx q[150],q[131];
u1(pi/1048576) q[131];
u1(pi/524288) q[150];
cx q[150],q[132];
u1(-pi/524288) q[132];
cx q[150],q[132];
u1(pi/524288) q[132];
u1(pi/262144) q[150];
cx q[150],q[133];
u1(-pi/262144) q[133];
cx q[150],q[133];
u1(pi/262144) q[133];
u1(pi/131072) q[150];
cx q[150],q[134];
u1(-pi/131072) q[134];
cx q[150],q[134];
u1(pi/131072) q[134];
u1(pi/65536) q[150];
cx q[150],q[135];
u1(-pi/65536) q[135];
cx q[150],q[135];
u1(pi/65536) q[135];
u1(pi/32768) q[150];
cx q[150],q[136];
u1(-pi/32768) q[136];
cx q[150],q[136];
u1(pi/32768) q[136];
u1(pi/16384) q[150];
cx q[150],q[137];
u1(-pi/16384) q[137];
cx q[150],q[137];
u1(pi/16384) q[137];
u1(pi/8192) q[150];
cx q[150],q[138];
u1(-pi/8192) q[138];
cx q[150],q[138];
u1(pi/8192) q[138];
u1(pi/4096) q[150];
cx q[150],q[139];
u1(-pi/4096) q[139];
cx q[150],q[139];
u1(pi/4096) q[139];
u1(pi/2048) q[150];
cx q[150],q[140];
u1(-pi/2048) q[140];
cx q[150],q[140];
u1(pi/2048) q[140];
u1(pi/1024) q[150];
cx q[150],q[141];
u1(-pi/1024) q[141];
cx q[150],q[141];
u1(pi/1024) q[141];
u1(pi/512) q[150];
cx q[150],q[142];
u1(-pi/512) q[142];
cx q[150],q[142];
u1(pi/512) q[142];
u1(pi/256) q[150];
cx q[150],q[143];
u1(-pi/256) q[143];
cx q[150],q[143];
u1(pi/256) q[143];
u1(pi/128) q[150];
cx q[150],q[144];
u1(-pi/128) q[144];
cx q[150],q[144];
u1(pi/128) q[144];
u1(pi/64) q[150];
cx q[150],q[145];
u1(-pi/64) q[145];
cx q[150],q[145];
u1(pi/64) q[145];
u1(pi/32) q[150];
cx q[150],q[146];
u1(-pi/32) q[146];
cx q[150],q[146];
u1(pi/32) q[146];
u1(pi/16) q[150];
cx q[150],q[147];
u1(-pi/16) q[147];
cx q[150],q[147];
u1(pi/16) q[147];
u1(pi/8) q[150];
cx q[150],q[148];
u1(-pi/8) q[148];
cx q[150],q[148];
u1(pi/8) q[148];
u1(pi/4) q[150];
cx q[150],q[149];
u1(-pi/4) q[149];
cx q[150],q[149];
u1(pi/4) q[149];
h q[150];
u1(0) q[151];
cx q[151],q[0];
u1(0) q[0];
cx q[151],q[0];
u1(0) q[0];
u1(0) q[151];
cx q[151],q[1];
u1(0) q[1];
cx q[151],q[1];
u1(0) q[1];
u1(0) q[151];
cx q[151],q[2];
u1(0) q[2];
cx q[151],q[2];
u1(0) q[2];
u1(0) q[151];
cx q[151],q[3];
u1(0) q[3];
cx q[151],q[3];
u1(0) q[3];
u1(0) q[151];
cx q[151],q[4];
u1(0) q[4];
cx q[151],q[4];
u1(0) q[4];
u1(0) q[151];
cx q[151],q[5];
u1(0) q[5];
cx q[151],q[5];
u1(0) q[5];
u1(0) q[151];
cx q[151],q[6];
u1(0) q[6];
cx q[151],q[6];
u1(0) q[6];
u1(0) q[151];
cx q[151],q[7];
u1(0) q[7];
cx q[151],q[7];
u1(0) q[7];
u1(0) q[151];
cx q[151],q[8];
u1(0) q[8];
cx q[151],q[8];
u1(0) q[8];
u1(0) q[151];
cx q[151],q[9];
u1(0) q[9];
cx q[151],q[9];
u1(0) q[9];
u1(0) q[151];
cx q[151],q[10];
u1(0) q[10];
cx q[151],q[10];
u1(0) q[10];
u1(0) q[151];
cx q[151],q[11];
u1(0) q[11];
cx q[151],q[11];
u1(0) q[11];
u1(0) q[151];
cx q[151],q[12];
u1(0) q[12];
cx q[151],q[12];
u1(0) q[12];
u1(0) q[151];
cx q[151],q[13];
u1(0) q[13];
cx q[151],q[13];
u1(0) q[13];
u1(0) q[151];
cx q[151],q[14];
u1(0) q[14];
cx q[151],q[14];
u1(0) q[14];
u1(0) q[151];
cx q[151],q[15];
u1(0) q[15];
cx q[151],q[15];
u1(0) q[15];
u1(0) q[151];
cx q[151],q[16];
u1(0) q[16];
cx q[151],q[16];
u1(0) q[16];
u1(0) q[151];
cx q[151],q[17];
u1(0) q[17];
cx q[151],q[17];
u1(0) q[17];
u1(0) q[151];
cx q[151],q[18];
u1(0) q[18];
cx q[151],q[18];
u1(0) q[18];
u1(0) q[151];
cx q[151],q[19];
u1(0) q[19];
cx q[151],q[19];
u1(0) q[19];
u1(0) q[151];
cx q[151],q[20];
u1(0) q[20];
cx q[151],q[20];
u1(0) q[20];
u1(0) q[151];
cx q[151],q[21];
u1(0) q[21];
cx q[151],q[21];
u1(0) q[21];
u1(0) q[151];
cx q[151],q[22];
u1(0) q[22];
cx q[151],q[22];
u1(0) q[22];
u1(0) q[151];
cx q[151],q[23];
u1(0) q[23];
cx q[151],q[23];
u1(0) q[23];
u1(0) q[151];
cx q[151],q[24];
u1(0) q[24];
cx q[151],q[24];
u1(0) q[24];
u1(0) q[151];
cx q[151],q[25];
u1(0) q[25];
cx q[151],q[25];
u1(0) q[25];
u1(0) q[151];
cx q[151],q[26];
u1(0) q[26];
cx q[151],q[26];
u1(0) q[26];
u1(0) q[151];
cx q[151],q[27];
u1(0) q[27];
cx q[151],q[27];
u1(0) q[27];
u1(0) q[151];
cx q[151],q[28];
u1(0) q[28];
cx q[151],q[28];
u1(0) q[28];
u1(0) q[151];
cx q[151],q[29];
u1(0) q[29];
cx q[151],q[29];
u1(0) q[29];
u1(0) q[151];
cx q[151],q[30];
u1(0) q[30];
cx q[151],q[30];
u1(0) q[30];
u1(0) q[151];
cx q[151],q[31];
u1(0) q[31];
cx q[151],q[31];
u1(0) q[31];
u1(0) q[151];
cx q[151],q[32];
u1(0) q[32];
cx q[151],q[32];
u1(0) q[32];
u1(0) q[151];
cx q[151],q[33];
u1(0) q[33];
cx q[151],q[33];
u1(0) q[33];
u1(0) q[151];
cx q[151],q[34];
u1(0) q[34];
cx q[151],q[34];
u1(0) q[34];
u1(0) q[151];
cx q[151],q[35];
u1(0) q[35];
cx q[151],q[35];
u1(0) q[35];
u1(0) q[151];
cx q[151],q[36];
u1(0) q[36];
cx q[151],q[36];
u1(0) q[36];
u1(0) q[151];
cx q[151],q[37];
u1(0) q[37];
cx q[151],q[37];
u1(0) q[37];
u1(0) q[151];
cx q[151],q[38];
u1(0) q[38];
cx q[151],q[38];
u1(0) q[38];
u1(0) q[151];
cx q[151],q[39];
u1(0) q[39];
cx q[151],q[39];
u1(0) q[39];
u1(0) q[151];
cx q[151],q[40];
u1(0) q[40];
cx q[151],q[40];
u1(0) q[40];
u1(0) q[151];
cx q[151],q[41];
u1(0) q[41];
cx q[151],q[41];
u1(0) q[41];
u1(0) q[151];
cx q[151],q[42];
u1(0) q[42];
cx q[151],q[42];
u1(0) q[42];
u1(0) q[151];
cx q[151],q[43];
u1(0) q[43];
cx q[151],q[43];
u1(0) q[43];
u1(0) q[151];
cx q[151],q[44];
u1(0) q[44];
cx q[151],q[44];
u1(0) q[44];
u1(0) q[151];
cx q[151],q[45];
u1(0) q[45];
cx q[151],q[45];
u1(0) q[45];
u1(0) q[151];
cx q[151],q[46];
u1(0) q[46];
cx q[151],q[46];
u1(0) q[46];
u1(0) q[151];
cx q[151],q[47];
u1(0) q[47];
cx q[151],q[47];
u1(0) q[47];
u1(0) q[151];
cx q[151],q[48];
u1(0) q[48];
cx q[151],q[48];
u1(0) q[48];
u1(0) q[151];
cx q[151],q[49];
u1(0) q[49];
cx q[151],q[49];
u1(0) q[49];
u1(0) q[151];
cx q[151],q[50];
u1(0) q[50];
cx q[151],q[50];
u1(0) q[50];
u1(0) q[151];
cx q[151],q[51];
u1(0) q[51];
cx q[151],q[51];
u1(0) q[51];
u1(0) q[151];
cx q[151],q[52];
u1(0) q[52];
cx q[151],q[52];
u1(0) q[52];
u1(0) q[151];
cx q[151],q[53];
u1(0) q[53];
cx q[151],q[53];
u1(0) q[53];
u1(0) q[151];
cx q[151],q[54];
u1(0) q[54];
cx q[151],q[54];
u1(0) q[54];
u1(0) q[151];
cx q[151],q[55];
u1(0) q[55];
cx q[151],q[55];
u1(0) q[55];
u1(0) q[151];
cx q[151],q[56];
u1(0) q[56];
cx q[151],q[56];
u1(0) q[56];
u1(0) q[151];
cx q[151],q[57];
u1(0) q[57];
cx q[151],q[57];
u1(0) q[57];
u1(0) q[151];
cx q[151],q[58];
u1(0) q[58];
cx q[151],q[58];
u1(0) q[58];
u1(0) q[151];
cx q[151],q[59];
u1(0) q[59];
cx q[151],q[59];
u1(0) q[59];
u1(0) q[151];
cx q[151],q[60];
u1(0) q[60];
cx q[151],q[60];
u1(0) q[60];
u1(0) q[151];
cx q[151],q[61];
u1(0) q[61];
cx q[151],q[61];
u1(0) q[61];
u1(0) q[151];
cx q[151],q[62];
u1(0) q[62];
cx q[151],q[62];
u1(0) q[62];
u1(0) q[151];
cx q[151],q[63];
u1(0) q[63];
cx q[151],q[63];
u1(0) q[63];
u1(0) q[151];
cx q[151],q[64];
u1(0) q[64];
cx q[151],q[64];
u1(0) q[64];
u1(0) q[151];
cx q[151],q[65];
u1(0) q[65];
cx q[151],q[65];
u1(0) q[65];
u1(0) q[151];
cx q[151],q[66];
u1(0) q[66];
cx q[151],q[66];
u1(0) q[66];
u1(0) q[151];
cx q[151],q[67];
u1(0) q[67];
cx q[151],q[67];
u1(0) q[67];
u1(0) q[151];
cx q[151],q[68];
u1(0) q[68];
cx q[151],q[68];
u1(0) q[68];
u1(0) q[151];
cx q[151],q[69];
u1(0) q[69];
cx q[151],q[69];
u1(0) q[69];
u1(0) q[151];
cx q[151],q[70];
u1(0) q[70];
cx q[151],q[70];
u1(0) q[70];
u1(0) q[151];
cx q[151],q[71];
u1(0) q[71];
cx q[151],q[71];
u1(0) q[71];
u1(0) q[151];
cx q[151],q[72];
u1(0) q[72];
cx q[151],q[72];
u1(0) q[72];
u1(0) q[151];
cx q[151],q[73];
u1(0) q[73];
cx q[151],q[73];
u1(0) q[73];
u1(0) q[151];
cx q[151],q[74];
u1(0) q[74];
cx q[151],q[74];
u1(0) q[74];
u1(0) q[151];
cx q[151],q[75];
u1(0) q[75];
cx q[151],q[75];
u1(0) q[75];
u1(0) q[151];
cx q[151],q[76];
u1(0) q[76];
cx q[151],q[76];
u1(0) q[76];
u1(0) q[151];
cx q[151],q[77];
u1(0) q[77];
cx q[151],q[77];
u1(0) q[77];
u1(0) q[151];
cx q[151],q[78];
u1(0) q[78];
cx q[151],q[78];
u1(0) q[78];
u1(0) q[151];
cx q[151],q[79];
u1(0) q[79];
cx q[151],q[79];
u1(0) q[79];
u1(0) q[151];
cx q[151],q[80];
u1(0) q[80];
cx q[151],q[80];
u1(0) q[80];
u1(0) q[151];
cx q[151],q[81];
u1(0) q[81];
cx q[151],q[81];
u1(0) q[81];
u1(0) q[151];
cx q[151],q[82];
u1(0) q[82];
cx q[151],q[82];
u1(0) q[82];
u1(0) q[151];
cx q[151],q[83];
u1(0) q[83];
cx q[151],q[83];
u1(0) q[83];
u1(0) q[151];
cx q[151],q[84];
u1(0) q[84];
cx q[151],q[84];
u1(0) q[84];
u1(0) q[151];
cx q[151],q[85];
u1(0) q[85];
cx q[151],q[85];
u1(0) q[85];
u1(0) q[151];
cx q[151],q[86];
u1(0) q[86];
cx q[151],q[86];
u1(0) q[86];
u1(0) q[151];
cx q[151],q[87];
u1(0) q[87];
cx q[151],q[87];
u1(0) q[87];
u1(0) q[151];
cx q[151],q[88];
u1(0) q[88];
cx q[151],q[88];
u1(0) q[88];
u1(0) q[151];
cx q[151],q[89];
u1(0) q[89];
cx q[151],q[89];
u1(0) q[89];
u1(0) q[151];
cx q[151],q[90];
u1(0) q[90];
cx q[151],q[90];
u1(0) q[90];
u1(0) q[151];
cx q[151],q[91];
u1(0) q[91];
cx q[151],q[91];
u1(0) q[91];
u1(0) q[151];
cx q[151],q[92];
u1(0) q[92];
cx q[151],q[92];
u1(0) q[92];
u1(0) q[151];
cx q[151],q[93];
u1(0) q[93];
cx q[151],q[93];
u1(0) q[93];
u1(0) q[151];
cx q[151],q[94];
u1(0) q[94];
cx q[151],q[94];
u1(0) q[94];
u1(0) q[151];
cx q[151],q[95];
u1(0) q[95];
cx q[151],q[95];
u1(0) q[95];
u1(0) q[151];
cx q[151],q[96];
u1(0) q[96];
cx q[151],q[96];
u1(0) q[96];
u1(0) q[151];
cx q[151],q[97];
u1(0) q[97];
cx q[151],q[97];
u1(0) q[97];
u1(0) q[151];
cx q[151],q[98];
u1(0) q[98];
cx q[151],q[98];
u1(0) q[98];
u1(0) q[151];
cx q[151],q[99];
u1(0) q[99];
cx q[151],q[99];
u1(0) q[99];
u1(0) q[151];
cx q[151],q[100];
u1(0) q[100];
cx q[151],q[100];
u1(0) q[100];
u1(0) q[151];
cx q[151],q[101];
u1(0) q[101];
cx q[151],q[101];
u1(0) q[101];
u1(0) q[151];
cx q[151],q[102];
u1(0) q[102];
cx q[151],q[102];
u1(0) q[102];
u1(0) q[151];
cx q[151],q[103];
u1(0) q[103];
cx q[151],q[103];
u1(0) q[103];
u1(pi/281474976710656) q[151];
cx q[151],q[104];
u1(-pi/281474976710656) q[104];
cx q[151],q[104];
u1(pi/281474976710656) q[104];
u1(pi/140737488355328) q[151];
cx q[151],q[105];
u1(-pi/140737488355328) q[105];
cx q[151],q[105];
u1(pi/140737488355328) q[105];
u1(pi/70368744177664) q[151];
cx q[151],q[106];
u1(-pi/70368744177664) q[106];
cx q[151],q[106];
u1(pi/70368744177664) q[106];
u1(pi/35184372088832) q[151];
cx q[151],q[107];
u1(-pi/35184372088832) q[107];
cx q[151],q[107];
u1(pi/35184372088832) q[107];
u1(pi/17592186044416) q[151];
cx q[151],q[108];
u1(-pi/17592186044416) q[108];
cx q[151],q[108];
u1(pi/17592186044416) q[108];
u1(pi/8796093022208) q[151];
cx q[151],q[109];
u1(-pi/8796093022208) q[109];
cx q[151],q[109];
u1(pi/8796093022208) q[109];
u1(pi/4398046511104) q[151];
cx q[151],q[110];
u1(-pi/4398046511104) q[110];
cx q[151],q[110];
u1(pi/4398046511104) q[110];
u1(pi/2199023255552) q[151];
cx q[151],q[111];
u1(-pi/2199023255552) q[111];
cx q[151],q[111];
u1(pi/2199023255552) q[111];
u1(pi/1099511627776) q[151];
cx q[151],q[112];
u1(-pi/1099511627776) q[112];
cx q[151],q[112];
u1(pi/1099511627776) q[112];
u1(pi/549755813888) q[151];
cx q[151],q[113];
u1(-pi/549755813888) q[113];
cx q[151],q[113];
u1(pi/549755813888) q[113];
u1(pi/274877906944) q[151];
cx q[151],q[114];
u1(-pi/274877906944) q[114];
cx q[151],q[114];
u1(pi/274877906944) q[114];
u1(pi/137438953472) q[151];
cx q[151],q[115];
u1(-pi/137438953472) q[115];
cx q[151],q[115];
u1(pi/137438953472) q[115];
u1(pi/68719476736) q[151];
cx q[151],q[116];
u1(-pi/68719476736) q[116];
cx q[151],q[116];
u1(pi/68719476736) q[116];
u1(pi/34359738368) q[151];
cx q[151],q[117];
u1(-pi/34359738368) q[117];
cx q[151],q[117];
u1(pi/34359738368) q[117];
u1(pi/17179869184) q[151];
cx q[151],q[118];
u1(-pi/17179869184) q[118];
cx q[151],q[118];
u1(pi/17179869184) q[118];
u1(pi/8589934592) q[151];
cx q[151],q[119];
u1(-pi/8589934592) q[119];
cx q[151],q[119];
u1(pi/8589934592) q[119];
u1(pi/4294967296) q[151];
cx q[151],q[120];
u1(-pi/4294967296) q[120];
cx q[151],q[120];
u1(pi/4294967296) q[120];
u1(pi/2147483648) q[151];
cx q[151],q[121];
u1(-pi/2147483648) q[121];
cx q[151],q[121];
u1(pi/2147483648) q[121];
u1(pi/1073741824) q[151];
cx q[151],q[122];
u1(-pi/1073741824) q[122];
cx q[151],q[122];
u1(pi/1073741824) q[122];
u1(pi/536870912) q[151];
cx q[151],q[123];
u1(-pi/536870912) q[123];
cx q[151],q[123];
u1(pi/536870912) q[123];
u1(pi/268435456) q[151];
cx q[151],q[124];
u1(-pi/268435456) q[124];
cx q[151],q[124];
u1(pi/268435456) q[124];
u1(pi/134217728) q[151];
cx q[151],q[125];
u1(-pi/134217728) q[125];
cx q[151],q[125];
u1(pi/134217728) q[125];
u1(pi/67108864) q[151];
cx q[151],q[126];
u1(-pi/67108864) q[126];
cx q[151],q[126];
u1(pi/67108864) q[126];
u1(pi/33554432) q[151];
cx q[151],q[127];
u1(-pi/33554432) q[127];
cx q[151],q[127];
u1(pi/33554432) q[127];
u1(pi/16777216) q[151];
cx q[151],q[128];
u1(-pi/16777216) q[128];
cx q[151],q[128];
u1(pi/16777216) q[128];
u1(pi/8388608) q[151];
cx q[151],q[129];
u1(-pi/8388608) q[129];
cx q[151],q[129];
u1(pi/8388608) q[129];
u1(pi/4194304) q[151];
cx q[151],q[130];
u1(-pi/4194304) q[130];
cx q[151],q[130];
u1(pi/4194304) q[130];
u1(pi/2097152) q[151];
cx q[151],q[131];
u1(-pi/2097152) q[131];
cx q[151],q[131];
u1(pi/2097152) q[131];
u1(pi/1048576) q[151];
cx q[151],q[132];
u1(-pi/1048576) q[132];
cx q[151],q[132];
u1(pi/1048576) q[132];
u1(pi/524288) q[151];
cx q[151],q[133];
u1(-pi/524288) q[133];
cx q[151],q[133];
u1(pi/524288) q[133];
u1(pi/262144) q[151];
cx q[151],q[134];
u1(-pi/262144) q[134];
cx q[151],q[134];
u1(pi/262144) q[134];
u1(pi/131072) q[151];
cx q[151],q[135];
u1(-pi/131072) q[135];
cx q[151],q[135];
u1(pi/131072) q[135];
u1(pi/65536) q[151];
cx q[151],q[136];
u1(-pi/65536) q[136];
cx q[151],q[136];
u1(pi/65536) q[136];
u1(pi/32768) q[151];
cx q[151],q[137];
u1(-pi/32768) q[137];
cx q[151],q[137];
u1(pi/32768) q[137];
u1(pi/16384) q[151];
cx q[151],q[138];
u1(-pi/16384) q[138];
cx q[151],q[138];
u1(pi/16384) q[138];
u1(pi/8192) q[151];
cx q[151],q[139];
u1(-pi/8192) q[139];
cx q[151],q[139];
u1(pi/8192) q[139];
u1(pi/4096) q[151];
cx q[151],q[140];
u1(-pi/4096) q[140];
cx q[151],q[140];
u1(pi/4096) q[140];
u1(pi/2048) q[151];
cx q[151],q[141];
u1(-pi/2048) q[141];
cx q[151],q[141];
u1(pi/2048) q[141];
u1(pi/1024) q[151];
cx q[151],q[142];
u1(-pi/1024) q[142];
cx q[151],q[142];
u1(pi/1024) q[142];
u1(pi/512) q[151];
cx q[151],q[143];
u1(-pi/512) q[143];
cx q[151],q[143];
u1(pi/512) q[143];
u1(pi/256) q[151];
cx q[151],q[144];
u1(-pi/256) q[144];
cx q[151],q[144];
u1(pi/256) q[144];
u1(pi/128) q[151];
cx q[151],q[145];
u1(-pi/128) q[145];
cx q[151],q[145];
u1(pi/128) q[145];
u1(pi/64) q[151];
cx q[151],q[146];
u1(-pi/64) q[146];
cx q[151],q[146];
u1(pi/64) q[146];
u1(pi/32) q[151];
cx q[151],q[147];
u1(-pi/32) q[147];
cx q[151],q[147];
u1(pi/32) q[147];
u1(pi/16) q[151];
cx q[151],q[148];
u1(-pi/16) q[148];
cx q[151],q[148];
u1(pi/16) q[148];
u1(pi/8) q[151];
cx q[151],q[149];
u1(-pi/8) q[149];
cx q[151],q[149];
u1(pi/8) q[149];
u1(pi/4) q[151];
cx q[151],q[150];
u1(-pi/4) q[150];
cx q[151],q[150];
u1(pi/4) q[150];
h q[151];
u1(0) q[152];
cx q[152],q[0];
u1(0) q[0];
cx q[152],q[0];
u1(0) q[0];
u1(0) q[152];
cx q[152],q[1];
u1(0) q[1];
cx q[152],q[1];
u1(0) q[1];
u1(0) q[152];
cx q[152],q[2];
u1(0) q[2];
cx q[152],q[2];
u1(0) q[2];
u1(0) q[152];
cx q[152],q[3];
u1(0) q[3];
cx q[152],q[3];
u1(0) q[3];
u1(0) q[152];
cx q[152],q[4];
u1(0) q[4];
cx q[152],q[4];
u1(0) q[4];
u1(0) q[152];
cx q[152],q[5];
u1(0) q[5];
cx q[152],q[5];
u1(0) q[5];
u1(0) q[152];
cx q[152],q[6];
u1(0) q[6];
cx q[152],q[6];
u1(0) q[6];
u1(0) q[152];
cx q[152],q[7];
u1(0) q[7];
cx q[152],q[7];
u1(0) q[7];
u1(0) q[152];
cx q[152],q[8];
u1(0) q[8];
cx q[152],q[8];
u1(0) q[8];
u1(0) q[152];
cx q[152],q[9];
u1(0) q[9];
cx q[152],q[9];
u1(0) q[9];
u1(0) q[152];
cx q[152],q[10];
u1(0) q[10];
cx q[152],q[10];
u1(0) q[10];
u1(0) q[152];
cx q[152],q[11];
u1(0) q[11];
cx q[152],q[11];
u1(0) q[11];
u1(0) q[152];
cx q[152],q[12];
u1(0) q[12];
cx q[152],q[12];
u1(0) q[12];
u1(0) q[152];
cx q[152],q[13];
u1(0) q[13];
cx q[152],q[13];
u1(0) q[13];
u1(0) q[152];
cx q[152],q[14];
u1(0) q[14];
cx q[152],q[14];
u1(0) q[14];
u1(0) q[152];
cx q[152],q[15];
u1(0) q[15];
cx q[152],q[15];
u1(0) q[15];
u1(0) q[152];
cx q[152],q[16];
u1(0) q[16];
cx q[152],q[16];
u1(0) q[16];
u1(0) q[152];
cx q[152],q[17];
u1(0) q[17];
cx q[152],q[17];
u1(0) q[17];
u1(0) q[152];
cx q[152],q[18];
u1(0) q[18];
cx q[152],q[18];
u1(0) q[18];
u1(0) q[152];
cx q[152],q[19];
u1(0) q[19];
cx q[152],q[19];
u1(0) q[19];
u1(0) q[152];
cx q[152],q[20];
u1(0) q[20];
cx q[152],q[20];
u1(0) q[20];
u1(0) q[152];
cx q[152],q[21];
u1(0) q[21];
cx q[152],q[21];
u1(0) q[21];
u1(0) q[152];
cx q[152],q[22];
u1(0) q[22];
cx q[152],q[22];
u1(0) q[22];
u1(0) q[152];
cx q[152],q[23];
u1(0) q[23];
cx q[152],q[23];
u1(0) q[23];
u1(0) q[152];
cx q[152],q[24];
u1(0) q[24];
cx q[152],q[24];
u1(0) q[24];
u1(0) q[152];
cx q[152],q[25];
u1(0) q[25];
cx q[152],q[25];
u1(0) q[25];
u1(0) q[152];
cx q[152],q[26];
u1(0) q[26];
cx q[152],q[26];
u1(0) q[26];
u1(0) q[152];
cx q[152],q[27];
u1(0) q[27];
cx q[152],q[27];
u1(0) q[27];
u1(0) q[152];
cx q[152],q[28];
u1(0) q[28];
cx q[152],q[28];
u1(0) q[28];
u1(0) q[152];
cx q[152],q[29];
u1(0) q[29];
cx q[152],q[29];
u1(0) q[29];
u1(0) q[152];
cx q[152],q[30];
u1(0) q[30];
cx q[152],q[30];
u1(0) q[30];
u1(0) q[152];
cx q[152],q[31];
u1(0) q[31];
cx q[152],q[31];
u1(0) q[31];
u1(0) q[152];
cx q[152],q[32];
u1(0) q[32];
cx q[152],q[32];
u1(0) q[32];
u1(0) q[152];
cx q[152],q[33];
u1(0) q[33];
cx q[152],q[33];
u1(0) q[33];
u1(0) q[152];
cx q[152],q[34];
u1(0) q[34];
cx q[152],q[34];
u1(0) q[34];
u1(0) q[152];
cx q[152],q[35];
u1(0) q[35];
cx q[152],q[35];
u1(0) q[35];
u1(0) q[152];
cx q[152],q[36];
u1(0) q[36];
cx q[152],q[36];
u1(0) q[36];
u1(0) q[152];
cx q[152],q[37];
u1(0) q[37];
cx q[152],q[37];
u1(0) q[37];
u1(0) q[152];
cx q[152],q[38];
u1(0) q[38];
cx q[152],q[38];
u1(0) q[38];
u1(0) q[152];
cx q[152],q[39];
u1(0) q[39];
cx q[152],q[39];
u1(0) q[39];
u1(0) q[152];
cx q[152],q[40];
u1(0) q[40];
cx q[152],q[40];
u1(0) q[40];
u1(0) q[152];
cx q[152],q[41];
u1(0) q[41];
cx q[152],q[41];
u1(0) q[41];
u1(0) q[152];
cx q[152],q[42];
u1(0) q[42];
cx q[152],q[42];
u1(0) q[42];
u1(0) q[152];
cx q[152],q[43];
u1(0) q[43];
cx q[152],q[43];
u1(0) q[43];
u1(0) q[152];
cx q[152],q[44];
u1(0) q[44];
cx q[152],q[44];
u1(0) q[44];
u1(0) q[152];
cx q[152],q[45];
u1(0) q[45];
cx q[152],q[45];
u1(0) q[45];
u1(0) q[152];
cx q[152],q[46];
u1(0) q[46];
cx q[152],q[46];
u1(0) q[46];
u1(0) q[152];
cx q[152],q[47];
u1(0) q[47];
cx q[152],q[47];
u1(0) q[47];
u1(0) q[152];
cx q[152],q[48];
u1(0) q[48];
cx q[152],q[48];
u1(0) q[48];
u1(0) q[152];
cx q[152],q[49];
u1(0) q[49];
cx q[152],q[49];
u1(0) q[49];
u1(0) q[152];
cx q[152],q[50];
u1(0) q[50];
cx q[152],q[50];
u1(0) q[50];
u1(0) q[152];
cx q[152],q[51];
u1(0) q[51];
cx q[152],q[51];
u1(0) q[51];
u1(0) q[152];
cx q[152],q[52];
u1(0) q[52];
cx q[152],q[52];
u1(0) q[52];
u1(0) q[152];
cx q[152],q[53];
u1(0) q[53];
cx q[152],q[53];
u1(0) q[53];
u1(0) q[152];
cx q[152],q[54];
u1(0) q[54];
cx q[152],q[54];
u1(0) q[54];
u1(0) q[152];
cx q[152],q[55];
u1(0) q[55];
cx q[152],q[55];
u1(0) q[55];
u1(0) q[152];
cx q[152],q[56];
u1(0) q[56];
cx q[152],q[56];
u1(0) q[56];
u1(0) q[152];
cx q[152],q[57];
u1(0) q[57];
cx q[152],q[57];
u1(0) q[57];
u1(0) q[152];
cx q[152],q[58];
u1(0) q[58];
cx q[152],q[58];
u1(0) q[58];
u1(0) q[152];
cx q[152],q[59];
u1(0) q[59];
cx q[152],q[59];
u1(0) q[59];
u1(0) q[152];
cx q[152],q[60];
u1(0) q[60];
cx q[152],q[60];
u1(0) q[60];
u1(0) q[152];
cx q[152],q[61];
u1(0) q[61];
cx q[152],q[61];
u1(0) q[61];
u1(0) q[152];
cx q[152],q[62];
u1(0) q[62];
cx q[152],q[62];
u1(0) q[62];
u1(0) q[152];
cx q[152],q[63];
u1(0) q[63];
cx q[152],q[63];
u1(0) q[63];
u1(0) q[152];
cx q[152],q[64];
u1(0) q[64];
cx q[152],q[64];
u1(0) q[64];
u1(0) q[152];
cx q[152],q[65];
u1(0) q[65];
cx q[152],q[65];
u1(0) q[65];
u1(0) q[152];
cx q[152],q[66];
u1(0) q[66];
cx q[152],q[66];
u1(0) q[66];
u1(0) q[152];
cx q[152],q[67];
u1(0) q[67];
cx q[152],q[67];
u1(0) q[67];
u1(0) q[152];
cx q[152],q[68];
u1(0) q[68];
cx q[152],q[68];
u1(0) q[68];
u1(0) q[152];
cx q[152],q[69];
u1(0) q[69];
cx q[152],q[69];
u1(0) q[69];
u1(0) q[152];
cx q[152],q[70];
u1(0) q[70];
cx q[152],q[70];
u1(0) q[70];
u1(0) q[152];
cx q[152],q[71];
u1(0) q[71];
cx q[152],q[71];
u1(0) q[71];
u1(0) q[152];
cx q[152],q[72];
u1(0) q[72];
cx q[152],q[72];
u1(0) q[72];
u1(0) q[152];
cx q[152],q[73];
u1(0) q[73];
cx q[152],q[73];
u1(0) q[73];
u1(0) q[152];
cx q[152],q[74];
u1(0) q[74];
cx q[152],q[74];
u1(0) q[74];
u1(0) q[152];
cx q[152],q[75];
u1(0) q[75];
cx q[152],q[75];
u1(0) q[75];
u1(0) q[152];
cx q[152],q[76];
u1(0) q[76];
cx q[152],q[76];
u1(0) q[76];
u1(0) q[152];
cx q[152],q[77];
u1(0) q[77];
cx q[152],q[77];
u1(0) q[77];
u1(0) q[152];
cx q[152],q[78];
u1(0) q[78];
cx q[152],q[78];
u1(0) q[78];
u1(0) q[152];
cx q[152],q[79];
u1(0) q[79];
cx q[152],q[79];
u1(0) q[79];
u1(0) q[152];
cx q[152],q[80];
u1(0) q[80];
cx q[152],q[80];
u1(0) q[80];
u1(0) q[152];
cx q[152],q[81];
u1(0) q[81];
cx q[152],q[81];
u1(0) q[81];
u1(0) q[152];
cx q[152],q[82];
u1(0) q[82];
cx q[152],q[82];
u1(0) q[82];
u1(0) q[152];
cx q[152],q[83];
u1(0) q[83];
cx q[152],q[83];
u1(0) q[83];
u1(0) q[152];
cx q[152],q[84];
u1(0) q[84];
cx q[152],q[84];
u1(0) q[84];
u1(0) q[152];
cx q[152],q[85];
u1(0) q[85];
cx q[152],q[85];
u1(0) q[85];
u1(0) q[152];
cx q[152],q[86];
u1(0) q[86];
cx q[152],q[86];
u1(0) q[86];
u1(0) q[152];
cx q[152],q[87];
u1(0) q[87];
cx q[152],q[87];
u1(0) q[87];
u1(0) q[152];
cx q[152],q[88];
u1(0) q[88];
cx q[152],q[88];
u1(0) q[88];
u1(0) q[152];
cx q[152],q[89];
u1(0) q[89];
cx q[152],q[89];
u1(0) q[89];
u1(0) q[152];
cx q[152],q[90];
u1(0) q[90];
cx q[152],q[90];
u1(0) q[90];
u1(0) q[152];
cx q[152],q[91];
u1(0) q[91];
cx q[152],q[91];
u1(0) q[91];
u1(0) q[152];
cx q[152],q[92];
u1(0) q[92];
cx q[152],q[92];
u1(0) q[92];
u1(0) q[152];
cx q[152],q[93];
u1(0) q[93];
cx q[152],q[93];
u1(0) q[93];
u1(0) q[152];
cx q[152],q[94];
u1(0) q[94];
cx q[152],q[94];
u1(0) q[94];
u1(0) q[152];
cx q[152],q[95];
u1(0) q[95];
cx q[152],q[95];
u1(0) q[95];
u1(0) q[152];
cx q[152],q[96];
u1(0) q[96];
cx q[152],q[96];
u1(0) q[96];
u1(0) q[152];
cx q[152],q[97];
u1(0) q[97];
cx q[152],q[97];
u1(0) q[97];
u1(0) q[152];
cx q[152],q[98];
u1(0) q[98];
cx q[152],q[98];
u1(0) q[98];
u1(0) q[152];
cx q[152],q[99];
u1(0) q[99];
cx q[152],q[99];
u1(0) q[99];
u1(0) q[152];
cx q[152],q[100];
u1(0) q[100];
cx q[152],q[100];
u1(0) q[100];
u1(0) q[152];
cx q[152],q[101];
u1(0) q[101];
cx q[152],q[101];
u1(0) q[101];
u1(0) q[152];
cx q[152],q[102];
u1(0) q[102];
cx q[152],q[102];
u1(0) q[102];
u1(0) q[152];
cx q[152],q[103];
u1(0) q[103];
cx q[152],q[103];
u1(0) q[103];
u1(0) q[152];
cx q[152],q[104];
u1(0) q[104];
cx q[152],q[104];
u1(0) q[104];
u1(pi/281474976710656) q[152];
cx q[152],q[105];
u1(-pi/281474976710656) q[105];
cx q[152],q[105];
u1(pi/281474976710656) q[105];
u1(pi/140737488355328) q[152];
cx q[152],q[106];
u1(-pi/140737488355328) q[106];
cx q[152],q[106];
u1(pi/140737488355328) q[106];
u1(pi/70368744177664) q[152];
cx q[152],q[107];
u1(-pi/70368744177664) q[107];
cx q[152],q[107];
u1(pi/70368744177664) q[107];
u1(pi/35184372088832) q[152];
cx q[152],q[108];
u1(-pi/35184372088832) q[108];
cx q[152],q[108];
u1(pi/35184372088832) q[108];
u1(pi/17592186044416) q[152];
cx q[152],q[109];
u1(-pi/17592186044416) q[109];
cx q[152],q[109];
u1(pi/17592186044416) q[109];
u1(pi/8796093022208) q[152];
cx q[152],q[110];
u1(-pi/8796093022208) q[110];
cx q[152],q[110];
u1(pi/8796093022208) q[110];
u1(pi/4398046511104) q[152];
cx q[152],q[111];
u1(-pi/4398046511104) q[111];
cx q[152],q[111];
u1(pi/4398046511104) q[111];
u1(pi/2199023255552) q[152];
cx q[152],q[112];
u1(-pi/2199023255552) q[112];
cx q[152],q[112];
u1(pi/2199023255552) q[112];
u1(pi/1099511627776) q[152];
cx q[152],q[113];
u1(-pi/1099511627776) q[113];
cx q[152],q[113];
u1(pi/1099511627776) q[113];
u1(pi/549755813888) q[152];
cx q[152],q[114];
u1(-pi/549755813888) q[114];
cx q[152],q[114];
u1(pi/549755813888) q[114];
u1(pi/274877906944) q[152];
cx q[152],q[115];
u1(-pi/274877906944) q[115];
cx q[152],q[115];
u1(pi/274877906944) q[115];
u1(pi/137438953472) q[152];
cx q[152],q[116];
u1(-pi/137438953472) q[116];
cx q[152],q[116];
u1(pi/137438953472) q[116];
u1(pi/68719476736) q[152];
cx q[152],q[117];
u1(-pi/68719476736) q[117];
cx q[152],q[117];
u1(pi/68719476736) q[117];
u1(pi/34359738368) q[152];
cx q[152],q[118];
u1(-pi/34359738368) q[118];
cx q[152],q[118];
u1(pi/34359738368) q[118];
u1(pi/17179869184) q[152];
cx q[152],q[119];
u1(-pi/17179869184) q[119];
cx q[152],q[119];
u1(pi/17179869184) q[119];
u1(pi/8589934592) q[152];
cx q[152],q[120];
u1(-pi/8589934592) q[120];
cx q[152],q[120];
u1(pi/8589934592) q[120];
u1(pi/4294967296) q[152];
cx q[152],q[121];
u1(-pi/4294967296) q[121];
cx q[152],q[121];
u1(pi/4294967296) q[121];
u1(pi/2147483648) q[152];
cx q[152],q[122];
u1(-pi/2147483648) q[122];
cx q[152],q[122];
u1(pi/2147483648) q[122];
u1(pi/1073741824) q[152];
cx q[152],q[123];
u1(-pi/1073741824) q[123];
cx q[152],q[123];
u1(pi/1073741824) q[123];
u1(pi/536870912) q[152];
cx q[152],q[124];
u1(-pi/536870912) q[124];
cx q[152],q[124];
u1(pi/536870912) q[124];
u1(pi/268435456) q[152];
cx q[152],q[125];
u1(-pi/268435456) q[125];
cx q[152],q[125];
u1(pi/268435456) q[125];
u1(pi/134217728) q[152];
cx q[152],q[126];
u1(-pi/134217728) q[126];
cx q[152],q[126];
u1(pi/134217728) q[126];
u1(pi/67108864) q[152];
cx q[152],q[127];
u1(-pi/67108864) q[127];
cx q[152],q[127];
u1(pi/67108864) q[127];
u1(pi/33554432) q[152];
cx q[152],q[128];
u1(-pi/33554432) q[128];
cx q[152],q[128];
u1(pi/33554432) q[128];
u1(pi/16777216) q[152];
cx q[152],q[129];
u1(-pi/16777216) q[129];
cx q[152],q[129];
u1(pi/16777216) q[129];
u1(pi/8388608) q[152];
cx q[152],q[130];
u1(-pi/8388608) q[130];
cx q[152],q[130];
u1(pi/8388608) q[130];
u1(pi/4194304) q[152];
cx q[152],q[131];
u1(-pi/4194304) q[131];
cx q[152],q[131];
u1(pi/4194304) q[131];
u1(pi/2097152) q[152];
cx q[152],q[132];
u1(-pi/2097152) q[132];
cx q[152],q[132];
u1(pi/2097152) q[132];
u1(pi/1048576) q[152];
cx q[152],q[133];
u1(-pi/1048576) q[133];
cx q[152],q[133];
u1(pi/1048576) q[133];
u1(pi/524288) q[152];
cx q[152],q[134];
u1(-pi/524288) q[134];
cx q[152],q[134];
u1(pi/524288) q[134];
u1(pi/262144) q[152];
cx q[152],q[135];
u1(-pi/262144) q[135];
cx q[152],q[135];
u1(pi/262144) q[135];
u1(pi/131072) q[152];
cx q[152],q[136];
u1(-pi/131072) q[136];
cx q[152],q[136];
u1(pi/131072) q[136];
u1(pi/65536) q[152];
cx q[152],q[137];
u1(-pi/65536) q[137];
cx q[152],q[137];
u1(pi/65536) q[137];
u1(pi/32768) q[152];
cx q[152],q[138];
u1(-pi/32768) q[138];
cx q[152],q[138];
u1(pi/32768) q[138];
u1(pi/16384) q[152];
cx q[152],q[139];
u1(-pi/16384) q[139];
cx q[152],q[139];
u1(pi/16384) q[139];
u1(pi/8192) q[152];
cx q[152],q[140];
u1(-pi/8192) q[140];
cx q[152],q[140];
u1(pi/8192) q[140];
u1(pi/4096) q[152];
cx q[152],q[141];
u1(-pi/4096) q[141];
cx q[152],q[141];
u1(pi/4096) q[141];
u1(pi/2048) q[152];
cx q[152],q[142];
u1(-pi/2048) q[142];
cx q[152],q[142];
u1(pi/2048) q[142];
u1(pi/1024) q[152];
cx q[152],q[143];
u1(-pi/1024) q[143];
cx q[152],q[143];
u1(pi/1024) q[143];
u1(pi/512) q[152];
cx q[152],q[144];
u1(-pi/512) q[144];
cx q[152],q[144];
u1(pi/512) q[144];
u1(pi/256) q[152];
cx q[152],q[145];
u1(-pi/256) q[145];
cx q[152],q[145];
u1(pi/256) q[145];
u1(pi/128) q[152];
cx q[152],q[146];
u1(-pi/128) q[146];
cx q[152],q[146];
u1(pi/128) q[146];
u1(pi/64) q[152];
cx q[152],q[147];
u1(-pi/64) q[147];
cx q[152],q[147];
u1(pi/64) q[147];
u1(pi/32) q[152];
cx q[152],q[148];
u1(-pi/32) q[148];
cx q[152],q[148];
u1(pi/32) q[148];
u1(pi/16) q[152];
cx q[152],q[149];
u1(-pi/16) q[149];
cx q[152],q[149];
u1(pi/16) q[149];
u1(pi/8) q[152];
cx q[152],q[150];
u1(-pi/8) q[150];
cx q[152],q[150];
u1(pi/8) q[150];
u1(pi/4) q[152];
cx q[152],q[151];
u1(-pi/4) q[151];
cx q[152],q[151];
u1(pi/4) q[151];
h q[152];
u1(0) q[153];
cx q[153],q[0];
u1(0) q[0];
cx q[153],q[0];
u1(0) q[0];
u1(0) q[153];
cx q[153],q[1];
u1(0) q[1];
cx q[153],q[1];
u1(0) q[1];
u1(0) q[153];
cx q[153],q[2];
u1(0) q[2];
cx q[153],q[2];
u1(0) q[2];
u1(0) q[153];
cx q[153],q[3];
u1(0) q[3];
cx q[153],q[3];
u1(0) q[3];
u1(0) q[153];
cx q[153],q[4];
u1(0) q[4];
cx q[153],q[4];
u1(0) q[4];
u1(0) q[153];
cx q[153],q[5];
u1(0) q[5];
cx q[153],q[5];
u1(0) q[5];
u1(0) q[153];
cx q[153],q[6];
u1(0) q[6];
cx q[153],q[6];
u1(0) q[6];
u1(0) q[153];
cx q[153],q[7];
u1(0) q[7];
cx q[153],q[7];
u1(0) q[7];
u1(0) q[153];
cx q[153],q[8];
u1(0) q[8];
cx q[153],q[8];
u1(0) q[8];
u1(0) q[153];
cx q[153],q[9];
u1(0) q[9];
cx q[153],q[9];
u1(0) q[9];
u1(0) q[153];
cx q[153],q[10];
u1(0) q[10];
cx q[153],q[10];
u1(0) q[10];
u1(0) q[153];
cx q[153],q[11];
u1(0) q[11];
cx q[153],q[11];
u1(0) q[11];
u1(0) q[153];
cx q[153],q[12];
u1(0) q[12];
cx q[153],q[12];
u1(0) q[12];
u1(0) q[153];
cx q[153],q[13];
u1(0) q[13];
cx q[153],q[13];
u1(0) q[13];
u1(0) q[153];
cx q[153],q[14];
u1(0) q[14];
cx q[153],q[14];
u1(0) q[14];
u1(0) q[153];
cx q[153],q[15];
u1(0) q[15];
cx q[153],q[15];
u1(0) q[15];
u1(0) q[153];
cx q[153],q[16];
u1(0) q[16];
cx q[153],q[16];
u1(0) q[16];
u1(0) q[153];
cx q[153],q[17];
u1(0) q[17];
cx q[153],q[17];
u1(0) q[17];
u1(0) q[153];
cx q[153],q[18];
u1(0) q[18];
cx q[153],q[18];
u1(0) q[18];
u1(0) q[153];
cx q[153],q[19];
u1(0) q[19];
cx q[153],q[19];
u1(0) q[19];
u1(0) q[153];
cx q[153],q[20];
u1(0) q[20];
cx q[153],q[20];
u1(0) q[20];
u1(0) q[153];
cx q[153],q[21];
u1(0) q[21];
cx q[153],q[21];
u1(0) q[21];
u1(0) q[153];
cx q[153],q[22];
u1(0) q[22];
cx q[153],q[22];
u1(0) q[22];
u1(0) q[153];
cx q[153],q[23];
u1(0) q[23];
cx q[153],q[23];
u1(0) q[23];
u1(0) q[153];
cx q[153],q[24];
u1(0) q[24];
cx q[153],q[24];
u1(0) q[24];
u1(0) q[153];
cx q[153],q[25];
u1(0) q[25];
cx q[153],q[25];
u1(0) q[25];
u1(0) q[153];
cx q[153],q[26];
u1(0) q[26];
cx q[153],q[26];
u1(0) q[26];
u1(0) q[153];
cx q[153],q[27];
u1(0) q[27];
cx q[153],q[27];
u1(0) q[27];
u1(0) q[153];
cx q[153],q[28];
u1(0) q[28];
cx q[153],q[28];
u1(0) q[28];
u1(0) q[153];
cx q[153],q[29];
u1(0) q[29];
cx q[153],q[29];
u1(0) q[29];
u1(0) q[153];
cx q[153],q[30];
u1(0) q[30];
cx q[153],q[30];
u1(0) q[30];
u1(0) q[153];
cx q[153],q[31];
u1(0) q[31];
cx q[153],q[31];
u1(0) q[31];
u1(0) q[153];
cx q[153],q[32];
u1(0) q[32];
cx q[153],q[32];
u1(0) q[32];
u1(0) q[153];
cx q[153],q[33];
u1(0) q[33];
cx q[153],q[33];
u1(0) q[33];
u1(0) q[153];
cx q[153],q[34];
u1(0) q[34];
cx q[153],q[34];
u1(0) q[34];
u1(0) q[153];
cx q[153],q[35];
u1(0) q[35];
cx q[153],q[35];
u1(0) q[35];
u1(0) q[153];
cx q[153],q[36];
u1(0) q[36];
cx q[153],q[36];
u1(0) q[36];
u1(0) q[153];
cx q[153],q[37];
u1(0) q[37];
cx q[153],q[37];
u1(0) q[37];
u1(0) q[153];
cx q[153],q[38];
u1(0) q[38];
cx q[153],q[38];
u1(0) q[38];
u1(0) q[153];
cx q[153],q[39];
u1(0) q[39];
cx q[153],q[39];
u1(0) q[39];
u1(0) q[153];
cx q[153],q[40];
u1(0) q[40];
cx q[153],q[40];
u1(0) q[40];
u1(0) q[153];
cx q[153],q[41];
u1(0) q[41];
cx q[153],q[41];
u1(0) q[41];
u1(0) q[153];
cx q[153],q[42];
u1(0) q[42];
cx q[153],q[42];
u1(0) q[42];
u1(0) q[153];
cx q[153],q[43];
u1(0) q[43];
cx q[153],q[43];
u1(0) q[43];
u1(0) q[153];
cx q[153],q[44];
u1(0) q[44];
cx q[153],q[44];
u1(0) q[44];
u1(0) q[153];
cx q[153],q[45];
u1(0) q[45];
cx q[153],q[45];
u1(0) q[45];
u1(0) q[153];
cx q[153],q[46];
u1(0) q[46];
cx q[153],q[46];
u1(0) q[46];
u1(0) q[153];
cx q[153],q[47];
u1(0) q[47];
cx q[153],q[47];
u1(0) q[47];
u1(0) q[153];
cx q[153],q[48];
u1(0) q[48];
cx q[153],q[48];
u1(0) q[48];
u1(0) q[153];
cx q[153],q[49];
u1(0) q[49];
cx q[153],q[49];
u1(0) q[49];
u1(0) q[153];
cx q[153],q[50];
u1(0) q[50];
cx q[153],q[50];
u1(0) q[50];
u1(0) q[153];
cx q[153],q[51];
u1(0) q[51];
cx q[153],q[51];
u1(0) q[51];
u1(0) q[153];
cx q[153],q[52];
u1(0) q[52];
cx q[153],q[52];
u1(0) q[52];
u1(0) q[153];
cx q[153],q[53];
u1(0) q[53];
cx q[153],q[53];
u1(0) q[53];
u1(0) q[153];
cx q[153],q[54];
u1(0) q[54];
cx q[153],q[54];
u1(0) q[54];
u1(0) q[153];
cx q[153],q[55];
u1(0) q[55];
cx q[153],q[55];
u1(0) q[55];
u1(0) q[153];
cx q[153],q[56];
u1(0) q[56];
cx q[153],q[56];
u1(0) q[56];
u1(0) q[153];
cx q[153],q[57];
u1(0) q[57];
cx q[153],q[57];
u1(0) q[57];
u1(0) q[153];
cx q[153],q[58];
u1(0) q[58];
cx q[153],q[58];
u1(0) q[58];
u1(0) q[153];
cx q[153],q[59];
u1(0) q[59];
cx q[153],q[59];
u1(0) q[59];
u1(0) q[153];
cx q[153],q[60];
u1(0) q[60];
cx q[153],q[60];
u1(0) q[60];
u1(0) q[153];
cx q[153],q[61];
u1(0) q[61];
cx q[153],q[61];
u1(0) q[61];
u1(0) q[153];
cx q[153],q[62];
u1(0) q[62];
cx q[153],q[62];
u1(0) q[62];
u1(0) q[153];
cx q[153],q[63];
u1(0) q[63];
cx q[153],q[63];
u1(0) q[63];
u1(0) q[153];
cx q[153],q[64];
u1(0) q[64];
cx q[153],q[64];
u1(0) q[64];
u1(0) q[153];
cx q[153],q[65];
u1(0) q[65];
cx q[153],q[65];
u1(0) q[65];
u1(0) q[153];
cx q[153],q[66];
u1(0) q[66];
cx q[153],q[66];
u1(0) q[66];
u1(0) q[153];
cx q[153],q[67];
u1(0) q[67];
cx q[153],q[67];
u1(0) q[67];
u1(0) q[153];
cx q[153],q[68];
u1(0) q[68];
cx q[153],q[68];
u1(0) q[68];
u1(0) q[153];
cx q[153],q[69];
u1(0) q[69];
cx q[153],q[69];
u1(0) q[69];
u1(0) q[153];
cx q[153],q[70];
u1(0) q[70];
cx q[153],q[70];
u1(0) q[70];
u1(0) q[153];
cx q[153],q[71];
u1(0) q[71];
cx q[153],q[71];
u1(0) q[71];
u1(0) q[153];
cx q[153],q[72];
u1(0) q[72];
cx q[153],q[72];
u1(0) q[72];
u1(0) q[153];
cx q[153],q[73];
u1(0) q[73];
cx q[153],q[73];
u1(0) q[73];
u1(0) q[153];
cx q[153],q[74];
u1(0) q[74];
cx q[153],q[74];
u1(0) q[74];
u1(0) q[153];
cx q[153],q[75];
u1(0) q[75];
cx q[153],q[75];
u1(0) q[75];
u1(0) q[153];
cx q[153],q[76];
u1(0) q[76];
cx q[153],q[76];
u1(0) q[76];
u1(0) q[153];
cx q[153],q[77];
u1(0) q[77];
cx q[153],q[77];
u1(0) q[77];
u1(0) q[153];
cx q[153],q[78];
u1(0) q[78];
cx q[153],q[78];
u1(0) q[78];
u1(0) q[153];
cx q[153],q[79];
u1(0) q[79];
cx q[153],q[79];
u1(0) q[79];
u1(0) q[153];
cx q[153],q[80];
u1(0) q[80];
cx q[153],q[80];
u1(0) q[80];
u1(0) q[153];
cx q[153],q[81];
u1(0) q[81];
cx q[153],q[81];
u1(0) q[81];
u1(0) q[153];
cx q[153],q[82];
u1(0) q[82];
cx q[153],q[82];
u1(0) q[82];
u1(0) q[153];
cx q[153],q[83];
u1(0) q[83];
cx q[153],q[83];
u1(0) q[83];
u1(0) q[153];
cx q[153],q[84];
u1(0) q[84];
cx q[153],q[84];
u1(0) q[84];
u1(0) q[153];
cx q[153],q[85];
u1(0) q[85];
cx q[153],q[85];
u1(0) q[85];
u1(0) q[153];
cx q[153],q[86];
u1(0) q[86];
cx q[153],q[86];
u1(0) q[86];
u1(0) q[153];
cx q[153],q[87];
u1(0) q[87];
cx q[153],q[87];
u1(0) q[87];
u1(0) q[153];
cx q[153],q[88];
u1(0) q[88];
cx q[153],q[88];
u1(0) q[88];
u1(0) q[153];
cx q[153],q[89];
u1(0) q[89];
cx q[153],q[89];
u1(0) q[89];
u1(0) q[153];
cx q[153],q[90];
u1(0) q[90];
cx q[153],q[90];
u1(0) q[90];
u1(0) q[153];
cx q[153],q[91];
u1(0) q[91];
cx q[153],q[91];
u1(0) q[91];
u1(0) q[153];
cx q[153],q[92];
u1(0) q[92];
cx q[153],q[92];
u1(0) q[92];
u1(0) q[153];
cx q[153],q[93];
u1(0) q[93];
cx q[153],q[93];
u1(0) q[93];
u1(0) q[153];
cx q[153],q[94];
u1(0) q[94];
cx q[153],q[94];
u1(0) q[94];
u1(0) q[153];
cx q[153],q[95];
u1(0) q[95];
cx q[153],q[95];
u1(0) q[95];
u1(0) q[153];
cx q[153],q[96];
u1(0) q[96];
cx q[153],q[96];
u1(0) q[96];
u1(0) q[153];
cx q[153],q[97];
u1(0) q[97];
cx q[153],q[97];
u1(0) q[97];
u1(0) q[153];
cx q[153],q[98];
u1(0) q[98];
cx q[153],q[98];
u1(0) q[98];
u1(0) q[153];
cx q[153],q[99];
u1(0) q[99];
cx q[153],q[99];
u1(0) q[99];
u1(0) q[153];
cx q[153],q[100];
u1(0) q[100];
cx q[153],q[100];
u1(0) q[100];
u1(0) q[153];
cx q[153],q[101];
u1(0) q[101];
cx q[153],q[101];
u1(0) q[101];
u1(0) q[153];
cx q[153],q[102];
u1(0) q[102];
cx q[153],q[102];
u1(0) q[102];
u1(0) q[153];
cx q[153],q[103];
u1(0) q[103];
cx q[153],q[103];
u1(0) q[103];
u1(0) q[153];
cx q[153],q[104];
u1(0) q[104];
cx q[153],q[104];
u1(0) q[104];
u1(0) q[153];
cx q[153],q[105];
u1(0) q[105];
cx q[153],q[105];
u1(0) q[105];
u1(pi/281474976710656) q[153];
cx q[153],q[106];
u1(-pi/281474976710656) q[106];
cx q[153],q[106];
u1(pi/281474976710656) q[106];
u1(pi/140737488355328) q[153];
cx q[153],q[107];
u1(-pi/140737488355328) q[107];
cx q[153],q[107];
u1(pi/140737488355328) q[107];
u1(pi/70368744177664) q[153];
cx q[153],q[108];
u1(-pi/70368744177664) q[108];
cx q[153],q[108];
u1(pi/70368744177664) q[108];
u1(pi/35184372088832) q[153];
cx q[153],q[109];
u1(-pi/35184372088832) q[109];
cx q[153],q[109];
u1(pi/35184372088832) q[109];
u1(pi/17592186044416) q[153];
cx q[153],q[110];
u1(-pi/17592186044416) q[110];
cx q[153],q[110];
u1(pi/17592186044416) q[110];
u1(pi/8796093022208) q[153];
cx q[153],q[111];
u1(-pi/8796093022208) q[111];
cx q[153],q[111];
u1(pi/8796093022208) q[111];
u1(pi/4398046511104) q[153];
cx q[153],q[112];
u1(-pi/4398046511104) q[112];
cx q[153],q[112];
u1(pi/4398046511104) q[112];
u1(pi/2199023255552) q[153];
cx q[153],q[113];
u1(-pi/2199023255552) q[113];
cx q[153],q[113];
u1(pi/2199023255552) q[113];
u1(pi/1099511627776) q[153];
cx q[153],q[114];
u1(-pi/1099511627776) q[114];
cx q[153],q[114];
u1(pi/1099511627776) q[114];
u1(pi/549755813888) q[153];
cx q[153],q[115];
u1(-pi/549755813888) q[115];
cx q[153],q[115];
u1(pi/549755813888) q[115];
u1(pi/274877906944) q[153];
cx q[153],q[116];
u1(-pi/274877906944) q[116];
cx q[153],q[116];
u1(pi/274877906944) q[116];
u1(pi/137438953472) q[153];
cx q[153],q[117];
u1(-pi/137438953472) q[117];
cx q[153],q[117];
u1(pi/137438953472) q[117];
u1(pi/68719476736) q[153];
cx q[153],q[118];
u1(-pi/68719476736) q[118];
cx q[153],q[118];
u1(pi/68719476736) q[118];
u1(pi/34359738368) q[153];
cx q[153],q[119];
u1(-pi/34359738368) q[119];
cx q[153],q[119];
u1(pi/34359738368) q[119];
u1(pi/17179869184) q[153];
cx q[153],q[120];
u1(-pi/17179869184) q[120];
cx q[153],q[120];
u1(pi/17179869184) q[120];
u1(pi/8589934592) q[153];
cx q[153],q[121];
u1(-pi/8589934592) q[121];
cx q[153],q[121];
u1(pi/8589934592) q[121];
u1(pi/4294967296) q[153];
cx q[153],q[122];
u1(-pi/4294967296) q[122];
cx q[153],q[122];
u1(pi/4294967296) q[122];
u1(pi/2147483648) q[153];
cx q[153],q[123];
u1(-pi/2147483648) q[123];
cx q[153],q[123];
u1(pi/2147483648) q[123];
u1(pi/1073741824) q[153];
cx q[153],q[124];
u1(-pi/1073741824) q[124];
cx q[153],q[124];
u1(pi/1073741824) q[124];
u1(pi/536870912) q[153];
cx q[153],q[125];
u1(-pi/536870912) q[125];
cx q[153],q[125];
u1(pi/536870912) q[125];
u1(pi/268435456) q[153];
cx q[153],q[126];
u1(-pi/268435456) q[126];
cx q[153],q[126];
u1(pi/268435456) q[126];
u1(pi/134217728) q[153];
cx q[153],q[127];
u1(-pi/134217728) q[127];
cx q[153],q[127];
u1(pi/134217728) q[127];
u1(pi/67108864) q[153];
cx q[153],q[128];
u1(-pi/67108864) q[128];
cx q[153],q[128];
u1(pi/67108864) q[128];
u1(pi/33554432) q[153];
cx q[153],q[129];
u1(-pi/33554432) q[129];
cx q[153],q[129];
u1(pi/33554432) q[129];
u1(pi/16777216) q[153];
cx q[153],q[130];
u1(-pi/16777216) q[130];
cx q[153],q[130];
u1(pi/16777216) q[130];
u1(pi/8388608) q[153];
cx q[153],q[131];
u1(-pi/8388608) q[131];
cx q[153],q[131];
u1(pi/8388608) q[131];
u1(pi/4194304) q[153];
cx q[153],q[132];
u1(-pi/4194304) q[132];
cx q[153],q[132];
u1(pi/4194304) q[132];
u1(pi/2097152) q[153];
cx q[153],q[133];
u1(-pi/2097152) q[133];
cx q[153],q[133];
u1(pi/2097152) q[133];
u1(pi/1048576) q[153];
cx q[153],q[134];
u1(-pi/1048576) q[134];
cx q[153],q[134];
u1(pi/1048576) q[134];
u1(pi/524288) q[153];
cx q[153],q[135];
u1(-pi/524288) q[135];
cx q[153],q[135];
u1(pi/524288) q[135];
u1(pi/262144) q[153];
cx q[153],q[136];
u1(-pi/262144) q[136];
cx q[153],q[136];
u1(pi/262144) q[136];
u1(pi/131072) q[153];
cx q[153],q[137];
u1(-pi/131072) q[137];
cx q[153],q[137];
u1(pi/131072) q[137];
u1(pi/65536) q[153];
cx q[153],q[138];
u1(-pi/65536) q[138];
cx q[153],q[138];
u1(pi/65536) q[138];
u1(pi/32768) q[153];
cx q[153],q[139];
u1(-pi/32768) q[139];
cx q[153],q[139];
u1(pi/32768) q[139];
u1(pi/16384) q[153];
cx q[153],q[140];
u1(-pi/16384) q[140];
cx q[153],q[140];
u1(pi/16384) q[140];
u1(pi/8192) q[153];
cx q[153],q[141];
u1(-pi/8192) q[141];
cx q[153],q[141];
u1(pi/8192) q[141];
u1(pi/4096) q[153];
cx q[153],q[142];
u1(-pi/4096) q[142];
cx q[153],q[142];
u1(pi/4096) q[142];
u1(pi/2048) q[153];
cx q[153],q[143];
u1(-pi/2048) q[143];
cx q[153],q[143];
u1(pi/2048) q[143];
u1(pi/1024) q[153];
cx q[153],q[144];
u1(-pi/1024) q[144];
cx q[153],q[144];
u1(pi/1024) q[144];
u1(pi/512) q[153];
cx q[153],q[145];
u1(-pi/512) q[145];
cx q[153],q[145];
u1(pi/512) q[145];
u1(pi/256) q[153];
cx q[153],q[146];
u1(-pi/256) q[146];
cx q[153],q[146];
u1(pi/256) q[146];
u1(pi/128) q[153];
cx q[153],q[147];
u1(-pi/128) q[147];
cx q[153],q[147];
u1(pi/128) q[147];
u1(pi/64) q[153];
cx q[153],q[148];
u1(-pi/64) q[148];
cx q[153],q[148];
u1(pi/64) q[148];
u1(pi/32) q[153];
cx q[153],q[149];
u1(-pi/32) q[149];
cx q[153],q[149];
u1(pi/32) q[149];
u1(pi/16) q[153];
cx q[153],q[150];
u1(-pi/16) q[150];
cx q[153],q[150];
u1(pi/16) q[150];
u1(pi/8) q[153];
cx q[153],q[151];
u1(-pi/8) q[151];
cx q[153],q[151];
u1(pi/8) q[151];
u1(pi/4) q[153];
cx q[153],q[152];
u1(-pi/4) q[152];
cx q[153],q[152];
u1(pi/4) q[152];
h q[153];
u1(0) q[154];
cx q[154],q[0];
u1(0) q[0];
cx q[154],q[0];
u1(0) q[0];
u1(0) q[154];
cx q[154],q[1];
u1(0) q[1];
cx q[154],q[1];
u1(0) q[1];
u1(0) q[154];
cx q[154],q[2];
u1(0) q[2];
cx q[154],q[2];
u1(0) q[2];
u1(0) q[154];
cx q[154],q[3];
u1(0) q[3];
cx q[154],q[3];
u1(0) q[3];
u1(0) q[154];
cx q[154],q[4];
u1(0) q[4];
cx q[154],q[4];
u1(0) q[4];
u1(0) q[154];
cx q[154],q[5];
u1(0) q[5];
cx q[154],q[5];
u1(0) q[5];
u1(0) q[154];
cx q[154],q[6];
u1(0) q[6];
cx q[154],q[6];
u1(0) q[6];
u1(0) q[154];
cx q[154],q[7];
u1(0) q[7];
cx q[154],q[7];
u1(0) q[7];
u1(0) q[154];
cx q[154],q[8];
u1(0) q[8];
cx q[154],q[8];
u1(0) q[8];
u1(0) q[154];
cx q[154],q[9];
u1(0) q[9];
cx q[154],q[9];
u1(0) q[9];
u1(0) q[154];
cx q[154],q[10];
u1(0) q[10];
cx q[154],q[10];
u1(0) q[10];
u1(0) q[154];
cx q[154],q[11];
u1(0) q[11];
cx q[154],q[11];
u1(0) q[11];
u1(0) q[154];
cx q[154],q[12];
u1(0) q[12];
cx q[154],q[12];
u1(0) q[12];
u1(0) q[154];
cx q[154],q[13];
u1(0) q[13];
cx q[154],q[13];
u1(0) q[13];
u1(0) q[154];
cx q[154],q[14];
u1(0) q[14];
cx q[154],q[14];
u1(0) q[14];
u1(0) q[154];
cx q[154],q[15];
u1(0) q[15];
cx q[154],q[15];
u1(0) q[15];
u1(0) q[154];
cx q[154],q[16];
u1(0) q[16];
cx q[154],q[16];
u1(0) q[16];
u1(0) q[154];
cx q[154],q[17];
u1(0) q[17];
cx q[154],q[17];
u1(0) q[17];
u1(0) q[154];
cx q[154],q[18];
u1(0) q[18];
cx q[154],q[18];
u1(0) q[18];
u1(0) q[154];
cx q[154],q[19];
u1(0) q[19];
cx q[154],q[19];
u1(0) q[19];
u1(0) q[154];
cx q[154],q[20];
u1(0) q[20];
cx q[154],q[20];
u1(0) q[20];
u1(0) q[154];
cx q[154],q[21];
u1(0) q[21];
cx q[154],q[21];
u1(0) q[21];
u1(0) q[154];
cx q[154],q[22];
u1(0) q[22];
cx q[154],q[22];
u1(0) q[22];
u1(0) q[154];
cx q[154],q[23];
u1(0) q[23];
cx q[154],q[23];
u1(0) q[23];
u1(0) q[154];
cx q[154],q[24];
u1(0) q[24];
cx q[154],q[24];
u1(0) q[24];
u1(0) q[154];
cx q[154],q[25];
u1(0) q[25];
cx q[154],q[25];
u1(0) q[25];
u1(0) q[154];
cx q[154],q[26];
u1(0) q[26];
cx q[154],q[26];
u1(0) q[26];
u1(0) q[154];
cx q[154],q[27];
u1(0) q[27];
cx q[154],q[27];
u1(0) q[27];
u1(0) q[154];
cx q[154],q[28];
u1(0) q[28];
cx q[154],q[28];
u1(0) q[28];
u1(0) q[154];
cx q[154],q[29];
u1(0) q[29];
cx q[154],q[29];
u1(0) q[29];
u1(0) q[154];
cx q[154],q[30];
u1(0) q[30];
cx q[154],q[30];
u1(0) q[30];
u1(0) q[154];
cx q[154],q[31];
u1(0) q[31];
cx q[154],q[31];
u1(0) q[31];
u1(0) q[154];
cx q[154],q[32];
u1(0) q[32];
cx q[154],q[32];
u1(0) q[32];
u1(0) q[154];
cx q[154],q[33];
u1(0) q[33];
cx q[154],q[33];
u1(0) q[33];
u1(0) q[154];
cx q[154],q[34];
u1(0) q[34];
cx q[154],q[34];
u1(0) q[34];
u1(0) q[154];
cx q[154],q[35];
u1(0) q[35];
cx q[154],q[35];
u1(0) q[35];
u1(0) q[154];
cx q[154],q[36];
u1(0) q[36];
cx q[154],q[36];
u1(0) q[36];
u1(0) q[154];
cx q[154],q[37];
u1(0) q[37];
cx q[154],q[37];
u1(0) q[37];
u1(0) q[154];
cx q[154],q[38];
u1(0) q[38];
cx q[154],q[38];
u1(0) q[38];
u1(0) q[154];
cx q[154],q[39];
u1(0) q[39];
cx q[154],q[39];
u1(0) q[39];
u1(0) q[154];
cx q[154],q[40];
u1(0) q[40];
cx q[154],q[40];
u1(0) q[40];
u1(0) q[154];
cx q[154],q[41];
u1(0) q[41];
cx q[154],q[41];
u1(0) q[41];
u1(0) q[154];
cx q[154],q[42];
u1(0) q[42];
cx q[154],q[42];
u1(0) q[42];
u1(0) q[154];
cx q[154],q[43];
u1(0) q[43];
cx q[154],q[43];
u1(0) q[43];
u1(0) q[154];
cx q[154],q[44];
u1(0) q[44];
cx q[154],q[44];
u1(0) q[44];
u1(0) q[154];
cx q[154],q[45];
u1(0) q[45];
cx q[154],q[45];
u1(0) q[45];
u1(0) q[154];
cx q[154],q[46];
u1(0) q[46];
cx q[154],q[46];
u1(0) q[46];
u1(0) q[154];
cx q[154],q[47];
u1(0) q[47];
cx q[154],q[47];
u1(0) q[47];
u1(0) q[154];
cx q[154],q[48];
u1(0) q[48];
cx q[154],q[48];
u1(0) q[48];
u1(0) q[154];
cx q[154],q[49];
u1(0) q[49];
cx q[154],q[49];
u1(0) q[49];
u1(0) q[154];
cx q[154],q[50];
u1(0) q[50];
cx q[154],q[50];
u1(0) q[50];
u1(0) q[154];
cx q[154],q[51];
u1(0) q[51];
cx q[154],q[51];
u1(0) q[51];
u1(0) q[154];
cx q[154],q[52];
u1(0) q[52];
cx q[154],q[52];
u1(0) q[52];
u1(0) q[154];
cx q[154],q[53];
u1(0) q[53];
cx q[154],q[53];
u1(0) q[53];
u1(0) q[154];
cx q[154],q[54];
u1(0) q[54];
cx q[154],q[54];
u1(0) q[54];
u1(0) q[154];
cx q[154],q[55];
u1(0) q[55];
cx q[154],q[55];
u1(0) q[55];
u1(0) q[154];
cx q[154],q[56];
u1(0) q[56];
cx q[154],q[56];
u1(0) q[56];
u1(0) q[154];
cx q[154],q[57];
u1(0) q[57];
cx q[154],q[57];
u1(0) q[57];
u1(0) q[154];
cx q[154],q[58];
u1(0) q[58];
cx q[154],q[58];
u1(0) q[58];
u1(0) q[154];
cx q[154],q[59];
u1(0) q[59];
cx q[154],q[59];
u1(0) q[59];
u1(0) q[154];
cx q[154],q[60];
u1(0) q[60];
cx q[154],q[60];
u1(0) q[60];
u1(0) q[154];
cx q[154],q[61];
u1(0) q[61];
cx q[154],q[61];
u1(0) q[61];
u1(0) q[154];
cx q[154],q[62];
u1(0) q[62];
cx q[154],q[62];
u1(0) q[62];
u1(0) q[154];
cx q[154],q[63];
u1(0) q[63];
cx q[154],q[63];
u1(0) q[63];
u1(0) q[154];
cx q[154],q[64];
u1(0) q[64];
cx q[154],q[64];
u1(0) q[64];
u1(0) q[154];
cx q[154],q[65];
u1(0) q[65];
cx q[154],q[65];
u1(0) q[65];
u1(0) q[154];
cx q[154],q[66];
u1(0) q[66];
cx q[154],q[66];
u1(0) q[66];
u1(0) q[154];
cx q[154],q[67];
u1(0) q[67];
cx q[154],q[67];
u1(0) q[67];
u1(0) q[154];
cx q[154],q[68];
u1(0) q[68];
cx q[154],q[68];
u1(0) q[68];
u1(0) q[154];
cx q[154],q[69];
u1(0) q[69];
cx q[154],q[69];
u1(0) q[69];
u1(0) q[154];
cx q[154],q[70];
u1(0) q[70];
cx q[154],q[70];
u1(0) q[70];
u1(0) q[154];
cx q[154],q[71];
u1(0) q[71];
cx q[154],q[71];
u1(0) q[71];
u1(0) q[154];
cx q[154],q[72];
u1(0) q[72];
cx q[154],q[72];
u1(0) q[72];
u1(0) q[154];
cx q[154],q[73];
u1(0) q[73];
cx q[154],q[73];
u1(0) q[73];
u1(0) q[154];
cx q[154],q[74];
u1(0) q[74];
cx q[154],q[74];
u1(0) q[74];
u1(0) q[154];
cx q[154],q[75];
u1(0) q[75];
cx q[154],q[75];
u1(0) q[75];
u1(0) q[154];
cx q[154],q[76];
u1(0) q[76];
cx q[154],q[76];
u1(0) q[76];
u1(0) q[154];
cx q[154],q[77];
u1(0) q[77];
cx q[154],q[77];
u1(0) q[77];
u1(0) q[154];
cx q[154],q[78];
u1(0) q[78];
cx q[154],q[78];
u1(0) q[78];
u1(0) q[154];
cx q[154],q[79];
u1(0) q[79];
cx q[154],q[79];
u1(0) q[79];
u1(0) q[154];
cx q[154],q[80];
u1(0) q[80];
cx q[154],q[80];
u1(0) q[80];
u1(0) q[154];
cx q[154],q[81];
u1(0) q[81];
cx q[154],q[81];
u1(0) q[81];
u1(0) q[154];
cx q[154],q[82];
u1(0) q[82];
cx q[154],q[82];
u1(0) q[82];
u1(0) q[154];
cx q[154],q[83];
u1(0) q[83];
cx q[154],q[83];
u1(0) q[83];
u1(0) q[154];
cx q[154],q[84];
u1(0) q[84];
cx q[154],q[84];
u1(0) q[84];
u1(0) q[154];
cx q[154],q[85];
u1(0) q[85];
cx q[154],q[85];
u1(0) q[85];
u1(0) q[154];
cx q[154],q[86];
u1(0) q[86];
cx q[154],q[86];
u1(0) q[86];
u1(0) q[154];
cx q[154],q[87];
u1(0) q[87];
cx q[154],q[87];
u1(0) q[87];
u1(0) q[154];
cx q[154],q[88];
u1(0) q[88];
cx q[154],q[88];
u1(0) q[88];
u1(0) q[154];
cx q[154],q[89];
u1(0) q[89];
cx q[154],q[89];
u1(0) q[89];
u1(0) q[154];
cx q[154],q[90];
u1(0) q[90];
cx q[154],q[90];
u1(0) q[90];
u1(0) q[154];
cx q[154],q[91];
u1(0) q[91];
cx q[154],q[91];
u1(0) q[91];
u1(0) q[154];
cx q[154],q[92];
u1(0) q[92];
cx q[154],q[92];
u1(0) q[92];
u1(0) q[154];
cx q[154],q[93];
u1(0) q[93];
cx q[154],q[93];
u1(0) q[93];
u1(0) q[154];
cx q[154],q[94];
u1(0) q[94];
cx q[154],q[94];
u1(0) q[94];
u1(0) q[154];
cx q[154],q[95];
u1(0) q[95];
cx q[154],q[95];
u1(0) q[95];
u1(0) q[154];
cx q[154],q[96];
u1(0) q[96];
cx q[154],q[96];
u1(0) q[96];
u1(0) q[154];
cx q[154],q[97];
u1(0) q[97];
cx q[154],q[97];
u1(0) q[97];
u1(0) q[154];
cx q[154],q[98];
u1(0) q[98];
cx q[154],q[98];
u1(0) q[98];
u1(0) q[154];
cx q[154],q[99];
u1(0) q[99];
cx q[154],q[99];
u1(0) q[99];
u1(0) q[154];
cx q[154],q[100];
u1(0) q[100];
cx q[154],q[100];
u1(0) q[100];
u1(0) q[154];
cx q[154],q[101];
u1(0) q[101];
cx q[154],q[101];
u1(0) q[101];
u1(0) q[154];
cx q[154],q[102];
u1(0) q[102];
cx q[154],q[102];
u1(0) q[102];
u1(0) q[154];
cx q[154],q[103];
u1(0) q[103];
cx q[154],q[103];
u1(0) q[103];
u1(0) q[154];
cx q[154],q[104];
u1(0) q[104];
cx q[154],q[104];
u1(0) q[104];
u1(0) q[154];
cx q[154],q[105];
u1(0) q[105];
cx q[154],q[105];
u1(0) q[105];
u1(0) q[154];
cx q[154],q[106];
u1(0) q[106];
cx q[154],q[106];
u1(0) q[106];
u1(pi/281474976710656) q[154];
cx q[154],q[107];
u1(-pi/281474976710656) q[107];
cx q[154],q[107];
u1(pi/281474976710656) q[107];
u1(pi/140737488355328) q[154];
cx q[154],q[108];
u1(-pi/140737488355328) q[108];
cx q[154],q[108];
u1(pi/140737488355328) q[108];
u1(pi/70368744177664) q[154];
cx q[154],q[109];
u1(-pi/70368744177664) q[109];
cx q[154],q[109];
u1(pi/70368744177664) q[109];
u1(pi/35184372088832) q[154];
cx q[154],q[110];
u1(-pi/35184372088832) q[110];
cx q[154],q[110];
u1(pi/35184372088832) q[110];
u1(pi/17592186044416) q[154];
cx q[154],q[111];
u1(-pi/17592186044416) q[111];
cx q[154],q[111];
u1(pi/17592186044416) q[111];
u1(pi/8796093022208) q[154];
cx q[154],q[112];
u1(-pi/8796093022208) q[112];
cx q[154],q[112];
u1(pi/8796093022208) q[112];
u1(pi/4398046511104) q[154];
cx q[154],q[113];
u1(-pi/4398046511104) q[113];
cx q[154],q[113];
u1(pi/4398046511104) q[113];
u1(pi/2199023255552) q[154];
cx q[154],q[114];
u1(-pi/2199023255552) q[114];
cx q[154],q[114];
u1(pi/2199023255552) q[114];
u1(pi/1099511627776) q[154];
cx q[154],q[115];
u1(-pi/1099511627776) q[115];
cx q[154],q[115];
u1(pi/1099511627776) q[115];
u1(pi/549755813888) q[154];
cx q[154],q[116];
u1(-pi/549755813888) q[116];
cx q[154],q[116];
u1(pi/549755813888) q[116];
u1(pi/274877906944) q[154];
cx q[154],q[117];
u1(-pi/274877906944) q[117];
cx q[154],q[117];
u1(pi/274877906944) q[117];
u1(pi/137438953472) q[154];
cx q[154],q[118];
u1(-pi/137438953472) q[118];
cx q[154],q[118];
u1(pi/137438953472) q[118];
u1(pi/68719476736) q[154];
cx q[154],q[119];
u1(-pi/68719476736) q[119];
cx q[154],q[119];
u1(pi/68719476736) q[119];
u1(pi/34359738368) q[154];
cx q[154],q[120];
u1(-pi/34359738368) q[120];
cx q[154],q[120];
u1(pi/34359738368) q[120];
u1(pi/17179869184) q[154];
cx q[154],q[121];
u1(-pi/17179869184) q[121];
cx q[154],q[121];
u1(pi/17179869184) q[121];
u1(pi/8589934592) q[154];
cx q[154],q[122];
u1(-pi/8589934592) q[122];
cx q[154],q[122];
u1(pi/8589934592) q[122];
u1(pi/4294967296) q[154];
cx q[154],q[123];
u1(-pi/4294967296) q[123];
cx q[154],q[123];
u1(pi/4294967296) q[123];
u1(pi/2147483648) q[154];
cx q[154],q[124];
u1(-pi/2147483648) q[124];
cx q[154],q[124];
u1(pi/2147483648) q[124];
u1(pi/1073741824) q[154];
cx q[154],q[125];
u1(-pi/1073741824) q[125];
cx q[154],q[125];
u1(pi/1073741824) q[125];
u1(pi/536870912) q[154];
cx q[154],q[126];
u1(-pi/536870912) q[126];
cx q[154],q[126];
u1(pi/536870912) q[126];
u1(pi/268435456) q[154];
cx q[154],q[127];
u1(-pi/268435456) q[127];
cx q[154],q[127];
u1(pi/268435456) q[127];
u1(pi/134217728) q[154];
cx q[154],q[128];
u1(-pi/134217728) q[128];
cx q[154],q[128];
u1(pi/134217728) q[128];
u1(pi/67108864) q[154];
cx q[154],q[129];
u1(-pi/67108864) q[129];
cx q[154],q[129];
u1(pi/67108864) q[129];
u1(pi/33554432) q[154];
cx q[154],q[130];
u1(-pi/33554432) q[130];
cx q[154],q[130];
u1(pi/33554432) q[130];
u1(pi/16777216) q[154];
cx q[154],q[131];
u1(-pi/16777216) q[131];
cx q[154],q[131];
u1(pi/16777216) q[131];
u1(pi/8388608) q[154];
cx q[154],q[132];
u1(-pi/8388608) q[132];
cx q[154],q[132];
u1(pi/8388608) q[132];
u1(pi/4194304) q[154];
cx q[154],q[133];
u1(-pi/4194304) q[133];
cx q[154],q[133];
u1(pi/4194304) q[133];
u1(pi/2097152) q[154];
cx q[154],q[134];
u1(-pi/2097152) q[134];
cx q[154],q[134];
u1(pi/2097152) q[134];
u1(pi/1048576) q[154];
cx q[154],q[135];
u1(-pi/1048576) q[135];
cx q[154],q[135];
u1(pi/1048576) q[135];
u1(pi/524288) q[154];
cx q[154],q[136];
u1(-pi/524288) q[136];
cx q[154],q[136];
u1(pi/524288) q[136];
u1(pi/262144) q[154];
cx q[154],q[137];
u1(-pi/262144) q[137];
cx q[154],q[137];
u1(pi/262144) q[137];
u1(pi/131072) q[154];
cx q[154],q[138];
u1(-pi/131072) q[138];
cx q[154],q[138];
u1(pi/131072) q[138];
u1(pi/65536) q[154];
cx q[154],q[139];
u1(-pi/65536) q[139];
cx q[154],q[139];
u1(pi/65536) q[139];
u1(pi/32768) q[154];
cx q[154],q[140];
u1(-pi/32768) q[140];
cx q[154],q[140];
u1(pi/32768) q[140];
u1(pi/16384) q[154];
cx q[154],q[141];
u1(-pi/16384) q[141];
cx q[154],q[141];
u1(pi/16384) q[141];
u1(pi/8192) q[154];
cx q[154],q[142];
u1(-pi/8192) q[142];
cx q[154],q[142];
u1(pi/8192) q[142];
u1(pi/4096) q[154];
cx q[154],q[143];
u1(-pi/4096) q[143];
cx q[154],q[143];
u1(pi/4096) q[143];
u1(pi/2048) q[154];
cx q[154],q[144];
u1(-pi/2048) q[144];
cx q[154],q[144];
u1(pi/2048) q[144];
u1(pi/1024) q[154];
cx q[154],q[145];
u1(-pi/1024) q[145];
cx q[154],q[145];
u1(pi/1024) q[145];
u1(pi/512) q[154];
cx q[154],q[146];
u1(-pi/512) q[146];
cx q[154],q[146];
u1(pi/512) q[146];
u1(pi/256) q[154];
cx q[154],q[147];
u1(-pi/256) q[147];
cx q[154],q[147];
u1(pi/256) q[147];
u1(pi/128) q[154];
cx q[154],q[148];
u1(-pi/128) q[148];
cx q[154],q[148];
u1(pi/128) q[148];
u1(pi/64) q[154];
cx q[154],q[149];
u1(-pi/64) q[149];
cx q[154],q[149];
u1(pi/64) q[149];
u1(pi/32) q[154];
cx q[154],q[150];
u1(-pi/32) q[150];
cx q[154],q[150];
u1(pi/32) q[150];
u1(pi/16) q[154];
cx q[154],q[151];
u1(-pi/16) q[151];
cx q[154],q[151];
u1(pi/16) q[151];
u1(pi/8) q[154];
cx q[154],q[152];
u1(-pi/8) q[152];
cx q[154],q[152];
u1(pi/8) q[152];
u1(pi/4) q[154];
cx q[154],q[153];
u1(-pi/4) q[153];
cx q[154],q[153];
u1(pi/4) q[153];
h q[154];
u1(0) q[155];
cx q[155],q[0];
u1(0) q[0];
cx q[155],q[0];
u1(0) q[0];
u1(0) q[155];
cx q[155],q[1];
u1(0) q[1];
cx q[155],q[1];
u1(0) q[1];
u1(0) q[155];
cx q[155],q[2];
u1(0) q[2];
cx q[155],q[2];
u1(0) q[2];
u1(0) q[155];
cx q[155],q[3];
u1(0) q[3];
cx q[155],q[3];
u1(0) q[3];
u1(0) q[155];
cx q[155],q[4];
u1(0) q[4];
cx q[155],q[4];
u1(0) q[4];
u1(0) q[155];
cx q[155],q[5];
u1(0) q[5];
cx q[155],q[5];
u1(0) q[5];
u1(0) q[155];
cx q[155],q[6];
u1(0) q[6];
cx q[155],q[6];
u1(0) q[6];
u1(0) q[155];
cx q[155],q[7];
u1(0) q[7];
cx q[155],q[7];
u1(0) q[7];
u1(0) q[155];
cx q[155],q[8];
u1(0) q[8];
cx q[155],q[8];
u1(0) q[8];
u1(0) q[155];
cx q[155],q[9];
u1(0) q[9];
cx q[155],q[9];
u1(0) q[9];
u1(0) q[155];
cx q[155],q[10];
u1(0) q[10];
cx q[155],q[10];
u1(0) q[10];
u1(0) q[155];
cx q[155],q[11];
u1(0) q[11];
cx q[155],q[11];
u1(0) q[11];
u1(0) q[155];
cx q[155],q[12];
u1(0) q[12];
cx q[155],q[12];
u1(0) q[12];
u1(0) q[155];
cx q[155],q[13];
u1(0) q[13];
cx q[155],q[13];
u1(0) q[13];
u1(0) q[155];
cx q[155],q[14];
u1(0) q[14];
cx q[155],q[14];
u1(0) q[14];
u1(0) q[155];
cx q[155],q[15];
u1(0) q[15];
cx q[155],q[15];
u1(0) q[15];
u1(0) q[155];
cx q[155],q[16];
u1(0) q[16];
cx q[155],q[16];
u1(0) q[16];
u1(0) q[155];
cx q[155],q[17];
u1(0) q[17];
cx q[155],q[17];
u1(0) q[17];
u1(0) q[155];
cx q[155],q[18];
u1(0) q[18];
cx q[155],q[18];
u1(0) q[18];
u1(0) q[155];
cx q[155],q[19];
u1(0) q[19];
cx q[155],q[19];
u1(0) q[19];
u1(0) q[155];
cx q[155],q[20];
u1(0) q[20];
cx q[155],q[20];
u1(0) q[20];
u1(0) q[155];
cx q[155],q[21];
u1(0) q[21];
cx q[155],q[21];
u1(0) q[21];
u1(0) q[155];
cx q[155],q[22];
u1(0) q[22];
cx q[155],q[22];
u1(0) q[22];
u1(0) q[155];
cx q[155],q[23];
u1(0) q[23];
cx q[155],q[23];
u1(0) q[23];
u1(0) q[155];
cx q[155],q[24];
u1(0) q[24];
cx q[155],q[24];
u1(0) q[24];
u1(0) q[155];
cx q[155],q[25];
u1(0) q[25];
cx q[155],q[25];
u1(0) q[25];
u1(0) q[155];
cx q[155],q[26];
u1(0) q[26];
cx q[155],q[26];
u1(0) q[26];
u1(0) q[155];
cx q[155],q[27];
u1(0) q[27];
cx q[155],q[27];
u1(0) q[27];
u1(0) q[155];
cx q[155],q[28];
u1(0) q[28];
cx q[155],q[28];
u1(0) q[28];
u1(0) q[155];
cx q[155],q[29];
u1(0) q[29];
cx q[155],q[29];
u1(0) q[29];
u1(0) q[155];
cx q[155],q[30];
u1(0) q[30];
cx q[155],q[30];
u1(0) q[30];
u1(0) q[155];
cx q[155],q[31];
u1(0) q[31];
cx q[155],q[31];
u1(0) q[31];
u1(0) q[155];
cx q[155],q[32];
u1(0) q[32];
cx q[155],q[32];
u1(0) q[32];
u1(0) q[155];
cx q[155],q[33];
u1(0) q[33];
cx q[155],q[33];
u1(0) q[33];
u1(0) q[155];
cx q[155],q[34];
u1(0) q[34];
cx q[155],q[34];
u1(0) q[34];
u1(0) q[155];
cx q[155],q[35];
u1(0) q[35];
cx q[155],q[35];
u1(0) q[35];
u1(0) q[155];
cx q[155],q[36];
u1(0) q[36];
cx q[155],q[36];
u1(0) q[36];
u1(0) q[155];
cx q[155],q[37];
u1(0) q[37];
cx q[155],q[37];
u1(0) q[37];
u1(0) q[155];
cx q[155],q[38];
u1(0) q[38];
cx q[155],q[38];
u1(0) q[38];
u1(0) q[155];
cx q[155],q[39];
u1(0) q[39];
cx q[155],q[39];
u1(0) q[39];
u1(0) q[155];
cx q[155],q[40];
u1(0) q[40];
cx q[155],q[40];
u1(0) q[40];
u1(0) q[155];
cx q[155],q[41];
u1(0) q[41];
cx q[155],q[41];
u1(0) q[41];
u1(0) q[155];
cx q[155],q[42];
u1(0) q[42];
cx q[155],q[42];
u1(0) q[42];
u1(0) q[155];
cx q[155],q[43];
u1(0) q[43];
cx q[155],q[43];
u1(0) q[43];
u1(0) q[155];
cx q[155],q[44];
u1(0) q[44];
cx q[155],q[44];
u1(0) q[44];
u1(0) q[155];
cx q[155],q[45];
u1(0) q[45];
cx q[155],q[45];
u1(0) q[45];
u1(0) q[155];
cx q[155],q[46];
u1(0) q[46];
cx q[155],q[46];
u1(0) q[46];
u1(0) q[155];
cx q[155],q[47];
u1(0) q[47];
cx q[155],q[47];
u1(0) q[47];
u1(0) q[155];
cx q[155],q[48];
u1(0) q[48];
cx q[155],q[48];
u1(0) q[48];
u1(0) q[155];
cx q[155],q[49];
u1(0) q[49];
cx q[155],q[49];
u1(0) q[49];
u1(0) q[155];
cx q[155],q[50];
u1(0) q[50];
cx q[155],q[50];
u1(0) q[50];
u1(0) q[155];
cx q[155],q[51];
u1(0) q[51];
cx q[155],q[51];
u1(0) q[51];
u1(0) q[155];
cx q[155],q[52];
u1(0) q[52];
cx q[155],q[52];
u1(0) q[52];
u1(0) q[155];
cx q[155],q[53];
u1(0) q[53];
cx q[155],q[53];
u1(0) q[53];
u1(0) q[155];
cx q[155],q[54];
u1(0) q[54];
cx q[155],q[54];
u1(0) q[54];
u1(0) q[155];
cx q[155],q[55];
u1(0) q[55];
cx q[155],q[55];
u1(0) q[55];
u1(0) q[155];
cx q[155],q[56];
u1(0) q[56];
cx q[155],q[56];
u1(0) q[56];
u1(0) q[155];
cx q[155],q[57];
u1(0) q[57];
cx q[155],q[57];
u1(0) q[57];
u1(0) q[155];
cx q[155],q[58];
u1(0) q[58];
cx q[155],q[58];
u1(0) q[58];
u1(0) q[155];
cx q[155],q[59];
u1(0) q[59];
cx q[155],q[59];
u1(0) q[59];
u1(0) q[155];
cx q[155],q[60];
u1(0) q[60];
cx q[155],q[60];
u1(0) q[60];
u1(0) q[155];
cx q[155],q[61];
u1(0) q[61];
cx q[155],q[61];
u1(0) q[61];
u1(0) q[155];
cx q[155],q[62];
u1(0) q[62];
cx q[155],q[62];
u1(0) q[62];
u1(0) q[155];
cx q[155],q[63];
u1(0) q[63];
cx q[155],q[63];
u1(0) q[63];
u1(0) q[155];
cx q[155],q[64];
u1(0) q[64];
cx q[155],q[64];
u1(0) q[64];
u1(0) q[155];
cx q[155],q[65];
u1(0) q[65];
cx q[155],q[65];
u1(0) q[65];
u1(0) q[155];
cx q[155],q[66];
u1(0) q[66];
cx q[155],q[66];
u1(0) q[66];
u1(0) q[155];
cx q[155],q[67];
u1(0) q[67];
cx q[155],q[67];
u1(0) q[67];
u1(0) q[155];
cx q[155],q[68];
u1(0) q[68];
cx q[155],q[68];
u1(0) q[68];
u1(0) q[155];
cx q[155],q[69];
u1(0) q[69];
cx q[155],q[69];
u1(0) q[69];
u1(0) q[155];
cx q[155],q[70];
u1(0) q[70];
cx q[155],q[70];
u1(0) q[70];
u1(0) q[155];
cx q[155],q[71];
u1(0) q[71];
cx q[155],q[71];
u1(0) q[71];
u1(0) q[155];
cx q[155],q[72];
u1(0) q[72];
cx q[155],q[72];
u1(0) q[72];
u1(0) q[155];
cx q[155],q[73];
u1(0) q[73];
cx q[155],q[73];
u1(0) q[73];
u1(0) q[155];
cx q[155],q[74];
u1(0) q[74];
cx q[155],q[74];
u1(0) q[74];
u1(0) q[155];
cx q[155],q[75];
u1(0) q[75];
cx q[155],q[75];
u1(0) q[75];
u1(0) q[155];
cx q[155],q[76];
u1(0) q[76];
cx q[155],q[76];
u1(0) q[76];
u1(0) q[155];
cx q[155],q[77];
u1(0) q[77];
cx q[155],q[77];
u1(0) q[77];
u1(0) q[155];
cx q[155],q[78];
u1(0) q[78];
cx q[155],q[78];
u1(0) q[78];
u1(0) q[155];
cx q[155],q[79];
u1(0) q[79];
cx q[155],q[79];
u1(0) q[79];
u1(0) q[155];
cx q[155],q[80];
u1(0) q[80];
cx q[155],q[80];
u1(0) q[80];
u1(0) q[155];
cx q[155],q[81];
u1(0) q[81];
cx q[155],q[81];
u1(0) q[81];
u1(0) q[155];
cx q[155],q[82];
u1(0) q[82];
cx q[155],q[82];
u1(0) q[82];
u1(0) q[155];
cx q[155],q[83];
u1(0) q[83];
cx q[155],q[83];
u1(0) q[83];
u1(0) q[155];
cx q[155],q[84];
u1(0) q[84];
cx q[155],q[84];
u1(0) q[84];
u1(0) q[155];
cx q[155],q[85];
u1(0) q[85];
cx q[155],q[85];
u1(0) q[85];
u1(0) q[155];
cx q[155],q[86];
u1(0) q[86];
cx q[155],q[86];
u1(0) q[86];
u1(0) q[155];
cx q[155],q[87];
u1(0) q[87];
cx q[155],q[87];
u1(0) q[87];
u1(0) q[155];
cx q[155],q[88];
u1(0) q[88];
cx q[155],q[88];
u1(0) q[88];
u1(0) q[155];
cx q[155],q[89];
u1(0) q[89];
cx q[155],q[89];
u1(0) q[89];
u1(0) q[155];
cx q[155],q[90];
u1(0) q[90];
cx q[155],q[90];
u1(0) q[90];
u1(0) q[155];
cx q[155],q[91];
u1(0) q[91];
cx q[155],q[91];
u1(0) q[91];
u1(0) q[155];
cx q[155],q[92];
u1(0) q[92];
cx q[155],q[92];
u1(0) q[92];
u1(0) q[155];
cx q[155],q[93];
u1(0) q[93];
cx q[155],q[93];
u1(0) q[93];
u1(0) q[155];
cx q[155],q[94];
u1(0) q[94];
cx q[155],q[94];
u1(0) q[94];
u1(0) q[155];
cx q[155],q[95];
u1(0) q[95];
cx q[155],q[95];
u1(0) q[95];
u1(0) q[155];
cx q[155],q[96];
u1(0) q[96];
cx q[155],q[96];
u1(0) q[96];
u1(0) q[155];
cx q[155],q[97];
u1(0) q[97];
cx q[155],q[97];
u1(0) q[97];
u1(0) q[155];
cx q[155],q[98];
u1(0) q[98];
cx q[155],q[98];
u1(0) q[98];
u1(0) q[155];
cx q[155],q[99];
u1(0) q[99];
cx q[155],q[99];
u1(0) q[99];
u1(0) q[155];
cx q[155],q[100];
u1(0) q[100];
cx q[155],q[100];
u1(0) q[100];
u1(0) q[155];
cx q[155],q[101];
u1(0) q[101];
cx q[155],q[101];
u1(0) q[101];
u1(0) q[155];
cx q[155],q[102];
u1(0) q[102];
cx q[155],q[102];
u1(0) q[102];
u1(0) q[155];
cx q[155],q[103];
u1(0) q[103];
cx q[155],q[103];
u1(0) q[103];
u1(0) q[155];
cx q[155],q[104];
u1(0) q[104];
cx q[155],q[104];
u1(0) q[104];
u1(0) q[155];
cx q[155],q[105];
u1(0) q[105];
cx q[155],q[105];
u1(0) q[105];
u1(0) q[155];
cx q[155],q[106];
u1(0) q[106];
cx q[155],q[106];
u1(0) q[106];
u1(0) q[155];
cx q[155],q[107];
u1(0) q[107];
cx q[155],q[107];
u1(0) q[107];
u1(pi/281474976710656) q[155];
cx q[155],q[108];
u1(-pi/281474976710656) q[108];
cx q[155],q[108];
u1(pi/281474976710656) q[108];
u1(pi/140737488355328) q[155];
cx q[155],q[109];
u1(-pi/140737488355328) q[109];
cx q[155],q[109];
u1(pi/140737488355328) q[109];
u1(pi/70368744177664) q[155];
cx q[155],q[110];
u1(-pi/70368744177664) q[110];
cx q[155],q[110];
u1(pi/70368744177664) q[110];
u1(pi/35184372088832) q[155];
cx q[155],q[111];
u1(-pi/35184372088832) q[111];
cx q[155],q[111];
u1(pi/35184372088832) q[111];
u1(pi/17592186044416) q[155];
cx q[155],q[112];
u1(-pi/17592186044416) q[112];
cx q[155],q[112];
u1(pi/17592186044416) q[112];
u1(pi/8796093022208) q[155];
cx q[155],q[113];
u1(-pi/8796093022208) q[113];
cx q[155],q[113];
u1(pi/8796093022208) q[113];
u1(pi/4398046511104) q[155];
cx q[155],q[114];
u1(-pi/4398046511104) q[114];
cx q[155],q[114];
u1(pi/4398046511104) q[114];
u1(pi/2199023255552) q[155];
cx q[155],q[115];
u1(-pi/2199023255552) q[115];
cx q[155],q[115];
u1(pi/2199023255552) q[115];
u1(pi/1099511627776) q[155];
cx q[155],q[116];
u1(-pi/1099511627776) q[116];
cx q[155],q[116];
u1(pi/1099511627776) q[116];
u1(pi/549755813888) q[155];
cx q[155],q[117];
u1(-pi/549755813888) q[117];
cx q[155],q[117];
u1(pi/549755813888) q[117];
u1(pi/274877906944) q[155];
cx q[155],q[118];
u1(-pi/274877906944) q[118];
cx q[155],q[118];
u1(pi/274877906944) q[118];
u1(pi/137438953472) q[155];
cx q[155],q[119];
u1(-pi/137438953472) q[119];
cx q[155],q[119];
u1(pi/137438953472) q[119];
u1(pi/68719476736) q[155];
cx q[155],q[120];
u1(-pi/68719476736) q[120];
cx q[155],q[120];
u1(pi/68719476736) q[120];
u1(pi/34359738368) q[155];
cx q[155],q[121];
u1(-pi/34359738368) q[121];
cx q[155],q[121];
u1(pi/34359738368) q[121];
u1(pi/17179869184) q[155];
cx q[155],q[122];
u1(-pi/17179869184) q[122];
cx q[155],q[122];
u1(pi/17179869184) q[122];
u1(pi/8589934592) q[155];
cx q[155],q[123];
u1(-pi/8589934592) q[123];
cx q[155],q[123];
u1(pi/8589934592) q[123];
u1(pi/4294967296) q[155];
cx q[155],q[124];
u1(-pi/4294967296) q[124];
cx q[155],q[124];
u1(pi/4294967296) q[124];
u1(pi/2147483648) q[155];
cx q[155],q[125];
u1(-pi/2147483648) q[125];
cx q[155],q[125];
u1(pi/2147483648) q[125];
u1(pi/1073741824) q[155];
cx q[155],q[126];
u1(-pi/1073741824) q[126];
cx q[155],q[126];
u1(pi/1073741824) q[126];
u1(pi/536870912) q[155];
cx q[155],q[127];
u1(-pi/536870912) q[127];
cx q[155],q[127];
u1(pi/536870912) q[127];
u1(pi/268435456) q[155];
cx q[155],q[128];
u1(-pi/268435456) q[128];
cx q[155],q[128];
u1(pi/268435456) q[128];
u1(pi/134217728) q[155];
cx q[155],q[129];
u1(-pi/134217728) q[129];
cx q[155],q[129];
u1(pi/134217728) q[129];
u1(pi/67108864) q[155];
cx q[155],q[130];
u1(-pi/67108864) q[130];
cx q[155],q[130];
u1(pi/67108864) q[130];
u1(pi/33554432) q[155];
cx q[155],q[131];
u1(-pi/33554432) q[131];
cx q[155],q[131];
u1(pi/33554432) q[131];
u1(pi/16777216) q[155];
cx q[155],q[132];
u1(-pi/16777216) q[132];
cx q[155],q[132];
u1(pi/16777216) q[132];
u1(pi/8388608) q[155];
cx q[155],q[133];
u1(-pi/8388608) q[133];
cx q[155],q[133];
u1(pi/8388608) q[133];
u1(pi/4194304) q[155];
cx q[155],q[134];
u1(-pi/4194304) q[134];
cx q[155],q[134];
u1(pi/4194304) q[134];
u1(pi/2097152) q[155];
cx q[155],q[135];
u1(-pi/2097152) q[135];
cx q[155],q[135];
u1(pi/2097152) q[135];
u1(pi/1048576) q[155];
cx q[155],q[136];
u1(-pi/1048576) q[136];
cx q[155],q[136];
u1(pi/1048576) q[136];
u1(pi/524288) q[155];
cx q[155],q[137];
u1(-pi/524288) q[137];
cx q[155],q[137];
u1(pi/524288) q[137];
u1(pi/262144) q[155];
cx q[155],q[138];
u1(-pi/262144) q[138];
cx q[155],q[138];
u1(pi/262144) q[138];
u1(pi/131072) q[155];
cx q[155],q[139];
u1(-pi/131072) q[139];
cx q[155],q[139];
u1(pi/131072) q[139];
u1(pi/65536) q[155];
cx q[155],q[140];
u1(-pi/65536) q[140];
cx q[155],q[140];
u1(pi/65536) q[140];
u1(pi/32768) q[155];
cx q[155],q[141];
u1(-pi/32768) q[141];
cx q[155],q[141];
u1(pi/32768) q[141];
u1(pi/16384) q[155];
cx q[155],q[142];
u1(-pi/16384) q[142];
cx q[155],q[142];
u1(pi/16384) q[142];
u1(pi/8192) q[155];
cx q[155],q[143];
u1(-pi/8192) q[143];
cx q[155],q[143];
u1(pi/8192) q[143];
u1(pi/4096) q[155];
cx q[155],q[144];
u1(-pi/4096) q[144];
cx q[155],q[144];
u1(pi/4096) q[144];
u1(pi/2048) q[155];
cx q[155],q[145];
u1(-pi/2048) q[145];
cx q[155],q[145];
u1(pi/2048) q[145];
u1(pi/1024) q[155];
cx q[155],q[146];
u1(-pi/1024) q[146];
cx q[155],q[146];
u1(pi/1024) q[146];
u1(pi/512) q[155];
cx q[155],q[147];
u1(-pi/512) q[147];
cx q[155],q[147];
u1(pi/512) q[147];
u1(pi/256) q[155];
cx q[155],q[148];
u1(-pi/256) q[148];
cx q[155],q[148];
u1(pi/256) q[148];
u1(pi/128) q[155];
cx q[155],q[149];
u1(-pi/128) q[149];
cx q[155],q[149];
u1(pi/128) q[149];
u1(pi/64) q[155];
cx q[155],q[150];
u1(-pi/64) q[150];
cx q[155],q[150];
u1(pi/64) q[150];
u1(pi/32) q[155];
cx q[155],q[151];
u1(-pi/32) q[151];
cx q[155],q[151];
u1(pi/32) q[151];
u1(pi/16) q[155];
cx q[155],q[152];
u1(-pi/16) q[152];
cx q[155],q[152];
u1(pi/16) q[152];
u1(pi/8) q[155];
cx q[155],q[153];
u1(-pi/8) q[153];
cx q[155],q[153];
u1(pi/8) q[153];
u1(pi/4) q[155];
cx q[155],q[154];
u1(-pi/4) q[154];
cx q[155],q[154];
u1(pi/4) q[154];
h q[155];
u1(0) q[156];
cx q[156],q[0];
u1(0) q[0];
cx q[156],q[0];
u1(0) q[0];
u1(0) q[156];
cx q[156],q[1];
u1(0) q[1];
cx q[156],q[1];
u1(0) q[1];
u1(0) q[156];
cx q[156],q[2];
u1(0) q[2];
cx q[156],q[2];
u1(0) q[2];
u1(0) q[156];
cx q[156],q[3];
u1(0) q[3];
cx q[156],q[3];
u1(0) q[3];
u1(0) q[156];
cx q[156],q[4];
u1(0) q[4];
cx q[156],q[4];
u1(0) q[4];
u1(0) q[156];
cx q[156],q[5];
u1(0) q[5];
cx q[156],q[5];
u1(0) q[5];
u1(0) q[156];
cx q[156],q[6];
u1(0) q[6];
cx q[156],q[6];
u1(0) q[6];
u1(0) q[156];
cx q[156],q[7];
u1(0) q[7];
cx q[156],q[7];
u1(0) q[7];
u1(0) q[156];
cx q[156],q[8];
u1(0) q[8];
cx q[156],q[8];
u1(0) q[8];
u1(0) q[156];
cx q[156],q[9];
u1(0) q[9];
cx q[156],q[9];
u1(0) q[9];
u1(0) q[156];
cx q[156],q[10];
u1(0) q[10];
cx q[156],q[10];
u1(0) q[10];
u1(0) q[156];
cx q[156],q[11];
u1(0) q[11];
cx q[156],q[11];
u1(0) q[11];
u1(0) q[156];
cx q[156],q[12];
u1(0) q[12];
cx q[156],q[12];
u1(0) q[12];
u1(0) q[156];
cx q[156],q[13];
u1(0) q[13];
cx q[156],q[13];
u1(0) q[13];
u1(0) q[156];
cx q[156],q[14];
u1(0) q[14];
cx q[156],q[14];
u1(0) q[14];
u1(0) q[156];
cx q[156],q[15];
u1(0) q[15];
cx q[156],q[15];
u1(0) q[15];
u1(0) q[156];
cx q[156],q[16];
u1(0) q[16];
cx q[156],q[16];
u1(0) q[16];
u1(0) q[156];
cx q[156],q[17];
u1(0) q[17];
cx q[156],q[17];
u1(0) q[17];
u1(0) q[156];
cx q[156],q[18];
u1(0) q[18];
cx q[156],q[18];
u1(0) q[18];
u1(0) q[156];
cx q[156],q[19];
u1(0) q[19];
cx q[156],q[19];
u1(0) q[19];
u1(0) q[156];
cx q[156],q[20];
u1(0) q[20];
cx q[156],q[20];
u1(0) q[20];
u1(0) q[156];
cx q[156],q[21];
u1(0) q[21];
cx q[156],q[21];
u1(0) q[21];
u1(0) q[156];
cx q[156],q[22];
u1(0) q[22];
cx q[156],q[22];
u1(0) q[22];
u1(0) q[156];
cx q[156],q[23];
u1(0) q[23];
cx q[156],q[23];
u1(0) q[23];
u1(0) q[156];
cx q[156],q[24];
u1(0) q[24];
cx q[156],q[24];
u1(0) q[24];
u1(0) q[156];
cx q[156],q[25];
u1(0) q[25];
cx q[156],q[25];
u1(0) q[25];
u1(0) q[156];
cx q[156],q[26];
u1(0) q[26];
cx q[156],q[26];
u1(0) q[26];
u1(0) q[156];
cx q[156],q[27];
u1(0) q[27];
cx q[156],q[27];
u1(0) q[27];
u1(0) q[156];
cx q[156],q[28];
u1(0) q[28];
cx q[156],q[28];
u1(0) q[28];
u1(0) q[156];
cx q[156],q[29];
u1(0) q[29];
cx q[156],q[29];
u1(0) q[29];
u1(0) q[156];
cx q[156],q[30];
u1(0) q[30];
cx q[156],q[30];
u1(0) q[30];
u1(0) q[156];
cx q[156],q[31];
u1(0) q[31];
cx q[156],q[31];
u1(0) q[31];
u1(0) q[156];
cx q[156],q[32];
u1(0) q[32];
cx q[156],q[32];
u1(0) q[32];
u1(0) q[156];
cx q[156],q[33];
u1(0) q[33];
cx q[156],q[33];
u1(0) q[33];
u1(0) q[156];
cx q[156],q[34];
u1(0) q[34];
cx q[156],q[34];
u1(0) q[34];
u1(0) q[156];
cx q[156],q[35];
u1(0) q[35];
cx q[156],q[35];
u1(0) q[35];
u1(0) q[156];
cx q[156],q[36];
u1(0) q[36];
cx q[156],q[36];
u1(0) q[36];
u1(0) q[156];
cx q[156],q[37];
u1(0) q[37];
cx q[156],q[37];
u1(0) q[37];
u1(0) q[156];
cx q[156],q[38];
u1(0) q[38];
cx q[156],q[38];
u1(0) q[38];
u1(0) q[156];
cx q[156],q[39];
u1(0) q[39];
cx q[156],q[39];
u1(0) q[39];
u1(0) q[156];
cx q[156],q[40];
u1(0) q[40];
cx q[156],q[40];
u1(0) q[40];
u1(0) q[156];
cx q[156],q[41];
u1(0) q[41];
cx q[156],q[41];
u1(0) q[41];
u1(0) q[156];
cx q[156],q[42];
u1(0) q[42];
cx q[156],q[42];
u1(0) q[42];
u1(0) q[156];
cx q[156],q[43];
u1(0) q[43];
cx q[156],q[43];
u1(0) q[43];
u1(0) q[156];
cx q[156],q[44];
u1(0) q[44];
cx q[156],q[44];
u1(0) q[44];
u1(0) q[156];
cx q[156],q[45];
u1(0) q[45];
cx q[156],q[45];
u1(0) q[45];
u1(0) q[156];
cx q[156],q[46];
u1(0) q[46];
cx q[156],q[46];
u1(0) q[46];
u1(0) q[156];
cx q[156],q[47];
u1(0) q[47];
cx q[156],q[47];
u1(0) q[47];
u1(0) q[156];
cx q[156],q[48];
u1(0) q[48];
cx q[156],q[48];
u1(0) q[48];
u1(0) q[156];
cx q[156],q[49];
u1(0) q[49];
cx q[156],q[49];
u1(0) q[49];
u1(0) q[156];
cx q[156],q[50];
u1(0) q[50];
cx q[156],q[50];
u1(0) q[50];
u1(0) q[156];
cx q[156],q[51];
u1(0) q[51];
cx q[156],q[51];
u1(0) q[51];
u1(0) q[156];
cx q[156],q[52];
u1(0) q[52];
cx q[156],q[52];
u1(0) q[52];
u1(0) q[156];
cx q[156],q[53];
u1(0) q[53];
cx q[156],q[53];
u1(0) q[53];
u1(0) q[156];
cx q[156],q[54];
u1(0) q[54];
cx q[156],q[54];
u1(0) q[54];
u1(0) q[156];
cx q[156],q[55];
u1(0) q[55];
cx q[156],q[55];
u1(0) q[55];
u1(0) q[156];
cx q[156],q[56];
u1(0) q[56];
cx q[156],q[56];
u1(0) q[56];
u1(0) q[156];
cx q[156],q[57];
u1(0) q[57];
cx q[156],q[57];
u1(0) q[57];
u1(0) q[156];
cx q[156],q[58];
u1(0) q[58];
cx q[156],q[58];
u1(0) q[58];
u1(0) q[156];
cx q[156],q[59];
u1(0) q[59];
cx q[156],q[59];
u1(0) q[59];
u1(0) q[156];
cx q[156],q[60];
u1(0) q[60];
cx q[156],q[60];
u1(0) q[60];
u1(0) q[156];
cx q[156],q[61];
u1(0) q[61];
cx q[156],q[61];
u1(0) q[61];
u1(0) q[156];
cx q[156],q[62];
u1(0) q[62];
cx q[156],q[62];
u1(0) q[62];
u1(0) q[156];
cx q[156],q[63];
u1(0) q[63];
cx q[156],q[63];
u1(0) q[63];
u1(0) q[156];
cx q[156],q[64];
u1(0) q[64];
cx q[156],q[64];
u1(0) q[64];
u1(0) q[156];
cx q[156],q[65];
u1(0) q[65];
cx q[156],q[65];
u1(0) q[65];
u1(0) q[156];
cx q[156],q[66];
u1(0) q[66];
cx q[156],q[66];
u1(0) q[66];
u1(0) q[156];
cx q[156],q[67];
u1(0) q[67];
cx q[156],q[67];
u1(0) q[67];
u1(0) q[156];
cx q[156],q[68];
u1(0) q[68];
cx q[156],q[68];
u1(0) q[68];
u1(0) q[156];
cx q[156],q[69];
u1(0) q[69];
cx q[156],q[69];
u1(0) q[69];
u1(0) q[156];
cx q[156],q[70];
u1(0) q[70];
cx q[156],q[70];
u1(0) q[70];
u1(0) q[156];
cx q[156],q[71];
u1(0) q[71];
cx q[156],q[71];
u1(0) q[71];
u1(0) q[156];
cx q[156],q[72];
u1(0) q[72];
cx q[156],q[72];
u1(0) q[72];
u1(0) q[156];
cx q[156],q[73];
u1(0) q[73];
cx q[156],q[73];
u1(0) q[73];
u1(0) q[156];
cx q[156],q[74];
u1(0) q[74];
cx q[156],q[74];
u1(0) q[74];
u1(0) q[156];
cx q[156],q[75];
u1(0) q[75];
cx q[156],q[75];
u1(0) q[75];
u1(0) q[156];
cx q[156],q[76];
u1(0) q[76];
cx q[156],q[76];
u1(0) q[76];
u1(0) q[156];
cx q[156],q[77];
u1(0) q[77];
cx q[156],q[77];
u1(0) q[77];
u1(0) q[156];
cx q[156],q[78];
u1(0) q[78];
cx q[156],q[78];
u1(0) q[78];
u1(0) q[156];
cx q[156],q[79];
u1(0) q[79];
cx q[156],q[79];
u1(0) q[79];
u1(0) q[156];
cx q[156],q[80];
u1(0) q[80];
cx q[156],q[80];
u1(0) q[80];
u1(0) q[156];
cx q[156],q[81];
u1(0) q[81];
cx q[156],q[81];
u1(0) q[81];
u1(0) q[156];
cx q[156],q[82];
u1(0) q[82];
cx q[156],q[82];
u1(0) q[82];
u1(0) q[156];
cx q[156],q[83];
u1(0) q[83];
cx q[156],q[83];
u1(0) q[83];
u1(0) q[156];
cx q[156],q[84];
u1(0) q[84];
cx q[156],q[84];
u1(0) q[84];
u1(0) q[156];
cx q[156],q[85];
u1(0) q[85];
cx q[156],q[85];
u1(0) q[85];
u1(0) q[156];
cx q[156],q[86];
u1(0) q[86];
cx q[156],q[86];
u1(0) q[86];
u1(0) q[156];
cx q[156],q[87];
u1(0) q[87];
cx q[156],q[87];
u1(0) q[87];
u1(0) q[156];
cx q[156],q[88];
u1(0) q[88];
cx q[156],q[88];
u1(0) q[88];
u1(0) q[156];
cx q[156],q[89];
u1(0) q[89];
cx q[156],q[89];
u1(0) q[89];
u1(0) q[156];
cx q[156],q[90];
u1(0) q[90];
cx q[156],q[90];
u1(0) q[90];
u1(0) q[156];
cx q[156],q[91];
u1(0) q[91];
cx q[156],q[91];
u1(0) q[91];
u1(0) q[156];
cx q[156],q[92];
u1(0) q[92];
cx q[156],q[92];
u1(0) q[92];
u1(0) q[156];
cx q[156],q[93];
u1(0) q[93];
cx q[156],q[93];
u1(0) q[93];
u1(0) q[156];
cx q[156],q[94];
u1(0) q[94];
cx q[156],q[94];
u1(0) q[94];
u1(0) q[156];
cx q[156],q[95];
u1(0) q[95];
cx q[156],q[95];
u1(0) q[95];
u1(0) q[156];
cx q[156],q[96];
u1(0) q[96];
cx q[156],q[96];
u1(0) q[96];
u1(0) q[156];
cx q[156],q[97];
u1(0) q[97];
cx q[156],q[97];
u1(0) q[97];
u1(0) q[156];
cx q[156],q[98];
u1(0) q[98];
cx q[156],q[98];
u1(0) q[98];
u1(0) q[156];
cx q[156],q[99];
u1(0) q[99];
cx q[156],q[99];
u1(0) q[99];
u1(0) q[156];
cx q[156],q[100];
u1(0) q[100];
cx q[156],q[100];
u1(0) q[100];
u1(0) q[156];
cx q[156],q[101];
u1(0) q[101];
cx q[156],q[101];
u1(0) q[101];
u1(0) q[156];
cx q[156],q[102];
u1(0) q[102];
cx q[156],q[102];
u1(0) q[102];
u1(0) q[156];
cx q[156],q[103];
u1(0) q[103];
cx q[156],q[103];
u1(0) q[103];
u1(0) q[156];
cx q[156],q[104];
u1(0) q[104];
cx q[156],q[104];
u1(0) q[104];
u1(0) q[156];
cx q[156],q[105];
u1(0) q[105];
cx q[156],q[105];
u1(0) q[105];
u1(0) q[156];
cx q[156],q[106];
u1(0) q[106];
cx q[156],q[106];
u1(0) q[106];
u1(0) q[156];
cx q[156],q[107];
u1(0) q[107];
cx q[156],q[107];
u1(0) q[107];
u1(0) q[156];
cx q[156],q[108];
u1(0) q[108];
cx q[156],q[108];
u1(0) q[108];
u1(pi/281474976710656) q[156];
cx q[156],q[109];
u1(-pi/281474976710656) q[109];
cx q[156],q[109];
u1(pi/281474976710656) q[109];
u1(pi/140737488355328) q[156];
cx q[156],q[110];
u1(-pi/140737488355328) q[110];
cx q[156],q[110];
u1(pi/140737488355328) q[110];
u1(pi/70368744177664) q[156];
cx q[156],q[111];
u1(-pi/70368744177664) q[111];
cx q[156],q[111];
u1(pi/70368744177664) q[111];
u1(pi/35184372088832) q[156];
cx q[156],q[112];
u1(-pi/35184372088832) q[112];
cx q[156],q[112];
u1(pi/35184372088832) q[112];
u1(pi/17592186044416) q[156];
cx q[156],q[113];
u1(-pi/17592186044416) q[113];
cx q[156],q[113];
u1(pi/17592186044416) q[113];
u1(pi/8796093022208) q[156];
cx q[156],q[114];
u1(-pi/8796093022208) q[114];
cx q[156],q[114];
u1(pi/8796093022208) q[114];
u1(pi/4398046511104) q[156];
cx q[156],q[115];
u1(-pi/4398046511104) q[115];
cx q[156],q[115];
u1(pi/4398046511104) q[115];
u1(pi/2199023255552) q[156];
cx q[156],q[116];
u1(-pi/2199023255552) q[116];
cx q[156],q[116];
u1(pi/2199023255552) q[116];
u1(pi/1099511627776) q[156];
cx q[156],q[117];
u1(-pi/1099511627776) q[117];
cx q[156],q[117];
u1(pi/1099511627776) q[117];
u1(pi/549755813888) q[156];
cx q[156],q[118];
u1(-pi/549755813888) q[118];
cx q[156],q[118];
u1(pi/549755813888) q[118];
u1(pi/274877906944) q[156];
cx q[156],q[119];
u1(-pi/274877906944) q[119];
cx q[156],q[119];
u1(pi/274877906944) q[119];
u1(pi/137438953472) q[156];
cx q[156],q[120];
u1(-pi/137438953472) q[120];
cx q[156],q[120];
u1(pi/137438953472) q[120];
u1(pi/68719476736) q[156];
cx q[156],q[121];
u1(-pi/68719476736) q[121];
cx q[156],q[121];
u1(pi/68719476736) q[121];
u1(pi/34359738368) q[156];
cx q[156],q[122];
u1(-pi/34359738368) q[122];
cx q[156],q[122];
u1(pi/34359738368) q[122];
u1(pi/17179869184) q[156];
cx q[156],q[123];
u1(-pi/17179869184) q[123];
cx q[156],q[123];
u1(pi/17179869184) q[123];
u1(pi/8589934592) q[156];
cx q[156],q[124];
u1(-pi/8589934592) q[124];
cx q[156],q[124];
u1(pi/8589934592) q[124];
u1(pi/4294967296) q[156];
cx q[156],q[125];
u1(-pi/4294967296) q[125];
cx q[156],q[125];
u1(pi/4294967296) q[125];
u1(pi/2147483648) q[156];
cx q[156],q[126];
u1(-pi/2147483648) q[126];
cx q[156],q[126];
u1(pi/2147483648) q[126];
u1(pi/1073741824) q[156];
cx q[156],q[127];
u1(-pi/1073741824) q[127];
cx q[156],q[127];
u1(pi/1073741824) q[127];
u1(pi/536870912) q[156];
cx q[156],q[128];
u1(-pi/536870912) q[128];
cx q[156],q[128];
u1(pi/536870912) q[128];
u1(pi/268435456) q[156];
cx q[156],q[129];
u1(-pi/268435456) q[129];
cx q[156],q[129];
u1(pi/268435456) q[129];
u1(pi/134217728) q[156];
cx q[156],q[130];
u1(-pi/134217728) q[130];
cx q[156],q[130];
u1(pi/134217728) q[130];
u1(pi/67108864) q[156];
cx q[156],q[131];
u1(-pi/67108864) q[131];
cx q[156],q[131];
u1(pi/67108864) q[131];
u1(pi/33554432) q[156];
cx q[156],q[132];
u1(-pi/33554432) q[132];
cx q[156],q[132];
u1(pi/33554432) q[132];
u1(pi/16777216) q[156];
cx q[156],q[133];
u1(-pi/16777216) q[133];
cx q[156],q[133];
u1(pi/16777216) q[133];
u1(pi/8388608) q[156];
cx q[156],q[134];
u1(-pi/8388608) q[134];
cx q[156],q[134];
u1(pi/8388608) q[134];
u1(pi/4194304) q[156];
cx q[156],q[135];
u1(-pi/4194304) q[135];
cx q[156],q[135];
u1(pi/4194304) q[135];
u1(pi/2097152) q[156];
cx q[156],q[136];
u1(-pi/2097152) q[136];
cx q[156],q[136];
u1(pi/2097152) q[136];
u1(pi/1048576) q[156];
cx q[156],q[137];
u1(-pi/1048576) q[137];
cx q[156],q[137];
u1(pi/1048576) q[137];
u1(pi/524288) q[156];
cx q[156],q[138];
u1(-pi/524288) q[138];
cx q[156],q[138];
u1(pi/524288) q[138];
u1(pi/262144) q[156];
cx q[156],q[139];
u1(-pi/262144) q[139];
cx q[156],q[139];
u1(pi/262144) q[139];
u1(pi/131072) q[156];
cx q[156],q[140];
u1(-pi/131072) q[140];
cx q[156],q[140];
u1(pi/131072) q[140];
u1(pi/65536) q[156];
cx q[156],q[141];
u1(-pi/65536) q[141];
cx q[156],q[141];
u1(pi/65536) q[141];
u1(pi/32768) q[156];
cx q[156],q[142];
u1(-pi/32768) q[142];
cx q[156],q[142];
u1(pi/32768) q[142];
u1(pi/16384) q[156];
cx q[156],q[143];
u1(-pi/16384) q[143];
cx q[156],q[143];
u1(pi/16384) q[143];
u1(pi/8192) q[156];
cx q[156],q[144];
u1(-pi/8192) q[144];
cx q[156],q[144];
u1(pi/8192) q[144];
u1(pi/4096) q[156];
cx q[156],q[145];
u1(-pi/4096) q[145];
cx q[156],q[145];
u1(pi/4096) q[145];
u1(pi/2048) q[156];
cx q[156],q[146];
u1(-pi/2048) q[146];
cx q[156],q[146];
u1(pi/2048) q[146];
u1(pi/1024) q[156];
cx q[156],q[147];
u1(-pi/1024) q[147];
cx q[156],q[147];
u1(pi/1024) q[147];
u1(pi/512) q[156];
cx q[156],q[148];
u1(-pi/512) q[148];
cx q[156],q[148];
u1(pi/512) q[148];
u1(pi/256) q[156];
cx q[156],q[149];
u1(-pi/256) q[149];
cx q[156],q[149];
u1(pi/256) q[149];
u1(pi/128) q[156];
cx q[156],q[150];
u1(-pi/128) q[150];
cx q[156],q[150];
u1(pi/128) q[150];
u1(pi/64) q[156];
cx q[156],q[151];
u1(-pi/64) q[151];
cx q[156],q[151];
u1(pi/64) q[151];
u1(pi/32) q[156];
cx q[156],q[152];
u1(-pi/32) q[152];
cx q[156],q[152];
u1(pi/32) q[152];
u1(pi/16) q[156];
cx q[156],q[153];
u1(-pi/16) q[153];
cx q[156],q[153];
u1(pi/16) q[153];
u1(pi/8) q[156];
cx q[156],q[154];
u1(-pi/8) q[154];
cx q[156],q[154];
u1(pi/8) q[154];
u1(pi/4) q[156];
cx q[156],q[155];
u1(-pi/4) q[155];
cx q[156],q[155];
u1(pi/4) q[155];
h q[156];
u1(0) q[157];
cx q[157],q[0];
u1(0) q[0];
cx q[157],q[0];
u1(0) q[0];
u1(0) q[157];
cx q[157],q[1];
u1(0) q[1];
cx q[157],q[1];
u1(0) q[1];
u1(0) q[157];
cx q[157],q[2];
u1(0) q[2];
cx q[157],q[2];
u1(0) q[2];
u1(0) q[157];
cx q[157],q[3];
u1(0) q[3];
cx q[157],q[3];
u1(0) q[3];
u1(0) q[157];
cx q[157],q[4];
u1(0) q[4];
cx q[157],q[4];
u1(0) q[4];
u1(0) q[157];
cx q[157],q[5];
u1(0) q[5];
cx q[157],q[5];
u1(0) q[5];
u1(0) q[157];
cx q[157],q[6];
u1(0) q[6];
cx q[157],q[6];
u1(0) q[6];
u1(0) q[157];
cx q[157],q[7];
u1(0) q[7];
cx q[157],q[7];
u1(0) q[7];
u1(0) q[157];
cx q[157],q[8];
u1(0) q[8];
cx q[157],q[8];
u1(0) q[8];
u1(0) q[157];
cx q[157],q[9];
u1(0) q[9];
cx q[157],q[9];
u1(0) q[9];
u1(0) q[157];
cx q[157],q[10];
u1(0) q[10];
cx q[157],q[10];
u1(0) q[10];
u1(0) q[157];
cx q[157],q[11];
u1(0) q[11];
cx q[157],q[11];
u1(0) q[11];
u1(0) q[157];
cx q[157],q[12];
u1(0) q[12];
cx q[157],q[12];
u1(0) q[12];
u1(0) q[157];
cx q[157],q[13];
u1(0) q[13];
cx q[157],q[13];
u1(0) q[13];
u1(0) q[157];
cx q[157],q[14];
u1(0) q[14];
cx q[157],q[14];
u1(0) q[14];
u1(0) q[157];
cx q[157],q[15];
u1(0) q[15];
cx q[157],q[15];
u1(0) q[15];
u1(0) q[157];
cx q[157],q[16];
u1(0) q[16];
cx q[157],q[16];
u1(0) q[16];
u1(0) q[157];
cx q[157],q[17];
u1(0) q[17];
cx q[157],q[17];
u1(0) q[17];
u1(0) q[157];
cx q[157],q[18];
u1(0) q[18];
cx q[157],q[18];
u1(0) q[18];
u1(0) q[157];
cx q[157],q[19];
u1(0) q[19];
cx q[157],q[19];
u1(0) q[19];
u1(0) q[157];
cx q[157],q[20];
u1(0) q[20];
cx q[157],q[20];
u1(0) q[20];
u1(0) q[157];
cx q[157],q[21];
u1(0) q[21];
cx q[157],q[21];
u1(0) q[21];
u1(0) q[157];
cx q[157],q[22];
u1(0) q[22];
cx q[157],q[22];
u1(0) q[22];
u1(0) q[157];
cx q[157],q[23];
u1(0) q[23];
cx q[157],q[23];
u1(0) q[23];
u1(0) q[157];
cx q[157],q[24];
u1(0) q[24];
cx q[157],q[24];
u1(0) q[24];
u1(0) q[157];
cx q[157],q[25];
u1(0) q[25];
cx q[157],q[25];
u1(0) q[25];
u1(0) q[157];
cx q[157],q[26];
u1(0) q[26];
cx q[157],q[26];
u1(0) q[26];
u1(0) q[157];
cx q[157],q[27];
u1(0) q[27];
cx q[157],q[27];
u1(0) q[27];
u1(0) q[157];
cx q[157],q[28];
u1(0) q[28];
cx q[157],q[28];
u1(0) q[28];
u1(0) q[157];
cx q[157],q[29];
u1(0) q[29];
cx q[157],q[29];
u1(0) q[29];
u1(0) q[157];
cx q[157],q[30];
u1(0) q[30];
cx q[157],q[30];
u1(0) q[30];
u1(0) q[157];
cx q[157],q[31];
u1(0) q[31];
cx q[157],q[31];
u1(0) q[31];
u1(0) q[157];
cx q[157],q[32];
u1(0) q[32];
cx q[157],q[32];
u1(0) q[32];
u1(0) q[157];
cx q[157],q[33];
u1(0) q[33];
cx q[157],q[33];
u1(0) q[33];
u1(0) q[157];
cx q[157],q[34];
u1(0) q[34];
cx q[157],q[34];
u1(0) q[34];
u1(0) q[157];
cx q[157],q[35];
u1(0) q[35];
cx q[157],q[35];
u1(0) q[35];
u1(0) q[157];
cx q[157],q[36];
u1(0) q[36];
cx q[157],q[36];
u1(0) q[36];
u1(0) q[157];
cx q[157],q[37];
u1(0) q[37];
cx q[157],q[37];
u1(0) q[37];
u1(0) q[157];
cx q[157],q[38];
u1(0) q[38];
cx q[157],q[38];
u1(0) q[38];
u1(0) q[157];
cx q[157],q[39];
u1(0) q[39];
cx q[157],q[39];
u1(0) q[39];
u1(0) q[157];
cx q[157],q[40];
u1(0) q[40];
cx q[157],q[40];
u1(0) q[40];
u1(0) q[157];
cx q[157],q[41];
u1(0) q[41];
cx q[157],q[41];
u1(0) q[41];
u1(0) q[157];
cx q[157],q[42];
u1(0) q[42];
cx q[157],q[42];
u1(0) q[42];
u1(0) q[157];
cx q[157],q[43];
u1(0) q[43];
cx q[157],q[43];
u1(0) q[43];
u1(0) q[157];
cx q[157],q[44];
u1(0) q[44];
cx q[157],q[44];
u1(0) q[44];
u1(0) q[157];
cx q[157],q[45];
u1(0) q[45];
cx q[157],q[45];
u1(0) q[45];
u1(0) q[157];
cx q[157],q[46];
u1(0) q[46];
cx q[157],q[46];
u1(0) q[46];
u1(0) q[157];
cx q[157],q[47];
u1(0) q[47];
cx q[157],q[47];
u1(0) q[47];
u1(0) q[157];
cx q[157],q[48];
u1(0) q[48];
cx q[157],q[48];
u1(0) q[48];
u1(0) q[157];
cx q[157],q[49];
u1(0) q[49];
cx q[157],q[49];
u1(0) q[49];
u1(0) q[157];
cx q[157],q[50];
u1(0) q[50];
cx q[157],q[50];
u1(0) q[50];
u1(0) q[157];
cx q[157],q[51];
u1(0) q[51];
cx q[157],q[51];
u1(0) q[51];
u1(0) q[157];
cx q[157],q[52];
u1(0) q[52];
cx q[157],q[52];
u1(0) q[52];
u1(0) q[157];
cx q[157],q[53];
u1(0) q[53];
cx q[157],q[53];
u1(0) q[53];
u1(0) q[157];
cx q[157],q[54];
u1(0) q[54];
cx q[157],q[54];
u1(0) q[54];
u1(0) q[157];
cx q[157],q[55];
u1(0) q[55];
cx q[157],q[55];
u1(0) q[55];
u1(0) q[157];
cx q[157],q[56];
u1(0) q[56];
cx q[157],q[56];
u1(0) q[56];
u1(0) q[157];
cx q[157],q[57];
u1(0) q[57];
cx q[157],q[57];
u1(0) q[57];
u1(0) q[157];
cx q[157],q[58];
u1(0) q[58];
cx q[157],q[58];
u1(0) q[58];
u1(0) q[157];
cx q[157],q[59];
u1(0) q[59];
cx q[157],q[59];
u1(0) q[59];
u1(0) q[157];
cx q[157],q[60];
u1(0) q[60];
cx q[157],q[60];
u1(0) q[60];
u1(0) q[157];
cx q[157],q[61];
u1(0) q[61];
cx q[157],q[61];
u1(0) q[61];
u1(0) q[157];
cx q[157],q[62];
u1(0) q[62];
cx q[157],q[62];
u1(0) q[62];
u1(0) q[157];
cx q[157],q[63];
u1(0) q[63];
cx q[157],q[63];
u1(0) q[63];
u1(0) q[157];
cx q[157],q[64];
u1(0) q[64];
cx q[157],q[64];
u1(0) q[64];
u1(0) q[157];
cx q[157],q[65];
u1(0) q[65];
cx q[157],q[65];
u1(0) q[65];
u1(0) q[157];
cx q[157],q[66];
u1(0) q[66];
cx q[157],q[66];
u1(0) q[66];
u1(0) q[157];
cx q[157],q[67];
u1(0) q[67];
cx q[157],q[67];
u1(0) q[67];
u1(0) q[157];
cx q[157],q[68];
u1(0) q[68];
cx q[157],q[68];
u1(0) q[68];
u1(0) q[157];
cx q[157],q[69];
u1(0) q[69];
cx q[157],q[69];
u1(0) q[69];
u1(0) q[157];
cx q[157],q[70];
u1(0) q[70];
cx q[157],q[70];
u1(0) q[70];
u1(0) q[157];
cx q[157],q[71];
u1(0) q[71];
cx q[157],q[71];
u1(0) q[71];
u1(0) q[157];
cx q[157],q[72];
u1(0) q[72];
cx q[157],q[72];
u1(0) q[72];
u1(0) q[157];
cx q[157],q[73];
u1(0) q[73];
cx q[157],q[73];
u1(0) q[73];
u1(0) q[157];
cx q[157],q[74];
u1(0) q[74];
cx q[157],q[74];
u1(0) q[74];
u1(0) q[157];
cx q[157],q[75];
u1(0) q[75];
cx q[157],q[75];
u1(0) q[75];
u1(0) q[157];
cx q[157],q[76];
u1(0) q[76];
cx q[157],q[76];
u1(0) q[76];
u1(0) q[157];
cx q[157],q[77];
u1(0) q[77];
cx q[157],q[77];
u1(0) q[77];
u1(0) q[157];
cx q[157],q[78];
u1(0) q[78];
cx q[157],q[78];
u1(0) q[78];
u1(0) q[157];
cx q[157],q[79];
u1(0) q[79];
cx q[157],q[79];
u1(0) q[79];
u1(0) q[157];
cx q[157],q[80];
u1(0) q[80];
cx q[157],q[80];
u1(0) q[80];
u1(0) q[157];
cx q[157],q[81];
u1(0) q[81];
cx q[157],q[81];
u1(0) q[81];
u1(0) q[157];
cx q[157],q[82];
u1(0) q[82];
cx q[157],q[82];
u1(0) q[82];
u1(0) q[157];
cx q[157],q[83];
u1(0) q[83];
cx q[157],q[83];
u1(0) q[83];
u1(0) q[157];
cx q[157],q[84];
u1(0) q[84];
cx q[157],q[84];
u1(0) q[84];
u1(0) q[157];
cx q[157],q[85];
u1(0) q[85];
cx q[157],q[85];
u1(0) q[85];
u1(0) q[157];
cx q[157],q[86];
u1(0) q[86];
cx q[157],q[86];
u1(0) q[86];
u1(0) q[157];
cx q[157],q[87];
u1(0) q[87];
cx q[157],q[87];
u1(0) q[87];
u1(0) q[157];
cx q[157],q[88];
u1(0) q[88];
cx q[157],q[88];
u1(0) q[88];
u1(0) q[157];
cx q[157],q[89];
u1(0) q[89];
cx q[157],q[89];
u1(0) q[89];
u1(0) q[157];
cx q[157],q[90];
u1(0) q[90];
cx q[157],q[90];
u1(0) q[90];
u1(0) q[157];
cx q[157],q[91];
u1(0) q[91];
cx q[157],q[91];
u1(0) q[91];
u1(0) q[157];
cx q[157],q[92];
u1(0) q[92];
cx q[157],q[92];
u1(0) q[92];
u1(0) q[157];
cx q[157],q[93];
u1(0) q[93];
cx q[157],q[93];
u1(0) q[93];
u1(0) q[157];
cx q[157],q[94];
u1(0) q[94];
cx q[157],q[94];
u1(0) q[94];
u1(0) q[157];
cx q[157],q[95];
u1(0) q[95];
cx q[157],q[95];
u1(0) q[95];
u1(0) q[157];
cx q[157],q[96];
u1(0) q[96];
cx q[157],q[96];
u1(0) q[96];
u1(0) q[157];
cx q[157],q[97];
u1(0) q[97];
cx q[157],q[97];
u1(0) q[97];
u1(0) q[157];
cx q[157],q[98];
u1(0) q[98];
cx q[157],q[98];
u1(0) q[98];
u1(0) q[157];
cx q[157],q[99];
u1(0) q[99];
cx q[157],q[99];
u1(0) q[99];
u1(0) q[157];
cx q[157],q[100];
u1(0) q[100];
cx q[157],q[100];
u1(0) q[100];
u1(0) q[157];
cx q[157],q[101];
u1(0) q[101];
cx q[157],q[101];
u1(0) q[101];
u1(0) q[157];
cx q[157],q[102];
u1(0) q[102];
cx q[157],q[102];
u1(0) q[102];
u1(0) q[157];
cx q[157],q[103];
u1(0) q[103];
cx q[157],q[103];
u1(0) q[103];
u1(0) q[157];
cx q[157],q[104];
u1(0) q[104];
cx q[157],q[104];
u1(0) q[104];
u1(0) q[157];
cx q[157],q[105];
u1(0) q[105];
cx q[157],q[105];
u1(0) q[105];
u1(0) q[157];
cx q[157],q[106];
u1(0) q[106];
cx q[157],q[106];
u1(0) q[106];
u1(0) q[157];
cx q[157],q[107];
u1(0) q[107];
cx q[157],q[107];
u1(0) q[107];
u1(0) q[157];
cx q[157],q[108];
u1(0) q[108];
cx q[157],q[108];
u1(0) q[108];
u1(0) q[157];
cx q[157],q[109];
u1(0) q[109];
cx q[157],q[109];
u1(0) q[109];
u1(pi/281474976710656) q[157];
cx q[157],q[110];
u1(-pi/281474976710656) q[110];
cx q[157],q[110];
u1(pi/281474976710656) q[110];
u1(pi/140737488355328) q[157];
cx q[157],q[111];
u1(-pi/140737488355328) q[111];
cx q[157],q[111];
u1(pi/140737488355328) q[111];
u1(pi/70368744177664) q[157];
cx q[157],q[112];
u1(-pi/70368744177664) q[112];
cx q[157],q[112];
u1(pi/70368744177664) q[112];
u1(pi/35184372088832) q[157];
cx q[157],q[113];
u1(-pi/35184372088832) q[113];
cx q[157],q[113];
u1(pi/35184372088832) q[113];
u1(pi/17592186044416) q[157];
cx q[157],q[114];
u1(-pi/17592186044416) q[114];
cx q[157],q[114];
u1(pi/17592186044416) q[114];
u1(pi/8796093022208) q[157];
cx q[157],q[115];
u1(-pi/8796093022208) q[115];
cx q[157],q[115];
u1(pi/8796093022208) q[115];
u1(pi/4398046511104) q[157];
cx q[157],q[116];
u1(-pi/4398046511104) q[116];
cx q[157],q[116];
u1(pi/4398046511104) q[116];
u1(pi/2199023255552) q[157];
cx q[157],q[117];
u1(-pi/2199023255552) q[117];
cx q[157],q[117];
u1(pi/2199023255552) q[117];
u1(pi/1099511627776) q[157];
cx q[157],q[118];
u1(-pi/1099511627776) q[118];
cx q[157],q[118];
u1(pi/1099511627776) q[118];
u1(pi/549755813888) q[157];
cx q[157],q[119];
u1(-pi/549755813888) q[119];
cx q[157],q[119];
u1(pi/549755813888) q[119];
u1(pi/274877906944) q[157];
cx q[157],q[120];
u1(-pi/274877906944) q[120];
cx q[157],q[120];
u1(pi/274877906944) q[120];
u1(pi/137438953472) q[157];
cx q[157],q[121];
u1(-pi/137438953472) q[121];
cx q[157],q[121];
u1(pi/137438953472) q[121];
u1(pi/68719476736) q[157];
cx q[157],q[122];
u1(-pi/68719476736) q[122];
cx q[157],q[122];
u1(pi/68719476736) q[122];
u1(pi/34359738368) q[157];
cx q[157],q[123];
u1(-pi/34359738368) q[123];
cx q[157],q[123];
u1(pi/34359738368) q[123];
u1(pi/17179869184) q[157];
cx q[157],q[124];
u1(-pi/17179869184) q[124];
cx q[157],q[124];
u1(pi/17179869184) q[124];
u1(pi/8589934592) q[157];
cx q[157],q[125];
u1(-pi/8589934592) q[125];
cx q[157],q[125];
u1(pi/8589934592) q[125];
u1(pi/4294967296) q[157];
cx q[157],q[126];
u1(-pi/4294967296) q[126];
cx q[157],q[126];
u1(pi/4294967296) q[126];
u1(pi/2147483648) q[157];
cx q[157],q[127];
u1(-pi/2147483648) q[127];
cx q[157],q[127];
u1(pi/2147483648) q[127];
u1(pi/1073741824) q[157];
cx q[157],q[128];
u1(-pi/1073741824) q[128];
cx q[157],q[128];
u1(pi/1073741824) q[128];
u1(pi/536870912) q[157];
cx q[157],q[129];
u1(-pi/536870912) q[129];
cx q[157],q[129];
u1(pi/536870912) q[129];
u1(pi/268435456) q[157];
cx q[157],q[130];
u1(-pi/268435456) q[130];
cx q[157],q[130];
u1(pi/268435456) q[130];
u1(pi/134217728) q[157];
cx q[157],q[131];
u1(-pi/134217728) q[131];
cx q[157],q[131];
u1(pi/134217728) q[131];
u1(pi/67108864) q[157];
cx q[157],q[132];
u1(-pi/67108864) q[132];
cx q[157],q[132];
u1(pi/67108864) q[132];
u1(pi/33554432) q[157];
cx q[157],q[133];
u1(-pi/33554432) q[133];
cx q[157],q[133];
u1(pi/33554432) q[133];
u1(pi/16777216) q[157];
cx q[157],q[134];
u1(-pi/16777216) q[134];
cx q[157],q[134];
u1(pi/16777216) q[134];
u1(pi/8388608) q[157];
cx q[157],q[135];
u1(-pi/8388608) q[135];
cx q[157],q[135];
u1(pi/8388608) q[135];
u1(pi/4194304) q[157];
cx q[157],q[136];
u1(-pi/4194304) q[136];
cx q[157],q[136];
u1(pi/4194304) q[136];
u1(pi/2097152) q[157];
cx q[157],q[137];
u1(-pi/2097152) q[137];
cx q[157],q[137];
u1(pi/2097152) q[137];
u1(pi/1048576) q[157];
cx q[157],q[138];
u1(-pi/1048576) q[138];
cx q[157],q[138];
u1(pi/1048576) q[138];
u1(pi/524288) q[157];
cx q[157],q[139];
u1(-pi/524288) q[139];
cx q[157],q[139];
u1(pi/524288) q[139];
u1(pi/262144) q[157];
cx q[157],q[140];
u1(-pi/262144) q[140];
cx q[157],q[140];
u1(pi/262144) q[140];
u1(pi/131072) q[157];
cx q[157],q[141];
u1(-pi/131072) q[141];
cx q[157],q[141];
u1(pi/131072) q[141];
u1(pi/65536) q[157];
cx q[157],q[142];
u1(-pi/65536) q[142];
cx q[157],q[142];
u1(pi/65536) q[142];
u1(pi/32768) q[157];
cx q[157],q[143];
u1(-pi/32768) q[143];
cx q[157],q[143];
u1(pi/32768) q[143];
u1(pi/16384) q[157];
cx q[157],q[144];
u1(-pi/16384) q[144];
cx q[157],q[144];
u1(pi/16384) q[144];
u1(pi/8192) q[157];
cx q[157],q[145];
u1(-pi/8192) q[145];
cx q[157],q[145];
u1(pi/8192) q[145];
u1(pi/4096) q[157];
cx q[157],q[146];
u1(-pi/4096) q[146];
cx q[157],q[146];
u1(pi/4096) q[146];
u1(pi/2048) q[157];
cx q[157],q[147];
u1(-pi/2048) q[147];
cx q[157],q[147];
u1(pi/2048) q[147];
u1(pi/1024) q[157];
cx q[157],q[148];
u1(-pi/1024) q[148];
cx q[157],q[148];
u1(pi/1024) q[148];
u1(pi/512) q[157];
cx q[157],q[149];
u1(-pi/512) q[149];
cx q[157],q[149];
u1(pi/512) q[149];
u1(pi/256) q[157];
cx q[157],q[150];
u1(-pi/256) q[150];
cx q[157],q[150];
u1(pi/256) q[150];
u1(pi/128) q[157];
cx q[157],q[151];
u1(-pi/128) q[151];
cx q[157],q[151];
u1(pi/128) q[151];
u1(pi/64) q[157];
cx q[157],q[152];
u1(-pi/64) q[152];
cx q[157],q[152];
u1(pi/64) q[152];
u1(pi/32) q[157];
cx q[157],q[153];
u1(-pi/32) q[153];
cx q[157],q[153];
u1(pi/32) q[153];
u1(pi/16) q[157];
cx q[157],q[154];
u1(-pi/16) q[154];
cx q[157],q[154];
u1(pi/16) q[154];
u1(pi/8) q[157];
cx q[157],q[155];
u1(-pi/8) q[155];
cx q[157],q[155];
u1(pi/8) q[155];
u1(pi/4) q[157];
cx q[157],q[156];
u1(-pi/4) q[156];
cx q[157],q[156];
u1(pi/4) q[156];
h q[157];
u1(0) q[158];
cx q[158],q[0];
u1(0) q[0];
cx q[158],q[0];
u1(0) q[0];
u1(0) q[158];
cx q[158],q[1];
u1(0) q[1];
cx q[158],q[1];
u1(0) q[1];
u1(0) q[158];
cx q[158],q[2];
u1(0) q[2];
cx q[158],q[2];
u1(0) q[2];
u1(0) q[158];
cx q[158],q[3];
u1(0) q[3];
cx q[158],q[3];
u1(0) q[3];
u1(0) q[158];
cx q[158],q[4];
u1(0) q[4];
cx q[158],q[4];
u1(0) q[4];
u1(0) q[158];
cx q[158],q[5];
u1(0) q[5];
cx q[158],q[5];
u1(0) q[5];
u1(0) q[158];
cx q[158],q[6];
u1(0) q[6];
cx q[158],q[6];
u1(0) q[6];
u1(0) q[158];
cx q[158],q[7];
u1(0) q[7];
cx q[158],q[7];
u1(0) q[7];
u1(0) q[158];
cx q[158],q[8];
u1(0) q[8];
cx q[158],q[8];
u1(0) q[8];
u1(0) q[158];
cx q[158],q[9];
u1(0) q[9];
cx q[158],q[9];
u1(0) q[9];
u1(0) q[158];
cx q[158],q[10];
u1(0) q[10];
cx q[158],q[10];
u1(0) q[10];
u1(0) q[158];
cx q[158],q[11];
u1(0) q[11];
cx q[158],q[11];
u1(0) q[11];
u1(0) q[158];
cx q[158],q[12];
u1(0) q[12];
cx q[158],q[12];
u1(0) q[12];
u1(0) q[158];
cx q[158],q[13];
u1(0) q[13];
cx q[158],q[13];
u1(0) q[13];
u1(0) q[158];
cx q[158],q[14];
u1(0) q[14];
cx q[158],q[14];
u1(0) q[14];
u1(0) q[158];
cx q[158],q[15];
u1(0) q[15];
cx q[158],q[15];
u1(0) q[15];
u1(0) q[158];
cx q[158],q[16];
u1(0) q[16];
cx q[158],q[16];
u1(0) q[16];
u1(0) q[158];
cx q[158],q[17];
u1(0) q[17];
cx q[158],q[17];
u1(0) q[17];
u1(0) q[158];
cx q[158],q[18];
u1(0) q[18];
cx q[158],q[18];
u1(0) q[18];
u1(0) q[158];
cx q[158],q[19];
u1(0) q[19];
cx q[158],q[19];
u1(0) q[19];
u1(0) q[158];
cx q[158],q[20];
u1(0) q[20];
cx q[158],q[20];
u1(0) q[20];
u1(0) q[158];
cx q[158],q[21];
u1(0) q[21];
cx q[158],q[21];
u1(0) q[21];
u1(0) q[158];
cx q[158],q[22];
u1(0) q[22];
cx q[158],q[22];
u1(0) q[22];
u1(0) q[158];
cx q[158],q[23];
u1(0) q[23];
cx q[158],q[23];
u1(0) q[23];
u1(0) q[158];
cx q[158],q[24];
u1(0) q[24];
cx q[158],q[24];
u1(0) q[24];
u1(0) q[158];
cx q[158],q[25];
u1(0) q[25];
cx q[158],q[25];
u1(0) q[25];
u1(0) q[158];
cx q[158],q[26];
u1(0) q[26];
cx q[158],q[26];
u1(0) q[26];
u1(0) q[158];
cx q[158],q[27];
u1(0) q[27];
cx q[158],q[27];
u1(0) q[27];
u1(0) q[158];
cx q[158],q[28];
u1(0) q[28];
cx q[158],q[28];
u1(0) q[28];
u1(0) q[158];
cx q[158],q[29];
u1(0) q[29];
cx q[158],q[29];
u1(0) q[29];
u1(0) q[158];
cx q[158],q[30];
u1(0) q[30];
cx q[158],q[30];
u1(0) q[30];
u1(0) q[158];
cx q[158],q[31];
u1(0) q[31];
cx q[158],q[31];
u1(0) q[31];
u1(0) q[158];
cx q[158],q[32];
u1(0) q[32];
cx q[158],q[32];
u1(0) q[32];
u1(0) q[158];
cx q[158],q[33];
u1(0) q[33];
cx q[158],q[33];
u1(0) q[33];
u1(0) q[158];
cx q[158],q[34];
u1(0) q[34];
cx q[158],q[34];
u1(0) q[34];
u1(0) q[158];
cx q[158],q[35];
u1(0) q[35];
cx q[158],q[35];
u1(0) q[35];
u1(0) q[158];
cx q[158],q[36];
u1(0) q[36];
cx q[158],q[36];
u1(0) q[36];
u1(0) q[158];
cx q[158],q[37];
u1(0) q[37];
cx q[158],q[37];
u1(0) q[37];
u1(0) q[158];
cx q[158],q[38];
u1(0) q[38];
cx q[158],q[38];
u1(0) q[38];
u1(0) q[158];
cx q[158],q[39];
u1(0) q[39];
cx q[158],q[39];
u1(0) q[39];
u1(0) q[158];
cx q[158],q[40];
u1(0) q[40];
cx q[158],q[40];
u1(0) q[40];
u1(0) q[158];
cx q[158],q[41];
u1(0) q[41];
cx q[158],q[41];
u1(0) q[41];
u1(0) q[158];
cx q[158],q[42];
u1(0) q[42];
cx q[158],q[42];
u1(0) q[42];
u1(0) q[158];
cx q[158],q[43];
u1(0) q[43];
cx q[158],q[43];
u1(0) q[43];
u1(0) q[158];
cx q[158],q[44];
u1(0) q[44];
cx q[158],q[44];
u1(0) q[44];
u1(0) q[158];
cx q[158],q[45];
u1(0) q[45];
cx q[158],q[45];
u1(0) q[45];
u1(0) q[158];
cx q[158],q[46];
u1(0) q[46];
cx q[158],q[46];
u1(0) q[46];
u1(0) q[158];
cx q[158],q[47];
u1(0) q[47];
cx q[158],q[47];
u1(0) q[47];
u1(0) q[158];
cx q[158],q[48];
u1(0) q[48];
cx q[158],q[48];
u1(0) q[48];
u1(0) q[158];
cx q[158],q[49];
u1(0) q[49];
cx q[158],q[49];
u1(0) q[49];
u1(0) q[158];
cx q[158],q[50];
u1(0) q[50];
cx q[158],q[50];
u1(0) q[50];
u1(0) q[158];
cx q[158],q[51];
u1(0) q[51];
cx q[158],q[51];
u1(0) q[51];
u1(0) q[158];
cx q[158],q[52];
u1(0) q[52];
cx q[158],q[52];
u1(0) q[52];
u1(0) q[158];
cx q[158],q[53];
u1(0) q[53];
cx q[158],q[53];
u1(0) q[53];
u1(0) q[158];
cx q[158],q[54];
u1(0) q[54];
cx q[158],q[54];
u1(0) q[54];
u1(0) q[158];
cx q[158],q[55];
u1(0) q[55];
cx q[158],q[55];
u1(0) q[55];
u1(0) q[158];
cx q[158],q[56];
u1(0) q[56];
cx q[158],q[56];
u1(0) q[56];
u1(0) q[158];
cx q[158],q[57];
u1(0) q[57];
cx q[158],q[57];
u1(0) q[57];
u1(0) q[158];
cx q[158],q[58];
u1(0) q[58];
cx q[158],q[58];
u1(0) q[58];
u1(0) q[158];
cx q[158],q[59];
u1(0) q[59];
cx q[158],q[59];
u1(0) q[59];
u1(0) q[158];
cx q[158],q[60];
u1(0) q[60];
cx q[158],q[60];
u1(0) q[60];
u1(0) q[158];
cx q[158],q[61];
u1(0) q[61];
cx q[158],q[61];
u1(0) q[61];
u1(0) q[158];
cx q[158],q[62];
u1(0) q[62];
cx q[158],q[62];
u1(0) q[62];
u1(0) q[158];
cx q[158],q[63];
u1(0) q[63];
cx q[158],q[63];
u1(0) q[63];
u1(0) q[158];
cx q[158],q[64];
u1(0) q[64];
cx q[158],q[64];
u1(0) q[64];
u1(0) q[158];
cx q[158],q[65];
u1(0) q[65];
cx q[158],q[65];
u1(0) q[65];
u1(0) q[158];
cx q[158],q[66];
u1(0) q[66];
cx q[158],q[66];
u1(0) q[66];
u1(0) q[158];
cx q[158],q[67];
u1(0) q[67];
cx q[158],q[67];
u1(0) q[67];
u1(0) q[158];
cx q[158],q[68];
u1(0) q[68];
cx q[158],q[68];
u1(0) q[68];
u1(0) q[158];
cx q[158],q[69];
u1(0) q[69];
cx q[158],q[69];
u1(0) q[69];
u1(0) q[158];
cx q[158],q[70];
u1(0) q[70];
cx q[158],q[70];
u1(0) q[70];
u1(0) q[158];
cx q[158],q[71];
u1(0) q[71];
cx q[158],q[71];
u1(0) q[71];
u1(0) q[158];
cx q[158],q[72];
u1(0) q[72];
cx q[158],q[72];
u1(0) q[72];
u1(0) q[158];
cx q[158],q[73];
u1(0) q[73];
cx q[158],q[73];
u1(0) q[73];
u1(0) q[158];
cx q[158],q[74];
u1(0) q[74];
cx q[158],q[74];
u1(0) q[74];
u1(0) q[158];
cx q[158],q[75];
u1(0) q[75];
cx q[158],q[75];
u1(0) q[75];
u1(0) q[158];
cx q[158],q[76];
u1(0) q[76];
cx q[158],q[76];
u1(0) q[76];
u1(0) q[158];
cx q[158],q[77];
u1(0) q[77];
cx q[158],q[77];
u1(0) q[77];
u1(0) q[158];
cx q[158],q[78];
u1(0) q[78];
cx q[158],q[78];
u1(0) q[78];
u1(0) q[158];
cx q[158],q[79];
u1(0) q[79];
cx q[158],q[79];
u1(0) q[79];
u1(0) q[158];
cx q[158],q[80];
u1(0) q[80];
cx q[158],q[80];
u1(0) q[80];
u1(0) q[158];
cx q[158],q[81];
u1(0) q[81];
cx q[158],q[81];
u1(0) q[81];
u1(0) q[158];
cx q[158],q[82];
u1(0) q[82];
cx q[158],q[82];
u1(0) q[82];
u1(0) q[158];
cx q[158],q[83];
u1(0) q[83];
cx q[158],q[83];
u1(0) q[83];
u1(0) q[158];
cx q[158],q[84];
u1(0) q[84];
cx q[158],q[84];
u1(0) q[84];
u1(0) q[158];
cx q[158],q[85];
u1(0) q[85];
cx q[158],q[85];
u1(0) q[85];
u1(0) q[158];
cx q[158],q[86];
u1(0) q[86];
cx q[158],q[86];
u1(0) q[86];
u1(0) q[158];
cx q[158],q[87];
u1(0) q[87];
cx q[158],q[87];
u1(0) q[87];
u1(0) q[158];
cx q[158],q[88];
u1(0) q[88];
cx q[158],q[88];
u1(0) q[88];
u1(0) q[158];
cx q[158],q[89];
u1(0) q[89];
cx q[158],q[89];
u1(0) q[89];
u1(0) q[158];
cx q[158],q[90];
u1(0) q[90];
cx q[158],q[90];
u1(0) q[90];
u1(0) q[158];
cx q[158],q[91];
u1(0) q[91];
cx q[158],q[91];
u1(0) q[91];
u1(0) q[158];
cx q[158],q[92];
u1(0) q[92];
cx q[158],q[92];
u1(0) q[92];
u1(0) q[158];
cx q[158],q[93];
u1(0) q[93];
cx q[158],q[93];
u1(0) q[93];
u1(0) q[158];
cx q[158],q[94];
u1(0) q[94];
cx q[158],q[94];
u1(0) q[94];
u1(0) q[158];
cx q[158],q[95];
u1(0) q[95];
cx q[158],q[95];
u1(0) q[95];
u1(0) q[158];
cx q[158],q[96];
u1(0) q[96];
cx q[158],q[96];
u1(0) q[96];
u1(0) q[158];
cx q[158],q[97];
u1(0) q[97];
cx q[158],q[97];
u1(0) q[97];
u1(0) q[158];
cx q[158],q[98];
u1(0) q[98];
cx q[158],q[98];
u1(0) q[98];
u1(0) q[158];
cx q[158],q[99];
u1(0) q[99];
cx q[158],q[99];
u1(0) q[99];
u1(0) q[158];
cx q[158],q[100];
u1(0) q[100];
cx q[158],q[100];
u1(0) q[100];
u1(0) q[158];
cx q[158],q[101];
u1(0) q[101];
cx q[158],q[101];
u1(0) q[101];
u1(0) q[158];
cx q[158],q[102];
u1(0) q[102];
cx q[158],q[102];
u1(0) q[102];
u1(0) q[158];
cx q[158],q[103];
u1(0) q[103];
cx q[158],q[103];
u1(0) q[103];
u1(0) q[158];
cx q[158],q[104];
u1(0) q[104];
cx q[158],q[104];
u1(0) q[104];
u1(0) q[158];
cx q[158],q[105];
u1(0) q[105];
cx q[158],q[105];
u1(0) q[105];
u1(0) q[158];
cx q[158],q[106];
u1(0) q[106];
cx q[158],q[106];
u1(0) q[106];
u1(0) q[158];
cx q[158],q[107];
u1(0) q[107];
cx q[158],q[107];
u1(0) q[107];
u1(0) q[158];
cx q[158],q[108];
u1(0) q[108];
cx q[158],q[108];
u1(0) q[108];
u1(0) q[158];
cx q[158],q[109];
u1(0) q[109];
cx q[158],q[109];
u1(0) q[109];
u1(0) q[158];
cx q[158],q[110];
u1(0) q[110];
cx q[158],q[110];
u1(0) q[110];
u1(pi/281474976710656) q[158];
cx q[158],q[111];
u1(-pi/281474976710656) q[111];
cx q[158],q[111];
u1(pi/281474976710656) q[111];
u1(pi/140737488355328) q[158];
cx q[158],q[112];
u1(-pi/140737488355328) q[112];
cx q[158],q[112];
u1(pi/140737488355328) q[112];
u1(pi/70368744177664) q[158];
cx q[158],q[113];
u1(-pi/70368744177664) q[113];
cx q[158],q[113];
u1(pi/70368744177664) q[113];
u1(pi/35184372088832) q[158];
cx q[158],q[114];
u1(-pi/35184372088832) q[114];
cx q[158],q[114];
u1(pi/35184372088832) q[114];
u1(pi/17592186044416) q[158];
cx q[158],q[115];
u1(-pi/17592186044416) q[115];
cx q[158],q[115];
u1(pi/17592186044416) q[115];
u1(pi/8796093022208) q[158];
cx q[158],q[116];
u1(-pi/8796093022208) q[116];
cx q[158],q[116];
u1(pi/8796093022208) q[116];
u1(pi/4398046511104) q[158];
cx q[158],q[117];
u1(-pi/4398046511104) q[117];
cx q[158],q[117];
u1(pi/4398046511104) q[117];
u1(pi/2199023255552) q[158];
cx q[158],q[118];
u1(-pi/2199023255552) q[118];
cx q[158],q[118];
u1(pi/2199023255552) q[118];
u1(pi/1099511627776) q[158];
cx q[158],q[119];
u1(-pi/1099511627776) q[119];
cx q[158],q[119];
u1(pi/1099511627776) q[119];
u1(pi/549755813888) q[158];
cx q[158],q[120];
u1(-pi/549755813888) q[120];
cx q[158],q[120];
u1(pi/549755813888) q[120];
u1(pi/274877906944) q[158];
cx q[158],q[121];
u1(-pi/274877906944) q[121];
cx q[158],q[121];
u1(pi/274877906944) q[121];
u1(pi/137438953472) q[158];
cx q[158],q[122];
u1(-pi/137438953472) q[122];
cx q[158],q[122];
u1(pi/137438953472) q[122];
u1(pi/68719476736) q[158];
cx q[158],q[123];
u1(-pi/68719476736) q[123];
cx q[158],q[123];
u1(pi/68719476736) q[123];
u1(pi/34359738368) q[158];
cx q[158],q[124];
u1(-pi/34359738368) q[124];
cx q[158],q[124];
u1(pi/34359738368) q[124];
u1(pi/17179869184) q[158];
cx q[158],q[125];
u1(-pi/17179869184) q[125];
cx q[158],q[125];
u1(pi/17179869184) q[125];
u1(pi/8589934592) q[158];
cx q[158],q[126];
u1(-pi/8589934592) q[126];
cx q[158],q[126];
u1(pi/8589934592) q[126];
u1(pi/4294967296) q[158];
cx q[158],q[127];
u1(-pi/4294967296) q[127];
cx q[158],q[127];
u1(pi/4294967296) q[127];
u1(pi/2147483648) q[158];
cx q[158],q[128];
u1(-pi/2147483648) q[128];
cx q[158],q[128];
u1(pi/2147483648) q[128];
u1(pi/1073741824) q[158];
cx q[158],q[129];
u1(-pi/1073741824) q[129];
cx q[158],q[129];
u1(pi/1073741824) q[129];
u1(pi/536870912) q[158];
cx q[158],q[130];
u1(-pi/536870912) q[130];
cx q[158],q[130];
u1(pi/536870912) q[130];
u1(pi/268435456) q[158];
cx q[158],q[131];
u1(-pi/268435456) q[131];
cx q[158],q[131];
u1(pi/268435456) q[131];
u1(pi/134217728) q[158];
cx q[158],q[132];
u1(-pi/134217728) q[132];
cx q[158],q[132];
u1(pi/134217728) q[132];
u1(pi/67108864) q[158];
cx q[158],q[133];
u1(-pi/67108864) q[133];
cx q[158],q[133];
u1(pi/67108864) q[133];
u1(pi/33554432) q[158];
cx q[158],q[134];
u1(-pi/33554432) q[134];
cx q[158],q[134];
u1(pi/33554432) q[134];
u1(pi/16777216) q[158];
cx q[158],q[135];
u1(-pi/16777216) q[135];
cx q[158],q[135];
u1(pi/16777216) q[135];
u1(pi/8388608) q[158];
cx q[158],q[136];
u1(-pi/8388608) q[136];
cx q[158],q[136];
u1(pi/8388608) q[136];
u1(pi/4194304) q[158];
cx q[158],q[137];
u1(-pi/4194304) q[137];
cx q[158],q[137];
u1(pi/4194304) q[137];
u1(pi/2097152) q[158];
cx q[158],q[138];
u1(-pi/2097152) q[138];
cx q[158],q[138];
u1(pi/2097152) q[138];
u1(pi/1048576) q[158];
cx q[158],q[139];
u1(-pi/1048576) q[139];
cx q[158],q[139];
u1(pi/1048576) q[139];
u1(pi/524288) q[158];
cx q[158],q[140];
u1(-pi/524288) q[140];
cx q[158],q[140];
u1(pi/524288) q[140];
u1(pi/262144) q[158];
cx q[158],q[141];
u1(-pi/262144) q[141];
cx q[158],q[141];
u1(pi/262144) q[141];
u1(pi/131072) q[158];
cx q[158],q[142];
u1(-pi/131072) q[142];
cx q[158],q[142];
u1(pi/131072) q[142];
u1(pi/65536) q[158];
cx q[158],q[143];
u1(-pi/65536) q[143];
cx q[158],q[143];
u1(pi/65536) q[143];
u1(pi/32768) q[158];
cx q[158],q[144];
u1(-pi/32768) q[144];
cx q[158],q[144];
u1(pi/32768) q[144];
u1(pi/16384) q[158];
cx q[158],q[145];
u1(-pi/16384) q[145];
cx q[158],q[145];
u1(pi/16384) q[145];
u1(pi/8192) q[158];
cx q[158],q[146];
u1(-pi/8192) q[146];
cx q[158],q[146];
u1(pi/8192) q[146];
u1(pi/4096) q[158];
cx q[158],q[147];
u1(-pi/4096) q[147];
cx q[158],q[147];
u1(pi/4096) q[147];
u1(pi/2048) q[158];
cx q[158],q[148];
u1(-pi/2048) q[148];
cx q[158],q[148];
u1(pi/2048) q[148];
u1(pi/1024) q[158];
cx q[158],q[149];
u1(-pi/1024) q[149];
cx q[158],q[149];
u1(pi/1024) q[149];
u1(pi/512) q[158];
cx q[158],q[150];
u1(-pi/512) q[150];
cx q[158],q[150];
u1(pi/512) q[150];
u1(pi/256) q[158];
cx q[158],q[151];
u1(-pi/256) q[151];
cx q[158],q[151];
u1(pi/256) q[151];
u1(pi/128) q[158];
cx q[158],q[152];
u1(-pi/128) q[152];
cx q[158],q[152];
u1(pi/128) q[152];
u1(pi/64) q[158];
cx q[158],q[153];
u1(-pi/64) q[153];
cx q[158],q[153];
u1(pi/64) q[153];
u1(pi/32) q[158];
cx q[158],q[154];
u1(-pi/32) q[154];
cx q[158],q[154];
u1(pi/32) q[154];
u1(pi/16) q[158];
cx q[158],q[155];
u1(-pi/16) q[155];
cx q[158],q[155];
u1(pi/16) q[155];
u1(pi/8) q[158];
cx q[158],q[156];
u1(-pi/8) q[156];
cx q[158],q[156];
u1(pi/8) q[156];
u1(pi/4) q[158];
cx q[158],q[157];
u1(-pi/4) q[157];
cx q[158],q[157];
u1(pi/4) q[157];
h q[158];
u1(0) q[159];
cx q[159],q[0];
u1(0) q[0];
cx q[159],q[0];
u1(0) q[0];
u1(0) q[159];
cx q[159],q[1];
u1(0) q[1];
cx q[159],q[1];
u1(0) q[1];
u1(0) q[159];
cx q[159],q[2];
u1(0) q[2];
cx q[159],q[2];
u1(0) q[2];
u1(0) q[159];
cx q[159],q[3];
u1(0) q[3];
cx q[159],q[3];
u1(0) q[3];
u1(0) q[159];
cx q[159],q[4];
u1(0) q[4];
cx q[159],q[4];
u1(0) q[4];
u1(0) q[159];
cx q[159],q[5];
u1(0) q[5];
cx q[159],q[5];
u1(0) q[5];
u1(0) q[159];
cx q[159],q[6];
u1(0) q[6];
cx q[159],q[6];
u1(0) q[6];
u1(0) q[159];
cx q[159],q[7];
u1(0) q[7];
cx q[159],q[7];
u1(0) q[7];
u1(0) q[159];
cx q[159],q[8];
u1(0) q[8];
cx q[159],q[8];
u1(0) q[8];
u1(0) q[159];
cx q[159],q[9];
u1(0) q[9];
cx q[159],q[9];
u1(0) q[9];
u1(0) q[159];
cx q[159],q[10];
u1(0) q[10];
cx q[159],q[10];
u1(0) q[10];
u1(0) q[159];
cx q[159],q[11];
u1(0) q[11];
cx q[159],q[11];
u1(0) q[11];
u1(0) q[159];
cx q[159],q[12];
u1(0) q[12];
cx q[159],q[12];
u1(0) q[12];
u1(0) q[159];
cx q[159],q[13];
u1(0) q[13];
cx q[159],q[13];
u1(0) q[13];
u1(0) q[159];
cx q[159],q[14];
u1(0) q[14];
cx q[159],q[14];
u1(0) q[14];
u1(0) q[159];
cx q[159],q[15];
u1(0) q[15];
cx q[159],q[15];
u1(0) q[15];
u1(0) q[159];
cx q[159],q[16];
u1(0) q[16];
cx q[159],q[16];
u1(0) q[16];
u1(0) q[159];
cx q[159],q[17];
u1(0) q[17];
cx q[159],q[17];
u1(0) q[17];
u1(0) q[159];
cx q[159],q[18];
u1(0) q[18];
cx q[159],q[18];
u1(0) q[18];
u1(0) q[159];
cx q[159],q[19];
u1(0) q[19];
cx q[159],q[19];
u1(0) q[19];
u1(0) q[159];
cx q[159],q[20];
u1(0) q[20];
cx q[159],q[20];
u1(0) q[20];
u1(0) q[159];
cx q[159],q[21];
u1(0) q[21];
cx q[159],q[21];
u1(0) q[21];
u1(0) q[159];
cx q[159],q[22];
u1(0) q[22];
cx q[159],q[22];
u1(0) q[22];
u1(0) q[159];
cx q[159],q[23];
u1(0) q[23];
cx q[159],q[23];
u1(0) q[23];
u1(0) q[159];
cx q[159],q[24];
u1(0) q[24];
cx q[159],q[24];
u1(0) q[24];
u1(0) q[159];
cx q[159],q[25];
u1(0) q[25];
cx q[159],q[25];
u1(0) q[25];
u1(0) q[159];
cx q[159],q[26];
u1(0) q[26];
cx q[159],q[26];
u1(0) q[26];
u1(0) q[159];
cx q[159],q[27];
u1(0) q[27];
cx q[159],q[27];
u1(0) q[27];
u1(0) q[159];
cx q[159],q[28];
u1(0) q[28];
cx q[159],q[28];
u1(0) q[28];
u1(0) q[159];
cx q[159],q[29];
u1(0) q[29];
cx q[159],q[29];
u1(0) q[29];
u1(0) q[159];
cx q[159],q[30];
u1(0) q[30];
cx q[159],q[30];
u1(0) q[30];
u1(0) q[159];
cx q[159],q[31];
u1(0) q[31];
cx q[159],q[31];
u1(0) q[31];
u1(0) q[159];
cx q[159],q[32];
u1(0) q[32];
cx q[159],q[32];
u1(0) q[32];
u1(0) q[159];
cx q[159],q[33];
u1(0) q[33];
cx q[159],q[33];
u1(0) q[33];
u1(0) q[159];
cx q[159],q[34];
u1(0) q[34];
cx q[159],q[34];
u1(0) q[34];
u1(0) q[159];
cx q[159],q[35];
u1(0) q[35];
cx q[159],q[35];
u1(0) q[35];
u1(0) q[159];
cx q[159],q[36];
u1(0) q[36];
cx q[159],q[36];
u1(0) q[36];
u1(0) q[159];
cx q[159],q[37];
u1(0) q[37];
cx q[159],q[37];
u1(0) q[37];
u1(0) q[159];
cx q[159],q[38];
u1(0) q[38];
cx q[159],q[38];
u1(0) q[38];
u1(0) q[159];
cx q[159],q[39];
u1(0) q[39];
cx q[159],q[39];
u1(0) q[39];
u1(0) q[159];
cx q[159],q[40];
u1(0) q[40];
cx q[159],q[40];
u1(0) q[40];
u1(0) q[159];
cx q[159],q[41];
u1(0) q[41];
cx q[159],q[41];
u1(0) q[41];
u1(0) q[159];
cx q[159],q[42];
u1(0) q[42];
cx q[159],q[42];
u1(0) q[42];
u1(0) q[159];
cx q[159],q[43];
u1(0) q[43];
cx q[159],q[43];
u1(0) q[43];
u1(0) q[159];
cx q[159],q[44];
u1(0) q[44];
cx q[159],q[44];
u1(0) q[44];
u1(0) q[159];
cx q[159],q[45];
u1(0) q[45];
cx q[159],q[45];
u1(0) q[45];
u1(0) q[159];
cx q[159],q[46];
u1(0) q[46];
cx q[159],q[46];
u1(0) q[46];
u1(0) q[159];
cx q[159],q[47];
u1(0) q[47];
cx q[159],q[47];
u1(0) q[47];
u1(0) q[159];
cx q[159],q[48];
u1(0) q[48];
cx q[159],q[48];
u1(0) q[48];
u1(0) q[159];
cx q[159],q[49];
u1(0) q[49];
cx q[159],q[49];
u1(0) q[49];
u1(0) q[159];
cx q[159],q[50];
u1(0) q[50];
cx q[159],q[50];
u1(0) q[50];
u1(0) q[159];
cx q[159],q[51];
u1(0) q[51];
cx q[159],q[51];
u1(0) q[51];
u1(0) q[159];
cx q[159],q[52];
u1(0) q[52];
cx q[159],q[52];
u1(0) q[52];
u1(0) q[159];
cx q[159],q[53];
u1(0) q[53];
cx q[159],q[53];
u1(0) q[53];
u1(0) q[159];
cx q[159],q[54];
u1(0) q[54];
cx q[159],q[54];
u1(0) q[54];
u1(0) q[159];
cx q[159],q[55];
u1(0) q[55];
cx q[159],q[55];
u1(0) q[55];
u1(0) q[159];
cx q[159],q[56];
u1(0) q[56];
cx q[159],q[56];
u1(0) q[56];
u1(0) q[159];
cx q[159],q[57];
u1(0) q[57];
cx q[159],q[57];
u1(0) q[57];
u1(0) q[159];
cx q[159],q[58];
u1(0) q[58];
cx q[159],q[58];
u1(0) q[58];
u1(0) q[159];
cx q[159],q[59];
u1(0) q[59];
cx q[159],q[59];
u1(0) q[59];
u1(0) q[159];
cx q[159],q[60];
u1(0) q[60];
cx q[159],q[60];
u1(0) q[60];
u1(0) q[159];
cx q[159],q[61];
u1(0) q[61];
cx q[159],q[61];
u1(0) q[61];
u1(0) q[159];
cx q[159],q[62];
u1(0) q[62];
cx q[159],q[62];
u1(0) q[62];
u1(0) q[159];
cx q[159],q[63];
u1(0) q[63];
cx q[159],q[63];
u1(0) q[63];
u1(0) q[159];
cx q[159],q[64];
u1(0) q[64];
cx q[159],q[64];
u1(0) q[64];
u1(0) q[159];
cx q[159],q[65];
u1(0) q[65];
cx q[159],q[65];
u1(0) q[65];
u1(0) q[159];
cx q[159],q[66];
u1(0) q[66];
cx q[159],q[66];
u1(0) q[66];
u1(0) q[159];
cx q[159],q[67];
u1(0) q[67];
cx q[159],q[67];
u1(0) q[67];
u1(0) q[159];
cx q[159],q[68];
u1(0) q[68];
cx q[159],q[68];
u1(0) q[68];
u1(0) q[159];
cx q[159],q[69];
u1(0) q[69];
cx q[159],q[69];
u1(0) q[69];
u1(0) q[159];
cx q[159],q[70];
u1(0) q[70];
cx q[159],q[70];
u1(0) q[70];
u1(0) q[159];
cx q[159],q[71];
u1(0) q[71];
cx q[159],q[71];
u1(0) q[71];
u1(0) q[159];
cx q[159],q[72];
u1(0) q[72];
cx q[159],q[72];
u1(0) q[72];
u1(0) q[159];
cx q[159],q[73];
u1(0) q[73];
cx q[159],q[73];
u1(0) q[73];
u1(0) q[159];
cx q[159],q[74];
u1(0) q[74];
cx q[159],q[74];
u1(0) q[74];
u1(0) q[159];
cx q[159],q[75];
u1(0) q[75];
cx q[159],q[75];
u1(0) q[75];
u1(0) q[159];
cx q[159],q[76];
u1(0) q[76];
cx q[159],q[76];
u1(0) q[76];
u1(0) q[159];
cx q[159],q[77];
u1(0) q[77];
cx q[159],q[77];
u1(0) q[77];
u1(0) q[159];
cx q[159],q[78];
u1(0) q[78];
cx q[159],q[78];
u1(0) q[78];
u1(0) q[159];
cx q[159],q[79];
u1(0) q[79];
cx q[159],q[79];
u1(0) q[79];
u1(0) q[159];
cx q[159],q[80];
u1(0) q[80];
cx q[159],q[80];
u1(0) q[80];
u1(0) q[159];
cx q[159],q[81];
u1(0) q[81];
cx q[159],q[81];
u1(0) q[81];
u1(0) q[159];
cx q[159],q[82];
u1(0) q[82];
cx q[159],q[82];
u1(0) q[82];
u1(0) q[159];
cx q[159],q[83];
u1(0) q[83];
cx q[159],q[83];
u1(0) q[83];
u1(0) q[159];
cx q[159],q[84];
u1(0) q[84];
cx q[159],q[84];
u1(0) q[84];
u1(0) q[159];
cx q[159],q[85];
u1(0) q[85];
cx q[159],q[85];
u1(0) q[85];
u1(0) q[159];
cx q[159],q[86];
u1(0) q[86];
cx q[159],q[86];
u1(0) q[86];
u1(0) q[159];
cx q[159],q[87];
u1(0) q[87];
cx q[159],q[87];
u1(0) q[87];
u1(0) q[159];
cx q[159],q[88];
u1(0) q[88];
cx q[159],q[88];
u1(0) q[88];
u1(0) q[159];
cx q[159],q[89];
u1(0) q[89];
cx q[159],q[89];
u1(0) q[89];
u1(0) q[159];
cx q[159],q[90];
u1(0) q[90];
cx q[159],q[90];
u1(0) q[90];
u1(0) q[159];
cx q[159],q[91];
u1(0) q[91];
cx q[159],q[91];
u1(0) q[91];
u1(0) q[159];
cx q[159],q[92];
u1(0) q[92];
cx q[159],q[92];
u1(0) q[92];
u1(0) q[159];
cx q[159],q[93];
u1(0) q[93];
cx q[159],q[93];
u1(0) q[93];
u1(0) q[159];
cx q[159],q[94];
u1(0) q[94];
cx q[159],q[94];
u1(0) q[94];
u1(0) q[159];
cx q[159],q[95];
u1(0) q[95];
cx q[159],q[95];
u1(0) q[95];
u1(0) q[159];
cx q[159],q[96];
u1(0) q[96];
cx q[159],q[96];
u1(0) q[96];
u1(0) q[159];
cx q[159],q[97];
u1(0) q[97];
cx q[159],q[97];
u1(0) q[97];
u1(0) q[159];
cx q[159],q[98];
u1(0) q[98];
cx q[159],q[98];
u1(0) q[98];
u1(0) q[159];
cx q[159],q[99];
u1(0) q[99];
cx q[159],q[99];
u1(0) q[99];
u1(0) q[159];
cx q[159],q[100];
u1(0) q[100];
cx q[159],q[100];
u1(0) q[100];
u1(0) q[159];
cx q[159],q[101];
u1(0) q[101];
cx q[159],q[101];
u1(0) q[101];
u1(0) q[159];
cx q[159],q[102];
u1(0) q[102];
cx q[159],q[102];
u1(0) q[102];
u1(0) q[159];
cx q[159],q[103];
u1(0) q[103];
cx q[159],q[103];
u1(0) q[103];
u1(0) q[159];
cx q[159],q[104];
u1(0) q[104];
cx q[159],q[104];
u1(0) q[104];
u1(0) q[159];
cx q[159],q[105];
u1(0) q[105];
cx q[159],q[105];
u1(0) q[105];
u1(0) q[159];
cx q[159],q[106];
u1(0) q[106];
cx q[159],q[106];
u1(0) q[106];
u1(0) q[159];
cx q[159],q[107];
u1(0) q[107];
cx q[159],q[107];
u1(0) q[107];
u1(0) q[159];
cx q[159],q[108];
u1(0) q[108];
cx q[159],q[108];
u1(0) q[108];
u1(0) q[159];
cx q[159],q[109];
u1(0) q[109];
cx q[159],q[109];
u1(0) q[109];
u1(0) q[159];
cx q[159],q[110];
u1(0) q[110];
cx q[159],q[110];
u1(0) q[110];
u1(0) q[159];
cx q[159],q[111];
u1(0) q[111];
cx q[159],q[111];
u1(0) q[111];
u1(pi/281474976710656) q[159];
cx q[159],q[112];
u1(-pi/281474976710656) q[112];
cx q[159],q[112];
u1(pi/281474976710656) q[112];
u1(pi/140737488355328) q[159];
cx q[159],q[113];
u1(-pi/140737488355328) q[113];
cx q[159],q[113];
u1(pi/140737488355328) q[113];
u1(pi/70368744177664) q[159];
cx q[159],q[114];
u1(-pi/70368744177664) q[114];
cx q[159],q[114];
u1(pi/70368744177664) q[114];
u1(pi/35184372088832) q[159];
cx q[159],q[115];
u1(-pi/35184372088832) q[115];
cx q[159],q[115];
u1(pi/35184372088832) q[115];
u1(pi/17592186044416) q[159];
cx q[159],q[116];
u1(-pi/17592186044416) q[116];
cx q[159],q[116];
u1(pi/17592186044416) q[116];
u1(pi/8796093022208) q[159];
cx q[159],q[117];
u1(-pi/8796093022208) q[117];
cx q[159],q[117];
u1(pi/8796093022208) q[117];
u1(pi/4398046511104) q[159];
cx q[159],q[118];
u1(-pi/4398046511104) q[118];
cx q[159],q[118];
u1(pi/4398046511104) q[118];
u1(pi/2199023255552) q[159];
cx q[159],q[119];
u1(-pi/2199023255552) q[119];
cx q[159],q[119];
u1(pi/2199023255552) q[119];
u1(pi/1099511627776) q[159];
cx q[159],q[120];
u1(-pi/1099511627776) q[120];
cx q[159],q[120];
u1(pi/1099511627776) q[120];
u1(pi/549755813888) q[159];
cx q[159],q[121];
u1(-pi/549755813888) q[121];
cx q[159],q[121];
u1(pi/549755813888) q[121];
u1(pi/274877906944) q[159];
cx q[159],q[122];
u1(-pi/274877906944) q[122];
cx q[159],q[122];
u1(pi/274877906944) q[122];
u1(pi/137438953472) q[159];
cx q[159],q[123];
u1(-pi/137438953472) q[123];
cx q[159],q[123];
u1(pi/137438953472) q[123];
u1(pi/68719476736) q[159];
cx q[159],q[124];
u1(-pi/68719476736) q[124];
cx q[159],q[124];
u1(pi/68719476736) q[124];
u1(pi/34359738368) q[159];
cx q[159],q[125];
u1(-pi/34359738368) q[125];
cx q[159],q[125];
u1(pi/34359738368) q[125];
u1(pi/17179869184) q[159];
cx q[159],q[126];
u1(-pi/17179869184) q[126];
cx q[159],q[126];
u1(pi/17179869184) q[126];
u1(pi/8589934592) q[159];
cx q[159],q[127];
u1(-pi/8589934592) q[127];
cx q[159],q[127];
u1(pi/8589934592) q[127];
u1(pi/4294967296) q[159];
cx q[159],q[128];
u1(-pi/4294967296) q[128];
cx q[159],q[128];
u1(pi/4294967296) q[128];
u1(pi/2147483648) q[159];
cx q[159],q[129];
u1(-pi/2147483648) q[129];
cx q[159],q[129];
u1(pi/2147483648) q[129];
u1(pi/1073741824) q[159];
cx q[159],q[130];
u1(-pi/1073741824) q[130];
cx q[159],q[130];
u1(pi/1073741824) q[130];
u1(pi/536870912) q[159];
cx q[159],q[131];
u1(-pi/536870912) q[131];
cx q[159],q[131];
u1(pi/536870912) q[131];
u1(pi/268435456) q[159];
cx q[159],q[132];
u1(-pi/268435456) q[132];
cx q[159],q[132];
u1(pi/268435456) q[132];
u1(pi/134217728) q[159];
cx q[159],q[133];
u1(-pi/134217728) q[133];
cx q[159],q[133];
u1(pi/134217728) q[133];
u1(pi/67108864) q[159];
cx q[159],q[134];
u1(-pi/67108864) q[134];
cx q[159],q[134];
u1(pi/67108864) q[134];
u1(pi/33554432) q[159];
cx q[159],q[135];
u1(-pi/33554432) q[135];
cx q[159],q[135];
u1(pi/33554432) q[135];
u1(pi/16777216) q[159];
cx q[159],q[136];
u1(-pi/16777216) q[136];
cx q[159],q[136];
u1(pi/16777216) q[136];
u1(pi/8388608) q[159];
cx q[159],q[137];
u1(-pi/8388608) q[137];
cx q[159],q[137];
u1(pi/8388608) q[137];
u1(pi/4194304) q[159];
cx q[159],q[138];
u1(-pi/4194304) q[138];
cx q[159],q[138];
u1(pi/4194304) q[138];
u1(pi/2097152) q[159];
cx q[159],q[139];
u1(-pi/2097152) q[139];
cx q[159],q[139];
u1(pi/2097152) q[139];
u1(pi/1048576) q[159];
cx q[159],q[140];
u1(-pi/1048576) q[140];
cx q[159],q[140];
u1(pi/1048576) q[140];
u1(pi/524288) q[159];
cx q[159],q[141];
u1(-pi/524288) q[141];
cx q[159],q[141];
u1(pi/524288) q[141];
u1(pi/262144) q[159];
cx q[159],q[142];
u1(-pi/262144) q[142];
cx q[159],q[142];
u1(pi/262144) q[142];
u1(pi/131072) q[159];
cx q[159],q[143];
u1(-pi/131072) q[143];
cx q[159],q[143];
u1(pi/131072) q[143];
u1(pi/65536) q[159];
cx q[159],q[144];
u1(-pi/65536) q[144];
cx q[159],q[144];
u1(pi/65536) q[144];
u1(pi/32768) q[159];
cx q[159],q[145];
u1(-pi/32768) q[145];
cx q[159],q[145];
u1(pi/32768) q[145];
u1(pi/16384) q[159];
cx q[159],q[146];
u1(-pi/16384) q[146];
cx q[159],q[146];
u1(pi/16384) q[146];
u1(pi/8192) q[159];
cx q[159],q[147];
u1(-pi/8192) q[147];
cx q[159],q[147];
u1(pi/8192) q[147];
u1(pi/4096) q[159];
cx q[159],q[148];
u1(-pi/4096) q[148];
cx q[159],q[148];
u1(pi/4096) q[148];
u1(pi/2048) q[159];
cx q[159],q[149];
u1(-pi/2048) q[149];
cx q[159],q[149];
u1(pi/2048) q[149];
u1(pi/1024) q[159];
cx q[159],q[150];
u1(-pi/1024) q[150];
cx q[159],q[150];
u1(pi/1024) q[150];
u1(pi/512) q[159];
cx q[159],q[151];
u1(-pi/512) q[151];
cx q[159],q[151];
u1(pi/512) q[151];
u1(pi/256) q[159];
cx q[159],q[152];
u1(-pi/256) q[152];
cx q[159],q[152];
u1(pi/256) q[152];
u1(pi/128) q[159];
cx q[159],q[153];
u1(-pi/128) q[153];
cx q[159],q[153];
u1(pi/128) q[153];
u1(pi/64) q[159];
cx q[159],q[154];
u1(-pi/64) q[154];
cx q[159],q[154];
u1(pi/64) q[154];
u1(pi/32) q[159];
cx q[159],q[155];
u1(-pi/32) q[155];
cx q[159],q[155];
u1(pi/32) q[155];
u1(pi/16) q[159];
cx q[159],q[156];
u1(-pi/16) q[156];
cx q[159],q[156];
u1(pi/16) q[156];
u1(pi/8) q[159];
cx q[159],q[157];
u1(-pi/8) q[157];
cx q[159],q[157];
u1(pi/8) q[157];
u1(pi/4) q[159];
cx q[159],q[158];
u1(-pi/4) q[158];
cx q[159],q[158];
u1(pi/4) q[158];
h q[159];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79],q[80],q[81],q[82],q[83],q[84],q[85],q[86],q[87],q[88],q[89],q[90],q[91],q[92],q[93],q[94],q[95],q[96],q[97],q[98],q[99],q[100],q[101],q[102],q[103],q[104],q[105],q[106],q[107],q[108],q[109],q[110],q[111],q[112],q[113],q[114],q[115],q[116],q[117],q[118],q[119],q[120],q[121],q[122],q[123],q[124],q[125],q[126],q[127],q[128],q[129],q[130],q[131],q[132],q[133],q[134],q[135],q[136],q[137],q[138],q[139],q[140],q[141],q[142],q[143],q[144],q[145],q[146],q[147],q[148],q[149],q[150],q[151],q[152],q[153],q[154],q[155],q[156],q[157],q[158],q[159];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];
measure q[66] -> meas[66];
measure q[67] -> meas[67];
measure q[68] -> meas[68];
measure q[69] -> meas[69];
measure q[70] -> meas[70];
measure q[71] -> meas[71];
measure q[72] -> meas[72];
measure q[73] -> meas[73];
measure q[74] -> meas[74];
measure q[75] -> meas[75];
measure q[76] -> meas[76];
measure q[77] -> meas[77];
measure q[78] -> meas[78];
measure q[79] -> meas[79];
measure q[80] -> meas[80];
measure q[81] -> meas[81];
measure q[82] -> meas[82];
measure q[83] -> meas[83];
measure q[84] -> meas[84];
measure q[85] -> meas[85];
measure q[86] -> meas[86];
measure q[87] -> meas[87];
measure q[88] -> meas[88];
measure q[89] -> meas[89];
measure q[90] -> meas[90];
measure q[91] -> meas[91];
measure q[92] -> meas[92];
measure q[93] -> meas[93];
measure q[94] -> meas[94];
measure q[95] -> meas[95];
measure q[96] -> meas[96];
measure q[97] -> meas[97];
measure q[98] -> meas[98];
measure q[99] -> meas[99];
measure q[100] -> meas[100];
measure q[101] -> meas[101];
measure q[102] -> meas[102];
measure q[103] -> meas[103];
measure q[104] -> meas[104];
measure q[105] -> meas[105];
measure q[106] -> meas[106];
measure q[107] -> meas[107];
measure q[108] -> meas[108];
measure q[109] -> meas[109];
measure q[110] -> meas[110];
measure q[111] -> meas[111];
measure q[112] -> meas[112];
measure q[113] -> meas[113];
measure q[114] -> meas[114];
measure q[115] -> meas[115];
measure q[116] -> meas[116];
measure q[117] -> meas[117];
measure q[118] -> meas[118];
measure q[119] -> meas[119];
measure q[120] -> meas[120];
measure q[121] -> meas[121];
measure q[122] -> meas[122];
measure q[123] -> meas[123];
measure q[124] -> meas[124];
measure q[125] -> meas[125];
measure q[126] -> meas[126];
measure q[127] -> meas[127];
measure q[128] -> meas[128];
measure q[129] -> meas[129];
measure q[130] -> meas[130];
measure q[131] -> meas[131];
measure q[132] -> meas[132];
measure q[133] -> meas[133];
measure q[134] -> meas[134];
measure q[135] -> meas[135];
measure q[136] -> meas[136];
measure q[137] -> meas[137];
measure q[138] -> meas[138];
measure q[139] -> meas[139];
measure q[140] -> meas[140];
measure q[141] -> meas[141];
measure q[142] -> meas[142];
measure q[143] -> meas[143];
measure q[144] -> meas[144];
measure q[145] -> meas[145];
measure q[146] -> meas[146];
measure q[147] -> meas[147];
measure q[148] -> meas[148];
measure q[149] -> meas[149];
measure q[150] -> meas[150];
measure q[151] -> meas[151];
measure q[152] -> meas[152];
measure q[153] -> meas[153];
measure q[154] -> meas[154];
measure q[155] -> meas[155];
measure q[156] -> meas[156];
measure q[157] -> meas[157];
measure q[158] -> meas[158];
measure q[159] -> meas[159];

'''

# %%
benchmarks['adder-433'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q[433];
creg c[433];
creg meas[433];
x q[1];
x q[2];
x q[3];
x q[4];
x q[5];
x q[6];
x q[7];
x q[8];
x q[9];
x q[10];
x q[11];
x q[12];
x q[13];
x q[14];
x q[15];
x q[16];
x q[17];
x q[18];
x q[19];
x q[20];
x q[21];
x q[22];
x q[23];
x q[24];
x q[25];
x q[26];
x q[27];
x q[28];
x q[29];
x q[30];
x q[31];
x q[32];
x q[33];
x q[34];
x q[35];
x q[36];
x q[37];
x q[38];
x q[39];
x q[40];
x q[41];
x q[42];
x q[43];
x q[44];
x q[45];
x q[46];
x q[47];
x q[48];
x q[49];
x q[50];
x q[51];
x q[52];
x q[53];
x q[54];
x q[55];
x q[56];
x q[57];
x q[58];
x q[59];
x q[60];
x q[61];
x q[62];
x q[63];
x q[64];
x q[65];
x q[66];
x q[67];
x q[68];
x q[69];
x q[70];
x q[71];
x q[72];
x q[73];
x q[74];
x q[75];
x q[76];
x q[77];
x q[78];
x q[79];
x q[80];
x q[81];
x q[82];
x q[83];
x q[84];
x q[85];
x q[86];
x q[87];
x q[88];
x q[89];
x q[90];
x q[91];
x q[92];
x q[93];
x q[94];
x q[95];
x q[96];
x q[97];
x q[98];
x q[99];
x q[100];
x q[101];
x q[102];
x q[103];
x q[104];
x q[105];
x q[106];
x q[107];
x q[108];
x q[109];
x q[110];
x q[111];
x q[112];
x q[113];
x q[114];
x q[115];
x q[116];
x q[117];
x q[118];
x q[119];
x q[120];
x q[121];
x q[122];
x q[123];
x q[124];
x q[125];
x q[126];
x q[127];
x q[128];
x q[129];
x q[130];
x q[131];
x q[132];
x q[133];
x q[134];
x q[135];
x q[136];
x q[137];
x q[138];
x q[139];
x q[140];
x q[141];
x q[142];
x q[143];
x q[144];
x q[145];
x q[146];
x q[147];
x q[148];
x q[149];
x q[150];
x q[151];
x q[152];
x q[153];
x q[154];
x q[155];
x q[156];
x q[157];
x q[158];
x q[159];
x q[160];
x q[161];
x q[162];
x q[163];
x q[164];
x q[165];
x q[166];
x q[167];
x q[168];
x q[169];
x q[170];
x q[171];
x q[172];
x q[173];
x q[174];
x q[175];
x q[176];
x q[177];
x q[178];
x q[179];
x q[180];
x q[181];
x q[182];
x q[183];
x q[184];
x q[185];
x q[186];
x q[187];
x q[188];
x q[189];
x q[190];
x q[191];
x q[192];
x q[384];
cx q[0],q[192];
cx q[0],q[384];
ccx q[384],q[192],q[0];
cx q[1],q[193];
cx q[1],q[0];
ccx q[0],q[193],q[1];
cx q[2],q[194];
cx q[2],q[1];
ccx q[1],q[194],q[2];
cx q[3],q[195];
cx q[3],q[2];
ccx q[2],q[195],q[3];
cx q[3],q[385];
ccx q[2],q[195],q[3];
cx q[3],q[2];
cx q[2],q[195];
ccx q[1],q[194],q[2];
cx q[2],q[1];
cx q[1],q[194];
ccx q[0],q[193],q[1];
cx q[1],q[0];
cx q[0],q[193];
ccx q[384],q[192],q[0];
cx q[0],q[384];
cx q[384],q[192];
cx q[4],q[196];
cx q[4],q[385];
ccx q[385],q[196],q[4];
cx q[5],q[197];
cx q[5],q[4];
ccx q[4],q[197],q[5];
cx q[6],q[198];
cx q[6],q[5];
ccx q[5],q[198],q[6];
cx q[7],q[199];
cx q[7],q[6];
ccx q[6],q[199],q[7];
cx q[7],q[386];
ccx q[6],q[199],q[7];
cx q[7],q[6];
cx q[6],q[199];
ccx q[5],q[198],q[6];
cx q[6],q[5];
cx q[5],q[198];
ccx q[4],q[197],q[5];
cx q[5],q[4];
cx q[4],q[197];
ccx q[385],q[196],q[4];
cx q[4],q[385];
cx q[385],q[196];
cx q[8],q[200];
cx q[8],q[386];
ccx q[386],q[200],q[8];
cx q[9],q[201];
cx q[9],q[8];
ccx q[8],q[201],q[9];
cx q[10],q[202];
cx q[10],q[9];
ccx q[9],q[202],q[10];
cx q[11],q[203];
cx q[11],q[10];
ccx q[10],q[203],q[11];
cx q[11],q[387];
ccx q[10],q[203],q[11];
cx q[11],q[10];
cx q[10],q[203];
ccx q[9],q[202],q[10];
cx q[10],q[9];
cx q[9],q[202];
ccx q[8],q[201],q[9];
cx q[9],q[8];
cx q[8],q[201];
ccx q[386],q[200],q[8];
cx q[8],q[386];
cx q[386],q[200];
cx q[12],q[204];
cx q[12],q[387];
ccx q[387],q[204],q[12];
cx q[13],q[205];
cx q[13],q[12];
ccx q[12],q[205],q[13];
cx q[14],q[206];
cx q[14],q[13];
ccx q[13],q[206],q[14];
cx q[15],q[207];
cx q[15],q[14];
ccx q[14],q[207],q[15];
cx q[15],q[388];
ccx q[14],q[207],q[15];
cx q[15],q[14];
cx q[14],q[207];
ccx q[13],q[206],q[14];
cx q[14],q[13];
cx q[13],q[206];
ccx q[12],q[205],q[13];
cx q[13],q[12];
cx q[12],q[205];
ccx q[387],q[204],q[12];
cx q[12],q[387];
cx q[387],q[204];
cx q[16],q[208];
cx q[16],q[388];
ccx q[388],q[208],q[16];
cx q[17],q[209];
cx q[17],q[16];
ccx q[16],q[209],q[17];
cx q[18],q[210];
cx q[18],q[17];
ccx q[17],q[210],q[18];
cx q[19],q[211];
cx q[19],q[18];
ccx q[18],q[211],q[19];
cx q[19],q[389];
ccx q[18],q[211],q[19];
cx q[19],q[18];
cx q[18],q[211];
ccx q[17],q[210],q[18];
cx q[18],q[17];
cx q[17],q[210];
ccx q[16],q[209],q[17];
cx q[17],q[16];
cx q[16],q[209];
ccx q[388],q[208],q[16];
cx q[16],q[388];
cx q[388],q[208];
cx q[20],q[212];
cx q[20],q[389];
ccx q[389],q[212],q[20];
cx q[21],q[213];
cx q[21],q[20];
ccx q[20],q[213],q[21];
cx q[22],q[214];
cx q[22],q[21];
ccx q[21],q[214],q[22];
cx q[23],q[215];
cx q[23],q[22];
ccx q[22],q[215],q[23];
cx q[23],q[390];
ccx q[22],q[215],q[23];
cx q[23],q[22];
cx q[22],q[215];
ccx q[21],q[214],q[22];
cx q[22],q[21];
cx q[21],q[214];
ccx q[20],q[213],q[21];
cx q[21],q[20];
cx q[20],q[213];
ccx q[389],q[212],q[20];
cx q[20],q[389];
cx q[389],q[212];
cx q[24],q[216];
cx q[24],q[390];
ccx q[390],q[216],q[24];
cx q[25],q[217];
cx q[25],q[24];
ccx q[24],q[217],q[25];
cx q[26],q[218];
cx q[26],q[25];
ccx q[25],q[218],q[26];
cx q[27],q[219];
cx q[27],q[26];
ccx q[26],q[219],q[27];
cx q[27],q[391];
ccx q[26],q[219],q[27];
cx q[27],q[26];
cx q[26],q[219];
ccx q[25],q[218],q[26];
cx q[26],q[25];
cx q[25],q[218];
ccx q[24],q[217],q[25];
cx q[25],q[24];
cx q[24],q[217];
ccx q[390],q[216],q[24];
cx q[24],q[390];
cx q[390],q[216];
cx q[28],q[220];
cx q[28],q[391];
ccx q[391],q[220],q[28];
cx q[29],q[221];
cx q[29],q[28];
ccx q[28],q[221],q[29];
cx q[30],q[222];
cx q[30],q[29];
ccx q[29],q[222],q[30];
cx q[31],q[223];
cx q[31],q[30];
ccx q[30],q[223],q[31];
cx q[31],q[392];
ccx q[30],q[223],q[31];
cx q[31],q[30];
cx q[30],q[223];
ccx q[29],q[222],q[30];
cx q[30],q[29];
cx q[29],q[222];
ccx q[28],q[221],q[29];
cx q[29],q[28];
cx q[28],q[221];
ccx q[391],q[220],q[28];
cx q[28],q[391];
cx q[391],q[220];
cx q[32],q[224];
cx q[32],q[392];
ccx q[392],q[224],q[32];
cx q[33],q[225];
cx q[33],q[32];
ccx q[32],q[225],q[33];
cx q[34],q[226];
cx q[34],q[33];
ccx q[33],q[226],q[34];
cx q[35],q[227];
cx q[35],q[34];
ccx q[34],q[227],q[35];
cx q[35],q[393];
ccx q[34],q[227],q[35];
cx q[35],q[34];
cx q[34],q[227];
ccx q[33],q[226],q[34];
cx q[34],q[33];
cx q[33],q[226];
ccx q[32],q[225],q[33];
cx q[33],q[32];
cx q[32],q[225];
ccx q[392],q[224],q[32];
cx q[32],q[392];
cx q[392],q[224];
cx q[36],q[228];
cx q[36],q[393];
ccx q[393],q[228],q[36];
cx q[37],q[229];
cx q[37],q[36];
ccx q[36],q[229],q[37];
cx q[38],q[230];
cx q[38],q[37];
ccx q[37],q[230],q[38];
cx q[39],q[231];
cx q[39],q[38];
ccx q[38],q[231],q[39];
cx q[39],q[394];
ccx q[38],q[231],q[39];
cx q[39],q[38];
cx q[38],q[231];
ccx q[37],q[230],q[38];
cx q[38],q[37];
cx q[37],q[230];
ccx q[36],q[229],q[37];
cx q[37],q[36];
cx q[36],q[229];
ccx q[393],q[228],q[36];
cx q[36],q[393];
cx q[393],q[228];
cx q[40],q[232];
cx q[40],q[394];
ccx q[394],q[232],q[40];
cx q[41],q[233];
cx q[41],q[40];
ccx q[40],q[233],q[41];
cx q[42],q[234];
cx q[42],q[41];
ccx q[41],q[234],q[42];
cx q[43],q[235];
cx q[43],q[42];
ccx q[42],q[235],q[43];
cx q[43],q[395];
ccx q[42],q[235],q[43];
cx q[43],q[42];
cx q[42],q[235];
ccx q[41],q[234],q[42];
cx q[42],q[41];
cx q[41],q[234];
ccx q[40],q[233],q[41];
cx q[41],q[40];
cx q[40],q[233];
ccx q[394],q[232],q[40];
cx q[40],q[394];
cx q[394],q[232];
cx q[44],q[236];
cx q[44],q[395];
ccx q[395],q[236],q[44];
cx q[45],q[237];
cx q[45],q[44];
ccx q[44],q[237],q[45];
cx q[46],q[238];
cx q[46],q[45];
ccx q[45],q[238],q[46];
cx q[47],q[239];
cx q[47],q[46];
ccx q[46],q[239],q[47];
cx q[47],q[396];
ccx q[46],q[239],q[47];
cx q[47],q[46];
cx q[46],q[239];
ccx q[45],q[238],q[46];
cx q[46],q[45];
cx q[45],q[238];
ccx q[44],q[237],q[45];
cx q[45],q[44];
cx q[44],q[237];
ccx q[395],q[236],q[44];
cx q[44],q[395];
cx q[395],q[236];
cx q[48],q[240];
cx q[48],q[396];
ccx q[396],q[240],q[48];
cx q[49],q[241];
cx q[49],q[48];
ccx q[48],q[241],q[49];
cx q[50],q[242];
cx q[50],q[49];
ccx q[49],q[242],q[50];
cx q[51],q[243];
cx q[51],q[50];
ccx q[50],q[243],q[51];
cx q[51],q[397];
ccx q[50],q[243],q[51];
cx q[51],q[50];
cx q[50],q[243];
ccx q[49],q[242],q[50];
cx q[50],q[49];
cx q[49],q[242];
ccx q[48],q[241],q[49];
cx q[49],q[48];
cx q[48],q[241];
ccx q[396],q[240],q[48];
cx q[48],q[396];
cx q[396],q[240];
cx q[52],q[244];
cx q[52],q[397];
ccx q[397],q[244],q[52];
cx q[53],q[245];
cx q[53],q[52];
ccx q[52],q[245],q[53];
cx q[54],q[246];
cx q[54],q[53];
ccx q[53],q[246],q[54];
cx q[55],q[247];
cx q[55],q[54];
ccx q[54],q[247],q[55];
cx q[55],q[398];
ccx q[54],q[247],q[55];
cx q[55],q[54];
cx q[54],q[247];
ccx q[53],q[246],q[54];
cx q[54],q[53];
cx q[53],q[246];
ccx q[52],q[245],q[53];
cx q[53],q[52];
cx q[52],q[245];
ccx q[397],q[244],q[52];
cx q[52],q[397];
cx q[397],q[244];
cx q[56],q[248];
cx q[56],q[398];
ccx q[398],q[248],q[56];
cx q[57],q[249];
cx q[57],q[56];
ccx q[56],q[249],q[57];
cx q[58],q[250];
cx q[58],q[57];
ccx q[57],q[250],q[58];
cx q[59],q[251];
cx q[59],q[58];
ccx q[58],q[251],q[59];
cx q[59],q[399];
ccx q[58],q[251],q[59];
cx q[59],q[58];
cx q[58],q[251];
ccx q[57],q[250],q[58];
cx q[58],q[57];
cx q[57],q[250];
ccx q[56],q[249],q[57];
cx q[57],q[56];
cx q[56],q[249];
ccx q[398],q[248],q[56];
cx q[56],q[398];
cx q[398],q[248];
cx q[60],q[252];
cx q[60],q[399];
ccx q[399],q[252],q[60];
cx q[61],q[253];
cx q[61],q[60];
ccx q[60],q[253],q[61];
cx q[62],q[254];
cx q[62],q[61];
ccx q[61],q[254],q[62];
cx q[63],q[255];
cx q[63],q[62];
ccx q[62],q[255],q[63];
cx q[63],q[400];
ccx q[62],q[255],q[63];
cx q[63],q[62];
cx q[62],q[255];
ccx q[61],q[254],q[62];
cx q[62],q[61];
cx q[61],q[254];
ccx q[60],q[253],q[61];
cx q[61],q[60];
cx q[60],q[253];
ccx q[399],q[252],q[60];
cx q[60],q[399];
cx q[399],q[252];
cx q[64],q[256];
cx q[64],q[400];
ccx q[400],q[256],q[64];
cx q[65],q[257];
cx q[65],q[64];
ccx q[64],q[257],q[65];
cx q[66],q[258];
cx q[66],q[65];
ccx q[65],q[258],q[66];
cx q[67],q[259];
cx q[67],q[66];
ccx q[66],q[259],q[67];
cx q[67],q[401];
ccx q[66],q[259],q[67];
cx q[67],q[66];
cx q[66],q[259];
ccx q[65],q[258],q[66];
cx q[66],q[65];
cx q[65],q[258];
ccx q[64],q[257],q[65];
cx q[65],q[64];
cx q[64],q[257];
ccx q[400],q[256],q[64];
cx q[64],q[400];
cx q[400],q[256];
cx q[68],q[260];
cx q[68],q[401];
ccx q[401],q[260],q[68];
cx q[69],q[261];
cx q[69],q[68];
ccx q[68],q[261],q[69];
cx q[70],q[262];
cx q[70],q[69];
ccx q[69],q[262],q[70];
cx q[71],q[263];
cx q[71],q[70];
ccx q[70],q[263],q[71];
cx q[71],q[402];
ccx q[70],q[263],q[71];
cx q[71],q[70];
cx q[70],q[263];
ccx q[69],q[262],q[70];
cx q[70],q[69];
cx q[69],q[262];
ccx q[68],q[261],q[69];
cx q[69],q[68];
cx q[68],q[261];
ccx q[401],q[260],q[68];
cx q[68],q[401];
cx q[401],q[260];
cx q[72],q[264];
cx q[72],q[402];
ccx q[402],q[264],q[72];
cx q[73],q[265];
cx q[73],q[72];
ccx q[72],q[265],q[73];
cx q[74],q[266];
cx q[74],q[73];
ccx q[73],q[266],q[74];
cx q[75],q[267];
cx q[75],q[74];
ccx q[74],q[267],q[75];
cx q[75],q[403];
ccx q[74],q[267],q[75];
cx q[75],q[74];
cx q[74],q[267];
ccx q[73],q[266],q[74];
cx q[74],q[73];
cx q[73],q[266];
ccx q[72],q[265],q[73];
cx q[73],q[72];
cx q[72],q[265];
ccx q[402],q[264],q[72];
cx q[72],q[402];
cx q[402],q[264];
cx q[76],q[268];
cx q[76],q[403];
ccx q[403],q[268],q[76];
cx q[77],q[269];
cx q[77],q[76];
ccx q[76],q[269],q[77];
cx q[78],q[270];
cx q[78],q[77];
ccx q[77],q[270],q[78];
cx q[79],q[271];
cx q[79],q[78];
ccx q[78],q[271],q[79];
cx q[79],q[404];
ccx q[78],q[271],q[79];
cx q[79],q[78];
cx q[78],q[271];
ccx q[77],q[270],q[78];
cx q[78],q[77];
cx q[77],q[270];
ccx q[76],q[269],q[77];
cx q[77],q[76];
cx q[76],q[269];
ccx q[403],q[268],q[76];
cx q[76],q[403];
cx q[403],q[268];
cx q[80],q[272];
cx q[80],q[404];
ccx q[404],q[272],q[80];
cx q[81],q[273];
cx q[81],q[80];
ccx q[80],q[273],q[81];
cx q[82],q[274];
cx q[82],q[81];
ccx q[81],q[274],q[82];
cx q[83],q[275];
cx q[83],q[82];
ccx q[82],q[275],q[83];
cx q[83],q[405];
ccx q[82],q[275],q[83];
cx q[83],q[82];
cx q[82],q[275];
ccx q[81],q[274],q[82];
cx q[82],q[81];
cx q[81],q[274];
ccx q[80],q[273],q[81];
cx q[81],q[80];
cx q[80],q[273];
ccx q[404],q[272],q[80];
cx q[80],q[404];
cx q[404],q[272];
cx q[84],q[276];
cx q[84],q[405];
ccx q[405],q[276],q[84];
cx q[85],q[277];
cx q[85],q[84];
ccx q[84],q[277],q[85];
cx q[86],q[278];
cx q[86],q[85];
ccx q[85],q[278],q[86];
cx q[87],q[279];
cx q[87],q[86];
ccx q[86],q[279],q[87];
cx q[87],q[406];
ccx q[86],q[279],q[87];
cx q[87],q[86];
cx q[86],q[279];
ccx q[85],q[278],q[86];
cx q[86],q[85];
cx q[85],q[278];
ccx q[84],q[277],q[85];
cx q[85],q[84];
cx q[84],q[277];
ccx q[405],q[276],q[84];
cx q[84],q[405];
cx q[405],q[276];
cx q[88],q[280];
cx q[88],q[406];
ccx q[406],q[280],q[88];
cx q[89],q[281];
cx q[89],q[88];
ccx q[88],q[281],q[89];
cx q[90],q[282];
cx q[90],q[89];
ccx q[89],q[282],q[90];
cx q[91],q[283];
cx q[91],q[90];
ccx q[90],q[283],q[91];
cx q[91],q[407];
ccx q[90],q[283],q[91];
cx q[91],q[90];
cx q[90],q[283];
ccx q[89],q[282],q[90];
cx q[90],q[89];
cx q[89],q[282];
ccx q[88],q[281],q[89];
cx q[89],q[88];
cx q[88],q[281];
ccx q[406],q[280],q[88];
cx q[88],q[406];
cx q[406],q[280];
cx q[92],q[284];
cx q[92],q[407];
ccx q[407],q[284],q[92];
cx q[93],q[285];
cx q[93],q[92];
ccx q[92],q[285],q[93];
cx q[94],q[286];
cx q[94],q[93];
ccx q[93],q[286],q[94];
cx q[95],q[287];
cx q[95],q[94];
ccx q[94],q[287],q[95];
cx q[95],q[408];
ccx q[94],q[287],q[95];
cx q[95],q[94];
cx q[94],q[287];
ccx q[93],q[286],q[94];
cx q[94],q[93];
cx q[93],q[286];
ccx q[92],q[285],q[93];
cx q[93],q[92];
cx q[92],q[285];
ccx q[407],q[284],q[92];
cx q[92],q[407];
cx q[407],q[284];
cx q[96],q[288];
cx q[96],q[408];
ccx q[408],q[288],q[96];
cx q[97],q[289];
cx q[97],q[96];
ccx q[96],q[289],q[97];
cx q[98],q[290];
cx q[98],q[97];
ccx q[97],q[290],q[98];
cx q[99],q[291];
cx q[99],q[98];
ccx q[98],q[291],q[99];
cx q[99],q[409];
ccx q[98],q[291],q[99];
cx q[99],q[98];
cx q[98],q[291];
ccx q[97],q[290],q[98];
cx q[98],q[97];
cx q[97],q[290];
ccx q[96],q[289],q[97];
cx q[97],q[96];
cx q[96],q[289];
ccx q[408],q[288],q[96];
cx q[96],q[408];
cx q[408],q[288];
cx q[100],q[292];
cx q[100],q[409];
ccx q[409],q[292],q[100];
cx q[101],q[293];
cx q[101],q[100];
ccx q[100],q[293],q[101];
cx q[102],q[294];
cx q[102],q[101];
ccx q[101],q[294],q[102];
cx q[103],q[295];
cx q[103],q[102];
ccx q[102],q[295],q[103];
cx q[103],q[410];
ccx q[102],q[295],q[103];
cx q[103],q[102];
cx q[102],q[295];
ccx q[101],q[294],q[102];
cx q[102],q[101];
cx q[101],q[294];
ccx q[100],q[293],q[101];
cx q[101],q[100];
cx q[100],q[293];
ccx q[409],q[292],q[100];
cx q[100],q[409];
cx q[409],q[292];
cx q[104],q[296];
cx q[104],q[410];
ccx q[410],q[296],q[104];
cx q[105],q[297];
cx q[105],q[104];
ccx q[104],q[297],q[105];
cx q[106],q[298];
cx q[106],q[105];
ccx q[105],q[298],q[106];
cx q[107],q[299];
cx q[107],q[106];
ccx q[106],q[299],q[107];
cx q[107],q[411];
ccx q[106],q[299],q[107];
cx q[107],q[106];
cx q[106],q[299];
ccx q[105],q[298],q[106];
cx q[106],q[105];
cx q[105],q[298];
ccx q[104],q[297],q[105];
cx q[105],q[104];
cx q[104],q[297];
ccx q[410],q[296],q[104];
cx q[104],q[410];
cx q[410],q[296];
cx q[108],q[300];
cx q[108],q[411];
ccx q[411],q[300],q[108];
cx q[109],q[301];
cx q[109],q[108];
ccx q[108],q[301],q[109];
cx q[110],q[302];
cx q[110],q[109];
ccx q[109],q[302],q[110];
cx q[111],q[303];
cx q[111],q[110];
ccx q[110],q[303],q[111];
cx q[111],q[412];
ccx q[110],q[303],q[111];
cx q[111],q[110];
cx q[110],q[303];
ccx q[109],q[302],q[110];
cx q[110],q[109];
cx q[109],q[302];
ccx q[108],q[301],q[109];
cx q[109],q[108];
cx q[108],q[301];
ccx q[411],q[300],q[108];
cx q[108],q[411];
cx q[411],q[300];
cx q[112],q[304];
cx q[112],q[412];
ccx q[412],q[304],q[112];
cx q[113],q[305];
cx q[113],q[112];
ccx q[112],q[305],q[113];
cx q[114],q[306];
cx q[114],q[113];
ccx q[113],q[306],q[114];
cx q[115],q[307];
cx q[115],q[114];
ccx q[114],q[307],q[115];
cx q[115],q[413];
ccx q[114],q[307],q[115];
cx q[115],q[114];
cx q[114],q[307];
ccx q[113],q[306],q[114];
cx q[114],q[113];
cx q[113],q[306];
ccx q[112],q[305],q[113];
cx q[113],q[112];
cx q[112],q[305];
ccx q[412],q[304],q[112];
cx q[112],q[412];
cx q[412],q[304];
cx q[116],q[308];
cx q[116],q[413];
ccx q[413],q[308],q[116];
cx q[117],q[309];
cx q[117],q[116];
ccx q[116],q[309],q[117];
cx q[118],q[310];
cx q[118],q[117];
ccx q[117],q[310],q[118];
cx q[119],q[311];
cx q[119],q[118];
ccx q[118],q[311],q[119];
cx q[119],q[414];
ccx q[118],q[311],q[119];
cx q[119],q[118];
cx q[118],q[311];
ccx q[117],q[310],q[118];
cx q[118],q[117];
cx q[117],q[310];
ccx q[116],q[309],q[117];
cx q[117],q[116];
cx q[116],q[309];
ccx q[413],q[308],q[116];
cx q[116],q[413];
cx q[413],q[308];
cx q[120],q[312];
cx q[120],q[414];
ccx q[414],q[312],q[120];
cx q[121],q[313];
cx q[121],q[120];
ccx q[120],q[313],q[121];
cx q[122],q[314];
cx q[122],q[121];
ccx q[121],q[314],q[122];
cx q[123],q[315];
cx q[123],q[122];
ccx q[122],q[315],q[123];
cx q[123],q[415];
ccx q[122],q[315],q[123];
cx q[123],q[122];
cx q[122],q[315];
ccx q[121],q[314],q[122];
cx q[122],q[121];
cx q[121],q[314];
ccx q[120],q[313],q[121];
cx q[121],q[120];
cx q[120],q[313];
ccx q[414],q[312],q[120];
cx q[120],q[414];
cx q[414],q[312];
cx q[124],q[316];
cx q[124],q[415];
ccx q[415],q[316],q[124];
cx q[125],q[317];
cx q[125],q[124];
ccx q[124],q[317],q[125];
cx q[126],q[318];
cx q[126],q[125];
ccx q[125],q[318],q[126];
cx q[127],q[319];
cx q[127],q[126];
ccx q[126],q[319],q[127];
cx q[127],q[416];
ccx q[126],q[319],q[127];
cx q[127],q[126];
cx q[126],q[319];
ccx q[125],q[318],q[126];
cx q[126],q[125];
cx q[125],q[318];
ccx q[124],q[317],q[125];
cx q[125],q[124];
cx q[124],q[317];
ccx q[415],q[316],q[124];
cx q[124],q[415];
cx q[415],q[316];
cx q[128],q[320];
cx q[128],q[416];
ccx q[416],q[320],q[128];
cx q[129],q[321];
cx q[129],q[128];
ccx q[128],q[321],q[129];
cx q[130],q[322];
cx q[130],q[129];
ccx q[129],q[322],q[130];
cx q[131],q[323];
cx q[131],q[130];
ccx q[130],q[323],q[131];
cx q[131],q[417];
ccx q[130],q[323],q[131];
cx q[131],q[130];
cx q[130],q[323];
ccx q[129],q[322],q[130];
cx q[130],q[129];
cx q[129],q[322];
ccx q[128],q[321],q[129];
cx q[129],q[128];
cx q[128],q[321];
ccx q[416],q[320],q[128];
cx q[128],q[416];
cx q[416],q[320];
cx q[132],q[324];
cx q[132],q[417];
ccx q[417],q[324],q[132];
cx q[133],q[325];
cx q[133],q[132];
ccx q[132],q[325],q[133];
cx q[134],q[326];
cx q[134],q[133];
ccx q[133],q[326],q[134];
cx q[135],q[327];
cx q[135],q[134];
ccx q[134],q[327],q[135];
cx q[135],q[418];
ccx q[134],q[327],q[135];
cx q[135],q[134];
cx q[134],q[327];
ccx q[133],q[326],q[134];
cx q[134],q[133];
cx q[133],q[326];
ccx q[132],q[325],q[133];
cx q[133],q[132];
cx q[132],q[325];
ccx q[417],q[324],q[132];
cx q[132],q[417];
cx q[417],q[324];
cx q[136],q[328];
cx q[136],q[418];
ccx q[418],q[328],q[136];
cx q[137],q[329];
cx q[137],q[136];
ccx q[136],q[329],q[137];
cx q[138],q[330];
cx q[138],q[137];
ccx q[137],q[330],q[138];
cx q[139],q[331];
cx q[139],q[138];
ccx q[138],q[331],q[139];
cx q[139],q[419];
ccx q[138],q[331],q[139];
cx q[139],q[138];
cx q[138],q[331];
ccx q[137],q[330],q[138];
cx q[138],q[137];
cx q[137],q[330];
ccx q[136],q[329],q[137];
cx q[137],q[136];
cx q[136],q[329];
ccx q[418],q[328],q[136];
cx q[136],q[418];
cx q[418],q[328];
cx q[140],q[332];
cx q[140],q[419];
ccx q[419],q[332],q[140];
cx q[141],q[333];
cx q[141],q[140];
ccx q[140],q[333],q[141];
cx q[142],q[334];
cx q[142],q[141];
ccx q[141],q[334],q[142];
cx q[143],q[335];
cx q[143],q[142];
ccx q[142],q[335],q[143];
cx q[143],q[420];
ccx q[142],q[335],q[143];
cx q[143],q[142];
cx q[142],q[335];
ccx q[141],q[334],q[142];
cx q[142],q[141];
cx q[141],q[334];
ccx q[140],q[333],q[141];
cx q[141],q[140];
cx q[140],q[333];
ccx q[419],q[332],q[140];
cx q[140],q[419];
cx q[419],q[332];
cx q[144],q[336];
cx q[144],q[420];
ccx q[420],q[336],q[144];
cx q[145],q[337];
cx q[145],q[144];
ccx q[144],q[337],q[145];
cx q[146],q[338];
cx q[146],q[145];
ccx q[145],q[338],q[146];
cx q[147],q[339];
cx q[147],q[146];
ccx q[146],q[339],q[147];
cx q[147],q[421];
ccx q[146],q[339],q[147];
cx q[147],q[146];
cx q[146],q[339];
ccx q[145],q[338],q[146];
cx q[146],q[145];
cx q[145],q[338];
ccx q[144],q[337],q[145];
cx q[145],q[144];
cx q[144],q[337];
ccx q[420],q[336],q[144];
cx q[144],q[420];
cx q[420],q[336];
cx q[148],q[340];
cx q[148],q[421];
ccx q[421],q[340],q[148];
cx q[149],q[341];
cx q[149],q[148];
ccx q[148],q[341],q[149];
cx q[150],q[342];
cx q[150],q[149];
ccx q[149],q[342],q[150];
cx q[151],q[343];
cx q[151],q[150];
ccx q[150],q[343],q[151];
cx q[151],q[422];
ccx q[150],q[343],q[151];
cx q[151],q[150];
cx q[150],q[343];
ccx q[149],q[342],q[150];
cx q[150],q[149];
cx q[149],q[342];
ccx q[148],q[341],q[149];
cx q[149],q[148];
cx q[148],q[341];
ccx q[421],q[340],q[148];
cx q[148],q[421];
cx q[421],q[340];
cx q[152],q[344];
cx q[152],q[422];
ccx q[422],q[344],q[152];
cx q[153],q[345];
cx q[153],q[152];
ccx q[152],q[345],q[153];
cx q[154],q[346];
cx q[154],q[153];
ccx q[153],q[346],q[154];
cx q[155],q[347];
cx q[155],q[154];
ccx q[154],q[347],q[155];
cx q[155],q[423];
ccx q[154],q[347],q[155];
cx q[155],q[154];
cx q[154],q[347];
ccx q[153],q[346],q[154];
cx q[154],q[153];
cx q[153],q[346];
ccx q[152],q[345],q[153];
cx q[153],q[152];
cx q[152],q[345];
ccx q[422],q[344],q[152];
cx q[152],q[422];
cx q[422],q[344];
cx q[156],q[348];
cx q[156],q[423];
ccx q[423],q[348],q[156];
cx q[157],q[349];
cx q[157],q[156];
ccx q[156],q[349],q[157];
cx q[158],q[350];
cx q[158],q[157];
ccx q[157],q[350],q[158];
cx q[159],q[351];
cx q[159],q[158];
ccx q[158],q[351],q[159];
cx q[159],q[424];
ccx q[158],q[351],q[159];
cx q[159],q[158];
cx q[158],q[351];
ccx q[157],q[350],q[158];
cx q[158],q[157];
cx q[157],q[350];
ccx q[156],q[349],q[157];
cx q[157],q[156];
cx q[156],q[349];
ccx q[423],q[348],q[156];
cx q[156],q[423];
cx q[423],q[348];
cx q[160],q[352];
cx q[160],q[424];
ccx q[424],q[352],q[160];
cx q[161],q[353];
cx q[161],q[160];
ccx q[160],q[353],q[161];
cx q[162],q[354];
cx q[162],q[161];
ccx q[161],q[354],q[162];
cx q[163],q[355];
cx q[163],q[162];
ccx q[162],q[355],q[163];
cx q[163],q[425];
ccx q[162],q[355],q[163];
cx q[163],q[162];
cx q[162],q[355];
ccx q[161],q[354],q[162];
cx q[162],q[161];
cx q[161],q[354];
ccx q[160],q[353],q[161];
cx q[161],q[160];
cx q[160],q[353];
ccx q[424],q[352],q[160];
cx q[160],q[424];
cx q[424],q[352];
cx q[164],q[356];
cx q[164],q[425];
ccx q[425],q[356],q[164];
cx q[165],q[357];
cx q[165],q[164];
ccx q[164],q[357],q[165];
cx q[166],q[358];
cx q[166],q[165];
ccx q[165],q[358],q[166];
cx q[167],q[359];
cx q[167],q[166];
ccx q[166],q[359],q[167];
cx q[167],q[426];
ccx q[166],q[359],q[167];
cx q[167],q[166];
cx q[166],q[359];
ccx q[165],q[358],q[166];
cx q[166],q[165];
cx q[165],q[358];
ccx q[164],q[357],q[165];
cx q[165],q[164];
cx q[164],q[357];
ccx q[425],q[356],q[164];
cx q[164],q[425];
cx q[425],q[356];
cx q[168],q[360];
cx q[168],q[426];
ccx q[426],q[360],q[168];
cx q[169],q[361];
cx q[169],q[168];
ccx q[168],q[361],q[169];
cx q[170],q[362];
cx q[170],q[169];
ccx q[169],q[362],q[170];
cx q[171],q[363];
cx q[171],q[170];
ccx q[170],q[363],q[171];
cx q[171],q[427];
ccx q[170],q[363],q[171];
cx q[171],q[170];
cx q[170],q[363];
ccx q[169],q[362],q[170];
cx q[170],q[169];
cx q[169],q[362];
ccx q[168],q[361],q[169];
cx q[169],q[168];
cx q[168],q[361];
ccx q[426],q[360],q[168];
cx q[168],q[426];
cx q[426],q[360];
cx q[172],q[364];
cx q[172],q[427];
ccx q[427],q[364],q[172];
cx q[173],q[365];
cx q[173],q[172];
ccx q[172],q[365],q[173];
cx q[174],q[366];
cx q[174],q[173];
ccx q[173],q[366],q[174];
cx q[175],q[367];
cx q[175],q[174];
ccx q[174],q[367],q[175];
cx q[175],q[428];
ccx q[174],q[367],q[175];
cx q[175],q[174];
cx q[174],q[367];
ccx q[173],q[366],q[174];
cx q[174],q[173];
cx q[173],q[366];
ccx q[172],q[365],q[173];
cx q[173],q[172];
cx q[172],q[365];
ccx q[427],q[364],q[172];
cx q[172],q[427];
cx q[427],q[364];
cx q[176],q[368];
cx q[176],q[428];
ccx q[428],q[368],q[176];
cx q[177],q[369];
cx q[177],q[176];
ccx q[176],q[369],q[177];
cx q[178],q[370];
cx q[178],q[177];
ccx q[177],q[370],q[178];
cx q[179],q[371];
cx q[179],q[178];
ccx q[178],q[371],q[179];
cx q[179],q[429];
ccx q[178],q[371],q[179];
cx q[179],q[178];
cx q[178],q[371];
ccx q[177],q[370],q[178];
cx q[178],q[177];
cx q[177],q[370];
ccx q[176],q[369],q[177];
cx q[177],q[176];
cx q[176],q[369];
ccx q[428],q[368],q[176];
cx q[176],q[428];
cx q[428],q[368];
cx q[180],q[372];
cx q[180],q[429];
ccx q[429],q[372],q[180];
cx q[181],q[373];
cx q[181],q[180];
ccx q[180],q[373],q[181];
cx q[182],q[374];
cx q[182],q[181];
ccx q[181],q[374],q[182];
cx q[183],q[375];
cx q[183],q[182];
ccx q[182],q[375],q[183];
cx q[183],q[430];
ccx q[182],q[375],q[183];
cx q[183],q[182];
cx q[182],q[375];
ccx q[181],q[374],q[182];
cx q[182],q[181];
cx q[181],q[374];
ccx q[180],q[373],q[181];
cx q[181],q[180];
cx q[180],q[373];
ccx q[429],q[372],q[180];
cx q[180],q[429];
cx q[429],q[372];
cx q[184],q[376];
cx q[184],q[430];
ccx q[430],q[376],q[184];
cx q[185],q[377];
cx q[185],q[184];
ccx q[184],q[377],q[185];
cx q[186],q[378];
cx q[186],q[185];
ccx q[185],q[378],q[186];
cx q[187],q[379];
cx q[187],q[186];
ccx q[186],q[379],q[187];
cx q[187],q[431];
ccx q[186],q[379],q[187];
cx q[187],q[186];
cx q[186],q[379];
ccx q[185],q[378],q[186];
cx q[186],q[185];
cx q[185],q[378];
ccx q[184],q[377],q[185];
cx q[185],q[184];
cx q[184],q[377];
ccx q[430],q[376],q[184];
cx q[184],q[430];
cx q[430],q[376];
cx q[188],q[380];
cx q[188],q[431];
ccx q[431],q[380],q[188];
cx q[189],q[381];
cx q[189],q[188];
ccx q[188],q[381],q[189];
cx q[190],q[382];
cx q[190],q[189];
ccx q[189],q[382],q[190];
cx q[191],q[383];
cx q[191],q[190];
ccx q[190],q[383],q[191];
cx q[191],q[432];
ccx q[190],q[383],q[191];
cx q[191],q[190];
cx q[190],q[383];
ccx q[189],q[382],q[190];
cx q[190],q[189];
cx q[189],q[382];
ccx q[188],q[381],q[189];
cx q[189],q[188];
cx q[188],q[381];
ccx q[431],q[380],q[188];
cx q[188],q[431];
cx q[431],q[380];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79],q[80],q[81],q[82],q[83],q[84],q[85],q[86],q[87],q[88],q[89],q[90],q[91],q[92],q[93],q[94],q[95],q[96],q[97],q[98],q[99],q[100],q[101],q[102],q[103],q[104],q[105],q[106],q[107],q[108],q[109],q[110],q[111],q[112],q[113],q[114],q[115],q[116],q[117],q[118],q[119],q[120],q[121],q[122],q[123],q[124],q[125],q[126],q[127],q[128],q[129],q[130],q[131],q[132],q[133],q[134],q[135],q[136],q[137],q[138],q[139],q[140],q[141],q[142],q[143],q[144],q[145],q[146],q[147],q[148],q[149],q[150],q[151],q[152],q[153],q[154],q[155],q[156],q[157],q[158],q[159],q[160],q[161],q[162],q[163],q[164],q[165],q[166],q[167],q[168],q[169],q[170],q[171],q[172],q[173],q[174],q[175],q[176],q[177],q[178],q[179],q[180],q[181],q[182],q[183],q[184],q[185],q[186],q[187],q[188],q[189],q[190],q[191],q[192],q[193],q[194],q[195],q[196],q[197],q[198],q[199],q[200],q[201],q[202],q[203],q[204],q[205],q[206],q[207],q[208],q[209],q[210],q[211],q[212],q[213],q[214],q[215],q[216],q[217],q[218],q[219],q[220],q[221],q[222],q[223],q[224],q[225],q[226],q[227],q[228],q[229],q[230],q[231],q[232],q[233],q[234],q[235],q[236],q[237],q[238],q[239],q[240],q[241],q[242],q[243],q[244],q[245],q[246],q[247],q[248],q[249],q[250],q[251],q[252],q[253],q[254],q[255],q[256],q[257],q[258],q[259],q[260],q[261],q[262],q[263],q[264],q[265],q[266],q[267],q[268],q[269],q[270],q[271],q[272],q[273],q[274],q[275],q[276],q[277],q[278],q[279],q[280],q[281],q[282],q[283],q[284],q[285],q[286],q[287],q[288],q[289],q[290],q[291],q[292],q[293],q[294],q[295],q[296],q[297],q[298],q[299],q[300],q[301],q[302],q[303],q[304],q[305],q[306],q[307],q[308],q[309],q[310],q[311],q[312],q[313],q[314],q[315],q[316],q[317],q[318],q[319],q[320],q[321],q[322],q[323],q[324],q[325],q[326],q[327],q[328],q[329],q[330],q[331],q[332],q[333],q[334],q[335],q[336],q[337],q[338],q[339],q[340],q[341],q[342],q[343],q[344],q[345],q[346],q[347],q[348],q[349],q[350],q[351],q[352],q[353],q[354],q[355],q[356],q[357],q[358],q[359],q[360],q[361],q[362],q[363],q[364],q[365],q[366],q[367],q[368],q[369],q[370],q[371],q[372],q[373],q[374],q[375],q[376],q[377],q[378],q[379],q[380],q[381],q[382],q[383],q[384],q[385],q[386],q[387],q[388],q[389],q[390],q[391],q[392],q[393],q[394],q[395],q[396],q[397],q[398],q[399],q[400],q[401],q[402],q[403],q[404],q[405],q[406],q[407],q[408],q[409],q[410],q[411],q[412],q[413],q[414],q[415],q[416],q[417],q[418],q[419],q[420],q[421],q[422],q[423],q[424],q[425],q[426],q[427],q[428],q[429],q[430],q[431],q[432];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];
measure q[66] -> meas[66];
measure q[67] -> meas[67];
measure q[68] -> meas[68];
measure q[69] -> meas[69];
measure q[70] -> meas[70];
measure q[71] -> meas[71];
measure q[72] -> meas[72];
measure q[73] -> meas[73];
measure q[74] -> meas[74];
measure q[75] -> meas[75];
measure q[76] -> meas[76];
measure q[77] -> meas[77];
measure q[78] -> meas[78];
measure q[79] -> meas[79];
measure q[80] -> meas[80];
measure q[81] -> meas[81];
measure q[82] -> meas[82];
measure q[83] -> meas[83];
measure q[84] -> meas[84];
measure q[85] -> meas[85];
measure q[86] -> meas[86];
measure q[87] -> meas[87];
measure q[88] -> meas[88];
measure q[89] -> meas[89];
measure q[90] -> meas[90];
measure q[91] -> meas[91];
measure q[92] -> meas[92];
measure q[93] -> meas[93];
measure q[94] -> meas[94];
measure q[95] -> meas[95];
measure q[96] -> meas[96];
measure q[97] -> meas[97];
measure q[98] -> meas[98];
measure q[99] -> meas[99];
measure q[100] -> meas[100];
measure q[101] -> meas[101];
measure q[102] -> meas[102];
measure q[103] -> meas[103];
measure q[104] -> meas[104];
measure q[105] -> meas[105];
measure q[106] -> meas[106];
measure q[107] -> meas[107];
measure q[108] -> meas[108];
measure q[109] -> meas[109];
measure q[110] -> meas[110];
measure q[111] -> meas[111];
measure q[112] -> meas[112];
measure q[113] -> meas[113];
measure q[114] -> meas[114];
measure q[115] -> meas[115];
measure q[116] -> meas[116];
measure q[117] -> meas[117];
measure q[118] -> meas[118];
measure q[119] -> meas[119];
measure q[120] -> meas[120];
measure q[121] -> meas[121];
measure q[122] -> meas[122];
measure q[123] -> meas[123];
measure q[124] -> meas[124];
measure q[125] -> meas[125];
measure q[126] -> meas[126];
measure q[127] -> meas[127];
measure q[128] -> meas[128];
measure q[129] -> meas[129];
measure q[130] -> meas[130];
measure q[131] -> meas[131];
measure q[132] -> meas[132];
measure q[133] -> meas[133];
measure q[134] -> meas[134];
measure q[135] -> meas[135];
measure q[136] -> meas[136];
measure q[137] -> meas[137];
measure q[138] -> meas[138];
measure q[139] -> meas[139];
measure q[140] -> meas[140];
measure q[141] -> meas[141];
measure q[142] -> meas[142];
measure q[143] -> meas[143];
measure q[144] -> meas[144];
measure q[145] -> meas[145];
measure q[146] -> meas[146];
measure q[147] -> meas[147];
measure q[148] -> meas[148];
measure q[149] -> meas[149];
measure q[150] -> meas[150];
measure q[151] -> meas[151];
measure q[152] -> meas[152];
measure q[153] -> meas[153];
measure q[154] -> meas[154];
measure q[155] -> meas[155];
measure q[156] -> meas[156];
measure q[157] -> meas[157];
measure q[158] -> meas[158];
measure q[159] -> meas[159];
measure q[160] -> meas[160];
measure q[161] -> meas[161];
measure q[162] -> meas[162];
measure q[163] -> meas[163];
measure q[164] -> meas[164];
measure q[165] -> meas[165];
measure q[166] -> meas[166];
measure q[167] -> meas[167];
measure q[168] -> meas[168];
measure q[169] -> meas[169];
measure q[170] -> meas[170];
measure q[171] -> meas[171];
measure q[172] -> meas[172];
measure q[173] -> meas[173];
measure q[174] -> meas[174];
measure q[175] -> meas[175];
measure q[176] -> meas[176];
measure q[177] -> meas[177];
measure q[178] -> meas[178];
measure q[179] -> meas[179];
measure q[180] -> meas[180];
measure q[181] -> meas[181];
measure q[182] -> meas[182];
measure q[183] -> meas[183];
measure q[184] -> meas[184];
measure q[185] -> meas[185];
measure q[186] -> meas[186];
measure q[187] -> meas[187];
measure q[188] -> meas[188];
measure q[189] -> meas[189];
measure q[190] -> meas[190];
measure q[191] -> meas[191];
measure q[192] -> meas[192];
measure q[193] -> meas[193];
measure q[194] -> meas[194];
measure q[195] -> meas[195];
measure q[196] -> meas[196];
measure q[197] -> meas[197];
measure q[198] -> meas[198];
measure q[199] -> meas[199];
measure q[200] -> meas[200];
measure q[201] -> meas[201];
measure q[202] -> meas[202];
measure q[203] -> meas[203];
measure q[204] -> meas[204];
measure q[205] -> meas[205];
measure q[206] -> meas[206];
measure q[207] -> meas[207];
measure q[208] -> meas[208];
measure q[209] -> meas[209];
measure q[210] -> meas[210];
measure q[211] -> meas[211];
measure q[212] -> meas[212];
measure q[213] -> meas[213];
measure q[214] -> meas[214];
measure q[215] -> meas[215];
measure q[216] -> meas[216];
measure q[217] -> meas[217];
measure q[218] -> meas[218];
measure q[219] -> meas[219];
measure q[220] -> meas[220];
measure q[221] -> meas[221];
measure q[222] -> meas[222];
measure q[223] -> meas[223];
measure q[224] -> meas[224];
measure q[225] -> meas[225];
measure q[226] -> meas[226];
measure q[227] -> meas[227];
measure q[228] -> meas[228];
measure q[229] -> meas[229];
measure q[230] -> meas[230];
measure q[231] -> meas[231];
measure q[232] -> meas[232];
measure q[233] -> meas[233];
measure q[234] -> meas[234];
measure q[235] -> meas[235];
measure q[236] -> meas[236];
measure q[237] -> meas[237];
measure q[238] -> meas[238];
measure q[239] -> meas[239];
measure q[240] -> meas[240];
measure q[241] -> meas[241];
measure q[242] -> meas[242];
measure q[243] -> meas[243];
measure q[244] -> meas[244];
measure q[245] -> meas[245];
measure q[246] -> meas[246];
measure q[247] -> meas[247];
measure q[248] -> meas[248];
measure q[249] -> meas[249];
measure q[250] -> meas[250];
measure q[251] -> meas[251];
measure q[252] -> meas[252];
measure q[253] -> meas[253];
measure q[254] -> meas[254];
measure q[255] -> meas[255];
measure q[256] -> meas[256];
measure q[257] -> meas[257];
measure q[258] -> meas[258];
measure q[259] -> meas[259];
measure q[260] -> meas[260];
measure q[261] -> meas[261];
measure q[262] -> meas[262];
measure q[263] -> meas[263];
measure q[264] -> meas[264];
measure q[265] -> meas[265];
measure q[266] -> meas[266];
measure q[267] -> meas[267];
measure q[268] -> meas[268];
measure q[269] -> meas[269];
measure q[270] -> meas[270];
measure q[271] -> meas[271];
measure q[272] -> meas[272];
measure q[273] -> meas[273];
measure q[274] -> meas[274];
measure q[275] -> meas[275];
measure q[276] -> meas[276];
measure q[277] -> meas[277];
measure q[278] -> meas[278];
measure q[279] -> meas[279];
measure q[280] -> meas[280];
measure q[281] -> meas[281];
measure q[282] -> meas[282];
measure q[283] -> meas[283];
measure q[284] -> meas[284];
measure q[285] -> meas[285];
measure q[286] -> meas[286];
measure q[287] -> meas[287];
measure q[288] -> meas[288];
measure q[289] -> meas[289];
measure q[290] -> meas[290];
measure q[291] -> meas[291];
measure q[292] -> meas[292];
measure q[293] -> meas[293];
measure q[294] -> meas[294];
measure q[295] -> meas[295];
measure q[296] -> meas[296];
measure q[297] -> meas[297];
measure q[298] -> meas[298];
measure q[299] -> meas[299];
measure q[300] -> meas[300];
measure q[301] -> meas[301];
measure q[302] -> meas[302];
measure q[303] -> meas[303];
measure q[304] -> meas[304];
measure q[305] -> meas[305];
measure q[306] -> meas[306];
measure q[307] -> meas[307];
measure q[308] -> meas[308];
measure q[309] -> meas[309];
measure q[310] -> meas[310];
measure q[311] -> meas[311];
measure q[312] -> meas[312];
measure q[313] -> meas[313];
measure q[314] -> meas[314];
measure q[315] -> meas[315];
measure q[316] -> meas[316];
measure q[317] -> meas[317];
measure q[318] -> meas[318];
measure q[319] -> meas[319];
measure q[320] -> meas[320];
measure q[321] -> meas[321];
measure q[322] -> meas[322];
measure q[323] -> meas[323];
measure q[324] -> meas[324];
measure q[325] -> meas[325];
measure q[326] -> meas[326];
measure q[327] -> meas[327];
measure q[328] -> meas[328];
measure q[329] -> meas[329];
measure q[330] -> meas[330];
measure q[331] -> meas[331];
measure q[332] -> meas[332];
measure q[333] -> meas[333];
measure q[334] -> meas[334];
measure q[335] -> meas[335];
measure q[336] -> meas[336];
measure q[337] -> meas[337];
measure q[338] -> meas[338];
measure q[339] -> meas[339];
measure q[340] -> meas[340];
measure q[341] -> meas[341];
measure q[342] -> meas[342];
measure q[343] -> meas[343];
measure q[344] -> meas[344];
measure q[345] -> meas[345];
measure q[346] -> meas[346];
measure q[347] -> meas[347];
measure q[348] -> meas[348];
measure q[349] -> meas[349];
measure q[350] -> meas[350];
measure q[351] -> meas[351];
measure q[352] -> meas[352];
measure q[353] -> meas[353];
measure q[354] -> meas[354];
measure q[355] -> meas[355];
measure q[356] -> meas[356];
measure q[357] -> meas[357];
measure q[358] -> meas[358];
measure q[359] -> meas[359];
measure q[360] -> meas[360];
measure q[361] -> meas[361];
measure q[362] -> meas[362];
measure q[363] -> meas[363];
measure q[364] -> meas[364];
measure q[365] -> meas[365];
measure q[366] -> meas[366];
measure q[367] -> meas[367];
measure q[368] -> meas[368];
measure q[369] -> meas[369];
measure q[370] -> meas[370];
measure q[371] -> meas[371];
measure q[372] -> meas[372];
measure q[373] -> meas[373];
measure q[374] -> meas[374];
measure q[375] -> meas[375];
measure q[376] -> meas[376];
measure q[377] -> meas[377];
measure q[378] -> meas[378];
measure q[379] -> meas[379];
measure q[380] -> meas[380];
measure q[381] -> meas[381];
measure q[382] -> meas[382];
measure q[383] -> meas[383];
measure q[384] -> meas[384];
measure q[385] -> meas[385];
measure q[386] -> meas[386];
measure q[387] -> meas[387];
measure q[388] -> meas[388];
measure q[389] -> meas[389];
measure q[390] -> meas[390];
measure q[391] -> meas[391];
measure q[392] -> meas[392];
measure q[393] -> meas[393];
measure q[394] -> meas[394];
measure q[395] -> meas[395];
measure q[396] -> meas[396];
measure q[397] -> meas[397];
measure q[398] -> meas[398];
measure q[399] -> meas[399];
measure q[400] -> meas[400];
measure q[401] -> meas[401];
measure q[402] -> meas[402];
measure q[403] -> meas[403];
measure q[404] -> meas[404];
measure q[405] -> meas[405];
measure q[406] -> meas[406];
measure q[407] -> meas[407];
measure q[408] -> meas[408];
measure q[409] -> meas[409];
measure q[410] -> meas[410];
measure q[411] -> meas[411];
measure q[412] -> meas[412];
measure q[413] -> meas[413];
measure q[414] -> meas[414];
measure q[415] -> meas[415];
measure q[416] -> meas[416];
measure q[417] -> meas[417];
measure q[418] -> meas[418];
measure q[419] -> meas[419];
measure q[420] -> meas[420];
measure q[421] -> meas[421];
measure q[422] -> meas[422];
measure q[423] -> meas[423];
measure q[424] -> meas[424];
measure q[425] -> meas[425];
measure q[426] -> meas[426];
measure q[427] -> meas[427];
measure q[428] -> meas[428];
measure q[429] -> meas[429];
measure q[430] -> meas[430];
measure q[431] -> meas[431];
measure q[432] -> meas[432];

'''

benchmarks['cc-151'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q0[151];
creg c0[151];
h q0[0];
h q0[1];
h q0[2];
h q0[3];
h q0[4];
h q0[5];
h q0[6];
h q0[7];
h q0[8];
h q0[9];
h q0[10];
h q0[11];
h q0[12];
h q0[13];
h q0[14];
h q0[15];
h q0[16];
h q0[17];
h q0[18];
h q0[19];
h q0[20];
h q0[21];
h q0[22];
h q0[23];
h q0[24];
h q0[25];
h q0[26];
h q0[27];
h q0[28];
h q0[29];
h q0[30];
h q0[31];
h q0[32];
h q0[33];
h q0[34];
h q0[35];
h q0[36];
h q0[37];
h q0[38];
h q0[39];
h q0[40];
h q0[41];
h q0[42];
h q0[43];
h q0[44];
h q0[45];
h q0[46];
h q0[47];
h q0[48];
h q0[49];
h q0[50];
h q0[51];
h q0[52];
h q0[53];
h q0[54];
h q0[55];
h q0[56];
h q0[57];
h q0[58];
h q0[59];
h q0[60];
h q0[61];
h q0[62];
h q0[63];
h q0[64];
h q0[65];
h q0[66];
h q0[67];
h q0[68];
h q0[69];
h q0[70];
h q0[71];
h q0[72];
h q0[73];
h q0[74];
h q0[75];
h q0[76];
h q0[77];
h q0[78];
h q0[79];
h q0[80];
h q0[81];
h q0[82];
h q0[83];
h q0[84];
h q0[85];
h q0[86];
h q0[87];
h q0[88];
h q0[89];
h q0[90];
h q0[91];
h q0[92];
h q0[93];
h q0[94];
h q0[95];
h q0[96];
h q0[97];
h q0[98];
h q0[99];
h q0[100];
h q0[101];
h q0[102];
h q0[103];
h q0[104];
h q0[105];
h q0[106];
h q0[107];
h q0[108];
h q0[109];
h q0[110];
h q0[111];
h q0[112];
h q0[113];
h q0[114];
h q0[115];
h q0[116];
h q0[117];
h q0[118];
h q0[119];
h q0[120];
h q0[121];
h q0[122];
h q0[123];
h q0[124];
h q0[125];
h q0[126];
h q0[127];
h q0[128];
h q0[129];
h q0[130];
h q0[131];
h q0[132];
h q0[133];
h q0[134];
h q0[135];
h q0[136];
h q0[137];
h q0[138];
h q0[139];
h q0[140];
h q0[141];
h q0[142];
h q0[143];
h q0[144];
h q0[145];
h q0[146];
h q0[147];
h q0[148];
h q0[149];
cx q0[0],q0[150];
cx q0[1],q0[150];
cx q0[2],q0[150];
cx q0[3],q0[150];
cx q0[4],q0[150];
cx q0[5],q0[150];
cx q0[6],q0[150];
cx q0[7],q0[150];
cx q0[8],q0[150];
cx q0[9],q0[150];
cx q0[10],q0[150];
cx q0[11],q0[150];
cx q0[12],q0[150];
cx q0[13],q0[150];
cx q0[14],q0[150];
cx q0[15],q0[150];
cx q0[16],q0[150];
cx q0[17],q0[150];
cx q0[18],q0[150];
cx q0[19],q0[150];
cx q0[20],q0[150];
cx q0[21],q0[150];
cx q0[22],q0[150];
cx q0[23],q0[150];
cx q0[24],q0[150];
cx q0[25],q0[150];
cx q0[26],q0[150];
cx q0[27],q0[150];
cx q0[28],q0[150];
cx q0[29],q0[150];
cx q0[30],q0[150];
cx q0[31],q0[150];
cx q0[32],q0[150];
cx q0[33],q0[150];
cx q0[34],q0[150];
cx q0[35],q0[150];
cx q0[36],q0[150];
cx q0[37],q0[150];
cx q0[38],q0[150];
cx q0[39],q0[150];
cx q0[40],q0[150];
cx q0[41],q0[150];
cx q0[42],q0[150];
cx q0[43],q0[150];
cx q0[44],q0[150];
cx q0[45],q0[150];
cx q0[46],q0[150];
cx q0[47],q0[150];
cx q0[48],q0[150];
cx q0[49],q0[150];
cx q0[50],q0[150];
cx q0[51],q0[150];
cx q0[52],q0[150];
cx q0[53],q0[150];
cx q0[54],q0[150];
cx q0[55],q0[150];
cx q0[56],q0[150];
cx q0[57],q0[150];
cx q0[58],q0[150];
cx q0[59],q0[150];
cx q0[60],q0[150];
cx q0[61],q0[150];
cx q0[62],q0[150];
cx q0[63],q0[150];
cx q0[64],q0[150];
cx q0[65],q0[150];
cx q0[66],q0[150];
cx q0[67],q0[150];
cx q0[68],q0[150];
cx q0[69],q0[150];
cx q0[70],q0[150];
cx q0[71],q0[150];
cx q0[72],q0[150];
cx q0[73],q0[150];
cx q0[74],q0[150];
cx q0[75],q0[150];
cx q0[76],q0[150];
cx q0[77],q0[150];
cx q0[78],q0[150];
cx q0[79],q0[150];
cx q0[80],q0[150];
cx q0[81],q0[150];
cx q0[82],q0[150];
cx q0[83],q0[150];
cx q0[84],q0[150];
cx q0[85],q0[150];
cx q0[86],q0[150];
cx q0[87],q0[150];
cx q0[88],q0[150];
cx q0[89],q0[150];
cx q0[90],q0[150];
cx q0[91],q0[150];
cx q0[92],q0[150];
cx q0[93],q0[150];
cx q0[94],q0[150];
cx q0[95],q0[150];
cx q0[96],q0[150];
cx q0[97],q0[150];
cx q0[98],q0[150];
cx q0[99],q0[150];
cx q0[100],q0[150];
cx q0[101],q0[150];
cx q0[102],q0[150];
cx q0[103],q0[150];
cx q0[104],q0[150];
cx q0[105],q0[150];
cx q0[106],q0[150];
cx q0[107],q0[150];
cx q0[108],q0[150];
cx q0[109],q0[150];
cx q0[110],q0[150];
cx q0[111],q0[150];
cx q0[112],q0[150];
cx q0[113],q0[150];
cx q0[114],q0[150];
cx q0[115],q0[150];
cx q0[116],q0[150];
cx q0[117],q0[150];
cx q0[118],q0[150];
cx q0[119],q0[150];
cx q0[120],q0[150];
cx q0[121],q0[150];
cx q0[122],q0[150];
cx q0[123],q0[150];
cx q0[124],q0[150];
cx q0[125],q0[150];
cx q0[126],q0[150];
cx q0[127],q0[150];
cx q0[128],q0[150];
cx q0[129],q0[150];
cx q0[130],q0[150];
cx q0[131],q0[150];
cx q0[132],q0[150];
cx q0[133],q0[150];
cx q0[134],q0[150];
cx q0[135],q0[150];
cx q0[136],q0[150];
cx q0[137],q0[150];
cx q0[138],q0[150];
cx q0[139],q0[150];
cx q0[140],q0[150];
cx q0[141],q0[150];
cx q0[142],q0[150];
cx q0[143],q0[150];
cx q0[144],q0[150];
cx q0[145],q0[150];
cx q0[146],q0[150];
cx q0[147],q0[150];
cx q0[148],q0[150];
cx q0[149],q0[150];
measure q0[150] -> c0[150];
if(c0==0) x q0[150];
if(c0==0) h q0[150];
if(c0==1427247692705959881058285969449495136382746624) h q0[0];
if(c0==1427247692705959881058285969449495136382746624) h q0[1];
if(c0==1427247692705959881058285969449495136382746624) h q0[2];
if(c0==1427247692705959881058285969449495136382746624) h q0[3];
if(c0==1427247692705959881058285969449495136382746624) h q0[4];
if(c0==1427247692705959881058285969449495136382746624) h q0[5];
if(c0==1427247692705959881058285969449495136382746624) h q0[6];
if(c0==1427247692705959881058285969449495136382746624) h q0[7];
if(c0==1427247692705959881058285969449495136382746624) h q0[8];
if(c0==1427247692705959881058285969449495136382746624) h q0[9];
if(c0==1427247692705959881058285969449495136382746624) h q0[10];
if(c0==1427247692705959881058285969449495136382746624) h q0[11];
if(c0==1427247692705959881058285969449495136382746624) h q0[12];
if(c0==1427247692705959881058285969449495136382746624) h q0[13];
if(c0==1427247692705959881058285969449495136382746624) h q0[14];
if(c0==1427247692705959881058285969449495136382746624) h q0[15];
if(c0==1427247692705959881058285969449495136382746624) h q0[16];
if(c0==1427247692705959881058285969449495136382746624) h q0[17];
if(c0==1427247692705959881058285969449495136382746624) h q0[18];
if(c0==1427247692705959881058285969449495136382746624) h q0[19];
if(c0==1427247692705959881058285969449495136382746624) h q0[20];
if(c0==1427247692705959881058285969449495136382746624) h q0[21];
if(c0==1427247692705959881058285969449495136382746624) h q0[22];
if(c0==1427247692705959881058285969449495136382746624) h q0[23];
if(c0==1427247692705959881058285969449495136382746624) h q0[24];
if(c0==1427247692705959881058285969449495136382746624) h q0[25];
if(c0==1427247692705959881058285969449495136382746624) h q0[26];
if(c0==1427247692705959881058285969449495136382746624) h q0[27];
if(c0==1427247692705959881058285969449495136382746624) h q0[28];
if(c0==1427247692705959881058285969449495136382746624) h q0[29];
if(c0==1427247692705959881058285969449495136382746624) h q0[30];
if(c0==1427247692705959881058285969449495136382746624) h q0[31];
if(c0==1427247692705959881058285969449495136382746624) h q0[32];
if(c0==1427247692705959881058285969449495136382746624) h q0[33];
if(c0==1427247692705959881058285969449495136382746624) h q0[34];
if(c0==1427247692705959881058285969449495136382746624) h q0[35];
if(c0==1427247692705959881058285969449495136382746624) h q0[36];
if(c0==1427247692705959881058285969449495136382746624) h q0[37];
if(c0==1427247692705959881058285969449495136382746624) h q0[38];
if(c0==1427247692705959881058285969449495136382746624) h q0[39];
if(c0==1427247692705959881058285969449495136382746624) h q0[40];
if(c0==1427247692705959881058285969449495136382746624) h q0[41];
if(c0==1427247692705959881058285969449495136382746624) h q0[42];
if(c0==1427247692705959881058285969449495136382746624) h q0[43];
if(c0==1427247692705959881058285969449495136382746624) h q0[44];
if(c0==1427247692705959881058285969449495136382746624) h q0[45];
if(c0==1427247692705959881058285969449495136382746624) h q0[46];
if(c0==1427247692705959881058285969449495136382746624) h q0[47];
if(c0==1427247692705959881058285969449495136382746624) h q0[48];
if(c0==1427247692705959881058285969449495136382746624) h q0[49];
if(c0==1427247692705959881058285969449495136382746624) h q0[50];
if(c0==1427247692705959881058285969449495136382746624) h q0[51];
if(c0==1427247692705959881058285969449495136382746624) h q0[52];
if(c0==1427247692705959881058285969449495136382746624) h q0[53];
if(c0==1427247692705959881058285969449495136382746624) h q0[54];
if(c0==1427247692705959881058285969449495136382746624) h q0[55];
if(c0==1427247692705959881058285969449495136382746624) h q0[56];
if(c0==1427247692705959881058285969449495136382746624) h q0[57];
if(c0==1427247692705959881058285969449495136382746624) h q0[58];
if(c0==1427247692705959881058285969449495136382746624) h q0[59];
if(c0==1427247692705959881058285969449495136382746624) h q0[60];
if(c0==1427247692705959881058285969449495136382746624) h q0[61];
if(c0==1427247692705959881058285969449495136382746624) h q0[62];
if(c0==1427247692705959881058285969449495136382746624) h q0[63];
if(c0==1427247692705959881058285969449495136382746624) h q0[64];
if(c0==1427247692705959881058285969449495136382746624) h q0[65];
if(c0==1427247692705959881058285969449495136382746624) h q0[66];
if(c0==1427247692705959881058285969449495136382746624) h q0[67];
if(c0==1427247692705959881058285969449495136382746624) h q0[68];
if(c0==1427247692705959881058285969449495136382746624) h q0[69];
if(c0==1427247692705959881058285969449495136382746624) h q0[70];
if(c0==1427247692705959881058285969449495136382746624) h q0[71];
if(c0==1427247692705959881058285969449495136382746624) h q0[72];
if(c0==1427247692705959881058285969449495136382746624) h q0[73];
if(c0==1427247692705959881058285969449495136382746624) h q0[74];
if(c0==1427247692705959881058285969449495136382746624) h q0[75];
if(c0==1427247692705959881058285969449495136382746624) h q0[76];
if(c0==1427247692705959881058285969449495136382746624) h q0[77];
if(c0==1427247692705959881058285969449495136382746624) h q0[78];
if(c0==1427247692705959881058285969449495136382746624) h q0[79];
if(c0==1427247692705959881058285969449495136382746624) h q0[80];
if(c0==1427247692705959881058285969449495136382746624) h q0[81];
if(c0==1427247692705959881058285969449495136382746624) h q0[82];
if(c0==1427247692705959881058285969449495136382746624) h q0[83];
if(c0==1427247692705959881058285969449495136382746624) h q0[84];
if(c0==1427247692705959881058285969449495136382746624) h q0[85];
if(c0==1427247692705959881058285969449495136382746624) h q0[86];
if(c0==1427247692705959881058285969449495136382746624) h q0[87];
if(c0==1427247692705959881058285969449495136382746624) h q0[88];
if(c0==1427247692705959881058285969449495136382746624) h q0[89];
if(c0==1427247692705959881058285969449495136382746624) h q0[90];
if(c0==1427247692705959881058285969449495136382746624) h q0[91];
if(c0==1427247692705959881058285969449495136382746624) h q0[92];
if(c0==1427247692705959881058285969449495136382746624) h q0[93];
if(c0==1427247692705959881058285969449495136382746624) h q0[94];
if(c0==1427247692705959881058285969449495136382746624) h q0[95];
if(c0==1427247692705959881058285969449495136382746624) h q0[96];
if(c0==1427247692705959881058285969449495136382746624) h q0[97];
if(c0==1427247692705959881058285969449495136382746624) h q0[98];
if(c0==1427247692705959881058285969449495136382746624) h q0[99];
if(c0==1427247692705959881058285969449495136382746624) h q0[100];
if(c0==1427247692705959881058285969449495136382746624) h q0[101];
if(c0==1427247692705959881058285969449495136382746624) h q0[102];
if(c0==1427247692705959881058285969449495136382746624) h q0[103];
if(c0==1427247692705959881058285969449495136382746624) h q0[104];
if(c0==1427247692705959881058285969449495136382746624) h q0[105];
if(c0==1427247692705959881058285969449495136382746624) h q0[106];
if(c0==1427247692705959881058285969449495136382746624) h q0[107];
if(c0==1427247692705959881058285969449495136382746624) h q0[108];
if(c0==1427247692705959881058285969449495136382746624) h q0[109];
if(c0==1427247692705959881058285969449495136382746624) h q0[110];
if(c0==1427247692705959881058285969449495136382746624) h q0[111];
if(c0==1427247692705959881058285969449495136382746624) h q0[112];
if(c0==1427247692705959881058285969449495136382746624) h q0[113];
if(c0==1427247692705959881058285969449495136382746624) h q0[114];
if(c0==1427247692705959881058285969449495136382746624) h q0[115];
if(c0==1427247692705959881058285969449495136382746624) h q0[116];
if(c0==1427247692705959881058285969449495136382746624) h q0[117];
if(c0==1427247692705959881058285969449495136382746624) h q0[118];
if(c0==1427247692705959881058285969449495136382746624) h q0[119];
if(c0==1427247692705959881058285969449495136382746624) h q0[120];
if(c0==1427247692705959881058285969449495136382746624) h q0[121];
if(c0==1427247692705959881058285969449495136382746624) h q0[122];
if(c0==1427247692705959881058285969449495136382746624) h q0[123];
if(c0==1427247692705959881058285969449495136382746624) h q0[124];
if(c0==1427247692705959881058285969449495136382746624) h q0[125];
if(c0==1427247692705959881058285969449495136382746624) h q0[126];
if(c0==1427247692705959881058285969449495136382746624) h q0[127];
if(c0==1427247692705959881058285969449495136382746624) h q0[128];
if(c0==1427247692705959881058285969449495136382746624) h q0[129];
if(c0==1427247692705959881058285969449495136382746624) h q0[130];
if(c0==1427247692705959881058285969449495136382746624) h q0[131];
if(c0==1427247692705959881058285969449495136382746624) h q0[132];
if(c0==1427247692705959881058285969449495136382746624) h q0[133];
if(c0==1427247692705959881058285969449495136382746624) h q0[134];
if(c0==1427247692705959881058285969449495136382746624) h q0[135];
if(c0==1427247692705959881058285969449495136382746624) h q0[136];
if(c0==1427247692705959881058285969449495136382746624) h q0[137];
if(c0==1427247692705959881058285969449495136382746624) h q0[138];
if(c0==1427247692705959881058285969449495136382746624) h q0[139];
if(c0==1427247692705959881058285969449495136382746624) h q0[140];
if(c0==1427247692705959881058285969449495136382746624) h q0[141];
if(c0==1427247692705959881058285969449495136382746624) h q0[142];
if(c0==1427247692705959881058285969449495136382746624) h q0[143];
if(c0==1427247692705959881058285969449495136382746624) h q0[144];
if(c0==1427247692705959881058285969449495136382746624) h q0[145];
if(c0==1427247692705959881058285969449495136382746624) h q0[146];
if(c0==1427247692705959881058285969449495136382746624) h q0[147];
if(c0==1427247692705959881058285969449495136382746624) h q0[148];
if(c0==1427247692705959881058285969449495136382746624) h q0[149];
barrier q0[0],q0[1],q0[2],q0[3],q0[4],q0[5],q0[6],q0[7],q0[8],q0[9],q0[10],q0[11],q0[12],q0[13],q0[14],q0[15],q0[16],q0[17],q0[18],q0[19],q0[20],q0[21],q0[22],q0[23],q0[24],q0[25],q0[26],q0[27],q0[28],q0[29],q0[30],q0[31],q0[32],q0[33],q0[34],q0[35],q0[36],q0[37],q0[38],q0[39],q0[40],q0[41],q0[42],q0[43],q0[44],q0[45],q0[46],q0[47],q0[48],q0[49],q0[50],q0[51],q0[52],q0[53],q0[54],q0[55],q0[56],q0[57],q0[58],q0[59],q0[60],q0[61],q0[62],q0[63],q0[64],q0[65],q0[66],q0[67],q0[68],q0[69],q0[70],q0[71],q0[72],q0[73],q0[74],q0[75],q0[76],q0[77],q0[78],q0[79],q0[80],q0[81],q0[82],q0[83],q0[84],q0[85],q0[86],q0[87],q0[88],q0[89],q0[90],q0[91],q0[92],q0[93],q0[94],q0[95],q0[96],q0[97],q0[98],q0[99],q0[100],q0[101],q0[102],q0[103],q0[104],q0[105],q0[106],q0[107],q0[108],q0[109],q0[110],q0[111],q0[112],q0[113],q0[114],q0[115],q0[116],q0[117],q0[118],q0[119],q0[120],q0[121],q0[122],q0[123],q0[124],q0[125],q0[126],q0[127],q0[128],q0[129],q0[130],q0[131],q0[132],q0[133],q0[134],q0[135],q0[136],q0[137],q0[138],q0[139],q0[140],q0[141],q0[142],q0[143],q0[144],q0[145],q0[146],q0[147],q0[148],q0[149],q0[150];
if(c0==0) cx q0[49],q0[150];
barrier q0[0],q0[1],q0[2],q0[3],q0[4],q0[5],q0[6],q0[7],q0[8],q0[9],q0[10],q0[11],q0[12],q0[13],q0[14],q0[15],q0[16],q0[17],q0[18],q0[19],q0[20],q0[21],q0[22],q0[23],q0[24],q0[25],q0[26],q0[27],q0[28],q0[29],q0[30],q0[31],q0[32],q0[33],q0[34],q0[35],q0[36],q0[37],q0[38],q0[39],q0[40],q0[41],q0[42],q0[43],q0[44],q0[45],q0[46],q0[47],q0[48],q0[49],q0[50],q0[51],q0[52],q0[53],q0[54],q0[55],q0[56],q0[57],q0[58],q0[59],q0[60],q0[61],q0[62],q0[63],q0[64],q0[65],q0[66],q0[67],q0[68],q0[69],q0[70],q0[71],q0[72],q0[73],q0[74],q0[75],q0[76],q0[77],q0[78],q0[79],q0[80],q0[81],q0[82],q0[83],q0[84],q0[85],q0[86],q0[87],q0[88],q0[89],q0[90],q0[91],q0[92],q0[93],q0[94],q0[95],q0[96],q0[97],q0[98],q0[99],q0[100],q0[101],q0[102],q0[103],q0[104],q0[105],q0[106],q0[107],q0[108],q0[109],q0[110],q0[111],q0[112],q0[113],q0[114],q0[115],q0[116],q0[117],q0[118],q0[119],q0[120],q0[121],q0[122],q0[123],q0[124],q0[125],q0[126],q0[127],q0[128],q0[129],q0[130],q0[131],q0[132],q0[133],q0[134],q0[135],q0[136],q0[137],q0[138],q0[139],q0[140],q0[141],q0[142],q0[143],q0[144],q0[145],q0[146],q0[147],q0[148],q0[149],q0[150];
if(c0==0) h q0[0];
if(c0==0) h q0[1];
if(c0==0) h q0[2];
if(c0==0) h q0[3];
if(c0==0) h q0[4];
if(c0==0) h q0[5];
if(c0==0) h q0[6];
if(c0==0) h q0[7];
if(c0==0) h q0[8];
if(c0==0) h q0[9];
if(c0==0) h q0[10];
if(c0==0) h q0[11];
if(c0==0) h q0[12];
if(c0==0) h q0[13];
if(c0==0) h q0[14];
if(c0==0) h q0[15];
if(c0==0) h q0[16];
if(c0==0) h q0[17];
if(c0==0) h q0[18];
if(c0==0) h q0[19];
if(c0==0) h q0[20];
if(c0==0) h q0[21];
if(c0==0) h q0[22];
if(c0==0) h q0[23];
if(c0==0) h q0[24];
if(c0==0) h q0[25];
if(c0==0) h q0[26];
if(c0==0) h q0[27];
if(c0==0) h q0[28];
if(c0==0) h q0[29];
if(c0==0) h q0[30];
if(c0==0) h q0[31];
if(c0==0) h q0[32];
if(c0==0) h q0[33];
if(c0==0) h q0[34];
if(c0==0) h q0[35];
if(c0==0) h q0[36];
if(c0==0) h q0[37];
if(c0==0) h q0[38];
if(c0==0) h q0[39];
if(c0==0) h q0[40];
if(c0==0) h q0[41];
if(c0==0) h q0[42];
if(c0==0) h q0[43];
if(c0==0) h q0[44];
if(c0==0) h q0[45];
if(c0==0) h q0[46];
if(c0==0) h q0[47];
if(c0==0) h q0[48];
if(c0==0) h q0[49];
if(c0==0) h q0[50];
if(c0==0) h q0[51];
if(c0==0) h q0[52];
if(c0==0) h q0[53];
if(c0==0) h q0[54];
if(c0==0) h q0[55];
if(c0==0) h q0[56];
if(c0==0) h q0[57];
if(c0==0) h q0[58];
if(c0==0) h q0[59];
if(c0==0) h q0[60];
if(c0==0) h q0[61];
if(c0==0) h q0[62];
if(c0==0) h q0[63];
if(c0==0) h q0[64];
if(c0==0) h q0[65];
if(c0==0) h q0[66];
if(c0==0) h q0[67];
if(c0==0) h q0[68];
if(c0==0) h q0[69];
if(c0==0) h q0[70];
if(c0==0) h q0[71];
if(c0==0) h q0[72];
if(c0==0) h q0[73];
if(c0==0) h q0[74];
if(c0==0) h q0[75];
if(c0==0) h q0[76];
if(c0==0) h q0[77];
if(c0==0) h q0[78];
if(c0==0) h q0[79];
if(c0==0) h q0[80];
if(c0==0) h q0[81];
if(c0==0) h q0[82];
if(c0==0) h q0[83];
if(c0==0) h q0[84];
if(c0==0) h q0[85];
if(c0==0) h q0[86];
if(c0==0) h q0[87];
if(c0==0) h q0[88];
if(c0==0) h q0[89];
if(c0==0) h q0[90];
if(c0==0) h q0[91];
if(c0==0) h q0[92];
if(c0==0) h q0[93];
if(c0==0) h q0[94];
if(c0==0) h q0[95];
if(c0==0) h q0[96];
if(c0==0) h q0[97];
if(c0==0) h q0[98];
if(c0==0) h q0[99];
if(c0==0) h q0[100];
if(c0==0) h q0[101];
if(c0==0) h q0[102];
if(c0==0) h q0[103];
if(c0==0) h q0[104];
if(c0==0) h q0[105];
if(c0==0) h q0[106];
if(c0==0) h q0[107];
if(c0==0) h q0[108];
if(c0==0) h q0[109];
if(c0==0) h q0[110];
if(c0==0) h q0[111];
if(c0==0) h q0[112];
if(c0==0) h q0[113];
if(c0==0) h q0[114];
if(c0==0) h q0[115];
if(c0==0) h q0[116];
if(c0==0) h q0[117];
if(c0==0) h q0[118];
if(c0==0) h q0[119];
if(c0==0) h q0[120];
if(c0==0) h q0[121];
if(c0==0) h q0[122];
if(c0==0) h q0[123];
if(c0==0) h q0[124];
if(c0==0) h q0[125];
if(c0==0) h q0[126];
if(c0==0) h q0[127];
if(c0==0) h q0[128];
if(c0==0) h q0[129];
if(c0==0) h q0[130];
if(c0==0) h q0[131];
if(c0==0) h q0[132];
if(c0==0) h q0[133];
if(c0==0) h q0[134];
if(c0==0) h q0[135];
if(c0==0) h q0[136];
if(c0==0) h q0[137];
if(c0==0) h q0[138];
if(c0==0) h q0[139];
if(c0==0) h q0[140];
if(c0==0) h q0[141];
if(c0==0) h q0[142];
if(c0==0) h q0[143];
if(c0==0) h q0[144];
if(c0==0) h q0[145];
if(c0==0) h q0[146];
if(c0==0) h q0[147];
if(c0==0) h q0[148];
if(c0==0) h q0[149];
measure q0[0] -> c0[0];
measure q0[1] -> c0[1];
measure q0[2] -> c0[2];
measure q0[3] -> c0[3];
measure q0[4] -> c0[4];
measure q0[5] -> c0[5];
measure q0[6] -> c0[6];
measure q0[7] -> c0[7];
measure q0[8] -> c0[8];
measure q0[9] -> c0[9];
measure q0[10] -> c0[10];
measure q0[11] -> c0[11];
measure q0[12] -> c0[12];
measure q0[13] -> c0[13];
measure q0[14] -> c0[14];
measure q0[15] -> c0[15];
measure q0[16] -> c0[16];
measure q0[17] -> c0[17];
measure q0[18] -> c0[18];
measure q0[19] -> c0[19];
measure q0[20] -> c0[20];
measure q0[21] -> c0[21];
measure q0[22] -> c0[22];
measure q0[23] -> c0[23];
measure q0[24] -> c0[24];
measure q0[25] -> c0[25];
measure q0[26] -> c0[26];
measure q0[27] -> c0[27];
measure q0[28] -> c0[28];
measure q0[29] -> c0[29];
measure q0[30] -> c0[30];
measure q0[31] -> c0[31];
measure q0[32] -> c0[32];
measure q0[33] -> c0[33];
measure q0[34] -> c0[34];
measure q0[35] -> c0[35];
measure q0[36] -> c0[36];
measure q0[37] -> c0[37];
measure q0[38] -> c0[38];
measure q0[39] -> c0[39];
measure q0[40] -> c0[40];
measure q0[41] -> c0[41];
measure q0[42] -> c0[42];
measure q0[43] -> c0[43];
measure q0[44] -> c0[44];
measure q0[45] -> c0[45];
measure q0[46] -> c0[46];
measure q0[47] -> c0[47];
measure q0[48] -> c0[48];
measure q0[49] -> c0[49];
measure q0[50] -> c0[50];
measure q0[51] -> c0[51];
measure q0[52] -> c0[52];
measure q0[53] -> c0[53];
measure q0[54] -> c0[54];
measure q0[55] -> c0[55];
measure q0[56] -> c0[56];
measure q0[57] -> c0[57];
measure q0[58] -> c0[58];
measure q0[59] -> c0[59];
measure q0[60] -> c0[60];
measure q0[61] -> c0[61];
measure q0[62] -> c0[62];
measure q0[63] -> c0[63];
measure q0[64] -> c0[64];
measure q0[65] -> c0[65];
measure q0[66] -> c0[66];
measure q0[67] -> c0[67];
measure q0[68] -> c0[68];
measure q0[69] -> c0[69];
measure q0[70] -> c0[70];
measure q0[71] -> c0[71];
measure q0[72] -> c0[72];
measure q0[73] -> c0[73];
measure q0[74] -> c0[74];
measure q0[75] -> c0[75];
measure q0[76] -> c0[76];
measure q0[77] -> c0[77];
measure q0[78] -> c0[78];
measure q0[79] -> c0[79];
measure q0[80] -> c0[80];
measure q0[81] -> c0[81];
measure q0[82] -> c0[82];
measure q0[83] -> c0[83];
measure q0[84] -> c0[84];
measure q0[85] -> c0[85];
measure q0[86] -> c0[86];
measure q0[87] -> c0[87];
measure q0[88] -> c0[88];
measure q0[89] -> c0[89];
measure q0[90] -> c0[90];
measure q0[91] -> c0[91];
measure q0[92] -> c0[92];
measure q0[93] -> c0[93];
measure q0[94] -> c0[94];
measure q0[95] -> c0[95];
measure q0[96] -> c0[96];
measure q0[97] -> c0[97];
measure q0[98] -> c0[98];
measure q0[99] -> c0[99];
measure q0[100] -> c0[100];
measure q0[101] -> c0[101];
measure q0[102] -> c0[102];
measure q0[103] -> c0[103];
measure q0[104] -> c0[104];
measure q0[105] -> c0[105];
measure q0[106] -> c0[106];
measure q0[107] -> c0[107];
measure q0[108] -> c0[108];
measure q0[109] -> c0[109];
measure q0[110] -> c0[110];
measure q0[111] -> c0[111];
measure q0[112] -> c0[112];
measure q0[113] -> c0[113];
measure q0[114] -> c0[114];
measure q0[115] -> c0[115];
measure q0[116] -> c0[116];
measure q0[117] -> c0[117];
measure q0[118] -> c0[118];
measure q0[119] -> c0[119];
measure q0[120] -> c0[120];
measure q0[121] -> c0[121];
measure q0[122] -> c0[122];
measure q0[123] -> c0[123];
measure q0[124] -> c0[124];
measure q0[125] -> c0[125];
measure q0[126] -> c0[126];
measure q0[127] -> c0[127];
measure q0[128] -> c0[128];
measure q0[129] -> c0[129];
measure q0[130] -> c0[130];
measure q0[131] -> c0[131];
measure q0[132] -> c0[132];
measure q0[133] -> c0[133];
measure q0[134] -> c0[134];
measure q0[135] -> c0[135];
measure q0[136] -> c0[136];
measure q0[137] -> c0[137];
measure q0[138] -> c0[138];
measure q0[139] -> c0[139];
measure q0[140] -> c0[140];
measure q0[141] -> c0[141];
measure q0[142] -> c0[142];
measure q0[143] -> c0[143];
measure q0[144] -> c0[144];
measure q0[145] -> c0[145];
measure q0[146] -> c0[146];
measure q0[147] -> c0[147];
measure q0[148] -> c0[148];
measure q0[149] -> c0[149];

'''

# %%
benchmarks['qft-80'] = '''
// Benchmark was created by MQT Bench on 2023-06-29
// For more information about MQT Bench, please visit https://www.cda.cit.tum.de/mqtbench/
// MQT Bench version: v1.0.0
// Qiskit version: {'qiskit-terra': '0.24.1', 'qiskit-aer': '0.12.0', 'qiskit-ignis': None, 'qiskit-ibmq-provider': '0.20.2', 'qiskit': '0.43.1', 'qiskit-nature': '0.6.2', 'qiskit-finance': '0.3.4', 'qiskit-optimization': '0.5.0', 'qiskit-machine-learning': '0.6.1'}

OPENQASM 2.0;
include "qelib1.inc";
qreg q[80];
creg c[80];
creg meas[80];
h q[79];
cp(pi/2) q[79],q[78];
h q[78];
cp(pi/4) q[79],q[77];
cp(pi/2) q[78],q[77];
h q[77];
cp(pi/8) q[79],q[76];
cp(pi/4) q[78],q[76];
cp(pi/2) q[77],q[76];
h q[76];
cp(pi/16) q[79],q[75];
cp(pi/8) q[78],q[75];
cp(pi/4) q[77],q[75];
cp(pi/2) q[76],q[75];
h q[75];
cp(pi/32) q[79],q[74];
cp(pi/16) q[78],q[74];
cp(pi/8) q[77],q[74];
cp(pi/4) q[76],q[74];
cp(pi/2) q[75],q[74];
h q[74];
cp(pi/64) q[79],q[73];
cp(pi/32) q[78],q[73];
cp(pi/16) q[77],q[73];
cp(pi/8) q[76],q[73];
cp(pi/4) q[75],q[73];
cp(pi/2) q[74],q[73];
h q[73];
cp(pi/128) q[79],q[72];
cp(pi/64) q[78],q[72];
cp(pi/32) q[77],q[72];
cp(pi/16) q[76],q[72];
cp(pi/8) q[75],q[72];
cp(pi/4) q[74],q[72];
cp(pi/2) q[73],q[72];
h q[72];
cp(pi/256) q[79],q[71];
cp(pi/128) q[78],q[71];
cp(pi/64) q[77],q[71];
cp(pi/32) q[76],q[71];
cp(pi/16) q[75],q[71];
cp(pi/8) q[74],q[71];
cp(pi/4) q[73],q[71];
cp(pi/2) q[72],q[71];
h q[71];
cp(pi/512) q[79],q[70];
cp(pi/256) q[78],q[70];
cp(pi/128) q[77],q[70];
cp(pi/64) q[76],q[70];
cp(pi/32) q[75],q[70];
cp(pi/16) q[74],q[70];
cp(pi/8) q[73],q[70];
cp(pi/4) q[72],q[70];
cp(pi/2) q[71],q[70];
h q[70];
cp(pi/1024) q[79],q[69];
cp(pi/512) q[78],q[69];
cp(pi/256) q[77],q[69];
cp(pi/128) q[76],q[69];
cp(pi/64) q[75],q[69];
cp(pi/32) q[74],q[69];
cp(pi/16) q[73],q[69];
cp(pi/8) q[72],q[69];
cp(pi/4) q[71],q[69];
cp(pi/2) q[70],q[69];
h q[69];
cp(pi/2048) q[79],q[68];
cp(pi/1024) q[78],q[68];
cp(pi/512) q[77],q[68];
cp(pi/256) q[76],q[68];
cp(pi/128) q[75],q[68];
cp(pi/64) q[74],q[68];
cp(pi/32) q[73],q[68];
cp(pi/16) q[72],q[68];
cp(pi/8) q[71],q[68];
cp(pi/4) q[70],q[68];
cp(pi/2) q[69],q[68];
h q[68];
cp(pi/4096) q[79],q[67];
cp(pi/2048) q[78],q[67];
cp(pi/1024) q[77],q[67];
cp(pi/512) q[76],q[67];
cp(pi/256) q[75],q[67];
cp(pi/128) q[74],q[67];
cp(pi/64) q[73],q[67];
cp(pi/32) q[72],q[67];
cp(pi/16) q[71],q[67];
cp(pi/8) q[70],q[67];
cp(pi/4) q[69],q[67];
cp(pi/2) q[68],q[67];
h q[67];
cp(pi/8192) q[79],q[66];
cp(pi/4096) q[78],q[66];
cp(pi/2048) q[77],q[66];
cp(pi/1024) q[76],q[66];
cp(pi/512) q[75],q[66];
cp(pi/256) q[74],q[66];
cp(pi/128) q[73],q[66];
cp(pi/64) q[72],q[66];
cp(pi/32) q[71],q[66];
cp(pi/16) q[70],q[66];
cp(pi/8) q[69],q[66];
cp(pi/4) q[68],q[66];
cp(pi/2) q[67],q[66];
h q[66];
cp(pi/16384) q[79],q[65];
cp(pi/8192) q[78],q[65];
cp(pi/4096) q[77],q[65];
cp(pi/2048) q[76],q[65];
cp(pi/1024) q[75],q[65];
cp(pi/512) q[74],q[65];
cp(pi/256) q[73],q[65];
cp(pi/128) q[72],q[65];
cp(pi/64) q[71],q[65];
cp(pi/32) q[70],q[65];
cp(pi/16) q[69],q[65];
cp(pi/8) q[68],q[65];
cp(pi/4) q[67],q[65];
cp(pi/2) q[66],q[65];
h q[65];
cp(pi/32768) q[79],q[64];
cp(pi/16384) q[78],q[64];
cp(pi/8192) q[77],q[64];
cp(pi/4096) q[76],q[64];
cp(pi/2048) q[75],q[64];
cp(pi/1024) q[74],q[64];
cp(pi/512) q[73],q[64];
cp(pi/256) q[72],q[64];
cp(pi/128) q[71],q[64];
cp(pi/64) q[70],q[64];
cp(pi/32) q[69],q[64];
cp(pi/16) q[68],q[64];
cp(pi/8) q[67],q[64];
cp(pi/4) q[66],q[64];
cp(pi/2) q[65],q[64];
h q[64];
cp(pi/65536) q[79],q[63];
cp(pi/32768) q[78],q[63];
cp(pi/16384) q[77],q[63];
cp(pi/8192) q[76],q[63];
cp(pi/4096) q[75],q[63];
cp(pi/2048) q[74],q[63];
cp(pi/1024) q[73],q[63];
cp(pi/512) q[72],q[63];
cp(pi/256) q[71],q[63];
cp(pi/128) q[70],q[63];
cp(pi/64) q[69],q[63];
cp(pi/32) q[68],q[63];
cp(pi/16) q[67],q[63];
cp(pi/8) q[66],q[63];
cp(pi/4) q[65],q[63];
cp(pi/2) q[64],q[63];
h q[63];
cp(pi/131072) q[79],q[62];
cp(pi/65536) q[78],q[62];
cp(pi/32768) q[77],q[62];
cp(pi/16384) q[76],q[62];
cp(pi/8192) q[75],q[62];
cp(pi/4096) q[74],q[62];
cp(pi/2048) q[73],q[62];
cp(pi/1024) q[72],q[62];
cp(pi/512) q[71],q[62];
cp(pi/256) q[70],q[62];
cp(pi/128) q[69],q[62];
cp(pi/64) q[68],q[62];
cp(pi/32) q[67],q[62];
cp(pi/16) q[66],q[62];
cp(pi/8) q[65],q[62];
cp(pi/4) q[64],q[62];
cp(pi/2) q[63],q[62];
h q[62];
cp(pi/262144) q[79],q[61];
cp(pi/131072) q[78],q[61];
cp(pi/65536) q[77],q[61];
cp(pi/32768) q[76],q[61];
cp(pi/16384) q[75],q[61];
cp(pi/8192) q[74],q[61];
cp(pi/4096) q[73],q[61];
cp(pi/2048) q[72],q[61];
cp(pi/1024) q[71],q[61];
cp(pi/512) q[70],q[61];
cp(pi/256) q[69],q[61];
cp(pi/128) q[68],q[61];
cp(pi/64) q[67],q[61];
cp(pi/32) q[66],q[61];
cp(pi/16) q[65],q[61];
cp(pi/8) q[64],q[61];
cp(pi/4) q[63],q[61];
cp(pi/2) q[62],q[61];
h q[61];
cp(pi/524288) q[79],q[60];
cp(pi/262144) q[78],q[60];
cp(pi/131072) q[77],q[60];
cp(pi/65536) q[76],q[60];
cp(pi/32768) q[75],q[60];
cp(pi/16384) q[74],q[60];
cp(pi/8192) q[73],q[60];
cp(pi/4096) q[72],q[60];
cp(pi/2048) q[71],q[60];
cp(pi/1024) q[70],q[60];
cp(pi/512) q[69],q[60];
cp(pi/256) q[68],q[60];
cp(pi/128) q[67],q[60];
cp(pi/64) q[66],q[60];
cp(pi/32) q[65],q[60];
cp(pi/16) q[64],q[60];
cp(pi/8) q[63],q[60];
cp(pi/4) q[62],q[60];
cp(pi/2) q[61],q[60];
h q[60];
cp(pi/1048576) q[79],q[59];
cp(pi/524288) q[78],q[59];
cp(pi/262144) q[77],q[59];
cp(pi/131072) q[76],q[59];
cp(pi/65536) q[75],q[59];
cp(pi/32768) q[74],q[59];
cp(pi/16384) q[73],q[59];
cp(pi/8192) q[72],q[59];
cp(pi/4096) q[71],q[59];
cp(pi/2048) q[70],q[59];
cp(pi/1024) q[69],q[59];
cp(pi/512) q[68],q[59];
cp(pi/256) q[67],q[59];
cp(pi/128) q[66],q[59];
cp(pi/64) q[65],q[59];
cp(pi/32) q[64],q[59];
cp(pi/16) q[63],q[59];
cp(pi/8) q[62],q[59];
cp(pi/4) q[61],q[59];
cp(pi/2) q[60],q[59];
h q[59];
cp(pi/2097152) q[79],q[58];
cp(pi/1048576) q[78],q[58];
cp(pi/524288) q[77],q[58];
cp(pi/262144) q[76],q[58];
cp(pi/131072) q[75],q[58];
cp(pi/65536) q[74],q[58];
cp(pi/32768) q[73],q[58];
cp(pi/16384) q[72],q[58];
cp(pi/8192) q[71],q[58];
cp(pi/4096) q[70],q[58];
cp(pi/2048) q[69],q[58];
cp(pi/1024) q[68],q[58];
cp(pi/512) q[67],q[58];
cp(pi/256) q[66],q[58];
cp(pi/128) q[65],q[58];
cp(pi/64) q[64],q[58];
cp(pi/32) q[63],q[58];
cp(pi/16) q[62],q[58];
cp(pi/8) q[61],q[58];
cp(pi/4) q[60],q[58];
cp(pi/2) q[59],q[58];
h q[58];
cp(pi/4194304) q[79],q[57];
cp(pi/2097152) q[78],q[57];
cp(pi/1048576) q[77],q[57];
cp(pi/524288) q[76],q[57];
cp(pi/262144) q[75],q[57];
cp(pi/131072) q[74],q[57];
cp(pi/65536) q[73],q[57];
cp(pi/32768) q[72],q[57];
cp(pi/16384) q[71],q[57];
cp(pi/8192) q[70],q[57];
cp(pi/4096) q[69],q[57];
cp(pi/2048) q[68],q[57];
cp(pi/1024) q[67],q[57];
cp(pi/512) q[66],q[57];
cp(pi/256) q[65],q[57];
cp(pi/128) q[64],q[57];
cp(pi/64) q[63],q[57];
cp(pi/32) q[62],q[57];
cp(pi/16) q[61],q[57];
cp(pi/8) q[60],q[57];
cp(pi/4) q[59],q[57];
cp(pi/2) q[58],q[57];
h q[57];
cp(pi/8388608) q[79],q[56];
cp(pi/4194304) q[78],q[56];
cp(pi/2097152) q[77],q[56];
cp(pi/1048576) q[76],q[56];
cp(pi/524288) q[75],q[56];
cp(pi/262144) q[74],q[56];
cp(pi/131072) q[73],q[56];
cp(pi/65536) q[72],q[56];
cp(pi/32768) q[71],q[56];
cp(pi/16384) q[70],q[56];
cp(pi/8192) q[69],q[56];
cp(pi/4096) q[68],q[56];
cp(pi/2048) q[67],q[56];
cp(pi/1024) q[66],q[56];
cp(pi/512) q[65],q[56];
cp(pi/256) q[64],q[56];
cp(pi/128) q[63],q[56];
cp(pi/64) q[62],q[56];
cp(pi/32) q[61],q[56];
cp(pi/16) q[60],q[56];
cp(pi/8) q[59],q[56];
cp(pi/4) q[58],q[56];
cp(pi/2) q[57],q[56];
h q[56];
cp(pi/16777216) q[79],q[55];
cp(pi/8388608) q[78],q[55];
cp(pi/4194304) q[77],q[55];
cp(pi/2097152) q[76],q[55];
cp(pi/1048576) q[75],q[55];
cp(pi/524288) q[74],q[55];
cp(pi/262144) q[73],q[55];
cp(pi/131072) q[72],q[55];
cp(pi/65536) q[71],q[55];
cp(pi/32768) q[70],q[55];
cp(pi/16384) q[69],q[55];
cp(pi/8192) q[68],q[55];
cp(pi/4096) q[67],q[55];
cp(pi/2048) q[66],q[55];
cp(pi/1024) q[65],q[55];
cp(pi/512) q[64],q[55];
cp(pi/256) q[63],q[55];
cp(pi/128) q[62],q[55];
cp(pi/64) q[61],q[55];
cp(pi/32) q[60],q[55];
cp(pi/16) q[59],q[55];
cp(pi/8) q[58],q[55];
cp(pi/4) q[57],q[55];
cp(pi/2) q[56],q[55];
h q[55];
cp(pi/33554432) q[79],q[54];
cp(pi/16777216) q[78],q[54];
cp(pi/8388608) q[77],q[54];
cp(pi/4194304) q[76],q[54];
cp(pi/2097152) q[75],q[54];
cp(pi/1048576) q[74],q[54];
cp(pi/524288) q[73],q[54];
cp(pi/262144) q[72],q[54];
cp(pi/131072) q[71],q[54];
cp(pi/65536) q[70],q[54];
cp(pi/32768) q[69],q[54];
cp(pi/16384) q[68],q[54];
cp(pi/8192) q[67],q[54];
cp(pi/4096) q[66],q[54];
cp(pi/2048) q[65],q[54];
cp(pi/1024) q[64],q[54];
cp(pi/512) q[63],q[54];
cp(pi/256) q[62],q[54];
cp(pi/128) q[61],q[54];
cp(pi/64) q[60],q[54];
cp(pi/32) q[59],q[54];
cp(pi/16) q[58],q[54];
cp(pi/8) q[57],q[54];
cp(pi/4) q[56],q[54];
cp(pi/2) q[55],q[54];
h q[54];
cp(pi/67108864) q[79],q[53];
cp(pi/33554432) q[78],q[53];
cp(pi/16777216) q[77],q[53];
cp(pi/8388608) q[76],q[53];
cp(pi/4194304) q[75],q[53];
cp(pi/2097152) q[74],q[53];
cp(pi/1048576) q[73],q[53];
cp(pi/524288) q[72],q[53];
cp(pi/262144) q[71],q[53];
cp(pi/131072) q[70],q[53];
cp(pi/65536) q[69],q[53];
cp(pi/32768) q[68],q[53];
cp(pi/16384) q[67],q[53];
cp(pi/8192) q[66],q[53];
cp(pi/4096) q[65],q[53];
cp(pi/2048) q[64],q[53];
cp(pi/1024) q[63],q[53];
cp(pi/512) q[62],q[53];
cp(pi/256) q[61],q[53];
cp(pi/128) q[60],q[53];
cp(pi/64) q[59],q[53];
cp(pi/32) q[58],q[53];
cp(pi/16) q[57],q[53];
cp(pi/8) q[56],q[53];
cp(pi/4) q[55],q[53];
cp(pi/2) q[54],q[53];
h q[53];
cp(pi/134217728) q[79],q[52];
cp(pi/67108864) q[78],q[52];
cp(pi/33554432) q[77],q[52];
cp(pi/16777216) q[76],q[52];
cp(pi/8388608) q[75],q[52];
cp(pi/4194304) q[74],q[52];
cp(pi/2097152) q[73],q[52];
cp(pi/1048576) q[72],q[52];
cp(pi/524288) q[71],q[52];
cp(pi/262144) q[70],q[52];
cp(pi/131072) q[69],q[52];
cp(pi/65536) q[68],q[52];
cp(pi/32768) q[67],q[52];
cp(pi/16384) q[66],q[52];
cp(pi/8192) q[65],q[52];
cp(pi/4096) q[64],q[52];
cp(pi/2048) q[63],q[52];
cp(pi/1024) q[62],q[52];
cp(pi/512) q[61],q[52];
cp(pi/256) q[60],q[52];
cp(pi/128) q[59],q[52];
cp(pi/64) q[58],q[52];
cp(pi/32) q[57],q[52];
cp(pi/16) q[56],q[52];
cp(pi/8) q[55],q[52];
cp(pi/4) q[54],q[52];
cp(pi/2) q[53],q[52];
h q[52];
cp(pi/268435456) q[79],q[51];
cp(pi/134217728) q[78],q[51];
cp(pi/67108864) q[77],q[51];
cp(pi/33554432) q[76],q[51];
cp(pi/16777216) q[75],q[51];
cp(pi/8388608) q[74],q[51];
cp(pi/4194304) q[73],q[51];
cp(pi/2097152) q[72],q[51];
cp(pi/1048576) q[71],q[51];
cp(pi/524288) q[70],q[51];
cp(pi/262144) q[69],q[51];
cp(pi/131072) q[68],q[51];
cp(pi/65536) q[67],q[51];
cp(pi/32768) q[66],q[51];
cp(pi/16384) q[65],q[51];
cp(pi/8192) q[64],q[51];
cp(pi/4096) q[63],q[51];
cp(pi/2048) q[62],q[51];
cp(pi/1024) q[61],q[51];
cp(pi/512) q[60],q[51];
cp(pi/256) q[59],q[51];
cp(pi/128) q[58],q[51];
cp(pi/64) q[57],q[51];
cp(pi/32) q[56],q[51];
cp(pi/16) q[55],q[51];
cp(pi/8) q[54],q[51];
cp(pi/4) q[53],q[51];
cp(pi/2) q[52],q[51];
h q[51];
cp(pi/536870912) q[79],q[50];
cp(pi/268435456) q[78],q[50];
cp(pi/134217728) q[77],q[50];
cp(pi/67108864) q[76],q[50];
cp(pi/33554432) q[75],q[50];
cp(pi/16777216) q[74],q[50];
cp(pi/8388608) q[73],q[50];
cp(pi/4194304) q[72],q[50];
cp(pi/2097152) q[71],q[50];
cp(pi/1048576) q[70],q[50];
cp(pi/524288) q[69],q[50];
cp(pi/262144) q[68],q[50];
cp(pi/131072) q[67],q[50];
cp(pi/65536) q[66],q[50];
cp(pi/32768) q[65],q[50];
cp(pi/16384) q[64],q[50];
cp(pi/8192) q[63],q[50];
cp(pi/4096) q[62],q[50];
cp(pi/2048) q[61],q[50];
cp(pi/1024) q[60],q[50];
cp(pi/512) q[59],q[50];
cp(pi/256) q[58],q[50];
cp(pi/128) q[57],q[50];
cp(pi/64) q[56],q[50];
cp(pi/32) q[55],q[50];
cp(pi/16) q[54],q[50];
cp(pi/8) q[53],q[50];
cp(pi/4) q[52],q[50];
cp(pi/2) q[51],q[50];
h q[50];
cp(pi/1073741824) q[79],q[49];
cp(pi/536870912) q[78],q[49];
cp(pi/268435456) q[77],q[49];
cp(pi/134217728) q[76],q[49];
cp(pi/67108864) q[75],q[49];
cp(pi/33554432) q[74],q[49];
cp(pi/16777216) q[73],q[49];
cp(pi/8388608) q[72],q[49];
cp(pi/4194304) q[71],q[49];
cp(pi/2097152) q[70],q[49];
cp(pi/1048576) q[69],q[49];
cp(pi/524288) q[68],q[49];
cp(pi/262144) q[67],q[49];
cp(pi/131072) q[66],q[49];
cp(pi/65536) q[65],q[49];
cp(pi/32768) q[64],q[49];
cp(pi/16384) q[63],q[49];
cp(pi/8192) q[62],q[49];
cp(pi/4096) q[61],q[49];
cp(pi/2048) q[60],q[49];
cp(pi/1024) q[59],q[49];
cp(pi/512) q[58],q[49];
cp(pi/256) q[57],q[49];
cp(pi/128) q[56],q[49];
cp(pi/64) q[55],q[49];
cp(pi/32) q[54],q[49];
cp(pi/16) q[53],q[49];
cp(pi/8) q[52],q[49];
cp(pi/4) q[51],q[49];
cp(pi/2) q[50],q[49];
h q[49];
cp(pi/2147483648) q[79],q[48];
cp(pi/1073741824) q[78],q[48];
cp(pi/536870912) q[77],q[48];
cp(pi/268435456) q[76],q[48];
cp(pi/134217728) q[75],q[48];
cp(pi/67108864) q[74],q[48];
cp(pi/33554432) q[73],q[48];
cp(pi/16777216) q[72],q[48];
cp(pi/8388608) q[71],q[48];
cp(pi/4194304) q[70],q[48];
cp(pi/2097152) q[69],q[48];
cp(pi/1048576) q[68],q[48];
cp(pi/524288) q[67],q[48];
cp(pi/262144) q[66],q[48];
cp(pi/131072) q[65],q[48];
cp(pi/65536) q[64],q[48];
cp(pi/32768) q[63],q[48];
cp(pi/16384) q[62],q[48];
cp(pi/8192) q[61],q[48];
cp(pi/4096) q[60],q[48];
cp(pi/2048) q[59],q[48];
cp(pi/1024) q[58],q[48];
cp(pi/512) q[57],q[48];
cp(pi/256) q[56],q[48];
cp(pi/128) q[55],q[48];
cp(pi/64) q[54],q[48];
cp(pi/32) q[53],q[48];
cp(pi/16) q[52],q[48];
cp(pi/8) q[51],q[48];
cp(pi/4) q[50],q[48];
cp(pi/2) q[49],q[48];
h q[48];
cp(pi/4294967296) q[79],q[47];
cp(pi/2147483648) q[78],q[47];
cp(pi/1073741824) q[77],q[47];
cp(pi/536870912) q[76],q[47];
cp(pi/268435456) q[75],q[47];
cp(pi/134217728) q[74],q[47];
cp(pi/67108864) q[73],q[47];
cp(pi/33554432) q[72],q[47];
cp(pi/16777216) q[71],q[47];
cp(pi/8388608) q[70],q[47];
cp(pi/4194304) q[69],q[47];
cp(pi/2097152) q[68],q[47];
cp(pi/1048576) q[67],q[47];
cp(pi/524288) q[66],q[47];
cp(pi/262144) q[65],q[47];
cp(pi/131072) q[64],q[47];
cp(pi/65536) q[63],q[47];
cp(pi/32768) q[62],q[47];
cp(pi/16384) q[61],q[47];
cp(pi/8192) q[60],q[47];
cp(pi/4096) q[59],q[47];
cp(pi/2048) q[58],q[47];
cp(pi/1024) q[57],q[47];
cp(pi/512) q[56],q[47];
cp(pi/256) q[55],q[47];
cp(pi/128) q[54],q[47];
cp(pi/64) q[53],q[47];
cp(pi/32) q[52],q[47];
cp(pi/16) q[51],q[47];
cp(pi/8) q[50],q[47];
cp(pi/4) q[49],q[47];
cp(pi/2) q[48],q[47];
h q[47];
cp(pi/8589934592) q[79],q[46];
cp(pi/4294967296) q[78],q[46];
cp(pi/2147483648) q[77],q[46];
cp(pi/1073741824) q[76],q[46];
cp(pi/536870912) q[75],q[46];
cp(pi/268435456) q[74],q[46];
cp(pi/134217728) q[73],q[46];
cp(pi/67108864) q[72],q[46];
cp(pi/33554432) q[71],q[46];
cp(pi/16777216) q[70],q[46];
cp(pi/8388608) q[69],q[46];
cp(pi/4194304) q[68],q[46];
cp(pi/2097152) q[67],q[46];
cp(pi/1048576) q[66],q[46];
cp(pi/524288) q[65],q[46];
cp(pi/262144) q[64],q[46];
cp(pi/131072) q[63],q[46];
cp(pi/65536) q[62],q[46];
cp(pi/32768) q[61],q[46];
cp(pi/16384) q[60],q[46];
cp(pi/8192) q[59],q[46];
cp(pi/4096) q[58],q[46];
cp(pi/2048) q[57],q[46];
cp(pi/1024) q[56],q[46];
cp(pi/512) q[55],q[46];
cp(pi/256) q[54],q[46];
cp(pi/128) q[53],q[46];
cp(pi/64) q[52],q[46];
cp(pi/32) q[51],q[46];
cp(pi/16) q[50],q[46];
cp(pi/8) q[49],q[46];
cp(pi/4) q[48],q[46];
cp(pi/2) q[47],q[46];
h q[46];
cp(pi/17179869184) q[79],q[45];
cp(pi/8589934592) q[78],q[45];
cp(pi/4294967296) q[77],q[45];
cp(pi/2147483648) q[76],q[45];
cp(pi/1073741824) q[75],q[45];
cp(pi/536870912) q[74],q[45];
cp(pi/268435456) q[73],q[45];
cp(pi/134217728) q[72],q[45];
cp(pi/67108864) q[71],q[45];
cp(pi/33554432) q[70],q[45];
cp(pi/16777216) q[69],q[45];
cp(pi/8388608) q[68],q[45];
cp(pi/4194304) q[67],q[45];
cp(pi/2097152) q[66],q[45];
cp(pi/1048576) q[65],q[45];
cp(pi/524288) q[64],q[45];
cp(pi/262144) q[63],q[45];
cp(pi/131072) q[62],q[45];
cp(pi/65536) q[61],q[45];
cp(pi/32768) q[60],q[45];
cp(pi/16384) q[59],q[45];
cp(pi/8192) q[58],q[45];
cp(pi/4096) q[57],q[45];
cp(pi/2048) q[56],q[45];
cp(pi/1024) q[55],q[45];
cp(pi/512) q[54],q[45];
cp(pi/256) q[53],q[45];
cp(pi/128) q[52],q[45];
cp(pi/64) q[51],q[45];
cp(pi/32) q[50],q[45];
cp(pi/16) q[49],q[45];
cp(pi/8) q[48],q[45];
cp(pi/4) q[47],q[45];
cp(pi/2) q[46],q[45];
h q[45];
cp(pi/34359738368) q[79],q[44];
cp(pi/17179869184) q[78],q[44];
cp(pi/8589934592) q[77],q[44];
cp(pi/4294967296) q[76],q[44];
cp(pi/2147483648) q[75],q[44];
cp(pi/1073741824) q[74],q[44];
cp(pi/536870912) q[73],q[44];
cp(pi/268435456) q[72],q[44];
cp(pi/134217728) q[71],q[44];
cp(pi/67108864) q[70],q[44];
cp(pi/33554432) q[69],q[44];
cp(pi/16777216) q[68],q[44];
cp(pi/8388608) q[67],q[44];
cp(pi/4194304) q[66],q[44];
cp(pi/2097152) q[65],q[44];
cp(pi/1048576) q[64],q[44];
cp(pi/524288) q[63],q[44];
cp(pi/262144) q[62],q[44];
cp(pi/131072) q[61],q[44];
cp(pi/65536) q[60],q[44];
cp(pi/32768) q[59],q[44];
cp(pi/16384) q[58],q[44];
cp(pi/8192) q[57],q[44];
cp(pi/4096) q[56],q[44];
cp(pi/2048) q[55],q[44];
cp(pi/1024) q[54],q[44];
cp(pi/512) q[53],q[44];
cp(pi/256) q[52],q[44];
cp(pi/128) q[51],q[44];
cp(pi/64) q[50],q[44];
cp(pi/32) q[49],q[44];
cp(pi/16) q[48],q[44];
cp(pi/8) q[47],q[44];
cp(pi/4) q[46],q[44];
cp(pi/2) q[45],q[44];
h q[44];
cp(pi/68719476736) q[79],q[43];
cp(pi/34359738368) q[78],q[43];
cp(pi/17179869184) q[77],q[43];
cp(pi/8589934592) q[76],q[43];
cp(pi/4294967296) q[75],q[43];
cp(pi/2147483648) q[74],q[43];
cp(pi/1073741824) q[73],q[43];
cp(pi/536870912) q[72],q[43];
cp(pi/268435456) q[71],q[43];
cp(pi/134217728) q[70],q[43];
cp(pi/67108864) q[69],q[43];
cp(pi/33554432) q[68],q[43];
cp(pi/16777216) q[67],q[43];
cp(pi/8388608) q[66],q[43];
cp(pi/4194304) q[65],q[43];
cp(pi/2097152) q[64],q[43];
cp(pi/1048576) q[63],q[43];
cp(pi/524288) q[62],q[43];
cp(pi/262144) q[61],q[43];
cp(pi/131072) q[60],q[43];
cp(pi/65536) q[59],q[43];
cp(pi/32768) q[58],q[43];
cp(pi/16384) q[57],q[43];
cp(pi/8192) q[56],q[43];
cp(pi/4096) q[55],q[43];
cp(pi/2048) q[54],q[43];
cp(pi/1024) q[53],q[43];
cp(pi/512) q[52],q[43];
cp(pi/256) q[51],q[43];
cp(pi/128) q[50],q[43];
cp(pi/64) q[49],q[43];
cp(pi/32) q[48],q[43];
cp(pi/16) q[47],q[43];
cp(pi/8) q[46],q[43];
cp(pi/4) q[45],q[43];
cp(pi/2) q[44],q[43];
h q[43];
cp(pi/137438953472) q[79],q[42];
cp(pi/68719476736) q[78],q[42];
cp(pi/34359738368) q[77],q[42];
cp(pi/17179869184) q[76],q[42];
cp(pi/8589934592) q[75],q[42];
cp(pi/4294967296) q[74],q[42];
cp(pi/2147483648) q[73],q[42];
cp(pi/1073741824) q[72],q[42];
cp(pi/536870912) q[71],q[42];
cp(pi/268435456) q[70],q[42];
cp(pi/134217728) q[69],q[42];
cp(pi/67108864) q[68],q[42];
cp(pi/33554432) q[67],q[42];
cp(pi/16777216) q[66],q[42];
cp(pi/8388608) q[65],q[42];
cp(pi/4194304) q[64],q[42];
cp(pi/2097152) q[63],q[42];
cp(pi/1048576) q[62],q[42];
cp(pi/524288) q[61],q[42];
cp(pi/262144) q[60],q[42];
cp(pi/131072) q[59],q[42];
cp(pi/65536) q[58],q[42];
cp(pi/32768) q[57],q[42];
cp(pi/16384) q[56],q[42];
cp(pi/8192) q[55],q[42];
cp(pi/4096) q[54],q[42];
cp(pi/2048) q[53],q[42];
cp(pi/1024) q[52],q[42];
cp(pi/512) q[51],q[42];
cp(pi/256) q[50],q[42];
cp(pi/128) q[49],q[42];
cp(pi/64) q[48],q[42];
cp(pi/32) q[47],q[42];
cp(pi/16) q[46],q[42];
cp(pi/8) q[45],q[42];
cp(pi/4) q[44],q[42];
cp(pi/2) q[43],q[42];
h q[42];
cp(pi/274877906944) q[79],q[41];
cp(pi/137438953472) q[78],q[41];
cp(pi/68719476736) q[77],q[41];
cp(pi/34359738368) q[76],q[41];
cp(pi/17179869184) q[75],q[41];
cp(pi/8589934592) q[74],q[41];
cp(pi/4294967296) q[73],q[41];
cp(pi/2147483648) q[72],q[41];
cp(pi/1073741824) q[71],q[41];
cp(pi/536870912) q[70],q[41];
cp(pi/268435456) q[69],q[41];
cp(pi/134217728) q[68],q[41];
cp(pi/67108864) q[67],q[41];
cp(pi/33554432) q[66],q[41];
cp(pi/16777216) q[65],q[41];
cp(pi/8388608) q[64],q[41];
cp(pi/4194304) q[63],q[41];
cp(pi/2097152) q[62],q[41];
cp(pi/1048576) q[61],q[41];
cp(pi/524288) q[60],q[41];
cp(pi/262144) q[59],q[41];
cp(pi/131072) q[58],q[41];
cp(pi/65536) q[57],q[41];
cp(pi/32768) q[56],q[41];
cp(pi/16384) q[55],q[41];
cp(pi/8192) q[54],q[41];
cp(pi/4096) q[53],q[41];
cp(pi/2048) q[52],q[41];
cp(pi/1024) q[51],q[41];
cp(pi/512) q[50],q[41];
cp(pi/256) q[49],q[41];
cp(pi/128) q[48],q[41];
cp(pi/64) q[47],q[41];
cp(pi/32) q[46],q[41];
cp(pi/16) q[45],q[41];
cp(pi/8) q[44],q[41];
cp(pi/4) q[43],q[41];
cp(pi/2) q[42],q[41];
h q[41];
cp(pi/549755813888) q[79],q[40];
cp(pi/274877906944) q[78],q[40];
cp(pi/137438953472) q[77],q[40];
cp(pi/68719476736) q[76],q[40];
cp(pi/34359738368) q[75],q[40];
cp(pi/17179869184) q[74],q[40];
cp(pi/8589934592) q[73],q[40];
cp(pi/4294967296) q[72],q[40];
cp(pi/2147483648) q[71],q[40];
cp(pi/1073741824) q[70],q[40];
cp(pi/536870912) q[69],q[40];
cp(pi/268435456) q[68],q[40];
cp(pi/134217728) q[67],q[40];
cp(pi/67108864) q[66],q[40];
cp(pi/33554432) q[65],q[40];
cp(pi/16777216) q[64],q[40];
cp(pi/8388608) q[63],q[40];
cp(pi/4194304) q[62],q[40];
cp(pi/2097152) q[61],q[40];
cp(pi/1048576) q[60],q[40];
cp(pi/524288) q[59],q[40];
cp(pi/262144) q[58],q[40];
cp(pi/131072) q[57],q[40];
cp(pi/65536) q[56],q[40];
cp(pi/32768) q[55],q[40];
cp(pi/16384) q[54],q[40];
cp(pi/8192) q[53],q[40];
cp(pi/4096) q[52],q[40];
cp(pi/2048) q[51],q[40];
cp(pi/1024) q[50],q[40];
cp(pi/512) q[49],q[40];
cp(pi/256) q[48],q[40];
cp(pi/128) q[47],q[40];
cp(pi/64) q[46],q[40];
cp(pi/32) q[45],q[40];
cp(pi/16) q[44],q[40];
cp(pi/8) q[43],q[40];
cp(pi/4) q[42],q[40];
cp(pi/2) q[41],q[40];
h q[40];
cp(pi/1099511627776) q[79],q[39];
cp(pi/549755813888) q[78],q[39];
cp(pi/274877906944) q[77],q[39];
cp(pi/137438953472) q[76],q[39];
cp(pi/68719476736) q[75],q[39];
cp(pi/34359738368) q[74],q[39];
cp(pi/17179869184) q[73],q[39];
cp(pi/8589934592) q[72],q[39];
cp(pi/4294967296) q[71],q[39];
cp(pi/2147483648) q[70],q[39];
cp(pi/1073741824) q[69],q[39];
cp(pi/536870912) q[68],q[39];
cp(pi/268435456) q[67],q[39];
cp(pi/134217728) q[66],q[39];
cp(pi/67108864) q[65],q[39];
cp(pi/33554432) q[64],q[39];
cp(pi/16777216) q[63],q[39];
cp(pi/8388608) q[62],q[39];
cp(pi/4194304) q[61],q[39];
cp(pi/2097152) q[60],q[39];
cp(pi/1048576) q[59],q[39];
cp(pi/524288) q[58],q[39];
cp(pi/262144) q[57],q[39];
cp(pi/131072) q[56],q[39];
cp(pi/65536) q[55],q[39];
cp(pi/32768) q[54],q[39];
cp(pi/16384) q[53],q[39];
cp(pi/8192) q[52],q[39];
cp(pi/4096) q[51],q[39];
cp(pi/2048) q[50],q[39];
cp(pi/1024) q[49],q[39];
cp(pi/512) q[48],q[39];
cp(pi/256) q[47],q[39];
cp(pi/128) q[46],q[39];
cp(pi/64) q[45],q[39];
cp(pi/32) q[44],q[39];
cp(pi/16) q[43],q[39];
cp(pi/8) q[42],q[39];
cp(pi/4) q[41],q[39];
cp(pi/2) q[40],q[39];
h q[39];
cp(pi/2199023255552) q[79],q[38];
cp(pi/1099511627776) q[78],q[38];
cp(pi/549755813888) q[77],q[38];
cp(pi/274877906944) q[76],q[38];
cp(pi/137438953472) q[75],q[38];
cp(pi/68719476736) q[74],q[38];
cp(pi/34359738368) q[73],q[38];
cp(pi/17179869184) q[72],q[38];
cp(pi/8589934592) q[71],q[38];
cp(pi/4294967296) q[70],q[38];
cp(pi/2147483648) q[69],q[38];
cp(pi/1073741824) q[68],q[38];
cp(pi/536870912) q[67],q[38];
cp(pi/268435456) q[66],q[38];
cp(pi/134217728) q[65],q[38];
cp(pi/67108864) q[64],q[38];
cp(pi/33554432) q[63],q[38];
cp(pi/16777216) q[62],q[38];
cp(pi/8388608) q[61],q[38];
cp(pi/4194304) q[60],q[38];
cp(pi/2097152) q[59],q[38];
cp(pi/1048576) q[58],q[38];
cp(pi/524288) q[57],q[38];
cp(pi/262144) q[56],q[38];
cp(pi/131072) q[55],q[38];
cp(pi/65536) q[54],q[38];
cp(pi/32768) q[53],q[38];
cp(pi/16384) q[52],q[38];
cp(pi/8192) q[51],q[38];
cp(pi/4096) q[50],q[38];
cp(pi/2048) q[49],q[38];
cp(pi/1024) q[48],q[38];
cp(pi/512) q[47],q[38];
cp(pi/256) q[46],q[38];
cp(pi/128) q[45],q[38];
cp(pi/64) q[44],q[38];
cp(pi/32) q[43],q[38];
cp(pi/16) q[42],q[38];
cp(pi/8) q[41],q[38];
cp(pi/4) q[40],q[38];
cp(pi/2) q[39],q[38];
h q[38];
cp(0) q[79],q[37];
cp(pi/2199023255552) q[78],q[37];
cp(pi/1099511627776) q[77],q[37];
cp(pi/549755813888) q[76],q[37];
cp(pi/274877906944) q[75],q[37];
cp(pi/137438953472) q[74],q[37];
cp(pi/68719476736) q[73],q[37];
cp(pi/34359738368) q[72],q[37];
cp(pi/17179869184) q[71],q[37];
cp(pi/8589934592) q[70],q[37];
cp(pi/4294967296) q[69],q[37];
cp(pi/2147483648) q[68],q[37];
cp(pi/1073741824) q[67],q[37];
cp(pi/536870912) q[66],q[37];
cp(pi/268435456) q[65],q[37];
cp(pi/134217728) q[64],q[37];
cp(pi/67108864) q[63],q[37];
cp(pi/33554432) q[62],q[37];
cp(pi/16777216) q[61],q[37];
cp(pi/8388608) q[60],q[37];
cp(pi/4194304) q[59],q[37];
cp(pi/2097152) q[58],q[37];
cp(pi/1048576) q[57],q[37];
cp(pi/524288) q[56],q[37];
cp(pi/262144) q[55],q[37];
cp(pi/131072) q[54],q[37];
cp(pi/65536) q[53],q[37];
cp(pi/32768) q[52],q[37];
cp(pi/16384) q[51],q[37];
cp(pi/8192) q[50],q[37];
cp(pi/4096) q[49],q[37];
cp(pi/2048) q[48],q[37];
cp(pi/1024) q[47],q[37];
cp(pi/512) q[46],q[37];
cp(pi/256) q[45],q[37];
cp(pi/128) q[44],q[37];
cp(pi/64) q[43],q[37];
cp(pi/32) q[42],q[37];
cp(pi/16) q[41],q[37];
cp(pi/8) q[40],q[37];
cp(pi/4) q[39],q[37];
cp(pi/2) q[38],q[37];
h q[37];
cp(0) q[79],q[36];
cp(0) q[78],q[36];
cp(pi/2199023255552) q[77],q[36];
cp(pi/1099511627776) q[76],q[36];
cp(pi/549755813888) q[75],q[36];
cp(pi/274877906944) q[74],q[36];
cp(pi/137438953472) q[73],q[36];
cp(pi/68719476736) q[72],q[36];
cp(pi/34359738368) q[71],q[36];
cp(pi/17179869184) q[70],q[36];
cp(pi/8589934592) q[69],q[36];
cp(pi/4294967296) q[68],q[36];
cp(pi/2147483648) q[67],q[36];
cp(pi/1073741824) q[66],q[36];
cp(pi/536870912) q[65],q[36];
cp(pi/268435456) q[64],q[36];
cp(pi/134217728) q[63],q[36];
cp(pi/67108864) q[62],q[36];
cp(pi/33554432) q[61],q[36];
cp(pi/16777216) q[60],q[36];
cp(pi/8388608) q[59],q[36];
cp(pi/4194304) q[58],q[36];
cp(pi/2097152) q[57],q[36];
cp(pi/1048576) q[56],q[36];
cp(pi/524288) q[55],q[36];
cp(pi/262144) q[54],q[36];
cp(pi/131072) q[53],q[36];
cp(pi/65536) q[52],q[36];
cp(pi/32768) q[51],q[36];
cp(pi/16384) q[50],q[36];
cp(pi/8192) q[49],q[36];
cp(pi/4096) q[48],q[36];
cp(pi/2048) q[47],q[36];
cp(pi/1024) q[46],q[36];
cp(pi/512) q[45],q[36];
cp(pi/256) q[44],q[36];
cp(pi/128) q[43],q[36];
cp(pi/64) q[42],q[36];
cp(pi/32) q[41],q[36];
cp(pi/16) q[40],q[36];
cp(pi/8) q[39],q[36];
cp(pi/4) q[38],q[36];
cp(pi/2) q[37],q[36];
h q[36];
cp(0) q[79],q[35];
cp(0) q[78],q[35];
cp(0) q[77],q[35];
cp(pi/2199023255552) q[76],q[35];
cp(pi/1099511627776) q[75],q[35];
cp(pi/549755813888) q[74],q[35];
cp(pi/274877906944) q[73],q[35];
cp(pi/137438953472) q[72],q[35];
cp(pi/68719476736) q[71],q[35];
cp(pi/34359738368) q[70],q[35];
cp(pi/17179869184) q[69],q[35];
cp(pi/8589934592) q[68],q[35];
cp(pi/4294967296) q[67],q[35];
cp(pi/2147483648) q[66],q[35];
cp(pi/1073741824) q[65],q[35];
cp(pi/536870912) q[64],q[35];
cp(pi/268435456) q[63],q[35];
cp(pi/134217728) q[62],q[35];
cp(pi/67108864) q[61],q[35];
cp(pi/33554432) q[60],q[35];
cp(pi/16777216) q[59],q[35];
cp(pi/8388608) q[58],q[35];
cp(pi/4194304) q[57],q[35];
cp(pi/2097152) q[56],q[35];
cp(pi/1048576) q[55],q[35];
cp(pi/524288) q[54],q[35];
cp(pi/262144) q[53],q[35];
cp(pi/131072) q[52],q[35];
cp(pi/65536) q[51],q[35];
cp(pi/32768) q[50],q[35];
cp(pi/16384) q[49],q[35];
cp(pi/8192) q[48],q[35];
cp(pi/4096) q[47],q[35];
cp(pi/2048) q[46],q[35];
cp(pi/1024) q[45],q[35];
cp(pi/512) q[44],q[35];
cp(pi/256) q[43],q[35];
cp(pi/128) q[42],q[35];
cp(pi/64) q[41],q[35];
cp(pi/32) q[40],q[35];
cp(pi/16) q[39],q[35];
cp(pi/8) q[38],q[35];
cp(pi/4) q[37],q[35];
cp(pi/2) q[36],q[35];
h q[35];
cp(0) q[79],q[34];
cp(0) q[78],q[34];
cp(0) q[77],q[34];
cp(0) q[76],q[34];
cp(pi/2199023255552) q[75],q[34];
cp(pi/1099511627776) q[74],q[34];
cp(pi/549755813888) q[73],q[34];
cp(pi/274877906944) q[72],q[34];
cp(pi/137438953472) q[71],q[34];
cp(pi/68719476736) q[70],q[34];
cp(pi/34359738368) q[69],q[34];
cp(pi/17179869184) q[68],q[34];
cp(pi/8589934592) q[67],q[34];
cp(pi/4294967296) q[66],q[34];
cp(pi/2147483648) q[65],q[34];
cp(pi/1073741824) q[64],q[34];
cp(pi/536870912) q[63],q[34];
cp(pi/268435456) q[62],q[34];
cp(pi/134217728) q[61],q[34];
cp(pi/67108864) q[60],q[34];
cp(pi/33554432) q[59],q[34];
cp(pi/16777216) q[58],q[34];
cp(pi/8388608) q[57],q[34];
cp(pi/4194304) q[56],q[34];
cp(pi/2097152) q[55],q[34];
cp(pi/1048576) q[54],q[34];
cp(pi/524288) q[53],q[34];
cp(pi/262144) q[52],q[34];
cp(pi/131072) q[51],q[34];
cp(pi/65536) q[50],q[34];
cp(pi/32768) q[49],q[34];
cp(pi/16384) q[48],q[34];
cp(pi/8192) q[47],q[34];
cp(pi/4096) q[46],q[34];
cp(pi/2048) q[45],q[34];
cp(pi/1024) q[44],q[34];
cp(pi/512) q[43],q[34];
cp(pi/256) q[42],q[34];
cp(pi/128) q[41],q[34];
cp(pi/64) q[40],q[34];
cp(pi/32) q[39],q[34];
cp(pi/16) q[38],q[34];
cp(pi/8) q[37],q[34];
cp(pi/4) q[36],q[34];
cp(pi/2) q[35],q[34];
h q[34];
cp(0) q[79],q[33];
cp(0) q[78],q[33];
cp(0) q[77],q[33];
cp(0) q[76],q[33];
cp(0) q[75],q[33];
cp(pi/2199023255552) q[74],q[33];
cp(pi/1099511627776) q[73],q[33];
cp(pi/549755813888) q[72],q[33];
cp(pi/274877906944) q[71],q[33];
cp(pi/137438953472) q[70],q[33];
cp(pi/68719476736) q[69],q[33];
cp(pi/34359738368) q[68],q[33];
cp(pi/17179869184) q[67],q[33];
cp(pi/8589934592) q[66],q[33];
cp(pi/4294967296) q[65],q[33];
cp(pi/2147483648) q[64],q[33];
cp(pi/1073741824) q[63],q[33];
cp(pi/536870912) q[62],q[33];
cp(pi/268435456) q[61],q[33];
cp(pi/134217728) q[60],q[33];
cp(pi/67108864) q[59],q[33];
cp(pi/33554432) q[58],q[33];
cp(pi/16777216) q[57],q[33];
cp(pi/8388608) q[56],q[33];
cp(pi/4194304) q[55],q[33];
cp(pi/2097152) q[54],q[33];
cp(pi/1048576) q[53],q[33];
cp(pi/524288) q[52],q[33];
cp(pi/262144) q[51],q[33];
cp(pi/131072) q[50],q[33];
cp(pi/65536) q[49],q[33];
cp(pi/32768) q[48],q[33];
cp(pi/16384) q[47],q[33];
cp(pi/8192) q[46],q[33];
cp(pi/4096) q[45],q[33];
cp(pi/2048) q[44],q[33];
cp(pi/1024) q[43],q[33];
cp(pi/512) q[42],q[33];
cp(pi/256) q[41],q[33];
cp(pi/128) q[40],q[33];
cp(pi/64) q[39],q[33];
cp(pi/32) q[38],q[33];
cp(pi/16) q[37],q[33];
cp(pi/8) q[36],q[33];
cp(pi/4) q[35],q[33];
cp(pi/2) q[34],q[33];
h q[33];
cp(0) q[79],q[32];
cp(0) q[78],q[32];
cp(0) q[77],q[32];
cp(0) q[76],q[32];
cp(0) q[75],q[32];
cp(0) q[74],q[32];
cp(pi/2199023255552) q[73],q[32];
cp(pi/1099511627776) q[72],q[32];
cp(pi/549755813888) q[71],q[32];
cp(pi/274877906944) q[70],q[32];
cp(pi/137438953472) q[69],q[32];
cp(pi/68719476736) q[68],q[32];
cp(pi/34359738368) q[67],q[32];
cp(pi/17179869184) q[66],q[32];
cp(pi/8589934592) q[65],q[32];
cp(pi/4294967296) q[64],q[32];
cp(pi/2147483648) q[63],q[32];
cp(pi/1073741824) q[62],q[32];
cp(pi/536870912) q[61],q[32];
cp(pi/268435456) q[60],q[32];
cp(pi/134217728) q[59],q[32];
cp(pi/67108864) q[58],q[32];
cp(pi/33554432) q[57],q[32];
cp(pi/16777216) q[56],q[32];
cp(pi/8388608) q[55],q[32];
cp(pi/4194304) q[54],q[32];
cp(pi/2097152) q[53],q[32];
cp(pi/1048576) q[52],q[32];
cp(pi/524288) q[51],q[32];
cp(pi/262144) q[50],q[32];
cp(pi/131072) q[49],q[32];
cp(pi/65536) q[48],q[32];
cp(pi/32768) q[47],q[32];
cp(pi/16384) q[46],q[32];
cp(pi/8192) q[45],q[32];
cp(pi/4096) q[44],q[32];
cp(pi/2048) q[43],q[32];
cp(pi/1024) q[42],q[32];
cp(pi/512) q[41],q[32];
cp(pi/256) q[40],q[32];
cp(pi/128) q[39],q[32];
cp(pi/64) q[38],q[32];
cp(pi/32) q[37],q[32];
cp(pi/16) q[36],q[32];
cp(pi/8) q[35],q[32];
cp(pi/4) q[34],q[32];
cp(pi/2) q[33],q[32];
h q[32];
cp(0) q[79],q[31];
cp(0) q[78],q[31];
cp(0) q[77],q[31];
cp(0) q[76],q[31];
cp(0) q[75],q[31];
cp(0) q[74],q[31];
cp(0) q[73],q[31];
cp(pi/2199023255552) q[72],q[31];
cp(pi/1099511627776) q[71],q[31];
cp(pi/549755813888) q[70],q[31];
cp(pi/274877906944) q[69],q[31];
cp(pi/137438953472) q[68],q[31];
cp(pi/68719476736) q[67],q[31];
cp(pi/34359738368) q[66],q[31];
cp(pi/17179869184) q[65],q[31];
cp(pi/8589934592) q[64],q[31];
cp(pi/4294967296) q[63],q[31];
cp(pi/2147483648) q[62],q[31];
cp(pi/1073741824) q[61],q[31];
cp(pi/536870912) q[60],q[31];
cp(pi/268435456) q[59],q[31];
cp(pi/134217728) q[58],q[31];
cp(pi/67108864) q[57],q[31];
cp(pi/33554432) q[56],q[31];
cp(pi/16777216) q[55],q[31];
cp(pi/8388608) q[54],q[31];
cp(pi/4194304) q[53],q[31];
cp(pi/2097152) q[52],q[31];
cp(pi/1048576) q[51],q[31];
cp(pi/524288) q[50],q[31];
cp(pi/262144) q[49],q[31];
cp(pi/131072) q[48],q[31];
cp(pi/65536) q[47],q[31];
cp(pi/32768) q[46],q[31];
cp(pi/16384) q[45],q[31];
cp(pi/8192) q[44],q[31];
cp(pi/4096) q[43],q[31];
cp(pi/2048) q[42],q[31];
cp(pi/1024) q[41],q[31];
cp(pi/512) q[40],q[31];
cp(pi/256) q[39],q[31];
cp(pi/128) q[38],q[31];
cp(pi/64) q[37],q[31];
cp(pi/32) q[36],q[31];
cp(pi/16) q[35],q[31];
cp(pi/8) q[34],q[31];
cp(pi/4) q[33],q[31];
cp(pi/2) q[32],q[31];
h q[31];
cp(0) q[79],q[30];
cp(0) q[78],q[30];
cp(0) q[77],q[30];
cp(0) q[76],q[30];
cp(0) q[75],q[30];
cp(0) q[74],q[30];
cp(0) q[73],q[30];
cp(0) q[72],q[30];
cp(pi/2199023255552) q[71],q[30];
cp(pi/1099511627776) q[70],q[30];
cp(pi/549755813888) q[69],q[30];
cp(pi/274877906944) q[68],q[30];
cp(pi/137438953472) q[67],q[30];
cp(pi/68719476736) q[66],q[30];
cp(pi/34359738368) q[65],q[30];
cp(pi/17179869184) q[64],q[30];
cp(pi/8589934592) q[63],q[30];
cp(pi/4294967296) q[62],q[30];
cp(pi/2147483648) q[61],q[30];
cp(pi/1073741824) q[60],q[30];
cp(pi/536870912) q[59],q[30];
cp(pi/268435456) q[58],q[30];
cp(pi/134217728) q[57],q[30];
cp(pi/67108864) q[56],q[30];
cp(pi/33554432) q[55],q[30];
cp(pi/16777216) q[54],q[30];
cp(pi/8388608) q[53],q[30];
cp(pi/4194304) q[52],q[30];
cp(pi/2097152) q[51],q[30];
cp(pi/1048576) q[50],q[30];
cp(pi/524288) q[49],q[30];
cp(pi/262144) q[48],q[30];
cp(pi/131072) q[47],q[30];
cp(pi/65536) q[46],q[30];
cp(pi/32768) q[45],q[30];
cp(pi/16384) q[44],q[30];
cp(pi/8192) q[43],q[30];
cp(pi/4096) q[42],q[30];
cp(pi/2048) q[41],q[30];
cp(pi/1024) q[40],q[30];
cp(pi/512) q[39],q[30];
cp(pi/256) q[38],q[30];
cp(pi/128) q[37],q[30];
cp(pi/64) q[36],q[30];
cp(pi/32) q[35],q[30];
cp(pi/16) q[34],q[30];
cp(pi/8) q[33],q[30];
cp(pi/4) q[32],q[30];
cp(pi/2) q[31],q[30];
h q[30];
cp(0) q[79],q[29];
cp(0) q[78],q[29];
cp(0) q[77],q[29];
cp(0) q[76],q[29];
cp(0) q[75],q[29];
cp(0) q[74],q[29];
cp(0) q[73],q[29];
cp(0) q[72],q[29];
cp(0) q[71],q[29];
cp(pi/2199023255552) q[70],q[29];
cp(pi/1099511627776) q[69],q[29];
cp(pi/549755813888) q[68],q[29];
cp(pi/274877906944) q[67],q[29];
cp(pi/137438953472) q[66],q[29];
cp(pi/68719476736) q[65],q[29];
cp(pi/34359738368) q[64],q[29];
cp(pi/17179869184) q[63],q[29];
cp(pi/8589934592) q[62],q[29];
cp(pi/4294967296) q[61],q[29];
cp(pi/2147483648) q[60],q[29];
cp(pi/1073741824) q[59],q[29];
cp(pi/536870912) q[58],q[29];
cp(pi/268435456) q[57],q[29];
cp(pi/134217728) q[56],q[29];
cp(pi/67108864) q[55],q[29];
cp(pi/33554432) q[54],q[29];
cp(pi/16777216) q[53],q[29];
cp(pi/8388608) q[52],q[29];
cp(pi/4194304) q[51],q[29];
cp(pi/2097152) q[50],q[29];
cp(pi/1048576) q[49],q[29];
cp(pi/524288) q[48],q[29];
cp(pi/262144) q[47],q[29];
cp(pi/131072) q[46],q[29];
cp(pi/65536) q[45],q[29];
cp(pi/32768) q[44],q[29];
cp(pi/16384) q[43],q[29];
cp(pi/8192) q[42],q[29];
cp(pi/4096) q[41],q[29];
cp(pi/2048) q[40],q[29];
cp(pi/1024) q[39],q[29];
cp(pi/512) q[38],q[29];
cp(pi/256) q[37],q[29];
cp(pi/128) q[36],q[29];
cp(pi/64) q[35],q[29];
cp(pi/32) q[34],q[29];
cp(pi/16) q[33],q[29];
cp(pi/8) q[32],q[29];
cp(pi/4) q[31],q[29];
cp(pi/2) q[30],q[29];
h q[29];
cp(0) q[79],q[28];
cp(0) q[78],q[28];
cp(0) q[77],q[28];
cp(0) q[76],q[28];
cp(0) q[75],q[28];
cp(0) q[74],q[28];
cp(0) q[73],q[28];
cp(0) q[72],q[28];
cp(0) q[71],q[28];
cp(0) q[70],q[28];
cp(pi/2199023255552) q[69],q[28];
cp(pi/1099511627776) q[68],q[28];
cp(pi/549755813888) q[67],q[28];
cp(pi/274877906944) q[66],q[28];
cp(pi/137438953472) q[65],q[28];
cp(pi/68719476736) q[64],q[28];
cp(pi/34359738368) q[63],q[28];
cp(pi/17179869184) q[62],q[28];
cp(pi/8589934592) q[61],q[28];
cp(pi/4294967296) q[60],q[28];
cp(pi/2147483648) q[59],q[28];
cp(pi/1073741824) q[58],q[28];
cp(pi/536870912) q[57],q[28];
cp(pi/268435456) q[56],q[28];
cp(pi/134217728) q[55],q[28];
cp(pi/67108864) q[54],q[28];
cp(pi/33554432) q[53],q[28];
cp(pi/16777216) q[52],q[28];
cp(pi/8388608) q[51],q[28];
cp(pi/4194304) q[50],q[28];
cp(pi/2097152) q[49],q[28];
cp(pi/1048576) q[48],q[28];
cp(pi/524288) q[47],q[28];
cp(pi/262144) q[46],q[28];
cp(pi/131072) q[45],q[28];
cp(pi/65536) q[44],q[28];
cp(pi/32768) q[43],q[28];
cp(pi/16384) q[42],q[28];
cp(pi/8192) q[41],q[28];
cp(pi/4096) q[40],q[28];
cp(pi/2048) q[39],q[28];
cp(pi/1024) q[38],q[28];
cp(pi/512) q[37],q[28];
cp(pi/256) q[36],q[28];
cp(pi/128) q[35],q[28];
cp(pi/64) q[34],q[28];
cp(pi/32) q[33],q[28];
cp(pi/16) q[32],q[28];
cp(pi/8) q[31],q[28];
cp(pi/4) q[30],q[28];
cp(pi/2) q[29],q[28];
h q[28];
cp(0) q[79],q[27];
cp(0) q[78],q[27];
cp(0) q[77],q[27];
cp(0) q[76],q[27];
cp(0) q[75],q[27];
cp(0) q[74],q[27];
cp(0) q[73],q[27];
cp(0) q[72],q[27];
cp(0) q[71],q[27];
cp(0) q[70],q[27];
cp(0) q[69],q[27];
cp(pi/2199023255552) q[68],q[27];
cp(pi/1099511627776) q[67],q[27];
cp(pi/549755813888) q[66],q[27];
cp(pi/274877906944) q[65],q[27];
cp(pi/137438953472) q[64],q[27];
cp(pi/68719476736) q[63],q[27];
cp(pi/34359738368) q[62],q[27];
cp(pi/17179869184) q[61],q[27];
cp(pi/8589934592) q[60],q[27];
cp(pi/4294967296) q[59],q[27];
cp(pi/2147483648) q[58],q[27];
cp(pi/1073741824) q[57],q[27];
cp(pi/536870912) q[56],q[27];
cp(pi/268435456) q[55],q[27];
cp(pi/134217728) q[54],q[27];
cp(pi/67108864) q[53],q[27];
cp(pi/33554432) q[52],q[27];
cp(pi/16777216) q[51],q[27];
cp(pi/8388608) q[50],q[27];
cp(pi/4194304) q[49],q[27];
cp(pi/2097152) q[48],q[27];
cp(pi/1048576) q[47],q[27];
cp(pi/524288) q[46],q[27];
cp(pi/262144) q[45],q[27];
cp(pi/131072) q[44],q[27];
cp(pi/65536) q[43],q[27];
cp(pi/32768) q[42],q[27];
cp(pi/16384) q[41],q[27];
cp(pi/8192) q[40],q[27];
cp(pi/4096) q[39],q[27];
cp(pi/2048) q[38],q[27];
cp(pi/1024) q[37],q[27];
cp(pi/512) q[36],q[27];
cp(pi/256) q[35],q[27];
cp(pi/128) q[34],q[27];
cp(pi/64) q[33],q[27];
cp(pi/32) q[32],q[27];
cp(pi/16) q[31],q[27];
cp(pi/8) q[30],q[27];
cp(pi/4) q[29],q[27];
cp(pi/2) q[28],q[27];
h q[27];
cp(0) q[79],q[26];
cp(0) q[78],q[26];
cp(0) q[77],q[26];
cp(0) q[76],q[26];
cp(0) q[75],q[26];
cp(0) q[74],q[26];
cp(0) q[73],q[26];
cp(0) q[72],q[26];
cp(0) q[71],q[26];
cp(0) q[70],q[26];
cp(0) q[69],q[26];
cp(0) q[68],q[26];
cp(pi/2199023255552) q[67],q[26];
cp(pi/1099511627776) q[66],q[26];
cp(pi/549755813888) q[65],q[26];
cp(pi/274877906944) q[64],q[26];
cp(pi/137438953472) q[63],q[26];
cp(pi/68719476736) q[62],q[26];
cp(pi/34359738368) q[61],q[26];
cp(pi/17179869184) q[60],q[26];
cp(pi/8589934592) q[59],q[26];
cp(pi/4294967296) q[58],q[26];
cp(pi/2147483648) q[57],q[26];
cp(pi/1073741824) q[56],q[26];
cp(pi/536870912) q[55],q[26];
cp(pi/268435456) q[54],q[26];
cp(pi/134217728) q[53],q[26];
cp(pi/67108864) q[52],q[26];
cp(pi/33554432) q[51],q[26];
cp(pi/16777216) q[50],q[26];
cp(pi/8388608) q[49],q[26];
cp(pi/4194304) q[48],q[26];
cp(pi/2097152) q[47],q[26];
cp(pi/1048576) q[46],q[26];
cp(pi/524288) q[45],q[26];
cp(pi/262144) q[44],q[26];
cp(pi/131072) q[43],q[26];
cp(pi/65536) q[42],q[26];
cp(pi/32768) q[41],q[26];
cp(pi/16384) q[40],q[26];
cp(pi/8192) q[39],q[26];
cp(pi/4096) q[38],q[26];
cp(pi/2048) q[37],q[26];
cp(pi/1024) q[36],q[26];
cp(pi/512) q[35],q[26];
cp(pi/256) q[34],q[26];
cp(pi/128) q[33],q[26];
cp(pi/64) q[32],q[26];
cp(pi/32) q[31],q[26];
cp(pi/16) q[30],q[26];
cp(pi/8) q[29],q[26];
cp(pi/4) q[28],q[26];
cp(pi/2) q[27],q[26];
h q[26];
cp(0) q[79],q[25];
cp(0) q[78],q[25];
cp(0) q[77],q[25];
cp(0) q[76],q[25];
cp(0) q[75],q[25];
cp(0) q[74],q[25];
cp(0) q[73],q[25];
cp(0) q[72],q[25];
cp(0) q[71],q[25];
cp(0) q[70],q[25];
cp(0) q[69],q[25];
cp(0) q[68],q[25];
cp(0) q[67],q[25];
cp(pi/2199023255552) q[66],q[25];
cp(pi/1099511627776) q[65],q[25];
cp(pi/549755813888) q[64],q[25];
cp(pi/274877906944) q[63],q[25];
cp(pi/137438953472) q[62],q[25];
cp(pi/68719476736) q[61],q[25];
cp(pi/34359738368) q[60],q[25];
cp(pi/17179869184) q[59],q[25];
cp(pi/8589934592) q[58],q[25];
cp(pi/4294967296) q[57],q[25];
cp(pi/2147483648) q[56],q[25];
cp(pi/1073741824) q[55],q[25];
cp(pi/536870912) q[54],q[25];
cp(pi/268435456) q[53],q[25];
cp(pi/134217728) q[52],q[25];
cp(pi/67108864) q[51],q[25];
cp(pi/33554432) q[50],q[25];
cp(pi/16777216) q[49],q[25];
cp(pi/8388608) q[48],q[25];
cp(pi/4194304) q[47],q[25];
cp(pi/2097152) q[46],q[25];
cp(pi/1048576) q[45],q[25];
cp(pi/524288) q[44],q[25];
cp(pi/262144) q[43],q[25];
cp(pi/131072) q[42],q[25];
cp(pi/65536) q[41],q[25];
cp(pi/32768) q[40],q[25];
cp(pi/16384) q[39],q[25];
cp(pi/8192) q[38],q[25];
cp(pi/4096) q[37],q[25];
cp(pi/2048) q[36],q[25];
cp(pi/1024) q[35],q[25];
cp(pi/512) q[34],q[25];
cp(pi/256) q[33],q[25];
cp(pi/128) q[32],q[25];
cp(pi/64) q[31],q[25];
cp(pi/32) q[30],q[25];
cp(pi/16) q[29],q[25];
cp(pi/8) q[28],q[25];
cp(pi/4) q[27],q[25];
cp(pi/2) q[26],q[25];
h q[25];
cp(0) q[79],q[24];
cp(0) q[78],q[24];
cp(0) q[77],q[24];
cp(0) q[76],q[24];
cp(0) q[75],q[24];
cp(0) q[74],q[24];
cp(0) q[73],q[24];
cp(0) q[72],q[24];
cp(0) q[71],q[24];
cp(0) q[70],q[24];
cp(0) q[69],q[24];
cp(0) q[68],q[24];
cp(0) q[67],q[24];
cp(0) q[66],q[24];
cp(pi/2199023255552) q[65],q[24];
cp(pi/1099511627776) q[64],q[24];
cp(pi/549755813888) q[63],q[24];
cp(pi/274877906944) q[62],q[24];
cp(pi/137438953472) q[61],q[24];
cp(pi/68719476736) q[60],q[24];
cp(pi/34359738368) q[59],q[24];
cp(pi/17179869184) q[58],q[24];
cp(pi/8589934592) q[57],q[24];
cp(pi/4294967296) q[56],q[24];
cp(pi/2147483648) q[55],q[24];
cp(pi/1073741824) q[54],q[24];
cp(pi/536870912) q[53],q[24];
cp(pi/268435456) q[52],q[24];
cp(pi/134217728) q[51],q[24];
cp(pi/67108864) q[50],q[24];
cp(pi/33554432) q[49],q[24];
cp(pi/16777216) q[48],q[24];
cp(pi/8388608) q[47],q[24];
cp(pi/4194304) q[46],q[24];
cp(pi/2097152) q[45],q[24];
cp(pi/1048576) q[44],q[24];
cp(pi/524288) q[43],q[24];
cp(pi/262144) q[42],q[24];
cp(pi/131072) q[41],q[24];
cp(pi/65536) q[40],q[24];
cp(pi/32768) q[39],q[24];
cp(pi/16384) q[38],q[24];
cp(pi/8192) q[37],q[24];
cp(pi/4096) q[36],q[24];
cp(pi/2048) q[35],q[24];
cp(pi/1024) q[34],q[24];
cp(pi/512) q[33],q[24];
cp(pi/256) q[32],q[24];
cp(pi/128) q[31],q[24];
cp(pi/64) q[30],q[24];
cp(pi/32) q[29],q[24];
cp(pi/16) q[28],q[24];
cp(pi/8) q[27],q[24];
cp(pi/4) q[26],q[24];
cp(pi/2) q[25],q[24];
h q[24];
cp(0) q[79],q[23];
cp(0) q[78],q[23];
cp(0) q[77],q[23];
cp(0) q[76],q[23];
cp(0) q[75],q[23];
cp(0) q[74],q[23];
cp(0) q[73],q[23];
cp(0) q[72],q[23];
cp(0) q[71],q[23];
cp(0) q[70],q[23];
cp(0) q[69],q[23];
cp(0) q[68],q[23];
cp(0) q[67],q[23];
cp(0) q[66],q[23];
cp(0) q[65],q[23];
cp(pi/2199023255552) q[64],q[23];
cp(pi/1099511627776) q[63],q[23];
cp(pi/549755813888) q[62],q[23];
cp(pi/274877906944) q[61],q[23];
cp(pi/137438953472) q[60],q[23];
cp(pi/68719476736) q[59],q[23];
cp(pi/34359738368) q[58],q[23];
cp(pi/17179869184) q[57],q[23];
cp(pi/8589934592) q[56],q[23];
cp(pi/4294967296) q[55],q[23];
cp(pi/2147483648) q[54],q[23];
cp(pi/1073741824) q[53],q[23];
cp(pi/536870912) q[52],q[23];
cp(pi/268435456) q[51],q[23];
cp(pi/134217728) q[50],q[23];
cp(pi/67108864) q[49],q[23];
cp(pi/33554432) q[48],q[23];
cp(pi/16777216) q[47],q[23];
cp(pi/8388608) q[46],q[23];
cp(pi/4194304) q[45],q[23];
cp(pi/2097152) q[44],q[23];
cp(pi/1048576) q[43],q[23];
cp(pi/524288) q[42],q[23];
cp(pi/262144) q[41],q[23];
cp(pi/131072) q[40],q[23];
cp(pi/65536) q[39],q[23];
cp(pi/32768) q[38],q[23];
cp(pi/16384) q[37],q[23];
cp(pi/8192) q[36],q[23];
cp(pi/4096) q[35],q[23];
cp(pi/2048) q[34],q[23];
cp(pi/1024) q[33],q[23];
cp(pi/512) q[32],q[23];
cp(pi/256) q[31],q[23];
cp(pi/128) q[30],q[23];
cp(pi/64) q[29],q[23];
cp(pi/32) q[28],q[23];
cp(pi/16) q[27],q[23];
cp(pi/8) q[26],q[23];
cp(pi/4) q[25],q[23];
cp(pi/2) q[24],q[23];
h q[23];
cp(0) q[79],q[22];
cp(0) q[78],q[22];
cp(0) q[77],q[22];
cp(0) q[76],q[22];
cp(0) q[75],q[22];
cp(0) q[74],q[22];
cp(0) q[73],q[22];
cp(0) q[72],q[22];
cp(0) q[71],q[22];
cp(0) q[70],q[22];
cp(0) q[69],q[22];
cp(0) q[68],q[22];
cp(0) q[67],q[22];
cp(0) q[66],q[22];
cp(0) q[65],q[22];
cp(0) q[64],q[22];
cp(pi/2199023255552) q[63],q[22];
cp(pi/1099511627776) q[62],q[22];
cp(pi/549755813888) q[61],q[22];
cp(pi/274877906944) q[60],q[22];
cp(pi/137438953472) q[59],q[22];
cp(pi/68719476736) q[58],q[22];
cp(pi/34359738368) q[57],q[22];
cp(pi/17179869184) q[56],q[22];
cp(pi/8589934592) q[55],q[22];
cp(pi/4294967296) q[54],q[22];
cp(pi/2147483648) q[53],q[22];
cp(pi/1073741824) q[52],q[22];
cp(pi/536870912) q[51],q[22];
cp(pi/268435456) q[50],q[22];
cp(pi/134217728) q[49],q[22];
cp(pi/67108864) q[48],q[22];
cp(pi/33554432) q[47],q[22];
cp(pi/16777216) q[46],q[22];
cp(pi/8388608) q[45],q[22];
cp(pi/4194304) q[44],q[22];
cp(pi/2097152) q[43],q[22];
cp(pi/1048576) q[42],q[22];
cp(pi/524288) q[41],q[22];
cp(pi/262144) q[40],q[22];
cp(pi/131072) q[39],q[22];
cp(pi/65536) q[38],q[22];
cp(pi/32768) q[37],q[22];
cp(pi/16384) q[36],q[22];
cp(pi/8192) q[35],q[22];
cp(pi/4096) q[34],q[22];
cp(pi/2048) q[33],q[22];
cp(pi/1024) q[32],q[22];
cp(pi/512) q[31],q[22];
cp(pi/256) q[30],q[22];
cp(pi/128) q[29],q[22];
cp(pi/64) q[28],q[22];
cp(pi/32) q[27],q[22];
cp(pi/16) q[26],q[22];
cp(pi/8) q[25],q[22];
cp(pi/4) q[24],q[22];
cp(pi/2) q[23],q[22];
h q[22];
cp(0) q[79],q[21];
cp(0) q[78],q[21];
cp(0) q[77],q[21];
cp(0) q[76],q[21];
cp(0) q[75],q[21];
cp(0) q[74],q[21];
cp(0) q[73],q[21];
cp(0) q[72],q[21];
cp(0) q[71],q[21];
cp(0) q[70],q[21];
cp(0) q[69],q[21];
cp(0) q[68],q[21];
cp(0) q[67],q[21];
cp(0) q[66],q[21];
cp(0) q[65],q[21];
cp(0) q[64],q[21];
cp(0) q[63],q[21];
cp(pi/2199023255552) q[62],q[21];
cp(pi/1099511627776) q[61],q[21];
cp(pi/549755813888) q[60],q[21];
cp(pi/274877906944) q[59],q[21];
cp(pi/137438953472) q[58],q[21];
cp(pi/68719476736) q[57],q[21];
cp(pi/34359738368) q[56],q[21];
cp(pi/17179869184) q[55],q[21];
cp(pi/8589934592) q[54],q[21];
cp(pi/4294967296) q[53],q[21];
cp(pi/2147483648) q[52],q[21];
cp(pi/1073741824) q[51],q[21];
cp(pi/536870912) q[50],q[21];
cp(pi/268435456) q[49],q[21];
cp(pi/134217728) q[48],q[21];
cp(pi/67108864) q[47],q[21];
cp(pi/33554432) q[46],q[21];
cp(pi/16777216) q[45],q[21];
cp(pi/8388608) q[44],q[21];
cp(pi/4194304) q[43],q[21];
cp(pi/2097152) q[42],q[21];
cp(pi/1048576) q[41],q[21];
cp(pi/524288) q[40],q[21];
cp(pi/262144) q[39],q[21];
cp(pi/131072) q[38],q[21];
cp(pi/65536) q[37],q[21];
cp(pi/32768) q[36],q[21];
cp(pi/16384) q[35],q[21];
cp(pi/8192) q[34],q[21];
cp(pi/4096) q[33],q[21];
cp(pi/2048) q[32],q[21];
cp(pi/1024) q[31],q[21];
cp(pi/512) q[30],q[21];
cp(pi/256) q[29],q[21];
cp(pi/128) q[28],q[21];
cp(pi/64) q[27],q[21];
cp(pi/32) q[26],q[21];
cp(pi/16) q[25],q[21];
cp(pi/8) q[24],q[21];
cp(pi/4) q[23],q[21];
cp(pi/2) q[22],q[21];
h q[21];
cp(0) q[79],q[20];
cp(0) q[78],q[20];
cp(0) q[77],q[20];
cp(0) q[76],q[20];
cp(0) q[75],q[20];
cp(0) q[74],q[20];
cp(0) q[73],q[20];
cp(0) q[72],q[20];
cp(0) q[71],q[20];
cp(0) q[70],q[20];
cp(0) q[69],q[20];
cp(0) q[68],q[20];
cp(0) q[67],q[20];
cp(0) q[66],q[20];
cp(0) q[65],q[20];
cp(0) q[64],q[20];
cp(0) q[63],q[20];
cp(0) q[62],q[20];
cp(pi/2199023255552) q[61],q[20];
cp(pi/1099511627776) q[60],q[20];
cp(pi/549755813888) q[59],q[20];
cp(pi/274877906944) q[58],q[20];
cp(pi/137438953472) q[57],q[20];
cp(pi/68719476736) q[56],q[20];
cp(pi/34359738368) q[55],q[20];
cp(pi/17179869184) q[54],q[20];
cp(pi/8589934592) q[53],q[20];
cp(pi/4294967296) q[52],q[20];
cp(pi/2147483648) q[51],q[20];
cp(pi/1073741824) q[50],q[20];
cp(pi/536870912) q[49],q[20];
cp(pi/268435456) q[48],q[20];
cp(pi/134217728) q[47],q[20];
cp(pi/67108864) q[46],q[20];
cp(pi/33554432) q[45],q[20];
cp(pi/16777216) q[44],q[20];
cp(pi/8388608) q[43],q[20];
cp(pi/4194304) q[42],q[20];
cp(pi/2097152) q[41],q[20];
cp(pi/1048576) q[40],q[20];
cp(pi/524288) q[39],q[20];
cp(pi/262144) q[38],q[20];
cp(pi/131072) q[37],q[20];
cp(pi/65536) q[36],q[20];
cp(pi/32768) q[35],q[20];
cp(pi/16384) q[34],q[20];
cp(pi/8192) q[33],q[20];
cp(pi/4096) q[32],q[20];
cp(pi/2048) q[31],q[20];
cp(pi/1024) q[30],q[20];
cp(pi/512) q[29],q[20];
cp(pi/256) q[28],q[20];
cp(pi/128) q[27],q[20];
cp(pi/64) q[26],q[20];
cp(pi/32) q[25],q[20];
cp(pi/16) q[24],q[20];
cp(pi/8) q[23],q[20];
cp(pi/4) q[22],q[20];
cp(pi/2) q[21],q[20];
h q[20];
cp(0) q[79],q[19];
cp(0) q[78],q[19];
cp(0) q[77],q[19];
cp(0) q[76],q[19];
cp(0) q[75],q[19];
cp(0) q[74],q[19];
cp(0) q[73],q[19];
cp(0) q[72],q[19];
cp(0) q[71],q[19];
cp(0) q[70],q[19];
cp(0) q[69],q[19];
cp(0) q[68],q[19];
cp(0) q[67],q[19];
cp(0) q[66],q[19];
cp(0) q[65],q[19];
cp(0) q[64],q[19];
cp(0) q[63],q[19];
cp(0) q[62],q[19];
cp(0) q[61],q[19];
cp(pi/2199023255552) q[60],q[19];
cp(pi/1099511627776) q[59],q[19];
cp(pi/549755813888) q[58],q[19];
cp(pi/274877906944) q[57],q[19];
cp(pi/137438953472) q[56],q[19];
cp(pi/68719476736) q[55],q[19];
cp(pi/34359738368) q[54],q[19];
cp(pi/17179869184) q[53],q[19];
cp(pi/8589934592) q[52],q[19];
cp(pi/4294967296) q[51],q[19];
cp(pi/2147483648) q[50],q[19];
cp(pi/1073741824) q[49],q[19];
cp(pi/536870912) q[48],q[19];
cp(pi/268435456) q[47],q[19];
cp(pi/134217728) q[46],q[19];
cp(pi/67108864) q[45],q[19];
cp(pi/33554432) q[44],q[19];
cp(pi/16777216) q[43],q[19];
cp(pi/8388608) q[42],q[19];
cp(pi/4194304) q[41],q[19];
cp(pi/2097152) q[40],q[19];
cp(pi/1048576) q[39],q[19];
cp(pi/524288) q[38],q[19];
cp(pi/262144) q[37],q[19];
cp(pi/131072) q[36],q[19];
cp(pi/65536) q[35],q[19];
cp(pi/32768) q[34],q[19];
cp(pi/16384) q[33],q[19];
cp(pi/8192) q[32],q[19];
cp(pi/4096) q[31],q[19];
cp(pi/2048) q[30],q[19];
cp(pi/1024) q[29],q[19];
cp(pi/512) q[28],q[19];
cp(pi/256) q[27],q[19];
cp(pi/128) q[26],q[19];
cp(pi/64) q[25],q[19];
cp(pi/32) q[24],q[19];
cp(pi/16) q[23],q[19];
cp(pi/8) q[22],q[19];
cp(pi/4) q[21],q[19];
cp(pi/2) q[20],q[19];
h q[19];
cp(0) q[79],q[18];
cp(0) q[78],q[18];
cp(0) q[77],q[18];
cp(0) q[76],q[18];
cp(0) q[75],q[18];
cp(0) q[74],q[18];
cp(0) q[73],q[18];
cp(0) q[72],q[18];
cp(0) q[71],q[18];
cp(0) q[70],q[18];
cp(0) q[69],q[18];
cp(0) q[68],q[18];
cp(0) q[67],q[18];
cp(0) q[66],q[18];
cp(0) q[65],q[18];
cp(0) q[64],q[18];
cp(0) q[63],q[18];
cp(0) q[62],q[18];
cp(0) q[61],q[18];
cp(0) q[60],q[18];
cp(pi/2199023255552) q[59],q[18];
cp(pi/1099511627776) q[58],q[18];
cp(pi/549755813888) q[57],q[18];
cp(pi/274877906944) q[56],q[18];
cp(pi/137438953472) q[55],q[18];
cp(pi/68719476736) q[54],q[18];
cp(pi/34359738368) q[53],q[18];
cp(pi/17179869184) q[52],q[18];
cp(pi/8589934592) q[51],q[18];
cp(pi/4294967296) q[50],q[18];
cp(pi/2147483648) q[49],q[18];
cp(pi/1073741824) q[48],q[18];
cp(pi/536870912) q[47],q[18];
cp(pi/268435456) q[46],q[18];
cp(pi/134217728) q[45],q[18];
cp(pi/67108864) q[44],q[18];
cp(pi/33554432) q[43],q[18];
cp(pi/16777216) q[42],q[18];
cp(pi/8388608) q[41],q[18];
cp(pi/4194304) q[40],q[18];
cp(pi/2097152) q[39],q[18];
cp(pi/1048576) q[38],q[18];
cp(pi/524288) q[37],q[18];
cp(pi/262144) q[36],q[18];
cp(pi/131072) q[35],q[18];
cp(pi/65536) q[34],q[18];
cp(pi/32768) q[33],q[18];
cp(pi/16384) q[32],q[18];
cp(pi/8192) q[31],q[18];
cp(pi/4096) q[30],q[18];
cp(pi/2048) q[29],q[18];
cp(pi/1024) q[28],q[18];
cp(pi/512) q[27],q[18];
cp(pi/256) q[26],q[18];
cp(pi/128) q[25],q[18];
cp(pi/64) q[24],q[18];
cp(pi/32) q[23],q[18];
cp(pi/16) q[22],q[18];
cp(pi/8) q[21],q[18];
cp(pi/4) q[20],q[18];
cp(pi/2) q[19],q[18];
h q[18];
cp(0) q[79],q[17];
cp(0) q[78],q[17];
cp(0) q[77],q[17];
cp(0) q[76],q[17];
cp(0) q[75],q[17];
cp(0) q[74],q[17];
cp(0) q[73],q[17];
cp(0) q[72],q[17];
cp(0) q[71],q[17];
cp(0) q[70],q[17];
cp(0) q[69],q[17];
cp(0) q[68],q[17];
cp(0) q[67],q[17];
cp(0) q[66],q[17];
cp(0) q[65],q[17];
cp(0) q[64],q[17];
cp(0) q[63],q[17];
cp(0) q[62],q[17];
cp(0) q[61],q[17];
cp(0) q[60],q[17];
cp(0) q[59],q[17];
cp(pi/2199023255552) q[58],q[17];
cp(pi/1099511627776) q[57],q[17];
cp(pi/549755813888) q[56],q[17];
cp(pi/274877906944) q[55],q[17];
cp(pi/137438953472) q[54],q[17];
cp(pi/68719476736) q[53],q[17];
cp(pi/34359738368) q[52],q[17];
cp(pi/17179869184) q[51],q[17];
cp(pi/8589934592) q[50],q[17];
cp(pi/4294967296) q[49],q[17];
cp(pi/2147483648) q[48],q[17];
cp(pi/1073741824) q[47],q[17];
cp(pi/536870912) q[46],q[17];
cp(pi/268435456) q[45],q[17];
cp(pi/134217728) q[44],q[17];
cp(pi/67108864) q[43],q[17];
cp(pi/33554432) q[42],q[17];
cp(pi/16777216) q[41],q[17];
cp(pi/8388608) q[40],q[17];
cp(pi/4194304) q[39],q[17];
cp(pi/2097152) q[38],q[17];
cp(pi/1048576) q[37],q[17];
cp(pi/524288) q[36],q[17];
cp(pi/262144) q[35],q[17];
cp(pi/131072) q[34],q[17];
cp(pi/65536) q[33],q[17];
cp(pi/32768) q[32],q[17];
cp(pi/16384) q[31],q[17];
cp(pi/8192) q[30],q[17];
cp(pi/4096) q[29],q[17];
cp(pi/2048) q[28],q[17];
cp(pi/1024) q[27],q[17];
cp(pi/512) q[26],q[17];
cp(pi/256) q[25],q[17];
cp(pi/128) q[24],q[17];
cp(pi/64) q[23],q[17];
cp(pi/32) q[22],q[17];
cp(pi/16) q[21],q[17];
cp(pi/8) q[20],q[17];
cp(pi/4) q[19],q[17];
cp(pi/2) q[18],q[17];
h q[17];
cp(0) q[79],q[16];
cp(0) q[78],q[16];
cp(0) q[77],q[16];
cp(0) q[76],q[16];
cp(0) q[75],q[16];
cp(0) q[74],q[16];
cp(0) q[73],q[16];
cp(0) q[72],q[16];
cp(0) q[71],q[16];
cp(0) q[70],q[16];
cp(0) q[69],q[16];
cp(0) q[68],q[16];
cp(0) q[67],q[16];
cp(0) q[66],q[16];
cp(0) q[65],q[16];
cp(0) q[64],q[16];
cp(0) q[63],q[16];
cp(0) q[62],q[16];
cp(0) q[61],q[16];
cp(0) q[60],q[16];
cp(0) q[59],q[16];
cp(0) q[58],q[16];
cp(pi/2199023255552) q[57],q[16];
cp(pi/1099511627776) q[56],q[16];
cp(pi/549755813888) q[55],q[16];
cp(pi/274877906944) q[54],q[16];
cp(pi/137438953472) q[53],q[16];
cp(pi/68719476736) q[52],q[16];
cp(pi/34359738368) q[51],q[16];
cp(pi/17179869184) q[50],q[16];
cp(pi/8589934592) q[49],q[16];
cp(pi/4294967296) q[48],q[16];
cp(pi/2147483648) q[47],q[16];
cp(pi/1073741824) q[46],q[16];
cp(pi/536870912) q[45],q[16];
cp(pi/268435456) q[44],q[16];
cp(pi/134217728) q[43],q[16];
cp(pi/67108864) q[42],q[16];
cp(pi/33554432) q[41],q[16];
cp(pi/16777216) q[40],q[16];
cp(pi/8388608) q[39],q[16];
cp(pi/4194304) q[38],q[16];
cp(pi/2097152) q[37],q[16];
cp(pi/1048576) q[36],q[16];
cp(pi/524288) q[35],q[16];
cp(pi/262144) q[34],q[16];
cp(pi/131072) q[33],q[16];
cp(pi/65536) q[32],q[16];
cp(pi/32768) q[31],q[16];
cp(pi/16384) q[30],q[16];
cp(pi/8192) q[29],q[16];
cp(pi/4096) q[28],q[16];
cp(pi/2048) q[27],q[16];
cp(pi/1024) q[26],q[16];
cp(pi/512) q[25],q[16];
cp(pi/256) q[24],q[16];
cp(pi/128) q[23],q[16];
cp(pi/64) q[22],q[16];
cp(pi/32) q[21],q[16];
cp(pi/16) q[20],q[16];
cp(pi/8) q[19],q[16];
cp(pi/4) q[18],q[16];
cp(pi/2) q[17],q[16];
h q[16];
cp(0) q[79],q[15];
cp(0) q[78],q[15];
cp(0) q[77],q[15];
cp(0) q[76],q[15];
cp(0) q[75],q[15];
cp(0) q[74],q[15];
cp(0) q[73],q[15];
cp(0) q[72],q[15];
cp(0) q[71],q[15];
cp(0) q[70],q[15];
cp(0) q[69],q[15];
cp(0) q[68],q[15];
cp(0) q[67],q[15];
cp(0) q[66],q[15];
cp(0) q[65],q[15];
cp(0) q[64],q[15];
cp(0) q[63],q[15];
cp(0) q[62],q[15];
cp(0) q[61],q[15];
cp(0) q[60],q[15];
cp(0) q[59],q[15];
cp(0) q[58],q[15];
cp(0) q[57],q[15];
cp(pi/2199023255552) q[56],q[15];
cp(pi/1099511627776) q[55],q[15];
cp(pi/549755813888) q[54],q[15];
cp(pi/274877906944) q[53],q[15];
cp(pi/137438953472) q[52],q[15];
cp(pi/68719476736) q[51],q[15];
cp(pi/34359738368) q[50],q[15];
cp(pi/17179869184) q[49],q[15];
cp(pi/8589934592) q[48],q[15];
cp(pi/4294967296) q[47],q[15];
cp(pi/2147483648) q[46],q[15];
cp(pi/1073741824) q[45],q[15];
cp(pi/536870912) q[44],q[15];
cp(pi/268435456) q[43],q[15];
cp(pi/134217728) q[42],q[15];
cp(pi/67108864) q[41],q[15];
cp(pi/33554432) q[40],q[15];
cp(pi/16777216) q[39],q[15];
cp(pi/8388608) q[38],q[15];
cp(pi/4194304) q[37],q[15];
cp(pi/2097152) q[36],q[15];
cp(pi/1048576) q[35],q[15];
cp(pi/524288) q[34],q[15];
cp(pi/262144) q[33],q[15];
cp(pi/131072) q[32],q[15];
cp(pi/65536) q[31],q[15];
cp(pi/32768) q[30],q[15];
cp(pi/16384) q[29],q[15];
cp(pi/8192) q[28],q[15];
cp(pi/4096) q[27],q[15];
cp(pi/2048) q[26],q[15];
cp(pi/1024) q[25],q[15];
cp(pi/512) q[24],q[15];
cp(pi/256) q[23],q[15];
cp(pi/128) q[22],q[15];
cp(pi/64) q[21],q[15];
cp(pi/32) q[20],q[15];
cp(pi/16) q[19],q[15];
cp(pi/8) q[18],q[15];
cp(pi/4) q[17],q[15];
cp(pi/2) q[16],q[15];
h q[15];
cp(0) q[79],q[14];
cp(0) q[78],q[14];
cp(0) q[77],q[14];
cp(0) q[76],q[14];
cp(0) q[75],q[14];
cp(0) q[74],q[14];
cp(0) q[73],q[14];
cp(0) q[72],q[14];
cp(0) q[71],q[14];
cp(0) q[70],q[14];
cp(0) q[69],q[14];
cp(0) q[68],q[14];
cp(0) q[67],q[14];
cp(0) q[66],q[14];
cp(0) q[65],q[14];
cp(0) q[64],q[14];
cp(0) q[63],q[14];
cp(0) q[62],q[14];
cp(0) q[61],q[14];
cp(0) q[60],q[14];
cp(0) q[59],q[14];
cp(0) q[58],q[14];
cp(0) q[57],q[14];
cp(0) q[56],q[14];
cp(pi/2199023255552) q[55],q[14];
cp(pi/1099511627776) q[54],q[14];
cp(pi/549755813888) q[53],q[14];
cp(pi/274877906944) q[52],q[14];
cp(pi/137438953472) q[51],q[14];
cp(pi/68719476736) q[50],q[14];
cp(pi/34359738368) q[49],q[14];
cp(pi/17179869184) q[48],q[14];
cp(pi/8589934592) q[47],q[14];
cp(pi/4294967296) q[46],q[14];
cp(pi/2147483648) q[45],q[14];
cp(pi/1073741824) q[44],q[14];
cp(pi/536870912) q[43],q[14];
cp(pi/268435456) q[42],q[14];
cp(pi/134217728) q[41],q[14];
cp(pi/67108864) q[40],q[14];
cp(pi/33554432) q[39],q[14];
cp(pi/16777216) q[38],q[14];
cp(pi/8388608) q[37],q[14];
cp(pi/4194304) q[36],q[14];
cp(pi/2097152) q[35],q[14];
cp(pi/1048576) q[34],q[14];
cp(pi/524288) q[33],q[14];
cp(pi/262144) q[32],q[14];
cp(pi/131072) q[31],q[14];
cp(pi/65536) q[30],q[14];
cp(pi/32768) q[29],q[14];
cp(pi/16384) q[28],q[14];
cp(pi/8192) q[27],q[14];
cp(pi/4096) q[26],q[14];
cp(pi/2048) q[25],q[14];
cp(pi/1024) q[24],q[14];
cp(pi/512) q[23],q[14];
cp(pi/256) q[22],q[14];
cp(pi/128) q[21],q[14];
cp(pi/64) q[20],q[14];
cp(pi/32) q[19],q[14];
cp(pi/16) q[18],q[14];
cp(pi/8) q[17],q[14];
cp(pi/4) q[16],q[14];
cp(pi/2) q[15],q[14];
h q[14];
cp(0) q[79],q[13];
cp(0) q[78],q[13];
cp(0) q[77],q[13];
cp(0) q[76],q[13];
cp(0) q[75],q[13];
cp(0) q[74],q[13];
cp(0) q[73],q[13];
cp(0) q[72],q[13];
cp(0) q[71],q[13];
cp(0) q[70],q[13];
cp(0) q[69],q[13];
cp(0) q[68],q[13];
cp(0) q[67],q[13];
cp(0) q[66],q[13];
cp(0) q[65],q[13];
cp(0) q[64],q[13];
cp(0) q[63],q[13];
cp(0) q[62],q[13];
cp(0) q[61],q[13];
cp(0) q[60],q[13];
cp(0) q[59],q[13];
cp(0) q[58],q[13];
cp(0) q[57],q[13];
cp(0) q[56],q[13];
cp(0) q[55],q[13];
cp(pi/2199023255552) q[54],q[13];
cp(pi/1099511627776) q[53],q[13];
cp(pi/549755813888) q[52],q[13];
cp(pi/274877906944) q[51],q[13];
cp(pi/137438953472) q[50],q[13];
cp(pi/68719476736) q[49],q[13];
cp(pi/34359738368) q[48],q[13];
cp(pi/17179869184) q[47],q[13];
cp(pi/8589934592) q[46],q[13];
cp(pi/4294967296) q[45],q[13];
cp(pi/2147483648) q[44],q[13];
cp(pi/1073741824) q[43],q[13];
cp(pi/536870912) q[42],q[13];
cp(pi/268435456) q[41],q[13];
cp(pi/134217728) q[40],q[13];
cp(pi/67108864) q[39],q[13];
cp(pi/33554432) q[38],q[13];
cp(pi/16777216) q[37],q[13];
cp(pi/8388608) q[36],q[13];
cp(pi/4194304) q[35],q[13];
cp(pi/2097152) q[34],q[13];
cp(pi/1048576) q[33],q[13];
cp(pi/524288) q[32],q[13];
cp(pi/262144) q[31],q[13];
cp(pi/131072) q[30],q[13];
cp(pi/65536) q[29],q[13];
cp(pi/32768) q[28],q[13];
cp(pi/16384) q[27],q[13];
cp(pi/8192) q[26],q[13];
cp(pi/4096) q[25],q[13];
cp(pi/2048) q[24],q[13];
cp(pi/1024) q[23],q[13];
cp(pi/512) q[22],q[13];
cp(pi/256) q[21],q[13];
cp(pi/128) q[20],q[13];
cp(pi/64) q[19],q[13];
cp(pi/32) q[18],q[13];
cp(pi/16) q[17],q[13];
cp(pi/8) q[16],q[13];
cp(pi/4) q[15],q[13];
cp(pi/2) q[14],q[13];
h q[13];
cp(0) q[79],q[12];
cp(0) q[78],q[12];
cp(0) q[77],q[12];
cp(0) q[76],q[12];
cp(0) q[75],q[12];
cp(0) q[74],q[12];
cp(0) q[73],q[12];
cp(0) q[72],q[12];
cp(0) q[71],q[12];
cp(0) q[70],q[12];
cp(0) q[69],q[12];
cp(0) q[68],q[12];
cp(0) q[67],q[12];
cp(0) q[66],q[12];
cp(0) q[65],q[12];
cp(0) q[64],q[12];
cp(0) q[63],q[12];
cp(0) q[62],q[12];
cp(0) q[61],q[12];
cp(0) q[60],q[12];
cp(0) q[59],q[12];
cp(0) q[58],q[12];
cp(0) q[57],q[12];
cp(0) q[56],q[12];
cp(0) q[55],q[12];
cp(0) q[54],q[12];
cp(pi/2199023255552) q[53],q[12];
cp(pi/1099511627776) q[52],q[12];
cp(pi/549755813888) q[51],q[12];
cp(pi/274877906944) q[50],q[12];
cp(pi/137438953472) q[49],q[12];
cp(pi/68719476736) q[48],q[12];
cp(pi/34359738368) q[47],q[12];
cp(pi/17179869184) q[46],q[12];
cp(pi/8589934592) q[45],q[12];
cp(pi/4294967296) q[44],q[12];
cp(pi/2147483648) q[43],q[12];
cp(pi/1073741824) q[42],q[12];
cp(pi/536870912) q[41],q[12];
cp(pi/268435456) q[40],q[12];
cp(pi/134217728) q[39],q[12];
cp(pi/67108864) q[38],q[12];
cp(pi/33554432) q[37],q[12];
cp(pi/16777216) q[36],q[12];
cp(pi/8388608) q[35],q[12];
cp(pi/4194304) q[34],q[12];
cp(pi/2097152) q[33],q[12];
cp(pi/1048576) q[32],q[12];
cp(pi/524288) q[31],q[12];
cp(pi/262144) q[30],q[12];
cp(pi/131072) q[29],q[12];
cp(pi/65536) q[28],q[12];
cp(pi/32768) q[27],q[12];
cp(pi/16384) q[26],q[12];
cp(pi/8192) q[25],q[12];
cp(pi/4096) q[24],q[12];
cp(pi/2048) q[23],q[12];
cp(pi/1024) q[22],q[12];
cp(pi/512) q[21],q[12];
cp(pi/256) q[20],q[12];
cp(pi/128) q[19],q[12];
cp(pi/64) q[18],q[12];
cp(pi/32) q[17],q[12];
cp(pi/16) q[16],q[12];
cp(pi/8) q[15],q[12];
cp(pi/4) q[14],q[12];
cp(pi/2) q[13],q[12];
h q[12];
cp(0) q[79],q[11];
cp(0) q[78],q[11];
cp(0) q[77],q[11];
cp(0) q[76],q[11];
cp(0) q[75],q[11];
cp(0) q[74],q[11];
cp(0) q[73],q[11];
cp(0) q[72],q[11];
cp(0) q[71],q[11];
cp(0) q[70],q[11];
cp(0) q[69],q[11];
cp(0) q[68],q[11];
cp(0) q[67],q[11];
cp(0) q[66],q[11];
cp(0) q[65],q[11];
cp(0) q[64],q[11];
cp(0) q[63],q[11];
cp(0) q[62],q[11];
cp(0) q[61],q[11];
cp(0) q[60],q[11];
cp(0) q[59],q[11];
cp(0) q[58],q[11];
cp(0) q[57],q[11];
cp(0) q[56],q[11];
cp(0) q[55],q[11];
cp(0) q[54],q[11];
cp(0) q[53],q[11];
cp(pi/2199023255552) q[52],q[11];
cp(pi/1099511627776) q[51],q[11];
cp(pi/549755813888) q[50],q[11];
cp(pi/274877906944) q[49],q[11];
cp(pi/137438953472) q[48],q[11];
cp(pi/68719476736) q[47],q[11];
cp(pi/34359738368) q[46],q[11];
cp(pi/17179869184) q[45],q[11];
cp(pi/8589934592) q[44],q[11];
cp(pi/4294967296) q[43],q[11];
cp(pi/2147483648) q[42],q[11];
cp(pi/1073741824) q[41],q[11];
cp(pi/536870912) q[40],q[11];
cp(pi/268435456) q[39],q[11];
cp(pi/134217728) q[38],q[11];
cp(pi/67108864) q[37],q[11];
cp(pi/33554432) q[36],q[11];
cp(pi/16777216) q[35],q[11];
cp(pi/8388608) q[34],q[11];
cp(pi/4194304) q[33],q[11];
cp(pi/2097152) q[32],q[11];
cp(pi/1048576) q[31],q[11];
cp(pi/524288) q[30],q[11];
cp(pi/262144) q[29],q[11];
cp(pi/131072) q[28],q[11];
cp(pi/65536) q[27],q[11];
cp(pi/32768) q[26],q[11];
cp(pi/16384) q[25],q[11];
cp(pi/8192) q[24],q[11];
cp(pi/4096) q[23],q[11];
cp(pi/2048) q[22],q[11];
cp(pi/1024) q[21],q[11];
cp(pi/512) q[20],q[11];
cp(pi/256) q[19],q[11];
cp(pi/128) q[18],q[11];
cp(pi/64) q[17],q[11];
cp(pi/32) q[16],q[11];
cp(pi/16) q[15],q[11];
cp(pi/8) q[14],q[11];
cp(pi/4) q[13],q[11];
cp(pi/2) q[12],q[11];
h q[11];
cp(0) q[79],q[10];
cp(0) q[78],q[10];
cp(0) q[77],q[10];
cp(0) q[76],q[10];
cp(0) q[75],q[10];
cp(0) q[74],q[10];
cp(0) q[73],q[10];
cp(0) q[72],q[10];
cp(0) q[71],q[10];
cp(0) q[70],q[10];
cp(0) q[69],q[10];
cp(0) q[68],q[10];
cp(0) q[67],q[10];
cp(0) q[66],q[10];
cp(0) q[65],q[10];
cp(0) q[64],q[10];
cp(0) q[63],q[10];
cp(0) q[62],q[10];
cp(0) q[61],q[10];
cp(0) q[60],q[10];
cp(0) q[59],q[10];
cp(0) q[58],q[10];
cp(0) q[57],q[10];
cp(0) q[56],q[10];
cp(0) q[55],q[10];
cp(0) q[54],q[10];
cp(0) q[53],q[10];
cp(0) q[52],q[10];
cp(pi/2199023255552) q[51],q[10];
cp(pi/1099511627776) q[50],q[10];
cp(pi/549755813888) q[49],q[10];
cp(pi/274877906944) q[48],q[10];
cp(pi/137438953472) q[47],q[10];
cp(pi/68719476736) q[46],q[10];
cp(pi/34359738368) q[45],q[10];
cp(pi/17179869184) q[44],q[10];
cp(pi/8589934592) q[43],q[10];
cp(pi/4294967296) q[42],q[10];
cp(pi/2147483648) q[41],q[10];
cp(pi/1073741824) q[40],q[10];
cp(pi/536870912) q[39],q[10];
cp(pi/268435456) q[38],q[10];
cp(pi/134217728) q[37],q[10];
cp(pi/67108864) q[36],q[10];
cp(pi/33554432) q[35],q[10];
cp(pi/16777216) q[34],q[10];
cp(pi/8388608) q[33],q[10];
cp(pi/4194304) q[32],q[10];
cp(pi/2097152) q[31],q[10];
cp(pi/1048576) q[30],q[10];
cp(pi/524288) q[29],q[10];
cp(pi/262144) q[28],q[10];
cp(pi/131072) q[27],q[10];
cp(pi/65536) q[26],q[10];
cp(pi/32768) q[25],q[10];
cp(pi/16384) q[24],q[10];
cp(pi/8192) q[23],q[10];
cp(pi/4096) q[22],q[10];
cp(pi/2048) q[21],q[10];
cp(pi/1024) q[20],q[10];
cp(pi/512) q[19],q[10];
cp(pi/256) q[18],q[10];
cp(pi/128) q[17],q[10];
cp(pi/64) q[16],q[10];
cp(pi/32) q[15],q[10];
cp(pi/16) q[14],q[10];
cp(pi/8) q[13],q[10];
cp(pi/4) q[12],q[10];
cp(pi/2) q[11],q[10];
h q[10];
cp(0) q[79],q[9];
cp(0) q[78],q[9];
cp(0) q[77],q[9];
cp(0) q[76],q[9];
cp(0) q[75],q[9];
cp(0) q[74],q[9];
cp(0) q[73],q[9];
cp(0) q[72],q[9];
cp(0) q[71],q[9];
cp(0) q[70],q[9];
cp(0) q[69],q[9];
cp(0) q[68],q[9];
cp(0) q[67],q[9];
cp(0) q[66],q[9];
cp(0) q[65],q[9];
cp(0) q[64],q[9];
cp(0) q[63],q[9];
cp(0) q[62],q[9];
cp(0) q[61],q[9];
cp(0) q[60],q[9];
cp(0) q[59],q[9];
cp(0) q[58],q[9];
cp(0) q[57],q[9];
cp(0) q[56],q[9];
cp(0) q[55],q[9];
cp(0) q[54],q[9];
cp(0) q[53],q[9];
cp(0) q[52],q[9];
cp(0) q[51],q[9];
cp(pi/2199023255552) q[50],q[9];
cp(pi/1099511627776) q[49],q[9];
cp(pi/549755813888) q[48],q[9];
cp(pi/274877906944) q[47],q[9];
cp(pi/137438953472) q[46],q[9];
cp(pi/68719476736) q[45],q[9];
cp(pi/34359738368) q[44],q[9];
cp(pi/17179869184) q[43],q[9];
cp(pi/8589934592) q[42],q[9];
cp(pi/4294967296) q[41],q[9];
cp(pi/2147483648) q[40],q[9];
cp(pi/1073741824) q[39],q[9];
cp(pi/536870912) q[38],q[9];
cp(pi/268435456) q[37],q[9];
cp(pi/134217728) q[36],q[9];
cp(pi/67108864) q[35],q[9];
cp(pi/33554432) q[34],q[9];
cp(pi/16777216) q[33],q[9];
cp(pi/8388608) q[32],q[9];
cp(pi/4194304) q[31],q[9];
cp(pi/2097152) q[30],q[9];
cp(pi/1048576) q[29],q[9];
cp(pi/524288) q[28],q[9];
cp(pi/262144) q[27],q[9];
cp(pi/131072) q[26],q[9];
cp(pi/65536) q[25],q[9];
cp(pi/32768) q[24],q[9];
cp(pi/16384) q[23],q[9];
cp(pi/8192) q[22],q[9];
cp(pi/4096) q[21],q[9];
cp(pi/2048) q[20],q[9];
cp(pi/1024) q[19],q[9];
cp(pi/512) q[18],q[9];
cp(pi/256) q[17],q[9];
cp(pi/128) q[16],q[9];
cp(pi/64) q[15],q[9];
cp(pi/32) q[14],q[9];
cp(pi/16) q[13],q[9];
cp(pi/8) q[12],q[9];
cp(pi/4) q[11],q[9];
cp(pi/2) q[10],q[9];
cp(0) q[79],q[8];
cp(0) q[78],q[8];
cp(0) q[77],q[8];
cp(0) q[76],q[8];
cp(0) q[75],q[8];
cp(0) q[74],q[8];
cp(0) q[73],q[8];
cp(0) q[72],q[8];
cp(0) q[71],q[8];
cp(0) q[70],q[8];
cp(0) q[69],q[8];
cp(0) q[68],q[8];
cp(0) q[67],q[8];
cp(0) q[66],q[8];
cp(0) q[65],q[8];
cp(0) q[64],q[8];
cp(0) q[63],q[8];
cp(0) q[62],q[8];
cp(0) q[61],q[8];
cp(0) q[60],q[8];
cp(0) q[59],q[8];
cp(0) q[58],q[8];
cp(0) q[57],q[8];
cp(0) q[56],q[8];
cp(0) q[55],q[8];
cp(0) q[54],q[8];
cp(0) q[53],q[8];
cp(0) q[52],q[8];
cp(0) q[51],q[8];
cp(0) q[50],q[8];
cp(pi/2199023255552) q[49],q[8];
cp(pi/1099511627776) q[48],q[8];
cp(pi/549755813888) q[47],q[8];
cp(pi/274877906944) q[46],q[8];
cp(pi/137438953472) q[45],q[8];
cp(pi/68719476736) q[44],q[8];
cp(pi/34359738368) q[43],q[8];
cp(pi/17179869184) q[42],q[8];
cp(pi/8589934592) q[41],q[8];
cp(pi/4294967296) q[40],q[8];
cp(pi/2147483648) q[39],q[8];
cp(pi/1073741824) q[38],q[8];
cp(pi/536870912) q[37],q[8];
cp(pi/268435456) q[36],q[8];
cp(pi/134217728) q[35],q[8];
cp(pi/67108864) q[34],q[8];
cp(pi/33554432) q[33],q[8];
cp(pi/16777216) q[32],q[8];
cp(pi/8388608) q[31],q[8];
cp(pi/4194304) q[30],q[8];
cp(pi/2097152) q[29],q[8];
cp(pi/1048576) q[28],q[8];
cp(pi/524288) q[27],q[8];
cp(pi/262144) q[26],q[8];
cp(pi/131072) q[25],q[8];
cp(pi/65536) q[24],q[8];
cp(pi/32768) q[23],q[8];
cp(pi/16384) q[22],q[8];
cp(pi/8192) q[21],q[8];
cp(pi/4096) q[20],q[8];
cp(pi/2048) q[19],q[8];
cp(pi/1024) q[18],q[8];
cp(pi/512) q[17],q[8];
cp(pi/256) q[16],q[8];
cp(pi/128) q[15],q[8];
cp(pi/64) q[14],q[8];
cp(pi/32) q[13],q[8];
cp(pi/16) q[12],q[8];
cp(pi/8) q[11],q[8];
cp(pi/4) q[10],q[8];
cp(0) q[79],q[7];
cp(0) q[78],q[7];
cp(0) q[77],q[7];
cp(0) q[76],q[7];
cp(0) q[75],q[7];
cp(0) q[74],q[7];
cp(0) q[73],q[7];
cp(0) q[72],q[7];
cp(0) q[71],q[7];
cp(0) q[70],q[7];
cp(0) q[69],q[7];
cp(0) q[68],q[7];
cp(0) q[67],q[7];
cp(0) q[66],q[7];
cp(0) q[65],q[7];
cp(0) q[64],q[7];
cp(0) q[63],q[7];
cp(0) q[62],q[7];
cp(0) q[61],q[7];
cp(0) q[60],q[7];
cp(0) q[59],q[7];
cp(0) q[58],q[7];
cp(0) q[57],q[7];
cp(0) q[56],q[7];
cp(0) q[55],q[7];
cp(0) q[54],q[7];
cp(0) q[53],q[7];
cp(0) q[52],q[7];
cp(0) q[51],q[7];
cp(0) q[50],q[7];
cp(0) q[49],q[7];
cp(pi/2199023255552) q[48],q[7];
cp(pi/1099511627776) q[47],q[7];
cp(pi/549755813888) q[46],q[7];
cp(pi/274877906944) q[45],q[7];
cp(pi/137438953472) q[44],q[7];
cp(pi/68719476736) q[43],q[7];
cp(pi/34359738368) q[42],q[7];
cp(pi/17179869184) q[41],q[7];
cp(pi/8589934592) q[40],q[7];
cp(pi/4294967296) q[39],q[7];
cp(pi/2147483648) q[38],q[7];
cp(pi/1073741824) q[37],q[7];
cp(pi/536870912) q[36],q[7];
cp(pi/268435456) q[35],q[7];
cp(pi/134217728) q[34],q[7];
cp(pi/67108864) q[33],q[7];
cp(pi/33554432) q[32],q[7];
cp(pi/16777216) q[31],q[7];
cp(pi/8388608) q[30],q[7];
cp(pi/4194304) q[29],q[7];
cp(pi/2097152) q[28],q[7];
cp(pi/1048576) q[27],q[7];
cp(pi/524288) q[26],q[7];
cp(pi/262144) q[25],q[7];
cp(pi/131072) q[24],q[7];
cp(pi/65536) q[23],q[7];
cp(pi/32768) q[22],q[7];
cp(pi/16384) q[21],q[7];
cp(pi/8192) q[20],q[7];
cp(pi/4096) q[19],q[7];
cp(pi/2048) q[18],q[7];
cp(pi/1024) q[17],q[7];
cp(pi/512) q[16],q[7];
cp(pi/256) q[15],q[7];
cp(pi/128) q[14],q[7];
cp(pi/64) q[13],q[7];
cp(pi/32) q[12],q[7];
cp(pi/16) q[11],q[7];
cp(pi/8) q[10],q[7];
cp(0) q[79],q[6];
cp(0) q[78],q[6];
cp(0) q[77],q[6];
cp(0) q[76],q[6];
cp(0) q[75],q[6];
cp(0) q[74],q[6];
cp(0) q[73],q[6];
cp(0) q[72],q[6];
cp(0) q[71],q[6];
cp(0) q[70],q[6];
cp(0) q[69],q[6];
cp(0) q[68],q[6];
cp(0) q[67],q[6];
cp(0) q[66],q[6];
cp(0) q[65],q[6];
cp(0) q[64],q[6];
cp(0) q[63],q[6];
cp(0) q[62],q[6];
cp(0) q[61],q[6];
cp(0) q[60],q[6];
cp(0) q[59],q[6];
cp(0) q[58],q[6];
cp(0) q[57],q[6];
cp(0) q[56],q[6];
cp(0) q[55],q[6];
cp(0) q[54],q[6];
cp(0) q[53],q[6];
cp(0) q[52],q[6];
cp(0) q[51],q[6];
cp(0) q[50],q[6];
cp(0) q[49],q[6];
cp(0) q[48],q[6];
cp(pi/2199023255552) q[47],q[6];
cp(pi/1099511627776) q[46],q[6];
cp(pi/549755813888) q[45],q[6];
cp(pi/274877906944) q[44],q[6];
cp(pi/137438953472) q[43],q[6];
cp(pi/68719476736) q[42],q[6];
cp(pi/34359738368) q[41],q[6];
cp(pi/17179869184) q[40],q[6];
cp(pi/8589934592) q[39],q[6];
cp(pi/4294967296) q[38],q[6];
cp(pi/2147483648) q[37],q[6];
cp(pi/1073741824) q[36],q[6];
cp(pi/536870912) q[35],q[6];
cp(pi/268435456) q[34],q[6];
cp(pi/134217728) q[33],q[6];
cp(pi/67108864) q[32],q[6];
cp(pi/33554432) q[31],q[6];
cp(pi/16777216) q[30],q[6];
cp(pi/8388608) q[29],q[6];
cp(pi/4194304) q[28],q[6];
cp(pi/2097152) q[27],q[6];
cp(pi/1048576) q[26],q[6];
cp(pi/524288) q[25],q[6];
cp(pi/262144) q[24],q[6];
cp(pi/131072) q[23],q[6];
cp(pi/65536) q[22],q[6];
cp(pi/32768) q[21],q[6];
cp(pi/16384) q[20],q[6];
cp(pi/8192) q[19],q[6];
cp(pi/4096) q[18],q[6];
cp(pi/2048) q[17],q[6];
cp(pi/1024) q[16],q[6];
cp(pi/512) q[15],q[6];
cp(pi/256) q[14],q[6];
cp(pi/128) q[13],q[6];
cp(pi/64) q[12],q[6];
cp(pi/32) q[11],q[6];
cp(pi/16) q[10],q[6];
cp(0) q[79],q[5];
cp(0) q[78],q[5];
cp(0) q[77],q[5];
cp(0) q[76],q[5];
cp(0) q[75],q[5];
cp(0) q[74],q[5];
cp(0) q[73],q[5];
cp(0) q[72],q[5];
cp(0) q[71],q[5];
cp(0) q[70],q[5];
cp(0) q[69],q[5];
cp(0) q[68],q[5];
cp(0) q[67],q[5];
cp(0) q[66],q[5];
cp(0) q[65],q[5];
cp(0) q[64],q[5];
cp(0) q[63],q[5];
cp(0) q[62],q[5];
cp(0) q[61],q[5];
cp(0) q[60],q[5];
cp(0) q[59],q[5];
cp(0) q[58],q[5];
cp(0) q[57],q[5];
cp(0) q[56],q[5];
cp(0) q[55],q[5];
cp(0) q[54],q[5];
cp(0) q[53],q[5];
cp(0) q[52],q[5];
cp(0) q[51],q[5];
cp(0) q[50],q[5];
cp(0) q[49],q[5];
cp(0) q[48],q[5];
cp(0) q[47],q[5];
cp(pi/2199023255552) q[46],q[5];
cp(pi/1099511627776) q[45],q[5];
cp(pi/549755813888) q[44],q[5];
cp(pi/274877906944) q[43],q[5];
cp(pi/137438953472) q[42],q[5];
cp(pi/68719476736) q[41],q[5];
cp(pi/34359738368) q[40],q[5];
cp(pi/17179869184) q[39],q[5];
cp(pi/8589934592) q[38],q[5];
cp(pi/4294967296) q[37],q[5];
cp(pi/2147483648) q[36],q[5];
cp(pi/1073741824) q[35],q[5];
cp(pi/536870912) q[34],q[5];
cp(pi/268435456) q[33],q[5];
cp(pi/134217728) q[32],q[5];
cp(pi/67108864) q[31],q[5];
cp(pi/33554432) q[30],q[5];
cp(pi/16777216) q[29],q[5];
cp(pi/8388608) q[28],q[5];
cp(pi/4194304) q[27],q[5];
cp(pi/2097152) q[26],q[5];
cp(pi/1048576) q[25],q[5];
cp(pi/524288) q[24],q[5];
cp(pi/262144) q[23],q[5];
cp(pi/131072) q[22],q[5];
cp(pi/65536) q[21],q[5];
cp(pi/32768) q[20],q[5];
cp(pi/16384) q[19],q[5];
cp(pi/8192) q[18],q[5];
cp(pi/4096) q[17],q[5];
cp(pi/2048) q[16],q[5];
cp(pi/1024) q[15],q[5];
cp(pi/512) q[14],q[5];
cp(pi/256) q[13],q[5];
cp(pi/128) q[12],q[5];
cp(pi/64) q[11],q[5];
cp(pi/32) q[10],q[5];
cp(0) q[79],q[4];
cp(0) q[78],q[4];
cp(0) q[77],q[4];
cp(0) q[76],q[4];
cp(0) q[75],q[4];
cp(0) q[74],q[4];
cp(0) q[73],q[4];
cp(0) q[72],q[4];
cp(0) q[71],q[4];
cp(0) q[70],q[4];
cp(0) q[69],q[4];
cp(0) q[68],q[4];
cp(0) q[67],q[4];
cp(0) q[66],q[4];
cp(0) q[65],q[4];
cp(0) q[64],q[4];
cp(0) q[63],q[4];
cp(0) q[62],q[4];
cp(0) q[61],q[4];
cp(0) q[60],q[4];
cp(0) q[59],q[4];
cp(0) q[58],q[4];
cp(0) q[57],q[4];
cp(0) q[56],q[4];
cp(0) q[55],q[4];
cp(0) q[54],q[4];
cp(0) q[53],q[4];
cp(0) q[52],q[4];
cp(0) q[51],q[4];
cp(0) q[50],q[4];
cp(0) q[49],q[4];
cp(0) q[48],q[4];
cp(0) q[47],q[4];
cp(0) q[46],q[4];
cp(pi/2199023255552) q[45],q[4];
cp(pi/1099511627776) q[44],q[4];
cp(pi/549755813888) q[43],q[4];
cp(pi/274877906944) q[42],q[4];
cp(pi/137438953472) q[41],q[4];
cp(pi/68719476736) q[40],q[4];
cp(pi/34359738368) q[39],q[4];
cp(pi/17179869184) q[38],q[4];
cp(pi/8589934592) q[37],q[4];
cp(pi/4294967296) q[36],q[4];
cp(pi/2147483648) q[35],q[4];
cp(pi/1073741824) q[34],q[4];
cp(pi/536870912) q[33],q[4];
cp(pi/268435456) q[32],q[4];
cp(pi/134217728) q[31],q[4];
cp(pi/67108864) q[30],q[4];
cp(pi/33554432) q[29],q[4];
cp(pi/16777216) q[28],q[4];
cp(pi/8388608) q[27],q[4];
cp(pi/4194304) q[26],q[4];
cp(pi/2097152) q[25],q[4];
cp(pi/1048576) q[24],q[4];
cp(pi/524288) q[23],q[4];
cp(pi/262144) q[22],q[4];
cp(pi/131072) q[21],q[4];
cp(pi/65536) q[20],q[4];
cp(pi/32768) q[19],q[4];
cp(pi/16384) q[18],q[4];
cp(pi/8192) q[17],q[4];
cp(pi/4096) q[16],q[4];
cp(pi/2048) q[15],q[4];
cp(pi/1024) q[14],q[4];
cp(pi/512) q[13],q[4];
cp(pi/256) q[12],q[4];
cp(pi/128) q[11],q[4];
cp(pi/64) q[10],q[4];
cp(0) q[79],q[3];
cp(0) q[78],q[3];
cp(0) q[77],q[3];
cp(0) q[76],q[3];
cp(0) q[75],q[3];
cp(0) q[74],q[3];
cp(0) q[73],q[3];
cp(0) q[72],q[3];
cp(0) q[71],q[3];
cp(0) q[70],q[3];
cp(0) q[69],q[3];
cp(0) q[68],q[3];
cp(0) q[67],q[3];
cp(0) q[66],q[3];
cp(0) q[65],q[3];
cp(0) q[64],q[3];
cp(0) q[63],q[3];
cp(0) q[62],q[3];
cp(0) q[61],q[3];
cp(0) q[60],q[3];
cp(0) q[59],q[3];
cp(0) q[58],q[3];
cp(0) q[57],q[3];
cp(0) q[56],q[3];
cp(0) q[55],q[3];
cp(0) q[54],q[3];
cp(0) q[53],q[3];
cp(0) q[52],q[3];
cp(0) q[51],q[3];
cp(0) q[50],q[3];
cp(0) q[49],q[3];
cp(0) q[48],q[3];
cp(0) q[47],q[3];
cp(0) q[46],q[3];
cp(0) q[45],q[3];
cp(pi/2199023255552) q[44],q[3];
cp(pi/1099511627776) q[43],q[3];
cp(pi/549755813888) q[42],q[3];
cp(pi/274877906944) q[41],q[3];
cp(pi/137438953472) q[40],q[3];
cp(pi/68719476736) q[39],q[3];
cp(pi/34359738368) q[38],q[3];
cp(pi/17179869184) q[37],q[3];
cp(pi/8589934592) q[36],q[3];
cp(pi/4294967296) q[35],q[3];
cp(pi/2147483648) q[34],q[3];
cp(pi/1073741824) q[33],q[3];
cp(pi/536870912) q[32],q[3];
cp(pi/268435456) q[31],q[3];
cp(pi/134217728) q[30],q[3];
cp(pi/67108864) q[29],q[3];
cp(pi/33554432) q[28],q[3];
cp(pi/16777216) q[27],q[3];
cp(pi/8388608) q[26],q[3];
cp(pi/4194304) q[25],q[3];
cp(pi/2097152) q[24],q[3];
cp(pi/1048576) q[23],q[3];
cp(pi/524288) q[22],q[3];
cp(pi/262144) q[21],q[3];
cp(pi/131072) q[20],q[3];
cp(pi/65536) q[19],q[3];
cp(pi/32768) q[18],q[3];
cp(pi/16384) q[17],q[3];
cp(pi/8192) q[16],q[3];
cp(pi/4096) q[15],q[3];
cp(pi/2048) q[14],q[3];
cp(pi/1024) q[13],q[3];
cp(pi/512) q[12],q[3];
cp(pi/256) q[11],q[3];
cp(pi/128) q[10],q[3];
cp(0) q[79],q[2];
cp(0) q[78],q[2];
cp(0) q[77],q[2];
cp(0) q[76],q[2];
cp(0) q[75],q[2];
cp(0) q[74],q[2];
cp(0) q[73],q[2];
cp(0) q[72],q[2];
cp(0) q[71],q[2];
cp(0) q[70],q[2];
cp(0) q[69],q[2];
cp(0) q[68],q[2];
cp(0) q[67],q[2];
cp(0) q[66],q[2];
cp(0) q[65],q[2];
cp(0) q[64],q[2];
cp(0) q[63],q[2];
cp(0) q[62],q[2];
cp(0) q[61],q[2];
cp(0) q[60],q[2];
cp(0) q[59],q[2];
cp(0) q[58],q[2];
cp(0) q[57],q[2];
cp(0) q[56],q[2];
cp(0) q[55],q[2];
cp(0) q[54],q[2];
cp(0) q[53],q[2];
cp(0) q[52],q[2];
cp(0) q[51],q[2];
cp(0) q[50],q[2];
cp(0) q[49],q[2];
cp(0) q[48],q[2];
cp(0) q[47],q[2];
cp(0) q[46],q[2];
cp(0) q[45],q[2];
cp(0) q[44],q[2];
cp(pi/2199023255552) q[43],q[2];
cp(pi/1099511627776) q[42],q[2];
cp(pi/549755813888) q[41],q[2];
cp(pi/274877906944) q[40],q[2];
cp(pi/137438953472) q[39],q[2];
cp(pi/68719476736) q[38],q[2];
cp(pi/34359738368) q[37],q[2];
cp(pi/17179869184) q[36],q[2];
cp(pi/8589934592) q[35],q[2];
cp(pi/4294967296) q[34],q[2];
cp(pi/2147483648) q[33],q[2];
cp(pi/1073741824) q[32],q[2];
cp(pi/536870912) q[31],q[2];
cp(pi/268435456) q[30],q[2];
cp(pi/134217728) q[29],q[2];
cp(pi/67108864) q[28],q[2];
cp(pi/33554432) q[27],q[2];
cp(pi/16777216) q[26],q[2];
cp(pi/8388608) q[25],q[2];
cp(pi/4194304) q[24],q[2];
cp(pi/2097152) q[23],q[2];
cp(pi/1048576) q[22],q[2];
cp(pi/524288) q[21],q[2];
cp(pi/262144) q[20],q[2];
cp(pi/131072) q[19],q[2];
cp(pi/65536) q[18],q[2];
cp(pi/32768) q[17],q[2];
cp(pi/16384) q[16],q[2];
cp(pi/8192) q[15],q[2];
cp(pi/4096) q[14],q[2];
cp(pi/2048) q[13],q[2];
cp(pi/1024) q[12],q[2];
cp(pi/512) q[11],q[2];
cp(pi/256) q[10],q[2];
cp(0) q[79],q[1];
cp(0) q[78],q[1];
cp(0) q[77],q[1];
cp(0) q[76],q[1];
cp(0) q[75],q[1];
cp(0) q[74],q[1];
cp(0) q[73],q[1];
cp(0) q[72],q[1];
cp(0) q[71],q[1];
cp(0) q[70],q[1];
cp(0) q[69],q[1];
cp(0) q[68],q[1];
cp(0) q[67],q[1];
cp(0) q[66],q[1];
cp(0) q[65],q[1];
cp(0) q[64],q[1];
cp(0) q[63],q[1];
cp(0) q[62],q[1];
cp(0) q[61],q[1];
cp(0) q[60],q[1];
cp(0) q[59],q[1];
cp(0) q[58],q[1];
cp(0) q[57],q[1];
cp(0) q[56],q[1];
cp(0) q[55],q[1];
cp(0) q[54],q[1];
cp(0) q[53],q[1];
cp(0) q[52],q[1];
cp(0) q[51],q[1];
cp(0) q[50],q[1];
cp(0) q[49],q[1];
cp(0) q[48],q[1];
cp(0) q[47],q[1];
cp(0) q[46],q[1];
cp(0) q[45],q[1];
cp(0) q[44],q[1];
cp(0) q[43],q[1];
cp(pi/2199023255552) q[42],q[1];
cp(pi/1099511627776) q[41],q[1];
cp(pi/549755813888) q[40],q[1];
cp(pi/274877906944) q[39],q[1];
cp(pi/137438953472) q[38],q[1];
cp(pi/68719476736) q[37],q[1];
cp(pi/34359738368) q[36],q[1];
cp(pi/17179869184) q[35],q[1];
cp(pi/8589934592) q[34],q[1];
cp(pi/4294967296) q[33],q[1];
cp(pi/2147483648) q[32],q[1];
cp(pi/1073741824) q[31],q[1];
cp(pi/536870912) q[30],q[1];
cp(pi/268435456) q[29],q[1];
cp(pi/134217728) q[28],q[1];
cp(pi/67108864) q[27],q[1];
cp(pi/33554432) q[26],q[1];
cp(pi/16777216) q[25],q[1];
cp(pi/8388608) q[24],q[1];
cp(pi/4194304) q[23],q[1];
cp(pi/2097152) q[22],q[1];
cp(pi/1048576) q[21],q[1];
cp(pi/524288) q[20],q[1];
cp(pi/262144) q[19],q[1];
cp(pi/131072) q[18],q[1];
cp(pi/65536) q[17],q[1];
cp(pi/32768) q[16],q[1];
cp(pi/16384) q[15],q[1];
cp(pi/8192) q[14],q[1];
cp(pi/4096) q[13],q[1];
cp(pi/2048) q[12],q[1];
cp(pi/1024) q[11],q[1];
cp(pi/512) q[10],q[1];
cp(0) q[79],q[0];
cp(0) q[78],q[0];
cp(0) q[77],q[0];
cp(0) q[76],q[0];
cp(0) q[75],q[0];
cp(0) q[74],q[0];
cp(0) q[73],q[0];
cp(0) q[72],q[0];
cp(0) q[71],q[0];
cp(0) q[70],q[0];
cp(0) q[69],q[0];
cp(0) q[68],q[0];
cp(0) q[67],q[0];
cp(0) q[66],q[0];
cp(0) q[65],q[0];
cp(0) q[64],q[0];
cp(0) q[63],q[0];
cp(0) q[62],q[0];
cp(0) q[61],q[0];
cp(0) q[60],q[0];
cp(0) q[59],q[0];
cp(0) q[58],q[0];
cp(0) q[57],q[0];
cp(0) q[56],q[0];
cp(0) q[55],q[0];
cp(0) q[54],q[0];
cp(0) q[53],q[0];
cp(0) q[52],q[0];
cp(0) q[51],q[0];
cp(0) q[50],q[0];
cp(0) q[49],q[0];
cp(0) q[48],q[0];
cp(0) q[47],q[0];
cp(0) q[46],q[0];
cp(0) q[45],q[0];
cp(0) q[44],q[0];
cp(0) q[43],q[0];
cp(0) q[42],q[0];
cp(pi/2199023255552) q[41],q[0];
cp(pi/1099511627776) q[40],q[0];
cp(pi/549755813888) q[39],q[0];
cp(pi/274877906944) q[38],q[0];
cp(pi/137438953472) q[37],q[0];
cp(pi/68719476736) q[36],q[0];
cp(pi/34359738368) q[35],q[0];
cp(pi/17179869184) q[34],q[0];
cp(pi/8589934592) q[33],q[0];
cp(pi/4294967296) q[32],q[0];
cp(pi/2147483648) q[31],q[0];
cp(pi/1073741824) q[30],q[0];
cp(pi/536870912) q[29],q[0];
cp(pi/268435456) q[28],q[0];
cp(pi/134217728) q[27],q[0];
cp(pi/67108864) q[26],q[0];
cp(pi/33554432) q[25],q[0];
cp(pi/16777216) q[24],q[0];
cp(pi/8388608) q[23],q[0];
cp(pi/4194304) q[22],q[0];
cp(pi/2097152) q[21],q[0];
cp(pi/1048576) q[20],q[0];
cp(pi/524288) q[19],q[0];
cp(pi/262144) q[18],q[0];
cp(pi/131072) q[17],q[0];
cp(pi/65536) q[16],q[0];
cp(pi/32768) q[15],q[0];
cp(pi/16384) q[14],q[0];
cp(pi/8192) q[13],q[0];
cp(pi/4096) q[12],q[0];
cp(pi/2048) q[11],q[0];
cp(pi/1024) q[10],q[0];
swap q[10],q[69];
swap q[11],q[68];
swap q[12],q[67];
swap q[13],q[66];
swap q[14],q[65];
swap q[15],q[64];
swap q[16],q[63];
swap q[17],q[62];
swap q[18],q[61];
swap q[19],q[60];
swap q[20],q[59];
swap q[21],q[58];
swap q[22],q[57];
swap q[23],q[56];
swap q[24],q[55];
swap q[25],q[54];
swap q[26],q[53];
swap q[27],q[52];
swap q[28],q[51];
swap q[29],q[50];
swap q[30],q[49];
swap q[31],q[48];
swap q[32],q[47];
swap q[33],q[46];
swap q[34],q[45];
swap q[35],q[44];
swap q[36],q[43];
swap q[37],q[42];
swap q[38],q[41];
swap q[39],q[40];
h q[9];
cp(pi/2) q[9],q[8];
h q[8];
cp(pi/4) q[9],q[7];
cp(pi/2) q[8],q[7];
h q[7];
cp(pi/8) q[9],q[6];
cp(pi/4) q[8],q[6];
cp(pi/2) q[7],q[6];
h q[6];
cp(pi/16) q[9],q[5];
cp(pi/8) q[8],q[5];
cp(pi/4) q[7],q[5];
cp(pi/2) q[6],q[5];
h q[5];
cp(pi/32) q[9],q[4];
cp(pi/16) q[8],q[4];
cp(pi/8) q[7],q[4];
cp(pi/4) q[6],q[4];
cp(pi/2) q[5],q[4];
h q[4];
cp(pi/64) q[9],q[3];
cp(pi/32) q[8],q[3];
cp(pi/16) q[7],q[3];
cp(pi/8) q[6],q[3];
cp(pi/4) q[5],q[3];
cp(pi/2) q[4],q[3];
h q[3];
cp(pi/128) q[9],q[2];
cp(pi/64) q[8],q[2];
cp(pi/32) q[7],q[2];
cp(pi/16) q[6],q[2];
cp(pi/8) q[5],q[2];
cp(pi/4) q[4],q[2];
cp(pi/2) q[3],q[2];
h q[2];
cp(pi/256) q[9],q[1];
cp(pi/128) q[8],q[1];
cp(pi/64) q[7],q[1];
cp(pi/32) q[6],q[1];
cp(pi/16) q[5],q[1];
cp(pi/8) q[4],q[1];
cp(pi/4) q[3],q[1];
cp(pi/2) q[2],q[1];
h q[1];
cp(pi/512) q[9],q[0];
cp(pi/256) q[8],q[0];
cp(pi/128) q[7],q[0];
cp(pi/64) q[6],q[0];
cp(pi/32) q[5],q[0];
cp(pi/16) q[4],q[0];
cp(pi/8) q[3],q[0];
cp(pi/4) q[2],q[0];
cp(pi/2) q[1],q[0];
h q[0];
swap q[0],q[79];
swap q[1],q[78];
swap q[2],q[77];
swap q[3],q[76];
swap q[4],q[75];
swap q[5],q[74];
swap q[6],q[73];
swap q[7],q[72];
swap q[8],q[71];
swap q[9],q[70];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];
measure q[66] -> meas[66];
measure q[67] -> meas[67];
measure q[68] -> meas[68];
measure q[69] -> meas[69];
measure q[70] -> meas[70];
measure q[71] -> meas[71];
measure q[72] -> meas[72];
measure q[73] -> meas[73];
measure q[74] -> meas[74];
measure q[75] -> meas[75];
measure q[76] -> meas[76];
measure q[77] -> meas[77];
measure q[78] -> meas[78];
measure q[79] -> meas[79];

'''

# %%
benchmarks['ising-98'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q[98];
creg c[98];
creg meas[98];
h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
h q[8];
h q[9];
h q[10];
h q[11];
h q[12];
h q[13];
h q[14];
h q[15];
h q[16];
h q[17];
h q[18];
h q[19];
h q[20];
h q[21];
h q[22];
h q[23];
h q[24];
h q[25];
h q[26];
h q[27];
h q[28];
h q[29];
h q[30];
h q[31];
h q[32];
h q[33];
h q[34];
h q[35];
h q[36];
h q[37];
h q[38];
h q[39];
h q[40];
h q[41];
h q[42];
h q[43];
h q[44];
h q[45];
h q[46];
h q[47];
h q[48];
h q[49];
h q[50];
h q[51];
h q[52];
h q[53];
h q[54];
h q[55];
h q[56];
h q[57];
h q[58];
h q[59];
h q[60];
h q[61];
h q[62];
h q[63];
h q[64];
h q[65];
h q[66];
h q[67];
h q[68];
h q[69];
h q[70];
h q[71];
h q[72];
h q[73];
h q[74];
h q[75];
h q[76];
h q[77];
h q[78];
h q[79];
h q[80];
h q[81];
h q[82];
h q[83];
h q[84];
h q[85];
h q[86];
h q[87];
h q[88];
h q[89];
h q[90];
h q[91];
h q[92];
h q[93];
h q[94];
h q[95];
h q[96];
h q[97];
rz(-0.10547849) q[0];
rz(0.10547849) q[1];
rz(0.10547849) q[1];
cx q[0],q[1];
rz(-0.10547849) q[1];
cx q[0],q[1];
rz(-0.32112909) q[2];
rz(0.32112909) q[3];
rz(0.32112909) q[3];
cx q[2],q[3];
rz(-0.32112909) q[3];
cx q[2],q[3];
rz(1.2551978) q[4];
rz(-1.2551978) q[5];
rz(-1.2551978) q[5];
cx q[4],q[5];
rz(1.2551978) q[5];
cx q[4],q[5];
rz(0.83274755) q[6];
rz(-0.83274755) q[7];
rz(-0.83274755) q[7];
cx q[6],q[7];
rz(0.83274755) q[7];
cx q[6],q[7];
rz(-0.51687854) q[8];
rz(0.51687854) q[9];
rz(0.51687854) q[9];
cx q[8],q[9];
rz(-0.51687854) q[9];
cx q[8],q[9];
rz(-1.6689561) q[10];
rz(1.6689561) q[11];
rz(1.6689561) q[11];
cx q[10],q[11];
rz(-1.6689561) q[11];
cx q[10],q[11];
rz(-0.87783496) q[12];
rz(0.87783496) q[13];
rz(0.87783496) q[13];
cx q[12],q[13];
rz(-0.87783496) q[13];
cx q[12],q[13];
rz(1.7917125) q[14];
rz(-1.7917125) q[15];
rz(-1.7917125) q[15];
cx q[14],q[15];
rz(1.7917125) q[15];
cx q[14],q[15];
rz(0.85318811) q[16];
rz(-0.85318811) q[17];
rz(-0.85318811) q[17];
cx q[16],q[17];
rz(0.85318811) q[17];
cx q[16],q[17];
rz(1.1007048) q[18];
rz(-1.1007048) q[19];
rz(-1.1007048) q[19];
cx q[18],q[19];
rz(1.1007048) q[19];
cx q[18],q[19];
rz(1.2374139) q[20];
rz(-1.2374139) q[21];
rz(-1.2374139) q[21];
cx q[20],q[21];
rz(1.2374139) q[21];
cx q[20],q[21];
rz(0.86900691) q[22];
rz(-0.86900691) q[23];
rz(-0.86900691) q[23];
cx q[22],q[23];
rz(0.86900691) q[23];
cx q[22],q[23];
rz(-0.075544295) q[24];
rz(0.075544295) q[25];
rz(0.075544295) q[25];
cx q[24],q[25];
rz(-0.075544295) q[25];
cx q[24],q[25];
rz(1.9666965) q[26];
rz(-1.9666965) q[27];
rz(-1.9666965) q[27];
cx q[26],q[27];
rz(1.9666965) q[27];
cx q[26],q[27];
rz(-0.8932567) q[28];
rz(0.8932567) q[29];
rz(0.8932567) q[29];
cx q[28],q[29];
rz(-0.8932567) q[29];
cx q[28],q[29];
rz(1.0753497) q[30];
rz(-1.0753497) q[31];
rz(-1.0753497) q[31];
cx q[30],q[31];
rz(1.0753497) q[31];
cx q[30],q[31];
rz(-0.23544851) q[32];
rz(0.23544851) q[33];
rz(0.23544851) q[33];
cx q[32],q[33];
rz(-0.23544851) q[33];
cx q[32],q[33];
rz(-0.12767731) q[34];
rz(0.12767731) q[35];
rz(0.12767731) q[35];
cx q[34],q[35];
rz(-0.12767731) q[35];
cx q[34],q[35];
rz(-0.30930673) q[36];
rz(0.30930673) q[37];
rz(0.30930673) q[37];
cx q[36],q[37];
rz(-0.30930673) q[37];
cx q[36],q[37];
rz(0.70850212) q[38];
rz(-0.70850212) q[39];
rz(-0.70850212) q[39];
cx q[38],q[39];
rz(0.70850212) q[39];
cx q[38],q[39];
rz(0.38802256) q[40];
rz(-0.38802256) q[41];
rz(-0.38802256) q[41];
cx q[40],q[41];
rz(0.38802256) q[41];
cx q[40],q[41];
rz(1.4663664) q[42];
rz(-1.4663664) q[43];
rz(-1.4663664) q[43];
cx q[42],q[43];
rz(1.4663664) q[43];
cx q[42],q[43];
rz(-0.48835821) q[44];
rz(0.48835821) q[45];
rz(0.48835821) q[45];
cx q[44],q[45];
rz(-0.48835821) q[45];
cx q[44],q[45];
rz(-0.98827906) q[46];
rz(0.98827906) q[47];
rz(0.98827906) q[47];
cx q[46],q[47];
rz(-0.98827906) q[47];
cx q[46],q[47];
rz(-0.34934642) q[48];
rz(0.34934642) q[49];
rz(0.34934642) q[49];
cx q[48],q[49];
rz(-0.34934642) q[49];
cx q[48],q[49];
rz(1.0319207) q[50];
rz(-1.0319207) q[51];
rz(-1.0319207) q[51];
cx q[50],q[51];
rz(1.0319207) q[51];
cx q[50],q[51];
rz(1.9122996) q[52];
rz(-1.9122996) q[53];
rz(-1.9122996) q[53];
cx q[52],q[53];
rz(1.9122996) q[53];
cx q[52],q[53];
rz(1.9124291) q[54];
rz(-1.9124291) q[55];
rz(-1.9124291) q[55];
cx q[54],q[55];
rz(1.9124291) q[55];
cx q[54],q[55];
rz(-1.935039) q[56];
rz(1.935039) q[57];
rz(1.935039) q[57];
cx q[56],q[57];
rz(-1.935039) q[57];
cx q[56],q[57];
rz(1.3289371) q[58];
rz(-1.3289371) q[59];
rz(-1.3289371) q[59];
cx q[58],q[59];
rz(1.3289371) q[59];
cx q[58],q[59];
rz(0.94895207) q[60];
rz(-0.94895207) q[61];
rz(-0.94895207) q[61];
cx q[60],q[61];
rz(0.94895207) q[61];
cx q[60],q[61];
rz(0.59986361) q[62];
rz(-0.59986361) q[63];
rz(-0.59986361) q[63];
cx q[62],q[63];
rz(0.59986361) q[63];
cx q[62],q[63];
rz(-0.19204913) q[64];
rz(0.19204913) q[65];
rz(0.19204913) q[65];
cx q[64],q[65];
rz(-0.19204913) q[65];
cx q[64],q[65];
rz(0.65661787) q[66];
rz(-0.65661787) q[67];
rz(-0.65661787) q[67];
cx q[66],q[67];
rz(0.65661787) q[67];
cx q[66],q[67];
rz(1.6385177) q[68];
rz(-1.6385177) q[69];
rz(-1.6385177) q[69];
cx q[68],q[69];
rz(1.6385177) q[69];
cx q[68],q[69];
rz(-1.7755501) q[70];
rz(1.7755501) q[71];
rz(1.7755501) q[71];
cx q[70],q[71];
rz(-1.7755501) q[71];
cx q[70],q[71];
rz(0.17121033) q[72];
rz(-0.17121033) q[73];
rz(-0.17121033) q[73];
cx q[72],q[73];
rz(0.17121033) q[73];
cx q[72],q[73];
rz(0.42230428) q[74];
rz(-0.42230428) q[75];
rz(-0.42230428) q[75];
cx q[74],q[75];
rz(0.42230428) q[75];
cx q[74],q[75];
rz(1.8346869) q[76];
rz(-1.8346869) q[77];
rz(-1.8346869) q[77];
cx q[76],q[77];
rz(1.8346869) q[77];
cx q[76],q[77];
rz(0.4499326) q[78];
rz(-0.4499326) q[79];
rz(-0.4499326) q[79];
cx q[78],q[79];
rz(0.4499326) q[79];
cx q[78],q[79];
rz(1.5614571) q[80];
rz(-1.5614571) q[81];
rz(-1.5614571) q[81];
cx q[80],q[81];
rz(1.5614571) q[81];
cx q[80],q[81];
rz(1.5218396) q[82];
rz(-1.5218396) q[83];
rz(-1.5218396) q[83];
cx q[82],q[83];
rz(1.5218396) q[83];
cx q[82],q[83];
rz(1.4987176) q[84];
rz(-1.4987176) q[85];
rz(-1.4987176) q[85];
cx q[84],q[85];
rz(1.4987176) q[85];
cx q[84],q[85];
rz(-0.59128614) q[86];
rz(0.59128614) q[87];
rz(0.59128614) q[87];
cx q[86],q[87];
rz(-0.59128614) q[87];
cx q[86],q[87];
rz(-1.363435) q[88];
rz(1.363435) q[89];
rz(1.363435) q[89];
cx q[88],q[89];
rz(-1.363435) q[89];
cx q[88],q[89];
rz(-1.6723291) q[90];
rz(1.6723291) q[91];
rz(1.6723291) q[91];
cx q[90],q[91];
rz(-1.6723291) q[91];
cx q[90],q[91];
rz(-0.79271136) q[92];
rz(0.79271136) q[93];
rz(0.79271136) q[93];
cx q[92],q[93];
rz(-0.79271136) q[93];
cx q[92],q[93];
rz(-0.78315718) q[94];
rz(0.78315718) q[95];
rz(0.78315718) q[95];
cx q[94],q[95];
rz(-0.78315718) q[95];
cx q[94],q[95];
rz(-0.35141842) q[96];
rz(0.35141842) q[97];
rz(0.35141842) q[97];
cx q[96],q[97];
rz(-0.35141842) q[97];
cx q[96],q[97];
rz(-0.3166508) q[1];
rz(0.3166508) q[2];
rz(0.3166508) q[2];
cx q[1],q[2];
rz(-0.3166508) q[2];
cx q[1],q[2];
rz(1.6679692) q[3];
rz(-1.6679692) q[4];
rz(-1.6679692) q[4];
cx q[3],q[4];
rz(1.6679692) q[4];
cx q[3],q[4];
rz(0.94889695) q[5];
rz(-0.94889695) q[6];
rz(-0.94889695) q[6];
cx q[5],q[6];
rz(0.94889695) q[6];
cx q[5],q[6];
rz(1.3389506) q[7];
rz(-1.3389506) q[8];
rz(-1.3389506) q[8];
cx q[7],q[8];
rz(1.3389506) q[8];
cx q[7],q[8];
rz(0.42250814) q[9];
rz(-0.42250814) q[10];
rz(-0.42250814) q[10];
cx q[9],q[10];
rz(0.42250814) q[10];
cx q[9],q[10];
rz(-0.16700096) q[11];
rz(0.16700096) q[12];
rz(0.16700096) q[12];
cx q[11],q[12];
rz(-0.16700096) q[12];
cx q[11],q[12];
rz(1.3028807) q[13];
rz(-1.3028807) q[14];
rz(-1.3028807) q[14];
cx q[13],q[14];
rz(1.3028807) q[14];
cx q[13],q[14];
rz(-1.8720307) q[15];
rz(1.8720307) q[16];
rz(1.8720307) q[16];
cx q[15],q[16];
rz(-1.8720307) q[16];
cx q[15],q[16];
rz(-1.1861875) q[17];
rz(1.1861875) q[18];
rz(1.1861875) q[18];
cx q[17],q[18];
rz(-1.1861875) q[18];
cx q[17],q[18];
rz(-0.11663793) q[19];
rz(0.11663793) q[20];
rz(0.11663793) q[20];
cx q[19],q[20];
rz(-0.11663793) q[20];
cx q[19],q[20];
rz(1.7434165) q[21];
rz(-1.7434165) q[22];
rz(-1.7434165) q[22];
cx q[21],q[22];
rz(1.7434165) q[22];
cx q[21],q[22];
rz(1.9586679) q[23];
rz(-1.9586679) q[24];
rz(-1.9586679) q[24];
cx q[23],q[24];
rz(1.9586679) q[24];
cx q[23],q[24];
rz(-0.91863643) q[25];
rz(0.91863643) q[26];
rz(0.91863643) q[26];
cx q[25],q[26];
rz(-0.91863643) q[26];
cx q[25],q[26];
rz(-1.378703) q[27];
rz(1.378703) q[28];
rz(1.378703) q[28];
cx q[27],q[28];
rz(-1.378703) q[28];
cx q[27],q[28];
rz(1.2285706) q[29];
rz(-1.2285706) q[30];
rz(-1.2285706) q[30];
cx q[29],q[30];
rz(1.2285706) q[30];
cx q[29],q[30];
rz(0.28670827) q[31];
rz(-0.28670827) q[32];
rz(-0.28670827) q[32];
cx q[31],q[32];
rz(0.28670827) q[32];
cx q[31],q[32];
rz(0.19762375) q[33];
rz(-0.19762375) q[34];
rz(-0.19762375) q[34];
cx q[33],q[34];
rz(0.19762375) q[34];
cx q[33],q[34];
rz(-0.20921184) q[35];
rz(0.20921184) q[36];
rz(0.20921184) q[36];
cx q[35],q[36];
rz(-0.20921184) q[36];
cx q[35],q[36];
rz(0.018508709) q[37];
rz(-0.018508709) q[38];
rz(-0.018508709) q[38];
cx q[37],q[38];
rz(0.018508709) q[38];
cx q[37],q[38];
rz(-0.35743569) q[39];
rz(0.35743569) q[40];
rz(0.35743569) q[40];
cx q[39],q[40];
rz(-0.35743569) q[40];
cx q[39],q[40];
rz(0.78440702) q[41];
rz(-0.78440702) q[42];
rz(-0.78440702) q[42];
cx q[41],q[42];
rz(0.78440702) q[42];
cx q[41],q[42];
rz(1.9154828) q[43];
rz(-1.9154828) q[44];
rz(-1.9154828) q[44];
cx q[43],q[44];
rz(1.9154828) q[44];
cx q[43],q[44];
rz(1.0147279) q[45];
rz(-1.0147279) q[46];
rz(-1.0147279) q[46];
cx q[45],q[46];
rz(1.0147279) q[46];
cx q[45],q[46];
rz(0.37307477) q[47];
rz(-0.37307477) q[48];
rz(-0.37307477) q[48];
cx q[47],q[48];
rz(0.37307477) q[48];
cx q[47],q[48];
rz(1.8344785) q[49];
rz(-1.8344785) q[50];
rz(-1.8344785) q[50];
cx q[49],q[50];
rz(1.8344785) q[50];
cx q[49],q[50];
rz(-1.9106685) q[51];
rz(1.9106685) q[52];
rz(1.9106685) q[52];
cx q[51],q[52];
rz(-1.9106685) q[52];
cx q[51],q[52];
rz(1.3210816) q[53];
rz(-1.3210816) q[54];
rz(-1.3210816) q[54];
cx q[53],q[54];
rz(1.3210816) q[54];
cx q[53],q[54];
rz(-0.7303086) q[55];
rz(0.7303086) q[56];
rz(0.7303086) q[56];
cx q[55],q[56];
rz(-0.7303086) q[56];
cx q[55],q[56];
rz(0.33347611) q[57];
rz(-0.33347611) q[58];
rz(-0.33347611) q[58];
cx q[57],q[58];
rz(0.33347611) q[58];
cx q[57],q[58];
rz(-1.6503585) q[59];
rz(1.6503585) q[60];
rz(1.6503585) q[60];
cx q[59],q[60];
rz(-1.6503585) q[60];
cx q[59],q[60];
rz(-1.3871256) q[61];
rz(1.3871256) q[62];
rz(1.3871256) q[62];
cx q[61],q[62];
rz(-1.3871256) q[62];
cx q[61],q[62];
rz(1.7412821) q[63];
rz(-1.7412821) q[64];
rz(-1.7412821) q[64];
cx q[63],q[64];
rz(1.7412821) q[64];
cx q[63],q[64];
rz(1.3090213) q[65];
rz(-1.3090213) q[66];
rz(-1.3090213) q[66];
cx q[65],q[66];
rz(1.3090213) q[66];
cx q[65],q[66];
rz(-0.25871319) q[67];
rz(0.25871319) q[68];
rz(0.25871319) q[68];
cx q[67],q[68];
rz(-0.25871319) q[68];
cx q[67],q[68];
rz(-0.80006361) q[69];
rz(0.80006361) q[70];
rz(0.80006361) q[70];
cx q[69],q[70];
rz(-0.80006361) q[70];
cx q[69],q[70];
rz(-0.11523599) q[71];
rz(0.11523599) q[72];
rz(0.11523599) q[72];
cx q[71],q[72];
rz(-0.11523599) q[72];
cx q[71],q[72];
rz(0.17468742) q[73];
rz(-0.17468742) q[74];
rz(-0.17468742) q[74];
cx q[73],q[74];
rz(0.17468742) q[74];
cx q[73],q[74];
rz(1.0842291) q[75];
rz(-1.0842291) q[76];
rz(-1.0842291) q[76];
cx q[75],q[76];
rz(1.0842291) q[76];
cx q[75],q[76];
rz(-1.6278165) q[77];
rz(1.6278165) q[78];
rz(1.6278165) q[78];
cx q[77],q[78];
rz(-1.6278165) q[78];
cx q[77],q[78];
rz(1.7280133) q[79];
rz(-1.7280133) q[80];
rz(-1.7280133) q[80];
cx q[79],q[80];
rz(1.7280133) q[80];
cx q[79],q[80];
rz(-1.1939662) q[81];
rz(1.1939662) q[82];
rz(1.1939662) q[82];
cx q[81],q[82];
rz(-1.1939662) q[82];
cx q[81],q[82];
rz(1.4127416) q[83];
rz(-1.4127416) q[84];
rz(-1.4127416) q[84];
cx q[83],q[84];
rz(1.4127416) q[84];
cx q[83],q[84];
rz(0.56706812) q[85];
rz(-0.56706812) q[86];
rz(-0.56706812) q[86];
cx q[85],q[86];
rz(0.56706812) q[86];
cx q[85],q[86];
rz(1.1411538) q[87];
rz(-1.1411538) q[88];
rz(-1.1411538) q[88];
cx q[87],q[88];
rz(1.1411538) q[88];
cx q[87],q[88];
rz(-1.2546659) q[89];
rz(1.2546659) q[90];
rz(1.2546659) q[90];
cx q[89],q[90];
rz(-1.2546659) q[90];
cx q[89],q[90];
rz(0.61837496) q[91];
rz(-0.61837496) q[92];
rz(-0.61837496) q[92];
cx q[91],q[92];
rz(0.61837496) q[92];
cx q[91],q[92];
rz(-0.47237304) q[93];
rz(0.47237304) q[94];
rz(0.47237304) q[94];
cx q[93],q[94];
rz(-0.47237304) q[94];
cx q[93],q[94];
rz(-0.88586084) q[95];
rz(0.88586084) q[96];
rz(0.88586084) q[96];
cx q[95],q[96];
rz(-0.88586084) q[96];
cx q[95],q[96];
h q[0];
rz(0) q[0];
h q[0];
rz(0) q[0];
h q[1];
rz(0) q[1];
h q[1];
rz(0) q[1];
h q[2];
rz(0) q[2];
h q[2];
rz(0) q[2];
h q[3];
rz(0) q[3];
h q[3];
rz(0) q[3];
h q[4];
rz(0) q[4];
h q[4];
rz(0) q[4];
h q[5];
rz(0) q[5];
h q[5];
rz(0) q[5];
h q[6];
rz(0) q[6];
h q[6];
rz(0) q[6];
h q[7];
rz(0) q[7];
h q[7];
rz(0) q[7];
h q[8];
rz(0) q[8];
h q[8];
rz(0) q[8];
h q[9];
rz(0) q[9];
h q[9];
rz(0) q[9];
h q[10];
rz(0) q[10];
h q[10];
rz(0) q[10];
h q[11];
rz(0) q[11];
h q[11];
rz(0) q[11];
h q[12];
rz(0) q[12];
h q[12];
rz(0) q[12];
h q[13];
rz(0) q[13];
h q[13];
rz(0) q[13];
h q[14];
rz(0) q[14];
h q[14];
rz(0) q[14];
h q[15];
rz(0) q[15];
h q[15];
rz(0) q[15];
h q[16];
rz(0) q[16];
h q[16];
rz(0) q[16];
h q[17];
rz(0) q[17];
h q[17];
rz(0) q[17];
h q[18];
rz(0) q[18];
h q[18];
rz(0) q[18];
h q[19];
rz(0) q[19];
h q[19];
rz(0) q[19];
h q[20];
rz(0) q[20];
h q[20];
rz(0) q[20];
h q[21];
rz(0) q[21];
h q[21];
rz(0) q[21];
h q[22];
rz(0) q[22];
h q[22];
rz(0) q[22];
h q[23];
rz(0) q[23];
h q[23];
rz(0) q[23];
h q[24];
rz(0) q[24];
h q[24];
rz(0) q[24];
h q[25];
rz(0) q[25];
h q[25];
rz(0) q[25];
h q[26];
rz(0) q[26];
h q[26];
rz(0) q[26];
h q[27];
rz(0) q[27];
h q[27];
rz(0) q[27];
h q[28];
rz(0) q[28];
h q[28];
rz(0) q[28];
h q[29];
rz(0) q[29];
h q[29];
rz(0) q[29];
h q[30];
rz(0) q[30];
h q[30];
rz(0) q[30];
h q[31];
rz(0) q[31];
h q[31];
rz(0) q[31];
h q[32];
rz(0) q[32];
h q[32];
rz(0) q[32];
h q[33];
rz(0) q[33];
h q[33];
rz(0) q[33];
h q[34];
rz(0) q[34];
h q[34];
rz(0) q[34];
h q[35];
rz(0) q[35];
h q[35];
rz(0) q[35];
h q[36];
rz(0) q[36];
h q[36];
rz(0) q[36];
h q[37];
rz(0) q[37];
h q[37];
rz(0) q[37];
h q[38];
rz(0) q[38];
h q[38];
rz(0) q[38];
h q[39];
rz(0) q[39];
h q[39];
rz(0) q[39];
h q[40];
rz(0) q[40];
h q[40];
rz(0) q[40];
h q[41];
rz(0) q[41];
h q[41];
rz(0) q[41];
h q[42];
rz(0) q[42];
h q[42];
rz(0) q[42];
h q[43];
rz(0) q[43];
h q[43];
rz(0) q[43];
h q[44];
rz(0) q[44];
h q[44];
rz(0) q[44];
h q[45];
rz(0) q[45];
h q[45];
rz(0) q[45];
h q[46];
rz(0) q[46];
h q[46];
rz(0) q[46];
h q[47];
rz(0) q[47];
h q[47];
rz(0) q[47];
h q[48];
rz(0) q[48];
h q[48];
rz(0) q[48];
h q[49];
rz(0) q[49];
h q[49];
rz(0) q[49];
h q[50];
rz(0) q[50];
h q[50];
rz(0) q[50];
h q[51];
rz(0) q[51];
h q[51];
rz(0) q[51];
h q[52];
rz(0) q[52];
h q[52];
rz(0) q[52];
h q[53];
rz(0) q[53];
h q[53];
rz(0) q[53];
h q[54];
rz(0) q[54];
h q[54];
rz(0) q[54];
h q[55];
rz(0) q[55];
h q[55];
rz(0) q[55];
h q[56];
rz(0) q[56];
h q[56];
rz(0) q[56];
h q[57];
rz(0) q[57];
h q[57];
rz(0) q[57];
h q[58];
rz(0) q[58];
h q[58];
rz(0) q[58];
h q[59];
rz(0) q[59];
h q[59];
rz(0) q[59];
h q[60];
rz(0) q[60];
h q[60];
rz(0) q[60];
h q[61];
rz(0) q[61];
h q[61];
rz(0) q[61];
h q[62];
rz(0) q[62];
h q[62];
rz(0) q[62];
h q[63];
rz(0) q[63];
h q[63];
rz(0) q[63];
h q[64];
rz(0) q[64];
h q[64];
rz(0) q[64];
h q[65];
rz(0) q[65];
h q[65];
rz(0) q[65];
h q[66];
rz(0) q[66];
h q[66];
rz(0) q[66];
h q[67];
rz(0) q[67];
h q[67];
rz(0) q[67];
h q[68];
rz(0) q[68];
h q[68];
rz(0) q[68];
h q[69];
rz(0) q[69];
h q[69];
rz(0) q[69];
h q[70];
rz(0) q[70];
h q[70];
rz(0) q[70];
h q[71];
rz(0) q[71];
h q[71];
rz(0) q[71];
h q[72];
rz(0) q[72];
h q[72];
rz(0) q[72];
h q[73];
rz(0) q[73];
h q[73];
rz(0) q[73];
h q[74];
rz(0) q[74];
h q[74];
rz(0) q[74];
h q[75];
rz(0) q[75];
h q[75];
rz(0) q[75];
h q[76];
rz(0) q[76];
h q[76];
rz(0) q[76];
h q[77];
rz(0) q[77];
h q[77];
rz(0) q[77];
h q[78];
rz(0) q[78];
h q[78];
rz(0) q[78];
h q[79];
rz(0) q[79];
h q[79];
rz(0) q[79];
h q[80];
rz(0) q[80];
h q[80];
rz(0) q[80];
h q[81];
rz(0) q[81];
h q[81];
rz(0) q[81];
h q[82];
rz(0) q[82];
h q[82];
rz(0) q[82];
h q[83];
rz(0) q[83];
h q[83];
rz(0) q[83];
h q[84];
rz(0) q[84];
h q[84];
rz(0) q[84];
h q[85];
rz(0) q[85];
h q[85];
rz(0) q[85];
h q[86];
rz(0) q[86];
h q[86];
rz(0) q[86];
h q[87];
rz(0) q[87];
h q[87];
rz(0) q[87];
h q[88];
rz(0) q[88];
h q[88];
rz(0) q[88];
h q[89];
rz(0) q[89];
h q[89];
rz(0) q[89];
h q[90];
rz(0) q[90];
h q[90];
rz(0) q[90];
h q[91];
rz(0) q[91];
h q[91];
rz(0) q[91];
h q[92];
rz(0) q[92];
h q[92];
rz(0) q[92];
h q[93];
rz(0) q[93];
h q[93];
rz(0) q[93];
h q[94];
rz(0) q[94];
h q[94];
rz(0) q[94];
h q[95];
rz(0) q[95];
h q[95];
rz(0) q[95];
h q[96];
rz(0) q[96];
h q[96];
rz(0) q[96];
h q[97];
rz(0) q[97];
h q[97];
rz(0) q[97];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79],q[80],q[81],q[82],q[83],q[84],q[85],q[86],q[87],q[88],q[89],q[90],q[91],q[92],q[93],q[94],q[95],q[96],q[97];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];
measure q[66] -> meas[66];
measure q[67] -> meas[67];
measure q[68] -> meas[68];
measure q[69] -> meas[69];
measure q[70] -> meas[70];
measure q[71] -> meas[71];
measure q[72] -> meas[72];
measure q[73] -> meas[73];
measure q[74] -> meas[74];
measure q[75] -> meas[75];
measure q[76] -> meas[76];
measure q[77] -> meas[77];
measure q[78] -> meas[78];
measure q[79] -> meas[79];
measure q[80] -> meas[80];
measure q[81] -> meas[81];
measure q[82] -> meas[82];
measure q[83] -> meas[83];
measure q[84] -> meas[84];
measure q[85] -> meas[85];
measure q[86] -> meas[86];
measure q[87] -> meas[87];
measure q[88] -> meas[88];
measure q[89] -> meas[89];
measure q[90] -> meas[90];
measure q[91] -> meas[91];
measure q[92] -> meas[92];
measure q[93] -> meas[93];
measure q[94] -> meas[94];
measure q[95] -> meas[95];
measure q[96] -> meas[96];
measure q[97] -> meas[97];
'''

# %%
benchmarks['adder-118'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q[118];
creg c[118];
creg meas[118];
x q[1];
x q[2];
x q[3];
x q[4];
x q[5];
x q[6];
x q[7];
x q[8];
x q[9];
x q[10];
x q[11];
x q[12];
x q[13];
x q[14];
x q[15];
x q[16];
x q[17];
x q[18];
x q[19];
x q[20];
x q[21];
x q[22];
x q[23];
x q[24];
x q[25];
x q[26];
x q[27];
x q[28];
x q[29];
x q[30];
x q[31];
x q[32];
x q[33];
x q[34];
x q[35];
x q[36];
x q[37];
x q[38];
x q[39];
x q[40];
x q[41];
x q[42];
x q[43];
x q[44];
x q[45];
x q[46];
x q[47];
x q[48];
x q[49];
x q[50];
x q[51];
x q[52];
x q[104];
cx q[0],q[52];
cx q[0],q[104];
ccx q[104],q[52],q[0];
cx q[1],q[53];
cx q[1],q[0];
ccx q[0],q[53],q[1];
cx q[2],q[54];
cx q[2],q[1];
ccx q[1],q[54],q[2];
cx q[3],q[55];
cx q[3],q[2];
ccx q[2],q[55],q[3];
cx q[3],q[105];
ccx q[2],q[55],q[3];
cx q[3],q[2];
cx q[2],q[55];
ccx q[1],q[54],q[2];
cx q[2],q[1];
cx q[1],q[54];
ccx q[0],q[53],q[1];
cx q[1],q[0];
cx q[0],q[53];
ccx q[104],q[52],q[0];
cx q[0],q[104];
cx q[104],q[52];
cx q[4],q[56];
cx q[4],q[105];
ccx q[105],q[56],q[4];
cx q[5],q[57];
cx q[5],q[4];
ccx q[4],q[57],q[5];
cx q[6],q[58];
cx q[6],q[5];
ccx q[5],q[58],q[6];
cx q[7],q[59];
cx q[7],q[6];
ccx q[6],q[59],q[7];
cx q[7],q[106];
ccx q[6],q[59],q[7];
cx q[7],q[6];
cx q[6],q[59];
ccx q[5],q[58],q[6];
cx q[6],q[5];
cx q[5],q[58];
ccx q[4],q[57],q[5];
cx q[5],q[4];
cx q[4],q[57];
ccx q[105],q[56],q[4];
cx q[4],q[105];
cx q[105],q[56];
cx q[8],q[60];
cx q[8],q[106];
ccx q[106],q[60],q[8];
cx q[9],q[61];
cx q[9],q[8];
ccx q[8],q[61],q[9];
cx q[10],q[62];
cx q[10],q[9];
ccx q[9],q[62],q[10];
cx q[11],q[63];
cx q[11],q[10];
ccx q[10],q[63],q[11];
cx q[11],q[107];
ccx q[10],q[63],q[11];
cx q[11],q[10];
cx q[10],q[63];
ccx q[9],q[62],q[10];
cx q[10],q[9];
cx q[9],q[62];
ccx q[8],q[61],q[9];
cx q[9],q[8];
cx q[8],q[61];
ccx q[106],q[60],q[8];
cx q[8],q[106];
cx q[106],q[60];
cx q[12],q[64];
cx q[12],q[107];
ccx q[107],q[64],q[12];
cx q[13],q[65];
cx q[13],q[12];
ccx q[12],q[65],q[13];
cx q[14],q[66];
cx q[14],q[13];
ccx q[13],q[66],q[14];
cx q[15],q[67];
cx q[15],q[14];
ccx q[14],q[67],q[15];
cx q[15],q[108];
ccx q[14],q[67],q[15];
cx q[15],q[14];
cx q[14],q[67];
ccx q[13],q[66],q[14];
cx q[14],q[13];
cx q[13],q[66];
ccx q[12],q[65],q[13];
cx q[13],q[12];
cx q[12],q[65];
ccx q[107],q[64],q[12];
cx q[12],q[107];
cx q[107],q[64];
cx q[16],q[68];
cx q[16],q[108];
ccx q[108],q[68],q[16];
cx q[17],q[69];
cx q[17],q[16];
ccx q[16],q[69],q[17];
cx q[18],q[70];
cx q[18],q[17];
ccx q[17],q[70],q[18];
cx q[19],q[71];
cx q[19],q[18];
ccx q[18],q[71],q[19];
cx q[19],q[109];
ccx q[18],q[71],q[19];
cx q[19],q[18];
cx q[18],q[71];
ccx q[17],q[70],q[18];
cx q[18],q[17];
cx q[17],q[70];
ccx q[16],q[69],q[17];
cx q[17],q[16];
cx q[16],q[69];
ccx q[108],q[68],q[16];
cx q[16],q[108];
cx q[108],q[68];
cx q[20],q[72];
cx q[20],q[109];
ccx q[109],q[72],q[20];
cx q[21],q[73];
cx q[21],q[20];
ccx q[20],q[73],q[21];
cx q[22],q[74];
cx q[22],q[21];
ccx q[21],q[74],q[22];
cx q[23],q[75];
cx q[23],q[22];
ccx q[22],q[75],q[23];
cx q[23],q[110];
ccx q[22],q[75],q[23];
cx q[23],q[22];
cx q[22],q[75];
ccx q[21],q[74],q[22];
cx q[22],q[21];
cx q[21],q[74];
ccx q[20],q[73],q[21];
cx q[21],q[20];
cx q[20],q[73];
ccx q[109],q[72],q[20];
cx q[20],q[109];
cx q[109],q[72];
cx q[24],q[76];
cx q[24],q[110];
ccx q[110],q[76],q[24];
cx q[25],q[77];
cx q[25],q[24];
ccx q[24],q[77],q[25];
cx q[26],q[78];
cx q[26],q[25];
ccx q[25],q[78],q[26];
cx q[27],q[79];
cx q[27],q[26];
ccx q[26],q[79],q[27];
cx q[27],q[111];
ccx q[26],q[79],q[27];
cx q[27],q[26];
cx q[26],q[79];
ccx q[25],q[78],q[26];
cx q[26],q[25];
cx q[25],q[78];
ccx q[24],q[77],q[25];
cx q[25],q[24];
cx q[24],q[77];
ccx q[110],q[76],q[24];
cx q[24],q[110];
cx q[110],q[76];
cx q[28],q[80];
cx q[28],q[111];
ccx q[111],q[80],q[28];
cx q[29],q[81];
cx q[29],q[28];
ccx q[28],q[81],q[29];
cx q[30],q[82];
cx q[30],q[29];
ccx q[29],q[82],q[30];
cx q[31],q[83];
cx q[31],q[30];
ccx q[30],q[83],q[31];
cx q[31],q[112];
ccx q[30],q[83],q[31];
cx q[31],q[30];
cx q[30],q[83];
ccx q[29],q[82],q[30];
cx q[30],q[29];
cx q[29],q[82];
ccx q[28],q[81],q[29];
cx q[29],q[28];
cx q[28],q[81];
ccx q[111],q[80],q[28];
cx q[28],q[111];
cx q[111],q[80];
cx q[32],q[84];
cx q[32],q[112];
ccx q[112],q[84],q[32];
cx q[33],q[85];
cx q[33],q[32];
ccx q[32],q[85],q[33];
cx q[34],q[86];
cx q[34],q[33];
ccx q[33],q[86],q[34];
cx q[35],q[87];
cx q[35],q[34];
ccx q[34],q[87],q[35];
cx q[35],q[113];
ccx q[34],q[87],q[35];
cx q[35],q[34];
cx q[34],q[87];
ccx q[33],q[86],q[34];
cx q[34],q[33];
cx q[33],q[86];
ccx q[32],q[85],q[33];
cx q[33],q[32];
cx q[32],q[85];
ccx q[112],q[84],q[32];
cx q[32],q[112];
cx q[112],q[84];
cx q[36],q[88];
cx q[36],q[113];
ccx q[113],q[88],q[36];
cx q[37],q[89];
cx q[37],q[36];
ccx q[36],q[89],q[37];
cx q[38],q[90];
cx q[38],q[37];
ccx q[37],q[90],q[38];
cx q[39],q[91];
cx q[39],q[38];
ccx q[38],q[91],q[39];
cx q[39],q[114];
ccx q[38],q[91],q[39];
cx q[39],q[38];
cx q[38],q[91];
ccx q[37],q[90],q[38];
cx q[38],q[37];
cx q[37],q[90];
ccx q[36],q[89],q[37];
cx q[37],q[36];
cx q[36],q[89];
ccx q[113],q[88],q[36];
cx q[36],q[113];
cx q[113],q[88];
cx q[40],q[92];
cx q[40],q[114];
ccx q[114],q[92],q[40];
cx q[41],q[93];
cx q[41],q[40];
ccx q[40],q[93],q[41];
cx q[42],q[94];
cx q[42],q[41];
ccx q[41],q[94],q[42];
cx q[43],q[95];
cx q[43],q[42];
ccx q[42],q[95],q[43];
cx q[43],q[115];
ccx q[42],q[95],q[43];
cx q[43],q[42];
cx q[42],q[95];
ccx q[41],q[94],q[42];
cx q[42],q[41];
cx q[41],q[94];
ccx q[40],q[93],q[41];
cx q[41],q[40];
cx q[40],q[93];
ccx q[114],q[92],q[40];
cx q[40],q[114];
cx q[114],q[92];
cx q[44],q[96];
cx q[44],q[115];
ccx q[115],q[96],q[44];
cx q[45],q[97];
cx q[45],q[44];
ccx q[44],q[97],q[45];
cx q[46],q[98];
cx q[46],q[45];
ccx q[45],q[98],q[46];
cx q[47],q[99];
cx q[47],q[46];
ccx q[46],q[99],q[47];
cx q[47],q[116];
ccx q[46],q[99],q[47];
cx q[47],q[46];
cx q[46],q[99];
ccx q[45],q[98],q[46];
cx q[46],q[45];
cx q[45],q[98];
ccx q[44],q[97],q[45];
cx q[45],q[44];
cx q[44],q[97];
ccx q[115],q[96],q[44];
cx q[44],q[115];
cx q[115],q[96];
cx q[48],q[100];
cx q[48],q[116];
ccx q[116],q[100],q[48];
cx q[49],q[101];
cx q[49],q[48];
ccx q[48],q[101],q[49];
cx q[50],q[102];
cx q[50],q[49];
ccx q[49],q[102],q[50];
cx q[51],q[103];
cx q[51],q[50];
ccx q[50],q[103],q[51];
cx q[51],q[117];
ccx q[50],q[103],q[51];
cx q[51],q[50];
cx q[50],q[103];
ccx q[49],q[102],q[50];
cx q[50],q[49];
cx q[49],q[102];
ccx q[48],q[101],q[49];
cx q[49],q[48];
cx q[48],q[101];
ccx q[116],q[100],q[48];
cx q[48],q[116];
cx q[116],q[100];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79],q[80],q[81],q[82],q[83],q[84],q[85],q[86],q[87],q[88],q[89],q[90],q[91],q[92],q[93],q[94],q[95],q[96],q[97],q[98],q[99],q[100],q[101],q[102],q[103],q[104],q[105],q[106],q[107],q[108],q[109],q[110],q[111],q[112],q[113],q[114],q[115],q[116],q[117];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];
measure q[66] -> meas[66];
measure q[67] -> meas[67];
measure q[68] -> meas[68];
measure q[69] -> meas[69];
measure q[70] -> meas[70];
measure q[71] -> meas[71];
measure q[72] -> meas[72];
measure q[73] -> meas[73];
measure q[74] -> meas[74];
measure q[75] -> meas[75];
measure q[76] -> meas[76];
measure q[77] -> meas[77];
measure q[78] -> meas[78];
measure q[79] -> meas[79];
measure q[80] -> meas[80];
measure q[81] -> meas[81];
measure q[82] -> meas[82];
measure q[83] -> meas[83];
measure q[84] -> meas[84];
measure q[85] -> meas[85];
measure q[86] -> meas[86];
measure q[87] -> meas[87];
measure q[88] -> meas[88];
measure q[89] -> meas[89];
measure q[90] -> meas[90];
measure q[91] -> meas[91];
measure q[92] -> meas[92];
measure q[93] -> meas[93];
measure q[94] -> meas[94];
measure q[95] -> meas[95];
measure q[96] -> meas[96];
measure q[97] -> meas[97];
measure q[98] -> meas[98];
measure q[99] -> meas[99];
measure q[100] -> meas[100];
measure q[101] -> meas[101];
measure q[102] -> meas[102];
measure q[103] -> meas[103];
measure q[104] -> meas[104];
measure q[105] -> meas[105];
measure q[106] -> meas[106];
measure q[107] -> meas[107];
measure q[108] -> meas[108];
measure q[109] -> meas[109];
measure q[110] -> meas[110];
measure q[111] -> meas[111];
measure q[112] -> meas[112];
measure q[113] -> meas[113];
measure q[114] -> meas[114];
measure q[115] -> meas[115];
measure q[116] -> meas[116];
measure q[117] -> meas[117];
'''

# %%
benchmarks['qpe-80'] = '''
// Benchmark was created by MQT Bench on 2024-03-18
// For more information about MQT Bench, please visit https://www.cda.cit.tum.de/mqtbench/
// MQT Bench version: 1.1.0
// Qiskit version: 1.0.2

OPENQASM 2.0;
include "qelib1.inc";
qreg q[79];
qreg psi[1];
creg c[79];
h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
h q[8];
h q[9];
h q[10];
h q[11];
h q[12];
h q[13];
h q[14];
h q[15];
h q[16];
h q[17];
h q[18];
h q[19];
h q[20];
h q[21];
h q[22];
h q[23];
h q[24];
h q[25];
h q[26];
h q[27];
h q[28];
h q[29];
h q[30];
h q[31];
h q[32];
h q[33];
h q[34];
h q[35];
h q[36];
h q[37];
h q[38];
h q[39];
h q[40];
h q[41];
h q[42];
h q[43];
h q[44];
h q[45];
h q[46];
h q[47];
h q[48];
h q[49];
h q[50];
h q[51];
h q[52];
h q[53];
h q[54];
h q[55];
h q[56];
h q[57];
h q[58];
h q[59];
h q[60];
h q[61];
h q[62];
h q[63];
h q[64];
h q[65];
h q[66];
h q[67];
h q[68];
h q[69];
h q[70];
h q[71];
h q[72];
h q[73];
h q[74];
h q[75];
h q[76];
h q[77];
h q[78];
x psi[0];
cp(2.6946352496278005) psi[0],q[0];
cp(-0.8939148079239851) psi[0],q[1];
cp(-1.7878296158479703) psi[0],q[2];
cp(2.707526075483645) psi[0],q[3];
cp(-0.8681331562122957) psi[0],q[4];
cp(-1.7362663124245914) psi[0],q[5];
cp(2.810652682330404) psi[0],q[6];
cp(-0.6618799425187788) psi[0],q[7];
cp(-1.3237598850375576) psi[0],q[8];
cp(-2.647519770075115) psi[0],q[9];
cp(0.9881457670293563) psi[0],q[10];
cp(1.9762915340587126) psi[0],q[11];
cp(-2.330602239062161) psi[0],q[12];
cp(1.6219808290552642) psi[0],q[13];
cp(-3.039223649069058) psi[0],q[14];
cp(0.20473800904147033) psi[0],q[15];
cp(0.40947601808294065) psi[0],q[16];
cp(0.8189520361658813) psi[0],q[17];
cp(1.6379040723317626) psi[0],q[18];
cp(-3.0073771625160615) psi[0],q[19];
cp(0.26843098214746364) psi[0],q[20];
cp(0.5368619642949273) psi[0],q[21];
cp(1.0737239285898545) psi[0],q[22];
cp(2.147447857179709) psi[0],q[23];
cp(-1.9882895928201683) psi[0],q[24];
cp(2.3066061215392497) psi[0],q[25];
cp(-1.669973064101087) psi[0],q[26];
cp(2.943239178977412) psi[0],q[27];
cp(-0.39670694922476224) psi[0],q[28];
cp(-0.7934138984495245) psi[0],q[29];
cp(-1.586827796899049) psi[0],q[30];
cp(3.1095297133814883) psi[0],q[31];
cp(-0.06412588041660923) psi[0],q[32];
cp(-0.12825176083321846) psi[0],q[33];
cp(-0.2565035216664369) psi[0],q[34];
cp(-0.5130070433328738) psi[0],q[35];
cp(-1.0260140866657477) psi[0],q[36];
cp(-2.0520281733314953) psi[0],q[37];
cp(2.179128960516595) psi[0],q[38];
cp(-1.9249273861463958) psi[0],q[39];
cp(2.4333305348867946) psi[0],q[40];
swap q[38],q[40];
cp(-1.416524237405997) psi[0],q[41];
swap q[37],q[41];
cp(-2.833048474811994) psi[0],q[42];
swap q[36],q[42];
cp(0.6170883575555981) psi[0],q[43];
swap q[35],q[43];
cp(1.2341767151111962) psi[0],q[44];
swap q[34],q[44];
cp(2.4683534302223924) psi[0],q[45];
swap q[33],q[45];
cp(-1.3464784467348012) psi[0],q[46];
swap q[32],q[46];
cp(-2.6929568934696024) psi[0],q[47];
swap q[31],q[47];
cp(0.8972715202403814) psi[0],q[48];
swap q[30],q[48];
cp(1.7945430404807627) psi[0],q[49];
swap q[29],q[49];
cp(-2.6940992262180607) psi[0],q[50];
swap q[28],q[50];
cp(0.8949868547434644) psi[0],q[51];
swap q[27],q[51];
cp(1.7899737094869288) psi[0],q[52];
swap q[26],q[52];
cp(-2.7032378882057286) psi[0],q[53];
swap q[25],q[53];
cp(0.8767095307681287) psi[0],q[54];
swap q[24],q[54];
cp(1.7534190615362575) psi[0],q[55];
swap q[23],q[55];
cp(-2.7763471841070713) psi[0],q[56];
swap q[22],q[56];
cp(0.7304909389654439) psi[0],q[57];
swap q[21],q[57];
cp(1.4609818779308879) psi[0],q[58];
swap q[20],q[58];
cp(2.9219637558617757) psi[0],q[59];
swap q[19],q[59];
cp(-0.43925779545603444) psi[0],q[60];
swap q[18],q[60];
cp(-0.8785155909120689) psi[0],q[61];
swap q[17],q[61];
cp(-1.7570311818241378) psi[0],q[62];
swap q[16],q[62];
cp(2.7691229435313107) psi[0],q[63];
swap q[15],q[63];
cp(-0.7449394201169645) psi[0],q[64];
swap q[14],q[64];
cp(-1.489878840233929) psi[0],q[65];
swap q[13],q[65];
cp(-2.979757680467858) psi[0],q[66];
swap q[12],q[66];
cp(0.3236699462438703) psi[0],q[67];
swap q[11],q[67];
cp(0.6473398924877406) psi[0],q[68];
swap q[10],q[68];
cp(1.2946797849754812) psi[0],q[69];
swap q[9],q[69];
cp(2.5893595699509624) psi[0],q[70];
swap q[8],q[70];
cp(-1.1044661672776617) psi[0],q[71];
swap q[7],q[71];
cp(-2.2089323345553233) psi[0],q[72];
swap q[6],q[72];
cp(1.8653206380689396) psi[0],q[73];
swap q[5],q[73];
cp(-13*pi/16) psi[0],q[74];
swap q[4],q[74];
cp(3*pi/8) psi[0],q[75];
swap q[3],q[75];
cp(3*pi/4) psi[0],q[76];
swap q[2],q[76];
cp(-pi/2) psi[0],q[77];
swap q[1],q[77];
cp(pi) psi[0],q[78];
swap q[0],q[78];
h q[0];
cp(-pi/2) q[1],q[0];
h q[1];
cp(-pi/4) q[2],q[0];
cp(-pi/2) q[2],q[1];
h q[2];
cp(-pi/8) q[3],q[0];
cp(-pi/4) q[3],q[1];
cp(-pi/2) q[3],q[2];
h q[3];
cp(-pi/16) q[4],q[0];
cp(-pi/8) q[4],q[1];
cp(-pi/4) q[4],q[2];
cp(-pi/2) q[4],q[3];
h q[4];
cp(-pi/32) q[5],q[0];
cp(-pi/16) q[5],q[1];
cp(-pi/8) q[5],q[2];
cp(-pi/4) q[5],q[3];
cp(-pi/2) q[5],q[4];
h q[5];
cp(-pi/64) q[6],q[0];
cp(-pi/32) q[6],q[1];
cp(-pi/16) q[6],q[2];
cp(-pi/8) q[6],q[3];
cp(-pi/4) q[6],q[4];
cp(-pi/2) q[6],q[5];
h q[6];
cp(-pi/128) q[7],q[0];
cp(-pi/64) q[7],q[1];
cp(-pi/32) q[7],q[2];
cp(-pi/16) q[7],q[3];
cp(-pi/8) q[7],q[4];
cp(-pi/4) q[7],q[5];
cp(-pi/2) q[7],q[6];
h q[7];
cp(-pi/256) q[8],q[0];
cp(-pi/128) q[8],q[1];
cp(-pi/64) q[8],q[2];
cp(-pi/32) q[8],q[3];
cp(-pi/16) q[8],q[4];
cp(-pi/8) q[8],q[5];
cp(-pi/4) q[8],q[6];
cp(-pi/2) q[8],q[7];
h q[8];
cp(-pi/512) q[9],q[0];
cp(-pi/256) q[9],q[1];
cp(-pi/128) q[9],q[2];
cp(-pi/64) q[9],q[3];
cp(-pi/32) q[9],q[4];
cp(-pi/16) q[9],q[5];
cp(-pi/8) q[9],q[6];
cp(-pi/4) q[9],q[7];
cp(-pi/2) q[9],q[8];
h q[9];
cp(-pi/1024) q[10],q[0];
cp(-pi/512) q[10],q[1];
cp(-pi/256) q[10],q[2];
cp(-pi/128) q[10],q[3];
cp(-pi/64) q[10],q[4];
cp(-pi/32) q[10],q[5];
cp(-pi/16) q[10],q[6];
cp(-pi/8) q[10],q[7];
cp(-pi/4) q[10],q[8];
cp(-pi/2) q[10],q[9];
h q[10];
cp(-pi/2048) q[11],q[0];
cp(-pi/1024) q[11],q[1];
cp(-pi/512) q[11],q[2];
cp(-pi/256) q[11],q[3];
cp(-pi/128) q[11],q[4];
cp(-pi/64) q[11],q[5];
cp(-pi/32) q[11],q[6];
cp(-pi/16) q[11],q[7];
cp(-pi/8) q[11],q[8];
cp(-pi/4) q[11],q[9];
cp(-pi/2) q[11],q[10];
h q[11];
cp(-pi/4096) q[12],q[0];
cp(-pi/2048) q[12],q[1];
cp(-pi/1024) q[12],q[2];
cp(-pi/512) q[12],q[3];
cp(-pi/256) q[12],q[4];
cp(-pi/128) q[12],q[5];
cp(-pi/64) q[12],q[6];
cp(-pi/32) q[12],q[7];
cp(-pi/16) q[12],q[8];
cp(-pi/8) q[12],q[9];
cp(-pi/4) q[12],q[10];
cp(-pi/2) q[12],q[11];
h q[12];
cp(-pi/8192) q[13],q[0];
cp(-pi/4096) q[13],q[1];
cp(-pi/2048) q[13],q[2];
cp(-pi/1024) q[13],q[3];
cp(-pi/512) q[13],q[4];
cp(-pi/256) q[13],q[5];
cp(-pi/128) q[13],q[6];
cp(-pi/64) q[13],q[7];
cp(-pi/32) q[13],q[8];
cp(-pi/16) q[13],q[9];
cp(-pi/8) q[13],q[10];
cp(-pi/4) q[13],q[11];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/16384) q[14],q[0];
cp(-pi/8192) q[14],q[1];
cp(-pi/4096) q[14],q[2];
cp(-pi/2048) q[14],q[3];
cp(-pi/1024) q[14],q[4];
cp(-pi/512) q[14],q[5];
cp(-pi/256) q[14],q[6];
cp(-pi/128) q[14],q[7];
cp(-pi/64) q[14],q[8];
cp(-pi/32) q[14],q[9];
cp(-pi/16) q[14],q[10];
cp(-pi/8) q[14],q[11];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/32768) q[15],q[0];
cp(-pi/16384) q[15],q[1];
cp(-pi/8192) q[15],q[2];
cp(-pi/4096) q[15],q[3];
cp(-pi/2048) q[15],q[4];
cp(-pi/1024) q[15],q[5];
cp(-pi/512) q[15],q[6];
cp(-pi/256) q[15],q[7];
cp(-pi/128) q[15],q[8];
cp(-pi/64) q[15],q[9];
cp(-pi/32) q[15],q[10];
cp(-pi/16) q[15],q[11];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/65536) q[16],q[0];
cp(-pi/32768) q[16],q[1];
cp(-pi/16384) q[16],q[2];
cp(-pi/8192) q[16],q[3];
cp(-pi/4096) q[16],q[4];
cp(-pi/2048) q[16],q[5];
cp(-pi/1024) q[16],q[6];
cp(-pi/512) q[16],q[7];
cp(-pi/256) q[16],q[8];
cp(-pi/128) q[16],q[9];
cp(-pi/64) q[16],q[10];
cp(-pi/32) q[16],q[11];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cp(-pi/131072) q[17],q[0];
cp(-pi/65536) q[17],q[1];
cp(-pi/32768) q[17],q[2];
cp(-pi/16384) q[17],q[3];
cp(-pi/8192) q[17],q[4];
cp(-pi/4096) q[17],q[5];
cp(-pi/2048) q[17],q[6];
cp(-pi/1024) q[17],q[7];
cp(-pi/512) q[17],q[8];
cp(-pi/256) q[17],q[9];
cp(-pi/128) q[17],q[10];
cp(-pi/64) q[17],q[11];
cp(-pi/32) q[17],q[12];
cp(-pi/16) q[17],q[13];
cp(-pi/8) q[17],q[14];
cp(-pi/4) q[17],q[15];
cp(-pi/2) q[17],q[16];
h q[17];
cp(-pi/262144) q[18],q[0];
cp(-pi/131072) q[18],q[1];
cp(-pi/65536) q[18],q[2];
cp(-pi/32768) q[18],q[3];
cp(-pi/16384) q[18],q[4];
cp(-pi/8192) q[18],q[5];
cp(-pi/4096) q[18],q[6];
cp(-pi/2048) q[18],q[7];
cp(-pi/1024) q[18],q[8];
cp(-pi/512) q[18],q[9];
cp(-pi/256) q[18],q[10];
cp(-pi/128) q[18],q[11];
cp(-pi/64) q[18],q[12];
cp(-pi/32) q[18],q[13];
cp(-pi/16) q[18],q[14];
cp(-pi/8) q[18],q[15];
cp(-pi/4) q[18],q[16];
cp(-pi/2) q[18],q[17];
h q[18];
cp(-pi/524288) q[19],q[0];
cp(-pi/262144) q[19],q[1];
cp(-pi/131072) q[19],q[2];
cp(-pi/65536) q[19],q[3];
cp(-pi/32768) q[19],q[4];
cp(-pi/16384) q[19],q[5];
cp(-pi/8192) q[19],q[6];
cp(-pi/4096) q[19],q[7];
cp(-pi/2048) q[19],q[8];
cp(-pi/1024) q[19],q[9];
cp(-pi/512) q[19],q[10];
cp(-pi/256) q[19],q[11];
cp(-pi/128) q[19],q[12];
cp(-pi/64) q[19],q[13];
cp(-pi/32) q[19],q[14];
cp(-pi/16) q[19],q[15];
cp(-pi/8) q[19],q[16];
cp(-pi/4) q[19],q[17];
cp(-pi/2) q[19],q[18];
h q[19];
cp(-pi/1048576) q[20],q[0];
cp(-pi/524288) q[20],q[1];
cp(-pi/262144) q[20],q[2];
cp(-pi/131072) q[20],q[3];
cp(-pi/65536) q[20],q[4];
cp(-pi/32768) q[20],q[5];
cp(-pi/16384) q[20],q[6];
cp(-pi/8192) q[20],q[7];
cp(-pi/4096) q[20],q[8];
cp(-pi/2048) q[20],q[9];
cp(-pi/1024) q[20],q[10];
cp(-pi/512) q[20],q[11];
cp(-pi/256) q[20],q[12];
cp(-pi/128) q[20],q[13];
cp(-pi/64) q[20],q[14];
cp(-pi/32) q[20],q[15];
cp(-pi/16) q[20],q[16];
cp(-pi/8) q[20],q[17];
cp(-pi/4) q[20],q[18];
cp(-pi/2) q[20],q[19];
h q[20];
cp(-pi/2097152) q[21],q[0];
cp(-pi/1048576) q[21],q[1];
cp(-pi/524288) q[21],q[2];
cp(-pi/262144) q[21],q[3];
cp(-pi/131072) q[21],q[4];
cp(-pi/65536) q[21],q[5];
cp(-pi/32768) q[21],q[6];
cp(-pi/16384) q[21],q[7];
cp(-pi/8192) q[21],q[8];
cp(-pi/4096) q[21],q[9];
cp(-pi/2048) q[21],q[10];
cp(-pi/1024) q[21],q[11];
cp(-pi/512) q[21],q[12];
cp(-pi/256) q[21],q[13];
cp(-pi/128) q[21],q[14];
cp(-pi/64) q[21],q[15];
cp(-pi/32) q[21],q[16];
cp(-pi/16) q[21],q[17];
cp(-pi/8) q[21],q[18];
cp(-pi/4) q[21],q[19];
cp(-pi/2) q[21],q[20];
h q[21];
cp(-pi/4194304) q[22],q[0];
cp(-pi/2097152) q[22],q[1];
cp(-pi/1048576) q[22],q[2];
cp(-pi/524288) q[22],q[3];
cp(-pi/262144) q[22],q[4];
cp(-pi/131072) q[22],q[5];
cp(-pi/65536) q[22],q[6];
cp(-pi/32768) q[22],q[7];
cp(-pi/16384) q[22],q[8];
cp(-pi/8192) q[22],q[9];
cp(-pi/4096) q[22],q[10];
cp(-pi/2048) q[22],q[11];
cp(-pi/1024) q[22],q[12];
cp(-pi/512) q[22],q[13];
cp(-pi/256) q[22],q[14];
cp(-pi/128) q[22],q[15];
cp(-pi/64) q[22],q[16];
cp(-pi/32) q[22],q[17];
cp(-pi/16) q[22],q[18];
cp(-pi/8) q[22],q[19];
cp(-pi/4) q[22],q[20];
cp(-pi/2) q[22],q[21];
h q[22];
cp(-pi/8388608) q[23],q[0];
cp(-pi/4194304) q[23],q[1];
cp(-pi/2097152) q[23],q[2];
cp(-pi/1048576) q[23],q[3];
cp(-pi/524288) q[23],q[4];
cp(-pi/262144) q[23],q[5];
cp(-pi/131072) q[23],q[6];
cp(-pi/65536) q[23],q[7];
cp(-pi/32768) q[23],q[8];
cp(-pi/16384) q[23],q[9];
cp(-pi/8192) q[23],q[10];
cp(-pi/4096) q[23],q[11];
cp(-pi/2048) q[23],q[12];
cp(-pi/1024) q[23],q[13];
cp(-pi/512) q[23],q[14];
cp(-pi/256) q[23],q[15];
cp(-pi/128) q[23],q[16];
cp(-pi/64) q[23],q[17];
cp(-pi/32) q[23],q[18];
cp(-pi/16) q[23],q[19];
cp(-pi/8) q[23],q[20];
cp(-pi/4) q[23],q[21];
cp(-pi/2) q[23],q[22];
h q[23];
cp(-pi/16777216) q[24],q[0];
cp(-pi/8388608) q[24],q[1];
cp(-pi/4194304) q[24],q[2];
cp(-pi/2097152) q[24],q[3];
cp(-pi/1048576) q[24],q[4];
cp(-pi/524288) q[24],q[5];
cp(-pi/262144) q[24],q[6];
cp(-pi/131072) q[24],q[7];
cp(-pi/65536) q[24],q[8];
cp(-pi/32768) q[24],q[9];
cp(-pi/16384) q[24],q[10];
cp(-pi/8192) q[24],q[11];
cp(-pi/4096) q[24],q[12];
cp(-pi/2048) q[24],q[13];
cp(-pi/1024) q[24],q[14];
cp(-pi/512) q[24],q[15];
cp(-pi/256) q[24],q[16];
cp(-pi/128) q[24],q[17];
cp(-pi/64) q[24],q[18];
cp(-pi/32) q[24],q[19];
cp(-pi/16) q[24],q[20];
cp(-pi/8) q[24],q[21];
cp(-pi/4) q[24],q[22];
cp(-pi/2) q[24],q[23];
h q[24];
cp(-pi/33554432) q[25],q[0];
cp(-pi/16777216) q[25],q[1];
cp(-pi/8388608) q[25],q[2];
cp(-pi/4194304) q[25],q[3];
cp(-pi/2097152) q[25],q[4];
cp(-pi/1048576) q[25],q[5];
cp(-pi/524288) q[25],q[6];
cp(-pi/262144) q[25],q[7];
cp(-pi/131072) q[25],q[8];
cp(-pi/65536) q[25],q[9];
cp(-pi/32768) q[25],q[10];
cp(-pi/16384) q[25],q[11];
cp(-pi/8192) q[25],q[12];
cp(-pi/4096) q[25],q[13];
cp(-pi/2048) q[25],q[14];
cp(-pi/1024) q[25],q[15];
cp(-pi/512) q[25],q[16];
cp(-pi/256) q[25],q[17];
cp(-pi/128) q[25],q[18];
cp(-pi/64) q[25],q[19];
cp(-pi/32) q[25],q[20];
cp(-pi/16) q[25],q[21];
cp(-pi/8) q[25],q[22];
cp(-pi/4) q[25],q[23];
cp(-pi/2) q[25],q[24];
h q[25];
cp(-pi/67108864) q[26],q[0];
cp(-pi/33554432) q[26],q[1];
cp(-pi/16777216) q[26],q[2];
cp(-pi/8388608) q[26],q[3];
cp(-pi/4194304) q[26],q[4];
cp(-pi/2097152) q[26],q[5];
cp(-pi/1048576) q[26],q[6];
cp(-pi/524288) q[26],q[7];
cp(-pi/262144) q[26],q[8];
cp(-pi/131072) q[26],q[9];
cp(-pi/65536) q[26],q[10];
cp(-pi/32768) q[26],q[11];
cp(-pi/16384) q[26],q[12];
cp(-pi/8192) q[26],q[13];
cp(-pi/4096) q[26],q[14];
cp(-pi/2048) q[26],q[15];
cp(-pi/1024) q[26],q[16];
cp(-pi/512) q[26],q[17];
cp(-pi/256) q[26],q[18];
cp(-pi/128) q[26],q[19];
cp(-pi/64) q[26],q[20];
cp(-pi/32) q[26],q[21];
cp(-pi/16) q[26],q[22];
cp(-pi/8) q[26],q[23];
cp(-pi/4) q[26],q[24];
cp(-pi/2) q[26],q[25];
h q[26];
cp(-pi/134217728) q[27],q[0];
cp(-pi/67108864) q[27],q[1];
cp(-pi/33554432) q[27],q[2];
cp(-pi/16777216) q[27],q[3];
cp(-pi/8388608) q[27],q[4];
cp(-pi/4194304) q[27],q[5];
cp(-pi/2097152) q[27],q[6];
cp(-pi/1048576) q[27],q[7];
cp(-pi/524288) q[27],q[8];
cp(-pi/262144) q[27],q[9];
cp(-pi/131072) q[27],q[10];
cp(-pi/65536) q[27],q[11];
cp(-pi/32768) q[27],q[12];
cp(-pi/16384) q[27],q[13];
cp(-pi/8192) q[27],q[14];
cp(-pi/4096) q[27],q[15];
cp(-pi/2048) q[27],q[16];
cp(-pi/1024) q[27],q[17];
cp(-pi/512) q[27],q[18];
cp(-pi/256) q[27],q[19];
cp(-pi/128) q[27],q[20];
cp(-pi/64) q[27],q[21];
cp(-pi/32) q[27],q[22];
cp(-pi/16) q[27],q[23];
cp(-pi/8) q[27],q[24];
cp(-pi/4) q[27],q[25];
cp(-pi/2) q[27],q[26];
h q[27];
cp(-pi/268435456) q[28],q[0];
cp(-pi/134217728) q[28],q[1];
cp(-pi/67108864) q[28],q[2];
cp(-pi/33554432) q[28],q[3];
cp(-pi/16777216) q[28],q[4];
cp(-pi/8388608) q[28],q[5];
cp(-pi/4194304) q[28],q[6];
cp(-pi/2097152) q[28],q[7];
cp(-pi/1048576) q[28],q[8];
cp(-pi/524288) q[28],q[9];
cp(-pi/262144) q[28],q[10];
cp(-pi/131072) q[28],q[11];
cp(-pi/65536) q[28],q[12];
cp(-pi/32768) q[28],q[13];
cp(-pi/16384) q[28],q[14];
cp(-pi/8192) q[28],q[15];
cp(-pi/4096) q[28],q[16];
cp(-pi/2048) q[28],q[17];
cp(-pi/1024) q[28],q[18];
cp(-pi/512) q[28],q[19];
cp(-pi/256) q[28],q[20];
cp(-pi/128) q[28],q[21];
cp(-pi/64) q[28],q[22];
cp(-pi/32) q[28],q[23];
cp(-pi/16) q[28],q[24];
cp(-pi/8) q[28],q[25];
cp(-pi/4) q[28],q[26];
cp(-pi/2) q[28],q[27];
h q[28];
cp(-pi/536870912) q[29],q[0];
cp(-pi/268435456) q[29],q[1];
cp(-pi/134217728) q[29],q[2];
cp(-pi/67108864) q[29],q[3];
cp(-pi/33554432) q[29],q[4];
cp(-pi/16777216) q[29],q[5];
cp(-pi/8388608) q[29],q[6];
cp(-pi/4194304) q[29],q[7];
cp(-pi/2097152) q[29],q[8];
cp(-pi/1048576) q[29],q[9];
cp(-pi/524288) q[29],q[10];
cp(-pi/262144) q[29],q[11];
cp(-pi/131072) q[29],q[12];
cp(-pi/65536) q[29],q[13];
cp(-pi/32768) q[29],q[14];
cp(-pi/16384) q[29],q[15];
cp(-pi/8192) q[29],q[16];
cp(-pi/4096) q[29],q[17];
cp(-pi/2048) q[29],q[18];
cp(-pi/1024) q[29],q[19];
cp(-pi/512) q[29],q[20];
cp(-pi/256) q[29],q[21];
cp(-pi/128) q[29],q[22];
cp(-pi/64) q[29],q[23];
cp(-pi/32) q[29],q[24];
cp(-pi/16) q[29],q[25];
cp(-pi/8) q[29],q[26];
cp(-pi/4) q[29],q[27];
cp(-pi/2) q[29],q[28];
h q[29];
cp(-pi/1073741824) q[30],q[0];
cp(-pi/536870912) q[30],q[1];
cp(-pi/268435456) q[30],q[2];
cp(-pi/134217728) q[30],q[3];
cp(-pi/67108864) q[30],q[4];
cp(-pi/33554432) q[30],q[5];
cp(-pi/16777216) q[30],q[6];
cp(-pi/8388608) q[30],q[7];
cp(-pi/4194304) q[30],q[8];
cp(-pi/2097152) q[30],q[9];
cp(-pi/1048576) q[30],q[10];
cp(-pi/524288) q[30],q[11];
cp(-pi/262144) q[30],q[12];
cp(-pi/131072) q[30],q[13];
cp(-pi/65536) q[30],q[14];
cp(-pi/32768) q[30],q[15];
cp(-pi/16384) q[30],q[16];
cp(-pi/8192) q[30],q[17];
cp(-pi/4096) q[30],q[18];
cp(-pi/2048) q[30],q[19];
cp(-pi/1024) q[30],q[20];
cp(-pi/512) q[30],q[21];
cp(-pi/256) q[30],q[22];
cp(-pi/128) q[30],q[23];
cp(-pi/64) q[30],q[24];
cp(-pi/32) q[30],q[25];
cp(-pi/16) q[30],q[26];
cp(-pi/8) q[30],q[27];
cp(-pi/4) q[30],q[28];
cp(-pi/2) q[30],q[29];
h q[30];
cp(-pi/2147483648) q[31],q[0];
cp(-pi/1073741824) q[31],q[1];
cp(-pi/536870912) q[31],q[2];
cp(-pi/268435456) q[31],q[3];
cp(-pi/134217728) q[31],q[4];
cp(-pi/67108864) q[31],q[5];
cp(-pi/33554432) q[31],q[6];
cp(-pi/16777216) q[31],q[7];
cp(-pi/8388608) q[31],q[8];
cp(-pi/4194304) q[31],q[9];
cp(-pi/2097152) q[31],q[10];
cp(-pi/1048576) q[31],q[11];
cp(-pi/524288) q[31],q[12];
cp(-pi/262144) q[31],q[13];
cp(-pi/131072) q[31],q[14];
cp(-pi/65536) q[31],q[15];
cp(-pi/32768) q[31],q[16];
cp(-pi/16384) q[31],q[17];
cp(-pi/8192) q[31],q[18];
cp(-pi/4096) q[31],q[19];
cp(-pi/2048) q[31],q[20];
cp(-pi/1024) q[31],q[21];
cp(-pi/512) q[31],q[22];
cp(-pi/256) q[31],q[23];
cp(-pi/128) q[31],q[24];
cp(-pi/64) q[31],q[25];
cp(-pi/32) q[31],q[26];
cp(-pi/16) q[31],q[27];
cp(-pi/8) q[31],q[28];
cp(-pi/4) q[31],q[29];
cp(-pi/2) q[31],q[30];
h q[31];
cp(-pi/4294967296) q[32],q[0];
cp(-pi/2147483648) q[32],q[1];
cp(-pi/1073741824) q[32],q[2];
cp(-pi/536870912) q[32],q[3];
cp(-pi/268435456) q[32],q[4];
cp(-pi/134217728) q[32],q[5];
cp(-pi/67108864) q[32],q[6];
cp(-pi/33554432) q[32],q[7];
cp(-pi/16777216) q[32],q[8];
cp(-pi/8388608) q[32],q[9];
cp(-pi/4194304) q[32],q[10];
cp(-pi/2097152) q[32],q[11];
cp(-pi/1048576) q[32],q[12];
cp(-pi/524288) q[32],q[13];
cp(-pi/262144) q[32],q[14];
cp(-pi/131072) q[32],q[15];
cp(-pi/65536) q[32],q[16];
cp(-pi/32768) q[32],q[17];
cp(-pi/16384) q[32],q[18];
cp(-pi/8192) q[32],q[19];
cp(-pi/4096) q[32],q[20];
cp(-pi/2048) q[32],q[21];
cp(-pi/1024) q[32],q[22];
cp(-pi/512) q[32],q[23];
cp(-pi/256) q[32],q[24];
cp(-pi/128) q[32],q[25];
cp(-pi/64) q[32],q[26];
cp(-pi/32) q[32],q[27];
cp(-pi/16) q[32],q[28];
cp(-pi/8) q[32],q[29];
cp(-pi/4) q[32],q[30];
cp(-pi/2) q[32],q[31];
h q[32];
cp(-pi/8589934592) q[33],q[0];
cp(-pi/4294967296) q[33],q[1];
cp(-pi/2147483648) q[33],q[2];
cp(-pi/1073741824) q[33],q[3];
cp(-pi/536870912) q[33],q[4];
cp(-pi/268435456) q[33],q[5];
cp(-pi/134217728) q[33],q[6];
cp(-pi/67108864) q[33],q[7];
cp(-pi/33554432) q[33],q[8];
cp(-pi/16777216) q[33],q[9];
cp(-pi/8388608) q[33],q[10];
cp(-pi/4194304) q[33],q[11];
cp(-pi/2097152) q[33],q[12];
cp(-pi/1048576) q[33],q[13];
cp(-pi/524288) q[33],q[14];
cp(-pi/262144) q[33],q[15];
cp(-pi/131072) q[33],q[16];
cp(-pi/65536) q[33],q[17];
cp(-pi/32768) q[33],q[18];
cp(-pi/16384) q[33],q[19];
cp(-pi/8192) q[33],q[20];
cp(-pi/4096) q[33],q[21];
cp(-pi/2048) q[33],q[22];
cp(-pi/1024) q[33],q[23];
cp(-pi/512) q[33],q[24];
cp(-pi/256) q[33],q[25];
cp(-pi/128) q[33],q[26];
cp(-pi/64) q[33],q[27];
cp(-pi/32) q[33],q[28];
cp(-pi/16) q[33],q[29];
cp(-pi/8) q[33],q[30];
cp(-pi/4) q[33],q[31];
cp(-pi/2) q[33],q[32];
h q[33];
cp(-pi/17179869184) q[34],q[0];
cp(-pi/8589934592) q[34],q[1];
cp(-pi/4294967296) q[34],q[2];
cp(-pi/2147483648) q[34],q[3];
cp(-pi/1073741824) q[34],q[4];
cp(-pi/536870912) q[34],q[5];
cp(-pi/268435456) q[34],q[6];
cp(-pi/134217728) q[34],q[7];
cp(-pi/67108864) q[34],q[8];
cp(-pi/33554432) q[34],q[9];
cp(-pi/16777216) q[34],q[10];
cp(-pi/8388608) q[34],q[11];
cp(-pi/4194304) q[34],q[12];
cp(-pi/2097152) q[34],q[13];
cp(-pi/1048576) q[34],q[14];
cp(-pi/524288) q[34],q[15];
cp(-pi/262144) q[34],q[16];
cp(-pi/131072) q[34],q[17];
cp(-pi/65536) q[34],q[18];
cp(-pi/32768) q[34],q[19];
cp(-pi/16384) q[34],q[20];
cp(-pi/8192) q[34],q[21];
cp(-pi/4096) q[34],q[22];
cp(-pi/2048) q[34],q[23];
cp(-pi/1024) q[34],q[24];
cp(-pi/512) q[34],q[25];
cp(-pi/256) q[34],q[26];
cp(-pi/128) q[34],q[27];
cp(-pi/64) q[34],q[28];
cp(-pi/32) q[34],q[29];
cp(-pi/16) q[34],q[30];
cp(-pi/8) q[34],q[31];
cp(-pi/4) q[34],q[32];
cp(-pi/2) q[34],q[33];
h q[34];
cp(-pi/34359738368) q[35],q[0];
cp(-pi/17179869184) q[35],q[1];
cp(-pi/8589934592) q[35],q[2];
cp(-pi/4294967296) q[35],q[3];
cp(-pi/2147483648) q[35],q[4];
cp(-pi/1073741824) q[35],q[5];
cp(-pi/536870912) q[35],q[6];
cp(-pi/268435456) q[35],q[7];
cp(-pi/134217728) q[35],q[8];
cp(-pi/67108864) q[35],q[9];
cp(-pi/33554432) q[35],q[10];
cp(-pi/16777216) q[35],q[11];
cp(-pi/8388608) q[35],q[12];
cp(-pi/4194304) q[35],q[13];
cp(-pi/2097152) q[35],q[14];
cp(-pi/1048576) q[35],q[15];
cp(-pi/524288) q[35],q[16];
cp(-pi/262144) q[35],q[17];
cp(-pi/131072) q[35],q[18];
cp(-pi/65536) q[35],q[19];
cp(-pi/32768) q[35],q[20];
cp(-pi/16384) q[35],q[21];
cp(-pi/8192) q[35],q[22];
cp(-pi/4096) q[35],q[23];
cp(-pi/2048) q[35],q[24];
cp(-pi/1024) q[35],q[25];
cp(-pi/512) q[35],q[26];
cp(-pi/256) q[35],q[27];
cp(-pi/128) q[35],q[28];
cp(-pi/64) q[35],q[29];
cp(-pi/32) q[35],q[30];
cp(-pi/16) q[35],q[31];
cp(-pi/8) q[35],q[32];
cp(-pi/4) q[35],q[33];
cp(-pi/2) q[35],q[34];
h q[35];
cp(-pi/68719476736) q[36],q[0];
cp(-pi/34359738368) q[36],q[1];
cp(-pi/17179869184) q[36],q[2];
cp(-pi/8589934592) q[36],q[3];
cp(-pi/4294967296) q[36],q[4];
cp(-pi/2147483648) q[36],q[5];
cp(-pi/1073741824) q[36],q[6];
cp(-pi/536870912) q[36],q[7];
cp(-pi/268435456) q[36],q[8];
cp(-pi/134217728) q[36],q[9];
cp(-pi/67108864) q[36],q[10];
cp(-pi/33554432) q[36],q[11];
cp(-pi/16777216) q[36],q[12];
cp(-pi/8388608) q[36],q[13];
cp(-pi/4194304) q[36],q[14];
cp(-pi/2097152) q[36],q[15];
cp(-pi/1048576) q[36],q[16];
cp(-pi/524288) q[36],q[17];
cp(-pi/262144) q[36],q[18];
cp(-pi/131072) q[36],q[19];
cp(-pi/65536) q[36],q[20];
cp(-pi/32768) q[36],q[21];
cp(-pi/16384) q[36],q[22];
cp(-pi/8192) q[36],q[23];
cp(-pi/4096) q[36],q[24];
cp(-pi/2048) q[36],q[25];
cp(-pi/1024) q[36],q[26];
cp(-pi/512) q[36],q[27];
cp(-pi/256) q[36],q[28];
cp(-pi/128) q[36],q[29];
cp(-pi/64) q[36],q[30];
cp(-pi/32) q[36],q[31];
cp(-pi/16) q[36],q[32];
cp(-pi/8) q[36],q[33];
cp(-pi/4) q[36],q[34];
cp(-pi/2) q[36],q[35];
h q[36];
cp(-pi/137438953472) q[37],q[0];
cp(-pi/68719476736) q[37],q[1];
cp(-pi/34359738368) q[37],q[2];
cp(-pi/17179869184) q[37],q[3];
cp(-pi/8589934592) q[37],q[4];
cp(-pi/4294967296) q[37],q[5];
cp(-pi/2147483648) q[37],q[6];
cp(-pi/1073741824) q[37],q[7];
cp(-pi/536870912) q[37],q[8];
cp(-pi/268435456) q[37],q[9];
cp(-pi/134217728) q[37],q[10];
cp(-pi/67108864) q[37],q[11];
cp(-pi/33554432) q[37],q[12];
cp(-pi/16777216) q[37],q[13];
cp(-pi/8388608) q[37],q[14];
cp(-pi/4194304) q[37],q[15];
cp(-pi/2097152) q[37],q[16];
cp(-pi/1048576) q[37],q[17];
cp(-pi/524288) q[37],q[18];
cp(-pi/262144) q[37],q[19];
cp(-pi/131072) q[37],q[20];
cp(-pi/65536) q[37],q[21];
cp(-pi/32768) q[37],q[22];
cp(-pi/16384) q[37],q[23];
cp(-pi/8192) q[37],q[24];
cp(-pi/4096) q[37],q[25];
cp(-pi/2048) q[37],q[26];
cp(-pi/1024) q[37],q[27];
cp(-pi/512) q[37],q[28];
cp(-pi/256) q[37],q[29];
cp(-pi/128) q[37],q[30];
cp(-pi/64) q[37],q[31];
cp(-pi/32) q[37],q[32];
cp(-pi/16) q[37],q[33];
cp(-pi/8) q[37],q[34];
cp(-pi/4) q[37],q[35];
cp(-pi/2) q[37],q[36];
h q[37];
cp(-pi/274877906944) q[38],q[0];
cp(-pi/137438953472) q[38],q[1];
cp(-pi/68719476736) q[38],q[2];
cp(-pi/34359738368) q[38],q[3];
cp(-pi/17179869184) q[38],q[4];
cp(-pi/8589934592) q[38],q[5];
cp(-pi/4294967296) q[38],q[6];
cp(-pi/2147483648) q[38],q[7];
cp(-pi/1073741824) q[38],q[8];
cp(-pi/536870912) q[38],q[9];
cp(-pi/268435456) q[38],q[10];
cp(-pi/134217728) q[38],q[11];
cp(-pi/67108864) q[38],q[12];
cp(-pi/33554432) q[38],q[13];
cp(-pi/16777216) q[38],q[14];
cp(-pi/8388608) q[38],q[15];
cp(-pi/4194304) q[38],q[16];
cp(-pi/2097152) q[38],q[17];
cp(-pi/1048576) q[38],q[18];
cp(-pi/524288) q[38],q[19];
cp(-pi/262144) q[38],q[20];
cp(-pi/131072) q[38],q[21];
cp(-pi/65536) q[38],q[22];
cp(-pi/32768) q[38],q[23];
cp(-pi/16384) q[38],q[24];
cp(-pi/8192) q[38],q[25];
cp(-pi/4096) q[38],q[26];
cp(-pi/2048) q[38],q[27];
cp(-pi/1024) q[38],q[28];
cp(-pi/512) q[38],q[29];
cp(-pi/256) q[38],q[30];
cp(-pi/128) q[38],q[31];
cp(-pi/64) q[38],q[32];
cp(-pi/32) q[38],q[33];
cp(-pi/16) q[38],q[34];
cp(-pi/8) q[38],q[35];
cp(-pi/4) q[38],q[36];
cp(-pi/2) q[38],q[37];
h q[38];
cp(-pi/549755813888) q[39],q[0];
cp(-pi/274877906944) q[39],q[1];
cp(-pi/137438953472) q[39],q[2];
cp(-pi/68719476736) q[39],q[3];
cp(-pi/34359738368) q[39],q[4];
cp(-pi/17179869184) q[39],q[5];
cp(-pi/8589934592) q[39],q[6];
cp(-pi/4294967296) q[39],q[7];
cp(-pi/2147483648) q[39],q[8];
cp(-pi/1073741824) q[39],q[9];
cp(-pi/536870912) q[39],q[10];
cp(-pi/268435456) q[39],q[11];
cp(-pi/134217728) q[39],q[12];
cp(-pi/67108864) q[39],q[13];
cp(-pi/33554432) q[39],q[14];
cp(-pi/16777216) q[39],q[15];
cp(-pi/8388608) q[39],q[16];
cp(-pi/4194304) q[39],q[17];
cp(-pi/2097152) q[39],q[18];
cp(-pi/1048576) q[39],q[19];
cp(-pi/524288) q[39],q[20];
cp(-pi/262144) q[39],q[21];
cp(-pi/131072) q[39],q[22];
cp(-pi/65536) q[39],q[23];
cp(-pi/32768) q[39],q[24];
cp(-pi/16384) q[39],q[25];
cp(-pi/8192) q[39],q[26];
cp(-pi/4096) q[39],q[27];
cp(-pi/2048) q[39],q[28];
cp(-pi/1024) q[39],q[29];
cp(-pi/512) q[39],q[30];
cp(-pi/256) q[39],q[31];
cp(-pi/128) q[39],q[32];
cp(-pi/64) q[39],q[33];
cp(-pi/32) q[39],q[34];
cp(-pi/16) q[39],q[35];
cp(-pi/8) q[39],q[36];
cp(-pi/4) q[39],q[37];
cp(-pi/2) q[39],q[38];
h q[39];
cp(-pi/1099511627776) q[40],q[0];
cp(-pi/549755813888) q[40],q[1];
cp(-pi/274877906944) q[40],q[2];
cp(-pi/137438953472) q[40],q[3];
cp(-pi/68719476736) q[40],q[4];
cp(-pi/34359738368) q[40],q[5];
cp(-pi/17179869184) q[40],q[6];
cp(-pi/8589934592) q[40],q[7];
cp(-pi/4294967296) q[40],q[8];
cp(-pi/2147483648) q[40],q[9];
cp(-pi/1073741824) q[40],q[10];
cp(-pi/536870912) q[40],q[11];
cp(-pi/268435456) q[40],q[12];
cp(-pi/134217728) q[40],q[13];
cp(-pi/67108864) q[40],q[14];
cp(-pi/33554432) q[40],q[15];
cp(-pi/16777216) q[40],q[16];
cp(-pi/8388608) q[40],q[17];
cp(-pi/4194304) q[40],q[18];
cp(-pi/2097152) q[40],q[19];
cp(-pi/1048576) q[40],q[20];
cp(-pi/524288) q[40],q[21];
cp(-pi/262144) q[40],q[22];
cp(-pi/131072) q[40],q[23];
cp(-pi/65536) q[40],q[24];
cp(-pi/32768) q[40],q[25];
cp(-pi/16384) q[40],q[26];
cp(-pi/8192) q[40],q[27];
cp(-pi/4096) q[40],q[28];
cp(-pi/2048) q[40],q[29];
cp(-pi/1024) q[40],q[30];
cp(-pi/512) q[40],q[31];
cp(-pi/256) q[40],q[32];
cp(-pi/128) q[40],q[33];
cp(-pi/64) q[40],q[34];
cp(-pi/32) q[40],q[35];
cp(-pi/16) q[40],q[36];
cp(-pi/8) q[40],q[37];
cp(-pi/4) q[40],q[38];
cp(-pi/2) q[40],q[39];
h q[40];
cp(-pi/2199023255552) q[41],q[0];
cp(-pi/1099511627776) q[41],q[1];
cp(-pi/549755813888) q[41],q[2];
cp(-pi/274877906944) q[41],q[3];
cp(-pi/137438953472) q[41],q[4];
cp(-pi/68719476736) q[41],q[5];
cp(-pi/34359738368) q[41],q[6];
cp(-pi/17179869184) q[41],q[7];
cp(-pi/8589934592) q[41],q[8];
cp(-pi/4294967296) q[41],q[9];
cp(-pi/2147483648) q[41],q[10];
cp(-pi/1073741824) q[41],q[11];
cp(-pi/536870912) q[41],q[12];
cp(-pi/268435456) q[41],q[13];
cp(-pi/134217728) q[41],q[14];
cp(-pi/67108864) q[41],q[15];
cp(-pi/33554432) q[41],q[16];
cp(-pi/16777216) q[41],q[17];
cp(-pi/8388608) q[41],q[18];
cp(-pi/4194304) q[41],q[19];
cp(-pi/2097152) q[41],q[20];
cp(-pi/1048576) q[41],q[21];
cp(-pi/524288) q[41],q[22];
cp(-pi/262144) q[41],q[23];
cp(-pi/131072) q[41],q[24];
cp(-pi/65536) q[41],q[25];
cp(-pi/32768) q[41],q[26];
cp(-pi/16384) q[41],q[27];
cp(-pi/8192) q[41],q[28];
cp(-pi/4096) q[41],q[29];
cp(-pi/2048) q[41],q[30];
cp(-pi/1024) q[41],q[31];
cp(-pi/512) q[41],q[32];
cp(-pi/256) q[41],q[33];
cp(-pi/128) q[41],q[34];
cp(-pi/64) q[41],q[35];
cp(-pi/32) q[41],q[36];
cp(-pi/16) q[41],q[37];
cp(-pi/8) q[41],q[38];
cp(-pi/4) q[41],q[39];
cp(-pi/2) q[41],q[40];
h q[41];
cp(0) q[42],q[0];
cp(-pi/2199023255552) q[42],q[1];
cp(-pi/1099511627776) q[42],q[2];
cp(-pi/549755813888) q[42],q[3];
cp(-pi/274877906944) q[42],q[4];
cp(-pi/137438953472) q[42],q[5];
cp(-pi/68719476736) q[42],q[6];
cp(-pi/34359738368) q[42],q[7];
cp(-pi/17179869184) q[42],q[8];
cp(-pi/8589934592) q[42],q[9];
cp(-pi/4294967296) q[42],q[10];
cp(-pi/2147483648) q[42],q[11];
cp(-pi/1073741824) q[42],q[12];
cp(-pi/536870912) q[42],q[13];
cp(-pi/268435456) q[42],q[14];
cp(-pi/134217728) q[42],q[15];
cp(-pi/67108864) q[42],q[16];
cp(-pi/33554432) q[42],q[17];
cp(-pi/16777216) q[42],q[18];
cp(-pi/8388608) q[42],q[19];
cp(-pi/4194304) q[42],q[20];
cp(-pi/2097152) q[42],q[21];
cp(-pi/1048576) q[42],q[22];
cp(-pi/524288) q[42],q[23];
cp(-pi/262144) q[42],q[24];
cp(-pi/131072) q[42],q[25];
cp(-pi/65536) q[42],q[26];
cp(-pi/32768) q[42],q[27];
cp(-pi/16384) q[42],q[28];
cp(-pi/8192) q[42],q[29];
cp(-pi/4096) q[42],q[30];
cp(-pi/2048) q[42],q[31];
cp(-pi/1024) q[42],q[32];
cp(-pi/512) q[42],q[33];
cp(-pi/256) q[42],q[34];
cp(-pi/128) q[42],q[35];
cp(-pi/64) q[42],q[36];
cp(-pi/32) q[42],q[37];
cp(-pi/16) q[42],q[38];
cp(-pi/8) q[42],q[39];
cp(-pi/4) q[42],q[40];
cp(-pi/2) q[42],q[41];
h q[42];
cp(0) q[43],q[0];
cp(0) q[43],q[1];
cp(-pi/2199023255552) q[43],q[2];
cp(-pi/1099511627776) q[43],q[3];
cp(-pi/549755813888) q[43],q[4];
cp(-pi/274877906944) q[43],q[5];
cp(-pi/137438953472) q[43],q[6];
cp(-pi/68719476736) q[43],q[7];
cp(-pi/34359738368) q[43],q[8];
cp(-pi/17179869184) q[43],q[9];
cp(-pi/8589934592) q[43],q[10];
cp(-pi/4294967296) q[43],q[11];
cp(-pi/2147483648) q[43],q[12];
cp(-pi/1073741824) q[43],q[13];
cp(-pi/536870912) q[43],q[14];
cp(-pi/268435456) q[43],q[15];
cp(-pi/134217728) q[43],q[16];
cp(-pi/67108864) q[43],q[17];
cp(-pi/33554432) q[43],q[18];
cp(-pi/16777216) q[43],q[19];
cp(-pi/8388608) q[43],q[20];
cp(-pi/4194304) q[43],q[21];
cp(-pi/2097152) q[43],q[22];
cp(-pi/1048576) q[43],q[23];
cp(-pi/524288) q[43],q[24];
cp(-pi/262144) q[43],q[25];
cp(-pi/131072) q[43],q[26];
cp(-pi/65536) q[43],q[27];
cp(-pi/32768) q[43],q[28];
cp(-pi/16384) q[43],q[29];
cp(-pi/8192) q[43],q[30];
cp(-pi/4096) q[43],q[31];
cp(-pi/2048) q[43],q[32];
cp(-pi/1024) q[43],q[33];
cp(-pi/512) q[43],q[34];
cp(-pi/256) q[43],q[35];
cp(-pi/128) q[43],q[36];
cp(-pi/64) q[43],q[37];
cp(-pi/32) q[43],q[38];
cp(-pi/16) q[43],q[39];
cp(-pi/8) q[43],q[40];
cp(-pi/4) q[43],q[41];
cp(-pi/2) q[43],q[42];
h q[43];
cp(0) q[44],q[0];
cp(0) q[44],q[1];
cp(0) q[44],q[2];
cp(-pi/2199023255552) q[44],q[3];
cp(-pi/1099511627776) q[44],q[4];
cp(-pi/549755813888) q[44],q[5];
cp(-pi/274877906944) q[44],q[6];
cp(-pi/137438953472) q[44],q[7];
cp(-pi/68719476736) q[44],q[8];
cp(-pi/34359738368) q[44],q[9];
cp(-pi/17179869184) q[44],q[10];
cp(-pi/8589934592) q[44],q[11];
cp(-pi/4294967296) q[44],q[12];
cp(-pi/2147483648) q[44],q[13];
cp(-pi/1073741824) q[44],q[14];
cp(-pi/536870912) q[44],q[15];
cp(-pi/268435456) q[44],q[16];
cp(-pi/134217728) q[44],q[17];
cp(-pi/67108864) q[44],q[18];
cp(-pi/33554432) q[44],q[19];
cp(-pi/16777216) q[44],q[20];
cp(-pi/8388608) q[44],q[21];
cp(-pi/4194304) q[44],q[22];
cp(-pi/2097152) q[44],q[23];
cp(-pi/1048576) q[44],q[24];
cp(-pi/524288) q[44],q[25];
cp(-pi/262144) q[44],q[26];
cp(-pi/131072) q[44],q[27];
cp(-pi/65536) q[44],q[28];
cp(-pi/32768) q[44],q[29];
cp(-pi/16384) q[44],q[30];
cp(-pi/8192) q[44],q[31];
cp(-pi/4096) q[44],q[32];
cp(-pi/2048) q[44],q[33];
cp(-pi/1024) q[44],q[34];
cp(-pi/512) q[44],q[35];
cp(-pi/256) q[44],q[36];
cp(-pi/128) q[44],q[37];
cp(-pi/64) q[44],q[38];
cp(-pi/32) q[44],q[39];
cp(-pi/16) q[44],q[40];
cp(-pi/8) q[44],q[41];
cp(-pi/4) q[44],q[42];
cp(-pi/2) q[44],q[43];
h q[44];
cp(0) q[45],q[0];
cp(0) q[45],q[1];
cp(0) q[45],q[2];
cp(0) q[45],q[3];
cp(-pi/2199023255552) q[45],q[4];
cp(-pi/1099511627776) q[45],q[5];
cp(-pi/549755813888) q[45],q[6];
cp(-pi/274877906944) q[45],q[7];
cp(-pi/137438953472) q[45],q[8];
cp(-pi/68719476736) q[45],q[9];
cp(-pi/34359738368) q[45],q[10];
cp(-pi/17179869184) q[45],q[11];
cp(-pi/8589934592) q[45],q[12];
cp(-pi/4294967296) q[45],q[13];
cp(-pi/2147483648) q[45],q[14];
cp(-pi/1073741824) q[45],q[15];
cp(-pi/536870912) q[45],q[16];
cp(-pi/268435456) q[45],q[17];
cp(-pi/134217728) q[45],q[18];
cp(-pi/67108864) q[45],q[19];
cp(-pi/33554432) q[45],q[20];
cp(-pi/16777216) q[45],q[21];
cp(-pi/8388608) q[45],q[22];
cp(-pi/4194304) q[45],q[23];
cp(-pi/2097152) q[45],q[24];
cp(-pi/1048576) q[45],q[25];
cp(-pi/524288) q[45],q[26];
cp(-pi/262144) q[45],q[27];
cp(-pi/131072) q[45],q[28];
cp(-pi/65536) q[45],q[29];
cp(-pi/32768) q[45],q[30];
cp(-pi/16384) q[45],q[31];
cp(-pi/8192) q[45],q[32];
cp(-pi/4096) q[45],q[33];
cp(-pi/2048) q[45],q[34];
cp(-pi/1024) q[45],q[35];
cp(-pi/512) q[45],q[36];
cp(-pi/256) q[45],q[37];
cp(-pi/128) q[45],q[38];
cp(-pi/64) q[45],q[39];
cp(-pi/32) q[45],q[40];
cp(-pi/16) q[45],q[41];
cp(-pi/8) q[45],q[42];
cp(-pi/4) q[45],q[43];
cp(-pi/2) q[45],q[44];
h q[45];
cp(0) q[46],q[0];
cp(0) q[46],q[1];
cp(0) q[46],q[2];
cp(0) q[46],q[3];
cp(0) q[46],q[4];
cp(-pi/2199023255552) q[46],q[5];
cp(-pi/1099511627776) q[46],q[6];
cp(-pi/549755813888) q[46],q[7];
cp(-pi/274877906944) q[46],q[8];
cp(-pi/137438953472) q[46],q[9];
cp(-pi/68719476736) q[46],q[10];
cp(-pi/34359738368) q[46],q[11];
cp(-pi/17179869184) q[46],q[12];
cp(-pi/8589934592) q[46],q[13];
cp(-pi/4294967296) q[46],q[14];
cp(-pi/2147483648) q[46],q[15];
cp(-pi/1073741824) q[46],q[16];
cp(-pi/536870912) q[46],q[17];
cp(-pi/268435456) q[46],q[18];
cp(-pi/134217728) q[46],q[19];
cp(-pi/67108864) q[46],q[20];
cp(-pi/33554432) q[46],q[21];
cp(-pi/16777216) q[46],q[22];
cp(-pi/8388608) q[46],q[23];
cp(-pi/4194304) q[46],q[24];
cp(-pi/2097152) q[46],q[25];
cp(-pi/1048576) q[46],q[26];
cp(-pi/524288) q[46],q[27];
cp(-pi/262144) q[46],q[28];
cp(-pi/131072) q[46],q[29];
cp(-pi/65536) q[46],q[30];
cp(-pi/32768) q[46],q[31];
cp(-pi/16384) q[46],q[32];
cp(-pi/8192) q[46],q[33];
cp(-pi/4096) q[46],q[34];
cp(-pi/2048) q[46],q[35];
cp(-pi/1024) q[46],q[36];
cp(-pi/512) q[46],q[37];
cp(-pi/256) q[46],q[38];
cp(-pi/128) q[46],q[39];
cp(-pi/64) q[46],q[40];
cp(-pi/32) q[46],q[41];
cp(-pi/16) q[46],q[42];
cp(-pi/8) q[46],q[43];
cp(-pi/4) q[46],q[44];
cp(-pi/2) q[46],q[45];
h q[46];
cp(0) q[47],q[0];
cp(0) q[47],q[1];
cp(0) q[47],q[2];
cp(0) q[47],q[3];
cp(0) q[47],q[4];
cp(0) q[47],q[5];
cp(-pi/2199023255552) q[47],q[6];
cp(-pi/1099511627776) q[47],q[7];
cp(-pi/549755813888) q[47],q[8];
cp(-pi/274877906944) q[47],q[9];
cp(-pi/137438953472) q[47],q[10];
cp(-pi/68719476736) q[47],q[11];
cp(-pi/34359738368) q[47],q[12];
cp(-pi/17179869184) q[47],q[13];
cp(-pi/8589934592) q[47],q[14];
cp(-pi/4294967296) q[47],q[15];
cp(-pi/2147483648) q[47],q[16];
cp(-pi/1073741824) q[47],q[17];
cp(-pi/536870912) q[47],q[18];
cp(-pi/268435456) q[47],q[19];
cp(-pi/134217728) q[47],q[20];
cp(-pi/67108864) q[47],q[21];
cp(-pi/33554432) q[47],q[22];
cp(-pi/16777216) q[47],q[23];
cp(-pi/8388608) q[47],q[24];
cp(-pi/4194304) q[47],q[25];
cp(-pi/2097152) q[47],q[26];
cp(-pi/1048576) q[47],q[27];
cp(-pi/524288) q[47],q[28];
cp(-pi/262144) q[47],q[29];
cp(-pi/131072) q[47],q[30];
cp(-pi/65536) q[47],q[31];
cp(-pi/32768) q[47],q[32];
cp(-pi/16384) q[47],q[33];
cp(-pi/8192) q[47],q[34];
cp(-pi/4096) q[47],q[35];
cp(-pi/2048) q[47],q[36];
cp(-pi/1024) q[47],q[37];
cp(-pi/512) q[47],q[38];
cp(-pi/256) q[47],q[39];
cp(-pi/128) q[47],q[40];
cp(-pi/64) q[47],q[41];
cp(-pi/32) q[47],q[42];
cp(-pi/16) q[47],q[43];
cp(-pi/8) q[47],q[44];
cp(-pi/4) q[47],q[45];
cp(-pi/2) q[47],q[46];
h q[47];
cp(0) q[48],q[0];
cp(0) q[48],q[1];
cp(0) q[48],q[2];
cp(0) q[48],q[3];
cp(0) q[48],q[4];
cp(0) q[48],q[5];
cp(0) q[48],q[6];
cp(-pi/2199023255552) q[48],q[7];
cp(-pi/1099511627776) q[48],q[8];
cp(-pi/549755813888) q[48],q[9];
cp(-pi/274877906944) q[48],q[10];
cp(-pi/137438953472) q[48],q[11];
cp(-pi/68719476736) q[48],q[12];
cp(-pi/34359738368) q[48],q[13];
cp(-pi/17179869184) q[48],q[14];
cp(-pi/8589934592) q[48],q[15];
cp(-pi/4294967296) q[48],q[16];
cp(-pi/2147483648) q[48],q[17];
cp(-pi/1073741824) q[48],q[18];
cp(-pi/536870912) q[48],q[19];
cp(-pi/268435456) q[48],q[20];
cp(-pi/134217728) q[48],q[21];
cp(-pi/67108864) q[48],q[22];
cp(-pi/33554432) q[48],q[23];
cp(-pi/16777216) q[48],q[24];
cp(-pi/8388608) q[48],q[25];
cp(-pi/4194304) q[48],q[26];
cp(-pi/2097152) q[48],q[27];
cp(-pi/1048576) q[48],q[28];
cp(-pi/524288) q[48],q[29];
cp(-pi/262144) q[48],q[30];
cp(-pi/131072) q[48],q[31];
cp(-pi/65536) q[48],q[32];
cp(-pi/32768) q[48],q[33];
cp(-pi/16384) q[48],q[34];
cp(-pi/8192) q[48],q[35];
cp(-pi/4096) q[48],q[36];
cp(-pi/2048) q[48],q[37];
cp(-pi/1024) q[48],q[38];
cp(-pi/512) q[48],q[39];
cp(-pi/256) q[48],q[40];
cp(-pi/128) q[48],q[41];
cp(-pi/64) q[48],q[42];
cp(-pi/32) q[48],q[43];
cp(-pi/16) q[48],q[44];
cp(-pi/8) q[48],q[45];
cp(-pi/4) q[48],q[46];
cp(-pi/2) q[48],q[47];
h q[48];
cp(0) q[49],q[0];
cp(0) q[49],q[1];
cp(0) q[49],q[2];
cp(0) q[49],q[3];
cp(0) q[49],q[4];
cp(0) q[49],q[5];
cp(0) q[49],q[6];
cp(0) q[49],q[7];
cp(-pi/2199023255552) q[49],q[8];
cp(-pi/1099511627776) q[49],q[9];
cp(-pi/549755813888) q[49],q[10];
cp(-pi/274877906944) q[49],q[11];
cp(-pi/137438953472) q[49],q[12];
cp(-pi/68719476736) q[49],q[13];
cp(-pi/34359738368) q[49],q[14];
cp(-pi/17179869184) q[49],q[15];
cp(-pi/8589934592) q[49],q[16];
cp(-pi/4294967296) q[49],q[17];
cp(-pi/2147483648) q[49],q[18];
cp(-pi/1073741824) q[49],q[19];
cp(-pi/536870912) q[49],q[20];
cp(-pi/268435456) q[49],q[21];
cp(-pi/134217728) q[49],q[22];
cp(-pi/67108864) q[49],q[23];
cp(-pi/33554432) q[49],q[24];
cp(-pi/16777216) q[49],q[25];
cp(-pi/8388608) q[49],q[26];
cp(-pi/4194304) q[49],q[27];
cp(-pi/2097152) q[49],q[28];
cp(-pi/1048576) q[49],q[29];
cp(-pi/524288) q[49],q[30];
cp(-pi/262144) q[49],q[31];
cp(-pi/131072) q[49],q[32];
cp(-pi/65536) q[49],q[33];
cp(-pi/32768) q[49],q[34];
cp(-pi/16384) q[49],q[35];
cp(-pi/8192) q[49],q[36];
cp(-pi/4096) q[49],q[37];
cp(-pi/2048) q[49],q[38];
cp(-pi/1024) q[49],q[39];
cp(-pi/512) q[49],q[40];
cp(-pi/256) q[49],q[41];
cp(-pi/128) q[49],q[42];
cp(-pi/64) q[49],q[43];
cp(-pi/32) q[49],q[44];
cp(-pi/16) q[49],q[45];
cp(-pi/8) q[49],q[46];
cp(-pi/4) q[49],q[47];
cp(-pi/2) q[49],q[48];
h q[49];
cp(0) q[50],q[0];
cp(0) q[50],q[1];
cp(0) q[50],q[2];
cp(0) q[50],q[3];
cp(0) q[50],q[4];
cp(0) q[50],q[5];
cp(0) q[50],q[6];
cp(0) q[50],q[7];
cp(0) q[50],q[8];
cp(-pi/2199023255552) q[50],q[9];
cp(-pi/1099511627776) q[50],q[10];
cp(-pi/549755813888) q[50],q[11];
cp(-pi/274877906944) q[50],q[12];
cp(-pi/137438953472) q[50],q[13];
cp(-pi/68719476736) q[50],q[14];
cp(-pi/34359738368) q[50],q[15];
cp(-pi/17179869184) q[50],q[16];
cp(-pi/8589934592) q[50],q[17];
cp(-pi/4294967296) q[50],q[18];
cp(-pi/2147483648) q[50],q[19];
cp(-pi/1073741824) q[50],q[20];
cp(-pi/536870912) q[50],q[21];
cp(-pi/268435456) q[50],q[22];
cp(-pi/134217728) q[50],q[23];
cp(-pi/67108864) q[50],q[24];
cp(-pi/33554432) q[50],q[25];
cp(-pi/16777216) q[50],q[26];
cp(-pi/8388608) q[50],q[27];
cp(-pi/4194304) q[50],q[28];
cp(-pi/2097152) q[50],q[29];
cp(-pi/1048576) q[50],q[30];
cp(-pi/524288) q[50],q[31];
cp(-pi/262144) q[50],q[32];
cp(-pi/131072) q[50],q[33];
cp(-pi/65536) q[50],q[34];
cp(-pi/32768) q[50],q[35];
cp(-pi/16384) q[50],q[36];
cp(-pi/8192) q[50],q[37];
cp(-pi/4096) q[50],q[38];
cp(-pi/2048) q[50],q[39];
cp(-pi/1024) q[50],q[40];
cp(-pi/512) q[50],q[41];
cp(-pi/256) q[50],q[42];
cp(-pi/128) q[50],q[43];
cp(-pi/64) q[50],q[44];
cp(-pi/32) q[50],q[45];
cp(-pi/16) q[50],q[46];
cp(-pi/8) q[50],q[47];
cp(-pi/4) q[50],q[48];
cp(-pi/2) q[50],q[49];
h q[50];
cp(0) q[51],q[0];
cp(0) q[51],q[1];
cp(0) q[51],q[2];
cp(0) q[51],q[3];
cp(0) q[51],q[4];
cp(0) q[51],q[5];
cp(0) q[51],q[6];
cp(0) q[51],q[7];
cp(0) q[51],q[8];
cp(0) q[51],q[9];
cp(-pi/2199023255552) q[51],q[10];
cp(-pi/1099511627776) q[51],q[11];
cp(-pi/549755813888) q[51],q[12];
cp(-pi/274877906944) q[51],q[13];
cp(-pi/137438953472) q[51],q[14];
cp(-pi/68719476736) q[51],q[15];
cp(-pi/34359738368) q[51],q[16];
cp(-pi/17179869184) q[51],q[17];
cp(-pi/8589934592) q[51],q[18];
cp(-pi/4294967296) q[51],q[19];
cp(-pi/2147483648) q[51],q[20];
cp(-pi/1073741824) q[51],q[21];
cp(-pi/536870912) q[51],q[22];
cp(-pi/268435456) q[51],q[23];
cp(-pi/134217728) q[51],q[24];
cp(-pi/67108864) q[51],q[25];
cp(-pi/33554432) q[51],q[26];
cp(-pi/16777216) q[51],q[27];
cp(-pi/8388608) q[51],q[28];
cp(-pi/4194304) q[51],q[29];
cp(-pi/2097152) q[51],q[30];
cp(-pi/1048576) q[51],q[31];
cp(-pi/524288) q[51],q[32];
cp(-pi/262144) q[51],q[33];
cp(-pi/131072) q[51],q[34];
cp(-pi/65536) q[51],q[35];
cp(-pi/32768) q[51],q[36];
cp(-pi/16384) q[51],q[37];
cp(-pi/8192) q[51],q[38];
cp(-pi/4096) q[51],q[39];
cp(-pi/2048) q[51],q[40];
cp(-pi/1024) q[51],q[41];
cp(-pi/512) q[51],q[42];
cp(-pi/256) q[51],q[43];
cp(-pi/128) q[51],q[44];
cp(-pi/64) q[51],q[45];
cp(-pi/32) q[51],q[46];
cp(-pi/16) q[51],q[47];
cp(-pi/8) q[51],q[48];
cp(-pi/4) q[51],q[49];
cp(-pi/2) q[51],q[50];
h q[51];
cp(0) q[52],q[0];
cp(0) q[52],q[1];
cp(0) q[52],q[2];
cp(0) q[52],q[3];
cp(0) q[52],q[4];
cp(0) q[52],q[5];
cp(0) q[52],q[6];
cp(0) q[52],q[7];
cp(0) q[52],q[8];
cp(0) q[52],q[9];
cp(0) q[52],q[10];
cp(-pi/2199023255552) q[52],q[11];
cp(-pi/1099511627776) q[52],q[12];
cp(-pi/549755813888) q[52],q[13];
cp(-pi/274877906944) q[52],q[14];
cp(-pi/137438953472) q[52],q[15];
cp(-pi/68719476736) q[52],q[16];
cp(-pi/34359738368) q[52],q[17];
cp(-pi/17179869184) q[52],q[18];
cp(-pi/8589934592) q[52],q[19];
cp(-pi/4294967296) q[52],q[20];
cp(-pi/2147483648) q[52],q[21];
cp(-pi/1073741824) q[52],q[22];
cp(-pi/536870912) q[52],q[23];
cp(-pi/268435456) q[52],q[24];
cp(-pi/134217728) q[52],q[25];
cp(-pi/67108864) q[52],q[26];
cp(-pi/33554432) q[52],q[27];
cp(-pi/16777216) q[52],q[28];
cp(-pi/8388608) q[52],q[29];
cp(-pi/4194304) q[52],q[30];
cp(-pi/2097152) q[52],q[31];
cp(-pi/1048576) q[52],q[32];
cp(-pi/524288) q[52],q[33];
cp(-pi/262144) q[52],q[34];
cp(-pi/131072) q[52],q[35];
cp(-pi/65536) q[52],q[36];
cp(-pi/32768) q[52],q[37];
cp(-pi/16384) q[52],q[38];
cp(-pi/8192) q[52],q[39];
cp(-pi/4096) q[52],q[40];
cp(-pi/2048) q[52],q[41];
cp(-pi/1024) q[52],q[42];
cp(-pi/512) q[52],q[43];
cp(-pi/256) q[52],q[44];
cp(-pi/128) q[52],q[45];
cp(-pi/64) q[52],q[46];
cp(-pi/32) q[52],q[47];
cp(-pi/16) q[52],q[48];
cp(-pi/8) q[52],q[49];
cp(-pi/4) q[52],q[50];
cp(-pi/2) q[52],q[51];
h q[52];
cp(0) q[53],q[0];
cp(0) q[53],q[1];
cp(0) q[53],q[2];
cp(0) q[53],q[3];
cp(0) q[53],q[4];
cp(0) q[53],q[5];
cp(0) q[53],q[6];
cp(0) q[53],q[7];
cp(0) q[53],q[8];
cp(0) q[53],q[9];
cp(0) q[53],q[10];
cp(0) q[53],q[11];
cp(-pi/2199023255552) q[53],q[12];
cp(-pi/1099511627776) q[53],q[13];
cp(-pi/549755813888) q[53],q[14];
cp(-pi/274877906944) q[53],q[15];
cp(-pi/137438953472) q[53],q[16];
cp(-pi/68719476736) q[53],q[17];
cp(-pi/34359738368) q[53],q[18];
cp(-pi/17179869184) q[53],q[19];
cp(-pi/8589934592) q[53],q[20];
cp(-pi/4294967296) q[53],q[21];
cp(-pi/2147483648) q[53],q[22];
cp(-pi/1073741824) q[53],q[23];
cp(-pi/536870912) q[53],q[24];
cp(-pi/268435456) q[53],q[25];
cp(-pi/134217728) q[53],q[26];
cp(-pi/67108864) q[53],q[27];
cp(-pi/33554432) q[53],q[28];
cp(-pi/16777216) q[53],q[29];
cp(-pi/8388608) q[53],q[30];
cp(-pi/4194304) q[53],q[31];
cp(-pi/2097152) q[53],q[32];
cp(-pi/1048576) q[53],q[33];
cp(-pi/524288) q[53],q[34];
cp(-pi/262144) q[53],q[35];
cp(-pi/131072) q[53],q[36];
cp(-pi/65536) q[53],q[37];
cp(-pi/32768) q[53],q[38];
cp(-pi/16384) q[53],q[39];
cp(-pi/8192) q[53],q[40];
cp(-pi/4096) q[53],q[41];
cp(-pi/2048) q[53],q[42];
cp(-pi/1024) q[53],q[43];
cp(-pi/512) q[53],q[44];
cp(-pi/256) q[53],q[45];
cp(-pi/128) q[53],q[46];
cp(-pi/64) q[53],q[47];
cp(-pi/32) q[53],q[48];
cp(-pi/16) q[53],q[49];
cp(-pi/8) q[53],q[50];
cp(-pi/4) q[53],q[51];
cp(-pi/2) q[53],q[52];
h q[53];
cp(0) q[54],q[0];
cp(0) q[54],q[1];
cp(0) q[54],q[2];
cp(0) q[54],q[3];
cp(0) q[54],q[4];
cp(0) q[54],q[5];
cp(0) q[54],q[6];
cp(0) q[54],q[7];
cp(0) q[54],q[8];
cp(0) q[54],q[9];
cp(0) q[54],q[10];
cp(0) q[54],q[11];
cp(0) q[54],q[12];
cp(-pi/2199023255552) q[54],q[13];
cp(-pi/1099511627776) q[54],q[14];
cp(-pi/549755813888) q[54],q[15];
cp(-pi/274877906944) q[54],q[16];
cp(-pi/137438953472) q[54],q[17];
cp(-pi/68719476736) q[54],q[18];
cp(-pi/34359738368) q[54],q[19];
cp(-pi/17179869184) q[54],q[20];
cp(-pi/8589934592) q[54],q[21];
cp(-pi/4294967296) q[54],q[22];
cp(-pi/2147483648) q[54],q[23];
cp(-pi/1073741824) q[54],q[24];
cp(-pi/536870912) q[54],q[25];
cp(-pi/268435456) q[54],q[26];
cp(-pi/134217728) q[54],q[27];
cp(-pi/67108864) q[54],q[28];
cp(-pi/33554432) q[54],q[29];
cp(-pi/16777216) q[54],q[30];
cp(-pi/8388608) q[54],q[31];
cp(-pi/4194304) q[54],q[32];
cp(-pi/2097152) q[54],q[33];
cp(-pi/1048576) q[54],q[34];
cp(-pi/524288) q[54],q[35];
cp(-pi/262144) q[54],q[36];
cp(-pi/131072) q[54],q[37];
cp(-pi/65536) q[54],q[38];
cp(-pi/32768) q[54],q[39];
cp(-pi/16384) q[54],q[40];
cp(-pi/8192) q[54],q[41];
cp(-pi/4096) q[54],q[42];
cp(-pi/2048) q[54],q[43];
cp(-pi/1024) q[54],q[44];
cp(-pi/512) q[54],q[45];
cp(-pi/256) q[54],q[46];
cp(-pi/128) q[54],q[47];
cp(-pi/64) q[54],q[48];
cp(-pi/32) q[54],q[49];
cp(-pi/16) q[54],q[50];
cp(-pi/8) q[54],q[51];
cp(-pi/4) q[54],q[52];
cp(-pi/2) q[54],q[53];
h q[54];
cp(0) q[55],q[0];
cp(0) q[55],q[1];
cp(0) q[55],q[2];
cp(0) q[55],q[3];
cp(0) q[55],q[4];
cp(0) q[55],q[5];
cp(0) q[55],q[6];
cp(0) q[55],q[7];
cp(0) q[55],q[8];
cp(0) q[55],q[9];
cp(0) q[55],q[10];
cp(0) q[55],q[11];
cp(0) q[55],q[12];
cp(0) q[55],q[13];
cp(-pi/2199023255552) q[55],q[14];
cp(-pi/1099511627776) q[55],q[15];
cp(-pi/549755813888) q[55],q[16];
cp(-pi/274877906944) q[55],q[17];
cp(-pi/137438953472) q[55],q[18];
cp(-pi/68719476736) q[55],q[19];
cp(-pi/34359738368) q[55],q[20];
cp(-pi/17179869184) q[55],q[21];
cp(-pi/8589934592) q[55],q[22];
cp(-pi/4294967296) q[55],q[23];
cp(-pi/2147483648) q[55],q[24];
cp(-pi/1073741824) q[55],q[25];
cp(-pi/536870912) q[55],q[26];
cp(-pi/268435456) q[55],q[27];
cp(-pi/134217728) q[55],q[28];
cp(-pi/67108864) q[55],q[29];
cp(-pi/33554432) q[55],q[30];
cp(-pi/16777216) q[55],q[31];
cp(-pi/8388608) q[55],q[32];
cp(-pi/4194304) q[55],q[33];
cp(-pi/2097152) q[55],q[34];
cp(-pi/1048576) q[55],q[35];
cp(-pi/524288) q[55],q[36];
cp(-pi/262144) q[55],q[37];
cp(-pi/131072) q[55],q[38];
cp(-pi/65536) q[55],q[39];
cp(-pi/32768) q[55],q[40];
cp(-pi/16384) q[55],q[41];
cp(-pi/8192) q[55],q[42];
cp(-pi/4096) q[55],q[43];
cp(-pi/2048) q[55],q[44];
cp(-pi/1024) q[55],q[45];
cp(-pi/512) q[55],q[46];
cp(-pi/256) q[55],q[47];
cp(-pi/128) q[55],q[48];
cp(-pi/64) q[55],q[49];
cp(-pi/32) q[55],q[50];
cp(-pi/16) q[55],q[51];
cp(-pi/8) q[55],q[52];
cp(-pi/4) q[55],q[53];
cp(-pi/2) q[55],q[54];
h q[55];
cp(0) q[56],q[0];
cp(0) q[56],q[1];
cp(0) q[56],q[2];
cp(0) q[56],q[3];
cp(0) q[56],q[4];
cp(0) q[56],q[5];
cp(0) q[56],q[6];
cp(0) q[56],q[7];
cp(0) q[56],q[8];
cp(0) q[56],q[9];
cp(0) q[56],q[10];
cp(0) q[56],q[11];
cp(0) q[56],q[12];
cp(0) q[56],q[13];
cp(0) q[56],q[14];
cp(-pi/2199023255552) q[56],q[15];
cp(-pi/1099511627776) q[56],q[16];
cp(-pi/549755813888) q[56],q[17];
cp(-pi/274877906944) q[56],q[18];
cp(-pi/137438953472) q[56],q[19];
cp(-pi/68719476736) q[56],q[20];
cp(-pi/34359738368) q[56],q[21];
cp(-pi/17179869184) q[56],q[22];
cp(-pi/8589934592) q[56],q[23];
cp(-pi/4294967296) q[56],q[24];
cp(-pi/2147483648) q[56],q[25];
cp(-pi/1073741824) q[56],q[26];
cp(-pi/536870912) q[56],q[27];
cp(-pi/268435456) q[56],q[28];
cp(-pi/134217728) q[56],q[29];
cp(-pi/67108864) q[56],q[30];
cp(-pi/33554432) q[56],q[31];
cp(-pi/16777216) q[56],q[32];
cp(-pi/8388608) q[56],q[33];
cp(-pi/4194304) q[56],q[34];
cp(-pi/2097152) q[56],q[35];
cp(-pi/1048576) q[56],q[36];
cp(-pi/524288) q[56],q[37];
cp(-pi/262144) q[56],q[38];
cp(-pi/131072) q[56],q[39];
cp(-pi/65536) q[56],q[40];
cp(-pi/32768) q[56],q[41];
cp(-pi/16384) q[56],q[42];
cp(-pi/8192) q[56],q[43];
cp(-pi/4096) q[56],q[44];
cp(-pi/2048) q[56],q[45];
cp(-pi/1024) q[56],q[46];
cp(-pi/512) q[56],q[47];
cp(-pi/256) q[56],q[48];
cp(-pi/128) q[56],q[49];
cp(-pi/64) q[56],q[50];
cp(-pi/32) q[56],q[51];
cp(-pi/16) q[56],q[52];
cp(-pi/8) q[56],q[53];
cp(-pi/4) q[56],q[54];
cp(-pi/2) q[56],q[55];
h q[56];
cp(0) q[57],q[0];
cp(0) q[57],q[1];
cp(0) q[57],q[2];
cp(0) q[57],q[3];
cp(0) q[57],q[4];
cp(0) q[57],q[5];
cp(0) q[57],q[6];
cp(0) q[57],q[7];
cp(0) q[57],q[8];
cp(0) q[57],q[9];
cp(0) q[57],q[10];
cp(0) q[57],q[11];
cp(0) q[57],q[12];
cp(0) q[57],q[13];
cp(0) q[57],q[14];
cp(0) q[57],q[15];
cp(-pi/2199023255552) q[57],q[16];
cp(-pi/1099511627776) q[57],q[17];
cp(-pi/549755813888) q[57],q[18];
cp(-pi/274877906944) q[57],q[19];
cp(-pi/137438953472) q[57],q[20];
cp(-pi/68719476736) q[57],q[21];
cp(-pi/34359738368) q[57],q[22];
cp(-pi/17179869184) q[57],q[23];
cp(-pi/8589934592) q[57],q[24];
cp(-pi/4294967296) q[57],q[25];
cp(-pi/2147483648) q[57],q[26];
cp(-pi/1073741824) q[57],q[27];
cp(-pi/536870912) q[57],q[28];
cp(-pi/268435456) q[57],q[29];
cp(-pi/134217728) q[57],q[30];
cp(-pi/67108864) q[57],q[31];
cp(-pi/33554432) q[57],q[32];
cp(-pi/16777216) q[57],q[33];
cp(-pi/8388608) q[57],q[34];
cp(-pi/4194304) q[57],q[35];
cp(-pi/2097152) q[57],q[36];
cp(-pi/1048576) q[57],q[37];
cp(-pi/524288) q[57],q[38];
cp(-pi/262144) q[57],q[39];
cp(-pi/131072) q[57],q[40];
cp(-pi/65536) q[57],q[41];
cp(-pi/32768) q[57],q[42];
cp(-pi/16384) q[57],q[43];
cp(-pi/8192) q[57],q[44];
cp(-pi/4096) q[57],q[45];
cp(-pi/2048) q[57],q[46];
cp(-pi/1024) q[57],q[47];
cp(-pi/512) q[57],q[48];
cp(-pi/256) q[57],q[49];
cp(-pi/128) q[57],q[50];
cp(-pi/64) q[57],q[51];
cp(-pi/32) q[57],q[52];
cp(-pi/16) q[57],q[53];
cp(-pi/8) q[57],q[54];
cp(-pi/4) q[57],q[55];
cp(-pi/2) q[57],q[56];
h q[57];
cp(0) q[58],q[0];
cp(0) q[58],q[1];
cp(0) q[58],q[2];
cp(0) q[58],q[3];
cp(0) q[58],q[4];
cp(0) q[58],q[5];
cp(0) q[58],q[6];
cp(0) q[58],q[7];
cp(0) q[58],q[8];
cp(0) q[58],q[9];
cp(0) q[58],q[10];
cp(0) q[58],q[11];
cp(0) q[58],q[12];
cp(0) q[58],q[13];
cp(0) q[58],q[14];
cp(0) q[58],q[15];
cp(0) q[58],q[16];
cp(-pi/2199023255552) q[58],q[17];
cp(-pi/1099511627776) q[58],q[18];
cp(-pi/549755813888) q[58],q[19];
cp(-pi/274877906944) q[58],q[20];
cp(-pi/137438953472) q[58],q[21];
cp(-pi/68719476736) q[58],q[22];
cp(-pi/34359738368) q[58],q[23];
cp(-pi/17179869184) q[58],q[24];
cp(-pi/8589934592) q[58],q[25];
cp(-pi/4294967296) q[58],q[26];
cp(-pi/2147483648) q[58],q[27];
cp(-pi/1073741824) q[58],q[28];
cp(-pi/536870912) q[58],q[29];
cp(-pi/268435456) q[58],q[30];
cp(-pi/134217728) q[58],q[31];
cp(-pi/67108864) q[58],q[32];
cp(-pi/33554432) q[58],q[33];
cp(-pi/16777216) q[58],q[34];
cp(-pi/8388608) q[58],q[35];
cp(-pi/4194304) q[58],q[36];
cp(-pi/2097152) q[58],q[37];
cp(-pi/1048576) q[58],q[38];
cp(-pi/524288) q[58],q[39];
cp(-pi/262144) q[58],q[40];
cp(-pi/131072) q[58],q[41];
cp(-pi/65536) q[58],q[42];
cp(-pi/32768) q[58],q[43];
cp(-pi/16384) q[58],q[44];
cp(-pi/8192) q[58],q[45];
cp(-pi/4096) q[58],q[46];
cp(-pi/2048) q[58],q[47];
cp(-pi/1024) q[58],q[48];
cp(-pi/512) q[58],q[49];
cp(-pi/256) q[58],q[50];
cp(-pi/128) q[58],q[51];
cp(-pi/64) q[58],q[52];
cp(-pi/32) q[58],q[53];
cp(-pi/16) q[58],q[54];
cp(-pi/8) q[58],q[55];
cp(-pi/4) q[58],q[56];
cp(-pi/2) q[58],q[57];
h q[58];
cp(0) q[59],q[0];
cp(0) q[59],q[1];
cp(0) q[59],q[2];
cp(0) q[59],q[3];
cp(0) q[59],q[4];
cp(0) q[59],q[5];
cp(0) q[59],q[6];
cp(0) q[59],q[7];
cp(0) q[59],q[8];
cp(0) q[59],q[9];
cp(0) q[59],q[10];
cp(0) q[59],q[11];
cp(0) q[59],q[12];
cp(0) q[59],q[13];
cp(0) q[59],q[14];
cp(0) q[59],q[15];
cp(0) q[59],q[16];
cp(0) q[59],q[17];
cp(-pi/2199023255552) q[59],q[18];
cp(-pi/1099511627776) q[59],q[19];
cp(-pi/549755813888) q[59],q[20];
cp(-pi/274877906944) q[59],q[21];
cp(-pi/137438953472) q[59],q[22];
cp(-pi/68719476736) q[59],q[23];
cp(-pi/34359738368) q[59],q[24];
cp(-pi/17179869184) q[59],q[25];
cp(-pi/8589934592) q[59],q[26];
cp(-pi/4294967296) q[59],q[27];
cp(-pi/2147483648) q[59],q[28];
cp(-pi/1073741824) q[59],q[29];
cp(-pi/536870912) q[59],q[30];
cp(-pi/268435456) q[59],q[31];
cp(-pi/134217728) q[59],q[32];
cp(-pi/67108864) q[59],q[33];
cp(-pi/33554432) q[59],q[34];
cp(-pi/16777216) q[59],q[35];
cp(-pi/8388608) q[59],q[36];
cp(-pi/4194304) q[59],q[37];
cp(-pi/2097152) q[59],q[38];
cp(-pi/1048576) q[59],q[39];
cp(-pi/524288) q[59],q[40];
cp(-pi/262144) q[59],q[41];
cp(-pi/131072) q[59],q[42];
cp(-pi/65536) q[59],q[43];
cp(-pi/32768) q[59],q[44];
cp(-pi/16384) q[59],q[45];
cp(-pi/8192) q[59],q[46];
cp(-pi/4096) q[59],q[47];
cp(-pi/2048) q[59],q[48];
cp(-pi/1024) q[59],q[49];
cp(-pi/512) q[59],q[50];
cp(-pi/256) q[59],q[51];
cp(-pi/128) q[59],q[52];
cp(-pi/64) q[59],q[53];
cp(-pi/32) q[59],q[54];
cp(-pi/16) q[59],q[55];
cp(-pi/8) q[59],q[56];
cp(-pi/4) q[59],q[57];
cp(-pi/2) q[59],q[58];
h q[59];
cp(0) q[60],q[0];
cp(0) q[60],q[1];
cp(0) q[60],q[2];
cp(0) q[60],q[3];
cp(0) q[60],q[4];
cp(0) q[60],q[5];
cp(0) q[60],q[6];
cp(0) q[60],q[7];
cp(0) q[60],q[8];
cp(0) q[60],q[9];
cp(0) q[60],q[10];
cp(0) q[60],q[11];
cp(0) q[60],q[12];
cp(0) q[60],q[13];
cp(0) q[60],q[14];
cp(0) q[60],q[15];
cp(0) q[60],q[16];
cp(0) q[60],q[17];
cp(0) q[60],q[18];
cp(-pi/2199023255552) q[60],q[19];
cp(-pi/1099511627776) q[60],q[20];
cp(-pi/549755813888) q[60],q[21];
cp(-pi/274877906944) q[60],q[22];
cp(-pi/137438953472) q[60],q[23];
cp(-pi/68719476736) q[60],q[24];
cp(-pi/34359738368) q[60],q[25];
cp(-pi/17179869184) q[60],q[26];
cp(-pi/8589934592) q[60],q[27];
cp(-pi/4294967296) q[60],q[28];
cp(-pi/2147483648) q[60],q[29];
cp(-pi/1073741824) q[60],q[30];
cp(-pi/536870912) q[60],q[31];
cp(-pi/268435456) q[60],q[32];
cp(-pi/134217728) q[60],q[33];
cp(-pi/67108864) q[60],q[34];
cp(-pi/33554432) q[60],q[35];
cp(-pi/16777216) q[60],q[36];
cp(-pi/8388608) q[60],q[37];
cp(-pi/4194304) q[60],q[38];
cp(-pi/2097152) q[60],q[39];
cp(-pi/1048576) q[60],q[40];
cp(-pi/524288) q[60],q[41];
cp(-pi/262144) q[60],q[42];
cp(-pi/131072) q[60],q[43];
cp(-pi/65536) q[60],q[44];
cp(-pi/32768) q[60],q[45];
cp(-pi/16384) q[60],q[46];
cp(-pi/8192) q[60],q[47];
cp(-pi/4096) q[60],q[48];
cp(-pi/2048) q[60],q[49];
cp(-pi/1024) q[60],q[50];
cp(-pi/512) q[60],q[51];
cp(-pi/256) q[60],q[52];
cp(-pi/128) q[60],q[53];
cp(-pi/64) q[60],q[54];
cp(-pi/32) q[60],q[55];
cp(-pi/16) q[60],q[56];
cp(-pi/8) q[60],q[57];
cp(-pi/4) q[60],q[58];
cp(-pi/2) q[60],q[59];
h q[60];
cp(0) q[61],q[0];
cp(0) q[61],q[1];
cp(0) q[61],q[2];
cp(0) q[61],q[3];
cp(0) q[61],q[4];
cp(0) q[61],q[5];
cp(0) q[61],q[6];
cp(0) q[61],q[7];
cp(0) q[61],q[8];
cp(0) q[61],q[9];
cp(0) q[61],q[10];
cp(0) q[61],q[11];
cp(0) q[61],q[12];
cp(0) q[61],q[13];
cp(0) q[61],q[14];
cp(0) q[61],q[15];
cp(0) q[61],q[16];
cp(0) q[61],q[17];
cp(0) q[61],q[18];
cp(0) q[61],q[19];
cp(-pi/2199023255552) q[61],q[20];
cp(-pi/1099511627776) q[61],q[21];
cp(-pi/549755813888) q[61],q[22];
cp(-pi/274877906944) q[61],q[23];
cp(-pi/137438953472) q[61],q[24];
cp(-pi/68719476736) q[61],q[25];
cp(-pi/34359738368) q[61],q[26];
cp(-pi/17179869184) q[61],q[27];
cp(-pi/8589934592) q[61],q[28];
cp(-pi/4294967296) q[61],q[29];
cp(-pi/2147483648) q[61],q[30];
cp(-pi/1073741824) q[61],q[31];
cp(-pi/536870912) q[61],q[32];
cp(-pi/268435456) q[61],q[33];
cp(-pi/134217728) q[61],q[34];
cp(-pi/67108864) q[61],q[35];
cp(-pi/33554432) q[61],q[36];
cp(-pi/16777216) q[61],q[37];
cp(-pi/8388608) q[61],q[38];
cp(-pi/4194304) q[61],q[39];
cp(-pi/2097152) q[61],q[40];
cp(-pi/1048576) q[61],q[41];
cp(-pi/524288) q[61],q[42];
cp(-pi/262144) q[61],q[43];
cp(-pi/131072) q[61],q[44];
cp(-pi/65536) q[61],q[45];
cp(-pi/32768) q[61],q[46];
cp(-pi/16384) q[61],q[47];
cp(-pi/8192) q[61],q[48];
cp(-pi/4096) q[61],q[49];
cp(-pi/2048) q[61],q[50];
cp(-pi/1024) q[61],q[51];
cp(-pi/512) q[61],q[52];
cp(-pi/256) q[61],q[53];
cp(-pi/128) q[61],q[54];
cp(-pi/64) q[61],q[55];
cp(-pi/32) q[61],q[56];
cp(-pi/16) q[61],q[57];
cp(-pi/8) q[61],q[58];
cp(-pi/4) q[61],q[59];
cp(-pi/2) q[61],q[60];
h q[61];
cp(0) q[62],q[0];
cp(0) q[62],q[1];
cp(0) q[62],q[2];
cp(0) q[62],q[3];
cp(0) q[62],q[4];
cp(0) q[62],q[5];
cp(0) q[62],q[6];
cp(0) q[62],q[7];
cp(0) q[62],q[8];
cp(0) q[62],q[9];
cp(0) q[62],q[10];
cp(0) q[62],q[11];
cp(0) q[62],q[12];
cp(0) q[62],q[13];
cp(0) q[62],q[14];
cp(0) q[62],q[15];
cp(0) q[62],q[16];
cp(0) q[62],q[17];
cp(0) q[62],q[18];
cp(0) q[62],q[19];
cp(0) q[62],q[20];
cp(-pi/2199023255552) q[62],q[21];
cp(-pi/1099511627776) q[62],q[22];
cp(-pi/549755813888) q[62],q[23];
cp(-pi/274877906944) q[62],q[24];
cp(-pi/137438953472) q[62],q[25];
cp(-pi/68719476736) q[62],q[26];
cp(-pi/34359738368) q[62],q[27];
cp(-pi/17179869184) q[62],q[28];
cp(-pi/8589934592) q[62],q[29];
cp(-pi/4294967296) q[62],q[30];
cp(-pi/2147483648) q[62],q[31];
cp(-pi/1073741824) q[62],q[32];
cp(-pi/536870912) q[62],q[33];
cp(-pi/268435456) q[62],q[34];
cp(-pi/134217728) q[62],q[35];
cp(-pi/67108864) q[62],q[36];
cp(-pi/33554432) q[62],q[37];
cp(-pi/16777216) q[62],q[38];
cp(-pi/8388608) q[62],q[39];
cp(-pi/4194304) q[62],q[40];
cp(-pi/2097152) q[62],q[41];
cp(-pi/1048576) q[62],q[42];
cp(-pi/524288) q[62],q[43];
cp(-pi/262144) q[62],q[44];
cp(-pi/131072) q[62],q[45];
cp(-pi/65536) q[62],q[46];
cp(-pi/32768) q[62],q[47];
cp(-pi/16384) q[62],q[48];
cp(-pi/8192) q[62],q[49];
cp(-pi/4096) q[62],q[50];
cp(-pi/2048) q[62],q[51];
cp(-pi/1024) q[62],q[52];
cp(-pi/512) q[62],q[53];
cp(-pi/256) q[62],q[54];
cp(-pi/128) q[62],q[55];
cp(-pi/64) q[62],q[56];
cp(-pi/32) q[62],q[57];
cp(-pi/16) q[62],q[58];
cp(-pi/8) q[62],q[59];
cp(-pi/4) q[62],q[60];
cp(-pi/2) q[62],q[61];
h q[62];
cp(0) q[63],q[0];
cp(0) q[63],q[1];
cp(0) q[63],q[2];
cp(0) q[63],q[3];
cp(0) q[63],q[4];
cp(0) q[63],q[5];
cp(0) q[63],q[6];
cp(0) q[63],q[7];
cp(0) q[63],q[8];
cp(0) q[63],q[9];
cp(0) q[63],q[10];
cp(0) q[63],q[11];
cp(0) q[63],q[12];
cp(0) q[63],q[13];
cp(0) q[63],q[14];
cp(0) q[63],q[15];
cp(0) q[63],q[16];
cp(0) q[63],q[17];
cp(0) q[63],q[18];
cp(0) q[63],q[19];
cp(0) q[63],q[20];
cp(0) q[63],q[21];
cp(-pi/2199023255552) q[63],q[22];
cp(-pi/1099511627776) q[63],q[23];
cp(-pi/549755813888) q[63],q[24];
cp(-pi/274877906944) q[63],q[25];
cp(-pi/137438953472) q[63],q[26];
cp(-pi/68719476736) q[63],q[27];
cp(-pi/34359738368) q[63],q[28];
cp(-pi/17179869184) q[63],q[29];
cp(-pi/8589934592) q[63],q[30];
cp(-pi/4294967296) q[63],q[31];
cp(-pi/2147483648) q[63],q[32];
cp(-pi/1073741824) q[63],q[33];
cp(-pi/536870912) q[63],q[34];
cp(-pi/268435456) q[63],q[35];
cp(-pi/134217728) q[63],q[36];
cp(-pi/67108864) q[63],q[37];
cp(-pi/33554432) q[63],q[38];
cp(-pi/16777216) q[63],q[39];
cp(-pi/8388608) q[63],q[40];
cp(-pi/4194304) q[63],q[41];
cp(-pi/2097152) q[63],q[42];
cp(-pi/1048576) q[63],q[43];
cp(-pi/524288) q[63],q[44];
cp(-pi/262144) q[63],q[45];
cp(-pi/131072) q[63],q[46];
cp(-pi/65536) q[63],q[47];
cp(-pi/32768) q[63],q[48];
cp(-pi/16384) q[63],q[49];
cp(-pi/8192) q[63],q[50];
cp(-pi/4096) q[63],q[51];
cp(-pi/2048) q[63],q[52];
cp(-pi/1024) q[63],q[53];
cp(-pi/512) q[63],q[54];
cp(-pi/256) q[63],q[55];
cp(-pi/128) q[63],q[56];
cp(-pi/64) q[63],q[57];
cp(-pi/32) q[63],q[58];
cp(-pi/16) q[63],q[59];
cp(-pi/8) q[63],q[60];
cp(-pi/4) q[63],q[61];
cp(-pi/2) q[63],q[62];
h q[63];
cp(0) q[64],q[0];
cp(0) q[64],q[1];
cp(0) q[64],q[2];
cp(0) q[64],q[3];
cp(0) q[64],q[4];
cp(0) q[64],q[5];
cp(0) q[64],q[6];
cp(0) q[64],q[7];
cp(0) q[64],q[8];
cp(0) q[64],q[9];
cp(0) q[64],q[10];
cp(0) q[64],q[11];
cp(0) q[64],q[12];
cp(0) q[64],q[13];
cp(0) q[64],q[14];
cp(0) q[64],q[15];
cp(0) q[64],q[16];
cp(0) q[64],q[17];
cp(0) q[64],q[18];
cp(0) q[64],q[19];
cp(0) q[64],q[20];
cp(0) q[64],q[21];
cp(0) q[64],q[22];
cp(-pi/2199023255552) q[64],q[23];
cp(-pi/1099511627776) q[64],q[24];
cp(-pi/549755813888) q[64],q[25];
cp(-pi/274877906944) q[64],q[26];
cp(-pi/137438953472) q[64],q[27];
cp(-pi/68719476736) q[64],q[28];
cp(-pi/34359738368) q[64],q[29];
cp(-pi/17179869184) q[64],q[30];
cp(-pi/8589934592) q[64],q[31];
cp(-pi/4294967296) q[64],q[32];
cp(-pi/2147483648) q[64],q[33];
cp(-pi/1073741824) q[64],q[34];
cp(-pi/536870912) q[64],q[35];
cp(-pi/268435456) q[64],q[36];
cp(-pi/134217728) q[64],q[37];
cp(-pi/67108864) q[64],q[38];
cp(-pi/33554432) q[64],q[39];
cp(-pi/16777216) q[64],q[40];
cp(-pi/8388608) q[64],q[41];
cp(-pi/4194304) q[64],q[42];
cp(-pi/2097152) q[64],q[43];
cp(-pi/1048576) q[64],q[44];
cp(-pi/524288) q[64],q[45];
cp(-pi/262144) q[64],q[46];
cp(-pi/131072) q[64],q[47];
cp(-pi/65536) q[64],q[48];
cp(-pi/32768) q[64],q[49];
cp(-pi/16384) q[64],q[50];
cp(-pi/8192) q[64],q[51];
cp(-pi/4096) q[64],q[52];
cp(-pi/2048) q[64],q[53];
cp(-pi/1024) q[64],q[54];
cp(-pi/512) q[64],q[55];
cp(-pi/256) q[64],q[56];
cp(-pi/128) q[64],q[57];
cp(-pi/64) q[64],q[58];
cp(-pi/32) q[64],q[59];
cp(-pi/16) q[64],q[60];
cp(-pi/8) q[64],q[61];
cp(-pi/4) q[64],q[62];
cp(-pi/2) q[64],q[63];
h q[64];
cp(0) q[65],q[0];
cp(0) q[65],q[1];
cp(0) q[65],q[2];
cp(0) q[65],q[3];
cp(0) q[65],q[4];
cp(0) q[65],q[5];
cp(0) q[65],q[6];
cp(0) q[65],q[7];
cp(0) q[65],q[8];
cp(0) q[65],q[9];
cp(0) q[65],q[10];
cp(0) q[65],q[11];
cp(0) q[65],q[12];
cp(0) q[65],q[13];
cp(0) q[65],q[14];
cp(0) q[65],q[15];
cp(0) q[65],q[16];
cp(0) q[65],q[17];
cp(0) q[65],q[18];
cp(0) q[65],q[19];
cp(0) q[65],q[20];
cp(0) q[65],q[21];
cp(0) q[65],q[22];
cp(0) q[65],q[23];
cp(-pi/2199023255552) q[65],q[24];
cp(-pi/1099511627776) q[65],q[25];
cp(-pi/549755813888) q[65],q[26];
cp(-pi/274877906944) q[65],q[27];
cp(-pi/137438953472) q[65],q[28];
cp(-pi/68719476736) q[65],q[29];
cp(-pi/34359738368) q[65],q[30];
cp(-pi/17179869184) q[65],q[31];
cp(-pi/8589934592) q[65],q[32];
cp(-pi/4294967296) q[65],q[33];
cp(-pi/2147483648) q[65],q[34];
cp(-pi/1073741824) q[65],q[35];
cp(-pi/536870912) q[65],q[36];
cp(-pi/268435456) q[65],q[37];
cp(-pi/134217728) q[65],q[38];
cp(-pi/67108864) q[65],q[39];
cp(-pi/33554432) q[65],q[40];
cp(-pi/16777216) q[65],q[41];
cp(-pi/8388608) q[65],q[42];
cp(-pi/4194304) q[65],q[43];
cp(-pi/2097152) q[65],q[44];
cp(-pi/1048576) q[65],q[45];
cp(-pi/524288) q[65],q[46];
cp(-pi/262144) q[65],q[47];
cp(-pi/131072) q[65],q[48];
cp(-pi/65536) q[65],q[49];
cp(-pi/32768) q[65],q[50];
cp(-pi/16384) q[65],q[51];
cp(-pi/8192) q[65],q[52];
cp(-pi/4096) q[65],q[53];
cp(-pi/2048) q[65],q[54];
cp(-pi/1024) q[65],q[55];
cp(-pi/512) q[65],q[56];
cp(-pi/256) q[65],q[57];
cp(-pi/128) q[65],q[58];
cp(-pi/64) q[65],q[59];
cp(-pi/32) q[65],q[60];
cp(-pi/16) q[65],q[61];
cp(-pi/8) q[65],q[62];
cp(-pi/4) q[65],q[63];
cp(-pi/2) q[65],q[64];
h q[65];
cp(0) q[66],q[0];
cp(0) q[66],q[1];
cp(0) q[66],q[2];
cp(0) q[66],q[3];
cp(0) q[66],q[4];
cp(0) q[66],q[5];
cp(0) q[66],q[6];
cp(0) q[66],q[7];
cp(0) q[66],q[8];
cp(0) q[66],q[9];
cp(0) q[66],q[10];
cp(0) q[66],q[11];
cp(0) q[66],q[12];
cp(0) q[66],q[13];
cp(0) q[66],q[14];
cp(0) q[66],q[15];
cp(0) q[66],q[16];
cp(0) q[66],q[17];
cp(0) q[66],q[18];
cp(0) q[66],q[19];
cp(0) q[66],q[20];
cp(0) q[66],q[21];
cp(0) q[66],q[22];
cp(0) q[66],q[23];
cp(0) q[66],q[24];
cp(-pi/2199023255552) q[66],q[25];
cp(-pi/1099511627776) q[66],q[26];
cp(-pi/549755813888) q[66],q[27];
cp(-pi/274877906944) q[66],q[28];
cp(-pi/137438953472) q[66],q[29];
cp(-pi/68719476736) q[66],q[30];
cp(-pi/34359738368) q[66],q[31];
cp(-pi/17179869184) q[66],q[32];
cp(-pi/8589934592) q[66],q[33];
cp(-pi/4294967296) q[66],q[34];
cp(-pi/2147483648) q[66],q[35];
cp(-pi/1073741824) q[66],q[36];
cp(-pi/536870912) q[66],q[37];
cp(-pi/268435456) q[66],q[38];
cp(-pi/134217728) q[66],q[39];
cp(-pi/67108864) q[66],q[40];
cp(-pi/33554432) q[66],q[41];
cp(-pi/16777216) q[66],q[42];
cp(-pi/8388608) q[66],q[43];
cp(-pi/4194304) q[66],q[44];
cp(-pi/2097152) q[66],q[45];
cp(-pi/1048576) q[66],q[46];
cp(-pi/524288) q[66],q[47];
cp(-pi/262144) q[66],q[48];
cp(-pi/131072) q[66],q[49];
cp(-pi/65536) q[66],q[50];
cp(-pi/32768) q[66],q[51];
cp(-pi/16384) q[66],q[52];
cp(-pi/8192) q[66],q[53];
cp(-pi/4096) q[66],q[54];
cp(-pi/2048) q[66],q[55];
cp(-pi/1024) q[66],q[56];
cp(-pi/512) q[66],q[57];
cp(-pi/256) q[66],q[58];
cp(-pi/128) q[66],q[59];
cp(-pi/64) q[66],q[60];
cp(-pi/32) q[66],q[61];
cp(-pi/16) q[66],q[62];
cp(-pi/8) q[66],q[63];
cp(-pi/4) q[66],q[64];
cp(-pi/2) q[66],q[65];
h q[66];
cp(0) q[67],q[0];
cp(0) q[67],q[1];
cp(0) q[67],q[2];
cp(0) q[67],q[3];
cp(0) q[67],q[4];
cp(0) q[67],q[5];
cp(0) q[67],q[6];
cp(0) q[67],q[7];
cp(0) q[67],q[8];
cp(0) q[67],q[9];
cp(0) q[67],q[10];
cp(0) q[67],q[11];
cp(0) q[67],q[12];
cp(0) q[67],q[13];
cp(0) q[67],q[14];
cp(0) q[67],q[15];
cp(0) q[67],q[16];
cp(0) q[67],q[17];
cp(0) q[67],q[18];
cp(0) q[67],q[19];
cp(0) q[67],q[20];
cp(0) q[67],q[21];
cp(0) q[67],q[22];
cp(0) q[67],q[23];
cp(0) q[67],q[24];
cp(0) q[67],q[25];
cp(-pi/2199023255552) q[67],q[26];
cp(-pi/1099511627776) q[67],q[27];
cp(-pi/549755813888) q[67],q[28];
cp(-pi/274877906944) q[67],q[29];
cp(-pi/137438953472) q[67],q[30];
cp(-pi/68719476736) q[67],q[31];
cp(-pi/34359738368) q[67],q[32];
cp(-pi/17179869184) q[67],q[33];
cp(-pi/8589934592) q[67],q[34];
cp(-pi/4294967296) q[67],q[35];
cp(-pi/2147483648) q[67],q[36];
cp(-pi/1073741824) q[67],q[37];
cp(-pi/536870912) q[67],q[38];
cp(-pi/268435456) q[67],q[39];
cp(-pi/134217728) q[67],q[40];
cp(-pi/67108864) q[67],q[41];
cp(-pi/33554432) q[67],q[42];
cp(-pi/16777216) q[67],q[43];
cp(-pi/8388608) q[67],q[44];
cp(-pi/4194304) q[67],q[45];
cp(-pi/2097152) q[67],q[46];
cp(-pi/1048576) q[67],q[47];
cp(-pi/524288) q[67],q[48];
cp(-pi/262144) q[67],q[49];
cp(-pi/131072) q[67],q[50];
cp(-pi/65536) q[67],q[51];
cp(-pi/32768) q[67],q[52];
cp(-pi/16384) q[67],q[53];
cp(-pi/8192) q[67],q[54];
cp(-pi/4096) q[67],q[55];
cp(-pi/2048) q[67],q[56];
cp(-pi/1024) q[67],q[57];
cp(-pi/512) q[67],q[58];
cp(-pi/256) q[67],q[59];
cp(-pi/128) q[67],q[60];
cp(-pi/64) q[67],q[61];
cp(-pi/32) q[67],q[62];
cp(-pi/16) q[67],q[63];
cp(-pi/8) q[67],q[64];
cp(-pi/4) q[67],q[65];
cp(-pi/2) q[67],q[66];
h q[67];
cp(0) q[68],q[0];
cp(0) q[68],q[1];
cp(0) q[68],q[2];
cp(0) q[68],q[3];
cp(0) q[68],q[4];
cp(0) q[68],q[5];
cp(0) q[68],q[6];
cp(0) q[68],q[7];
cp(0) q[68],q[8];
cp(0) q[68],q[9];
cp(0) q[68],q[10];
cp(0) q[68],q[11];
cp(0) q[68],q[12];
cp(0) q[68],q[13];
cp(0) q[68],q[14];
cp(0) q[68],q[15];
cp(0) q[68],q[16];
cp(0) q[68],q[17];
cp(0) q[68],q[18];
cp(0) q[68],q[19];
cp(0) q[68],q[20];
cp(0) q[68],q[21];
cp(0) q[68],q[22];
cp(0) q[68],q[23];
cp(0) q[68],q[24];
cp(0) q[68],q[25];
cp(0) q[68],q[26];
cp(-pi/2199023255552) q[68],q[27];
cp(-pi/1099511627776) q[68],q[28];
cp(-pi/549755813888) q[68],q[29];
cp(-pi/274877906944) q[68],q[30];
cp(-pi/137438953472) q[68],q[31];
cp(-pi/68719476736) q[68],q[32];
cp(-pi/34359738368) q[68],q[33];
cp(-pi/17179869184) q[68],q[34];
cp(-pi/8589934592) q[68],q[35];
cp(-pi/4294967296) q[68],q[36];
cp(-pi/2147483648) q[68],q[37];
cp(-pi/1073741824) q[68],q[38];
cp(-pi/536870912) q[68],q[39];
cp(-pi/268435456) q[68],q[40];
cp(-pi/134217728) q[68],q[41];
cp(-pi/67108864) q[68],q[42];
cp(-pi/33554432) q[68],q[43];
cp(-pi/16777216) q[68],q[44];
cp(-pi/8388608) q[68],q[45];
cp(-pi/4194304) q[68],q[46];
cp(-pi/2097152) q[68],q[47];
cp(-pi/1048576) q[68],q[48];
cp(-pi/524288) q[68],q[49];
cp(-pi/262144) q[68],q[50];
cp(-pi/131072) q[68],q[51];
cp(-pi/65536) q[68],q[52];
cp(-pi/32768) q[68],q[53];
cp(-pi/16384) q[68],q[54];
cp(-pi/8192) q[68],q[55];
cp(-pi/4096) q[68],q[56];
cp(-pi/2048) q[68],q[57];
cp(-pi/1024) q[68],q[58];
cp(-pi/512) q[68],q[59];
cp(-pi/256) q[68],q[60];
cp(-pi/128) q[68],q[61];
cp(-pi/64) q[68],q[62];
cp(-pi/32) q[68],q[63];
cp(-pi/16) q[68],q[64];
cp(-pi/8) q[68],q[65];
cp(-pi/4) q[68],q[66];
cp(-pi/2) q[68],q[67];
h q[68];
cp(0) q[69],q[0];
cp(0) q[69],q[1];
cp(0) q[69],q[2];
cp(0) q[69],q[3];
cp(0) q[69],q[4];
cp(0) q[69],q[5];
cp(0) q[69],q[6];
cp(0) q[69],q[7];
cp(0) q[69],q[8];
cp(0) q[69],q[9];
cp(0) q[69],q[10];
cp(0) q[69],q[11];
cp(0) q[69],q[12];
cp(0) q[69],q[13];
cp(0) q[69],q[14];
cp(0) q[69],q[15];
cp(0) q[69],q[16];
cp(0) q[69],q[17];
cp(0) q[69],q[18];
cp(0) q[69],q[19];
cp(0) q[69],q[20];
cp(0) q[69],q[21];
cp(0) q[69],q[22];
cp(0) q[69],q[23];
cp(0) q[69],q[24];
cp(0) q[69],q[25];
cp(0) q[69],q[26];
cp(0) q[69],q[27];
cp(-pi/2199023255552) q[69],q[28];
cp(-pi/1099511627776) q[69],q[29];
cp(-pi/549755813888) q[69],q[30];
cp(-pi/274877906944) q[69],q[31];
cp(-pi/137438953472) q[69],q[32];
cp(-pi/68719476736) q[69],q[33];
cp(-pi/34359738368) q[69],q[34];
cp(-pi/17179869184) q[69],q[35];
cp(-pi/8589934592) q[69],q[36];
cp(-pi/4294967296) q[69],q[37];
cp(-pi/2147483648) q[69],q[38];
cp(-pi/1073741824) q[69],q[39];
cp(-pi/536870912) q[69],q[40];
cp(-pi/268435456) q[69],q[41];
cp(-pi/134217728) q[69],q[42];
cp(-pi/67108864) q[69],q[43];
cp(-pi/33554432) q[69],q[44];
cp(-pi/16777216) q[69],q[45];
cp(-pi/8388608) q[69],q[46];
cp(-pi/4194304) q[69],q[47];
cp(-pi/2097152) q[69],q[48];
cp(-pi/1048576) q[69],q[49];
cp(-pi/524288) q[69],q[50];
cp(-pi/262144) q[69],q[51];
cp(-pi/131072) q[69],q[52];
cp(-pi/65536) q[69],q[53];
cp(-pi/32768) q[69],q[54];
cp(-pi/16384) q[69],q[55];
cp(-pi/8192) q[69],q[56];
cp(-pi/4096) q[69],q[57];
cp(-pi/2048) q[69],q[58];
cp(-pi/1024) q[69],q[59];
cp(-pi/512) q[69],q[60];
cp(-pi/256) q[69],q[61];
cp(-pi/128) q[69],q[62];
cp(-pi/64) q[69],q[63];
cp(-pi/32) q[69],q[64];
cp(-pi/16) q[69],q[65];
cp(-pi/8) q[69],q[66];
cp(-pi/4) q[69],q[67];
cp(-pi/2) q[69],q[68];
h q[69];
cp(0) q[70],q[0];
cp(0) q[70],q[1];
cp(0) q[70],q[2];
cp(0) q[70],q[3];
cp(0) q[70],q[4];
cp(0) q[70],q[5];
cp(0) q[70],q[6];
cp(0) q[70],q[7];
cp(0) q[70],q[8];
cp(0) q[70],q[9];
cp(0) q[70],q[10];
cp(0) q[70],q[11];
cp(0) q[70],q[12];
cp(0) q[70],q[13];
cp(0) q[70],q[14];
cp(0) q[70],q[15];
cp(0) q[70],q[16];
cp(0) q[70],q[17];
cp(0) q[70],q[18];
cp(0) q[70],q[19];
cp(0) q[70],q[20];
cp(0) q[70],q[21];
cp(0) q[70],q[22];
cp(0) q[70],q[23];
cp(0) q[70],q[24];
cp(0) q[70],q[25];
cp(0) q[70],q[26];
cp(0) q[70],q[27];
cp(0) q[70],q[28];
cp(-pi/2199023255552) q[70],q[29];
cp(-pi/1099511627776) q[70],q[30];
cp(-pi/549755813888) q[70],q[31];
cp(-pi/274877906944) q[70],q[32];
cp(-pi/137438953472) q[70],q[33];
cp(-pi/68719476736) q[70],q[34];
cp(-pi/34359738368) q[70],q[35];
cp(-pi/17179869184) q[70],q[36];
cp(-pi/8589934592) q[70],q[37];
cp(-pi/4294967296) q[70],q[38];
cp(-pi/2147483648) q[70],q[39];
cp(-pi/1073741824) q[70],q[40];
cp(-pi/536870912) q[70],q[41];
cp(-pi/268435456) q[70],q[42];
cp(-pi/134217728) q[70],q[43];
cp(-pi/67108864) q[70],q[44];
cp(-pi/33554432) q[70],q[45];
cp(-pi/16777216) q[70],q[46];
cp(-pi/8388608) q[70],q[47];
cp(-pi/4194304) q[70],q[48];
cp(-pi/2097152) q[70],q[49];
cp(-pi/1048576) q[70],q[50];
cp(-pi/524288) q[70],q[51];
cp(-pi/262144) q[70],q[52];
cp(-pi/131072) q[70],q[53];
cp(-pi/65536) q[70],q[54];
cp(-pi/32768) q[70],q[55];
cp(-pi/16384) q[70],q[56];
cp(-pi/8192) q[70],q[57];
cp(-pi/4096) q[70],q[58];
cp(-pi/2048) q[70],q[59];
cp(-pi/1024) q[70],q[60];
cp(-pi/512) q[70],q[61];
cp(-pi/256) q[70],q[62];
cp(-pi/128) q[70],q[63];
cp(-pi/64) q[70],q[64];
cp(-pi/32) q[70],q[65];
cp(-pi/16) q[70],q[66];
cp(-pi/8) q[70],q[67];
cp(-pi/4) q[70],q[68];
cp(-pi/2) q[70],q[69];
h q[70];
cp(0) q[71],q[0];
cp(0) q[71],q[1];
cp(0) q[71],q[2];
cp(0) q[71],q[3];
cp(0) q[71],q[4];
cp(0) q[71],q[5];
cp(0) q[71],q[6];
cp(0) q[71],q[7];
cp(0) q[71],q[8];
cp(0) q[71],q[9];
cp(0) q[71],q[10];
cp(0) q[71],q[11];
cp(0) q[71],q[12];
cp(0) q[71],q[13];
cp(0) q[71],q[14];
cp(0) q[71],q[15];
cp(0) q[71],q[16];
cp(0) q[71],q[17];
cp(0) q[71],q[18];
cp(0) q[71],q[19];
cp(0) q[71],q[20];
cp(0) q[71],q[21];
cp(0) q[71],q[22];
cp(0) q[71],q[23];
cp(0) q[71],q[24];
cp(0) q[71],q[25];
cp(0) q[71],q[26];
cp(0) q[71],q[27];
cp(0) q[71],q[28];
cp(0) q[71],q[29];
cp(-pi/2199023255552) q[71],q[30];
cp(-pi/1099511627776) q[71],q[31];
cp(-pi/549755813888) q[71],q[32];
cp(-pi/274877906944) q[71],q[33];
cp(-pi/137438953472) q[71],q[34];
cp(-pi/68719476736) q[71],q[35];
cp(-pi/34359738368) q[71],q[36];
cp(-pi/17179869184) q[71],q[37];
cp(-pi/8589934592) q[71],q[38];
cp(-pi/4294967296) q[71],q[39];
cp(-pi/2147483648) q[71],q[40];
cp(-pi/1073741824) q[71],q[41];
cp(-pi/536870912) q[71],q[42];
cp(-pi/268435456) q[71],q[43];
cp(-pi/134217728) q[71],q[44];
cp(-pi/67108864) q[71],q[45];
cp(-pi/33554432) q[71],q[46];
cp(-pi/16777216) q[71],q[47];
cp(-pi/8388608) q[71],q[48];
cp(-pi/4194304) q[71],q[49];
cp(-pi/2097152) q[71],q[50];
cp(-pi/1048576) q[71],q[51];
cp(-pi/524288) q[71],q[52];
cp(-pi/262144) q[71],q[53];
cp(-pi/131072) q[71],q[54];
cp(-pi/65536) q[71],q[55];
cp(-pi/32768) q[71],q[56];
cp(-pi/16384) q[71],q[57];
cp(-pi/8192) q[71],q[58];
cp(-pi/4096) q[71],q[59];
cp(-pi/2048) q[71],q[60];
cp(-pi/1024) q[71],q[61];
cp(-pi/512) q[71],q[62];
cp(-pi/256) q[71],q[63];
cp(-pi/128) q[71],q[64];
cp(-pi/64) q[71],q[65];
cp(-pi/32) q[71],q[66];
cp(-pi/16) q[71],q[67];
cp(-pi/8) q[71],q[68];
cp(-pi/4) q[71],q[69];
cp(-pi/2) q[71],q[70];
h q[71];
cp(0) q[72],q[0];
cp(0) q[72],q[1];
cp(0) q[72],q[2];
cp(0) q[72],q[3];
cp(0) q[72],q[4];
cp(0) q[72],q[5];
cp(0) q[72],q[6];
cp(0) q[72],q[7];
cp(0) q[72],q[8];
cp(0) q[72],q[9];
cp(0) q[72],q[10];
cp(0) q[72],q[11];
cp(0) q[72],q[12];
cp(0) q[72],q[13];
cp(0) q[72],q[14];
cp(0) q[72],q[15];
cp(0) q[72],q[16];
cp(0) q[72],q[17];
cp(0) q[72],q[18];
cp(0) q[72],q[19];
cp(0) q[72],q[20];
cp(0) q[72],q[21];
cp(0) q[72],q[22];
cp(0) q[72],q[23];
cp(0) q[72],q[24];
cp(0) q[72],q[25];
cp(0) q[72],q[26];
cp(0) q[72],q[27];
cp(0) q[72],q[28];
cp(0) q[72],q[29];
cp(0) q[72],q[30];
cp(-pi/2199023255552) q[72],q[31];
cp(-pi/1099511627776) q[72],q[32];
cp(-pi/549755813888) q[72],q[33];
cp(-pi/274877906944) q[72],q[34];
cp(-pi/137438953472) q[72],q[35];
cp(-pi/68719476736) q[72],q[36];
cp(-pi/34359738368) q[72],q[37];
cp(-pi/17179869184) q[72],q[38];
cp(-pi/8589934592) q[72],q[39];
cp(-pi/4294967296) q[72],q[40];
cp(-pi/2147483648) q[72],q[41];
cp(-pi/1073741824) q[72],q[42];
cp(-pi/536870912) q[72],q[43];
cp(-pi/268435456) q[72],q[44];
cp(-pi/134217728) q[72],q[45];
cp(-pi/67108864) q[72],q[46];
cp(-pi/33554432) q[72],q[47];
cp(-pi/16777216) q[72],q[48];
cp(-pi/8388608) q[72],q[49];
cp(-pi/4194304) q[72],q[50];
cp(-pi/2097152) q[72],q[51];
cp(-pi/1048576) q[72],q[52];
cp(-pi/524288) q[72],q[53];
cp(-pi/262144) q[72],q[54];
cp(-pi/131072) q[72],q[55];
cp(-pi/65536) q[72],q[56];
cp(-pi/32768) q[72],q[57];
cp(-pi/16384) q[72],q[58];
cp(-pi/8192) q[72],q[59];
cp(-pi/4096) q[72],q[60];
cp(-pi/2048) q[72],q[61];
cp(-pi/1024) q[72],q[62];
cp(-pi/512) q[72],q[63];
cp(-pi/256) q[72],q[64];
cp(-pi/128) q[72],q[65];
cp(-pi/64) q[72],q[66];
cp(-pi/32) q[72],q[67];
cp(-pi/16) q[72],q[68];
cp(-pi/8) q[72],q[69];
cp(-pi/4) q[72],q[70];
cp(-pi/2) q[72],q[71];
h q[72];
cp(0) q[73],q[0];
cp(0) q[73],q[1];
cp(0) q[73],q[2];
cp(0) q[73],q[3];
cp(0) q[73],q[4];
cp(0) q[73],q[5];
cp(0) q[73],q[6];
cp(0) q[73],q[7];
cp(0) q[73],q[8];
cp(0) q[73],q[9];
cp(0) q[73],q[10];
cp(0) q[73],q[11];
cp(0) q[73],q[12];
cp(0) q[73],q[13];
cp(0) q[73],q[14];
cp(0) q[73],q[15];
cp(0) q[73],q[16];
cp(0) q[73],q[17];
cp(0) q[73],q[18];
cp(0) q[73],q[19];
cp(0) q[73],q[20];
cp(0) q[73],q[21];
cp(0) q[73],q[22];
cp(0) q[73],q[23];
cp(0) q[73],q[24];
cp(0) q[73],q[25];
cp(0) q[73],q[26];
cp(0) q[73],q[27];
cp(0) q[73],q[28];
cp(0) q[73],q[29];
cp(0) q[73],q[30];
cp(0) q[73],q[31];
cp(-pi/2199023255552) q[73],q[32];
cp(-pi/1099511627776) q[73],q[33];
cp(-pi/549755813888) q[73],q[34];
cp(-pi/274877906944) q[73],q[35];
cp(-pi/137438953472) q[73],q[36];
cp(-pi/68719476736) q[73],q[37];
cp(-pi/34359738368) q[73],q[38];
cp(-pi/17179869184) q[73],q[39];
cp(-pi/8589934592) q[73],q[40];
cp(-pi/4294967296) q[73],q[41];
cp(-pi/2147483648) q[73],q[42];
cp(-pi/1073741824) q[73],q[43];
cp(-pi/536870912) q[73],q[44];
cp(-pi/268435456) q[73],q[45];
cp(-pi/134217728) q[73],q[46];
cp(-pi/67108864) q[73],q[47];
cp(-pi/33554432) q[73],q[48];
cp(-pi/16777216) q[73],q[49];
cp(-pi/8388608) q[73],q[50];
cp(-pi/4194304) q[73],q[51];
cp(-pi/2097152) q[73],q[52];
cp(-pi/1048576) q[73],q[53];
cp(-pi/524288) q[73],q[54];
cp(-pi/262144) q[73],q[55];
cp(-pi/131072) q[73],q[56];
cp(-pi/65536) q[73],q[57];
cp(-pi/32768) q[73],q[58];
cp(-pi/16384) q[73],q[59];
cp(-pi/8192) q[73],q[60];
cp(-pi/4096) q[73],q[61];
cp(-pi/2048) q[73],q[62];
cp(-pi/1024) q[73],q[63];
cp(-pi/512) q[73],q[64];
cp(-pi/256) q[73],q[65];
cp(-pi/128) q[73],q[66];
cp(-pi/64) q[73],q[67];
cp(-pi/32) q[73],q[68];
cp(-pi/16) q[73],q[69];
cp(-pi/8) q[73],q[70];
cp(-pi/4) q[73],q[71];
cp(-pi/2) q[73],q[72];
h q[73];
cp(0) q[74],q[0];
cp(0) q[74],q[1];
cp(0) q[74],q[2];
cp(0) q[74],q[3];
cp(0) q[74],q[4];
cp(0) q[74],q[5];
cp(0) q[74],q[6];
cp(0) q[74],q[7];
cp(0) q[74],q[8];
cp(0) q[74],q[9];
cp(0) q[74],q[10];
cp(0) q[74],q[11];
cp(0) q[74],q[12];
cp(0) q[74],q[13];
cp(0) q[74],q[14];
cp(0) q[74],q[15];
cp(0) q[74],q[16];
cp(0) q[74],q[17];
cp(0) q[74],q[18];
cp(0) q[74],q[19];
cp(0) q[74],q[20];
cp(0) q[74],q[21];
cp(0) q[74],q[22];
cp(0) q[74],q[23];
cp(0) q[74],q[24];
cp(0) q[74],q[25];
cp(0) q[74],q[26];
cp(0) q[74],q[27];
cp(0) q[74],q[28];
cp(0) q[74],q[29];
cp(0) q[74],q[30];
cp(0) q[74],q[31];
cp(0) q[74],q[32];
cp(-pi/2199023255552) q[74],q[33];
cp(-pi/1099511627776) q[74],q[34];
cp(-pi/549755813888) q[74],q[35];
cp(-pi/274877906944) q[74],q[36];
cp(-pi/137438953472) q[74],q[37];
cp(-pi/68719476736) q[74],q[38];
cp(-pi/34359738368) q[74],q[39];
cp(-pi/17179869184) q[74],q[40];
cp(-pi/8589934592) q[74],q[41];
cp(-pi/4294967296) q[74],q[42];
cp(-pi/2147483648) q[74],q[43];
cp(-pi/1073741824) q[74],q[44];
cp(-pi/536870912) q[74],q[45];
cp(-pi/268435456) q[74],q[46];
cp(-pi/134217728) q[74],q[47];
cp(-pi/67108864) q[74],q[48];
cp(-pi/33554432) q[74],q[49];
cp(-pi/16777216) q[74],q[50];
cp(-pi/8388608) q[74],q[51];
cp(-pi/4194304) q[74],q[52];
cp(-pi/2097152) q[74],q[53];
cp(-pi/1048576) q[74],q[54];
cp(-pi/524288) q[74],q[55];
cp(-pi/262144) q[74],q[56];
cp(-pi/131072) q[74],q[57];
cp(-pi/65536) q[74],q[58];
cp(-pi/32768) q[74],q[59];
cp(-pi/16384) q[74],q[60];
cp(-pi/8192) q[74],q[61];
cp(-pi/4096) q[74],q[62];
cp(-pi/2048) q[74],q[63];
cp(-pi/1024) q[74],q[64];
cp(-pi/512) q[74],q[65];
cp(-pi/256) q[74],q[66];
cp(-pi/128) q[74],q[67];
cp(-pi/64) q[74],q[68];
cp(-pi/32) q[74],q[69];
cp(-pi/16) q[74],q[70];
cp(-pi/8) q[74],q[71];
cp(-pi/4) q[74],q[72];
cp(-pi/2) q[74],q[73];
h q[74];
cp(0) q[75],q[0];
cp(0) q[75],q[1];
cp(0) q[75],q[2];
cp(0) q[75],q[3];
cp(0) q[75],q[4];
cp(0) q[75],q[5];
cp(0) q[75],q[6];
cp(0) q[75],q[7];
cp(0) q[75],q[8];
cp(0) q[75],q[9];
cp(0) q[75],q[10];
cp(0) q[75],q[11];
cp(0) q[75],q[12];
cp(0) q[75],q[13];
cp(0) q[75],q[14];
cp(0) q[75],q[15];
cp(0) q[75],q[16];
cp(0) q[75],q[17];
cp(0) q[75],q[18];
cp(0) q[75],q[19];
cp(0) q[75],q[20];
cp(0) q[75],q[21];
cp(0) q[75],q[22];
cp(0) q[75],q[23];
cp(0) q[75],q[24];
cp(0) q[75],q[25];
cp(0) q[75],q[26];
cp(0) q[75],q[27];
cp(0) q[75],q[28];
cp(0) q[75],q[29];
cp(0) q[75],q[30];
cp(0) q[75],q[31];
cp(0) q[75],q[32];
cp(0) q[75],q[33];
cp(-pi/2199023255552) q[75],q[34];
cp(-pi/1099511627776) q[75],q[35];
cp(-pi/549755813888) q[75],q[36];
cp(-pi/274877906944) q[75],q[37];
cp(-pi/137438953472) q[75],q[38];
cp(-pi/68719476736) q[75],q[39];
cp(-pi/34359738368) q[75],q[40];
cp(-pi/17179869184) q[75],q[41];
cp(-pi/8589934592) q[75],q[42];
cp(-pi/4294967296) q[75],q[43];
cp(-pi/2147483648) q[75],q[44];
cp(-pi/1073741824) q[75],q[45];
cp(-pi/536870912) q[75],q[46];
cp(-pi/268435456) q[75],q[47];
cp(-pi/134217728) q[75],q[48];
cp(-pi/67108864) q[75],q[49];
cp(-pi/33554432) q[75],q[50];
cp(-pi/16777216) q[75],q[51];
cp(-pi/8388608) q[75],q[52];
cp(-pi/4194304) q[75],q[53];
cp(-pi/2097152) q[75],q[54];
cp(-pi/1048576) q[75],q[55];
cp(-pi/524288) q[75],q[56];
cp(-pi/262144) q[75],q[57];
cp(-pi/131072) q[75],q[58];
cp(-pi/65536) q[75],q[59];
cp(-pi/32768) q[75],q[60];
cp(-pi/16384) q[75],q[61];
cp(-pi/8192) q[75],q[62];
cp(-pi/4096) q[75],q[63];
cp(-pi/2048) q[75],q[64];
cp(-pi/1024) q[75],q[65];
cp(-pi/512) q[75],q[66];
cp(-pi/256) q[75],q[67];
cp(-pi/128) q[75],q[68];
cp(-pi/64) q[75],q[69];
cp(-pi/32) q[75],q[70];
cp(-pi/16) q[75],q[71];
cp(-pi/8) q[75],q[72];
cp(-pi/4) q[75],q[73];
cp(-pi/2) q[75],q[74];
h q[75];
cp(0) q[76],q[0];
cp(0) q[76],q[1];
cp(0) q[76],q[2];
cp(0) q[76],q[3];
cp(0) q[76],q[4];
cp(0) q[76],q[5];
cp(0) q[76],q[6];
cp(0) q[76],q[7];
cp(0) q[76],q[8];
cp(0) q[76],q[9];
cp(0) q[76],q[10];
cp(0) q[76],q[11];
cp(0) q[76],q[12];
cp(0) q[76],q[13];
cp(0) q[76],q[14];
cp(0) q[76],q[15];
cp(0) q[76],q[16];
cp(0) q[76],q[17];
cp(0) q[76],q[18];
cp(0) q[76],q[19];
cp(0) q[76],q[20];
cp(0) q[76],q[21];
cp(0) q[76],q[22];
cp(0) q[76],q[23];
cp(0) q[76],q[24];
cp(0) q[76],q[25];
cp(0) q[76],q[26];
cp(0) q[76],q[27];
cp(0) q[76],q[28];
cp(0) q[76],q[29];
cp(0) q[76],q[30];
cp(0) q[76],q[31];
cp(0) q[76],q[32];
cp(0) q[76],q[33];
cp(0) q[76],q[34];
cp(-pi/2199023255552) q[76],q[35];
cp(-pi/1099511627776) q[76],q[36];
cp(-pi/549755813888) q[76],q[37];
cp(-pi/274877906944) q[76],q[38];
cp(-pi/137438953472) q[76],q[39];
cp(-pi/68719476736) q[76],q[40];
cp(-pi/34359738368) q[76],q[41];
cp(-pi/17179869184) q[76],q[42];
cp(-pi/8589934592) q[76],q[43];
cp(-pi/4294967296) q[76],q[44];
cp(-pi/2147483648) q[76],q[45];
cp(-pi/1073741824) q[76],q[46];
cp(-pi/536870912) q[76],q[47];
cp(-pi/268435456) q[76],q[48];
cp(-pi/134217728) q[76],q[49];
cp(-pi/67108864) q[76],q[50];
cp(-pi/33554432) q[76],q[51];
cp(-pi/16777216) q[76],q[52];
cp(-pi/8388608) q[76],q[53];
cp(-pi/4194304) q[76],q[54];
cp(-pi/2097152) q[76],q[55];
cp(-pi/1048576) q[76],q[56];
cp(-pi/524288) q[76],q[57];
cp(-pi/262144) q[76],q[58];
cp(-pi/131072) q[76],q[59];
cp(-pi/65536) q[76],q[60];
cp(-pi/32768) q[76],q[61];
cp(-pi/16384) q[76],q[62];
cp(-pi/8192) q[76],q[63];
cp(-pi/4096) q[76],q[64];
cp(-pi/2048) q[76],q[65];
cp(-pi/1024) q[76],q[66];
cp(-pi/512) q[76],q[67];
cp(-pi/256) q[76],q[68];
cp(-pi/128) q[76],q[69];
cp(-pi/64) q[76],q[70];
cp(-pi/32) q[76],q[71];
cp(-pi/16) q[76],q[72];
cp(-pi/8) q[76],q[73];
cp(-pi/4) q[76],q[74];
cp(-pi/2) q[76],q[75];
h q[76];
cp(0) q[77],q[0];
cp(0) q[77],q[1];
cp(0) q[77],q[2];
cp(0) q[77],q[3];
cp(0) q[77],q[4];
cp(0) q[77],q[5];
cp(0) q[77],q[6];
cp(0) q[77],q[7];
cp(0) q[77],q[8];
cp(0) q[77],q[9];
cp(0) q[77],q[10];
cp(0) q[77],q[11];
cp(0) q[77],q[12];
cp(0) q[77],q[13];
cp(0) q[77],q[14];
cp(0) q[77],q[15];
cp(0) q[77],q[16];
cp(0) q[77],q[17];
cp(0) q[77],q[18];
cp(0) q[77],q[19];
cp(0) q[77],q[20];
cp(0) q[77],q[21];
cp(0) q[77],q[22];
cp(0) q[77],q[23];
cp(0) q[77],q[24];
cp(0) q[77],q[25];
cp(0) q[77],q[26];
cp(0) q[77],q[27];
cp(0) q[77],q[28];
cp(0) q[77],q[29];
cp(0) q[77],q[30];
cp(0) q[77],q[31];
cp(0) q[77],q[32];
cp(0) q[77],q[33];
cp(0) q[77],q[34];
cp(0) q[77],q[35];
cp(-pi/2199023255552) q[77],q[36];
cp(-pi/1099511627776) q[77],q[37];
cp(-pi/549755813888) q[77],q[38];
cp(-pi/274877906944) q[77],q[39];
cp(-pi/137438953472) q[77],q[40];
cp(-pi/68719476736) q[77],q[41];
cp(-pi/34359738368) q[77],q[42];
cp(-pi/17179869184) q[77],q[43];
cp(-pi/8589934592) q[77],q[44];
cp(-pi/4294967296) q[77],q[45];
cp(-pi/2147483648) q[77],q[46];
cp(-pi/1073741824) q[77],q[47];
cp(-pi/536870912) q[77],q[48];
cp(-pi/268435456) q[77],q[49];
cp(-pi/134217728) q[77],q[50];
cp(-pi/67108864) q[77],q[51];
cp(-pi/33554432) q[77],q[52];
cp(-pi/16777216) q[77],q[53];
cp(-pi/8388608) q[77],q[54];
cp(-pi/4194304) q[77],q[55];
cp(-pi/2097152) q[77],q[56];
cp(-pi/1048576) q[77],q[57];
cp(-pi/524288) q[77],q[58];
cp(-pi/262144) q[77],q[59];
cp(-pi/131072) q[77],q[60];
cp(-pi/65536) q[77],q[61];
cp(-pi/32768) q[77],q[62];
cp(-pi/16384) q[77],q[63];
cp(-pi/8192) q[77],q[64];
cp(-pi/4096) q[77],q[65];
cp(-pi/2048) q[77],q[66];
cp(-pi/1024) q[77],q[67];
cp(-pi/512) q[77],q[68];
cp(-pi/256) q[77],q[69];
cp(-pi/128) q[77],q[70];
cp(-pi/64) q[77],q[71];
cp(-pi/32) q[77],q[72];
cp(-pi/16) q[77],q[73];
cp(-pi/8) q[77],q[74];
cp(-pi/4) q[77],q[75];
cp(-pi/2) q[77],q[76];
h q[77];
cp(0) q[78],q[0];
cp(0) q[78],q[1];
cp(0) q[78],q[2];
cp(0) q[78],q[3];
cp(0) q[78],q[4];
cp(0) q[78],q[5];
cp(0) q[78],q[6];
cp(0) q[78],q[7];
cp(0) q[78],q[8];
cp(0) q[78],q[9];
cp(0) q[78],q[10];
cp(0) q[78],q[11];
cp(0) q[78],q[12];
cp(0) q[78],q[13];
cp(0) q[78],q[14];
cp(0) q[78],q[15];
cp(0) q[78],q[16];
cp(0) q[78],q[17];
cp(0) q[78],q[18];
cp(0) q[78],q[19];
cp(0) q[78],q[20];
cp(0) q[78],q[21];
cp(0) q[78],q[22];
cp(0) q[78],q[23];
cp(0) q[78],q[24];
cp(0) q[78],q[25];
cp(0) q[78],q[26];
cp(0) q[78],q[27];
cp(0) q[78],q[28];
cp(0) q[78],q[29];
cp(0) q[78],q[30];
cp(0) q[78],q[31];
cp(0) q[78],q[32];
cp(0) q[78],q[33];
cp(0) q[78],q[34];
cp(0) q[78],q[35];
cp(0) q[78],q[36];
cp(-pi/2199023255552) q[78],q[37];
cp(-pi/1099511627776) q[78],q[38];
cp(-pi/549755813888) q[78],q[39];
cp(-pi/274877906944) q[78],q[40];
cp(-pi/137438953472) q[78],q[41];
cp(-pi/68719476736) q[78],q[42];
cp(-pi/34359738368) q[78],q[43];
cp(-pi/17179869184) q[78],q[44];
cp(-pi/8589934592) q[78],q[45];
cp(-pi/4294967296) q[78],q[46];
cp(-pi/2147483648) q[78],q[47];
cp(-pi/1073741824) q[78],q[48];
cp(-pi/536870912) q[78],q[49];
cp(-pi/268435456) q[78],q[50];
cp(-pi/134217728) q[78],q[51];
cp(-pi/67108864) q[78],q[52];
cp(-pi/33554432) q[78],q[53];
cp(-pi/16777216) q[78],q[54];
cp(-pi/8388608) q[78],q[55];
cp(-pi/4194304) q[78],q[56];
cp(-pi/2097152) q[78],q[57];
cp(-pi/1048576) q[78],q[58];
cp(-pi/524288) q[78],q[59];
cp(-pi/262144) q[78],q[60];
cp(-pi/131072) q[78],q[61];
cp(-pi/65536) q[78],q[62];
cp(-pi/32768) q[78],q[63];
cp(-pi/16384) q[78],q[64];
cp(-pi/8192) q[78],q[65];
cp(-pi/4096) q[78],q[66];
cp(-pi/2048) q[78],q[67];
cp(-pi/1024) q[78],q[68];
cp(-pi/512) q[78],q[69];
cp(-pi/256) q[78],q[70];
cp(-pi/128) q[78],q[71];
cp(-pi/64) q[78],q[72];
cp(-pi/32) q[78],q[73];
cp(-pi/16) q[78],q[74];
cp(-pi/8) q[78],q[75];
cp(-pi/4) q[78],q[76];
cp(-pi/2) q[78],q[77];
h q[78];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],psi[0];
measure q[0] -> c[0];
measure q[1] -> c[1];
measure q[2] -> c[2];
measure q[3] -> c[3];
measure q[4] -> c[4];
measure q[5] -> c[5];
measure q[6] -> c[6];
measure q[7] -> c[7];
measure q[8] -> c[8];
measure q[9] -> c[9];
measure q[10] -> c[10];
measure q[11] -> c[11];
measure q[12] -> c[12];
measure q[13] -> c[13];
measure q[14] -> c[14];
measure q[15] -> c[15];
measure q[16] -> c[16];
measure q[17] -> c[17];
measure q[18] -> c[18];
measure q[19] -> c[19];
measure q[20] -> c[20];
measure q[21] -> c[21];
measure q[22] -> c[22];
measure q[23] -> c[23];
measure q[24] -> c[24];
measure q[25] -> c[25];
measure q[26] -> c[26];
measure q[27] -> c[27];
measure q[28] -> c[28];
measure q[29] -> c[29];
measure q[30] -> c[30];
measure q[31] -> c[31];
measure q[32] -> c[32];
measure q[33] -> c[33];
measure q[34] -> c[34];
measure q[35] -> c[35];
measure q[36] -> c[36];
measure q[37] -> c[37];
measure q[38] -> c[38];
measure q[39] -> c[39];
measure q[40] -> c[40];
measure q[41] -> c[41];
measure q[42] -> c[42];
measure q[43] -> c[43];
measure q[44] -> c[44];
measure q[45] -> c[45];
measure q[46] -> c[46];
measure q[47] -> c[47];
measure q[48] -> c[48];
measure q[49] -> c[49];
measure q[50] -> c[50];
measure q[51] -> c[51];
measure q[52] -> c[52];
measure q[53] -> c[53];
measure q[54] -> c[54];
measure q[55] -> c[55];
measure q[56] -> c[56];
measure q[57] -> c[57];
measure q[58] -> c[58];
measure q[59] -> c[59];
measure q[60] -> c[60];
measure q[61] -> c[61];
measure q[62] -> c[62];
measure q[63] -> c[63];
measure q[64] -> c[64];
measure q[65] -> c[65];
measure q[66] -> c[66];
measure q[67] -> c[67];
measure q[68] -> c[68];
measure q[69] -> c[69];
measure q[70] -> c[70];
measure q[71] -> c[71];
measure q[72] -> c[72];
measure q[73] -> c[73];
measure q[74] -> c[74];
measure q[75] -> c[75];
measure q[76] -> c[76];
measure q[77] -> c[77];
measure q[78] -> c[78];
'''

# %%
benchmarks['qpe-120'] = '''
// Benchmark was created by MQT Bench on 2024-03-18
// For more information about MQT Bench, please visit https://www.cda.cit.tum.de/mqtbench/
// MQT Bench version: 1.1.0
// Qiskit version: 1.0.2

OPENQASM 2.0;
include "qelib1.inc";
qreg q[119];
qreg psi[1];
creg c[119];
h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
h q[8];
h q[9];
h q[10];
h q[11];
h q[12];
h q[13];
h q[14];
h q[15];
h q[16];
h q[17];
h q[18];
h q[19];
h q[20];
h q[21];
h q[22];
h q[23];
h q[24];
h q[25];
h q[26];
h q[27];
h q[28];
h q[29];
h q[30];
h q[31];
h q[32];
h q[33];
h q[34];
h q[35];
h q[36];
h q[37];
h q[38];
h q[39];
h q[40];
h q[41];
h q[42];
h q[43];
h q[44];
h q[45];
h q[46];
h q[47];
h q[48];
h q[49];
h q[50];
h q[51];
h q[52];
h q[53];
h q[54];
h q[55];
h q[56];
h q[57];
h q[58];
h q[59];
h q[60];
h q[61];
h q[62];
h q[63];
h q[64];
h q[65];
h q[66];
h q[67];
h q[68];
h q[69];
h q[70];
h q[71];
h q[72];
h q[73];
h q[74];
h q[75];
h q[76];
h q[77];
h q[78];
h q[79];
h q[80];
h q[81];
h q[82];
h q[83];
h q[84];
h q[85];
h q[86];
h q[87];
h q[88];
h q[89];
h q[90];
h q[91];
h q[92];
h q[93];
h q[94];
h q[95];
h q[96];
h q[97];
h q[98];
h q[99];
h q[100];
h q[101];
h q[102];
h q[103];
h q[104];
h q[105];
h q[106];
h q[107];
h q[108];
h q[109];
h q[110];
h q[111];
h q[112];
h q[113];
h q[114];
h q[115];
h q[116];
h q[117];
h q[118];
x psi[0];
cp(3.032024202580275) psi[0],q[0];
cp(-0.21913690201903607) psi[0],q[1];
cp(-0.43827380403807215) psi[0],q[2];
cp(-0.8765476080761443) psi[0],q[3];
cp(-1.7530952161522886) psi[0],q[4];
cp(2.7769948748750095) psi[0],q[5];
cp(-0.7291955574295674) psi[0],q[6];
cp(-1.4583911148591349) psi[0],q[7];
cp(-2.9167822297182697) psi[0],q[8];
cp(0.44962084774304706) psi[0],q[9];
cp(0.8992416954860941) psi[0],q[10];
cp(1.7984833909721882) psi[0],q[11];
cp(-2.6862185252352093) psi[0],q[12];
cp(0.9107482567091676) psi[0],q[13];
cp(1.8214965134183352) psi[0],q[14];
cp(-2.640192280342916) psi[0],q[15];
cp(1.0028007464937543) psi[0],q[16];
cp(2.0056014929875086) psi[0],q[17];
cp(-2.2719823212045687) psi[0],q[18];
cp(1.7392206647704491) psi[0],q[19];
cp(-2.804743977638688) psi[0],q[20];
cp(0.6736973519022098) psi[0],q[21];
cp(1.3473947038044196) psi[0],q[22];
cp(2.6947894076088392) psi[0],q[23];
cp(-0.8936064919619078) psi[0],q[24];
cp(-1.7872129839238156) psi[0],q[25];
cp(2.7087593393319547) psi[0],q[26];
cp(-0.8656666285156766) psi[0],q[27];
cp(-1.731333257031353) psi[0],q[28];
cp(2.8205187931168796) psi[0],q[29];
cp(-0.6421477209458266) psi[0],q[30];
cp(-1.2842954418916532) psi[0],q[31];
cp(-2.5685908837833065) psi[0],q[32];
cp(1.1460035396129726) psi[0],q[33];
cp(2.2920070792259453) psi[0],q[34];
cp(-1.6991711487276955) psi[0],q[35];
cp(2.8848430097241957) psi[0],q[36];
cp(-0.5134992877311951) psi[0],q[37];
cp(-1.0269985754623903) psi[0],q[38];
cp(-2.0539971509247805) psi[0],q[39];
cp(2.175191005330025) psi[0],q[40];
cp(-1.9328032965195359) psi[0],q[41];
cp(2.417578714140515) psi[0],q[42];
cp(-1.4480278788985568) psi[0],q[43];
cp(-2.8960557577971136) psi[0],q[44];
cp(0.49107379158535974) psi[0],q[45];
cp(0.9821475831707195) psi[0],q[46];
cp(1.964295166341439) psi[0],q[47];
cp(-2.3545949744967083) psi[0],q[48];
cp(1.5739953581861694) psi[0],q[49];
cp(-3.135194590807247) psi[0],q[50];
cp(0.012796125565091895) psi[0],q[51];
cp(0.02559225113018379) psi[0],q[52];
cp(0.05118450226036758) psi[0],q[53];
cp(0.10236900452073516) psi[0],q[54];
cp(0.20473800904147033) psi[0],q[55];
cp(0.40947601808294065) psi[0],q[56];
cp(0.8189520361658813) psi[0],q[57];
cp(1.6379040723317626) psi[0],q[58];
cp(-3.0073771625160615) psi[0],q[59];
cp(0.26843098214746364) psi[0],q[60];
swap q[58],q[60];
cp(0.5368619642949273) psi[0],q[61];
swap q[57],q[61];
cp(1.0737239285898545) psi[0],q[62];
swap q[56],q[62];
cp(2.147447857179709) psi[0],q[63];
swap q[55],q[63];
cp(-1.9882895928201683) psi[0],q[64];
swap q[54],q[64];
cp(2.3066061215392497) psi[0],q[65];
swap q[53],q[65];
cp(-1.669973064101087) psi[0],q[66];
swap q[52],q[66];
cp(2.943239178977412) psi[0],q[67];
swap q[51],q[67];
cp(-0.39670694922476224) psi[0],q[68];
swap q[50],q[68];
cp(-0.7934138984495245) psi[0],q[69];
swap q[49],q[69];
cp(-1.586827796899049) psi[0],q[70];
swap q[48],q[70];
cp(3.1095297133814883) psi[0],q[71];
swap q[47],q[71];
cp(-0.06412588041660923) psi[0],q[72];
swap q[46],q[72];
cp(-0.12825176083321846) psi[0],q[73];
swap q[45],q[73];
cp(-0.2565035216664369) psi[0],q[74];
swap q[44],q[74];
cp(-0.5130070433328738) psi[0],q[75];
swap q[43],q[75];
cp(-1.0260140866657477) psi[0],q[76];
swap q[42],q[76];
cp(-2.0520281733314953) psi[0],q[77];
swap q[41],q[77];
cp(2.179128960516595) psi[0],q[78];
swap q[40],q[78];
cp(-1.9249273861463958) psi[0],q[79];
swap q[39],q[79];
cp(2.4333305348867946) psi[0],q[80];
swap q[38],q[80];
cp(-1.416524237405997) psi[0],q[81];
swap q[37],q[81];
cp(-2.833048474811994) psi[0],q[82];
swap q[36],q[82];
cp(0.6170883575555981) psi[0],q[83];
swap q[35],q[83];
cp(1.2341767151111962) psi[0],q[84];
swap q[34],q[84];
cp(2.4683534302223924) psi[0],q[85];
swap q[33],q[85];
cp(-1.3464784467348012) psi[0],q[86];
swap q[32],q[86];
cp(-2.6929568934696024) psi[0],q[87];
swap q[31],q[87];
cp(0.8972715202403814) psi[0],q[88];
swap q[30],q[88];
cp(1.7945430404807627) psi[0],q[89];
swap q[29],q[89];
cp(-2.6940992262180607) psi[0],q[90];
swap q[28],q[90];
cp(0.8949868547434644) psi[0],q[91];
swap q[27],q[91];
cp(1.7899737094869288) psi[0],q[92];
swap q[26],q[92];
cp(-2.7032378882057286) psi[0],q[93];
swap q[25],q[93];
cp(0.8767095307681287) psi[0],q[94];
swap q[24],q[94];
cp(1.7534190615362575) psi[0],q[95];
swap q[23],q[95];
cp(-2.7763471841070713) psi[0],q[96];
swap q[22],q[96];
cp(0.7304909389654439) psi[0],q[97];
swap q[21],q[97];
cp(1.4609818779308879) psi[0],q[98];
swap q[20],q[98];
cp(2.9219637558617757) psi[0],q[99];
swap q[19],q[99];
cp(-0.43925779545603444) psi[0],q[100];
swap q[18],q[100];
cp(-0.8785155909120689) psi[0],q[101];
swap q[17],q[101];
cp(-1.7570311818241378) psi[0],q[102];
swap q[16],q[102];
cp(2.7691229435313107) psi[0],q[103];
swap q[15],q[103];
cp(-0.7449394201169645) psi[0],q[104];
swap q[14],q[104];
cp(-1.489878840233929) psi[0],q[105];
swap q[13],q[105];
cp(-2.979757680467858) psi[0],q[106];
swap q[12],q[106];
cp(0.3236699462438703) psi[0],q[107];
swap q[11],q[107];
cp(0.6473398924877406) psi[0],q[108];
swap q[10],q[108];
cp(1.2946797849754812) psi[0],q[109];
swap q[9],q[109];
cp(2.5893595699509624) psi[0],q[110];
swap q[8],q[110];
cp(-1.1044661672776617) psi[0],q[111];
swap q[7],q[111];
cp(-2.2089323345553233) psi[0],q[112];
swap q[6],q[112];
cp(1.8653206380689396) psi[0],q[113];
swap q[5],q[113];
cp(-13*pi/16) psi[0],q[114];
swap q[4],q[114];
cp(3*pi/8) psi[0],q[115];
swap q[3],q[115];
cp(3*pi/4) psi[0],q[116];
swap q[2],q[116];
cp(-pi/2) psi[0],q[117];
swap q[1],q[117];
cp(pi) psi[0],q[118];
swap q[0],q[118];
h q[0];
cp(-pi/2) q[1],q[0];
h q[1];
cp(-pi/4) q[2],q[0];
cp(-pi/2) q[2],q[1];
h q[2];
cp(-pi/8) q[3],q[0];
cp(-pi/4) q[3],q[1];
cp(-pi/2) q[3],q[2];
h q[3];
cp(-pi/16) q[4],q[0];
cp(-pi/8) q[4],q[1];
cp(-pi/4) q[4],q[2];
cp(-pi/2) q[4],q[3];
h q[4];
cp(-pi/32) q[5],q[0];
cp(-pi/16) q[5],q[1];
cp(-pi/8) q[5],q[2];
cp(-pi/4) q[5],q[3];
cp(-pi/2) q[5],q[4];
h q[5];
cp(-pi/64) q[6],q[0];
cp(-pi/32) q[6],q[1];
cp(-pi/16) q[6],q[2];
cp(-pi/8) q[6],q[3];
cp(-pi/4) q[6],q[4];
cp(-pi/2) q[6],q[5];
h q[6];
cp(-pi/128) q[7],q[0];
cp(-pi/64) q[7],q[1];
cp(-pi/32) q[7],q[2];
cp(-pi/16) q[7],q[3];
cp(-pi/8) q[7],q[4];
cp(-pi/4) q[7],q[5];
cp(-pi/2) q[7],q[6];
h q[7];
cp(-pi/256) q[8],q[0];
cp(-pi/128) q[8],q[1];
cp(-pi/64) q[8],q[2];
cp(-pi/32) q[8],q[3];
cp(-pi/16) q[8],q[4];
cp(-pi/8) q[8],q[5];
cp(-pi/4) q[8],q[6];
cp(-pi/2) q[8],q[7];
h q[8];
cp(-pi/512) q[9],q[0];
cp(-pi/256) q[9],q[1];
cp(-pi/128) q[9],q[2];
cp(-pi/64) q[9],q[3];
cp(-pi/32) q[9],q[4];
cp(-pi/16) q[9],q[5];
cp(-pi/8) q[9],q[6];
cp(-pi/4) q[9],q[7];
cp(-pi/2) q[9],q[8];
h q[9];
cp(-pi/1024) q[10],q[0];
cp(-pi/512) q[10],q[1];
cp(-pi/256) q[10],q[2];
cp(-pi/128) q[10],q[3];
cp(-pi/64) q[10],q[4];
cp(-pi/32) q[10],q[5];
cp(-pi/16) q[10],q[6];
cp(-pi/8) q[10],q[7];
cp(-pi/4) q[10],q[8];
cp(-pi/2) q[10],q[9];
h q[10];
cp(-pi/2048) q[11],q[0];
cp(-pi/1024) q[11],q[1];
cp(-pi/512) q[11],q[2];
cp(-pi/256) q[11],q[3];
cp(-pi/128) q[11],q[4];
cp(-pi/64) q[11],q[5];
cp(-pi/32) q[11],q[6];
cp(-pi/16) q[11],q[7];
cp(-pi/8) q[11],q[8];
cp(-pi/4) q[11],q[9];
cp(-pi/2) q[11],q[10];
h q[11];
cp(-pi/4096) q[12],q[0];
cp(-pi/2048) q[12],q[1];
cp(-pi/1024) q[12],q[2];
cp(-pi/512) q[12],q[3];
cp(-pi/256) q[12],q[4];
cp(-pi/128) q[12],q[5];
cp(-pi/64) q[12],q[6];
cp(-pi/32) q[12],q[7];
cp(-pi/16) q[12],q[8];
cp(-pi/8) q[12],q[9];
cp(-pi/4) q[12],q[10];
cp(-pi/2) q[12],q[11];
h q[12];
cp(-pi/8192) q[13],q[0];
cp(-pi/4096) q[13],q[1];
cp(-pi/2048) q[13],q[2];
cp(-pi/1024) q[13],q[3];
cp(-pi/512) q[13],q[4];
cp(-pi/256) q[13],q[5];
cp(-pi/128) q[13],q[6];
cp(-pi/64) q[13],q[7];
cp(-pi/32) q[13],q[8];
cp(-pi/16) q[13],q[9];
cp(-pi/8) q[13],q[10];
cp(-pi/4) q[13],q[11];
cp(-pi/2) q[13],q[12];
h q[13];
cp(-pi/16384) q[14],q[0];
cp(-pi/8192) q[14],q[1];
cp(-pi/4096) q[14],q[2];
cp(-pi/2048) q[14],q[3];
cp(-pi/1024) q[14],q[4];
cp(-pi/512) q[14],q[5];
cp(-pi/256) q[14],q[6];
cp(-pi/128) q[14],q[7];
cp(-pi/64) q[14],q[8];
cp(-pi/32) q[14],q[9];
cp(-pi/16) q[14],q[10];
cp(-pi/8) q[14],q[11];
cp(-pi/4) q[14],q[12];
cp(-pi/2) q[14],q[13];
h q[14];
cp(-pi/32768) q[15],q[0];
cp(-pi/16384) q[15],q[1];
cp(-pi/8192) q[15],q[2];
cp(-pi/4096) q[15],q[3];
cp(-pi/2048) q[15],q[4];
cp(-pi/1024) q[15],q[5];
cp(-pi/512) q[15],q[6];
cp(-pi/256) q[15],q[7];
cp(-pi/128) q[15],q[8];
cp(-pi/64) q[15],q[9];
cp(-pi/32) q[15],q[10];
cp(-pi/16) q[15],q[11];
cp(-pi/8) q[15],q[12];
cp(-pi/4) q[15],q[13];
cp(-pi/2) q[15],q[14];
h q[15];
cp(-pi/65536) q[16],q[0];
cp(-pi/32768) q[16],q[1];
cp(-pi/16384) q[16],q[2];
cp(-pi/8192) q[16],q[3];
cp(-pi/4096) q[16],q[4];
cp(-pi/2048) q[16],q[5];
cp(-pi/1024) q[16],q[6];
cp(-pi/512) q[16],q[7];
cp(-pi/256) q[16],q[8];
cp(-pi/128) q[16],q[9];
cp(-pi/64) q[16],q[10];
cp(-pi/32) q[16],q[11];
cp(-pi/16) q[16],q[12];
cp(-pi/8) q[16],q[13];
cp(-pi/4) q[16],q[14];
cp(-pi/2) q[16],q[15];
h q[16];
cp(-pi/131072) q[17],q[0];
cp(-pi/65536) q[17],q[1];
cp(-pi/32768) q[17],q[2];
cp(-pi/16384) q[17],q[3];
cp(-pi/8192) q[17],q[4];
cp(-pi/4096) q[17],q[5];
cp(-pi/2048) q[17],q[6];
cp(-pi/1024) q[17],q[7];
cp(-pi/512) q[17],q[8];
cp(-pi/256) q[17],q[9];
cp(-pi/128) q[17],q[10];
cp(-pi/64) q[17],q[11];
cp(-pi/32) q[17],q[12];
cp(-pi/16) q[17],q[13];
cp(-pi/8) q[17],q[14];
cp(-pi/4) q[17],q[15];
cp(-pi/2) q[17],q[16];
h q[17];
cp(-pi/262144) q[18],q[0];
cp(-pi/131072) q[18],q[1];
cp(-pi/65536) q[18],q[2];
cp(-pi/32768) q[18],q[3];
cp(-pi/16384) q[18],q[4];
cp(-pi/8192) q[18],q[5];
cp(-pi/4096) q[18],q[6];
cp(-pi/2048) q[18],q[7];
cp(-pi/1024) q[18],q[8];
cp(-pi/512) q[18],q[9];
cp(-pi/256) q[18],q[10];
cp(-pi/128) q[18],q[11];
cp(-pi/64) q[18],q[12];
cp(-pi/32) q[18],q[13];
cp(-pi/16) q[18],q[14];
cp(-pi/8) q[18],q[15];
cp(-pi/4) q[18],q[16];
cp(-pi/2) q[18],q[17];
h q[18];
cp(-pi/524288) q[19],q[0];
cp(-pi/262144) q[19],q[1];
cp(-pi/131072) q[19],q[2];
cp(-pi/65536) q[19],q[3];
cp(-pi/32768) q[19],q[4];
cp(-pi/16384) q[19],q[5];
cp(-pi/8192) q[19],q[6];
cp(-pi/4096) q[19],q[7];
cp(-pi/2048) q[19],q[8];
cp(-pi/1024) q[19],q[9];
cp(-pi/512) q[19],q[10];
cp(-pi/256) q[19],q[11];
cp(-pi/128) q[19],q[12];
cp(-pi/64) q[19],q[13];
cp(-pi/32) q[19],q[14];
cp(-pi/16) q[19],q[15];
cp(-pi/8) q[19],q[16];
cp(-pi/4) q[19],q[17];
cp(-pi/2) q[19],q[18];
h q[19];
cp(-pi/1048576) q[20],q[0];
cp(-pi/524288) q[20],q[1];
cp(-pi/262144) q[20],q[2];
cp(-pi/131072) q[20],q[3];
cp(-pi/65536) q[20],q[4];
cp(-pi/32768) q[20],q[5];
cp(-pi/16384) q[20],q[6];
cp(-pi/8192) q[20],q[7];
cp(-pi/4096) q[20],q[8];
cp(-pi/2048) q[20],q[9];
cp(-pi/1024) q[20],q[10];
cp(-pi/512) q[20],q[11];
cp(-pi/256) q[20],q[12];
cp(-pi/128) q[20],q[13];
cp(-pi/64) q[20],q[14];
cp(-pi/32) q[20],q[15];
cp(-pi/16) q[20],q[16];
cp(-pi/8) q[20],q[17];
cp(-pi/4) q[20],q[18];
cp(-pi/2) q[20],q[19];
h q[20];
cp(-pi/2097152) q[21],q[0];
cp(-pi/1048576) q[21],q[1];
cp(-pi/524288) q[21],q[2];
cp(-pi/262144) q[21],q[3];
cp(-pi/131072) q[21],q[4];
cp(-pi/65536) q[21],q[5];
cp(-pi/32768) q[21],q[6];
cp(-pi/16384) q[21],q[7];
cp(-pi/8192) q[21],q[8];
cp(-pi/4096) q[21],q[9];
cp(-pi/2048) q[21],q[10];
cp(-pi/1024) q[21],q[11];
cp(-pi/512) q[21],q[12];
cp(-pi/256) q[21],q[13];
cp(-pi/128) q[21],q[14];
cp(-pi/64) q[21],q[15];
cp(-pi/32) q[21],q[16];
cp(-pi/16) q[21],q[17];
cp(-pi/8) q[21],q[18];
cp(-pi/4) q[21],q[19];
cp(-pi/2) q[21],q[20];
h q[21];
cp(-pi/4194304) q[22],q[0];
cp(-pi/2097152) q[22],q[1];
cp(-pi/1048576) q[22],q[2];
cp(-pi/524288) q[22],q[3];
cp(-pi/262144) q[22],q[4];
cp(-pi/131072) q[22],q[5];
cp(-pi/65536) q[22],q[6];
cp(-pi/32768) q[22],q[7];
cp(-pi/16384) q[22],q[8];
cp(-pi/8192) q[22],q[9];
cp(-pi/4096) q[22],q[10];
cp(-pi/2048) q[22],q[11];
cp(-pi/1024) q[22],q[12];
cp(-pi/512) q[22],q[13];
cp(-pi/256) q[22],q[14];
cp(-pi/128) q[22],q[15];
cp(-pi/64) q[22],q[16];
cp(-pi/32) q[22],q[17];
cp(-pi/16) q[22],q[18];
cp(-pi/8) q[22],q[19];
cp(-pi/4) q[22],q[20];
cp(-pi/2) q[22],q[21];
h q[22];
cp(-pi/8388608) q[23],q[0];
cp(-pi/4194304) q[23],q[1];
cp(-pi/2097152) q[23],q[2];
cp(-pi/1048576) q[23],q[3];
cp(-pi/524288) q[23],q[4];
cp(-pi/262144) q[23],q[5];
cp(-pi/131072) q[23],q[6];
cp(-pi/65536) q[23],q[7];
cp(-pi/32768) q[23],q[8];
cp(-pi/16384) q[23],q[9];
cp(-pi/8192) q[23],q[10];
cp(-pi/4096) q[23],q[11];
cp(-pi/2048) q[23],q[12];
cp(-pi/1024) q[23],q[13];
cp(-pi/512) q[23],q[14];
cp(-pi/256) q[23],q[15];
cp(-pi/128) q[23],q[16];
cp(-pi/64) q[23],q[17];
cp(-pi/32) q[23],q[18];
cp(-pi/16) q[23],q[19];
cp(-pi/8) q[23],q[20];
cp(-pi/4) q[23],q[21];
cp(-pi/2) q[23],q[22];
h q[23];
cp(-pi/16777216) q[24],q[0];
cp(-pi/8388608) q[24],q[1];
cp(-pi/4194304) q[24],q[2];
cp(-pi/2097152) q[24],q[3];
cp(-pi/1048576) q[24],q[4];
cp(-pi/524288) q[24],q[5];
cp(-pi/262144) q[24],q[6];
cp(-pi/131072) q[24],q[7];
cp(-pi/65536) q[24],q[8];
cp(-pi/32768) q[24],q[9];
cp(-pi/16384) q[24],q[10];
cp(-pi/8192) q[24],q[11];
cp(-pi/4096) q[24],q[12];
cp(-pi/2048) q[24],q[13];
cp(-pi/1024) q[24],q[14];
cp(-pi/512) q[24],q[15];
cp(-pi/256) q[24],q[16];
cp(-pi/128) q[24],q[17];
cp(-pi/64) q[24],q[18];
cp(-pi/32) q[24],q[19];
cp(-pi/16) q[24],q[20];
cp(-pi/8) q[24],q[21];
cp(-pi/4) q[24],q[22];
cp(-pi/2) q[24],q[23];
h q[24];
cp(-pi/33554432) q[25],q[0];
cp(-pi/16777216) q[25],q[1];
cp(-pi/8388608) q[25],q[2];
cp(-pi/4194304) q[25],q[3];
cp(-pi/2097152) q[25],q[4];
cp(-pi/1048576) q[25],q[5];
cp(-pi/524288) q[25],q[6];
cp(-pi/262144) q[25],q[7];
cp(-pi/131072) q[25],q[8];
cp(-pi/65536) q[25],q[9];
cp(-pi/32768) q[25],q[10];
cp(-pi/16384) q[25],q[11];
cp(-pi/8192) q[25],q[12];
cp(-pi/4096) q[25],q[13];
cp(-pi/2048) q[25],q[14];
cp(-pi/1024) q[25],q[15];
cp(-pi/512) q[25],q[16];
cp(-pi/256) q[25],q[17];
cp(-pi/128) q[25],q[18];
cp(-pi/64) q[25],q[19];
cp(-pi/32) q[25],q[20];
cp(-pi/16) q[25],q[21];
cp(-pi/8) q[25],q[22];
cp(-pi/4) q[25],q[23];
cp(-pi/2) q[25],q[24];
h q[25];
cp(-pi/67108864) q[26],q[0];
cp(-pi/33554432) q[26],q[1];
cp(-pi/16777216) q[26],q[2];
cp(-pi/8388608) q[26],q[3];
cp(-pi/4194304) q[26],q[4];
cp(-pi/2097152) q[26],q[5];
cp(-pi/1048576) q[26],q[6];
cp(-pi/524288) q[26],q[7];
cp(-pi/262144) q[26],q[8];
cp(-pi/131072) q[26],q[9];
cp(-pi/65536) q[26],q[10];
cp(-pi/32768) q[26],q[11];
cp(-pi/16384) q[26],q[12];
cp(-pi/8192) q[26],q[13];
cp(-pi/4096) q[26],q[14];
cp(-pi/2048) q[26],q[15];
cp(-pi/1024) q[26],q[16];
cp(-pi/512) q[26],q[17];
cp(-pi/256) q[26],q[18];
cp(-pi/128) q[26],q[19];
cp(-pi/64) q[26],q[20];
cp(-pi/32) q[26],q[21];
cp(-pi/16) q[26],q[22];
cp(-pi/8) q[26],q[23];
cp(-pi/4) q[26],q[24];
cp(-pi/2) q[26],q[25];
h q[26];
cp(-pi/134217728) q[27],q[0];
cp(-pi/67108864) q[27],q[1];
cp(-pi/33554432) q[27],q[2];
cp(-pi/16777216) q[27],q[3];
cp(-pi/8388608) q[27],q[4];
cp(-pi/4194304) q[27],q[5];
cp(-pi/2097152) q[27],q[6];
cp(-pi/1048576) q[27],q[7];
cp(-pi/524288) q[27],q[8];
cp(-pi/262144) q[27],q[9];
cp(-pi/131072) q[27],q[10];
cp(-pi/65536) q[27],q[11];
cp(-pi/32768) q[27],q[12];
cp(-pi/16384) q[27],q[13];
cp(-pi/8192) q[27],q[14];
cp(-pi/4096) q[27],q[15];
cp(-pi/2048) q[27],q[16];
cp(-pi/1024) q[27],q[17];
cp(-pi/512) q[27],q[18];
cp(-pi/256) q[27],q[19];
cp(-pi/128) q[27],q[20];
cp(-pi/64) q[27],q[21];
cp(-pi/32) q[27],q[22];
cp(-pi/16) q[27],q[23];
cp(-pi/8) q[27],q[24];
cp(-pi/4) q[27],q[25];
cp(-pi/2) q[27],q[26];
h q[27];
cp(-pi/268435456) q[28],q[0];
cp(-pi/134217728) q[28],q[1];
cp(-pi/67108864) q[28],q[2];
cp(-pi/33554432) q[28],q[3];
cp(-pi/16777216) q[28],q[4];
cp(-pi/8388608) q[28],q[5];
cp(-pi/4194304) q[28],q[6];
cp(-pi/2097152) q[28],q[7];
cp(-pi/1048576) q[28],q[8];
cp(-pi/524288) q[28],q[9];
cp(-pi/262144) q[28],q[10];
cp(-pi/131072) q[28],q[11];
cp(-pi/65536) q[28],q[12];
cp(-pi/32768) q[28],q[13];
cp(-pi/16384) q[28],q[14];
cp(-pi/8192) q[28],q[15];
cp(-pi/4096) q[28],q[16];
cp(-pi/2048) q[28],q[17];
cp(-pi/1024) q[28],q[18];
cp(-pi/512) q[28],q[19];
cp(-pi/256) q[28],q[20];
cp(-pi/128) q[28],q[21];
cp(-pi/64) q[28],q[22];
cp(-pi/32) q[28],q[23];
cp(-pi/16) q[28],q[24];
cp(-pi/8) q[28],q[25];
cp(-pi/4) q[28],q[26];
cp(-pi/2) q[28],q[27];
h q[28];
cp(-pi/536870912) q[29],q[0];
cp(-pi/268435456) q[29],q[1];
cp(-pi/134217728) q[29],q[2];
cp(-pi/67108864) q[29],q[3];
cp(-pi/33554432) q[29],q[4];
cp(-pi/16777216) q[29],q[5];
cp(-pi/8388608) q[29],q[6];
cp(-pi/4194304) q[29],q[7];
cp(-pi/2097152) q[29],q[8];
cp(-pi/1048576) q[29],q[9];
cp(-pi/524288) q[29],q[10];
cp(-pi/262144) q[29],q[11];
cp(-pi/131072) q[29],q[12];
cp(-pi/65536) q[29],q[13];
cp(-pi/32768) q[29],q[14];
cp(-pi/16384) q[29],q[15];
cp(-pi/8192) q[29],q[16];
cp(-pi/4096) q[29],q[17];
cp(-pi/2048) q[29],q[18];
cp(-pi/1024) q[29],q[19];
cp(-pi/512) q[29],q[20];
cp(-pi/256) q[29],q[21];
cp(-pi/128) q[29],q[22];
cp(-pi/64) q[29],q[23];
cp(-pi/32) q[29],q[24];
cp(-pi/16) q[29],q[25];
cp(-pi/8) q[29],q[26];
cp(-pi/4) q[29],q[27];
cp(-pi/2) q[29],q[28];
h q[29];
cp(-pi/1073741824) q[30],q[0];
cp(-pi/536870912) q[30],q[1];
cp(-pi/268435456) q[30],q[2];
cp(-pi/134217728) q[30],q[3];
cp(-pi/67108864) q[30],q[4];
cp(-pi/33554432) q[30],q[5];
cp(-pi/16777216) q[30],q[6];
cp(-pi/8388608) q[30],q[7];
cp(-pi/4194304) q[30],q[8];
cp(-pi/2097152) q[30],q[9];
cp(-pi/1048576) q[30],q[10];
cp(-pi/524288) q[30],q[11];
cp(-pi/262144) q[30],q[12];
cp(-pi/131072) q[30],q[13];
cp(-pi/65536) q[30],q[14];
cp(-pi/32768) q[30],q[15];
cp(-pi/16384) q[30],q[16];
cp(-pi/8192) q[30],q[17];
cp(-pi/4096) q[30],q[18];
cp(-pi/2048) q[30],q[19];
cp(-pi/1024) q[30],q[20];
cp(-pi/512) q[30],q[21];
cp(-pi/256) q[30],q[22];
cp(-pi/128) q[30],q[23];
cp(-pi/64) q[30],q[24];
cp(-pi/32) q[30],q[25];
cp(-pi/16) q[30],q[26];
cp(-pi/8) q[30],q[27];
cp(-pi/4) q[30],q[28];
cp(-pi/2) q[30],q[29];
h q[30];
cp(-pi/2147483648) q[31],q[0];
cp(-pi/1073741824) q[31],q[1];
cp(-pi/536870912) q[31],q[2];
cp(-pi/268435456) q[31],q[3];
cp(-pi/134217728) q[31],q[4];
cp(-pi/67108864) q[31],q[5];
cp(-pi/33554432) q[31],q[6];
cp(-pi/16777216) q[31],q[7];
cp(-pi/8388608) q[31],q[8];
cp(-pi/4194304) q[31],q[9];
cp(-pi/2097152) q[31],q[10];
cp(-pi/1048576) q[31],q[11];
cp(-pi/524288) q[31],q[12];
cp(-pi/262144) q[31],q[13];
cp(-pi/131072) q[31],q[14];
cp(-pi/65536) q[31],q[15];
cp(-pi/32768) q[31],q[16];
cp(-pi/16384) q[31],q[17];
cp(-pi/8192) q[31],q[18];
cp(-pi/4096) q[31],q[19];
cp(-pi/2048) q[31],q[20];
cp(-pi/1024) q[31],q[21];
cp(-pi/512) q[31],q[22];
cp(-pi/256) q[31],q[23];
cp(-pi/128) q[31],q[24];
cp(-pi/64) q[31],q[25];
cp(-pi/32) q[31],q[26];
cp(-pi/16) q[31],q[27];
cp(-pi/8) q[31],q[28];
cp(-pi/4) q[31],q[29];
cp(-pi/2) q[31],q[30];
h q[31];
cp(-pi/4294967296) q[32],q[0];
cp(-pi/2147483648) q[32],q[1];
cp(-pi/1073741824) q[32],q[2];
cp(-pi/536870912) q[32],q[3];
cp(-pi/268435456) q[32],q[4];
cp(-pi/134217728) q[32],q[5];
cp(-pi/67108864) q[32],q[6];
cp(-pi/33554432) q[32],q[7];
cp(-pi/16777216) q[32],q[8];
cp(-pi/8388608) q[32],q[9];
cp(-pi/4194304) q[32],q[10];
cp(-pi/2097152) q[32],q[11];
cp(-pi/1048576) q[32],q[12];
cp(-pi/524288) q[32],q[13];
cp(-pi/262144) q[32],q[14];
cp(-pi/131072) q[32],q[15];
cp(-pi/65536) q[32],q[16];
cp(-pi/32768) q[32],q[17];
cp(-pi/16384) q[32],q[18];
cp(-pi/8192) q[32],q[19];
cp(-pi/4096) q[32],q[20];
cp(-pi/2048) q[32],q[21];
cp(-pi/1024) q[32],q[22];
cp(-pi/512) q[32],q[23];
cp(-pi/256) q[32],q[24];
cp(-pi/128) q[32],q[25];
cp(-pi/64) q[32],q[26];
cp(-pi/32) q[32],q[27];
cp(-pi/16) q[32],q[28];
cp(-pi/8) q[32],q[29];
cp(-pi/4) q[32],q[30];
cp(-pi/2) q[32],q[31];
h q[32];
cp(-pi/8589934592) q[33],q[0];
cp(-pi/4294967296) q[33],q[1];
cp(-pi/2147483648) q[33],q[2];
cp(-pi/1073741824) q[33],q[3];
cp(-pi/536870912) q[33],q[4];
cp(-pi/268435456) q[33],q[5];
cp(-pi/134217728) q[33],q[6];
cp(-pi/67108864) q[33],q[7];
cp(-pi/33554432) q[33],q[8];
cp(-pi/16777216) q[33],q[9];
cp(-pi/8388608) q[33],q[10];
cp(-pi/4194304) q[33],q[11];
cp(-pi/2097152) q[33],q[12];
cp(-pi/1048576) q[33],q[13];
cp(-pi/524288) q[33],q[14];
cp(-pi/262144) q[33],q[15];
cp(-pi/131072) q[33],q[16];
cp(-pi/65536) q[33],q[17];
cp(-pi/32768) q[33],q[18];
cp(-pi/16384) q[33],q[19];
cp(-pi/8192) q[33],q[20];
cp(-pi/4096) q[33],q[21];
cp(-pi/2048) q[33],q[22];
cp(-pi/1024) q[33],q[23];
cp(-pi/512) q[33],q[24];
cp(-pi/256) q[33],q[25];
cp(-pi/128) q[33],q[26];
cp(-pi/64) q[33],q[27];
cp(-pi/32) q[33],q[28];
cp(-pi/16) q[33],q[29];
cp(-pi/8) q[33],q[30];
cp(-pi/4) q[33],q[31];
cp(-pi/2) q[33],q[32];
h q[33];
cp(-pi/17179869184) q[34],q[0];
cp(-pi/8589934592) q[34],q[1];
cp(-pi/4294967296) q[34],q[2];
cp(-pi/2147483648) q[34],q[3];
cp(-pi/1073741824) q[34],q[4];
cp(-pi/536870912) q[34],q[5];
cp(-pi/268435456) q[34],q[6];
cp(-pi/134217728) q[34],q[7];
cp(-pi/67108864) q[34],q[8];
cp(-pi/33554432) q[34],q[9];
cp(-pi/16777216) q[34],q[10];
cp(-pi/8388608) q[34],q[11];
cp(-pi/4194304) q[34],q[12];
cp(-pi/2097152) q[34],q[13];
cp(-pi/1048576) q[34],q[14];
cp(-pi/524288) q[34],q[15];
cp(-pi/262144) q[34],q[16];
cp(-pi/131072) q[34],q[17];
cp(-pi/65536) q[34],q[18];
cp(-pi/32768) q[34],q[19];
cp(-pi/16384) q[34],q[20];
cp(-pi/8192) q[34],q[21];
cp(-pi/4096) q[34],q[22];
cp(-pi/2048) q[34],q[23];
cp(-pi/1024) q[34],q[24];
cp(-pi/512) q[34],q[25];
cp(-pi/256) q[34],q[26];
cp(-pi/128) q[34],q[27];
cp(-pi/64) q[34],q[28];
cp(-pi/32) q[34],q[29];
cp(-pi/16) q[34],q[30];
cp(-pi/8) q[34],q[31];
cp(-pi/4) q[34],q[32];
cp(-pi/2) q[34],q[33];
h q[34];
cp(-pi/34359738368) q[35],q[0];
cp(-pi/17179869184) q[35],q[1];
cp(-pi/8589934592) q[35],q[2];
cp(-pi/4294967296) q[35],q[3];
cp(-pi/2147483648) q[35],q[4];
cp(-pi/1073741824) q[35],q[5];
cp(-pi/536870912) q[35],q[6];
cp(-pi/268435456) q[35],q[7];
cp(-pi/134217728) q[35],q[8];
cp(-pi/67108864) q[35],q[9];
cp(-pi/33554432) q[35],q[10];
cp(-pi/16777216) q[35],q[11];
cp(-pi/8388608) q[35],q[12];
cp(-pi/4194304) q[35],q[13];
cp(-pi/2097152) q[35],q[14];
cp(-pi/1048576) q[35],q[15];
cp(-pi/524288) q[35],q[16];
cp(-pi/262144) q[35],q[17];
cp(-pi/131072) q[35],q[18];
cp(-pi/65536) q[35],q[19];
cp(-pi/32768) q[35],q[20];
cp(-pi/16384) q[35],q[21];
cp(-pi/8192) q[35],q[22];
cp(-pi/4096) q[35],q[23];
cp(-pi/2048) q[35],q[24];
cp(-pi/1024) q[35],q[25];
cp(-pi/512) q[35],q[26];
cp(-pi/256) q[35],q[27];
cp(-pi/128) q[35],q[28];
cp(-pi/64) q[35],q[29];
cp(-pi/32) q[35],q[30];
cp(-pi/16) q[35],q[31];
cp(-pi/8) q[35],q[32];
cp(-pi/4) q[35],q[33];
cp(-pi/2) q[35],q[34];
h q[35];
cp(-pi/68719476736) q[36],q[0];
cp(-pi/34359738368) q[36],q[1];
cp(-pi/17179869184) q[36],q[2];
cp(-pi/8589934592) q[36],q[3];
cp(-pi/4294967296) q[36],q[4];
cp(-pi/2147483648) q[36],q[5];
cp(-pi/1073741824) q[36],q[6];
cp(-pi/536870912) q[36],q[7];
cp(-pi/268435456) q[36],q[8];
cp(-pi/134217728) q[36],q[9];
cp(-pi/67108864) q[36],q[10];
cp(-pi/33554432) q[36],q[11];
cp(-pi/16777216) q[36],q[12];
cp(-pi/8388608) q[36],q[13];
cp(-pi/4194304) q[36],q[14];
cp(-pi/2097152) q[36],q[15];
cp(-pi/1048576) q[36],q[16];
cp(-pi/524288) q[36],q[17];
cp(-pi/262144) q[36],q[18];
cp(-pi/131072) q[36],q[19];
cp(-pi/65536) q[36],q[20];
cp(-pi/32768) q[36],q[21];
cp(-pi/16384) q[36],q[22];
cp(-pi/8192) q[36],q[23];
cp(-pi/4096) q[36],q[24];
cp(-pi/2048) q[36],q[25];
cp(-pi/1024) q[36],q[26];
cp(-pi/512) q[36],q[27];
cp(-pi/256) q[36],q[28];
cp(-pi/128) q[36],q[29];
cp(-pi/64) q[36],q[30];
cp(-pi/32) q[36],q[31];
cp(-pi/16) q[36],q[32];
cp(-pi/8) q[36],q[33];
cp(-pi/4) q[36],q[34];
cp(-pi/2) q[36],q[35];
h q[36];
cp(-pi/137438953472) q[37],q[0];
cp(-pi/68719476736) q[37],q[1];
cp(-pi/34359738368) q[37],q[2];
cp(-pi/17179869184) q[37],q[3];
cp(-pi/8589934592) q[37],q[4];
cp(-pi/4294967296) q[37],q[5];
cp(-pi/2147483648) q[37],q[6];
cp(-pi/1073741824) q[37],q[7];
cp(-pi/536870912) q[37],q[8];
cp(-pi/268435456) q[37],q[9];
cp(-pi/134217728) q[37],q[10];
cp(-pi/67108864) q[37],q[11];
cp(-pi/33554432) q[37],q[12];
cp(-pi/16777216) q[37],q[13];
cp(-pi/8388608) q[37],q[14];
cp(-pi/4194304) q[37],q[15];
cp(-pi/2097152) q[37],q[16];
cp(-pi/1048576) q[37],q[17];
cp(-pi/524288) q[37],q[18];
cp(-pi/262144) q[37],q[19];
cp(-pi/131072) q[37],q[20];
cp(-pi/65536) q[37],q[21];
cp(-pi/32768) q[37],q[22];
cp(-pi/16384) q[37],q[23];
cp(-pi/8192) q[37],q[24];
cp(-pi/4096) q[37],q[25];
cp(-pi/2048) q[37],q[26];
cp(-pi/1024) q[37],q[27];
cp(-pi/512) q[37],q[28];
cp(-pi/256) q[37],q[29];
cp(-pi/128) q[37],q[30];
cp(-pi/64) q[37],q[31];
cp(-pi/32) q[37],q[32];
cp(-pi/16) q[37],q[33];
cp(-pi/8) q[37],q[34];
cp(-pi/4) q[37],q[35];
cp(-pi/2) q[37],q[36];
h q[37];
cp(-pi/274877906944) q[38],q[0];
cp(-pi/137438953472) q[38],q[1];
cp(-pi/68719476736) q[38],q[2];
cp(-pi/34359738368) q[38],q[3];
cp(-pi/17179869184) q[38],q[4];
cp(-pi/8589934592) q[38],q[5];
cp(-pi/4294967296) q[38],q[6];
cp(-pi/2147483648) q[38],q[7];
cp(-pi/1073741824) q[38],q[8];
cp(-pi/536870912) q[38],q[9];
cp(-pi/268435456) q[38],q[10];
cp(-pi/134217728) q[38],q[11];
cp(-pi/67108864) q[38],q[12];
cp(-pi/33554432) q[38],q[13];
cp(-pi/16777216) q[38],q[14];
cp(-pi/8388608) q[38],q[15];
cp(-pi/4194304) q[38],q[16];
cp(-pi/2097152) q[38],q[17];
cp(-pi/1048576) q[38],q[18];
cp(-pi/524288) q[38],q[19];
cp(-pi/262144) q[38],q[20];
cp(-pi/131072) q[38],q[21];
cp(-pi/65536) q[38],q[22];
cp(-pi/32768) q[38],q[23];
cp(-pi/16384) q[38],q[24];
cp(-pi/8192) q[38],q[25];
cp(-pi/4096) q[38],q[26];
cp(-pi/2048) q[38],q[27];
cp(-pi/1024) q[38],q[28];
cp(-pi/512) q[38],q[29];
cp(-pi/256) q[38],q[30];
cp(-pi/128) q[38],q[31];
cp(-pi/64) q[38],q[32];
cp(-pi/32) q[38],q[33];
cp(-pi/16) q[38],q[34];
cp(-pi/8) q[38],q[35];
cp(-pi/4) q[38],q[36];
cp(-pi/2) q[38],q[37];
h q[38];
cp(-pi/549755813888) q[39],q[0];
cp(-pi/274877906944) q[39],q[1];
cp(-pi/137438953472) q[39],q[2];
cp(-pi/68719476736) q[39],q[3];
cp(-pi/34359738368) q[39],q[4];
cp(-pi/17179869184) q[39],q[5];
cp(-pi/8589934592) q[39],q[6];
cp(-pi/4294967296) q[39],q[7];
cp(-pi/2147483648) q[39],q[8];
cp(-pi/1073741824) q[39],q[9];
cp(-pi/536870912) q[39],q[10];
cp(-pi/268435456) q[39],q[11];
cp(-pi/134217728) q[39],q[12];
cp(-pi/67108864) q[39],q[13];
cp(-pi/33554432) q[39],q[14];
cp(-pi/16777216) q[39],q[15];
cp(-pi/8388608) q[39],q[16];
cp(-pi/4194304) q[39],q[17];
cp(-pi/2097152) q[39],q[18];
cp(-pi/1048576) q[39],q[19];
cp(-pi/524288) q[39],q[20];
cp(-pi/262144) q[39],q[21];
cp(-pi/131072) q[39],q[22];
cp(-pi/65536) q[39],q[23];
cp(-pi/32768) q[39],q[24];
cp(-pi/16384) q[39],q[25];
cp(-pi/8192) q[39],q[26];
cp(-pi/4096) q[39],q[27];
cp(-pi/2048) q[39],q[28];
cp(-pi/1024) q[39],q[29];
cp(-pi/512) q[39],q[30];
cp(-pi/256) q[39],q[31];
cp(-pi/128) q[39],q[32];
cp(-pi/64) q[39],q[33];
cp(-pi/32) q[39],q[34];
cp(-pi/16) q[39],q[35];
cp(-pi/8) q[39],q[36];
cp(-pi/4) q[39],q[37];
cp(-pi/2) q[39],q[38];
h q[39];
cp(-pi/1099511627776) q[40],q[0];
cp(-pi/549755813888) q[40],q[1];
cp(-pi/274877906944) q[40],q[2];
cp(-pi/137438953472) q[40],q[3];
cp(-pi/68719476736) q[40],q[4];
cp(-pi/34359738368) q[40],q[5];
cp(-pi/17179869184) q[40],q[6];
cp(-pi/8589934592) q[40],q[7];
cp(-pi/4294967296) q[40],q[8];
cp(-pi/2147483648) q[40],q[9];
cp(-pi/1073741824) q[40],q[10];
cp(-pi/536870912) q[40],q[11];
cp(-pi/268435456) q[40],q[12];
cp(-pi/134217728) q[40],q[13];
cp(-pi/67108864) q[40],q[14];
cp(-pi/33554432) q[40],q[15];
cp(-pi/16777216) q[40],q[16];
cp(-pi/8388608) q[40],q[17];
cp(-pi/4194304) q[40],q[18];
cp(-pi/2097152) q[40],q[19];
cp(-pi/1048576) q[40],q[20];
cp(-pi/524288) q[40],q[21];
cp(-pi/262144) q[40],q[22];
cp(-pi/131072) q[40],q[23];
cp(-pi/65536) q[40],q[24];
cp(-pi/32768) q[40],q[25];
cp(-pi/16384) q[40],q[26];
cp(-pi/8192) q[40],q[27];
cp(-pi/4096) q[40],q[28];
cp(-pi/2048) q[40],q[29];
cp(-pi/1024) q[40],q[30];
cp(-pi/512) q[40],q[31];
cp(-pi/256) q[40],q[32];
cp(-pi/128) q[40],q[33];
cp(-pi/64) q[40],q[34];
cp(-pi/32) q[40],q[35];
cp(-pi/16) q[40],q[36];
cp(-pi/8) q[40],q[37];
cp(-pi/4) q[40],q[38];
cp(-pi/2) q[40],q[39];
h q[40];
cp(-pi/2199023255552) q[41],q[0];
cp(-pi/1099511627776) q[41],q[1];
cp(-pi/549755813888) q[41],q[2];
cp(-pi/274877906944) q[41],q[3];
cp(-pi/137438953472) q[41],q[4];
cp(-pi/68719476736) q[41],q[5];
cp(-pi/34359738368) q[41],q[6];
cp(-pi/17179869184) q[41],q[7];
cp(-pi/8589934592) q[41],q[8];
cp(-pi/4294967296) q[41],q[9];
cp(-pi/2147483648) q[41],q[10];
cp(-pi/1073741824) q[41],q[11];
cp(-pi/536870912) q[41],q[12];
cp(-pi/268435456) q[41],q[13];
cp(-pi/134217728) q[41],q[14];
cp(-pi/67108864) q[41],q[15];
cp(-pi/33554432) q[41],q[16];
cp(-pi/16777216) q[41],q[17];
cp(-pi/8388608) q[41],q[18];
cp(-pi/4194304) q[41],q[19];
cp(-pi/2097152) q[41],q[20];
cp(-pi/1048576) q[41],q[21];
cp(-pi/524288) q[41],q[22];
cp(-pi/262144) q[41],q[23];
cp(-pi/131072) q[41],q[24];
cp(-pi/65536) q[41],q[25];
cp(-pi/32768) q[41],q[26];
cp(-pi/16384) q[41],q[27];
cp(-pi/8192) q[41],q[28];
cp(-pi/4096) q[41],q[29];
cp(-pi/2048) q[41],q[30];
cp(-pi/1024) q[41],q[31];
cp(-pi/512) q[41],q[32];
cp(-pi/256) q[41],q[33];
cp(-pi/128) q[41],q[34];
cp(-pi/64) q[41],q[35];
cp(-pi/32) q[41],q[36];
cp(-pi/16) q[41],q[37];
cp(-pi/8) q[41],q[38];
cp(-pi/4) q[41],q[39];
cp(-pi/2) q[41],q[40];
h q[41];
cp(0) q[42],q[0];
cp(-pi/2199023255552) q[42],q[1];
cp(-pi/1099511627776) q[42],q[2];
cp(-pi/549755813888) q[42],q[3];
cp(-pi/274877906944) q[42],q[4];
cp(-pi/137438953472) q[42],q[5];
cp(-pi/68719476736) q[42],q[6];
cp(-pi/34359738368) q[42],q[7];
cp(-pi/17179869184) q[42],q[8];
cp(-pi/8589934592) q[42],q[9];
cp(-pi/4294967296) q[42],q[10];
cp(-pi/2147483648) q[42],q[11];
cp(-pi/1073741824) q[42],q[12];
cp(-pi/536870912) q[42],q[13];
cp(-pi/268435456) q[42],q[14];
cp(-pi/134217728) q[42],q[15];
cp(-pi/67108864) q[42],q[16];
cp(-pi/33554432) q[42],q[17];
cp(-pi/16777216) q[42],q[18];
cp(-pi/8388608) q[42],q[19];
cp(-pi/4194304) q[42],q[20];
cp(-pi/2097152) q[42],q[21];
cp(-pi/1048576) q[42],q[22];
cp(-pi/524288) q[42],q[23];
cp(-pi/262144) q[42],q[24];
cp(-pi/131072) q[42],q[25];
cp(-pi/65536) q[42],q[26];
cp(-pi/32768) q[42],q[27];
cp(-pi/16384) q[42],q[28];
cp(-pi/8192) q[42],q[29];
cp(-pi/4096) q[42],q[30];
cp(-pi/2048) q[42],q[31];
cp(-pi/1024) q[42],q[32];
cp(-pi/512) q[42],q[33];
cp(-pi/256) q[42],q[34];
cp(-pi/128) q[42],q[35];
cp(-pi/64) q[42],q[36];
cp(-pi/32) q[42],q[37];
cp(-pi/16) q[42],q[38];
cp(-pi/8) q[42],q[39];
cp(-pi/4) q[42],q[40];
cp(-pi/2) q[42],q[41];
h q[42];
cp(0) q[43],q[0];
cp(0) q[43],q[1];
cp(-pi/2199023255552) q[43],q[2];
cp(-pi/1099511627776) q[43],q[3];
cp(-pi/549755813888) q[43],q[4];
cp(-pi/274877906944) q[43],q[5];
cp(-pi/137438953472) q[43],q[6];
cp(-pi/68719476736) q[43],q[7];
cp(-pi/34359738368) q[43],q[8];
cp(-pi/17179869184) q[43],q[9];
cp(-pi/8589934592) q[43],q[10];
cp(-pi/4294967296) q[43],q[11];
cp(-pi/2147483648) q[43],q[12];
cp(-pi/1073741824) q[43],q[13];
cp(-pi/536870912) q[43],q[14];
cp(-pi/268435456) q[43],q[15];
cp(-pi/134217728) q[43],q[16];
cp(-pi/67108864) q[43],q[17];
cp(-pi/33554432) q[43],q[18];
cp(-pi/16777216) q[43],q[19];
cp(-pi/8388608) q[43],q[20];
cp(-pi/4194304) q[43],q[21];
cp(-pi/2097152) q[43],q[22];
cp(-pi/1048576) q[43],q[23];
cp(-pi/524288) q[43],q[24];
cp(-pi/262144) q[43],q[25];
cp(-pi/131072) q[43],q[26];
cp(-pi/65536) q[43],q[27];
cp(-pi/32768) q[43],q[28];
cp(-pi/16384) q[43],q[29];
cp(-pi/8192) q[43],q[30];
cp(-pi/4096) q[43],q[31];
cp(-pi/2048) q[43],q[32];
cp(-pi/1024) q[43],q[33];
cp(-pi/512) q[43],q[34];
cp(-pi/256) q[43],q[35];
cp(-pi/128) q[43],q[36];
cp(-pi/64) q[43],q[37];
cp(-pi/32) q[43],q[38];
cp(-pi/16) q[43],q[39];
cp(-pi/8) q[43],q[40];
cp(-pi/4) q[43],q[41];
cp(-pi/2) q[43],q[42];
h q[43];
cp(0) q[44],q[0];
cp(0) q[44],q[1];
cp(0) q[44],q[2];
cp(-pi/2199023255552) q[44],q[3];
cp(-pi/1099511627776) q[44],q[4];
cp(-pi/549755813888) q[44],q[5];
cp(-pi/274877906944) q[44],q[6];
cp(-pi/137438953472) q[44],q[7];
cp(-pi/68719476736) q[44],q[8];
cp(-pi/34359738368) q[44],q[9];
cp(-pi/17179869184) q[44],q[10];
cp(-pi/8589934592) q[44],q[11];
cp(-pi/4294967296) q[44],q[12];
cp(-pi/2147483648) q[44],q[13];
cp(-pi/1073741824) q[44],q[14];
cp(-pi/536870912) q[44],q[15];
cp(-pi/268435456) q[44],q[16];
cp(-pi/134217728) q[44],q[17];
cp(-pi/67108864) q[44],q[18];
cp(-pi/33554432) q[44],q[19];
cp(-pi/16777216) q[44],q[20];
cp(-pi/8388608) q[44],q[21];
cp(-pi/4194304) q[44],q[22];
cp(-pi/2097152) q[44],q[23];
cp(-pi/1048576) q[44],q[24];
cp(-pi/524288) q[44],q[25];
cp(-pi/262144) q[44],q[26];
cp(-pi/131072) q[44],q[27];
cp(-pi/65536) q[44],q[28];
cp(-pi/32768) q[44],q[29];
cp(-pi/16384) q[44],q[30];
cp(-pi/8192) q[44],q[31];
cp(-pi/4096) q[44],q[32];
cp(-pi/2048) q[44],q[33];
cp(-pi/1024) q[44],q[34];
cp(-pi/512) q[44],q[35];
cp(-pi/256) q[44],q[36];
cp(-pi/128) q[44],q[37];
cp(-pi/64) q[44],q[38];
cp(-pi/32) q[44],q[39];
cp(-pi/16) q[44],q[40];
cp(-pi/8) q[44],q[41];
cp(-pi/4) q[44],q[42];
cp(-pi/2) q[44],q[43];
h q[44];
cp(0) q[45],q[0];
cp(0) q[45],q[1];
cp(0) q[45],q[2];
cp(0) q[45],q[3];
cp(-pi/2199023255552) q[45],q[4];
cp(-pi/1099511627776) q[45],q[5];
cp(-pi/549755813888) q[45],q[6];
cp(-pi/274877906944) q[45],q[7];
cp(-pi/137438953472) q[45],q[8];
cp(-pi/68719476736) q[45],q[9];
cp(-pi/34359738368) q[45],q[10];
cp(-pi/17179869184) q[45],q[11];
cp(-pi/8589934592) q[45],q[12];
cp(-pi/4294967296) q[45],q[13];
cp(-pi/2147483648) q[45],q[14];
cp(-pi/1073741824) q[45],q[15];
cp(-pi/536870912) q[45],q[16];
cp(-pi/268435456) q[45],q[17];
cp(-pi/134217728) q[45],q[18];
cp(-pi/67108864) q[45],q[19];
cp(-pi/33554432) q[45],q[20];
cp(-pi/16777216) q[45],q[21];
cp(-pi/8388608) q[45],q[22];
cp(-pi/4194304) q[45],q[23];
cp(-pi/2097152) q[45],q[24];
cp(-pi/1048576) q[45],q[25];
cp(-pi/524288) q[45],q[26];
cp(-pi/262144) q[45],q[27];
cp(-pi/131072) q[45],q[28];
cp(-pi/65536) q[45],q[29];
cp(-pi/32768) q[45],q[30];
cp(-pi/16384) q[45],q[31];
cp(-pi/8192) q[45],q[32];
cp(-pi/4096) q[45],q[33];
cp(-pi/2048) q[45],q[34];
cp(-pi/1024) q[45],q[35];
cp(-pi/512) q[45],q[36];
cp(-pi/256) q[45],q[37];
cp(-pi/128) q[45],q[38];
cp(-pi/64) q[45],q[39];
cp(-pi/32) q[45],q[40];
cp(-pi/16) q[45],q[41];
cp(-pi/8) q[45],q[42];
cp(-pi/4) q[45],q[43];
cp(-pi/2) q[45],q[44];
h q[45];
cp(0) q[46],q[0];
cp(0) q[46],q[1];
cp(0) q[46],q[2];
cp(0) q[46],q[3];
cp(0) q[46],q[4];
cp(-pi/2199023255552) q[46],q[5];
cp(-pi/1099511627776) q[46],q[6];
cp(-pi/549755813888) q[46],q[7];
cp(-pi/274877906944) q[46],q[8];
cp(-pi/137438953472) q[46],q[9];
cp(-pi/68719476736) q[46],q[10];
cp(-pi/34359738368) q[46],q[11];
cp(-pi/17179869184) q[46],q[12];
cp(-pi/8589934592) q[46],q[13];
cp(-pi/4294967296) q[46],q[14];
cp(-pi/2147483648) q[46],q[15];
cp(-pi/1073741824) q[46],q[16];
cp(-pi/536870912) q[46],q[17];
cp(-pi/268435456) q[46],q[18];
cp(-pi/134217728) q[46],q[19];
cp(-pi/67108864) q[46],q[20];
cp(-pi/33554432) q[46],q[21];
cp(-pi/16777216) q[46],q[22];
cp(-pi/8388608) q[46],q[23];
cp(-pi/4194304) q[46],q[24];
cp(-pi/2097152) q[46],q[25];
cp(-pi/1048576) q[46],q[26];
cp(-pi/524288) q[46],q[27];
cp(-pi/262144) q[46],q[28];
cp(-pi/131072) q[46],q[29];
cp(-pi/65536) q[46],q[30];
cp(-pi/32768) q[46],q[31];
cp(-pi/16384) q[46],q[32];
cp(-pi/8192) q[46],q[33];
cp(-pi/4096) q[46],q[34];
cp(-pi/2048) q[46],q[35];
cp(-pi/1024) q[46],q[36];
cp(-pi/512) q[46],q[37];
cp(-pi/256) q[46],q[38];
cp(-pi/128) q[46],q[39];
cp(-pi/64) q[46],q[40];
cp(-pi/32) q[46],q[41];
cp(-pi/16) q[46],q[42];
cp(-pi/8) q[46],q[43];
cp(-pi/4) q[46],q[44];
cp(-pi/2) q[46],q[45];
h q[46];
cp(0) q[47],q[0];
cp(0) q[47],q[1];
cp(0) q[47],q[2];
cp(0) q[47],q[3];
cp(0) q[47],q[4];
cp(0) q[47],q[5];
cp(-pi/2199023255552) q[47],q[6];
cp(-pi/1099511627776) q[47],q[7];
cp(-pi/549755813888) q[47],q[8];
cp(-pi/274877906944) q[47],q[9];
cp(-pi/137438953472) q[47],q[10];
cp(-pi/68719476736) q[47],q[11];
cp(-pi/34359738368) q[47],q[12];
cp(-pi/17179869184) q[47],q[13];
cp(-pi/8589934592) q[47],q[14];
cp(-pi/4294967296) q[47],q[15];
cp(-pi/2147483648) q[47],q[16];
cp(-pi/1073741824) q[47],q[17];
cp(-pi/536870912) q[47],q[18];
cp(-pi/268435456) q[47],q[19];
cp(-pi/134217728) q[47],q[20];
cp(-pi/67108864) q[47],q[21];
cp(-pi/33554432) q[47],q[22];
cp(-pi/16777216) q[47],q[23];
cp(-pi/8388608) q[47],q[24];
cp(-pi/4194304) q[47],q[25];
cp(-pi/2097152) q[47],q[26];
cp(-pi/1048576) q[47],q[27];
cp(-pi/524288) q[47],q[28];
cp(-pi/262144) q[47],q[29];
cp(-pi/131072) q[47],q[30];
cp(-pi/65536) q[47],q[31];
cp(-pi/32768) q[47],q[32];
cp(-pi/16384) q[47],q[33];
cp(-pi/8192) q[47],q[34];
cp(-pi/4096) q[47],q[35];
cp(-pi/2048) q[47],q[36];
cp(-pi/1024) q[47],q[37];
cp(-pi/512) q[47],q[38];
cp(-pi/256) q[47],q[39];
cp(-pi/128) q[47],q[40];
cp(-pi/64) q[47],q[41];
cp(-pi/32) q[47],q[42];
cp(-pi/16) q[47],q[43];
cp(-pi/8) q[47],q[44];
cp(-pi/4) q[47],q[45];
cp(-pi/2) q[47],q[46];
h q[47];
cp(0) q[48],q[0];
cp(0) q[48],q[1];
cp(0) q[48],q[2];
cp(0) q[48],q[3];
cp(0) q[48],q[4];
cp(0) q[48],q[5];
cp(0) q[48],q[6];
cp(-pi/2199023255552) q[48],q[7];
cp(-pi/1099511627776) q[48],q[8];
cp(-pi/549755813888) q[48],q[9];
cp(-pi/274877906944) q[48],q[10];
cp(-pi/137438953472) q[48],q[11];
cp(-pi/68719476736) q[48],q[12];
cp(-pi/34359738368) q[48],q[13];
cp(-pi/17179869184) q[48],q[14];
cp(-pi/8589934592) q[48],q[15];
cp(-pi/4294967296) q[48],q[16];
cp(-pi/2147483648) q[48],q[17];
cp(-pi/1073741824) q[48],q[18];
cp(-pi/536870912) q[48],q[19];
cp(-pi/268435456) q[48],q[20];
cp(-pi/134217728) q[48],q[21];
cp(-pi/67108864) q[48],q[22];
cp(-pi/33554432) q[48],q[23];
cp(-pi/16777216) q[48],q[24];
cp(-pi/8388608) q[48],q[25];
cp(-pi/4194304) q[48],q[26];
cp(-pi/2097152) q[48],q[27];
cp(-pi/1048576) q[48],q[28];
cp(-pi/524288) q[48],q[29];
cp(-pi/262144) q[48],q[30];
cp(-pi/131072) q[48],q[31];
cp(-pi/65536) q[48],q[32];
cp(-pi/32768) q[48],q[33];
cp(-pi/16384) q[48],q[34];
cp(-pi/8192) q[48],q[35];
cp(-pi/4096) q[48],q[36];
cp(-pi/2048) q[48],q[37];
cp(-pi/1024) q[48],q[38];
cp(-pi/512) q[48],q[39];
cp(-pi/256) q[48],q[40];
cp(-pi/128) q[48],q[41];
cp(-pi/64) q[48],q[42];
cp(-pi/32) q[48],q[43];
cp(-pi/16) q[48],q[44];
cp(-pi/8) q[48],q[45];
cp(-pi/4) q[48],q[46];
cp(-pi/2) q[48],q[47];
h q[48];
cp(0) q[49],q[0];
cp(0) q[49],q[1];
cp(0) q[49],q[2];
cp(0) q[49],q[3];
cp(0) q[49],q[4];
cp(0) q[49],q[5];
cp(0) q[49],q[6];
cp(0) q[49],q[7];
cp(-pi/2199023255552) q[49],q[8];
cp(-pi/1099511627776) q[49],q[9];
cp(-pi/549755813888) q[49],q[10];
cp(-pi/274877906944) q[49],q[11];
cp(-pi/137438953472) q[49],q[12];
cp(-pi/68719476736) q[49],q[13];
cp(-pi/34359738368) q[49],q[14];
cp(-pi/17179869184) q[49],q[15];
cp(-pi/8589934592) q[49],q[16];
cp(-pi/4294967296) q[49],q[17];
cp(-pi/2147483648) q[49],q[18];
cp(-pi/1073741824) q[49],q[19];
cp(-pi/536870912) q[49],q[20];
cp(-pi/268435456) q[49],q[21];
cp(-pi/134217728) q[49],q[22];
cp(-pi/67108864) q[49],q[23];
cp(-pi/33554432) q[49],q[24];
cp(-pi/16777216) q[49],q[25];
cp(-pi/8388608) q[49],q[26];
cp(-pi/4194304) q[49],q[27];
cp(-pi/2097152) q[49],q[28];
cp(-pi/1048576) q[49],q[29];
cp(-pi/524288) q[49],q[30];
cp(-pi/262144) q[49],q[31];
cp(-pi/131072) q[49],q[32];
cp(-pi/65536) q[49],q[33];
cp(-pi/32768) q[49],q[34];
cp(-pi/16384) q[49],q[35];
cp(-pi/8192) q[49],q[36];
cp(-pi/4096) q[49],q[37];
cp(-pi/2048) q[49],q[38];
cp(-pi/1024) q[49],q[39];
cp(-pi/512) q[49],q[40];
cp(-pi/256) q[49],q[41];
cp(-pi/128) q[49],q[42];
cp(-pi/64) q[49],q[43];
cp(-pi/32) q[49],q[44];
cp(-pi/16) q[49],q[45];
cp(-pi/8) q[49],q[46];
cp(-pi/4) q[49],q[47];
cp(-pi/2) q[49],q[48];
h q[49];
cp(0) q[50],q[0];
cp(0) q[50],q[1];
cp(0) q[50],q[2];
cp(0) q[50],q[3];
cp(0) q[50],q[4];
cp(0) q[50],q[5];
cp(0) q[50],q[6];
cp(0) q[50],q[7];
cp(0) q[50],q[8];
cp(-pi/2199023255552) q[50],q[9];
cp(-pi/1099511627776) q[50],q[10];
cp(-pi/549755813888) q[50],q[11];
cp(-pi/274877906944) q[50],q[12];
cp(-pi/137438953472) q[50],q[13];
cp(-pi/68719476736) q[50],q[14];
cp(-pi/34359738368) q[50],q[15];
cp(-pi/17179869184) q[50],q[16];
cp(-pi/8589934592) q[50],q[17];
cp(-pi/4294967296) q[50],q[18];
cp(-pi/2147483648) q[50],q[19];
cp(-pi/1073741824) q[50],q[20];
cp(-pi/536870912) q[50],q[21];
cp(-pi/268435456) q[50],q[22];
cp(-pi/134217728) q[50],q[23];
cp(-pi/67108864) q[50],q[24];
cp(-pi/33554432) q[50],q[25];
cp(-pi/16777216) q[50],q[26];
cp(-pi/8388608) q[50],q[27];
cp(-pi/4194304) q[50],q[28];
cp(-pi/2097152) q[50],q[29];
cp(-pi/1048576) q[50],q[30];
cp(-pi/524288) q[50],q[31];
cp(-pi/262144) q[50],q[32];
cp(-pi/131072) q[50],q[33];
cp(-pi/65536) q[50],q[34];
cp(-pi/32768) q[50],q[35];
cp(-pi/16384) q[50],q[36];
cp(-pi/8192) q[50],q[37];
cp(-pi/4096) q[50],q[38];
cp(-pi/2048) q[50],q[39];
cp(-pi/1024) q[50],q[40];
cp(-pi/512) q[50],q[41];
cp(-pi/256) q[50],q[42];
cp(-pi/128) q[50],q[43];
cp(-pi/64) q[50],q[44];
cp(-pi/32) q[50],q[45];
cp(-pi/16) q[50],q[46];
cp(-pi/8) q[50],q[47];
cp(-pi/4) q[50],q[48];
cp(-pi/2) q[50],q[49];
h q[50];
cp(0) q[51],q[0];
cp(0) q[51],q[1];
cp(0) q[51],q[2];
cp(0) q[51],q[3];
cp(0) q[51],q[4];
cp(0) q[51],q[5];
cp(0) q[51],q[6];
cp(0) q[51],q[7];
cp(0) q[51],q[8];
cp(0) q[51],q[9];
cp(-pi/2199023255552) q[51],q[10];
cp(-pi/1099511627776) q[51],q[11];
cp(-pi/549755813888) q[51],q[12];
cp(-pi/274877906944) q[51],q[13];
cp(-pi/137438953472) q[51],q[14];
cp(-pi/68719476736) q[51],q[15];
cp(-pi/34359738368) q[51],q[16];
cp(-pi/17179869184) q[51],q[17];
cp(-pi/8589934592) q[51],q[18];
cp(-pi/4294967296) q[51],q[19];
cp(-pi/2147483648) q[51],q[20];
cp(-pi/1073741824) q[51],q[21];
cp(-pi/536870912) q[51],q[22];
cp(-pi/268435456) q[51],q[23];
cp(-pi/134217728) q[51],q[24];
cp(-pi/67108864) q[51],q[25];
cp(-pi/33554432) q[51],q[26];
cp(-pi/16777216) q[51],q[27];
cp(-pi/8388608) q[51],q[28];
cp(-pi/4194304) q[51],q[29];
cp(-pi/2097152) q[51],q[30];
cp(-pi/1048576) q[51],q[31];
cp(-pi/524288) q[51],q[32];
cp(-pi/262144) q[51],q[33];
cp(-pi/131072) q[51],q[34];
cp(-pi/65536) q[51],q[35];
cp(-pi/32768) q[51],q[36];
cp(-pi/16384) q[51],q[37];
cp(-pi/8192) q[51],q[38];
cp(-pi/4096) q[51],q[39];
cp(-pi/2048) q[51],q[40];
cp(-pi/1024) q[51],q[41];
cp(-pi/512) q[51],q[42];
cp(-pi/256) q[51],q[43];
cp(-pi/128) q[51],q[44];
cp(-pi/64) q[51],q[45];
cp(-pi/32) q[51],q[46];
cp(-pi/16) q[51],q[47];
cp(-pi/8) q[51],q[48];
cp(-pi/4) q[51],q[49];
cp(-pi/2) q[51],q[50];
h q[51];
cp(0) q[52],q[0];
cp(0) q[52],q[1];
cp(0) q[52],q[2];
cp(0) q[52],q[3];
cp(0) q[52],q[4];
cp(0) q[52],q[5];
cp(0) q[52],q[6];
cp(0) q[52],q[7];
cp(0) q[52],q[8];
cp(0) q[52],q[9];
cp(0) q[52],q[10];
cp(-pi/2199023255552) q[52],q[11];
cp(-pi/1099511627776) q[52],q[12];
cp(-pi/549755813888) q[52],q[13];
cp(-pi/274877906944) q[52],q[14];
cp(-pi/137438953472) q[52],q[15];
cp(-pi/68719476736) q[52],q[16];
cp(-pi/34359738368) q[52],q[17];
cp(-pi/17179869184) q[52],q[18];
cp(-pi/8589934592) q[52],q[19];
cp(-pi/4294967296) q[52],q[20];
cp(-pi/2147483648) q[52],q[21];
cp(-pi/1073741824) q[52],q[22];
cp(-pi/536870912) q[52],q[23];
cp(-pi/268435456) q[52],q[24];
cp(-pi/134217728) q[52],q[25];
cp(-pi/67108864) q[52],q[26];
cp(-pi/33554432) q[52],q[27];
cp(-pi/16777216) q[52],q[28];
cp(-pi/8388608) q[52],q[29];
cp(-pi/4194304) q[52],q[30];
cp(-pi/2097152) q[52],q[31];
cp(-pi/1048576) q[52],q[32];
cp(-pi/524288) q[52],q[33];
cp(-pi/262144) q[52],q[34];
cp(-pi/131072) q[52],q[35];
cp(-pi/65536) q[52],q[36];
cp(-pi/32768) q[52],q[37];
cp(-pi/16384) q[52],q[38];
cp(-pi/8192) q[52],q[39];
cp(-pi/4096) q[52],q[40];
cp(-pi/2048) q[52],q[41];
cp(-pi/1024) q[52],q[42];
cp(-pi/512) q[52],q[43];
cp(-pi/256) q[52],q[44];
cp(-pi/128) q[52],q[45];
cp(-pi/64) q[52],q[46];
cp(-pi/32) q[52],q[47];
cp(-pi/16) q[52],q[48];
cp(-pi/8) q[52],q[49];
cp(-pi/4) q[52],q[50];
cp(-pi/2) q[52],q[51];
h q[52];
cp(0) q[53],q[0];
cp(0) q[53],q[1];
cp(0) q[53],q[2];
cp(0) q[53],q[3];
cp(0) q[53],q[4];
cp(0) q[53],q[5];
cp(0) q[53],q[6];
cp(0) q[53],q[7];
cp(0) q[53],q[8];
cp(0) q[53],q[9];
cp(0) q[53],q[10];
cp(0) q[53],q[11];
cp(-pi/2199023255552) q[53],q[12];
cp(-pi/1099511627776) q[53],q[13];
cp(-pi/549755813888) q[53],q[14];
cp(-pi/274877906944) q[53],q[15];
cp(-pi/137438953472) q[53],q[16];
cp(-pi/68719476736) q[53],q[17];
cp(-pi/34359738368) q[53],q[18];
cp(-pi/17179869184) q[53],q[19];
cp(-pi/8589934592) q[53],q[20];
cp(-pi/4294967296) q[53],q[21];
cp(-pi/2147483648) q[53],q[22];
cp(-pi/1073741824) q[53],q[23];
cp(-pi/536870912) q[53],q[24];
cp(-pi/268435456) q[53],q[25];
cp(-pi/134217728) q[53],q[26];
cp(-pi/67108864) q[53],q[27];
cp(-pi/33554432) q[53],q[28];
cp(-pi/16777216) q[53],q[29];
cp(-pi/8388608) q[53],q[30];
cp(-pi/4194304) q[53],q[31];
cp(-pi/2097152) q[53],q[32];
cp(-pi/1048576) q[53],q[33];
cp(-pi/524288) q[53],q[34];
cp(-pi/262144) q[53],q[35];
cp(-pi/131072) q[53],q[36];
cp(-pi/65536) q[53],q[37];
cp(-pi/32768) q[53],q[38];
cp(-pi/16384) q[53],q[39];
cp(-pi/8192) q[53],q[40];
cp(-pi/4096) q[53],q[41];
cp(-pi/2048) q[53],q[42];
cp(-pi/1024) q[53],q[43];
cp(-pi/512) q[53],q[44];
cp(-pi/256) q[53],q[45];
cp(-pi/128) q[53],q[46];
cp(-pi/64) q[53],q[47];
cp(-pi/32) q[53],q[48];
cp(-pi/16) q[53],q[49];
cp(-pi/8) q[53],q[50];
cp(-pi/4) q[53],q[51];
cp(-pi/2) q[53],q[52];
h q[53];
cp(0) q[54],q[0];
cp(0) q[54],q[1];
cp(0) q[54],q[2];
cp(0) q[54],q[3];
cp(0) q[54],q[4];
cp(0) q[54],q[5];
cp(0) q[54],q[6];
cp(0) q[54],q[7];
cp(0) q[54],q[8];
cp(0) q[54],q[9];
cp(0) q[54],q[10];
cp(0) q[54],q[11];
cp(0) q[54],q[12];
cp(-pi/2199023255552) q[54],q[13];
cp(-pi/1099511627776) q[54],q[14];
cp(-pi/549755813888) q[54],q[15];
cp(-pi/274877906944) q[54],q[16];
cp(-pi/137438953472) q[54],q[17];
cp(-pi/68719476736) q[54],q[18];
cp(-pi/34359738368) q[54],q[19];
cp(-pi/17179869184) q[54],q[20];
cp(-pi/8589934592) q[54],q[21];
cp(-pi/4294967296) q[54],q[22];
cp(-pi/2147483648) q[54],q[23];
cp(-pi/1073741824) q[54],q[24];
cp(-pi/536870912) q[54],q[25];
cp(-pi/268435456) q[54],q[26];
cp(-pi/134217728) q[54],q[27];
cp(-pi/67108864) q[54],q[28];
cp(-pi/33554432) q[54],q[29];
cp(-pi/16777216) q[54],q[30];
cp(-pi/8388608) q[54],q[31];
cp(-pi/4194304) q[54],q[32];
cp(-pi/2097152) q[54],q[33];
cp(-pi/1048576) q[54],q[34];
cp(-pi/524288) q[54],q[35];
cp(-pi/262144) q[54],q[36];
cp(-pi/131072) q[54],q[37];
cp(-pi/65536) q[54],q[38];
cp(-pi/32768) q[54],q[39];
cp(-pi/16384) q[54],q[40];
cp(-pi/8192) q[54],q[41];
cp(-pi/4096) q[54],q[42];
cp(-pi/2048) q[54],q[43];
cp(-pi/1024) q[54],q[44];
cp(-pi/512) q[54],q[45];
cp(-pi/256) q[54],q[46];
cp(-pi/128) q[54],q[47];
cp(-pi/64) q[54],q[48];
cp(-pi/32) q[54],q[49];
cp(-pi/16) q[54],q[50];
cp(-pi/8) q[54],q[51];
cp(-pi/4) q[54],q[52];
cp(-pi/2) q[54],q[53];
h q[54];
cp(0) q[55],q[0];
cp(0) q[55],q[1];
cp(0) q[55],q[2];
cp(0) q[55],q[3];
cp(0) q[55],q[4];
cp(0) q[55],q[5];
cp(0) q[55],q[6];
cp(0) q[55],q[7];
cp(0) q[55],q[8];
cp(0) q[55],q[9];
cp(0) q[55],q[10];
cp(0) q[55],q[11];
cp(0) q[55],q[12];
cp(0) q[55],q[13];
cp(-pi/2199023255552) q[55],q[14];
cp(-pi/1099511627776) q[55],q[15];
cp(-pi/549755813888) q[55],q[16];
cp(-pi/274877906944) q[55],q[17];
cp(-pi/137438953472) q[55],q[18];
cp(-pi/68719476736) q[55],q[19];
cp(-pi/34359738368) q[55],q[20];
cp(-pi/17179869184) q[55],q[21];
cp(-pi/8589934592) q[55],q[22];
cp(-pi/4294967296) q[55],q[23];
cp(-pi/2147483648) q[55],q[24];
cp(-pi/1073741824) q[55],q[25];
cp(-pi/536870912) q[55],q[26];
cp(-pi/268435456) q[55],q[27];
cp(-pi/134217728) q[55],q[28];
cp(-pi/67108864) q[55],q[29];
cp(-pi/33554432) q[55],q[30];
cp(-pi/16777216) q[55],q[31];
cp(-pi/8388608) q[55],q[32];
cp(-pi/4194304) q[55],q[33];
cp(-pi/2097152) q[55],q[34];
cp(-pi/1048576) q[55],q[35];
cp(-pi/524288) q[55],q[36];
cp(-pi/262144) q[55],q[37];
cp(-pi/131072) q[55],q[38];
cp(-pi/65536) q[55],q[39];
cp(-pi/32768) q[55],q[40];
cp(-pi/16384) q[55],q[41];
cp(-pi/8192) q[55],q[42];
cp(-pi/4096) q[55],q[43];
cp(-pi/2048) q[55],q[44];
cp(-pi/1024) q[55],q[45];
cp(-pi/512) q[55],q[46];
cp(-pi/256) q[55],q[47];
cp(-pi/128) q[55],q[48];
cp(-pi/64) q[55],q[49];
cp(-pi/32) q[55],q[50];
cp(-pi/16) q[55],q[51];
cp(-pi/8) q[55],q[52];
cp(-pi/4) q[55],q[53];
cp(-pi/2) q[55],q[54];
h q[55];
cp(0) q[56],q[0];
cp(0) q[56],q[1];
cp(0) q[56],q[2];
cp(0) q[56],q[3];
cp(0) q[56],q[4];
cp(0) q[56],q[5];
cp(0) q[56],q[6];
cp(0) q[56],q[7];
cp(0) q[56],q[8];
cp(0) q[56],q[9];
cp(0) q[56],q[10];
cp(0) q[56],q[11];
cp(0) q[56],q[12];
cp(0) q[56],q[13];
cp(0) q[56],q[14];
cp(-pi/2199023255552) q[56],q[15];
cp(-pi/1099511627776) q[56],q[16];
cp(-pi/549755813888) q[56],q[17];
cp(-pi/274877906944) q[56],q[18];
cp(-pi/137438953472) q[56],q[19];
cp(-pi/68719476736) q[56],q[20];
cp(-pi/34359738368) q[56],q[21];
cp(-pi/17179869184) q[56],q[22];
cp(-pi/8589934592) q[56],q[23];
cp(-pi/4294967296) q[56],q[24];
cp(-pi/2147483648) q[56],q[25];
cp(-pi/1073741824) q[56],q[26];
cp(-pi/536870912) q[56],q[27];
cp(-pi/268435456) q[56],q[28];
cp(-pi/134217728) q[56],q[29];
cp(-pi/67108864) q[56],q[30];
cp(-pi/33554432) q[56],q[31];
cp(-pi/16777216) q[56],q[32];
cp(-pi/8388608) q[56],q[33];
cp(-pi/4194304) q[56],q[34];
cp(-pi/2097152) q[56],q[35];
cp(-pi/1048576) q[56],q[36];
cp(-pi/524288) q[56],q[37];
cp(-pi/262144) q[56],q[38];
cp(-pi/131072) q[56],q[39];
cp(-pi/65536) q[56],q[40];
cp(-pi/32768) q[56],q[41];
cp(-pi/16384) q[56],q[42];
cp(-pi/8192) q[56],q[43];
cp(-pi/4096) q[56],q[44];
cp(-pi/2048) q[56],q[45];
cp(-pi/1024) q[56],q[46];
cp(-pi/512) q[56],q[47];
cp(-pi/256) q[56],q[48];
cp(-pi/128) q[56],q[49];
cp(-pi/64) q[56],q[50];
cp(-pi/32) q[56],q[51];
cp(-pi/16) q[56],q[52];
cp(-pi/8) q[56],q[53];
cp(-pi/4) q[56],q[54];
cp(-pi/2) q[56],q[55];
h q[56];
cp(0) q[57],q[0];
cp(0) q[57],q[1];
cp(0) q[57],q[2];
cp(0) q[57],q[3];
cp(0) q[57],q[4];
cp(0) q[57],q[5];
cp(0) q[57],q[6];
cp(0) q[57],q[7];
cp(0) q[57],q[8];
cp(0) q[57],q[9];
cp(0) q[57],q[10];
cp(0) q[57],q[11];
cp(0) q[57],q[12];
cp(0) q[57],q[13];
cp(0) q[57],q[14];
cp(0) q[57],q[15];
cp(-pi/2199023255552) q[57],q[16];
cp(-pi/1099511627776) q[57],q[17];
cp(-pi/549755813888) q[57],q[18];
cp(-pi/274877906944) q[57],q[19];
cp(-pi/137438953472) q[57],q[20];
cp(-pi/68719476736) q[57],q[21];
cp(-pi/34359738368) q[57],q[22];
cp(-pi/17179869184) q[57],q[23];
cp(-pi/8589934592) q[57],q[24];
cp(-pi/4294967296) q[57],q[25];
cp(-pi/2147483648) q[57],q[26];
cp(-pi/1073741824) q[57],q[27];
cp(-pi/536870912) q[57],q[28];
cp(-pi/268435456) q[57],q[29];
cp(-pi/134217728) q[57],q[30];
cp(-pi/67108864) q[57],q[31];
cp(-pi/33554432) q[57],q[32];
cp(-pi/16777216) q[57],q[33];
cp(-pi/8388608) q[57],q[34];
cp(-pi/4194304) q[57],q[35];
cp(-pi/2097152) q[57],q[36];
cp(-pi/1048576) q[57],q[37];
cp(-pi/524288) q[57],q[38];
cp(-pi/262144) q[57],q[39];
cp(-pi/131072) q[57],q[40];
cp(-pi/65536) q[57],q[41];
cp(-pi/32768) q[57],q[42];
cp(-pi/16384) q[57],q[43];
cp(-pi/8192) q[57],q[44];
cp(-pi/4096) q[57],q[45];
cp(-pi/2048) q[57],q[46];
cp(-pi/1024) q[57],q[47];
cp(-pi/512) q[57],q[48];
cp(-pi/256) q[57],q[49];
cp(-pi/128) q[57],q[50];
cp(-pi/64) q[57],q[51];
cp(-pi/32) q[57],q[52];
cp(-pi/16) q[57],q[53];
cp(-pi/8) q[57],q[54];
cp(-pi/4) q[57],q[55];
cp(-pi/2) q[57],q[56];
h q[57];
cp(0) q[58],q[0];
cp(0) q[58],q[1];
cp(0) q[58],q[2];
cp(0) q[58],q[3];
cp(0) q[58],q[4];
cp(0) q[58],q[5];
cp(0) q[58],q[6];
cp(0) q[58],q[7];
cp(0) q[58],q[8];
cp(0) q[58],q[9];
cp(0) q[58],q[10];
cp(0) q[58],q[11];
cp(0) q[58],q[12];
cp(0) q[58],q[13];
cp(0) q[58],q[14];
cp(0) q[58],q[15];
cp(0) q[58],q[16];
cp(-pi/2199023255552) q[58],q[17];
cp(-pi/1099511627776) q[58],q[18];
cp(-pi/549755813888) q[58],q[19];
cp(-pi/274877906944) q[58],q[20];
cp(-pi/137438953472) q[58],q[21];
cp(-pi/68719476736) q[58],q[22];
cp(-pi/34359738368) q[58],q[23];
cp(-pi/17179869184) q[58],q[24];
cp(-pi/8589934592) q[58],q[25];
cp(-pi/4294967296) q[58],q[26];
cp(-pi/2147483648) q[58],q[27];
cp(-pi/1073741824) q[58],q[28];
cp(-pi/536870912) q[58],q[29];
cp(-pi/268435456) q[58],q[30];
cp(-pi/134217728) q[58],q[31];
cp(-pi/67108864) q[58],q[32];
cp(-pi/33554432) q[58],q[33];
cp(-pi/16777216) q[58],q[34];
cp(-pi/8388608) q[58],q[35];
cp(-pi/4194304) q[58],q[36];
cp(-pi/2097152) q[58],q[37];
cp(-pi/1048576) q[58],q[38];
cp(-pi/524288) q[58],q[39];
cp(-pi/262144) q[58],q[40];
cp(-pi/131072) q[58],q[41];
cp(-pi/65536) q[58],q[42];
cp(-pi/32768) q[58],q[43];
cp(-pi/16384) q[58],q[44];
cp(-pi/8192) q[58],q[45];
cp(-pi/4096) q[58],q[46];
cp(-pi/2048) q[58],q[47];
cp(-pi/1024) q[58],q[48];
cp(-pi/512) q[58],q[49];
cp(-pi/256) q[58],q[50];
cp(-pi/128) q[58],q[51];
cp(-pi/64) q[58],q[52];
cp(-pi/32) q[58],q[53];
cp(-pi/16) q[58],q[54];
cp(-pi/8) q[58],q[55];
cp(-pi/4) q[58],q[56];
cp(-pi/2) q[58],q[57];
h q[58];
cp(0) q[59],q[0];
cp(0) q[59],q[1];
cp(0) q[59],q[2];
cp(0) q[59],q[3];
cp(0) q[59],q[4];
cp(0) q[59],q[5];
cp(0) q[59],q[6];
cp(0) q[59],q[7];
cp(0) q[59],q[8];
cp(0) q[59],q[9];
cp(0) q[59],q[10];
cp(0) q[59],q[11];
cp(0) q[59],q[12];
cp(0) q[59],q[13];
cp(0) q[59],q[14];
cp(0) q[59],q[15];
cp(0) q[59],q[16];
cp(0) q[59],q[17];
cp(-pi/2199023255552) q[59],q[18];
cp(-pi/1099511627776) q[59],q[19];
cp(-pi/549755813888) q[59],q[20];
cp(-pi/274877906944) q[59],q[21];
cp(-pi/137438953472) q[59],q[22];
cp(-pi/68719476736) q[59],q[23];
cp(-pi/34359738368) q[59],q[24];
cp(-pi/17179869184) q[59],q[25];
cp(-pi/8589934592) q[59],q[26];
cp(-pi/4294967296) q[59],q[27];
cp(-pi/2147483648) q[59],q[28];
cp(-pi/1073741824) q[59],q[29];
cp(-pi/536870912) q[59],q[30];
cp(-pi/268435456) q[59],q[31];
cp(-pi/134217728) q[59],q[32];
cp(-pi/67108864) q[59],q[33];
cp(-pi/33554432) q[59],q[34];
cp(-pi/16777216) q[59],q[35];
cp(-pi/8388608) q[59],q[36];
cp(-pi/4194304) q[59],q[37];
cp(-pi/2097152) q[59],q[38];
cp(-pi/1048576) q[59],q[39];
cp(-pi/524288) q[59],q[40];
cp(-pi/262144) q[59],q[41];
cp(-pi/131072) q[59],q[42];
cp(-pi/65536) q[59],q[43];
cp(-pi/32768) q[59],q[44];
cp(-pi/16384) q[59],q[45];
cp(-pi/8192) q[59],q[46];
cp(-pi/4096) q[59],q[47];
cp(-pi/2048) q[59],q[48];
cp(-pi/1024) q[59],q[49];
cp(-pi/512) q[59],q[50];
cp(-pi/256) q[59],q[51];
cp(-pi/128) q[59],q[52];
cp(-pi/64) q[59],q[53];
cp(-pi/32) q[59],q[54];
cp(-pi/16) q[59],q[55];
cp(-pi/8) q[59],q[56];
cp(-pi/4) q[59],q[57];
cp(-pi/2) q[59],q[58];
h q[59];
cp(0) q[60],q[0];
cp(0) q[60],q[1];
cp(0) q[60],q[2];
cp(0) q[60],q[3];
cp(0) q[60],q[4];
cp(0) q[60],q[5];
cp(0) q[60],q[6];
cp(0) q[60],q[7];
cp(0) q[60],q[8];
cp(0) q[60],q[9];
cp(0) q[60],q[10];
cp(0) q[60],q[11];
cp(0) q[60],q[12];
cp(0) q[60],q[13];
cp(0) q[60],q[14];
cp(0) q[60],q[15];
cp(0) q[60],q[16];
cp(0) q[60],q[17];
cp(0) q[60],q[18];
cp(-pi/2199023255552) q[60],q[19];
cp(-pi/1099511627776) q[60],q[20];
cp(-pi/549755813888) q[60],q[21];
cp(-pi/274877906944) q[60],q[22];
cp(-pi/137438953472) q[60],q[23];
cp(-pi/68719476736) q[60],q[24];
cp(-pi/34359738368) q[60],q[25];
cp(-pi/17179869184) q[60],q[26];
cp(-pi/8589934592) q[60],q[27];
cp(-pi/4294967296) q[60],q[28];
cp(-pi/2147483648) q[60],q[29];
cp(-pi/1073741824) q[60],q[30];
cp(-pi/536870912) q[60],q[31];
cp(-pi/268435456) q[60],q[32];
cp(-pi/134217728) q[60],q[33];
cp(-pi/67108864) q[60],q[34];
cp(-pi/33554432) q[60],q[35];
cp(-pi/16777216) q[60],q[36];
cp(-pi/8388608) q[60],q[37];
cp(-pi/4194304) q[60],q[38];
cp(-pi/2097152) q[60],q[39];
cp(-pi/1048576) q[60],q[40];
cp(-pi/524288) q[60],q[41];
cp(-pi/262144) q[60],q[42];
cp(-pi/131072) q[60],q[43];
cp(-pi/65536) q[60],q[44];
cp(-pi/32768) q[60],q[45];
cp(-pi/16384) q[60],q[46];
cp(-pi/8192) q[60],q[47];
cp(-pi/4096) q[60],q[48];
cp(-pi/2048) q[60],q[49];
cp(-pi/1024) q[60],q[50];
cp(-pi/512) q[60],q[51];
cp(-pi/256) q[60],q[52];
cp(-pi/128) q[60],q[53];
cp(-pi/64) q[60],q[54];
cp(-pi/32) q[60],q[55];
cp(-pi/16) q[60],q[56];
cp(-pi/8) q[60],q[57];
cp(-pi/4) q[60],q[58];
cp(-pi/2) q[60],q[59];
h q[60];
cp(0) q[61],q[0];
cp(0) q[61],q[1];
cp(0) q[61],q[2];
cp(0) q[61],q[3];
cp(0) q[61],q[4];
cp(0) q[61],q[5];
cp(0) q[61],q[6];
cp(0) q[61],q[7];
cp(0) q[61],q[8];
cp(0) q[61],q[9];
cp(0) q[61],q[10];
cp(0) q[61],q[11];
cp(0) q[61],q[12];
cp(0) q[61],q[13];
cp(0) q[61],q[14];
cp(0) q[61],q[15];
cp(0) q[61],q[16];
cp(0) q[61],q[17];
cp(0) q[61],q[18];
cp(0) q[61],q[19];
cp(-pi/2199023255552) q[61],q[20];
cp(-pi/1099511627776) q[61],q[21];
cp(-pi/549755813888) q[61],q[22];
cp(-pi/274877906944) q[61],q[23];
cp(-pi/137438953472) q[61],q[24];
cp(-pi/68719476736) q[61],q[25];
cp(-pi/34359738368) q[61],q[26];
cp(-pi/17179869184) q[61],q[27];
cp(-pi/8589934592) q[61],q[28];
cp(-pi/4294967296) q[61],q[29];
cp(-pi/2147483648) q[61],q[30];
cp(-pi/1073741824) q[61],q[31];
cp(-pi/536870912) q[61],q[32];
cp(-pi/268435456) q[61],q[33];
cp(-pi/134217728) q[61],q[34];
cp(-pi/67108864) q[61],q[35];
cp(-pi/33554432) q[61],q[36];
cp(-pi/16777216) q[61],q[37];
cp(-pi/8388608) q[61],q[38];
cp(-pi/4194304) q[61],q[39];
cp(-pi/2097152) q[61],q[40];
cp(-pi/1048576) q[61],q[41];
cp(-pi/524288) q[61],q[42];
cp(-pi/262144) q[61],q[43];
cp(-pi/131072) q[61],q[44];
cp(-pi/65536) q[61],q[45];
cp(-pi/32768) q[61],q[46];
cp(-pi/16384) q[61],q[47];
cp(-pi/8192) q[61],q[48];
cp(-pi/4096) q[61],q[49];
cp(-pi/2048) q[61],q[50];
cp(-pi/1024) q[61],q[51];
cp(-pi/512) q[61],q[52];
cp(-pi/256) q[61],q[53];
cp(-pi/128) q[61],q[54];
cp(-pi/64) q[61],q[55];
cp(-pi/32) q[61],q[56];
cp(-pi/16) q[61],q[57];
cp(-pi/8) q[61],q[58];
cp(-pi/4) q[61],q[59];
cp(-pi/2) q[61],q[60];
h q[61];
cp(0) q[62],q[0];
cp(0) q[62],q[1];
cp(0) q[62],q[2];
cp(0) q[62],q[3];
cp(0) q[62],q[4];
cp(0) q[62],q[5];
cp(0) q[62],q[6];
cp(0) q[62],q[7];
cp(0) q[62],q[8];
cp(0) q[62],q[9];
cp(0) q[62],q[10];
cp(0) q[62],q[11];
cp(0) q[62],q[12];
cp(0) q[62],q[13];
cp(0) q[62],q[14];
cp(0) q[62],q[15];
cp(0) q[62],q[16];
cp(0) q[62],q[17];
cp(0) q[62],q[18];
cp(0) q[62],q[19];
cp(0) q[62],q[20];
cp(-pi/2199023255552) q[62],q[21];
cp(-pi/1099511627776) q[62],q[22];
cp(-pi/549755813888) q[62],q[23];
cp(-pi/274877906944) q[62],q[24];
cp(-pi/137438953472) q[62],q[25];
cp(-pi/68719476736) q[62],q[26];
cp(-pi/34359738368) q[62],q[27];
cp(-pi/17179869184) q[62],q[28];
cp(-pi/8589934592) q[62],q[29];
cp(-pi/4294967296) q[62],q[30];
cp(-pi/2147483648) q[62],q[31];
cp(-pi/1073741824) q[62],q[32];
cp(-pi/536870912) q[62],q[33];
cp(-pi/268435456) q[62],q[34];
cp(-pi/134217728) q[62],q[35];
cp(-pi/67108864) q[62],q[36];
cp(-pi/33554432) q[62],q[37];
cp(-pi/16777216) q[62],q[38];
cp(-pi/8388608) q[62],q[39];
cp(-pi/4194304) q[62],q[40];
cp(-pi/2097152) q[62],q[41];
cp(-pi/1048576) q[62],q[42];
cp(-pi/524288) q[62],q[43];
cp(-pi/262144) q[62],q[44];
cp(-pi/131072) q[62],q[45];
cp(-pi/65536) q[62],q[46];
cp(-pi/32768) q[62],q[47];
cp(-pi/16384) q[62],q[48];
cp(-pi/8192) q[62],q[49];
cp(-pi/4096) q[62],q[50];
cp(-pi/2048) q[62],q[51];
cp(-pi/1024) q[62],q[52];
cp(-pi/512) q[62],q[53];
cp(-pi/256) q[62],q[54];
cp(-pi/128) q[62],q[55];
cp(-pi/64) q[62],q[56];
cp(-pi/32) q[62],q[57];
cp(-pi/16) q[62],q[58];
cp(-pi/8) q[62],q[59];
cp(-pi/4) q[62],q[60];
cp(-pi/2) q[62],q[61];
h q[62];
cp(0) q[63],q[0];
cp(0) q[63],q[1];
cp(0) q[63],q[2];
cp(0) q[63],q[3];
cp(0) q[63],q[4];
cp(0) q[63],q[5];
cp(0) q[63],q[6];
cp(0) q[63],q[7];
cp(0) q[63],q[8];
cp(0) q[63],q[9];
cp(0) q[63],q[10];
cp(0) q[63],q[11];
cp(0) q[63],q[12];
cp(0) q[63],q[13];
cp(0) q[63],q[14];
cp(0) q[63],q[15];
cp(0) q[63],q[16];
cp(0) q[63],q[17];
cp(0) q[63],q[18];
cp(0) q[63],q[19];
cp(0) q[63],q[20];
cp(0) q[63],q[21];
cp(-pi/2199023255552) q[63],q[22];
cp(-pi/1099511627776) q[63],q[23];
cp(-pi/549755813888) q[63],q[24];
cp(-pi/274877906944) q[63],q[25];
cp(-pi/137438953472) q[63],q[26];
cp(-pi/68719476736) q[63],q[27];
cp(-pi/34359738368) q[63],q[28];
cp(-pi/17179869184) q[63],q[29];
cp(-pi/8589934592) q[63],q[30];
cp(-pi/4294967296) q[63],q[31];
cp(-pi/2147483648) q[63],q[32];
cp(-pi/1073741824) q[63],q[33];
cp(-pi/536870912) q[63],q[34];
cp(-pi/268435456) q[63],q[35];
cp(-pi/134217728) q[63],q[36];
cp(-pi/67108864) q[63],q[37];
cp(-pi/33554432) q[63],q[38];
cp(-pi/16777216) q[63],q[39];
cp(-pi/8388608) q[63],q[40];
cp(-pi/4194304) q[63],q[41];
cp(-pi/2097152) q[63],q[42];
cp(-pi/1048576) q[63],q[43];
cp(-pi/524288) q[63],q[44];
cp(-pi/262144) q[63],q[45];
cp(-pi/131072) q[63],q[46];
cp(-pi/65536) q[63],q[47];
cp(-pi/32768) q[63],q[48];
cp(-pi/16384) q[63],q[49];
cp(-pi/8192) q[63],q[50];
cp(-pi/4096) q[63],q[51];
cp(-pi/2048) q[63],q[52];
cp(-pi/1024) q[63],q[53];
cp(-pi/512) q[63],q[54];
cp(-pi/256) q[63],q[55];
cp(-pi/128) q[63],q[56];
cp(-pi/64) q[63],q[57];
cp(-pi/32) q[63],q[58];
cp(-pi/16) q[63],q[59];
cp(-pi/8) q[63],q[60];
cp(-pi/4) q[63],q[61];
cp(-pi/2) q[63],q[62];
h q[63];
cp(0) q[64],q[0];
cp(0) q[64],q[1];
cp(0) q[64],q[2];
cp(0) q[64],q[3];
cp(0) q[64],q[4];
cp(0) q[64],q[5];
cp(0) q[64],q[6];
cp(0) q[64],q[7];
cp(0) q[64],q[8];
cp(0) q[64],q[9];
cp(0) q[64],q[10];
cp(0) q[64],q[11];
cp(0) q[64],q[12];
cp(0) q[64],q[13];
cp(0) q[64],q[14];
cp(0) q[64],q[15];
cp(0) q[64],q[16];
cp(0) q[64],q[17];
cp(0) q[64],q[18];
cp(0) q[64],q[19];
cp(0) q[64],q[20];
cp(0) q[64],q[21];
cp(0) q[64],q[22];
cp(-pi/2199023255552) q[64],q[23];
cp(-pi/1099511627776) q[64],q[24];
cp(-pi/549755813888) q[64],q[25];
cp(-pi/274877906944) q[64],q[26];
cp(-pi/137438953472) q[64],q[27];
cp(-pi/68719476736) q[64],q[28];
cp(-pi/34359738368) q[64],q[29];
cp(-pi/17179869184) q[64],q[30];
cp(-pi/8589934592) q[64],q[31];
cp(-pi/4294967296) q[64],q[32];
cp(-pi/2147483648) q[64],q[33];
cp(-pi/1073741824) q[64],q[34];
cp(-pi/536870912) q[64],q[35];
cp(-pi/268435456) q[64],q[36];
cp(-pi/134217728) q[64],q[37];
cp(-pi/67108864) q[64],q[38];
cp(-pi/33554432) q[64],q[39];
cp(-pi/16777216) q[64],q[40];
cp(-pi/8388608) q[64],q[41];
cp(-pi/4194304) q[64],q[42];
cp(-pi/2097152) q[64],q[43];
cp(-pi/1048576) q[64],q[44];
cp(-pi/524288) q[64],q[45];
cp(-pi/262144) q[64],q[46];
cp(-pi/131072) q[64],q[47];
cp(-pi/65536) q[64],q[48];
cp(-pi/32768) q[64],q[49];
cp(-pi/16384) q[64],q[50];
cp(-pi/8192) q[64],q[51];
cp(-pi/4096) q[64],q[52];
cp(-pi/2048) q[64],q[53];
cp(-pi/1024) q[64],q[54];
cp(-pi/512) q[64],q[55];
cp(-pi/256) q[64],q[56];
cp(-pi/128) q[64],q[57];
cp(-pi/64) q[64],q[58];
cp(-pi/32) q[64],q[59];
cp(-pi/16) q[64],q[60];
cp(-pi/8) q[64],q[61];
cp(-pi/4) q[64],q[62];
cp(-pi/2) q[64],q[63];
h q[64];
cp(0) q[65],q[0];
cp(0) q[65],q[1];
cp(0) q[65],q[2];
cp(0) q[65],q[3];
cp(0) q[65],q[4];
cp(0) q[65],q[5];
cp(0) q[65],q[6];
cp(0) q[65],q[7];
cp(0) q[65],q[8];
cp(0) q[65],q[9];
cp(0) q[65],q[10];
cp(0) q[65],q[11];
cp(0) q[65],q[12];
cp(0) q[65],q[13];
cp(0) q[65],q[14];
cp(0) q[65],q[15];
cp(0) q[65],q[16];
cp(0) q[65],q[17];
cp(0) q[65],q[18];
cp(0) q[65],q[19];
cp(0) q[65],q[20];
cp(0) q[65],q[21];
cp(0) q[65],q[22];
cp(0) q[65],q[23];
cp(-pi/2199023255552) q[65],q[24];
cp(-pi/1099511627776) q[65],q[25];
cp(-pi/549755813888) q[65],q[26];
cp(-pi/274877906944) q[65],q[27];
cp(-pi/137438953472) q[65],q[28];
cp(-pi/68719476736) q[65],q[29];
cp(-pi/34359738368) q[65],q[30];
cp(-pi/17179869184) q[65],q[31];
cp(-pi/8589934592) q[65],q[32];
cp(-pi/4294967296) q[65],q[33];
cp(-pi/2147483648) q[65],q[34];
cp(-pi/1073741824) q[65],q[35];
cp(-pi/536870912) q[65],q[36];
cp(-pi/268435456) q[65],q[37];
cp(-pi/134217728) q[65],q[38];
cp(-pi/67108864) q[65],q[39];
cp(-pi/33554432) q[65],q[40];
cp(-pi/16777216) q[65],q[41];
cp(-pi/8388608) q[65],q[42];
cp(-pi/4194304) q[65],q[43];
cp(-pi/2097152) q[65],q[44];
cp(-pi/1048576) q[65],q[45];
cp(-pi/524288) q[65],q[46];
cp(-pi/262144) q[65],q[47];
cp(-pi/131072) q[65],q[48];
cp(-pi/65536) q[65],q[49];
cp(-pi/32768) q[65],q[50];
cp(-pi/16384) q[65],q[51];
cp(-pi/8192) q[65],q[52];
cp(-pi/4096) q[65],q[53];
cp(-pi/2048) q[65],q[54];
cp(-pi/1024) q[65],q[55];
cp(-pi/512) q[65],q[56];
cp(-pi/256) q[65],q[57];
cp(-pi/128) q[65],q[58];
cp(-pi/64) q[65],q[59];
cp(-pi/32) q[65],q[60];
cp(-pi/16) q[65],q[61];
cp(-pi/8) q[65],q[62];
cp(-pi/4) q[65],q[63];
cp(-pi/2) q[65],q[64];
h q[65];
cp(0) q[66],q[0];
cp(0) q[66],q[1];
cp(0) q[66],q[2];
cp(0) q[66],q[3];
cp(0) q[66],q[4];
cp(0) q[66],q[5];
cp(0) q[66],q[6];
cp(0) q[66],q[7];
cp(0) q[66],q[8];
cp(0) q[66],q[9];
cp(0) q[66],q[10];
cp(0) q[66],q[11];
cp(0) q[66],q[12];
cp(0) q[66],q[13];
cp(0) q[66],q[14];
cp(0) q[66],q[15];
cp(0) q[66],q[16];
cp(0) q[66],q[17];
cp(0) q[66],q[18];
cp(0) q[66],q[19];
cp(0) q[66],q[20];
cp(0) q[66],q[21];
cp(0) q[66],q[22];
cp(0) q[66],q[23];
cp(0) q[66],q[24];
cp(-pi/2199023255552) q[66],q[25];
cp(-pi/1099511627776) q[66],q[26];
cp(-pi/549755813888) q[66],q[27];
cp(-pi/274877906944) q[66],q[28];
cp(-pi/137438953472) q[66],q[29];
cp(-pi/68719476736) q[66],q[30];
cp(-pi/34359738368) q[66],q[31];
cp(-pi/17179869184) q[66],q[32];
cp(-pi/8589934592) q[66],q[33];
cp(-pi/4294967296) q[66],q[34];
cp(-pi/2147483648) q[66],q[35];
cp(-pi/1073741824) q[66],q[36];
cp(-pi/536870912) q[66],q[37];
cp(-pi/268435456) q[66],q[38];
cp(-pi/134217728) q[66],q[39];
cp(-pi/67108864) q[66],q[40];
cp(-pi/33554432) q[66],q[41];
cp(-pi/16777216) q[66],q[42];
cp(-pi/8388608) q[66],q[43];
cp(-pi/4194304) q[66],q[44];
cp(-pi/2097152) q[66],q[45];
cp(-pi/1048576) q[66],q[46];
cp(-pi/524288) q[66],q[47];
cp(-pi/262144) q[66],q[48];
cp(-pi/131072) q[66],q[49];
cp(-pi/65536) q[66],q[50];
cp(-pi/32768) q[66],q[51];
cp(-pi/16384) q[66],q[52];
cp(-pi/8192) q[66],q[53];
cp(-pi/4096) q[66],q[54];
cp(-pi/2048) q[66],q[55];
cp(-pi/1024) q[66],q[56];
cp(-pi/512) q[66],q[57];
cp(-pi/256) q[66],q[58];
cp(-pi/128) q[66],q[59];
cp(-pi/64) q[66],q[60];
cp(-pi/32) q[66],q[61];
cp(-pi/16) q[66],q[62];
cp(-pi/8) q[66],q[63];
cp(-pi/4) q[66],q[64];
cp(-pi/2) q[66],q[65];
h q[66];
cp(0) q[67],q[0];
cp(0) q[67],q[1];
cp(0) q[67],q[2];
cp(0) q[67],q[3];
cp(0) q[67],q[4];
cp(0) q[67],q[5];
cp(0) q[67],q[6];
cp(0) q[67],q[7];
cp(0) q[67],q[8];
cp(0) q[67],q[9];
cp(0) q[67],q[10];
cp(0) q[67],q[11];
cp(0) q[67],q[12];
cp(0) q[67],q[13];
cp(0) q[67],q[14];
cp(0) q[67],q[15];
cp(0) q[67],q[16];
cp(0) q[67],q[17];
cp(0) q[67],q[18];
cp(0) q[67],q[19];
cp(0) q[67],q[20];
cp(0) q[67],q[21];
cp(0) q[67],q[22];
cp(0) q[67],q[23];
cp(0) q[67],q[24];
cp(0) q[67],q[25];
cp(-pi/2199023255552) q[67],q[26];
cp(-pi/1099511627776) q[67],q[27];
cp(-pi/549755813888) q[67],q[28];
cp(-pi/274877906944) q[67],q[29];
cp(-pi/137438953472) q[67],q[30];
cp(-pi/68719476736) q[67],q[31];
cp(-pi/34359738368) q[67],q[32];
cp(-pi/17179869184) q[67],q[33];
cp(-pi/8589934592) q[67],q[34];
cp(-pi/4294967296) q[67],q[35];
cp(-pi/2147483648) q[67],q[36];
cp(-pi/1073741824) q[67],q[37];
cp(-pi/536870912) q[67],q[38];
cp(-pi/268435456) q[67],q[39];
cp(-pi/134217728) q[67],q[40];
cp(-pi/67108864) q[67],q[41];
cp(-pi/33554432) q[67],q[42];
cp(-pi/16777216) q[67],q[43];
cp(-pi/8388608) q[67],q[44];
cp(-pi/4194304) q[67],q[45];
cp(-pi/2097152) q[67],q[46];
cp(-pi/1048576) q[67],q[47];
cp(-pi/524288) q[67],q[48];
cp(-pi/262144) q[67],q[49];
cp(-pi/131072) q[67],q[50];
cp(-pi/65536) q[67],q[51];
cp(-pi/32768) q[67],q[52];
cp(-pi/16384) q[67],q[53];
cp(-pi/8192) q[67],q[54];
cp(-pi/4096) q[67],q[55];
cp(-pi/2048) q[67],q[56];
cp(-pi/1024) q[67],q[57];
cp(-pi/512) q[67],q[58];
cp(-pi/256) q[67],q[59];
cp(-pi/128) q[67],q[60];
cp(-pi/64) q[67],q[61];
cp(-pi/32) q[67],q[62];
cp(-pi/16) q[67],q[63];
cp(-pi/8) q[67],q[64];
cp(-pi/4) q[67],q[65];
cp(-pi/2) q[67],q[66];
h q[67];
cp(0) q[68],q[0];
cp(0) q[68],q[1];
cp(0) q[68],q[2];
cp(0) q[68],q[3];
cp(0) q[68],q[4];
cp(0) q[68],q[5];
cp(0) q[68],q[6];
cp(0) q[68],q[7];
cp(0) q[68],q[8];
cp(0) q[68],q[9];
cp(0) q[68],q[10];
cp(0) q[68],q[11];
cp(0) q[68],q[12];
cp(0) q[68],q[13];
cp(0) q[68],q[14];
cp(0) q[68],q[15];
cp(0) q[68],q[16];
cp(0) q[68],q[17];
cp(0) q[68],q[18];
cp(0) q[68],q[19];
cp(0) q[68],q[20];
cp(0) q[68],q[21];
cp(0) q[68],q[22];
cp(0) q[68],q[23];
cp(0) q[68],q[24];
cp(0) q[68],q[25];
cp(0) q[68],q[26];
cp(-pi/2199023255552) q[68],q[27];
cp(-pi/1099511627776) q[68],q[28];
cp(-pi/549755813888) q[68],q[29];
cp(-pi/274877906944) q[68],q[30];
cp(-pi/137438953472) q[68],q[31];
cp(-pi/68719476736) q[68],q[32];
cp(-pi/34359738368) q[68],q[33];
cp(-pi/17179869184) q[68],q[34];
cp(-pi/8589934592) q[68],q[35];
cp(-pi/4294967296) q[68],q[36];
cp(-pi/2147483648) q[68],q[37];
cp(-pi/1073741824) q[68],q[38];
cp(-pi/536870912) q[68],q[39];
cp(-pi/268435456) q[68],q[40];
cp(-pi/134217728) q[68],q[41];
cp(-pi/67108864) q[68],q[42];
cp(-pi/33554432) q[68],q[43];
cp(-pi/16777216) q[68],q[44];
cp(-pi/8388608) q[68],q[45];
cp(-pi/4194304) q[68],q[46];
cp(-pi/2097152) q[68],q[47];
cp(-pi/1048576) q[68],q[48];
cp(-pi/524288) q[68],q[49];
cp(-pi/262144) q[68],q[50];
cp(-pi/131072) q[68],q[51];
cp(-pi/65536) q[68],q[52];
cp(-pi/32768) q[68],q[53];
cp(-pi/16384) q[68],q[54];
cp(-pi/8192) q[68],q[55];
cp(-pi/4096) q[68],q[56];
cp(-pi/2048) q[68],q[57];
cp(-pi/1024) q[68],q[58];
cp(-pi/512) q[68],q[59];
cp(-pi/256) q[68],q[60];
cp(-pi/128) q[68],q[61];
cp(-pi/64) q[68],q[62];
cp(-pi/32) q[68],q[63];
cp(-pi/16) q[68],q[64];
cp(-pi/8) q[68],q[65];
cp(-pi/4) q[68],q[66];
cp(-pi/2) q[68],q[67];
h q[68];
cp(0) q[69],q[0];
cp(0) q[69],q[1];
cp(0) q[69],q[2];
cp(0) q[69],q[3];
cp(0) q[69],q[4];
cp(0) q[69],q[5];
cp(0) q[69],q[6];
cp(0) q[69],q[7];
cp(0) q[69],q[8];
cp(0) q[69],q[9];
cp(0) q[69],q[10];
cp(0) q[69],q[11];
cp(0) q[69],q[12];
cp(0) q[69],q[13];
cp(0) q[69],q[14];
cp(0) q[69],q[15];
cp(0) q[69],q[16];
cp(0) q[69],q[17];
cp(0) q[69],q[18];
cp(0) q[69],q[19];
cp(0) q[69],q[20];
cp(0) q[69],q[21];
cp(0) q[69],q[22];
cp(0) q[69],q[23];
cp(0) q[69],q[24];
cp(0) q[69],q[25];
cp(0) q[69],q[26];
cp(0) q[69],q[27];
cp(-pi/2199023255552) q[69],q[28];
cp(-pi/1099511627776) q[69],q[29];
cp(-pi/549755813888) q[69],q[30];
cp(-pi/274877906944) q[69],q[31];
cp(-pi/137438953472) q[69],q[32];
cp(-pi/68719476736) q[69],q[33];
cp(-pi/34359738368) q[69],q[34];
cp(-pi/17179869184) q[69],q[35];
cp(-pi/8589934592) q[69],q[36];
cp(-pi/4294967296) q[69],q[37];
cp(-pi/2147483648) q[69],q[38];
cp(-pi/1073741824) q[69],q[39];
cp(-pi/536870912) q[69],q[40];
cp(-pi/268435456) q[69],q[41];
cp(-pi/134217728) q[69],q[42];
cp(-pi/67108864) q[69],q[43];
cp(-pi/33554432) q[69],q[44];
cp(-pi/16777216) q[69],q[45];
cp(-pi/8388608) q[69],q[46];
cp(-pi/4194304) q[69],q[47];
cp(-pi/2097152) q[69],q[48];
cp(-pi/1048576) q[69],q[49];
cp(-pi/524288) q[69],q[50];
cp(-pi/262144) q[69],q[51];
cp(-pi/131072) q[69],q[52];
cp(-pi/65536) q[69],q[53];
cp(-pi/32768) q[69],q[54];
cp(-pi/16384) q[69],q[55];
cp(-pi/8192) q[69],q[56];
cp(-pi/4096) q[69],q[57];
cp(-pi/2048) q[69],q[58];
cp(-pi/1024) q[69],q[59];
cp(-pi/512) q[69],q[60];
cp(-pi/256) q[69],q[61];
cp(-pi/128) q[69],q[62];
cp(-pi/64) q[69],q[63];
cp(-pi/32) q[69],q[64];
cp(-pi/16) q[69],q[65];
cp(-pi/8) q[69],q[66];
cp(-pi/4) q[69],q[67];
cp(-pi/2) q[69],q[68];
h q[69];
cp(0) q[70],q[0];
cp(0) q[70],q[1];
cp(0) q[70],q[2];
cp(0) q[70],q[3];
cp(0) q[70],q[4];
cp(0) q[70],q[5];
cp(0) q[70],q[6];
cp(0) q[70],q[7];
cp(0) q[70],q[8];
cp(0) q[70],q[9];
cp(0) q[70],q[10];
cp(0) q[70],q[11];
cp(0) q[70],q[12];
cp(0) q[70],q[13];
cp(0) q[70],q[14];
cp(0) q[70],q[15];
cp(0) q[70],q[16];
cp(0) q[70],q[17];
cp(0) q[70],q[18];
cp(0) q[70],q[19];
cp(0) q[70],q[20];
cp(0) q[70],q[21];
cp(0) q[70],q[22];
cp(0) q[70],q[23];
cp(0) q[70],q[24];
cp(0) q[70],q[25];
cp(0) q[70],q[26];
cp(0) q[70],q[27];
cp(0) q[70],q[28];
cp(-pi/2199023255552) q[70],q[29];
cp(-pi/1099511627776) q[70],q[30];
cp(-pi/549755813888) q[70],q[31];
cp(-pi/274877906944) q[70],q[32];
cp(-pi/137438953472) q[70],q[33];
cp(-pi/68719476736) q[70],q[34];
cp(-pi/34359738368) q[70],q[35];
cp(-pi/17179869184) q[70],q[36];
cp(-pi/8589934592) q[70],q[37];
cp(-pi/4294967296) q[70],q[38];
cp(-pi/2147483648) q[70],q[39];
cp(-pi/1073741824) q[70],q[40];
cp(-pi/536870912) q[70],q[41];
cp(-pi/268435456) q[70],q[42];
cp(-pi/134217728) q[70],q[43];
cp(-pi/67108864) q[70],q[44];
cp(-pi/33554432) q[70],q[45];
cp(-pi/16777216) q[70],q[46];
cp(-pi/8388608) q[70],q[47];
cp(-pi/4194304) q[70],q[48];
cp(-pi/2097152) q[70],q[49];
cp(-pi/1048576) q[70],q[50];
cp(-pi/524288) q[70],q[51];
cp(-pi/262144) q[70],q[52];
cp(-pi/131072) q[70],q[53];
cp(-pi/65536) q[70],q[54];
cp(-pi/32768) q[70],q[55];
cp(-pi/16384) q[70],q[56];
cp(-pi/8192) q[70],q[57];
cp(-pi/4096) q[70],q[58];
cp(-pi/2048) q[70],q[59];
cp(-pi/1024) q[70],q[60];
cp(-pi/512) q[70],q[61];
cp(-pi/256) q[70],q[62];
cp(-pi/128) q[70],q[63];
cp(-pi/64) q[70],q[64];
cp(-pi/32) q[70],q[65];
cp(-pi/16) q[70],q[66];
cp(-pi/8) q[70],q[67];
cp(-pi/4) q[70],q[68];
cp(-pi/2) q[70],q[69];
h q[70];
cp(0) q[71],q[0];
cp(0) q[71],q[1];
cp(0) q[71],q[2];
cp(0) q[71],q[3];
cp(0) q[71],q[4];
cp(0) q[71],q[5];
cp(0) q[71],q[6];
cp(0) q[71],q[7];
cp(0) q[71],q[8];
cp(0) q[71],q[9];
cp(0) q[71],q[10];
cp(0) q[71],q[11];
cp(0) q[71],q[12];
cp(0) q[71],q[13];
cp(0) q[71],q[14];
cp(0) q[71],q[15];
cp(0) q[71],q[16];
cp(0) q[71],q[17];
cp(0) q[71],q[18];
cp(0) q[71],q[19];
cp(0) q[71],q[20];
cp(0) q[71],q[21];
cp(0) q[71],q[22];
cp(0) q[71],q[23];
cp(0) q[71],q[24];
cp(0) q[71],q[25];
cp(0) q[71],q[26];
cp(0) q[71],q[27];
cp(0) q[71],q[28];
cp(0) q[71],q[29];
cp(-pi/2199023255552) q[71],q[30];
cp(-pi/1099511627776) q[71],q[31];
cp(-pi/549755813888) q[71],q[32];
cp(-pi/274877906944) q[71],q[33];
cp(-pi/137438953472) q[71],q[34];
cp(-pi/68719476736) q[71],q[35];
cp(-pi/34359738368) q[71],q[36];
cp(-pi/17179869184) q[71],q[37];
cp(-pi/8589934592) q[71],q[38];
cp(-pi/4294967296) q[71],q[39];
cp(-pi/2147483648) q[71],q[40];
cp(-pi/1073741824) q[71],q[41];
cp(-pi/536870912) q[71],q[42];
cp(-pi/268435456) q[71],q[43];
cp(-pi/134217728) q[71],q[44];
cp(-pi/67108864) q[71],q[45];
cp(-pi/33554432) q[71],q[46];
cp(-pi/16777216) q[71],q[47];
cp(-pi/8388608) q[71],q[48];
cp(-pi/4194304) q[71],q[49];
cp(-pi/2097152) q[71],q[50];
cp(-pi/1048576) q[71],q[51];
cp(-pi/524288) q[71],q[52];
cp(-pi/262144) q[71],q[53];
cp(-pi/131072) q[71],q[54];
cp(-pi/65536) q[71],q[55];
cp(-pi/32768) q[71],q[56];
cp(-pi/16384) q[71],q[57];
cp(-pi/8192) q[71],q[58];
cp(-pi/4096) q[71],q[59];
cp(-pi/2048) q[71],q[60];
cp(-pi/1024) q[71],q[61];
cp(-pi/512) q[71],q[62];
cp(-pi/256) q[71],q[63];
cp(-pi/128) q[71],q[64];
cp(-pi/64) q[71],q[65];
cp(-pi/32) q[71],q[66];
cp(-pi/16) q[71],q[67];
cp(-pi/8) q[71],q[68];
cp(-pi/4) q[71],q[69];
cp(-pi/2) q[71],q[70];
h q[71];
cp(0) q[72],q[0];
cp(0) q[72],q[1];
cp(0) q[72],q[2];
cp(0) q[72],q[3];
cp(0) q[72],q[4];
cp(0) q[72],q[5];
cp(0) q[72],q[6];
cp(0) q[72],q[7];
cp(0) q[72],q[8];
cp(0) q[72],q[9];
cp(0) q[72],q[10];
cp(0) q[72],q[11];
cp(0) q[72],q[12];
cp(0) q[72],q[13];
cp(0) q[72],q[14];
cp(0) q[72],q[15];
cp(0) q[72],q[16];
cp(0) q[72],q[17];
cp(0) q[72],q[18];
cp(0) q[72],q[19];
cp(0) q[72],q[20];
cp(0) q[72],q[21];
cp(0) q[72],q[22];
cp(0) q[72],q[23];
cp(0) q[72],q[24];
cp(0) q[72],q[25];
cp(0) q[72],q[26];
cp(0) q[72],q[27];
cp(0) q[72],q[28];
cp(0) q[72],q[29];
cp(0) q[72],q[30];
cp(-pi/2199023255552) q[72],q[31];
cp(-pi/1099511627776) q[72],q[32];
cp(-pi/549755813888) q[72],q[33];
cp(-pi/274877906944) q[72],q[34];
cp(-pi/137438953472) q[72],q[35];
cp(-pi/68719476736) q[72],q[36];
cp(-pi/34359738368) q[72],q[37];
cp(-pi/17179869184) q[72],q[38];
cp(-pi/8589934592) q[72],q[39];
cp(-pi/4294967296) q[72],q[40];
cp(-pi/2147483648) q[72],q[41];
cp(-pi/1073741824) q[72],q[42];
cp(-pi/536870912) q[72],q[43];
cp(-pi/268435456) q[72],q[44];
cp(-pi/134217728) q[72],q[45];
cp(-pi/67108864) q[72],q[46];
cp(-pi/33554432) q[72],q[47];
cp(-pi/16777216) q[72],q[48];
cp(-pi/8388608) q[72],q[49];
cp(-pi/4194304) q[72],q[50];
cp(-pi/2097152) q[72],q[51];
cp(-pi/1048576) q[72],q[52];
cp(-pi/524288) q[72],q[53];
cp(-pi/262144) q[72],q[54];
cp(-pi/131072) q[72],q[55];
cp(-pi/65536) q[72],q[56];
cp(-pi/32768) q[72],q[57];
cp(-pi/16384) q[72],q[58];
cp(-pi/8192) q[72],q[59];
cp(-pi/4096) q[72],q[60];
cp(-pi/2048) q[72],q[61];
cp(-pi/1024) q[72],q[62];
cp(-pi/512) q[72],q[63];
cp(-pi/256) q[72],q[64];
cp(-pi/128) q[72],q[65];
cp(-pi/64) q[72],q[66];
cp(-pi/32) q[72],q[67];
cp(-pi/16) q[72],q[68];
cp(-pi/8) q[72],q[69];
cp(-pi/4) q[72],q[70];
cp(-pi/2) q[72],q[71];
h q[72];
cp(0) q[73],q[0];
cp(0) q[73],q[1];
cp(0) q[73],q[2];
cp(0) q[73],q[3];
cp(0) q[73],q[4];
cp(0) q[73],q[5];
cp(0) q[73],q[6];
cp(0) q[73],q[7];
cp(0) q[73],q[8];
cp(0) q[73],q[9];
cp(0) q[73],q[10];
cp(0) q[73],q[11];
cp(0) q[73],q[12];
cp(0) q[73],q[13];
cp(0) q[73],q[14];
cp(0) q[73],q[15];
cp(0) q[73],q[16];
cp(0) q[73],q[17];
cp(0) q[73],q[18];
cp(0) q[73],q[19];
cp(0) q[73],q[20];
cp(0) q[73],q[21];
cp(0) q[73],q[22];
cp(0) q[73],q[23];
cp(0) q[73],q[24];
cp(0) q[73],q[25];
cp(0) q[73],q[26];
cp(0) q[73],q[27];
cp(0) q[73],q[28];
cp(0) q[73],q[29];
cp(0) q[73],q[30];
cp(0) q[73],q[31];
cp(-pi/2199023255552) q[73],q[32];
cp(-pi/1099511627776) q[73],q[33];
cp(-pi/549755813888) q[73],q[34];
cp(-pi/274877906944) q[73],q[35];
cp(-pi/137438953472) q[73],q[36];
cp(-pi/68719476736) q[73],q[37];
cp(-pi/34359738368) q[73],q[38];
cp(-pi/17179869184) q[73],q[39];
cp(-pi/8589934592) q[73],q[40];
cp(-pi/4294967296) q[73],q[41];
cp(-pi/2147483648) q[73],q[42];
cp(-pi/1073741824) q[73],q[43];
cp(-pi/536870912) q[73],q[44];
cp(-pi/268435456) q[73],q[45];
cp(-pi/134217728) q[73],q[46];
cp(-pi/67108864) q[73],q[47];
cp(-pi/33554432) q[73],q[48];
cp(-pi/16777216) q[73],q[49];
cp(-pi/8388608) q[73],q[50];
cp(-pi/4194304) q[73],q[51];
cp(-pi/2097152) q[73],q[52];
cp(-pi/1048576) q[73],q[53];
cp(-pi/524288) q[73],q[54];
cp(-pi/262144) q[73],q[55];
cp(-pi/131072) q[73],q[56];
cp(-pi/65536) q[73],q[57];
cp(-pi/32768) q[73],q[58];
cp(-pi/16384) q[73],q[59];
cp(-pi/8192) q[73],q[60];
cp(-pi/4096) q[73],q[61];
cp(-pi/2048) q[73],q[62];
cp(-pi/1024) q[73],q[63];
cp(-pi/512) q[73],q[64];
cp(-pi/256) q[73],q[65];
cp(-pi/128) q[73],q[66];
cp(-pi/64) q[73],q[67];
cp(-pi/32) q[73],q[68];
cp(-pi/16) q[73],q[69];
cp(-pi/8) q[73],q[70];
cp(-pi/4) q[73],q[71];
cp(-pi/2) q[73],q[72];
h q[73];
cp(0) q[74],q[0];
cp(0) q[74],q[1];
cp(0) q[74],q[2];
cp(0) q[74],q[3];
cp(0) q[74],q[4];
cp(0) q[74],q[5];
cp(0) q[74],q[6];
cp(0) q[74],q[7];
cp(0) q[74],q[8];
cp(0) q[74],q[9];
cp(0) q[74],q[10];
cp(0) q[74],q[11];
cp(0) q[74],q[12];
cp(0) q[74],q[13];
cp(0) q[74],q[14];
cp(0) q[74],q[15];
cp(0) q[74],q[16];
cp(0) q[74],q[17];
cp(0) q[74],q[18];
cp(0) q[74],q[19];
cp(0) q[74],q[20];
cp(0) q[74],q[21];
cp(0) q[74],q[22];
cp(0) q[74],q[23];
cp(0) q[74],q[24];
cp(0) q[74],q[25];
cp(0) q[74],q[26];
cp(0) q[74],q[27];
cp(0) q[74],q[28];
cp(0) q[74],q[29];
cp(0) q[74],q[30];
cp(0) q[74],q[31];
cp(0) q[74],q[32];
cp(-pi/2199023255552) q[74],q[33];
cp(-pi/1099511627776) q[74],q[34];
cp(-pi/549755813888) q[74],q[35];
cp(-pi/274877906944) q[74],q[36];
cp(-pi/137438953472) q[74],q[37];
cp(-pi/68719476736) q[74],q[38];
cp(-pi/34359738368) q[74],q[39];
cp(-pi/17179869184) q[74],q[40];
cp(-pi/8589934592) q[74],q[41];
cp(-pi/4294967296) q[74],q[42];
cp(-pi/2147483648) q[74],q[43];
cp(-pi/1073741824) q[74],q[44];
cp(-pi/536870912) q[74],q[45];
cp(-pi/268435456) q[74],q[46];
cp(-pi/134217728) q[74],q[47];
cp(-pi/67108864) q[74],q[48];
cp(-pi/33554432) q[74],q[49];
cp(-pi/16777216) q[74],q[50];
cp(-pi/8388608) q[74],q[51];
cp(-pi/4194304) q[74],q[52];
cp(-pi/2097152) q[74],q[53];
cp(-pi/1048576) q[74],q[54];
cp(-pi/524288) q[74],q[55];
cp(-pi/262144) q[74],q[56];
cp(-pi/131072) q[74],q[57];
cp(-pi/65536) q[74],q[58];
cp(-pi/32768) q[74],q[59];
cp(-pi/16384) q[74],q[60];
cp(-pi/8192) q[74],q[61];
cp(-pi/4096) q[74],q[62];
cp(-pi/2048) q[74],q[63];
cp(-pi/1024) q[74],q[64];
cp(-pi/512) q[74],q[65];
cp(-pi/256) q[74],q[66];
cp(-pi/128) q[74],q[67];
cp(-pi/64) q[74],q[68];
cp(-pi/32) q[74],q[69];
cp(-pi/16) q[74],q[70];
cp(-pi/8) q[74],q[71];
cp(-pi/4) q[74],q[72];
cp(-pi/2) q[74],q[73];
h q[74];
cp(0) q[75],q[0];
cp(0) q[75],q[1];
cp(0) q[75],q[2];
cp(0) q[75],q[3];
cp(0) q[75],q[4];
cp(0) q[75],q[5];
cp(0) q[75],q[6];
cp(0) q[75],q[7];
cp(0) q[75],q[8];
cp(0) q[75],q[9];
cp(0) q[75],q[10];
cp(0) q[75],q[11];
cp(0) q[75],q[12];
cp(0) q[75],q[13];
cp(0) q[75],q[14];
cp(0) q[75],q[15];
cp(0) q[75],q[16];
cp(0) q[75],q[17];
cp(0) q[75],q[18];
cp(0) q[75],q[19];
cp(0) q[75],q[20];
cp(0) q[75],q[21];
cp(0) q[75],q[22];
cp(0) q[75],q[23];
cp(0) q[75],q[24];
cp(0) q[75],q[25];
cp(0) q[75],q[26];
cp(0) q[75],q[27];
cp(0) q[75],q[28];
cp(0) q[75],q[29];
cp(0) q[75],q[30];
cp(0) q[75],q[31];
cp(0) q[75],q[32];
cp(0) q[75],q[33];
cp(-pi/2199023255552) q[75],q[34];
cp(-pi/1099511627776) q[75],q[35];
cp(-pi/549755813888) q[75],q[36];
cp(-pi/274877906944) q[75],q[37];
cp(-pi/137438953472) q[75],q[38];
cp(-pi/68719476736) q[75],q[39];
cp(-pi/34359738368) q[75],q[40];
cp(-pi/17179869184) q[75],q[41];
cp(-pi/8589934592) q[75],q[42];
cp(-pi/4294967296) q[75],q[43];
cp(-pi/2147483648) q[75],q[44];
cp(-pi/1073741824) q[75],q[45];
cp(-pi/536870912) q[75],q[46];
cp(-pi/268435456) q[75],q[47];
cp(-pi/134217728) q[75],q[48];
cp(-pi/67108864) q[75],q[49];
cp(-pi/33554432) q[75],q[50];
cp(-pi/16777216) q[75],q[51];
cp(-pi/8388608) q[75],q[52];
cp(-pi/4194304) q[75],q[53];
cp(-pi/2097152) q[75],q[54];
cp(-pi/1048576) q[75],q[55];
cp(-pi/524288) q[75],q[56];
cp(-pi/262144) q[75],q[57];
cp(-pi/131072) q[75],q[58];
cp(-pi/65536) q[75],q[59];
cp(-pi/32768) q[75],q[60];
cp(-pi/16384) q[75],q[61];
cp(-pi/8192) q[75],q[62];
cp(-pi/4096) q[75],q[63];
cp(-pi/2048) q[75],q[64];
cp(-pi/1024) q[75],q[65];
cp(-pi/512) q[75],q[66];
cp(-pi/256) q[75],q[67];
cp(-pi/128) q[75],q[68];
cp(-pi/64) q[75],q[69];
cp(-pi/32) q[75],q[70];
cp(-pi/16) q[75],q[71];
cp(-pi/8) q[75],q[72];
cp(-pi/4) q[75],q[73];
cp(-pi/2) q[75],q[74];
h q[75];
cp(0) q[76],q[0];
cp(0) q[76],q[1];
cp(0) q[76],q[2];
cp(0) q[76],q[3];
cp(0) q[76],q[4];
cp(0) q[76],q[5];
cp(0) q[76],q[6];
cp(0) q[76],q[7];
cp(0) q[76],q[8];
cp(0) q[76],q[9];
cp(0) q[76],q[10];
cp(0) q[76],q[11];
cp(0) q[76],q[12];
cp(0) q[76],q[13];
cp(0) q[76],q[14];
cp(0) q[76],q[15];
cp(0) q[76],q[16];
cp(0) q[76],q[17];
cp(0) q[76],q[18];
cp(0) q[76],q[19];
cp(0) q[76],q[20];
cp(0) q[76],q[21];
cp(0) q[76],q[22];
cp(0) q[76],q[23];
cp(0) q[76],q[24];
cp(0) q[76],q[25];
cp(0) q[76],q[26];
cp(0) q[76],q[27];
cp(0) q[76],q[28];
cp(0) q[76],q[29];
cp(0) q[76],q[30];
cp(0) q[76],q[31];
cp(0) q[76],q[32];
cp(0) q[76],q[33];
cp(0) q[76],q[34];
cp(-pi/2199023255552) q[76],q[35];
cp(-pi/1099511627776) q[76],q[36];
cp(-pi/549755813888) q[76],q[37];
cp(-pi/274877906944) q[76],q[38];
cp(-pi/137438953472) q[76],q[39];
cp(-pi/68719476736) q[76],q[40];
cp(-pi/34359738368) q[76],q[41];
cp(-pi/17179869184) q[76],q[42];
cp(-pi/8589934592) q[76],q[43];
cp(-pi/4294967296) q[76],q[44];
cp(-pi/2147483648) q[76],q[45];
cp(-pi/1073741824) q[76],q[46];
cp(-pi/536870912) q[76],q[47];
cp(-pi/268435456) q[76],q[48];
cp(-pi/134217728) q[76],q[49];
cp(-pi/67108864) q[76],q[50];
cp(-pi/33554432) q[76],q[51];
cp(-pi/16777216) q[76],q[52];
cp(-pi/8388608) q[76],q[53];
cp(-pi/4194304) q[76],q[54];
cp(-pi/2097152) q[76],q[55];
cp(-pi/1048576) q[76],q[56];
cp(-pi/524288) q[76],q[57];
cp(-pi/262144) q[76],q[58];
cp(-pi/131072) q[76],q[59];
cp(-pi/65536) q[76],q[60];
cp(-pi/32768) q[76],q[61];
cp(-pi/16384) q[76],q[62];
cp(-pi/8192) q[76],q[63];
cp(-pi/4096) q[76],q[64];
cp(-pi/2048) q[76],q[65];
cp(-pi/1024) q[76],q[66];
cp(-pi/512) q[76],q[67];
cp(-pi/256) q[76],q[68];
cp(-pi/128) q[76],q[69];
cp(-pi/64) q[76],q[70];
cp(-pi/32) q[76],q[71];
cp(-pi/16) q[76],q[72];
cp(-pi/8) q[76],q[73];
cp(-pi/4) q[76],q[74];
cp(-pi/2) q[76],q[75];
h q[76];
cp(0) q[77],q[0];
cp(0) q[77],q[1];
cp(0) q[77],q[2];
cp(0) q[77],q[3];
cp(0) q[77],q[4];
cp(0) q[77],q[5];
cp(0) q[77],q[6];
cp(0) q[77],q[7];
cp(0) q[77],q[8];
cp(0) q[77],q[9];
cp(0) q[77],q[10];
cp(0) q[77],q[11];
cp(0) q[77],q[12];
cp(0) q[77],q[13];
cp(0) q[77],q[14];
cp(0) q[77],q[15];
cp(0) q[77],q[16];
cp(0) q[77],q[17];
cp(0) q[77],q[18];
cp(0) q[77],q[19];
cp(0) q[77],q[20];
cp(0) q[77],q[21];
cp(0) q[77],q[22];
cp(0) q[77],q[23];
cp(0) q[77],q[24];
cp(0) q[77],q[25];
cp(0) q[77],q[26];
cp(0) q[77],q[27];
cp(0) q[77],q[28];
cp(0) q[77],q[29];
cp(0) q[77],q[30];
cp(0) q[77],q[31];
cp(0) q[77],q[32];
cp(0) q[77],q[33];
cp(0) q[77],q[34];
cp(0) q[77],q[35];
cp(-pi/2199023255552) q[77],q[36];
cp(-pi/1099511627776) q[77],q[37];
cp(-pi/549755813888) q[77],q[38];
cp(-pi/274877906944) q[77],q[39];
cp(-pi/137438953472) q[77],q[40];
cp(-pi/68719476736) q[77],q[41];
cp(-pi/34359738368) q[77],q[42];
cp(-pi/17179869184) q[77],q[43];
cp(-pi/8589934592) q[77],q[44];
cp(-pi/4294967296) q[77],q[45];
cp(-pi/2147483648) q[77],q[46];
cp(-pi/1073741824) q[77],q[47];
cp(-pi/536870912) q[77],q[48];
cp(-pi/268435456) q[77],q[49];
cp(-pi/134217728) q[77],q[50];
cp(-pi/67108864) q[77],q[51];
cp(-pi/33554432) q[77],q[52];
cp(-pi/16777216) q[77],q[53];
cp(-pi/8388608) q[77],q[54];
cp(-pi/4194304) q[77],q[55];
cp(-pi/2097152) q[77],q[56];
cp(-pi/1048576) q[77],q[57];
cp(-pi/524288) q[77],q[58];
cp(-pi/262144) q[77],q[59];
cp(-pi/131072) q[77],q[60];
cp(-pi/65536) q[77],q[61];
cp(-pi/32768) q[77],q[62];
cp(-pi/16384) q[77],q[63];
cp(-pi/8192) q[77],q[64];
cp(-pi/4096) q[77],q[65];
cp(-pi/2048) q[77],q[66];
cp(-pi/1024) q[77],q[67];
cp(-pi/512) q[77],q[68];
cp(-pi/256) q[77],q[69];
cp(-pi/128) q[77],q[70];
cp(-pi/64) q[77],q[71];
cp(-pi/32) q[77],q[72];
cp(-pi/16) q[77],q[73];
cp(-pi/8) q[77],q[74];
cp(-pi/4) q[77],q[75];
cp(-pi/2) q[77],q[76];
h q[77];
cp(0) q[78],q[0];
cp(0) q[78],q[1];
cp(0) q[78],q[2];
cp(0) q[78],q[3];
cp(0) q[78],q[4];
cp(0) q[78],q[5];
cp(0) q[78],q[6];
cp(0) q[78],q[7];
cp(0) q[78],q[8];
cp(0) q[78],q[9];
cp(0) q[78],q[10];
cp(0) q[78],q[11];
cp(0) q[78],q[12];
cp(0) q[78],q[13];
cp(0) q[78],q[14];
cp(0) q[78],q[15];
cp(0) q[78],q[16];
cp(0) q[78],q[17];
cp(0) q[78],q[18];
cp(0) q[78],q[19];
cp(0) q[78],q[20];
cp(0) q[78],q[21];
cp(0) q[78],q[22];
cp(0) q[78],q[23];
cp(0) q[78],q[24];
cp(0) q[78],q[25];
cp(0) q[78],q[26];
cp(0) q[78],q[27];
cp(0) q[78],q[28];
cp(0) q[78],q[29];
cp(0) q[78],q[30];
cp(0) q[78],q[31];
cp(0) q[78],q[32];
cp(0) q[78],q[33];
cp(0) q[78],q[34];
cp(0) q[78],q[35];
cp(0) q[78],q[36];
cp(-pi/2199023255552) q[78],q[37];
cp(-pi/1099511627776) q[78],q[38];
cp(-pi/549755813888) q[78],q[39];
cp(-pi/274877906944) q[78],q[40];
cp(-pi/137438953472) q[78],q[41];
cp(-pi/68719476736) q[78],q[42];
cp(-pi/34359738368) q[78],q[43];
cp(-pi/17179869184) q[78],q[44];
cp(-pi/8589934592) q[78],q[45];
cp(-pi/4294967296) q[78],q[46];
cp(-pi/2147483648) q[78],q[47];
cp(-pi/1073741824) q[78],q[48];
cp(-pi/536870912) q[78],q[49];
cp(-pi/268435456) q[78],q[50];
cp(-pi/134217728) q[78],q[51];
cp(-pi/67108864) q[78],q[52];
cp(-pi/33554432) q[78],q[53];
cp(-pi/16777216) q[78],q[54];
cp(-pi/8388608) q[78],q[55];
cp(-pi/4194304) q[78],q[56];
cp(-pi/2097152) q[78],q[57];
cp(-pi/1048576) q[78],q[58];
cp(-pi/524288) q[78],q[59];
cp(-pi/262144) q[78],q[60];
cp(-pi/131072) q[78],q[61];
cp(-pi/65536) q[78],q[62];
cp(-pi/32768) q[78],q[63];
cp(-pi/16384) q[78],q[64];
cp(-pi/8192) q[78],q[65];
cp(-pi/4096) q[78],q[66];
cp(-pi/2048) q[78],q[67];
cp(-pi/1024) q[78],q[68];
cp(-pi/512) q[78],q[69];
cp(-pi/256) q[78],q[70];
cp(-pi/128) q[78],q[71];
cp(-pi/64) q[78],q[72];
cp(-pi/32) q[78],q[73];
cp(-pi/16) q[78],q[74];
cp(-pi/8) q[78],q[75];
cp(-pi/4) q[78],q[76];
cp(-pi/2) q[78],q[77];
h q[78];
cp(0) q[79],q[0];
cp(0) q[79],q[1];
cp(0) q[79],q[2];
cp(0) q[79],q[3];
cp(0) q[79],q[4];
cp(0) q[79],q[5];
cp(0) q[79],q[6];
cp(0) q[79],q[7];
cp(0) q[79],q[8];
cp(0) q[79],q[9];
cp(0) q[79],q[10];
cp(0) q[79],q[11];
cp(0) q[79],q[12];
cp(0) q[79],q[13];
cp(0) q[79],q[14];
cp(0) q[79],q[15];
cp(0) q[79],q[16];
cp(0) q[79],q[17];
cp(0) q[79],q[18];
cp(0) q[79],q[19];
cp(0) q[79],q[20];
cp(0) q[79],q[21];
cp(0) q[79],q[22];
cp(0) q[79],q[23];
cp(0) q[79],q[24];
cp(0) q[79],q[25];
cp(0) q[79],q[26];
cp(0) q[79],q[27];
cp(0) q[79],q[28];
cp(0) q[79],q[29];
cp(0) q[79],q[30];
cp(0) q[79],q[31];
cp(0) q[79],q[32];
cp(0) q[79],q[33];
cp(0) q[79],q[34];
cp(0) q[79],q[35];
cp(0) q[79],q[36];
cp(0) q[79],q[37];
cp(-pi/2199023255552) q[79],q[38];
cp(-pi/1099511627776) q[79],q[39];
cp(-pi/549755813888) q[79],q[40];
cp(-pi/274877906944) q[79],q[41];
cp(-pi/137438953472) q[79],q[42];
cp(-pi/68719476736) q[79],q[43];
cp(-pi/34359738368) q[79],q[44];
cp(-pi/17179869184) q[79],q[45];
cp(-pi/8589934592) q[79],q[46];
cp(-pi/4294967296) q[79],q[47];
cp(-pi/2147483648) q[79],q[48];
cp(-pi/1073741824) q[79],q[49];
cp(-pi/536870912) q[79],q[50];
cp(-pi/268435456) q[79],q[51];
cp(-pi/134217728) q[79],q[52];
cp(-pi/67108864) q[79],q[53];
cp(-pi/33554432) q[79],q[54];
cp(-pi/16777216) q[79],q[55];
cp(-pi/8388608) q[79],q[56];
cp(-pi/4194304) q[79],q[57];
cp(-pi/2097152) q[79],q[58];
cp(-pi/1048576) q[79],q[59];
cp(-pi/524288) q[79],q[60];
cp(-pi/262144) q[79],q[61];
cp(-pi/131072) q[79],q[62];
cp(-pi/65536) q[79],q[63];
cp(-pi/32768) q[79],q[64];
cp(-pi/16384) q[79],q[65];
cp(-pi/8192) q[79],q[66];
cp(-pi/4096) q[79],q[67];
cp(-pi/2048) q[79],q[68];
cp(-pi/1024) q[79],q[69];
cp(-pi/512) q[79],q[70];
cp(-pi/256) q[79],q[71];
cp(-pi/128) q[79],q[72];
cp(-pi/64) q[79],q[73];
cp(-pi/32) q[79],q[74];
cp(-pi/16) q[79],q[75];
cp(-pi/8) q[79],q[76];
cp(-pi/4) q[79],q[77];
cp(-pi/2) q[79],q[78];
h q[79];
cp(0) q[80],q[0];
cp(0) q[80],q[1];
cp(0) q[80],q[2];
cp(0) q[80],q[3];
cp(0) q[80],q[4];
cp(0) q[80],q[5];
cp(0) q[80],q[6];
cp(0) q[80],q[7];
cp(0) q[80],q[8];
cp(0) q[80],q[9];
cp(0) q[80],q[10];
cp(0) q[80],q[11];
cp(0) q[80],q[12];
cp(0) q[80],q[13];
cp(0) q[80],q[14];
cp(0) q[80],q[15];
cp(0) q[80],q[16];
cp(0) q[80],q[17];
cp(0) q[80],q[18];
cp(0) q[80],q[19];
cp(0) q[80],q[20];
cp(0) q[80],q[21];
cp(0) q[80],q[22];
cp(0) q[80],q[23];
cp(0) q[80],q[24];
cp(0) q[80],q[25];
cp(0) q[80],q[26];
cp(0) q[80],q[27];
cp(0) q[80],q[28];
cp(0) q[80],q[29];
cp(0) q[80],q[30];
cp(0) q[80],q[31];
cp(0) q[80],q[32];
cp(0) q[80],q[33];
cp(0) q[80],q[34];
cp(0) q[80],q[35];
cp(0) q[80],q[36];
cp(0) q[80],q[37];
cp(0) q[80],q[38];
cp(-pi/2199023255552) q[80],q[39];
cp(-pi/1099511627776) q[80],q[40];
cp(-pi/549755813888) q[80],q[41];
cp(-pi/274877906944) q[80],q[42];
cp(-pi/137438953472) q[80],q[43];
cp(-pi/68719476736) q[80],q[44];
cp(-pi/34359738368) q[80],q[45];
cp(-pi/17179869184) q[80],q[46];
cp(-pi/8589934592) q[80],q[47];
cp(-pi/4294967296) q[80],q[48];
cp(-pi/2147483648) q[80],q[49];
cp(-pi/1073741824) q[80],q[50];
cp(-pi/536870912) q[80],q[51];
cp(-pi/268435456) q[80],q[52];
cp(-pi/134217728) q[80],q[53];
cp(-pi/67108864) q[80],q[54];
cp(-pi/33554432) q[80],q[55];
cp(-pi/16777216) q[80],q[56];
cp(-pi/8388608) q[80],q[57];
cp(-pi/4194304) q[80],q[58];
cp(-pi/2097152) q[80],q[59];
cp(-pi/1048576) q[80],q[60];
cp(-pi/524288) q[80],q[61];
cp(-pi/262144) q[80],q[62];
cp(-pi/131072) q[80],q[63];
cp(-pi/65536) q[80],q[64];
cp(-pi/32768) q[80],q[65];
cp(-pi/16384) q[80],q[66];
cp(-pi/8192) q[80],q[67];
cp(-pi/4096) q[80],q[68];
cp(-pi/2048) q[80],q[69];
cp(-pi/1024) q[80],q[70];
cp(-pi/512) q[80],q[71];
cp(-pi/256) q[80],q[72];
cp(-pi/128) q[80],q[73];
cp(-pi/64) q[80],q[74];
cp(-pi/32) q[80],q[75];
cp(-pi/16) q[80],q[76];
cp(-pi/8) q[80],q[77];
cp(-pi/4) q[80],q[78];
cp(-pi/2) q[80],q[79];
h q[80];
cp(0) q[81],q[0];
cp(0) q[81],q[1];
cp(0) q[81],q[2];
cp(0) q[81],q[3];
cp(0) q[81],q[4];
cp(0) q[81],q[5];
cp(0) q[81],q[6];
cp(0) q[81],q[7];
cp(0) q[81],q[8];
cp(0) q[81],q[9];
cp(0) q[81],q[10];
cp(0) q[81],q[11];
cp(0) q[81],q[12];
cp(0) q[81],q[13];
cp(0) q[81],q[14];
cp(0) q[81],q[15];
cp(0) q[81],q[16];
cp(0) q[81],q[17];
cp(0) q[81],q[18];
cp(0) q[81],q[19];
cp(0) q[81],q[20];
cp(0) q[81],q[21];
cp(0) q[81],q[22];
cp(0) q[81],q[23];
cp(0) q[81],q[24];
cp(0) q[81],q[25];
cp(0) q[81],q[26];
cp(0) q[81],q[27];
cp(0) q[81],q[28];
cp(0) q[81],q[29];
cp(0) q[81],q[30];
cp(0) q[81],q[31];
cp(0) q[81],q[32];
cp(0) q[81],q[33];
cp(0) q[81],q[34];
cp(0) q[81],q[35];
cp(0) q[81],q[36];
cp(0) q[81],q[37];
cp(0) q[81],q[38];
cp(0) q[81],q[39];
cp(-pi/2199023255552) q[81],q[40];
cp(-pi/1099511627776) q[81],q[41];
cp(-pi/549755813888) q[81],q[42];
cp(-pi/274877906944) q[81],q[43];
cp(-pi/137438953472) q[81],q[44];
cp(-pi/68719476736) q[81],q[45];
cp(-pi/34359738368) q[81],q[46];
cp(-pi/17179869184) q[81],q[47];
cp(-pi/8589934592) q[81],q[48];
cp(-pi/4294967296) q[81],q[49];
cp(-pi/2147483648) q[81],q[50];
cp(-pi/1073741824) q[81],q[51];
cp(-pi/536870912) q[81],q[52];
cp(-pi/268435456) q[81],q[53];
cp(-pi/134217728) q[81],q[54];
cp(-pi/67108864) q[81],q[55];
cp(-pi/33554432) q[81],q[56];
cp(-pi/16777216) q[81],q[57];
cp(-pi/8388608) q[81],q[58];
cp(-pi/4194304) q[81],q[59];
cp(-pi/2097152) q[81],q[60];
cp(-pi/1048576) q[81],q[61];
cp(-pi/524288) q[81],q[62];
cp(-pi/262144) q[81],q[63];
cp(-pi/131072) q[81],q[64];
cp(-pi/65536) q[81],q[65];
cp(-pi/32768) q[81],q[66];
cp(-pi/16384) q[81],q[67];
cp(-pi/8192) q[81],q[68];
cp(-pi/4096) q[81],q[69];
cp(-pi/2048) q[81],q[70];
cp(-pi/1024) q[81],q[71];
cp(-pi/512) q[81],q[72];
cp(-pi/256) q[81],q[73];
cp(-pi/128) q[81],q[74];
cp(-pi/64) q[81],q[75];
cp(-pi/32) q[81],q[76];
cp(-pi/16) q[81],q[77];
cp(-pi/8) q[81],q[78];
cp(-pi/4) q[81],q[79];
cp(-pi/2) q[81],q[80];
h q[81];
cp(0) q[82],q[0];
cp(0) q[82],q[1];
cp(0) q[82],q[2];
cp(0) q[82],q[3];
cp(0) q[82],q[4];
cp(0) q[82],q[5];
cp(0) q[82],q[6];
cp(0) q[82],q[7];
cp(0) q[82],q[8];
cp(0) q[82],q[9];
cp(0) q[82],q[10];
cp(0) q[82],q[11];
cp(0) q[82],q[12];
cp(0) q[82],q[13];
cp(0) q[82],q[14];
cp(0) q[82],q[15];
cp(0) q[82],q[16];
cp(0) q[82],q[17];
cp(0) q[82],q[18];
cp(0) q[82],q[19];
cp(0) q[82],q[20];
cp(0) q[82],q[21];
cp(0) q[82],q[22];
cp(0) q[82],q[23];
cp(0) q[82],q[24];
cp(0) q[82],q[25];
cp(0) q[82],q[26];
cp(0) q[82],q[27];
cp(0) q[82],q[28];
cp(0) q[82],q[29];
cp(0) q[82],q[30];
cp(0) q[82],q[31];
cp(0) q[82],q[32];
cp(0) q[82],q[33];
cp(0) q[82],q[34];
cp(0) q[82],q[35];
cp(0) q[82],q[36];
cp(0) q[82],q[37];
cp(0) q[82],q[38];
cp(0) q[82],q[39];
cp(0) q[82],q[40];
cp(-pi/2199023255552) q[82],q[41];
cp(-pi/1099511627776) q[82],q[42];
cp(-pi/549755813888) q[82],q[43];
cp(-pi/274877906944) q[82],q[44];
cp(-pi/137438953472) q[82],q[45];
cp(-pi/68719476736) q[82],q[46];
cp(-pi/34359738368) q[82],q[47];
cp(-pi/17179869184) q[82],q[48];
cp(-pi/8589934592) q[82],q[49];
cp(-pi/4294967296) q[82],q[50];
cp(-pi/2147483648) q[82],q[51];
cp(-pi/1073741824) q[82],q[52];
cp(-pi/536870912) q[82],q[53];
cp(-pi/268435456) q[82],q[54];
cp(-pi/134217728) q[82],q[55];
cp(-pi/67108864) q[82],q[56];
cp(-pi/33554432) q[82],q[57];
cp(-pi/16777216) q[82],q[58];
cp(-pi/8388608) q[82],q[59];
cp(-pi/4194304) q[82],q[60];
cp(-pi/2097152) q[82],q[61];
cp(-pi/1048576) q[82],q[62];
cp(-pi/524288) q[82],q[63];
cp(-pi/262144) q[82],q[64];
cp(-pi/131072) q[82],q[65];
cp(-pi/65536) q[82],q[66];
cp(-pi/32768) q[82],q[67];
cp(-pi/16384) q[82],q[68];
cp(-pi/8192) q[82],q[69];
cp(-pi/4096) q[82],q[70];
cp(-pi/2048) q[82],q[71];
cp(-pi/1024) q[82],q[72];
cp(-pi/512) q[82],q[73];
cp(-pi/256) q[82],q[74];
cp(-pi/128) q[82],q[75];
cp(-pi/64) q[82],q[76];
cp(-pi/32) q[82],q[77];
cp(-pi/16) q[82],q[78];
cp(-pi/8) q[82],q[79];
cp(-pi/4) q[82],q[80];
cp(-pi/2) q[82],q[81];
h q[82];
cp(0) q[83],q[0];
cp(0) q[83],q[1];
cp(0) q[83],q[2];
cp(0) q[83],q[3];
cp(0) q[83],q[4];
cp(0) q[83],q[5];
cp(0) q[83],q[6];
cp(0) q[83],q[7];
cp(0) q[83],q[8];
cp(0) q[83],q[9];
cp(0) q[83],q[10];
cp(0) q[83],q[11];
cp(0) q[83],q[12];
cp(0) q[83],q[13];
cp(0) q[83],q[14];
cp(0) q[83],q[15];
cp(0) q[83],q[16];
cp(0) q[83],q[17];
cp(0) q[83],q[18];
cp(0) q[83],q[19];
cp(0) q[83],q[20];
cp(0) q[83],q[21];
cp(0) q[83],q[22];
cp(0) q[83],q[23];
cp(0) q[83],q[24];
cp(0) q[83],q[25];
cp(0) q[83],q[26];
cp(0) q[83],q[27];
cp(0) q[83],q[28];
cp(0) q[83],q[29];
cp(0) q[83],q[30];
cp(0) q[83],q[31];
cp(0) q[83],q[32];
cp(0) q[83],q[33];
cp(0) q[83],q[34];
cp(0) q[83],q[35];
cp(0) q[83],q[36];
cp(0) q[83],q[37];
cp(0) q[83],q[38];
cp(0) q[83],q[39];
cp(0) q[83],q[40];
cp(0) q[83],q[41];
cp(-pi/2199023255552) q[83],q[42];
cp(-pi/1099511627776) q[83],q[43];
cp(-pi/549755813888) q[83],q[44];
cp(-pi/274877906944) q[83],q[45];
cp(-pi/137438953472) q[83],q[46];
cp(-pi/68719476736) q[83],q[47];
cp(-pi/34359738368) q[83],q[48];
cp(-pi/17179869184) q[83],q[49];
cp(-pi/8589934592) q[83],q[50];
cp(-pi/4294967296) q[83],q[51];
cp(-pi/2147483648) q[83],q[52];
cp(-pi/1073741824) q[83],q[53];
cp(-pi/536870912) q[83],q[54];
cp(-pi/268435456) q[83],q[55];
cp(-pi/134217728) q[83],q[56];
cp(-pi/67108864) q[83],q[57];
cp(-pi/33554432) q[83],q[58];
cp(-pi/16777216) q[83],q[59];
cp(-pi/8388608) q[83],q[60];
cp(-pi/4194304) q[83],q[61];
cp(-pi/2097152) q[83],q[62];
cp(-pi/1048576) q[83],q[63];
cp(-pi/524288) q[83],q[64];
cp(-pi/262144) q[83],q[65];
cp(-pi/131072) q[83],q[66];
cp(-pi/65536) q[83],q[67];
cp(-pi/32768) q[83],q[68];
cp(-pi/16384) q[83],q[69];
cp(-pi/8192) q[83],q[70];
cp(-pi/4096) q[83],q[71];
cp(-pi/2048) q[83],q[72];
cp(-pi/1024) q[83],q[73];
cp(-pi/512) q[83],q[74];
cp(-pi/256) q[83],q[75];
cp(-pi/128) q[83],q[76];
cp(-pi/64) q[83],q[77];
cp(-pi/32) q[83],q[78];
cp(-pi/16) q[83],q[79];
cp(-pi/8) q[83],q[80];
cp(-pi/4) q[83],q[81];
cp(-pi/2) q[83],q[82];
h q[83];
cp(0) q[84],q[0];
cp(0) q[84],q[1];
cp(0) q[84],q[2];
cp(0) q[84],q[3];
cp(0) q[84],q[4];
cp(0) q[84],q[5];
cp(0) q[84],q[6];
cp(0) q[84],q[7];
cp(0) q[84],q[8];
cp(0) q[84],q[9];
cp(0) q[84],q[10];
cp(0) q[84],q[11];
cp(0) q[84],q[12];
cp(0) q[84],q[13];
cp(0) q[84],q[14];
cp(0) q[84],q[15];
cp(0) q[84],q[16];
cp(0) q[84],q[17];
cp(0) q[84],q[18];
cp(0) q[84],q[19];
cp(0) q[84],q[20];
cp(0) q[84],q[21];
cp(0) q[84],q[22];
cp(0) q[84],q[23];
cp(0) q[84],q[24];
cp(0) q[84],q[25];
cp(0) q[84],q[26];
cp(0) q[84],q[27];
cp(0) q[84],q[28];
cp(0) q[84],q[29];
cp(0) q[84],q[30];
cp(0) q[84],q[31];
cp(0) q[84],q[32];
cp(0) q[84],q[33];
cp(0) q[84],q[34];
cp(0) q[84],q[35];
cp(0) q[84],q[36];
cp(0) q[84],q[37];
cp(0) q[84],q[38];
cp(0) q[84],q[39];
cp(0) q[84],q[40];
cp(0) q[84],q[41];
cp(0) q[84],q[42];
cp(-pi/2199023255552) q[84],q[43];
cp(-pi/1099511627776) q[84],q[44];
cp(-pi/549755813888) q[84],q[45];
cp(-pi/274877906944) q[84],q[46];
cp(-pi/137438953472) q[84],q[47];
cp(-pi/68719476736) q[84],q[48];
cp(-pi/34359738368) q[84],q[49];
cp(-pi/17179869184) q[84],q[50];
cp(-pi/8589934592) q[84],q[51];
cp(-pi/4294967296) q[84],q[52];
cp(-pi/2147483648) q[84],q[53];
cp(-pi/1073741824) q[84],q[54];
cp(-pi/536870912) q[84],q[55];
cp(-pi/268435456) q[84],q[56];
cp(-pi/134217728) q[84],q[57];
cp(-pi/67108864) q[84],q[58];
cp(-pi/33554432) q[84],q[59];
cp(-pi/16777216) q[84],q[60];
cp(-pi/8388608) q[84],q[61];
cp(-pi/4194304) q[84],q[62];
cp(-pi/2097152) q[84],q[63];
cp(-pi/1048576) q[84],q[64];
cp(-pi/524288) q[84],q[65];
cp(-pi/262144) q[84],q[66];
cp(-pi/131072) q[84],q[67];
cp(-pi/65536) q[84],q[68];
cp(-pi/32768) q[84],q[69];
cp(-pi/16384) q[84],q[70];
cp(-pi/8192) q[84],q[71];
cp(-pi/4096) q[84],q[72];
cp(-pi/2048) q[84],q[73];
cp(-pi/1024) q[84],q[74];
cp(-pi/512) q[84],q[75];
cp(-pi/256) q[84],q[76];
cp(-pi/128) q[84],q[77];
cp(-pi/64) q[84],q[78];
cp(-pi/32) q[84],q[79];
cp(-pi/16) q[84],q[80];
cp(-pi/8) q[84],q[81];
cp(-pi/4) q[84],q[82];
cp(-pi/2) q[84],q[83];
h q[84];
cp(0) q[85],q[0];
cp(0) q[85],q[1];
cp(0) q[85],q[2];
cp(0) q[85],q[3];
cp(0) q[85],q[4];
cp(0) q[85],q[5];
cp(0) q[85],q[6];
cp(0) q[85],q[7];
cp(0) q[85],q[8];
cp(0) q[85],q[9];
cp(0) q[85],q[10];
cp(0) q[85],q[11];
cp(0) q[85],q[12];
cp(0) q[85],q[13];
cp(0) q[85],q[14];
cp(0) q[85],q[15];
cp(0) q[85],q[16];
cp(0) q[85],q[17];
cp(0) q[85],q[18];
cp(0) q[85],q[19];
cp(0) q[85],q[20];
cp(0) q[85],q[21];
cp(0) q[85],q[22];
cp(0) q[85],q[23];
cp(0) q[85],q[24];
cp(0) q[85],q[25];
cp(0) q[85],q[26];
cp(0) q[85],q[27];
cp(0) q[85],q[28];
cp(0) q[85],q[29];
cp(0) q[85],q[30];
cp(0) q[85],q[31];
cp(0) q[85],q[32];
cp(0) q[85],q[33];
cp(0) q[85],q[34];
cp(0) q[85],q[35];
cp(0) q[85],q[36];
cp(0) q[85],q[37];
cp(0) q[85],q[38];
cp(0) q[85],q[39];
cp(0) q[85],q[40];
cp(0) q[85],q[41];
cp(0) q[85],q[42];
cp(0) q[85],q[43];
cp(-pi/2199023255552) q[85],q[44];
cp(-pi/1099511627776) q[85],q[45];
cp(-pi/549755813888) q[85],q[46];
cp(-pi/274877906944) q[85],q[47];
cp(-pi/137438953472) q[85],q[48];
cp(-pi/68719476736) q[85],q[49];
cp(-pi/34359738368) q[85],q[50];
cp(-pi/17179869184) q[85],q[51];
cp(-pi/8589934592) q[85],q[52];
cp(-pi/4294967296) q[85],q[53];
cp(-pi/2147483648) q[85],q[54];
cp(-pi/1073741824) q[85],q[55];
cp(-pi/536870912) q[85],q[56];
cp(-pi/268435456) q[85],q[57];
cp(-pi/134217728) q[85],q[58];
cp(-pi/67108864) q[85],q[59];
cp(-pi/33554432) q[85],q[60];
cp(-pi/16777216) q[85],q[61];
cp(-pi/8388608) q[85],q[62];
cp(-pi/4194304) q[85],q[63];
cp(-pi/2097152) q[85],q[64];
cp(-pi/1048576) q[85],q[65];
cp(-pi/524288) q[85],q[66];
cp(-pi/262144) q[85],q[67];
cp(-pi/131072) q[85],q[68];
cp(-pi/65536) q[85],q[69];
cp(-pi/32768) q[85],q[70];
cp(-pi/16384) q[85],q[71];
cp(-pi/8192) q[85],q[72];
cp(-pi/4096) q[85],q[73];
cp(-pi/2048) q[85],q[74];
cp(-pi/1024) q[85],q[75];
cp(-pi/512) q[85],q[76];
cp(-pi/256) q[85],q[77];
cp(-pi/128) q[85],q[78];
cp(-pi/64) q[85],q[79];
cp(-pi/32) q[85],q[80];
cp(-pi/16) q[85],q[81];
cp(-pi/8) q[85],q[82];
cp(-pi/4) q[85],q[83];
cp(-pi/2) q[85],q[84];
h q[85];
cp(0) q[86],q[0];
cp(0) q[86],q[1];
cp(0) q[86],q[2];
cp(0) q[86],q[3];
cp(0) q[86],q[4];
cp(0) q[86],q[5];
cp(0) q[86],q[6];
cp(0) q[86],q[7];
cp(0) q[86],q[8];
cp(0) q[86],q[9];
cp(0) q[86],q[10];
cp(0) q[86],q[11];
cp(0) q[86],q[12];
cp(0) q[86],q[13];
cp(0) q[86],q[14];
cp(0) q[86],q[15];
cp(0) q[86],q[16];
cp(0) q[86],q[17];
cp(0) q[86],q[18];
cp(0) q[86],q[19];
cp(0) q[86],q[20];
cp(0) q[86],q[21];
cp(0) q[86],q[22];
cp(0) q[86],q[23];
cp(0) q[86],q[24];
cp(0) q[86],q[25];
cp(0) q[86],q[26];
cp(0) q[86],q[27];
cp(0) q[86],q[28];
cp(0) q[86],q[29];
cp(0) q[86],q[30];
cp(0) q[86],q[31];
cp(0) q[86],q[32];
cp(0) q[86],q[33];
cp(0) q[86],q[34];
cp(0) q[86],q[35];
cp(0) q[86],q[36];
cp(0) q[86],q[37];
cp(0) q[86],q[38];
cp(0) q[86],q[39];
cp(0) q[86],q[40];
cp(0) q[86],q[41];
cp(0) q[86],q[42];
cp(0) q[86],q[43];
cp(0) q[86],q[44];
cp(-pi/2199023255552) q[86],q[45];
cp(-pi/1099511627776) q[86],q[46];
cp(-pi/549755813888) q[86],q[47];
cp(-pi/274877906944) q[86],q[48];
cp(-pi/137438953472) q[86],q[49];
cp(-pi/68719476736) q[86],q[50];
cp(-pi/34359738368) q[86],q[51];
cp(-pi/17179869184) q[86],q[52];
cp(-pi/8589934592) q[86],q[53];
cp(-pi/4294967296) q[86],q[54];
cp(-pi/2147483648) q[86],q[55];
cp(-pi/1073741824) q[86],q[56];
cp(-pi/536870912) q[86],q[57];
cp(-pi/268435456) q[86],q[58];
cp(-pi/134217728) q[86],q[59];
cp(-pi/67108864) q[86],q[60];
cp(-pi/33554432) q[86],q[61];
cp(-pi/16777216) q[86],q[62];
cp(-pi/8388608) q[86],q[63];
cp(-pi/4194304) q[86],q[64];
cp(-pi/2097152) q[86],q[65];
cp(-pi/1048576) q[86],q[66];
cp(-pi/524288) q[86],q[67];
cp(-pi/262144) q[86],q[68];
cp(-pi/131072) q[86],q[69];
cp(-pi/65536) q[86],q[70];
cp(-pi/32768) q[86],q[71];
cp(-pi/16384) q[86],q[72];
cp(-pi/8192) q[86],q[73];
cp(-pi/4096) q[86],q[74];
cp(-pi/2048) q[86],q[75];
cp(-pi/1024) q[86],q[76];
cp(-pi/512) q[86],q[77];
cp(-pi/256) q[86],q[78];
cp(-pi/128) q[86],q[79];
cp(-pi/64) q[86],q[80];
cp(-pi/32) q[86],q[81];
cp(-pi/16) q[86],q[82];
cp(-pi/8) q[86],q[83];
cp(-pi/4) q[86],q[84];
cp(-pi/2) q[86],q[85];
h q[86];
cp(0) q[87],q[0];
cp(0) q[87],q[1];
cp(0) q[87],q[2];
cp(0) q[87],q[3];
cp(0) q[87],q[4];
cp(0) q[87],q[5];
cp(0) q[87],q[6];
cp(0) q[87],q[7];
cp(0) q[87],q[8];
cp(0) q[87],q[9];
cp(0) q[87],q[10];
cp(0) q[87],q[11];
cp(0) q[87],q[12];
cp(0) q[87],q[13];
cp(0) q[87],q[14];
cp(0) q[87],q[15];
cp(0) q[87],q[16];
cp(0) q[87],q[17];
cp(0) q[87],q[18];
cp(0) q[87],q[19];
cp(0) q[87],q[20];
cp(0) q[87],q[21];
cp(0) q[87],q[22];
cp(0) q[87],q[23];
cp(0) q[87],q[24];
cp(0) q[87],q[25];
cp(0) q[87],q[26];
cp(0) q[87],q[27];
cp(0) q[87],q[28];
cp(0) q[87],q[29];
cp(0) q[87],q[30];
cp(0) q[87],q[31];
cp(0) q[87],q[32];
cp(0) q[87],q[33];
cp(0) q[87],q[34];
cp(0) q[87],q[35];
cp(0) q[87],q[36];
cp(0) q[87],q[37];
cp(0) q[87],q[38];
cp(0) q[87],q[39];
cp(0) q[87],q[40];
cp(0) q[87],q[41];
cp(0) q[87],q[42];
cp(0) q[87],q[43];
cp(0) q[87],q[44];
cp(0) q[87],q[45];
cp(-pi/2199023255552) q[87],q[46];
cp(-pi/1099511627776) q[87],q[47];
cp(-pi/549755813888) q[87],q[48];
cp(-pi/274877906944) q[87],q[49];
cp(-pi/137438953472) q[87],q[50];
cp(-pi/68719476736) q[87],q[51];
cp(-pi/34359738368) q[87],q[52];
cp(-pi/17179869184) q[87],q[53];
cp(-pi/8589934592) q[87],q[54];
cp(-pi/4294967296) q[87],q[55];
cp(-pi/2147483648) q[87],q[56];
cp(-pi/1073741824) q[87],q[57];
cp(-pi/536870912) q[87],q[58];
cp(-pi/268435456) q[87],q[59];
cp(-pi/134217728) q[87],q[60];
cp(-pi/67108864) q[87],q[61];
cp(-pi/33554432) q[87],q[62];
cp(-pi/16777216) q[87],q[63];
cp(-pi/8388608) q[87],q[64];
cp(-pi/4194304) q[87],q[65];
cp(-pi/2097152) q[87],q[66];
cp(-pi/1048576) q[87],q[67];
cp(-pi/524288) q[87],q[68];
cp(-pi/262144) q[87],q[69];
cp(-pi/131072) q[87],q[70];
cp(-pi/65536) q[87],q[71];
cp(-pi/32768) q[87],q[72];
cp(-pi/16384) q[87],q[73];
cp(-pi/8192) q[87],q[74];
cp(-pi/4096) q[87],q[75];
cp(-pi/2048) q[87],q[76];
cp(-pi/1024) q[87],q[77];
cp(-pi/512) q[87],q[78];
cp(-pi/256) q[87],q[79];
cp(-pi/128) q[87],q[80];
cp(-pi/64) q[87],q[81];
cp(-pi/32) q[87],q[82];
cp(-pi/16) q[87],q[83];
cp(-pi/8) q[87],q[84];
cp(-pi/4) q[87],q[85];
cp(-pi/2) q[87],q[86];
h q[87];
cp(0) q[88],q[0];
cp(0) q[88],q[1];
cp(0) q[88],q[2];
cp(0) q[88],q[3];
cp(0) q[88],q[4];
cp(0) q[88],q[5];
cp(0) q[88],q[6];
cp(0) q[88],q[7];
cp(0) q[88],q[8];
cp(0) q[88],q[9];
cp(0) q[88],q[10];
cp(0) q[88],q[11];
cp(0) q[88],q[12];
cp(0) q[88],q[13];
cp(0) q[88],q[14];
cp(0) q[88],q[15];
cp(0) q[88],q[16];
cp(0) q[88],q[17];
cp(0) q[88],q[18];
cp(0) q[88],q[19];
cp(0) q[88],q[20];
cp(0) q[88],q[21];
cp(0) q[88],q[22];
cp(0) q[88],q[23];
cp(0) q[88],q[24];
cp(0) q[88],q[25];
cp(0) q[88],q[26];
cp(0) q[88],q[27];
cp(0) q[88],q[28];
cp(0) q[88],q[29];
cp(0) q[88],q[30];
cp(0) q[88],q[31];
cp(0) q[88],q[32];
cp(0) q[88],q[33];
cp(0) q[88],q[34];
cp(0) q[88],q[35];
cp(0) q[88],q[36];
cp(0) q[88],q[37];
cp(0) q[88],q[38];
cp(0) q[88],q[39];
cp(0) q[88],q[40];
cp(0) q[88],q[41];
cp(0) q[88],q[42];
cp(0) q[88],q[43];
cp(0) q[88],q[44];
cp(0) q[88],q[45];
cp(0) q[88],q[46];
cp(-pi/2199023255552) q[88],q[47];
cp(-pi/1099511627776) q[88],q[48];
cp(-pi/549755813888) q[88],q[49];
cp(-pi/274877906944) q[88],q[50];
cp(-pi/137438953472) q[88],q[51];
cp(-pi/68719476736) q[88],q[52];
cp(-pi/34359738368) q[88],q[53];
cp(-pi/17179869184) q[88],q[54];
cp(-pi/8589934592) q[88],q[55];
cp(-pi/4294967296) q[88],q[56];
cp(-pi/2147483648) q[88],q[57];
cp(-pi/1073741824) q[88],q[58];
cp(-pi/536870912) q[88],q[59];
cp(-pi/268435456) q[88],q[60];
cp(-pi/134217728) q[88],q[61];
cp(-pi/67108864) q[88],q[62];
cp(-pi/33554432) q[88],q[63];
cp(-pi/16777216) q[88],q[64];
cp(-pi/8388608) q[88],q[65];
cp(-pi/4194304) q[88],q[66];
cp(-pi/2097152) q[88],q[67];
cp(-pi/1048576) q[88],q[68];
cp(-pi/524288) q[88],q[69];
cp(-pi/262144) q[88],q[70];
cp(-pi/131072) q[88],q[71];
cp(-pi/65536) q[88],q[72];
cp(-pi/32768) q[88],q[73];
cp(-pi/16384) q[88],q[74];
cp(-pi/8192) q[88],q[75];
cp(-pi/4096) q[88],q[76];
cp(-pi/2048) q[88],q[77];
cp(-pi/1024) q[88],q[78];
cp(-pi/512) q[88],q[79];
cp(-pi/256) q[88],q[80];
cp(-pi/128) q[88],q[81];
cp(-pi/64) q[88],q[82];
cp(-pi/32) q[88],q[83];
cp(-pi/16) q[88],q[84];
cp(-pi/8) q[88],q[85];
cp(-pi/4) q[88],q[86];
cp(-pi/2) q[88],q[87];
h q[88];
cp(0) q[89],q[0];
cp(0) q[89],q[1];
cp(0) q[89],q[2];
cp(0) q[89],q[3];
cp(0) q[89],q[4];
cp(0) q[89],q[5];
cp(0) q[89],q[6];
cp(0) q[89],q[7];
cp(0) q[89],q[8];
cp(0) q[89],q[9];
cp(0) q[89],q[10];
cp(0) q[89],q[11];
cp(0) q[89],q[12];
cp(0) q[89],q[13];
cp(0) q[89],q[14];
cp(0) q[89],q[15];
cp(0) q[89],q[16];
cp(0) q[89],q[17];
cp(0) q[89],q[18];
cp(0) q[89],q[19];
cp(0) q[89],q[20];
cp(0) q[89],q[21];
cp(0) q[89],q[22];
cp(0) q[89],q[23];
cp(0) q[89],q[24];
cp(0) q[89],q[25];
cp(0) q[89],q[26];
cp(0) q[89],q[27];
cp(0) q[89],q[28];
cp(0) q[89],q[29];
cp(0) q[89],q[30];
cp(0) q[89],q[31];
cp(0) q[89],q[32];
cp(0) q[89],q[33];
cp(0) q[89],q[34];
cp(0) q[89],q[35];
cp(0) q[89],q[36];
cp(0) q[89],q[37];
cp(0) q[89],q[38];
cp(0) q[89],q[39];
cp(0) q[89],q[40];
cp(0) q[89],q[41];
cp(0) q[89],q[42];
cp(0) q[89],q[43];
cp(0) q[89],q[44];
cp(0) q[89],q[45];
cp(0) q[89],q[46];
cp(0) q[89],q[47];
cp(-pi/2199023255552) q[89],q[48];
cp(-pi/1099511627776) q[89],q[49];
cp(-pi/549755813888) q[89],q[50];
cp(-pi/274877906944) q[89],q[51];
cp(-pi/137438953472) q[89],q[52];
cp(-pi/68719476736) q[89],q[53];
cp(-pi/34359738368) q[89],q[54];
cp(-pi/17179869184) q[89],q[55];
cp(-pi/8589934592) q[89],q[56];
cp(-pi/4294967296) q[89],q[57];
cp(-pi/2147483648) q[89],q[58];
cp(-pi/1073741824) q[89],q[59];
cp(-pi/536870912) q[89],q[60];
cp(-pi/268435456) q[89],q[61];
cp(-pi/134217728) q[89],q[62];
cp(-pi/67108864) q[89],q[63];
cp(-pi/33554432) q[89],q[64];
cp(-pi/16777216) q[89],q[65];
cp(-pi/8388608) q[89],q[66];
cp(-pi/4194304) q[89],q[67];
cp(-pi/2097152) q[89],q[68];
cp(-pi/1048576) q[89],q[69];
cp(-pi/524288) q[89],q[70];
cp(-pi/262144) q[89],q[71];
cp(-pi/131072) q[89],q[72];
cp(-pi/65536) q[89],q[73];
cp(-pi/32768) q[89],q[74];
cp(-pi/16384) q[89],q[75];
cp(-pi/8192) q[89],q[76];
cp(-pi/4096) q[89],q[77];
cp(-pi/2048) q[89],q[78];
cp(-pi/1024) q[89],q[79];
cp(-pi/512) q[89],q[80];
cp(-pi/256) q[89],q[81];
cp(-pi/128) q[89],q[82];
cp(-pi/64) q[89],q[83];
cp(-pi/32) q[89],q[84];
cp(-pi/16) q[89],q[85];
cp(-pi/8) q[89],q[86];
cp(-pi/4) q[89],q[87];
cp(-pi/2) q[89],q[88];
h q[89];
cp(0) q[90],q[0];
cp(0) q[90],q[1];
cp(0) q[90],q[2];
cp(0) q[90],q[3];
cp(0) q[90],q[4];
cp(0) q[90],q[5];
cp(0) q[90],q[6];
cp(0) q[90],q[7];
cp(0) q[90],q[8];
cp(0) q[90],q[9];
cp(0) q[90],q[10];
cp(0) q[90],q[11];
cp(0) q[90],q[12];
cp(0) q[90],q[13];
cp(0) q[90],q[14];
cp(0) q[90],q[15];
cp(0) q[90],q[16];
cp(0) q[90],q[17];
cp(0) q[90],q[18];
cp(0) q[90],q[19];
cp(0) q[90],q[20];
cp(0) q[90],q[21];
cp(0) q[90],q[22];
cp(0) q[90],q[23];
cp(0) q[90],q[24];
cp(0) q[90],q[25];
cp(0) q[90],q[26];
cp(0) q[90],q[27];
cp(0) q[90],q[28];
cp(0) q[90],q[29];
cp(0) q[90],q[30];
cp(0) q[90],q[31];
cp(0) q[90],q[32];
cp(0) q[90],q[33];
cp(0) q[90],q[34];
cp(0) q[90],q[35];
cp(0) q[90],q[36];
cp(0) q[90],q[37];
cp(0) q[90],q[38];
cp(0) q[90],q[39];
cp(0) q[90],q[40];
cp(0) q[90],q[41];
cp(0) q[90],q[42];
cp(0) q[90],q[43];
cp(0) q[90],q[44];
cp(0) q[90],q[45];
cp(0) q[90],q[46];
cp(0) q[90],q[47];
cp(0) q[90],q[48];
cp(-pi/2199023255552) q[90],q[49];
cp(-pi/1099511627776) q[90],q[50];
cp(-pi/549755813888) q[90],q[51];
cp(-pi/274877906944) q[90],q[52];
cp(-pi/137438953472) q[90],q[53];
cp(-pi/68719476736) q[90],q[54];
cp(-pi/34359738368) q[90],q[55];
cp(-pi/17179869184) q[90],q[56];
cp(-pi/8589934592) q[90],q[57];
cp(-pi/4294967296) q[90],q[58];
cp(-pi/2147483648) q[90],q[59];
cp(-pi/1073741824) q[90],q[60];
cp(-pi/536870912) q[90],q[61];
cp(-pi/268435456) q[90],q[62];
cp(-pi/134217728) q[90],q[63];
cp(-pi/67108864) q[90],q[64];
cp(-pi/33554432) q[90],q[65];
cp(-pi/16777216) q[90],q[66];
cp(-pi/8388608) q[90],q[67];
cp(-pi/4194304) q[90],q[68];
cp(-pi/2097152) q[90],q[69];
cp(-pi/1048576) q[90],q[70];
cp(-pi/524288) q[90],q[71];
cp(-pi/262144) q[90],q[72];
cp(-pi/131072) q[90],q[73];
cp(-pi/65536) q[90],q[74];
cp(-pi/32768) q[90],q[75];
cp(-pi/16384) q[90],q[76];
cp(-pi/8192) q[90],q[77];
cp(-pi/4096) q[90],q[78];
cp(-pi/2048) q[90],q[79];
cp(-pi/1024) q[90],q[80];
cp(-pi/512) q[90],q[81];
cp(-pi/256) q[90],q[82];
cp(-pi/128) q[90],q[83];
cp(-pi/64) q[90],q[84];
cp(-pi/32) q[90],q[85];
cp(-pi/16) q[90],q[86];
cp(-pi/8) q[90],q[87];
cp(-pi/4) q[90],q[88];
cp(-pi/2) q[90],q[89];
h q[90];
cp(0) q[91],q[0];
cp(0) q[91],q[1];
cp(0) q[91],q[2];
cp(0) q[91],q[3];
cp(0) q[91],q[4];
cp(0) q[91],q[5];
cp(0) q[91],q[6];
cp(0) q[91],q[7];
cp(0) q[91],q[8];
cp(0) q[91],q[9];
cp(0) q[91],q[10];
cp(0) q[91],q[11];
cp(0) q[91],q[12];
cp(0) q[91],q[13];
cp(0) q[91],q[14];
cp(0) q[91],q[15];
cp(0) q[91],q[16];
cp(0) q[91],q[17];
cp(0) q[91],q[18];
cp(0) q[91],q[19];
cp(0) q[91],q[20];
cp(0) q[91],q[21];
cp(0) q[91],q[22];
cp(0) q[91],q[23];
cp(0) q[91],q[24];
cp(0) q[91],q[25];
cp(0) q[91],q[26];
cp(0) q[91],q[27];
cp(0) q[91],q[28];
cp(0) q[91],q[29];
cp(0) q[91],q[30];
cp(0) q[91],q[31];
cp(0) q[91],q[32];
cp(0) q[91],q[33];
cp(0) q[91],q[34];
cp(0) q[91],q[35];
cp(0) q[91],q[36];
cp(0) q[91],q[37];
cp(0) q[91],q[38];
cp(0) q[91],q[39];
cp(0) q[91],q[40];
cp(0) q[91],q[41];
cp(0) q[91],q[42];
cp(0) q[91],q[43];
cp(0) q[91],q[44];
cp(0) q[91],q[45];
cp(0) q[91],q[46];
cp(0) q[91],q[47];
cp(0) q[91],q[48];
cp(0) q[91],q[49];
cp(-pi/2199023255552) q[91],q[50];
cp(-pi/1099511627776) q[91],q[51];
cp(-pi/549755813888) q[91],q[52];
cp(-pi/274877906944) q[91],q[53];
cp(-pi/137438953472) q[91],q[54];
cp(-pi/68719476736) q[91],q[55];
cp(-pi/34359738368) q[91],q[56];
cp(-pi/17179869184) q[91],q[57];
cp(-pi/8589934592) q[91],q[58];
cp(-pi/4294967296) q[91],q[59];
cp(-pi/2147483648) q[91],q[60];
cp(-pi/1073741824) q[91],q[61];
cp(-pi/536870912) q[91],q[62];
cp(-pi/268435456) q[91],q[63];
cp(-pi/134217728) q[91],q[64];
cp(-pi/67108864) q[91],q[65];
cp(-pi/33554432) q[91],q[66];
cp(-pi/16777216) q[91],q[67];
cp(-pi/8388608) q[91],q[68];
cp(-pi/4194304) q[91],q[69];
cp(-pi/2097152) q[91],q[70];
cp(-pi/1048576) q[91],q[71];
cp(-pi/524288) q[91],q[72];
cp(-pi/262144) q[91],q[73];
cp(-pi/131072) q[91],q[74];
cp(-pi/65536) q[91],q[75];
cp(-pi/32768) q[91],q[76];
cp(-pi/16384) q[91],q[77];
cp(-pi/8192) q[91],q[78];
cp(-pi/4096) q[91],q[79];
cp(-pi/2048) q[91],q[80];
cp(-pi/1024) q[91],q[81];
cp(-pi/512) q[91],q[82];
cp(-pi/256) q[91],q[83];
cp(-pi/128) q[91],q[84];
cp(-pi/64) q[91],q[85];
cp(-pi/32) q[91],q[86];
cp(-pi/16) q[91],q[87];
cp(-pi/8) q[91],q[88];
cp(-pi/4) q[91],q[89];
cp(-pi/2) q[91],q[90];
h q[91];
cp(0) q[92],q[0];
cp(0) q[92],q[1];
cp(0) q[92],q[2];
cp(0) q[92],q[3];
cp(0) q[92],q[4];
cp(0) q[92],q[5];
cp(0) q[92],q[6];
cp(0) q[92],q[7];
cp(0) q[92],q[8];
cp(0) q[92],q[9];
cp(0) q[92],q[10];
cp(0) q[92],q[11];
cp(0) q[92],q[12];
cp(0) q[92],q[13];
cp(0) q[92],q[14];
cp(0) q[92],q[15];
cp(0) q[92],q[16];
cp(0) q[92],q[17];
cp(0) q[92],q[18];
cp(0) q[92],q[19];
cp(0) q[92],q[20];
cp(0) q[92],q[21];
cp(0) q[92],q[22];
cp(0) q[92],q[23];
cp(0) q[92],q[24];
cp(0) q[92],q[25];
cp(0) q[92],q[26];
cp(0) q[92],q[27];
cp(0) q[92],q[28];
cp(0) q[92],q[29];
cp(0) q[92],q[30];
cp(0) q[92],q[31];
cp(0) q[92],q[32];
cp(0) q[92],q[33];
cp(0) q[92],q[34];
cp(0) q[92],q[35];
cp(0) q[92],q[36];
cp(0) q[92],q[37];
cp(0) q[92],q[38];
cp(0) q[92],q[39];
cp(0) q[92],q[40];
cp(0) q[92],q[41];
cp(0) q[92],q[42];
cp(0) q[92],q[43];
cp(0) q[92],q[44];
cp(0) q[92],q[45];
cp(0) q[92],q[46];
cp(0) q[92],q[47];
cp(0) q[92],q[48];
cp(0) q[92],q[49];
cp(0) q[92],q[50];
cp(-pi/2199023255552) q[92],q[51];
cp(-pi/1099511627776) q[92],q[52];
cp(-pi/549755813888) q[92],q[53];
cp(-pi/274877906944) q[92],q[54];
cp(-pi/137438953472) q[92],q[55];
cp(-pi/68719476736) q[92],q[56];
cp(-pi/34359738368) q[92],q[57];
cp(-pi/17179869184) q[92],q[58];
cp(-pi/8589934592) q[92],q[59];
cp(-pi/4294967296) q[92],q[60];
cp(-pi/2147483648) q[92],q[61];
cp(-pi/1073741824) q[92],q[62];
cp(-pi/536870912) q[92],q[63];
cp(-pi/268435456) q[92],q[64];
cp(-pi/134217728) q[92],q[65];
cp(-pi/67108864) q[92],q[66];
cp(-pi/33554432) q[92],q[67];
cp(-pi/16777216) q[92],q[68];
cp(-pi/8388608) q[92],q[69];
cp(-pi/4194304) q[92],q[70];
cp(-pi/2097152) q[92],q[71];
cp(-pi/1048576) q[92],q[72];
cp(-pi/524288) q[92],q[73];
cp(-pi/262144) q[92],q[74];
cp(-pi/131072) q[92],q[75];
cp(-pi/65536) q[92],q[76];
cp(-pi/32768) q[92],q[77];
cp(-pi/16384) q[92],q[78];
cp(-pi/8192) q[92],q[79];
cp(-pi/4096) q[92],q[80];
cp(-pi/2048) q[92],q[81];
cp(-pi/1024) q[92],q[82];
cp(-pi/512) q[92],q[83];
cp(-pi/256) q[92],q[84];
cp(-pi/128) q[92],q[85];
cp(-pi/64) q[92],q[86];
cp(-pi/32) q[92],q[87];
cp(-pi/16) q[92],q[88];
cp(-pi/8) q[92],q[89];
cp(-pi/4) q[92],q[90];
cp(-pi/2) q[92],q[91];
h q[92];
cp(0) q[93],q[0];
cp(0) q[93],q[1];
cp(0) q[93],q[2];
cp(0) q[93],q[3];
cp(0) q[93],q[4];
cp(0) q[93],q[5];
cp(0) q[93],q[6];
cp(0) q[93],q[7];
cp(0) q[93],q[8];
cp(0) q[93],q[9];
cp(0) q[93],q[10];
cp(0) q[93],q[11];
cp(0) q[93],q[12];
cp(0) q[93],q[13];
cp(0) q[93],q[14];
cp(0) q[93],q[15];
cp(0) q[93],q[16];
cp(0) q[93],q[17];
cp(0) q[93],q[18];
cp(0) q[93],q[19];
cp(0) q[93],q[20];
cp(0) q[93],q[21];
cp(0) q[93],q[22];
cp(0) q[93],q[23];
cp(0) q[93],q[24];
cp(0) q[93],q[25];
cp(0) q[93],q[26];
cp(0) q[93],q[27];
cp(0) q[93],q[28];
cp(0) q[93],q[29];
cp(0) q[93],q[30];
cp(0) q[93],q[31];
cp(0) q[93],q[32];
cp(0) q[93],q[33];
cp(0) q[93],q[34];
cp(0) q[93],q[35];
cp(0) q[93],q[36];
cp(0) q[93],q[37];
cp(0) q[93],q[38];
cp(0) q[93],q[39];
cp(0) q[93],q[40];
cp(0) q[93],q[41];
cp(0) q[93],q[42];
cp(0) q[93],q[43];
cp(0) q[93],q[44];
cp(0) q[93],q[45];
cp(0) q[93],q[46];
cp(0) q[93],q[47];
cp(0) q[93],q[48];
cp(0) q[93],q[49];
cp(0) q[93],q[50];
cp(0) q[93],q[51];
cp(-pi/2199023255552) q[93],q[52];
cp(-pi/1099511627776) q[93],q[53];
cp(-pi/549755813888) q[93],q[54];
cp(-pi/274877906944) q[93],q[55];
cp(-pi/137438953472) q[93],q[56];
cp(-pi/68719476736) q[93],q[57];
cp(-pi/34359738368) q[93],q[58];
cp(-pi/17179869184) q[93],q[59];
cp(-pi/8589934592) q[93],q[60];
cp(-pi/4294967296) q[93],q[61];
cp(-pi/2147483648) q[93],q[62];
cp(-pi/1073741824) q[93],q[63];
cp(-pi/536870912) q[93],q[64];
cp(-pi/268435456) q[93],q[65];
cp(-pi/134217728) q[93],q[66];
cp(-pi/67108864) q[93],q[67];
cp(-pi/33554432) q[93],q[68];
cp(-pi/16777216) q[93],q[69];
cp(-pi/8388608) q[93],q[70];
cp(-pi/4194304) q[93],q[71];
cp(-pi/2097152) q[93],q[72];
cp(-pi/1048576) q[93],q[73];
cp(-pi/524288) q[93],q[74];
cp(-pi/262144) q[93],q[75];
cp(-pi/131072) q[93],q[76];
cp(-pi/65536) q[93],q[77];
cp(-pi/32768) q[93],q[78];
cp(-pi/16384) q[93],q[79];
cp(-pi/8192) q[93],q[80];
cp(-pi/4096) q[93],q[81];
cp(-pi/2048) q[93],q[82];
cp(-pi/1024) q[93],q[83];
cp(-pi/512) q[93],q[84];
cp(-pi/256) q[93],q[85];
cp(-pi/128) q[93],q[86];
cp(-pi/64) q[93],q[87];
cp(-pi/32) q[93],q[88];
cp(-pi/16) q[93],q[89];
cp(-pi/8) q[93],q[90];
cp(-pi/4) q[93],q[91];
cp(-pi/2) q[93],q[92];
h q[93];
cp(0) q[94],q[0];
cp(0) q[94],q[1];
cp(0) q[94],q[2];
cp(0) q[94],q[3];
cp(0) q[94],q[4];
cp(0) q[94],q[5];
cp(0) q[94],q[6];
cp(0) q[94],q[7];
cp(0) q[94],q[8];
cp(0) q[94],q[9];
cp(0) q[94],q[10];
cp(0) q[94],q[11];
cp(0) q[94],q[12];
cp(0) q[94],q[13];
cp(0) q[94],q[14];
cp(0) q[94],q[15];
cp(0) q[94],q[16];
cp(0) q[94],q[17];
cp(0) q[94],q[18];
cp(0) q[94],q[19];
cp(0) q[94],q[20];
cp(0) q[94],q[21];
cp(0) q[94],q[22];
cp(0) q[94],q[23];
cp(0) q[94],q[24];
cp(0) q[94],q[25];
cp(0) q[94],q[26];
cp(0) q[94],q[27];
cp(0) q[94],q[28];
cp(0) q[94],q[29];
cp(0) q[94],q[30];
cp(0) q[94],q[31];
cp(0) q[94],q[32];
cp(0) q[94],q[33];
cp(0) q[94],q[34];
cp(0) q[94],q[35];
cp(0) q[94],q[36];
cp(0) q[94],q[37];
cp(0) q[94],q[38];
cp(0) q[94],q[39];
cp(0) q[94],q[40];
cp(0) q[94],q[41];
cp(0) q[94],q[42];
cp(0) q[94],q[43];
cp(0) q[94],q[44];
cp(0) q[94],q[45];
cp(0) q[94],q[46];
cp(0) q[94],q[47];
cp(0) q[94],q[48];
cp(0) q[94],q[49];
cp(0) q[94],q[50];
cp(0) q[94],q[51];
cp(0) q[94],q[52];
cp(-pi/2199023255552) q[94],q[53];
cp(-pi/1099511627776) q[94],q[54];
cp(-pi/549755813888) q[94],q[55];
cp(-pi/274877906944) q[94],q[56];
cp(-pi/137438953472) q[94],q[57];
cp(-pi/68719476736) q[94],q[58];
cp(-pi/34359738368) q[94],q[59];
cp(-pi/17179869184) q[94],q[60];
cp(-pi/8589934592) q[94],q[61];
cp(-pi/4294967296) q[94],q[62];
cp(-pi/2147483648) q[94],q[63];
cp(-pi/1073741824) q[94],q[64];
cp(-pi/536870912) q[94],q[65];
cp(-pi/268435456) q[94],q[66];
cp(-pi/134217728) q[94],q[67];
cp(-pi/67108864) q[94],q[68];
cp(-pi/33554432) q[94],q[69];
cp(-pi/16777216) q[94],q[70];
cp(-pi/8388608) q[94],q[71];
cp(-pi/4194304) q[94],q[72];
cp(-pi/2097152) q[94],q[73];
cp(-pi/1048576) q[94],q[74];
cp(-pi/524288) q[94],q[75];
cp(-pi/262144) q[94],q[76];
cp(-pi/131072) q[94],q[77];
cp(-pi/65536) q[94],q[78];
cp(-pi/32768) q[94],q[79];
cp(-pi/16384) q[94],q[80];
cp(-pi/8192) q[94],q[81];
cp(-pi/4096) q[94],q[82];
cp(-pi/2048) q[94],q[83];
cp(-pi/1024) q[94],q[84];
cp(-pi/512) q[94],q[85];
cp(-pi/256) q[94],q[86];
cp(-pi/128) q[94],q[87];
cp(-pi/64) q[94],q[88];
cp(-pi/32) q[94],q[89];
cp(-pi/16) q[94],q[90];
cp(-pi/8) q[94],q[91];
cp(-pi/4) q[94],q[92];
cp(-pi/2) q[94],q[93];
h q[94];
cp(0) q[95],q[0];
cp(0) q[95],q[1];
cp(0) q[95],q[2];
cp(0) q[95],q[3];
cp(0) q[95],q[4];
cp(0) q[95],q[5];
cp(0) q[95],q[6];
cp(0) q[95],q[7];
cp(0) q[95],q[8];
cp(0) q[95],q[9];
cp(0) q[95],q[10];
cp(0) q[95],q[11];
cp(0) q[95],q[12];
cp(0) q[95],q[13];
cp(0) q[95],q[14];
cp(0) q[95],q[15];
cp(0) q[95],q[16];
cp(0) q[95],q[17];
cp(0) q[95],q[18];
cp(0) q[95],q[19];
cp(0) q[95],q[20];
cp(0) q[95],q[21];
cp(0) q[95],q[22];
cp(0) q[95],q[23];
cp(0) q[95],q[24];
cp(0) q[95],q[25];
cp(0) q[95],q[26];
cp(0) q[95],q[27];
cp(0) q[95],q[28];
cp(0) q[95],q[29];
cp(0) q[95],q[30];
cp(0) q[95],q[31];
cp(0) q[95],q[32];
cp(0) q[95],q[33];
cp(0) q[95],q[34];
cp(0) q[95],q[35];
cp(0) q[95],q[36];
cp(0) q[95],q[37];
cp(0) q[95],q[38];
cp(0) q[95],q[39];
cp(0) q[95],q[40];
cp(0) q[95],q[41];
cp(0) q[95],q[42];
cp(0) q[95],q[43];
cp(0) q[95],q[44];
cp(0) q[95],q[45];
cp(0) q[95],q[46];
cp(0) q[95],q[47];
cp(0) q[95],q[48];
cp(0) q[95],q[49];
cp(0) q[95],q[50];
cp(0) q[95],q[51];
cp(0) q[95],q[52];
cp(0) q[95],q[53];
cp(-pi/2199023255552) q[95],q[54];
cp(-pi/1099511627776) q[95],q[55];
cp(-pi/549755813888) q[95],q[56];
cp(-pi/274877906944) q[95],q[57];
cp(-pi/137438953472) q[95],q[58];
cp(-pi/68719476736) q[95],q[59];
cp(-pi/34359738368) q[95],q[60];
cp(-pi/17179869184) q[95],q[61];
cp(-pi/8589934592) q[95],q[62];
cp(-pi/4294967296) q[95],q[63];
cp(-pi/2147483648) q[95],q[64];
cp(-pi/1073741824) q[95],q[65];
cp(-pi/536870912) q[95],q[66];
cp(-pi/268435456) q[95],q[67];
cp(-pi/134217728) q[95],q[68];
cp(-pi/67108864) q[95],q[69];
cp(-pi/33554432) q[95],q[70];
cp(-pi/16777216) q[95],q[71];
cp(-pi/8388608) q[95],q[72];
cp(-pi/4194304) q[95],q[73];
cp(-pi/2097152) q[95],q[74];
cp(-pi/1048576) q[95],q[75];
cp(-pi/524288) q[95],q[76];
cp(-pi/262144) q[95],q[77];
cp(-pi/131072) q[95],q[78];
cp(-pi/65536) q[95],q[79];
cp(-pi/32768) q[95],q[80];
cp(-pi/16384) q[95],q[81];
cp(-pi/8192) q[95],q[82];
cp(-pi/4096) q[95],q[83];
cp(-pi/2048) q[95],q[84];
cp(-pi/1024) q[95],q[85];
cp(-pi/512) q[95],q[86];
cp(-pi/256) q[95],q[87];
cp(-pi/128) q[95],q[88];
cp(-pi/64) q[95],q[89];
cp(-pi/32) q[95],q[90];
cp(-pi/16) q[95],q[91];
cp(-pi/8) q[95],q[92];
cp(-pi/4) q[95],q[93];
cp(-pi/2) q[95],q[94];
h q[95];
cp(0) q[96],q[0];
cp(0) q[96],q[1];
cp(0) q[96],q[2];
cp(0) q[96],q[3];
cp(0) q[96],q[4];
cp(0) q[96],q[5];
cp(0) q[96],q[6];
cp(0) q[96],q[7];
cp(0) q[96],q[8];
cp(0) q[96],q[9];
cp(0) q[96],q[10];
cp(0) q[96],q[11];
cp(0) q[96],q[12];
cp(0) q[96],q[13];
cp(0) q[96],q[14];
cp(0) q[96],q[15];
cp(0) q[96],q[16];
cp(0) q[96],q[17];
cp(0) q[96],q[18];
cp(0) q[96],q[19];
cp(0) q[96],q[20];
cp(0) q[96],q[21];
cp(0) q[96],q[22];
cp(0) q[96],q[23];
cp(0) q[96],q[24];
cp(0) q[96],q[25];
cp(0) q[96],q[26];
cp(0) q[96],q[27];
cp(0) q[96],q[28];
cp(0) q[96],q[29];
cp(0) q[96],q[30];
cp(0) q[96],q[31];
cp(0) q[96],q[32];
cp(0) q[96],q[33];
cp(0) q[96],q[34];
cp(0) q[96],q[35];
cp(0) q[96],q[36];
cp(0) q[96],q[37];
cp(0) q[96],q[38];
cp(0) q[96],q[39];
cp(0) q[96],q[40];
cp(0) q[96],q[41];
cp(0) q[96],q[42];
cp(0) q[96],q[43];
cp(0) q[96],q[44];
cp(0) q[96],q[45];
cp(0) q[96],q[46];
cp(0) q[96],q[47];
cp(0) q[96],q[48];
cp(0) q[96],q[49];
cp(0) q[96],q[50];
cp(0) q[96],q[51];
cp(0) q[96],q[52];
cp(0) q[96],q[53];
cp(0) q[96],q[54];
cp(-pi/2199023255552) q[96],q[55];
cp(-pi/1099511627776) q[96],q[56];
cp(-pi/549755813888) q[96],q[57];
cp(-pi/274877906944) q[96],q[58];
cp(-pi/137438953472) q[96],q[59];
cp(-pi/68719476736) q[96],q[60];
cp(-pi/34359738368) q[96],q[61];
cp(-pi/17179869184) q[96],q[62];
cp(-pi/8589934592) q[96],q[63];
cp(-pi/4294967296) q[96],q[64];
cp(-pi/2147483648) q[96],q[65];
cp(-pi/1073741824) q[96],q[66];
cp(-pi/536870912) q[96],q[67];
cp(-pi/268435456) q[96],q[68];
cp(-pi/134217728) q[96],q[69];
cp(-pi/67108864) q[96],q[70];
cp(-pi/33554432) q[96],q[71];
cp(-pi/16777216) q[96],q[72];
cp(-pi/8388608) q[96],q[73];
cp(-pi/4194304) q[96],q[74];
cp(-pi/2097152) q[96],q[75];
cp(-pi/1048576) q[96],q[76];
cp(-pi/524288) q[96],q[77];
cp(-pi/262144) q[96],q[78];
cp(-pi/131072) q[96],q[79];
cp(-pi/65536) q[96],q[80];
cp(-pi/32768) q[96],q[81];
cp(-pi/16384) q[96],q[82];
cp(-pi/8192) q[96],q[83];
cp(-pi/4096) q[96],q[84];
cp(-pi/2048) q[96],q[85];
cp(-pi/1024) q[96],q[86];
cp(-pi/512) q[96],q[87];
cp(-pi/256) q[96],q[88];
cp(-pi/128) q[96],q[89];
cp(-pi/64) q[96],q[90];
cp(-pi/32) q[96],q[91];
cp(-pi/16) q[96],q[92];
cp(-pi/8) q[96],q[93];
cp(-pi/4) q[96],q[94];
cp(-pi/2) q[96],q[95];
h q[96];
cp(0) q[97],q[0];
cp(0) q[97],q[1];
cp(0) q[97],q[2];
cp(0) q[97],q[3];
cp(0) q[97],q[4];
cp(0) q[97],q[5];
cp(0) q[97],q[6];
cp(0) q[97],q[7];
cp(0) q[97],q[8];
cp(0) q[97],q[9];
cp(0) q[97],q[10];
cp(0) q[97],q[11];
cp(0) q[97],q[12];
cp(0) q[97],q[13];
cp(0) q[97],q[14];
cp(0) q[97],q[15];
cp(0) q[97],q[16];
cp(0) q[97],q[17];
cp(0) q[97],q[18];
cp(0) q[97],q[19];
cp(0) q[97],q[20];
cp(0) q[97],q[21];
cp(0) q[97],q[22];
cp(0) q[97],q[23];
cp(0) q[97],q[24];
cp(0) q[97],q[25];
cp(0) q[97],q[26];
cp(0) q[97],q[27];
cp(0) q[97],q[28];
cp(0) q[97],q[29];
cp(0) q[97],q[30];
cp(0) q[97],q[31];
cp(0) q[97],q[32];
cp(0) q[97],q[33];
cp(0) q[97],q[34];
cp(0) q[97],q[35];
cp(0) q[97],q[36];
cp(0) q[97],q[37];
cp(0) q[97],q[38];
cp(0) q[97],q[39];
cp(0) q[97],q[40];
cp(0) q[97],q[41];
cp(0) q[97],q[42];
cp(0) q[97],q[43];
cp(0) q[97],q[44];
cp(0) q[97],q[45];
cp(0) q[97],q[46];
cp(0) q[97],q[47];
cp(0) q[97],q[48];
cp(0) q[97],q[49];
cp(0) q[97],q[50];
cp(0) q[97],q[51];
cp(0) q[97],q[52];
cp(0) q[97],q[53];
cp(0) q[97],q[54];
cp(0) q[97],q[55];
cp(-pi/2199023255552) q[97],q[56];
cp(-pi/1099511627776) q[97],q[57];
cp(-pi/549755813888) q[97],q[58];
cp(-pi/274877906944) q[97],q[59];
cp(-pi/137438953472) q[97],q[60];
cp(-pi/68719476736) q[97],q[61];
cp(-pi/34359738368) q[97],q[62];
cp(-pi/17179869184) q[97],q[63];
cp(-pi/8589934592) q[97],q[64];
cp(-pi/4294967296) q[97],q[65];
cp(-pi/2147483648) q[97],q[66];
cp(-pi/1073741824) q[97],q[67];
cp(-pi/536870912) q[97],q[68];
cp(-pi/268435456) q[97],q[69];
cp(-pi/134217728) q[97],q[70];
cp(-pi/67108864) q[97],q[71];
cp(-pi/33554432) q[97],q[72];
cp(-pi/16777216) q[97],q[73];
cp(-pi/8388608) q[97],q[74];
cp(-pi/4194304) q[97],q[75];
cp(-pi/2097152) q[97],q[76];
cp(-pi/1048576) q[97],q[77];
cp(-pi/524288) q[97],q[78];
cp(-pi/262144) q[97],q[79];
cp(-pi/131072) q[97],q[80];
cp(-pi/65536) q[97],q[81];
cp(-pi/32768) q[97],q[82];
cp(-pi/16384) q[97],q[83];
cp(-pi/8192) q[97],q[84];
cp(-pi/4096) q[97],q[85];
cp(-pi/2048) q[97],q[86];
cp(-pi/1024) q[97],q[87];
cp(-pi/512) q[97],q[88];
cp(-pi/256) q[97],q[89];
cp(-pi/128) q[97],q[90];
cp(-pi/64) q[97],q[91];
cp(-pi/32) q[97],q[92];
cp(-pi/16) q[97],q[93];
cp(-pi/8) q[97],q[94];
cp(-pi/4) q[97],q[95];
cp(-pi/2) q[97],q[96];
h q[97];
cp(0) q[98],q[0];
cp(0) q[98],q[1];
cp(0) q[98],q[2];
cp(0) q[98],q[3];
cp(0) q[98],q[4];
cp(0) q[98],q[5];
cp(0) q[98],q[6];
cp(0) q[98],q[7];
cp(0) q[98],q[8];
cp(0) q[98],q[9];
cp(0) q[98],q[10];
cp(0) q[98],q[11];
cp(0) q[98],q[12];
cp(0) q[98],q[13];
cp(0) q[98],q[14];
cp(0) q[98],q[15];
cp(0) q[98],q[16];
cp(0) q[98],q[17];
cp(0) q[98],q[18];
cp(0) q[98],q[19];
cp(0) q[98],q[20];
cp(0) q[98],q[21];
cp(0) q[98],q[22];
cp(0) q[98],q[23];
cp(0) q[98],q[24];
cp(0) q[98],q[25];
cp(0) q[98],q[26];
cp(0) q[98],q[27];
cp(0) q[98],q[28];
cp(0) q[98],q[29];
cp(0) q[98],q[30];
cp(0) q[98],q[31];
cp(0) q[98],q[32];
cp(0) q[98],q[33];
cp(0) q[98],q[34];
cp(0) q[98],q[35];
cp(0) q[98],q[36];
cp(0) q[98],q[37];
cp(0) q[98],q[38];
cp(0) q[98],q[39];
cp(0) q[98],q[40];
cp(0) q[98],q[41];
cp(0) q[98],q[42];
cp(0) q[98],q[43];
cp(0) q[98],q[44];
cp(0) q[98],q[45];
cp(0) q[98],q[46];
cp(0) q[98],q[47];
cp(0) q[98],q[48];
cp(0) q[98],q[49];
cp(0) q[98],q[50];
cp(0) q[98],q[51];
cp(0) q[98],q[52];
cp(0) q[98],q[53];
cp(0) q[98],q[54];
cp(0) q[98],q[55];
cp(0) q[98],q[56];
cp(-pi/2199023255552) q[98],q[57];
cp(-pi/1099511627776) q[98],q[58];
cp(-pi/549755813888) q[98],q[59];
cp(-pi/274877906944) q[98],q[60];
cp(-pi/137438953472) q[98],q[61];
cp(-pi/68719476736) q[98],q[62];
cp(-pi/34359738368) q[98],q[63];
cp(-pi/17179869184) q[98],q[64];
cp(-pi/8589934592) q[98],q[65];
cp(-pi/4294967296) q[98],q[66];
cp(-pi/2147483648) q[98],q[67];
cp(-pi/1073741824) q[98],q[68];
cp(-pi/536870912) q[98],q[69];
cp(-pi/268435456) q[98],q[70];
cp(-pi/134217728) q[98],q[71];
cp(-pi/67108864) q[98],q[72];
cp(-pi/33554432) q[98],q[73];
cp(-pi/16777216) q[98],q[74];
cp(-pi/8388608) q[98],q[75];
cp(-pi/4194304) q[98],q[76];
cp(-pi/2097152) q[98],q[77];
cp(-pi/1048576) q[98],q[78];
cp(-pi/524288) q[98],q[79];
cp(-pi/262144) q[98],q[80];
cp(-pi/131072) q[98],q[81];
cp(-pi/65536) q[98],q[82];
cp(-pi/32768) q[98],q[83];
cp(-pi/16384) q[98],q[84];
cp(-pi/8192) q[98],q[85];
cp(-pi/4096) q[98],q[86];
cp(-pi/2048) q[98],q[87];
cp(-pi/1024) q[98],q[88];
cp(-pi/512) q[98],q[89];
cp(-pi/256) q[98],q[90];
cp(-pi/128) q[98],q[91];
cp(-pi/64) q[98],q[92];
cp(-pi/32) q[98],q[93];
cp(-pi/16) q[98],q[94];
cp(-pi/8) q[98],q[95];
cp(-pi/4) q[98],q[96];
cp(-pi/2) q[98],q[97];
h q[98];
cp(0) q[99],q[0];
cp(0) q[99],q[1];
cp(0) q[99],q[2];
cp(0) q[99],q[3];
cp(0) q[99],q[4];
cp(0) q[99],q[5];
cp(0) q[99],q[6];
cp(0) q[99],q[7];
cp(0) q[99],q[8];
cp(0) q[99],q[9];
cp(0) q[99],q[10];
cp(0) q[99],q[11];
cp(0) q[99],q[12];
cp(0) q[99],q[13];
cp(0) q[99],q[14];
cp(0) q[99],q[15];
cp(0) q[99],q[16];
cp(0) q[99],q[17];
cp(0) q[99],q[18];
cp(0) q[99],q[19];
cp(0) q[99],q[20];
cp(0) q[99],q[21];
cp(0) q[99],q[22];
cp(0) q[99],q[23];
cp(0) q[99],q[24];
cp(0) q[99],q[25];
cp(0) q[99],q[26];
cp(0) q[99],q[27];
cp(0) q[99],q[28];
cp(0) q[99],q[29];
cp(0) q[99],q[30];
cp(0) q[99],q[31];
cp(0) q[99],q[32];
cp(0) q[99],q[33];
cp(0) q[99],q[34];
cp(0) q[99],q[35];
cp(0) q[99],q[36];
cp(0) q[99],q[37];
cp(0) q[99],q[38];
cp(0) q[99],q[39];
cp(0) q[99],q[40];
cp(0) q[99],q[41];
cp(0) q[99],q[42];
cp(0) q[99],q[43];
cp(0) q[99],q[44];
cp(0) q[99],q[45];
cp(0) q[99],q[46];
cp(0) q[99],q[47];
cp(0) q[99],q[48];
cp(0) q[99],q[49];
cp(0) q[99],q[50];
cp(0) q[99],q[51];
cp(0) q[99],q[52];
cp(0) q[99],q[53];
cp(0) q[99],q[54];
cp(0) q[99],q[55];
cp(0) q[99],q[56];
cp(0) q[99],q[57];
cp(-pi/2199023255552) q[99],q[58];
cp(-pi/1099511627776) q[99],q[59];
cp(-pi/549755813888) q[99],q[60];
cp(-pi/274877906944) q[99],q[61];
cp(-pi/137438953472) q[99],q[62];
cp(-pi/68719476736) q[99],q[63];
cp(-pi/34359738368) q[99],q[64];
cp(-pi/17179869184) q[99],q[65];
cp(-pi/8589934592) q[99],q[66];
cp(-pi/4294967296) q[99],q[67];
cp(-pi/2147483648) q[99],q[68];
cp(-pi/1073741824) q[99],q[69];
cp(-pi/536870912) q[99],q[70];
cp(-pi/268435456) q[99],q[71];
cp(-pi/134217728) q[99],q[72];
cp(-pi/67108864) q[99],q[73];
cp(-pi/33554432) q[99],q[74];
cp(-pi/16777216) q[99],q[75];
cp(-pi/8388608) q[99],q[76];
cp(-pi/4194304) q[99],q[77];
cp(-pi/2097152) q[99],q[78];
cp(-pi/1048576) q[99],q[79];
cp(-pi/524288) q[99],q[80];
cp(-pi/262144) q[99],q[81];
cp(-pi/131072) q[99],q[82];
cp(-pi/65536) q[99],q[83];
cp(-pi/32768) q[99],q[84];
cp(-pi/16384) q[99],q[85];
cp(-pi/8192) q[99],q[86];
cp(-pi/4096) q[99],q[87];
cp(-pi/2048) q[99],q[88];
cp(-pi/1024) q[99],q[89];
cp(-pi/512) q[99],q[90];
cp(-pi/256) q[99],q[91];
cp(-pi/128) q[99],q[92];
cp(-pi/64) q[99],q[93];
cp(-pi/32) q[99],q[94];
cp(-pi/16) q[99],q[95];
cp(-pi/8) q[99],q[96];
cp(-pi/4) q[99],q[97];
cp(-pi/2) q[99],q[98];
h q[99];
cp(0) q[100],q[0];
cp(0) q[100],q[1];
cp(0) q[100],q[2];
cp(0) q[100],q[3];
cp(0) q[100],q[4];
cp(0) q[100],q[5];
cp(0) q[100],q[6];
cp(0) q[100],q[7];
cp(0) q[100],q[8];
cp(0) q[100],q[9];
cp(0) q[100],q[10];
cp(0) q[100],q[11];
cp(0) q[100],q[12];
cp(0) q[100],q[13];
cp(0) q[100],q[14];
cp(0) q[100],q[15];
cp(0) q[100],q[16];
cp(0) q[100],q[17];
cp(0) q[100],q[18];
cp(0) q[100],q[19];
cp(0) q[100],q[20];
cp(0) q[100],q[21];
cp(0) q[100],q[22];
cp(0) q[100],q[23];
cp(0) q[100],q[24];
cp(0) q[100],q[25];
cp(0) q[100],q[26];
cp(0) q[100],q[27];
cp(0) q[100],q[28];
cp(0) q[100],q[29];
cp(0) q[100],q[30];
cp(0) q[100],q[31];
cp(0) q[100],q[32];
cp(0) q[100],q[33];
cp(0) q[100],q[34];
cp(0) q[100],q[35];
cp(0) q[100],q[36];
cp(0) q[100],q[37];
cp(0) q[100],q[38];
cp(0) q[100],q[39];
cp(0) q[100],q[40];
cp(0) q[100],q[41];
cp(0) q[100],q[42];
cp(0) q[100],q[43];
cp(0) q[100],q[44];
cp(0) q[100],q[45];
cp(0) q[100],q[46];
cp(0) q[100],q[47];
cp(0) q[100],q[48];
cp(0) q[100],q[49];
cp(0) q[100],q[50];
cp(0) q[100],q[51];
cp(0) q[100],q[52];
cp(0) q[100],q[53];
cp(0) q[100],q[54];
cp(0) q[100],q[55];
cp(0) q[100],q[56];
cp(0) q[100],q[57];
cp(0) q[100],q[58];
cp(-pi/2199023255552) q[100],q[59];
cp(-pi/1099511627776) q[100],q[60];
cp(-pi/549755813888) q[100],q[61];
cp(-pi/274877906944) q[100],q[62];
cp(-pi/137438953472) q[100],q[63];
cp(-pi/68719476736) q[100],q[64];
cp(-pi/34359738368) q[100],q[65];
cp(-pi/17179869184) q[100],q[66];
cp(-pi/8589934592) q[100],q[67];
cp(-pi/4294967296) q[100],q[68];
cp(-pi/2147483648) q[100],q[69];
cp(-pi/1073741824) q[100],q[70];
cp(-pi/536870912) q[100],q[71];
cp(-pi/268435456) q[100],q[72];
cp(-pi/134217728) q[100],q[73];
cp(-pi/67108864) q[100],q[74];
cp(-pi/33554432) q[100],q[75];
cp(-pi/16777216) q[100],q[76];
cp(-pi/8388608) q[100],q[77];
cp(-pi/4194304) q[100],q[78];
cp(-pi/2097152) q[100],q[79];
cp(-pi/1048576) q[100],q[80];
cp(-pi/524288) q[100],q[81];
cp(-pi/262144) q[100],q[82];
cp(-pi/131072) q[100],q[83];
cp(-pi/65536) q[100],q[84];
cp(-pi/32768) q[100],q[85];
cp(-pi/16384) q[100],q[86];
cp(-pi/8192) q[100],q[87];
cp(-pi/4096) q[100],q[88];
cp(-pi/2048) q[100],q[89];
cp(-pi/1024) q[100],q[90];
cp(-pi/512) q[100],q[91];
cp(-pi/256) q[100],q[92];
cp(-pi/128) q[100],q[93];
cp(-pi/64) q[100],q[94];
cp(-pi/32) q[100],q[95];
cp(-pi/16) q[100],q[96];
cp(-pi/8) q[100],q[97];
cp(-pi/4) q[100],q[98];
cp(-pi/2) q[100],q[99];
h q[100];
cp(0) q[101],q[0];
cp(0) q[101],q[1];
cp(0) q[101],q[2];
cp(0) q[101],q[3];
cp(0) q[101],q[4];
cp(0) q[101],q[5];
cp(0) q[101],q[6];
cp(0) q[101],q[7];
cp(0) q[101],q[8];
cp(0) q[101],q[9];
cp(0) q[101],q[10];
cp(0) q[101],q[11];
cp(0) q[101],q[12];
cp(0) q[101],q[13];
cp(0) q[101],q[14];
cp(0) q[101],q[15];
cp(0) q[101],q[16];
cp(0) q[101],q[17];
cp(0) q[101],q[18];
cp(0) q[101],q[19];
cp(0) q[101],q[20];
cp(0) q[101],q[21];
cp(0) q[101],q[22];
cp(0) q[101],q[23];
cp(0) q[101],q[24];
cp(0) q[101],q[25];
cp(0) q[101],q[26];
cp(0) q[101],q[27];
cp(0) q[101],q[28];
cp(0) q[101],q[29];
cp(0) q[101],q[30];
cp(0) q[101],q[31];
cp(0) q[101],q[32];
cp(0) q[101],q[33];
cp(0) q[101],q[34];
cp(0) q[101],q[35];
cp(0) q[101],q[36];
cp(0) q[101],q[37];
cp(0) q[101],q[38];
cp(0) q[101],q[39];
cp(0) q[101],q[40];
cp(0) q[101],q[41];
cp(0) q[101],q[42];
cp(0) q[101],q[43];
cp(0) q[101],q[44];
cp(0) q[101],q[45];
cp(0) q[101],q[46];
cp(0) q[101],q[47];
cp(0) q[101],q[48];
cp(0) q[101],q[49];
cp(0) q[101],q[50];
cp(0) q[101],q[51];
cp(0) q[101],q[52];
cp(0) q[101],q[53];
cp(0) q[101],q[54];
cp(0) q[101],q[55];
cp(0) q[101],q[56];
cp(0) q[101],q[57];
cp(0) q[101],q[58];
cp(0) q[101],q[59];
cp(-pi/2199023255552) q[101],q[60];
cp(-pi/1099511627776) q[101],q[61];
cp(-pi/549755813888) q[101],q[62];
cp(-pi/274877906944) q[101],q[63];
cp(-pi/137438953472) q[101],q[64];
cp(-pi/68719476736) q[101],q[65];
cp(-pi/34359738368) q[101],q[66];
cp(-pi/17179869184) q[101],q[67];
cp(-pi/8589934592) q[101],q[68];
cp(-pi/4294967296) q[101],q[69];
cp(-pi/2147483648) q[101],q[70];
cp(-pi/1073741824) q[101],q[71];
cp(-pi/536870912) q[101],q[72];
cp(-pi/268435456) q[101],q[73];
cp(-pi/134217728) q[101],q[74];
cp(-pi/67108864) q[101],q[75];
cp(-pi/33554432) q[101],q[76];
cp(-pi/16777216) q[101],q[77];
cp(-pi/8388608) q[101],q[78];
cp(-pi/4194304) q[101],q[79];
cp(-pi/2097152) q[101],q[80];
cp(-pi/1048576) q[101],q[81];
cp(-pi/524288) q[101],q[82];
cp(-pi/262144) q[101],q[83];
cp(-pi/131072) q[101],q[84];
cp(-pi/65536) q[101],q[85];
cp(-pi/32768) q[101],q[86];
cp(-pi/16384) q[101],q[87];
cp(-pi/8192) q[101],q[88];
cp(-pi/4096) q[101],q[89];
cp(-pi/2048) q[101],q[90];
cp(-pi/1024) q[101],q[91];
cp(-pi/512) q[101],q[92];
cp(-pi/256) q[101],q[93];
cp(-pi/128) q[101],q[94];
cp(-pi/64) q[101],q[95];
cp(-pi/32) q[101],q[96];
cp(-pi/16) q[101],q[97];
cp(-pi/8) q[101],q[98];
cp(-pi/4) q[101],q[99];
cp(-pi/2) q[101],q[100];
h q[101];
cp(0) q[102],q[0];
cp(0) q[102],q[1];
cp(0) q[102],q[2];
cp(0) q[102],q[3];
cp(0) q[102],q[4];
cp(0) q[102],q[5];
cp(0) q[102],q[6];
cp(0) q[102],q[7];
cp(0) q[102],q[8];
cp(0) q[102],q[9];
cp(0) q[102],q[10];
cp(0) q[102],q[11];
cp(0) q[102],q[12];
cp(0) q[102],q[13];
cp(0) q[102],q[14];
cp(0) q[102],q[15];
cp(0) q[102],q[16];
cp(0) q[102],q[17];
cp(0) q[102],q[18];
cp(0) q[102],q[19];
cp(0) q[102],q[20];
cp(0) q[102],q[21];
cp(0) q[102],q[22];
cp(0) q[102],q[23];
cp(0) q[102],q[24];
cp(0) q[102],q[25];
cp(0) q[102],q[26];
cp(0) q[102],q[27];
cp(0) q[102],q[28];
cp(0) q[102],q[29];
cp(0) q[102],q[30];
cp(0) q[102],q[31];
cp(0) q[102],q[32];
cp(0) q[102],q[33];
cp(0) q[102],q[34];
cp(0) q[102],q[35];
cp(0) q[102],q[36];
cp(0) q[102],q[37];
cp(0) q[102],q[38];
cp(0) q[102],q[39];
cp(0) q[102],q[40];
cp(0) q[102],q[41];
cp(0) q[102],q[42];
cp(0) q[102],q[43];
cp(0) q[102],q[44];
cp(0) q[102],q[45];
cp(0) q[102],q[46];
cp(0) q[102],q[47];
cp(0) q[102],q[48];
cp(0) q[102],q[49];
cp(0) q[102],q[50];
cp(0) q[102],q[51];
cp(0) q[102],q[52];
cp(0) q[102],q[53];
cp(0) q[102],q[54];
cp(0) q[102],q[55];
cp(0) q[102],q[56];
cp(0) q[102],q[57];
cp(0) q[102],q[58];
cp(0) q[102],q[59];
cp(0) q[102],q[60];
cp(-pi/2199023255552) q[102],q[61];
cp(-pi/1099511627776) q[102],q[62];
cp(-pi/549755813888) q[102],q[63];
cp(-pi/274877906944) q[102],q[64];
cp(-pi/137438953472) q[102],q[65];
cp(-pi/68719476736) q[102],q[66];
cp(-pi/34359738368) q[102],q[67];
cp(-pi/17179869184) q[102],q[68];
cp(-pi/8589934592) q[102],q[69];
cp(-pi/4294967296) q[102],q[70];
cp(-pi/2147483648) q[102],q[71];
cp(-pi/1073741824) q[102],q[72];
cp(-pi/536870912) q[102],q[73];
cp(-pi/268435456) q[102],q[74];
cp(-pi/134217728) q[102],q[75];
cp(-pi/67108864) q[102],q[76];
cp(-pi/33554432) q[102],q[77];
cp(-pi/16777216) q[102],q[78];
cp(-pi/8388608) q[102],q[79];
cp(-pi/4194304) q[102],q[80];
cp(-pi/2097152) q[102],q[81];
cp(-pi/1048576) q[102],q[82];
cp(-pi/524288) q[102],q[83];
cp(-pi/262144) q[102],q[84];
cp(-pi/131072) q[102],q[85];
cp(-pi/65536) q[102],q[86];
cp(-pi/32768) q[102],q[87];
cp(-pi/16384) q[102],q[88];
cp(-pi/8192) q[102],q[89];
cp(-pi/4096) q[102],q[90];
cp(-pi/2048) q[102],q[91];
cp(-pi/1024) q[102],q[92];
cp(-pi/512) q[102],q[93];
cp(-pi/256) q[102],q[94];
cp(-pi/128) q[102],q[95];
cp(-pi/64) q[102],q[96];
cp(-pi/32) q[102],q[97];
cp(-pi/16) q[102],q[98];
cp(-pi/8) q[102],q[99];
cp(-pi/4) q[102],q[100];
cp(-pi/2) q[102],q[101];
h q[102];
cp(0) q[103],q[0];
cp(0) q[103],q[1];
cp(0) q[103],q[2];
cp(0) q[103],q[3];
cp(0) q[103],q[4];
cp(0) q[103],q[5];
cp(0) q[103],q[6];
cp(0) q[103],q[7];
cp(0) q[103],q[8];
cp(0) q[103],q[9];
cp(0) q[103],q[10];
cp(0) q[103],q[11];
cp(0) q[103],q[12];
cp(0) q[103],q[13];
cp(0) q[103],q[14];
cp(0) q[103],q[15];
cp(0) q[103],q[16];
cp(0) q[103],q[17];
cp(0) q[103],q[18];
cp(0) q[103],q[19];
cp(0) q[103],q[20];
cp(0) q[103],q[21];
cp(0) q[103],q[22];
cp(0) q[103],q[23];
cp(0) q[103],q[24];
cp(0) q[103],q[25];
cp(0) q[103],q[26];
cp(0) q[103],q[27];
cp(0) q[103],q[28];
cp(0) q[103],q[29];
cp(0) q[103],q[30];
cp(0) q[103],q[31];
cp(0) q[103],q[32];
cp(0) q[103],q[33];
cp(0) q[103],q[34];
cp(0) q[103],q[35];
cp(0) q[103],q[36];
cp(0) q[103],q[37];
cp(0) q[103],q[38];
cp(0) q[103],q[39];
cp(0) q[103],q[40];
cp(0) q[103],q[41];
cp(0) q[103],q[42];
cp(0) q[103],q[43];
cp(0) q[103],q[44];
cp(0) q[103],q[45];
cp(0) q[103],q[46];
cp(0) q[103],q[47];
cp(0) q[103],q[48];
cp(0) q[103],q[49];
cp(0) q[103],q[50];
cp(0) q[103],q[51];
cp(0) q[103],q[52];
cp(0) q[103],q[53];
cp(0) q[103],q[54];
cp(0) q[103],q[55];
cp(0) q[103],q[56];
cp(0) q[103],q[57];
cp(0) q[103],q[58];
cp(0) q[103],q[59];
cp(0) q[103],q[60];
cp(0) q[103],q[61];
cp(-pi/2199023255552) q[103],q[62];
cp(-pi/1099511627776) q[103],q[63];
cp(-pi/549755813888) q[103],q[64];
cp(-pi/274877906944) q[103],q[65];
cp(-pi/137438953472) q[103],q[66];
cp(-pi/68719476736) q[103],q[67];
cp(-pi/34359738368) q[103],q[68];
cp(-pi/17179869184) q[103],q[69];
cp(-pi/8589934592) q[103],q[70];
cp(-pi/4294967296) q[103],q[71];
cp(-pi/2147483648) q[103],q[72];
cp(-pi/1073741824) q[103],q[73];
cp(-pi/536870912) q[103],q[74];
cp(-pi/268435456) q[103],q[75];
cp(-pi/134217728) q[103],q[76];
cp(-pi/67108864) q[103],q[77];
cp(-pi/33554432) q[103],q[78];
cp(-pi/16777216) q[103],q[79];
cp(-pi/8388608) q[103],q[80];
cp(-pi/4194304) q[103],q[81];
cp(-pi/2097152) q[103],q[82];
cp(-pi/1048576) q[103],q[83];
cp(-pi/524288) q[103],q[84];
cp(-pi/262144) q[103],q[85];
cp(-pi/131072) q[103],q[86];
cp(-pi/65536) q[103],q[87];
cp(-pi/32768) q[103],q[88];
cp(-pi/16384) q[103],q[89];
cp(-pi/8192) q[103],q[90];
cp(-pi/4096) q[103],q[91];
cp(-pi/2048) q[103],q[92];
cp(-pi/1024) q[103],q[93];
cp(-pi/512) q[103],q[94];
cp(-pi/256) q[103],q[95];
cp(-pi/128) q[103],q[96];
cp(-pi/64) q[103],q[97];
cp(-pi/32) q[103],q[98];
cp(-pi/16) q[103],q[99];
cp(-pi/8) q[103],q[100];
cp(-pi/4) q[103],q[101];
cp(-pi/2) q[103],q[102];
h q[103];
cp(0) q[104],q[0];
cp(0) q[104],q[1];
cp(0) q[104],q[2];
cp(0) q[104],q[3];
cp(0) q[104],q[4];
cp(0) q[104],q[5];
cp(0) q[104],q[6];
cp(0) q[104],q[7];
cp(0) q[104],q[8];
cp(0) q[104],q[9];
cp(0) q[104],q[10];
cp(0) q[104],q[11];
cp(0) q[104],q[12];
cp(0) q[104],q[13];
cp(0) q[104],q[14];
cp(0) q[104],q[15];
cp(0) q[104],q[16];
cp(0) q[104],q[17];
cp(0) q[104],q[18];
cp(0) q[104],q[19];
cp(0) q[104],q[20];
cp(0) q[104],q[21];
cp(0) q[104],q[22];
cp(0) q[104],q[23];
cp(0) q[104],q[24];
cp(0) q[104],q[25];
cp(0) q[104],q[26];
cp(0) q[104],q[27];
cp(0) q[104],q[28];
cp(0) q[104],q[29];
cp(0) q[104],q[30];
cp(0) q[104],q[31];
cp(0) q[104],q[32];
cp(0) q[104],q[33];
cp(0) q[104],q[34];
cp(0) q[104],q[35];
cp(0) q[104],q[36];
cp(0) q[104],q[37];
cp(0) q[104],q[38];
cp(0) q[104],q[39];
cp(0) q[104],q[40];
cp(0) q[104],q[41];
cp(0) q[104],q[42];
cp(0) q[104],q[43];
cp(0) q[104],q[44];
cp(0) q[104],q[45];
cp(0) q[104],q[46];
cp(0) q[104],q[47];
cp(0) q[104],q[48];
cp(0) q[104],q[49];
cp(0) q[104],q[50];
cp(0) q[104],q[51];
cp(0) q[104],q[52];
cp(0) q[104],q[53];
cp(0) q[104],q[54];
cp(0) q[104],q[55];
cp(0) q[104],q[56];
cp(0) q[104],q[57];
cp(0) q[104],q[58];
cp(0) q[104],q[59];
cp(0) q[104],q[60];
cp(0) q[104],q[61];
cp(0) q[104],q[62];
cp(-pi/2199023255552) q[104],q[63];
cp(-pi/1099511627776) q[104],q[64];
cp(-pi/549755813888) q[104],q[65];
cp(-pi/274877906944) q[104],q[66];
cp(-pi/137438953472) q[104],q[67];
cp(-pi/68719476736) q[104],q[68];
cp(-pi/34359738368) q[104],q[69];
cp(-pi/17179869184) q[104],q[70];
cp(-pi/8589934592) q[104],q[71];
cp(-pi/4294967296) q[104],q[72];
cp(-pi/2147483648) q[104],q[73];
cp(-pi/1073741824) q[104],q[74];
cp(-pi/536870912) q[104],q[75];
cp(-pi/268435456) q[104],q[76];
cp(-pi/134217728) q[104],q[77];
cp(-pi/67108864) q[104],q[78];
cp(-pi/33554432) q[104],q[79];
cp(-pi/16777216) q[104],q[80];
cp(-pi/8388608) q[104],q[81];
cp(-pi/4194304) q[104],q[82];
cp(-pi/2097152) q[104],q[83];
cp(-pi/1048576) q[104],q[84];
cp(-pi/524288) q[104],q[85];
cp(-pi/262144) q[104],q[86];
cp(-pi/131072) q[104],q[87];
cp(-pi/65536) q[104],q[88];
cp(-pi/32768) q[104],q[89];
cp(-pi/16384) q[104],q[90];
cp(-pi/8192) q[104],q[91];
cp(-pi/4096) q[104],q[92];
cp(-pi/2048) q[104],q[93];
cp(-pi/1024) q[104],q[94];
cp(-pi/512) q[104],q[95];
cp(-pi/256) q[104],q[96];
cp(-pi/128) q[104],q[97];
cp(-pi/64) q[104],q[98];
cp(-pi/32) q[104],q[99];
cp(-pi/16) q[104],q[100];
cp(-pi/8) q[104],q[101];
cp(-pi/4) q[104],q[102];
cp(-pi/2) q[104],q[103];
h q[104];
cp(0) q[105],q[0];
cp(0) q[105],q[1];
cp(0) q[105],q[2];
cp(0) q[105],q[3];
cp(0) q[105],q[4];
cp(0) q[105],q[5];
cp(0) q[105],q[6];
cp(0) q[105],q[7];
cp(0) q[105],q[8];
cp(0) q[105],q[9];
cp(0) q[105],q[10];
cp(0) q[105],q[11];
cp(0) q[105],q[12];
cp(0) q[105],q[13];
cp(0) q[105],q[14];
cp(0) q[105],q[15];
cp(0) q[105],q[16];
cp(0) q[105],q[17];
cp(0) q[105],q[18];
cp(0) q[105],q[19];
cp(0) q[105],q[20];
cp(0) q[105],q[21];
cp(0) q[105],q[22];
cp(0) q[105],q[23];
cp(0) q[105],q[24];
cp(0) q[105],q[25];
cp(0) q[105],q[26];
cp(0) q[105],q[27];
cp(0) q[105],q[28];
cp(0) q[105],q[29];
cp(0) q[105],q[30];
cp(0) q[105],q[31];
cp(0) q[105],q[32];
cp(0) q[105],q[33];
cp(0) q[105],q[34];
cp(0) q[105],q[35];
cp(0) q[105],q[36];
cp(0) q[105],q[37];
cp(0) q[105],q[38];
cp(0) q[105],q[39];
cp(0) q[105],q[40];
cp(0) q[105],q[41];
cp(0) q[105],q[42];
cp(0) q[105],q[43];
cp(0) q[105],q[44];
cp(0) q[105],q[45];
cp(0) q[105],q[46];
cp(0) q[105],q[47];
cp(0) q[105],q[48];
cp(0) q[105],q[49];
cp(0) q[105],q[50];
cp(0) q[105],q[51];
cp(0) q[105],q[52];
cp(0) q[105],q[53];
cp(0) q[105],q[54];
cp(0) q[105],q[55];
cp(0) q[105],q[56];
cp(0) q[105],q[57];
cp(0) q[105],q[58];
cp(0) q[105],q[59];
cp(0) q[105],q[60];
cp(0) q[105],q[61];
cp(0) q[105],q[62];
cp(0) q[105],q[63];
cp(-pi/2199023255552) q[105],q[64];
cp(-pi/1099511627776) q[105],q[65];
cp(-pi/549755813888) q[105],q[66];
cp(-pi/274877906944) q[105],q[67];
cp(-pi/137438953472) q[105],q[68];
cp(-pi/68719476736) q[105],q[69];
cp(-pi/34359738368) q[105],q[70];
cp(-pi/17179869184) q[105],q[71];
cp(-pi/8589934592) q[105],q[72];
cp(-pi/4294967296) q[105],q[73];
cp(-pi/2147483648) q[105],q[74];
cp(-pi/1073741824) q[105],q[75];
cp(-pi/536870912) q[105],q[76];
cp(-pi/268435456) q[105],q[77];
cp(-pi/134217728) q[105],q[78];
cp(-pi/67108864) q[105],q[79];
cp(-pi/33554432) q[105],q[80];
cp(-pi/16777216) q[105],q[81];
cp(-pi/8388608) q[105],q[82];
cp(-pi/4194304) q[105],q[83];
cp(-pi/2097152) q[105],q[84];
cp(-pi/1048576) q[105],q[85];
cp(-pi/524288) q[105],q[86];
cp(-pi/262144) q[105],q[87];
cp(-pi/131072) q[105],q[88];
cp(-pi/65536) q[105],q[89];
cp(-pi/32768) q[105],q[90];
cp(-pi/16384) q[105],q[91];
cp(-pi/8192) q[105],q[92];
cp(-pi/4096) q[105],q[93];
cp(-pi/2048) q[105],q[94];
cp(-pi/1024) q[105],q[95];
cp(-pi/512) q[105],q[96];
cp(-pi/256) q[105],q[97];
cp(-pi/128) q[105],q[98];
cp(-pi/64) q[105],q[99];
cp(-pi/32) q[105],q[100];
cp(-pi/16) q[105],q[101];
cp(-pi/8) q[105],q[102];
cp(-pi/4) q[105],q[103];
cp(-pi/2) q[105],q[104];
h q[105];
cp(0) q[106],q[0];
cp(0) q[106],q[1];
cp(0) q[106],q[2];
cp(0) q[106],q[3];
cp(0) q[106],q[4];
cp(0) q[106],q[5];
cp(0) q[106],q[6];
cp(0) q[106],q[7];
cp(0) q[106],q[8];
cp(0) q[106],q[9];
cp(0) q[106],q[10];
cp(0) q[106],q[11];
cp(0) q[106],q[12];
cp(0) q[106],q[13];
cp(0) q[106],q[14];
cp(0) q[106],q[15];
cp(0) q[106],q[16];
cp(0) q[106],q[17];
cp(0) q[106],q[18];
cp(0) q[106],q[19];
cp(0) q[106],q[20];
cp(0) q[106],q[21];
cp(0) q[106],q[22];
cp(0) q[106],q[23];
cp(0) q[106],q[24];
cp(0) q[106],q[25];
cp(0) q[106],q[26];
cp(0) q[106],q[27];
cp(0) q[106],q[28];
cp(0) q[106],q[29];
cp(0) q[106],q[30];
cp(0) q[106],q[31];
cp(0) q[106],q[32];
cp(0) q[106],q[33];
cp(0) q[106],q[34];
cp(0) q[106],q[35];
cp(0) q[106],q[36];
cp(0) q[106],q[37];
cp(0) q[106],q[38];
cp(0) q[106],q[39];
cp(0) q[106],q[40];
cp(0) q[106],q[41];
cp(0) q[106],q[42];
cp(0) q[106],q[43];
cp(0) q[106],q[44];
cp(0) q[106],q[45];
cp(0) q[106],q[46];
cp(0) q[106],q[47];
cp(0) q[106],q[48];
cp(0) q[106],q[49];
cp(0) q[106],q[50];
cp(0) q[106],q[51];
cp(0) q[106],q[52];
cp(0) q[106],q[53];
cp(0) q[106],q[54];
cp(0) q[106],q[55];
cp(0) q[106],q[56];
cp(0) q[106],q[57];
cp(0) q[106],q[58];
cp(0) q[106],q[59];
cp(0) q[106],q[60];
cp(0) q[106],q[61];
cp(0) q[106],q[62];
cp(0) q[106],q[63];
cp(0) q[106],q[64];
cp(-pi/2199023255552) q[106],q[65];
cp(-pi/1099511627776) q[106],q[66];
cp(-pi/549755813888) q[106],q[67];
cp(-pi/274877906944) q[106],q[68];
cp(-pi/137438953472) q[106],q[69];
cp(-pi/68719476736) q[106],q[70];
cp(-pi/34359738368) q[106],q[71];
cp(-pi/17179869184) q[106],q[72];
cp(-pi/8589934592) q[106],q[73];
cp(-pi/4294967296) q[106],q[74];
cp(-pi/2147483648) q[106],q[75];
cp(-pi/1073741824) q[106],q[76];
cp(-pi/536870912) q[106],q[77];
cp(-pi/268435456) q[106],q[78];
cp(-pi/134217728) q[106],q[79];
cp(-pi/67108864) q[106],q[80];
cp(-pi/33554432) q[106],q[81];
cp(-pi/16777216) q[106],q[82];
cp(-pi/8388608) q[106],q[83];
cp(-pi/4194304) q[106],q[84];
cp(-pi/2097152) q[106],q[85];
cp(-pi/1048576) q[106],q[86];
cp(-pi/524288) q[106],q[87];
cp(-pi/262144) q[106],q[88];
cp(-pi/131072) q[106],q[89];
cp(-pi/65536) q[106],q[90];
cp(-pi/32768) q[106],q[91];
cp(-pi/16384) q[106],q[92];
cp(-pi/8192) q[106],q[93];
cp(-pi/4096) q[106],q[94];
cp(-pi/2048) q[106],q[95];
cp(-pi/1024) q[106],q[96];
cp(-pi/512) q[106],q[97];
cp(-pi/256) q[106],q[98];
cp(-pi/128) q[106],q[99];
cp(-pi/64) q[106],q[100];
cp(-pi/32) q[106],q[101];
cp(-pi/16) q[106],q[102];
cp(-pi/8) q[106],q[103];
cp(-pi/4) q[106],q[104];
cp(-pi/2) q[106],q[105];
h q[106];
cp(0) q[107],q[0];
cp(0) q[107],q[1];
cp(0) q[107],q[2];
cp(0) q[107],q[3];
cp(0) q[107],q[4];
cp(0) q[107],q[5];
cp(0) q[107],q[6];
cp(0) q[107],q[7];
cp(0) q[107],q[8];
cp(0) q[107],q[9];
cp(0) q[107],q[10];
cp(0) q[107],q[11];
cp(0) q[107],q[12];
cp(0) q[107],q[13];
cp(0) q[107],q[14];
cp(0) q[107],q[15];
cp(0) q[107],q[16];
cp(0) q[107],q[17];
cp(0) q[107],q[18];
cp(0) q[107],q[19];
cp(0) q[107],q[20];
cp(0) q[107],q[21];
cp(0) q[107],q[22];
cp(0) q[107],q[23];
cp(0) q[107],q[24];
cp(0) q[107],q[25];
cp(0) q[107],q[26];
cp(0) q[107],q[27];
cp(0) q[107],q[28];
cp(0) q[107],q[29];
cp(0) q[107],q[30];
cp(0) q[107],q[31];
cp(0) q[107],q[32];
cp(0) q[107],q[33];
cp(0) q[107],q[34];
cp(0) q[107],q[35];
cp(0) q[107],q[36];
cp(0) q[107],q[37];
cp(0) q[107],q[38];
cp(0) q[107],q[39];
cp(0) q[107],q[40];
cp(0) q[107],q[41];
cp(0) q[107],q[42];
cp(0) q[107],q[43];
cp(0) q[107],q[44];
cp(0) q[107],q[45];
cp(0) q[107],q[46];
cp(0) q[107],q[47];
cp(0) q[107],q[48];
cp(0) q[107],q[49];
cp(0) q[107],q[50];
cp(0) q[107],q[51];
cp(0) q[107],q[52];
cp(0) q[107],q[53];
cp(0) q[107],q[54];
cp(0) q[107],q[55];
cp(0) q[107],q[56];
cp(0) q[107],q[57];
cp(0) q[107],q[58];
cp(0) q[107],q[59];
cp(0) q[107],q[60];
cp(0) q[107],q[61];
cp(0) q[107],q[62];
cp(0) q[107],q[63];
cp(0) q[107],q[64];
cp(0) q[107],q[65];
cp(-pi/2199023255552) q[107],q[66];
cp(-pi/1099511627776) q[107],q[67];
cp(-pi/549755813888) q[107],q[68];
cp(-pi/274877906944) q[107],q[69];
cp(-pi/137438953472) q[107],q[70];
cp(-pi/68719476736) q[107],q[71];
cp(-pi/34359738368) q[107],q[72];
cp(-pi/17179869184) q[107],q[73];
cp(-pi/8589934592) q[107],q[74];
cp(-pi/4294967296) q[107],q[75];
cp(-pi/2147483648) q[107],q[76];
cp(-pi/1073741824) q[107],q[77];
cp(-pi/536870912) q[107],q[78];
cp(-pi/268435456) q[107],q[79];
cp(-pi/134217728) q[107],q[80];
cp(-pi/67108864) q[107],q[81];
cp(-pi/33554432) q[107],q[82];
cp(-pi/16777216) q[107],q[83];
cp(-pi/8388608) q[107],q[84];
cp(-pi/4194304) q[107],q[85];
cp(-pi/2097152) q[107],q[86];
cp(-pi/1048576) q[107],q[87];
cp(-pi/524288) q[107],q[88];
cp(-pi/262144) q[107],q[89];
cp(-pi/131072) q[107],q[90];
cp(-pi/65536) q[107],q[91];
cp(-pi/32768) q[107],q[92];
cp(-pi/16384) q[107],q[93];
cp(-pi/8192) q[107],q[94];
cp(-pi/4096) q[107],q[95];
cp(-pi/2048) q[107],q[96];
cp(-pi/1024) q[107],q[97];
cp(-pi/512) q[107],q[98];
cp(-pi/256) q[107],q[99];
cp(-pi/128) q[107],q[100];
cp(-pi/64) q[107],q[101];
cp(-pi/32) q[107],q[102];
cp(-pi/16) q[107],q[103];
cp(-pi/8) q[107],q[104];
cp(-pi/4) q[107],q[105];
cp(-pi/2) q[107],q[106];
h q[107];
cp(0) q[108],q[0];
cp(0) q[108],q[1];
cp(0) q[108],q[2];
cp(0) q[108],q[3];
cp(0) q[108],q[4];
cp(0) q[108],q[5];
cp(0) q[108],q[6];
cp(0) q[108],q[7];
cp(0) q[108],q[8];
cp(0) q[108],q[9];
cp(0) q[108],q[10];
cp(0) q[108],q[11];
cp(0) q[108],q[12];
cp(0) q[108],q[13];
cp(0) q[108],q[14];
cp(0) q[108],q[15];
cp(0) q[108],q[16];
cp(0) q[108],q[17];
cp(0) q[108],q[18];
cp(0) q[108],q[19];
cp(0) q[108],q[20];
cp(0) q[108],q[21];
cp(0) q[108],q[22];
cp(0) q[108],q[23];
cp(0) q[108],q[24];
cp(0) q[108],q[25];
cp(0) q[108],q[26];
cp(0) q[108],q[27];
cp(0) q[108],q[28];
cp(0) q[108],q[29];
cp(0) q[108],q[30];
cp(0) q[108],q[31];
cp(0) q[108],q[32];
cp(0) q[108],q[33];
cp(0) q[108],q[34];
cp(0) q[108],q[35];
cp(0) q[108],q[36];
cp(0) q[108],q[37];
cp(0) q[108],q[38];
cp(0) q[108],q[39];
cp(0) q[108],q[40];
cp(0) q[108],q[41];
cp(0) q[108],q[42];
cp(0) q[108],q[43];
cp(0) q[108],q[44];
cp(0) q[108],q[45];
cp(0) q[108],q[46];
cp(0) q[108],q[47];
cp(0) q[108],q[48];
cp(0) q[108],q[49];
cp(0) q[108],q[50];
cp(0) q[108],q[51];
cp(0) q[108],q[52];
cp(0) q[108],q[53];
cp(0) q[108],q[54];
cp(0) q[108],q[55];
cp(0) q[108],q[56];
cp(0) q[108],q[57];
cp(0) q[108],q[58];
cp(0) q[108],q[59];
cp(0) q[108],q[60];
cp(0) q[108],q[61];
cp(0) q[108],q[62];
cp(0) q[108],q[63];
cp(0) q[108],q[64];
cp(0) q[108],q[65];
cp(0) q[108],q[66];
cp(-pi/2199023255552) q[108],q[67];
cp(-pi/1099511627776) q[108],q[68];
cp(-pi/549755813888) q[108],q[69];
cp(-pi/274877906944) q[108],q[70];
cp(-pi/137438953472) q[108],q[71];
cp(-pi/68719476736) q[108],q[72];
cp(-pi/34359738368) q[108],q[73];
cp(-pi/17179869184) q[108],q[74];
cp(-pi/8589934592) q[108],q[75];
cp(-pi/4294967296) q[108],q[76];
cp(-pi/2147483648) q[108],q[77];
cp(-pi/1073741824) q[108],q[78];
cp(-pi/536870912) q[108],q[79];
cp(-pi/268435456) q[108],q[80];
cp(-pi/134217728) q[108],q[81];
cp(-pi/67108864) q[108],q[82];
cp(-pi/33554432) q[108],q[83];
cp(-pi/16777216) q[108],q[84];
cp(-pi/8388608) q[108],q[85];
cp(-pi/4194304) q[108],q[86];
cp(-pi/2097152) q[108],q[87];
cp(-pi/1048576) q[108],q[88];
cp(-pi/524288) q[108],q[89];
cp(-pi/262144) q[108],q[90];
cp(-pi/131072) q[108],q[91];
cp(-pi/65536) q[108],q[92];
cp(-pi/32768) q[108],q[93];
cp(-pi/16384) q[108],q[94];
cp(-pi/8192) q[108],q[95];
cp(-pi/4096) q[108],q[96];
cp(-pi/2048) q[108],q[97];
cp(-pi/1024) q[108],q[98];
cp(-pi/512) q[108],q[99];
cp(-pi/256) q[108],q[100];
cp(-pi/128) q[108],q[101];
cp(-pi/64) q[108],q[102];
cp(-pi/32) q[108],q[103];
cp(-pi/16) q[108],q[104];
cp(-pi/8) q[108],q[105];
cp(-pi/4) q[108],q[106];
cp(-pi/2) q[108],q[107];
h q[108];
cp(0) q[109],q[0];
cp(0) q[109],q[1];
cp(0) q[109],q[2];
cp(0) q[109],q[3];
cp(0) q[109],q[4];
cp(0) q[109],q[5];
cp(0) q[109],q[6];
cp(0) q[109],q[7];
cp(0) q[109],q[8];
cp(0) q[109],q[9];
cp(0) q[109],q[10];
cp(0) q[109],q[11];
cp(0) q[109],q[12];
cp(0) q[109],q[13];
cp(0) q[109],q[14];
cp(0) q[109],q[15];
cp(0) q[109],q[16];
cp(0) q[109],q[17];
cp(0) q[109],q[18];
cp(0) q[109],q[19];
cp(0) q[109],q[20];
cp(0) q[109],q[21];
cp(0) q[109],q[22];
cp(0) q[109],q[23];
cp(0) q[109],q[24];
cp(0) q[109],q[25];
cp(0) q[109],q[26];
cp(0) q[109],q[27];
cp(0) q[109],q[28];
cp(0) q[109],q[29];
cp(0) q[109],q[30];
cp(0) q[109],q[31];
cp(0) q[109],q[32];
cp(0) q[109],q[33];
cp(0) q[109],q[34];
cp(0) q[109],q[35];
cp(0) q[109],q[36];
cp(0) q[109],q[37];
cp(0) q[109],q[38];
cp(0) q[109],q[39];
cp(0) q[109],q[40];
cp(0) q[109],q[41];
cp(0) q[109],q[42];
cp(0) q[109],q[43];
cp(0) q[109],q[44];
cp(0) q[109],q[45];
cp(0) q[109],q[46];
cp(0) q[109],q[47];
cp(0) q[109],q[48];
cp(0) q[109],q[49];
cp(0) q[109],q[50];
cp(0) q[109],q[51];
cp(0) q[109],q[52];
cp(0) q[109],q[53];
cp(0) q[109],q[54];
cp(0) q[109],q[55];
cp(0) q[109],q[56];
cp(0) q[109],q[57];
cp(0) q[109],q[58];
cp(0) q[109],q[59];
cp(0) q[109],q[60];
cp(0) q[109],q[61];
cp(0) q[109],q[62];
cp(0) q[109],q[63];
cp(0) q[109],q[64];
cp(0) q[109],q[65];
cp(0) q[109],q[66];
cp(0) q[109],q[67];
cp(-pi/2199023255552) q[109],q[68];
cp(-pi/1099511627776) q[109],q[69];
cp(-pi/549755813888) q[109],q[70];
cp(-pi/274877906944) q[109],q[71];
cp(-pi/137438953472) q[109],q[72];
cp(-pi/68719476736) q[109],q[73];
cp(-pi/34359738368) q[109],q[74];
cp(-pi/17179869184) q[109],q[75];
cp(-pi/8589934592) q[109],q[76];
cp(-pi/4294967296) q[109],q[77];
cp(-pi/2147483648) q[109],q[78];
cp(-pi/1073741824) q[109],q[79];
cp(-pi/536870912) q[109],q[80];
cp(-pi/268435456) q[109],q[81];
cp(-pi/134217728) q[109],q[82];
cp(-pi/67108864) q[109],q[83];
cp(-pi/33554432) q[109],q[84];
cp(-pi/16777216) q[109],q[85];
cp(-pi/8388608) q[109],q[86];
cp(-pi/4194304) q[109],q[87];
cp(-pi/2097152) q[109],q[88];
cp(-pi/1048576) q[109],q[89];
cp(-pi/524288) q[109],q[90];
cp(-pi/262144) q[109],q[91];
cp(-pi/131072) q[109],q[92];
cp(-pi/65536) q[109],q[93];
cp(-pi/32768) q[109],q[94];
cp(-pi/16384) q[109],q[95];
cp(-pi/8192) q[109],q[96];
cp(-pi/4096) q[109],q[97];
cp(-pi/2048) q[109],q[98];
cp(-pi/1024) q[109],q[99];
cp(-pi/512) q[109],q[100];
cp(-pi/256) q[109],q[101];
cp(-pi/128) q[109],q[102];
cp(-pi/64) q[109],q[103];
cp(-pi/32) q[109],q[104];
cp(-pi/16) q[109],q[105];
cp(-pi/8) q[109],q[106];
cp(-pi/4) q[109],q[107];
cp(-pi/2) q[109],q[108];
h q[109];
cp(0) q[110],q[0];
cp(0) q[110],q[1];
cp(0) q[110],q[2];
cp(0) q[110],q[3];
cp(0) q[110],q[4];
cp(0) q[110],q[5];
cp(0) q[110],q[6];
cp(0) q[110],q[7];
cp(0) q[110],q[8];
cp(0) q[110],q[9];
cp(0) q[110],q[10];
cp(0) q[110],q[11];
cp(0) q[110],q[12];
cp(0) q[110],q[13];
cp(0) q[110],q[14];
cp(0) q[110],q[15];
cp(0) q[110],q[16];
cp(0) q[110],q[17];
cp(0) q[110],q[18];
cp(0) q[110],q[19];
cp(0) q[110],q[20];
cp(0) q[110],q[21];
cp(0) q[110],q[22];
cp(0) q[110],q[23];
cp(0) q[110],q[24];
cp(0) q[110],q[25];
cp(0) q[110],q[26];
cp(0) q[110],q[27];
cp(0) q[110],q[28];
cp(0) q[110],q[29];
cp(0) q[110],q[30];
cp(0) q[110],q[31];
cp(0) q[110],q[32];
cp(0) q[110],q[33];
cp(0) q[110],q[34];
cp(0) q[110],q[35];
cp(0) q[110],q[36];
cp(0) q[110],q[37];
cp(0) q[110],q[38];
cp(0) q[110],q[39];
cp(0) q[110],q[40];
cp(0) q[110],q[41];
cp(0) q[110],q[42];
cp(0) q[110],q[43];
cp(0) q[110],q[44];
cp(0) q[110],q[45];
cp(0) q[110],q[46];
cp(0) q[110],q[47];
cp(0) q[110],q[48];
cp(0) q[110],q[49];
cp(0) q[110],q[50];
cp(0) q[110],q[51];
cp(0) q[110],q[52];
cp(0) q[110],q[53];
cp(0) q[110],q[54];
cp(0) q[110],q[55];
cp(0) q[110],q[56];
cp(0) q[110],q[57];
cp(0) q[110],q[58];
cp(0) q[110],q[59];
cp(0) q[110],q[60];
cp(0) q[110],q[61];
cp(0) q[110],q[62];
cp(0) q[110],q[63];
cp(0) q[110],q[64];
cp(0) q[110],q[65];
cp(0) q[110],q[66];
cp(0) q[110],q[67];
cp(0) q[110],q[68];
cp(-pi/2199023255552) q[110],q[69];
cp(-pi/1099511627776) q[110],q[70];
cp(-pi/549755813888) q[110],q[71];
cp(-pi/274877906944) q[110],q[72];
cp(-pi/137438953472) q[110],q[73];
cp(-pi/68719476736) q[110],q[74];
cp(-pi/34359738368) q[110],q[75];
cp(-pi/17179869184) q[110],q[76];
cp(-pi/8589934592) q[110],q[77];
cp(-pi/4294967296) q[110],q[78];
cp(-pi/2147483648) q[110],q[79];
cp(-pi/1073741824) q[110],q[80];
cp(-pi/536870912) q[110],q[81];
cp(-pi/268435456) q[110],q[82];
cp(-pi/134217728) q[110],q[83];
cp(-pi/67108864) q[110],q[84];
cp(-pi/33554432) q[110],q[85];
cp(-pi/16777216) q[110],q[86];
cp(-pi/8388608) q[110],q[87];
cp(-pi/4194304) q[110],q[88];
cp(-pi/2097152) q[110],q[89];
cp(-pi/1048576) q[110],q[90];
cp(-pi/524288) q[110],q[91];
cp(-pi/262144) q[110],q[92];
cp(-pi/131072) q[110],q[93];
cp(-pi/65536) q[110],q[94];
cp(-pi/32768) q[110],q[95];
cp(-pi/16384) q[110],q[96];
cp(-pi/8192) q[110],q[97];
cp(-pi/4096) q[110],q[98];
cp(-pi/2048) q[110],q[99];
cp(-pi/1024) q[110],q[100];
cp(-pi/512) q[110],q[101];
cp(-pi/256) q[110],q[102];
cp(-pi/128) q[110],q[103];
cp(-pi/64) q[110],q[104];
cp(-pi/32) q[110],q[105];
cp(-pi/16) q[110],q[106];
cp(-pi/8) q[110],q[107];
cp(-pi/4) q[110],q[108];
cp(-pi/2) q[110],q[109];
h q[110];
cp(0) q[111],q[0];
cp(0) q[111],q[1];
cp(0) q[111],q[2];
cp(0) q[111],q[3];
cp(0) q[111],q[4];
cp(0) q[111],q[5];
cp(0) q[111],q[6];
cp(0) q[111],q[7];
cp(0) q[111],q[8];
cp(0) q[111],q[9];
cp(0) q[111],q[10];
cp(0) q[111],q[11];
cp(0) q[111],q[12];
cp(0) q[111],q[13];
cp(0) q[111],q[14];
cp(0) q[111],q[15];
cp(0) q[111],q[16];
cp(0) q[111],q[17];
cp(0) q[111],q[18];
cp(0) q[111],q[19];
cp(0) q[111],q[20];
cp(0) q[111],q[21];
cp(0) q[111],q[22];
cp(0) q[111],q[23];
cp(0) q[111],q[24];
cp(0) q[111],q[25];
cp(0) q[111],q[26];
cp(0) q[111],q[27];
cp(0) q[111],q[28];
cp(0) q[111],q[29];
cp(0) q[111],q[30];
cp(0) q[111],q[31];
cp(0) q[111],q[32];
cp(0) q[111],q[33];
cp(0) q[111],q[34];
cp(0) q[111],q[35];
cp(0) q[111],q[36];
cp(0) q[111],q[37];
cp(0) q[111],q[38];
cp(0) q[111],q[39];
cp(0) q[111],q[40];
cp(0) q[111],q[41];
cp(0) q[111],q[42];
cp(0) q[111],q[43];
cp(0) q[111],q[44];
cp(0) q[111],q[45];
cp(0) q[111],q[46];
cp(0) q[111],q[47];
cp(0) q[111],q[48];
cp(0) q[111],q[49];
cp(0) q[111],q[50];
cp(0) q[111],q[51];
cp(0) q[111],q[52];
cp(0) q[111],q[53];
cp(0) q[111],q[54];
cp(0) q[111],q[55];
cp(0) q[111],q[56];
cp(0) q[111],q[57];
cp(0) q[111],q[58];
cp(0) q[111],q[59];
cp(0) q[111],q[60];
cp(0) q[111],q[61];
cp(0) q[111],q[62];
cp(0) q[111],q[63];
cp(0) q[111],q[64];
cp(0) q[111],q[65];
cp(0) q[111],q[66];
cp(0) q[111],q[67];
cp(0) q[111],q[68];
cp(0) q[111],q[69];
cp(-pi/2199023255552) q[111],q[70];
cp(-pi/1099511627776) q[111],q[71];
cp(-pi/549755813888) q[111],q[72];
cp(-pi/274877906944) q[111],q[73];
cp(-pi/137438953472) q[111],q[74];
cp(-pi/68719476736) q[111],q[75];
cp(-pi/34359738368) q[111],q[76];
cp(-pi/17179869184) q[111],q[77];
cp(-pi/8589934592) q[111],q[78];
cp(-pi/4294967296) q[111],q[79];
cp(-pi/2147483648) q[111],q[80];
cp(-pi/1073741824) q[111],q[81];
cp(-pi/536870912) q[111],q[82];
cp(-pi/268435456) q[111],q[83];
cp(-pi/134217728) q[111],q[84];
cp(-pi/67108864) q[111],q[85];
cp(-pi/33554432) q[111],q[86];
cp(-pi/16777216) q[111],q[87];
cp(-pi/8388608) q[111],q[88];
cp(-pi/4194304) q[111],q[89];
cp(-pi/2097152) q[111],q[90];
cp(-pi/1048576) q[111],q[91];
cp(-pi/524288) q[111],q[92];
cp(-pi/262144) q[111],q[93];
cp(-pi/131072) q[111],q[94];
cp(-pi/65536) q[111],q[95];
cp(-pi/32768) q[111],q[96];
cp(-pi/16384) q[111],q[97];
cp(-pi/8192) q[111],q[98];
cp(-pi/4096) q[111],q[99];
cp(-pi/2048) q[111],q[100];
cp(-pi/1024) q[111],q[101];
cp(-pi/512) q[111],q[102];
cp(-pi/256) q[111],q[103];
cp(-pi/128) q[111],q[104];
cp(-pi/64) q[111],q[105];
cp(-pi/32) q[111],q[106];
cp(-pi/16) q[111],q[107];
cp(-pi/8) q[111],q[108];
cp(-pi/4) q[111],q[109];
cp(-pi/2) q[111],q[110];
h q[111];
cp(0) q[112],q[0];
cp(0) q[112],q[1];
cp(0) q[112],q[2];
cp(0) q[112],q[3];
cp(0) q[112],q[4];
cp(0) q[112],q[5];
cp(0) q[112],q[6];
cp(0) q[112],q[7];
cp(0) q[112],q[8];
cp(0) q[112],q[9];
cp(0) q[112],q[10];
cp(0) q[112],q[11];
cp(0) q[112],q[12];
cp(0) q[112],q[13];
cp(0) q[112],q[14];
cp(0) q[112],q[15];
cp(0) q[112],q[16];
cp(0) q[112],q[17];
cp(0) q[112],q[18];
cp(0) q[112],q[19];
cp(0) q[112],q[20];
cp(0) q[112],q[21];
cp(0) q[112],q[22];
cp(0) q[112],q[23];
cp(0) q[112],q[24];
cp(0) q[112],q[25];
cp(0) q[112],q[26];
cp(0) q[112],q[27];
cp(0) q[112],q[28];
cp(0) q[112],q[29];
cp(0) q[112],q[30];
cp(0) q[112],q[31];
cp(0) q[112],q[32];
cp(0) q[112],q[33];
cp(0) q[112],q[34];
cp(0) q[112],q[35];
cp(0) q[112],q[36];
cp(0) q[112],q[37];
cp(0) q[112],q[38];
cp(0) q[112],q[39];
cp(0) q[112],q[40];
cp(0) q[112],q[41];
cp(0) q[112],q[42];
cp(0) q[112],q[43];
cp(0) q[112],q[44];
cp(0) q[112],q[45];
cp(0) q[112],q[46];
cp(0) q[112],q[47];
cp(0) q[112],q[48];
cp(0) q[112],q[49];
cp(0) q[112],q[50];
cp(0) q[112],q[51];
cp(0) q[112],q[52];
cp(0) q[112],q[53];
cp(0) q[112],q[54];
cp(0) q[112],q[55];
cp(0) q[112],q[56];
cp(0) q[112],q[57];
cp(0) q[112],q[58];
cp(0) q[112],q[59];
cp(0) q[112],q[60];
cp(0) q[112],q[61];
cp(0) q[112],q[62];
cp(0) q[112],q[63];
cp(0) q[112],q[64];
cp(0) q[112],q[65];
cp(0) q[112],q[66];
cp(0) q[112],q[67];
cp(0) q[112],q[68];
cp(0) q[112],q[69];
cp(0) q[112],q[70];
cp(-pi/2199023255552) q[112],q[71];
cp(-pi/1099511627776) q[112],q[72];
cp(-pi/549755813888) q[112],q[73];
cp(-pi/274877906944) q[112],q[74];
cp(-pi/137438953472) q[112],q[75];
cp(-pi/68719476736) q[112],q[76];
cp(-pi/34359738368) q[112],q[77];
cp(-pi/17179869184) q[112],q[78];
cp(-pi/8589934592) q[112],q[79];
cp(-pi/4294967296) q[112],q[80];
cp(-pi/2147483648) q[112],q[81];
cp(-pi/1073741824) q[112],q[82];
cp(-pi/536870912) q[112],q[83];
cp(-pi/268435456) q[112],q[84];
cp(-pi/134217728) q[112],q[85];
cp(-pi/67108864) q[112],q[86];
cp(-pi/33554432) q[112],q[87];
cp(-pi/16777216) q[112],q[88];
cp(-pi/8388608) q[112],q[89];
cp(-pi/4194304) q[112],q[90];
cp(-pi/2097152) q[112],q[91];
cp(-pi/1048576) q[112],q[92];
cp(-pi/524288) q[112],q[93];
cp(-pi/262144) q[112],q[94];
cp(-pi/131072) q[112],q[95];
cp(-pi/65536) q[112],q[96];
cp(-pi/32768) q[112],q[97];
cp(-pi/16384) q[112],q[98];
cp(-pi/8192) q[112],q[99];
cp(-pi/4096) q[112],q[100];
cp(-pi/2048) q[112],q[101];
cp(-pi/1024) q[112],q[102];
cp(-pi/512) q[112],q[103];
cp(-pi/256) q[112],q[104];
cp(-pi/128) q[112],q[105];
cp(-pi/64) q[112],q[106];
cp(-pi/32) q[112],q[107];
cp(-pi/16) q[112],q[108];
cp(-pi/8) q[112],q[109];
cp(-pi/4) q[112],q[110];
cp(-pi/2) q[112],q[111];
h q[112];
cp(0) q[113],q[0];
cp(0) q[113],q[1];
cp(0) q[113],q[2];
cp(0) q[113],q[3];
cp(0) q[113],q[4];
cp(0) q[113],q[5];
cp(0) q[113],q[6];
cp(0) q[113],q[7];
cp(0) q[113],q[8];
cp(0) q[113],q[9];
cp(0) q[113],q[10];
cp(0) q[113],q[11];
cp(0) q[113],q[12];
cp(0) q[113],q[13];
cp(0) q[113],q[14];
cp(0) q[113],q[15];
cp(0) q[113],q[16];
cp(0) q[113],q[17];
cp(0) q[113],q[18];
cp(0) q[113],q[19];
cp(0) q[113],q[20];
cp(0) q[113],q[21];
cp(0) q[113],q[22];
cp(0) q[113],q[23];
cp(0) q[113],q[24];
cp(0) q[113],q[25];
cp(0) q[113],q[26];
cp(0) q[113],q[27];
cp(0) q[113],q[28];
cp(0) q[113],q[29];
cp(0) q[113],q[30];
cp(0) q[113],q[31];
cp(0) q[113],q[32];
cp(0) q[113],q[33];
cp(0) q[113],q[34];
cp(0) q[113],q[35];
cp(0) q[113],q[36];
cp(0) q[113],q[37];
cp(0) q[113],q[38];
cp(0) q[113],q[39];
cp(0) q[113],q[40];
cp(0) q[113],q[41];
cp(0) q[113],q[42];
cp(0) q[113],q[43];
cp(0) q[113],q[44];
cp(0) q[113],q[45];
cp(0) q[113],q[46];
cp(0) q[113],q[47];
cp(0) q[113],q[48];
cp(0) q[113],q[49];
cp(0) q[113],q[50];
cp(0) q[113],q[51];
cp(0) q[113],q[52];
cp(0) q[113],q[53];
cp(0) q[113],q[54];
cp(0) q[113],q[55];
cp(0) q[113],q[56];
cp(0) q[113],q[57];
cp(0) q[113],q[58];
cp(0) q[113],q[59];
cp(0) q[113],q[60];
cp(0) q[113],q[61];
cp(0) q[113],q[62];
cp(0) q[113],q[63];
cp(0) q[113],q[64];
cp(0) q[113],q[65];
cp(0) q[113],q[66];
cp(0) q[113],q[67];
cp(0) q[113],q[68];
cp(0) q[113],q[69];
cp(0) q[113],q[70];
cp(0) q[113],q[71];
cp(-pi/2199023255552) q[113],q[72];
cp(-pi/1099511627776) q[113],q[73];
cp(-pi/549755813888) q[113],q[74];
cp(-pi/274877906944) q[113],q[75];
cp(-pi/137438953472) q[113],q[76];
cp(-pi/68719476736) q[113],q[77];
cp(-pi/34359738368) q[113],q[78];
cp(-pi/17179869184) q[113],q[79];
cp(-pi/8589934592) q[113],q[80];
cp(-pi/4294967296) q[113],q[81];
cp(-pi/2147483648) q[113],q[82];
cp(-pi/1073741824) q[113],q[83];
cp(-pi/536870912) q[113],q[84];
cp(-pi/268435456) q[113],q[85];
cp(-pi/134217728) q[113],q[86];
cp(-pi/67108864) q[113],q[87];
cp(-pi/33554432) q[113],q[88];
cp(-pi/16777216) q[113],q[89];
cp(-pi/8388608) q[113],q[90];
cp(-pi/4194304) q[113],q[91];
cp(-pi/2097152) q[113],q[92];
cp(-pi/1048576) q[113],q[93];
cp(-pi/524288) q[113],q[94];
cp(-pi/262144) q[113],q[95];
cp(-pi/131072) q[113],q[96];
cp(-pi/65536) q[113],q[97];
cp(-pi/32768) q[113],q[98];
cp(-pi/16384) q[113],q[99];
cp(-pi/8192) q[113],q[100];
cp(-pi/4096) q[113],q[101];
cp(-pi/2048) q[113],q[102];
cp(-pi/1024) q[113],q[103];
cp(-pi/512) q[113],q[104];
cp(-pi/256) q[113],q[105];
cp(-pi/128) q[113],q[106];
cp(-pi/64) q[113],q[107];
cp(-pi/32) q[113],q[108];
cp(-pi/16) q[113],q[109];
cp(-pi/8) q[113],q[110];
cp(-pi/4) q[113],q[111];
cp(-pi/2) q[113],q[112];
h q[113];
cp(0) q[114],q[0];
cp(0) q[114],q[1];
cp(0) q[114],q[2];
cp(0) q[114],q[3];
cp(0) q[114],q[4];
cp(0) q[114],q[5];
cp(0) q[114],q[6];
cp(0) q[114],q[7];
cp(0) q[114],q[8];
cp(0) q[114],q[9];
cp(0) q[114],q[10];
cp(0) q[114],q[11];
cp(0) q[114],q[12];
cp(0) q[114],q[13];
cp(0) q[114],q[14];
cp(0) q[114],q[15];
cp(0) q[114],q[16];
cp(0) q[114],q[17];
cp(0) q[114],q[18];
cp(0) q[114],q[19];
cp(0) q[114],q[20];
cp(0) q[114],q[21];
cp(0) q[114],q[22];
cp(0) q[114],q[23];
cp(0) q[114],q[24];
cp(0) q[114],q[25];
cp(0) q[114],q[26];
cp(0) q[114],q[27];
cp(0) q[114],q[28];
cp(0) q[114],q[29];
cp(0) q[114],q[30];
cp(0) q[114],q[31];
cp(0) q[114],q[32];
cp(0) q[114],q[33];
cp(0) q[114],q[34];
cp(0) q[114],q[35];
cp(0) q[114],q[36];
cp(0) q[114],q[37];
cp(0) q[114],q[38];
cp(0) q[114],q[39];
cp(0) q[114],q[40];
cp(0) q[114],q[41];
cp(0) q[114],q[42];
cp(0) q[114],q[43];
cp(0) q[114],q[44];
cp(0) q[114],q[45];
cp(0) q[114],q[46];
cp(0) q[114],q[47];
cp(0) q[114],q[48];
cp(0) q[114],q[49];
cp(0) q[114],q[50];
cp(0) q[114],q[51];
cp(0) q[114],q[52];
cp(0) q[114],q[53];
cp(0) q[114],q[54];
cp(0) q[114],q[55];
cp(0) q[114],q[56];
cp(0) q[114],q[57];
cp(0) q[114],q[58];
cp(0) q[114],q[59];
cp(0) q[114],q[60];
cp(0) q[114],q[61];
cp(0) q[114],q[62];
cp(0) q[114],q[63];
cp(0) q[114],q[64];
cp(0) q[114],q[65];
cp(0) q[114],q[66];
cp(0) q[114],q[67];
cp(0) q[114],q[68];
cp(0) q[114],q[69];
cp(0) q[114],q[70];
cp(0) q[114],q[71];
cp(0) q[114],q[72];
cp(-pi/2199023255552) q[114],q[73];
cp(-pi/1099511627776) q[114],q[74];
cp(-pi/549755813888) q[114],q[75];
cp(-pi/274877906944) q[114],q[76];
cp(-pi/137438953472) q[114],q[77];
cp(-pi/68719476736) q[114],q[78];
cp(-pi/34359738368) q[114],q[79];
cp(-pi/17179869184) q[114],q[80];
cp(-pi/8589934592) q[114],q[81];
cp(-pi/4294967296) q[114],q[82];
cp(-pi/2147483648) q[114],q[83];
cp(-pi/1073741824) q[114],q[84];
cp(-pi/536870912) q[114],q[85];
cp(-pi/268435456) q[114],q[86];
cp(-pi/134217728) q[114],q[87];
cp(-pi/67108864) q[114],q[88];
cp(-pi/33554432) q[114],q[89];
cp(-pi/16777216) q[114],q[90];
cp(-pi/8388608) q[114],q[91];
cp(-pi/4194304) q[114],q[92];
cp(-pi/2097152) q[114],q[93];
cp(-pi/1048576) q[114],q[94];
cp(-pi/524288) q[114],q[95];
cp(-pi/262144) q[114],q[96];
cp(-pi/131072) q[114],q[97];
cp(-pi/65536) q[114],q[98];
cp(-pi/32768) q[114],q[99];
cp(-pi/16384) q[114],q[100];
cp(-pi/8192) q[114],q[101];
cp(-pi/4096) q[114],q[102];
cp(-pi/2048) q[114],q[103];
cp(-pi/1024) q[114],q[104];
cp(-pi/512) q[114],q[105];
cp(-pi/256) q[114],q[106];
cp(-pi/128) q[114],q[107];
cp(-pi/64) q[114],q[108];
cp(-pi/32) q[114],q[109];
cp(-pi/16) q[114],q[110];
cp(-pi/8) q[114],q[111];
cp(-pi/4) q[114],q[112];
cp(-pi/2) q[114],q[113];
h q[114];
cp(0) q[115],q[0];
cp(0) q[115],q[1];
cp(0) q[115],q[2];
cp(0) q[115],q[3];
cp(0) q[115],q[4];
cp(0) q[115],q[5];
cp(0) q[115],q[6];
cp(0) q[115],q[7];
cp(0) q[115],q[8];
cp(0) q[115],q[9];
cp(0) q[115],q[10];
cp(0) q[115],q[11];
cp(0) q[115],q[12];
cp(0) q[115],q[13];
cp(0) q[115],q[14];
cp(0) q[115],q[15];
cp(0) q[115],q[16];
cp(0) q[115],q[17];
cp(0) q[115],q[18];
cp(0) q[115],q[19];
cp(0) q[115],q[20];
cp(0) q[115],q[21];
cp(0) q[115],q[22];
cp(0) q[115],q[23];
cp(0) q[115],q[24];
cp(0) q[115],q[25];
cp(0) q[115],q[26];
cp(0) q[115],q[27];
cp(0) q[115],q[28];
cp(0) q[115],q[29];
cp(0) q[115],q[30];
cp(0) q[115],q[31];
cp(0) q[115],q[32];
cp(0) q[115],q[33];
cp(0) q[115],q[34];
cp(0) q[115],q[35];
cp(0) q[115],q[36];
cp(0) q[115],q[37];
cp(0) q[115],q[38];
cp(0) q[115],q[39];
cp(0) q[115],q[40];
cp(0) q[115],q[41];
cp(0) q[115],q[42];
cp(0) q[115],q[43];
cp(0) q[115],q[44];
cp(0) q[115],q[45];
cp(0) q[115],q[46];
cp(0) q[115],q[47];
cp(0) q[115],q[48];
cp(0) q[115],q[49];
cp(0) q[115],q[50];
cp(0) q[115],q[51];
cp(0) q[115],q[52];
cp(0) q[115],q[53];
cp(0) q[115],q[54];
cp(0) q[115],q[55];
cp(0) q[115],q[56];
cp(0) q[115],q[57];
cp(0) q[115],q[58];
cp(0) q[115],q[59];
cp(0) q[115],q[60];
cp(0) q[115],q[61];
cp(0) q[115],q[62];
cp(0) q[115],q[63];
cp(0) q[115],q[64];
cp(0) q[115],q[65];
cp(0) q[115],q[66];
cp(0) q[115],q[67];
cp(0) q[115],q[68];
cp(0) q[115],q[69];
cp(0) q[115],q[70];
cp(0) q[115],q[71];
cp(0) q[115],q[72];
cp(0) q[115],q[73];
cp(-pi/2199023255552) q[115],q[74];
cp(-pi/1099511627776) q[115],q[75];
cp(-pi/549755813888) q[115],q[76];
cp(-pi/274877906944) q[115],q[77];
cp(-pi/137438953472) q[115],q[78];
cp(-pi/68719476736) q[115],q[79];
cp(-pi/34359738368) q[115],q[80];
cp(-pi/17179869184) q[115],q[81];
cp(-pi/8589934592) q[115],q[82];
cp(-pi/4294967296) q[115],q[83];
cp(-pi/2147483648) q[115],q[84];
cp(-pi/1073741824) q[115],q[85];
cp(-pi/536870912) q[115],q[86];
cp(-pi/268435456) q[115],q[87];
cp(-pi/134217728) q[115],q[88];
cp(-pi/67108864) q[115],q[89];
cp(-pi/33554432) q[115],q[90];
cp(-pi/16777216) q[115],q[91];
cp(-pi/8388608) q[115],q[92];
cp(-pi/4194304) q[115],q[93];
cp(-pi/2097152) q[115],q[94];
cp(-pi/1048576) q[115],q[95];
cp(-pi/524288) q[115],q[96];
cp(-pi/262144) q[115],q[97];
cp(-pi/131072) q[115],q[98];
cp(-pi/65536) q[115],q[99];
cp(-pi/32768) q[115],q[100];
cp(-pi/16384) q[115],q[101];
cp(-pi/8192) q[115],q[102];
cp(-pi/4096) q[115],q[103];
cp(-pi/2048) q[115],q[104];
cp(-pi/1024) q[115],q[105];
cp(-pi/512) q[115],q[106];
cp(-pi/256) q[115],q[107];
cp(-pi/128) q[115],q[108];
cp(-pi/64) q[115],q[109];
cp(-pi/32) q[115],q[110];
cp(-pi/16) q[115],q[111];
cp(-pi/8) q[115],q[112];
cp(-pi/4) q[115],q[113];
cp(-pi/2) q[115],q[114];
h q[115];
cp(0) q[116],q[0];
cp(0) q[116],q[1];
cp(0) q[116],q[2];
cp(0) q[116],q[3];
cp(0) q[116],q[4];
cp(0) q[116],q[5];
cp(0) q[116],q[6];
cp(0) q[116],q[7];
cp(0) q[116],q[8];
cp(0) q[116],q[9];
cp(0) q[116],q[10];
cp(0) q[116],q[11];
cp(0) q[116],q[12];
cp(0) q[116],q[13];
cp(0) q[116],q[14];
cp(0) q[116],q[15];
cp(0) q[116],q[16];
cp(0) q[116],q[17];
cp(0) q[116],q[18];
cp(0) q[116],q[19];
cp(0) q[116],q[20];
cp(0) q[116],q[21];
cp(0) q[116],q[22];
cp(0) q[116],q[23];
cp(0) q[116],q[24];
cp(0) q[116],q[25];
cp(0) q[116],q[26];
cp(0) q[116],q[27];
cp(0) q[116],q[28];
cp(0) q[116],q[29];
cp(0) q[116],q[30];
cp(0) q[116],q[31];
cp(0) q[116],q[32];
cp(0) q[116],q[33];
cp(0) q[116],q[34];
cp(0) q[116],q[35];
cp(0) q[116],q[36];
cp(0) q[116],q[37];
cp(0) q[116],q[38];
cp(0) q[116],q[39];
cp(0) q[116],q[40];
cp(0) q[116],q[41];
cp(0) q[116],q[42];
cp(0) q[116],q[43];
cp(0) q[116],q[44];
cp(0) q[116],q[45];
cp(0) q[116],q[46];
cp(0) q[116],q[47];
cp(0) q[116],q[48];
cp(0) q[116],q[49];
cp(0) q[116],q[50];
cp(0) q[116],q[51];
cp(0) q[116],q[52];
cp(0) q[116],q[53];
cp(0) q[116],q[54];
cp(0) q[116],q[55];
cp(0) q[116],q[56];
cp(0) q[116],q[57];
cp(0) q[116],q[58];
cp(0) q[116],q[59];
cp(0) q[116],q[60];
cp(0) q[116],q[61];
cp(0) q[116],q[62];
cp(0) q[116],q[63];
cp(0) q[116],q[64];
cp(0) q[116],q[65];
cp(0) q[116],q[66];
cp(0) q[116],q[67];
cp(0) q[116],q[68];
cp(0) q[116],q[69];
cp(0) q[116],q[70];
cp(0) q[116],q[71];
cp(0) q[116],q[72];
cp(0) q[116],q[73];
cp(0) q[116],q[74];
cp(-pi/2199023255552) q[116],q[75];
cp(-pi/1099511627776) q[116],q[76];
cp(-pi/549755813888) q[116],q[77];
cp(-pi/274877906944) q[116],q[78];
cp(-pi/137438953472) q[116],q[79];
cp(-pi/68719476736) q[116],q[80];
cp(-pi/34359738368) q[116],q[81];
cp(-pi/17179869184) q[116],q[82];
cp(-pi/8589934592) q[116],q[83];
cp(-pi/4294967296) q[116],q[84];
cp(-pi/2147483648) q[116],q[85];
cp(-pi/1073741824) q[116],q[86];
cp(-pi/536870912) q[116],q[87];
cp(-pi/268435456) q[116],q[88];
cp(-pi/134217728) q[116],q[89];
cp(-pi/67108864) q[116],q[90];
cp(-pi/33554432) q[116],q[91];
cp(-pi/16777216) q[116],q[92];
cp(-pi/8388608) q[116],q[93];
cp(-pi/4194304) q[116],q[94];
cp(-pi/2097152) q[116],q[95];
cp(-pi/1048576) q[116],q[96];
cp(-pi/524288) q[116],q[97];
cp(-pi/262144) q[116],q[98];
cp(-pi/131072) q[116],q[99];
cp(-pi/65536) q[116],q[100];
cp(-pi/32768) q[116],q[101];
cp(-pi/16384) q[116],q[102];
cp(-pi/8192) q[116],q[103];
cp(-pi/4096) q[116],q[104];
cp(-pi/2048) q[116],q[105];
cp(-pi/1024) q[116],q[106];
cp(-pi/512) q[116],q[107];
cp(-pi/256) q[116],q[108];
cp(-pi/128) q[116],q[109];
cp(-pi/64) q[116],q[110];
cp(-pi/32) q[116],q[111];
cp(-pi/16) q[116],q[112];
cp(-pi/8) q[116],q[113];
cp(-pi/4) q[116],q[114];
cp(-pi/2) q[116],q[115];
h q[116];
cp(0) q[117],q[0];
cp(0) q[117],q[1];
cp(0) q[117],q[2];
cp(0) q[117],q[3];
cp(0) q[117],q[4];
cp(0) q[117],q[5];
cp(0) q[117],q[6];
cp(0) q[117],q[7];
cp(0) q[117],q[8];
cp(0) q[117],q[9];
cp(0) q[117],q[10];
cp(0) q[117],q[11];
cp(0) q[117],q[12];
cp(0) q[117],q[13];
cp(0) q[117],q[14];
cp(0) q[117],q[15];
cp(0) q[117],q[16];
cp(0) q[117],q[17];
cp(0) q[117],q[18];
cp(0) q[117],q[19];
cp(0) q[117],q[20];
cp(0) q[117],q[21];
cp(0) q[117],q[22];
cp(0) q[117],q[23];
cp(0) q[117],q[24];
cp(0) q[117],q[25];
cp(0) q[117],q[26];
cp(0) q[117],q[27];
cp(0) q[117],q[28];
cp(0) q[117],q[29];
cp(0) q[117],q[30];
cp(0) q[117],q[31];
cp(0) q[117],q[32];
cp(0) q[117],q[33];
cp(0) q[117],q[34];
cp(0) q[117],q[35];
cp(0) q[117],q[36];
cp(0) q[117],q[37];
cp(0) q[117],q[38];
cp(0) q[117],q[39];
cp(0) q[117],q[40];
cp(0) q[117],q[41];
cp(0) q[117],q[42];
cp(0) q[117],q[43];
cp(0) q[117],q[44];
cp(0) q[117],q[45];
cp(0) q[117],q[46];
cp(0) q[117],q[47];
cp(0) q[117],q[48];
cp(0) q[117],q[49];
cp(0) q[117],q[50];
cp(0) q[117],q[51];
cp(0) q[117],q[52];
cp(0) q[117],q[53];
cp(0) q[117],q[54];
cp(0) q[117],q[55];
cp(0) q[117],q[56];
cp(0) q[117],q[57];
cp(0) q[117],q[58];
cp(0) q[117],q[59];
cp(0) q[117],q[60];
cp(0) q[117],q[61];
cp(0) q[117],q[62];
cp(0) q[117],q[63];
cp(0) q[117],q[64];
cp(0) q[117],q[65];
cp(0) q[117],q[66];
cp(0) q[117],q[67];
cp(0) q[117],q[68];
cp(0) q[117],q[69];
cp(0) q[117],q[70];
cp(0) q[117],q[71];
cp(0) q[117],q[72];
cp(0) q[117],q[73];
cp(0) q[117],q[74];
cp(0) q[117],q[75];
cp(-pi/2199023255552) q[117],q[76];
cp(-pi/1099511627776) q[117],q[77];
cp(-pi/549755813888) q[117],q[78];
cp(-pi/274877906944) q[117],q[79];
cp(-pi/137438953472) q[117],q[80];
cp(-pi/68719476736) q[117],q[81];
cp(-pi/34359738368) q[117],q[82];
cp(-pi/17179869184) q[117],q[83];
cp(-pi/8589934592) q[117],q[84];
cp(-pi/4294967296) q[117],q[85];
cp(-pi/2147483648) q[117],q[86];
cp(-pi/1073741824) q[117],q[87];
cp(-pi/536870912) q[117],q[88];
cp(-pi/268435456) q[117],q[89];
cp(-pi/134217728) q[117],q[90];
cp(-pi/67108864) q[117],q[91];
cp(-pi/33554432) q[117],q[92];
cp(-pi/16777216) q[117],q[93];
cp(-pi/8388608) q[117],q[94];
cp(-pi/4194304) q[117],q[95];
cp(-pi/2097152) q[117],q[96];
cp(-pi/1048576) q[117],q[97];
cp(-pi/524288) q[117],q[98];
cp(-pi/262144) q[117],q[99];
cp(-pi/131072) q[117],q[100];
cp(-pi/65536) q[117],q[101];
cp(-pi/32768) q[117],q[102];
cp(-pi/16384) q[117],q[103];
cp(-pi/8192) q[117],q[104];
cp(-pi/4096) q[117],q[105];
cp(-pi/2048) q[117],q[106];
cp(-pi/1024) q[117],q[107];
cp(-pi/512) q[117],q[108];
cp(-pi/256) q[117],q[109];
cp(-pi/128) q[117],q[110];
cp(-pi/64) q[117],q[111];
cp(-pi/32) q[117],q[112];
cp(-pi/16) q[117],q[113];
cp(-pi/8) q[117],q[114];
cp(-pi/4) q[117],q[115];
cp(-pi/2) q[117],q[116];
h q[117];
cp(0) q[118],q[0];
cp(0) q[118],q[1];
cp(0) q[118],q[2];
cp(0) q[118],q[3];
cp(0) q[118],q[4];
cp(0) q[118],q[5];
cp(0) q[118],q[6];
cp(0) q[118],q[7];
cp(0) q[118],q[8];
cp(0) q[118],q[9];
cp(0) q[118],q[10];
cp(0) q[118],q[11];
cp(0) q[118],q[12];
cp(0) q[118],q[13];
cp(0) q[118],q[14];
cp(0) q[118],q[15];
cp(0) q[118],q[16];
cp(0) q[118],q[17];
cp(0) q[118],q[18];
cp(0) q[118],q[19];
cp(0) q[118],q[20];
cp(0) q[118],q[21];
cp(0) q[118],q[22];
cp(0) q[118],q[23];
cp(0) q[118],q[24];
cp(0) q[118],q[25];
cp(0) q[118],q[26];
cp(0) q[118],q[27];
cp(0) q[118],q[28];
cp(0) q[118],q[29];
cp(0) q[118],q[30];
cp(0) q[118],q[31];
cp(0) q[118],q[32];
cp(0) q[118],q[33];
cp(0) q[118],q[34];
cp(0) q[118],q[35];
cp(0) q[118],q[36];
cp(0) q[118],q[37];
cp(0) q[118],q[38];
cp(0) q[118],q[39];
cp(0) q[118],q[40];
cp(0) q[118],q[41];
cp(0) q[118],q[42];
cp(0) q[118],q[43];
cp(0) q[118],q[44];
cp(0) q[118],q[45];
cp(0) q[118],q[46];
cp(0) q[118],q[47];
cp(0) q[118],q[48];
cp(0) q[118],q[49];
cp(0) q[118],q[50];
cp(0) q[118],q[51];
cp(0) q[118],q[52];
cp(0) q[118],q[53];
cp(0) q[118],q[54];
cp(0) q[118],q[55];
cp(0) q[118],q[56];
cp(0) q[118],q[57];
cp(0) q[118],q[58];
cp(0) q[118],q[59];
cp(0) q[118],q[60];
cp(0) q[118],q[61];
cp(0) q[118],q[62];
cp(0) q[118],q[63];
cp(0) q[118],q[64];
cp(0) q[118],q[65];
cp(0) q[118],q[66];
cp(0) q[118],q[67];
cp(0) q[118],q[68];
cp(0) q[118],q[69];
cp(0) q[118],q[70];
cp(0) q[118],q[71];
cp(0) q[118],q[72];
cp(0) q[118],q[73];
cp(0) q[118],q[74];
cp(0) q[118],q[75];
cp(0) q[118],q[76];
cp(-pi/2199023255552) q[118],q[77];
cp(-pi/1099511627776) q[118],q[78];
cp(-pi/549755813888) q[118],q[79];
cp(-pi/274877906944) q[118],q[80];
cp(-pi/137438953472) q[118],q[81];
cp(-pi/68719476736) q[118],q[82];
cp(-pi/34359738368) q[118],q[83];
cp(-pi/17179869184) q[118],q[84];
cp(-pi/8589934592) q[118],q[85];
cp(-pi/4294967296) q[118],q[86];
cp(-pi/2147483648) q[118],q[87];
cp(-pi/1073741824) q[118],q[88];
cp(-pi/536870912) q[118],q[89];
cp(-pi/268435456) q[118],q[90];
cp(-pi/134217728) q[118],q[91];
cp(-pi/67108864) q[118],q[92];
cp(-pi/33554432) q[118],q[93];
cp(-pi/16777216) q[118],q[94];
cp(-pi/8388608) q[118],q[95];
cp(-pi/4194304) q[118],q[96];
cp(-pi/2097152) q[118],q[97];
cp(-pi/1048576) q[118],q[98];
cp(-pi/524288) q[118],q[99];
cp(-pi/262144) q[118],q[100];
cp(-pi/131072) q[118],q[101];
cp(-pi/65536) q[118],q[102];
cp(-pi/32768) q[118],q[103];
cp(-pi/16384) q[118],q[104];
cp(-pi/8192) q[118],q[105];
cp(-pi/4096) q[118],q[106];
cp(-pi/2048) q[118],q[107];
cp(-pi/1024) q[118],q[108];
cp(-pi/512) q[118],q[109];
cp(-pi/256) q[118],q[110];
cp(-pi/128) q[118],q[111];
cp(-pi/64) q[118],q[112];
cp(-pi/32) q[118],q[113];
cp(-pi/16) q[118],q[114];
cp(-pi/8) q[118],q[115];
cp(-pi/4) q[118],q[116];
cp(-pi/2) q[118],q[117];
h q[118];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79],q[80],q[81],q[82],q[83],q[84],q[85],q[86],q[87],q[88],q[89],q[90],q[91],q[92],q[93],q[94],q[95],q[96],q[97],q[98],q[99],q[100],q[101],q[102],q[103],q[104],q[105],q[106],q[107],q[108],q[109],q[110],q[111],q[112],q[113],q[114],q[115],q[116],q[117],q[118],psi[0];
measure q[0] -> c[0];
measure q[1] -> c[1];
measure q[2] -> c[2];
measure q[3] -> c[3];
measure q[4] -> c[4];
measure q[5] -> c[5];
measure q[6] -> c[6];
measure q[7] -> c[7];
measure q[8] -> c[8];
measure q[9] -> c[9];
measure q[10] -> c[10];
measure q[11] -> c[11];
measure q[12] -> c[12];
measure q[13] -> c[13];
measure q[14] -> c[14];
measure q[15] -> c[15];
measure q[16] -> c[16];
measure q[17] -> c[17];
measure q[18] -> c[18];
measure q[19] -> c[19];
measure q[20] -> c[20];
measure q[21] -> c[21];
measure q[22] -> c[22];
measure q[23] -> c[23];
measure q[24] -> c[24];
measure q[25] -> c[25];
measure q[26] -> c[26];
measure q[27] -> c[27];
measure q[28] -> c[28];
measure q[29] -> c[29];
measure q[30] -> c[30];
measure q[31] -> c[31];
measure q[32] -> c[32];
measure q[33] -> c[33];
measure q[34] -> c[34];
measure q[35] -> c[35];
measure q[36] -> c[36];
measure q[37] -> c[37];
measure q[38] -> c[38];
measure q[39] -> c[39];
measure q[40] -> c[40];
measure q[41] -> c[41];
measure q[42] -> c[42];
measure q[43] -> c[43];
measure q[44] -> c[44];
measure q[45] -> c[45];
measure q[46] -> c[46];
measure q[47] -> c[47];
measure q[48] -> c[48];
measure q[49] -> c[49];
measure q[50] -> c[50];
measure q[51] -> c[51];
measure q[52] -> c[52];
measure q[53] -> c[53];
measure q[54] -> c[54];
measure q[55] -> c[55];
measure q[56] -> c[56];
measure q[57] -> c[57];
measure q[58] -> c[58];
measure q[59] -> c[59];
measure q[60] -> c[60];
measure q[61] -> c[61];
measure q[62] -> c[62];
measure q[63] -> c[63];
measure q[64] -> c[64];
measure q[65] -> c[65];
measure q[66] -> c[66];
measure q[67] -> c[67];
measure q[68] -> c[68];
measure q[69] -> c[69];
measure q[70] -> c[70];
measure q[71] -> c[71];
measure q[72] -> c[72];
measure q[73] -> c[73];
measure q[74] -> c[74];
measure q[75] -> c[75];
measure q[76] -> c[76];
measure q[77] -> c[77];
measure q[78] -> c[78];
measure q[79] -> c[79];
measure q[80] -> c[80];
measure q[81] -> c[81];
measure q[82] -> c[82];
measure q[83] -> c[83];
measure q[84] -> c[84];
measure q[85] -> c[85];
measure q[86] -> c[86];
measure q[87] -> c[87];
measure q[88] -> c[88];
measure q[89] -> c[89];
measure q[90] -> c[90];
measure q[91] -> c[91];
measure q[92] -> c[92];
measure q[93] -> c[93];
measure q[94] -> c[94];
measure q[95] -> c[95];
measure q[96] -> c[96];
measure q[97] -> c[97];
measure q[98] -> c[98];
measure q[99] -> c[99];
measure q[100] -> c[100];
measure q[101] -> c[101];
measure q[102] -> c[102];
measure q[103] -> c[103];
measure q[104] -> c[104];
measure q[105] -> c[105];
measure q[106] -> c[106];
measure q[107] -> c[107];
measure q[108] -> c[108];
measure q[109] -> c[109];
measure q[110] -> c[110];
measure q[111] -> c[111];
measure q[112] -> c[112];
measure q[113] -> c[113];
measure q[114] -> c[114];
measure q[115] -> c[115];
measure q[116] -> c[116];
measure q[117] -> c[117];
measure q[118] -> c[118];
'''

# %%
benchmarks['wstate-118'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q[118];
creg c[118];
creg meas[118];
x q[117];
ry(-1.4786083) q[116];
cz q[117],q[116];
ry(1.4786083) q[116];
ry(-1.4782141) q[115];
cz q[116],q[115];
ry(1.4782141) q[115];
ry(-1.4778147) q[114];
cz q[115],q[114];
ry(1.4778147) q[114];
ry(-1.4774102) q[113];
cz q[114],q[113];
ry(1.4774102) q[113];
ry(-1.4770003) q[112];
cz q[113],q[112];
ry(1.4770003) q[112];
ry(-1.4765849) q[111];
cz q[112],q[111];
ry(1.4765849) q[111];
ry(-1.476164) q[110];
cz q[111],q[110];
ry(1.476164) q[110];
ry(-1.4757374) q[109];
cz q[110],q[109];
ry(1.4757374) q[109];
ry(-1.475305) q[108];
cz q[109],q[108];
ry(1.475305) q[108];
ry(-1.4748666) q[107];
cz q[108],q[107];
ry(1.4748666) q[107];
ry(-1.4744222) q[106];
cz q[107],q[106];
ry(1.4744222) q[106];
ry(-1.4739715) q[105];
cz q[106],q[105];
ry(1.4739715) q[105];
ry(-1.4735144) q[104];
cz q[105],q[104];
ry(1.4735144) q[104];
ry(-1.4730507) q[103];
cz q[104],q[103];
ry(1.4730507) q[103];
ry(-1.4725804) q[102];
cz q[103],q[102];
ry(1.4725804) q[102];
ry(-1.4721033) q[101];
cz q[102],q[101];
ry(1.4721033) q[101];
ry(-1.4716191) q[100];
cz q[101],q[100];
ry(1.4716191) q[100];
ry(-1.4711277) q[99];
cz q[100],q[99];
ry(1.4711277) q[99];
ry(-1.4706289) q[98];
cz q[99],q[98];
ry(1.4706289) q[98];
ry(-1.4701226) q[97];
cz q[98],q[97];
ry(1.4701226) q[97];
ry(-1.4696085) q[96];
cz q[97],q[96];
ry(1.4696085) q[96];
ry(-1.4690864) q[95];
cz q[96],q[95];
ry(1.4690864) q[95];
ry(-1.4685562) q[94];
cz q[95],q[94];
ry(1.4685562) q[94];
ry(-1.4680176) q[93];
cz q[94],q[93];
ry(1.4680176) q[93];
ry(-1.4674704) q[92];
cz q[93],q[92];
ry(1.4674704) q[92];
ry(-1.4669144) q[91];
cz q[92],q[91];
ry(1.4669144) q[91];
ry(-1.4663493) q[90];
cz q[91],q[90];
ry(1.4663493) q[90];
ry(-1.4657749) q[89];
cz q[90],q[89];
ry(1.4657749) q[89];
ry(-1.4651909) q[88];
cz q[89],q[88];
ry(1.4651909) q[88];
ry(-1.464597) q[87];
cz q[88],q[87];
ry(1.464597) q[87];
ry(-1.463993) q[86];
cz q[87],q[86];
ry(1.463993) q[86];
ry(-1.4633786) q[85];
cz q[86],q[85];
ry(1.4633786) q[85];
ry(-1.4627535) q[84];
cz q[85],q[84];
ry(1.4627535) q[84];
ry(-1.4621173) q[83];
cz q[84],q[83];
ry(1.4621173) q[83];
ry(-1.4614697) q[82];
cz q[83],q[82];
ry(1.4614697) q[82];
ry(-1.4608105) q[81];
cz q[82],q[81];
ry(1.4608105) q[81];
ry(-1.4601391) q[80];
cz q[81],q[80];
ry(1.4601391) q[80];
ry(-1.4594553) q[79];
cz q[80],q[79];
ry(1.4594553) q[79];
ry(-1.4587587) q[78];
cz q[79],q[78];
ry(1.4587587) q[78];
ry(-1.4580488) q[77];
cz q[78],q[77];
ry(1.4580488) q[77];
ry(-1.4573253) q[76];
cz q[77],q[76];
ry(1.4573253) q[76];
ry(-1.4565876) q[75];
cz q[76],q[75];
ry(1.4565876) q[75];
ry(-1.4558354) q[74];
cz q[75],q[74];
ry(1.4558354) q[74];
ry(-1.4550681) q[73];
cz q[74],q[73];
ry(1.4550681) q[73];
ry(-1.4542853) q[72];
cz q[73],q[72];
ry(1.4542853) q[72];
ry(-1.4534863) q[71];
cz q[72],q[71];
ry(1.4534863) q[71];
ry(-1.4526707) q[70];
cz q[71],q[70];
ry(1.4526707) q[70];
ry(-1.4518378) q[69];
cz q[70],q[69];
ry(1.4518378) q[69];
ry(-1.450987) q[68];
cz q[69],q[68];
ry(1.450987) q[68];
ry(-1.4501178) q[67];
cz q[68],q[67];
ry(1.4501178) q[67];
ry(-1.4492293) q[66];
cz q[67],q[66];
ry(1.4492293) q[66];
ry(-1.4483209) q[65];
cz q[66],q[65];
ry(1.4483209) q[65];
ry(-1.4473919) q[64];
cz q[65],q[64];
ry(1.4473919) q[64];
ry(-1.4464413) q[63];
cz q[64],q[63];
ry(1.4464413) q[63];
ry(-1.4454685) q[62];
cz q[63],q[62];
ry(1.4454685) q[62];
ry(-1.4444725) q[61];
cz q[62],q[61];
ry(1.4444725) q[61];
ry(-1.4434523) q[60];
cz q[61],q[60];
ry(1.4434523) q[60];
ry(-1.442407) q[59];
cz q[60],q[59];
ry(1.442407) q[59];
ry(-1.4413356) q[58];
cz q[59],q[58];
ry(1.4413356) q[58];
ry(-1.4402368) q[57];
cz q[58],q[57];
ry(1.4402368) q[57];
ry(-1.4391096) q[56];
cz q[57],q[56];
ry(1.4391096) q[56];
ry(-1.4379527) q[55];
cz q[56],q[55];
ry(1.4379527) q[55];
ry(-1.4367648) q[54];
cz q[55],q[54];
ry(1.4367648) q[54];
ry(-1.4355444) q[53];
cz q[54],q[53];
ry(1.4355444) q[53];
ry(-1.43429) q[52];
cz q[53],q[52];
ry(1.43429) q[52];
ry(-1.4330001) q[51];
cz q[52],q[51];
ry(1.4330001) q[51];
ry(-1.4316729) q[50];
cz q[51],q[50];
ry(1.4316729) q[50];
ry(-1.4303066) q[49];
cz q[50],q[49];
ry(1.4303066) q[49];
ry(-1.4288993) q[48];
cz q[49],q[48];
ry(1.4288993) q[48];
ry(-1.4274488) q[47];
cz q[48],q[47];
ry(1.4274488) q[47];
ry(-1.4259528) q[46];
cz q[47],q[46];
ry(1.4259528) q[46];
ry(-1.4244091) q[45];
cz q[46],q[45];
ry(1.4244091) q[45];
ry(-1.4228149) q[44];
cz q[45],q[44];
ry(1.4228149) q[44];
ry(-1.4211674) q[43];
cz q[44],q[43];
ry(1.4211674) q[43];
ry(-1.4194637) q[42];
cz q[43],q[42];
ry(1.4194637) q[42];
ry(-1.4177004) q[41];
cz q[42],q[41];
ry(1.4177004) q[41];
ry(-1.415874) q[40];
cz q[41],q[40];
ry(1.415874) q[40];
ry(-1.4139806) q[39];
cz q[40],q[39];
ry(1.4139806) q[39];
ry(-1.4120161) q[38];
cz q[39],q[38];
ry(1.4120161) q[38];
ry(-1.4099758) q[37];
cz q[38],q[37];
ry(1.4099758) q[37];
ry(-1.4078548) q[36];
cz q[37],q[36];
ry(1.4078548) q[36];
ry(-1.4056476) q[35];
cz q[36],q[35];
ry(1.4056476) q[35];
ry(-1.4033482) q[34];
cz q[35],q[34];
ry(1.4033482) q[34];
ry(-1.40095) q[33];
cz q[34],q[33];
ry(1.40095) q[33];
ry(-1.3984457) q[32];
cz q[33],q[32];
ry(1.3984457) q[32];
ry(-1.3958273) q[31];
cz q[32],q[31];
ry(1.3958273) q[31];
ry(-1.3930857) q[30];
cz q[31],q[30];
ry(1.3930857) q[30];
ry(-1.3902111) q[29];
cz q[30],q[29];
ry(1.3902111) q[29];
ry(-1.3871923) q[28];
cz q[29],q[28];
ry(1.3871923) q[28];
ry(-1.3840169) q[27];
cz q[28],q[27];
ry(1.3840169) q[27];
ry(-1.3806707) q[26];
cz q[27],q[26];
ry(1.3806707) q[26];
ry(-1.377138) q[25];
cz q[26],q[25];
ry(1.377138) q[25];
ry(-1.3734008) q[24];
cz q[25],q[24];
ry(1.3734008) q[24];
ry(-1.3694384) q[23];
cz q[24],q[23];
ry(1.3694384) q[23];
ry(-1.3652274) q[22];
cz q[23],q[22];
ry(1.3652274) q[22];
ry(-1.3607406) q[21];
cz q[22],q[21];
ry(1.3607406) q[21];
ry(-1.3559465) q[20];
cz q[21],q[20];
ry(1.3559465) q[20];
ry(-1.3508083) q[19];
cz q[20],q[19];
ry(1.3508083) q[19];
ry(-1.3452829) q[18];
cz q[19],q[18];
ry(1.3452829) q[18];
ry(-1.339319) q[17];
cz q[18],q[17];
ry(1.339319) q[17];
ry(-1.3328552) q[16];
cz q[17],q[16];
ry(1.3328552) q[16];
ry(-1.3258177) q[15];
cz q[16],q[15];
ry(1.3258177) q[15];
ry(-1.3181161) q[14];
cz q[15],q[14];
ry(1.3181161) q[14];
ry(-1.3096389) q[13];
cz q[14],q[13];
ry(1.3096389) q[13];
ry(-1.3002466) q[12];
cz q[13],q[12];
ry(1.3002466) q[12];
ry(-1.2897614) q[11];
cz q[12],q[11];
ry(1.2897614) q[11];
ry(-1.2779536) q[10];
cz q[11],q[10];
ry(1.2779536) q[10];
ry(-1.264519) q[9];
cz q[10],q[9];
ry(1.264519) q[9];
ry(-1.2490458) q[8];
cz q[9],q[8];
ry(1.2490458) q[8];
ry(-1.2309594) q[7];
cz q[8],q[7];
ry(1.2309594) q[7];
ry(-1.2094292) q[6];
cz q[7],q[6];
ry(1.2094292) q[6];
ry(-1.1831996) q[5];
cz q[6],q[5];
ry(1.1831996) q[5];
ry(-1.150262) q[4];
cz q[5],q[4];
ry(1.150262) q[4];
ry(-1.1071487) q[3];
cz q[4],q[3];
ry(1.1071487) q[3];
ry(-pi/3) q[2];
cz q[3],q[2];
ry(pi/3) q[2];
ry(-0.95531662) q[1];
cz q[2],q[1];
ry(0.95531662) q[1];
ry(-pi/4) q[0];
cz q[1],q[0];
ry(pi/4) q[0];
cx q[116],q[117];
cx q[115],q[116];
cx q[114],q[115];
cx q[113],q[114];
cx q[112],q[113];
cx q[111],q[112];
cx q[110],q[111];
cx q[109],q[110];
cx q[108],q[109];
cx q[107],q[108];
cx q[106],q[107];
cx q[105],q[106];
cx q[104],q[105];
cx q[103],q[104];
cx q[102],q[103];
cx q[101],q[102];
cx q[100],q[101];
cx q[99],q[100];
cx q[98],q[99];
cx q[97],q[98];
cx q[96],q[97];
cx q[95],q[96];
cx q[94],q[95];
cx q[93],q[94];
cx q[92],q[93];
cx q[91],q[92];
cx q[90],q[91];
cx q[89],q[90];
cx q[88],q[89];
cx q[87],q[88];
cx q[86],q[87];
cx q[85],q[86];
cx q[84],q[85];
cx q[83],q[84];
cx q[82],q[83];
cx q[81],q[82];
cx q[80],q[81];
cx q[79],q[80];
cx q[78],q[79];
cx q[77],q[78];
cx q[76],q[77];
cx q[75],q[76];
cx q[74],q[75];
cx q[73],q[74];
cx q[72],q[73];
cx q[71],q[72];
cx q[70],q[71];
cx q[69],q[70];
cx q[68],q[69];
cx q[67],q[68];
cx q[66],q[67];
cx q[65],q[66];
cx q[64],q[65];
cx q[63],q[64];
cx q[62],q[63];
cx q[61],q[62];
cx q[60],q[61];
cx q[59],q[60];
cx q[58],q[59];
cx q[57],q[58];
cx q[56],q[57];
cx q[55],q[56];
cx q[54],q[55];
cx q[53],q[54];
cx q[52],q[53];
cx q[51],q[52];
cx q[50],q[51];
cx q[49],q[50];
cx q[48],q[49];
cx q[47],q[48];
cx q[46],q[47];
cx q[45],q[46];
cx q[44],q[45];
cx q[43],q[44];
cx q[42],q[43];
cx q[41],q[42];
cx q[40],q[41];
cx q[39],q[40];
cx q[38],q[39];
cx q[37],q[38];
cx q[36],q[37];
cx q[35],q[36];
cx q[34],q[35];
cx q[33],q[34];
cx q[32],q[33];
cx q[31],q[32];
cx q[30],q[31];
cx q[29],q[30];
cx q[28],q[29];
cx q[27],q[28];
cx q[26],q[27];
cx q[25],q[26];
cx q[24],q[25];
cx q[23],q[24];
cx q[22],q[23];
cx q[21],q[22];
cx q[20],q[21];
cx q[19],q[20];
cx q[18],q[19];
cx q[17],q[18];
cx q[16],q[17];
cx q[15],q[16];
cx q[14],q[15];
cx q[13],q[14];
cx q[12],q[13];
cx q[11],q[12];
cx q[10],q[11];
cx q[9],q[10];
cx q[8],q[9];
cx q[7],q[8];
cx q[6],q[7];
cx q[5],q[6];
cx q[4],q[5];
cx q[3],q[4];
cx q[2],q[3];
cx q[1],q[2];
cx q[0],q[1];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39],q[40],q[41],q[42],q[43],q[44],q[45],q[46],q[47],q[48],q[49],q[50],q[51],q[52],q[53],q[54],q[55],q[56],q[57],q[58],q[59],q[60],q[61],q[62],q[63],q[64],q[65],q[66],q[67],q[68],q[69],q[70],q[71],q[72],q[73],q[74],q[75],q[76],q[77],q[78],q[79],q[80],q[81],q[82],q[83],q[84],q[85],q[86],q[87],q[88],q[89],q[90],q[91],q[92],q[93],q[94],q[95],q[96],q[97],q[98],q[99],q[100],q[101],q[102],q[103],q[104],q[105],q[106],q[107],q[108],q[109],q[110],q[111],q[112],q[113],q[114],q[115],q[116],q[117];
measure q[0] -> meas[0];
measure q[1] -> meas[1];
measure q[2] -> meas[2];
measure q[3] -> meas[3];
measure q[4] -> meas[4];
measure q[5] -> meas[5];
measure q[6] -> meas[6];
measure q[7] -> meas[7];
measure q[8] -> meas[8];
measure q[9] -> meas[9];
measure q[10] -> meas[10];
measure q[11] -> meas[11];
measure q[12] -> meas[12];
measure q[13] -> meas[13];
measure q[14] -> meas[14];
measure q[15] -> meas[15];
measure q[16] -> meas[16];
measure q[17] -> meas[17];
measure q[18] -> meas[18];
measure q[19] -> meas[19];
measure q[20] -> meas[20];
measure q[21] -> meas[21];
measure q[22] -> meas[22];
measure q[23] -> meas[23];
measure q[24] -> meas[24];
measure q[25] -> meas[25];
measure q[26] -> meas[26];
measure q[27] -> meas[27];
measure q[28] -> meas[28];
measure q[29] -> meas[29];
measure q[30] -> meas[30];
measure q[31] -> meas[31];
measure q[32] -> meas[32];
measure q[33] -> meas[33];
measure q[34] -> meas[34];
measure q[35] -> meas[35];
measure q[36] -> meas[36];
measure q[37] -> meas[37];
measure q[38] -> meas[38];
measure q[39] -> meas[39];
measure q[40] -> meas[40];
measure q[41] -> meas[41];
measure q[42] -> meas[42];
measure q[43] -> meas[43];
measure q[44] -> meas[44];
measure q[45] -> meas[45];
measure q[46] -> meas[46];
measure q[47] -> meas[47];
measure q[48] -> meas[48];
measure q[49] -> meas[49];
measure q[50] -> meas[50];
measure q[51] -> meas[51];
measure q[52] -> meas[52];
measure q[53] -> meas[53];
measure q[54] -> meas[54];
measure q[55] -> meas[55];
measure q[56] -> meas[56];
measure q[57] -> meas[57];
measure q[58] -> meas[58];
measure q[59] -> meas[59];
measure q[60] -> meas[60];
measure q[61] -> meas[61];
measure q[62] -> meas[62];
measure q[63] -> meas[63];
measure q[64] -> meas[64];
measure q[65] -> meas[65];
measure q[66] -> meas[66];
measure q[67] -> meas[67];
measure q[68] -> meas[68];
measure q[69] -> meas[69];
measure q[70] -> meas[70];
measure q[71] -> meas[71];
measure q[72] -> meas[72];
measure q[73] -> meas[73];
measure q[74] -> meas[74];
measure q[75] -> meas[75];
measure q[76] -> meas[76];
measure q[77] -> meas[77];
measure q[78] -> meas[78];
measure q[79] -> meas[79];
measure q[80] -> meas[80];
measure q[81] -> meas[81];
measure q[82] -> meas[82];
measure q[83] -> meas[83];
measure q[84] -> meas[84];
measure q[85] -> meas[85];
measure q[86] -> meas[86];
measure q[87] -> meas[87];
measure q[88] -> meas[88];
measure q[89] -> meas[89];
measure q[90] -> meas[90];
measure q[91] -> meas[91];
measure q[92] -> meas[92];
measure q[93] -> meas[93];
measure q[94] -> meas[94];
measure q[95] -> meas[95];
measure q[96] -> meas[96];
measure q[97] -> meas[97];
measure q[98] -> meas[98];
measure q[99] -> meas[99];
measure q[100] -> meas[100];
measure q[101] -> meas[101];
measure q[102] -> meas[102];
measure q[103] -> meas[103];
measure q[104] -> meas[104];
measure q[105] -> meas[105];
measure q[106] -> meas[106];
measure q[107] -> meas[107];
measure q[108] -> meas[108];
measure q[109] -> meas[109];
measure q[110] -> meas[110];
measure q[111] -> meas[111];
measure q[112] -> meas[112];
measure q[113] -> meas[113];
measure q[114] -> meas[114];
measure q[115] -> meas[115];
measure q[116] -> meas[116];
measure q[117] -> meas[117];
'''

# %%
benchmarks['multiplier-75'] = '''
OPENQASM 2.0;
include "qelib1.inc";
qreg q0[75];
creg c0[15];
x q0[73];
x q0[69];
x q0[68];
x q0[67];
x q0[57];
x q0[56];
x q0[53];
ccx q0[60],q0[45],q0[1];
ccx q0[60],q0[46],q0[4];
ccx q0[60],q0[47],q0[7];
ccx q0[60],q0[48],q0[10];
ccx q0[60],q0[49],q0[13];
ccx q0[60],q0[50],q0[16];
ccx q0[60],q0[51],q0[19];
ccx q0[60],q0[52],q0[22];
ccx q0[60],q0[53],q0[25];
ccx q0[60],q0[54],q0[28];
ccx q0[60],q0[55],q0[31];
ccx q0[60],q0[56],q0[34];
ccx q0[60],q0[57],q0[37];
ccx q0[60],q0[58],q0[40];
ccx q0[60],q0[59],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[60],q0[45],q0[1];
ccx q0[60],q0[46],q0[4];
ccx q0[60],q0[47],q0[7];
ccx q0[60],q0[48],q0[10];
ccx q0[60],q0[49],q0[13];
ccx q0[60],q0[50],q0[16];
ccx q0[60],q0[51],q0[19];
ccx q0[60],q0[52],q0[22];
ccx q0[60],q0[53],q0[25];
ccx q0[60],q0[54],q0[28];
ccx q0[60],q0[55],q0[31];
ccx q0[60],q0[56],q0[34];
ccx q0[60],q0[57],q0[37];
ccx q0[60],q0[58],q0[40];
ccx q0[60],q0[59],q0[43];
ccx q0[61],q0[45],q0[4];
ccx q0[61],q0[46],q0[7];
ccx q0[61],q0[47],q0[10];
ccx q0[61],q0[48],q0[13];
ccx q0[61],q0[49],q0[16];
ccx q0[61],q0[50],q0[19];
ccx q0[61],q0[51],q0[22];
ccx q0[61],q0[52],q0[25];
ccx q0[61],q0[53],q0[28];
ccx q0[61],q0[54],q0[31];
ccx q0[61],q0[55],q0[34];
ccx q0[61],q0[56],q0[37];
ccx q0[61],q0[57],q0[40];
ccx q0[61],q0[58],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[61],q0[45],q0[4];
ccx q0[61],q0[46],q0[7];
ccx q0[61],q0[47],q0[10];
ccx q0[61],q0[48],q0[13];
ccx q0[61],q0[49],q0[16];
ccx q0[61],q0[50],q0[19];
ccx q0[61],q0[51],q0[22];
ccx q0[61],q0[52],q0[25];
ccx q0[61],q0[53],q0[28];
ccx q0[61],q0[54],q0[31];
ccx q0[61],q0[55],q0[34];
ccx q0[61],q0[56],q0[37];
ccx q0[61],q0[57],q0[40];
ccx q0[61],q0[58],q0[43];
ccx q0[62],q0[45],q0[7];
ccx q0[62],q0[46],q0[10];
ccx q0[62],q0[47],q0[13];
ccx q0[62],q0[48],q0[16];
ccx q0[62],q0[49],q0[19];
ccx q0[62],q0[50],q0[22];
ccx q0[62],q0[51],q0[25];
ccx q0[62],q0[52],q0[28];
ccx q0[62],q0[53],q0[31];
ccx q0[62],q0[54],q0[34];
ccx q0[62],q0[55],q0[37];
ccx q0[62],q0[56],q0[40];
ccx q0[62],q0[57],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[62],q0[45],q0[7];
ccx q0[62],q0[46],q0[10];
ccx q0[62],q0[47],q0[13];
ccx q0[62],q0[48],q0[16];
ccx q0[62],q0[49],q0[19];
ccx q0[62],q0[50],q0[22];
ccx q0[62],q0[51],q0[25];
ccx q0[62],q0[52],q0[28];
ccx q0[62],q0[53],q0[31];
ccx q0[62],q0[54],q0[34];
ccx q0[62],q0[55],q0[37];
ccx q0[62],q0[56],q0[40];
ccx q0[62],q0[57],q0[43];
ccx q0[63],q0[45],q0[10];
ccx q0[63],q0[46],q0[13];
ccx q0[63],q0[47],q0[16];
ccx q0[63],q0[48],q0[19];
ccx q0[63],q0[49],q0[22];
ccx q0[63],q0[50],q0[25];
ccx q0[63],q0[51],q0[28];
ccx q0[63],q0[52],q0[31];
ccx q0[63],q0[53],q0[34];
ccx q0[63],q0[54],q0[37];
ccx q0[63],q0[55],q0[40];
ccx q0[63],q0[56],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[63],q0[45],q0[10];
ccx q0[63],q0[46],q0[13];
ccx q0[63],q0[47],q0[16];
ccx q0[63],q0[48],q0[19];
ccx q0[63],q0[49],q0[22];
ccx q0[63],q0[50],q0[25];
ccx q0[63],q0[51],q0[28];
ccx q0[63],q0[52],q0[31];
ccx q0[63],q0[53],q0[34];
ccx q0[63],q0[54],q0[37];
ccx q0[63],q0[55],q0[40];
ccx q0[63],q0[56],q0[43];
ccx q0[64],q0[45],q0[13];
ccx q0[64],q0[46],q0[16];
ccx q0[64],q0[47],q0[19];
ccx q0[64],q0[48],q0[22];
ccx q0[64],q0[49],q0[25];
ccx q0[64],q0[50],q0[28];
ccx q0[64],q0[51],q0[31];
ccx q0[64],q0[52],q0[34];
ccx q0[64],q0[53],q0[37];
ccx q0[64],q0[54],q0[40];
ccx q0[64],q0[55],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[64],q0[45],q0[13];
ccx q0[64],q0[46],q0[16];
ccx q0[64],q0[47],q0[19];
ccx q0[64],q0[48],q0[22];
ccx q0[64],q0[49],q0[25];
ccx q0[64],q0[50],q0[28];
ccx q0[64],q0[51],q0[31];
ccx q0[64],q0[52],q0[34];
ccx q0[64],q0[53],q0[37];
ccx q0[64],q0[54],q0[40];
ccx q0[64],q0[55],q0[43];
ccx q0[65],q0[45],q0[16];
ccx q0[65],q0[46],q0[19];
ccx q0[65],q0[47],q0[22];
ccx q0[65],q0[48],q0[25];
ccx q0[65],q0[49],q0[28];
ccx q0[65],q0[50],q0[31];
ccx q0[65],q0[51],q0[34];
ccx q0[65],q0[52],q0[37];
ccx q0[65],q0[53],q0[40];
ccx q0[65],q0[54],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[65],q0[45],q0[16];
ccx q0[65],q0[46],q0[19];
ccx q0[65],q0[47],q0[22];
ccx q0[65],q0[48],q0[25];
ccx q0[65],q0[49],q0[28];
ccx q0[65],q0[50],q0[31];
ccx q0[65],q0[51],q0[34];
ccx q0[65],q0[52],q0[37];
ccx q0[65],q0[53],q0[40];
ccx q0[65],q0[54],q0[43];
ccx q0[66],q0[45],q0[19];
ccx q0[66],q0[46],q0[22];
ccx q0[66],q0[47],q0[25];
ccx q0[66],q0[48],q0[28];
ccx q0[66],q0[49],q0[31];
ccx q0[66],q0[50],q0[34];
ccx q0[66],q0[51],q0[37];
ccx q0[66],q0[52],q0[40];
ccx q0[66],q0[53],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[66],q0[45],q0[19];
ccx q0[66],q0[46],q0[22];
ccx q0[66],q0[47],q0[25];
ccx q0[66],q0[48],q0[28];
ccx q0[66],q0[49],q0[31];
ccx q0[66],q0[50],q0[34];
ccx q0[66],q0[51],q0[37];
ccx q0[66],q0[52],q0[40];
ccx q0[66],q0[53],q0[43];
ccx q0[67],q0[45],q0[22];
ccx q0[67],q0[46],q0[25];
ccx q0[67],q0[47],q0[28];
ccx q0[67],q0[48],q0[31];
ccx q0[67],q0[49],q0[34];
ccx q0[67],q0[50],q0[37];
ccx q0[67],q0[51],q0[40];
ccx q0[67],q0[52],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[67],q0[45],q0[22];
ccx q0[67],q0[46],q0[25];
ccx q0[67],q0[47],q0[28];
ccx q0[67],q0[48],q0[31];
ccx q0[67],q0[49],q0[34];
ccx q0[67],q0[50],q0[37];
ccx q0[67],q0[51],q0[40];
ccx q0[67],q0[52],q0[43];
ccx q0[68],q0[45],q0[25];
ccx q0[68],q0[46],q0[28];
ccx q0[68],q0[47],q0[31];
ccx q0[68],q0[48],q0[34];
ccx q0[68],q0[49],q0[37];
ccx q0[68],q0[50],q0[40];
ccx q0[68],q0[51],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[68],q0[45],q0[25];
ccx q0[68],q0[46],q0[28];
ccx q0[68],q0[47],q0[31];
ccx q0[68],q0[48],q0[34];
ccx q0[68],q0[49],q0[37];
ccx q0[68],q0[50],q0[40];
ccx q0[68],q0[51],q0[43];
ccx q0[69],q0[45],q0[28];
ccx q0[69],q0[46],q0[31];
ccx q0[69],q0[47],q0[34];
ccx q0[69],q0[48],q0[37];
ccx q0[69],q0[49],q0[40];
ccx q0[69],q0[50],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[69],q0[45],q0[28];
ccx q0[69],q0[46],q0[31];
ccx q0[69],q0[47],q0[34];
ccx q0[69],q0[48],q0[37];
ccx q0[69],q0[49],q0[40];
ccx q0[69],q0[50],q0[43];
ccx q0[70],q0[45],q0[31];
ccx q0[70],q0[46],q0[34];
ccx q0[70],q0[47],q0[37];
ccx q0[70],q0[48],q0[40];
ccx q0[70],q0[49],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[70],q0[45],q0[31];
ccx q0[70],q0[46],q0[34];
ccx q0[70],q0[47],q0[37];
ccx q0[70],q0[48],q0[40];
ccx q0[70],q0[49],q0[43];
ccx q0[71],q0[45],q0[34];
ccx q0[71],q0[46],q0[37];
ccx q0[71],q0[47],q0[40];
ccx q0[71],q0[48],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[71],q0[45],q0[34];
ccx q0[71],q0[46],q0[37];
ccx q0[71],q0[47],q0[40];
ccx q0[71],q0[48],q0[43];
ccx q0[72],q0[45],q0[37];
ccx q0[72],q0[46],q0[40];
ccx q0[72],q0[47],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[72],q0[45],q0[37];
ccx q0[72],q0[46],q0[40];
ccx q0[72],q0[47],q0[43];
ccx q0[73],q0[45],q0[40];
ccx q0[73],q0[46],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[73],q0[45],q0[40];
ccx q0[73],q0[46],q0[43];
ccx q0[74],q0[45],q0[43];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[0],q0[2],q0[3];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[3],q0[5],q0[6];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[6],q0[8],q0[9];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[9],q0[11],q0[12];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[12],q0[14],q0[15];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[15],q0[17],q0[18];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[18],q0[20],q0[21];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[21],q0[23],q0[24];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[24],q0[26],q0[27];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[27],q0[29],q0[30];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[30],q0[32],q0[33];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[33],q0[35],q0[36];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[36],q0[38],q0[39];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[39],q0[41],q0[42];
cx q0[43],q0[44];
cx q0[42],q0[44];
ccx q0[39],q0[41],q0[42];
cx q0[40],q0[41];
ccx q0[40],q0[41],q0[42];
cx q0[40],q0[41];
cx q0[39],q0[41];
ccx q0[36],q0[38],q0[39];
cx q0[37],q0[38];
ccx q0[37],q0[38],q0[39];
cx q0[37],q0[38];
cx q0[36],q0[38];
ccx q0[33],q0[35],q0[36];
cx q0[34],q0[35];
ccx q0[34],q0[35],q0[36];
cx q0[34],q0[35];
cx q0[33],q0[35];
ccx q0[30],q0[32],q0[33];
cx q0[31],q0[32];
ccx q0[31],q0[32],q0[33];
cx q0[31],q0[32];
cx q0[30],q0[32];
ccx q0[27],q0[29],q0[30];
cx q0[28],q0[29];
ccx q0[28],q0[29],q0[30];
cx q0[28],q0[29];
cx q0[27],q0[29];
ccx q0[24],q0[26],q0[27];
cx q0[25],q0[26];
ccx q0[25],q0[26],q0[27];
cx q0[25],q0[26];
cx q0[24],q0[26];
ccx q0[21],q0[23],q0[24];
cx q0[22],q0[23];
ccx q0[22],q0[23],q0[24];
cx q0[22],q0[23];
cx q0[21],q0[23];
ccx q0[18],q0[20],q0[21];
cx q0[19],q0[20];
ccx q0[19],q0[20],q0[21];
cx q0[19],q0[20];
cx q0[18],q0[20];
ccx q0[15],q0[17],q0[18];
cx q0[16],q0[17];
ccx q0[16],q0[17],q0[18];
cx q0[16],q0[17];
cx q0[15],q0[17];
ccx q0[12],q0[14],q0[15];
cx q0[13],q0[14];
ccx q0[13],q0[14],q0[15];
cx q0[13],q0[14];
cx q0[12],q0[14];
ccx q0[9],q0[11],q0[12];
cx q0[10],q0[11];
ccx q0[10],q0[11],q0[12];
cx q0[10],q0[11];
cx q0[9],q0[11];
ccx q0[6],q0[8],q0[9];
cx q0[7],q0[8];
ccx q0[7],q0[8],q0[9];
cx q0[7],q0[8];
cx q0[6],q0[8];
ccx q0[3],q0[5],q0[6];
cx q0[4],q0[5];
ccx q0[4],q0[5],q0[6];
cx q0[4],q0[5];
cx q0[3],q0[5];
ccx q0[0],q0[2],q0[3];
cx q0[1],q0[2];
ccx q0[1],q0[2],q0[3];
cx q0[1],q0[2];
cx q0[0],q0[2];
ccx q0[74],q0[45],q0[43];
measure q0[2] -> c0[0];
measure q0[5] -> c0[1];
measure q0[8] -> c0[2];
measure q0[11] -> c0[3];
measure q0[14] -> c0[4];
measure q0[17] -> c0[5];
measure q0[20] -> c0[6];
measure q0[23] -> c0[7];
measure q0[26] -> c0[8];
measure q0[29] -> c0[9];
measure q0[32] -> c0[10];
measure q0[35] -> c0[11];
measure q0[38] -> c0[12];
measure q0[41] -> c0[13];
measure q0[44] -> c0[14];
'''

# %%
print(benchmarks.keys())
bms = ['shor-15', 'ising-66', 'ising-98', 'multiplier-75', 'adder-118', 'qpe-80', 'qpe-120', 'qft-80', 'qft-160', 'wstate-118']
temp = {i:QuantumCircuit.from_qasm_str(benchmarks[i]) for i in benchmarks.keys() if i in bms}
benchmarks = temp
print(benchmarks.keys())
# Out:
# dict_keys(['shor-15', 'ising-66', 'wstate-60', 'multiplier-45', 'qft-160', 'adder-433', 'cc-151', 'qft-80', 'ising-98', 'adder-118', 'qpe-80', 'qpe-120', 'wstate-118', 'multiplier-75'])
# dict_keys(['shor-15', 'ising-66', 'qft-160', 'qft-80', 'ising-98', 'adder-118', 'qpe-80', 'qpe-120', 'wstate-118', 'multiplier-75'])

# %%
results = {}
for key in benchmarks.keys():
    print(key)
    circ = get_transpiled_circ(benchmarks[key], backend)
    job = backend.run(circ, qubitParams={"name":"qubit_gate_ns_e3"})
    # job_monitor(job)
    result = job.result()
    results[key] = result
# Out:
# shor-15
# [INFO]   qubit count: 18
# [INFO]   gate counts
# [INFO]   - rz: 18964
# [INFO]   - cx: 14328
# [INFO]   - h: 1234
# [INFO]   - rx: 192
# [INFO]   - ccx: 32
# [INFO]   - measure: 18
# [INFO]   - swap: 4
# [INFO]   - x: 1
# [INFO]   - barrier: 1
# .........ising-66
# [INFO]   qubit count: 66
# [INFO]   gate counts
# [INFO]   - rz: 392
# [INFO]   - h: 198
# [INFO]   - cx: 130
# [INFO]   - measure: 66
# [INFO]   - barrier: 1
# ......qft-160
# [INFO]   qubit count: 160
# [INFO]   gate counts
# [INFO]   - rz: 38160
# [INFO]   - cx: 25440
# [INFO]   - h: 160
# [INFO]   - measure: 160
# [INFO]   - barrier: 1
# .........qft-80
# [INFO]   qubit count: 80
# [INFO]   gate counts
# [INFO]   - rz: 9480
# [INFO]   - cx: 6320
# [INFO]   - h: 80
# [INFO]   - measure: 80
# [INFO]   - swap: 40
# [INFO]   - barrier: 1
# .........ising-98
# [INFO]   qubit count: 98
# [INFO]   gate counts
# [INFO]   - rz: 584
# [INFO]   - h: 294
# [INFO]   - cx: 194
# [INFO]   - measure: 98
# ...

# %%
print(results)
# Out:
# {'shor-15': {'status': 'success', 'jobParams': {'qecScheme': {'name': 'surface_code', 'errorCorrectionThreshold': 0.01, 'crossingPrefactor': 0.03, 'logicalCycleTime': '(4 * twoQubitGateTime + 2 * oneQubitMeasurementTime) * codeDistance', 'physicalQubitsPerLogicalQubit': '2 * codeDistance * codeDistance', 'maxCodeDistance': 50}, 'errorBudget': 0.001, 'qubitParams': {'instructionSet': 'GateBased', 'name': 'qubit_gate_ns_e3', 'oneQubitMeasurementTime': '100 ns', 'oneQubitGateTime': '50 ns', 'twoQubitGateTime': '50 ns', 'tGateTime': '50 ns', 'oneQubitMeasurementErrorRate': 0.001, 'oneQubitGateErrorRate': 0.001, 'twoQubitGateErrorRate': 0.001, 'tGateErrorRate': 0.001, 'idleErrorRate': 0.001}}, 'physicalCounts': {'physicalQubits': 496322, 'runtime': 807112400, 'rqops': 7205883, 'breakdown': {'algorithmicLogicalQubits': 49, 'algorithmicLogicalDepth': 118693, 'logicalDepth': 118693, 'numTstates': 200738, 'clockFrequency': 147058.82352941178, 'numTfactories': 26, 'numTfactoryRuns': 7721, 'phy
# ...

# %%
estimates = results

magic_states = {}
cycles = {}
freq = {}
for key, val in estimates.items():
    magic_states[key] = val['physicalCounts']['breakdown']['numTstates']
    cycles[key] = val['physicalCounts']['breakdown']['algorithmicLogicalDepth']
    freq[key + '\n(%i)'%(cycles[key])] = magic_states[key] / cycles[key]
    pass
print(magic_states, cycles, freq)
# Out:
# {'shor-15': 200738, 'ising-66': 4160, 'qft-160': 355758, 'qft-80': 133617, 'ising-98': 6208, 'adder-118': 416, 'qpe-80': 135726, 'qpe-120': 229326, 'wstate-118': 3714, 'multiplier-75': 4320} {'shor-15': 118693, 'ising-66': 422, 'qft-160': 31325, 'qft-80': 13246, 'ising-98': 582, 'adder-118': 430, 'qpe-80': 16225, 'qpe-120': 25865, 'wstate-118': 2224, 'multiplier-75': 3255} {'shor-15\n(118693)': 1.6912370569452284, 'ising-66\n(422)': 9.85781990521327, 'qft-160\n(31325)': 11.356999201915404, 'qft-80\n(13246)': 10.087347123659972, 'ising-98\n(582)': 10.666666666666666, 'adder-118\n(430)': 0.9674418604651163, 'qpe-80\n(16225)': 8.365238828967643, 'qpe-120\n(25865)': 8.866267156388943, 'wstate-118\n(2224)': 1.6699640287769784, 'multiplier-75\n(3255)': 1.327188940092166}
